# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafiryd/Rafiryd/blob/rafiryd/skripsi27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Referensi: https://www.linkedin.com/pulse/how-scrape-google-play-reviews-4-simple-steps-using-python-kundi/

# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.10/dist-packages (1.2.4)

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

import seaborn as sns

# %%
#Scrape desired number of reviews
#Run kode ini jika ingin scrape data dengan jumlah tertentu. Ganti (misal, ingin scrape sejumlah 1000, maka ganti kode , count = 1000 )

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.bukalapak.android',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=1300, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %% [markdown]
# Problems slovlig tools = mencari akar permasalahan pada suatu masalah
#
# 5 why
#
# metode mencari problems sloving dengan cara menanyakan apa penyebab permasalahaan muncul dan mencari jawabannya. hal ini di lakUkan berkali klai sampai permasalahan dapat tergambar dengan jelas
#
# action priority
#
# diagram yang dapat di gunakan untuk mencari prioritas masalah berdasarkan impact atas benefit yang bisa diberikan dengan diagram ini kita memilih masalah yang impactnya mayoritas dari permasalahan yang ada.
#
# fishbone digram
#
# digram yang dapat di gunakan untuk merinci masalah dan membantu mencari akar masalah yang dapat dilihat dari beberapa point of view
#
# flowchart/algo
#
# metode pemecahan masalah dengan cara memetakan flow atau membuat pseudo algoritma yang untuk menentukan masalah dan cara untuk mencari solusinya secara sistematis

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId        userName  \
# 0  f2e26548-83d2-4bcf-bac3-6dc9db1cb12d    Nizar Rayyan
# 1  08f05b3b-be88-43f2-a300-aaebf6585655  Ganjar Hermadi
# 2  5ef5f760-f72a-473b-9fb3-48e5556cefc6      Fandy Komo
# 3  37b934e6-6cfe-4e2b-8a8b-fb8061f2c7fe     Dwi Indarti
# 4  17640730-6dcd-4836-9cd9-2e99a36d2be6    Yuda Nugraha
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# 1  https://play-lh.googleusercontent.com/a-/AD_cM...
# 2  https://play-lh.googleusercontent.com/a/AAcHTt...
# 3  https://play-lh.googleusercontent.com/a/AAcHTt...
# 4  https://play-lh.googleusercontent.com/a-/AD_cM...
#
#                                              content  score  thumbsUpCount  \
# 0  Paylater ngk bener.. selalu di batalkan otomat...      1            344
# 1  Pengembalian dana otomatis ga berfungsi...sy l...      1             67
# 2  Tambah kesini buka lapak tambah kurang bagus p...      1            190
# 3  Setelah dibayar lunas,paylater tidak bisa dibu...      1              0
# 4  Di update malah ngaco ini aplikasi, menu baran...      3             17
#
#   reviewCreatedVersion                  at  \
# 0               5.31.3 2023-04-16 23:03:31
# 1               5.32.1 2023-05-27 23:42:34
# 2               5.31.3 2023-05-05 02:37:25
# 3               5.31.3 2023-06-06 04:19:17
# 4               5.32.2 2023-05-31 10:59:36
#
#                                         replyContent           repliedAt  \
# 0  Hai, mohon maaf atas ketidaknyamanannya. Jika ... 2020-03-06 11:44:30
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4                                               None                 NaT
#
#   appVersion
# 0     5.31.3
# 1     5.32.1
# 2     5.31.3
# 3     5.31.3
# 4     5.32.2

# %%
len(df_busu.index) #count the number of data we got
# Out:
# 1300

# %%
df_busu[['userName', 'score','at', 'content']].tail()  #preview userName, rating, date-time, and reviews only
# Out:
#               userName  score                  at  \
# 1295    Aidil Pridiyah      5 2023-05-20 01:05:47
# 1296     Moja Maharani      4 2023-05-19 06:37:48
# 1297     Putri Sentani      5 2023-05-21 11:23:13
# 1298  Novian Syahputra      3 2023-05-10 10:55:50
# 1299            Payung      1 2023-05-23 09:16:07
#
#                                                 content
# 1295                          Tingkatkan terus promonya
# 1296  Ini bonus undang referal kok belum masuk ini s...
# 1297  Sangat bagus kiriman cepat sampai terimakasih ...
# 1298  Kok pelapaknya ada yang ga benerrrrrr....!!! K...
# 1299  WOY Transaksi gua jadi ga jelas. gara gara cha...

# %%
name_dataframe = df_busu.loc[:,["userName", "score", "at", "content"]]
name_dataframe.rename(columns={"userName": "Nama pengguna", "score":"Rating", "at": "Date", "content": "Ulasan"}, inplace=True)

# %%
name_dataframe.tail()
# Out:
#          Nama pengguna  Rating                Date  \
# 1295    Aidil Pridiyah       5 2023-05-20 01:05:47
# 1296     Moja Maharani       4 2023-05-19 06:37:48
# 1297     Putri Sentani       5 2023-05-21 11:23:13
# 1298  Novian Syahputra       3 2023-05-10 10:55:50
# 1299            Payung       1 2023-05-23 09:16:07
#
#                                                  Ulasan
# 1295                          Tingkatkan terus promonya
# 1296  Ini bonus undang referal kok belum masuk ini s...
# 1297  Sangat bagus kiriman cepat sampai terimakasih ...
# 1298  Kok pelapaknya ada yang ga benerrrrrr....!!! K...
# 1299  WOY Transaksi gua jadi ga jelas. gara gara cha...

# %%
name_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nama pengguna  1300 non-null   object
#  1   Rating         1300 non-null   int64
#  2   Date           1300 non-null   datetime64[ns]
#  3   Ulasan         1300 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 40.8+ KB

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].astype(str)
name_dataframe.head()
# Out:
#     Nama pengguna  Rating                Date  \
# 0    Nizar Rayyan       1 2023-04-16 23:03:31
# 1  Ganjar Hermadi       1 2023-05-27 23:42:34
# 2      Fandy Komo       1 2023-05-05 02:37:25
# 3     Dwi Indarti       1 2023-06-06 04:19:17
# 4    Yuda Nugraha       3 2023-05-31 10:59:36
#
#                                               Ulasan
# 0  Paylater ngk bener.. selalu di batalkan otomat...
# 1  Pengembalian dana otomatis ga berfungsi...sy l...
# 2  Tambah kesini buka lapak tambah kurang bagus p...
# 3  Setelah dibayar lunas,paylater tidak bisa dibu...
# 4  Di update malah ngaco ini aplikasi, menu baran...

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].str.lower()

# %%
import string 
import re 
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

def remove_links(text):
    # menghapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus URL
    return text.replace("http://", " ").replace("https://", " ")
                
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_links)

# %%
#menghapus number
def remove_number(text):
    return  re.sub(r"\d+", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_number)

# %%
#menghapus punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_punctuation)

# %%
# menghapus single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_singl_char)

# %%
# Tokenisasi 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

name_dataframe['Ulasan_tokenize'] = name_dataframe['Ulasan'].apply(word_tokenize_wrapper)

# %%
name_dataframe
# Out:
#          Nama pengguna  Rating                Date  \
# 0         Nizar Rayyan       1 2023-04-16 23:03:31
# 1       Ganjar Hermadi       1 2023-05-27 23:42:34
# 2           Fandy Komo       1 2023-05-05 02:37:25
# 3          Dwi Indarti       1 2023-06-06 04:19:17
# 4         Yuda Nugraha       3 2023-05-31 10:59:36
# ...                ...     ...                 ...
# 1295    Aidil Pridiyah       5 2023-05-20 01:05:47
# 1296     Moja Maharani       4 2023-05-19 06:37:48
# 1297     Putri Sentani       5 2023-05-21 11:23:13
# 1298  Novian Syahputra       3 2023-05-10 10:55:50
# 1299            Payung       1 2023-05-23 09:16:07
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     pengembalian dana otomatis ga berfungsisy lg b...
# 2     tambah kesini buka lapak tambah kurang bagus p...
# 3     setelah dibayar lunaspaylater tidak bisa dibua...
# 4     di update malah ngaco ini aplikasi menu barang...
# ...                                                 ...
# 1295                          tingkatkan terus promonya
# 1296  ini bonus undang referal kok belum masuk ini s...
# 1297  sangat bagus kiriman cepat sampai terimakasih ...
# 1298  kok pelapaknya ada yang ga benerrrrrr klo niat...
# 1299  woy transaksi gua jadi ga jelas gara gara chat...
#
#                                         Ulasan_tokenize
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3     [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4     [di, update, malah, ngaco, ini, aplikasi, menu...
# ...                                                 ...
# 1295                      [tingkatkan, terus, promonya]
# 1296  [ini, bonus, undang, referal, kok, belum, masu...
# 1297  [sangat, bagus, kiriman, cepat, sampai, terima...
# 1298  [kok, pelapaknya, ada, yang, ga, benerrrrrr, k...
# 1299  [woy, transaksi, gua, jadi, ga, jelas, gara, g...
#
# [1300 rows x 5 columns]

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize'], dtype='object')

# %%
#Run This Code to Sort the Data By Date 
# tanggal 26-04-2022 sampai 12-10-2022

new_df = name_dataframe[['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize']]
sorted_df = new_df.sort_values(by='Date', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#        Nama pengguna  Rating                Date  \
# 669    Wawan Ganteng       1 2023-06-08 02:40:28
# 934         pras tyo       5 2023-06-07 13:43:02
# 759      Regi Wirata       4 2023-06-07 11:44:47
# 1163  Suvendal Basri       5 2023-06-07 10:40:43
# 205         M. Rusli       5 2023-06-07 09:59:07
#
#                                                  Ulasan  \
# 669   aplikasi kayak taekk mau komplain aja susah ba...
# 934                                transaksi aman mudah
# 759   setelah di update ini kenapa fitur untuk mengi...
# 1163                  selama ini selalu lancar dan aman
# 205   mempermudah belanja yg kita perlukandengan onl...
#
#                                         Ulasan_tokenize
# 669   [aplikasi, kayak, taekk, mau, komplain, aja, s...
# 934                            [transaksi, aman, mudah]
# 759   [setelah, di, update, ini, kenapa, fitur, untu...
# 1163           [selama, ini, selalu, lancar, dan, aman]
# 205   [mempermudah, belanja, yg, kita, perlukandenga...

# %%
sorted_df.dtypes
# Out:
# Nama pengguna              object
# Rating                      int64
# Date               datetime64[ns]
# Ulasan                     object
# Ulasan_tokenize            object
# dtype: object

# %%
import pandas as pd

# Assuming you have a DataFrame named ulasan with columns 'Ulasan_tokenize' and 'Ulasan_ears'

word_to_erase = 'nya'  # Replace 'word' with the word you want to erase

name_dataframe["ulasan_ears"] = name_dataframe['Ulasan_tokenize'].apply(lambda x: [word for word in x if word != word_to_erase])

print(name_dataframe)
# Out:
#          Nama pengguna  Rating                Date  \
# 0         Nizar Rayyan       1 2023-04-16 23:03:31
# 1       Ganjar Hermadi       1 2023-05-27 23:42:34
# 2           Fandy Komo       1 2023-05-05 02:37:25
# 3          Dwi Indarti       1 2023-06-06 04:19:17
# 4         Yuda Nugraha       3 2023-05-31 10:59:36
# ...                ...     ...                 ...
# 1295    Aidil Pridiyah       5 2023-05-20 01:05:47
# 1296     Moja Maharani       4 2023-05-19 06:37:48
# 1297     Putri Sentani       5 2023-05-21 11:23:13
# 1298  Novian Syahputra       3 2023-05-10 10:55:50
# 1299            Payung       1 2023-05-23 09:16:07
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     pengembalian dana otomatis ga berfungsisy lg b...
# 2     tambah kesini buka lapak tambah kurang bagus p...
# 3     setelah dibayar lunaspaylater tidak bisa dibua...
# 4     di update malah ngaco ini aplikasi menu barang...
# ...                                                 ...
# 1295                          tingkatkan terus promonya
# 1296  ini bonus undang referal kok belum masuk ini s...
# 1297  sangat bagus kiriman cepat sampai terimakasih ...
# 1298  kok pelapaknya ada yang ga benerrrrrr klo niat...
# 1299  woy transaksi gua jadi ga jelas gara gara chat...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3     [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4     [di, update, malah, ngaco, ini, aplikasi, menu...
# ...                                                 ...
# 1295                      [tingkatkan, terus, promonya]
# 1296  [ini, bonus, undang, referal, kok, belum, masu...
# 1297  [sangat, bagus, kiriman, cepat, sampai, terima...
# 1298  [kok, pelapaknya, ada, yang, ga, benerrrrrr, k...
# 1299  [woy, transaksi, gua, jadi, ga, jelas, gara, g...
#
#                                             ulasan_ears
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3     [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4     [di, update, malah, ngaco, ini, aplikasi, menu...
# ...                                                 ...
# 1295                      [tingkatkan, terus, promonya]
# 1296  [ini, bonus, undang, referal, kok, belum, masu...
# 1297  [sangat, bagus, kiriman, cepat, sampai, terima...
# 1298  [kok, pelapaknya, ada, yang, ga, benerrrrrr, k...
# 1299  [woy, transaksi, gua, jadi, ga, jelas, gara, g...
#
# [1300 rows x 6 columns]

# %%
name_dataframe.head()
# Out:
#     Nama pengguna  Rating                Date  \
# 0    Nizar Rayyan       1 2023-04-16 23:03:31
# 1  Ganjar Hermadi       1 2023-05-27 23:42:34
# 2      Fandy Komo       1 2023-05-05 02:37:25
# 3     Dwi Indarti       1 2023-06-06 04:19:17
# 4    Yuda Nugraha       3 2023-05-31 10:59:36
#
#                                               Ulasan  \
# 0  paylater ngk bener selalu di batalkan otomatis...
# 1  pengembalian dana otomatis ga berfungsisy lg b...
# 2  tambah kesini buka lapak tambah kurang bagus p...
# 3  setelah dibayar lunaspaylater tidak bisa dibua...
# 4  di update malah ngaco ini aplikasi menu barang...
#
#                                      Ulasan_tokenize  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [pengembalian, dana, otomatis, ga, berfungsisy...
# 2  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3  [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4  [di, update, malah, ngaco, ini, aplikasi, menu...
#
#                                          ulasan_ears
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [pengembalian, dana, otomatis, ga, berfungsisy...
# 2  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3  [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4  [di, update, malah, ngaco, ini, aplikasi, menu...

# %%
new_df = name_dataframe

# %%
# Menghitung Distibusi Persebaran Kata
def freqDist_wrapper(text):
    return FreqDist(text)

Ulasan_fqsist = name_dataframe['ulasan_ears'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(Ulasan_fqsist.head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(tidak, 4), (di, 3), (kadang, 2), (gantian, 2...
# 1    [(ga, 3), (dana, 2), (tombol, 2), (pengembalia...
# 2    [(tambah, 3), (buka, 2), (susah, 2), (di, 2), ...
# 3    [(tidak, 2), (cs, 2), (agen, 2), (setelah, 1),...
# 4    [(di, 5), (barang, 3), (cari, 3), (malah, 2), ...
# Name: ulasan_ears, dtype: object

# %%
print(name_dataframe.columns)
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize',
#        'ulasan_ears'],
#       dtype='object')

# %%
name_dataframe['Ulasan_tokenize'].unique
# Out:
# <bound method Series.unique of 0       [paylater, ngk, bener, selalu, di, batalkan, o...
# 1       [pengembalian, dana, otomatis, ga, berfungsisy...
# 2       [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3       [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4       [di, update, malah, ngaco, ini, aplikasi, menu...
#                               ...
# 1295                        [tingkatkan, terus, promonya]
# 1296    [ini, bonus, undang, referal, kok, belum, masu...
# 1297    [sangat, bagus, kiriman, cepat, sampai, terima...
# 1298    [kok, pelapaknya, ada, yang, ga, benerrrrrr, k...
# 1299    [woy, transaksi, gua, jadi, ga, jelas, gara, g...
# Name: Ulasan_tokenize, Length: 1300, dtype: object>

# %%
slank_word_dict = {
    "berjalansudah" : "berjalan",
    "paraah" : "parah",
    "keduakali" : "",
    "keduakali" : "kedua kali",
    "agak" : "sedikit",
    "pas" : "saat",
    "produkx" : "produknya",
    "sukamkasih" : "suka makasih",
    "gak" : "tidak",
    "cpt" : "cepat",
    "sdh" : "sudah",
    "recommend" : "rekomendasi",
    "bagusseller" : "bagus",
    "bagusssss" : "bagus",
    "bagussssss" : "bagus",
    "baguuussss" : "bagus",
    "cepatmakasih": "cepat",
    "cepatmantappp": "cepat",
    "cepatproduct": "cepat",
    "cepatrecomended": "cepat",
    "cepattoko": "cepat",
    "recomended": "rekomendasi",
    "recommended": "rekomendasi",
    "rekomendasi": "rekomendasi",
    "rekomended": "rekomendasi",
    }

def slank_normalized_term(document):
    return [slank_word_dict[term] if term in slank_word_dict else term for term in document]

# %%
normalizad_word = pd.read_csv("/content/kamusindonesia.csv (2).csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

# %%
normalizad_word_dict = {}

with open('/content/indonesian-words.txt', 'r', encoding='utf-8') as file:
    for line in file:
        term = line.strip()
        normalizad_word_dict[term] = term

def normalized_term(document):
    return [normalizad_word_dict.get(term, term) for term in document]

# %%
name_dataframe['Ulasan_normalized'] = name_dataframe['Ulasan_tokenize'].apply(normalized_term).apply(slank_normalized_term)

# %%
name_dataframe.head(100)
# Out:
#                     Nama pengguna  Rating                Date  \
# 0                    Nizar Rayyan       1 2023-04-16 23:03:31
# 1                  Ganjar Hermadi       1 2023-05-27 23:42:34
# 2                      Fandy Komo       1 2023-05-05 02:37:25
# 3                     Dwi Indarti       1 2023-06-06 04:19:17
# 4                    Yuda Nugraha       3 2023-05-31 10:59:36
# ..                            ...     ...                 ...
# 95  Kawaī monsutāかわいいモンスター（Ricks）       1 2023-04-11 15:45:35
# 96                   Aris Gunawan       5 2023-05-04 23:26:15
# 97                Arif Zulkarnaen       1 2023-04-15 02:25:56
# 98               Ndank Syarifudin       3 2023-04-12 04:42:58
# 99            PICOM LODOYO Blitar       1 2023-03-31 02:53:26
#
#                                                Ulasan  \
# 0   paylater ngk bener selalu di batalkan otomatis...
# 1   pengembalian dana otomatis ga berfungsisy lg b...
# 2   tambah kesini buka lapak tambah kurang bagus p...
# 3   setelah dibayar lunaspaylater tidak bisa dibua...
# 4   di update malah ngaco ini aplikasi menu barang...
# ..                                                ...
# 95  apk gak jelas error terus sistem cod pun jadi ...
# 96  aplikasi bukalapak sangat membantu untuk prose...
# 97  apk yg sulit untuk komplain jika ada kendala t...
# 98  gak ngerti dengan biyaya penanganan maksudnya ...
# 99  aplikasi bukalapak lemot parah smartphone saya...
#
#                                       Ulasan_tokenize  \
# 0   [paylater, ngk, bener, selalu, di, batalkan, o...
# 1   [pengembalian, dana, otomatis, ga, berfungsisy...
# 2   [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3   [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4   [di, update, malah, ngaco, ini, aplikasi, menu...
# ..                                                ...
# 95  [apk, gak, jelas, error, terus, sistem, cod, p...
# 96  [aplikasi, bukalapak, sangat, membantu, untuk,...
# 97  [apk, yg, sulit, untuk, komplain, jika, ada, k...
# 98  [gak, ngerti, dengan, biyaya, penanganan, maks...
# 99  [aplikasi, bukalapak, lemot, parah, smartphone...
#
#                                           ulasan_ears  \
# 0   [paylater, ngk, bener, selalu, di, batalkan, o...
# 1   [pengembalian, dana, otomatis, ga, berfungsisy...
# 2   [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3   [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4   [di, update, malah, ngaco, ini, aplikasi, menu...
# ..                                                ...
# 95  [apk, gak, jelas, error, terus, sistem, cod, p...
# 96  [aplikasi, bukalapak, sangat, membantu, untuk,...
# 97  [apk, yg, sulit, untuk, komplain, jika, ada, k...
# 98  [gak, ngerti, dengan, biyaya, penanganan, maks...
# 99  [aplikasi, bukalapak, lemot, parah, smartphone...
#
#                                     Ulasan_normalized
# 0   [paylater, ngk, bener, selalu, di, batalkan, o...
# 1   [pengembalian, dana, otomatis, ga, berfungsisy...
# 2   [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3   [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4   [di, update, malah, ngaco, ini, aplikasi, menu...
# ..                                                ...
# 95  [apk, tidak, jelas, error, terus, sistem, cod,...
# 96  [aplikasi, bukalapak, sangat, membantu, untuk,...
# 97  [apk, yg, sulit, untuk, komplain, jika, ada, k...
# 98  [tidak, ngerti, dengan, biyaya, penanganan, ma...
# 99  [aplikasi, bukalapak, lemot, parah, smartphone...
#
# [100 rows x 7 columns]

# %%
name_dataframe['Ulasan_normalized'].unique
# Out:
# <bound method Series.unique of 0       [paylater, ngk, bener, selalu, di, batalkan, o...
# 1       [pengembalian, dana, otomatis, ga, berfungsisy...
# 2       [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3       [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4       [di, update, malah, ngaco, ini, aplikasi, menu...
#                               ...
# 1295                        [tingkatkan, terus, promonya]
# 1296    [ini, bonus, undang, referal, kok, belum, masu...
# 1297    [sangat, bagus, kiriman, cepat, sampai, terima...
# 1298    [kok, pelapaknya, ada, yang, ga, benerrrrrr, k...
# 1299    [woy, transaksi, gua, jadi, ga, jelas, gara, g...
# Name: Ulasan_normalized, Length: 1300, dtype: object>

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

name_dataframe['Ulasan_stop_removed'] = name_dataframe['Ulasan_normalized'].apply(stopwords_removal)

# %%
name_dataframe
# Out:
#          Nama pengguna  Rating                Date  \
# 0         Nizar Rayyan       1 2023-04-16 23:03:31
# 1       Ganjar Hermadi       1 2023-05-27 23:42:34
# 2           Fandy Komo       1 2023-05-05 02:37:25
# 3          Dwi Indarti       1 2023-06-06 04:19:17
# 4         Yuda Nugraha       3 2023-05-31 10:59:36
# ...                ...     ...                 ...
# 1295    Aidil Pridiyah       5 2023-05-20 01:05:47
# 1296     Moja Maharani       4 2023-05-19 06:37:48
# 1297     Putri Sentani       5 2023-05-21 11:23:13
# 1298  Novian Syahputra       3 2023-05-10 10:55:50
# 1299            Payung       1 2023-05-23 09:16:07
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     pengembalian dana otomatis ga berfungsisy lg b...
# 2     tambah kesini buka lapak tambah kurang bagus p...
# 3     setelah dibayar lunaspaylater tidak bisa dibua...
# 4     di update malah ngaco ini aplikasi menu barang...
# ...                                                 ...
# 1295                          tingkatkan terus promonya
# 1296  ini bonus undang referal kok belum masuk ini s...
# 1297  sangat bagus kiriman cepat sampai terimakasih ...
# 1298  kok pelapaknya ada yang ga benerrrrrr klo niat...
# 1299  woy transaksi gua jadi ga jelas gara gara chat...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3     [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4     [di, update, malah, ngaco, ini, aplikasi, menu...
# ...                                                 ...
# 1295                      [tingkatkan, terus, promonya]
# 1296  [ini, bonus, undang, referal, kok, belum, masu...
# 1297  [sangat, bagus, kiriman, cepat, sampai, terima...
# 1298  [kok, pelapaknya, ada, yang, ga, benerrrrrr, k...
# 1299  [woy, transaksi, gua, jadi, ga, jelas, gara, g...
#
#                                             ulasan_ears  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3     [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4     [di, update, malah, ngaco, ini, aplikasi, menu...
# ...                                                 ...
# 1295                      [tingkatkan, terus, promonya]
# 1296  [ini, bonus, undang, referal, kok, belum, masu...
# 1297  [sangat, bagus, kiriman, cepat, sampai, terima...
# 1298  [kok, pelapaknya, ada, yang, ga, benerrrrrr, k...
# 1299  [woy, transaksi, gua, jadi, ga, jelas, gara, g...
#
#                                       Ulasan_normalized  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3     [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4     [di, update, malah, ngaco, ini, aplikasi, menu...
# ...                                                 ...
# 1295                      [tingkatkan, terus, promonya]
# 1296  [ini, bonus, undang, referal, kok, belum, masu...
# 1297  [sangat, bagus, kiriman, cepat, sampai, terima...
# 1298  [kok, pelapaknya, ada, yang, ga, benerrrrrr, k...
# 1299  [woy, transaksi, gua, jadi, ga, jelas, gara, g...
#
#                                     Ulasan_stop_removed
# 0     [paylater, ngk, bener, batalkan, otomatis, kad...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [kesini, buka, lapak, bagus, pelayanannya, kom...
# 3     [dibayar, lunaspaylater, transaksi, apapunsela...
# 4     [update, ngaco, aplikasi, menu, barang, favori...
# ...                                                 ...
# 1295                             [tingkatkan, promonya]
# 1296  [bonus, undang, referal, masuk, orng, menunggu...
# 1297    [bagus, kiriman, cepat, terimakasih, bukalapak]
# 1298  [pelapaknya, ga, benerrrrrr, klo, niatny, pela...
# 1299  [woy, transaksi, gua, ga, gara, gara, chat, ny...
#
# [1300 rows x 8 columns]

# %%
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: swifter in /usr/local/lib/python3.10/dist-packages (1.3.4)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (1.5.3)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.10/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2022.12.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (4.65.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (7.7.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from swifter) (2.2.1)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from swifter) (6.0.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (8.1.3)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2023.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (23.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.22.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2022.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.3.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (6.4.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.1.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.11.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.21)

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in name_dataframe['Ulasan_stop_removed']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

name_dataframe['Ulasan_Stemmed'] = name_dataframe['Ulasan_stop_removed'].swifter.apply(get_stemmed_term)
# Out:
# 4942
# ------------------------
# paylater : paylater
# ngk : ngk
# bener : bener
# batalkan : batal
# otomatis : otomatis
# kadang : kadang
# nya : nya
# gantian : ganti
# jatuh : jatuh
# tempo : tempo
# bayar : bayar
# biaya : biaya
# keterlambatan : lambat
# layanan : layan
# biar : biar
# merasakan : rasa
# rasakan : rasa
# sistem : sistem
# seenak : enak
# chat : chat
# susah : susah
# error : error
# menyalahkan : salah
# bikin : bikin
# pusing : pusing
# pengembalian : kembali
# dana : dana
# ga : ga
# berfungsisy : berfungsisy
# lg : lg
# butuh : butuh
# bgt : bgt
# dananya : dana
# ajuin : ajuin
# komplainada : komplainada
# tombol : tombol
# komplain : komplain
# diarahin : diarahin
# pusat : pusat
# bantuan : bantu
# utk : utk
# pengajuan : aju
# pembatalanpengembalian : pembatalanpengembalian
# aplikasinya : aplikasi
# payahmenyulitkan : payahmenyulitkan
# konsumen : konsumen
# kesini : kesini
# buka : buka
# lapak : lapak
# bagus : bagus
# pelayanannya : layan
# komplan : komplan
# aja : aja
# banget : banget
# beberapakali : beberapakali
# transaksi : transaksi
# rekening : rekening
# dah : dah
# kepotong : potong
# lapaknya : lapak
# terverifikasi : verifikasi
# kalo : kalo
# pingin : pingin
# menu : menu
# upload : upload
# bukti : bukti
# bayarnya : bayar
# nggak : nggak
# muncul : muncul
# kali : kali
# kehilangan : hilang
# uang : uang
# pembayaran : bayar
# gagal : gagal
# dibayar : bayar
# lunaspaylater : lunaspaylater
# apapunselalu : apapunselalu
# dibatalkan : batal
# berhari : hari
# coba : coba
# cs : cs
# bukalapak : bukalapak
# tersambungjawaban : tersambungjawaban
# agen : agen
# sibuk : sibuk
# parahpayah : parahpayah
# update : update
# ngaco : ngaco
# aplikasi : aplikasi
# barang : barang
# favorit : favorit
# gbs : gbs
# search : search
# skrg : skrg
# klo : klo
# cari : cari
# bl : bl
# yg : yg
# ad : ad
# tau : tau
# pd : pd
# kmn : kmn
# penjual : jual
# item : item
# toko : toko
# sebelah : belah
# sulit : sulit
# belanja : belanja
# dsni : dsni
# terpaksa : paksa
# maaf : maaf
# ya : ya
# boss : boss
# bekukan : beku
# limit : limit
# tdk : tdk
# naikyg : naikyg
# percaya : percaya
# mode : mode
# cod : cod
# tambahan : tambah
# rp : rp
# aga : aga
# males : males
# systemnya : systemnya
# udah : udah
# pelayanan : layan
# tutupin : tutupin
# pelanggan : langgan
# kecewa : kecewa
# kurirnya : kurir
# ngirim : ngirim
# ongkirku : ongkirku
# dipotong : potong
# dikembalikan : kembali
# ongkirnya : ongkirnya
# kemana : mana
# pake : pake
# bukabantuan : bukabantuan
# live : live
# jalan : jalan
# permasalahan : masalah
# tsb : tsb
# sekian : sekian
# pke : pke
# apk : apk
# bru : bru
# kli : kli
# berat : berat
# serasa : serasa
# ditipu : tipu
# sma : sma
# beli : beli
# jasa : jasa
# pengiriman : kirim
# ekspres : ekspres
# dgn : dgn
# estimasi : estimasi
# kerja : kerja
# ekspedisi : ekspedisi
# peniriman : peniriman
# jdi : jdi
# bertanggung : tanggung
# kerugian : rugi
# materi : materi
# ribet : ribet
# sumpah : sumpah
# setting : setting
# maps : maps
# refresh : refresh
# ngulangin : ngulangin
# kebanyakan : banyak
# fitur : fitur
# ganti : ganti
# nomor : nomor
# pilihan : pilih
# wallet : wallet
# seikit : seikit
# bintang : bintang
# membantu : bantu
# ditingkatkan : tingkat
# ongkir : ongkir
# vocer : vocer
# diskon : diskon
# harapkan : harap
# penambahan : tambah
# pengguna : guna
# berhak : hak
# cocok : cocok
# tuh : tuh
# pelapak : lapak
# verifikasi : verifikasi
# ktp : ktp
# infonya : info
# jam : jam
# akun : akun
# verifikasigak : verifikasigak
# masuk : masuk
# gimana : gimana
# jualan : jual
# lemot : lot
# parah : parah
# login : login
# sampe : sampe
# terhubung : hubung
# alias : alias
# tulisan : tulis
# jarang : jarang
# dapet : dapet
# potongan : potong
# harga : harga
# nyamantidak : nyamantidak
# aman : aman
# bukalapakselain : bukalapakselain
# mahalada : mahalada
# bebankanmending : bebankanmending
# kl : kl
# kirim : kirim
# benermending : benermending
# tujuansudah : tujuansudah
# jamannya : jaman
# online : online
# selepas : lepas
# kesalahan : salah
# kebutuhan : butuh
# mendesakharusnya : mendesakharusnya
# dibantu : bantu
# kembalibagaimanapun : kembalibagaimanapun
# jg : jg
# bldah : bldah
# ulangi : ulang
# samatapi : samatapi
# mohon : mohon
# kasih : kasih
# voucher : voucher
# pakai : pakai
# dipakai : pakai
# kuotanya : kuota
# habis : habis
# diskonnya : diskon
# emang : emang
# makan : makan
# balikin : balikin
# vouchernya : vouchernya
# batal : batal
# pesanan : pesan
# yak : yak
# bilang : bilang
# ready : ready
# stok : stok
# tp : tp
# duit : duit
# ditransfer : transfer
# dikirim : kirim
# amplop : amplop
# kosong : kosong
# dpt : dpt
# pembeli : beli
# dikasih : kasih
# template : template
# kagak : kagak
# solusi : solusi
# suruh : suruh
# nunggu : nunggu
# batas : batas
# proses : proses
# asli : asli
# dosa : dosa
# lu : lu
# nahan : nahan
# rejeki : rejeki
# orang : orang
# paraaaahhhh : paraaaahhhh
# mudahpengiriman : mudahpengiriman
# cepatqualitas : cepatqualitas
# sesuai : sesuai
# hargasaya : hargasaya
# nyaman : nyaman
# mengunakan : mengunakan
# semoga : moga
# jaya : jaya
# andalan : andal
# penggunanya : guna
# tpi : tpi
# bingung : bingung
# mengadu : adu
# bermasalah : masalah
# memproses : proses
# berhenti : henti
# salah : salah
# commerce : commerce
# worth : worth
# it : it
# halaman : halaman
# pengecekan : kece
# sampainya : sampai
# tolong : tolong
# cek : cek
# pengembang : kembang
# halamannya : halaman
# internet : internet
# stabil : stabil
# cepat : cepat
# diperbaiki : baik
# terimakasih : terimakasih
# trnsaksi : trnsaksi
# pulsa : pulsa
# berhasilpulsa : berhasilpulsa
# gk : gk
# masuktagihan : masuktagihan
# adakomplen : adakomplen
# diurus : urus
# mesin : mesin
# satunya : satu
# olshop : olshop
# rampog : rampog
# ap : ap
# paraaaaaaaahhhhh : paraaaaaaaahhhhh
# kosongkan : kosong
# bintangnya : bintang
# bukalapakpercuma : bukalapakpercuma
# limite : limite
# belanjatagihan : belanjatagihan
# aktifpenanganan : aktifpenanganan
# wow : wow
# min : min
# mautanya : mautanya
# jual : jual
# lihat : lihat
# calon : calon
# terkecuali : kecuali
# link : link
# akses : akses
# pembatalan : batal
# pemesanansaya : pemesanansaya
# tertipu : tipu
# rb : rb
# store : store
# kecewasaya : kecewasaya
# rugi : rugi
# total : total
# respon : respon
# kejadian : jadi
# inibukalapak : inibukalapak
# tanggal : tanggal
# kecuali : kecuali
# trus : trus
# pajangan : pajang
# doang : doang
# jgn : jgn
# kredivo : kredivo
# sensitif : sensitif
# jelaspercuma : jelaspercuma
# aktif : aktif
# transaksinyesel : transaksinyesel
# belanjajelas : belanjajelas
# tagihan : tagih
# sekaliperdetik : sekaliperdetik
# uninstalmakasih : uninstalmakasih
# dicoba : coba
# penggunaan : guna
# paylaternya : paylaternya
# tersedia : sedia
# limitnya : limit
# uda : uda
# terpakai : pakai
# sisa : sisa
# giliran : gilir
# dipake : dipake
# bisaslalu : bisaslalu
# otomatisketerangan : otomatisketerangan
# pembatalannya : batal
# dibatalkanseakan : dibatalkanseakan
# batalkanpadahal : batalkanpadahal
# sistemnya : sistem
# ngasih : ngasih
# tabungan : tabung
# diperbanyak : banyak
# produknya : produk
# produk : produk
# karna : karna
# membeli : beli
# langsung : langsung
# fiture : fiture
# cicilan : cicil
# lunas : lunas
# moga : moga
# maju : maju
# aplikais : aplikais
# penjualan : jual
# oke : oke
# upraged : upraged
# super : super
# seller : seller
# foto : foto
# bisanya : bisa
# tokopedia : tokopedia
# lebh : lebh
# gampang : gampang
# jualanannya : jualanannya
# mengecewakan : kecewa
# membela : bela
# kepentingan : penting
# kembalikan : kembali
# status : status
# terima : terima
# selesai : selesai
# sy : sy
# cm : cm
# menjanjikan : janji
# to : to
# seminggu : minggu
# lbh : lbh
# byk : byk
# iklan : iklan
# pemakai : pakai
# klik : klik
# meninggalkan : tinggal
# spt : spt
# sya : sya
# kuota : kuota
# dagangan : dagang
# pdhl : pdhl
# jualannya : jual
# antik : antik
# unik : unik
# quota : quota
# diketerangan : terang
# promosi : promosi
# email : email
# validpadahal : validpadahal
# data : data
# kesal : kesal
# jngn : jngn
# download : download
# daftar : daftar
# gitu : gitu
# kaya : kaya
# adain : adain
# perbanyak : banyak
# jelek : jelek
# dr : dr
# adl : adl
# bertele : tele
# kesana : kesana
# kemari : kemari
# tinggal : tinggal
# koleksinya : koleksi
# dikit : dikit
# cmn : cmn
# barangnya : barang
# kalah : kalah
# sepi : sepi
# berbulan : bulan
# laku : laku
# stagnan : stagnan
# greget : greget
# ol : ol
# shop : shop
# bukalapakygdulu : bukalapakygdulu
# kendala : kendala
# bonus : bonus
# credit : credit
# ulasan : ulas
# menyenangkan : senang
# syarat : syarat
# ketentuan : tentu
# ketahui : tahu
# bst : bst
# pedagang : dagang
# modal : modal
# pasan : pas
# muterin : muterin
# dsini : dsini
# ambil : ambil
# feedback : feedback
# berakibat : akibat
# notifikasi : notifikasi
# sampah : sampah
# berguna : guna
# tsbt : tsbt
# notif : notif
# matikan : mati
# pembelian : beli
# hilang : hilang
# aktifkan : aktif
# gua : gua
# heran : heran
# sebagus : bagus
# sayang : sayang
# paham : paham
# simpel : simpel
# aturan : atur
# ayo : ayo
# iklanin : iklanin
# perusahaan : usaha
# serius : serius
# minim : minim
# mantap : mantap
# unggul : unggul
# topup : topup
# saldo : saldo
# jt : jt
# knp : knp
# truss : truss
# dompet : dompet
# nyuruh : nyuruh
# hasil : hasil
# aneh : aneh
# gini : gin
# mah : mah
# nominal : nominal
# maen : maen
# balesan : balesan
# benarbenar : benarbenar
# tertata : tata
# penipuan : tipu
# batasi : batas
# pepalak : palak
# mengirimkan : kirim
# transfer : transfer
# puas : puas
# rekomendasi : rekomendasi
# tibatiba : tibatiba
# beku : beku
# baned : baned
# menerima : terima
# feed : feed
# back : back
# merugikan : rugi
# gede : gede
# korban : korban
# payah : payah
# perihal : perihal
# event : event
# bukatabungan : bukatabungan
# menggundang : gundang
# reward : reward
# tertulis : tulis
# pesan : pesan
# kekurir : kurir
# kejelasan : jelas
# asuransi : asuransi
# terpotong : potong
# mundur : mundur
# ngajuin : ngajuin
# susahnya : susah
# ampun : ampun
# call : call
# center : center
# sekalinya : sekali
# main : main
# left : left
# seenaknyalangsg : seenaknyalangsg
# percakapan : cakap
# percakapanjadi : percakapanjadi
# ragu : ragu
# kebelakang : belakang
# ko : ko
# customer : customer
# no : no
# antrian : antri
# nutup : nutup
# diterima : terima
# trecking : trecking
# pengirimannya : kirim
# udh : udh
# saran : saran
# susupin : susupin
# shopee : shopee
# bnyk : bnyk
# pasang : pasang
# separuhnya : paruh
# murah : murah
# rusak : rusak
# realpict : realpict
# jd : jd
# kapok : kapok
# org : org
# wajib : wajib
# lbih : lbih
# dlm : dlm
# bs : bs
# permudah : mudah
# editsaat : editsaat
# memasukkan : masuk
# alamat : alamat
# manual : manual
# bisakalau : bisakalau
# dibilang : bilang
# pelosokmungkintapi : pelosokmungkintapi
# lainsaya : lainsaya
# manualtanpa : manualtanpa
# gpssaya : gpssaya
# kecewakarena : kecewakarena
# berkali : kali
# tunggu : tunggu
# aa : aa
# bantu : bantu
# kaka : kaka
# alami : alami
# solusinya : solusi
# memudahkan : mudah
# ktpno : ktpno
# telphone : telphone
# membuktikan : bukti
# pemilik : milik
# ampas : ampas
# bnyak : bnyak
# penipu : tipu
# bangkrut : bangkrut
# hapus : hapus
# play : play
# marketplace : marketplace
# sellerseller : sellerseller
# terkait : kait
# seakan : akan
# bertanggungjawab : bertanggungjawab
# alasan : alas
# ujungnya : ujung
# lepas : lepas
# tangan : tangan
# bukalapk : bukalapk
# sicepat : sicepat
# kurir : kurir
# tautpi : tautpi
# kg : kg
# gramdi : gramdi
# hitung : hitung
# kgdan : kgdan
# ahirnya : ahirnya
# lgi : lgi
# sayagak : sayagak
# ijoklo : ijoklo
# komplin : komplin
# lgsg : lgsg
# teratasi : atas
# nomer : nomer
# hp : hp
# terdaftar : daftar
# lainemang : lainemang
# daptar : daptar
# alikasi : alikasi
# yahsangat : yahsangat
# membingungkanlangsung : membingungkanlangsung
# uninstal : uninstal
# mudah : mudah
# kompalain : kompalain
# tpdiketangan : tpdiketangan
# komplen : komplen
# enak : enak
# make : make
# eh : eh
# top : top
# up : up
# berhasil : hasil
# tarik : tarik
# belu : belu
# cairkan : cair
# hadehh : hadehh
# hadehhh : hadehhh
# sandi : sandi
# gunanya : guna
# tingkatkan : tingkat
# serepes : repes
# kompetitor : kompetitor
# via : via
# bsi : bsi
# penjelasan : jelas
# wadah : wadah
# tim : tim
# system : system
# bobrok : bobrok
# jawabannya : jawab
# disuruh : suruh
# alhasil : alhasil
# dinyatakan : nyata
# valid : valid
# mengutamakan : utama
# untung : untung
# yaa : yaa
# kayak : kayak
# potong : potong
# kedaluarsa : kedaluarsa
# keterangan : terang
# pakek : pakek
# hati : hati
# kawan : kawan
# retur : retur
# diskusi : diskusi
# admin : admin
# cenderung : cenderung
# video : video
# pertimbangkan : timbang
# koneksi : koneksi
# server : server
# promo : promo
# ui : ui
# buruk : buruk
# agt : agt
# pengoperasian : operasi
# praktis : praktis
# urusan : urus
# mencari : cari
# profil : profil
# des : des
# ajib : ajib
# nih : nih
# fiturfiturnya : fiturfiturnya
# dicari : cari
# desain : desain
# layar : layar
# rapi : rapi
# biru : biru
# belanjaan : belanja
# gmna : gmna
# mo : mo
# dipindahin : dipindahin
# kerna : kerna
# sia : sia
# recomend : recomend
# terselesaikan : selesai
# loading : loading
# lancar : lancar
# menampilkan : tampil
# utama : utama
# sudahlama : sudahlama
# kayanya : kaya
# uninstall : uninstall
# berasa : asa
# ngga : ngga
# hubungkan : hubung
# aplkasi : aplkasi
# iniakun : iniakun
# kena : kena
# hack : hack
# steam : steam
# vcr : vcr
# game : game
# pembajak : bajak
# manusia : manusia
# berhati : hati
# mendewakan : dewa
# sih : sih
# mkin : mkin
# gajelas : gajelas
# semacem : semacem
# gabisa : gabisa
# tlng : tlng
# terkaitdevelop : terkaitdevelop
# penanganan : tangan
# dri : dri
# dlu : dlu
# dikecewain : dikecewain
# penutupan : tutup
# tanggapinnya : tanggapinnya
# formulir : formulir
# permohonan : mohon
# gratis : gratis
# boongan : boongan
# pilih : pilih
# jnt : jnt
# sellernya : sellernya
# nyantumin : nyantumin
# pembohong : bohong
# siniudah : siniudah
# capek : capek
# ngetikpas : ngetikpas
# tuju : tuju
# jdinya : jdinya
# terimatpi : terimatpi
# reportnya : reportnya
# bingungmo : bingungmo
# hrs : hrs
# gmn : gmn
# pasrah : pasrah
# aj : aj
# an : an
# tanggapin : tanggapin
# dihapus : hapus
# tutup : tutup
# bertahun : tahun
# dibenahi : benah
# kabur : kabur
# pembelinya : bel
# ok : ok
# disaat : saat
# permintaan : minta
# penjualanpembatalan : penjualanpembatalan
# apl : apl
# bulalapak : bulalapak
# nyanotif : nyanotif
# menanggapi : tanggap
# kpd : kpd
# perbaiki : baik
# pencariannya : cari
# pencarian : cari
# nyari : nyari
# ikan : ikan
# hias : hias
# pakan : pakan
# ganggu : ganggu
# minusnya : minus
# mahal : mahal
# memenuhi : penuh
# persyaratan : syarat
# tgl : tgl
# april : april
# simpan : simpan
# gudang : gudang
# bukaexpress : bukaexpress
# livechat : livechat
# berfungsi : fungsi
# beda : beda
# merchant : merchant
# payleter : payleter
# cancel : cancel
# sungguh : sungguh
# mematikan : mati
# obrolannya : obrol
# aktifin : aktifin
# hangus : hangus
# kyc : kyc
# sory : sory
# ane : ane
# join : join
# kepercayan : kepercayan
# ecom : ecom
# aktifasi : aktifasi
# enek : enek
# masak : masak
# kode : kode
# otp : otp
# sefty : sefty
# lo : lo
# nyataanya : nyataanya
# nomornya : nomor
# aktivasi : aktivasi
# ampuun : ampuun
# syaratnya : syarat
# kyk : kyk
# pinjaman : pinjam
# bank : bank
# sumpaah : sumpaah
# oohh : oohh
# devlover : devlover
# lebay : lebay
# pengen : ken
# dikirimkan : kirim
# ktprekening : ktprekening
# seribet : seribet
# kah : kah
# cantumin : cantumin
# diubah : ubah
# masukin : masukin
# tipenyasaya : tipenyasaya
# menyelesaikan : selesai
# paket : paket
# dipilih : pilih
# zonk : zonk
# melanggar : langgar
# ngapain : ngapain
# tampilkan : tampil
# iklannya : iklan
# loadingnya : loadingnya
# membuka : buka
# ngechek : ngechek
# internetdi : internetdi
# nglungker : nglungker
# trs : trs
# nambah : nambah
# jenuhtlg : jenuhtlg
# perhatikan : perhati
# mantabb : mantabb
# menunya : menu
# simple : simple
# pahami : paham
# lemottnya : lemottnya
# emas : emas
# bukaemas : bukaemas
# problemnya : problem
# bad : bad
# gateway : gateway
# ulang : ulang
# keknya : kek
# sengaja : sengaja
# dipersulit : sulit
# investasi : investasi
# app : app
# dibikin : bikin
# ajabanyak : ajabanyak
# sisrem : sisrem
# gunabuka : gunabuka
# kya : kya
# ajaisi : ajaisi
# harap : harap
# buang : buang
# ajadan : ajadan
# bagusmasuk : bagusmasuk
# ribetnya : ribetnya
# didownload : didownload
# touch : touch
# ud : ud
# az : az
# la : la
# merepotkan : repot
# dear : dear
# check : check
# posisi : posisi
# pesana : sana
# bug : bug
# perhatiannya : perhati
# kerusakan : rusa
# perbaikan : baik
# menggangu : menggangu
# dengar : dengar
# ribuan : ribu
# cumq : cumq
# tampil : tampil
# temukan : temu
# gaya : gaya
# pengunjung : unjung
# bantuannyasaya : bantuannyasaya
# mengalami : alami
# kesulitan : sulit
# logindikarenakan : logindikarenakan
# masukkan : masuk
# aktifmau : aktifmau
# sayadan : sayadan
# bukalapakmohon : bukalapakmohon
# mempersulit : sulit
# isi : isi
# pengaturan : atur
# betah : betah
# perdagangan : dagang
# statusnya : status
# kadaluarsamau : kadaluarsamau
# dibeli : beli
# canggih : canggih
# dikomplain : komplain
# cman : cman
# sadah : sadah
# kembaliini : kembaliini
# blum : blum
# kepastianpayah : kepastianpayah
# nyesel : nyesel
# gw : gw
# dibukalapak : dibukalapak
# fiturnya : fiturnya
# pelit : pelit
# nonaktif : nonaktif
# dijual : jual
# berulang : ulang
# set : set
# ni : ni
# pesen : sen
# mengajukan : aju
# dibls : dibls
# blm : blm
# mls : mls
# uangnya : uang
# woi : woi
# bertambah : tambah
# profesional : profesional
# beban : beban
# and : and
# smartphone : smartphone
# gue : gue
# dipiara : piara
# bermanfaat : manfaat
# cepet : cepet
# tujuan : tuju
# manapun : mana
# promonya : promonya
# fee : fee
# lainnyamataap : lainnyamataap
# daah : daah
# gunawan : gunawan
# sm : sm
# mitra : mitra
# dalem : dalem
# ketipu : tipu
# msk : msk
# refund : refund
# smpe : smpe
# detik : detik
# ngerti : ngerti
# biyaya : biyaya
# maksudnya : maksud
# apalg : apalg
# nyesek : nyesek
# dg : dg
# sgitu : sgitu
# bsa : bsa
# ilangin : ilangin
# tuhklo : tuhklo
# kurangin : rangin
# kepakasa : kepakasa
# blanja : blanja
# saking : saking
# tmpt : tmpt
# chip : chip
# snapdragon : snapdragon
# gen : gen
# ram : ram
# gb : gb
# clear : clear
# chace : chace
# logout : logout
# terbaru : baru
# expedisi : expedisi
# reg : reg
# next : next
# day : day
# pick : pick
# lelet : lelet
# criss : criss
# cross : cross
# sop : sop
# resi : resi
# ybs : ybs
# kepercayaan : percaya
# kedepan : depan
# buset : buset
# ditemukan : temu
# hebat : hebat
# lenya : lenya
# ribu : ribu
# mempermudah : mudah
# berbelanjatapi : berbelanjatapi
# dam : dam
# halapalagi : halapalagi
# tanggapan : tanggap
# sistemnyakecewa : sistemnyakecewa
# telat : telat
# pemilihan : pilih
# ditambah : tambah
# report : report
# bermasalahpaket : bermasalahpaket
# jadwal : jadwal
# kompensasi : kompensasi
# jaminan : jamin
# kembalihanya : kembalihanya
# slogan : slogan
# belakabagaimana : belakabagaimana
# muter : muter
# ajalihat : ajalihat
# history : history
# mainnumpuk : mainnumpuk
# diserver : diserver
# akunbuatlah : akunbuatlah
# penyimpanan : simpan
# nge : nge
# suka : suka
# hang : hang
# selebihnya : lebih
# star : star
# memberatkan : berat
# itemku : item
# higs : higs
# domino : domino
# menerapkan : terap
# digital : digital
# payleater : payleater
# bukalapaksaya : bukalapaksaya
# tagih : tagih
# lagibukti : lagibukti
# struknya : struknya
# kasir : kasir
# indomart : indomart
# yeah : yeah
# tagihantapi : tagihantapi
# anehnya : aneh
# kecewadimana : kecewadimana
# menyediakan : sedia
# codtapi : codtapi
# express : express
# transaksinya : transaksi
# peforma : forma
# huhuhuuuuu : huhuhuuuuu
# mengenali : nali
# pribadi : pribadi
# beliau : beliau
# berkurang : kurang
# riwayat : riwayat
# telusur : telusur
# kunci : kunci
# sebutin : sebutin
# merek : merek
# official : official
# brand : brand
# paylatternya : paylatternya
# pemberitahuan : pemberitahuan
# tetep : tetep
# dikirm : dikirm
# nyampai : nyampai
# hubungi : hubung
# aktiv : aktiv
# januari : januari
# jugasudah : jugasudah
# ajukan : aju
# tanggapi : tanggap
# bukalapaksungguh : bukalapaksungguh
# sukses : sukses
# ditutup : tutup
# konfirmasi : konfirmasi
# turunin : turunin
# deh : deh
# eror : eror
# langganan : langgan
# sayapadahal : sayapadahal
# label : label
# cekout : cekout
# catatan : catat
# memakai : pakai
# metode : metode
# inipadahal : inipadahal
# penipunya : tipu
# berubah : ubah
# pengaduan : adu
# mending : mending
# keren : keren
# bertahan : tahan
# persaingan : saing
# ketat : ketat
# kompetitornya : kompetitor
# yuk : yuk
# buruan : buru
# konsisten : konsisten
# timbul : timbul
# tenggelam : tenggelam
# loh : loh
# hehee : hehee
# way : way
# ketinggalan : tinggal
# pbb : pbb
# koreksi : koreksi
# alhamdulillah : alhamdulillah
# sengketa : sengketa
# aplaus : aplaus
# normal : normal
# bukareksauang : bukareksauang
# setatusy : setatusy
# selesaidikomplen : selesaidikomplen
# transfermasuk : transfermasuk
# jawabpaylater : jawabpaylater
# rusuhmasih : rusuhmasih
# belbel : belbel
# terusruwed : terusruwed
# pemesanan : mesan
# memesan : mes
# rokok : rokok
# pindahkan : pindah
# kartu : kartu
# sd : sd
# penagihan : tagih
# melunasi : lunas
# ditinjau : tinjau
# dc : dc
# screen : screen
# shot : shot
# menagih : tagih
# wa : wa
# mengganggu : ganggu
# berbeda : beda
# ditindak : tindak
# lanjuti : lanjut
# bolak : bolak
# kantor : kantor
# program : program
# diperlakukan : laku
# setia : setia
# kak : kak
# blom : blom
# pdhal : pdhal
# transit : transit
# pay : pay
# later : later
# ah : ah
# hbis : hbis
# ngisi : ngisi
# msh : msh
# cash : cash
# lom : lom
# tlp : tlp
# memuaskan : muas
# jawabannyacoba : jawabannyacoba
# membatalkan : batal
# tanggepin : tanggepin
# tlong : tlong
# tentui : tentu
# jgbuat : jgbuat
# bantumakin : bantumakin
# hubungin : hubungin
# chatlemot : chatlemot
# tele : tele
# turun : turun
# lag : lag
# memperbaiki : baik
# karuan : karuan
# krna : krna
# dibajak : bajak
# kredit : kredit
# hub : hub
# pending : pending
# bukalapakeh : bukalapakeh
# suami : suami
# jutamasa : jutamasa
# blokir : blokir
# bajakhrsny : bajakhrsny
# ditahan : tahan
# pesanannyakan : pesanannyakan
# byr : byr
# vamandiri : vamandiri
# pembyran : pembyran
# auto : auto
# ditarik : tarik
# duitnya : duit
# transferpenarikkan : transferpenarikkan
# upgrade : upgrade
# premium : premium
# bari : bari
# dibekukan : beku
# sabar : sabar
# kepastian : pasti
# penilain : penilain
# kasian : kasi
# terputus : putus
# opsi : opsi
# dicetak : cetak
# helooo : helooo
# syaa : syaa
# buyer : buyer
# ky : ky
# driver : driver
# tampilan : tampil
# user : user
# friendly : friendly
# menyulitkan : sulit
# lemotbukan : lemotbukan
# lemotaplikasinya : lemotaplikasinya
# perbaikimasi : perbaikimasi
# ringan : ringan
# orangemasa : orangemasa
# utuma : utuma
# flashdeal : flashdeal
# belinya : beli
# shake : shake
# thon : thon
# dapatnya : dapat
# perak : perak
# thx : thx
# kacau : kacau
# nipu : nipu
# dateng : dateng
# apliksi : apliksi
# bukalapaknya : bukalapaknya
# ahh : ahh
# dadi : dadi
# komplainnya : komplain
# action : action
# melindungi : lindung
# membantuuang : membantuuang
# chating : chating
# nagih : nagih
# hutang : hutang
# playlater : playlater
# bermutu : mutu
# dak : dak
# ngebantu : ngebantu
# wishlist : wishlist
# kedepannya : depan
# cantumkan : cantum
# kolom : kolom
# detail : detail
# masukan : masuk
# batalin : batalin
# pejual : jual
# jugasedangkan : jugasedangkan
# gunakanharus : gunakanharus
# mengadutolong : mengadutolong
# lapakbiar : lapakbiar
# mengadukan : adu
# keluhan : keluh
# developer : developer
# liat : liat
# lazada : lazada
# tiktok : tiktok
# minimal : minimal
# pantes : pantes
# wajar : wajar
# orentiktok : orentiktok
# layak : layak
# disana : sana
# ketimbang : ketimbang
# wkwk : wkwk
# elektronik : elektronik
# digabung : gabung
# darp : darp
# nyaedaaaan : nyaedaaaan
# pemerasan : peras
# klw : klw
# its : its
# sense : sense
# fungsi : fungsi
# larinya : lari
# dodol : dodol
# danatransfer : danatransfer
# bertransaksi : transaksi
# pokoke : pokoke
# is : is
# the : the
# best : best
# bos : bos
# dikatan : dikatan
# itupun : itu
# bayarkan : bayar
# antusias : antusias
# sydah : sydah
# masalahsudah : masalahsudah
# hasilnya : hasil
# keluarketika : keluarketika
# mengetik : etik
# putus : putus
# sambungan : sambung
# nyakalo : nyakalo
# menggu : menggu
# yohana : yohana
# nama : nama
# bersabar : sabar
# nunggusaaya : nunggusaaya
# ngetiikkkk : ngetiikkkk
# hynaevinv : hynaevinv
# dicancelsejak : dicancelsejak
# sampaiudah : sampaiudah
# loohhhkembalikan : loohhhkembalikan
# seharga : harga
# amanah : amanah
# diproses : proses
# pelapaknya : lapak
# bukamall : bukamall
# pilihannya : pilih
# complainnya : complainnya
# complain : complain
# digunain : digunain
# sadar : sadar
# gunakanauto : gunakanauto
# uninstaljika : uninstaljika
# trmksih : trmksih
# malas : malas
# hijau : hijau
# orange : orange
# full : full
# dibatasi : batas
# terbaik : baik
# checkout : checkout
# dibatalin : dibatalin
# maksa : maksa
# bentar : bentar
# pokoknya : pokok
# bisnis : bisnis
# berlimpah : limpah
# mantaab : mantaab
# markotopmaknyosss : markotopmaknyosss
# baikbaiiiil : baikbaiiiil
# telp : telp
# custemservis : custemservis
# ngurusinya : ngurusinya
# chatlive : chatlive
# ngelunasin : ngelunasin
# belom : bom
# sehari : hari
# ttp : ttp
# kinerjanya : kerja
# informasj : informasj
# dipahami : paham
# pengerjaannya : kerja
# codpembayaran : codpembayaran
# tunai : tunai
# bulanansaldo : bulanansaldo
# menunggu : tunggu
# pastinya : pasti
# wifi : wifi
# lemmooottttt : lemmooottttt
# dasarnya : dasar
# transsaksi : transsaksi
# terisi : isi
# penuh : penuh
# penawaran : tawar
# tanda : tanda
# terbaca : baca
# kepencet : pencet
# bermain : main
# sperti : sperti
# konten : konten
# webnya : webnya
# lumayan : lumayan
# kecurigaan : curiga
# maafkan : maaf
# efisien : efisien
# hemat : hemat
# duduk : duduk
# manis : manis
# rumah : rumah
# low : low
# cost : cost
# ngirit : ngirit
# mengundang : undang
# teman : teman
# refferal : refferal
# setujui : tuju
# pembukaan : buka
# undang : undang
# cair : cair
# bantuannya : bantu
# account : account
# berani : berani
# kontak : kontak
# rumit : rumit
# danabukalapak : danabukalapak
# trimakasih : trimakasih
# inovatif : inovatif
# lamaproses : lamaproses
# lamarespon : lamarespon
# penjualnya : jual
# lamabru : lamabru
# bukalapakternyata : bukalapakternyata
# lamaaaa : lamaaaa
# slow : slow
# responfix : responfix
# ecommerce : ecommerce
# pembisnis : bisnis
# all : all
# in : in
# one : one
# feature : feature
# barangpake : barangpake
# nyampe : nyampe
# dikomplen : dikomplen
# kejelasannyakatanya : kejelasannyakatanya
# prosesnya : proses
# diprosesmana : diprosesmana
# ribed : ribed
# menindaklanjuti : menindaklanjuti
# kemudahan : mudah
# berbelanja : belanja
# rating : rating
# terpisah : pisah
# instal : instal
# donload : donload
# bangst : bangst
# ta : ta
# rubah : rubah
# tipu : tipu
# berjalan : jalan
# keuangan : uang
# cuman : cuman
# benahi : benah
# platform : platform
# mnrut : mnrut
# terbaiknya : baik
# acc : acc
# sgt : sgt
# good : good
# job : job
# berjualan : jual
# barangsaya : barangsaya
# memperumit : rumit
# disitu : situ
# pencairan : cair
# sisanya : sisa
# pinjem : pinjem
# free : free
# harganya : harga
# sejenisnya : jenis
# ttup : ttup
# tranksaksi : tranksaksi
# tranksasi : tranksasi
# layanananya : layanananya
# untungnya : untung
# parahhhhhhhhhhh : parahhhhhhhhhhh
# errorklo : errorklo
# sendiripayahudah : sendiripayahudah
# gtu : gtu
# ongkirskrg : ongkirskrg
# pindah : pindah
# abuabu : abuabu
# skarang : skarang
# takut : takut
# tipa : tipa
# terpercaya : percaya
# room : room
# muat : muat
# mengakses : akses
# ribettt : ribettt
# mengecewakanaman : mengecewakanaman
# customertingkatkan : customertingkatkan
# prestasi : prestasi
# blspy : blspy
# lengkap : lengkap
# ekonomis : ekonomis
# konfirm : konfirm
# bego : bego
# tolol : tolol
# gabut : gabut
# open : open
# of : of
# maksimalkan : maksimal
# om : om
# padaha : padaha
# nyagara : nyagara
# gara : gara
# lunassss : lunassss
# diberikankalau : diberikankalau
# ditambh : ditambh
# aplikasikadang : aplikasikadang
# ngetik : ngetik
# dipencarian : cari
# diem : diem
# jalanpadahal : jalanpadahal
# sinyal : sinyal
# normallama : normallama
# ditinggak : ditinggak
# gni : gni
# sekrng : sekrng
# problem : problem
# blkadang : blkadang
# buffering : buffering
# wae : wae
# euy : euy
# kumaha : maha
# atuh : atuh
# dikecewakan : kecewa
# penyelesaian : selesai
# duanya : dua
# paitmasuk : paitmasuk
# bajaktapi : bajaktapi
# membiarkan : biar
# syyg : syyg
# orgbikin : orgbikin
# raya : raya
# lapakmenurut : lapakmenurut
# rekrutmen : rekrutmen
# resller : resller
# nyadan : nyadan
# cepatjk : cepatjk
# uanggood : uanggood
# success : success
# bwt : bwt
# info : info
# kadaluarsa : kadaluarsa
# keamanan : aman
# kaitkan : kait
# perlukandengan : perlukandengan
# adaa : adaa
# applikasi : applikasi
# bnget : bnget
# mna : mna
# darurat : darurat
# token : token
# listrik : listrik
# atw : atw
# ynk : ynk
# jamin : jamin
# pass : pass
# klianynk : klianynk
# kerjaana : kerjaana
# numpuk : numpuk
# brang : brang
# impian : impi
# ples : ples
# torrr : torrr
# sampenya : sampenya
# responnya : responnya
# ditolak : tolak
# ig : ig
# direspon : direspon
# oren : oren
# gercep : gercep
# claim : claim
# ikhlas : ikhlas
# ditawarkan : tawar
# kualitas : kualitas
# slalu : slalu
# belanjaada : belanjaada
# nyatp : nyatp
# ditambahin : ditambahin
# dicicil : cicil
# tenor : tenor
# syukur : syukur
# watelpon : watelpon
# membingunkan : membingunkan
# kemarin : kemarin
# kompain : kompain
# terkirim : kirim
# ceat : ceat
# langanan : langanan
# klaim : klaim
# hak : hak
# refundlangsung : refundlangsung
# customermau : customermau
# pengalaman : alam
# lambat : lambat
# rekomen : rekomen
# penyedia : sedia
# fasilitas : fasilitas
# sediakan : sedia
# prifasi : prifasi
# histori : histori
# obatproduk : obatproduk
# dewasa : dewasa
# sebagainyaitu : sebagainyaitu
# prifasitrims : prifasitrims
# virtual : virtual
# sekarng : sekarng
# kmna : kmna
# tu : tu
# khusus : khusus
# diaktifkan : aktif
# haduhh : haduhh
# ribett : ribett
# cc : cc
# tertagih : tagih
# confirmasi : confirmasi
# urus : urus
# temen : temen
# kabar : kabar
# bangke : bangke
# minggu : minggu
# alasnya : alas
# komen : komen
# kasar : kasar
# chatnya : chatnya
# block : block
# anjiiinbg : anjiiinbg
# nyampek : nyampek
# terkadang : terkadang
# nnya : nnya
# amana : amana
# suport : suport
# kelanjutan : lanjut
# komplainya : komplainya
# jozzzzz : jozzzzz
# gandossssst : gandossssst
# menutup : tutup
# meresa : resa
# rugikan : rugi
# senang : senang
# belanjatop : belanjatop
# palyeter : palyeter
# akulaku : akulaku
# penilaian : nilai
# ruang : ruang
# tutupdi : tutupdi
# tlfn : tlfn
# marah : marah
# ku : ku
# barusan : barusan
# hmpir : hmpir
# non : non
# etalase : etalase
# nonaktifkan : nonaktif
# lainya : lai
# gaib : gaib
# meningkatkan : tingkat
# mengajak : ajak
# menambah : tambah
# keranjang : keranjang
# klau : klau
# transfertapi : transfertapi
# pertahankan : tahan
# test : test
# bberapa : bberapa
# mempelajari : ajar
# kyknya : kyknya
# palsu : palsu
# apalah : apa
# gabakalan : gabakalan
# apapun : apa
# penangan : nang
# berkeliaran : liar
# bnr : bnr
# disaldo : saldo
# dibelikan : beli
# dikembalin : dikembalin
# merubah : rubah
# makasih : makasih
# bln : bln
# dgunakan : dgunakan
# ceo : ceo
# asugak : asugak
# mahalan : mahal
# belilama : belilama
# pertanda : tanda
# kolaps : kolaps
# tf : tf
# service : service
# komunikasi : komunikasi
# maintenance : maintenance
# disebelah : belah
# keberanda : beranda
# bloon : bloon
# bukasend : bukasend
# semprul : semprul
# start : start
# mei : mei
# subuh : subuh
# yakali : yakali
# kebagian : bagi
# kouta : kouta
# emg : emg
# disengaja : sengaja
# beritahu : beritahu
# disediakan : sedia
# care : care
# faq : faq
# mekanisme : mekanisme
# pemeliharaan : pelihara
# dimatiin : dimatiin
# scroll : scroll
# stak : stak
# perubahan : ubah
# erortolong : erortolong
# dipwrbaiki : dipwrbaiki
# dll : dll
# nyaterima : nyaterima
# butuhkan : butuh
# cicil : cicil
# tiki : tik
# mengaktifkan : aktif
# paraaah : paraaah
# zaman : zaman
# tercontreng : tercontreng
# covid : covid
# kebaca : baca
# kebeli : kebel
# voucer : voucer
# buru : buru
# miring : miring
# ori : ori
# platfom : platfom
# tertatrik : tertatrik
# smoga : smoga
# indonesia : indonesia
# menggunakannya : guna
# support : support
# perlindungan : lindung
# thn : thn
# ceritanya : cerita
# bbrp : bbrp
# mw : mw
# harapan : harap
# dibl : dibl
# menarik : tarik
# akibatnya : akibat
# drpd : drpd
# instan : instan
# bukalapakpesanan : bukalapakpesanan
# kurur : kurur
# si : si
# cepattapi : cepattapi
# complainmenu : complainmenu
# bukanantuan : bukanantuan
# betfungsi : betfungsi
# roda : roda
# sdikit : sdikit
# menit : menit
# jaringan : jaring
# indihome : indihome
# pengirimanya : pengirimanya
# melebihi : lebih
# tentukan : tentu
# responsif : responsif
# skrng : skrng
# lemoot : lemoot
# aplikasinyatolong : aplikasinyatolong
# lainudh : lainudh
# callcenter : callcenter
# isinya : isi
# artikel : artikel
# wkwkwk : wkwkwk
# berhubung : hubung
# newbie : newbie
# nilai : nilai
# nyalahin : nyalahin
# anjenggg : anjenggg
# toped : toped
# shopeee : shopeee
# bapuk : bapuk
# taiii : taiii
# berbelanjatp : berbelanjatp
# pembayarannya : bayar
# bebas : bebas
# persulit : sulit
# contohhanya : contohhanya
# berlaku : laku
# gt : gt
# banyakin : banyakin
# pelayananya : pelayananya
# responterima : responterima
# belanjanya : belanja
# custom : custom
# kalimat : kalimat
# terkesan : kes
# baku : baku
# harapannya : harap
# dimudahkan : mudah
# display : display
# merk : merk
# spesifikasi : spesifikasi
# tertampil : tampil
# variatif : variatif
# selisih : selisih
# signifikan : signifikan
# memilih : pilih
# kwalitas : kwalitas
# samsung : samsung
# plus : plus
# menginstal : menginstal
# pembaruan : baru
# tahan : tahan
# shoope : shoope
# secepatnya : cepat
# tindak : tindak
# lanjutinsaya : lanjutinsaya
# sampek : sampek
# bekukanke : bekukanke
# ngak : ngak
# produkbarang : produkbarang
# paporitdiketik : paporitdiketik
# keluartolong : keluartolong
# perbaikannya : baik
# tangapannya : tangap
# gajelasudah : gajelasudah
# lemottoko : lemottoko
# pengawasan : awas
# bukamau : bukamau
# mbatalin : mbatalin
# gabisaharus : gabisaharus
# on : on
# beritahuakan : beritahuakan
# yaadi : yaadi
# tanggung : tanggung
# xsetelah : xsetelah
# tercantumini : tercantumini
# akal : akal
# melayang : layang
# kabarsangat : kabarsangat
# lh : lh
# burukpenipuan : burukpenipuan
# gmail : gmail
# benerin : benerin
# nungguin : nungguin
# gmailnya : gmailnya
# goblogg : goblogg
# tertua : tua
# inovasi : inovasi
# satusatunya : satusatunya
# berfungsihatihati : berfungsihatihati
# xufsinv : xufsinv
# maksimal : maksimal
# dbatalkan : dbatalkan
# tertahan : tahan
# jelasjelas : jelasjelas
# tertera : tera
# hr : hr
# terbuka : buka
# updatenya : updatenya
# punyeng : punyeng
# hallo : hallo
# setahun : tahun
# bukadompet : bukadompet
# senilai : nila
# struk : struk
# bual : bual
# adakan : adakan
# request : request
# pickup : pickup
# awam : awam
# ramadhan : ramadhan
# posting : posting
# iming : iming
# utang : utang
# warung : warung
# hahaha : hahaha
# haaaaa : haaaaa
# halooooo : halooooo
# biji : biji
# order : order
# pajaknya : pajak
# royal : royal
# emosi : emosi
# pantesan : pantesan
# jadul : jadul
# ditinggalkan : tinggal
# costumer : costumer
# banyaktidak : banyaktidak
# bukabantuannya : bukabantuannya
# ninja : ninja
# expres : expres
# berpuluh : puluh
# puluh : puluh
# dilacak : lacak
# sukur : sukur
# sich : sich
# kopeten : kopeten
# stock : stock
# abis : abis
# beranda : beranda
# tayangin : tayangin
# transparant : transparant
# updatetan : updatetan
# install : install
# berulangulang : berulangulang
# mencoba : coba
# wadew : wadew
# blank : blank
# tandatanda : tandatanda
# berjamjam : berjamjam
# sore : sore
# pagi : pagi
# biarkan : biar
# ketemu : ketemu
# acha : acha
# niat : niat
# ilang : ilang
# wilyah : wilyah
# timur : timur
# contoh : contoh
# ongkos : ongkos
# kirimnya : kirim
# mencapai : capai
# fer : fer
# kemahalan : mahal
# jadikan : jadi
# gonta : gonta
# mencukupi : cukup
# memiliki : milik
# tolonglah : tolong
# basah : basah
# basih : basih
# custumer : custumer
# servicenya : servicenya
# ditangguhkan : tangguh
# sunguh : sunguh
# sarankan : saran
# menyimpan : simpan
# menghindari : hindar
# jepara : jepara
# bandung : bandung
# teramat : amat
# lamalebih : lamalebih
# wajargk : wajargk
# kerjasama : kerjasama
# orderan : order
# lagibukan : lagibukan
# sangt : sangt
# emak : emak
# lato : lato
# engga : engga
# swafoto : swafoto
# kanan : kanan
# kiri : kiri
# pegang : pegang
# buku : buku
# bantuin : bantuin
# rempong : rempong
# donk : donk
# warning : warning
# sistemnyasya : sistemnyasya
# sellerkenapa : sellerkenapa
# pencariandi : pencariandi
# tracking : tracking
# validbanyak : validbanyak
# pembelitapi : pembelitapi
# trackingnya : trackingnya
# percepat : cepat
# marketpkace : marketpkace
# kemaren : kemaren
# dibuka : buka
# mengembalikan : kembali
# kekurangan : kurang
# menilai : nilai
# kemunduran : mundur
# ratingnya : ratingnya
# angsuran : angsur
# syg : syg
# sajadan : sajadan
# aktifharus : aktifharus
# belanjabrg : belanjabrg
# potongam : potongam
# saller : saller
# promote : promote
# push : push
# efek : efek
# bhulshittt : bhulshittt
# garansi : garansi
# tipunya : tipu
# claimnya : claimnya
# default : default
# curang : curang
# berkahh : berkahh
# siasat : siasat
# mnjamingaransi : mnjamingaransi
# kunjung : kunjung
# juta : juta
# selau : selau
# sesi : sesi
# terkocak : kocak
# mulu : mulu
# kelar : kelar
# eneg : eneg
# dengernya : dengernya
# badut : badut
# tengkyuu : tengkyuu
# dijamin : jamin
# ktpreffvral : ktpreffvral
# btbldkzqvt : btbldkzqvt
# nyaaplikasii : nyaaplikasii
# lamasangat : lamasangat
# dikala : kala
# belanjatinggal : belanjatinggal
# bayarbarang : bayarbarang
# membaiktengkyuuu : membaiktengkyuuu
# password : password
# sekalibegitu : sekalibegitu
# verif : verif
# passwordklik : passwordklik
# lupa : lupa
# bisagimana : bisagimana
# traktiran : traktir
# debitnya : debit
# knyatanya : knyatanya
# sebulan : bulan
# akunnya : akun
# hoax : hoax
# menghubungi : hubung
# servis : servis
# presiden : presiden
# ngadu : ngadu
# standby : standby
# lokasi : lokasi
# dihalaman : halaman
# ka : ka
# ngalami : ngalami
# mendingan : mending
# ngalamin : ngalamin
# variannya : varian
# dipermudah : mudah
# fleksibel : fleksibel
# monoton : monoton
# disesuaikan : sesuai
# size : size
# real : real
# nurut : nurut
# kategori : kategori
# dinonaktifkan : nonaktif
# drastis : drastis
# keperluan : perlu
# mendesak : desak
# pinjam : pinjam
# tetangga : tetangga
# bisaselalu : bisaselalu
# lengkapi : lengkap
# chapta : chapta
# lulus : lulus
# ijo : ijo
# oran : oran
# paylter : paylter
# jebakan : jebak
# betmen : betmen
# berikanhanya : berikanhanya
# diwajibakan : diwajibakan
# tolak : tolak
# tampa : tampa
# penerimaan : terima
# gmana : gmana
# inikasih : inikasih
# bgtkasihan : bgtkasihan
# dongharusnya : dongharusnya
# max : max
# haribukanya : haribukanya
# pembelimenurut : pembelimenurut
# bukalapakklo : bukalapakklo
# pesananmereka : pesananmereka
# sendiridan : sendiridan
# kirimkanentah : kirimkanentah
# lupaatau : lupaatau
# readymohon : readymohon
# lagibuat : lagibuat
# rumitpadahal : rumitpadahal
# refaund : refaund
# prosespadahal : prosespadahal
# skali : skali
# laporan : lapor
# review : review
# dok : dok
# smua : smua
# prosez : prosez
# memutuskan : putus
# melampirkan : lampir
# rek : rek
# mutasi : mutasi
# nampaklah : nampaklah
# nota : nota
# bene : bene
# informasi : informasi
# krusial : krusial
# ats : ats
# profile : profile
# dmpak : dmpak
# securitynya : securitynya
# sk : sk
# mini : mini
# periode : periode
# maret : maret
# seharus : harus
# php : php
# kesempatan : sempat
# or : or
# lahh : lahh
# dibayarkan : bayar
# sprti : sprti
# prcuma : prcuma
# variasi : variasi
# laptop : laptop
# pc : pc
# telkom : telkom
# td : td
# wib : wib
# kebutuhandan : kebutuhandan
# berkwalitas : berkwalitas
# bangking : bangking
# cencel : cencel
# uangpun : uang
# sejarahbuktiin : sejarahbuktiin
# sendirikalah : sendirikalah
# sebelahjoos : sebelahjoos
# dowload : dowload
# inikarna : inikarna
# lamatp : lamatp
# barangpengiriman : barangpengiriman
# standar : standar
# membaiksesuai : membaiksesuai
# estimasiuntuk : estimasiuntuk
# ditingkat : tingkat
# lgtrima : lgtrima
# kasihapk : kasihapk
# mati : mati
# belain : bain
# galeri : galeri
# ehh : ehh
# taunya : tau
# melulu : melulu
# nyeesel : nyeesel
# bltp : bltp
# perlahan : perlahan
# beralih : alih
# lainselain : lainselain
# blnja : blnja
# rendah : rendah
# dn : dn
# beragamdi : beragamdi
# tawarkn : tawarkn
# kn : kn
# bhkn : bhkn
# kdg : kdg
# ketikcari : ketikcari
# ongir : ongir
# dibandingkan : banding
# bersaing : saing
# terbatas : batas
# com : com
# laindan : laindan
# de : de
# keaman : aman
# menjamin : jamin
# lemah : lemah
# taii : taii
# rekomendasikan : rekomendasi
# pikir : pikir
# power : power
# perasaan : asa
# lagiterima : lagiterima
# barangterima : barangterima
# bukalapaktidak : bukalapaktidak
# mengecewakanjaya : mengecewakanjaya
# bukalapakaplikasi : bukalapakaplikasi
# indonesiasekali : indonesiasekali
# so : so
# far : far
# icon : icon
# mutarmutar : mutarmutar
# dimana : mana
# menemukan : temu
# rekomendet : rekomendet
# bukak : bukak
# ujung : ujung
# gag : gag
# matiin : matiin
# eroor : eroor
# paylatter : paylatter
# pmesanan : pmesanan
# penjelasannya : jelas
# taeeek : taeeek
# zusah : zusah
# sms : sms
# trnyata : trnyata
# kepeeet : kepeeet
# hitungan : hitung
# julan : julan
# bayak : bayak
# tampilll : tampilll
# penjuln : penjuln
# peroduk : peroduk
# sayh : sayh
# bertulis : tulis
# juragan : juragan
# tampill : tampill
# peminat : minat
# buatt : buatt
# jahitannya : jahit
# hadiah : hadiah
# pengharum : harum
# lagitoplah : lagitoplah
# dihistory : dihistory
# menyertakan : serta
# kenal : kenal
# debit : debit
# indomaret : indomaret
# notifnya : notifnya
# gada : gada
# ovo : ovo
# haduh : haduh
# bngt : bngt
# ngercash : ngercash
# appnya : appnya
# gegara : gegara
# fiturenyanotif : fiturenyanotif
# lokasinya : lokasi
# jngan : jngan
# msih : msih
# pencariantrus : pencariantrus
# banned : banned
# member : member
# area : area
# wlaaupun : wlaaupun
# seh : seh
# tayangkankacau : tayangkankacau
# skrgadukan : skrgadukan
# rindu : rindu
# bpk : bpk
# achmad : achmad
# zakypro : zakypro
# umkm : umkm
# komplennpun : komplennpun
# bukaklapak : bukaklapak
# sehat : sehat
# berisik : berisik
# nongol : nongol
# managamentnya : managamentnya
# perbaikin : perbaikin
# pakaibuat : pakaibuat
# paylatenya : paylatenya
# bodong : bodong
# terrlambat : terrlambat
# seumur : umur
# hidup : hidup
# tanggap : tanggap
# kategorinya : kategori
# apknya : apknya
# mskin : mskin
# mendukung : dukung
# dancok : dancok
# asu : asu
# soldoku : soldoku
# wes : wes
# cok : cok
# vlinv : vlinv
# nyampenya : nyampenya
# ditransit : transit
# paketnya : paket
# periksa : periksa
# tambahkan : tambah
# dngn : dngn
# enaknya : enak
# dipercaya : percaya
# pin : pin
# otak : otak
# mutu : mutu
# playstore : playstore
# pelatihan : latih
# prakerja : prakerja
# centang : centang
# slot : slot
# bela : bela
# berusaha : usaha
# tokped : tokped
# anti : anti
# lemotnya : lot
# pelarian : lari
# marketplasce : marketplasce
# seduniaongkir : seduniaongkir
# tingkat : tingkat
# da : da
# danalagian : danalagian
# ngebatalinpuaaaayah : ngebatalinpuaaaayah
# kupon : kupon
# centernya : centernya
# waktugk : waktugk
# lamamannnnntap : lamamannnnntap
# apasih : apasih
# lemottt : lemottt
# gakk : gakk
# kapokk : kapokk
# nolong : nolong
# aji : aji
# mumpung : mumpung
# ny : ny
# dy : dy
# qt : qt
# terburuk : buruk
# tenggang : tenggang
# wktu : wktu
# nihil : nihil
# dukung : dukung
# buatan : buat
# anak : anak
# negeri : negeri
# baliksaya : baliksaya
# khawatir : khawatir
# diatas : atas
# efektif : efektif
# comerce : comerce
# bilangin : bilangin
# kalikalo : kalikalo
# bagusdan : bagusdan
# bagusawas : bagusawas
# komentartetap : komentartetap
# jaga : jaga
# kebagusannya : bagus
# gestun : gestun
# selfie : selfie
# oknum : oknum
# memgecewakan : memgecewakan
# biargak : biargak
# biargesit : biargesit
# bukanya : buka
# meresah : resah
# kanbelum : kanbelum
# puluhan : puluh
# nelpon : nelpon
# ma : ma
# maling : maling
# bahasa : bahasa
# duh : duh
# sopan : sopan
# santun : santun
# tar : tar
# menyesal : sesal
# siang : siang
# dicairkan : cair
# contact : contact
# jga : jga
# maa : maa
# allah : allah
# professional : professional
# komunikatif : komunikatif
# ditampilkan : tampil
# please : please
# dimengerti : erti
# pengusaha : usaha
# bijak : bijak
# mantapsudah : mantapsudah
# bagussesuai : bagussesuai
# dihati : hati
# log : log
# bagussemua : bagussemua
# rillrespon : rillrespon
# cepatpuas : cepatpuas
# gapernah : gapernah
# vocher : vocher
# najis : najis
# terpercayasemua : terpercayasemua
# adajelascepat : adajelascepat
# komplit : komplit
# bgtmantep : bgtmantep
# lapaksudah : lapaksudah
# sllu : sllu
# mengecewakanmasa : mengecewakanmasa
# lazadadi : lazadadi
# performa : performa
# kembangkan : kembang
# cinta : cinta
# sempurna : sempurna
# asyik : asyik
# dilesan : les
# dikirimnya : kirim
# susa : susa
# na : na
# diupgrade : diupgrade
# gunakanpadahal : gunakanpadahal
# lunastransakasi : lunastransakasi
# teruscoba : teruscoba
# faylaternya : faylaternya
# bisah : bisah
# nagihnya : nagihnya
# kayaknya : kayak
# daaah : daaah
# penyedot : sedot
# lemotblengga : lemotblengga
# inikayak : inikayak
# xxxxx : xxxxx
# mantulll : mantulll
# kondisi : kondisi
# very : very
# gus : gus
# diriwayat : riwayat
# penerima : terima
# trims : trims
# bangetmau : bangetmau
# berkalikali : berkalikali
# loginkatanya : loginkatanya
# apanyajelas : apanyajelas
# bilangnya : bilang
# salahsalah : salahsalah
# ahterus : ahterus
# loginnya : loginnya
# cap : cap
# kaki : kaki
# atm : atm
# kecepatan : cepat
# permintaannya : minta
# laganan : lagan
# perbarui : baru
# menurun : turun
# pembelijangan : pembelijangan
# dulususah : dulususah
# komfirmasi : komfirmasi
# fast : fast
# kepuasan : puas
# diseleksi : seleksi
# menunda : tunda
# pesanannya : pesan
# lagibuang : lagibuang
# kargo : kargo
# laman : laman
# tks : tks
# lma : lma
# bgtpadahal : bgtpadahal
# bekasipake : bekasipake
# jne : jne
# brng : brng
# pengirimankedepanya : pengirimankedepanya
# pdam : pdam
# dipercepat : cepat
# tanggalnya : tanggal
# diawal : awal
# jembutsaya : jembutsaya
# dagang : dagang
# kluar : kluar
# th : th
# dlliklan : dlliklan
# dngan : dngan
# belasan : bas
# boroboro : boroboro
# munculbangsaaatt : munculbangsaaatt
# great : great
# mank : mank
# tmantmin : tmantmin
# bergabung : gabung
# bawa : bawa
# dalamapa : dalamapa
# bongkaran : bongkar
# higgs : higgs
# dominosaya : dominosaya
# susahcukup : susahcukup
# sisi : sisi
# popup : popup
# stelah : stelah
# dikirimlha : dikirimlha
# kendaladan : kendaladan
# solusitidak : solusitidak
# utamakan : utama
# merah : merah
# bendera : bendera
# putih : putih
# jingga : jingga
# cintai : cinta
# karya : karya
# bangsa : bangsa
# mantapsemakin : mantapsemakin
# bukalapakmemberikan : bukalapakmemberikan
# bertransaksitx : bertransaksitx
# bagusbanyakin : bagusbanyakin
# codnya : codnya
# byar : byar
# trlalu : trlalu
# dobel : dobel
# bunga : bunga
# anjir : anjir
# mencret : mencret
# we : we
# kirain : kirain
# penasaran : penasaran
# ttep : ttep
# stiap : stiap
# rentenir : rentenir
# bner : bner
# parahnya : parah
# kelewatan : lewat
# unistal : unistal
# ayolah : ayo
# pengambilan : ambil
# keping : keping
# gram : gram
# bintan : bintan
# csa : csa
# pelayananaslowresponudh : pelayananaslowresponudh
# masalaha : masalaha
# ampe : ampe
# selesaisorry : selesaisorry
# apus : apus
# aplikasimending : aplikasimending
# nonaktifin : nonaktifin
# skalian : skalian
# konsumennya : konsumen
# ber : ber
# original : original
# munculnya : muncul
# chapcat : chapcat
# ters : ters
# otpnya : otpnya
# kesel : kesel
# btblbnfvpw : btblbnfvpw
# luncurkan : luncur
# versi : versi
# lite : lite
# minimum : minimum
# makai : maka
# mudahan : mudah
# knapa : knapa
# gwa : gwa
# sayamaling : sayamaling
# kocakngak : kocakngak
# nyabukti : nyabukti
# transferan : transfer
# sayaatas : sayaatas
# kwkwkwwktaiktaik : kwkwkwwktaiktaik
# taikjangan : taikjangan
# banyakdan : banyakdan
# cashback : cashback
# ampuuuunnnnnbaru : ampuuuunnnnnbaru
# downlod : downlod
# lemooooooooottttttudh : lemooooooooottttttudh
# kebuka : buka
# layarnya : layar
# teruuuuussssaplikasi : teruuuuussssaplikasi
# jlelekgk : jlelekgk
# bltransaksi : bltransaksi
# sufah : sufah
# diteruskan : terus
# pelapakharus : pelapakharus
# jamaneh : jamaneh
# dtoko : dtoko
# masuktp : masuktp
# terpotongmau : terpotongmau
# digubriskecewa : digubriskecewa
# trim : trim
# gan : gan
# mendarat : darat
# selamat : selamat
# manfaat : manfaat
# diberanda : beranda
# gambarnya : gambar
# kosongsearch : kosongsearch
# kosonggimana : kosonggimana
# jringan : jringan
# ngebut : ngebut
# unit : unit
# powerbank : powerbank
# soulkarena : soulkarena
# masingrp : masingrp
# berhasiltgl : berhasiltgl
# prosestp : prosestp
# systemkarena : systemkarena
# bukalapakfitur : bukalapakfitur
# pakaibukalapak : pakaibukalapak
# customermana : customermana
# tanggungjawab : tanggungjawab
# andasy : andasy
# payleternya : payleternya
# mmbuat : mmbuat
# smkin : smkin
# blh : blh
# brkali : brkali
# ttap : ttap
# setenga : setenga
# percayaterima : percayaterima
# bukalapakbarang : bukalapakbarang
# yahuuuutt : yahuuuutt
# kasihby : kasihby
# rahesa : rahesa
# dewaga : dewaga
# adanyadi : adanyadi
# manasemua : manasemua
# lapakga : lapakga
# tertarik : tarik
# love : love
# lapakselalu : lapakselalu
# bestbuka : bestbuka
# lapakpastiadaa : lapakpastiadaa
# serbah : serbah
# laloadnya : laloadnya
# malem : malem
# ngebug : ngebug
# yx : yx
# samday : samday
# sekeng : keng
# urgent : urgent
# disarankan : saran
# jangn : jangn
# sinh : sinh
# input : input
# emailnya : email
# dibuatkan : buat
# baguss : baguss
# ajah : ajah
# stuck : stuck
# captcha : captcha
# situh : situh
# melulubebalik : melulubebalik
# bacaan : baca
# gituan : gituan
# pembelanjaan : belanja
# syang : syang
# mngajukan : mngajukan
# payltr : payltr
# nihpadahal : nihpadahal
# fullberat : fullberat
# trmksh : trmksh
# puassssssssssssbanget : puassssssssssssbanget
# dipertahankan : tahan
# cape : cape
# berhasilaplikasi : berhasilaplikasi
# taiiiii : taiiiii
# ketidak : tidak
# nyamanan : nyaman
# bla : bla
# jugajd : jugajd
# carisukses : carisukses
# jaman : jaman
# tertinggal : tinggal
# menjalankan : jalan
# kelola : kelola
# terimaka : terimaka
# thanks : thanks
# baguskalo : baguskalo
# murahsama : murahsama
# senyum : senyum
# dibukalapakkarena : dibukalapakkarena
# menguntungkan : untung
# komlplen : komlplen
# terkonfirmasi : konfirmasi
# kelas : kelas
# pelayananterutama : pelayananterutama
# transitnya : transit
# badal : badal
# terusapk : terusapk
# berbelit : belit
# belit : belit
# dicobasemoga : dicobasemoga
# bagussayang : bagussayang
# pos : pos
# signal : signal
# grab : grab
# kaga : kaga
# depoktangsel : depoktangsel
# jaraka : jaraka
# kebijaksanaan : bijaksana
# boskuh : boskuh
# bisabisa : bisabisa
# upnya : upnya
# tawarkan : tawar
# depelover : depelover
# diprosses : diprosses
# kudu : kudu
# pelyanannya : pelyanannya
# woiiiiiii : woiiiiiii
# manaudah : manaudah
# logindaftar : logindaftar
# ongkirtp : ongkirtp
# murahjd : murahjd
# mengadakan : ada
# mksh : mksh
# referral : referral
# rezeki : rezeki
# mendaftar : daftar
# perpanjang : panjang
# bukutabungan : bukutabungan
# hpgmail : hpgmail
# code : code
# undangan : undang
# btblvj : btblvj
# nasabah : nasabah
# paylaternyakatanya : paylaternyakatanya
# brg : brg
# mantablah : mantablah
# rekomend : rekomend
# muluss : muluss
# keselahan : lah
# mengulang : ulang
# beresin : resin
# terganggu : ganggu
# semuaskrg : semuaskrg
# nyamantap : nyamantap
# blsmoga : blsmoga
# umurmakin : umurmakin
# aplika : aplika
# dunk : dunk
# itikad : itikad
# tingkatkn : tingkatkn
# ditingkatkn : ditingkatkn
# yrus : yrus
# berkembang : kembang
# lemotmuter : lemotmuter
# selesaikan : selesai
# bukalapakpadahal : bukalapakpadahal
# daftarapa : daftarapa
# distatus : status
# kompaliannya : kompaliannya
# rada : rada
# eksis : eks
# ...
# selfi : selfi
# difaq : difaq
# pemulihan : pulih
# pembekuan : beku
# koq : koq
# dibalas : balas
# terimakasib : terimakasib
# belenja : belenja
# blenk : blenk
# disisni : disisni
# compatible : compatible
# rotasi : rotasi
# perputaran : putar
# tegak : tegak
# landscape : landscape
# mengurangi : kurang
# sentuh : sentuh
# genting : genting
# pling : pling
# menyebalkan : sebal
# perbulannya : bulan
# mpe : mpe
# kepepet : pepet
# scam : scam
# jangam : jangam
# trm : trm
# ksh : ksh
# bagusmalah : bagusmalah
# menurunupdate : menurunupdate
# berpengaruhhapus : berpengaruhhapus
# cacheclear : cacheclear
# datasama : datasama
# ajaaplikasi : ajaaplikasi
# nonton : nonton
# hd : hd
# peringan : pering
# punyak : punyak
# orderannya : order
# sok : sok
# lemotbahkan : lemotbahkan
# sesimpel : simpel
# emaneman : emaneman
# berdiri : diri
# tetspi : tetspi
# performanya : performa
# belangganan : banggan
# bertambahnya : tambah
# kemampuan : mampu
# seringkali : seringkali
# sarang : sarang
# big : big
# kecewatiap : kecewatiap
# utuh : utuh
# onlineuntuk : onlineuntuk
# hehe : hehe
# mintak : mintak
# photo : photo
# menunjukan : tunjuk
# temanteman : temanteman
# bukalapakkurirnya : bukalapakkurirnya
# jidat : jidat
# otakbarang : otakbarang
# kirimkirimitu : kirimkirimitu
# tanaman : tanam
# sialanbukalapak : sialanbukalapak
# adalive : adalive
# janjiin : janjiin
# sampaikurirnya : sampaikurirnya
# akhlak : akhlak
# terkendalakalau : terkendalakalau
# jawabburuk : jawabburuk
# tiada : tiada
# berinovasi : inovasi
# semangatsemangat : semangatsemangat
# im : im
# ttpi : ttpi
# alfamaret : alfamaret
# terkena : kena
# menghilangkan : hilang
# laintokopedia : laintokopedia
# akalkok : akalkok
# uinstal : uinstal
# lapaktp : lapaktp
# diposting : diposting
# bukalapakkrn : bukalapakkrn
# lebaran : lebaran
# mengisi : isi
# dilampirkan : lampir
# meneruskan : terus
# diajukan : aju
# menghapus : hapus
# padahap : padahap
# out : out
# mengoprasikan : mengoprasikan
# uplod : uplod
# lambatasuknya : lambatasuknya
# muudah : muudah
# bidang : bidang
# academy : academy
# handle : handle
# hape : hape
# besoknya : besok
# gerak : gerak
# gosok : gosok
# mumpuni : mumpuni
# dipencet : pencet
# white : white
# kapasitas : kapasitas
# sekalik : sekalik
# hank : hank
# terbit : terbit
# ilangresetbaik : ilangresetbaik
# perncarian : perncarian
# sellerbuyer : sellerbuyer
# puasnyaman : puasnyaman
# tenang : tenang
# pastikan : pasti
# gangguannya : ganggu
# sependapat : dapat
# acara : acara
# mjd : mjd
# bunyi : bunyi
# pesannya : pesan
# oranye : oranye
# rese : rese
# seri : seri
# platformnya : platform
# operating : operating
# interfacenya : interfacenya
# reinstal : reinstal
# akitivitas : akitivitas
# desktop : desktop
# androin : androin
# ios : ios
# ngelink : ngelink
# bandwitch : bandwitch
# sizenya : sizenya
# note : note
# smarphone : smarphone
# terlewati : lewat
# dibawah : bawah
# bunyinya : bunyi
# baruudah : baruudah
# mohondiperbaiki : mohondiperbaiki
# teraman : ram
# fiktif : fiktif
# dichat : dichat
# transaksinyajd : transaksinyajd
# nyapada : nyapada
# eksekusi : eksekusi
# transaksidalam : transaksidalam
# satuharus : satuharus
# berkualitastidak : berkualitastidak
# bedanya : beda
# lancarbisa : lancarbisa
# errorserver : errorserver
# berkualitasdan : berkualitasdan
# berkualitasbuat : berkualitasbuat
# koplain : koplain
# vidio : vidio
# mengubah : ubah
# telepon : telepon
# tabunganrekeningsedangkan : tabunganrekeningsedangkan
# datanya : data
# minnn : minnn
# sanksi : sanksi
# wanprestasi : wanprestasi
# urgentpkknya : urgentpkknya
# adaptasi : adaptasi
# pentingkan : penting
# waktupokoknya : waktupokoknya
# joss : joss
# seharihari : seharihari
# pertahan : tahan
# semngt : semngt
# diperbaikisoalnya : diperbaikisoalnya
# kecamatan : camat
# dimanfaatkan : manfaat
# ordreran : ordreran
# ekspedisikarna : ekspedisikarna
# dendaga : dendaga
# ngotak : ngotak
# bermanfaatmateri : bermanfaatmateri
# formalbiar : formalbiar
# lgebook : lgebook
# typo : typo
# dijelaskantambahkan : dijelaskantambahkan
# diputar : putar
# userjumlah : userjumlah
# mbelgedez : mbelgedez
# ne : ne
# rentang : rentang
# kadauwarsa : kadauwarsa
# keuangannya : uang
# optimal : optimal
# keblokir : blokir
# nomormasuk : nomormasuk
# diupload : diupload
# reaponsif : reaponsif
# etc : etc
# instant : instant
# itulahpantes : itulahpantes
# bales : bales
# arahin : arahin
# blidappreview : blidappreview
# nonus : nonus
# neruntun : neruntun
# mendeteksi : deteksi
# kejanggalan : janggal
# bantuantapi : bantuantapi
# ngakses : ngakses
# pencerahannya : cerah
# menbuat : menbuat
# penyebabnya : sebab
# setabil : setabil
# singkronisasi : singkronisasi
# bgsond : bgsond
# shak : shak
# tingkatkkan : tingkatkkan
# mbnya : mbnya
# pelunasan : lunas
# deadline : deadline
# pemrosesannya : pemrosesannya
# kuantitas : kuantitas
# letak : letak
# pop : pop
# ponsel : ponsel
# end : end
# gaguna : gaguna
# amatir : amatir
# irman : irman
# kopon : kopon
# komentar : komentar
# apasly : apasly
# kkurangan : kkurangan
# daplikasi : daplikasi
# bukalapaksky : bukalapaksky
# ysuper : ysuper
# lengkapapa : lengkapapa
# bthknada : bthknada
# ddlm : ddlm
# inibuat : inibuat
# raguuntk : raguuntk
# mdownloadpergunakan : mdownloadpergunakan
# jgnikmati : jgnikmati
# sgla : sgla
# kmudahan : kmudahan
# ysukses : ysukses
# truntuk : truntuk
# bukalapaktq : bukalapaktq
# waswas : waswas
# maraknya : marak
# macamtapi : macamtapi
# responnyaterima : responnyaterima
# pelayanannyagoodluck : pelayanannyagoodluck
# sameday : sameday
# mengantarkan : antar
# diolshop : diolshop
# stoknya : stok
# dibatalikan : dibatalikan
# namezulmarrusdiputra : namezulmarrusdiputra
# adasemua : adasemua
# ckup : ckup
# dbandingkan : dbandingkan
# laintuk : laintuk
# pemblian : pemblian
# pengirman : pengirman
# lambatlama : lambatlama
# wacana : wacana
# tuk : tuk
# kdepany : kdepany
# dpaki : dpaki
# thank : thank
# susunan : susun
# disederhanakan : sederhana
# transisi : transisi
# memakan : makan
# membangun : bangun
# modern : modern
# cttn : cttn
# be : be
# connected : connected
# copy : copy
# perangkat : perangkat
# gamti : gamti
# memuaskandan : memuaskandan
# datangi : datang
# sesui : sesui
# diharapkankurir : diharapkankurir
# okrespon : okrespon
# siiip : siiip
# trnyta : trnyta
# bnar : bnar
# nie : nie
# hrg : hrg
# trnytaa : trnytaa
# trma : trma
# trtahan : trtahan
# complen : complen
# tdak : tdak
# bsatidak : bsatidak
# tnggung : tnggung
# blsaya : blsaya
# tw : tw
# trima : trima
# untk : untk
# mnta : mnta
# bossharap : bossharap
# pelan : pelan
# simpati : simpati
# paylaterbayarnya : paylaterbayarnya
# gaessternyata : gaessternyata
# ditetangga : tetangga
# lamagak : lamagak
# pemantauan : pantau
# adabeberapa : adabeberapa
# ongkirlahmasa : ongkirlahmasa
# sukarela : sukarela
# nganterin : nganterin
# belanjatingkat : belanjatingkat
# peminatnya : minat
# terjaga : jaga
# giamanasih : giamanasih
# mgadain : mgadain
# sesuaikalo : sesuaikalo
# sanggup : sanggup
# ngafain : ngafain
# gala : gala
# gj : gj
# saldobuktinya : saldobuktinya
# halaaaah : halaaaah
# loyo : loyo
# vouher : vouher
# pmbelian : pmbelian
# terachir : terachir
# kmana : kmana
# sajayang : sajayang
# snub : snub
# ring : ring
# sblh : sblh
# membantusemoga : membantusemoga
# sealu : alu
# prodak : prodak
# penguriman : penguriman
# samakin : samakin
# bekukanpadahal : bekukanpadahal
# pakaipas : pakaipas
# tangkurak : tangkurak
# butuuuuuuuut : butuuuuuuuut
# pesanancuman : pesanancuman
# loodingnya : loodingnya
# perkiraan : kira
# nyala : nyala
# chapca : chapca
# padahl : padahl
# terferivikasi : terferivikasi
# lemottttmending : lemottttmending
# sat : sat
# iklanhasilnya : iklanhasilnya
# manfaatatnya : manfaatatnya
# satupuntidak : satupuntidak
# biometrik : biometrik
# bukalapa : bukalapa
# sayangkan : sayang
# otomatisnya : otomatis
# dulusekali : dulusekali
# parahudh : parahudh
# tahunan : tahun
# lazadauinstal : lazadauinstal
# bukalapakudah : bukalapakudah
# centre : centre
# tott : tott
# pala : pala
# bapako : bapako
# stop : stop
# saler : saler
# bahaya : bahaya
# dng : dng
# pushnya : pushnya
# nyoba : nyoba
# penipusaya : penipusaya
# bukalapakmksd : bukalapakmksd
# bgtu : bgtu
# aplikasii : aplikasi
# bisadi : bisadi
# negeriigoodgood : negeriigoodgood
# kb : kb
# mainkan : main
# coz : coz
# rubahterus : rubahterus
# lolos : lolos
# maless : maless
# bnaget : bnaget
# inih : inih
# malashubungkan : malashubungkan
# susahsilahkn : susahsilahkn
# diam : diam
# keluhn : keluhn
# kitamalas : kitamalas
# bklapak : bklapak
# benlanja : benlanja
# shoppe : shoppe
# siaga : siaga
# susahbertanya : susahbertanya
# opensusahgek : opensusahgek
# ksini : ksini
# pait : pait
# paylaterparah : paylaterparah
# sgini : sgini
# lamabukabantuan : lamabukabantuan
# ribetsusah : ribetsusah
# dmna : dmna
# cpat : cpat
# pokokny : pokokny
# seringan : sering
# penjaualan : penjaualan
# rekeninglama : rekeninglama
# rajin : rajin
# sussh : sussh
# tmbhin : tmbhin
# prdukgk : prdukgk
# tkopedia : tkopedia
# shope : shope
# gampangcontact : gampangcontact
# hbngitnya : hbngitnya
# jwab : jwab
# smuagmna : smuagmna
# konsulpntesan : konsulpntesan
# klah : klah
# mahalsukses : mahalsukses
# nol : nol
# seting : ting
# banking : banking
# verifikasibikin : verifikasibikin
# darting : darting
# bukalapaksangat : bukalapaksangat
# cashterimkasih : cashterimkasih
# paylatersetiap : paylatersetiap
# rbkalau : rbkalau
# kapooooookk : kapooooookk
# aplicationtapi : aplicationtapi
# sueee : sueee
# nglunasin : nglunasin
# re : re
# kebukapas : kebukapas
# barangselalu : barangselalu
# awaldan : awaldan
# animasi : animasi
# berlaripayah : berlaripayah
# perbaikisaya : perbaikisaya
# respect : respect
# instagram : instagram
# dibales : dibales
# reload : reload
# berabe : berabe
# kek : kek
# sarana : sarana
# perantara : antara
# berintegritas : integritas
# tidk : tidk
# keinginanpesanan : keinginanpesanan
# dinamika : dinamika
# kasat : kasat
# skr : skr
# diandalkanayo : diandalkanayo
# secepatnyananti : secepatnyananti
# ketinggalankita : ketinggalankita
# surat : surat
# sistemkurang : sistemkurang
# dijadikan : jadi
# formitu : formitu
# masalahnyajawaban : masalahnyajawaban
# lamawaalaaeh : lamawaalaaeh
# komitmen : komitmen
# bentuk : bentuk
# belah : belah
# promopromo : promopromo
# berterimakasih : berterimakasih
# aksesnya : akses
# penyampaian : sampai
# materinya : materi
# terperincipelatihannya : terperincipelatihannya
# pahamisangat : pahamisangat
# sayatrimakasih : sayatrimakasih
# terbantu : bantu
# pembelajaran : ajar
# prakerjasaya : prakerjasaya
# menerangkan : terang
# terjun : terjun
# freelancer : freelancer
# nampilin : nampilin
# terpopuler : populer
# komparasi : komparasi
# puaskanpengunaan : puaskanpengunaan
# carisaya : carisaya
# pembuat : buat
# traksaksi : traksaksi
# kaliklo : kaliklo
# terjangkauongkos : terjangkauongkos
# shaller : shaller
# ringansekarang : ringansekarang
# hitam : hitam
# duluterus : duluterus
# merespongak : merespongak
# aplikasibiar : aplikasibiar
# kebawa : bawa
# pebaharui : baharu
# mepersulit : mepersulit
# melakukakan : melakukakan
# kontakcall : kontakcall
# berinteraksi : interaksi
# blnya : blnya
# berbenti : berbenti
# dibagian : bagi
# diganti : ganti
# memusingkan : pusing
# security : security
# cekup : cekup
# ngurut : ngurut
# ngacak : ngacak
# semuajadi : semuajadi
# lapaklangsung : lapaklangsung
# satusebenarnya : satusebenarnya
# menyukai : suka
# lapakmeski : lapakmeski
# lapaksemoga : lapaksemoga
# memajukan : maju
# dipoto : dipoto
# tanggapannya : tanggap
# dibobol : bobol
# phising : phising
# judulnya : judul
# shoponline : shoponline
# iti : iti
# diperhatikan : perhati
# lapakdan : lapakdan
# abang : abang
# ekspedisinya : ekspedisi
# dibanned : dibanned
# hahaa : hahaa
# tulisannya : tulis
# lapakrecommended : lapakrecommended
# dahbrg : dahbrg
# sampenyagak : sampenyagak
# mark : mark
# tarif : tarif
# ttg : ttg
# dianggap : anggap
# gerai : gerai
# wlwpun : wlwpun
# pembeliannya : beli
# bkin : bkin
# menyempatkan : sempat
# customers : customers
# siasia : siasia
# naikkan : naik
# bukadanabukadompet : bukadanabukadompet
# bukadana : bukadana
# uninsntall : uninsntall
# sebelmnya : sebelmnya
# menjengkelkan : jengkel
# perpaling : paling
# menghalangi : halang
# ditemui : temu
# laih : laih
# dipertimbangkan : timbang
# survey : survey
# berkaitan : kait
# telur : telur
# rusakkomplainnya : rusakkomplainnya
# sepadan : padan
# hasilnyakarna : hasilnyakarna
# klaimkomplain : klaimkomplain
# rusaknya : rusak
# ekspedisimemang : ekspedisimemang
# kitauntuk : kitauntuk
# jeleknya : jelek
# terbaiiiiiiiiiiik : terbaiiiiiiiiiiik
# mempesona : pesona
# memudahkanmantap : memudahkanmantap
# dbayar : dbayar
# lunastp : lunastp
# dpesan : dpesan
# pelapakkesan : pelapakkesan
# terbusuk : busuk
# membantusukses : membantusukses
# gays : gays
# referal : referal
# mksih : mksih
# benerrrrrr : benerrrrrr
# niatny : niatny
# bpm : bpm
# {'paylater': 'paylater', 'ngk': 'ngk', 'bener': 'bener', 'batalkan': 'batal', 'otomatis': 'otomatis', 'kadang': 'kadang', 'nya': 'nya', 'gantian': 'ganti', 'jatuh': 'jatuh', 'tempo': 'tempo', 'bayar': 'bayar', 'biaya': 'biaya', 'keterlambatan': 'lambat', 'layanan': 'layan', 'biar': 'biar', 'merasakan': 'rasa', 'rasakan': 'rasa', 'sistem': 'sistem', 'seenak': 'enak', 'chat': 'chat', 'susah': 'susah', 'error': 'error', 'menyalahkan': 'salah', 'bikin': 'bikin', 'pusing': 'pusing', 'pengembalian': 'kembali', 'dana': 'dana', 'ga': 'ga', 'berfungsisy': 'berfungsisy', 'lg': 'lg', 'butuh': 'butuh', 'bgt': 'bgt', 'dananya': 'dana', 'ajuin': 'ajuin', 'komplainada': 'komplainada', 'tombol': 'tombol', 'komplain': 'komplain', 'diarahin': 'diarahin', 'pusat': 'pusat', 'bantuan': 'bantu', 'utk': 'utk', 'pengajuan': 'aju', 'pembatalanpengembalian': 'pembatalanpengembalian', 'aplikasinya': 'aplikasi', 'payahmenyulitkan': 'payahmenyulitkan', 'konsumen': 'konsumen', 'kesini': 'kesini', 'buka': 'buka', 'lapak': 'lapak', 'bagus': 'bagus', 'pelayanannya': 'layan', 'komplan': 'komplan', 'aja': 'aja', 'banget': 'banget', 'beberapakali': 'beberapakali', 'transaksi': 'transaksi', 'rekening': 'rekening', 'dah': 'dah', 'kepotong': 'potong', 'lapaknya': 'lapak', 'terverifikasi': 'verifikasi', 'kalo': 'kalo', 'pingin': 'pingin', 'menu': 'menu', 'upload': 'upload', 'bukti': 'bukti', 'bayarnya': 'bayar', 'nggak': 'nggak', 'muncul': 'muncul', 'kali': 'kali', 'kehilangan': 'hilang', 'uang': 'uang', 'pembayaran': 'bayar', 'gagal': 'gagal', 'dibayar': 'bayar', 'lunaspaylater': 'lunaspaylater', 'apapunselalu': 'apapunselalu', 'dibatalkan': 'batal', 'berhari': 'hari', 'coba': 'coba', 'cs': 'cs', 'bukalapak': 'bukalapak', 'tersambungjawaban': 'tersambungjawaban', 'agen': 'agen', 'sibuk': 'sibuk', 'parahpayah': 'parahpayah', 'update': 'update', 'ngaco': 'ngaco', 'aplikasi': 'aplikasi', 'barang': 'barang', 'favorit': 'favorit', 'gbs': 'gbs', 'search': 'search', 'skrg': 'skrg', 'klo': 'klo', 'cari': 'cari', 'bl': 'bl', 'yg': 'yg', 'ad': 'ad', 'tau': 'tau', 'pd': 'pd', 'kmn': 'kmn', 'penjual': 'jual', 'item': 'item', 'toko': 'toko', 'sebelah': 'belah', 'sulit': 'sulit', 'belanja': 'belanja', 'dsni': 'dsni', 'terpaksa': 'paksa', 'maaf': 'maaf', 'ya': 'ya', 'boss': 'boss', 'bekukan': 'beku', 'limit': 'limit', 'tdk': 'tdk', 'naikyg': 'naikyg', 'percaya': 'percaya', 'mode': 'mode', 'cod': 'cod', 'tambahan': 'tambah', 'rp': 'rp', 'aga': 'aga', 'males': 'males', 'systemnya': 'systemnya', 'udah': 'udah', 'pelayanan': 'layan', 'tutupin': 'tutupin', 'pelanggan': 'langgan', 'kecewa': 'kecewa', 'kurirnya': 'kurir', 'ngirim': 'ngirim', 'ongkirku': 'ongkirku', 'dipotong': 'potong', 'dikembalikan': 'kembali', 'ongkirnya': 'ongkirnya', 'kemana': 'mana', 'pake': 'pake', 'bukabantuan': 'bukabantuan', 'live': 'live', 'jalan': 'jalan', 'permasalahan': 'masalah', 'tsb': 'tsb', 'sekian': 'sekian', 'pke': 'pke', 'apk': 'apk', 'bru': 'bru', 'kli': 'kli', 'berat': 'berat', 'serasa': 'serasa', 'ditipu': 'tipu', 'sma': 'sma', 'beli': 'beli', 'jasa': 'jasa', 'pengiriman': 'kirim', 'ekspres': 'ekspres', 'dgn': 'dgn', 'estimasi': 'estimasi', 'kerja': 'kerja', 'ekspedisi': 'ekspedisi', 'peniriman': 'peniriman', 'jdi': 'jdi', 'bertanggung': 'tanggung', 'kerugian': 'rugi', 'materi': 'materi', 'ribet': 'ribet', 'sumpah': 'sumpah', 'setting': 'setting', 'maps': 'maps', 'refresh': 'refresh', 'ngulangin': 'ngulangin', 'kebanyakan': 'banyak', 'fitur': 'fitur', 'ganti': 'ganti', 'nomor': 'nomor', 'pilihan': 'pilih', 'wallet': 'wallet', 'seikit': 'seikit', 'bintang': 'bintang', 'membantu': 'bantu', 'ditingkatkan': 'tingkat', 'ongkir': 'ongkir', 'vocer': 'vocer', 'diskon': 'diskon', 'harapkan': 'harap', 'penambahan': 'tambah', 'pengguna': 'guna', 'berhak': 'hak', 'cocok': 'cocok', 'tuh': 'tuh', 'pelapak': 'lapak', 'verifikasi': 'verifikasi', 'ktp': 'ktp', 'infonya': 'info', 'jam': 'jam', 'akun': 'akun', 'verifikasigak': 'verifikasigak', 'masuk': 'masuk', 'gimana': 'gimana', 'jualan': 'jual', 'lemot': 'lot',  ...
# ------------------------
# Pandas Apply:   0%|          | 0/1300 [00:00<?, ?it/s]

# %%
name_dataframe["Ulasan_clean"] = [' '.join(map(str, l)) for l in name_dataframe['Ulasan_Stemmed']]

# %%
name_dataframe.to_excel("tokped_text.xlsx")

# %%
ulasan = ' '.join(str(v) for v in name_dataframe['Ulasan_clean'])

# %%
tokenize_ulasan = word_tokenize(ulasan)

# %%
tokenize_ulasan
# Out:
# ['paylater',
#  'ngk',
#  'bener',
#  'batal',
#  'otomatis',
#  'kadang',
#  'nya',
#  'ganti',
#  'jatuh',
#  'tempo',
#  'bayar',
#  'biaya',
#  'lambat',
#  'biaya',
#  'layan',
#  'biar',
#  'rasa',
#  'rasa',
#  'sistem',
#  'enak',
#  'nya',
#  'chat',
#  'susah',
#  'kadang',
#  'error',
#  'salah',
#  'layan',
#  'nya',
#  'bikin',
#  'pusing',
#  'ganti',
#  'pusing',
#  'kembali',
#  'dana',
#  'otomatis',
#  'ga',
#  'berfungsisy',
#  'lg',
#  'butuh',
#  'bgt',
#  'dana',
#  'ga',
#  'ajuin',
#  'komplainada',
#  'tombol',
#  'komplain',
#  'diarahin',
#  'pusat',
#  'bantu',
#  'ga',
#  'tombol',
#  'utk',
#  'aju',
#  'pembatalanpengembalian',
#  'dana',
#  'aplikasi',
#  'bener',
#  'payahmenyulitkan',
#  'konsumen',
#  'kesini',
#  'buka',
#  'lapak',
#  'bagus',
#  'layan',
#  'komplan',
#  'aja',
#  'susah',
#  'susah',
#  'banget',
#  'beberapakali',
#  'transaksi',
#  'rekening',
#  'dah',
#  'potong',
#  'buka',
#  'lapak',
#  'verifikasi',
#  'kalo',
#  'pingin',
#  'komplain',
#  'menu',
#  'upload',
#  'bukti',
#  'bayar',
#  'nggak',
#  'muncul',
#  'kali',
#  'kali',
#  'hilang',
#  'uang',
#  'bayar',
#  'gagal',
#  'verifikasi',
#  'bayar',
#  'lunaspaylater',
#  'transaksi',
#  'apapunselalu',
#  'batal',
#  'otomatis',
#  'hari',
#  'coba',
#  'komplain',
#  'cs',
#  'bukalapak',
#  'tersambungjawaban',
#  'agen',
#  'sibuk',
#  'ga',
#  'agen',
#  'cs',
#  'parahpayah',
#  'update',
#  'ngaco',
#  'aplikasi',
#  'menu',
#  'barang',
#  'favorit',
#  'gbs',
#  'search',
#  'skrg',
#  'klo',
#  'cari',
#  'barang',
#  'bl',
#  'yg',
#  'ga',
#  'ad',
#  'tau',
#  'pd',
#  'kmn',
#  'dah',
#  'jual',
#  'item',
#  'toko',
#  'belah',
#  'skrg',
#  'ga',
#  'sulit',
#  'cari',
#  'barang',
#  'favorit',
#  'belanja',
#  'dsni',
#  'paksa',
#  'cari',
#  'toko',
#  'belah',
#  'maaf',
#  'ya',
#  'boss',
#  'bayar',
#  'jatuh',
#  'tempo',
#  'paylater',
#  'beku',
#  'limit',
#  'tdk',
#  'naikyg',
#  'beku',
#  'percaya',
#  'aplikasi',
#  'mode',
#  'cod',
#  'biaya',
#  'tambah',
#  'rp',
#  'aga',
#  'males',
#  'belanja',
#  'nya',
#  'systemnya',
#  'kalo',
#  'udah',
#  'layan',
#  'tutupin',
#  'aja',
#  'aplikasi',
#  'langgan',
#  'kecewa',
#  'kurir',
#  'ngirim',
#  'barang',
#  'ongkirku',
#  'potong',
#  'uang',
#  'barang',
#  'kembali',
#  'ongkirnya',
#  'mana',
#  'udah',
#  'pake',
#  'bukabantuan',
#  'live',
#  'chat',
#  'jalan',
#  'masalah',
#  'tsb',
#  'sekian',
#  'pke',
#  'apk',
#  'bru',
#  'kli',
#  'kecewa',
#  'berat',
#  'serasa',
#  'tipu',
#  'sma',
#  'apk',
#  'beli',
#  'barang',
#  'jasa',
#  'kirim',
#  'ekspres',
#  'dgn',
#  'estimasi',
#  'barang',
#  'kerja',
#  'barang',
#  'ekspedisi',
#  'jasa',
#  'peniriman',
#  'yg',
#  'jdi',
#  'bukalapak',
#  'tanggung',
#  'rugi',
#  'materi',
#  'aplikasi',
#  'ribet',
#  'bgt',
#  'sumpah',
#  'setting',
#  'maps',
#  'aja',
#  'susah',
#  'refresh',
#  'ngulangin',
#  'banyak',
#  'fitur',
#  'ganti',
#  'nomor',
#  'aja',
#  'susah',
#  'pilih',
#  'wallet',
#  'nya',
#  'seikit',
#  'maaf',
#  'bintang',
#  'fitur',
#  'paylater',
#  'nya',
#  'bantu',
#  'yg',
#  'tingkat',
#  'biaya',
#  'ongkir',
#  'vocer',
#  'diskon',
#  'belanja',
#  'ongkir',
#  'harap',
#  'tambah',
#  'limit',
#  'paylater',
#  'guna',
#  'hak',
#  'cocok',
#  'tuh',
#  'lapak',
#  'verifikasi',
#  'ktp',
#  'info',
#  'jam',
#  'dah',
#  'akun',
#  'verifikasigak',
#  'masuk',
#  'menu',
#  'upload',
#  'barang',
#  'gimana',
#  'jual',
#  'lot',
#  'banget',
#  'verifikasi',
#  'nya',
#  'ribet',
#  'kesini',
#  'parah',
#  'error',
#  'login',
#  'sampe',
#  'bikin',
#  'akun',
#  'hubung',
#  'dana',
#  'alias',
#  'error',
#  'tulis',
#  'coba',
#  'jarang',
#  'dapet',
#  'potong',
#  'harga',
#  'belanja',
#  'nyamantidak',
#  'aman',
#  'beli',
#  'bukalapakselain',
#  'dah',
#  'mahalada',
#  'tambah',
#  'biaya',
#  'yg',
#  'bebankanmending',
#  'kl',
#  'barang',
#  'yg',
#  'kirim',
#  'benermending',
#  'kl',
#  'barang',
#  'kirim',
#  'aman',
#  'tujuansudah',
#  'ga',
#  'jaman',
#  'beli',
#  'online',
#  'kali',
#  'ya',
#  'lepas',
#  'salah',
#  'butuh',
#  'mendesakharusnya',
#  'bantu',
#  'dana',
#  'kembalibagaimanapun',
#  'konsumen',
#  'transaksi',
#  'jg',
#  'bldah',
#  'ulang',
#  'salah',
#  'samatapi',
#  'mohon',
#  'maaf',
#  'bintang',
#  'kasih',
#  'voucher',
#  'diskon',
#  'beli',
#  'pakai',
#  'dana',
#  'pakai',
#  'kuota',
#  'habis',
#  'diskon',
#  'emang',
#  'ga',
#  'dana',
#  'yg',
#  'pakai',
#  'beli',
#  'tuh',
#  'biaya',
#  'makan',
#  'balikin',
#  'dana',
#  'emang',
#  'vouchernya',
#  'pakai',
#  'batal',
#  'pesan',
#  'susah',
#  'yak',
#  'jual',
#  'bilang',
#  'ready',
#  'stok',
#  'tp',
#  'habis',
#  'nomor',
#  'rekening',
#  'biar',
#  'duit',
#  'transfer',
#  'tp',
#  'yg',
#  'kirim',
#  'amplop',
#  'kosong',
#  'jual',
#  'dpt',
#  'transaksi',
#  'beli',
#  'dpt',
#  'amplop',
#  'kosong',
#  'komplain',
#  'cs',
#  'bukabantuan',
#  'kasih',
#  'template',
#  'kagak',
#  'solusi',
#  'suruh',
#  'nunggu',
#  'jam',
#  'udah',
#  'udah',
#  'batas',
#  'proses',
#  'jg',
#  'tuh',
#  'batal',
#  'otomatis',
#  'parah',
#  'asli',
#  'parah',
#  'dosa',
#  'lu',
#  'nahan',
#  'rejeki',
#  'orang',
#  'batal',
#  'transaksi',
#  'aja',
#  'banget',
#  'paraaaahhhh',
#  'bayar',
#  'mudahpengiriman',
#  'cepatqualitas',
#  'sesuai',
#  'hargasaya',
#  'nyaman',
#  'mengunakan',
#  'aplikasi',
#  'bukalapak',
#  'moga',
#  'jaya',
#  'andal',
#  'guna',
#  'guna',
#  'bukalapak',
#  'tpi',
#  'bingung',
#  'adu',
#  'transaksi',
#  'masalah',
#  'lapak',
#  'proses',
#  'pesan',
#  'batal',
#  'uang',
#  'henti',
#  'aplikasi',
#  'salah',
#  'commerce',
#  'udah',
#  'pakai',
#  'worth',
#  'it',
#  'halaman',
#  'transaksi',
#  'kece',
#  'barang',
#  'sampai',
#  'tolong',
#  'cek',
#  'kembang',
#  'berat',
#  'banget',
#  'buka',
#  'halaman',
#  'internet',
#  'stabil',
#  'moga',
#  'cepat',
#  'baik',
#  'terimakasih',
#  'aplikasi',
#  'parah',
#  'trnsaksi',
#  'pulsa',
#  'berhasilpulsa',
#  'gk',
#  'masuktagihan',
#  'nya',
#  'adakomplen',
#  'urus',
#  'menu',
#  'bantu',
#  'live',
#  'chat',
#  'mesin',
#  'yg',
#  'satu',
#  'olshop',
#  'rampog',
#  'gk',
#  'transaksi',
#  'gk',
#  'ap',
#  'muncul',
#  'biaya',
#  'layan',
#  'paraaaaaaaahhhhh',
#  'kalo',
#  'kosong',
#  'kosong',
#  'bintang',
#  'bukalapakpercuma',
#  'limite',
#  'gagal',
#  'belanjatagihan',
#  'kosong',
#  'paylater',
#  'aktifpenanganan',
#  'nunggu',
#  'jam',
#  'wow',
#  'bukalapak',
#  'min',
#  'mautanya',
#  'jual',
#  'barang',
#  'bukalapak',
#  'barang',
#  'jual',
#  'lihat',
#  'calon',
#  'beli',
#  'kecuali',
#  'kasih',
#  'link',
#  'barang',
#  'nya',
#  'akses',
#  'beli',
#  'bukalapak',
#  'batal',
#  'pemesanansaya',
#  'tipu',
#  'rb',
#  'toko',
#  'store',
#  'kecewasaya',
#  'rugi',
#  'total',
#  'respon',
#  'bukalapak',
#  'jadi',
#  'inibukalapak',
#  'percaya',
#  'paylater',
#  'jatuh',
#  'tempo',
#  'tanggal',
#  'nya',
#  'udah',
#  'beku',
#  'aja',
#  'kecuali',
#  'udah',
#  'tanggal',
#  'jatuh',
#  'tempo',
#  'nya',
#  'beku',
#  'trus',
#  'ga',
#  'pake',
#  'paylater',
#  'nya',
#  'jg',
#  'pajang',
#  'doang',
#  'coba',
#  'jgn',
#  'kredivo',
#  'kerja',
#  'paylater',
#  'nya',
#  'sensitif',
#  'kredivo',
#  'bukalapak',
#  'ga',
#  'jelaspercuma',
#  'limite',
#  'aktif',
#  'gagal',
#  'transaksinyesel',
#  'belanjajelas',
#  'tagih',
#  'ga',
#  'sekaliperdetik',
#  'uninstalmakasih',
#  'coba',
#  'guna',
#  'paylaternya',
#  'sesuai',
#  'limit',
#  'yg',
#  'sedia',
#  'limit',
#  'uda',
#  'pakai',
#  'sisa',
#  'gilir',
#  'dipake',
#  'belanja',
#  'bisaslalu',
#  'batal',
#  'otomatisketerangan',
#  'batal',
#  'dibatalkanseakan',
#  'yg',
#  'batalkanpadahal',
#  'emang',
#  'sistem',
#  'yg',
#  'sesuai',
#  'ngasih',
#  'limit',
#  'tolong',
#  'tabung',
#  'diskon',
#  'banyak',
#  'produk',
#  'kl',
#  'produk',
#  'karna',
#  'orang',
#  'yg',
#  'beli',
#  'barang',
#  'langsung',
#  'fiture',
#  'yg',
#  'bayar',
#  'cicil',
#  'kalo',
#  'lunas',
#  'barang',
#  'kirim',
#  'orang',
#  'yg',
#  'fiture',
#  'moga',
#  'bukalapak',
#  'maju',
#  'aplikais',
#  'bukalapak',
#  'parah',
#  'kali',
#  'pakai',
#  'ad',
#  'verifikasi',
#  'ktp',
#  'jual',
#  'oke',
#  'verifikasi',
#  'ktp',
#  'upraged',
#  'super',
#  'seller',
#  'bru',
#  'upload',
#  'foto',
#  'bisa',
#  'upload',
#  'foto',
#  'aja',
#  'jual',
#  'tokopedia',
#  'lebh',
#  'gampang',
#  'jualanannya',
#  'ribet',
#  'kali',
#  'kecewa',
#  'bela',
#  'penting',
#  'langgan',
#  'barang',
#  'kembali',
#  'tp',
#  'status',
#  'transaksi',
#  'terima',
#  'selesai',
#  'sy',
#  'komplain',
#  'langsung',
#  'uang',
#  'lapak',
#  'jg',
#  'cm',
#  'janji',
#  'kirim',
#  'to',
#  'dah',
#  'minggu',
#  'lbh',
#  'barang',
#  'kirim',
#  'jg',
#  'byk',
#  'iklan',
#  'halaman',
#  'pakai',
#  'byk',
#  'yg',
#  'klik',
#  'ga',
#  'tinggal',
#  'bl',
#  'ribet',
#  'super',
#  'seller',
#  'spt',
#  'sya',
#  'dapet',
#  'kuota',
#  'barang',
#  'dagang',
#  'pdhl',
#  'sya',
#  'jual',
#  'antik',
#  'unik',
#  'bayar',
#  'pdhl',
#  'pakai',
#  'yg',
#  'ga',
#  'bayar',
#  'dapet',
#  'quota',
#  'barang',
#  'spt',
#  'terang',
#  'promosi',
#  'ga',
#  'toko',
#  'belah',
#  'verifikasi',
#  'email',
#  'aja',
#  'yg',
#  'validpadahal',
#  'data',
#  'email',
#  'kesal',
#  'nya',
#  'login',
#  'login',
#  'jngn',
#  'download',
#  'bukalapak',
#  'kesal',
#  'daftar',
#  'nya',
#  'paylater',
#  'bukalapak',
#  'ga',
#  'cicil',
#  'gitu',
#  'ya',
#  'bisa',
#  'cicil',
#  'aja',
#  'kaya',
#  'bayar',
#  'kasih',
#  'aja',
#  'tolong',
#  'adain',
#  'cicil',
#  'gitu',
#  'trus',
#  'produk',
#  'banyak',
#  'yg',
#  'jelek',
#  'dr',
#  'bukalapak',
#  'yg',
#  'adl',
#  'aplikasi',
#  'lot',
#  'adu',
#  'bukabantuan',
#  'langsung',
#  'tele',
#  'kesana',
#  'kemari',
#  'coba',
#  'kasih',
#  'menu',
#  'yg',
#  'langsung',
#  'tinggal',
#  'klik',
#  'cari',
#  'barang',
#  'koleksi',
#  'dikit',
#  'cmn',
#  'dikit',
#  'barang',
#  'kalah',
#  'aplikasi',
#  'yg',
#  'bl',
#  'sepi',
#  'jual',
#  'barang',
#  'bulan',
#  'laku',
#  'tokopedia',
#  'laku',
#  'stagnan',
#  'kaya',
#  'greget',
#  'ol',
#  'shop',
#  'yg',
#  'bukalapakygdulu',
#  'pakai',
#  'bukalapak',
#  'kendala',
#  'belanja',
#  'online',
#  'pakai',
#  'aplikasi',
#  'bonus',
#  'credit',
#  'kasih',
#  'ulas',
#  'barang',
#  'senang',
#  'sistem',
#  'yg',
#  'error',
#  'syarat',
#  'tentu',
#  'yg',
#  'tahu',
#  'bukalapak',
#  'kesini',
#  'bst',
#  'dagang',
#  'dgn',
#  'modal',
#  'pas',
#  'ga',
#  'muterin',
#  'duit',
#  'dsini',
#  'beli',
#  'kirim',
#  'ambil',
#  'transaksi',
#  'selesai',
#  'beli',
#  'kasih',
#  'feedback',
#  'akibat',
#  'dana',
#  'masuk',
#  'akun',
#  'notifikasi',
#  'sampah',
#  'notifikasi',
#  'guna',
#  'lapak',
#  'beli',
#  'nyaman',
#  'tsbt',
#  'kalo',
#  'notif',
#  'nya',
#  'mati',
#  'makan',
#  'notifikasi',
#  'beli',
#  'hilang',
#  'kalo',
#  'notifikasi',
#  'beli',
#  'aktif',
#  'notifikasi',
#  'sampah',
#  'masuk',
#  'pilih',
#  'gua',
#  'heran',
#  'seller',
#  'seller',
#  'aplikasi',
#  'bagus',
#  'tinggal',
#  'bukalapak',
#  'super',
#  'bagus',
#  'sayang',
#  'ga',
#  'tau',
#  'ga',
#  'paham',
#  'sistem',
#  'nya',
#  'bukalapak',
#  'sistem',
#  'bagus',
#  'simpel',
#  'pilih',
#  'atur',
#  'nya',
#  'ga',
#  'ribet',
#  'ayo',
#  'bukalapak',
#  'iklanin',
#  'usaha',
#  'serius',
#  'modal',
#  'iklan',
#  'minim',
#  'usaha',
#  'mantap',
#  'iklanin',
#  'usaha',
#  'unggul',
#  'ga',
#  'bayar',
#  'sesuai',
#  'topup',
#  'saldo',
#  'dana',
#  'jt',
#  'tau',
#  'knp',
#  'kirim',
#  'otomatis',
#  'bukalapak',
#  'truss',
#  'dompet',
#  'nya',
#  'beku',
#  'nyuruh',
#  'hasil',
#  'transaksi',
#  'aneh',
#  'beku',
#  'aneh',
#  'bgt',
#  'tau',
#  'gin',
#  'mah',
#  'pake',
#  'bukalapak',
#  'jt',
#  'nominal',
#  'maen',
#  'beku',
#  'aja',
#  'email',
#  'balesan',
#  'bagus',
#  'kecewa',
#  'sistem',
#  'benarbenar',
#  'tata',
#  'tipu',
#  'kirim',
#  'yg',
#  'batas',
#  'palak',
#  'kirim',
#  'pesan',
#  'sistem',
#  'langsung',
#  'kembali',
#  'dana',
#  'yg',
#  'transfer',
#  'puas',
#  'rekomendasi',
#  'toko',
#  'online',
#  'akun',
#  'tibatiba',
#  'beku',
#  'baned',
#  'terima',
#  'pesan',
#  ...]

# %%
fqdist = FreqDist(tokenize_ulasan)

# %%
fqdist
# Out:
# FreqDist({'bukalapak': 506, 'aplikasi': 482, 'yg': 444, 'barang': 432, 'nya': 403, 'ga': 235, 'beli': 231, 'kirim': 225, 'buka': 224, 'belanja': 222, ...})

# %%
# mencetak 15 kata paling banyak digunakan
fqdist.most_common(15)
# Out:
# [('bukalapak', 506),
#  ('aplikasi', 482),
#  ('yg', 444),
#  ('barang', 432),
#  ('nya', 403),
#  ('ga', 235),
#  ('beli', 231),
#  ('kirim', 225),
#  ('buka', 224),
#  ('belanja', 222),
#  ('lapak', 219),
#  ('bayar', 211),
#  ('transaksi', 196),
#  ('aja', 183),
#  ('bantu', 163)]

# %%
import matplotlib.pyplot as plt

# plotting
fqdist.plot(10,cumulative=False)
plt.show()

# %%
label = []
for index, row in name_dataframe.iterrows():
    if row["Rating"] == 5 or row["Rating"] == 4:
        label.append(1)
    else:
        label.append(0)

name_dataframe["label"] = label

name_dataframe
# Out:
#          Nama pengguna  Rating                Date  \
# 0         Nizar Rayyan       1 2023-04-16 23:03:31
# 1       Ganjar Hermadi       1 2023-05-27 23:42:34
# 2           Fandy Komo       1 2023-05-05 02:37:25
# 3          Dwi Indarti       1 2023-06-06 04:19:17
# 4         Yuda Nugraha       3 2023-05-31 10:59:36
# ...                ...     ...                 ...
# 1295    Aidil Pridiyah       5 2023-05-20 01:05:47
# 1296     Moja Maharani       4 2023-05-19 06:37:48
# 1297     Putri Sentani       5 2023-05-21 11:23:13
# 1298  Novian Syahputra       3 2023-05-10 10:55:50
# 1299            Payung       1 2023-05-23 09:16:07
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     pengembalian dana otomatis ga berfungsisy lg b...
# 2     tambah kesini buka lapak tambah kurang bagus p...
# 3     setelah dibayar lunaspaylater tidak bisa dibua...
# 4     di update malah ngaco ini aplikasi menu barang...
# ...                                                 ...
# 1295                          tingkatkan terus promonya
# 1296  ini bonus undang referal kok belum masuk ini s...
# 1297  sangat bagus kiriman cepat sampai terimakasih ...
# 1298  kok pelapaknya ada yang ga benerrrrrr klo niat...
# 1299  woy transaksi gua jadi ga jelas gara gara chat...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3     [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4     [di, update, malah, ngaco, ini, aplikasi, menu...
# ...                                                 ...
# 1295                      [tingkatkan, terus, promonya]
# 1296  [ini, bonus, undang, referal, kok, belum, masu...
# 1297  [sangat, bagus, kiriman, cepat, sampai, terima...
# 1298  [kok, pelapaknya, ada, yang, ga, benerrrrrr, k...
# 1299  [woy, transaksi, gua, jadi, ga, jelas, gara, g...
#
#                                             ulasan_ears  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3     [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4     [di, update, malah, ngaco, ini, aplikasi, menu...
# ...                                                 ...
# 1295                      [tingkatkan, terus, promonya]
# 1296  [ini, bonus, undang, referal, kok, belum, masu...
# 1297  [sangat, bagus, kiriman, cepat, sampai, terima...
# 1298  [kok, pelapaknya, ada, yang, ga, benerrrrrr, k...
# 1299  [woy, transaksi, gua, jadi, ga, jelas, gara, g...
#
#                                       Ulasan_normalized  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3     [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4     [di, update, malah, ngaco, ini, aplikasi, menu...
# ...                                                 ...
# 1295                      [tingkatkan, terus, promonya]
# 1296  [ini, bonus, undang, referal, kok, belum, masu...
# 1297  [sangat, bagus, kiriman, cepat, sampai, terima...
# 1298  [kok, pelapaknya, ada, yang, ga, benerrrrrr, k...
# 1299  [woy, transaksi, gua, jadi, ga, jelas, gara, g...
#
#                                     Ulasan_stop_removed  \
# 0     [paylater, ngk, bener, batalkan, otomatis, kad...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [kesini, buka, lapak, bagus, pelayanannya, kom...
# 3     [dibayar, lunaspaylater, transaksi, apapunsela...
# 4     [update, ngaco, aplikasi, menu, barang, favori...
# ...                                                 ...
# 1295                             [tingkatkan, promonya]
# 1296  [bonus, undang, referal, masuk, orng, menunggu...
# 1297    [bagus, kiriman, cepat, terimakasih, bukalapak]
# 1298  [pelapaknya, ga, benerrrrrr, klo, niatny, pela...
# 1299  [woy, transaksi, gua, ga, gara, gara, chat, ny...
#
#                                          Ulasan_Stemmed  \
# 0     [paylater, ngk, bener, batal, otomatis, kadang...
# 1     [kembali, dana, otomatis, ga, berfungsisy, lg,...
# 2     [kesini, buka, lapak, bagus, layan, komplan, a...
# 3     [bayar, lunaspaylater, transaksi, apapunselalu...
# 4     [update, ngaco, aplikasi, menu, barang, favori...
# ...                                                 ...
# 1295                                [tingkat, promonya]
# 1296  [bonus, undang, referal, masuk, orng, tunggu, ...
# 1297      [bagus, kirim, cepat, terimakasih, bukalapak]
# 1298  [lapak, ga, benerrrrrr, klo, niatny, lapak, ga...
# 1299  [woy, transaksi, gua, ga, gara, gara, chat, ny...
#
#                                            Ulasan_clean  label
# 0     paylater ngk bener batal otomatis kadang nya g...      0
# 1     kembali dana otomatis ga berfungsisy lg butuh ...      0
# 2     kesini buka lapak bagus layan komplan aja susa...      0
# 3     bayar lunaspaylater transaksi apapunselalu bat...      0
# 4     update ngaco aplikasi menu barang favorit gbs ...      0
# ...                                                 ...    ...
# 1295                                   tingkat promonya      1
# 1296  bonus undang referal masuk orng tunggu cepat y...      1
# 1297            bagus kirim cepat terimakasih bukalapak      1
# 1298  lapak ga benerrrrrr klo niatny lapak ga bener ...      0
# 1299  woy transaksi gua ga gara gara chat nya lu bek...      0
#
# [1300 rows x 11 columns]

# %%
#create a user define function to find out polarity & subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

#creating another user define function to label the sentiment 

def getSentiment(value):
    if value < 0:
        return 'Negative'
    elif value > 0:
        return 'Positive'
    else:
        return 'Neutral'

# %%
name_dataframe.head()
# Out:
#     Nama pengguna  Rating                Date  \
# 0    Nizar Rayyan       1 2023-04-16 23:03:31
# 1  Ganjar Hermadi       1 2023-05-27 23:42:34
# 2      Fandy Komo       1 2023-05-05 02:37:25
# 3     Dwi Indarti       1 2023-06-06 04:19:17
# 4    Yuda Nugraha       3 2023-05-31 10:59:36
#
#                                               Ulasan  \
# 0  paylater ngk bener selalu di batalkan otomatis...
# 1  pengembalian dana otomatis ga berfungsisy lg b...
# 2  tambah kesini buka lapak tambah kurang bagus p...
# 3  setelah dibayar lunaspaylater tidak bisa dibua...
# 4  di update malah ngaco ini aplikasi menu barang...
#
#                                      Ulasan_tokenize  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [pengembalian, dana, otomatis, ga, berfungsisy...
# 2  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3  [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4  [di, update, malah, ngaco, ini, aplikasi, menu...
#
#                                          ulasan_ears  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [pengembalian, dana, otomatis, ga, berfungsisy...
# 2  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3  [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4  [di, update, malah, ngaco, ini, aplikasi, menu...
#
#                                    Ulasan_normalized  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [pengembalian, dana, otomatis, ga, berfungsisy...
# 2  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3  [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4  [di, update, malah, ngaco, ini, aplikasi, menu...
#
#                                  Ulasan_stop_removed  \
# 0  [paylater, ngk, bener, batalkan, otomatis, kad...
# 1  [pengembalian, dana, otomatis, ga, berfungsisy...
# 2  [kesini, buka, lapak, bagus, pelayanannya, kom...
# 3  [dibayar, lunaspaylater, transaksi, apapunsela...
# 4  [update, ngaco, aplikasi, menu, barang, favori...
#
#                                       Ulasan_Stemmed  \
# 0  [paylater, ngk, bener, batal, otomatis, kadang...
# 1  [kembali, dana, otomatis, ga, berfungsisy, lg,...
# 2  [kesini, buka, lapak, bagus, layan, komplan, a...
# 3  [bayar, lunaspaylater, transaksi, apapunselalu...
# 4  [update, ngaco, aplikasi, menu, barang, favori...
#
#                                         Ulasan_clean  label
# 0  paylater ngk bener batal otomatis kadang nya g...      0
# 1  kembali dana otomatis ga berfungsisy lg butuh ...      0
# 2  kesini buka lapak bagus layan komplan aja susa...      0
# 3  bayar lunaspaylater transaksi apapunselalu bat...      0
# 4  update ngaco aplikasi menu barang favorit gbs ...      0

# %%
from textblob import TextBlob

# %%
def run_vader(name_dataframe):
    # Generate VADER sentiment analyzer object
    sid = SentimentIntensityAnalyzer()

# %%
name_dataframe['Polarity']=name_dataframe['Ulasan_clean'].apply(getPolarity)
name_dataframe['Subjectivity']=name_dataframe['Ulasan_clean'].apply(getSubjectivity)
name_dataframe['Sentiment']=name_dataframe['Polarity'].apply(getSentiment)
name_dataframe.head()
# Out:
#     Nama pengguna  Rating                Date  \
# 0    Nizar Rayyan       1 2023-04-16 23:03:31
# 1  Ganjar Hermadi       1 2023-05-27 23:42:34
# 2      Fandy Komo       1 2023-05-05 02:37:25
# 3     Dwi Indarti       1 2023-06-06 04:19:17
# 4    Yuda Nugraha       3 2023-05-31 10:59:36
#
#                                               Ulasan  \
# 0  paylater ngk bener selalu di batalkan otomatis...
# 1  pengembalian dana otomatis ga berfungsisy lg b...
# 2  tambah kesini buka lapak tambah kurang bagus p...
# 3  setelah dibayar lunaspaylater tidak bisa dibua...
# 4  di update malah ngaco ini aplikasi menu barang...
#
#                                      Ulasan_tokenize  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [pengembalian, dana, otomatis, ga, berfungsisy...
# 2  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3  [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4  [di, update, malah, ngaco, ini, aplikasi, menu...
#
#                                          ulasan_ears  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [pengembalian, dana, otomatis, ga, berfungsisy...
# 2  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3  [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4  [di, update, malah, ngaco, ini, aplikasi, menu...
#
#                                    Ulasan_normalized  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [pengembalian, dana, otomatis, ga, berfungsisy...
# 2  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3  [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4  [di, update, malah, ngaco, ini, aplikasi, menu...
#
#                                  Ulasan_stop_removed  \
# 0  [paylater, ngk, bener, batalkan, otomatis, kad...
# 1  [pengembalian, dana, otomatis, ga, berfungsisy...
# 2  [kesini, buka, lapak, bagus, pelayanannya, kom...
# 3  [dibayar, lunaspaylater, transaksi, apapunsela...
# 4  [update, ngaco, aplikasi, menu, barang, favori...
#
#                                       Ulasan_Stemmed  \
# 0  [paylater, ngk, bener, batal, otomatis, kadang...
# 1  [kembali, dana, otomatis, ga, berfungsisy, lg,...
# 2  [kesini, buka, lapak, bagus, layan, komplan, a...
# 3  [bayar, lunaspaylater, transaksi, apapunselalu...
# 4  [update, ngaco, aplikasi, menu, barang, favori...
#
#                                         Ulasan_clean  label  Polarity  \
# 0  paylater ngk bener batal otomatis kadang nya g...      0       0.0
# 1  kembali dana otomatis ga berfungsisy lg butuh ...      0       0.0
# 2  kesini buka lapak bagus layan komplan aja susa...      0       0.0
# 3  bayar lunaspaylater transaksi apapunselalu bat...      0       0.0
# 4  update ngaco aplikasi menu barang favorit gbs ...      0       0.0
#
#    Subjectivity Sentiment  month
# 0           0.0   Neutral      4
# 1           0.0   Neutral      5
# 2           0.0   Neutral      5
# 3           0.0   Neutral      6
# 4           0.0   Neutral      5

# %%
name_dataframe['month'] = name_dataframe['Date'].dt.month

# %%
name_dataframe
# Out:
#          Nama pengguna  Rating                Date  \
# 0         Nizar Rayyan       1 2023-04-16 23:03:31
# 1       Ganjar Hermadi       1 2023-05-27 23:42:34
# 2           Fandy Komo       1 2023-05-05 02:37:25
# 3          Dwi Indarti       1 2023-06-06 04:19:17
# 4         Yuda Nugraha       3 2023-05-31 10:59:36
# ...                ...     ...                 ...
# 1295    Aidil Pridiyah       5 2023-05-20 01:05:47
# 1296     Moja Maharani       4 2023-05-19 06:37:48
# 1297     Putri Sentani       5 2023-05-21 11:23:13
# 1298  Novian Syahputra       3 2023-05-10 10:55:50
# 1299            Payung       1 2023-05-23 09:16:07
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     pengembalian dana otomatis ga berfungsisy lg b...
# 2     tambah kesini buka lapak tambah kurang bagus p...
# 3     setelah dibayar lunaspaylater tidak bisa dibua...
# 4     di update malah ngaco ini aplikasi menu barang...
# ...                                                 ...
# 1295                          tingkatkan terus promonya
# 1296  ini bonus undang referal kok belum masuk ini s...
# 1297  sangat bagus kiriman cepat sampai terimakasih ...
# 1298  kok pelapaknya ada yang ga benerrrrrr klo niat...
# 1299  woy transaksi gua jadi ga jelas gara gara chat...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3     [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4     [di, update, malah, ngaco, ini, aplikasi, menu...
# ...                                                 ...
# 1295                      [tingkatkan, terus, promonya]
# 1296  [ini, bonus, undang, referal, kok, belum, masu...
# 1297  [sangat, bagus, kiriman, cepat, sampai, terima...
# 1298  [kok, pelapaknya, ada, yang, ga, benerrrrrr, k...
# 1299  [woy, transaksi, gua, jadi, ga, jelas, gara, g...
#
#                                             ulasan_ears  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3     [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4     [di, update, malah, ngaco, ini, aplikasi, menu...
# ...                                                 ...
# 1295                      [tingkatkan, terus, promonya]
# 1296  [ini, bonus, undang, referal, kok, belum, masu...
# 1297  [sangat, bagus, kiriman, cepat, sampai, terima...
# 1298  [kok, pelapaknya, ada, yang, ga, benerrrrrr, k...
# 1299  [woy, transaksi, gua, jadi, ga, jelas, gara, g...
#
#                                       Ulasan_normalized  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 3     [setelah, dibayar, lunaspaylater, tidak, bisa,...
# 4     [di, update, malah, ngaco, ini, aplikasi, menu...
# ...                                                 ...
# 1295                      [tingkatkan, terus, promonya]
# 1296  [ini, bonus, undang, referal, kok, belum, masu...
# 1297  [sangat, bagus, kiriman, cepat, sampai, terima...
# 1298  [kok, pelapaknya, ada, yang, ga, benerrrrrr, k...
# 1299  [woy, transaksi, gua, jadi, ga, jelas, gara, g...
#
#                                     Ulasan_stop_removed  \
# 0     [paylater, ngk, bener, batalkan, otomatis, kad...
# 1     [pengembalian, dana, otomatis, ga, berfungsisy...
# 2     [kesini, buka, lapak, bagus, pelayanannya, kom...
# 3     [dibayar, lunaspaylater, transaksi, apapunsela...
# 4     [update, ngaco, aplikasi, menu, barang, favori...
# ...                                                 ...
# 1295                             [tingkatkan, promonya]
# 1296  [bonus, undang, referal, masuk, orng, menunggu...
# 1297    [bagus, kiriman, cepat, terimakasih, bukalapak]
# 1298  [pelapaknya, ga, benerrrrrr, klo, niatny, pela...
# 1299  [woy, transaksi, gua, ga, gara, gara, chat, ny...
#
#                                          Ulasan_Stemmed  \
# 0     [paylater, ngk, bener, batal, otomatis, kadang...
# 1     [kembali, dana, otomatis, ga, berfungsisy, lg,...
# 2     [kesini, buka, lapak, bagus, layan, komplan, a...
# 3     [bayar, lunaspaylater, transaksi, apapunselalu...
# 4     [update, ngaco, aplikasi, menu, barang, favori...
# ...                                                 ...
# 1295                                [tingkat, promonya]
# 1296  [bonus, undang, referal, masuk, orng, tunggu, ...
# 1297      [bagus, kirim, cepat, terimakasih, bukalapak]
# 1298  [lapak, ga, benerrrrrr, klo, niatny, lapak, ga...
# 1299  [woy, transaksi, gua, ga, gara, gara, chat, ny...
#
#                                            Ulasan_clean  label  Polarity  \
# 0     paylater ngk bener batal otomatis kadang nya g...      0  0.000000
# 1     kembali dana otomatis ga berfungsisy lg butuh ...      0  0.000000
# 2     kesini buka lapak bagus layan komplan aja susa...      0  0.000000
# 3     bayar lunaspaylater transaksi apapunselalu bat...      0  0.000000
# 4     update ngaco aplikasi menu barang favorit gbs ...      0  0.000000
# ...                                                 ...    ...       ...
# 1295                                   tingkat promonya      1  0.000000
# 1296  bonus undang referal masuk orng tunggu cepat y...      1  0.000000
# 1297            bagus kirim cepat terimakasih bukalapak      1  0.000000
# 1298  lapak ga benerrrrrr klo niatny lapak ga bener ...      0  0.000000
# 1299  woy transaksi gua ga gara gara chat nya lu bek...      0  0.136364
#
#       Subjectivity Sentiment  month
# 0              0.0   Neutral      4
# 1              0.0   Neutral      5
# 2              0.0   Neutral      5
# 3              0.0   Neutral      6
# 4              0.0   Neutral      5
# ...            ...       ...    ...
# 1295           0.0   Neutral      5
# 1296           0.0   Neutral      5
# 1297           0.0   Neutral      5
# 1298           0.0   Neutral      5
# 1299           0.5  Positive      5
#
# [1300 rows x 15 columns]

# %%
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Create scatter plot
sns.set_style('darkgrid')
plt.figure(figsize = (15,7))

markers = {'Positive':'o', 'Neutral':'s','Negative':'X'}

sns.scatterplot(data=name_dataframe, x='Polarity', y='Subjectivity', hue = 'Sentiment', style = 'Sentiment', markers = markers, palette = 'gist_earth').set(xlim=(-1,1))
plt.title('Scatter Plot')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')

plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group by month and sentiment
sentiment_df = name_dataframe.groupby(['month', 'Sentiment']).size().reset_index(name='Count')


# Plot the sentiment counts by month
plt.figure(figsize=(12, 6))
sns.lineplot(x='month', y='Count', hue='Sentiment', data=sentiment_df)
plt.title('Sentiment by Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %%
sentimen_data=pd.value_counts(name_dataframe["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["green", "red", "black"])
plt.title('Bar chart')
plt.show()

# %%
name_dataframe["Sentiment"].value_counts()
# Out:
# Neutral     1050
# Positive     199
# Negative      51
# Name: Sentiment, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
Ulasan = name_dataframe['Ulasan_clean']

# %%
Ulasan.isnull().sum()
# Out:
# 0

# %%
#untuk menghitung jumlah kata yang telah di steming
cv = CountVectorizer()
term_fit = cv.fit(Ulasan)

print (len(term_fit.vocabulary_))
# Out:
# 4077

# %%
term_fit.vocabulary_ #mengurutkan berdasarkan urutab abjad kata
# Out:
# {'paylater': 2736,
#  'ngk': 2494,
#  'bener': 386,
#  'batal': 325,
#  'otomatis': 2663,
#  'kadang': 1609,
#  'nya': 2559,
#  'ganti': 1239,
#  'jatuh': 1533,
#  'tempo': 3661,
#  'bayar': 333,
#  'biaya': 471,
#  'lambat': 1971,
#  'layan': 2008,
#  'biar': 467,
#  'rasa': 3011,
#  'sistem': 3420,
#  'enak': 1120,
#  'chat': 760,
#  'susah': 3553,
#  'error': 1133,
#  'salah': 3152,
#  'bikin': 478,
#  'pusing': 2989,
#  'kembali': 1700,
#  'dana': 857,
#  'ga': 1208,
#  'berfungsisy': 416,
#  'lg': 2058,
#  'butuh': 680,
#  'bgt': 456,
#  'ajuin': 67,
#  'komplainada': 1821,
#  'tombol': 3792,
#  'komplain': 1820,
#  'diarahin': 931,
#  'pusat': 2986,
#  'bantu': 293,
#  'utk': 3952,
#  'aju': 66,
#  'pembatalanpengembalian': 2783,
#  'aplikasi': 179,
#  'payahmenyulitkan': 2734,
#  'konsumen': 1844,
#  'kesini': 1738,
#  'buka': 603,
#  'lapak': 1985,
#  'bagus': 238,
#  'komplan': 1823,
#  'aja': 51,
#  'banget': 280,
#  'beberapakali': 344,
#  'transaksi': 3813,
#  'rekening': 3047,
#  'dah': 848,
#  'potong': 2923,
#  'verifikasi': 3967,
#  'kalo': 1627,
#  'pingin': 2884,
#  'menu': 2291,
#  'upload': 3935,
#  'bukti': 662,
#  'nggak': 2486,
#  'muncul': 2388,
#  'kali': 1623,
#  'hilang': 1391,
#  'uang': 3886,
#  'gagal': 1220,
#  'lunaspaylater': 2122,
#  'apapunselalu': 165,
#  'hari': 1362,
#  'coba': 780,
#  'cs': 816,
#  'bukalapak': 616,
#  'tersambungjawaban': 3706,
#  'agen': 44,
#  'sibuk': 3388,
#  'parahpayah': 2718,
#  'update': 3927,
#  'ngaco': 2445,
#  'barang': 306,
#  'favorit': 1163,
#  'gbs': 1251,
#  'search': 3226,
#  'skrg': 3440,
#  'klo': 1776,
#  'cari': 711,
#  'bl': 513,
#  'yg': 4061,
#  'ad': 17,
#  'tau': 3628,
#  'pd': 2756,
#  'kmn': 1783,
#  'jual': 1582,
#  'item': 1498,
#  'toko': 3783,
#  'belah': 359,
#  'sulit': 3538,
#  'belanja': 362,
#  'dsni': 1069,
#  'paksa': 2700,
#  'maaf': 2134,
#  'ya': 4047,
#  'boss': 568,
#  'beku': 353,
#  'limit': 2069,
#  'tdk': 3636,
#  'naikyg': 2414,
#  'percaya': 2844,
#  'mode': 2356,
#  'cod': 782,
#  'tambah': 3595,
#  'rp': 3125,
#  'aga': 42,
#  'males': 2164,
#  'systemnya': 3571,
#  'udah': 3893,
#  'tutupin': 3881,
#  'langgan': 1979,
#  'kecewa': 1669,
#  'kurir': 1898,
#  'ngirim': 2489,
#  'ongkirku': 2625,
#  'ongkirnya': 2627,
#  'mana': 2171,
#  'pake': 2695,
#  'bukabantuan': 604,
#  'live': 2081,
#  'jalan': 1515,
#  'masalah': 2213,
#  'tsb': 3852,
#  'sekian': 3266,
#  'pke': 2889,
#  'apk': 170,
#  'bru': 586,
#  'kli': 1772,
#  'berat': 403,
#  'serasa': 3324,
#  'tipu': 3763,
#  'sma': 3451,
#  'beli': 373,
#  'jasa': 1532,
#  'kirim': 1760,
#  'ekspres': 1104,
#  'dgn': 923,
#  'estimasi': 1138,
#  'kerja': 1727,
#  'ekspedisi': 1101,
#  'peniriman': 2823,
#  'jdi': 1544,
#  'tanggung': 3618,
#  'rugi': 3130,
#  'materi': 2226,
#  'ribet': 3093,
#  'sumpah': 3541,
#  'setting': 3354,
#  'maps': 2200,
#  'refresh': 3036,
#  'ngulangin': 2502,
#  'banyak': 299,
#  'fitur': 1183,
#  'nomor': 2530,
#  'pilih': 2878,
#  'wallet': 4005,
#  'seikit': 3255,
#  'bintang': 485,
#  'tingkat': 3756,
#  'ongkir': 2623,
#  'vocer': 3981,
#  'diskon': 1006,
#  'harap': 1359,
#  'guna': 1312,
#  'hak': 1339,
#  'cocok': 781,
#  'tuh': 3862,
#  'ktp': 1879,
#  'info': 1455,
#  'jam': 1518,
#  'akun': 89,
#  'verifikasigak': 3969,
#  'masuk': 2220,
#  'gimana': 1268,
#  'lot': 2111,
#  'parah': 2715,
#  'login': 2093,
#  'sampe': 3175,
#  'hubung': 1414,
#  'alias': 104,
#  'tulis': 3868,
#  'jarang': 1530,
#  'dapet': 865,
#  'harga': 1360,
#  'nyamantidak': 2574,
#  'aman': 114,
#  'bukalapakselain': 641,
#  'mahalada': 2144,
#  'bebankanmending': 341,
#  'kl': 1767,
#  'benermending': 389,
#  'tujuansudah': 3865,
#  'jaman': 1519,
#  'online': 2633,
#  'lepas': 2051,
#  'mendesakharusnya': 2270,
#  'kembalibagaimanapun': 1701,
#  'jg': 1561,
#  'bldah': 519,
#  'ulang': 3901,
#  'samatapi': 3165,
#  'mohon': 2361,
#  'kasih': 1649,
#  'voucher': 3985,
#  'pakai': 2689,
#  'kuota': 1891,
#  'habis': 1325,
#  'emang': 1114,
#  'makan': 2153,
#  'balikin': 273,
#  'vouchernya': 3986,
#  'pesan': 2862,
#  'yak': 4054,
#  'bilang': 479,
#  'ready': 3022,
#  'stok': 3515,
#  'tp': 3801,
#  'duit': 1074,
#  'transfer': 3818,
#  'amplop': 125,
#  'kosong': 1855,
#  'dpt': 1060,
#  'template': 3660,
#  'kagak': 1612,
#  'solusi': 3474,
#  'suruh': 3550,
#  'nunggu': 2553,
#  'batas': 328,
#  'proses': 2967,
#  'asli': 206,
#  'dosa': 1051,
#  'lu': 2116,
#  'nahan': 2411,
#  'rejeki': 3042,
#  'orang': 2645,
#  'paraaaahhhh': 2713,
#  'mudahpengiriman': 2377,
#  'cepatqualitas': 746,
#  'sesuai': 3344,
#  'hargasaya': 1361,
#  'nyaman': 2571,
#  'mengunakan': 2285,
#  'moga': 2360,
#  'jaya': 1541,
#  'andal': 134,
#  'tpi': 3803,
#  'bingung': 482,
#  'adu': 40,
#  'henti': 1382,
#  'commerce': 791,
#  'worth': 4041,
#  'it': 1497,
#  'halaman': 1342,
#  'kece': 1668,
#  'sampai': 3172,
#  'tolong': 3791,
#  'cek': 725,
#  'kembang': 1704,
#  'internet': 1485,
#  'stabil': 3499,
#  'cepat': 737,
#  'baik': 258,
#  'terimakasih': 3688,
#  'trnsaksi': 3841,
#  'pulsa': 2981,
#  'berhasilpulsa': 419,
#  'gk': 1278,
#  'masuktagihan': 2222,
#  'adakomplen': 28,
#  'urus': 3941,
#  'mesin': 2308,
#  'satu': 3198,
#  'olshop': 2618,
#  'rampog': 3006,
#  'ap': 160,
#  'paraaaaaaaahhhhh': 2712,
#  'bukalapakpercuma': 637,
#  'limite': 2070,
#  'belanjatagihan': 366,
#  'aktifpenanganan': 85,
#  'wow': 4042,
#  'min': 2316,
#  'mautanya': 2231,
#  'lihat': 2068,
#  'calon': 699,
#  'kecuali': 1676,
#  'link': 2075,
#  'akses': 75,
#  'pemesanansaya': 2797,
#  'rb': 3017,
#  'store': 3517,
#  'kecewasaya': 1672,
#  'total': 3798,
#  'respon': 3079,
#  'jadi': 1508,
#  'inibukalapak': 1462,
#  'tanggal': 3608,
#  'trus': 3850,
#  'pajang': 2687,
#  'doang': 1036,
#  'jgn': 1565,
#  'kredivo': 1866,
#  'sensitif': 3316,
#  'jelaspercuma': 1551,
#  'aktif': 79,
#  'transaksinyesel': 3816,
#  'belanjajelas': 365,
#  'tagih': 3581,
#  'sekaliperdetik': 3261,
#  'uninstalmakasih': 3915,
#  'paylaternya': 2738,
#  'sedia': 3244,
#  'uda': 3892,
#  'sisa': 3417,
#  'gilir': 1267,
#  'dipake': 982,
#  'bisaslalu': 504,
#  'otomatisketerangan': 2664,
#  'dibatalkanseakan': 938,
#  'batalkanpadahal': 327,
#  'ngasih': 2458,
#  'tabung': 3577,
#  'produk': 2949,
#  'karna': 1638,
#  'langsung': 1982,
#  'fiture': 1184,
#  'cicil': 771,
#  'lunas': 2121,
#  'maju': 2150,
#  'aplikais': 178,
#  'oke': 2609,
#  'upraged': 3938,
#  'super': 3544,
#  'seller': 3285,
#  'foto': 1199,
#  'bisa': 490,
#  'tokopedia': 3785,
#  'lebh': 2023,
#  'gampang': 1233,
#  'jualanannya': 1583,
#  'bela': 358,
#  'penting': 2830,
#  'status': 3508,
#  'terima': 3685,
#  'selesai': 3276,
#  'sy': 3562,
#  'cm': 777,
#  'janji': 1526,
#  'to': 3779,
#  'minggu': 2318,
#  'lbh': 2017,
#  'byk': 688,
#  'iklan': 1428,
#  'klik': 1774,
#  'tinggal': 3755,
#  'spt': 3495,
#  'sya': 3563,
#  'dagang': 847,
#  'pdhl': 2760,
#  'antik': 155,
#  'unik': 3910,
#  'quota': 2994,
#  'terang': 3674,
#  'promosi': 2962,
#  'email': 1110,
#  'validpadahal': 3958,
#  'data': 876,
#  'kesal': 1734,
#  'jngn': 1573,
#  'download': 1053,
#  'daftar': 845,
#  'gitu': 1273,
#  'kaya': 1657,
#  'adain': 23,
#  'jelek': 1552,
#  'dr': 1062,
#  'adl': 36,
#  'tele': 3645,
#  'kesana': 1735,
#  'kemari': 1697,
#  'koleksi': 1802,
#  'dikit': 974,
#  'cmn': 779,
#  'kalah': 1620,
#  'sepi': 3321,
#  'bulan': 667,
#  'laku': 1954,
#  'stagnan': 3501,
#  'greget': 1302,
#  'ol': 2615,
#  'shop': 3366,
#  'bukalapakygdulu': 651,
#  'kendala': 1710,
#  'bonus': 559,
#  'credit': 811,
#  'ulas': 3902,
#  'senang': 3306,
#  'syarat': 3566,
#  'tentu': 3670,
#  'tahu': 3584,
#  'bst': 591,
#  'modal': 2355,
#  'pas': 2722,
#  'muterin': 2401,
#  'dsini': 1068,
#  'ambil': 120,
#  'feedback': 1171,
#  'akibat': 73,
#  'notifikasi': 2546,
#  'sampah': 3170,
#  'tsbt': 3853,
#  'notif': 2545,
#  'mati': 2227,
#  'gua': 1308,
#  'heran': 1383,
#  'sayang': 3208,
#  'paham': 2682,
#  'simpel': 3408,
#  'atur': 217,
#  'ayo': 227,
#  'iklanin': 1430,
#  'usaha': 3944,
#  'serius': 3332,
#  'minim': 2321,
#  'mantap': 2188,
#  'unggul': 3909,
#  'topup': 3796,
#  'saldo': 3155,
#  'jt': 1581,
#  'knp': 1789,
#  'truss': 3851,
#  'dompet': 1044,
#  'nyuruh': 2598,
#  'hasil': 1367,
#  'aneh': 139,
#  'gin': 1271,
#  'mah': 2141,
#  'nominal': 2529,
#  'maen': 2140,
#  'balesan': 271,
#  'benarbenar': 383,
#  'tata': 3627,
#  'palak': 2702,
#  'puas': 2975,
#  'rekomendasi': 3053,
#  'tibatiba': 3740,
#  'baned': 278,
#  'feed': 1170,
#  'back': 230,
#  'gede': 1252,
#  'korban': 1853,
#  'payah': 2733,
#  'perihal': 2848,
#  'event': 1146,
#  'bukatabungan': 661,
#  'gundang': 1319,
#  'reward': 3089,
#  'jelas': 1548,
#  'asuransi': 209,
#  'mundur': 2391,
#  'ngajuin': 2450,
#  'ampun': 126,
#  'call': 696,
#  'center': 733,
#  'sekali': 3257,
#  'main': 2147,
#  'left': 2025,
#  'seenaknyalangsg': 3248,
#  'cakap': 694,
#  'percakapanjadi': 2843,
#  'ragu': 2996,
#  'belakang': 361,
#  'ko': 1793,
#  'customer': 831,
#  'no': 2522,
#  'antri': 157,
#  'nutup': 2557,
#  'trecking': 3828,
#  'udh': 3895,
#  'saran': 3191,
#  'susupin': 3560,
#  'shopee': 3368,
#  'bnyk': 549,
#  'pasang': 2723,
#  'paruh': 2721,
#  'murah': 2393,
#  'rusak': 3138,
#  'realpict': 3025,
#  'jd': 1543,
#  'kapok': 1633,
#  'org': 2653,
#  'wajib': 3999,
#  'lbih': 2018,
#  'dlm': 1025,
#  'bs': 587,
#  'mudah': 2374,
#  'editsaat': 1090,
#  'alamat': 94,
#  'manual': 2196,
#  'bisakalau': 499,
#  'pelosokmungkintapi': 2780,
#  'lainsaya': 1945,
#  'manualtanpa': 2197,
#  'gpssaya': 1295,
#  'kecewakarena': 1671,
#  'tunggu': 3872,
#  'aa': 0,
#  'kaka': 1617,
#  'alami': 95,
#  'ktpno': 1880,
#  'telphone': 3652,
#  'milik': 2314,
#  'ampas': 123,
#  'bnyak': 547,
#  'bangkrut': 286,
#  'hapus': 1358,
#  'play': 2894,
#  'marketplace': 2207,
#  'sellerseller': 3289,
#  'kait': 1615,
#  'akan': 71,
#  'bertanggungjawab': 440,
#  'alas': 97,
#  'ujung': 3899,
#  'tangan': 3606,
#  'bukalapk': 652,
#  'sicepat': 3389,
#  'tautpi': 3629,
#  'kg': 1749,
#  'gramdi': 1299,
#  'hitung': 1398,
#  'kgdan': 1750,
#  'ahirnya': 48,
#  'lgi': 2061,
#  'sayagak': 3206,
#  'ijoklo': 1425,
#  'komplin': 1828,
#  'lgsg': 2062,
#  'atas': 212,
#  'nomer': 2528,
#  'hp': 1405,
#  'lainemang': 1942,
#  'daptar': 867,
#  'alikasi': 106,
#  'yahsangat': 4052,
#  'membingungkanlangsung': 2257,
#  'uninstal': 3912,
#  'kompalain': 1812,
#  'tpdiketangan': 3802,
#  'komplen': 1825,
#  'make': 2156,
#  'eh': 1095,
#  'top': 3794,
#  'up': 3926,
#  'tarik': 3626,
#  'belu': 381,
#  'cair': 693,
#  'hadehh': 1328,
#  'hadehhh': 1329,
#  'sandi': 3183,
#  'repes': 3064,
#  'kompetitor': 1819,
#  'via': 3973,
#  'bsi': 590,
#  'wadah': 3993,
#  'tim': 3747,
#  'system': 3569,
#  'bobrok': 551,
#  'jawab': 1534,
#  'alhasil': 103,
#  'nyata': 2586,
#  'valid': 3956,
#  'utama': 3950,
#  'untung': 3925,
#  'yaa': 4048,
#  'kayak': 1658,
#  'kedaluarsa': 1677,
#  'pakek': 2696,
#  'hati': 1369,
#  'kawan': 1656,
#  'retur': 3087,
#  'diskusi': 1009,
#  'admin': 37,
#  'cenderung': 730,
#  'video': 3974,
#  'timbang': 3748,
#  'koneksi': 1835,
#  'server': 3336,
#  'promo': 2958,
#  'ui': 3896,
#  'buruk': 672,
#  'agt': 45,
#  'operasi': 2639,
#  'praktis': 2931,
#  'profil': 2954,
#  'des': 908,
#  'ajib': 65,
#  'nih': 2513,
#  'fiturfiturnya': 1186,
#  'desain': 910,
#  'layar': 2012,
#  'rapi': 3010,
#  'biru': 489,
#  'gmna': 1283,
#  'mo': 2353,
#  'dipindahin': 987,
#  'kerna': 1732,
#  'sia': 3381,
#  'recomend': 3028,
#  'loading': 2088,
#  'lancar': 1975,
#  'tampil': 3598,
#  'sudahlama': 3529,
#  'uninstall': 3914,
#  'asa': 202,
#  'ngga': 2485,
#  'aplkasi': 186,
#  'iniakun': 1460,
#  'kena': 1706,
#  'hack': 1326,
#  'steam': 3509,
#  'vcr': 3964,
#  'game': 1232,
#  'bajak': 261,
#  'manusia': 2198,
#  'dewa': 919,
#  'sih': 3395,
#  'mkin': 2337,
#  'gajelas': 1223,
#  'semacem': 3292,
#  'gabisa': 1211,
#  'tlng': 3771,
#  'terkaitdevelop': 3696,
#  'dri': 1064,
#  'dlu': 1026,
#  'dikecewain': 968,
#  'tutup': 3879,
#  'tanggapinnya': 3614,
#  'formulir': 1198,
#  'gratis': 1300,
#  'boongan': 561,
#  'jnt': 1574,
#  'sellernya': 3288,
#  'nyantumin': 2582,
#  'bohong': 553,
#  'siniudah': 3414,
#  'capek': 708,
#  'ngetikpas': 2484,
#  'tuju': 3864,
#  'jdinya': 1545,
#  'terimatpi': 3690,
#  'reportnya': 3066,
#  'bingungmo': 483,
#  'hrs': 1410,
#  'gmn': 1282,
#  'pasrah': 2724,
#  'aj': 50,
#  'an': 130,
#  'tanggapin': 3613,
#  'tahun': 3585,
#  'benah': 382,
#  'kabur': 1605,
#  'bel': 357,
#  'ok': 2608,
#  'saat': 3143,
#  'minta': 2328,
#  'penjualanpembatalan': 2826,
#  'apl': 172,
#  'bulalapak': 666,
#  'nyanotif': 2581,
#  'tanggap': 3609,
#  'kpd': 1861,
#  'nyari': 2585,
#  'ikan': 1426,
#  'hias': 1385,
#  'pakan': 2694,
#  'ganggu': 1238,
#  'minus': 2331,
#  'mahal': 2143,
#  'penuh': 2831,
#  'tgl': 3728,
#  'april': 193,
#  'simpan': 3404,
#  'gudang': 1310,
#  'bukaexpress': 610,
#  'livechat': 2083,
#  'fungsi': 1205,
#  'beda': 345,
#  'merchant': 2299,
#  'payleter': 2748,
#  'cancel': 701,
#  'sungguh': 3542,
#  'obrol': 2600,
#  'aktifin': 82,
#  'hangus': 1354,
#  'kyc': 1911,
#  'sory': 3482,
#  'ane': 138,
#  'join': 1576,
#  'kepercayan': 1720,
#  'ecom': 1086,
#  'aktifasi': 80,
#  'enek': 1124,
#  'masak': 2211,
#  'kode': 1798,
#  'otp': 2666,
#  'sefty': 3249,
#  'lo': 2086,
#  'nyataanya': 2587,
#  'aktivasi': 87,
#  'ampuun': 128,
#  'kyk': 1912,
#  'pinjam': 2885,
#  'bank': 290,
#  'sumpaah': 3540,
#  'oohh': 2636,
#  'devlover': 918,
#  'lebay': 2022,
#  'ken': 1705,
#  'ktprekening': 1882,
#  'seribet': 3329,
#  'kah': 1614,
#  'cantumin': 704,
#  'ubah': 3888,
#  'masukin': 2221,
#  'tipenyasaya': 3762,
#  'paket': 2698,
#  'zonk': 4074,
#  'langgar': 1980,
#  'ngapain': 2457,
#  'loadingnya': 2090,
#  'ngechek': 2469,
#  'internetdi': 1486,
#  'nglungker': 2497,
#  'trs': 3846,
#  'nambah': 2420,
#  'jenuhtlg': 1559,
#  'perhati': 2847,
#  'mantabb': 2186,
#  'simple': 3409,
#  'lemottnya': 2041,
#  'emas': 1115,
#  'bukaemas': 609,
#  'problem': 2946,
#  'bad': 233,
#  'gateway': 1247,
#  'kek': 1684,
#  'sengaja': 3312,
#  'investasi': 1489,
#  'app': 188,
#  'ajabanyak': 53,
#  'sisrem': 3419,
#  'gunabuka': 1313,
#  'kya': 1909,
#  'ajaisi': 56,
#  'buang': 597,
#  'ajadan': 54,
#  'bagusmasuk': 248,
#  'ribetnya': 3095,
#  'didownload': 951,
#  'touch': 3800,
#  'ud': 3891,
#  'az': 228,
#  'la': 1914,
#  'repot': 3067,
#  'dear': 890,
#  'check': 768,
#  'posisi': 2918,
#  'sana': 3182,
#  'bug': 601,
#  'rusa': 3137,
#  'menggangu': 2280,
#  'dengar': 903,
#  'ribu': 3099,
#  'cumq': 823,
#  'temu': 3662,
#  'gaya': 1248,
#  'unjung': 3918,
#  'bantuannyasaya': 294,
#  'logindikarenakan': 2095,
#  'aktifmau': 84,
#  'sayadan': 3205,
#  'bukalapakmohon': 632,
#  'isi': 1495,
#  'betah': 450,
#  'kadaluarsamau': 1608,
#  'canggih': 702,
#  'cman': 778,
#  'sadah': 3146,
#  'kembaliini': 1703,
#  'blum': 540,
#  'kepastianpayah': 1716,
#  'nyesel': 2595,
#  'gw': 1321,
#  'dibukalapak': 943,
#  'fiturnya': 1187,
#  'pelit': 2779,
#  'nonaktif': 2534,
#  'set': 3347,
#  'ni': 2508,
#  'sen': 3305,
#  'dibls': 942,
#  'blm': 525,
#  'mls': 2343,
#  'woi': 4039,
#  'profesional': 2952,
#  'beban': 340,
#  'and': 133,
#  'smartphone': 3454,
#  'gue': 1311,
#  'piara': 2873,
#  'manfaat': 2177,
#  'cepet': 749,
#  'promonya': 2959,
#  'fee': 1169,
#  'lainnyamataap': 1944,
#  'daah': 842,
#  'gunawan': 1318,
#  'sm': 3450,
#  'mitra': 2334,
#  'dalem': 855,
#  'msk': 2368,
#  'refund': 3038,
#  'smpe': 3461,
#  'detik': 916,
#  'ngerti': 2480,
#  'biyaya': 510,
#  'maksud': 2159,
#  'apalg': 162,
#  'nyesek': 2594,
#  'dg': 922,
#  'sgitu': 3356,
#  'bsa': 588,
#  'ilangin': 1435,
#  'tuhklo': 3863,
#  'rangin': 3008,
#  'kepakasa': 1715,
#  'blanja': 515,
#  'saking': 3151,
#  'tmpt': 3776,
#  'chip': 770,
#  'snapdragon': 3467,
#  'gen': 1256,
#  'ram': 3002,
#  'gb': 1250,
#  'clear': 776,
#  'chace': 755,
#  'logout': 2099,
#  'baru': 317,
#  'expedisi': 1151,
#  'reg': 3040,
#  'next': 2442,
#  'day': 880,
#  'pick': 2874,
#  'lelet': 2026,
#  'criss': 812,
#  'cross': 814,
#  'sop': 3477,
#  'resi': 3073,
#  'ybs': 4059,
#  'depan': 905,
#  'buset': 675,
#  'hebat': 1376,
#  'lenya': 2050,
#  'berbelanjatapi': 404,
#  'dam': 856,
#  'halapalagi': 1345,
#  'sistemnyakecewa': 3423,
#  'telat': 3642,
#  'report': 3065,
#  'bermasalahpaket': 436,
#  'jadwal': 1510,
#  'kompensasi': 1816,
#  'jamin': 1521,
#  'kembalihanya': 1702,
#  'slogan': 3447,
#  'belakabagaimana': 360,
#  'muter': 2400,
#  'ajalihat': 58,
#  'history': 1396,
#  'mainnumpuk': 2148,
#  'diserver': 1004,
#  'akunbuatlah': 90,
#  'nge': 2461,
#  'suka': 3533,
#  'hang': 1353,
#  'lebih': 2024,
#  'star': 3505,
#  'higs': 1389,
#  'domino': 1042,
#  'terap': 3675,
#  'digital': 956,
#  'payleater': 2746,
#  'bukalapaksaya': 640,
#  'lagibukti': 1927,
#  'struknya': 3522,
#  'kasir': 1654,
#  'indomart': 1452,
#  'yeah': 4060,
#  'tagihantapi': 3582,
#  'kecewadimana': 1670,
#  'codtapi': 787,
#  'express': 1153,
#  'forma': 1195,
#  'huhuhuuuuu': 1417,
#  'nali': 2418,
#  'pribadi': 2939,
#  'beliau': 374,
#  'kurang': 1895,
#  'riwayat': 3113,
#  'telusur': 3655,
#  'kunci': 1889,
#  'sebutin': 3238,
#  'merek': 2300,
#  'official': 2604,
#  'brand': 573,
#  'paylatternya': 2745,
#  'pemberitahuan': 2793,
#  'tetep': 3724,
#  'dikirm': 973,
#  'nyampai': 2576,
#  'aktiv': 86,
#  'januari': 1528,
#  'jugasudah': 1591,
#  'bukalapaksungguh': 644,
#  'sukses': 3536,
#  'konfirmasi': 1838,
#  'turunin': 3877,
#  'deh': 895,
#  'eror': 1131,
#  'sayapadahal': 3209,
#  'label': 1916,
#  'cekout': 726,
#  'catat': 720,
#  'metode': 2310,
#  'inipadahal': 1468,
#  'mending': 2271,
#  'keren': 1725,
#  'tahan': 3583,
#  'saing': 3148,
#  'ketat': 1739,
#  'yuk': 4068,
#  'buru': 671,
#  'konsisten': 1840,
#  'timbul': 3749,
#  'tenggelam': 3667,
#  'loh': 2100,
#  'hehee': 1378,
#  'way': 4017,
#  'pbb': 2753,
#  'koreksi': 1854,
#  'alhamdulillah': 102,
#  'sengketa': 3313,
#  'aplaus': 173,
#  'normal': 2540,
#  'bukareksauang': 658,
#  'setatusy': 3351,
#  'selesaidikomplen': 3277,
#  'transfermasuk': 3819,
#  'jawabpaylater': 1540,
#  'rusuhmasih': 3140,
#  'belbel': 371,
#  'terusruwed': 3716,
#  'mesan': 2307,
#  'mes': 2306,
#  'rokok': 3121,
#  'pindah': 2883,
#  'kartu': 1639,
#  'sd': 3223,
#  'tinjau': 3759,
#  'dc': 885,
#  'screen': 3221,
#  'shot': 3378,
#  'wa': 3991,
#  'tindak': 3752,
#  'lanjut': 1983,
#  'bolak': 555,
#  'kantor': 1631,
#  'program': 2956,
#  'setia': 3353,
#  'kak': 1616,
#  'blom': 532,
#  'pdhal': 2759,
#  'transit': 3823,
#  'pay': 2731,
#  'later': 2003,
#  'ah': 46,
#  'hbis': 1371,
#  'ngisi': 2492,
#  'msh': 2366,
#  'cash': 716,
#  'lom': 2107,
#  ...}

# %%
#kolom pertama ini berarti jumlah dokumen
#kolom kedua berarti letak katanya
#kolom ketiga hasil dari tf

term_frequency_all = term_fit.transform(Ulasan)
print (term_frequency_all)
# Out:
#   (0, 325)	1
#   (0, 333)	1
#   (0, 386)	1
#   (0, 467)	1
#   (0, 471)	2
#   (0, 478)	1
#   (0, 760)	1
#   (0, 1120)	1
#   (0, 1133)	1
#   (0, 1239)	2
#   (0, 1533)	1
#   (0, 1609)	2
#   (0, 1971)	1
#   (0, 2008)	2
#   (0, 2494)	1
#   (0, 2559)	3
#   (0, 2663)	1
#   (0, 2736)	1
#   (0, 2989)	2
#   (0, 3011)	2
#   (0, 3152)	1
#   (0, 3420)	1
#   (0, 3553)	1
#   (0, 3661)	1
#   (1, 66)	1
#   :	:
#   (1298, 456)	1
#   (1298, 572)	1
#   (1298, 680)	1
#   (1298, 816)	1
#   (1298, 1208)	2
#   (1298, 1518)	1
#   (1298, 1776)	1
#   (1298, 1985)	3
#   (1298, 2510)	1
#   (1298, 2715)	1
#   (1298, 3079)	1
#   (1298, 3879)	1
#   (1298, 3886)	2
#   (1299, 139)	1
#   (1299, 179)	1
#   (1299, 353)	1
#   (1299, 760)	2
#   (1299, 1208)	2
#   (1299, 1244)	2
#   (1299, 1308)	1
#   (1299, 2081)	1
#   (1299, 2116)	1
#   (1299, 2559)	1
#   (1299, 3813)	1
#   (1299, 4043)	1

# %%
ulasan_tf = Ulasan[1] #memanggil kata pada index ke 1
print (ulasan_tf)
# Out:
# kembali dana otomatis ga berfungsisy lg butuh bgt dana ga ajuin komplainada tombol komplain diarahin pusat bantu ga tombol utk aju pembatalanpengembalian dana aplikasi bener payahmenyulitkan konsumen

# %%
term_frequency = term_fit.transform([ulasan_tf]) #hanya menampilkan hasil document 1
print (term_frequency)
# Out:
#   (0, 66)	1
#   (0, 67)	1
#   (0, 179)	1
#   (0, 293)	1
#   (0, 386)	1
#   (0, 416)	1
#   (0, 456)	1
#   (0, 680)	1
#   (0, 857)	3
#   (0, 931)	1
#   (0, 1208)	3
#   (0, 1700)	1
#   (0, 1820)	1
#   (0, 1821)	1
#   (0, 1844)	1
#   (0, 2058)	1
#   (0, 2663)	1
#   (0, 2734)	1
#   (0, 2783)	1
#   (0, 2986)	1
#   (0, 3792)	2
#   (0, 3952)	1

# %%
dokumen = term_fit.transform(Ulasan) #hasil perhitungan tf idf dalam 1 doc
tfidf_transformer = TfidfTransformer().fit(dokumen)
print (tfidf_transformer.idf_)

tfidf=tfidf_transformer.transform(term_frequency)
print (tfidf) #hasil manual dengan sistem pyhton
# Out:
# [7.4777413  7.07227619 6.78459412 ... 6.78459412 7.4777413  7.4777413 ]
#   (0, 3952)	0.17203854268714736
#   (0, 3792)	0.413273223909903
#   (0, 2986)	0.1918350133486976
#   (0, 2783)	0.23549291598306538
#   (0, 2734)	0.23549291598306538
#   (0, 2663)	0.13475863945294528
#   (0, 2058)	0.14817711071432985
#   (0, 1844)	0.15997715159470519
#   (0, 1821)	0.23549291598306538
#   (0, 1820)	0.10900689412499102
#   (0, 1700)	0.13961323279160923
#   (0, 1208)	0.29794524789434707
#   (0, 931)	0.23549291598306538
#   (0, 857)	0.35796242005864787
#   (0, 680)	0.14817711071432985
#   (0, 456)	0.1614421841087931
#   (0, 416)	0.23549291598306538
#   (0, 386)	0.16629677744745708
#   (0, 293)	0.10037553702536428
#   (0, 179)	0.07195361946779157
#   (0, 67)	0.23549291598306538
#   (0, 66)	0.1585772535812156

# %%
data_label = name_dataframe[["Nama pengguna", "Ulasan_clean", "Sentiment"]]

# %%
data_label["Ulasan_clean"] = data_label["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-234-5732072d6cca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label["Ulasan_clean"] = data_label["Ulasan_clean"].fillna("tidak ada komentar")

# %%
data_label.to_excel("data_label.xlsx")

# %%
sentimen_data=pd.value_counts(data_label["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["#ccd5ae"])
plt.title('Bar chart')
plt.show()

# %%
plt.figure(figsize=(16, 6))

heatmap = sns.heatmap(name_dataframe.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12)

plt.tight_layout()

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize',
#        'ulasan_ears', 'Ulasan_normalized', 'Ulasan_stop_removed',
#        'Ulasan_Stemmed', 'Ulasan_clean', 'label', 'Polarity', 'Subjectivity',
#        'Sentiment', 'month'],
#       dtype='object')

# %%
train_s3 = data_label[data_label["Sentiment"] == 'Neutral']

# %%
train_s3["Ulasan_clean"] = train_s3["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-240-0d6c2c4956f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s3["Ulasan_clean"] = train_s3["Ulasan_clean"].fillna("tidak ada komentar")

# %%
all_text_s0 = ' '.join(word for word in train_s3["Ulasan_clean"])
wordcloud = WordCloud(colormap='gist_stern', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s0)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
print("Neutral words")
plt.show()
# Out:
# Neutral words

# %%
from wordcloud import WordCloud

# %%
train_s0 = data_label[data_label["Sentiment"] == 'Negative']

# %%
train_s0["Ulasan_clean"] = train_s0["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-244-4a391e85ccb2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s0["Ulasan_clean"] = train_s0["Ulasan_clean"].fillna("tidak ada komentar")

# %%
train_s0
# Out:
#                       Nama pengguna  \
# 50               Ilham Padka Wijaya
# 66                      imam maliki
# 74                    Afifur Rohman
# 84          Kaloka Galih Kayu Wangi
# 85                     Bam Hendrian
# 147                          eH boy
# 169              haidar dabi kataro
# 179                 hidayat mudaris
# 181   Infinik smart6 Infinik smart6
# 212                        Nursamsi
# 222                   Candra Wijaya
# 321                          Lemuel
# 332                   Sutris Trisno
# 361                        Ucu Imen
# 392                  Silva Widianti
# 393            Dony Settia Official
# 397                    Bayu Arsandi
# 400                     Fudin Fudin
# 461                  Arjuna Pratama
# 537                     Rizal Bahri
# 544                    tri mulyanto
# 545                     david james
# 546                Achenk Chonsleth
# 553                       Trade Day
# 572                        Nyon bae
# 578                 Novi Nurhalimah
# 582                      Ahmad Amek
# 594                     Endi irawan
# 599                    Cucu Latipah
# 615                   Annisa Arifah
# 617                   ari hariyanto
# 679                   inaya putry26
# 797                      Tegar Ibnu
# 838           Ulfa Mar'atus Solihah
# 895                       X0s Sprtn
# 932               Oktavdian Sonjaya
# 956                 Pengguna Google
# 965                     Najwa Jemur
# 983                 Pengguna Google
# 987                 Pengguna Google
# 1000           Revan Cahaya pratama
# 1041                      Hr Tester
# 1046                Pengguna Google
# 1105                      Fian Syah
# 1154                    Vaka Vaka13
# 1200                     Dhani Deff
# 1218                 Muhammad Basir
# 1243                Brandal Cimanuk
# 1251                Pengguna Google
# 1252                   wisnu arifin
# 1287                    dita 210496
#
#                                            Ulasan_clean Sentiment
# 50    bukalapak marketplace nya sellerseller tipu ka...  Negative
# 66    hati hubung akun aplkasi iniakun kena hack tra...  Negative
# 74    aplikasi bagus minus ongkir mahal voucher yg g...  Negative
# 84    jual emas bukaemas susah banget banget problem...  Negative
# 85    kesini sistem nya berat ajabanyak sisrem yg gu...  Negative
# 147   developer bukalapak gk liat aplikasi shopee la...  Negative
# 169   proses konfirmasi nya lamaproses kirim nya lam...  Negative
# 179   tolong rumit verifikasi akun saldo bukalapak g...  Negative
# 181   bintang deh gagal pinjem alas pinjam tunai akt...  Negative
# 212   mantap paylater limit paylaternya ditambahin c...  Negative
# 222   aplikasi bangke belanja barang gk udh minggu u...  Negative
# 321   mohon maaf kasih bintang alas hubung cs via ch...  Negative
# 332   sy guna setia bltp perlahan sy alih toko onlin...  Negative
# 361   hati hati download aplikasi korban bayar lunas...  Negative
# 392   tagih paylater bl resah kanbelum jatuh tempo a...  Negative
# 393   kali kecewa kembali refund dana masuk dompet s...  Negative
# 397          seller yg slow respon pesan batal otomatis  Negative
# 400                barang lengkap minimal gratis ongkir  Negative
# 461   tgl sy beli unit powerbank merek soulkarena fl...  Negative
# 537   bukalapak jarang dapet gratis ongkirya minimal...  Negative
# 544   kecewa kali belanja lapak merespon pesan batas...  Negative
# 545   order alamat kirim yg laku lapak bilang kode b...  Negative
# 546   lumayan bagus minus sedia menu layan varian pr...  Negative
# 553   kecewa sihketika dapet voucher voucher alas vo...  Negative
# 572   aplikasi guna ganti nomor hp kirim foto ktp ga...  Negative
# 578   kecewa aplikasi bukalapak telat bayar jatuh te...  Negative
# 582   maaf turun bintangnyakarena pakai bukalapak pa...  Negative
# 594   beli barang nonfisik chip game inti barang yg ...  Negative
# 599   sengaja aja bintang biar baca isi saldo atm ta...  Negative
# 615   kecewa sellernya fiturnya live chat susah tamb...  Negative
# 617   parah bukalapak komplen klaim barang sulit pot...  Negative
# 679   aplikasi nya ga visa live chat gmn maju bukala...  Negative
# 797   sih ga ngasih voucher gratis ongkir minimal po...  Negative
# 838   edit ulas hubung customer care aplikasi kait b...  Negative
# 895   pilih bl belanja voucher voucher minimal blnja...  Negative
# 932   suka bingung sm bonus credit nya ya plus minus...  Negative
# 956   heran aplikasi upload jual barang kaya susahhh...  Negative
# 965   kalo bukalapak rame tampil barang jual bayar i...  Negative
# 983   baik servernya fitur macet traffict diserver j...  Negative
# 987   bukastruk gagal struk identifikasi deteksi dup...  Negative
# 1000                          gua main game notif ga lu  Negative
# 1041  aplikasi bagus sgt bantu kendala admin komplai...  Negative
# 1046  kurangtapi suka dwngan tampil bukalapak update...  Negative
# 1105  barang yg pesan tdk yg langsung sy aju komplai...  Negative
# 1154  bingung mw komentar apasly ssh mw cari minus k...  Negative
# 1200  kesini tdk bagus aplikasi buka chat loading tr...  Negative
# 1218  sussh seller gk bsa tmbhin varian prdukgk sma ...  Negative
# 1243  jual gambar kosong dgn alas barang hapus tampi...  Negative
# 1251  baharu akun email username tp ttp error pakai ...  Negative
# 1252  aplikasi belanja mepersulit melakukakan ubah d...  Negative
# 1287  respon customer center susah komplain barang s...  Negative

# %%
all_text_s0 = ' '.join(word for word in train_s0["Ulasan_clean"])
wordcloud = WordCloud(colormap='Reds', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s0)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
print("Negatif words")
plt.show()
# Out:
# Negatif words

# %%
train_s1 = data_label[data_label["Sentiment"] == 'Positive']

# %%
train_s1["Ulasan_clean"] = train_s1["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-248-89653e0cae75>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s1["Ulasan_clean"] = train_s1["Ulasan_clean"].fillna("tidak ada komentar")

# %%
train_s1
# Out:
#                   Nama pengguna  \
# 6                    Sultan Get
# 15                Triadhi Purna
# 18                  Holil Ludin
# 19    Servis Tv CIPANAS CIANJUR
# 20     Lutfipitrahadi Pitrahadi
# ...                         ...
# 1255               Lha Maulhana
# 1271          BIO TEKNO SELARAS
# 1273            Pengguna Google
# 1275                KARMAD ZAIN
# 1299                     Payung
#
#                                            Ulasan_clean Sentiment
# 6     systemnya kalo udah layan tutupin aja aplikasi...  Positive
# 15    batal pesan susah yak jual bilang ready stok t...  Positive
# 18    salah commerce udah pakai worth it halaman tra...  Positive
# 19    aplikasi parah trnsaksi pulsa berhasilpulsa gk...  Positive
# 20    kalo kosong kosong bintang bukalapakpercuma li...  Positive
# ...                                                 ...       ...
# 1255  kacau biaya tangan paylater banget komplain li...  Positive
# 1271  batal pesan sulit komplain live chat jg hubung...  Positive
# 1273  commerce yg nilai super nego skrg tdk bs dipak...  Positive
# 1275  kecewa aplikasi bukalapak fitur zonk spin top ...  Positive
# 1299  woy transaksi gua ga gara gara chat nya lu bek...  Positive
#
# [199 rows x 3 columns]

# %%
all_text_s1 = ' '.join(word for word in train_s1["Ulasan_clean"])
wordcloud = WordCloud(colormap='Blues', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s1)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Ulasan Positif")
plt.margins(x=0, y=0)
print("Positif words")
plt.show()
# Out:
# Positif words

# %%
data_label['Ulasan_clean'] = data_label['Ulasan_clean'].fillna("tidak ada komentar")
# Out:
# <ipython-input-251-27b828896519>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['Ulasan_clean'] = data_label['Ulasan_clean'].fillna("tidak ada komentar")

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_clean'], data_label['Sentiment'], 
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(data_label['Ulasan_clean'])

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, data_label['Sentiment'], test_size=0.2, random_state=42)

# Train the Gaussian Naive Bayes classifier on the training set
gnb = GaussianNB()
gnb.fit(X_train.toarray(), y_train)

# Evaluate the classifier on the testing set
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)

# Use the classifier to predict the sentiment class for all reviews in the dataset
data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# Save the resulting dataframe to a new CSV file
data_label.to_csv('predicted_sentiment1.csv', index=False)
# Out:
# Accuracy: 0.6230769230769231
# <ipython-input-254-35ea0f31f4f4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# %%
import numpy as np

X_train = X_train.toarray()
X_test = X_test.toarray()

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# Gaussian Naive Bayes with original data
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_gnb = gnb.predict(X_test)
print('Original Results:')
print(classification_report(y_test, y_gnb))
print(confusion_matrix(y_test, y_gnb))
print('Accuracy with original test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with undersampling
rus = RandomUnderSampler(random_state=1)
X_rus, y_rus = rus.fit_resample(X_train, y_train)
gnb = GaussianNB()
gnb.fit(X_rus, y_rus)
y_gnb = gnb.predict(X_test)
print('Undersampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with undersampling test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with oversampling
smote = SMOTE(random_state=1)
X_smote, y_smote = smote.fit_resample(X_train, y_train)
gnb = GaussianNB()
gnb.fit(X_smote, y_smote)
y_gnb = gnb.predict(X_test)
print('Oversampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with oversampling test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with combined oversampling and undersampling
rus = RandomUnderSampler(random_state=1)
X_rus, y_rus = rus.fit_resample(X_train, y_train)

smote = SMOTE(random_state=1)
X_smt, y_smt = smote.fit_resample(X_rus, y_rus)

gnb = GaussianNB()
gnb.fit(X_smt, y_smt)
y_gnb = gnb.predict(X_test)
print('Combined Oversampling and Undersampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with combined oversampling and undersampling test data:', accuracy_score(y_test, y_gnb))
# Out:
# Original Results:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         8
#      Neutral       0.84      0.68      0.75       214
#     Positive       0.22      0.42      0.29        38
#
#     accuracy                           0.62       260
#    macro avg       0.35      0.37      0.35       260
# weighted avg       0.72      0.62      0.66       260
#
# [[  0   6   2]
#  [ 13 146  55]
#  [  0  22  16]]
# Accuracy with original test data: 0.6230769230769231
# Undersampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.06      0.75      0.11         8
#      Neutral       0.96      0.30      0.46       214
#     Positive       0.17      0.39      0.24        38
#
#     accuracy                           0.33       260
#    macro avg       0.39      0.48      0.27       260
# weighted avg       0.81      0.33      0.41       260
#
# Accuracy with undersampling test data: 0.3269230769230769
# Oversampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         8
#      Neutral       0.84      0.68      0.75       214
#     Positive       0.22      0.42      0.29        38
#
#     accuracy                           0.62       260
#    macro avg       0.35      0.37      0.35       260
# weighted avg       0.72      0.62      0.66       260
#
# Accuracy with oversampling test data: 0.6230769230769231
# Combined Oversampling and Undersampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.06      0.75      0.11         8
#      Neutral       0.96      0.30      0.46       214
#     Positive       0.17      0.39      0.24        38
#
#     accuracy                           0.33       260
#    macro avg       0.39      0.48      0.27       260
# weighted avg       0.81      0.33      0.41       260
#
# Accuracy with combined oversampling and undersampling test data: 0.3269230769230769

# %%
import numpy as np

# %%
from sklearn.feature_extraction.text import TfidfVectorizer             #menghitung n menjumlah kan dan menjumlah kan tf and n berdasarkan seluruh dokumen 
vectorizer = TfidfVectorizer(decode_error='replace', encoding='utf-8')

# %%
data_label['predicted_sentiment_class'].value_counts()
# Out:
# Neutral     922
# Positive    299
# Negative     79
# Name: predicted_sentiment_class, dtype: int64

# %%
data_label['predicted_sentiment_class'].hist()
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# **sample random**
#
# mengambil secara acak dari daftar sample atau sampling frame yang tersedia setiap individu memiliki peluang yang sama untuk terpilih
# peluang tersebut ada melakukan peluang sama ketika mempunyai data besar akan memliki peluang lebih besar untuk terpilih tetapi sebaliknya ketika mempunyai data dikit dapat peluang lebih sedikit

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_clean'], data_label['Sentiment'], 
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# Vectorize the text data
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# Create the Naive Bayes Classifier object
gnb = GaussianNB()

# Perform cross-validation
scores = cross_val_score(gnb, X_train.toarray(), y_train, cv=5)

# Print the cross-validation scores
print('Cross-validation scores:', scores)

# Fit the classifier to the training data
gnb.fit(X_train.toarray(), y_train)

# Predict the sentiment of the test data
y_pred = gnb.predict(X_test.toarray())

# Print the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:\n', conf_matrix)
# Out:
# Cross-validation scores: [0.58547009 0.61965812 0.56837607 0.62820513 0.64102564]
# Confusion Matrix:
#  [[ 1  4  0]
#  [ 1 78 26]
#  [ 1 10  9]]

# %%
# Convert sparse matrix to dense numpy array
X_train_dense = X_train.toarray()
X_test_dense = X_test.toarray()

# Print the scores on the training and test sets
print('Training set score: {:.4f}'.format(gnb.score(X_train_dense, y_train)))
print('Test set score: {:.4f}'.format(gnb.score(X_test_dense, y_test)))
# Out:
# Training set score: 0.9000
# Test set score: 0.6769

# %%
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.676923076923077

# %%
vectorizer
# Out:
# TfidfVectorizer()

# %%
nb = GaussianNB(var_smoothing=1.0) # untuk tidak overviting

# %%
data_label
# Out:
#          Nama pengguna                                       Ulasan_clean  \
# 0         Nizar Rayyan  paylater ngk bener batal otomatis kadang nya g...
# 1       Ganjar Hermadi  kembali dana otomatis ga berfungsisy lg butuh ...
# 2           Fandy Komo  kesini buka lapak bagus layan komplan aja susa...
# 3          Dwi Indarti  bayar lunaspaylater transaksi apapunselalu bat...
# 4         Yuda Nugraha  update ngaco aplikasi menu barang favorit gbs ...
# ...                ...                                                ...
# 1295    Aidil Pridiyah                                   tingkat promonya
# 1296     Moja Maharani  bonus undang referal masuk orng tunggu cepat y...
# 1297     Putri Sentani            bagus kirim cepat terimakasih bukalapak
# 1298  Novian Syahputra  lapak ga benerrrrrr klo niatny lapak ga bener ...
# 1299            Payung  woy transaksi gua ga gara gara chat nya lu bek...
#
#      Sentiment predicted_sentiment_class
# 0      Neutral                   Neutral
# 1      Neutral                   Neutral
# 2      Neutral                   Neutral
# 3      Neutral                   Neutral
# 4      Neutral                   Neutral
# ...        ...                       ...
# 1295   Neutral                  Positive
# 1296   Neutral                   Neutral
# 1297   Neutral                  Positive
# 1298   Neutral                   Neutral
# 1299  Positive                  Positive
#
# [1300 rows x 4 columns]

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
print('--------------------- confusion matrix  ----------------------------')
print(confusion_matrix(y_test, y_pred))
print('--------------------- classification report  ----------------------------')
print(classification_report(y_test, y_pred))
# Out:
# --------------------- confusion matrix  ----------------------------
# [[ 1  4  0]
#  [ 1 78 26]
#  [ 1 10  9]]
# --------------------- classification report  ----------------------------
#               precision    recall  f1-score   support
#
#     Negative       0.33      0.20      0.25         5
#      Neutral       0.85      0.74      0.79       105
#     Positive       0.26      0.45      0.33        20
#
#     accuracy                           0.68       130
#    macro avg       0.48      0.46      0.46       130
# weighted avg       0.74      0.68      0.70       130

# %%
TP = cm[0,0]
TN = cm[1,1]
FP = cm[0,1]
FN = cm[1,0]

# %%
# print classification error kesalahan klasifikasi 

classification_error = (FP + FN) / float(TP + TN + FP + FN)

print('Classification error : {0:0.4f}'.format(classification_error))
# Out:
# Classification error : 0.0595

# %%
classification_accuracy = (TP + TN) / float(TP + TN + FP + FN)

print('Classification accuracy : {0:0.4f}'.format(classification_accuracy))
# Out:
# Classification accuracy : 0.9405

# %%
# visualize confusion matrix with seaborn heatmap

cm_matrix = pd.DataFrame(data=cm, columns=['Negative:1', 'Neutral:0', 'Positive:2'], 
                                 index=['Negative:1', 'Neutral:0', 'Positive:2'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <Axes: >

# %%
X_test
# Out:
# <130x3825 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1778 stored elements in Compressed Sparse Row format>

# %%
X_train
# Out:
# <1170x3825 sparse matrix of type '<class 'numpy.float64'>'
# 	with 18290 stored elements in Compressed Sparse Row format>

# %%
y_test
# Out:
# 787      Neutral
# 671      Neutral
# 965     Negative
# 605      Neutral
# 565      Neutral
#           ...
# 815      Neutral
# 510     Positive
# 931      Neutral
# 1037    Positive
# 1249     Neutral
# Name: Sentiment, Length: 130, dtype: object

# %%
y_train
# Out:
# 1235    Neutral
# 863     Neutral
# 407     Neutral
# 93      Neutral
# 909     Neutral
#          ...
# 304     Neutral
# 216     Neutral
# 284     Neutral
# 14      Neutral
# 1216    Neutral
# Name: Sentiment, Length: 1170, dtype: object

# %%
print(y_train)
# Out:
# 1235    Neutral
# 863     Neutral
# 407     Neutral
# 93      Neutral
# 909     Neutral
#          ...
# 304     Neutral
# 216     Neutral
# 284     Neutral
# 14      Neutral
# 1216    Neutral
# Name: Sentiment, Length: 1170, dtype: object

# %%
# visualize confusion matrix with seaborn heatmap

cm_matrix = pd.DataFrame(data=cm, columns=['Negative:1', 'Neutral:0', 'Positive:2'], 
                                 index=['Negative:1', 'Neutral:0', 'Positive:2'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <Axes: >

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
print('Confusion matrix\n\n', cm)
# Out:
# Confusion matrix
#
#  [[ 1  4  0]
#  [ 1 78 26]
#  [ 1 10  9]]

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
# Regresi Logistik
logreg = LogisticRegression()
# SVM
svm = SVC(probability=True)

# %%
logreg.fit(X_train, y_train)
svm.fit(X_train, y_train)
# Out:
# SVC(probability=True)

# %%
y_pred1_logreg = logreg.predict(X_test)
y_pred1_svm = svm.predict(X_test)

# %%
print('---------------  Regresi Logistik  -------------------')
print(classification_report(y_test, y_pred1_logreg))
print('--------------------- SVM ----------------------------')
print(classification_report(y_test, y_pred1_svm))
# Out:
# ---------------  Regresi Logistik  -------------------
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         5
#      Neutral       0.84      1.00      0.91       105
#     Positive       1.00      0.25      0.40        20
#
#     accuracy                           0.85       130
#    macro avg       0.61      0.42      0.44       130
# weighted avg       0.83      0.85      0.80       130
#
# --------------------- SVM ----------------------------
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         5
#      Neutral       0.83      1.00      0.91       105
#     Positive       1.00      0.15      0.26        20
#
#     accuracy                           0.83       130
#    macro avg       0.61      0.38      0.39       130
# weighted avg       0.82      0.83      0.77       130
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
