# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafiryd/Rafiryd/blob/rafiryd/expore%20datetime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime

# %%
df = pd.read_excel('df_time.xlsx')
df.head()
# Out:
#    Unnamed: 0                  at
# 0           0 2022-10-20 02:10:35
# 1           1 2022-10-29 11:18:02
# 2           2 2022-10-20 18:21:45
# 3           3 2022-08-15 16:53:45
# 4           4 2022-10-15 03:40:36

# %%
df.dtypes
# Out:
# index                  int64
# Unnamed: 0             int64
# at            datetime64[ns]
# date                  object
# time                  object
# dtype: object

# %%
#df['hr'] = df['date'].dt.strftime('%Y-%m-%d %H:00')
df['time'] = df['at'].dt.strftime('%H:00')
df
# Out:
#       Unnamed: 0                  at        date   time
# 0              0 2022-10-20 02:10:35  2022-10-20  02:00
# 1              1 2022-10-29 11:18:02  2022-10-29  11:00
# 2              2 2022-10-20 18:21:45  2022-10-20  18:00
# 3              3 2022-08-15 16:53:45  2022-08-15  16:00
# 4              4 2022-10-15 03:40:36  2022-10-15  03:00
# ...          ...                 ...         ...    ...
# 996          996 2022-07-30 12:56:41  2022-07-30  12:00
# 997          997 2022-09-11 12:56:54  2022-09-11  12:00
# 998          998 2022-10-14 13:43:16  2022-10-14  13:00
# 999          999 2022-07-14 07:18:45  2022-07-14  07:00
# 1000        1000 2022-08-16 10:57:22  2022-08-16  10:00
#
# [1001 rows x 4 columns]

# %%
df.reset_index(inplace=True)
df['year'] = df.date.dt.year
df['month'] = df.date.dt.month
df['day'] = df.date.dt.day
df['day of week'] = df.date.dt.dayofweek

df.set_index('date', inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-20b93a514fcc> in <module>
# ----> 1 df.reset_index(inplace=True)
#       2 df['year'] = df.date.dt.year
#       3 df['month'] = df.date.dt.month
#       4 df['day'] = df.date.dt.day
#       5 df['day of week'] = df.date.dt.dayofweek
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5797                     )
#    5798
# -> 5799                 new_obj.insert(0, name, level_values)
#    5800
#    5801         new_obj.index = new_index
#
# ...

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df
# Out:
#       level_0  index  Unnamed: 0                  at       date   time  year  \
# 0           0      0           0 2022-10-20 02:10:35 2022-10-20  02:00  2022
# 1           1      1           1 2022-10-29 11:18:02 2022-10-29  11:00  2022
# 2           2      2           2 2022-10-20 18:21:45 2022-10-20  18:00  2022
# 3           3      3           3 2022-08-15 16:53:45 2022-08-15  16:00  2022
# 4           4      4           4 2022-10-15 03:40:36 2022-10-15  03:00  2022
# ...       ...    ...         ...                 ...        ...    ...   ...
# 996       996    996         996 2022-07-30 12:56:41 2022-07-30  12:00  2022
# 997       997    997         997 2022-09-11 12:56:54 2022-09-11  12:00  2022
# 998       998    998         998 2022-10-14 13:43:16 2022-10-14  13:00  2022
# 999       999    999         999 2022-07-14 07:18:45 2022-07-14  07:00  2022
# 1000     1000   1000        1000 2022-08-16 10:57:22 2022-08-16  10:00  2022
#
#       month  day  day of week
# ...

# %%
df['Weekday Name'] = df.date.dt.strftime("%A")
df.set_index('date', inplace=True)
df.head()
# Out:
#             level_0  index  Unnamed: 0                  at   time  year  \
# date
# 2022-10-20        0      0           0 2022-10-20 02:10:35  02:00  2022
# 2022-10-29        1      1           1 2022-10-29 11:18:02  11:00  2022
# 2022-10-20        2      2           2 2022-10-20 18:21:45  18:00  2022
# 2022-08-15        3      3           3 2022-08-15 16:53:45  16:00  2022
# 2022-10-15        4      4           4 2022-10-15 03:40:36  03:00  2022
#
#             month  day  day of week Weekday Name
# date
# 2022-10-20     10   20            3     Thursday
# 2022-10-29     10   29            5     Saturday
# 2022-10-20     10   20            3     Thursday
# 2022-08-15      8   15            0       Monday
# 2022-10-15     10   15            5     Saturday

# %%
df.dtypes
# Out:
# level_0                  int64
# index                    int64
# Unnamed: 0               int64
# at              datetime64[ns]
# time                    object
# year                     int64
# month                    int64
# day                      int64
# day of week              int64
# Weekday Name            object
# dtype: object
