# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafiryd/Rafiryd/blob/rafiryd/skripsi12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Referensi: https://www.linkedin.com/pulse/how-scrape-google-play-reviews-4-simple-steps-using-python-kundi/

# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.2-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.2

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

import seaborn as sns

# %%
#Scrape desired number of reviews
#Run kode ini jika ingin scrape data dengan jumlah tertentu. Ganti (misal, ingin scrape sejumlah 1000, maka ganti kode , count = 1000 )

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.bukalapak.android',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=1300, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId                  userName  \
# 0  c162506f-1395-419e-ae5b-48076e3349a0             Ryan Apriandi
# 1  1e5a820b-3464-478a-926f-a473ae402175                     Aya 4
# 2  798fd05d-c1b8-4bbb-b16a-fb42bb5ac32f                     Ranie
# 3  9e769ec0-5063-4f7c-8fef-ac2f90b95046           Fajron Musayyab
# 4  99ac25bb-686c-4009-8edd-016279b23fbb  Agroprobiotik Jawa Barat
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD5-W...
# 1  https://play-lh.googleusercontent.com/a/AEdFTp...
# 2  https://play-lh.googleusercontent.com/a-/AD5-W...
# 3  https://play-lh.googleusercontent.com/a-/AD5-W...
# 4  https://play-lh.googleusercontent.com/a-/AD5-W...
#
#                                              content  score  thumbsUpCount  \
# 0  Aplikasi parah, saya belanja dengan CC pilih k...      1            120
# 1  Bagus sih. Cuman skrg ribet. krn sering kali m...      3             24
# 2  Setelah 4thn ga buka akun BL, barusan saya buk...      1             54
# 3  Maaf saya kasih bintang 2, karena untuk layana...      2              4
# 4  Sy kesulitan ingin komplen masalah pembayaran ...      2            109
#
#   reviewCreatedVersion                  at replyContent repliedAt
# 0               5.27.3 2023-01-05 15:39:31         None       NaT
# 1               5.27.3 2023-01-17 01:15:20         None       NaT
# 2               5.27.3 2023-01-13 02:11:50         None       NaT
# 3               5.27.3 2023-01-11 23:20:18         None       NaT
# 4               5.27.2 2022-12-30 03:49:00         None       NaT

# %%
len(df_busu.index) #count the number of data we got
# Out:
# 1300

# %%
df_busu[['userName', 'score','at', 'content']].tail()  #preview userName, rating, date-time, and reviews only
# Out:
#                             userName  score                  at  \
# 1295                      FST GAMING      1 2022-09-14 18:24:38
# 1296                 Pengguna Google      1 2018-12-24 06:15:22
# 1297  Antonius Andika Riski Setiawan      1 2022-08-10 08:46:22
# 1298                    sarip kedung      3 2022-10-14 21:18:02
# 1299     Stefanus Ananda Sapta Putra      5 2022-08-31 09:29:58
#
#                                                 content
# 1295  Lawak ni applikasi, sudah jadi aplikasi Underr...
# 1296  Aplikasi kurang berkualitas,tidak ada bedanya ...
# 1297  Terburuk dari semua aplikasi penjualan yang pe...
# 1298  Biaya Ongkir kurangin jangan terlalu mahal..ba...
# 1299  Belanja di sini belum pernah ada kekecewaan, k...

# %%
name_dataframe = df_busu.loc[:,["userName", "score", "at", "content"]]
name_dataframe.rename(columns={"userName": "Nama pengguna", "score":"Rating", "at": "Date", "content": "Ulasan"}, inplace=True)

# %%
name_dataframe.tail()
# Out:
#                        Nama pengguna  Rating                Date  \
# 1295                      FST GAMING       1 2022-09-14 18:24:38
# 1296                 Pengguna Google       1 2018-12-24 06:15:22
# 1297  Antonius Andika Riski Setiawan       1 2022-08-10 08:46:22
# 1298                    sarip kedung       3 2022-10-14 21:18:02
# 1299     Stefanus Ananda Sapta Putra       5 2022-08-31 09:29:58
#
#                                                  Ulasan
# 1295  Lawak ni applikasi, sudah jadi aplikasi Underr...
# 1296  Aplikasi kurang berkualitas,tidak ada bedanya ...
# 1297  Terburuk dari semua aplikasi penjualan yang pe...
# 1298  Biaya Ongkir kurangin jangan terlalu mahal..ba...
# 1299  Belanja di sini belum pernah ada kekecewaan, k...

# %%
name_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nama pengguna  1300 non-null   object
#  1   Rating         1300 non-null   int64
#  2   Date           1300 non-null   datetime64[ns]
#  3   Ulasan         1300 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 40.8+ KB

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].astype(str)
name_dataframe.head()
# Out:
#               Nama pengguna  Rating                Date  \
# 0             Ryan Apriandi       1 2023-01-05 15:39:31
# 1                     Aya 4       3 2023-01-17 01:15:20
# 2                     Ranie       1 2023-01-13 02:11:50
# 3           Fajron Musayyab       2 2023-01-11 23:20:18
# 4  Agroprobiotik Jawa Barat       2 2022-12-30 03:49:00
#
#                                               Ulasan
# 0  Aplikasi parah, saya belanja dengan CC pilih k...
# 1  Bagus sih. Cuman skrg ribet. krn sering kali m...
# 2  Setelah 4thn ga buka akun BL, barusan saya buk...
# 3  Maaf saya kasih bintang 2, karena untuk layana...
# 4  Sy kesulitan ingin komplen masalah pembayaran ...

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].str.lower()

# %%
import string 
import re 
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

def remove_links(text):
    # menghapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus URL
    return text.replace("http://", " ").replace("https://", " ")
                
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_links)

# %%
#menghapus number
def remove_number(text):
    return  re.sub(r"\d+", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_number)

# %%
#menghapus punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_punctuation)

# %%
# menghapus single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_singl_char)

# %%
# Tokenisasi 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

name_dataframe['Ulasan_tokenize'] = name_dataframe['Ulasan'].apply(word_tokenize_wrapper)

# %%
name_dataframe
# Out:
#                        Nama pengguna  Rating                Date  \
# 0                      Ryan Apriandi       1 2023-01-05 15:39:31
# 1                              Aya 4       3 2023-01-17 01:15:20
# 2                              Ranie       1 2023-01-13 02:11:50
# 3                    Fajron Musayyab       2 2023-01-11 23:20:18
# 4           Agroprobiotik Jawa Barat       2 2022-12-30 03:49:00
# ...                              ...     ...                 ...
# 1295                      FST GAMING       1 2022-09-14 18:24:38
# 1296                 Pengguna Google       1 2018-12-24 06:15:22
# 1297  Antonius Andika Riski Setiawan       1 2022-08-10 08:46:22
# 1298                    sarip kedung       3 2022-10-14 21:18:02
# 1299     Stefanus Ananda Sapta Putra       5 2022-08-31 09:29:58
#
#                                                  Ulasan  \
# 0     aplikasi parah saya belanja dengan cc pilih kl...
# 1     bagus sih cuman skrg ribet krn sering kali min...
# 2     setelah  thn ga buka akun bl barusan saya buka...
# 3     maaf saya kasih bintang   karena untuk layanan...
# 4     sy kesulitan ingin komplen masalah pembayaran ...
# ...                                                 ...
# 1295  lawak ni applikasi sudah jadi aplikasi underra...
# 1296  aplikasi kurang berkualitastidak ada bedanya d...
# 1297  terburuk dari semua aplikasi penjualan yang pe...
# 1298  biaya ongkir kurangin jangan terlalu mahalbany...
# 1299  belanja di sini belum pernah ada kekecewaan ka...
#
#                                         Ulasan_tokenize
# 0     [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1     [bagus, sih, cuman, skrg, ribet, krn, sering, ...
# 2     [setelah, thn, ga, buka, akun, bl, barusan, sa...
# 3     [maaf, saya, kasih, bintang, karena, untuk, la...
# 4     [sy, kesulitan, ingin, komplen, masalah, pemba...
# ...                                                 ...
# 1295  [lawak, ni, applikasi, sudah, jadi, aplikasi, ...
# 1296  [aplikasi, kurang, berkualitastidak, ada, beda...
# 1297  [terburuk, dari, semua, aplikasi, penjualan, y...
# 1298  [biaya, ongkir, kurangin, jangan, terlalu, mah...
# 1299  [belanja, di, sini, belum, pernah, ada, kekece...
#
# [1300 rows x 5 columns]

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize'], dtype='object')

# %%
#Run This Code to Sort the Data By Date 
# tanggal 26-04-2022 sampai 12-10-2022

new_df = name_dataframe[['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize']]
sorted_df = new_df.sort_values(by='Date', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#              Nama pengguna  Rating                Date  \
# 1075              MUGIYONO       5 2023-01-18 12:40:14
# 1074           yuma aditya       4 2023-01-18 12:29:36
# 261   Putri Adelia Khrisna       5 2023-01-18 12:18:35
# 1066            Ahmad Rofi       1 2023-01-18 11:27:20
# 790        Erwin Setiawann       5 2023-01-18 09:41:16
#
#                                                  Ulasan  \
# 1075  sangat membantu saya untuk mencari barang yg s...
# 1074  susah mengganti akun dana sedangkan nomor akun...
# 261   mau tanya kenapa bukalapak paylaternya ga bisa...
# 1066  mw komplain di aplikasi ini di persulit sepert...
# 790   bukalapak memang top dan amanah semoga jadi de...
#
#                                         Ulasan_tokenize
# 1075  [sangat, membantu, saya, untuk, mencari, baran...
# 1074  [susah, mengganti, akun, dana, sedangkan, nomo...
# 261   [mau, tanya, kenapa, bukalapak, paylaternya, g...
# 1066  [mw, komplain, di, aplikasi, ini, di, persulit...
# 790   [bukalapak, memang, top, dan, amanah, semoga, ...

# %%
sorted_df.dtypes
# Out:
# Nama pengguna              object
# Rating                      int64
# Date               datetime64[ns]
# Ulasan                     object
# Ulasan_tokenize            object
# dtype: object

# %%
# Menghitung Distibusi Persebaran Kata
def freqDist_wrapper(text):
    return FreqDist(text)

Ulasan_fqsist = name_dataframe['Ulasan_tokenize'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(Ulasan_fqsist.head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(di, 3), (saya, 2), (belanja, 2), (cicilan, 2...
# 1    [(ribet, 2), (krn, 2), (susah, 2), (tdk, 2), (...
# 2    [(ada, 4), (yg, 4), (bl, 3), (barang, 3), (lbh...
# 3    [(tidak, 2), (sesuai, 2), (dan, 2), (maaf, 1),...
# 4    [(ingin, 3), (komplen, 3), (sy, 2), (pembayara...
# Name: Ulasan_tokenize, dtype: object

# %%
name_dataframe['Ulasan_tokenize'].unique
# Out:
# <bound method Series.unique of 0       [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1       [bagus, sih, cuman, skrg, ribet, krn, sering, ...
# 2       [setelah, thn, ga, buka, akun, bl, barusan, sa...
# 3       [maaf, saya, kasih, bintang, karena, untuk, la...
# 4       [sy, kesulitan, ingin, komplen, masalah, pemba...
#                               ...
# 1295    [lawak, ni, applikasi, sudah, jadi, aplikasi, ...
# 1296    [aplikasi, kurang, berkualitastidak, ada, beda...
# 1297    [terburuk, dari, semua, aplikasi, penjualan, y...
# 1298    [biaya, ongkir, kurangin, jangan, terlalu, mah...
# 1299    [belanja, di, sini, belum, pernah, ada, kekece...
# Name: Ulasan_tokenize, Length: 1300, dtype: object>

# %%
slank_word_dict = {
    "paraah" : "parah",
    "keduakali" : "",
    "keduakali" : "kedua kali",
    "agak" : "sedikit",
    "pas" : "saat",
    "produkx" : "produknya",
    "sukamkasih" : "suka makasih",
    "gak" : "tidak",
    "cpt" : "cepat",
    "sdh" : "sudah",
    "recommend" : "rekomendasi",
    "bagusseller" : "bagus",
    "bagusssss" : "bagus",
    "bagussssss" : "bagus",
    "baguuussss" : "bagus",
    "cepatmakasih": "cepat",
    "cepatmantappp": "cepat",
    "cepatproduct": "cepat",
    "cepatrecomended": "cepat",
    "cepattoko": "cepat",
    "recomended": "rekomendasi",
    "recommended": "rekomendasi",
    "rekomendasi": "rekomendasi",
    "rekomended": "rekomendasi",
    }

def slank_normalized_term(document):
    return [slank_word_dict[term] if term in slank_word_dict else term for term in document]

# %%
normalizad_word = pd.read_csv("/content/kamusindonesia.csv.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

# %%
name_dataframe['Ulasan_normalized'] = name_dataframe['Ulasan_tokenize'].apply(normalized_term).apply(slank_normalized_term)

# %%
name_dataframe
# Out:
#                        Nama pengguna  Rating                Date  \
# 0                      Ryan Apriandi       1 2023-01-05 15:39:31
# 1                              Aya 4       3 2023-01-17 01:15:20
# 2                              Ranie       1 2023-01-13 02:11:50
# 3                    Fajron Musayyab       2 2023-01-11 23:20:18
# 4           Agroprobiotik Jawa Barat       2 2022-12-30 03:49:00
# ...                              ...     ...                 ...
# 1295                      FST GAMING       1 2022-09-14 18:24:38
# 1296                 Pengguna Google       1 2018-12-24 06:15:22
# 1297  Antonius Andika Riski Setiawan       1 2022-08-10 08:46:22
# 1298                    sarip kedung       3 2022-10-14 21:18:02
# 1299     Stefanus Ananda Sapta Putra       5 2022-08-31 09:29:58
#
#                                                  Ulasan  \
# 0     aplikasi parah saya belanja dengan cc pilih kl...
# 1     bagus sih cuman skrg ribet krn sering kali min...
# 2     setelah  thn ga buka akun bl barusan saya buka...
# 3     maaf saya kasih bintang   karena untuk layanan...
# 4     sy kesulitan ingin komplen masalah pembayaran ...
# ...                                                 ...
# 1295  lawak ni applikasi sudah jadi aplikasi underra...
# 1296  aplikasi kurang berkualitastidak ada bedanya d...
# 1297  terburuk dari semua aplikasi penjualan yang pe...
# 1298  biaya ongkir kurangin jangan terlalu mahalbany...
# 1299  belanja di sini belum pernah ada kekecewaan ka...
#
#                                         Ulasan_tokenize  \
# 0     [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1     [bagus, sih, cuman, skrg, ribet, krn, sering, ...
# 2     [setelah, thn, ga, buka, akun, bl, barusan, sa...
# 3     [maaf, saya, kasih, bintang, karena, untuk, la...
# 4     [sy, kesulitan, ingin, komplen, masalah, pemba...
# ...                                                 ...
# 1295  [lawak, ni, applikasi, sudah, jadi, aplikasi, ...
# 1296  [aplikasi, kurang, berkualitastidak, ada, beda...
# 1297  [terburuk, dari, semua, aplikasi, penjualan, y...
# 1298  [biaya, ongkir, kurangin, jangan, terlalu, mah...
# 1299  [belanja, di, sini, belum, pernah, ada, kekece...
#
#                                       Ulasan_normalized
# 0     [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1     [bagus, sih, cuman, sekarang, ribet, karena, s...
# 2     [setelah, tahun, enggak, buka, akun, bl, barus...
# 3     [maaf, saya, kasih, bintang, karena, untuk, la...
# 4     [saya, kesulitan, ingin, komplen, masalah, pem...
# ...                                                 ...
# 1295  [lawak, ini, aplikasi, sudah, jadi, aplikasi, ...
# 1296  [aplikasi, kurang, berkualitastidak, ada, beda...
# 1297  [terburuk, dari, semua, aplikasi, penjualan, y...
# 1298  [biaya, ongkir, kurangi, jangan, terlalu, maha...
# 1299  [belanja, di, sini, belum, pernah, ada, kekece...
#
# [1300 rows x 6 columns]

# %%
name_dataframe['Ulasan_normalized'].unique
# Out:
# <bound method Series.unique of 0       [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1       [bagus, sih, cuman, sekarang, ribet, karena, s...
# 2       [setelah, tahun, enggak, buka, akun, bl, barus...
# 3       [maaf, saya, kasih, bintang, karena, untuk, la...
# 4       [saya, kesulitan, ingin, komplen, masalah, pem...
#                               ...
# 1295    [lawak, ini, aplikasi, sudah, jadi, aplikasi, ...
# 1296    [aplikasi, kurang, berkualitastidak, ada, beda...
# 1297    [terburuk, dari, semua, aplikasi, penjualan, y...
# 1298    [biaya, ongkir, kurangi, jangan, terlalu, maha...
# 1299    [belanja, di, sini, belum, pernah, ada, kekece...
# Name: Ulasan_normalized, Length: 1300, dtype: object>

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

name_dataframe['Ulasan_stop_removed'] = name_dataframe['Ulasan_normalized'].apply(stopwords_removal)

# %%
name_dataframe
# Out:
#                        Nama pengguna  Rating                Date  \
# 0                      Ryan Apriandi       1 2023-01-05 15:39:31
# 1                              Aya 4       3 2023-01-17 01:15:20
# 2                              Ranie       1 2023-01-13 02:11:50
# 3                    Fajron Musayyab       2 2023-01-11 23:20:18
# 4           Agroprobiotik Jawa Barat       2 2022-12-30 03:49:00
# ...                              ...     ...                 ...
# 1295                      FST GAMING       1 2022-09-14 18:24:38
# 1296                 Pengguna Google       1 2018-12-24 06:15:22
# 1297  Antonius Andika Riski Setiawan       1 2022-08-10 08:46:22
# 1298                    sarip kedung       3 2022-10-14 21:18:02
# 1299     Stefanus Ananda Sapta Putra       5 2022-08-31 09:29:58
#
#                                                  Ulasan  \
# 0     aplikasi parah saya belanja dengan cc pilih kl...
# 1     bagus sih cuman skrg ribet krn sering kali min...
# 2     setelah  thn ga buka akun bl barusan saya buka...
# 3     maaf saya kasih bintang   karena untuk layanan...
# 4     sy kesulitan ingin komplen masalah pembayaran ...
# ...                                                 ...
# 1295  lawak ni applikasi sudah jadi aplikasi underra...
# 1296  aplikasi kurang berkualitastidak ada bedanya d...
# 1297  terburuk dari semua aplikasi penjualan yang pe...
# 1298  biaya ongkir kurangin jangan terlalu mahalbany...
# 1299  belanja di sini belum pernah ada kekecewaan ka...
#
#                                         Ulasan_tokenize  \
# 0     [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1     [bagus, sih, cuman, skrg, ribet, krn, sering, ...
# 2     [setelah, thn, ga, buka, akun, bl, barusan, sa...
# 3     [maaf, saya, kasih, bintang, karena, untuk, la...
# 4     [sy, kesulitan, ingin, komplen, masalah, pemba...
# ...                                                 ...
# 1295  [lawak, ni, applikasi, sudah, jadi, aplikasi, ...
# 1296  [aplikasi, kurang, berkualitastidak, ada, beda...
# 1297  [terburuk, dari, semua, aplikasi, penjualan, y...
# 1298  [biaya, ongkir, kurangin, jangan, terlalu, mah...
# 1299  [belanja, di, sini, belum, pernah, ada, kekece...
#
#                                       Ulasan_normalized  \
# 0     [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1     [bagus, sih, cuman, sekarang, ribet, karena, s...
# 2     [setelah, tahun, enggak, buka, akun, bl, barus...
# 3     [maaf, saya, kasih, bintang, karena, untuk, la...
# 4     [saya, kesulitan, ingin, komplen, masalah, pem...
# ...                                                 ...
# 1295  [lawak, ini, aplikasi, sudah, jadi, aplikasi, ...
# 1296  [aplikasi, kurang, berkualitastidak, ada, beda...
# 1297  [terburuk, dari, semua, aplikasi, penjualan, y...
# 1298  [biaya, ongkir, kurangi, jangan, terlalu, maha...
# 1299  [belanja, di, sini, belum, pernah, ada, kekece...
#
#                                     Ulasan_stop_removed
# 0     [aplikasi, parah, belanja, cc, pilih, klik, ci...
# 1     [bagus, sih, cuman, ribet, kali, update, aplik...
# 2     [buka, akun, bl, barusan, buka, ceritanya, bar...
# 3     [maaf, kasih, bintang, layanan, customer, meng...
# 4     [kesulitan, komplen, pembayaran, paylater, no,...
# ...                                                 ...
# 1295  [lawak, aplikasi, aplikasi, underratedmasih, k...
# 1296  [aplikasi, berkualitastidak, bedanya, aplikasi...
# 1297  [terburuk, aplikasi, penjualan, akun, bekukan,...
# 1298  [biaya, ongkir, kurangi, mahalbanyakin, promo,...
# 1299  [belanja, kekecewaan, kalopun, salah, kirim, b...
#
# [1300 rows x 7 columns]

# %%
pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 KB 6.5 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting swifter
#   Downloading swifter-1.3.4.tar.gz (830 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 830.9/830.9 KB 13.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from swifter) (1.3.5)
# Collecting psutil>=5.6.6
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 KB 26.9 MB/s eta 0:00:00
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.8/dist-packages (from swifter) (2022.2.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.8/dist-packages (from swifter) (4.64.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.8/dist-packages (from swifter) (7.7.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from swifter) (2.2.0)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.8/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.8/dist-packages (from swifter) (5.0.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from bleach>=3.1.1->swifter) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2022.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from dask[dataframe]>=2.10.0->swifter) (21.3)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.8/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.8/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.3.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.8/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.21.6)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets>=7.0.0->swifter) (5.7.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets>=7.0.0->swifter) (3.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets>=7.0.0->swifter) (5.3.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets>=7.0.0->swifter) (7.9.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->swifter) (2022.7)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.0.4)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1.12)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.0.10)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.0 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->dask[dataframe]>=2.10.0->swifter) (3.0.9)
# Requirement already satisfied: locket in /usr/local/lib/python3.8/dist-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.7.16)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.1.3)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.15.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.7.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (23.2.1)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.6.1)
# Requirement already satisfied: jinja2<=3.0.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.11.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.13.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2<=3.0.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core>=4.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.6.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.16.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (22.2.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.10.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.11.0)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.3.4-py3-none-any.whl size=16321 sha256=d68dfe90e7226db7c36a1b5b30f3c8503e54b5af0f7c06dfd90c0da89d1e6efc
#   Stored in directory: /root/.cache/pip/wheels/08/66/b4/921e351e63d88696932279d6163e125727c9da70ed8ca38419
# Successfully built swifter
# Installing collected packages: psutil, jedi, swifter
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# Successfully installed jedi-0.18.2 psutil-5.9.4 swifter-1.3.4

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in name_dataframe['Ulasan_stop_removed']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

name_dataframe['Ulasan_Stemmed'] = name_dataframe['Ulasan_stop_removed'].swifter.apply(get_stemmed_term)
# Out:
# 4416
# ------------------------
# aplikasi : aplikasi
# parah : parah
# belanja : belanja
# cc : cc
# pilih : pilih
# klik : klik
# cicilan : cicil
# tertagih : tagih
# full : full
# confirmasi : confirmasi
# urus : urus
# teman : teman
# metode : metode
# korban : korban
# kabar : kabar
# bukalapak : bukalapak
# bagus : bagus
# sih : sih
# cuman : cuman
# ribet : ribet
# kali : kali
# update : update
# aplikasinya : aplikasi
# susah : susah
# bertransaksi : transaksi
# hp : hp
# memorinya : memori
# terbatas : batas
# hapus : hapus
# terpaksa : paksa
# buka : buka
# akun : akun
# bl : bl
# barusan : barusan
# ceritanya : cerita
# barang : barang
# dibeli : beli
# harapan : harap
# dibl : dibl
# murah : murah
# promo : promo
# menarik : tarik
# dijual : jual
# lengkap : lengkap
# sekalinya : sekali
# pilihan : pilih
# seller : seller
# akibatnya : akibat
# mahal : mahal
# marketplace : marketplace
# sebelah : belah
# disaat : saat
# voucher : voucher
# gratis : gratis
# ongkir : ongkir
# mengasih : asih
# diskon : diskon
# nya : nya
# instan : instan
# maaf : maaf
# kasih : kasih
# bintang : bintang
# layanan : layan
# customer : customer
# mengajukan : aju
# pesan : pesan
# custom : custom
# bebas : bebas
# sesuai : sesuai
# kalimat : kalimat
# sehari : hari
# pembeli : beli
# terkesan : kes
# baku : baku
# aturan : atur
# toko : toko
# hijau : hijau
# orange : orange
# harapannya : harap
# tolong : tolong
# dimudahkan : mudah
# fitur : fitur
# chat : chat
# bantuan : bantu
# terimakasih : terimakasih
# kesulitan : sulit
# komplen : komplen
# pembayaran : bayar
# paylater : paylater
# no : no
# watelpon : watelpon
# aktif : aktif
# membingunkan : membingunkan
# masuk : masuk
# penjual : jual
# nyaman : nyaman
# konfirmasi : konfirmasi
# pesanan : pesan
# terima : terima
# batalkan : batal
# kemauan : mau
# batal : batal
# otomasi : otomasi
# kerlambatan : kerlambatan
# pengiriman : kirim
# lakh : lakh
# feedback : feedback
# negatif : negatif
# kesalahan : salah
# pembelinya : bel
# plin : plin
# plan : plan
# kirim : kirim
# eh : eh
# star : star
# bagusmalah : bagusmalah
# menurunupdate : menurunupdate
# terbaru : baru
# berpengaruhhapus : berpengaruhhapus
# cacheclear : cacheclear
# datasama : datasama
# ajaaplikasi : ajaaplikasi
# berat : berat
# loadingnya : loadingnya
# menonton : tonton
# streaming : streaming
# hd : hd
# lancar : lancar
# jaya : jaya
# live : live
# penipuan : tipu
# kontak : kontak
# cs : cs
# hubungi : hubung
# konsumen : konsumen
# aman : aman
# cari : cari
# solusi : solusi
# kendala : kendala
# dipersulit : sulit
# kayak : kayak
# proses : proses
# batas : batas
# maksimal : maksimal
# dana : dana
# mengecewakan : kecewa
# pengguna : guna
# lumayan : lumayan
# transaksi : transaksi
# riwayat : riwayat
# status : status
# updatenya : updatenya
# telat : telat
# mulu : mulu
# pelapak : lapak
# mengirimkan : kirim
# sore : sore
# pickup : pickup
# pisan : pis
# pesanannya : pesan
# tambahan : tambah
# bukti : bukti
# gambarfoto : gambarfoto
# ditujuan : tuju
# barangpesanan : barangpesanan
# diterima : terima
# masukan : masuk
# bual : bual
# cepat : cepat
# kembalikan : kembali
# langsung : langsung
# orang : orang
# awam : awam
# bingung : bingung
# csnya : csnya
# ramah : ramah
# melayani : layan
# pelanggan : langgan
# terkait : kait
# pengembalian : kembali
# mengalami : alami
# responnya : responnya
# positif : positif
# sesi : sesi
# koneksi : koneksi
# diputus : putus
# pertimbangannya : timbang
# tutup : tutup
# suka : suka
# pakai : pakai
# buatan : buat
# anak : anak
# bangsa : bangsa
# training : training
# kompeten : kompeten
# minimal : minimal
# sikap : sikap
# bobrok : bobrok
# pemesanan : mesan
# cod : cod
# tagihan : tagih
# detailnya : detail
# tersedia : sedia
# pembatalan : batal
# dipesan : pes
# kosong : kosong
# batalin : batalin
# bertul : bertul
# emah : emah
# kondisi : kondisi
# lapangan : lapang
# menghubungi : hubung
# loading : loading
# menunggu : tunggu
# respon : respon
# nenguntungkan : nenguntungkan
# membatalkan : batal
# buyer : buyer
# butuh : butuh
# persetujuan : tuju
# hatihati : hatihati
# kalo : kalo
# cermat : cermat
# tertipu : tipu
# menguntungkan : untung
# mencari : cari
# susahnya : susah
# ampun : ampun
# pencarian : cari
# aga : aga
# ketik : ketik
# merk : merk
# nongol : nongol
# perlengkapan : lengkap
# history : history
# ongkirnya : ongkirnya
# mnrt : mnrt
# segi : segi
# postingan : postingan
# jual : jual
# lazada : lazada
# oke : oke
# diskonnya : diskon
# kena : kena
# tipu : tipu
# lapak : lapak
# foto : foto
# produk : produk
# hilang : hilang
# tinggal : tinggal
# bukabantuan : bukabantuan
# tanggapanapa : tanggapanapa
# karyawannya : karyawannya
# kesini : kesini
# turunkan : turun
# bintangnyakarena : bintangnyakarena
# memakai : pakai
# paylaternya : paylaternya
# setujui : tuju
# alasan : alas
# coba : coba
# cek : cek
# sayaudh : sayaudh
# terhitung : hitung
# sayasaya : sayasaya
# naikin : naikin
# bintangnya : bintang
# recom : recom
# edit : edit
# ulasannya : ulas
# care : care
# alhamdulillah : alhamdulillah
# selesai : selesai
# bukasend : bukasend
# terkadang : terkadang
# trouble : trouble
# mohon : mohon
# diperbaiki : baik
# minim : minim
# itupun : itu
# potongan : potong
# akses : akses
# berlaku : laku
# serius : serius
# pembelian : beli
# costumer : costumer
# heran : heran
# buruk : buruk
# tampil : tampil
# dasboard : dasboard
# ribuan : ribu
# kriteria : kriteria
# beli : beli
# terkonfirmasi : konfirmasi
# menghasilkan : hasil
# penjualan : jual
# online : online
# bermutu : mutu
# namanya : nama
# usaha : usaha
# mendukung : dukung
# pedagang : dagang
# mempermudah : mudah
# pertahankan : tahan
# perekonomian : ekonomi
# bertahan : tahan
# sarankan : saran
# apk : apk
# ya : ya
# salam : salam
# sukses : sukses
# kecewa : kecewa
# perubahan : ubah
# diproses : proses
# terkirim : kirim
# detik : detik
# berubah : ubah
# payah : payah
# hasil : hasil
# laporan : lapor
# tunggu : tunggu
# jam : jam
# mengirim : kirim
# kota : kota
# cancel : cancel
# setuju : tuju
# refund : refund
# dananya : dana
# berkali : kali
# dicoba : coba
# ditunggu : tunggu
# terhubung : hubung
# shopee : shopee
# menit : menit
# masalahbaik : masalahbaik
# pembelikurir : pembelikurir
# komplain : komplain
# kepihak : pihak
# menyelesaikannyabeberapa : menyelesaikannyabeberapa
# pelayanannya : layan
# bagusknp : bagusknp
# ganti : ganti
# ratingnya : ratingnya
# turunin : turunin
# puluhan : puluh
# mitra : mitra
# dikasih : kasih
# kepercayaan : percaya
# paylatter : paylatter
# pinjaman : pinjam
# resi : resi
# cetak : cetak
# alamat : alamat
# tujuan : tuju
# salah : salah
# menarikpromo : menarikpromo
# menariksaya : menariksaya
# nabung : nabung
# danatapi : danatapi
# dipakai : pakai
# dngn : dngn
# paylaterpadahal : paylaterpadahal
# paylaterkan : paylaterkan
# ajaritu : ajaritu
# pemaksaandi : pemaksaandi
# letak : letak
# profesionalitasnyamau : profesionalitasnyamau
# fiturnya : fiturnya
# mengertitolong : mengertitolong
# perbaiki : baik
# sistem : sistem
# ajabanyak : ajabanyak
# sisrem : sisrem
# gunabuka : gunabuka
# kaya : kaya
# game : game
# ajaisi : ajaisi
# harap : harap
# buang : buang
# ajadan : ajadan
# bagusmasuk : bagusmasuk
# ribetnya : ribetnya
# token : token
# listrik : listrik
# nominal : nominal
# ribu : ribu
# pembayarannya : bayar
# terbayar : bayar
# pusat : pusat
# hubungiaktifpercuma : hubungiaktifpercuma
# aneh : aneh
# pembaruan : baru
# warna : warna
# ukuran : ukur
# banget : banget
# topup : topup
# pulsa : pulsa
# telkomsel : telkomsel
# terkuras : kuras
# dirugikan : rugi
# membantu : bantu
# minimnya : minim
# voucer : voucer
# enggan : enggan
# virtual : virtual
# gagal : gagal
# kebelakang : belakang
# hiasan : hias
# pengin : pengin
# robot : robot
# nomer : nomer
# twitter : twitter
# ditiadakan : tiada
# fb : fb
# tipenya : tipe
# yag : yag
# pinalty : pinalty
# posting : posting
# jualan : jual
# dibatasi : batas
# dimunculkan : muncul
# ditemukan : temu
# disarankan : saran
# berbayar : bayar
# muncul : muncul
# lamaaaaa : lamaaaaa
# ditambah : tambah
# lamaa : lamaa
# ekspedisi : ekspedisi
# ekspresaseem : ekspresaseem
# merugikan : rugi
# kamis : kamis
# jumat : jumat
# sabtu : sabtu
# hmmmmm : hmmmmm
# buktinya : bukti
# silakan : sila
# email : email
# gue : gue
# mengadaada : mengadaada
# deh : deh
# bro : bro
# diperbaikilah : baik
# saran : saran
# expedisi : expedisi
# kurir : kurir
# reg : reg
# next : next
# day : day
# bukaexpress : bukaexpress
# sicepat : sicepat
# error : error
# pick : pick
# up : up
# lelet : lelet
# criss : criss
# cross : cross
# sop : sop
# ybs : ybs
# semoga : moga
# kedepan : depan
# bismillahbarangnya : bismillahbarangnya
# bermanfaat : manfaat
# berbelanja : belanja
# berjualan : jual
# beramal : amal
# amin : amin
# kredivo : kredivo
# urusan : urus
# kayanya : kaya
# mending : mending
# uninstall : uninstall
# ajalah : aja
# enak : enak
# instal : instal
# analis : analis
# kepinteran : kepinteran
# lulusan : lulus
# wkwkwk : wkwkwk
# kekurangan : kurang
# opsi : opsi
# habis : habis
# kadang : kadang
# pikiran : pikir
# ulang : ulang
# kecepatan : cepat
# pelayanan : layan
# service : service
# pencairan : cair
# uang : uang
# nilai : nilai
# lambat : lambat
# hitungannya : hitung
# berjamjam : berjamjam
# tau : tau
# lemah : lemah
# sengaja : sengaja
# keyword : keyword
# luas : luas
# peningkatan : tingkat
# diakses : akses
# signifikanmudahan : signifikanmudahan
# menjaga : jaga
# konsumennya : konsumen
# good : good
# prima : prima
# ketemu : ketemu
# abalabal : abalabal
# disengaja : sengaja
# cenderung : cenderung
# menipu : tipu
# diseleksi : seleksi
# penjualnya : jual
# berguna : guna
# membayar : bayar
# terverifikasi : verifikasi
# chatnya : chatnya
# bermasalah : masalah
# hati : hati
# siapsiap : siapsiap
# saldo : saldo
# terpotong : potong
# rekomendasi : rekomendasi
# reksadana : reksadana
# samapai : samapai
# kadaluwarsa : kadaluwarsa
# berbelit : belit
# belit : belit
# agen : agen
# dapatnya : dapat
# mesti : mesti
# mengantri : antri
# stay : stay
# page : page
# dibatalin : dibatalin
# antrian : antri
# terbaik : baik
# terpercaya : percaya
# pengalaman : alam
# tabungannya : tabung
# vouchernya : vouchernya
# menu : menu
# dikembalikan : kembali
# dasar : dasar
# penipu : tipu
# bikin : bikin
# laku : laku
# nipu : nipu
# beda : beda
# kudu : kudu
# goceng : goceng
# minggu : minggu
# kejelasan : jelas
# paket : paket
# tawaran : tawar
# suruh : suruh
# tindak : tindak
# mencairkan : cair
# persulit : sulit
# tibatiba : tibatiba
# bukadompet : bukadompet
# dibekukan : beku
# nyangkut : nyangkut
# mengikuti : ikut
# langkah : langkah
# poto : poto
# buku : buku
# rekening : rekening
# ktp : ktp
# dikirim : kirim
# telpon : telpon
# benarbenar : benarbenar
# tiket : tiket
# menemani : tani
# perjalanan : jalan
# uiux : uiux
# rapi : rapi
# fleksibel : fleksibel
# orderan : order
# rumah : rumah
# kedepannya : depan
# jos : jos
# diragukan : ragu
# simple : simple
# gamblangbaik : gamblangbaik
# cashcod : cashcod
# bayar : bayar
# dibelakangan : belakang
# mantap : mantap
# wes : wes
# berjalan : jalan
# mencet : mencet
# tombol : tombol
# close : close
# penawaran : tawar
# kepencet : pencet
# disiniisi : disiniisi
# tokonya : toko
# semuasaya : semuasaya
# lepas : lepas
# tangan : tangan
# limit : limit
# akulakutapi : akulakutapi
# tagihansaya : tagihansaya
# tanganini : tanganini
# lucupelanggannya : lucupelanggannya
# disuruh : suruh
# perwakilan : wakil
# kerumah : rumah
# disembunyikan : sembunyi
# untum : untum
# menghadapi : hadap
# protes : protes
# sebentar : sebentar
# menghilang : hilang
# tipikal : tipikal
# bodo : bodo
# yanh : yanh
# verifikasi : verifikasi
# link : link
# lucu : lucu
# lengkapbnyk : lengkapbnyk
# promopilihan : promopilihan
# pembayarandan : pembayarandan
# vouchersemog : vouchersemog
# favorit : favorit
# lagigratis : lagigratis
# adaflash : adaflash
# deal : deal
# menarikdan : menarikdan
# mengandalkan : andal
# serbu : serbu
# seruyang : seruyang
# peluang : peluang
# menang : menang
# juta : juta
# banding : banding
# bukalapaktpi : bukalapaktpi
# amati : amat
# intinya : inti
# harga : harga
# ngluarin : ngluarin
# vouchermending : vouchermending
# lazadashopee : lazadashopee
# bahasa : bahasa
# marketing : marketing
# langgananku : langgan
# favoritku : favorit
# barangnya : barang
# harganya : harga
# dibilang : bilang
# puas : puas
# pokoknya : pokok
# is : is
# the : the
# best : best
# buatku : buat
# lengkapbagus : lengkapbagus
# penuh : penuh
# discount : discount
# vocher : vocher
# terpakai : pakai
# oknum : oknum
# mengatas : atas
# namakan : nama
# jalan : jalan
# merekomendasikan : rekomendasi
# dibayar : bayar
# partner : partner
# terkendala : kendala
# situ : situ
# berulang : ulang
# matikan : mati
# sayang : sayang
# macet : macet
# free : free
# berbelitbelit : berbelitbelit
# trik : trik
# cekout : cekout
# vocer : vocer
# anu : anu
# jenis : jenis
# ogah : ogah
# gangguan : ganggu
# pembayaranya : pembayaranya
# arror : arror
# lapor : lapor
# mas : mas
# kemarin : kemarin
# tanggal : tanggal
# payleter : payleter
# mbangking : mbangking
# baca : baca
# berhasil : hasil
# kepotong : potong
# sinyal : sinyal
# jelek : jelek
# muter : muter
# cencel : cencel
# mutasi : mutasi
# hubungin : hubungin
# whatapps : whatapps
# sukai : suka
# ambil : ambil
# ditempat : tempat
# hemat : hemat
# and : and
# keep : keep
# fighting : fighting
# ok : ok
# nih : nih
# complain : complain
# berdebat : debat
# maju : maju
# diklik : klik
# selebihnya : lebih
# dihubungi : hubung
# boncos : boncos
# promonya : promonya
# honest : honest
# review : review
# keren : keren
# gampang : gampang
# sulitnya : sulit
# mati : mati
# kagak : kagak
# kpake : kpake
# manfaat : manfaat
# planggan : planggan
# aktipin : aktipin
# printer : printer
# terima kasih : terima kasih
# lengkapi : lengkap
# detail : detail
# barangpadahal : barangpadahal
# lemot : lot
# ngelag : ngelag
# ditangan : tang
# statusnya : status
# kesian : kesi
# sellernya : sellernya
# praktisgk : praktisgk
# ribetnamun : ribetnamun
# unsur : unsur
# adakalo : adakalo
# paketnya : paket
# dibuka : buka
# kurirnyaterutama : kurirnyaterutama
# order : order
# blanja : blanja
# app : app
# detil : detil
# tingkat : tingkat
# profesional : profesional
# lacak : lacak
# nyauntuk : nyauntuk
# melunasi : lunas
# jatuh : jatuh
# tempo : tempo
# sebulan : bulan
# koplain : koplain
# putuskan : putus
# berlangganan : langgan
# setan : setan
# daftar : daftar
# nik : nik
# terbaca : baca
# kakak : kakak
# apikasi : apikasi
# perbankan : perban
# apaapa : apaapa
# admin : admin
# parahhhh : parahhhh
# lihat : lihat
# hantu : hantu
# via : via
# pc : pc
# mobile : mobile
# alhamdulillahnya : alhamdulillah
# transfer : transfer
# pembatasan : batas
# menanggapi : tanggap
# adakah : ada
# biaya : biaya
# unuk : unuk
# menelpon : telpon
# seharus : harus
# diselesaikan : selesai
# hitungan : hitung
# akhirmya : akhirmya
# kadaluarsa : kadaluarsa
# dilampirkan : lampir
# penilaian : nilai
# gambar : gambar
# bajakan : baja
# anjeng : anjeng
# web : web
# modal : modal
# putar : putar
# bukapak : bukapak
# modalnya : modal
# gede : gede
# bos : bos
# bukalapakbangkrut : bukalapakbangkrut
# errorresi : errorresi
# jne : jne
# trucking : trucking
# otomatismau : otomatismau
# adaga : adaga
# bisalive : bisalive
# berfungsi : fungsi
# pergunakan : guna
# alhasil : alhasil
# telfon : telfon
# untjk : untjk
# kemana : mana
# otomatis : otomatis
# berhari : hari
# tolonglah : tolong
# pegawai : pegawai
# makan : makan
# batu : batu
# nasi : nasi
# biar : biar
# kerja : kerja
# memenuhi : penuh
# sarat : sarat
# beralih : alih
# tatanan : tatanan
# friendly : friendly
# menurutku : turut
# lainlainnya : lainlainnya
# tingkatkan : tingkat
# jahat : jahat
# penanganan : tangan
# keterangannya : terang
# melampirkan : lampir
# bilang : bilang
# ditangani : tangan
# dampaknya : dampak
# beribas : beribas
# terkena : kena
# keterlambatan : lambat
# jshat : jshat
# sumpah : sumpah
# tegaaaa : tegaaaa
# durasi : durasi
# alami : alami
# stock : stock
# merespon : merespon
# dirubah : rubah
# diganti : ganti
# realtime : realtime
# terselesaikan : selesai
# dimana : mana
# infonya : info
# buruburu : buruburu
# syarat : syarat
# ditinggal : tinggal
# bentar : bentar
# pergi : pergi
# disitu : situ
# hey : hey
# data : data
# ss : ss
# apalah : apa
# dicarikan : cari
# kabur : kabur
# diperbarui : baru
# estimasi : estimasi
# segitu : segitu
# habisrefund : habisrefund
# rugi : rugi
# mengembalikan : kembali
# lupa : lupa
# password : password
# tabungan : tabung
# yth : yth
# pt : pt
# prakerja : prakerja
# kode : kode
# kupon : kupon
# pelatihan : latih
# akal : akal
# sebelumsebelumnya : sebelumsebelumnya
# tim : tim
# langganan : langgan
# tokennya : tokennya
# commerce : commerce
# terparah : parah
# tulisan : tulis
# muat : muat
# jaringan : jaring
# stabil : stabil
# bego : bego
# gara : gara
# denda : denda
# taih : taih
# sellerseller : sellerseller
# doang : doang
# katalog : katalog
# keterangan : terang
# histori : histori
# jasa : jasa
# bernomor : nomor
# stuk : stuk
# dibalikin : dibalikin
# dianggap : anggap
# item : item
# tampilan : tampil
# memasukkan : masuk
# nama : nama
# url : url
# kerjaangak : kerjaangak
# mengerti : erti
# syulit : syulit
# halo : halo
# min : min
# playlater : playlater
# loh : loh
# syaa : syaa
# telepon : telepon
# tlng : tlng
# solusinya : solusi
# ta : ta
# soale : soale
# kesel : kesel
# iya : iya
# download : download
# tertera : tera
# pertahanin : pertahanin
# menggiurkan : giur
# embel : embel
# aslinya : asli
# kak : kak
# account : account
# keteragan : agan
# sungguh : sungguh
# konsisten : konsisten
# penerapan : terap
# system : system
# diberlakukan : laku
# rubah : rubah
# retur : retur
# dihentikan : henti
# dibukalapak : dibukalapak
# tegaskan : tegas
# mendapati : dapat
# pelanggaran : langgar
# tokomuakunmu : tokomuakunmu
# dinonaktifkan : nonaktif
# bukalapakbukalapakpaylater : bukalapakbukalapakpaylater
# fitue : fitue
# bukalapakpaylater : bukalapakpaylater
# normal : normal
# gajih : gajih
# turun : turun
# kebutuhan : butuh
# bekukan : beku
# amanan : aman
# bot : bot
# pokok : pokok
# woiii : woiii
# gua : gua
# november : november
# bayarkan : bayar
# memegang : pegang
# nomor : nomor
# tlpn : tlpn
# nomornya : nomor
# sengsara : sengsara
# lu : lu
# pengirimana : pengirimana
# reguler : reguler
# senin : senin
# call : call
# center : center
# media : media
# bertemunya : temu
# dangan : dang
# varian : varian
# kompetetif : kompetetif
# melindungi : lindung
# keamanan : aman
# komplin : komplin
# menghindari : hindar
# tindakan : tindak
# prestasinya : prestasi
# sulit : sulit
# masalh : masalh
# oren : oren
# seperi : per
# mempersulit : sulit
# danauang : danauang
# tanggapan : tanggap
# memuaskan : muas
# hasilnya : hasil
# koo : koo
# akomodatif : akomodatif
# siihmaaaana : siihmaaaana
# doangngeklaim : doangngeklaim
# laaagini : laaagini
# kolom : kolom
# direspon : direspon
# gimanabeneran : gimanabeneran
# artikel : artikel
# tata : tata
# valid : valid
# waktunyaudah : waktunyaudah
# blga : blga
# blapa : blapa
# melaporkan : lapor
# bertanggung : tanggung
# jawabga : jawabga
# dlutolong : dlutolong
# bantuanya : bantuanya
# malas : malas
# menggunakannya : guna
# lainya : lai
# ringan : ringan
# cepatlama : cepatlama
# memilih : pilih
# digagalkan : gagal
# emailnya : email
# padahalan : padahal
# otp : otp
# tulis : tulis
# spam : spam
# mengapai : kapai
# isi : isi
# tokenya : toke
# apesnya : apes
# terlanjur : lanjur
# kunjung : kunjung
# dibatalkan : batal
# bye : bye
# recomded : recomded
# brengseksangat : brengseksangat
# menjengkelkantiap : menjengkelkantiap
# login : login
# ubah : ubah
# bisaaplikasi : bisaaplikasi
# duniasudah : duniasudah
# pribadi : pribadi
# teleponaplikasi : teleponaplikasi
# berengsek : berengsek
# pelacakan : lacak
# efectif : efectif
# notipikasi : notipikasi
# barangnggak : barangnggak
# lainyabegitu : lainyabegitu
# keberadaan : ada
# barangmohon : barangmohon
# permudah : mudah
# ku : ku
# temui : temu
# mengadakan : ada
# event : event
# mengundang : undang
# miskin : miskin
# mmbayar : mmbayar
# perpersulit : sulit
# suksesko : suksesko
# kadaluarsalimit : kadaluarsalimit
# tida : tida
# bertambahuang : bertambahuang
# hangus : hangus
# kembalikomplen : kembalikomplen
# bantua : bantua
# sekalimohon : sekalimohon
# bayarkarna : bayarkarna
# bayardan : bayardan
# kompirmasisekian : kompirmasisekian
# semog : semog
# versi : versi
# melacak : lacak
# bugs : bugs
# lahcuma : lahcuma
# paylatersllu : paylatersllu
# penagihkolektormasukannyaniat : penagihkolektormasukannyaniat
# lari : lari
# hutang : hutang
# disayangkan : sayang
# risih : risih
# dikala : kala
# sibuk : sibuk
# kantor : kantor
# kompalian : kompalian
# penangan : nang
# rugikan : rugi
# operasi : operasi
# anjir : anjir
# bukalapakdan : bukalapakdan
# ratusan : ratus
# bukalapaktapi : bukalapaktapi
# beginisaya : beginisaya
# datangdan : datangdan
# anetolong : anetolong
# ditindak : tindak
# nakal : nakal
# inijngn : inijngn
# berpindah : pindah
# secepat : cepat
# lanjutiii : lanjutiii
# rekan : rekan
# bayak : bayak
# penipuannya : tipu
# korbannya : korban
# membela : bela
# duit : duit
# lenyap : lenyap
# mencekik : cekik
# adminnya : adminnya
# pikir : pikir
# pengambilan : ambil
# byr : byr
# haram : haram
# tuh : tuh
# sjop : sjop
# membantuapalagi : membantuapalagi
# bukapaylater : bukapaylater
# nysangat : nysangat
# menyenangkan : senang
# komsumen : komsumen
# mengubungi : ubung
# abal : abal
# penerimaan : terima
# ditunjukan : tunjuk
# bukalapakknp : bukalapakknp
# ditampilkan : tampil
# akunya : aku
# ber : ber
# ekspektasi : ekspektasi
# dimenu : menu
# upload : upload
# form : form
# sampah : sampah
# ahirnya : ahirnya
# top : top
# banking : banking
# ajukan : aju
# menunya : menu
# layar : layar
# kedap : kedap
# kedip : kedip
# smax : smax
# giliran : gilir
# cairin : cairin
# atm : atm
# pagi : pagi
# tolol : tolol
# prosesnya : proses
# pemotongan : potong
# menjual : jual
# saingan : saing
# ketat : ketat
# transsaksi : transsaksi
# tipis : tipis
# untung : untung
# tetangga : tetangga
# upgrade : upgrade
# credit : credit
# cashback : cashback
# pemberitahuan : pemberitahuan
# bertambah : tambah
# sinibila : sinibila
# fikir : fikir
# dulukarena : dulukarena
# lamaitu : lamaitu
# denga : denga
# sebelaj : sebelaj
# fix : fix
# niat : niat
# asli : asli
# diterimaehh : diterimaehh
# menyambung : sambung
# slow : slow
# pengaduan : adu
# parahbukalapak : parahbukalapak
# percaya : percaya
# inigak : inigak
# uninstal : uninstal
# menyesal : sesal
# diskcoun : diskcoun
# daya : daya
# vocernya : vocernya
# ketentuannya : tentu
# nyaada : nyaada
# samasekaliuntuk : samasekaliuntuk
# ampunsuruh : ampunsuruh
# ngantrigiliran : ngantrigiliran
# keputussuruh : keputussuruh
# lagisaya : lagisaya
# magrib : magrib
# mencoba : coba
# bisamaaf : bisamaaf
# dikembangkan : kembang
# perkembangannya : kembang
# stok : stok
# variannya : varian
# dll : dll
# mintaa : mintaa
# udan : udan
# pindah : pindah
# ditanggapi : tanggap
# lempar : lempar
# pengirimannya : kirim
# jutaan : juta
# perbulan : bulan
# kuota : kuota
# volume : volume
# tambahkan : tambah
# kuotavolume : kuotavolume
# diskoncashback : diskoncashback
# kalah : kalah
# bersaing : saing
# tarik : tarik
# penjelasannya : jelas
# parahnya : parah
# lgh : lgh
# antri : antri
# berjam : jam
# ngbisin : ngbisin
# batre : batre
# gunakn : gunakn
# enggak bisa : enggak bisa
# teratasi : atas
# penyelesaian : selesai
# padahhal : padahhal
# pencet : pencet
# olshop : olshop
# sebalah : seba
# selesaikan : selesai
# tokenmudah : tokenmudah
# ditulis : tulis
# ditingkatkan : tingkat
# ijo : ijo
# trustiap : trustiap
# pusing : pusing
# kecewamasa : kecewamasa
# pakebuat : pakebuat
# untungnya : untung
# niisaya : niisaya
# mmbyara : mmbyara
# perbulannya : bulan
# mengatur : atur
# dc : dc
# shopie : shopie
# jarang : jarang
# trx : trx
# sekian : sekian
# pantesan : pantesan
# sepi : sepi
# tokped : tokped
# shoope : shoope
# kartu : kartu
# kredit : kredit
# rating : rating
# aplikasinyasaat : aplikasinyasaat
# pembayaranmasa : pembayaranmasa
# terusmuncul : terusmuncul
# teknis : teknis
# ngeleg : ngeleg
# disitusitu : disitusitu
# sgera : sgera
# nov : nov
# masukk : masukk
# membeli : beli
# cepattapi : cepattapi
# sayangnya : sayang
# penagihan : tagih
# japo : japo
# wuih : wuih
# mengganggu : ganggu
# bangetbikin : bangetbikin
# risisemoga : risisemoga
# sayaterima : sayaterima
# mengecek : ecek
# internet : internet
# mengakses : akses
# oranye : oranye
# mudah : mudah
# pengajuan : aju
# kepuasan : puas
# tersendiri : sendiri
# penggunanya : guna
# pengelolaan : kelola
# berkredibilitas : kredibilitas
# fast : fast
# peduli : peduli
# kesemuanya : semua
# penggunaan : guna
# smuanya : smuanya
# tergantung : gantung
# proaktif : proaktif
# informasi : informasi
# packing : packing
# va : va
# perhasil : hasil
# onlinesudah : onlinesudah
# seminggu : minggu
# btal : btal
# csnyabukalapak : csnyabukalapak
# pay : pay
# leternya : leter
# saldonya : saldo
# pemakai : pakai
# utuh : utuh
# aqw : aqw
# langanan : langanan
# setia : setia
# teranyar : anyar
# namana : namana
# dipertahankan : tahan
# dipantau : pantau
# dijadikan : jadi
# pertimbangan : timbang
# kenyamanan : nyaman
# bugnya : bugnya
# shopeepay : shopeepay
# later : later
# kwalitas : kwalitas
# auto : auto
# perhatian : perhati
# modus : modus
# lakukan : laku
# perlindungan : lindung
# konsumengak : konsumengak
# lainhapus : lainhapus
# hei : hei
# sadar : sadar
# notifikasi : notifikasi
# notifikasinya : notifikasi
# terbalik : balik
# maksud : maksud
# matanya : mata
# hah : hah
# enggak ada : enggak ada
# both : both
# menyelesaikan : selesai
# apapun : apa
# pelit : pelit
# langka : langka
# rp : rp
# kebawah : bawah
# tukang : tukang
# parkir : parkir
# receh : receh
# memanjakan : manja
# letter : letter
# prioritaskan : prioritas
# terpaku : terpa
# telefon : telefon
# negara : negara
# darurat : darurat
# musti : musti
# blanjaan : blanjaan
# programnya : program
# halupayah : halupayah
# ecommersnya : ecommersnya
# tampilannya : tampil
# mata : mata
# dibandingkan : banding
# sejenis : jenis
# pembayaranyauang : pembayaranyauang
# computerlaptop : computerlaptop
# nurulasysyifa : nurulasysyifa
# shop : shop
# keluarga : keluarga
# discountnya : discountnya
# awrtakan : awrtakan
# fotonya : foto
# paaaraaaahisi : paaaraaaahisi
# masukparah : masukparah
# reksa : reksa
# bursa : bursa
# cair : cair
# servis : servis
# final : final
# tercantum : cantum
# bantuannya : bantu
# real : real
# biru : biru
# cuek : cuek
# bebek : bebek
# dalamnya : dalam
# payleternya : payleternya
# pulsanya : pulsa
# anjrit : anjrit
# kapok : kapok
# kebanyakan : banyak
# bangkrut : bangkrut
# failet : failet
# ilegal : ilegal
# semenjak : semenjak
# bbm : bbm
# ih : ih
# jiji : jiji
# play : play
# store : store
# an : an
# servernya : servernya
# mah : mah
# lawan : lawan
# mudahaman : mudahaman
# berbelanjacuma : berbelanjacuma
# dpet : dpet
# memudahkan : mudah
# keuangan : uang
# pembukuan : buku
# diatur : atur
# thanks : thanks
# wuiiih : wuiiih
# mantab : mantab
# masukkan : masuk
# kedepanyya : kedepanyya
# akurat : akurat
# komplit : komplit
# menjengkelkan : jengkel
# alternatif : alternatif
# vs : vs
# kemunduran : mundur
# penjemputan : jemput
# diperbesar : besar
# tokopedia : tokopedia
# rbu : rbu
# kenaikan : naik
# naiknya : naik
# tarif : tarif
# mengeluarkan : keluar
# asuransi : asuransi
# bulshitt : bulshitt
# pasrah : pasrah
# beol : beol
# terjamin : jamin
# keamanannya : aman
# baguscustomer : baguscustomer
# masalahberjam : masalahberjam
# complaindimana : complaindimana
# halaman : halaman
# keluhan : keluh
# jozz : jozz
# iklan : iklan
# pintar : pintar
# waktupokoknya : waktupokoknya
# sopian : sopi
# username : username
# angkara : angkara
# vouchernyatidak : vouchernyatidak
# bukalaak : bukalaak
# menerima : terima
# terproses : proses
# terpotongapa : terpotongapa
# lagj : lagj
# disalahgunakan : disalahgunakan
# diaktifkan : aktif
# errorga : errorga
# nyamakin : nyamakin
# sayah : sayah
# pertahan : tahan
# berkembang : kembang
# dailygift : dailygift
# boxnya : boxnya
# semakinturun : semakinturun
# nilainyadr : nilainyadr
# ngacak : ngacak
# pointnyaini : pointnyaini
# samaterus : samaterus
# segitumasa : segitumasa
# applain : applain
# pendapatan : dapat
# pointnya : point
# meningkat : tingkat
# nilainyai : nilainyai
# pesenan : sen
# kelaman : kelam
# mudahkan : mudah
# oia : oia
# driver : driver
# seharian : hari
# provinsi : provinsi
# aceh : aceh
# sing : sing
# sheeeett : sheeeett
# kilat : kilat
# mintabtolong : mintabtolong
# batalinnatau : batalinnatau
# otw : otw
# flash : flash
# hatihatai : hatihatai
# bukalapk : bukalapk
# diajak : ajak
# diskusi : diskusi
# biaa : biaa
# dont : dont
# this : this
# pending : pending
# kesedot : sedot
# terbodoh : bodoh
# super : super
# puter : puter
# cust : cust
# pelanyaanan : pelanyaanan
# bk : bk
# binggung : binggung
# bergunasangat : bergunasangat
# komplainnggak : komplainnggak
# pelapaksulit : pelapaksulit
# darurarsampai : darurarsampai
# grab : grab
# ekpres : ekpres
# sampaistatus : sampaistatus
# kenyataan : nyata
# pqket : pqket
# pelapqkdwt : pelapqkdwt
# kemanamenurut : kemanamenurut
# sampahjauh : sampahjauh
# pedia : dia
# tulisannya : tulis
# diupdate : diupdate
# kualitas : kualitas
# payletter : payletter
# sebelumny : sebelumny
# andalkan : andal
# kawan : kawan
# takut : takut
# dijamin : jamin
# sentosaa : sentosaa
# trimakasih : trimakasih
# sms : sms
# wa : wa
# celakanya : celaka
# seluler : seluler
# daftarkan : daftar
# nopin : nopin
# keperluan : perlu
# oy : oy
# barunya : baru
# info : info
# kabarin : kabarin
# ngestuck : ngestuck
# oenjual : oenjual
# beratnya : berat
# alias : alias
# korupsisemakin : korupsisemakin
# bukapalak : bukapalak
# pelapaknya : lapak
# maksudnya : maksud
# okelahsangat : okelahsangat
# melambung : lambung
# aplikasnya : aplikasnya
# payahsetelaah : payahsetelaah
# log : log
# out : out
# baguscuma : baguscuma
# playleter : playleter
# teruspadahal : teruspadahal
# acc : acc
# program : program
# ajak : ajak
# undang : undang
# tampilkan : tampil
# diawal : awal
# nominalnya : nominal
# bengkak : bengkak
# dipertimbangkan : timbang
# terlindungi : lindung
# praktis : praktis
# bertahun : tahun
# andalan : andal
# impian : impi
# checkout : checkout
# faklah : faklah
# serasa : serasa
# pastikan : pasti
# refound : refound
# max : max
# overall : overall
# ecekecek : ecekecek
# dicari : cari
# blibli : blibli
# jdid : jdid
# aliexpress : aliexpress
# ongkos : ongkos
# aturannyapun : atur
# bodong : bodong
# anggap : anggap
# melanggar : langgar
# ketentuan : tentu
# ecommerce : ecommerce
# banyakjadi : banyakjadi
# regular : regular
# menghapus : hapus
# fikturnya : fikturnya
# rumit : rumit
# imail : imail
# keranjang : keranjang
# persembahkan : sembah
# sehat : sehat
# trimkakasih : trimkakasih
# diminati : mati
# sepertinyajualan : sepertinyajualan
# dshopee : dshopee
# laris : laris
# dbukalapak : dbukalapak
# sepigmn : sepigmn
# otomatisfitur : otomatisfitur
# tempopaylater : tempopaylater
# bekukakankapok : bekukakankapok
# adukan : adu
# optimal : optimal
# kansaya : kansaya
# latter : latter
# bukalapan : bukalapan
# berjualankita : berjualankita
# komunikasi : komunikasi
# tertutup : tutup
# astaga : astaga
# berulangkali : berulangkali
# dipengecekan : kece
# paham : paham
# ngelanggar : ngelanggar
# gitubisa : gitubisa
# nggu : nggu
# agustus : agustus
# kesalahannya : salah
# jelasmau : jelasmau
# vcr : vcr
# diamond : diamond
# digaji : gaji
# check : check
# komfirmasi : komfirmasi
# anjinglah : anjing
# termahalpengirimany : termahalpengirimany
# laingratis : laingratis
# pengirimany : pengirimany
# cepatbukalapk : cepatbukalapk
# rekomend : rekomend
# ditutup : tutup
# peringatan : ingat
# dilempar : lempar
# website : website
# sistim : sistim
# erortolong : erortolong
# terbantu : bantu
# dipahami : paham
# tingkatin : tingkatin
# permasalah : masa
# cht : cht
# dipermudah : mudah
# bangkai : bangkai
# eeh : eeh
# lagikan : lagi
# kontollllllllllll : kontollllllllllll
# gwe : gwe
# dimanabayar : dimanabayar
# jtpgilaran : jtpgilaran
# bayaralah : bayaralah
# limitnya : limit
# superseller : superseller
# mu : mu
# grtis : grtis
# murahan : murah
# ketinggian : tinggi
# memberatkan : berat
# lapaknyasll : lapaknyasll
# internetbuka : internetbuka
# lancarrr : lancarrr
# all : all
# indonesia : indonesia
# tertinggal : tinggal
# menjalankan : jalan
# bisnis : bisnis
# kelola : kelola
# terimaka : terimaka
# mengunakan : mengunakan
# temukan : temu
# nomthanks : nomthanks
# lengkapkarna : lengkapkarna
# berisial : berisial
# disana : sana
# lagihalo : lagihalo
# set : set
# bok : bok
# merek : merek
# advance : advance
# iniminta : iniminta
# kreasi : kreasi
# cocok : cocok
# sistemm : sistemm
# ngotak : ngotak
# euyy : euyy
# ngeri : ngeri
# euy : euy
# bati : bati
# berbaiki : baik
# payahhhhhhh : payahhhhhhh
# dihari : hari
# produck : produck
# digital : digital
# kurirnya : kurir
# situs : situs
# gubluk : gubluk
# enakan : enak
# shoppee : shoppee
# shoppe : shoppe
# ramai : ramai
# bermamfaat : bermamfaat
# mudahmudahan : mudahmudahan
# ayo : ayo
# belanjakan : belanja
# install : install
# dialaihkan : dialaihkan
# paketan : paket
# video : video
# peembayaran : peembayaran
# nyasip : nyasip
# lanjutkan : lanjut
# pertamakali : pertamakali
# niatnya : niat
# money : money
# diapk : diapk
# centernyasangat : centernyasangat
# menyertakan : serta
# delivery : delivery
# bukalapaksemoga : bukalapaksemoga
# depannya : depan
# recovery : recovery
# bareng : bareng
# tenggang : tenggang
# dihapus : hapus
# aplikasiy : aplikasiy
# berbelanjaapa : berbelanjaapa
# elektrohp : elektrohp
# sistemnya : sistem
# competitornya : competitornya
# enggak mau : enggak mau
# beku : beku
# hadehh : hadehh
# pajak : pajak
# uplod : uplod
# diorder : order
# adaterutama : adaterutama
# stb : stb
# dvbt : dvbt
# aplgi : aplgi
# pngiriman : pngiriman
# orangebiru : orangebiru
# dllaku : dllaku
# ajongkir : ajongkir
# ribuansukses : ribuansukses
# ttansaksi : ttansaksi
# respect : respect
# dm : dm
# instagram : instagram
# dibales : dibales
# centang : centang
# mengadu : adu
# uangnya : uang
# mintak : mintak
# photo : photo
# menunjukan : tunjuk
# marketplaca : marketplaca
# kacaumasa : kacaumasa
# ngorder : ngorder
# jaktim : jaktim
# jaksel : jaksel
# parahngk : parahngk
# ekspedisiyg : ekspedisiyg
# cepatganti : cepatganti
# sikeong : sikeong
# parahhhhh : parahhhhh
# terkorup : korup
# masamasa : masamasa
# ampuncs : ampuncs
# melamun : lamun
# awet : awet
# abang : abang
# semang : semang
# ongkirdgn : ongkirdgn
# inikalo : inikalo
# nyanda : nyanda
# ongkirpdhal : ongkirpdhal
# sekalibelanja : sekalibelanja
# lgjd : lgjd
# nyaga : nyaga
# sebln : sebln
# bonus : bonus
# pendaftaran : daftar
# bukalapakbukatabungan : bukalapakbukatabungan
# landing : landing
# tertulis : tulis
# desember : desember
# enggak usah : enggak usah
# iming : iming
# sytemnya : sytemnya
# bukanya : buka
# bantu : bantu
# mundur : mundur
# terburuk : buruk
# jaman : jaman
# vyata : vyata
# air : air
# boom : boom
# bentuknya : bentuk
# bentuk : bentuk
# khusus : khusus
# haga : haga
# selisih : selisih
# ati : ati
# banyakan : banyak
# acara : acara
# maleskalau : maleskalau
# senang : senang
# bukalapakkualitas : bukalapakkualitas
# bagusongkirnya : bagusongkirnya
# murahterjangkau : murahterjangkau
# estimasinya : estimasi
# barangnyapokoknya : barangnyapokoknya
# barangselalu : barangselalu
# lapaknyapdhallimit : lapaknyapdhallimit
# ributp : ributp
# dinofikasinya : dinofikasinya
# berulng : berulng
# lggimana : lggimana
# bisatombol : bisatombol
# daftarnya : daftar
# buram : buram
# tidk : tidk
# dkliksangat : dkliksangat
# kendaraan : kendara
# jempol : jempol
# mengkonfirmasi : konfirmasi
# menyediakan : sedia
# kelalaian : lalai
# mengaktifkan : aktif
# wajah : wajah
# bawahnya : bawah
# panduanhnya : panduanhnya
# kamera : kamera
# untukberbelanja : untukberbelanja
# pembelanjaan : belanja
# bagusmempermudah : bagusmempermudah
# livechat : livechat
# angin : angin
# enggak tau : enggak tau
# belikan : belikan
# milik : milik
# wkwk : wkwk
# kemudahan : mudah
# iconnect : iconnect
# kerjasamanya : kerjasamanya
# iconnet : iconnet
# fasilitas : fasilitas
# contoh : contoh
# apl : apl
# siang : siang
# dinikmati : nikmat
# tanggapannya : tanggap
# repot : repot
# waktubukalapak : waktubukalapak
# upgrde : upgrde
# dibukasetiap : dibukasetiap
# aplikase : aplikase
# keluarsuruh : keluarsuruh
# upgradepdahal : upgradepdahal
# perbarui : baru
# sercice : sercice
# elektrobisa : elektrobisa
# atow : atow
# layanannya : layan
# perintah : perintah
# tercatat : catat
# adaada : adaada
# terdaftar : daftar
# tolongdi : tolongdi
# sesuaikan : sesuai
# kependudukan : duduk
# cssalah : cssalah
# mengambil : ambil
# shoot : shoot
# perhatikan : perhati
# thx : thx
# angsuran : angsur
# rekomendasikan : rekomendasi
# temansaudara : temansaudara
# ythbukalapak : ythbukalapak
# bank : bank
# bri : bri
# chip : chip
# user : user
# banyaknya : banyak
# bermunculan : muncul
# disekitar : sekitar
# hadiah : hadiah
# merubah : rubah
# menambah : tambah
# brimo : brimo
# karenakan : karena
# persyaratan : syarat
# selfie : selfie
# seribet : seribet
# sesusah : susah
# astaghfirullah : astaghfirullah
# platform : platform
# terang : terang
# memblokir : blokir
# diandelin : diandelin
# nyalain : nyalain
# jelasjelas : jelasjelas
# tokoh : tokoh
# rame : rame
# sayaitu : sayaitu
# masak : masak
# rek : rek
# oalaahhh : oalaahhh
# dicairkan : cair
# kejadian : jadi
# pembekuan : beku
# itukan : itu
# keteranganalasanya : keteranganalasanya
# kecawa : kecawa
# peristiwa : peristiwa
# diarahkan : arah
# sarannya : saran
# maunya : mau
# mengstatuskan : mengstatuskan
# gantung : gantung
# biarkan : biar
# berbicara : bicara
# merangkul : rangkul
# umkm : umkm
# patut : patut
# diapresiasi : apresiasi
# serunya : seru
# dibanding : banding
# terbilang : bilang
# market : market
# berkarya : karya
# berinovasi : inovasi
# mengaco : aco
# uangku : uang
# cairkan : cair
# taunya : tau
# menerapkan : terap
# embelnya : embel
# izin : izin
# appnya : appnya
# percuman : cuman
# membalas : balas
# menyeleseikan : menyeleseikan
# kasihan : kasihan
# diseleseikan : diseleseikan
# selesei : selesei
# otomatus : otomatus
# ngeloading : ngeloading
# wifi : wifi
# jgmalah : jgmalah
# kebukatolong : kebukatolong
# secepatnya : cepat
# simpel : simpel
# penggunaannya : guna
# santai : santai
# apkls : apkls
# ol : ol
# trmksh : trmksh
# hang : hang
# youtube : youtube
# masukjd : masukjd
# menikmati : nikmat
# team : team
# inisya : inisya
# aktiftapi : aktiftapi
# sekalikomplain : sekalikomplain
# satupun : satu
# puaspadahal : puaspadahal
# narkoba : narkoba
# aturananda : aturananda
# bukalapaktolong : bukalapaktolong
# anehnya : aneh
# aru : aru
# pin : pin
# notif : notif
# selamat : selamat
# sianghalo : sianghalo
# wahyu : wahyu
# agung : agung
# ferbriliansalah : ferbriliansalah
# baylater : baylater
# paylatertapi : paylatertapi
# konfirmasidan : konfirmasidan
# kedaluarsa : kedaluarsa
# petunjuknyatagihan : petunjuknyatagihan
# memunculkan : muncul
# daftarin : daftarin
# didaftarin : didaftarin
# faq : faq
# pembahasan : bahas
# woyyyysaya : woyyyysaya
# aktifasi : aktifasi
# pertanyaannya : tanya
# disediakan : sedia
# sayapembeli : sayapembeli
# dipikirkan : pikir
# ketahan : tahan
# dilapak : lapak
# nyusain : nyusain
# apps : apps
# responsif : responsif
# entry : entry
# level : level
# utama : utama
# hadeh : hadeh
# kedaluwarsa : kedaluwarsa
# fungsi : fungsi
# dompet : dompet
# mengendap : endap
# freeongkir : freeongkir
# gudang : gudang
# stuck : stuck
# tanggap : tanggap
# kacau : kacau
# dijangkau : jangkau
# lancarlancar : lancarlancar
# permisi : permisi
# eror : eror
# sekitaran : sekitar
# ter : ter
# logout : logout
# dimohon : mohon
# kerjasama : kerjasama
# cepatnya : cepat
# komen : komen
# blidappreview : blidappreview
# diperbaikin : diperbaikin
# keberatan : berat
# sihcoba : sihcoba
# dikurangi : rang
# diperhatikan : perhati
# akunku : akun
# berkurang : kurang
# menyusahkan : susah
# deskripsi : deskripsi
# syaratnya : syarat
# ngurangin : ngurangin
# rewards : rewards
# sedih : sedih
# warung : warung
# nb : nb
# manual : manual
# sokor : sokor
# bni : bni
# hilangkan : hilang
# lapaksoalnya : lapaksoalnya
# errolldan : errolldan
# membosankan : bosan
# blokir : blokir
# kunci : kunci
# itutapi : itutapi
# beehati : beehati
# ceria : ceria
# slesai : slesai
# tanggapamnya : tanggapamnya
# byar : byar
# expres : expres
# mengecewakandi : mengecewakandi
# pilihannya : pilih
# harikok : harikok
# surabayadan : surabayadan
# jakartamalah : jakartamalah
# darat : darat
# surabayaemang : surabayaemang
# pesawatkan : pesawat
# beratkecewa : beratkecewa
# sameday : sameday
# senilai : nila
# membekukan : beku
# pulsapaket : pulsapaket
# mikir : mikir
# mafia : mafia
# didalem : dalem
# kesana : kesana
# dipindahkan : pindah
# nyadan : nyadan
# jeleeeeeeeeeeeeek : jeleeeeeeeeeeeeek
# perbaikaaaaan : perbaikaaaaan
# jeleeeeek : jeleeeeek
# codnya : codnya
# wajar : wajar
# seler : seler
# terjelek : jelek
# berlimpah : limpah
# mantaab : mantaab
# markotopmaknyosss : markotopmaknyosss
# sampahjangan : sampahjangan
# downloadpasti : downloadpasti
# nyeselalasan : nyeselalasan
# mulupadahal : mulupadahal
# reccomended : reccomended
# perihal : perihal
# ketutup : tutup
# kejelasannya : jelas
# sihsaya : sihsaya
# rbpembayaran : rbpembayaran
# rbsaya : rbsaya
# berharap : harap
# kuranginlah : rangin
# verivikasi : verivikasi
# belanjaan : belanja
# non : non
# membantupromo : membantupromo
# banyakpaylater : banyakpaylater
# duitsemoga : duitsemoga
# baterai : baterai
# mac : mac
# second : second
# garansi : garansi
# gambling : gambling
# balikin : balikin
# bad : bad
# nyuruh : nyuruh
# amp : amp
# jelasin : jelasin
# healt : healt
# pic : pic
# tenang : tenang
# anter : anter
# jemput : jemput
# send : send
# post : post
# place : place
# daerah : daerah
# allah : allah
# minn : minn
# sabar : sabar
# inidari : inidari
# bisamalah : bisamalah
# bgtmau : bgtmau
# menangis : menang
# sampean : sampean
# mbak : mbak
# inimah : inimah
# layani : layan
# sech : sech
# malamngisi : malamngisi
# nominalkecil : nominalkecil
# ngisi : ngisi
# malam : malam
# kasig : kasig
# utuk : utuk
# tagihancuman : tagihancuman
# belnja : belnja
# pengirimanny : pengirimanny
# lamaklu : lamaklu
# pengirimanya : pengirimanya
# menawarkan : tawar
# sejenisnya : jenis
# hobi : hobi
# mesin : mesin
# pencariannya : cari
# melencengnya : lenceng
# biayanya : biaya
# kompetitornya : kompetitor
# tanggung : tanggung
# kesambung : sambung
# balasan : balas
# seng : seng
# dwonload : dwonload
# content : content
# terussga : terussga
# ecommercemending : ecommercemending
# terpercayabelanja : terpercayabelanja
# nyamanpelapaknya : nyamanpelapaknya
# amanah : amanah
# ongkisnya : ongkisnya
# uadh : uadh
# gbsa : gbsa
# telp : telp
# aduh : aduh
# proseskan : proses
# kredibel : kredibel
# perbaikan : baik
# server : server
# beritau : beritau
# pengumuman : umum
# samgat : samgat
# bukalapaktokonya : bukalapaktokonya
# gesit : gesit
# berhubung : hubung
# aps : aps
# permata : permata
# sok : sok
# mendadak : dadak
# report : report
# lemoot : lemoot
# tokpedshopee : tokpedshopee
# beraaaaat : beraaaaat
# ijoorange : ijoorange
# efisien : efisien
# duduk : duduk
# manis : manis
# low : low
# cost : cost
# akulaku : akulaku
# mengurus : urus
# kendalanya : kendala
# diarah : arah
# kemasalah : masa
# ikhlasin : ikhlasin
# berkah : berkah
# bagustp : bagustp
# fahan : fahan
# perjuangan : juang
# merintis : rintis
# nol : nol
# peringkat : peringkat
# libur : libur
# pinjol : pinjol
# memutuskan : putus
# swafoto : swafoto
# ovo : ovo
# tolo : tolo
# games : games
# serial : serial
# numbernya : numbernya
# didalamnya : dalam
# relatif : relatif
# ketidak : tidak
# sesuaian : sesuai
# bahaya : bahaya
# nihbanyak : nihbanyak
# nelpon : nelpon
# mengaku : aku
# bukalapakpakai : bukalapakpakai
# lagiharusnya : lagiharusnya
# protek : protek
# bukalapakini : bukalapakini
# membahayakan : bahaya
# tanda : tanda
# far : far
# goodselalu : goodselalu
# ferifikasi : ferifikasi
# pedagangnya : dagang
# meminimalisir : meminimalisir
# berbuat : buat
# curangmaju : curangmaju
# bukalapaksy : bukalapaksy
# cinta : cinta
# negerisemoga : negerisemoga
# exspress : exspress
# dikit : dikit
# belanjaannya : belanja
# cpat : cpat
# pokokny : pokokny
# knapa : knapa
# terussudah : terussudah
# terifikasi : terifikasi
# rajin : rajin
# najis : najis
# gojek : gojek
# geloooo : geloooo
# ancurrrrr : ancurrrrr
# layak : layak
# terikasih : terikasih
# mantaaabbb : mantaaabbb
# nyagampang : nyagampang
# jugaterimakasih : jugaterimakasih
# menyebalkan : sebal
# sdng : sdng
# masalahbukabantuanpaylater : masalahbukabantuanpaylater
# dibukapadahal : dibukapadahal
# pelayananx : pelayananx
# cepatbanyak : cepatbanyak
# diskonbanyak : diskonbanyak
# casback : casback
# reason : reason
# pasword : pasword
# melanjutkan : lanjut
# shipper : shipper
# updated : updated
# ngebug : ngebug
# mndesakbisa : mndesakbisa
# brag : brag
# tggu : tggu
# haribyak : haribyak
# ah : ah
# bekukandengan : bekukandengan
# jelaspadahal : jelaspadahal
# kemari : kemari
# terbuka : buka
# ulangitu : ulangitu
# tipusaya : tipusaya
# google : google
# dikirimpadahal : dikirimpadahal
# management : management
# usut : usut
# permasalahan : masalah
# sayagimana : sayagimana
# original : original
# klaim : klaim
# playlaternya : playlaternya
# bangetbeda : bangetbeda
# jta : jta
# kaategori : kaategori
# provisi : provisi
# shope : shope
# butuhkan : butuh
# negeri : negeri
# sederhana : sederhana
# pencarianya : pencarianya
# seting : ting
# ribetttt : ribetttt
# paylettersaya : paylettersaya
# indomart : indomart
# pilihannyatetapi : pilihannyatetapi
# kadaluarsadan : kadaluarsadan
# dendasaya : dendasaya
# ngertiapakah : ngertiapakah
# systemnya : systemnya
# segaja : segaja
# ujung : ujung
# ujungnya : ujung
# dikembalikandan : dikembalikandan
# bayarlagi : bayarlagi
# dendanyaparrraaaaahpokoknya : dendanyaparrraaaaahpokoknya
# bayarrr : bayarrr
# meragukan : ragu
# kulit : kulit
# handphone : handphone
# beres : beres
# benarkomplit : benarkomplit
# sangatmembatu : sangatmembatu
# barangatau : barangatau
# pergerakan : gera
# mantul : mantul
# menginstal : menginstal
# dikirm : dikirm
# tingkan : ting
# kemasannya : kemas
# diharapkan : harap
# maksa : maksa
# home : home
# lamaloading : lamaloading
# doangmakin : doangmakin
# bukalapakbutut : bukalapakbutut
# sia : sia
# bug : bug
# muantapterpecayamohon : muantapterpecayamohon
# jaringannya : jaring
# percepat : cepat
# bozchasback : bozchasback
# krg : krg
# bangetpenggunaan : bangetpenggunaan
# kayaknya : kayak
# terjaga : jaga
# sngat : sngat
# dilaporin : dilaporin
# polisi : polisi
# sihuangku : sihuangku
# dikembaliin : dikembaliin
# bukalapakhatihati : bukalapakhatihati
# menjebakpenipu : menjebakpenipu
# nampil : nampil
# pengambilannyaini : pengambilannyaini
# parahudah : parahudah
# tf : tf
# kadluarsa : kadluarsa
# okeedan : okeedan
# trimaksh : trimaksh
# serra : serra
# barangkali : barangkali
# playstore : playstore
# device : device
# huawei : huawei
# pro : pro
# kembangkan : kembang
# input : input
# lumayantapi : lumayantapi
# spaylater : spaylater
# bangga : bangga
# bersyukur : syukur
# efesien : efesien
# memudah : mudah
# nyaaneh : nyaaneh
# busuk : busuk
# jahanam : jahanam
# babi : babi
# tujuantapi : tujuantapi
# terhenti : henti
# sendirimakin : sendirimakin
# inisial : inisial
# sediakan : sedia
# penyedia : sedia
# besok : besok
# gofood : gofood
# grabfood : grabfood
# kiriman : kirim
# developernya : developer
# itupayah : itupayah
# parahpunya : parahpunya
# rbdi : rbdi
# bulanan : bulan
# rbpadhal : rbpadhal
# gunkan : gun
# rbiya : rbiya
# kebalikanyaparah : kebalikanyaparah
# disuguhin : disuguhin
# artis : artis
# sipit : sipit
# unistall : unistall
# kenpa : kenpa
# bukasuruh : bukasuruh
# upgradegimana : upgradegimana
# terjangkau : jangkau
# pinjamannya : pinjam
# transaksinya : transaksi
# infomasi : infomasi
# diperbaharui : baharu
# kerennnklo : kerennnklo
# dipercepat : cepat
# dananyaheeee : dananyaheeee
# bloon : bloon
# pln : pln
# percayaterima : percayaterima
# bukalapakbarang : bukalapakbarang
# yahuuuutt : yahuuuutt
# kasihby : kasihby
# rahesa : rahesa
# dewaga : dewaga
# adanyadi : adanyadi
# manasemua : manasemua
# lapakga : lapakga
# tertarik : tarik
# love : love
# lapakselalu : lapakselalu
# bestbuka : bestbuka
# harikalau : harikalau
# jamsupaya : jamsupaya
# profesionalkecuali : profesionalkecuali
# preorder : preorder
# rejeki : rejeki
# moga : moga
# berkat : berkat
# orangketolong : orangketolong
# dinyalakan : nyala
# refferal : refferal
# sale : sale
# seru : seru
# tertariktapi : tertariktapi
# jujur : jujur
# bukalpaak : bukalpaak
# mengomongnya : omong
# bayaran : bayar
# fiktif : fiktif
# manahan : manah
# lemotterlalu : lemotterlalu
# promapromo : promapromo
# lagihadehhh : lagihadehhh
# senter : senter
# harimakin : harimakin
# bukalapakga : bukalapakga
# kbukalapak : kbukalapak
# lunas : lunas
# dropshoper : dropshoper
# callcenter : callcenter
# kenal : kenal
# dewasa : dewasa
# sehinggan : sehinggan
# mengkaver : kaver
# ekspidisi : ekspidisi
# penengananya : penengananya
# pelayananya : pelayananya
# sip : sip
# variasi : variasi
# tunggakan : tunggak
# you : you
# puasssssssssssbanget : puasssssssssssbanget
# dibantu : bantu
# seputar : putar
# menampilkan : tampil
# beratdan : beratdan
# sukit : sukit
# muternggak : muternggak
# pemakain : pemakain
# kenyataannya : nyata
# terbayarkan : bayar
# benersyarat : benersyarat
# diikuti : ikut
# syaratgk : syaratgk
# hancur : hancur
# ditf : ditf
# fajri : fajri
# acur : acur
# bpk : bpk
# tlkom : tlkom
# mudahpelapaknya : mudahpelapaknya
# okkarena : okkarena
# tercantumkurir : tercantumkurir
# end : end
# tangall : tangall
# tangal : tangal
# januarin : januarin
# modall : modall
# rate : rate
# playstor : playstor
# gunain : gunain
# onlonesy : onlonesy
# muka : muka
# pendanaantrimkasih : pendanaantrimkasih
# bltp : bltp
# sebaliknykurir : sebaliknykurir
# paylatternyaongkir : paylatternyaongkir
# shoppp : shoppp
# pengepakan : epak
# praktek : praktek
# kompensasi : kompensasi
# membiarkan : biar
# pernyataan : nyata
# sajamudah : sajamudah
# mudahan : mudah
# job : job
# sayapertahankantingkatkan : sayapertahankantingkatkan
# pelayanannyaterima : pelayanannyaterima
# lumayantpi : lumayantpi
# erortidak : erortidak
# vpntolong : vpntolong
# az : az
# brlanjakan : brlanjakan
# terjalin : jalin
# pembayar : bayar
# payliter : payliter
# ditail : ditail
# sebelahtoko : sebelahtoko
# balas : balas
# posisi : posisi
# on : on
# cancelnya : cancelnya
# ajg : ajg
# tahan : tahan
# nyaipay : nyaipay
# miring : miring
# plis : plis
# ui : ui
# ux : ux
# evaluasi : evaluasi
# instant : instant
# selasa : selasa
# juni : juni
# lawas : lawas
# koleksi : koleksi
# keilmuan : ilmu
# pesanantolong : pesanantolong
# mengatasi : atas
# enggak jelas : enggak jelas
# kelar : kelar
# berkualitas : kualitas
# bravo : bravo
# nympe : nympe
# diretur : retur
# menyerah : serah
# dibenahin : dibenahin
# kekurangannya : kurang
# pakevertifikasi : pakevertifikasi
# bolak : bolak
# edan : edan
# mark : mark
# taeif : taeif
# resmi : resmi
# edann : edann
# verikasi : verikasi
# bagustapi : bagustapi
# onlinejadi : onlinejadi
# bagong : bagong
# teranjing : anjing
# nmuin : nmuin
# okskrg : okskrg
# pnts : pnts
# gercep : gercep
# dibalas : balas
# kelebihan : lebih
# diongkir : diongkir
# pooollllll : pooollllll
# kesinikenapa : kesinikenapa
# menurun : turun
# ajuin : ajuin
# playter : playter
# lolos : lolos
# gliran : gliran
# surabaya : surabaya
# lokasi : lokasi
# kau : kau
# bruuk : bruuk
# alhamdulilah : alhamdulilah
# berani : berani
# terosss : terosss
# canter : canter
# suksesamin : suksesamin
# bangetudah : bangetudah
# budget : budget
# promoted : promoted
# belidulu : belidulu
# promotedjadi : promotedjadi
# inimaaf : inimaaf
# blkalw : blkalw
# tampa : tampa
# belanjaini : belanjaini
# teliti : teliti
# return : return
# kwh : kwh
# meter : meter
# hadehhhh : hadehhhh
# lampiran : lampir
# bukalapakpertamakali : bukalapakpertamakali
# bayarnya : bayar
# terlambat : lambat
# bayarannya : bayar
# esok : esok
# lusa : lusa
# lahpokoknya : lahpokoknya
# bertele : tele
# tele : tele
# penganannya : penganan
# dibikin : bikin
# terputus : putus
# pastinya : pasti
# belajar : ajar
# apknya : apknya
# bossegera : bossegera
# yapenting : yapenting
# ...
# nonaktifkandi : nonaktifkandi
# aktifdibekukan : aktifdibekukan
# lemotbahkan : lemotbahkan
# sesimpel : simpel
# emaneman : emaneman
# berdiri : diri
# tetspi : tetspi
# performanya : performa
# belooommm : belooommm
# bikalapak : bikalapak
# pengecekan : kece
# barangsangat : barangsangat
# lapakdan : lapakdan
# makdusnya : makdusnya
# jajal : jajal
# layanankalu : layanankalu
# hi : hi
# livenya : livenya
# mecahkan : mecahkan
# troble : troble
# dipihak : pihak
# gitukah : gitukah
# pn : pn
# keterang : terang
# adminya : adminya
# terkecuali : kecuali
# berasa : asa
# paylattercicilan : paylattercicilan
# minaku : mina
# bukalapaksuruh : bukalapaksuruh
# updateudh : updateudh
# isa : isa
# dibukamau : dibukamau
# inimau : inimau
# mintolong : mintolong
# balaas : balaas
# payletternyapadahal : payletternyapadahal
# kebeli : kebel
# adil : adil
# resolusi : resolusi
# sreg : sreg
# desain : desain
# lte : lte
# ikuti : ikut
# casbak : casbak
# jamin : jamin
# klou : klou
# atou : atou
# dgan : dgan
# besaran : besar
# sando : sando
# dimata : mata
# efeknya : efek
# onkirnya : onkirnya
# asing : asing
# bandingkan : banding
# panas : panas
# programmernya : programmernya
# memperbaiki : baik
# standar : standar
# trendy : trendy
# kategori : kategori
# dihilangkan : hilang
# kurangnya : kurang
# privacy : privacy
# enggine : enggine
# mengetikkan : etik
# muncullah : muncul
# tab : tab
# komentarnya : komentar
# pr : pr
# terbesar : besar
# pengembang : kembang
# smooth : smooth
# minimalis : minimal
# cashbackharga : cashbackharga
# bersaingpembelian : bersaingpembelian
# cepatcoba : cepatcoba
# leasing : leasing
# keluhanpromo : keluhanpromo
# lahpadahal : lahpadahal
# kursusuntuk : kursusuntuk
# skill : skill
# wawasansaya : wawasansaya
# kursus : kursus
# strategi : strategi
# efektif : efektif
# membandingkan : banding
# background : background
# signal : signal
# om : om
# konten : konten
# ram : ram
# bukange : bukange
# laghangstuck : laghangstuck
# jualbeli : jualbeli
# susahhh : susahhh
# atur : atur
# crop : crop
# brightness : brightness
# sorry : sorry
# visualnya : visual
# featuresnya : featuresnya
# grafisnya : grafis
# oh : oh
# diakali : akal
# pclaptop : pclaptop
# bergunajadi : bergunajadi
# selipkan : selip
# follow : follow
# dihilangkannya : hilang
# penambahan : tambah
# jalankan : jalan
# kentang : kentang
# lainwalopun : lainwalopun
# mandek : mandek
# mengetik : etik
# lag : lag
# pencariang : pencariang
# koneksinya : koneksi
# formulir : formulir
# klaimnya : klaim
# pengecualian : kecuali
# cthnya : cthnya
# smsung : smsung
# berasal : asal
# dicarinya : cari
# pemasukan : pasu
# sekilas : kilas
# istimewa : istimewa
# menghemat : hemat
# mengklik : klik
# sebagus : bagus
# diclose : diclose
# diinstal : diinstal
# ganggu : ganggu
# rezeki : rezeki
# hebat : hebat
# ruet : ruet
# ngklik : ngklik
# grosir : grosir
# ngeklik : ngeklik
# model : model
# jawabanya : jawabanya
# paka : paka
# dibaca : baca
# pemasangan : pasang
# lemodlemoodlemot : lemodlemoodlemot
# penyimpanan : simpan
# mananya : mana
# singkat : singkat
# padat : padat
# lebar : lebar
# terpasang : pasang
# dipublish : dipublish
# sifat : sifat
# curiganya : curiga
# extrem : extrem
# kalap : kalap
# putih : putih
# donlot : donlot
# terinstall : terinstall
# clear : clear
# chace : chace
# alasanya : alasanya
# chatting : chatting
# tidaknya : tidak
# ngejamin : ngejamin
# okkalau : okkalau
# beragambanyak : beragambanyak
# vanyak : vanyak
# plus : plus
# diiklankan : iklan
# beragam : agam
# perbandingan : banding
# tujuh : tujuh
# dekstop : dekstop
# sepuluh : puluh
# enam : enam
# hilangnya : hilang
# gimmick : gimmick
# strategis : strategis
# kebingungan : bingung
# pakenya : pakenya
# menjalani : jalan
# berjeda : jeda
# terjeda : jeda
# emosian : emosi
# voucherpromohadiah : voucherpromohadiah
# poin : poin
# cicil : cicil
# memfilter : filter
# indikasi : indikasi
# produkbarang : produkbarang
# barangproduk : barangproduk
# perbedaan : beda
# huruf : huruf
# notes : notes
# anti : anti
# scroll : scroll
# buffering : buffering
# lion : lion
# parcel : parcel
# kilo : kilo
# hitung : hitung
# toki : tok
# interface : interface
# startup : startup
# keteranga : keteranga
# restart : restart
# android : android
# alikasinya : alikasinya
# traffict : traffict
# diserver : diserver
# disalahkan : salah
# base : base
# mall : mall
# sevelumnya : velum
# upgradean : upgradean
# simpanmasukin : simpanmasukin
# bermenit : menit
# untik : untik
# terbarunya : baru
# bukalapakbelanja : bukalapakbelanja
# efisiensi : efisiensi
# pengeluaran : keluar
# bagussuntuk : bagussuntuk
# chating : chating
# karuan : karuan
# noyifikasi : noyifikasi
# refresh : refresh
# notifjuga : notifjuga
# bltdk : bltdk
# sarantingkatkan : sarantingkatkan
# kompetitif : kompetitif
# bukastruk : bukastruk
# teridentifikasi : identifikasi
# dideteksi : deteksi
# duplikat : duplikat
# ditolak : tolak
# scan : scan
# petunjuk : tunjuk
# zonknya : zonknya
# rocket : rocket
# shake : shake
# nilainya : nilai
# pertamanya : pertama
# pajangan : pajang
# sponsored : sponsored
# by : by
# menyesatkan : sesat
# tunanetra : tunanetra
# talk : talk
# aksesibilitas : aksesibilitas
# kebaca : baca
# mengirangira : mengirangira
# tekan : tekan
# tombolnya : tombol
# performa : performa
# sinyalnya : sinyal
# rutinkan : rutin
# pemeliharaan : pelihara
# categories : categories
# mencakup : cakup
# informatif : informatif
# highlight : highlight
# subs : subs
# mauditinju : mauditinju
# turunya : turunya
# konsistensi : konsistensi
# map : map
# rincian : rincian
# dsb : dsb
# tabel : tabel
# trayning : trayning
# menganalisa : menganalisa
# penengah : tengah
# berdasarkan : dasar
# fakta : fakta
# invoice : invoice
# rekam : rekam
# manipulasi : manipulasi
# rekaman : rekam
# berlarut : larut
# larut : larut
# menangani : tangan
# mampusss : mampusss
# ruwet : ruwet
# pengoperasiannya : operasi
# unggul : unggul
# codkarna : codkarna
# sinergi : sinergi
# pokoknyapngennya : pokoknyapngennya
# bntang : bntang
# mamtul : mamtul
# setelqh : setelqh
# bukaaplikasinya : bukaaplikasinya
# lapakkarna : lapakkarna
# bayarmaupun : bayarmaupun
# seya : seya
# sosmed : sosmed
# rugiiiii : rugiiiii
# nihpakai : nihpakai
# terusbisa : terusbisa
# ajagak : ajagak
# minjeminditambah : minjeminditambah
# mentransfer : transfer
# blpaylatter : blpaylatter
# nalangin : nalangin
# mada : mada
# nada : nada
# marah : marah
# dikritik : kritik
# toklist : toklist
# kodenya : kode
# degh : degh
# kemasan : kemas
# bagusaman : bagusaman
# mitranya : mitra
# aplikator : aplikator
# batuan : batu
# rspon : rspon
# pulsatoken : pulsatoken
# jeleknya : jelek
# agent : agent
# berkomunikasi : komunikasi
# peminatnya : minat
# selebih : lebih
# mendownload : mendownload
# terdownload : terdownload
# kenyamana : kenyamana
# userpembeli : userpembeli
# szusah : szusah
# jangkauan : jangkau
# kaspoh : kaspoh
# diperbaruitggl : diperbaruitggl
# pengunduhan : unduh
# brenti : brenti
# ditengah : tengah
# nguras : nguras
# dalih : dalih
# lembaruan : lembaruan
# mengkalkulasi : kalkulasi
# blakangan : blakangan
# utamakan : utama
# keuntunganya : keuntunganya
# lho : lho
# diantar : antar
# bercerita : cerita
# disusun : susun
# berantakan : beranta
# acak : acak
# enggak pernah : enggak pernah
# suami : suami
# pemesannya : mes
# menangkap : tangkap
# permainan : main
# padahap : padahap
# mengoprasikan : mengoprasikan
# komputer : komputer
# spin : spin
# dapatkan : dapat
# thr : thr
# dputar : dputar
# reaponsif : reaponsif
# diverifikasi : verifikasi
# lampirkan : lampir
# transfernya : transfer
# tambahannya : tambah
# tercancel : tercancel
# duitpun : duit
# dialihkan : alih
# senangi : senang
# mutar : mutar
# beraaattt : beraaattt
# lamaaaa : lamaaaa
# aplod : aplod
# ketidaknyamanan : ketidaknyamanan
# keruntuhannya : runtuh
# berkunjung : kunjung
# gosok : gosok
# mumpuni : mumpuni
# dipencet : pencet
# white : white
# screen : screen
# kapasitas : kapasitas
# karana : karana
# pebelian : beli
# customet : customet
# memberitahu : memberitahu
# step : step
# dialami : alami
# digunakanbanyak : digunakanbanyak
# keuntungannya : untung
# jugaasemangat : jugaasemangat
# untul : untul
# keunggulan : unggul
# benjol : benjol
# mukaberanda : mukaberanda
# nego : nego
# execelent : execelent
# application : application
# kurangtapi : kurangtapi
# dwngan : dwngan
# updatetampilan : updatetampilan
# sekaranguntuk : sekaranguntuk
# mengelola : kelola
# bulak : bulak
# filtergak : filtergak
# halamanditambah : halamanditambah
# goib : goib
# ditransaksi : transaksi
# penjelasanjadi : penjelasanjadi
# fake : fake
# bermanfaatmateri : bermanfaatmateri
# formalbiar : formalbiar
# lgebook : lgebook
# typo : typo
# dijelaskantambahkan : dijelaskantambahkan
# userjumlah : userjumlah
# judul : judul
# gabtek : gabtek
# kaget : kaget
# gambarnya : gambar
# diikutin : diikutin
# dihubungin : dihubungin
# gemas : gemas
# ceunah : ceunah
# nge : nge
# load : load
# beranda : beranda
# terbik : bik
# akademi : akademi
# memuaskanmateri : memuaskanmateri
# rincipenyampaiannya : rincipenyampaiannya
# mudahbelajar : mudahbelajar
# uinya : uinya
# gaperlu : gaperlu
# was : was
# teknisnya : teknis
# laennya : laennya
# galangsung : galangsung
# ikutan : ikut
# minusnya : minus
# digabung : gabung
# bandwitch : bandwitch
# sizenya : sizenya
# smarphone : smarphone
# berdaya : daya
# tipe : tipe
# updatekurang : updatekurang
# penipuuu : penipuuu
# produkdll : produkdll
# complainnya : complainnya
# sterilin : sterilin
# mencurigakan : curiga
# cache : cache
# tertampil : tampil
# miskomunikasi : miskomunikasi
# dikirimkan : kirim
# menyederhanakan : sederhana
# konsep : konsep
# tokopea : tokopea
# gfatis : gfatis
# bagusdan : bagusdan
# barangbarangnya : barangbarangnya
# kuotadan : kuotadan
# hadeww : hadeww
# disetiap : tiap
# koneksimu : koneksi
# pesawat : pesawat
# antariksa : antariksa
# melintas : lintas
# shoop : shoop
# sukamudah : sukamudah
# ndk : ndk
# harganyabanyak : harganyabanyak
# barangnyasucses : barangnyasucses
# sebutin : sebutin
# belenja : belenja
# blenk : blenk
# dengar : dengar
# compatible : compatible
# rotasi : rotasi
# tegak : tegak
# landscape : landscape
# mengurangi : kurang
# sentuh : sentuh
# genting : genting
# membnatu : membnatu
# pemberian : beri
# hh : hh
# sayaanehnya : sayaanehnya
# hmmm : hmmm
# terferifikasibukti : terferifikasibukti
# adajujur : adajujur
# haiisaya : haiisaya
# bukalapakbukalapak : bukalapakbukalapak
# sekaliterima : sekaliterima
# bertambahnya : tambah
# lemotnya : lot
# tingkatkandan : tingkatkandan
# pencuri : curi
# desemer : desemer
# ditahan : tahan
# miris : miris
# paksa : paksa
# minggunya : minggu
# penurunan : turun
# degan : degan
# pundi : pundi
# padahalkami : padahalkami
# terimatapi : terimatapi
# pedback : pedback
# mengabaikan : abai
# perform : perform
# quick : quick
# respons : respons
# outo : outo
# tinggalkan : tinggal
# berteletele : berteletele
# deskripsitokonya : deskripsitokonya
# ketepatan : tepat
# leluasa : leluasa
# ditinjau : tinjau
# laintokopedia : laintokopedia
# akalkok : akalkok
# uinstal : uinstal
# diatas : atas
# lapaktp : lapaktp
# diposting : diposting
# bukalapakkrn : bukalapakkrn
# dinyatakan : nyata
# meneruskan : terus
# diajukan : aju
# lambatasuknya : lambatasuknya
# abaikan : abai
# academy : academy
# handle : handle
# interfacenya : interfacenya
# disederhanakan : sederhana
# transisi : transisi
# memakan : makan
# perusahaan : usaha
# membangun : bangun
# modern : modern
# claim : claim
# sekalik : sekalik
# hank : hank
# terbit : terbit
# ilangresetbaik : ilangresetbaik
# perncarian : perncarian
# sellerbuyer : sellerbuyer
# puasnyaman : puasnyaman
# semangat : semangat
# gangguannya : ganggu
# kepastian : pasti
# sependapat : dapat
# permintaan : minta
# mjd : mjd
# bunyi : bunyi
# pesannya : pesan
# rese : rese
# seri : seri
# platformnya : platform
# operating : operating
# menutup : tutup
# reinstal : reinstal
# akitivitas : akitivitas
# desktop : desktop
# androin : androin
# ios : ios
# ngelink : ngelink
# etalase : etalase
# terlewati : lewat
# bunyinya : bunyi
# baruudah : baruudah
# mohondiperbaiki : mohondiperbaiki
# teraman : ram
# dichat : dichat
# transaksinyajd : transaksinyajd
# berjalansudah : berjalansudah
# re : re
# kebukapas : kebukapas
# tap : tap
# awaldan : awaldan
# icon : icon
# animasi : animasi
# berlaripayah : berlaripayah
# perbaikisaya : perbaikisaya
# nyapada : nyapada
# eksekusi : eksekusi
# transaksidalam : transaksidalam
# satuharus : satuharus
# lawak : lawak
# underratedmasih : underratedmasih
# tingkah : tingkah
# sadarbaru : sadarbaru
# engah : engah
# berkualitastidak : berkualitastidak
# bedanya : beda
# lancarbisa : lancarbisa
# errorserver : errorserver
# berkualitasdan : berkualitasdan
# berkualitasbuat : berkualitasbuat
# mahalbanyakin : mahalbanyakin
# manjakan : manja
# sebelahgratis : sebelahgratis
# ongkirgratis : ongkirgratis
# ongkirdan : ongkirdan
# kekecewaan : kecewa
# kalopun : kalo
# wsrted : wsrted
# {'aplikasi': 'aplikasi', 'parah': 'parah', 'belanja': 'belanja', 'cc': 'cc', 'pilih': 'pilih', 'klik': 'klik', 'cicilan': 'cicil', 'tertagih': 'tagih', 'full': 'full', 'confirmasi': 'confirmasi', 'urus': 'urus', 'teman': 'teman', 'metode': 'metode', 'korban': 'korban', 'kabar': 'kabar', 'bukalapak': 'bukalapak', 'bagus': 'bagus', 'sih': 'sih', 'cuman': 'cuman', 'ribet': 'ribet', 'kali': 'kali', 'update': 'update', 'aplikasinya': 'aplikasi', 'susah': 'susah', 'bertransaksi': 'transaksi', 'hp': 'hp', 'memorinya': 'memori', 'terbatas': 'batas', 'hapus': 'hapus', 'terpaksa': 'paksa', 'buka': 'buka', 'akun': 'akun', 'bl': 'bl', 'barusan': 'barusan', 'ceritanya': 'cerita', 'barang': 'barang', 'dibeli': 'beli', 'harapan': 'harap', 'dibl': 'dibl', 'murah': 'murah', 'promo': 'promo', 'menarik': 'tarik', 'dijual': 'jual', 'lengkap': 'lengkap', 'sekalinya': 'sekali', 'pilihan': 'pilih', 'seller': 'seller', 'akibatnya': 'akibat', 'mahal': 'mahal', 'marketplace': 'marketplace', 'sebelah': 'belah', 'disaat': 'saat', 'voucher': 'voucher', 'gratis': 'gratis', 'ongkir': 'ongkir', 'mengasih': 'asih', 'diskon': 'diskon', 'nya': 'nya', 'instan': 'instan', 'maaf': 'maaf', 'kasih': 'kasih', 'bintang': 'bintang', 'layanan': 'layan', 'customer': 'customer', 'mengajukan': 'aju', 'pesan': 'pesan', 'custom': 'custom', 'bebas': 'bebas', 'sesuai': 'sesuai', 'kalimat': 'kalimat', 'sehari': 'hari', 'pembeli': 'beli', 'terkesan': 'kes', 'baku': 'baku', 'aturan': 'atur', 'toko': 'toko', 'hijau': 'hijau', 'orange': 'orange', 'harapannya': 'harap', 'tolong': 'tolong', 'dimudahkan': 'mudah', 'fitur': 'fitur', 'chat': 'chat', 'bantuan': 'bantu', 'terimakasih': 'terimakasih', 'kesulitan': 'sulit', 'komplen': 'komplen', 'pembayaran': 'bayar', 'paylater': 'paylater', 'no': 'no', 'watelpon': 'watelpon', 'aktif': 'aktif', 'membingunkan': 'membingunkan', 'masuk': 'masuk', 'penjual': 'jual', 'nyaman': 'nyaman', 'konfirmasi': 'konfirmasi', 'pesanan': 'pesan', 'terima': 'terima', 'batalkan': 'batal', 'kemauan': 'mau', 'batal': 'batal', 'otomasi': 'otomasi', 'kerlambatan': 'kerlambatan', 'pengiriman': 'kirim', 'lakh': 'lakh', 'feedback': 'feedback', 'negatif': 'negatif', 'kesalahan': 'salah', 'pembelinya': 'bel', 'plin': 'plin', 'plan': 'plan', 'kirim': 'kirim', 'eh': 'eh', 'star': 'star', 'bagusmalah': 'bagusmalah', 'menurunupdate': 'menurunupdate', 'terbaru': 'baru', 'berpengaruhhapus': 'berpengaruhhapus', 'cacheclear': 'cacheclear', 'datasama': 'datasama', 'ajaaplikasi': 'ajaaplikasi', 'berat': 'berat', 'loadingnya': 'loadingnya', 'menonton': 'tonton', 'streaming': 'streaming', 'hd': 'hd', 'lancar': 'lancar', 'jaya': 'jaya', 'live': 'live', 'penipuan': 'tipu', 'kontak': 'kontak', 'cs': 'cs', 'hubungi': 'hubung', 'konsumen': 'konsumen', 'aman': 'aman', 'cari': 'cari', 'solusi': 'solusi', 'kendala': 'kendala', 'dipersulit': 'sulit', 'kayak': 'kayak', 'proses': 'proses', 'batas': 'batas', 'maksimal': 'maksimal', 'dana': 'dana', 'mengecewakan': 'kecewa', 'pengguna': 'guna', 'lumayan': 'lumayan', 'transaksi': 'transaksi', 'riwayat': 'riwayat', 'status': 'status', 'updatenya': 'updatenya', 'telat': 'telat', 'mulu': 'mulu', 'pelapak': 'lapak', 'mengirimkan': 'kirim', 'sore': 'sore', 'pickup': 'pickup', 'pisan': 'pis', 'pesanannya': 'pesan', 'tambahan': 'tambah', 'bukti': 'bukti', 'gambarfoto': 'gambarfoto', 'ditujuan': 'tuju', 'barangpesanan': 'barangpesanan', 'diterima': 'terima', 'masukan': 'masuk', 'bual': 'bual', 'cepat': 'cepat', 'kembalikan': 'kembali', 'langsung': 'langsung', 'orang': 'orang', 'awam': 'awam', 'bingung': 'bingung', 'csnya': 'csnya', 'ramah': 'ramah', 'melayani': 'layan', 'pelanggan': 'langgan', 'terkait': 'kait', 'pengembalian': 'kembali', 'mengalami': 'alami', 'responnya': 'responnya', 'positif': 'positif', 'sesi': 'sesi', 'koneksi': 'koneksi', 'diputus': 'putus', 'pertimbangannya': 'timbang', 'tutup': 'tutup', 'suka': 'suka', 'pakai': 'pakai', 'buatan': 'buat', 'anak': 'anak', 'bangsa': 'bangsa', 'training': 'training', 'kompeten': 'kompeten', 'minimal ...
# ------------------------
# Pandas Apply:   0%|          | 0/1300 [00:00<?, ?it/s]

# %%
name_dataframe
# Out:
#                        Nama pengguna  Rating                Date  \
# 0                      Ryan Apriandi       1 2023-01-05 15:39:31
# 1                              Aya 4       3 2023-01-17 01:15:20
# 2                              Ranie       1 2023-01-13 02:11:50
# 3                    Fajron Musayyab       2 2023-01-11 23:20:18
# 4           Agroprobiotik Jawa Barat       2 2022-12-30 03:49:00
# ...                              ...     ...                 ...
# 1295                      FST GAMING       1 2022-09-14 18:24:38
# 1296                 Pengguna Google       1 2018-12-24 06:15:22
# 1297  Antonius Andika Riski Setiawan       1 2022-08-10 08:46:22
# 1298                    sarip kedung       3 2022-10-14 21:18:02
# 1299     Stefanus Ananda Sapta Putra       5 2022-08-31 09:29:58
#
#                                                  Ulasan  \
# 0     aplikasi parah saya belanja dengan cc pilih kl...
# 1     bagus sih cuman skrg ribet krn sering kali min...
# 2     setelah  thn ga buka akun bl barusan saya buka...
# 3     maaf saya kasih bintang   karena untuk layanan...
# 4     sy kesulitan ingin komplen masalah pembayaran ...
# ...                                                 ...
# 1295  lawak ni applikasi sudah jadi aplikasi underra...
# 1296  aplikasi kurang berkualitastidak ada bedanya d...
# 1297  terburuk dari semua aplikasi penjualan yang pe...
# 1298  biaya ongkir kurangin jangan terlalu mahalbany...
# 1299  belanja di sini belum pernah ada kekecewaan ka...
#
#                                         Ulasan_tokenize  \
# 0     [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1     [bagus, sih, cuman, skrg, ribet, krn, sering, ...
# 2     [setelah, thn, ga, buka, akun, bl, barusan, sa...
# 3     [maaf, saya, kasih, bintang, karena, untuk, la...
# 4     [sy, kesulitan, ingin, komplen, masalah, pemba...
# ...                                                 ...
# 1295  [lawak, ni, applikasi, sudah, jadi, aplikasi, ...
# 1296  [aplikasi, kurang, berkualitastidak, ada, beda...
# 1297  [terburuk, dari, semua, aplikasi, penjualan, y...
# 1298  [biaya, ongkir, kurangin, jangan, terlalu, mah...
# 1299  [belanja, di, sini, belum, pernah, ada, kekece...
#
#                                       Ulasan_normalized  \
# 0     [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1     [bagus, sih, cuman, sekarang, ribet, karena, s...
# 2     [setelah, tahun, enggak, buka, akun, bl, barus...
# 3     [maaf, saya, kasih, bintang, karena, untuk, la...
# 4     [saya, kesulitan, ingin, komplen, masalah, pem...
# ...                                                 ...
# 1295  [lawak, ini, aplikasi, sudah, jadi, aplikasi, ...
# 1296  [aplikasi, kurang, berkualitastidak, ada, beda...
# 1297  [terburuk, dari, semua, aplikasi, penjualan, y...
# 1298  [biaya, ongkir, kurangi, jangan, terlalu, maha...
# 1299  [belanja, di, sini, belum, pernah, ada, kekece...
#
#                                     Ulasan_stop_removed  \
# 0     [aplikasi, parah, belanja, cc, pilih, klik, ci...
# 1     [bagus, sih, cuman, ribet, kali, update, aplik...
# 2     [buka, akun, bl, barusan, buka, ceritanya, bar...
# 3     [maaf, kasih, bintang, layanan, customer, meng...
# 4     [kesulitan, komplen, pembayaran, paylater, no,...
# ...                                                 ...
# 1295  [lawak, aplikasi, aplikasi, underratedmasih, k...
# 1296  [aplikasi, berkualitastidak, bedanya, aplikasi...
# 1297  [terburuk, aplikasi, penjualan, akun, bekukan,...
# 1298  [biaya, ongkir, kurangi, mahalbanyakin, promo,...
# 1299  [belanja, kekecewaan, kalopun, salah, kirim, b...
#
#                                          Ulasan_Stemmed
# 0     [aplikasi, parah, belanja, cc, pilih, klik, ci...
# 1     [bagus, sih, cuman, ribet, kali, update, aplik...
# 2     [buka, akun, bl, barusan, buka, cerita, barang...
# 3     [maaf, kasih, bintang, layan, customer, aju, p...
# 4     [sulit, komplen, bayar, paylater, no, watelpon...
# ...                                                 ...
# 1295  [lawak, aplikasi, aplikasi, underratedmasih, k...
# 1296  [aplikasi, berkualitastidak, beda, aplikasi, b...
# 1297  [buruk, aplikasi, jual, akun, beku, aktif, pro...
# 1298  [biaya, ongkir, kurang, mahalbanyakin, promo, ...
# 1299  [belanja, kecewa, kalo, salah, kirim, barang, ...
#
# [1300 rows x 8 columns]

# %%
name_dataframe["Ulasan_clean"] = [' '.join(map(str, l)) for l in name_dataframe['Ulasan_Stemmed']]

# %%
name_dataframe.to_excel("tokped_text.xlsx")

# %%
ulasan = ' '.join(str(v) for v in name_dataframe['Ulasan_clean'])

# %%
tokenize_ulasan = word_tokenize(ulasan)

# %%
tokenize_ulasan
# Out:
# ['aplikasi',
#  'parah',
#  'belanja',
#  'cc',
#  'pilih',
#  'klik',
#  'cicil',
#  'tagih',
#  'full',
#  'confirmasi',
#  'urus',
#  'teman',
#  'belanja',
#  'metode',
#  'cicil',
#  'korban',
#  'kabar',
#  'bukalapak',
#  'bagus',
#  'sih',
#  'cuman',
#  'ribet',
#  'kali',
#  'update',
#  'aplikasi',
#  'susah',
#  'transaksi',
#  'susah',
#  'hp',
#  'memori',
#  'batas',
#  'hapus',
#  'paksa',
#  'aplikasi',
#  'ribet',
#  'buka',
#  'akun',
#  'bl',
#  'barusan',
#  'buka',
#  'cerita',
#  'barang',
#  'beli',
#  'harap',
#  'dibl',
#  'murah',
#  'promo',
#  'tarik',
#  'bl',
#  'tarik',
#  'barang',
#  'jual',
#  'lengkap',
#  'sekali',
#  'pilih',
#  'seller',
#  'akibat',
#  'barang',
#  'jual',
#  'mahal',
#  'marketplace',
#  'belah',
#  'saat',
#  'voucher',
#  'gratis',
#  'ongkir',
#  'bl',
#  'asih',
#  'diskon',
#  'nya',
#  'ongkir',
#  'instan',
#  'mahal',
#  'belah',
#  'maaf',
#  'kasih',
#  'bintang',
#  'layan',
#  'customer',
#  'aju',
#  'pesan',
#  'custom',
#  'bebas',
#  'sesuai',
#  'kalimat',
#  'hari',
#  'sih',
#  'beli',
#  'kes',
#  'baku',
#  'sesuai',
#  'atur',
#  'aplikasi',
#  'marketplace',
#  'toko',
#  'hijau',
#  'orange',
#  'harap',
#  'tolong',
#  'mudah',
#  'fitur',
#  'chat',
#  'bantu',
#  'terimakasih',
#  'sulit',
#  'komplen',
#  'bayar',
#  'paylater',
#  'no',
#  'watelpon',
#  'susah',
#  'aktif',
#  'membingunkan',
#  'komplen',
#  'komplen',
#  'paylater',
#  'bayar',
#  'masuk',
#  'jual',
#  'nyaman',
#  'konfirmasi',
#  'pesan',
#  'terima',
#  'batal',
#  'mau',
#  'beli',
#  'batal',
#  'batal',
#  'batal',
#  'otomasi',
#  'bukalapak',
#  'nya',
#  'kerlambatan',
#  'kirim',
#  'lakh',
#  'feedback',
#  'negatif',
#  'salah',
#  'toko',
#  'bel',
#  'plin',
#  'plan',
#  'pesan',
#  'konfirmasi',
#  'kirim',
#  'eh',
#  'batal',
#  'star',
#  'bagusmalah',
#  'menurunupdate',
#  'baru',
#  'berpengaruhhapus',
#  'cacheclear',
#  'datasama',
#  'ajaaplikasi',
#  'berat',
#  'loadingnya',
#  'tonton',
#  'streaming',
#  'hd',
#  'lancar',
#  'jaya',
#  'fitur',
#  'live',
#  'chat',
#  'tipu',
#  'kontak',
#  'cs',
#  'hubung',
#  'konsumen',
#  'aman',
#  'nyaman',
#  'belanja',
#  'cari',
#  'solusi',
#  'kendala',
#  'belanja',
#  'sulit',
#  'kayak',
#  'barang',
#  'proses',
#  'toko',
#  'batas',
#  'maksimal',
#  'kirim',
#  'dana',
#  'kali',
#  'belanja',
#  'kecewa',
#  'guna',
#  'bl',
#  'lumayan',
#  'transaksi',
#  'riwayat',
#  'status',
#  'kirim',
#  'updatenya',
#  'telat',
#  'mulu',
#  'lapak',
#  'kirim',
#  'sore',
#  'pickup',
#  'telat',
#  'pis',
#  'update',
#  'status',
#  'kirim',
#  'pesan',
#  'tolong',
#  'tambah',
#  'fitur',
#  'bukti',
#  'gambarfoto',
#  'barang',
#  'tuju',
#  'barangpesanan',
#  'terima',
#  'masuk',
#  'bual',
#  'bl',
#  'fitur',
#  'pickup',
#  'sih',
#  'cepat',
#  'kembali',
#  'fitur',
#  'bantu',
#  'klik',
#  'langsung',
#  'chat',
#  'cs',
#  'klik',
#  'chat',
#  'cs',
#  'orang',
#  'awam',
#  'bingung',
#  'chat',
#  'cs',
#  'kali',
#  'bintang',
#  'sih',
#  'csnya',
#  'ramah',
#  'layan',
#  'langgan',
#  'kait',
#  'kembali',
#  'dana',
#  'kali',
#  'alami',
#  'kendala',
#  'responnya',
#  'positif',
#  'konfirmasi',
#  'live',
#  'chat',
#  'sesi',
#  'koneksi',
#  'putus',
#  'timbang',
#  'tutup',
#  'akun',
#  'sih',
#  'suka',
#  'pakai',
#  'bukalapak',
#  'buat',
#  'anak',
#  'bangsa',
#  'nyaman',
#  'tolong',
#  'cs',
#  'training',
#  'kompeten',
#  'minimal',
#  'sikap',
#  'bobrok',
#  'mesan',
#  'cod',
#  'masuk',
#  'tagih',
#  'detail',
#  'sedia',
#  'batal',
#  'pesan',
#  'konfirmasi',
#  'toko',
#  'barang',
#  'pes',
#  'kosong',
#  'batalin',
#  'transaksi',
#  'susah',
#  'bertul',
#  'fitur',
#  'buka',
#  'bantu',
#  'emah',
#  'sesuai',
#  'kondisi',
#  'lapang',
#  'hubung',
#  'live',
#  'cs',
#  'loading',
#  'mulu',
#  'tunggu',
#  'respon',
#  'aplikasi',
#  'nenguntungkan',
#  'seller',
#  'batal',
#  'pesan',
#  'susah',
#  'buyer',
#  'butuh',
#  'tuju',
#  'seller',
#  'hatihati',
#  'kalo',
#  'belanja',
#  'chat',
#  'seller',
#  'cermat',
#  'kalo',
#  'tipu',
#  'aplikasi',
#  'untung',
#  'buyer',
#  'seller',
#  'cari',
#  'fitur',
#  'chat',
#  'cs',
#  'susah',
#  'ampun',
#  'lumayan',
#  'cari',
#  'aga',
#  'susah',
#  'kalo',
#  'ketik',
#  'merk',
#  'barang',
#  'suka',
#  'nongol',
#  'lengkap',
#  'history',
#  'kirim',
#  'cuman',
#  'ongkirnya',
#  'mnrt',
#  'aga',
#  'mahal',
#  'segi',
#  'postingan',
#  'barang',
#  'jual',
#  'lumayan',
#  'kalo',
#  'lazada',
#  'oke',
#  'diskon',
#  'cuman',
#  'kena',
#  'tipu',
#  'segi',
#  'postingan',
#  'mnrt',
#  'buka',
#  'lapak',
#  'oke',
#  'foto',
#  'produk',
#  'hilang',
#  'produk',
#  'tinggal',
#  'komplen',
#  'bukabantuan',
#  'respon',
#  'tanggapanapa',
#  'karyawannya',
#  'bl',
#  'kesini',
#  'maaf',
#  'turun',
#  'bintangnyakarena',
#  'pakai',
#  'bukalapak',
#  'paylaternya',
#  'tuju',
#  'alas',
#  'nya',
#  'transaksi',
#  'bukalapak',
#  'coba',
#  'cek',
#  'transaksi',
#  'sayaudh',
#  'hitung',
#  'tuju',
#  'paylater',
#  'sayasaya',
#  'naikin',
#  'bintang',
#  'recom',
#  'teman',
#  'terimakasih',
#  'edit',
#  'ulas',
#  'hubung',
#  'customer',
#  'care',
#  'aplikasi',
#  'kait',
#  'bukalapak',
#  'alhamdulillah',
#  'selesai',
#  'promo',
#  'bukasend',
#  'nya',
#  'murah',
#  'terkadang',
#  'trouble',
#  'mohon',
#  'baik',
#  'marketplace',
#  'minim',
#  'gratis',
#  'ongkir',
#  'itu',
#  'potong',
#  'gratis',
#  'ongkir',
#  'pakai',
#  'metode',
#  'bayar',
#  'susah',
#  'akses',
#  'bayar',
#  'nya',
#  'voucher',
#  'gratis',
#  'ongkir',
#  'laku',
#  'marketplace',
#  'serius',
#  'layan',
#  'beli',
#  'costumer',
#  'heran',
#  'bukalapak',
#  'bukalapak',
#  'buruk',
#  'barang',
#  'tampil',
#  'dasboard',
#  'toko',
#  'lapak',
#  'cari',
#  'cari',
#  'barang',
#  'tampil',
#  'ribu',
#  'lapak',
#  'kayak',
#  'barang',
#  'tampil',
#  'sesuai',
#  'kriteria',
#  'cari',
#  'beli',
#  'barang',
#  'langsung',
#  'konfirmasi',
#  'barang',
#  'buka',
#  'bantu',
#  'chat',
#  'bukalapak',
#  'hasil',
#  'solusi',
#  'jual',
#  'tipu',
#  'batal',
#  'pesan',
#  'aplikasi',
#  'jual',
#  'online',
#  'mutu',
#  'nama',
#  'aplikasi',
#  'usaha',
#  'bagus',
#  'dukung',
#  'dagang',
#  'mudah',
#  'beli',
#  'tahan',
#  'bukalapak',
#  'ekonomi',
#  'bangsa',
#  'tahan',
#  'saran',
#  'teman',
#  'teman',
#  'apk',
#  'bukalapak',
#  'terima',
#  'kasih',
#  'ya',
#  'salam',
#  'sukses',
#  'bukalapak',
#  'kecewa',
#  'buka',
#  'bantu',
#  'buka',
#  'lapak',
#  'ubah',
#  'no',
#  'hp',
#  'proses',
#  'hubung',
#  'bantu',
#  'buka',
#  'lapak',
#  'kirim',
#  'detik',
#  'ubah',
#  'payah',
#  'hasil',
#  'lapor',
#  'tunggu',
#  'jam',
#  'detik',
#  'ubah',
#  'pakai',
#  'bukalapak',
#  'kali',
#  'kecewa',
#  'beli',
#  'barang',
#  'lapak',
#  'kirim',
#  'kota',
#  'cancel',
#  'lapak',
#  'tuju',
#  'refund',
#  'dana',
#  'masuk',
#  'coba',
#  'cs',
#  'live',
#  'kali',
#  'kali',
#  'coba',
#  'tunggu',
#  'hubung',
#  'bagus',
#  'shopee',
#  'refund',
#  'dana',
#  'menit',
#  'masuk',
#  'kendala',
#  'masalahbaik',
#  'jual',
#  'pembelikurir',
#  'komplain',
#  'pihak',
#  'bukalapak',
#  'menyelesaikannyabeberapa',
#  'layan',
#  'bagusknp',
#  'buruk',
#  'ganti',
#  'ratingnya',
#  'bintang',
#  'bintang',
#  'maaf',
#  'turunin',
#  'bintang',
#  'pakai',
#  'puluh',
#  'transaksi',
#  'belanja',
#  'mitra',
#  'bukalapak',
#  'kasih',
#  'percaya',
#  'pakai',
#  'paylatter',
#  'pinjam',
#  'kecewa',
#  'beli',
#  'batal',
#  'resi',
#  'cetak',
#  'alamat',
#  'tuju',
#  'salah',
#  'jual',
#  'batal',
#  'pesan',
#  'kontak',
#  'cs',
#  'bukalapak',
#  'kesini',
#  'bukalapak',
#  'menarikpromo',
#  'menariksaya',
#  'fitur',
#  'nabung',
#  'diskon',
#  'metode',
#  'bayar',
#  'danatapi',
#  'selesai',
#  'voucher',
#  'pakai',
#  'belanja',
#  'dngn',
#  'metode',
#  'bayar',
#  'paylaterpadahal',
#  'suka',
#  'paylaterkan',
#  'ajaritu',
#  'nama',
#  'pemaksaandi',
#  'letak',
#  'profesionalitasnyamau',
#  'komplain',
#  'bukabantuan',
#  'fiturnya',
#  'susah',
#  'mengertitolong',
#  'fitur',
#  'layan',
#  'baik',
#  'kesini',
#  'sistem',
#  'nya',
#  'berat',
#  'ajabanyak',
#  'sisrem',
#  'gunabuka',
#  'apk',
#  'bl',
#  'kaya',
#  'buka',
#  'game',
#  'berat',
#  'ajaisi',
#  'harap',
#  'buang',
#  'ajadan',
#  'sistem',
#  'bagusmasuk',
#  'buka',
#  'bantu',
#  'ribetnya',
#  'ampun',
#  'beli',
#  'token',
#  'listrik',
#  'nominal',
#  'ribu',
#  'bayar',
#  'bayar',
#  'bayar',
#  'coba',
#  'bantu',
#  'pusat',
#  'bantu',
#  'bukalapak',
#  'hubungiaktifpercuma',
#  'kecewa',
#  'aneh',
#  'baru',
#  'aplikasi',
#  'ribet',
#  'pesan',
#  'salah',
#  'pilih',
#  'warna',
#  'ukur',
#  'batalin',
#  'transaksi',
#  'kecewa',
#  'banget',
#  'bukalapak',
#  'topup',
#  'pulsa',
#  'telkomsel',
#  'masuk',
#  'paylater',
#  'kuras',
#  'komplain',
#  'komplain',
#  'mohon',
#  'bantu',
#  'nya',
#  'rugi',
#  'proses',
#  'komplain',
#  'ribet',
#  'bantu',
#  'minim',
#  'voucer',
#  'enggan',
#  'belanja',
#  'produk',
#  'virtual',
#  'promo',
#  'gratis',
#  'ongkir',
#  'banget',
#  'gagal',
#  'belakang',
#  'nyaman',
#  'fitur',
#  'chat',
#  'hias',
#  'pengin',
#  'chat',
#  'robot',
#  'nomer',
#  'layan',
#  'cs',
#  'fitur',
#  'chat',
#  'twitter',
#  'tiada',
#  'fitur',
#  'chat',
#  'fb',
#  'tiada',
#  'nyaman',
#  'bukalapak',
#  'beli',
#  'batal',
#  'beli',
#  'beli',
#  'salah',
#  'tipe',
#  'jual',
#  'yag',
#  'kena',
#  'pinalty',
#  'posting',
#  'jual',
#  'batas',
#  'posting',
#  'muncul',
#  'temu',
#  'cari',
#  'saran',
#  'pakai',
#  'bayar',
#  'muncul',
#  'batas',
#  'proses',
#  'barang',
#  'beli',
#  'lamaaaaa',
#  'tambah',
#  'batas',
#  'kirim',
#  'lamaa',
#  'ekspedisi',
#  'pilih',
#  'buka',
#  'ekspresaseem',
#  'rugi',
#  'beli',
#  'customer',
#  'pesan',
#  'kamis',
#  'jumat',
#  'sabtu',
#  'hmmmmm',
#  'butuh',
#  'bukti',
#  'sila',
#  'email',
#  'gue',
#  'mengadaada',
#  'deh',
#  'bro',
#  'tolong',
#  'baik',
#  'cepat',
#  'saran',
#  'expedisi',
#  'kurir',
#  'reg',
#  'next',
#  'day',
#  'bukaexpress',
#  'pakai',
#  'sicepat',
#  'error',
#  'pick',
#  'up',
#  'kurir',
#  'lelet',
#  'kurir',
#  'kurir',
#  'kirim',
#  'criss',
#  'cross',
#  'sesuai',
#  'sop',
#  'status',
#  'resi',
#  'update',
#  'komplen',
#  'cs',
#  'ybs',
#  'solusi',
#  'percaya',
#  'kirim',
#  'konsumen',
#  'moga',
#  'baik',
#  'depan',
#  'nya',
#  'bismillahbarangnya',
#  'bagus',
#  'aplikasi',
#  'manfaat',
#  'belanja',
#  'jual',
#  'amal',
#  'moga',
#  'sukses',
#  'bukalapak',
#  'guna',
#  'nya',
#  'amin',
#  'paylater',
#  'kredivo',
#  'pakai',
#  'urus',
#  'kredivo',
#  'kaya',
#  'ribet',
#  'mending',
#  'uninstall',
#  'aja',
#  'shopee',
#  'enak',
#  'paylater',
#  'pakai',
#  'instal',
#  'paylater',
#  'kredivo',
#  'pakai',
#  'analis',
#  'kredivo',
#  'kepinteran',
#  'lulus',
#  'kaya',
#  'wkwkwk',
#  'kurang',
#  'opsi',
#  'batal',
#  'tagih',
#  'paksa',
#  'tunggu',
#  'bayar',
#  'habis',
#  'customer',
#  'kadang',
#  'ubah',
#  'pikir',
#  'transaksi',
#  'ulang',
#  'cepat',
#  'layan',
#  'customer',
#  'service',
#  'susah',
#  'ampun',
#  'urus',
#  'cair',
#  'dana',
#  'kembali',
#  'uang',
#  'nilai',
#  'lambat',
#  'hitung',
#  'berjamjam',
#  'jam',
#  'tau',
#  'sistem',
#  'lemah',
#  'sengaja',
#  'cari',
#  'keyword',
#  'luas',
#  'bukalapak',
#  'lumayan',
#  'tingkat',
#  'cepat',
#  'akses',
#  'signifikanmudahan',
#  'bukalapak',
#  'ubah',
#  'jaga',
#  'percaya',
#  'konsumen',
#  'good',
#  'good',
#  'good',
#  'layan',
#  'prima',
#  'suka',
#  'ketemu',
#  'jual',
#  'abalabal',
#  'kirim',
#  'barang',
#  'sesuai',
#  'sengaja',
#  'cenderung',
#  'tipu',
#  'mohon',
#  'seleksi',
#  'jual',
#  'aplikasi',
#  'guna',
#  'bayar',
#  'verifikasi',
#  'bayar',
#  'komplain',
#  'live',
#  'chatnya',
#  'masalah',
#  'hati',
#  'bayar',
#  'siapsiap',
#  'saldo',
#  'potong',
#  'sukses',
#  'bayar',
#  'rekomendasi',
#  'aplikasi',
#  'buruk',
#  'beli',
#  'reksadana',
#  'masalah',
#  'saldo',
#  'potong',
#  'status',
#  'tunggu',
#  'bayar',
#  'samapai',
#  'kadaluwarsa',
#  'komplain',
#  'belit',
#  'belit',
#  'chat',
#  'agen',
#  'susah',
#  'dapat',
#  'mesti',
#  'antri',
#  'mesti',
#  'stay',
#  'page',
#  'chatnya',
#  'kalo',
#  'dibatalin',
#  'tunggu',
#  'antri',
#  'chat',
#  'jam',
#  'bukalapak',
#  'baik',
#  'percaya',
#  'alam',
#  'kali',
#  'transaksi',
#  'nya',
#  'moga',
#  'bagus',
#  'apk',
#  'nya',
#  'promo',
#  'nabung',
#  'diskon',
#  'selesai',
#  'tabung',
#  'vouchernya',
#  ...]

# %%
fqdist = FreqDist(tokenize_ulasan)

# %%
fqdist
# Out:
# FreqDist({'bukalapak': 568, 'aplikasi': 474, 'nya': 400, 'barang': 382, 'bayar': 276, 'pakai': 256, 'buka': 252, 'beli': 242, 'kirim': 232, 'belanja': 219, ...})

# %%
# mencetak 15 kata paling banyak digunakan
fqdist.most_common(15)
# Out:
# [('bukalapak', 568),
#  ('aplikasi', 474),
#  ('nya', 400),
#  ('barang', 382),
#  ('bayar', 276),
#  ('pakai', 256),
#  ('buka', 252),
#  ('beli', 242),
#  ('kirim', 232),
#  ('belanja', 219),
#  ('jual', 205),
#  ('lapak', 196),
#  ('transaksi', 184),
#  ('bantu', 170),
#  ('chat', 155)]

# %%
import matplotlib.pyplot as plt

# plotting
fqdist.plot(10,cumulative=False)
plt.show()

# %%
label = []
for index, row in name_dataframe.iterrows():
    if row["Rating"] == 5 or row["Rating"] == 4:
        label.append(1)
    else:
        label.append(0)

name_dataframe["label"] = label

name_dataframe
# Out:
#                        Nama pengguna  Rating                Date  \
# 0                      Ryan Apriandi       1 2023-01-05 15:39:31
# 1                              Aya 4       3 2023-01-17 01:15:20
# 2                              Ranie       1 2023-01-13 02:11:50
# 3                    Fajron Musayyab       2 2023-01-11 23:20:18
# 4           Agroprobiotik Jawa Barat       2 2022-12-30 03:49:00
# ...                              ...     ...                 ...
# 1295                      FST GAMING       1 2022-09-14 18:24:38
# 1296                 Pengguna Google       1 2018-12-24 06:15:22
# 1297  Antonius Andika Riski Setiawan       1 2022-08-10 08:46:22
# 1298                    sarip kedung       3 2022-10-14 21:18:02
# 1299     Stefanus Ananda Sapta Putra       5 2022-08-31 09:29:58
#
#                                                  Ulasan  \
# 0     aplikasi parah saya belanja dengan cc pilih kl...
# 1     bagus sih cuman skrg ribet krn sering kali min...
# 2     setelah  thn ga buka akun bl barusan saya buka...
# 3     maaf saya kasih bintang   karena untuk layanan...
# 4     sy kesulitan ingin komplen masalah pembayaran ...
# ...                                                 ...
# 1295  lawak ni applikasi sudah jadi aplikasi underra...
# 1296  aplikasi kurang berkualitastidak ada bedanya d...
# 1297  terburuk dari semua aplikasi penjualan yang pe...
# 1298  biaya ongkir kurangin jangan terlalu mahalbany...
# 1299  belanja di sini belum pernah ada kekecewaan ka...
#
#                                         Ulasan_tokenize  \
# 0     [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1     [bagus, sih, cuman, skrg, ribet, krn, sering, ...
# 2     [setelah, thn, ga, buka, akun, bl, barusan, sa...
# 3     [maaf, saya, kasih, bintang, karena, untuk, la...
# 4     [sy, kesulitan, ingin, komplen, masalah, pemba...
# ...                                                 ...
# 1295  [lawak, ni, applikasi, sudah, jadi, aplikasi, ...
# 1296  [aplikasi, kurang, berkualitastidak, ada, beda...
# 1297  [terburuk, dari, semua, aplikasi, penjualan, y...
# 1298  [biaya, ongkir, kurangin, jangan, terlalu, mah...
# 1299  [belanja, di, sini, belum, pernah, ada, kekece...
#
#                                       Ulasan_normalized  \
# 0     [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1     [bagus, sih, cuman, sekarang, ribet, karena, s...
# 2     [setelah, tahun, enggak, buka, akun, bl, barus...
# 3     [maaf, saya, kasih, bintang, karena, untuk, la...
# 4     [saya, kesulitan, ingin, komplen, masalah, pem...
# ...                                                 ...
# 1295  [lawak, ini, aplikasi, sudah, jadi, aplikasi, ...
# 1296  [aplikasi, kurang, berkualitastidak, ada, beda...
# 1297  [terburuk, dari, semua, aplikasi, penjualan, y...
# 1298  [biaya, ongkir, kurangi, jangan, terlalu, maha...
# 1299  [belanja, di, sini, belum, pernah, ada, kekece...
#
#                                     Ulasan_stop_removed  \
# 0     [aplikasi, parah, belanja, cc, pilih, klik, ci...
# 1     [bagus, sih, cuman, ribet, kali, update, aplik...
# 2     [buka, akun, bl, barusan, buka, ceritanya, bar...
# 3     [maaf, kasih, bintang, layanan, customer, meng...
# 4     [kesulitan, komplen, pembayaran, paylater, no,...
# ...                                                 ...
# 1295  [lawak, aplikasi, aplikasi, underratedmasih, k...
# 1296  [aplikasi, berkualitastidak, bedanya, aplikasi...
# 1297  [terburuk, aplikasi, penjualan, akun, bekukan,...
# 1298  [biaya, ongkir, kurangi, mahalbanyakin, promo,...
# 1299  [belanja, kekecewaan, kalopun, salah, kirim, b...
#
#                                          Ulasan_Stemmed  \
# 0     [aplikasi, parah, belanja, cc, pilih, klik, ci...
# 1     [bagus, sih, cuman, ribet, kali, update, aplik...
# 2     [buka, akun, bl, barusan, buka, cerita, barang...
# 3     [maaf, kasih, bintang, layan, customer, aju, p...
# 4     [sulit, komplen, bayar, paylater, no, watelpon...
# ...                                                 ...
# 1295  [lawak, aplikasi, aplikasi, underratedmasih, k...
# 1296  [aplikasi, berkualitastidak, beda, aplikasi, b...
# 1297  [buruk, aplikasi, jual, akun, beku, aktif, pro...
# 1298  [biaya, ongkir, kurang, mahalbanyakin, promo, ...
# 1299  [belanja, kecewa, kalo, salah, kirim, barang, ...
#
#                                            Ulasan_clean  label
# 0     aplikasi parah belanja cc pilih klik cicil tag...      0
# 1     bagus sih cuman ribet kali update aplikasi sus...      0
# 2     buka akun bl barusan buka cerita barang beli h...      0
# 3     maaf kasih bintang layan customer aju pesan cu...      0
# 4     sulit komplen bayar paylater no watelpon susah...      0
# ...                                                 ...    ...
# 1295  lawak aplikasi aplikasi underratedmasih konyol...      0
# 1296  aplikasi berkualitastidak beda aplikasi belah ...      0
# 1297  buruk aplikasi jual akun beku aktif produk mun...      0
# 1298  biaya ongkir kurang mahalbanyakin promo gratis...      0
# 1299  belanja kecewa kalo salah kirim barang proses ...      1
#
# [1300 rows x 10 columns]

# %%
#create a user define function to find out polarity & subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

#creating another user define function to label the sentiment 

def getSentiment(value):
    if value<0:
        return 'Negative'
    elif value==0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
name_dataframe.head()
# Out:
#               Nama pengguna  Rating                Date  \
# 0             Ryan Apriandi       1 2023-01-05 15:39:31
# 1                     Aya 4       3 2023-01-17 01:15:20
# 2                     Ranie       1 2023-01-13 02:11:50
# 3           Fajron Musayyab       2 2023-01-11 23:20:18
# 4  Agroprobiotik Jawa Barat       2 2022-12-30 03:49:00
#
#                                               Ulasan  \
# 0  aplikasi parah saya belanja dengan cc pilih kl...
# 1  bagus sih cuman skrg ribet krn sering kali min...
# 2  setelah  thn ga buka akun bl barusan saya buka...
# 3  maaf saya kasih bintang   karena untuk layanan...
# 4  sy kesulitan ingin komplen masalah pembayaran ...
#
#                                      Ulasan_tokenize  \
# 0  [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1  [bagus, sih, cuman, skrg, ribet, krn, sering, ...
# 2  [setelah, thn, ga, buka, akun, bl, barusan, sa...
# 3  [maaf, saya, kasih, bintang, karena, untuk, la...
# 4  [sy, kesulitan, ingin, komplen, masalah, pemba...
#
#                                    Ulasan_normalized  \
# 0  [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1  [bagus, sih, cuman, sekarang, ribet, karena, s...
# 2  [setelah, tahun, enggak, buka, akun, bl, barus...
# 3  [maaf, saya, kasih, bintang, karena, untuk, la...
# 4  [saya, kesulitan, ingin, komplen, masalah, pem...
#
#                                  Ulasan_stop_removed  \
# 0  [aplikasi, parah, belanja, cc, pilih, klik, ci...
# 1  [bagus, sih, cuman, ribet, kali, update, aplik...
# 2  [buka, akun, bl, barusan, buka, ceritanya, bar...
# 3  [maaf, kasih, bintang, layanan, customer, meng...
# 4  [kesulitan, komplen, pembayaran, paylater, no,...
#
#                                       Ulasan_Stemmed  \
# 0  [aplikasi, parah, belanja, cc, pilih, klik, ci...
# 1  [bagus, sih, cuman, ribet, kali, update, aplik...
# 2  [buka, akun, bl, barusan, buka, cerita, barang...
# 3  [maaf, kasih, bintang, layan, customer, aju, p...
# 4  [sulit, komplen, bayar, paylater, no, watelpon...
#
#                                         Ulasan_clean  label
# 0  aplikasi parah belanja cc pilih klik cicil tag...      0
# 1  bagus sih cuman ribet kali update aplikasi sus...      0
# 2  buka akun bl barusan buka cerita barang beli h...      0
# 3  maaf kasih bintang layan customer aju pesan cu...      0
# 4  sulit komplen bayar paylater no watelpon susah...      0

# %%
from textblob import TextBlob

# %%
def run_vader(name_dataframe):
    # Generate VADER sentiment analyzer object
    sid = SentimentIntensityAnalyzer()

# %%
name_dataframe['Polarity']=name_dataframe['Ulasan_clean'].apply(getPolarity)
name_dataframe['Subjectivity']=name_dataframe['Ulasan_clean'].apply(getSubjectivity)
name_dataframe['Sentiment']=name_dataframe['Polarity'].apply(getSentiment)
name_dataframe.head()
# Out:
#               Nama pengguna  Rating                Date  \
# 0             Ryan Apriandi       1 2023-01-05 15:39:31
# 1                     Aya 4       3 2023-01-17 01:15:20
# 2                     Ranie       1 2023-01-13 02:11:50
# 3           Fajron Musayyab       2 2023-01-11 23:20:18
# 4  Agroprobiotik Jawa Barat       2 2022-12-30 03:49:00
#
#                                               Ulasan  \
# 0  aplikasi parah saya belanja dengan cc pilih kl...
# 1  bagus sih cuman skrg ribet krn sering kali min...
# 2  setelah  thn ga buka akun bl barusan saya buka...
# 3  maaf saya kasih bintang   karena untuk layanan...
# 4  sy kesulitan ingin komplen masalah pembayaran ...
#
#                                      Ulasan_tokenize  \
# 0  [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1  [bagus, sih, cuman, skrg, ribet, krn, sering, ...
# 2  [setelah, thn, ga, buka, akun, bl, barusan, sa...
# 3  [maaf, saya, kasih, bintang, karena, untuk, la...
# 4  [sy, kesulitan, ingin, komplen, masalah, pemba...
#
#                                    Ulasan_normalized  \
# 0  [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1  [bagus, sih, cuman, sekarang, ribet, karena, s...
# 2  [setelah, tahun, enggak, buka, akun, bl, barus...
# 3  [maaf, saya, kasih, bintang, karena, untuk, la...
# 4  [saya, kesulitan, ingin, komplen, masalah, pem...
#
#                                  Ulasan_stop_removed  \
# 0  [aplikasi, parah, belanja, cc, pilih, klik, ci...
# 1  [bagus, sih, cuman, ribet, kali, update, aplik...
# 2  [buka, akun, bl, barusan, buka, ceritanya, bar...
# 3  [maaf, kasih, bintang, layanan, customer, meng...
# 4  [kesulitan, komplen, pembayaran, paylater, no,...
#
#                                       Ulasan_Stemmed  \
# 0  [aplikasi, parah, belanja, cc, pilih, klik, ci...
# 1  [bagus, sih, cuman, ribet, kali, update, aplik...
# 2  [buka, akun, bl, barusan, buka, cerita, barang...
# 3  [maaf, kasih, bintang, layan, customer, aju, p...
# 4  [sulit, komplen, bayar, paylater, no, watelpon...
#
#                                         Ulasan_clean  label  Polarity  \
# 0  aplikasi parah belanja cc pilih klik cicil tag...      0      0.35
# 1  bagus sih cuman ribet kali update aplikasi sus...      0      0.00
# 2  buka akun bl barusan buka cerita barang beli h...      0      0.00
# 3  maaf kasih bintang layan customer aju pesan cu...      0      0.00
# 4  sulit komplen bayar paylater no watelpon susah...      0      0.00
#
#    Subjectivity Sentiment
# 0          0.55  Positive
# 1          0.00   Neutral
# 2          0.00   Neutral
# 3          0.00   Neutral
# 4          0.00   Neutral

# %%
name_dataframe
# Out:
#                        Nama pengguna  Rating                Date  \
# 0                      Ryan Apriandi       1 2023-01-05 15:39:31
# 1                              Aya 4       3 2023-01-17 01:15:20
# 2                              Ranie       1 2023-01-13 02:11:50
# 3                    Fajron Musayyab       2 2023-01-11 23:20:18
# 4           Agroprobiotik Jawa Barat       2 2022-12-30 03:49:00
# ...                              ...     ...                 ...
# 1295                      FST GAMING       1 2022-09-14 18:24:38
# 1296                 Pengguna Google       1 2018-12-24 06:15:22
# 1297  Antonius Andika Riski Setiawan       1 2022-08-10 08:46:22
# 1298                    sarip kedung       3 2022-10-14 21:18:02
# 1299     Stefanus Ananda Sapta Putra       5 2022-08-31 09:29:58
#
#                                                  Ulasan  \
# 0     aplikasi parah saya belanja dengan cc pilih kl...
# 1     bagus sih cuman skrg ribet krn sering kali min...
# 2     setelah  thn ga buka akun bl barusan saya buka...
# 3     maaf saya kasih bintang   karena untuk layanan...
# 4     sy kesulitan ingin komplen masalah pembayaran ...
# ...                                                 ...
# 1295  lawak ni applikasi sudah jadi aplikasi underra...
# 1296  aplikasi kurang berkualitastidak ada bedanya d...
# 1297  terburuk dari semua aplikasi penjualan yang pe...
# 1298  biaya ongkir kurangin jangan terlalu mahalbany...
# 1299  belanja di sini belum pernah ada kekecewaan ka...
#
#                                         Ulasan_tokenize  \
# 0     [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1     [bagus, sih, cuman, skrg, ribet, krn, sering, ...
# 2     [setelah, thn, ga, buka, akun, bl, barusan, sa...
# 3     [maaf, saya, kasih, bintang, karena, untuk, la...
# 4     [sy, kesulitan, ingin, komplen, masalah, pemba...
# ...                                                 ...
# 1295  [lawak, ni, applikasi, sudah, jadi, aplikasi, ...
# 1296  [aplikasi, kurang, berkualitastidak, ada, beda...
# 1297  [terburuk, dari, semua, aplikasi, penjualan, y...
# 1298  [biaya, ongkir, kurangin, jangan, terlalu, mah...
# 1299  [belanja, di, sini, belum, pernah, ada, kekece...
#
#                                       Ulasan_normalized  \
# 0     [aplikasi, parah, saya, belanja, dengan, cc, p...
# 1     [bagus, sih, cuman, sekarang, ribet, karena, s...
# 2     [setelah, tahun, enggak, buka, akun, bl, barus...
# 3     [maaf, saya, kasih, bintang, karena, untuk, la...
# 4     [saya, kesulitan, ingin, komplen, masalah, pem...
# ...                                                 ...
# 1295  [lawak, ini, aplikasi, sudah, jadi, aplikasi, ...
# 1296  [aplikasi, kurang, berkualitastidak, ada, beda...
# 1297  [terburuk, dari, semua, aplikasi, penjualan, y...
# 1298  [biaya, ongkir, kurangi, jangan, terlalu, maha...
# 1299  [belanja, di, sini, belum, pernah, ada, kekece...
#
#                                     Ulasan_stop_removed  \
# 0     [aplikasi, parah, belanja, cc, pilih, klik, ci...
# 1     [bagus, sih, cuman, ribet, kali, update, aplik...
# 2     [buka, akun, bl, barusan, buka, ceritanya, bar...
# 3     [maaf, kasih, bintang, layanan, customer, meng...
# 4     [kesulitan, komplen, pembayaran, paylater, no,...
# ...                                                 ...
# 1295  [lawak, aplikasi, aplikasi, underratedmasih, k...
# 1296  [aplikasi, berkualitastidak, bedanya, aplikasi...
# 1297  [terburuk, aplikasi, penjualan, akun, bekukan,...
# 1298  [biaya, ongkir, kurangi, mahalbanyakin, promo,...
# 1299  [belanja, kekecewaan, kalopun, salah, kirim, b...
#
#                                          Ulasan_Stemmed  \
# 0     [aplikasi, parah, belanja, cc, pilih, klik, ci...
# 1     [bagus, sih, cuman, ribet, kali, update, aplik...
# 2     [buka, akun, bl, barusan, buka, cerita, barang...
# 3     [maaf, kasih, bintang, layan, customer, aju, p...
# 4     [sulit, komplen, bayar, paylater, no, watelpon...
# ...                                                 ...
# 1295  [lawak, aplikasi, aplikasi, underratedmasih, k...
# 1296  [aplikasi, berkualitastidak, beda, aplikasi, b...
# 1297  [buruk, aplikasi, jual, akun, beku, aktif, pro...
# 1298  [biaya, ongkir, kurang, mahalbanyakin, promo, ...
# 1299  [belanja, kecewa, kalo, salah, kirim, barang, ...
#
#                                            Ulasan_clean  label  Polarity  \
# 0     aplikasi parah belanja cc pilih klik cicil tag...      0      0.35
# 1     bagus sih cuman ribet kali update aplikasi sus...      0      0.00
# 2     buka akun bl barusan buka cerita barang beli h...      0      0.00
# 3     maaf kasih bintang layan customer aju pesan cu...      0      0.00
# 4     sulit komplen bayar paylater no watelpon susah...      0      0.00
# ...                                                 ...    ...       ...
# 1295  lawak aplikasi aplikasi underratedmasih konyol...      0      0.00
# 1296  aplikasi berkualitastidak beda aplikasi belah ...      0      0.00
# 1297  buruk aplikasi jual akun beku aktif produk mun...      0      0.00
# 1298  biaya ongkir kurang mahalbanyakin promo gratis...      0      0.00
# 1299  belanja kecewa kalo salah kirim barang proses ...      1      0.00
#
#       Subjectivity Sentiment
# 0             0.55  Positive
# 1             0.00   Neutral
# 2             0.00   Neutral
# 3             0.00   Neutral
# 4             0.00   Neutral
# ...            ...       ...
# 1295          0.00   Neutral
# 1296          0.00   Neutral
# 1297          0.00   Neutral
# 1298          0.00   Neutral
# 1299          0.00   Neutral
#
# [1300 rows x 13 columns]

# %%
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_pos = name_dataframe[ name_dataframe['Sentiment'] == 'Positive']
train_pos = train_pos['Ulasan_clean']
train_neg = name_dataframe[ name_dataframe['Sentiment'] == 'Negative']
train_neg = train_neg['Ulasan_clean']
train_net = name_dataframe[ name_dataframe['Sentiment'] == 'Neutral']
train_net = train_net['Ulasan_clean']

def wordcloud_draw(data, color = 'black'):
    words = ' '.join(data)
    cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT'
                            ])
    wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color=color,
                      width=2500,
                      height=2000
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    
print("Positive words")
wordcloud_draw(train_pos,'white')
print("Negative words")
wordcloud_draw(train_neg)
print("c words")
wordcloud_draw(train_net,'#ccd5ae')
# Out:
# Positive words
# Negative words
# Neutral words

# %%
sentimen_data=pd.value_counts(name_dataframe["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["green", "red", "black"])
plt.title('Bar chart')
plt.show()

# %%
name_dataframe["Sentiment"].value_counts()
# Out:
# Neutral     1054
# Positive     205
# Negative      41
# Name: Sentiment, dtype: int64

# %%
name_dataframe["Sentiment"].value_counts()
# Out:
# Neutral     1054
# Positive     205
# Negative      41
# Name: Sentiment, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
Ulasan = name_dataframe['Ulasan_clean']

# %%
Ulasan.isnull().sum()
# Out:
# 0

# %%
#untuk menghitung jumlah kata yang telah di steming
cv = CountVectorizer()
term_fit = cv.fit(Ulasan)

print (len(term_fit.vocabulary_))
# Out:
# 3500

# %%
term_fit.vocabulary_ #mengurutkan berdasarkan urutab abjad kata
# Out:
# {'aplikasi': 168,
#  'parah': 2305,
#  'belanja': 347,
#  'cc': 634,
#  'pilih': 2459,
#  'klik': 1542,
#  'cicil': 673,
#  'tagih': 3092,
#  'full': 1055,
#  'confirmasi': 692,
#  'urus': 3392,
#  'teman': 3152,
#  'metode': 1978,
#  'korban': 1599,
#  'kabar': 1396,
#  'bukalapak': 536,
#  'bagus': 230,
#  'sih': 2958,
#  'cuman': 714,
#  'ribet': 2683,
#  'kali': 1419,
#  'update': 3373,
#  'susah': 3069,
#  'transaksi': 3283,
#  'hp': 1220,
#  'memori': 1930,
#  'batas': 309,
#  'hapus': 1172,
#  'paksa': 2297,
#  'buka': 529,
#  'akun': 88,
#  'bl': 459,
#  'barusan': 302,
#  'cerita': 655,
#  'barang': 283,
#  'beli': 351,
#  'harap': 1174,
#  'dibl': 807,
#  'murah': 2044,
#  'promo': 2546,
#  'tarik': 3126,
#  'jual': 1382,
#  'lengkap': 1748,
#  'sekali': 2829,
#  'seller': 2855,
#  'akibat': 72,
#  'mahal': 1829,
#  'marketplace': 1880,
#  'belah': 345,
#  'saat': 2723,
#  'voucher': 3434,
#  'gratis': 1126,
#  'ongkir': 2222,
#  'asih': 197,
#  'diskon': 861,
#  'nya': 2163,
#  'instan': 1288,
#  'maaf': 1821,
#  'kasih': 1444,
#  'bintang': 440,
#  'layan': 1728,
#  'customer': 720,
#  'aju': 65,
#  'pesan': 2444,
#  'custom': 719,
#  'bebas': 329,
#  'sesuai': 2919,
#  'kalimat': 1421,
#  'hari': 1178,
#  'kes': 1516,
#  'baku': 256,
#  'atur': 210,
#  'toko': 3254,
#  'hijau': 1208,
#  'orange': 2248,
#  'tolong': 3268,
#  'mudah': 2031,
#  'fitur': 1039,
#  'chat': 661,
#  'bantu': 276,
#  'terimakasih': 3180,
#  'sulit': 3054,
#  'komplen': 1569,
#  'bayar': 318,
#  'paylater': 2335,
#  'no': 2133,
#  'watelpon': 3458,
#  'aktif': 78,
#  'membingunkan': 1926,
#  'masuk': 1895,
#  'nyaman': 2179,
#  'konfirmasi': 1581,
#  'terima': 3176,
#  'batal': 305,
#  'mau': 1905,
#  'otomasi': 2258,
#  'kerlambatan': 1514,
#  'kirim': 1539,
#  'lakh': 1671,
#  'feedback': 1026,
#  'negatif': 2074,
#  'salah': 2735,
#  'bel': 343,
#  'plin': 2482,
#  'plan': 2471,
#  'eh': 939,
#  'star': 3027,
#  'bagusmalah': 238,
#  'menurunupdate': 1964,
#  'baru': 301,
#  'berpengaruhhapus': 415,
#  'cacheclear': 607,
#  'datasama': 751,
#  'ajaaplikasi': 50,
#  'berat': 380,
#  'loadingnya': 1788,
#  'tonton': 3272,
#  'streaming': 3040,
#  'hd': 1190,
#  'lancar': 1688,
#  'jaya': 1349,
#  'live': 1780,
#  'tipu': 3239,
#  'kontak': 1591,
#  'cs': 706,
#  'hubung': 1224,
#  'konsumen': 1589,
#  'aman': 114,
#  'cari': 623,
#  'solusi': 3007,
#  'kendala': 1497,
#  'kayak': 1454,
#  'proses': 2553,
#  'maksimal': 1840,
#  'dana': 735,
#  'kecewa': 1465,
#  'guna': 1136,
#  'lumayan': 1811,
#  'riwayat': 2699,
#  'status': 3029,
#  'updatenya': 3377,
#  'telat': 3140,
#  'mulu': 2039,
#  'lapak': 1704,
#  'sore': 3012,
#  'pickup': 2455,
#  'pis': 2468,
#  'tambah': 3103,
#  'bukti': 584,
#  'gambarfoto': 1067,
#  'tuju': 3313,
#  'barangpesanan': 294,
#  'bual': 521,
#  'cepat': 644,
#  'kembali': 1491,
#  'langsung': 1699,
#  'orang': 2247,
#  'awam': 217,
#  'bingung': 439,
#  'csnya': 707,
#  'ramah': 2591,
#  'langgan': 1695,
#  'kait': 1413,
#  'alami': 94,
#  'responnya': 2669,
#  'positif': 2506,
#  'sesi': 2918,
#  'koneksi': 1580,
#  'putus': 2581,
#  'timbang': 3226,
#  'tutup': 3330,
#  'suka': 3048,
#  'pakai': 2291,
#  'buat': 523,
#  'anak': 125,
#  'bangsa': 272,
#  'training': 3279,
#  'kompeten': 1558,
#  'minimal': 1986,
#  'sikap': 2963,
#  'bobrok': 482,
#  'mesan': 1974,
#  'cod': 681,
#  'detail': 783,
#  'sedia': 2819,
#  'pes': 2443,
#  'kosong': 1602,
#  'batalin': 306,
#  'bertul': 419,
#  'emah': 955,
#  'kondisi': 1579,
#  'lapang': 1716,
#  'loading': 1787,
#  'tunggu': 3322,
#  'respon': 2666,
#  'nenguntungkan': 2079,
#  'buyer': 599,
#  'butuh': 598,
#  'hatihati': 1189,
#  'kalo': 1423,
#  'cermat': 656,
#  'untung': 3370,
#  'ampun': 121,
#  'aga': 37,
#  'ketik': 1528,
#  'merk': 1972,
#  'nongol': 2145,
#  'history': 1213,
#  'ongkirnya': 2227,
#  'mnrt': 2006,
#  'segi': 2824,
#  'postingan': 2509,
#  'lazada': 1731,
#  'oke': 2204,
#  'kena': 1494,
#  'foto': 1051,
#  'produk': 2533,
#  'hilang': 1209,
#  'tinggal': 3229,
#  'bukabantuan': 531,
#  'tanggapanapa': 3116,
#  'karyawannya': 1441,
#  'kesini': 1520,
#  'turun': 3325,
#  'bintangnyakarena': 441,
#  'paylaternya': 2338,
#  'alas': 95,
#  'coba': 679,
#  'cek': 635,
#  'sayaudh': 2791,
#  'hitung': 1214,
#  'sayasaya': 2787,
#  'naikin': 2058,
#  'recom': 2624,
#  'edit': 930,
#  'ulas': 3348,
#  'care': 622,
#  'alhamdulillah': 102,
#  'selesai': 2850,
#  'bukasend': 580,
#  'terkadang': 3186,
#  'trouble': 3303,
#  'mohon': 2018,
#  'baik': 252,
#  'minim': 1985,
#  'itu': 1314,
#  'potong': 2511,
#  'akses': 75,
#  'laku': 1672,
#  'serius': 2904,
#  'costumer': 700,
#  'heran': 1201,
#  'buruk': 595,
#  'tampil': 3105,
#  'dasboard': 746,
#  'ribu': 2688,
#  'kriteria': 1615,
#  'hasil': 1186,
#  'online': 2233,
#  'mutu': 2054,
#  'nama': 2062,
#  'usaha': 3395,
#  'dukung': 910,
#  'dagang': 728,
#  'tahan': 3095,
#  'ekonomi': 940,
#  'saran': 2771,
#  'apk': 161,
#  'ya': 3484,
#  'salam': 2739,
#  'sukses': 3051,
#  'ubah': 3336,
#  'detik': 785,
#  'payah': 2331,
#  'lapor': 1717,
#  'jam': 1331,
#  'kota': 1604,
#  'cancel': 615,
#  'refund': 2633,
#  'shopee': 2939,
#  'menit': 1957,
#  'masalahbaik': 1887,
#  'pembelikurir': 2384,
#  'komplain': 1565,
#  'pihak': 2456,
#  'menyelesaikannyabeberapa': 1965,
#  'bagusknp': 237,
#  'ganti': 1077,
#  'ratingnya': 2602,
#  'turunin': 3326,
#  'puluh': 2572,
#  'mitra': 2000,
#  'percaya': 2419,
#  'paylatter': 2344,
#  'pinjam': 2465,
#  'resi': 2662,
#  'cetak': 657,
#  'alamat': 92,
#  'menarikpromo': 1936,
#  'menariksaya': 1937,
#  'nabung': 2055,
#  'danatapi': 737,
#  'dngn': 882,
#  'paylaterpadahal': 2340,
#  'paylaterkan': 2337,
#  'ajaritu': 60,
#  'pemaksaandi': 2376,
#  'letak': 1755,
#  'profesionalitasnyamau': 2538,
#  'fiturnya': 1041,
#  'mengertitolong': 1949,
#  'sistem': 2982,
#  'ajabanyak': 51,
#  'sisrem': 2981,
#  'gunabuka': 1137,
#  'kaya': 1453,
#  'game': 1070,
#  'ajaisi': 54,
#  'buang': 522,
#  'ajadan': 52,
#  'bagusmasuk': 239,
#  'ribetnya': 2686,
#  'token': 3249,
#  'listrik': 1779,
#  'nominal': 2137,
#  'pusat': 2575,
#  'hubungiaktifpercuma': 1225,
#  'aneh': 133,
#  'warna': 3454,
#  'ukur': 3345,
#  'banget': 264,
#  'topup': 3274,
#  'pulsa': 2569,
#  'telkomsel': 3148,
#  'kuras': 1633,
#  'rugi': 2713,
#  'voucer': 3433,
#  'enggan': 971,
#  'virtual': 3427,
#  'gagal': 1059,
#  'belakang': 346,
#  'hias': 1206,
#  'pengin': 2400,
#  'robot': 2700,
#  'nomer': 2136,
#  'twitter': 3331,
#  'tiada': 3214,
#  'fb': 1023,
#  'tipe': 3236,
#  'yag': 3487,
#  'pinalty': 2462,
#  'posting': 2508,
#  'muncul': 2042,
#  'temu': 3157,
#  'lamaaaaa': 1676,
#  'lamaa': 1674,
#  'ekspedisi': 945,
#  'ekspresaseem': 950,
#  'kamis': 1426,
#  'jumat': 1390,
#  'sabtu': 2725,
#  'hmmmmm': 1216,
#  'sila': 2965,
#  'email': 957,
#  'gue': 1134,
#  'mengadaada': 1942,
#  'deh': 764,
#  'bro': 514,
#  'expedisi': 999,
#  'kurir': 1634,
#  'reg': 2635,
#  'next': 2082,
#  'day': 752,
#  'bukaexpress': 534,
#  'sicepat': 2954,
#  'error': 985,
#  'pick': 2454,
#  'up': 3372,
#  'lelet': 1736,
#  'criss': 703,
#  'cross': 705,
#  'sop': 3009,
#  'ybs': 3492,
#  'moga': 2017,
#  'depan': 775,
#  'bismillahbarangnya': 454,
#  'manfaat': 1859,
#  'amal': 113,
#  'amin': 119,
#  'kredivo': 1612,
#  'mending': 1939,
#  'uninstall': 3359,
#  'aja': 48,
#  'enak': 964,
#  'instal': 1286,
#  'analis': 126,
#  'kepinteran': 1505,
#  'lulus': 1810,
#  'wkwkwk': 3473,
#  'kurang': 1631,
#  'opsi': 2243,
#  'habis': 1143,
#  'kadang': 1407,
#  'pikir': 2457,
#  'ulang': 3346,
#  'service': 2912,
#  'cair': 608,
#  'uang': 3335,
#  'nilai': 2127,
#  'lambat': 1682,
#  'berjamjam': 398,
#  'tau': 3129,
#  'lemah': 1739,
#  'sengaja': 2881,
#  'keyword': 1531,
#  'luas': 1805,
#  'tingkat': 3232,
#  'signifikanmudahan': 2957,
#  'jaga': 1320,
#  'good': 1113,
#  'prima': 2525,
#  'ketemu': 1524,
#  'abalabal': 2,
#  'cenderung': 640,
#  'seleksi': 2847,
#  'verifikasi': 3415,
#  'chatnya': 663,
#  'masalah': 1886,
#  'hati': 1187,
#  'siapsiap': 2952,
#  'saldo': 2740,
#  'rekomendasi': 2650,
#  'reksadana': 2653,
#  'samapai': 2744,
#  'kadaluwarsa': 1405,
#  'belit': 355,
#  'agen': 40,
#  'dapat': 740,
#  'mesti': 1976,
#  'antri': 150,
#  'stay': 3030,
#  'page': 2285,
#  'dibatalin': 803,
#  'alam': 91,
#  'tabung': 3089,
#  'vouchernya': 3436,
#  'menu': 1962,
#  'dasar': 745,
#  'bikin': 436,
#  'nipu': 2130,
#  'beda': 332,
#  'kudu': 1622,
#  'goceng': 1107,
#  'minggu': 1984,
#  'jelas': 1354,
#  'paket': 2294,
#  'tawar': 3130,
#  'suruh': 3066,
#  'tindak': 3227,
#  'tibatiba': 3216,
#  'bukadompet': 532,
#  'beku': 340,
#  'nyangkut': 2184,
#  'ikut': 1244,
#  'langkah': 1698,
#  'poto': 2510,
#  'buku': 585,
#  'rekening': 2647,
#  'ktp': 1617,
#  'telpon': 3150,
#  'benarbenar': 360,
#  'tiket': 3224,
#  'tani': 3121,
#  'jalan': 1329,
#  'uiux': 3343,
#  'rapi': 2598,
#  'fleksibel': 1044,
#  'order': 2254,
#  'rumah': 2715,
#  'jos': 1376,
#  'ragu': 2585,
#  'simple': 2969,
#  'gamblangbaik': 1068,
#  'cashcod': 630,
#  'mantap': 1866,
#  'wes': 3463,
#  'mencet': 1938,
#  'tombol': 3271,
#  'close': 678,
#  'pencet': 2394,
#  'disiniisi': 857,
#  'semuasaya': 2874,
#  'lepas': 1754,
#  'tangan': 3110,
#  'limit': 1770,
#  'akulakutapi': 87,
#  'tagihansaya': 3094,
#  'tanganini': 3111,
#  'lucupelanggannya': 1809,
#  'wakil': 3450,
#  'sembunyi': 2866,
#  'untum': 3369,
#  'hadap': 1146,
#  'protes': 2556,
#  'sebentar': 2809,
#  'tipikal': 3237,
#  'bodo': 483,
#  'yanh': 3490,
#  'link': 1774,
#  'lucu': 1808,
#  'lengkapbnyk': 1750,
#  'promopilihan': 2548,
#  'pembayarandan': 2377,
#  'vouchersemog': 3439,
#  'favorit': 1022,
#  'lagigratis': 1651,
#  'adaflash': 17,
#  'deal': 758,
#  'menarikdan': 1935,
#  'andal': 129,
#  'serbu': 2898,
#  'seruyang': 2909,
#  'peluang': 2373,
#  'menang': 1934,
#  'juta': 1393,
#  'banding': 262,
#  'bukalapaktpi': 569,
#  'amat': 117,
#  'inti': 1299,
#  'harga': 1175,
#  'ngluarin': 2112,
#  'vouchermending': 3435,
#  'lazadashopee': 1732,
#  'bahasa': 250,
#  'marketing': 1877,
#  'bilang': 437,
#  'puas': 2563,
#  'pokok': 2496,
#  'is': 1305,
#  'the': 3210,
#  'best': 424,
#  'lengkapbagus': 1749,
#  'penuh': 2412,
#  'discount': 852,
#  'vocher': 3431,
#  'oknum': 2211,
#  'atas': 204,
#  'partner': 2318,
#  'situ': 2986,
#  'mati': 1903,
#  'sayang': 2784,
#  'macet': 1823,
#  'free': 1052,
#  'berbelitbelit': 386,
#  'trik': 3295,
#  'cekout': 637,
#  'vocer': 3429,
#  'anu': 152,
#  'jenis': 1367,
#  'ogah': 2200,
#  'ganggu': 1075,
#  'pembayaranya': 2381,
#  'arror': 190,
#  'mas': 1883,
#  'kemarin': 1489,
#  'tanggal': 3113,
#  'payleter': 2347,
#  'mbangking': 1910,
#  'baca': 224,
#  'sinyal': 2976,
#  'jelek': 1363,
#  'muter': 2051,
#  'cencel': 639,
#  'mutasi': 2050,
#  'hubungin': 1227,
#  'whatapps': 3464,
#  'ambil': 118,
#  'tempat': 3154,
#  'hemat': 1199,
#  'and': 128,
#  'keep': 1475,
#  'fighting': 1029,
#  'ok': 2203,
#  'nih': 2119,
#  'complain': 687,
#  'debat': 760,
#  'maju': 1835,
#  'lebih': 1735,
#  'boncos': 490,
#  'promonya': 2547,
#  'honest': 1219,
#  'review': 2677,
#  'keren': 1508,
#  'gampang': 1072,
#  'kagak': 1411,
#  'kpake': 1606,
#  'planggan': 2472,
#  'aktipin': 82,
#  'printer': 2526,
#  'barangpadahal': 292,
#  'lot': 1800,
#  'ngelag': 2097,
#  'tang': 3107,
#  'kesi': 1519,
#  'sellernya': 2857,
#  'praktisgk': 2520,
#  'ribetnamun': 2685,
#  'unsur': 3363,
#  'adakalo': 20,
#  'kurirnyaterutama': 1635,
#  'blanja': 461,
#  'app': 181,
#  'detil': 786,
#  'profesional': 2537,
#  'lacak': 1644,
#  'nyauntuk': 2190,
#  'lunas': 1814,
#  'jatuh': 1345,
#  'tempo': 3155,
#  'bulan': 587,
#  'koplain': 1598,
#  'setan': 2921,
#  'daftar': 725,
#  'nik': 2124,
#  'kakak': 1415,
#  'apikasi': 160,
#  'perban': 2418,
#  'apaapa': 155,
#  'admin': 28,
#  'parahhhh': 2307,
#  'lihat': 1769,
#  'hantu': 1170,
#  'via': 3422,
#  'pc': 2353,
#  'mobile': 2009,
#  'transfer': 3288,
#  'tanggap': 3114,
#  'ada': 14,
#  'biaya': 431,
#  'unuk': 3371,
#  'harus': 1184,
#  'akhirmya': 71,
#  'kadaluarsa': 1401,
#  'lampir': 1686,
#  'gambar': 1066,
#  'baja': 253,
#  'anjeng': 141,
#  'web': 3461,
#  'modal': 2010,
#  'putar': 2578,
#  'bukapak': 576,
#  'gede': 1085,
#  'bos': 495,
#  'bukalapakbangkrut': 537,
#  'errorresi': 987,
#  'jne': 1373,
#  'trucking': 3304,
#  'otomatismau': 2265,
#  'adaga': 18,
#  'bisalive': 448,
#  'fungsi': 1056,
#  'alhasil': 103,
#  'telfon': 3146,
#  'untjk': 3365,
#  'mana': 1851,
#  'otomatis': 2260,
#  'pegawai': 2359,
#  'makan': 1836,
#  'batu': 314,
#  'nasi': 2070,
#  'biar': 430,
#  'kerja': 1510,
#  'sarat': 2773,
#  'alih': 107,
#  'tatanan': 3128,
#  'friendly': 1054,
#  'turut': 3328,
#  'lainlainnya': 1667,
#  'jahat': 1322,
#  'terang': 3166,
#  'dampak': 734,
#  'beribas': 393,
#  'jshat': 1379,
#  'sumpah': 3056,
#  'tegaaaa': 3134,
#  'durasi': 916,
#  'stock': 3035,
#  'merespon': 1971,
#  'rubah': 2710,
#  'realtime': 2619,
#  'info': 1263,
#  'buruburu': 594,
#  'syarat': 3078,
#  'bentar': 368,
#  'pergi': 2423,
#  'hey': 1202,
#  'data': 748,
#  'ss': 3023,
#  'apa': 154,
#  'kabur': 1398,
#  'estimasi': 991,
#  'segitu': 2825,
#  'habisrefund': 1144,
#  'lupa': 1816,
#  'password': 2323,
#  'yth': 3496,
#  'pt': 2561,
#  'prakerja': 2516,
#  'kode': 1548,
#  'kupon': 1630,
#  'latih': 1722,
#  'akal': 68,
#  'sebelumsebelumnya': 2808,
#  'tim': 3225,
#  'tokennya': 3251,
#  'commerce': 684,
#  'tulis': 3318,
#  'muat': 2029,
#  'jaring': 1343,
#  'stabil': 3025,
#  'bego': 336,
#  'gara': 1080,
#  'denda': 769,
#  'taih': 3098,
#  'sellerseller': 2858,
#  'doang': 883,
#  'katalog': 1448,
#  'histori': 1212,
#  'jasa': 1344,
#  'nomor': 2139,
#  'stuk': 3043,
#  'dibalikin': 801,
#  'anggap': 135,
#  'item': 1311,
#  'url': 3391,
#  'kerjaangak': 1511,
#  'erti': 989,
#  'syulit': 3084,
#  'halo': 1159,
#  'min': 1981,
#  'playlater': 2476,
#  'loh': 1794,
#  'syaa': 3077,
#  'telepon': 3144,
#  'tlng': 3243,
#  'ta': 3086,
#  'soale': 3003,
#  'kesel': 1518,
#  'iya': 1317,
#  'download': 892,
#  'tera': 3165,
#  'pertahanin': 2440,
#  'giur': 1105,
#  'embel': 961,
#  'asli': 200,
#  'kak': 1414,
#  'account': 10,
#  'agan': 39,
#  'sungguh': 3057,
#  'konsisten': 1587,
#  'terap': 3167,
#  'system': 3080,
#  'retur': 2675,
#  'henti': 1200,
#  'dibukalapak': 809,
#  'tegas': 3136,
#  'langgar': 1696,
#  'tokomuakunmu': 3257,
#  'nonaktif': 2143,
#  'bukalapakbukalapakpaylater': 541,
#  'fitue': 1038,
#  'bukalapakpaylater': 556,
#  'normal': 2147,
#  'gajih': 1063,
#  'bot': 498,
#  'woiii': 3475,
#  'gua': 1131,
#  'november': 2157,
#  'pegang': 2358,
#  'tlpn': 3245,
#  'sengsara': 2882,
#  'lu': 1804,
#  'pengirimana': 2401,
#  'reguler': 2638,
#  'senin': 2883,
#  'call': 611,
#  'center': 642,
#  'media': 1914,
#  'dang': 739,
#  'varian': 3410,
#  'kompetetif': 1559,
#  'lindung': 1773,
#  'komplin': 1571,
#  'hindar': 1211,
#  'prestasi': 2523,
#  'masalh': 1891,
#  'oren': 2255,
#  'per': 2414,
#  'danauang': 738,
#  'muas': 2028,
#  'koo': 1597,
#  'akomodatif': 74,
#  'siihmaaaana': 2962,
#  'doangngeklaim': 886,
#  'laaagini': 1643,
#  'kolom': 1551,
#  'direspon': 848,
#  'gimanabeneran': 1099,
#  'artikel': 191,
#  'tata': 3127,
#  'valid': 3407,
#  'waktunyaudah': 3452,
#  'blga': 466,
#  'blapa': 464,
#  'tanggung': 3118,
#  'jawabga': 1348,
#  'dlutolong': 880,
#  'bantuanya': 278,
#  'malas': 1844,
#  'lai': 1664,
#  'ringan': 2694,
#  'cepatlama': 649,
#  'padahal': 2280,
#  'otp': 2268,
#  'spam': 3015,
#  'kapai': 1430,
#  'isi': 1308,
#  'toke': 3248,
#  'apes': 159,
#  'lanjur': 1700,
#  'kunjung': 1626,
#  'bye': 603,
#  'recomded': 2625,
#  'brengseksangat': 507,
#  'menjengkelkantiap': 1959,
#  'login': 1790,
#  'bisaaplikasi': 446,
#  'duniasudah': 914,
#  'pribadi': 2524,
#  'teleponaplikasi': 3145,
#  'berengsek': 387,
#  'efectif': 933,
#  'notipikasi': 2155,
#  'barangnggak': 289,
#  'lainyabegitu': 1670,
#  'barangmohon': 288,
#  'ku': 1619,
#  'event': 997,
#  'undang': 3353,
#  'miskin': 1998,
#  'mmbayar': 2003,
#  'suksesko': 3053,
#  'kadaluarsalimit': 1403,
#  'tida': 3217,
#  'bertambahuang': 417,
#  'hangus': 1168,
#  'kembalikomplen': 1492,
#  'bantua': 277,
#  'sekalimohon': 2833,
#  'bayarkarna': 321,
#  'bayardan': 320,
#  'kompirmasisekian': 1564,
#  'semog': 2868,
#  'versi': 3418,
#  'bugs': 528,
#  'lahcuma': 1660,
#  'paylatersllu': 2342,
#  'penagihkolektormasukannyaniat': 2390,
#  'lari': 1718,
#  'hutang': 1230,
#  'risih': 2697,
#  'kala': 1416,
#  'sibuk': 2953,
#  'kantor': 1429,
#  'kompalian': 1556,
#  'nang': 2066,
#  'operasi': 2241,
#  'anjir': 143,
#  'bukalapakdan': 544,
#  'ratus': 2604,
#  'bukalapaktapi': 564,
#  'beginisaya': 334,
#  'datangdan': 750,
#  'anetolong': 134,
#  'nakal': 2060,
#  'inijngn': 1272,
#  'pindah': 2463,
#  'lanjutiii': 1702,
#  'rekan': 2644,
#  'bayak': 317,
#  'bela': 344,
#  'duit': 908,
#  'lenyap': 1753,
#  'cekik': 636,
#  'adminnya': 29,
#  'byr': 604,
#  'haram': 1173,
#  'tuh': 3312,
#  'sjop': 2990,
#  'membantuapalagi': 1920,
#  'bukapaylater': 578,
#  'nysangat': 2194,
#  'senang': 2876,
#  'komsumen': 1576,
#  'ubung': 3337,
#  'abal': 1,
#  'tunjuk': 3323,
#  'bukalapakknp': 550,
#  'aku': 84,
#  'ber': 371,
#  'ekspektasi': 947,
#  'upload': 3388,
#  'form': 1047,
#  'sampah': 2751,
#  'ahirnya': 46,
#  'top': 3273,
#  'banking': 275,
#  'layar': 1730,
#  'kedap': 1472,
#  'kedip': 1474,
#  'smax': 2996,
#  'gilir': 1098,
#  'cairin': 609,
#  'atm': 207,
#  'pagi': 2286,
#  'tolol': 3267,
#  'saing': 2731,
#  'ketat': 1523,
#  'transsaksi': 3292,
#  'tipis': 3238,
#  'tetangga': 3204,
#  'upgrade': 3382,
#  'credit': 702,
#  'cashback': 627,
#  'pemberitahuan': 2387,
#  'sinibila': 2974,
#  'fikir': 1030,
#  'dulukarena': 913,
#  'lamaitu': 1678,
#  'denga': 772,
#  'sebelaj': 2805,
#  'fix': 1042,
#  'niat': 2118,
#  'diterimaehh': 870,
#  'sambung': 2747,
#  'slow': 2993,
#  'adu': 32,
#  'parahbukalapak': 2306,
#  'inigak': 1271,
#  'uninstal': 3358,
#  'sesal': 2915,
#  'diskcoun': 860,
#  'daya': 753,
#  'vocernya': 3430,
#  'tentu': 3162,
#  'nyaada': 2164,
#  'samasekaliuntuk': 2745,
#  'ampunsuruh': 123,
#  'ngantrigiliran': 2087,
#  'keputussuruh': 1506,
#  'lagisaya': 1656,
#  'magrib': 1827,
#  'bisamaaf': 449,
#  'kembang': 1493,
#  'stok': 3036,
#  'dll': 877,
#  'mintaa': 1990,
#  'udan': 3338,
#  'lempar': 1746,
#  'kuota': 1627,
#  'volume': 3432,
#  'kuotavolume': 1629,
#  'diskoncashback': 863,
#  'kalah': 1417,
#  'lgh': 1763,
#  'ngbisin': 2088,
#  'batre': 313,
#  'gunakn': 1140,
#  'enggak': 970,
#  'bisa': 444,
#  'padahhal': 2283,
#  'olshop': 2216,
#  'seba': 2800,
#  'tokenmudah': 3250,
#  'ijo': 1239,
#  'trustiap': 3305,
#  'pusing': 2577,
#  'kecewamasa': 1467,
#  'pakebuat': 2292,
#  'niisaya': 2123,
#  'mmbyara': 2004,
#  'dc': 757,
#  'shopie': 2941,
#  'jarang': 1342,
#  'trx': 3306,
#  'sekian': 2840,
#  'pantesan': 2303,
#  'sepi': 2890,
#  'tokped': 3262,
#  'shoope': 2934,
#  ...}

# %%
#kolom pertama ini berarti jumlah dokumen
#kolom kedua berarti letak katanya
#kolom ketiga hasil dari tf

term_frequency_all = term_fit.transform(Ulasan)
print (term_frequency_all)
# Out:
#   (0, 168)	1
#   (0, 347)	2
#   (0, 536)	1
#   (0, 634)	1
#   (0, 673)	2
#   (0, 692)	1
#   (0, 1055)	1
#   (0, 1396)	1
#   (0, 1542)	1
#   (0, 1599)	1
#   (0, 1978)	1
#   (0, 2305)	1
#   (0, 2459)	1
#   (0, 3092)	1
#   (0, 3152)	1
#   (0, 3392)	1
#   (1, 168)	2
#   (1, 230)	1
#   (1, 309)	1
#   (1, 714)	1
#   (1, 1172)	1
#   (1, 1220)	1
#   (1, 1419)	1
#   (1, 1930)	1
#   (1, 2297)	1
#   :	:
#   (1298, 1497)	1
#   (1298, 1589)	1
#   (1298, 1631)	1
#   (1298, 1829)	1
#   (1298, 1830)	1
#   (1298, 1862)	1
#   (1298, 2163)	2
#   (1298, 2222)	3
#   (1298, 2223)	1
#   (1298, 2226)	1
#   (1298, 2546)	1
#   (1298, 2803)	1
#   (1298, 3254)	1
#   (1299, 283)	2
#   (1299, 347)	1
#   (1299, 644)	1
#   (1299, 1423)	1
#   (1299, 1465)	1
#   (1299, 1539)	1
#   (1299, 2553)	1
#   (1299, 2675)	1
#   (1299, 2735)	1
#   (1299, 2850)	1
#   (1299, 3317)	1
#   (1299, 3479)	1

# %%
ulasan_tf = Ulasan[1] #memanggil kata pada index ke 1
print (ulasan_tf)
# Out:
# bagus sih cuman ribet kali update aplikasi susah transaksi susah hp memori batas hapus paksa aplikasi ribet

# %%
term_frequency = term_fit.transform([ulasan_tf]) #hanya menampilkan hasil document 1
print (term_frequency)
# Out:
#   (0, 168)	2
#   (0, 230)	1
#   (0, 309)	1
#   (0, 714)	1
#   (0, 1172)	1
#   (0, 1220)	1
#   (0, 1419)	1
#   (0, 1930)	1
#   (0, 2297)	1
#   (0, 2683)	2
#   (0, 2958)	1
#   (0, 3069)	2
#   (0, 3283)	1
#   (0, 3373)	1

# %%
dokumen = term_fit.transform(Ulasan) #hasil perhitungan tf idf dalam 1 doc
tfidf_transformer = TfidfTransformer().fit(dokumen)
print (tfidf_transformer.idf_)

tfidf=tfidf_transformer.transform(term_frequency)
print (tfidf) #hasil manual dengan sistem pyhton
# Out:
# [6.78459412 7.07227619 7.07227619 ... 7.4777413  7.4777413  7.4777413 ]
#   (0, 3373)	0.1995680427469527
#   (0, 3283)	0.16161365379629808
#   (0, 3069)	0.38212353410220445
#   (0, 2958)	0.2080644337455008
#   (0, 2683)	0.3870639808605283
#   (0, 2297)	0.2958498124911391
#   (0, 1930)	0.3476915398882393
#   (0, 1419)	0.19353199043026414
#   (0, 1220)	0.23368578288675834
#   (0, 1172)	0.25176689502485794
#   (0, 714)	0.26271197243523886
#   (0, 309)	0.2799552368157217
#   (0, 230)	0.16697539094990174
#   (0, 168)	0.23619024839667196

# %%
data_label = name_dataframe[["Nama pengguna", "Ulasan_clean", "Sentiment"]]

# %%
data_label["Ulasan_clean"] = data_label["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-69-5732072d6cca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label["Ulasan_clean"] = data_label["Ulasan_clean"].fillna("tidak ada komentar")

# %%
data_label.to_excel("data_label.xlsx")

# %%
sentimen_data=pd.value_counts(data_label["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["#ccd5ae"])
plt.title('Bar chart')
plt.show()

# %%
plt.figure(figsize=(16, 6))

heatmap = sns.heatmap(name_dataframe.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12)

plt.tight_layout()

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize',
#        'Ulasan_normalized', 'Ulasan_stop_removed', 'Ulasan_Stemmed',
#        'Ulasan_clean', 'label', 'Polarity', 'Subjectivity', 'Sentiment'],
#       dtype='object')

# %%
from wordcloud import WordCloud

# %%
train_s0 = data_label[data_label["Sentiment"] == 'Negative']

# %%
train_s0["Ulasan_clean"] = train_s0["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-76-4a391e85ccb2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s0["Ulasan_clean"] = train_s0["Ulasan_clean"].fillna("tidak ada komentar")

# %%
train_s0
# Out:
#                  Nama pengguna  \
# 15                  Ahmad Amek
# 16       Ulfa Mar'atus Solihah
# 27                Bam Hendrian
# 45                  Tegar Ibnu
# 86                       WesLi
# 99              official store
# 101            Novi Nurhalimah
# 103              Helmi Arianto
# 112             Richo Agustian
# 126                    Hambali
# 140                munif abdul
# 164          Budiman Android16
# 259               Vianda Putri
# 270                  Jhuiya 52
# 297            nur ahmad salim
# 353               mantri kumis
# 377             ANDI SUDARTO S
# 390        afrians jo official
# 393               Hermanto Ptk
# 397                     Riyanz
# 437                DANTE KODOK
# 592            Aspal Gorbachev
# 630                   Abie Dan
# 632               Kiki Susanti
# 644         Naufal Adi Nugraha
# 661                ams_saintis
# 666             Putri Cellular
# 674             Dadang Hidayat
# 736             Nicsen Chalter
# 924             Indah Yulianto
# 996               wisnu arifin
# 999   F_212 Muhamad Hapidulloh
# 1061            Ganik Iskandar
# 1112       agan Sin (agan age)
# 1139           Pengguna Google
# 1148               Najwa Jemur
# 1166           Pengguna Google
# 1171           Pengguna Google
# 1180                 Hr Tester
# 1228           Pengguna Google
# 1276                 Fian Syah
#
#                                            Ulasan_clean Sentiment
# 15    maaf turun bintangnyakarena pakai bukalapak pa...  Negative
# 16    edit ulas hubung customer care aplikasi kait b...  Negative
# 27    kesini sistem nya berat ajabanyak sisrem gunab...  Negative
# 45    sih asih voucher gratis ongkir minimal potong ...  Negative
# 86    susah hubungin cs sulit hubung cs pakai email ...  Negative
# 99    aplikasi sungguh kecewa konsisten terap atur s...  Negative
# 101   kecewa aplikasi bukalapak telat bayar jatuh te...  Negative
# 103   jual barang bukalapak sabtu sore transaksi bar...  Negative
# 112   halo bukalapak email ganti alas gagal kirim em...  Negative
# 126   rekan saran belanja bukalapak bayak tipu salah...  Negative
# 140   komplain tagih bayar lelet deh bayar status ba...  Negative
# 164   sistem nya parah seller ecek jual masuk ecek a...  Negative
# 259   beli vcr game diamond masuk saldo komplen susa...  Negative
# 270   gratis ongkir mu nama diskon ongkir grtis ongk...  Negative
# 297   sistem kalah competitornya lot gagal sistem al...  Negative
# 353   kecewa aplikasi inisya saldo paylater status a...  Negative
# 377   kecewa bukadompet beku saldo pindah saldo mitr...  Negative
# 390   kapok beli baterai mac second sih jual kasih g...  Negative
# 393   aplikasi sampah buka dompet beku alas hubung b...  Negative
# 397   aplikasi kesini enggan pakai aplikasi bukalapa...  Negative
# 437   kecewa bukalapak paylater bekukandengan alas j...  Negative
# 592   kacau nih bukalapak ganti nomer hp susah mati ...  Negative
# 630   kecewa hati ngalamin sayauang bayar barang buk...  Negative
# 632   parah banget bukalapak coba belanja aplikasi b...  Negative
# 644   aplikasi konyol saldo aplikasi enggak bisa pak...  Negative
# 661   barang sesuai fungsi aju return tolak bukti vi...  Negative
# 666   toko blokir min sih bukalapak toko shopee toko...  Negative
# 674   akun hack buka lapak juta raib bukalapak tau h...  Negative
# 736   app voucher numpuk pakai alas voucher potong o...  Negative
# 924   kecewa bukalapak paylater cs nya tibatiba limi...  Negative
# 996   aplikasi belanja mepersulit melakukakan ubah d...  Negative
# 999   tolong suhu deplov jalan nomer akun hilang log...  Negative
# 1061  komplain kembali dana media center susah hubun...  Negative
# 1112  hi team kait butuh chat livenya mana mohon her...  Negative
# 1139  heran aplikasi upload jual barang kaya susahhh...  Negative
# 1148  kalo bukalapak rame tampil barang jual bayar i...  Negative
# 1166  baik servernya fitur macet traffict diserver j...  Negative
# 1171  bukastruk gagal struk identifikasi deteksi dup...  Negative
# 1180  aplikasi bagus bantu kendala admin komplain me...  Negative
# 1228  kurangtapi suka dwngan tampil bukalapak update...  Negative
# 1276  barang pesan langsung aju komplain selesai isi...  Negative

# %%
all_text_s0 = ' '.join(word for word in train_s0["Ulasan_clean"])
wordcloud = WordCloud(colormap='Reds', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s0)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
# Create scatter plot
sns.set_style('darkgrid')
plt.figure(figsize = (15,7))

markers = {'Positive':'o', 'Neutral':'s','Negative':'X'}

sns.scatterplot(data=name_dataframe, x='Polarity', y='Subjectivity', hue = 'Sentiment', style = 'Sentiment', markers = markers, palette = 'gist_earth').set(xlim=(-1,1))
plt.title('Scatter Plot')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')

plt.tight_layout()

# %%
train_s1 = data_label[data_label["Sentiment"] == 'Positive']

# %%
train_s1["Ulasan_clean"] = train_s1["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-81-89653e0cae75>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s1["Ulasan_clean"] = train_s1["Ulasan_clean"].fillna("tidak ada komentar")

# %%
train_s1
# Out:
#             Nama pengguna                                       Ulasan_clean  \
# 0           Ryan Apriandi  aplikasi parah belanja cc pilih klik cicil tag...
# 7              rizky adhi  fitur live chat tipu kontak cs hubung konsumen...
# 10          Animah Astuti  kali bintang sih csnya ramah layan langgan kai...
# 11    Hajna Agung Milkham  bobrok mesan cod masuk tagih detail sedia bata...
# 22         kastowo taylor  pakai bukalapak kali kecewa beli barang lapak ...
# ...                   ...                                                ...
# 1241      Pengguna Google  kembang sederhana konsep guna vocer vocer grat...
# 1271          Joe R Saleh  sekian lapak puas perform lapak tampil user fr...
# 1272       fauzi cbr shop  layan buruk live chat ribet bug telfon cs dll ...
# 1282        Rizki Pratama  kesini aplikasi berat interfacenya user friend...
# 1287       Laras Agustina  transfer status tunggu bayar status kadaluwars...
#
#      Sentiment
# 0     Positive
# 7     Positive
# 10    Positive
# 11    Positive
# 22    Positive
# ...        ...
# 1241  Positive
# 1271  Positive
# 1272  Positive
# 1282  Positive
# 1287  Positive
#
# [205 rows x 3 columns]

# %%
all_text_s1 = ' '.join(word for word in train_s1["Ulasan_clean"])
wordcloud = WordCloud(colormap='Blues', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s1)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Ulasan Positif")
plt.margins(x=0, y=0)
plt.show()

# %%
data_label['Ulasan_clean'] = data_label['Ulasan_clean'].fillna("tidak ada komentar")
# Out:
# <ipython-input-84-27b828896519>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['Ulasan_clean'] = data_label['Ulasan_clean'].fillna("tidak ada komentar")

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_clean'], data_label['Sentiment'], 
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# %%
import numpy as np

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(decode_error='replace', encoding='utf-8')

# %%
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

print(X_train.shape)
print(X_test.shape)
# Out:
# (1170, 3243)
# (130, 3243)

# %%
X_train = X_train.toarray()

# %%
X_test = X_test.toarray()

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

#deklarasi metode cross validation
cv_method = RepeatedStratifiedKFold(n_splits=5,  n_repeats=3, random_state=999)
#tuning hyperparameter menggunakan gridsearch

params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}
gscv_nb = GridSearchCV(estimator=nb, 
                 param_grid=params_NB, 
                 cv=cv_method,   # use any cross validation technique 
                 verbose=1, 
                 scoring='accuracy') 

#Fitting ke Model
gscv_nb.fit(X_train,y_train)
#mendapatkan hyperparameters terbaik
gscv_nb.best_params_
# Out:
# Fitting 15 folds for each of 1000 candidates, totalling 15000 fits
# {'var_smoothing': 0.0006468607661546328}

# %%
nb = GaussianNB(var_smoothing=1.0)

# %%
nb.fit(X_train, y_train)
# Out:
# GaussianNB(var_smoothing=1.0)

# %%
y_pred_nb = nb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
# visualize confusion matrix with seaborn heatmap

cm_matrix = pd.DataFrame(data=cm, columns=['Positive:1', 'Negative:0', 'Neutral:2'], 
                                 index=['Positive:1', 'Negative:0', 'Neutral:2'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')

# %%
cm = confusion_matrix(y_test, y_pred_nb)

# %%
print('Confusion matrix\n\n', cm)
# Out:
# Confusion matrix
#
#  [[ 4  0  0]
#  [37 49 19]
#  [ 6  1 14]]

# %%
print('--------------------- confusion matrix  ----------------------------')
print(confusion_matrix(y_test, y_pred_nb))
print('--------------------- classification report  ----------------------------')
print(classification_report(y_test, y_pred_nb))
# Out:
# --------------------- confusion matrix  ----------------------------
# [[ 4  0  0]
#  [37 49 19]
#  [ 6  1 14]]
# --------------------- classification report  ----------------------------
#               precision    recall  f1-score   support
#
#     Negative       0.09      1.00      0.16         4
#      Neutral       0.98      0.47      0.63       105
#     Positive       0.42      0.67      0.52        21
#
#     accuracy                           0.52       130
#    macro avg       0.50      0.71      0.44       130
# weighted avg       0.86      0.52      0.60       130

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
# Regresi Logistik
logreg = LogisticRegression()
# SVM
svm = SVC(probability=True)

# %%
logreg.fit(X_train, y_train)
svm.fit(X_train, y_train)

# %%
y_pred1_logreg = logreg.predict(X_test)
y_pred1_svm = svm.predict(X_test)

# %%
print('---------------  Regresi Logistik  -------------------')
print(classification_report(y_test, y_pred1_logreg))
print('--------------------- SVM ----------------------------')
print(classification_report(y_test, y_pred1_svm))
