# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafiryd/Rafiryd/blob/rafiryd/skripsi22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Referensi: https://www.linkedin.com/pulse/how-scrape-google-play-reviews-4-simple-steps-using-python-kundi/

# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

import seaborn as sns

# %%
#Scrape desired number of reviews
#Run kode ini jika ingin scrape data dengan jumlah tertentu. Ganti (misal, ingin scrape sejumlah 1000, maka ganti kode , count = 1000 )

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.bukalapak.android',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=1300, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %% [markdown]
# Problems slovlig tools = mencari akar permasalahan pada suatu masalah
#
# 5 why
#
# metode mencari problems sloving dengan cara menanyakan apa penyebab permasalahaan muncul dan mencari jawabannya. hal ini di lakUkan berkali klai sampai permasalahan dapat tergambar dengan jelas
#
# action priority
#
# diagram yang dapat di gunakan untuk mencari prioritas masalah berdasarkan impact atas benefit yang bisa diberikan dengan diagram ini kita memilih masalah yang impactnya mayoritas dari permasalahan yang ada.
#
# fishbone digram
#
# digram yang dapat di gunakan untuk merinci masalah dan membantu mencari akar masalah yang dapat dilihat dari beberapa point of view
#
# flowchart/algo
#
# metode pemecahan masalah dengan cara memetakan flow atau membuat pseudo algoritma yang untuk menentukan masalah dan cara untuk mencari solusinya secara sistematis

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId                          userName  \
# 0  f2e26548-83d2-4bcf-bac3-6dc9db1cb12d                      Nizar Rayyan
# 1  5ef5f760-f72a-473b-9fb3-48e5556cefc6                        Fandy Komo
# 2  5576763d-7e2f-416b-b262-bcdb8945722c                   hidayat mudaris
# 3  9d6aac3b-63cf-4144-9b4e-c94d291d808a  dedy kelana (CV PRIBUMI BANGKIT)
# 4  b5eb4cfa-705b-40cc-8469-a6d563203787                      Aris Gunawan
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ACB-R...
# 1  https://play-lh.googleusercontent.com/a/AGNmyx...
# 2  https://play-lh.googleusercontent.com/a-/ACB-R...
# 3  https://play-lh.googleusercontent.com/a/AGNmyx...
# 4  https://play-lh.googleusercontent.com/a/AGNmyx...
#
#                                              content  score  thumbsUpCount  \
# 0  Paylater ngk bener.. selalu di batalkan otomat...      1            183
# 1  Tambah kesini buka lapak tambah kurang bagus p...      1             49
# 2  Tolong jangan memperumit untuk Verifikasi Akun...      1             27
# 3  pastinya bukan hp dan wifi saya yang lemmooott...      1            211
# 4  Aplikasi bukalapak sangat membantu untuk prose...      5              3
#
#   reviewCreatedVersion                  at  \
# 0               5.31.3 2023-04-16 23:03:31
# 1               5.31.3 2023-05-05 02:37:25
# 2               5.30.2 2023-05-06 17:32:58
# 3               5.30.2 2023-03-25 10:26:56
# 4               5.31.3 2023-05-04 23:26:15
#
#                                         replyContent           repliedAt  \
# 0  Hai, mohon maaf atas ketidaknyamanannya. Jika ... 2020-03-06 11:44:30
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4                                               None                 NaT
#
#   appVersion
# 0     5.31.3
# 1     5.31.3
# 2     5.30.2
# 3     5.30.2
# 4     5.31.3

# %%
len(df_busu.index) #count the number of data we got
# Out:
# 1300

# %%
df_busu[['userName', 'score','at', 'content']].tail()  #preview userName, rating, date-time, and reviews only
# Out:
#                 userName  score                  at  \
# 1295      Sitorus Edward      5 2023-04-24 03:40:01
# 1296        DK Mattawang      5 2023-04-16 04:31:17
# 1297        M2D Projects      2 2023-04-16 00:14:31
# 1298            KA risma      1 2023-04-25 08:25:01
# 1299  Bic Stevie Sualang      5 2023-04-22 09:57:05
#
#                                                 content
# 1295                           Baik dan cepat prosesnya
# 1296   Sangat berguna, bermanfaat dan sangat diperlukan
# 1297  Banyak barang di pencarian begitu di klik bara...
# 1298  Permisi apakah Sistem Aplikasi Bukalapak sedan...
# 1299  Tingkatkan terus jaga kenyamanan Nasabah bertr...

# %%
name_dataframe = df_busu.loc[:,["userName", "score", "at", "content"]]
name_dataframe.rename(columns={"userName": "Nama pengguna", "score":"Rating", "at": "Date", "content": "Ulasan"}, inplace=True)

# %%
name_dataframe.tail()
# Out:
#            Nama pengguna  Rating                Date  \
# 1295      Sitorus Edward       5 2023-04-24 03:40:01
# 1296        DK Mattawang       5 2023-04-16 04:31:17
# 1297        M2D Projects       2 2023-04-16 00:14:31
# 1298            KA risma       1 2023-04-25 08:25:01
# 1299  Bic Stevie Sualang       5 2023-04-22 09:57:05
#
#                                                  Ulasan
# 1295                           Baik dan cepat prosesnya
# 1296   Sangat berguna, bermanfaat dan sangat diperlukan
# 1297  Banyak barang di pencarian begitu di klik bara...
# 1298  Permisi apakah Sistem Aplikasi Bukalapak sedan...
# 1299  Tingkatkan terus jaga kenyamanan Nasabah bertr...

# %%
name_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nama pengguna  1300 non-null   object
#  1   Rating         1300 non-null   int64
#  2   Date           1300 non-null   datetime64[ns]
#  3   Ulasan         1300 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 40.8+ KB

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].astype(str)
name_dataframe.head()
# Out:
#                       Nama pengguna  Rating                Date  \
# 0                      Nizar Rayyan       1 2023-04-16 23:03:31
# 1                        Fandy Komo       1 2023-05-05 02:37:25
# 2                   hidayat mudaris       1 2023-05-06 17:32:58
# 3  dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 4                      Aris Gunawan       5 2023-05-04 23:26:15
#
#                                               Ulasan
# 0  Paylater ngk bener.. selalu di batalkan otomat...
# 1  Tambah kesini buka lapak tambah kurang bagus p...
# 2  Tolong jangan memperumit untuk Verifikasi Akun...
# 3  pastinya bukan hp dan wifi saya yang lemmooott...
# 4  Aplikasi bukalapak sangat membantu untuk prose...

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].str.lower()

# %%
import string 
import re 
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

def remove_links(text):
    # menghapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus URL
    return text.replace("http://", " ").replace("https://", " ")
                
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_links)

# %%
#menghapus number
def remove_number(text):
    return  re.sub(r"\d+", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_number)

# %%
#menghapus punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_punctuation)

# %%
# menghapus single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_singl_char)

# %%
# Tokenisasi 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

name_dataframe['Ulasan_tokenize'] = name_dataframe['Ulasan'].apply(word_tokenize_wrapper)

# %%
name_dataframe
# Out:
#                          Nama pengguna  Rating                Date  \
# 0                         Nizar Rayyan       1 2023-04-16 23:03:31
# 1                           Fandy Komo       1 2023-05-05 02:37:25
# 2                      hidayat mudaris       1 2023-05-06 17:32:58
# 3     dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 4                         Aris Gunawan       5 2023-05-04 23:26:15
# ...                                ...     ...                 ...
# 1295                    Sitorus Edward       5 2023-04-24 03:40:01
# 1296                      DK Mattawang       5 2023-04-16 04:31:17
# 1297                      M2D Projects       2 2023-04-16 00:14:31
# 1298                          KA risma       1 2023-04-25 08:25:01
# 1299                Bic Stevie Sualang       5 2023-04-22 09:57:05
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     tambah kesini buka lapak tambah kurang bagus p...
# 2     tolong jangan memperumit untuk verifikasi akun...
# 3     pastinya bukan hp dan wifi saya yang lemmooott...
# 4     aplikasi bukalapak sangat membantu untuk prose...
# ...                                                 ...
# 1295                           baik dan cepat prosesnya
# 1296    sangat berguna bermanfaat dan sangat diperlukan
# 1297  banyak barang di pencarian begitu di klik bara...
# 1298  permisi apakah sistem aplikasi bukalapak sedan...
# 1299  tingkatkan terus jaga kenyamanan nasabah bertr...
#
#                                         Ulasan_tokenize
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [tolong, jangan, memperumit, untuk, verifikasi...
# 3     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4     [aplikasi, bukalapak, sangat, membantu, untuk,...
# ...                                                 ...
# 1295                      [baik, dan, cepat, prosesnya]
# 1296  [sangat, berguna, bermanfaat, dan, sangat, dip...
# 1297  [banyak, barang, di, pencarian, begitu, di, kl...
# 1298  [permisi, apakah, sistem, aplikasi, bukalapak,...
# 1299  [tingkatkan, terus, jaga, kenyamanan, nasabah,...
#
# [1300 rows x 5 columns]

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize'], dtype='object')

# %%
#Run This Code to Sort the Data By Date 
# tanggal 26-04-2022 sampai 12-10-2022

new_df = name_dataframe[['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize']]
sorted_df = new_df.sort_values(by='Date', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#       Nama pengguna  Rating                Date  \
# 343  Silva Widianti       4 2023-05-11 11:35:27
# 218      Ruddy Arie       1 2023-05-11 11:19:29
# 261      Dans Jamal       5 2023-05-11 10:43:14
# 682  Channel Amatir       1 2023-05-11 09:07:36
# 215        Tri Heri       5 2023-05-11 07:02:58
#
#                                                 Ulasan  \
# 343  cara penagihan di paylater di bl amat sangat m...
# 218  fitur live chat tidak tersedia untuk bantuan n...
# 261  so far so good saran kalau bisa ada icon sendi...
# 682  pada hari jumat tanggal   april   pukul    wib...
# 215  aplikasi kok tidak suport video  trus gimana k...
#
#                                        Ulasan_tokenize
# 343  [cara, penagihan, di, paylater, di, bl, amat, ...
# 218  [fitur, live, chat, tidak, tersedia, untuk, ba...
# 261  [so, far, so, good, saran, kalau, bisa, ada, i...
# 682  [pada, hari, jumat, tanggal, april, pukul, wib...
# 215  [aplikasi, kok, tidak, suport, video, trus, gi...

# %%
sorted_df.dtypes
# Out:
# Nama pengguna              object
# Rating                      int64
# Date               datetime64[ns]
# Ulasan                     object
# Ulasan_tokenize            object
# dtype: object

# %%
# Menghitung Distibusi Persebaran Kata
def freqDist_wrapper(text):
    return FreqDist(text)

Ulasan_fqsist = name_dataframe['Ulasan_tokenize'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(Ulasan_fqsist.head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(tidak, 4), (di, 3), (nya, 3), (kadang, 2), (...
# 1    [(tambah, 3), (buka, 2), (susah, 2), (di, 2), ...
# 2    [(ga, 4), (untuk, 3), (saldo, 3), (bisa, 3), (...
# 3    [(dan, 3), (saya, 3), (mau, 3), (yang, 2), (se...
# 4    [(kirim, 2), (uang, 2), (ke, 2), (banyak, 2), ...
# Name: Ulasan_tokenize, dtype: object

# %%
name_dataframe['Ulasan_tokenize'].unique
# Out:
# <bound method Series.unique of 0       [paylater, ngk, bener, selalu, di, batalkan, o...
# 1       [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2       [tolong, jangan, memperumit, untuk, verifikasi...
# 3       [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4       [aplikasi, bukalapak, sangat, membantu, untuk,...
#                               ...
# 1295                        [baik, dan, cepat, prosesnya]
# 1296    [sangat, berguna, bermanfaat, dan, sangat, dip...
# 1297    [banyak, barang, di, pencarian, begitu, di, kl...
# 1298    [permisi, apakah, sistem, aplikasi, bukalapak,...
# 1299    [tingkatkan, terus, jaga, kenyamanan, nasabah,...
# Name: Ulasan_tokenize, Length: 1300, dtype: object>

# %%
slank_word_dict = {
    "berjalansudah" : "berjalan",
    "paraah" : "parah",
    "keduakali" : "",
    "keduakali" : "kedua kali",
    "agak" : "sedikit",
    "pas" : "saat",
    "produkx" : "produknya",
    "sukamkasih" : "suka makasih",
    "gak" : "tidak",
    "cpt" : "cepat",
    "sdh" : "sudah",
    "recommend" : "rekomendasi",
    "bagusseller" : "bagus",
    "bagusssss" : "bagus",
    "bagussssss" : "bagus",
    "baguuussss" : "bagus",
    "cepatmakasih": "cepat",
    "cepatmantappp": "cepat",
    "cepatproduct": "cepat",
    "cepatrecomended": "cepat",
    "cepattoko": "cepat",
    "recomended": "rekomendasi",
    "recommended": "rekomendasi",
    "rekomendasi": "rekomendasi",
    "rekomended": "rekomendasi",
    }

def slank_normalized_term(document):
    return [slank_word_dict[term] if term in slank_word_dict else term for term in document]

# %%
normalizad_word = pd.read_csv("/content/kamusindonesia.csv (2).csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

# %%
name_dataframe['Ulasan_normalized'] = name_dataframe['Ulasan_tokenize'].apply(normalized_term).apply(slank_normalized_term)

# %%
name_dataframe
# Out:
#                          Nama pengguna  Rating                Date  \
# 0                         Nizar Rayyan       1 2023-04-16 23:03:31
# 1                           Fandy Komo       1 2023-05-05 02:37:25
# 2                      hidayat mudaris       1 2023-05-06 17:32:58
# 3     dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 4                         Aris Gunawan       5 2023-05-04 23:26:15
# ...                                ...     ...                 ...
# 1295                    Sitorus Edward       5 2023-04-24 03:40:01
# 1296                      DK Mattawang       5 2023-04-16 04:31:17
# 1297                      M2D Projects       2 2023-04-16 00:14:31
# 1298                          KA risma       1 2023-04-25 08:25:01
# 1299                Bic Stevie Sualang       5 2023-04-22 09:57:05
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     tambah kesini buka lapak tambah kurang bagus p...
# 2     tolong jangan memperumit untuk verifikasi akun...
# 3     pastinya bukan hp dan wifi saya yang lemmooott...
# 4     aplikasi bukalapak sangat membantu untuk prose...
# ...                                                 ...
# 1295                           baik dan cepat prosesnya
# 1296    sangat berguna bermanfaat dan sangat diperlukan
# 1297  banyak barang di pencarian begitu di klik bara...
# 1298  permisi apakah sistem aplikasi bukalapak sedan...
# 1299  tingkatkan terus jaga kenyamanan nasabah bertr...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [tolong, jangan, memperumit, untuk, verifikasi...
# 3     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4     [aplikasi, bukalapak, sangat, membantu, untuk,...
# ...                                                 ...
# 1295                      [baik, dan, cepat, prosesnya]
# 1296  [sangat, berguna, bermanfaat, dan, sangat, dip...
# 1297  [banyak, barang, di, pencarian, begitu, di, kl...
# 1298  [permisi, apakah, sistem, aplikasi, bukalapak,...
# 1299  [tingkatkan, terus, jaga, kenyamanan, nasabah,...
#
#                                       Ulasan_normalized
# 0     [paylater, enggak, benar, selalu, di, batalkan...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [tolong, jangan, memperumit, untuk, verifikasi...
# 3     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4     [aplikasi, bukalapak, sangat, membantu, untuk,...
# ...                                                 ...
# 1295                      [baik, dan, cepat, prosesnya]
# 1296  [sangat, berguna, bermanfaat, dan, sangat, dip...
# 1297  [banyak, barang, di, pencarian, begitu, di, kl...
# 1298  [permisi, apakah, sistem, aplikasi, bukalapak,...
# 1299  [tingkatkan, terus, jaga, kenyamanan, nasabah,...
#
# [1300 rows x 6 columns]

# %%
name_dataframe['Ulasan_normalized'].unique
# Out:
# <bound method Series.unique of 0       [paylater, enggak, benar, selalu, di, batalkan...
# 1       [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2       [tolong, jangan, memperumit, untuk, verifikasi...
# 3       [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4       [aplikasi, bukalapak, sangat, membantu, untuk,...
#                               ...
# 1295                        [baik, dan, cepat, prosesnya]
# 1296    [sangat, berguna, bermanfaat, dan, sangat, dip...
# 1297    [banyak, barang, di, pencarian, begitu, di, kl...
# 1298    [permisi, apakah, sistem, aplikasi, bukalapak,...
# 1299    [tingkatkan, terus, jaga, kenyamanan, nasabah,...
# Name: Ulasan_normalized, Length: 1300, dtype: object>

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

name_dataframe['Ulasan_stop_removed'] = name_dataframe['Ulasan_normalized'].apply(stopwords_removal)

# %%
name_dataframe
# Out:
#                          Nama pengguna  Rating                Date  \
# 0                         Nizar Rayyan       1 2023-04-16 23:03:31
# 1                           Fandy Komo       1 2023-05-05 02:37:25
# 2                      hidayat mudaris       1 2023-05-06 17:32:58
# 3     dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 4                         Aris Gunawan       5 2023-05-04 23:26:15
# ...                                ...     ...                 ...
# 1295                    Sitorus Edward       5 2023-04-24 03:40:01
# 1296                      DK Mattawang       5 2023-04-16 04:31:17
# 1297                      M2D Projects       2 2023-04-16 00:14:31
# 1298                          KA risma       1 2023-04-25 08:25:01
# 1299                Bic Stevie Sualang       5 2023-04-22 09:57:05
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     tambah kesini buka lapak tambah kurang bagus p...
# 2     tolong jangan memperumit untuk verifikasi akun...
# 3     pastinya bukan hp dan wifi saya yang lemmooott...
# 4     aplikasi bukalapak sangat membantu untuk prose...
# ...                                                 ...
# 1295                           baik dan cepat prosesnya
# 1296    sangat berguna bermanfaat dan sangat diperlukan
# 1297  banyak barang di pencarian begitu di klik bara...
# 1298  permisi apakah sistem aplikasi bukalapak sedan...
# 1299  tingkatkan terus jaga kenyamanan nasabah bertr...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [tolong, jangan, memperumit, untuk, verifikasi...
# 3     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4     [aplikasi, bukalapak, sangat, membantu, untuk,...
# ...                                                 ...
# 1295                      [baik, dan, cepat, prosesnya]
# 1296  [sangat, berguna, bermanfaat, dan, sangat, dip...
# 1297  [banyak, barang, di, pencarian, begitu, di, kl...
# 1298  [permisi, apakah, sistem, aplikasi, bukalapak,...
# 1299  [tingkatkan, terus, jaga, kenyamanan, nasabah,...
#
#                                       Ulasan_normalized  \
# 0     [paylater, enggak, benar, selalu, di, batalkan...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [tolong, jangan, memperumit, untuk, verifikasi...
# 3     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4     [aplikasi, bukalapak, sangat, membantu, untuk,...
# ...                                                 ...
# 1295                      [baik, dan, cepat, prosesnya]
# 1296  [sangat, berguna, bermanfaat, dan, sangat, dip...
# 1297  [banyak, barang, di, pencarian, begitu, di, kl...
# 1298  [permisi, apakah, sistem, aplikasi, bukalapak,...
# 1299  [tingkatkan, terus, jaga, kenyamanan, nasabah,...
#
#                                     Ulasan_stop_removed
# 0     [paylater, batalkan, otomatis, kadang, nya, ga...
# 1     [kesini, buka, lapak, bagus, pelayanannya, kom...
# 2     [tolong, memperumit, verifikasi, akun, saldo, ...
# 3     [pastinya, hp, wifi, lemmooottttt, dasarnya, b...
# 4     [aplikasi, bukalapak, membantu, proses, kirim,...
# ...                                                 ...
# 1295                                 [cepat, prosesnya]
# 1296                              [berguna, bermanfaat]
# 1297         [barang, pencarian, klik, barang, dihapus]
# 1298  [permisi, sistem, aplikasi, bukalapak, eror, m...
# 1299  [tingkatkan, jaga, kenyamanan, nasabah, bertra...
#
# [1300 rows x 7 columns]

# %%
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 7.9 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting swifter
#   Downloading swifter-1.3.4.tar.gz (830 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 830.9/830.9 kB 19.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (1.5.3)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.10/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2022.12.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (4.65.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (7.7.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from swifter) (2.2.1)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from swifter) (6.0.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (8.1.3)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2023.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (23.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.22.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2022.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.3.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.8 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (6.4.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.1.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.11.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.21)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.3.4-py3-none-any.whl size=16299 sha256=2a5e4fcf1d9b0f43fc6ce92b838d53ecf83c0f1715511e96db7ea9c84c8596f5
#   Stored in directory: /root/.cache/pip/wheels/6c/bd/3e/2d6afc9bc36c9975f8e4215a270bbac6580c4361ebd6bb2323
# Successfully built swifter
# Installing collected packages: jedi, swifter
# Successfully installed jedi-0.18.2 swifter-1.3.4

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in name_dataframe['Ulasan_stop_removed']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

name_dataframe['Ulasan_Stemmed'] = name_dataframe['Ulasan_stop_removed'].swifter.apply(get_stemmed_term)
# Out:
# 4514
# ------------------------
# paylater : paylater
# batalkan : batal
# otomatis : otomatis
# kadang : kadang
# nya : nya
# gantian : ganti
# jatuh : jatuh
# tempo : tempo
# bayar : bayar
# biaya : biaya
# keterlambatan : lambat
# layanan : layan
# biar : biar
# merasakan : rasa
# rasakan : rasa
# sistem : sistem
# seenak : enak
# chat : chat
# susah : susah
# error : error
# menyalahkan : salah
# bikin : bikin
# pusing : pusing
# kesini : kesini
# buka : buka
# lapak : lapak
# bagus : bagus
# pelayanannya : layan
# komplan : komplan
# banget : banget
# beberapakali : beberapakali
# transaksi : transaksi
# rekening : rekening
# deh : deh
# kepotong : potong
# lapaknya : lapak
# terverifikasi : verifikasi
# kalo : kalo
# pengin : pengin
# komplain : komplain
# menu : menu
# upload : upload
# bukti : bukti
# bayarnya : bayar
# muncul : muncul
# kali : kali
# kehilangan : hilang
# uang : uang
# pembayaran : bayar
# gagal : gagal
# tolong : tolong
# memperumit : rumit
# verifikasi : verifikasi
# akun : akun
# saldo : saldo
# bukalapak : bukalapak
# dipakai : pakai
# checkout : checkout
# barang : barang
# belanjaan : belanja
# bantuan : bantu
# mengasih : asih
# solusi : solusi
# muter : muter
# disitu : situ
# doang : doang
# diperbaiki : baik
# urusan : urus
# belanja : belanja
# minimal : minimal
# mempersulit : sulit
# proses : proses
# pencairan : cair
# dana : dana
# pastinya : pasti
# hp : hp
# wifi : wifi
# lemmooottttt : lemmooottttt
# dasarnya : dasar
# karuan : karuan
# lihat : lihat
# status : status
# transsaksi : transsaksi
# menunggu : tunggu
# halaman : halaman
# terisi : isi
# penuh : penuh
# penawaran : tawar
# tanda : tanda
# kesulitan : sulit
# terbaca : baca
# kepencet : pencet
# bulalapak : bulalapak
# bermain : main
# paket : paket
# data : data
# orang : orang
# konten : konten
# webnya : webnya
# lumayan : lumayan
# hasilnya : hasil
# semoga : moga
# kecurigaan : curiga
# maafkan : maaf
# aplikasi : aplikasi
# membantu : bantu
# kirim : kirim
# mudah : mudah
# langsung : langsung
# cepat : cepat
# tujuan : tuju
# manapun : mana
# fitur : fitur
# promonya : promonya
# fee : fee
# admin : admin
# promo : promo
# lainnyamataap : lainnyamataap
# dah : dah
# gunawan : gunawan
# pengalaman : alam
# apk : apk
# selesai : selesai
# auto : auto
# hapus : hapus
# mengecewakan : kecewa
# pengiriman : kirim
# ekspedisi : ekspedisi
# lambat : lambat
# transit : transit
# toko : toko
# pick : pick
# up : up
# rekomen : rekomen
# mending : mending
# pakai : pakai
# shopee : shopee
# aplikasinya : aplikasi
# berat : berat
# kalah : kalah
# online : online
# sebelah : belah
# klik : klik
# terbuka : buka
# super : super
# lemot : lot
# nyaman : nyaman
# kasih : kasih
# updatenya : updatenya
# coba : coba
# update : update
# punyeng : punyeng
# pokoknya : pokok
# pelapak : lapak
# disaat : saat
# pembeli : beli
# terkait : kait
# permintaan : minta
# pengembalian : kembali
# penjualanpembatalan : penjualanpembatalan
# notif : notif
# apl : apl
# nyanotif : nyanotif
# penjualan : jual
# email : email
# menanggapi : tanggap
# jam : jam
# dibatalkan : batal
# kembalikan : kembali
# merugikan : rugi
# cek : cek
# mohon : mohon
# perbaiki : baik
# dear : dear
# check : check
# posisi : posisi
# pesana : sana
# loading : loading
# bug : bug
# perhatiannya : perhati
# kerusakan : rusa
# system : system
# perbaikan : baik
# menggangu : menggangu
# penggunaan : guna
# dengar : dengar
# terima : terima
# membela : bela
# kepentingan : penting
# pelanggan : langgan
# menjanjikan : janji
# seminggu : minggu
# payleter : payleter
# lancar : lancar
# top : top
# game : game
# cancel : cancel
# sungguh : sungguh
# pantesan : pantesan
# jadul : jadul
# ditinggalkan : tinggal
# costumer : costumer
# fiturnya : fiturnya
# parah : parah
# banyaktidak : banyaktidak
# berfungsi : fungsi
# bukabantuannya : bukabantuannya
# susahnya : susah
# ampun : ampun
# penyelesaian : selesai
# penjual : jual
# sesuai : sesuai
# ninja : ninja
# expres : expres
# berpuluh : puluh
# puluh : puluh
# dilacak : lacak
# dikasih : kasih
# bintang : bintang
# sukur : sukur
# sih : sih
# pencarian : cari
# dipilih : pilih
# zonk : zonk
# dihapus : hapus
# alhasil : alhasil
# pilih : pilih
# melanggar : langgar
# saran : saran
# mengapai : kapai
# tampilkan : tampil
# barangnya : barang
# bantuannyasaya : bantuannyasaya
# mengalami : alami
# logindikarenakan : logindikarenakan
# menerima : terima
# kode : kode
# otp : otp
# nomor : nomor
# masukkan : masuk
# aktifmau : aktifmau
# live : live
# sayadan : sayadan
# bukalapakmohon : bukalapakmohon
# bantu : bantu
# isi : isi
# pengaturan : atur
# konsumen : konsumen
# betah : betah
# perdagangan : dagang
# pembelian : beli
# produk : produk
# digital : digital
# tanggal : tanggal
# mei : mei
# potongam : potongam
# saller : saller
# harga : harga
# jual : jual
# promote : promote
# push : push
# efek : efek
# mahal : mahal
# solusinya : solusi
# perubahan : ubah
# tutup : tutup
# pindah : pindah
# platform : platform
# buang : buang
# menyesal : sesal
# tabungan : tabung
# traktiran : traktir
# pengguna : guna
# kartu : kartu
# debitnya : debit
# tambahan : tambah
# knyatanya : knyatanya
# sebulan : bulan
# akunnya : akun
# hoax : hoax
# star : star
# seller : seller
# memberatkan : berat
# itemku : item
# higs : higs
# domino : domino
# bl : bl
# menerapkan : terap
# kecewa : kecewa
# kemudahan : mudah
# berbelanja : belanja
# rating : rating
# terpisah : pisah
# jasa : jasa
# puas : puas
# pelayanan : layan
# jelek : jelek
# pesan : pesan
# kekurir : kurir
# kejelasan : jelas
# asuransi : asuransi
# hilang : hilang
# mantulll : mantulll
# kondisi : kondisi
# ready : ready
# very : very
# gus : gus
# diriwayat : riwayat
# pesanan : pesan
# april : april
# pagi : pagi
# dikirim : kirim
# alamat : alamat
# penerima : terima
# an : an
# terima kasih : terima kasih
# ajalihat : ajalihat
# history : history
# mainnumpuk : mainnumpuk
# diserver : diserver
# akunbuatlah : akunbuatlah
# penyimpanan : simpan
# terbaru : baru
# nge : nge
# loadingnya : loadingnya
# suka : suka
# hang : hang
# selebihnya : lebih
# mantap : mantap
# rumitpadahal : rumitpadahal
# mengadukan : adu
# refaund : refaund
# prosespadahal : prosespadahal
# setia : setia
# bltp : bltp
# perlahan : perlahan
# beralih : alih
# lainselain : lainselain
# potongan : potong
# ongkir : ongkir
# rendah : rendah
# kolom : kolom
# beragamdi : beragamdi
# tawarkn : tawarkn
# ketikcari : ketikcari
# transaksinya : transaksi
# peforma : forma
# huhuhuuuuu : huhuhuuuuu
# komplen : komplen
# siniudah : siniudah
# capek : capek
# ngetikpas : ngetikpas
# tertulis : tulis
# tuju : tuju
# kemana : mana
# jdinya : jdinya
# beli : beli
# terimatpi : terimatpi
# reportnya : reportnya
# kurir : kurir
# bingungmo : bingungmo
# pasrah : pasrah
# tanggapin : tanggapin
# mantab : mantab
# menunya : menu
# simple : simple
# praktis : praktis
# pahami : paham
# kayak : kayak
# lemottnya : lemottnya
# bingung : bingung
# minusnya : minus
# voucher : voucher
# memenuhi : penuh
# persyaratan : syarat
# pilihan : pilih
# simpan : simpan
# gudang : gudang
# bukaexpress : bukaexpress
# livechat : livechat
# beda : beda
# merchant : merchant
# masuk : masuk
# dikirimkan : kirim
# aktif : aktif
# ganti : ganti
# foto : foto
# ktprekening : ktprekening
# daftar : daftar
# ktp : ktp
# seribet : seribet
# kah : kah
# cantumin : cantumin
# keterangan : terang
# diubah : ubah
# memasukkan : masuk
# tipenyasaya : tipenyasaya
# menyelesaikan : selesai
# rugi : rugi
# iklannya : iklan
# membuka : buka
# ngechek : ngechek
# iklan : iklan
# kuota : kuota
# internetdi : internetdi
# nglungker : nglungker
# bertambah : tambah
# jenuhtlg : jenuhtlg
# perhatikan : perhati
# mengadu : adu
# bukabantuan : bukabantuan
# bertele : tele
# kesana : kesana
# kemari : kemari
# tinggal : tinggal
# cari : cari
# sulit : sulit
# cuman : cuman
# dikit : dikit
# bukalapakygdulu : bukalapakygdulu
# aneh : aneh
# ya : ya
# didownload : didownload
# ulang : ulang
# touch : touch
# az : az
# merepotkan : repot
# batal : batal
# statusnya : status
# kadaluarsamau : kadaluarsamau
# ambil : ambil
# kapok : kapok
# kendala : kendala
# dibeli : beli
# dibayar : bayar
# sistemnya : sistem
# canggih : canggih
# dikomplain : komplain
# sadah : sadah
# kembaliini : kembaliini
# kepastianpayah : kepastianpayah
# gue : gue
# dibukalapak : dibukalapak
# malas : malas
# sayang : sayang
# mengajukan : aju
# dibalas : balas
# kurirnya : kurir
# mls : mls
# uangnya : uang
# woi : woi
# cs : cs
# mitra : mitra
# dalem : dalem
# penipu : tipu
# tertipu : tipu
# refund : refund
# detik : detik
# expedisi : expedisi
# reg : reg
# next : next
# day : day
# sicepat : sicepat
# lelet : lelet
# criss : criss
# cross : cross
# sop : sop
# resi : resi
# ybs : ybs
# kepercayaan : percaya
# kedepan : depan
# buset : buset
# pajangan : pajang
# ditemukan : temu
# diterima : terima
# hebat : hebat
# lenya : lenya
# ribu : ribu
# mempermudah : mudah
# berbelanjatapi : berbelanjatapi
# dam : dam
# halapalagi : halapalagi
# tanggapan : tanggap
# sistemnyakecewa : sistemnyakecewa
# telat : telat
# pemilihan : pilih
# ditambah : tambah
# report : report
# bermasalahpaket : bermasalahpaket
# jadwal : jadwal
# kompensasi : kompensasi
# jaminan : jamin
# kembalihanya : kembalihanya
# slogan : slogan
# belakabagaimana : belakabagaimana
# min : min
# respon : respon
# payah : payah
# ah : ah
# habis : habis
# untung : untung
# ngisi : ngisi
# cash : cash
# back : back
# lom : lom
# tau : tau
# telepon : telepon
# memuaskan : muas
# jawabannyacoba : jawabannyacoba
# membatalkan : batal
# tanggepin : tanggepin
# tlong : tlong
# jawabannya : jawab
# tentui : tentu
# jgbuat : jgbuat
# bantumakin : bantumakin
# hubungin : hubungin
# chatlemot : chatlemot
# tele : tele
# sory : sory
# turun : turun
# lag : lag
# memperbaiki : baik
# payleater : payleater
# bukalapaksaya : bukalapaksaya
# tagihan : tagih
# tagih : tagih
# lagibukti : lagibukti
# struknya : struknya
# kasir : kasir
# indomart : indomart
# berhasil : hasil
# yeah : yeah
# tagihantapi : tagihantapi
# anehnya : aneh
# limit : limit
# salah : salah
# bukaemas : bukaemas
# bilang : bilang
# sabar : sabar
# pengecekan : kece
# kepastian : pasti
# gua : gua
# ramadhan : ramadhan
# jualan : jual
# posting : posting
# enak : enak
# flashdeal : flashdeal
# belinya : beli
# shake : shake
# thon : thon
# dapatnya : dapat
# perak : perak
# thx : thx
# sudahlama : sudahlama
# retur : retur
# kayanya : kaya
# uninstall : uninstall
# berasa : asa
# aman : aman
# ribet : ribet
# dipersulit : sulit
# hubungkan : hubung
# dibilang : bilang
# ecommerce : ecommerce
# tertua : tua
# inovasi : inovasi
# rp : rp
# byr : byr
# vamandiri : vamandiri
# duit : duit
# pembyran : pembyran
# ditarik : tarik
# duitnya : duit
# transferpenarikkan : transferpenarikkan
# upgrade : upgrade
# premium : premium
# satusatunya : satusatunya
# akses : akses
# berfungsihatihati : berfungsihatihati
# xufsinv : xufsinv
# diproses : proses
# melebihi : lebih
# batas : batas
# maksimal : maksimal
# dbatalkan : dbatalkan
# tertahan : tahan
# jelasjelas : jelasjelas
# tertera : tera
# pencariannya : cari
# mencari : cari
# ikan : ikan
# hias : hias
# pakan : pakan
# ganggu : ganggu
# bukatabungan : bukatabungan
# minada : mada
# gangguan : ganggu
# teman : teman
# undang : undang
# permasalahn : permasalahn
# masukan : masuk
# bual : bual
# adakan : adakan
# request : request
# pickup : pickup
# awam : awam
# tampil : tampil
# edit : edit
# dijual : jual
# tampilan : tampil
# varian : varian
# keterangannya : terang
# memiliki : milik
# tipe : tipe
# nginput : nginput
# apanya : apa
# disamainnnnn : disamainnnnn
# feedback : feedback
# dm : dm
# ig : ig
# digubris : gubris
# sptnya : sptnya
# halooooo : halooooo
# ribuan : ribu
# biji : biji
# order : order
# marketplace : marketplace
# sepi : sepi
# pelit : pelit
# free : free
# pajaknya : pajak
# gede : gede
# royal : royal
# uninstal : uninstal
# emosi : emosi
# mematikan : mati
# obrolannya : obrol
# aktifin : aktifin
# no : no
# hangus : hangus
# kyc : kyc
# ane : ane
# join : join
# buruk : buruk
# metode : metode
# gonta : gonta
# mencukupi : cukup
# hadehh : hadehh
# tolonglah : tolong
# paylaternya : paylaternya
# bekukan : beku
# basah : basah
# basih : basih
# custumer : custumer
# customer : customer
# servicenya : servicenya
# kepercayan : kepercayan
# ecom : ecom
# utama : utama
# aktifasi : aktifasi
# gampang : gampang
# komplin : komplin
# sumpah : sumpah
# enek : enek
# masak : masak
# nomer : nomer
# sefty : sefty
# main : main
# lo : lo
# nyataanya : nyataanya
# nomornya : nomor
# aktivasi : aktivasi
# syaratnya : syarat
# pinjaman : pinjam
# bank : bank
# sumpaah : sumpaah
# oohh : oohh
# devlover : devlover
# lebay : lebay
# syarat : syarat
# pengirimannya : kirim
# koreksi : koreksi
# wilyah : wilyah
# timur : timur
# indonesia : indonesia
# harganya : harga
# contoh : contoh
# ongkos : ongkos
# kirimnya : kirim
# mencapai : capai
# fer : fer
# kemahalan : mahal
# jadikan : jadi
# bertransaksi : transaksi
# install : install
# berulangulang : berulangulang
# mencoba : coba
# wadew : wadew
# tunggu : tunggu
# blank : blank
# tandatanda : tandatanda
# apapun : apa
# berjamjam : berjamjam
# sore : sore
# biarkan : biar
# normal : normal
# tibatiba : tibatiba
# ditangguhkan : tangguh
# konfirmasi : konfirmasi
# login : login
# sunguh : sunguh
# sarankan : saran
# menyimpan : simpan
# menghindari : hindar
# alami : alami
# kredit : kredit
# kena : kena
# warning : warning
# nih : nih
# emak : emak
# lato : lato
# swafoto : swafoto
# tangan : tangan
# kanan : kanan
# kiri : kiri
# pegang : pegang
# buku : buku
# bantuin : bantuin
# repot : repot
# sistemnyasya : sistemnyasya
# sellerkenapa : sellerkenapa
# nama : nama
# pencariandi : pencariandi
# tracking : tracking
# validbanyak : validbanyak
# pembelitapi : pembelitapi
# trackingnya : trackingnya
# percepat : cepat
# marketpkace : marketpkace
# emas : emas
# problemnya : problem
# bad : bad
# gateway : gateway
# enggak bisa : enggak bisa
# kayaknya : kayak
# sengaja : sengaja
# tarik : tarik
# investasi : investasi
# app : app
# kebanyakan : banyak
# rusak : rusak
# dibikin : bikin
# simpel : simpel
# kemarin : kemarin
# dibuka : buka
# diskusi : diskusi
# mengembalikan : kembali
# kekurangan : kurang
# transfer : transfer
# ajabanyak : ajabanyak
# sisrem : sisrem
# gunabuka : gunabuka
# kaya : kaya
# ajaisi : ajaisi
# harap : harap
# ajadan : ajadan
# bagusmasuk : bagusmasuk
# ribetnya : ribetnya
# menilai : nilai
# kemunduran : mundur
# ratingnya : ratingnya
# cumq : cumq
# temukan : temu
# gaya : gaya
# pengunjung : unjung
# angsuran : angsur
# sajadan : sajadan
# aktifharus : aktifharus
# belanjabrg : belanjabrg
# tengkyuu : tengkyuu
# dijamin : jamin
# ktpreffvral : ktpreffvral
# btbldkzqvt : btbldkzqvt
# nyaaplikasii : nyaaplikasii
# lamasangat : lamasangat
# dikala : kala
# belanjatinggal : belanjatinggal
# bayarbarang : bayarbarang
# kedepannya : depan
# membaiktengkyuuu : membaiktengkyuuu
# mengaco : aco
# aturan : atur
# nonaktif : nonaktif
# berulang : ulang
# set : set
# list : list
# item : item
# beranda : beranda
# profile : profile
# mengerti : erti
# ditampilkan : tampil
# halah : halah
# pikir : pikir
# menghubungi : hubung
# servis : servis
# presiden : presiden
# standby : standby
# lokasi : lokasi
# dihalaman : halaman
# kak : kak
# ngalami : ngalami
# mendingan : mending
# ngalamin : ngalamin
# bhulshittt : bhulshittt
# program : program
# express : express
# garansi : garansi
# tipu : tipu
# tipunya : tipu
# mode : mode
# claimnya : claimnya
# default : default
# curang : curang
# berkahh : berkahh
# siasat : siasat
# mnjamingaransi : mnjamingaransi
# bertanggung : tanggung
# profesional : profesional
# maju : maju
# cod : cod
# beban : beban
# and : and
# sampah : sampah
# smartphone : smartphone
# dipiara : piara
# bermanfaat : manfaat
# terkocak : kocak
# terkirim : kirim
# mulu : mulu
# kelar : kelar
# eneg : eneg
# dengernya : dengernya
# eh : eh
# blokir : blokir
# badut : badut
# password : password
# sekalibegitu : sekalibegitu
# verif : verif
# suruh : suruh
# passwordklik : passwordklik
# lupa : lupa
# bisagimana : bisagimana
# percaya : percaya
# ulasan : ulas
# promoted : promoted
# orderan : order
# selau : selau
# sesi : sesi
# info : info
# variannya : varian
# dipermudah : mudah
# fleksibel : fleksibel
# monoton : monoton
# disesuaikan : sesuai
# size : size
# real : real
# nurut : nurut
# disediakan : sedia
# kategori : kategori
# biyaya : biyaya
# penanganan : tangan
# maksudnya : maksud
# menyesak : sesak
# sgitu : sgitu
# ilangin : ilangin
# tuhklo : tuhklo
# kurangi : kurang
# kepakasa : kepakasa
# blanja : blanja
# saking : saking
# chip : chip
# snapdragon : snapdragon
# gen : gen
# ram : ram
# gb : gb
# clear : clear
# chace : chace
# logout : logout
# permasalahan : masalah
# server : server
# bisaselalu : bisaselalu
# disuruh : suruh
# lengkapi : lengkap
# chapta : chapta
# dinyatakan : nyata
# lulus : lulus
# dinonaktifkan : nonaktif
# drastis : drastis
# hasil : hasil
# berjualan : jual
# cairkan : cair
# butuh : butuh
# keperluan : perlu
# mendesak : desak
# cair : cair
# pinjam : pinjam
# tetangga : tetangga
# promot : promot
# ngitung : ngitung
# utang : utang
# lunas : lunas
# penjumlahan : jumlah
# mines : mes
# hutang : hutang
# pulsa : pulsa
# ijo : ijo
# oran : oran
# pemberitahuan : pemberitahuan
# paylter : paylter
# jebakan : jebak
# betmen : betmen
# harapan : harap
# lagiterima : lagiterima
# dompet : dompet
# barangterima : barangterima
# bukalapaktidak : bukalapaktidak
# mengecewakanjaya : mengecewakanjaya
# bukalapakaplikasi : bukalapakaplikasi
# indonesiasekali : indonesiasekali
# inikasih : inikasih
# memproses : proses
# bgtkasihan : bgtkasihan
# dongharusnya : dongharusnya
# max : max
# mengirimkan : kirim
# haribukanya : haribukanya
# pembelimenurut : pembelimenurut
# bukalapakklo : bukalapakklo
# pesananmereka : pesananmereka
# sendiridan : sendiridan
# kirimkanentah : kirimkanentah
# lupaatau : lupaatau
# readymohon : readymohon
# lagibuat : lagibuat
# aga : aga
# dowload : dowload
# inikarna : inikarna
# lamatp : lamatp
# barangpengiriman : barangpengiriman
# standar : standar
# membaiksesuai : membaiksesuai
# estimasiuntuk : estimasiuntuk
# ditingkat : tingkat
# lgtrima : lgtrima
# kasihapk : kasihapk
# berguna : guna
# laporan : lapor
# kabar : kabar
# maaf : maaf
# alasan : alas
# hubungi : hubung
# via : via
# artikel : artikel
# review : review
# dok : dok
# prosez : prosez
# memutuskan : putus
# melampirkan : lampir
# rek : rek
# mutasi : mutasi
# nampaklah : nampaklah
# nota : nota
# bene : bene
# informasi : informasi
# krusial : krusial
# dmpak : dmpak
# securitynya : securitynya
# brengsek : brengsek
# dajjal : dajjal
# google : google
# permanen : permanen
# kagak : kagak
# pembayaranya : pembayaranya
# lainyasangat : lainyasangat
# mudahsangat : mudahsangat
# kalangan : kalang
# menengah : tengah
# kebawahapalagi : kebawahapalagi
# gratis : gratis
# vocer : vocer
# lainya : lai
# dapatkanpayah : dapatkanpayah
# penjualnya : jual
# bukalapaknya : bukalapaknya
# seharus : harus
# php : php
# kesempatan : sempat
# bonus : bonus
# event : event
# secepatnya : cepat
# mini : mini
# periode : periode
# maret : maret
# kecewadimana : kecewadimana
# menyediakan : sedia
# codtapi : codtapi
# bukalapakudah : bukalapakudah
# limite : limite
# naikpantaslah : naikpantaslah
# telkom : telkom
# wib : wib
# cocok : cocok
# pembisnis : bisnis
# ringan : ringan
# all : all
# one : one
# feature : feature
# rekomendasi : rekomendasi
# januari : januari
# jugasudah : jugasudah
# ajukan : aju
# tanggapi : tanggap
# bukalapaksungguh : bukalapaksungguh
# pemesanan : mesan
# memesan : mes
# rokok : rokok
# pindahkan : pindah
# sd : sd
# estimasi : estimasi
# pay : pay
# later : later
# dibajak : bajak
# pusat : pusat
# pending : pending
# bukalapakeh : bukalapakeh
# suami : suami
# jutamasa : jutamasa
# bajakhrsny : bajakhrsny
# ditahan : tahan
# pesanannyakan : pesanannyakan
# keren : keren
# bertahan : tahan
# persaingan : saing
# ketat : ketat
# kompetitornya : kompetitor
# yuk : yuk
# buruan : buru
# download : download
# konsisten : konsisten
# timbul : timbul
# tenggelam : tenggelam
# loh : loh
# hehee : hehee
# sukses : sukses
# andalan : andal
# way : way
# ketinggalan : tinggal
# terpotong : potong
# opsi : opsi
# dicetak : cetak
# helooo : helooo
# syaa : syaa
# buyer : buyer
# driver : driver
# user : user
# friendly : friendly
# menyulitkan : sulit
# penilain : penilain
# kasihan : kasihan
# langanan : langanan
# laganan : lagan
# perbarui : baru
# kualitas : kualitas
# menurun : turun
# tingkatkan : tingkat
# membanyaki : banyak
# vouchernya : vouchernya
# kargo : kargo
# sediakan : sedia
# laman : laman
# tks : tks
# lemotbukan : lemotbukan
# internet : internet
# lemotaplikasinya : lemotaplikasinya
# perbaikimasi : perbaikimasi
# orangemasa : orangemasa
# utuma : utuma
# mengadakan : ada
# kerjasama : kerjasama
# referral : referral
# alhamdulillah : alhamdulillah
# rezeki : rezeki
# tsbt : tsbt
# mengajak : ajak
# mendaftar : daftar
# perpanjang : panjang
# bukutabungan : bukutabungan
# hpgmail : hpgmail
# code : code
# undangan : undang
# btblvj : btblvj
# turunin : turunin
# bintangnya : bintang
# eror : eror
# langganan : langgan
# sayapadahal : sayapadahal
# label : label
# tersedia : sedia
# cekout : cekout
# catatan : catat
# memakai : pakai
# inipadahal : inipadahal
# jembutsaya : jembutsaya
# dagang : dagang
# dlliklan : dlliklan
# belasan : bas
# boroboro : boroboro
# munculbangsaaatt : munculbangsaaatt
# sisi : sisi
# ui : ui
# popup : popup
# mengganggu : ganggu
# call : call
# center : center
# dadi : dadi
# komplainnya : komplain
# action : action
# bermasalah : masalah
# pribadi : pribadi
# bisnis : bisnis
# berlimpah : limpah
# mantaab : mantaab
# markotopmaknyosss : markotopmaknyosss
# baikbaiiiil : baikbaiiiil
# service : service
# kendaladan : kendaladan
# solusitidak : solusitidak
# sekian : sekian
# complain : complain
# dikirimlha : dikirimlha
# menit : menit
# software : software
# instal : instal
# akunpu : akunpu
# petunjuk : tunjuk
# bantuannya : bantu
# lacak : lacak
# elektronik : elektronik
# digabung : gabung
# darp : darp
# nyaedaaaan : nyaedaaaan
# pemerasan : peras
# its : its
# ok : ok
# sense : sense
# fungsi : fungsi
# larinya : lari
# dodol : dodol
# nasabah : nasabah
# token : token
# listrik : listrik
# urgent : urgent
# laaahh : laaahh
# kabupaten : kabupaten
# bandung : bandung
# padalarang : padalarang
# mesan : mesan
# februari : februari
# tulisan : tulis
# nobody : nobody
# at : at
# home : home
# dirumah : rumah
# ente : ente
# jne : jne
# dll : dll
# beginiga : beginiga
# kabbandung : kabbandung
# jakarta : jakarta
# amanah : amanah
# bareng : bareng
# dipahami : paham
# mantablah : mantablah
# keselahan : lah
# dimana : mana
# captcha : captcha
# mengulang : ulang
# beresin : resin
# terganggu : ganggu
# danatransfer : danatransfer
# berubah : ubah
# ongkirnya : ongkirnya
# yrus : yrus
# berkembang : kembang
# prosespelapak : prosespelapak
# meresponsolusi : meresponsolusi
# menungguini : menungguini
# pemrosesan : pemrosesan
# hak : hak
# developer : developer
# lazada : lazada
# tiktok : tiktok
# wajar : wajar
# orentiktok : orentiktok
# layak : layak
# disana : sana
# ketimbang : ketimbang
# wkwk : wkwk
# letoy : letoy
# audit : audit
# gimmick : gimmick
# heran : heran
# tertinggal : tinggal
# tik : tik
# tok : tok
# murah : murah
# masang : masang
# pasang : pasang
# ayo : ayo
# diminati : mati
# grosiran : grosir
# bos : bos
# dikatan : dikatan
# itupun : itu
# bayarkan : bayar
# antusias : antusias
# menagih : tagih
# sydah : sydah
# lagicustomer : lagicustomer
# servisnya : servis
# onlinetapi : onlinetapi
# buatlah : buat
# indomaretalfamartbahkan : indomaretalfamartbahkan
# atmjadi : atmjadi
# rumah : rumah
# trnsaksi : trnsaksi
# berhasilpulsa : berhasilpulsa
# masuktagihan : masuktagihan
# adakomplen : adakomplen
# diurus : urus
# mesin : mesin
# hynaevinv : hynaevinv
# dicancelsejak : dicancelsejak
# sampaiudah : sampaiudah
# loohhhkembalikan : loohhhkembalikan
# seharga : harga
# account : account
# berani : berani
# kontak : kontak
# rumit : rumit
# danabukalapak : danabukalapak
# trimakasih : trimakasih
# inovatif : inovatif
# sadar : sadar
# gunakanauto : gunakanauto
# uninstaljika : uninstaljika
# trmksih : trmksih
# masalahsudah : masalahsudah
# jalan : jalan
# keluarketika : keluarketika
# mengetik : etik
# putus : putus
# sambungan : sambung
# nyakalo : nyakalo
# menggu : menggu
# giliran : gilir
# yohana : yohana
# bersabar : sabar
# nunggusaaya : nunggusaaya
# ngetiikkkk : ngetiikkkk
# efisien : efisien
# hemat : hemat
# duduk : duduk
# manis : manis
# low : low
# cost : cost
# ngirit : ngirit
# pencaria : pencaria
# penjualanya : penjualanya
# visual : visual
# alangkah : alangkah
# baiknya : baik
# ditingkatkan : tingkat
# terbaik : baik
# hijau : hijau
# orange : orange
# full : full
# dibatasi : batas
# kuotanya : kuota
# mudahproses : mudahproses
# cepatdan : cepatdan
# menariksangat : menariksangat
# rekomendit : rekomendit
# sehari : hari
# batalin : batalin
# pejual : jual
# jugasedangkan : jugasedangkan
# gunakanharus : gunakanharus
# mengadutolong : mengadutolong
# lapakbiar : lapakbiar
# keluhan : keluh
# alias : alias
# gajelasgda : gajelasgda
# dgunainmaupun : dgunainmaupun
# gitupadahal : gitupadahal
# plytrkecewa : plytrkecewa
# telp : telp
# custemservis : custemservis
# ngurusinya : ngurusinya
# visa : visa
# chatlive : chatlive
# ngelunasin : ngelunasin
# always : always
# nice : nice
# lengkap : lengkap
# terpercaya : percaya
# diskon : diskon
# provider : provider
# good : good
# job : job
# satisfied : satisfied
# lakukan : laku
# payletter : payletter
# teror : teror
# reseller : reseller
# diperbaharui : baharu
# dimudahkan : mudah
# berfungsipadahal : berfungsipadahal
# pelapaknya : lapak
# codketika : codketika
# codpembayaran : codpembayaran
# tunai : tunai
# benerin : benerin
# iya : iya
# notifikasi : notifikasi
# kota : kota
# pengirim : kirim
# nyasar : nyasar
# kmna : kmna
# lemott : lemott
# sistemya : sistemya
# bukamall : bukamall
# pilihannya : pilih
# complainnya : complainnya
# digunain : digunain
# aplikasinyamau : aplikasinyamau
# jaringan : jaring
# bagusmemori : bagusmemori
# banyakkuota : banyakkuota
# hmm : hmm
# detail : detail
# penjemputan : jemput
# kepeeluan : kepeeluan
# dagangan : dagang
# kmp : kmp
# bisatp : bisatp
# kuotapulsatoken : kuotapulsatoken
# ybarang : ybarang
# kirimtapi : kirimtapi
# sistembarang : sistembarang
# komple : komple
# pejualan : jual
# selesaiklu : selesaiklu
# ketingakan : ketingakan
# shopetikopedia : shopetikopedia
# barusan : barusan
# nominal : nominal
# dipaktur : dipaktur
# selisihnya : selisih
# mnrut : mnrut
# terbaiknya : baik
# acc : acc
# terimakasih : terimakasih
# menindaklanjuti : menindaklanjuti
# enggak jelas : enggak jelas
# kinerjanya : kerja
# informasj : informasj
# pengerjaannya : kerja
# barangsaya : barangsaya
# layar : layar
# putih : putih
# berjam : jam
# ragu : ragu
# komplainan : komplain
# livechatnya : livechatnya
# wadah : wadah
# prosedur : prosedur
# sejenisnya : jenis
# ttup : ttup
# amnah : amnah
# sopan : sopan
# mas : mas
# bagusmalah : bagusmalah
# menurunupdate : menurunupdate
# berpengaruhhapus : berpengaruhhapus
# cacheclear : cacheclear
# datasama : datasama
# ajaaplikasi : ajaaplikasi
# menonton : tonton
# streaming : streaming
# hd : hd
# jaya : jaya
# masal : masal
# artikelnya : artikel
# kenyataannya : nyata
# imfor : imfor
# kunci : kunci
# menggunakannya : guna
# support : support
# nyampek : nyampek
# terkadang : terkadang
# nnya : nnya
# amana : amana
# tranksaksi : tranksaksi
# tranksasi : tranksasi
# layanananya : layanananya
# untungnya : untung
# parahhhhhhhhhhh : parahhhhhhhhhhh
# ikuti : ikut
# bekukangmna : bekukangmna
# bgtuh : bgtuh
# menutup : tutup
# hati : hati
# meresa : resa
# rugikan : rugi
# senang : senang
# belanjatop : belanjatop
# palyeter : palyeter
# akulaku : akulaku
# penilaian : nilai
# ruang : ruang
# tutupdi : tutupdi
# tlfn : tlfn
# marah : marah
# ku : ku
# abuabu : abuabu
# shop : shop
# keluarga : keluarga
# diragukan : ragu
# discountnya : discountnya
# tambahkan : tambah
# sertakan : serta
# fotonya : foto
# setahun : tahun
# laku : laku
# ditampilin : ditampilin
# etalase : etalase
# profil : profil
# mengecewakanaman : mengecewakanaman
# customertingkatkan : customertingkatkan
# prestasi : prestasi
# blspy : blspy
# maintenance : maintenance
# disebelah : belah
# keberanda : beranda
# berbuln : berbuln
# balikin : balikin
# nympe : nympe
# bda : bda
# pulau : pulau
# blnj : blnj
# ssh : ssh
# nonaktifkan : nonaktif
# kebutuhan : butuh
# biaa : biaa
# virtualsaldo : virtualsaldo
# mengirim : kirim
# plus : plus
# dendauang : dendauang
# melayangmau : melayangmau
# bisajadi : bisajadi
# transfertapi : transfertapi
# oke : oke
# pertahankan : tahan
# dgunakan : dgunakan
# test : test
# bberapa : bberapa
# mempelajari : ajar
# jarang : jarang
# palsu : palsu
# watelpon : watelpon
# membingunkan : membingunkan
# ceo : ceo
# asugak : asugak
# mahalan : mahal
# belilama : belilama
# apalah : apa
# gabakalan : gabakalan
# terhubung : hubung
# terputus : putus
# penyedia : sedia
# fasilitas : fasilitas
# prifasi : prifasi
# histori : histori
# obatproduk : obatproduk
# dewasa : dewasa
# sebagainyaitu : sebagainyaitu
# prifasitrims : prifasitrims
# virtual : virtual
# kadaluarsa : kadaluarsa
# nayar : nayar
# jagn : jagn
# berbelanjatp : berbelanjatp
# pembayarannya : bayar
# permudah : mudah
# bebas : bebas
# persulit : sulit
# contohhanya : contohhanya
# berlaku : laku
# kreditx : kreditx
# dipindahkan : pindah
# minkhusus : minkhusus
# rokets : rokets
# dapatx : dapatx
# kekumpul : kumpul
# exp : exp
# cc : cc
# cicilan : cicil
# tertagih : tagih
# confirmasi : confirmasi
# urus : urus
# korban : korban
# wninv : wninv
# pembatalan : batal
# curiga : curiga
# pencuri : curi
# pemeliharaan : pelihara
# dimatiin : dimatiin
# butuhkan : butuh
# cicil : cicil
# suport : suport
# video : video
# kelanjutan : lanjut
# komplainya : komplainya
# jozzzzz : jozzzzz
# gandossssst : gandossssst
# perlindungan : lindung
# on : on
# line : line
# penggunaannya : guna
# segitu : segitu
# limitnya : limit
# non : non
# belajan : bajan
# akal : akal
# bersaing : saing
# bukalapakpesanan : bukalapakpesanan
# kurur : kurur
# cepattapi : cepattapi
# complainmenu : complainmenu
# bukanantuan : bukanantuan
# betfungsi : betfungsi
# aesuai : aesuai
# subhanallah : subhanallah
# pertanda : tanda
# bangkrut : bangkrut
# kolaps : kolaps
# tf : tf
# komunikasi : komunikasi
# emailpun : email
# direspon : direspon
# bloon : bloon
# bukasend : bukasend
# semprul : semprul
# beritahuakan : beritahuakan
# yaadi : yaadi
# tanggung : tanggung
# xsetelah : xsetelah
# tercantumini : tercantumini
# melayang : layang
# kabarsangat : kabarsangat
# burukpenipuan : burukpenipuan
# lu : lu
# anjenggg : anjenggg
# toped : toped
# shopeee : shopeee
# bapuk : bapuk
# taiii : taiii
# kredivo : kredivo
# juta : juta
# lemoot : lemoot
# aplikasinyatolong : aplikasinyatolong
# lainudh : lainudh
# pengirimanya : pengirimanya
# tentukan : tentu
# stak : stak
# erortolong : erortolong
# dipwrbaiki : dipwrbaiki
# nyaterima : nyaterima
# komplit : komplit
# kejadian : jadi
# tiki : tik
# mengaktifkan : aktif
# zaman : zaman
# manual : manual
# dibutuhin : dibutuhin
# peningkatan : tingkat
# bla : bla
# hadeuhh : hadeuhh
# mantapsemakin : mantapsemakin
# bukalapakmemberikan : bukalapakmemberikan
# bertransaksitx : bertransaksitx
# iming : iming
# warung : warung
# hahaha : hahaha
# haaaaa : haaaaa
# ketemu : ketemu
# acha : acha
# niat : niat
# berkali : kali
# serius : serius
# kopeten : kopeten
# stock : stock
# tayangin : tayangin
# kesalahan : salah
# transparant : transparant
# play : play
# store : store
# updatetan : updatetan
# berpihak : pihak
# kepelapak : lapak
# kompalin : kompalin
# banyakan : banyak
# intinya : inti
# pudar : pudar
# butuuutttt : butuuutttt
# mengikuti : ikut
# arahan : arah
# disarankan : saran
# bebarapa : bebarapa
# chattapi : chattapi
# terkesan : kes
# memutus : putus
# percakapan : cakap
# etika : etika
# tuntutan : tuntut
# sejarahbuktiin : sejarahbuktiin
# sendirikalah : sendirikalah
# sebelahjoos : sebelahjoos
# ceritanya : cerita
# dibl : dibl
# menarik : tarik
# sekalinya : sekali
# akibatnya : akibat
# instan : instan
# byar : byar
# berikanhanya : berikanhanya
# diwajibakan : diwajibakan
# tolak : tolak
# tampa : tampa
# penerimaan : terima
# variasi : variasi
# laptop : laptop
# pc : pc
# indihome : indihome
# gara : gara
# roda : roda
# rejeki : rejeki
# sdikit : sdikit
# rekomendet : rekomendet
# ongir : ongir
# dibandingkan : banding
# dibantu : bantu
# performa : performa
# kembangkan : kembang
# cinta : cinta
# negeri : negeri
# terbatas : batas
# com : com
# laindan : laindan
# dek : dek
# susa : susa
# temanteman : temanteman
# bukalapakkurirnya : bukalapakkurirnya
# jidat : jidat
# otakbarang : otakbarang
# kirimkirimitu : kirimkirimitu
# tanaman : tanam
# busuk : busuk
# garagara : garagara
# sialanbukalapak : sialanbukalapak
# terburuk : buruk
# adalive : adalive
# janjiin : janjiin
# sampaikurirnya : sampaikurirnya
# akhlak : akhlak
# wa : wa
# terkendalakalau : terkendalakalau
# jawabburuk : jawabburuk
# lemah : lemah
# keamanan : aman
# taii : taii
# rekomendasikan : rekomendasi
# ujung : ujung
# ujungnya : ujung
# matikan : mati
# paham : paham
# matiin : matiin
# eroor : eroor
# berhubung : hubung
# newbie : newbie
# nilai : nilai
# playlater : playlater
# lapaksudah : lapaksudah
# diaktifkan : aktif
# dicoba : coba
# sok : sok
# far : far
# icon : icon
# mutarmutar : mutarmutar
# menemukan : temu
# aneka : aneka
# sparepart : sparepart
# otomotif : otomotif
# inden : inden
# dilesan : les
# dikirimnya : kirim
# bangetmau : bangetmau
# gmail : gmail
# sandi : sandi
# berkalikali : berkalikali
# loginkatanya : loginkatanya
# apanyajelas : apanyajelas
# bilangnya : bilang
# salahsalah : salahsalah
# ahterus : ahterus
# loginnya : loginnya
# pelayananya : pelayananya
# responterima : responterima
# belanjanya : belanja
# fast : fast
# kepuasan : puas
# diseleksi : seleksi
# menunda : tunda
# pesanannya : pesan
# dikembalikan : kembali
# lagibuang : lagibuang
# euy : euy
# ndk : ndk
# bisauang : bisauang
# ditranfer : ditranfer
# lagisudah : lagisudah
# responrelakan : responrelakan
# custom : custom
# kalimat : kalimat
# baku : baku
# harapannya : harap
# display : display
# merk : merk
# spesifikasi : spesifikasi
# tertampil : tampil
# variatif : variatif
# selisih : selisih
# signifikan : signifikan
# memilih : pilih
# berbeda : beda
# kwalitas : kwalitas
# amin : amin
# judul : judul
# gambar : gambar
# memodifikasi : modifikasi
# selainnya : selain
# halo : halo
# bukadompet : bukadompet
# dibekukan : beku
# senilai : nila
# struk : struk
# topup : topup
# berjaya : jaya
# seleksi : seleksi
# curangpenjual : curangpenjual
# nakal : nakal
# menipu : tipu
# dikecewakan : kecewa
# pertahanan : tahan
# pedagang : dagang
# ketempat : tempat
# mutermuter : mutermuter
# market : market
# place : place
# backup : backup
# tuntas : tuntas
# berpikir : pikir
# tingkat : tingkat
# pemgiriman : pemgiriman
# setatus : setatus
# brang : brang
# keburu : keburu
# mingkin : mingkin
# finalti : finalti
# perbiaki : biak
# lagicoba : lagicoba
# menurunbukan : menurunbukan
# membaik : baik
# jepara : jepara
# teramat : amat
# lamalebih : lamalebih
# wajargk : wajargk
# lagibukan : lagibukan
# kenapaverifikasi : kenapaverifikasi
# sms : sms
# kodenyasampe : kodenyasampe
# terusuninstal : terusuninstal
# bisakode : bisakode
# berhenti : henti
# kethabis : kethabis
# memuncak : puncak
# ditiadakan : tiada
# filter : filter
# bersifat : sifat
# dikonfirmasi : konfirmasi
# improve : improve
# perampok : rampok
# olshop : olshop
# pasword : pasword
# elh : elh
# screen : screen
# shot : shot
# dihubungi : hubung
# kacau : kacau
# bukalapaknamun : bukalapaknamun
# tgn : tgn
# penipuan : tipu
# ongkirjasa : ongkirjasa
# kuriryang : kuriryang
# mahaltujuan : mahaltujuan
# manado : manado
# ribunamun : ribunamun
# permainan : main
# darathanya : darathanya
# ribualhasil : ribualhasil
# samasaya : samasaya
# berbenahjgn : berbenahjgn
# permainkan : main
# pelangganjangan : pelangganjangan
# salahkan : salah
# bnyaktapi : bnyaktapi
# difungsikan : fungsi
# ewallet : ewallet
# kunjung : kunjung
# tahan : tahan
# nonfisik : nonfisik
# fisikisinya : fisikisinya
# semuasaya : semuasaya
# higgs : higgs
# selesaisukses : selesaisukses
# dikirimudah : dikirimudah
# tanggapidiliat : tanggapidiliat
# mengambil : ambil
# keputusan : putus
# mitrabukalapak : mitrabukalapak
# penghasilanbikin : penghasilanbikin
# pelangganbikin : pelangganbikin
# laris : laris
# manisbiaya : manisbiaya
# cashback : cashback
# poin : poin
# lagicari : lagicari
# agen : agen
# username : username
# adeirmasari : adeirmasari
# ranting : ranting
# unistal : unistal
# rekomdasi : rekomdasi
# kurisr : kurisr
# irm : irm
# mengantar : antar
# sedia : sedia
# melayani : layan
# jnt : jnt
# aktifkan : aktif
# terselesaikan : selesai
# knpsejak : knpsejak
# bajakdi : bajakdi
# situ : situ
# cemasdan : cemasdan
# updatelengkap : updatelengkap
# rinci : rinci
# malesblm : malesblm
# nyablm : nyablm
# nyatrlalu : nyatrlalu
# makan : makan
# waktucoba : waktucoba
# lahapa : lahapa
# titipagar : titipagar
# perbaikiagar : perbaikiagar
# berbobotdan : berbobotdan
# lagiputusin : lagiputusin
# hubungan : hubung
# paylaterpercumaga : paylaterpercumaga
# jugakl : jugakl
# wat : wat
# tekan : tekan
# smile : smile
# selepas : lepas
# mendesakharusnya : mendesakharusnya
# kembalibagaimanapun : kembalibagaimanapun
# bldah : bldah
# ulangi : ulang
# samatapi : samatapi
# diedit : edit
# sekedar : dar
# tiket : tiket
# pelaporan : lapor
# dokumen : dokumen
# bukalapaksukses : bukalapaksukses
# off : off
# the : the
# best : best
# mantapsya : mantapsya
# bisakarena : bisakarena
# terivikasi : terivikasi
# training : training
# tercover : tercover
# bukalapakbayar : bukalapakbayar
# telatmalah : telatmalah
# splayter : splayter
# splayternya : splayternya
# aktifinntar : aktifinntar
# menjual : jual
# terjual : jual
# hda : hda
# tua : tua
# berbenah : benah
# fyuuhh : fyuuhh
# beres : beres
# dicek : cek
# ngeri : ngeri
# slow : slow
# ancurlahhh : ancurlahhh
# move : move
# oren : oren
# ptongan : ptongan
# rda : rda
# maksud : maksud
# daya : daya
# kompalain : kompalain
# tpdiketangan : tpdiketangan
# cap : cap
# kaki : kaki
# atm : atm
# kecepatan : cepat
# sellernya : sellernya
# permintaannya : minta
# prosesnya : proses
# relatif : relatif
# ols : ols
# seribu : ribu
# semangat : semangat
# dibayarkan : bayar
# pilihannyacuma : pilihannyacuma
# alau : alau
# outcaranya : outcaranya
# ukuran : ukur
# warna : warna
# barangtp : barangtp
# bagusisinya : bagusisinya
# adajooossss : adajooossss
# pengganti : ganti
# bukasen : bukasen
# input : input
# kostumer : kostumer
# media : media
# sosial : sosial
# fb : fb
# aktf : aktf
# cht : cht
# memahami : paham
# memudahkan : mudah
# kejutan : kejut
# bangking : bangking
# cencel : cencel
# uangpun : uang
# kebukatolong : kebukatolong
# mati : mati
# galeri : galeri
# taunya : tau
# melulu : melulu
# pengajuan : aju
# riwayat : riwayat
# nyeesel : nyeesel
# terpaksa : paksa
# buffering : buffering
# sh : sh
# pee : pee
# belik : belik
# ayolah : ayo
# power : power
# perasaan : asa
# walopun : walopun
# signal : signal
# kencang : kencang
# perasaaan : perasaaan
# wkwkwwk : wkwkwwk
# delay : delay
# disisni : disisni
# ampas : ampas
# berkomunikasi : komunikasi
# videokan : video
# youtube : youtube
# konsumennya : konsumen
# pengirimanharusnya : pengirimanharusnya
# pemberithuan : pemberithuan
# espedisi : espedisi
# pakete : pakete
# dibtalinjgn : dibtalinjgn
# munculnya : muncul
# chapcat : chapcat
# bolak : bolak
# ters : ters
# otpnya : otpnya
# kesel : kesel
# percayaterima : percayaterima
# bukalapakbarang : bukalapakbarang
# yahuuuutt : yahuuuutt
# kasihby : kasihby
# rahesa : rahesa
# dewaga : dewaga
# adanyadi : adanyadi
# manasemua : manasemua
# lapakga : lapakga
# tertarik : tarik
# love : love
# lapakselalu : lapakselalu
# is : is
# bestbuka : bestbuka
# lapakpastiadaa : lapakpastiadaa
# knapa : knapa
# gwa : gwa
# sayamaling : sayamaling
# wkwkwk : wkwkwk
# kocakngak : kocakngak
# nyabukti : nyabukti
# transferan : transfer
# sayaatas : sayaatas
# kwkwkwwktaiktaik : kwkwkwwktaiktaik
# taikjangan : taikjangan
# banyakdan : banyakdan
# payleternya : payleternya
# mmbuat : mmbuat
# brkali : brkali
# bltransaksi : bltransaksi
# sufah : sufah
# diteruskan : terus
# pelapakharus : pelapakharus
# jamaneh : jamaneh
# dtoko : dtoko
# unit : unit
# powerbank : powerbank
# merek : merek
# soulkarena : soulkarena
# masingrp : masingrp
# berhasiltgl : berhasiltgl
# prosestp : prosestp
# dngn : dngn
# systemkarena : systemkarena
# lepas : lepas
# nyuruh : nyuruh
# bukalapakfitur : bukalapakfitur
# pakaibukalapak : pakaibukalapak
# customermana : customermana
# tanggungjawab : tanggungjawab
# andasy : andasy
# sampainya : sampai
# ditransit : transit
# paketnya : paket
# kapokk : kapokk
# dipertahankan : tahan
# jugajd : jugajd
# carisukses : carisukses
# komlplen : komlplen
# terkonfirmasi : konfirmasi
# senyum : senyum
# dibukalapakkarena : dibukalapakkarena
# menguntungkan : untung
# malashubungkan : malashubungkan
# susahsilahkn : susahsilahkn
# diam : diam
# keluhn : keluhn
# kitamalas : kitamalas
# bklapak : bklapak
# benlanja : benlanja
# shoppe : shoppe
# siaga : siaga
# susahbertanya : susahbertanya
# opensusahgek : opensusahgek
# penagihan : tagih
# meresah : resah
# kanbelum : kanbelum
# puluhan : puluh
# nelpon : nelpon
# maling : maling
# bahasa : bahasa
# duh : duh
# santun : santun
# padaha : padaha
# entar : entar
# siang : siang
# bagussayang : bagussayang
# pos : pos
# kebijaksanaan : bijaksana
# boskuh : boskuh
# log : log
# tawarkan : tawar
# kudu : kudu
# belangganan : banggan
# big : big
# kecewatiap : kecewatiap
# utuh : utuh
# menyebalkan : sebal
# tiada : tiada
# berinovasi : inovasi
# semangatsemangat : semangatsemangat
# bintan : bintan
# csa : csa
# pelayananaslowresponudh : pelayananaslowresponudh
# masalaha : masalaha
# selesaisorry : selesaisorry
# aplikasimending : aplikasimending
# tokped : tokped
# nonaktifin : nonaktifin
# skalian : skalian
# reward : reward
# btblbnfvpw : btblbnfvpw
# ber : ber
# menyenangkan : senang
# original : original
# luncurkan : luncur
# versi : versi
# lite : lite
# mah : mah
# minimum : minimum
# makai : maka
# mudahan : mudah
# masuktp : masuktp
# terpotongmau : terpotongmau
# digubriskecewa : digubriskecewa
# trim : trim
# gan : gan
# mendarat : darat
# selamat : selamat
# manfaat : manfaat
# diberanda : beranda
# gambarnya : gambar
# kosongsearch : kosongsearch
# kosonggimana : kosonggimana
# jringan : jringan
# ngebut : ngebut
# setenga : setenga
# dibuatkan : buat
# khusus : khusus
# stuck : stuck
# tuh : tuh
# situh : situh
# melulubebalik : melulubebalik
# bacaan : baca
# begituan : begitu
# pembelanjaan : belanja
# mngajukan : mngajukan
# payltr : payltr
# nihpadahal : nihpadahal
# fullberat : fullberat
# trmksh : trmksh
# puassssssssssssbanget : puassssssssssssbanget
# setujui : tuju
# berhasilaplikasi : berhasilaplikasi
# taiiiii : taiiiii
# ketidak : tidak
# nyamanan : nyaman
# jaman : jaman
# baguskalo : baguskalo
# murahsama : murahsama
# pelayananterutama : pelayananterutama
# transitnya : transit
# kebutuhandan : kebutuhandan
# berkwalitas : berkwalitas
# grab : grab
# depoktangsel : depoktangsel
# jaraka : jaraka
# bisabisa : bisabisa
# upnya : upnya
# minggu : minggu
# pelyanannya : pelyanannya
# woiiiiiii : woiiiiiii
# manaudah : manaudah
# logindaftar : logindaftar
# ongkirtp : ongkirtp
# murahjd : murahjd
# alfamaret : alfamaret
# terkena : kena
# denda : denda
# bantuanya : bantuanya
# pin : pin
# unik : unik
# dicari : cari
# rada : rada
# eksis : eks
# janji : janji
# alhamdulilah : alhamdulilah
# kemajuan : maju
# lol : lol
# sebagus : bagus
# gantung : gantung
# kejarin : kejarin
# selesaikan : selesai
# komentar : komentar
# apasly : apasly
# minus : minus
# kkurangan : kkurangan
# daplikasi : daplikasi
# bukalapaksky : bukalapaksky
# ysuper : ysuper
# lengkapapa : lengkapapa
# bthknada : bthknada
# di dalam : di dalam
# inibuat : inibuat
# raguuntk : raguuntk
# mdownloadpergunakan : mdownloadpergunakan
# jgnikmati : jgnikmati
# kmudahan : kmudahan
# ysukses : ysukses
# truntuk : truntuk
# bukalapaktq : bukalapaktq
# membership : membership
# bagusan : bagus
# tokxxxxxx : tokxxxxxx
# shoxxx : shoxxx
# lazxxx : lazxxx
# bukakapok : bukakapok
# paya : paya
# lainmau : lainmau
# bisayang : bisayang
# mikir : mikir
# memuaskandan : memuaskandan
# datangi : datang
# sesui : sesui
# diharapkankurir : diharapkankurir
# okrespon : okrespon
# siiip : siiip
# baca : baca
# trnyta : trnyta
# bnar : bnar
# hrg : hrg
# trnytaa : trnytaa
# trma : trma
# trtahan : trtahan
# complen : complen
# bsatidak : bsatidak
# tnggung : tnggung
# blsaya : blsaya
# bossharap : bossharap
# dibaca : baca
# pelan : pelan
# kepepet : pepet
# simpati : simpati
# paylaterbayarnya : paylaterbayarnya
# gaessternyata : gaessternyata
# cas : cas
# ditetangga : tetangga
# lamagak : lamagak
# hadehhh : hadehhh
# bulannya : bulan
# koperasi : koperasi
# adabeberapa : adabeberapa
# ongkirlahmasa : ongkirlahmasa
# sukarela : sukarela
# mengantarkan : antar
# belanjatingkat : belanjatingkat
# peminatnya : minat
# loyo : loyo
# vouher : vouher
# pmbelian : pmbelian
# terachir : terachir
# snub : snub
# ring : ring
# lemotsdh : lemotsdh
# bcara : bcara
# verifikasiketika : verifikasiketika
# pesananan : pesananan
# gunanya : guna
# woyy : woyy
# tlng : tlng
# gercep : gercep
# hah : hah
# tangkurak : tangkurak
# sia : sia
# sinyal : sinyal
# butuuuuuuuut : butuuuuuuuut
# ampuuuunnnnnbaru : ampuuuunnnnnbaru
# downlod : downlod
# lemooooooooottttttudh : lemooooooooottttttudh
# kebuka : buka
# layarnya : layar
# teruuuuussssaplikasi : teruuuuussssaplikasi
# jlelekgk : jlelekgk
# pesanancuman : pesanancuman
# apknya : apknya
# loodingnya : loodingnya
# chapca : chapca
# terferivikasi : terferivikasi
# perkiraan : kira
# nyala : nyala
# lemottttmending : lemottttmending
# sat : sat
# iklanhasilnya : iklanhasilnya
# manfaatatnya : manfaatatnya
# satupuntidak : satupuntidak
# berlangganan : langgan
# serbah : serbah
# laloadnya : laloadnya
# biometrik : biometrik
# bukalapa : bukalapa
# malam : malam
# ngebug : ngebug
# yx : yx
# responnya : responnya
# samday : samday
# sekeng : keng
# jangn : jangn
# sinh : sinh
# sayangkan : sayang
# otomatisnya : otomatis
# dulusekali : dulusekali
# parahudh : parahudh
# tahunan : tahun
# lazadauinstal : lazadauinstal
# terpakai : pakai
# rubah : rubah
# emailnya : email
# centre : centre
# tott : tott
# kesal : kesal
# berjalan : jalan
# raib : raib
# kepala : kepala
# bapako : bapako
# kotak : kotak
# stop : stop
# kebijakan : bijak
# saler : saler
# bahaya : bahaya
# pushnya : pushnya
# penipusaya : penipusaya
# telpon : telpon
# bukalapakmksd : bukalapakmksd
# kerjanya : kerja
# nipu : nipu
# kerana : rana
# pinada : pada
# kumpulkan : kumpul
# oia : oia
# penjyal : penjyal
# berbuat : buat
# oknum : oknum
# ditindak : tindak
# lanjuti : lanjut
# berwajib : wajib
# menjalankan : jalan
# kelola : kelola
# terimaka : terimaka
# thanks : thanks
# aplikasii : aplikasi
# bisadi : bisadi
# negeriigoodgood : negeriigoodgood
# kb : kb
# mainkan : main
# rubahterus : rubahterus
# valid : valid
# coz : coz
# kelas : kelas
# prakerja : prakerja
# gila : gila
# lolos : lolos
# maless : maless
# bnaget : bnaget
# badal : badal
# terusapk : terusapk
# berbelit : belit
# belit : belit
# bagussesuai : bagussesuai
# dicobasemoga : dicobasemoga
# cpat : cpat
# pokokny : pokokny
# rekomend : rekomend
# pahit : pahit
# paylaterparah : paylaterparah
# sgini : sgini
# lamabukabantuan : lamabukabantuan
# ribetsusah : ribetsusah
# seringan : sering
# web : web
# penjaualan : penjaualan
# rekeninglama : rekeninglama
# rajin : rajin
# nyairkan : nyairkan
# berhari : hari
# xpenanganan : xpenanganan
# sussh : sussh
# tmbhin : tmbhin
# prdukgk : prdukgk
# tkopedia : tkopedia
# shope : shope
# gampangcontact : gampangcontact
# hbngitnya : hbngitnya
# smuagmna : smuagmna
# konsulpntesan : konsulpntesan
# klah : klah
# tokopedia : tokopedia
# mahalsukses : mahalsukses
# depelover : depelover
# diprosses : diprosses
# banking : banking
# verifikasibikin : verifikasibikin
# darting : darting
# bukalapaksangat : bukalapaksangat
# cashterimkasih : cashterimkasih
# paylatersetiap : paylatersetiap
# layanannya : layan
# rbkalau : rbkalau
# kapooooookk : kapooooookk
# muluss : muluss
# turunkan : turun
# difitur : difitur
# berdaya : daya
# banding : banding
# dipriroritaskan : dipriroritaskan
# pembeki : bek
# aplika : aplika
# bunga : bunga
# itikad : itikad
# kerendan : kerendan
# klaim : klaim
# paylatersama : paylatersama
# lzdgak : lzdgak
# bukalapakuntuk : bukalapakuntuk
# chatnya : chatnya
# diakses : akses
# pepek : pepek
# macet : macet
# jos : jos
# loadinggg : loadinggg
# alah : alah
# sampaaaahhhhhh : sampaaaahhhhhh
# beljar : beljar
# mudahada : mudahada
# kluhan : kluhan
# dilayani : layan
# membeli : beli
# tirmkasih : tirmkasih
# terbaikresponship : terbaikresponship
# aplicationtapi : aplicationtapi
# sueee : sueee
# nglunasin : nglunasin
# pelayan : layan
# buruuktiap : buruuktiap
# solusiyg : solusiyg
# dirugikan : rugi
# sellertrrimakasih : sellertrrimakasih
# mu : mu
# sebelahbrafobukalapak : sebelahbrafobukalapak
# bertahun : tahun
# caseback : caseback
# memorinya : memori
# kemauan : mau
# otomasi : otomasi
# kerlambatan : kerlambatan
# lakh : lakh
# negatif : negatif
# pembelinya : bel
# plin : plin
# plan : plan
# nik : nik
# kakak : kakak
# apikasi : apikasi
# perbankan : perban
# apaapa : apaapa
# parahhhh : parahhhh
# merespon : merespon
# mengepentingkan : penting
# nb : nb
# menawarkan : tawar
# shopy : shopy
# booking : booking
# muncultdk : muncultdk
# tercantum : cantum
# nyangkut : nyangkut
# resmi : resmi
# hantu : hantu
# lapor : lapor
# mobile : mobile
# alhamdulillahnya : alhamdulillah
# anjeng : anjeng
# modal : modal
# putar : putar
# bukapak : bukapak
# modalnya : modal
# bukalapakbangkrut : bukalapakbangkrut
# disc : disc
# sisanya : sisa
# esok : esok
# masukannya : masuk
# segi : segi
# sebentar : sebentar
# mata : mata
# berkunang : nang
# kunang : nang
# warni : warni
# lollipop : lollipop
# sarat : sarat
# voucer : voucer
# sihketika : sihketika
# adil : adil
# nombokin : nombokin
# lingkungan : lingkung
# diganti : ganti
# realtime : realtime
# infonya : info
# buruburu : buruburu
# ditinggal : tinggal
# bentar : bentar
# pergi : pergi
# hey : hey
# ss : ss
# dicarikan : cari
# kabur : kabur
# menghilangkan : hilang
# serbu : serbu
# seru : seru
# casback : casback
# badai : badai
# tap : tap
# vocher : vocher
# melimpah : limpah
# bersamaan : sama
# tiru : tiru
# biru : biru
# muluk : muluk
# hadiah : hadiah
# merata : rata
# berbelitbelit : berbelitbelit
# trik : trik
# anu : anu
# jenis : jenis
# ogah : ogah
# lucu : lucu
# pilihah : pilihah
# dibintang : bintang
# usahini : usahini
# aps : aps
# berisik : berisik
# maksa : maksa
# silakan : sila
# bye : bye
# commerce : commerce
# terparah : parah
# diklik : klik
# muat : muat
# stabil : stabil
# bego : bego
# terbayar : bayar
# taih : taih
# csnya : csnya
# ramah : ramah
# positif : positif
# koneksi : koneksi
# diputus : putus
# pertimbangannya : timbang
# buatan : buat
# anak : anak
# bangsa : bangsa
# kompeten : kompeten
# sikap : sikap
# nenguntungkan : nenguntungkan
# persetujuan : tuju
# hatihati : hatihati
# cermat : cermat
# outlet : outlet
# mundur : mundur
# pengelompokan : kelompok
# wishlist : wishlist
# favorit : favorit
# mengelompokkan : kelompok
# stabilitas : stabilitas
# bobrok : bobrok
# detailnya : detail
# dipesan : pes
# kosong : kosong
# bertul : bertul
# emah : emah
# lapangan : lapang
# file : file
# mbak : mbak
# crop : crop
# dikecilkan : kecil
# komputer : komputer
# maunya : mau
# dibatasbatasin : dibatasbatasin
# buktinya : bukti
# dibalikin : dibalikin
# dianggap : anggap
# tanggapanapa : tanggapanapa
# karyawannya : karyawannya
# woy : woy
# pakaidan : pakaidan
# belanjatp : belanjatp
# rewardatau : rewardatau
# kelebihan : lebih
# adasama : adasama
# baruakhir : baruakhir
# lainsemakin : lainsemakin
# ol : ol
# sellertoko : sellertoko
# direct : direct
# pengirimanretur : pengirimanretur
# semangaaat : semangaaat
# timmanjemen : timmanjemen
# penggantian : ganti
# sayangnya : sayang
# kasik : kasik
# arahkan : arah
# instruksi : instruksi
# team : team
# mengutamakan : utama
# custumernya : custumernya
# arror : arror
# tindak : tindak
# membayar : bayar
# amanan : aman
# bot : bot
# pokok : pokok
# ta : ta
# soale : soale
# bukamaal : bukamaal
# bintangnyakarena : bintangnyakarena
# ...
# sekalik : sekalik
# hank : hank
# terbit : terbit
# enggak pernah : enggak pernah
# ilangresetbaik : ilangresetbaik
# perncarian : perncarian
# sellerbuyer : sellerbuyer
# puasnyaman : puasnyaman
# tenang : tenang
# pastikan : pasti
# gangguannya : ganggu
# sependapat : dapat
# acara : acara
# mjd : mjd
# bunyi : bunyi
# pesannya : pesan
# oranye : oranye
# rese : rese
# seri : seri
# platformnya : platform
# operating : operating
# interfacenya : interfacenya
# reinstal : reinstal
# akitivitas : akitivitas
# desktop : desktop
# androin : androin
# ios : ios
# ngelink : ngelink
# terlewati : lewat
# dibawah : bawah
# bunyinya : bunyi
# baruudah : baruudah
# mohondiperbaiki : mohondiperbaiki
# teraman : ram
# fiktif : fiktif
# dichat : dichat
# transaksinyajd : transaksinyajd
# nyapada : nyapada
# eksekusi : eksekusi
# transaksidalam : transaksidalam
# satuharus : satuharus
# berkualitastidak : berkualitastidak
# bedanya : beda
# lancarbisa : lancarbisa
# errorserver : errorserver
# berkualitasdan : berkualitasdan
# berkualitasbuat : berkualitasbuat
# mengubah : ubah
# tabunganrekeningsedangkan : tabunganrekeningsedangkan
# wajib : wajib
# datanya : data
# minnn : minnn
# adaptasi : adaptasi
# pentingkan : penting
# waktupokoknya : waktupokoknya
# ahlak : ahlak
# mengeluarkan : keluar
# seduniacuma : seduniacuma
# ambilini : ambilini
# kendla : kendla
# bngung : bngung
# siapaini : siapaini
# adminbuat : adminbuat
# tanganin : tanganin
# ajaapliaksi : ajaapliaksi
# nangungtinggal : nangungtinggal
# tutupnya : tutup
# doankgini : doankgini
# saingin : saingin
# shopemimpi : shopemimpi
# lue : lue
# bang : bang
# higss : higss
# perjudian : judi
# berkedok : kedok
# gameyang : gameyang
# marketplce : marketplce
# tolakcuma : tolakcuma
# terimasadar : terimasadar
# nuggu : nuggu
# diperbaikisoalnya : diperbaikisoalnya
# kecamatan : camat
# dimanfaatkan : manfaat
# ordreran : ordreran
# ekspedisikarna : ekspedisikarna
# security : security
# cekup : cekup
# mbelgedez : mbelgedez
# rentang : rentang
# kadauwarsa : kadauwarsa
# keuangannya : uang
# optimal : optimal
# bagustapi : bagustapi
# keblokir : blokir
# nomormasuk : nomormasuk
# diupload : diupload
# reaponsif : reaponsif
# lapakrecommended : lapakrecommended
# dahbrg : dahbrg
# etc : etc
# instant : instant
# itulahpantes : itulahpantes
# balas : balas
# arahin : arahin
# blidappreview : blidappreview
# nonus : nonus
# neruntun : neruntun
# mendeteksi : deteksi
# kejanggalan : janggal
# bantuantapi : bantuantapi
# ngakses : ngakses
# pencerahannya : cerah
# menbuat : menbuat
# ketahui : tahu
# penyebabnya : sebab
# singkronisasi : singkronisasi
# bgsond : bgsond
# shak : shak
# tingkatkkan : tingkatkkan
# mbnya : mbnya
# belikan : belikan
# waswas : waswas
# maraknya : marak
# macamtapi : macamtapi
# responnyaterima : responnyaterima
# pelayanannyagoodluck : pelayanannyagoodluck
# angin : angin
# enggak tau : enggak tau
# terkendali : kendali
# namezulmarrusdiputra : namezulmarrusdiputra
# terduga : duga
# naikthanks : naikthanks
# recovery : recovery
# terintegritas : integritas
# apkmempermudah : apkmempermudah
# setting : setting
# filternya : filter
# ikonik : ikonik
# susunan : susun
# disederhanakan : sederhana
# transisi : transisi
# memakan : makan
# perusahaan : usaha
# membangun : bangun
# modern : modern
# cttn : cttn
# be : be
# connected : connected
# copy : copy
# perangkat : perangkat
# gamti : gamti
# eamasalah : eamasalah
# cicilansaya : cicilansaya
# merchan : merchan
# verifikasitrus : verifikasitrus
# dihistory : dihistory
# kenal : kenal
# masalahny : masalahny
# rutin : rutin
# gegara : gegara
# pemantauan : pantau
# serunya : seru
# mantapppp : mantapppp
# kendor : kendor
# terjaga : jaga
# oriented : oriented
# wasit : wasit
# intermediasi : intermediasi
# haknya : hak
# kompaint : kompaint
# complaint : complaint
# kau : kau
# menceritakan : cerita
# semesta : semesta
# mencatat : catat
# wilayah : wilayah
# papua : papua
# giamanasih : giamanasih
# mgadain : mgadain
# sesuaikalo : sesuaikalo
# ngafain : ngafain
# gala : gala
# gj : gj
# saldobuktinya : saldobuktinya
# halaaaah : halaaaah
# belielektronik : belielektronik
# nyatrimakasih : nyatrimakasih
# sajayang : sajayang
# byaya : byaya
# lanannya : lanannya
# yanyoba : yanyoba
# wkwkwkprasaan : wkwkwkprasaan
# layannalias : layannalias
# besok : besok
# membantusemoga : membantusemoga
# sealu : alu
# penguriman : penguriman
# samakin : samakin
# moga : moga
# maksimalkan : maksimal
# bekukanpadahal : bekukanpadahal
# pakaipas : pakaipas
# dehkayak : dehkayak
# nyaklo : nyaklo
# termurah : murah
# reksada : reksada
# kilat : kilat
# nyagara : nyagara
# lunassss : lunassss
# pergantian : ganti
# lather : lather
# hmnnnmnmmmmmn : hmnnnmnmmmmmn
# berbedaaneh : berbedaaneh
# pto : pto
# pp : pp
# gadget : gadget
# berselancar : selancar
# jadulku : jadulku
# kabel : kabel
# handrem : handrem
# nampaknya : nampaknya
# penanggulangan : tanggulang
# pulsatoken : pulsatoken
# darurat : darurat
# diadakan : ada
# sebelahkarena : sebelahkarena
# kbnykn : kbnykn
# duluantransfer : duluantransfer
# masalihat : masalihat
# pegawai : pegawai
# lapakpernah : lapakpernah
# aplikator : aplikator
# memelihara : pelihara
# nyaternyata : nyaternyata
# pedahal : pedahal
# melewati : lewat
# vitur : vitur
# gampangpengiriman : gampangpengiriman
# cepatkurir : cepatkurir
# minat : minat
# aplikasiditambah : aplikasiditambah
# mahaaallll : mahaaallll
# gdk : gdk
# bumi : bumi
# miskin : miskin
# limid : limid
# kepake : kepake
# mencekit : cekit
# licik : licik
# doakan : doa
# pengurus : urus
# mengenaskan : enas
# riba : riba
# onderdil : onderdil
# sepeda : sepeda
# kreatif : kreatif
# optimis : optimis
# mengganti : ganti
# recomendkomplen : recomendkomplen
# bisalive : bisalive
# lagiga : lagiga
# perbaikannya : baik
# rekomented : rekomented
# teruuuss : teruuuss
# adehh : adehh
# gblok : gblok
# istri : istri
# rbpula : rbpula
# bagussssssssss : bagussssssssss
# nol : nol
# seting : ting
# optimalkan : optimal
# re : re
# kebukapas : kebukapas
# barangselalu : barangselalu
# awaldan : awaldan
# animasi : animasi
# berlaripayah : berlaripayah
# perbaikisaya : perbaikisaya
# respect : respect
# instagram : instagram
# dibales : dibales
# cepatsy : cepatsy
# reload : reload
# berabe : berabe
# kualitasnya : kualitas
# sarana : sarana
# perantara : antara
# berintegritas : integritas
# tidk : tidk
# keinginanpesanan : keinginanpesanan
# dinamika : dinamika
# kasat : kasat
# diandalkanayo : diandalkanayo
# secepatnyananti : secepatnyananti
# ketinggalankita : ketinggalankita
# surat : surat
# sistemkurang : sistemkurang
# dijadikan : jadi
# formitu : formitu
# masalahnyajawaban : masalahnyajawaban
# lamawaalaaeh : lamawaalaaeh
# cyang : cyang
# berterimakasih : berterimakasih
# penyampaian : sampai
# materinya : materi
# terperincipelatihannya : terperincipelatihannya
# pahamisangat : pahamisangat
# sayatrimakasih : sayatrimakasih
# terbantu : bantu
# perbanyak : banyak
# pembelajaran : ajar
# prakerjasaya : prakerjasaya
# menerangkan : terang
# terjun : terjun
# freelancer : freelancer
# nampilin : nampilin
# terpopuler : populer
# komparasi : komparasi
# puaskanpengunaan : puaskanpengunaan
# carisaya : carisaya
# upgrde : upgrde
# dibukasetiap : dibukasetiap
# aplikase : aplikase
# keluarsuruh : keluarsuruh
# upgradepdahal : upgradepdahal
# traksaksi : traksaksi
# kaliklo : kaliklo
# terjangkauongkos : terjangkauongkos
# shaller : shaller
# samsung : samsung
# ringansekarang : ringansekarang
# hitam : hitam
# duluterus : duluterus
# merespongak : merespongak
# aplikasibiar : aplikasibiar
# terbawa : bawa
# berbau : bau
# judi : judi
# koin : koin
# pebaharui : baharu
# mepersulit : mepersulit
# melakukakan : melakukakan
# kontakcall : kontakcall
# berinteraksi : interaksi
# blnya : blnya
# berbenti : berbenti
# dibagian : bagi
# ngurut : ngurut
# ngacak : ngacak
# semuajadi : semuajadi
# lapaklangsung : lapaklangsung
# satusebenarnya : satusebenarnya
# menyukai : suka
# lapakmeski : lapakmeski
# lapaksemoga : lapaksemoga
# pasan : pas
# memajukan : maju
# dipoto : dipoto
# tanggapannya : tanggap
# dibobol : bobol
# phising : phising
# judulnya : judul
# shoponline : shoponline
# dikemas : kemas
# iti : iti
# diperhatikan : perhati
# calon : calon
# memudahkn : memudahkn
# lapakdan : lapakdan
# kecewasaya : kecewasaya
# ekspedisinya : ekspedisi
# terjamin : jamin
# sim : sim
# dibanned : dibanned
# hahaa : hahaa
# pelunasan : lunas
# tulisannya : tulis
# anter : anter
# kerumah : rumah
# lapaknyapdhallimit : lapaknyapdhallimit
# ributp : ributp
# dinofikasinya : dinofikasinya
# berulng : berulng
# lggimana : lggimana
# wajah : wajah
# bawahnya : bawah
# panduanhnya : panduanhnya
# kamera : kamera
# mark : mark
# tarif : tarif
# gerai : gerai
# pembeliannya : beli
# menyempatkan : sempat
# customers : customers
# siasia : siasia
# naikkan : naik
# bukadanabukadompet : bukadanabukadompet
# bukadana : bukadana
# uninsntall : uninsntall
# systemnya : systemnya
# sebelmnya : sebelmnya
# perpaling : paling
# menghalangi : halang
# ditemui : temu
# laih : laih
# dipertimbangkan : timbang
# survey : survey
# berkaitan : kait
# telur : telur
# olah : olah
# ket : ket
# rusakkomplainnya : rusakkomplainnya
# sepadan : padan
# hasilnyakarna : hasilnyakarna
# klaimkomplain : klaimkomplain
# rusaknya : rusak
# ekspedisimemang : ekspedisimemang
# kitauntuk : kitauntuk
# bis : bis
# terkrimalamat : terkrimalamat
# kadaluwarsa : kadaluwarsa
# ribetsulit : ribetsulit
# mantabbbbb : mantabbbbb
# pelayanannyacepat : pelayanannyacepat
# please : please
# waitnya : waitnya
# komplenretur : komplenretur
# barangikutin : barangikutin
# tutorial : tutorial
# dibantuan : bantu
# menjerumuskan : jerumus
# selesaimerasa : selesaimerasa
# miin : miin
# dibutuhkan : butuh
# disatuin : disatuin
# tingkatkn : tingkatkn
# plater : plater
# mantafcuman : mantafcuman
# pelayanannyadan : pelayanannyadan
# benerrrrrr : benerrrrrr
# niatny : niatny
# bpm : bpm
# sori : sori
# ges : ges
# tun : tun
# bekuin : bekuin
# pesansn : pesansn
# lapaktoko : lapaktoko
# masyarakatmohon : masyarakatmohon
# keamananperlindungan : keamananperlindungan
# mengurus : urus
# dsuruh : dsuruh
# recomend : recomend
# berfaedah : faedah
# mantulsangat : mantulsangat
# membantuterimakasih : membantuterimakasih
# lainbagus : lainbagus
# bravo : bravo
# memantau : pantau
# jalannya : jalan
# hilanguntuk : hilanguntuk
# nyabuat : nyabuat
# gulung : gulung
# tikar : tikar
# dengarkan : dengar
# saka : saka
# tercepat : cepat
# sekarangmalesbosen : sekarangmalesbosen
# keselkarena : keselkarena
# perbaharui : baharu
# leletlemotkayak : leletlemotkayak
# siput : siput
# mabuktolong : mabuktolong
# perbaikidan : perbaikidan
# persyaratannya : syarat
# terbarutapi : terbarutapi
# bisatrims : bisatrims
# panjual : panjual
# weekend : weekend
# novita : novita
# sari : sari
# peserta : serta
# mentor : mentor
# memotivasi : motivasi
# wawasan : wawas
# potensi : potensi
# miliki : milik
# adadan : adad
# pengiklanan : iklan
# assalamualaikum : assalamualaikum
# membelih : membelih
# berjudul : judul
# kuasai : kuasa
# berbicara : bicara
# teknik : teknik
# nlp : nlp
# pelatihannya : latih
# ditoko : toko
# orangehijau : orangehijau
# ngrestart : ngrestart
# kenyamana : kenyamana
# utamakan : utama
# optimalisasi : optimalisasi
# membentuk : bentuk
# luas : luas
# motor : motor
# mobil : mobil
# vita : vita
# membelinya : bel
# tema : tema
# menarikedukatif : menarikedukatif
# inspiratif : inspiratif
# pencarinya : pencar
# difilter : filter
# lakunya : laku
# asuw : asuw
# cacat : cacat
# memotret : potret
# hptidak : hptidak
# familiar : familiar
# dropshiper : dropshiper
# supplier : supplier
# menonaktifkan : nonaktif
# paylaterpadahal : paylaterpadahal
# betahun : betahun
# haous : haous
# balesan : balesan
# respone : respone
# oiya : oiya
# dipercepat : cepat
# bugbuka : bugbuka
# lamamasuk : lamamasuk
# lamake : lamake
# iconnya : iconnya
# ahjgn : ahjgn
# inigak : inigak
# tulisanmu : tulis
# down : down
# cobalagi : cobalagi
# terusmenjengkelkan : terusmenjengkelkan
# tokosebelah : tokosebelah
# saing : saing
# pelangganny : pelangganny
# fiturfitur : fiturfitur
# bervariatif : variatif
# nggantung : nggantung
# frakerja : frakerja
# penjelasan : jelas
# bahasanya : bahasa
# kemenaker : kemenaker
# terbantudengan : terbantudengan
# ilmu : ilmu
# burukkk : burukkk
# oper : oper
# konfirmasitindak : konfirmasitindak
# blsanggat : blsanggat
# thinv : thinv
# desember : desember
# help : help
# me : me
# diada : ada
# pembayaransemoga : pembayaransemoga
# hendaki : hendak
# kubeli : bel
# lamalama : lamalama
# pasar : pasar
# maruk : maruk
# perthankan : perthankan
# mutu : mutu
# belanjanyasukses : belanjanyasukses
# bukalapaksekarang : bukalapaksekarang
# nyesal : nyesal
# rademnya : rademnya
# pelayananan : pelayananan
# nyediain : nyediain
# datangnya : datang
# mengulur : ulur
# paylatternya : paylatternya
# dangampang : dangampang
# permisi : permisi
# jaga : jaga
# {'paylater': 'paylater', 'batalkan': 'batal', 'otomatis': 'otomatis', 'kadang': 'kadang', 'nya': 'nya', 'gantian': 'ganti', 'jatuh': 'jatuh', 'tempo': 'tempo', 'bayar': 'bayar', 'biaya': 'biaya', 'keterlambatan': 'lambat', 'layanan': 'layan', 'biar': 'biar', 'merasakan': 'rasa', 'rasakan': 'rasa', 'sistem': 'sistem', 'seenak': 'enak', 'chat': 'chat', 'susah': 'susah', 'error': 'error', 'menyalahkan': 'salah', 'bikin': 'bikin', 'pusing': 'pusing', 'kesini': 'kesini', 'buka': 'buka', 'lapak': 'lapak', 'bagus': 'bagus', 'pelayanannya': 'layan', 'komplan': 'komplan', 'banget': 'banget', 'beberapakali': 'beberapakali', 'transaksi': 'transaksi', 'rekening': 'rekening', 'deh': 'deh', 'kepotong': 'potong', 'lapaknya': 'lapak', 'terverifikasi': 'verifikasi', 'kalo': 'kalo', 'pengin': 'pengin', 'komplain': 'komplain', 'menu': 'menu', 'upload': 'upload', 'bukti': 'bukti', 'bayarnya': 'bayar', 'muncul': 'muncul', 'kali': 'kali', 'kehilangan': 'hilang', 'uang': 'uang', 'pembayaran': 'bayar', 'gagal': 'gagal', 'tolong': 'tolong', 'memperumit': 'rumit', 'verifikasi': 'verifikasi', 'akun': 'akun', 'saldo': 'saldo', 'bukalapak': 'bukalapak', 'dipakai': 'pakai', 'checkout': 'checkout', 'barang': 'barang', 'belanjaan': 'belanja', 'bantuan': 'bantu', 'mengasih': 'asih', 'solusi': 'solusi', 'muter': 'muter', 'disitu': 'situ', 'doang': 'doang', 'diperbaiki': 'baik', 'urusan': 'urus', 'belanja': 'belanja', 'minimal': 'minimal', 'mempersulit': 'sulit', 'proses': 'proses', 'pencairan': 'cair', 'dana': 'dana', 'pastinya': 'pasti', 'hp': 'hp', 'wifi': 'wifi', 'lemmooottttt': 'lemmooottttt', 'dasarnya': 'dasar', 'karuan': 'karuan', 'lihat': 'lihat', 'status': 'status', 'transsaksi': 'transsaksi', 'menunggu': 'tunggu', 'halaman': 'halaman', 'terisi': 'isi', 'penuh': 'penuh', 'penawaran': 'tawar', 'tanda': 'tanda', 'kesulitan': 'sulit', 'terbaca': 'baca', 'kepencet': 'pencet', 'bulalapak': 'bulalapak', 'bermain': 'main', 'paket': 'paket', 'data': 'data', 'orang': 'orang', 'konten': 'konten', 'webnya': 'webnya', 'lumayan': 'lumayan', 'hasilnya': 'hasil', 'semoga': 'moga', 'kecurigaan': 'curiga', 'maafkan': 'maaf', 'aplikasi': 'aplikasi', 'membantu': 'bantu', 'kirim': 'kirim', 'mudah': 'mudah', 'langsung': 'langsung', 'cepat': 'cepat', 'tujuan': 'tuju', 'manapun': 'mana', 'fitur': 'fitur', 'promonya': 'promonya', 'fee': 'fee', 'admin': 'admin', 'promo': 'promo', 'lainnyamataap': 'lainnyamataap', 'dah': 'dah', 'gunawan': 'gunawan', 'pengalaman': 'alam', 'apk': 'apk', 'selesai': 'selesai', 'auto': 'auto', 'hapus': 'hapus', 'mengecewakan': 'kecewa', 'pengiriman': 'kirim', 'ekspedisi': 'ekspedisi', 'lambat': 'lambat', 'transit': 'transit', 'toko': 'toko', 'pick': 'pick', 'up': 'up', 'rekomen': 'rekomen', 'mending': 'mending', 'pakai': 'pakai', 'shopee': 'shopee', 'aplikasinya': 'aplikasi', 'berat': 'berat', 'kalah': 'kalah', 'online': 'online', 'sebelah': 'belah', 'klik': 'klik', 'terbuka': 'buka', 'super': 'super', 'lemot': 'lot', 'nyaman': 'nyaman', 'kasih': 'kasih', 'updatenya': 'updatenya', 'coba': 'coba', 'update': 'update', 'punyeng': 'punyeng', 'pokoknya': 'pokok', 'pelapak': 'lapak', 'disaat': 'saat', 'pembeli': 'beli', 'terkait': 'kait', 'permintaan': 'minta', 'pengembalian': 'kembali', 'penjualanpembatalan': 'penjualanpembatalan', 'notif': 'notif', 'apl': 'apl', 'nyanotif': 'nyanotif', 'penjualan': 'jual', 'email': 'email', 'menanggapi': 'tanggap', 'jam': 'jam', 'dibatalkan': 'batal', 'kembalikan': 'kembali', 'merugikan': 'rugi', 'cek': 'cek', 'mohon': 'mohon', 'perbaiki': 'baik', 'dear': 'dear', 'check': 'check', 'posisi': 'posisi', 'pesana': 'sana', 'loading': 'loading', 'bug': 'bug', 'perhatiannya': 'perhati', 'kerusakan': 'rusa', 'system': 'system', 'perbaikan': 'baik', 'menggangu': 'menggangu', 'penggunaan': 'guna', 'dengar': 'dengar', 'terima': 'terima', 'membela': 'bela', 'kepentingan': 'penting', 'pelanggan': 'langgan', 'menjanjikan': 'janji', 'seminggu': 'minggu', 'payleter': 'payleter', 'lancar': 'lancar', 'top': 'top', 'game': 'game', 'cance ...
# ------------------------
# Pandas Apply:   0%|          | 0/1300 [00:00<?, ?it/s]

# %%
name_dataframe["Ulasan_clean"] = [' '.join(map(str, l)) for l in name_dataframe['Ulasan_Stemmed']]

# %%
name_dataframe.to_excel("tokped_text.xlsx")

# %%
ulasan = ' '.join(str(v) for v in name_dataframe['Ulasan_clean'])

# %%
tokenize_ulasan = word_tokenize(ulasan)

# %%
tokenize_ulasan
# Out:
# ['paylater',
#  'batal',
#  'otomatis',
#  'kadang',
#  'nya',
#  'ganti',
#  'jatuh',
#  'tempo',
#  'bayar',
#  'biaya',
#  'lambat',
#  'biaya',
#  'layan',
#  'biar',
#  'rasa',
#  'rasa',
#  'sistem',
#  'enak',
#  'nya',
#  'chat',
#  'susah',
#  'kadang',
#  'error',
#  'salah',
#  'layan',
#  'nya',
#  'bikin',
#  'pusing',
#  'ganti',
#  'pusing',
#  'kesini',
#  'buka',
#  'lapak',
#  'bagus',
#  'layan',
#  'komplan',
#  'susah',
#  'susah',
#  'banget',
#  'beberapakali',
#  'transaksi',
#  'rekening',
#  'deh',
#  'potong',
#  'buka',
#  'lapak',
#  'verifikasi',
#  'kalo',
#  'pengin',
#  'komplain',
#  'menu',
#  'upload',
#  'bukti',
#  'bayar',
#  'muncul',
#  'kali',
#  'kali',
#  'hilang',
#  'uang',
#  'bayar',
#  'gagal',
#  'verifikasi',
#  'tolong',
#  'rumit',
#  'verifikasi',
#  'akun',
#  'saldo',
#  'bukalapak',
#  'pakai',
#  'checkout',
#  'barang',
#  'belanja',
#  'kesini',
#  'buka',
#  'bantu',
#  'asih',
#  'solusi',
#  'muter',
#  'situ',
#  'doang',
#  'tolong',
#  'baik',
#  'urus',
#  'saldo',
#  'bukalapak',
#  'pakai',
#  'belanja',
#  'barang',
#  'minimal',
#  'sulit',
#  'proses',
#  'cair',
#  'dana',
#  'saldo',
#  'rekening',
#  'pasti',
#  'hp',
#  'wifi',
#  'lemmooottttt',
#  'dasar',
#  'bukalapak',
#  'karuan',
#  'lihat',
#  'status',
#  'transsaksi',
#  'tunggu',
#  'halaman',
#  'isi',
#  'penuh',
#  'muncul',
#  'tawar',
#  'kadang',
#  'tanda',
#  'nya',
#  'sulit',
#  'baca',
#  'pencet',
#  'bulalapak',
#  'main',
#  'paket',
#  'data',
#  'orang',
#  'konten',
#  'webnya',
#  'lumayan',
#  'hasil',
#  'moga',
#  'curiga',
#  'maaf',
#  'aplikasi',
#  'bukalapak',
#  'bantu',
#  'proses',
#  'kirim',
#  'uang',
#  'mudah',
#  'langsung',
#  'cepat',
#  'tuju',
#  'rekening',
#  'mana',
#  'fitur',
#  'promonya',
#  'kirim',
#  'uang',
#  'fee',
#  'admin',
#  'promo',
#  'lainnyamataap',
#  'banget',
#  'dah',
#  'gunawan',
#  'alam',
#  'apk',
#  'kalo',
#  'urus',
#  'selesai',
#  'langsung',
#  'auto',
#  'hapus',
#  'kecewa',
#  'kirim',
#  'ekspedisi',
#  'lambat',
#  'transit',
#  'toko',
#  'lambat',
#  'pick',
#  'up',
#  'barang',
#  'rekomen',
#  'belanja',
#  'bukalapak',
#  'mending',
#  'pakai',
#  'shopee',
#  'aplikasi',
#  'berat',
#  'kalah',
#  'toko',
#  'online',
#  'belah',
#  'klik',
#  'langsung',
#  'buka',
#  'promo',
#  'lapak',
#  'bukalapak',
#  'super',
#  'lot',
#  'nyaman',
#  'aplikasi',
#  'kasih',
#  'updatenya',
#  'coba',
#  'update',
#  'punyeng',
#  'deh',
#  'pokok',
#  'lapak',
#  'saat',
#  'komplain',
#  'beli',
#  'kait',
#  'minta',
#  'kembali',
#  'dana',
#  'penjualanpembatalan',
#  'transaksi',
#  'notif',
#  'apl',
#  'bulalapak',
#  'nyanotif',
#  'transaksi',
#  'jual',
#  'notif',
#  'email',
#  'tanggap',
#  'email',
#  'transaksi',
#  'jam',
#  'otomatis',
#  'batal',
#  'dana',
#  'jual',
#  'otomatis',
#  'kembali',
#  'beli',
#  'barang',
#  'kirim',
#  'rugi',
#  'lapak',
#  'saat',
#  'lapak',
#  'cek',
#  'email',
#  'mohon',
#  'baik',
#  'fitur',
#  'komplain',
#  'dear',
#  'bukalapak',
#  'buka',
#  'transaksi',
#  'check',
#  'posisi',
#  'sana',
#  'loading',
#  'nya',
#  'bug',
#  'mohon',
#  'perhati',
#  'rusa',
#  'system',
#  'mohon',
#  'baik',
#  'menggangu',
#  'transaksi',
#  'guna',
#  'nyaman',
#  'moga',
#  'dengar',
#  'bukalapak',
#  'terima',
#  'kasih',
#  'kecewa',
#  'bela',
#  'penting',
#  'langgan',
#  'barang',
#  'kembali',
#  'status',
#  'transaksi',
#  'terima',
#  'selesai',
#  'komplain',
#  'langsung',
#  'uang',
#  'lapak',
#  'janji',
#  'kirim',
#  'deh',
#  'minggu',
#  'barang',
#  'kirim',
#  'payleter',
#  'bayar',
#  'lancar',
#  'payleter',
#  'nya',
#  'pakai',
#  'top',
#  'up',
#  'game',
#  'cancel',
#  'otomatis',
#  'bukalapak',
#  'sungguh',
#  'kecewa',
#  'loading',
#  'pantesan',
#  'aplikasi',
#  'jadul',
#  'tinggal',
#  'costumer',
#  'orang',
#  'pakai',
#  'aplikasi',
#  'fiturnya',
#  'parah',
#  'banget',
#  'banyaktidak',
#  'fungsi',
#  'fitur',
#  'bukabantuannya',
#  'error',
#  'komplain',
#  'susah',
#  'ampun',
#  'selesai',
#  'rugi',
#  'jual',
#  'beli',
#  'solusi',
#  'sesuai',
#  'kirim',
#  'ninja',
#  'expres',
#  'puluh',
#  'puluh',
#  'susah',
#  'lacak',
#  'kasih',
#  'bintang',
#  'sukur',
#  'kasih',
#  'bintang',
#  'sih',
#  'barang',
#  'muncul',
#  'menu',
#  'cari',
#  'pilih',
#  'zonk',
#  'barang',
#  'hapus',
#  'alhasil',
#  'menu',
#  'cari',
#  'pilih',
#  'barang',
#  'zonk',
#  'lapak',
#  'langgar',
#  'alhasil',
#  'menu',
#  'cari',
#  'pilih',
#  'saran',
#  'barang',
#  'hapus',
#  'lapak',
#  'langgar',
#  'muncul',
#  'menu',
#  'cari',
#  'menu',
#  'cari',
#  'kapai',
#  'tampil',
#  'barang',
#  'baik',
#  'aplikasi',
#  'bukalapak',
#  'mohon',
#  'bantuannyasaya',
#  'alami',
#  'sulit',
#  'logindikarenakan',
#  'akun',
#  'terima',
#  'kode',
#  'otp',
#  'nomor',
#  'masuk',
#  'nomor',
#  'aktifmau',
#  'bantu',
#  'live',
#  'chat',
#  'akun',
#  'sayadan',
#  'terima',
#  'bantu',
#  'bukalapakmohon',
#  'bantu',
#  'sulit',
#  'isi',
#  'atur',
#  'bukalapak',
#  'konsumen',
#  'betah',
#  'dagang',
#  'beli',
#  'lapak',
#  'produk',
#  'digital',
#  'tanggal',
#  'mei',
#  'potongam',
#  'super',
#  'saller',
#  'harga',
#  'barang',
#  'susah',
#  'jual',
#  'promote',
#  'push',
#  'efek',
#  'harga',
#  'mahal',
#  'tolong',
#  'solusi',
#  'minggu',
#  'ubah',
#  'mending',
#  'tutup',
#  'lapak',
#  'pindah',
#  'platform',
#  'buang',
#  'uang',
#  'promote',
#  'push',
#  'sesal',
#  'banget',
#  'buka',
#  'tabung',
#  'bukalapak',
#  'kalo',
#  'buka',
#  'tabung',
#  'traktir',
#  'guna',
#  'saldo',
#  'kalo',
#  'bikin',
#  'kartu',
#  'debit',
#  'tambah',
#  'knyatanya',
#  'bulan',
#  'auto',
#  'hapus',
#  'akun',
#  'hoax',
#  'biaya',
#  'star',
#  'seller',
#  'mahal',
#  'berat',
#  'jual',
#  'beli',
#  'item',
#  'higs',
#  'domino',
#  'bl',
#  'terap',
#  'produk',
#  'digital',
#  'kecewa',
#  'sih',
#  'mudah',
#  'belanja',
#  'saran',
#  'rating',
#  'pisah',
#  'lapak',
#  'jasa',
#  'kirim',
#  'puas',
#  'layan',
#  'lapak',
#  'jasa',
#  'kirim',
#  'kecewa',
#  'langgan',
#  'rating',
#  'jelek',
#  'transaksi',
#  'kecewa',
#  'pesan',
#  'barang',
#  'komplain',
#  'bukalapak',
#  'error',
#  'komplain',
#  'kurir',
#  'jelas',
#  'komplain',
#  'asuransi',
#  'barang',
#  'hilang',
#  'mantulll',
#  'barang',
#  'deh',
#  'kondisi',
#  'ready',
#  'bagus',
#  'very',
#  'gus',
#  'cek',
#  'riwayat',
#  'pesan',
#  'tanggal',
#  'april',
#  'pagi',
#  'jam',
#  'posisi',
#  'transit',
#  'cek',
#  'jam',
#  'posisi',
#  'barang',
#  'kirim',
#  'alamat',
#  'terima',
#  'jam',
#  'an',
#  'terima',
#  'terima',
#  'kasih',
#  'bukalapak',
#  'bukalapak',
#  'tolong',
#  'baik',
#  'muter',
#  'ajalihat',
#  'history',
#  'transaksi',
#  'susah',
#  'mainnumpuk',
#  'diserver',
#  'history',
#  'akunbuatlah',
#  'simpan',
#  'biar',
#  'muter',
#  'update',
#  'baru',
#  'nge',
#  'bug',
#  'menu',
#  'transaksi',
#  'loadingnya',
#  'suka',
#  'nge',
#  'hang',
#  'lebih',
#  'mantap',
#  'fitur',
#  'live',
#  'chat',
#  'rumitpadahal',
#  'adu',
#  'transaksi',
#  'batal',
#  'refaund',
#  'transaksi',
#  'status',
#  'prosespadahal',
#  'guna',
#  'setia',
#  'bltp',
#  'perlahan',
#  'alih',
#  'toko',
#  'online',
#  'lainselain',
#  'nya',
#  'potong',
#  'ongkir',
#  'belanja',
#  'minimal',
#  'rendah',
#  'kolom',
#  'cari',
#  'mudah',
#  'tawar',
#  'barang',
#  'beragamdi',
#  'bl',
#  'potong',
#  'ongkir',
#  'paylater',
#  'kolom',
#  'cari',
#  'barang',
#  'tawarkn',
#  'kadang',
#  'sesuai',
#  'ketikcari',
#  'biaya',
#  'potong',
#  'lapak',
#  'produk',
#  'digital',
#  'mahal',
#  'proses',
#  'transaksi',
#  'error',
#  'berat',
#  'apk',
#  'potong',
#  'mahal',
#  'forma',
#  'huhuhuuuuu',
#  'susah',
#  'banget',
#  'komplen',
#  'siniudah',
#  'capek',
#  'ngetikpas',
#  'kirim',
#  'tulis',
#  'halaman',
#  'tuju',
#  'komplen',
#  'mana',
#  'jdinya',
#  'barang',
#  'beli',
#  'terimatpi',
#  'reportnya',
#  'kurir',
#  'barang',
#  'terima',
#  'bingungmo',
#  'komplain',
#  'mana',
#  'bukalapak',
#  'pasrah',
#  'mudah',
#  'an',
#  'tanggapin',
#  'mantab',
#  'menu',
#  'menu',
#  'simple',
#  'praktis',
#  'nyaman',
#  'mudah',
#  'paham',
#  'kayak',
#  'belah',
#  'lemottnya',
#  'ampun',
#  'menu',
#  'menu',
#  'bikin',
#  'bingung',
#  'praktis',
#  'aplikasi',
#  'bagus',
#  'minus',
#  'ongkir',
#  'mahal',
#  'voucher',
#  'pakai',
#  'penuh',
#  'syarat',
#  'pilih',
#  'jasa',
#  'ekspedisi',
#  'bukalapak',
#  'parah',
#  'pesan',
#  'tanggal',
#  'april',
#  'kirim',
#  'lapak',
#  'april',
#  'april',
#  'barang',
#  'simpan',
#  'gudang',
#  'ekspedisi',
#  'bukaexpress',
#  'buka',
#  'bantu',
#  'menu',
#  'livechat',
#  'fungsi',
#  'beda',
#  'aplikasi',
#  'merchant',
#  'bukalapak',
#  'bikin',
#  'kecewa',
#  'parah',
#  'kayak',
#  'pengin',
#  'masuk',
#  'akun',
#  'email',
#  'kode',
#  'verifikasi',
#  'nya',
#  'kirim',
#  'nomor',
#  'nomor',
#  'aktif',
#  'pengin',
#  'ganti',
#  'nomor',
#  'syarat',
#  'nya',
#  'foto',
#  'ktprekening',
#  'daftar',
#  'pakai',
#  'ktp',
#  'rekening',
#  'seribet',
#  'kah',
#  'daftar',
#  'bikin',
#  'akun',
#  'pengin',
#  'cantumin',
#  'email',
#  'terang',
#  'nya',
#  'email',
#  'ubah',
#  'masuk',
#  'email',
#  'nya',
#  'terima',
#  'barang',
#  'tipenyasaya',
#  'komplain',
#  'admin',
#  'selesai',
#  'bayar',
#  'rugi',
#  'terima',
#  'paket',
#  'lapak',
#  'hilang',
#  'uang',
#  'transaksi',
#  'barang',
#  'terima',
#  'iklan',
#  'loadingnya',
#  'buka',
#  'aplikasi',
#  'buka',
#  'lapak',
#  'ngechek',
#  'kirim',
#  'tunggu',
#  'loading',
#  'iklan',
#  'mohon',
#  'biar',
#  'langgan',
#  'nyaman',
#  'buka',
#  'aplikasi',
#  'pakai',
#  'kuota',
#  'internetdi',
#  'iklan',
#  'nglungker',
#  'tambah',
#  'jenuhtlg',
#  'perhati',
#  'jelek',
#  'bukalapak',
#  'aplikasi',
#  'lot',
#  'adu',
#  'bukabantuan',
#  'langsung',
#  'tele',
#  'kesana',
#  'kemari',
#  'coba',
#  'kasih',
#  'menu',
#  'langsung',
#  'tinggal',
#  'klik',
#  'cari',
#  'barang',
#  'sulit',
#  'cuman',
#  'dikit',
#  'barang',
#  'kalah',
#  'aplikasi',
#  'bukalapakygdulu',
#  'aneh',
#  'ya',
#  'didownload',
#  'ulang',
#  'masuk',
#  'apk',
#  'touch',
#  'touch',
#  'pakai',
#  'ya',
#  'apk',
#  'nya',
#  'hapus',
#  'az',
#  'apk',
#  'nya',
#  'repot',
#  'pesan',
#  'batal',
#  'otomatis',
#  'tanggal',
#  'proses',
#  'status',
#  'jual',
#  'kadaluarsamau',
#  'komplen',
#  'hilang',
#  'uang',
#  'ambil',
#  'buka',
#  'lapak',
#  'kapok',
#  'belanja',
#  'buka',
#  'lapak',
#  'pesan',
#  'kendala',
#  'kirim',
#  'barang',
#  'beli',
#  'bayar',
#  'sistem',
#  'canggih',
#  'komplain',
#  'tunggu',
#  'aplikasi',
#  'cuman',
#  'uang',
#  'sadah',
#  'kembaliini',
#  'tunggu',
#  'kepastianpayah',
#  'sesal',
#  'gue',
#  'beli',
#  'barang',
#  'dibukalapak',
#  'uang',
#  'gue',
#  'malas',
#  'banget',
#  'pesan',
#  'kirim',
#  'bayar',
#  'cancel',
#  'sayang',
#  'banget',
#  'mahal',
#  'aju',
#  'komplen',
#  'balas',
#  'bayar',
#  'kirim',
#  'tanggal',
#  'april',
#  'tanggal',
#  'kurir',
#  'ambil',
#  'ambil',
#  'mls',
#  'banget',
#  'uang',
#  'pakai',
#  'woi',
#  'rugi',
#  'apk',
#  'sulit',
#  'komplain',
#  'kendala',
#  'live',
#  'chat',
#  'cs',
#  'nya',
#  'mitra',
#  'dalem',
#  'nya',
#  'tipu',
#  'tipu',
#  'uang',
#  'masuk',
#  'refund',
#  'detik',
#  'saran',
#  'expedisi',
#  'kurir',
#  'reg',
#  'next',
#  'day',
#  'bukaexpress',
#  'pakai',
#  'sicepat',
#  'error',
#  'pick',
#  'up',
#  'kurir',
#  'lelet',
#  'kurir',
#  'kurir',
#  'kirim',
#  'criss',
#  'cross',
#  'sesuai',
#  'sop',
#  'status',
#  'resi',
#  'update',
#  'komplen',
#  'cs',
#  'ybs',
#  'solusi',
#  'percaya',
#  'kirim',
#  'konsumen',
#  'moga',
#  'baik',
#  'depan',
#  'nya',
#  'buset',
#  'fitur',
#  'fitur',
#  'bukalapak',
#  'pajang',
#  'fitur',
#  'komplain',
#  'halaman',
#  'temu',
#  'pesan',
#  'terima',
#  'otomatis',
#  'bukalapak',
#  'hebat',
#  'uang',
#  'lenya',
#  'ribu',
#  'kecewa',
#  'aplikasi',
#  'mudah',
#  'berbelanjatapi',
#  'susah',
#  'dam',
#  'halapalagi',
#  'tanggap',
#  'lapak',
#  'nya',
#  'bantu',
#  'beli',
#  'baik',
#  'sistemnyakecewa',
#  'layan',
#  'bukaexpress',
#  'paket',
#  'telat',
#  'pilih',
#  'kurir',
#  'tambah',
#  'report',
#  'kurir',
#  'bermasalahpaket',
#  'jadwal',
#  'kompensasi',
#  'jamin',
#  'uang',
#  'kembalihanya',
#  'slogan',
#  'belakabagaimana',
#  'min',
#  'chat',
#  'buka',
#  'bantu',
#  'respon',
#  'payah',
#  'ah',
#  'kecewa',
#  'saldo',
#  'habis',
#  'untung',
#  ...]

# %%
fqdist = FreqDist(tokenize_ulasan)

# %%
fqdist
# Out:
# FreqDist({'bukalapak': 503, 'aplikasi': 469, 'nya': 418, 'barang': 397, 'buka': 255, 'pakai': 250, 'lapak': 229, 'kirim': 228, 'bayar': 221, 'belanja': 218, ...})

# %%
# mencetak 15 kata paling banyak digunakan
fqdist.most_common(15)
# Out:
# [('bukalapak', 503),
#  ('aplikasi', 469),
#  ('nya', 418),
#  ('barang', 397),
#  ('buka', 255),
#  ('pakai', 250),
#  ('lapak', 229),
#  ('kirim', 228),
#  ('bayar', 221),
#  ('belanja', 218),
#  ('beli', 195),
#  ('transaksi', 183),
#  ('bantu', 163),
#  ('jual', 156),
#  ('bagus', 151)]

# %%
import matplotlib.pyplot as plt

# plotting
fqdist.plot(10,cumulative=False)
plt.show()

# %%
label = []
for index, row in name_dataframe.iterrows():
    if row["Rating"] == 5 or row["Rating"] == 4:
        label.append(1)
    else:
        label.append(0)

name_dataframe["label"] = label

name_dataframe
# Out:
#                          Nama pengguna  Rating                Date  \
# 0                         Nizar Rayyan       1 2023-04-16 23:03:31
# 1                           Fandy Komo       1 2023-05-05 02:37:25
# 2                      hidayat mudaris       1 2023-05-06 17:32:58
# 3     dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 4                         Aris Gunawan       5 2023-05-04 23:26:15
# ...                                ...     ...                 ...
# 1295                    Sitorus Edward       5 2023-04-24 03:40:01
# 1296                      DK Mattawang       5 2023-04-16 04:31:17
# 1297                      M2D Projects       2 2023-04-16 00:14:31
# 1298                          KA risma       1 2023-04-25 08:25:01
# 1299                Bic Stevie Sualang       5 2023-04-22 09:57:05
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     tambah kesini buka lapak tambah kurang bagus p...
# 2     tolong jangan memperumit untuk verifikasi akun...
# 3     pastinya bukan hp dan wifi saya yang lemmooott...
# 4     aplikasi bukalapak sangat membantu untuk prose...
# ...                                                 ...
# 1295                           baik dan cepat prosesnya
# 1296    sangat berguna bermanfaat dan sangat diperlukan
# 1297  banyak barang di pencarian begitu di klik bara...
# 1298  permisi apakah sistem aplikasi bukalapak sedan...
# 1299  tingkatkan terus jaga kenyamanan nasabah bertr...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [tolong, jangan, memperumit, untuk, verifikasi...
# 3     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4     [aplikasi, bukalapak, sangat, membantu, untuk,...
# ...                                                 ...
# 1295                      [baik, dan, cepat, prosesnya]
# 1296  [sangat, berguna, bermanfaat, dan, sangat, dip...
# 1297  [banyak, barang, di, pencarian, begitu, di, kl...
# 1298  [permisi, apakah, sistem, aplikasi, bukalapak,...
# 1299  [tingkatkan, terus, jaga, kenyamanan, nasabah,...
#
#                                       Ulasan_normalized  \
# 0     [paylater, enggak, benar, selalu, di, batalkan...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [tolong, jangan, memperumit, untuk, verifikasi...
# 3     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4     [aplikasi, bukalapak, sangat, membantu, untuk,...
# ...                                                 ...
# 1295                      [baik, dan, cepat, prosesnya]
# 1296  [sangat, berguna, bermanfaat, dan, sangat, dip...
# 1297  [banyak, barang, di, pencarian, begitu, di, kl...
# 1298  [permisi, apakah, sistem, aplikasi, bukalapak,...
# 1299  [tingkatkan, terus, jaga, kenyamanan, nasabah,...
#
#                                     Ulasan_stop_removed  \
# 0     [paylater, batalkan, otomatis, kadang, nya, ga...
# 1     [kesini, buka, lapak, bagus, pelayanannya, kom...
# 2     [tolong, memperumit, verifikasi, akun, saldo, ...
# 3     [pastinya, hp, wifi, lemmooottttt, dasarnya, b...
# 4     [aplikasi, bukalapak, membantu, proses, kirim,...
# ...                                                 ...
# 1295                                 [cepat, prosesnya]
# 1296                              [berguna, bermanfaat]
# 1297         [barang, pencarian, klik, barang, dihapus]
# 1298  [permisi, sistem, aplikasi, bukalapak, eror, m...
# 1299  [tingkatkan, jaga, kenyamanan, nasabah, bertra...
#
#                                          Ulasan_Stemmed  \
# 0     [paylater, batal, otomatis, kadang, nya, ganti...
# 1     [kesini, buka, lapak, bagus, layan, komplan, s...
# 2     [tolong, rumit, verifikasi, akun, saldo, bukal...
# 3     [pasti, hp, wifi, lemmooottttt, dasar, bukalap...
# 4     [aplikasi, bukalapak, bantu, proses, kirim, ua...
# ...                                                 ...
# 1295                                    [cepat, proses]
# 1296                                    [guna, manfaat]
# 1297                [barang, cari, klik, barang, hapus]
# 1298  [permisi, sistem, aplikasi, bukalapak, eror, h...
# 1299        [tingkat, jaga, nyaman, nasabah, transaksi]
#
#                                            Ulasan_clean  label
# 0     paylater batal otomatis kadang nya ganti jatuh...      0
# 1     kesini buka lapak bagus layan komplan susah su...      0
# 2     tolong rumit verifikasi akun saldo bukalapak p...      0
# 3     pasti hp wifi lemmooottttt dasar bukalapak kar...      0
# 4     aplikasi bukalapak bantu proses kirim uang mud...      1
# ...                                                 ...    ...
# 1295                                       cepat proses      1
# 1296                                       guna manfaat      1
# 1297                      barang cari klik barang hapus      0
# 1298  permisi sistem aplikasi bukalapak eror hubung ...      0
# 1299              tingkat jaga nyaman nasabah transaksi      1
#
# [1300 rows x 10 columns]

# %%
#create a user define function to find out polarity & subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

#creating another user define function to label the sentiment 

def getSentiment(value):
    if value<0:
        return 'Negative'
    elif value==0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
name_dataframe.head()
# Out:
#                       Nama pengguna  Rating                Date  \
# 0                      Nizar Rayyan       1 2023-04-16 23:03:31
# 1                        Fandy Komo       1 2023-05-05 02:37:25
# 2                   hidayat mudaris       1 2023-05-06 17:32:58
# 3  dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 4                      Aris Gunawan       5 2023-05-04 23:26:15
#
#                                               Ulasan  \
# 0  paylater ngk bener selalu di batalkan otomatis...
# 1  tambah kesini buka lapak tambah kurang bagus p...
# 2  tolong jangan memperumit untuk verifikasi akun...
# 3  pastinya bukan hp dan wifi saya yang lemmooott...
# 4  aplikasi bukalapak sangat membantu untuk prose...
#
#                                      Ulasan_tokenize  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2  [tolong, jangan, memperumit, untuk, verifikasi...
# 3  [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4  [aplikasi, bukalapak, sangat, membantu, untuk,...
#
#                                    Ulasan_normalized  \
# 0  [paylater, enggak, benar, selalu, di, batalkan...
# 1  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2  [tolong, jangan, memperumit, untuk, verifikasi...
# 3  [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4  [aplikasi, bukalapak, sangat, membantu, untuk,...
#
#                                  Ulasan_stop_removed  \
# 0  [paylater, batalkan, otomatis, kadang, nya, ga...
# 1  [kesini, buka, lapak, bagus, pelayanannya, kom...
# 2  [tolong, memperumit, verifikasi, akun, saldo, ...
# 3  [pastinya, hp, wifi, lemmooottttt, dasarnya, b...
# 4  [aplikasi, bukalapak, membantu, proses, kirim,...
#
#                                       Ulasan_Stemmed  \
# 0  [paylater, batal, otomatis, kadang, nya, ganti...
# 1  [kesini, buka, lapak, bagus, layan, komplan, s...
# 2  [tolong, rumit, verifikasi, akun, saldo, bukal...
# 3  [pasti, hp, wifi, lemmooottttt, dasar, bukalap...
# 4  [aplikasi, bukalapak, bantu, proses, kirim, ua...
#
#                                         Ulasan_clean  label
# 0  paylater batal otomatis kadang nya ganti jatuh...      0
# 1  kesini buka lapak bagus layan komplan susah su...      0
# 2  tolong rumit verifikasi akun saldo bukalapak p...      0
# 3  pasti hp wifi lemmooottttt dasar bukalapak kar...      0
# 4  aplikasi bukalapak bantu proses kirim uang mud...      1

# %%
from textblob import TextBlob

# %%
def run_vader(name_dataframe):
    # Generate VADER sentiment analyzer object
    sid = SentimentIntensityAnalyzer()

# %%
name_dataframe['Polarity']=name_dataframe['Ulasan_clean'].apply(getPolarity)
name_dataframe['Subjectivity']=name_dataframe['Ulasan_clean'].apply(getSubjectivity)
name_dataframe['Sentiment']=name_dataframe['Polarity'].apply(getSentiment)
name_dataframe.head()
# Out:
#                       Nama pengguna  Rating                Date  \
# 0                      Nizar Rayyan       1 2023-04-16 23:03:31
# 1                        Fandy Komo       1 2023-05-05 02:37:25
# 2                   hidayat mudaris       1 2023-05-06 17:32:58
# 3  dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 4                      Aris Gunawan       5 2023-05-04 23:26:15
#
#                                               Ulasan  \
# 0  paylater ngk bener selalu di batalkan otomatis...
# 1  tambah kesini buka lapak tambah kurang bagus p...
# 2  tolong jangan memperumit untuk verifikasi akun...
# 3  pastinya bukan hp dan wifi saya yang lemmooott...
# 4  aplikasi bukalapak sangat membantu untuk prose...
#
#                                      Ulasan_tokenize  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2  [tolong, jangan, memperumit, untuk, verifikasi...
# 3  [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4  [aplikasi, bukalapak, sangat, membantu, untuk,...
#
#                                    Ulasan_normalized  \
# 0  [paylater, enggak, benar, selalu, di, batalkan...
# 1  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2  [tolong, jangan, memperumit, untuk, verifikasi...
# 3  [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4  [aplikasi, bukalapak, sangat, membantu, untuk,...
#
#                                  Ulasan_stop_removed  \
# 0  [paylater, batalkan, otomatis, kadang, nya, ga...
# 1  [kesini, buka, lapak, bagus, pelayanannya, kom...
# 2  [tolong, memperumit, verifikasi, akun, saldo, ...
# 3  [pastinya, hp, wifi, lemmooottttt, dasarnya, b...
# 4  [aplikasi, bukalapak, membantu, proses, kirim,...
#
#                                       Ulasan_Stemmed  \
# 0  [paylater, batal, otomatis, kadang, nya, ganti...
# 1  [kesini, buka, lapak, bagus, layan, komplan, s...
# 2  [tolong, rumit, verifikasi, akun, saldo, bukal...
# 3  [pasti, hp, wifi, lemmooottttt, dasar, bukalap...
# 4  [aplikasi, bukalapak, bantu, proses, kirim, ua...
#
#                                         Ulasan_clean  label  Polarity  \
# 0  paylater batal otomatis kadang nya ganti jatuh...      0  0.000000
# 1  kesini buka lapak bagus layan komplan susah su...      0  0.000000
# 2  tolong rumit verifikasi akun saldo bukalapak p...      0 -0.100000
# 3  pasti hp wifi lemmooottttt dasar bukalapak kar...      0  0.166667
# 4  aplikasi bukalapak bantu proses kirim uang mud...      1  0.000000
#
#    Subjectivity Sentiment
# 0      0.000000   Neutral
# 1      0.000000   Neutral
# 2      0.600000  Negative
# 3      0.333333  Positive
# 4      0.000000   Neutral

# %%
name_dataframe['month'] = name_dataframe['Date'].dt.month

# %%
name_dataframe
# Out:
#                          Nama pengguna  Rating                Date  \
# 0                         Nizar Rayyan       1 2023-04-16 23:03:31
# 1                           Fandy Komo       1 2023-05-05 02:37:25
# 2                      hidayat mudaris       1 2023-05-06 17:32:58
# 3     dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 4                         Aris Gunawan       5 2023-05-04 23:26:15
# ...                                ...     ...                 ...
# 1295                    Sitorus Edward       5 2023-04-24 03:40:01
# 1296                      DK Mattawang       5 2023-04-16 04:31:17
# 1297                      M2D Projects       2 2023-04-16 00:14:31
# 1298                          KA risma       1 2023-04-25 08:25:01
# 1299                Bic Stevie Sualang       5 2023-04-22 09:57:05
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     tambah kesini buka lapak tambah kurang bagus p...
# 2     tolong jangan memperumit untuk verifikasi akun...
# 3     pastinya bukan hp dan wifi saya yang lemmooott...
# 4     aplikasi bukalapak sangat membantu untuk prose...
# ...                                                 ...
# 1295                           baik dan cepat prosesnya
# 1296    sangat berguna bermanfaat dan sangat diperlukan
# 1297  banyak barang di pencarian begitu di klik bara...
# 1298  permisi apakah sistem aplikasi bukalapak sedan...
# 1299  tingkatkan terus jaga kenyamanan nasabah bertr...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [tolong, jangan, memperumit, untuk, verifikasi...
# 3     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4     [aplikasi, bukalapak, sangat, membantu, untuk,...
# ...                                                 ...
# 1295                      [baik, dan, cepat, prosesnya]
# 1296  [sangat, berguna, bermanfaat, dan, sangat, dip...
# 1297  [banyak, barang, di, pencarian, begitu, di, kl...
# 1298  [permisi, apakah, sistem, aplikasi, bukalapak,...
# 1299  [tingkatkan, terus, jaga, kenyamanan, nasabah,...
#
#                                       Ulasan_normalized  \
# 0     [paylater, enggak, benar, selalu, di, batalkan...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [tolong, jangan, memperumit, untuk, verifikasi...
# 3     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4     [aplikasi, bukalapak, sangat, membantu, untuk,...
# ...                                                 ...
# 1295                      [baik, dan, cepat, prosesnya]
# 1296  [sangat, berguna, bermanfaat, dan, sangat, dip...
# 1297  [banyak, barang, di, pencarian, begitu, di, kl...
# 1298  [permisi, apakah, sistem, aplikasi, bukalapak,...
# 1299  [tingkatkan, terus, jaga, kenyamanan, nasabah,...
#
#                                     Ulasan_stop_removed  \
# 0     [paylater, batalkan, otomatis, kadang, nya, ga...
# 1     [kesini, buka, lapak, bagus, pelayanannya, kom...
# 2     [tolong, memperumit, verifikasi, akun, saldo, ...
# 3     [pastinya, hp, wifi, lemmooottttt, dasarnya, b...
# 4     [aplikasi, bukalapak, membantu, proses, kirim,...
# ...                                                 ...
# 1295                                 [cepat, prosesnya]
# 1296                              [berguna, bermanfaat]
# 1297         [barang, pencarian, klik, barang, dihapus]
# 1298  [permisi, sistem, aplikasi, bukalapak, eror, m...
# 1299  [tingkatkan, jaga, kenyamanan, nasabah, bertra...
#
#                                          Ulasan_Stemmed  \
# 0     [paylater, batal, otomatis, kadang, nya, ganti...
# 1     [kesini, buka, lapak, bagus, layan, komplan, s...
# 2     [tolong, rumit, verifikasi, akun, saldo, bukal...
# 3     [pasti, hp, wifi, lemmooottttt, dasar, bukalap...
# 4     [aplikasi, bukalapak, bantu, proses, kirim, ua...
# ...                                                 ...
# 1295                                    [cepat, proses]
# 1296                                    [guna, manfaat]
# 1297                [barang, cari, klik, barang, hapus]
# 1298  [permisi, sistem, aplikasi, bukalapak, eror, h...
# 1299        [tingkat, jaga, nyaman, nasabah, transaksi]
#
#                                            Ulasan_clean  label  Polarity  \
# 0     paylater batal otomatis kadang nya ganti jatuh...      0  0.000000
# 1     kesini buka lapak bagus layan komplan susah su...      0  0.000000
# 2     tolong rumit verifikasi akun saldo bukalapak p...      0 -0.100000
# 3     pasti hp wifi lemmooottttt dasar bukalapak kar...      0  0.166667
# 4     aplikasi bukalapak bantu proses kirim uang mud...      1  0.000000
# ...                                                 ...    ...       ...
# 1295                                       cepat proses      1  0.000000
# 1296                                       guna manfaat      1  0.000000
# 1297                      barang cari klik barang hapus      0  0.000000
# 1298  permisi sistem aplikasi bukalapak eror hubung ...      0  0.000000
# 1299              tingkat jaga nyaman nasabah transaksi      1  0.000000
#
#       Subjectivity Sentiment  month
# 0         0.000000   Neutral      4
# 1         0.000000   Neutral      5
# 2         0.600000  Negative      5
# 3         0.333333  Positive      3
# 4         0.000000   Neutral      5
# ...            ...       ...    ...
# 1295      0.000000   Neutral      4
# 1296      0.000000   Neutral      4
# 1297      0.000000   Neutral      4
# 1298      0.000000   Neutral      4
# 1299      0.000000   Neutral      4
#
# [1300 rows x 14 columns]

# %%
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
name_dataframe.head()
# Out:
#                       Nama pengguna  Rating                Date  \
# 0                      Nizar Rayyan       1 2023-04-16 23:03:31
# 1                        Fandy Komo       1 2023-05-05 02:37:25
# 2                   hidayat mudaris       1 2023-05-06 17:32:58
# 3  dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 4                      Aris Gunawan       5 2023-05-04 23:26:15
#
#                                               Ulasan  \
# 0  paylater ngk bener selalu di batalkan otomatis...
# 1  tambah kesini buka lapak tambah kurang bagus p...
# 2  tolong jangan memperumit untuk verifikasi akun...
# 3  pastinya bukan hp dan wifi saya yang lemmooott...
# 4  aplikasi bukalapak sangat membantu untuk prose...
#
#                                      Ulasan_tokenize  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2  [tolong, jangan, memperumit, untuk, verifikasi...
# 3  [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4  [aplikasi, bukalapak, sangat, membantu, untuk,...
#
#                                    Ulasan_normalized  \
# 0  [paylater, enggak, benar, selalu, di, batalkan...
# 1  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2  [tolong, jangan, memperumit, untuk, verifikasi...
# 3  [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 4  [aplikasi, bukalapak, sangat, membantu, untuk,...
#
#                                  Ulasan_stop_removed  \
# 0  [paylater, batalkan, otomatis, kadang, nya, ga...
# 1  [kesini, buka, lapak, bagus, pelayanannya, kom...
# 2  [tolong, memperumit, verifikasi, akun, saldo, ...
# 3  [pastinya, hp, wifi, lemmooottttt, dasarnya, b...
# 4  [aplikasi, bukalapak, membantu, proses, kirim,...
#
#                                       Ulasan_Stemmed  \
# 0  [paylater, batal, otomatis, kadang, nya, ganti...
# 1  [kesini, buka, lapak, bagus, layan, komplan, s...
# 2  [tolong, rumit, verifikasi, akun, saldo, bukal...
# 3  [pasti, hp, wifi, lemmooottttt, dasar, bukalap...
# 4  [aplikasi, bukalapak, bantu, proses, kirim, ua...
#
#                                         Ulasan_clean  label  Polarity  \
# 0  paylater batal otomatis kadang nya ganti jatuh...      0  0.000000
# 1  kesini buka lapak bagus layan komplan susah su...      0  0.000000
# 2  tolong rumit verifikasi akun saldo bukalapak p...      0 -0.100000
# 3  pasti hp wifi lemmooottttt dasar bukalapak kar...      0  0.166667
# 4  aplikasi bukalapak bantu proses kirim uang mud...      1  0.000000
#
#    Subjectivity Sentiment  month
# 0      0.000000   Neutral      4
# 1      0.000000   Neutral      5
# 2      0.600000  Negative      5
# 3      0.333333  Positive      3
# 4      0.000000   Neutral      5

# %%
# Create scatter plot
sns.set_style('darkgrid')
plt.figure(figsize = (15,7))

markers = {'Positive':'o', 'Neutral':'s','Negative':'X'}

sns.scatterplot(data=name_dataframe, x='Polarity', y='Subjectivity', hue = 'Sentiment', style = 'Sentiment', markers = markers, palette = 'gist_earth').set(xlim=(-1,1))
plt.title('Scatter Plot')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')

plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group by month and sentiment
sentiment_df = name_dataframe.groupby(['month', 'Sentiment']).size().reset_index(name='Count')


# Plot the sentiment counts by month
plt.figure(figsize=(12, 6))
sns.lineplot(x='month', y='Count', hue='Sentiment', data=sentiment_df)
plt.title('Sentiment by Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %%
sentimen_data=pd.value_counts(name_dataframe["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["green", "red", "black"])
plt.title('Bar chart')
plt.show()

# %%
name_dataframe["Sentiment"].value_counts()
# Out:
# Neutral     1059
# Positive     195
# Negative      46
# Name: Sentiment, dtype: int64

# %%
name_dataframe["Sentiment"].value_counts()
# Out:
# Neutral     1059
# Positive     195
# Negative      46
# Name: Sentiment, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
Ulasan = name_dataframe['Ulasan_clean']

# %%
Ulasan.isnull().sum()
# Out:
# 0

# %%
#untuk menghitung jumlah kata yang telah di steming
cv = CountVectorizer()
term_fit = cv.fit(Ulasan)

print (len(term_fit.vocabulary_))
# Out:
# 3640

# %%
term_fit.vocabulary_ #mengurutkan berdasarkan urutab abjad kata
# Out:
# {'paylater': 2440,
#  'batal': 300,
#  'otomatis': 2371,
#  'kadang': 1438,
#  'nya': 2277,
#  'ganti': 1124,
#  'jatuh': 1378,
#  'tempo': 3275,
#  'bayar': 309,
#  'biaya': 433,
#  'lambat': 1756,
#  'layan': 1799,
#  'biar': 431,
#  'rasa': 2708,
#  'sistem': 3082,
#  'enak': 1012,
#  'chat': 695,
#  'susah': 3184,
#  'error': 1028,
#  'salah': 2848,
#  'bikin': 441,
#  'pusing': 2686,
#  'kesini': 1561,
#  'buka': 539,
#  'lapak': 1771,
#  'bagus': 219,
#  'komplan': 1622,
#  'banget': 255,
#  'beberapakali': 319,
#  'transaksi': 3413,
#  'rekening': 2743,
#  'deh': 815,
#  'potong': 2618,
#  'verifikasi': 3539,
#  'kalo': 1454,
#  'pengin': 2513,
#  'komplain': 1620,
#  'menu': 2061,
#  'upload': 3514,
#  'bukti': 598,
#  'muncul': 2147,
#  'kali': 1451,
#  'hilang': 1252,
#  'uang': 3473,
#  'gagal': 1108,
#  'tolong': 3394,
#  'rumit': 2827,
#  'akun': 75,
#  'saldo': 2851,
#  'bukalapak': 552,
#  'pakai': 2396,
#  'checkout': 704,
#  'barang': 279,
#  'belanja': 338,
#  'bantu': 267,
#  'asih': 187,
#  'solusi': 3113,
#  'muter': 2159,
#  'situ': 3088,
#  'doang': 941,
#  'baik': 238,
#  'urus': 3518,
#  'minimal': 2092,
#  'sulit': 3169,
#  'proses': 2660,
#  'cair': 632,
#  'dana': 785,
#  'pasti': 2433,
#  'hp': 1266,
#  'wifi': 3600,
#  'lemmooottttt': 1818,
#  'dasar': 799,
#  'karuan': 1467,
#  'lihat': 1853,
#  'status': 3145,
#  'transsaksi': 3424,
#  'tunggu': 3460,
#  'halaman': 1202,
#  'isi': 1343,
#  'penuh': 2531,
#  'tawar': 3249,
#  'tanda': 3221,
#  'baca': 209,
#  'pencet': 2508,
#  'bulalapak': 602,
#  'main': 1927,
#  'paket': 2403,
#  'data': 801,
#  'orang': 2358,
#  'konten': 1645,
#  'webnya': 3593,
#  'lumayan': 1906,
#  'hasil': 1228,
#  'moga': 2122,
#  'curiga': 761,
#  'maaf': 1916,
#  'aplikasi': 164,
#  'kirim': 1582,
#  'mudah': 2133,
#  'langsung': 1769,
#  'cepat': 675,
#  'tuju': 3452,
#  'mana': 1946,
#  'fitur': 1079,
#  'promonya': 2652,
#  'fee': 1066,
#  'admin': 30,
#  'promo': 2651,
#  'lainnyamataap': 1730,
#  'dah': 779,
#  'gunawan': 1184,
#  'alam': 79,
#  'apk': 155,
#  'selesai': 2948,
#  'auto': 202,
#  'hapus': 1219,
#  'kecewa': 1493,
#  'ekspedisi': 996,
#  'transit': 3421,
#  'toko': 3384,
#  'pick': 2575,
#  'up': 3503,
#  'rekomen': 2747,
#  'mending': 2041,
#  'shopee': 3030,
#  'berat': 371,
#  'kalah': 1448,
#  'online': 2344,
#  'belah': 335,
#  'klik': 1592,
#  'super': 3174,
#  'lot': 1896,
#  'nyaman': 2289,
#  'kasih': 1471,
#  'updatenya': 3507,
#  'coba': 713,
#  'update': 3504,
#  'punyeng': 2682,
#  'pokok': 2605,
#  'saat': 2837,
#  'beli': 347,
#  'kait': 1443,
#  'minta': 2098,
#  'kembali': 1522,
#  'penjualanpembatalan': 2527,
#  'notif': 2268,
#  'apl': 158,
#  'nyanotif': 2293,
#  'jual': 1413,
#  'email': 1005,
#  'tanggap': 3228,
#  'jam': 1363,
#  'rugi': 2825,
#  'cek': 661,
#  'mohon': 2123,
#  'dear': 811,
#  'check': 703,
#  'posisi': 2612,
#  'sana': 2873,
#  'loading': 1873,
#  'bug': 536,
#  'perhati': 2548,
#  'rusa': 2832,
#  'system': 3194,
#  'menggangu': 2050,
#  'guna': 1179,
#  'dengar': 825,
#  'terima': 3298,
#  'bela': 334,
#  'penting': 2530,
#  'langgan': 1765,
#  'janji': 1370,
#  'minggu': 2088,
#  'payleter': 2451,
#  'lancar': 1761,
#  'top': 3398,
#  'game': 1115,
#  'cancel': 638,
#  'sungguh': 3172,
#  'pantesan': 2416,
#  'jadul': 1356,
#  'tinggal': 3363,
#  'costumer': 738,
#  'fiturnya': 1081,
#  'parah': 2418,
#  'banyaktidak': 276,
#  'fungsi': 1100,
#  'bukabantuannya': 541,
#  'ampun': 113,
#  'sesuai': 3011,
#  'ninja': 2243,
#  'expres': 1048,
#  'puluh': 2679,
#  'lacak': 1703,
#  'bintang': 447,
#  'sukur': 3168,
#  'sih': 3055,
#  'cari': 647,
#  'pilih': 2579,
#  'zonk': 3638,
#  'alhasil': 91,
#  'langgar': 1766,
#  'saran': 2880,
#  'kapai': 1459,
#  'tampil': 3219,
#  'bantuannyasaya': 268,
#  'alami': 81,
#  'logindikarenakan': 1880,
#  'kode': 1603,
#  'otp': 2373,
#  'nomor': 2255,
#  'masuk': 1996,
#  'aktifmau': 71,
#  'live': 1867,
#  'sayadan': 2894,
#  'bukalapakmohon': 569,
#  'atur': 199,
#  'konsumen': 1642,
#  'betah': 420,
#  'dagang': 778,
#  'produk': 2642,
#  'digital': 873,
#  'tanggal': 3227,
#  'mei': 2016,
#  'potongam': 2619,
#  'saller': 2855,
#  'harga': 1223,
#  'promote': 2657,
#  'push': 2684,
#  'efek': 988,
#  'mahal': 1924,
#  'ubah': 3474,
#  'tutup': 3469,
#  'pindah': 2584,
#  'platform': 2592,
#  'buang': 533,
#  'sesal': 3008,
#  'tabung': 3200,
#  'traktir': 3410,
#  'kartu': 1466,
#  'debit': 813,
#  'tambah': 3217,
#  'knyatanya': 1599,
#  'bulan': 603,
#  'hoax': 1263,
#  'star': 3143,
#  'seller': 2957,
#  'item': 1346,
#  'higs': 1249,
#  'domino': 947,
#  'bl': 475,
#  'terap': 3288,
#  'rating': 2710,
#  'pisah': 2588,
#  'jasa': 1377,
#  'puas': 2670,
#  'jelek': 1391,
#  'pesan': 2563,
#  'kurir': 1690,
#  'jelas': 1389,
#  'asuransi': 193,
#  'mantulll': 1969,
#  'kondisi': 1632,
#  'ready': 2718,
#  'very': 3545,
#  'gus': 1185,
#  'riwayat': 2810,
#  'april': 179,
#  'pagi': 2389,
#  'alamat': 80,
#  'an': 116,
#  'ajalihat': 51,
#  'history': 1257,
#  'mainnumpuk': 1928,
#  'diserver': 920,
#  'akunbuatlah': 76,
#  'simpan': 3065,
#  'baru': 292,
#  'nge': 2200,
#  'loadingnya': 1875,
#  'suka': 3164,
#  'hang': 1213,
#  'lebih': 1813,
#  'mantap': 1962,
#  'rumitpadahal': 2829,
#  'adu': 33,
#  'refaund': 2730,
#  'prosespadahal': 2661,
#  'setia': 3017,
#  'bltp': 494,
#  'perlahan': 2551,
#  'alih': 93,
#  'lainselain': 1731,
#  'ongkir': 2336,
#  'rendah': 2758,
#  'kolom': 1608,
#  'beragamdi': 367,
#  'tawarkn': 3250,
#  'ketikcari': 1569,
#  'forma': 1089,
#  'huhuhuuuuu': 1274,
#  'komplen': 1624,
#  'siniudah': 3075,
#  'capek': 644,
#  'ngetikpas': 2216,
#  'tulis': 3455,
#  'jdinya': 1386,
#  'terimatpi': 3304,
#  'reportnya': 2761,
#  'bingungmo': 445,
#  'pasrah': 2430,
#  'tanggapin': 3232,
#  'mantab': 1958,
#  'simple': 3070,
#  'praktis': 2627,
#  'paham': 2390,
#  'kayak': 1481,
#  'lemottnya': 1830,
#  'bingung': 444,
#  'minus': 2101,
#  'voucher': 3559,
#  'syarat': 3192,
#  'gudang': 1175,
#  'bukaexpress': 547,
#  'livechat': 1869,
#  'beda': 320,
#  'merchant': 2069,
#  'aktif': 65,
#  'foto': 1093,
#  'ktprekening': 1674,
#  'daftar': 776,
#  'ktp': 1672,
#  'seribet': 2995,
#  'kah': 1442,
#  'cantumin': 641,
#  'terang': 3287,
#  'tipenyasaya': 3369,
#  'iklan': 1285,
#  'ngechek': 2205,
#  'kuota': 1684,
#  'internetdi': 1335,
#  'nglungker': 2225,
#  'jenuhtlg': 1397,
#  'bukabantuan': 540,
#  'tele': 3262,
#  'kesana': 1556,
#  'kemari': 1519,
#  'cuman': 756,
#  'dikit': 889,
#  'bukalapakygdulu': 586,
#  'aneh': 126,
#  'ya': 3619,
#  'didownload': 869,
#  'ulang': 3482,
#  'touch': 3403,
#  'az': 208,
#  'repot': 2762,
#  'kadaluarsamau': 1436,
#  'ambil': 106,
#  'kapok': 1461,
#  'kendala': 1532,
#  'canggih': 639,
#  'sadah': 2840,
#  'kembaliini': 1525,
#  'kepastianpayah': 1543,
#  'gue': 1176,
#  'dibukalapak': 860,
#  'malas': 1938,
#  'sayang': 2896,
#  'aju': 54,
#  'balas': 247,
#  'mls': 2109,
#  'woi': 3611,
#  'cs': 748,
#  'mitra': 2105,
#  'dalem': 783,
#  'tipu': 3370,
#  'refund': 2736,
#  'detik': 839,
#  'expedisi': 1047,
#  'reg': 2737,
#  'next': 2189,
#  'day': 805,
#  'sicepat': 3050,
#  'lelet': 1814,
#  'criss': 744,
#  'cross': 746,
#  'sop': 3116,
#  'resi': 2770,
#  'ybs': 3627,
#  'percaya': 2544,
#  'depan': 827,
#  'buset': 613,
#  'pajang': 2394,
#  'temu': 3276,
#  'hebat': 1235,
#  'lenya': 1836,
#  'ribu': 2796,
#  'berbelanjatapi': 374,
#  'dam': 784,
#  'halapalagi': 1205,
#  'sistemnyakecewa': 3085,
#  'telat': 3258,
#  'report': 2760,
#  'bermasalahpaket': 406,
#  'jadwal': 1358,
#  'kompensasi': 1616,
#  'jamin': 1366,
#  'kembalihanya': 1524,
#  'slogan': 3096,
#  'belakabagaimana': 336,
#  'min': 2086,
#  'respon': 2775,
#  'payah': 2438,
#  'ah': 38,
#  'habis': 1188,
#  'untung': 3502,
#  'ngisi': 2221,
#  'cash': 653,
#  'back': 210,
#  'lom': 1893,
#  'tau': 3248,
#  'telepon': 3263,
#  'muas': 2131,
#  'jawabannyacoba': 1380,
#  'tanggepin': 3233,
#  'tlong': 3379,
#  'jawab': 1379,
#  'tentu': 3283,
#  'jgbuat': 1400,
#  'bantumakin': 272,
#  'hubungin': 1273,
#  'chatlemot': 697,
#  'sory': 3122,
#  'turun': 3464,
#  'lag': 1706,
#  'payleater': 2450,
#  'bukalapaksaya': 575,
#  'tagih': 3202,
#  'lagibukti': 1712,
#  'struknya': 3156,
#  'kasir': 1476,
#  'indomart': 1304,
#  'yeah': 3628,
#  'tagihantapi': 3203,
#  'limit': 1855,
#  'bukaemas': 545,
#  'bilang': 442,
#  'sabar': 2838,
#  'kece': 1492,
#  'gua': 1173,
#  'ramadhan': 2701,
#  'posting': 2614,
#  'flashdeal': 1085,
#  'shake': 3023,
#  'thon': 3341,
#  'dapat': 789,
#  'perak': 2534,
#  'thx': 3343,
#  'sudahlama': 3161,
#  'retur': 2784,
#  'kaya': 1480,
#  'uninstall': 3494,
#  'asa': 185,
#  'aman': 100,
#  'ribet': 2791,
#  'hubung': 1271,
#  'ecommerce': 985,
#  'tua': 3449,
#  'inovasi': 1318,
#  'rp': 2820,
#  'byr': 627,
#  'vamandiri': 3532,
#  'duit': 971,
#  'pembyran': 2500,
#  'tarik': 3245,
#  'transferpenarikkan': 3418,
#  'upgrade': 3510,
#  'premium': 2630,
#  'satusatunya': 2891,
#  'akses': 62,
#  'berfungsihatihati': 384,
#  'xufsinv': 3618,
#  'batas': 302,
#  'maksimal': 1935,
#  'dbatalkan': 808,
#  'tahan': 3204,
#  'jelasjelas': 1390,
#  'tera': 3285,
#  'ikan': 1284,
#  'hias': 1246,
#  'pakan': 2400,
#  'ganggu': 1123,
#  'bukatabungan': 597,
#  'mada': 1921,
#  'teman': 3272,
#  'undang': 3487,
#  'permasalahn': 2554,
#  'bual': 532,
#  'adakan': 21,
#  'request': 2763,
#  'pickup': 2576,
#  'awam': 205,
#  'edit': 986,
#  'varian': 3534,
#  'milik': 2084,
#  'tipe': 3368,
#  'nginput': 2218,
#  'apa': 147,
#  'disamainnnnn': 915,
#  'feedback': 1067,
#  'dm': 937,
#  'ig': 1282,
#  'gubris': 1174,
#  'sptnya': 3134,
#  'halooooo': 1207,
#  'biji': 439,
#  'order': 2363,
#  'marketplace': 1979,
#  'sepi': 2987,
#  'pelit': 2483,
#  'free': 1095,
#  'pajak': 2393,
#  'gede': 1138,
#  'royal': 2819,
#  'uninstal': 3492,
#  'emosi': 1011,
#  'mati': 2003,
#  'obrol': 2310,
#  'aktifin': 68,
#  'no': 2248,
#  'hangus': 1214,
#  'kyc': 1699,
#  'ane': 125,
#  'join': 1407,
#  'buruk': 609,
#  'metode': 2080,
#  'gonta': 1162,
#  'cukup': 755,
#  'hadehh': 1191,
#  'paylaternya': 2442,
#  'beku': 328,
#  'basah': 297,
#  'basih': 299,
#  'custumer': 770,
#  'customer': 765,
#  'servicenya': 3005,
#  'kepercayan': 1545,
#  'ecom': 983,
#  'utama': 3525,
#  'aktifasi': 66,
#  'gampang': 1117,
#  'komplin': 1626,
#  'sumpah': 3171,
#  'enek': 1018,
#  'masak': 1984,
#  'nomer': 2253,
#  'sefty': 2927,
#  'lo': 1871,
#  'nyataanya': 2298,
#  'aktivasi': 72,
#  'pinjam': 2585,
#  'bank': 264,
#  'sumpaah': 3170,
#  'oohh': 2348,
#  'devlover': 841,
#  'lebay': 1812,
#  'koreksi': 1652,
#  'wilyah': 3603,
#  'timur': 3359,
#  'indonesia': 1305,
#  'contoh': 733,
#  'ongkos': 2342,
#  'capai': 643,
#  'fer': 1068,
#  'jadi': 1354,
#  'install': 1324,
#  'berulangulang': 413,
#  'wadew': 3568,
#  'blank': 479,
#  'tandatanda': 3222,
#  'berjamjam': 394,
#  'sore': 3119,
#  'normal': 2264,
#  'tibatiba': 3346,
#  'tangguh': 3235,
#  'konfirmasi': 1635,
#  'login': 1878,
#  'sunguh': 3173,
#  'hindar': 1255,
#  'kredit': 1663,
#  'kena': 1528,
#  'warning': 3582,
#  'nih': 2237,
#  'emak': 1006,
#  'lato': 1794,
#  'swafoto': 3190,
#  'tangan': 3225,
#  'kanan': 1457,
#  'kiri': 1581,
#  'pegang': 2463,
#  'buku': 599,
#  'bantuin': 271,
#  'sistemnyasya': 3086,
#  'sellerkenapa': 2959,
#  'nama': 2169,
#  'pencariandi': 2506,
#  'tracking': 3405,
#  'validbanyak': 3531,
#  'pembelitapi': 2495,
#  'trackingnya': 3406,
#  'marketpkace': 1978,
#  'emas': 1009,
#  'problem': 2641,
#  'bad': 213,
#  'gateway': 1132,
#  'enggak': 1019,
#  'bisa': 452,
#  'sengaja': 2979,
#  'investasi': 1338,
#  'app': 175,
#  'banyak': 273,
#  'rusak': 2833,
#  'simpel': 3069,
#  'kemarin': 1520,
#  'diskusi': 924,
#  'kurang': 1687,
#  'transfer': 3417,
#  'ajabanyak': 47,
#  'sisrem': 3081,
#  'gunabuka': 1180,
#  'ajaisi': 49,
#  'harap': 1222,
#  'ajadan': 48,
#  'bagusmasuk': 226,
#  'ribetnya': 2793,
#  'nilai': 2242,
#  'mundur': 2150,
#  'ratingnya': 2711,
#  'cumq': 757,
#  'gaya': 1134,
#  'unjung': 3497,
#  'angsur': 132,
#  'sajadan': 2844,
#  'aktifharus': 67,
#  'belanjabrg': 339,
#  'tengkyuu': 3282,
#  'ktpreffvral': 1673,
#  'btbldkzqvt': 529,
#  'nyaaplikasii': 2279,
#  'lamasangat': 1753,
#  'kala': 1447,
#  'belanjatinggal': 342,
#  'bayarbarang': 310,
#  'membaiktengkyuuu': 2023,
#  'aco': 11,
#  'nonaktif': 2259,
#  'set': 3014,
#  'list': 1864,
#  'beranda': 368,
#  'profile': 2648,
#  'erti': 1031,
#  'halah': 1201,
#  'pikir': 2578,
#  'servis': 3006,
#  'presiden': 2631,
#  'standby': 3142,
#  'lokasi': 1888,
#  'kak': 1444,
#  'ngalami': 2196,
#  'ngalamin': 2197,
#  'bhulshittt': 428,
#  'program': 2649,
#  'express': 1049,
#  'garansi': 1131,
#  'mode': 2118,
#  'claimnya': 711,
#  'default': 814,
#  'curang': 758,
#  'berkahh': 396,
#  'siasat': 3047,
#  'mnjamingaransi': 2112,
#  'tanggung': 3237,
#  'profesional': 2645,
#  'maju': 1930,
#  'cod': 716,
#  'beban': 315,
#  'and': 120,
#  'sampah': 2865,
#  'smartphone': 3099,
#  'piara': 2574,
#  'manfaat': 1951,
#  'kocak': 1600,
#  'mulu': 2142,
#  'kelar': 1508,
#  'eneg': 1017,
#  'dengernya': 826,
#  'eh': 992,
#  'blokir': 488,
#  'badut': 216,
#  'password': 2431,
#  'sekalibegitu': 2934,
#  'verif': 3538,
#  'suruh': 3181,
#  'passwordklik': 2432,
#  'lupa': 1911,
#  'bisagimana': 456,
#  'ulas': 3483,
#  'promoted': 2658,
#  'selau': 2944,
#  'sesi': 3010,
#  'info': 1307,
#  'fleksibel': 1086,
#  'monoton': 2125,
#  'size': 3091,
#  'real': 2720,
#  'nurut': 2276,
#  'sedia': 2924,
#  'kategori': 1477,
#  'biyaya': 472,
#  'maksud': 1936,
#  'sesak': 3007,
#  'sgitu': 3020,
#  'ilangin': 1290,
#  'tuhklo': 3451,
#  'kepakasa': 1540,
#  'blanja': 477,
#  'saking': 2847,
#  'chip': 705,
#  'snapdragon': 3107,
#  'gen': 1141,
#  'ram': 2700,
#  'gb': 1135,
#  'clear': 712,
#  'chace': 690,
#  'logout': 1884,
#  'masalah': 1987,
#  'server': 3002,
#  'bisaselalu': 464,
#  'lengkap': 1833,
#  'chapta': 694,
#  'nyata': 2297,
#  'lulus': 1905,
#  'drastis': 962,
#  'butuh': 617,
#  'perlu': 2552,
#  'desak': 832,
#  'tetangga': 3332,
#  'promot': 2656,
#  'ngitung': 2222,
#  'utang': 3526,
#  'lunas': 1908,
#  'jumlah': 1424,
#  'mes': 2076,
#  'hutang': 1276,
#  'pulsa': 2677,
#  'ijo': 1283,
#  'oran': 2357,
#  'pemberitahuan': 2496,
#  'paylter': 2454,
#  'jebak': 1387,
#  'betmen': 423,
#  'lagiterima': 1720,
#  'dompet': 948,
#  'barangterima': 289,
#  'bukalapaktidak': 582,
#  'mengecewakanjaya': 2047,
#  'bukalapakaplikasi': 554,
#  'indonesiasekali': 1306,
#  'inikasih': 1315,
#  'bgtkasihan': 426,
#  'dongharusnya': 950,
#  'max': 2007,
#  'haribukanya': 1225,
#  'pembelimenurut': 2493,
#  'bukalapakklo': 562,
#  'pesananmereka': 2566,
#  'sendiridan': 2977,
#  'kirimkanentah': 1583,
#  'lupaatau': 1912,
#  'readymohon': 2719,
#  'lagibuat': 1710,
#  'aga': 35,
#  'dowload': 953,
#  'inikarna': 1314,
#  'lamatp': 1754,
#  'barangpengiriman': 285,
#  'standar': 3141,
#  'membaiksesuai': 2022,
#  'estimasiuntuk': 1035,
#  'tingkat': 3364,
#  'lgtrima': 1850,
#  'kasihapk': 1473,
#  'lapor': 1787,
#  'kabar': 1427,
#  'alas': 84,
#  'via': 3546,
#  'artikel': 184,
#  'review': 2785,
#  'dok': 945,
#  'prosez': 2665,
#  'putus': 2690,
#  'lampir': 1759,
#  'rek': 2740,
#  'mutasi': 2158,
#  'nampaklah': 2171,
#  'nota': 2265,
#  'bene': 356,
#  'informasi': 1308,
#  'krusial': 1669,
#  'dmpak': 938,
#  'securitynya': 2922,
#  'brengsek': 519,
#  'dajjal': 781,
#  'google': 1165,
#  'permanen': 2553,
#  'kagak': 1440,
#  'pembayaranya': 2490,
#  'lainyasangat': 1738,
#  'mudahsangat': 2139,
#  'kalang': 1449,
#  'tengah': 3280,
#  'kebawahapalagi': 1486,
#  'gratis': 1170,
#  'vocer': 3555,
#  'lai': 1725,
#  'dapatkanpayah': 790,
#  'bukalapaknya': 571,
#  'harus': 1227,
#  'php': 2573,
#  'sempat': 2970,
#  'bonus': 506,
#  'event': 1042,
#  'mini': 2090,
#  'periode': 2550,
#  'maret': 1975,
#  'kecewadimana': 1494,
#  'codtapi': 720,
#  'bukalapakudah': 584,
#  'limite': 1856,
#  'naikpantaslah': 2165,
#  'telkom': 3265,
#  'wib': 3599,
#  'cocok': 715,
#  'bisnis': 471,
#  'ringan': 2804,
#  'all': 95,
#  'one': 2334,
#  'feature': 1063,
#  'rekomendasi': 2749,
#  'januari': 1372,
#  'jugasudah': 1422,
#  'bukalapaksungguh': 580,
#  'mesan': 2077,
#  'rokok': 2816,
#  'sd': 2905,
#  'estimasi': 1034,
#  'pay': 2436,
#  'later': 1791,
#  'bajak': 240,
#  'pusat': 2683,
#  'pending': 2509,
#  'bukalapakeh': 559,
#  'suami': 3158,
#  'jutamasa': 1426,
#  'bajakhrsny': 242,
#  'pesanannyakan': 2567,
#  'keren': 1548,
#  'saing': 2842,
#  'ketat': 1563,
#  'kompetitor': 1619,
#  'yuk': 3634,
#  'buru': 607,
#  'download': 955,
#  'konsisten': 1638,
#  'timbul': 3357,
#  'tenggelam': 3281,
#  'loh': 1885,
#  'hehee': 1237,
#  'sukses': 3167,
#  'andal': 121,
#  'way': 3591,
#  'opsi': 2353,
#  'cetak': 688,
#  'helooo': 1239,
#  'syaa': 3191,
#  'buyer': 620,
#  'driver': 963,
#  'user': 3521,
#  'friendly': 1097,
#  'penilain': 2522,
#  'kasihan': 1472,
#  'langanan': 1764,
#  'lagan': 1707,
#  'kualitas': 1676,
#  'vouchernya': 3560,
#  'kargo': 1465,
#  'laman': 1752,
#  'tks': 3376,
#  'lemotbukan': 1825,
#  'internet': 1334,
#  'lemotaplikasinya': 1823,
#  'perbaikimasi': 2540,
#  'orangemasa': 2361,
#  'utuma': 3528,
#  'ada': 13,
#  'kerjasama': 1552,
#  'referral': 2731,
#  'alhamdulillah': 90,
#  'rezeki': 2789,
#  'tsbt': 3444,
#  'ajak': 50,
#  'panjang': 2413,
#  'bukutabungan': 600,
#  'hpgmail': 1267,
#  'code': 717,
#  'btblvj': 530,
#  'turunin': 3465,
#  'eror': 1026,
#  'sayapadahal': 2897,
#  'label': 1702,
#  'cekout': 664,
#  'catat': 658,
#  'inipadahal': 1317,
#  'jembutsaya': 1392,
#  'dlliklan': 934,
#  'bas': 296,
#  'boroboro': 509,
#  'munculbangsaaatt': 2148,
#  'sisi': 3080,
#  'ui': 3477,
#  'popup': 2610,
#  'call': 635,
#  'center': 672,
#  'dadi': 774,
#  'action': 12,
#  'pribadi': 2633,
#  'limpah': 1857,
#  'mantaab': 1957,
#  'markotopmaknyosss': 1981,
#  'baikbaiiiil': 239,
#  'service': 3004,
#  'kendaladan': 1533,
#  'solusitidak': 3114,
#  'sekian': 2939,
#  'complain': 726,
#  'dikirimlha': 886,
#  'menit': 2058,
#  'software': 3110,
#  'instal': 1323,
#  'akunpu': 77,
#  'tunjuk': 3461,
#  'elektronik': 1001,
#  'gabung': 1105,
#  'darp': 796,
#  'nyaedaaaan': 2283,
#  'peras': 2536,
#  'its': 1349,
#  'ok': 2318,
#  'sense': 2981,
#  'lari': 1789,
#  'dodol': 944,
#  'nasabah': 2176,
#  'token': 3383,
#  'listrik': 1865,
#  'urgent': 3517,
#  'laaahh': 1701,
#  'kabupaten': 1432,
#  'bandung': 252,
#  'padalarang': 2386,
#  'februari': 1065,
#  'nobody': 2249,
#  'at': 195,
#  'home': 1264,
#  'rumah': 2826,
#  'ente': 1023,
#  'jne': 1404,
#  'dll': 933,
#  'beginiga': 322,
#  'kabbandung': 1430,
#  'jakarta': 1361,
#  'amanah': 102,
#  'bareng': 291,
#  'mantablah': 1960,
#  'lah': 1721,
#  'captcha': 645,
#  'resin': 2771,
#  'danatransfer': 787,
#  'ongkirnya': 2339,
#  'yrus': 3631,
#  'kembang': 1526,
#  'prosespelapak': 2662,
#  'meresponsolusi': 2074,
#  'menungguini': 2062,
#  'pemrosesan': 2502,
#  'hak': 1199,
#  'developer': 840,
#  'lazada': 1806,
#  'tiktok': 3354,
#  'wajar': 3571,
#  ...}

# %%
#kolom pertama ini berarti jumlah dokumen
#kolom kedua berarti letak katanya
#kolom ketiga hasil dari tf

term_frequency_all = term_fit.transform(Ulasan)
print (term_frequency_all)
# Out:
#   (0, 300)	1
#   (0, 309)	1
#   (0, 431)	1
#   (0, 433)	2
#   (0, 441)	1
#   (0, 695)	1
#   (0, 1012)	1
#   (0, 1028)	1
#   (0, 1124)	2
#   (0, 1378)	1
#   (0, 1438)	2
#   (0, 1756)	1
#   (0, 1799)	2
#   (0, 2277)	3
#   (0, 2371)	1
#   (0, 2440)	1
#   (0, 2686)	2
#   (0, 2708)	2
#   (0, 2848)	1
#   (0, 3082)	1
#   (0, 3184)	1
#   (0, 3275)	1
#   (1, 219)	1
#   (1, 255)	1
#   (1, 309)	2
#   :	:
#   (1294, 1962)	1
#   (1294, 3619)	1
#   (1295, 675)	1
#   (1295, 2660)	1
#   (1296, 1179)	1
#   (1296, 1951)	1
#   (1297, 279)	2
#   (1297, 647)	1
#   (1297, 1219)	1
#   (1297, 1592)	1
#   (1298, 75)	1
#   (1298, 164)	1
#   (1298, 552)	1
#   (1298, 785)	1
#   (1298, 1026)	1
#   (1298, 1108)	1
#   (1298, 1271)	1
#   (1298, 1520)	1
#   (1298, 2556)	1
#   (1298, 3082)	1
#   (1299, 1359)	1
#   (1299, 2176)	1
#   (1299, 2289)	1
#   (1299, 3364)	1
#   (1299, 3413)	1

# %%
ulasan_tf = Ulasan[1] #memanggil kata pada index ke 1
print (ulasan_tf)
# Out:
# kesini buka lapak bagus layan komplan susah susah banget beberapakali transaksi rekening deh potong buka lapak verifikasi kalo pengin komplain menu upload bukti bayar muncul kali kali hilang uang bayar gagal verifikasi

# %%
term_frequency = term_fit.transform([ulasan_tf]) #hanya menampilkan hasil document 1
print (term_frequency)
# Out:
#   (0, 219)	1
#   (0, 255)	1
#   (0, 309)	2
#   (0, 319)	1
#   (0, 539)	2
#   (0, 598)	1
#   (0, 815)	1
#   (0, 1108)	1
#   (0, 1252)	1
#   (0, 1451)	2
#   (0, 1454)	1
#   (0, 1561)	1
#   (0, 1620)	1
#   (0, 1622)	1
#   (0, 1771)	2
#   (0, 1799)	1
#   (0, 2061)	1
#   (0, 2147)	1
#   (0, 2513)	1
#   (0, 2618)	1
#   (0, 2743)	1
#   (0, 3184)	2
#   (0, 3413)	1
#   (0, 3473)	1
#   (0, 3514)	1
#   (0, 3539)	2

# %%
dokumen = term_fit.transform(Ulasan) #hasil perhitungan tf idf dalam 1 doc
tfidf_transformer = TfidfTransformer().fit(dokumen)
print (tfidf_transformer.idf_)

tfidf=tfidf_transformer.transform(term_frequency)
print (tfidf) #hasil manual dengan sistem pyhton
# Out:
# [6.78459412 6.78459412 7.4777413  ... 7.4777413  6.78459412 7.4777413 ]
#   (0, 3539)	0.3389481920696739
#   (0, 3514)	0.1795398969238902
#   (0, 3473)	0.14068862059068274
#   (0, 3413)	0.11482048027647254
#   (0, 3184)	0.2630436728895783
#   (0, 2743)	0.18763017718048455
#   (0, 2618)	0.16947409603483696
#   (0, 2513)	0.23128134859434746
#   (0, 2147)	0.1574322700792808
#   (0, 2061)	0.1551416593158881
#   (0, 1799)	0.13152183644478915
#   (0, 1771)	0.2163394158249711
#   (0, 1622)	0.2711125749789639
#   (0, 1620)	0.12648818997781958
#   (0, 1561)	0.1795398969238902
#   (0, 1454)	0.12682545701176146
#   (0, 1451)	0.2738367505755862
#   (0, 1252)	0.15095363046826907
#   (0, 1108)	0.1616042173366162
#   (0, 815)	0.1544091910765952
#   (0, 598)	0.19572045743707894
#   (0, 539)	0.20793390270558476
#   (0, 319)	0.2711125749789639
#   (0, 309)	0.22402433034278074
#   (0, 255)	0.12682545701176146
#   (0, 219)	0.11605800466784605

# %%
data_label = name_dataframe[["Nama pengguna", "Ulasan_clean", "Sentiment"]]

# %%
data_label["Ulasan_clean"] = data_label["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-71-5732072d6cca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label["Ulasan_clean"] = data_label["Ulasan_clean"].fillna("tidak ada komentar")

# %%
data_label.to_excel("data_label.xlsx")

# %%
sentimen_data=pd.value_counts(data_label["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["#ccd5ae"])
plt.title('Bar chart')
plt.show()

# %%
plt.figure(figsize=(16, 6))

heatmap = sns.heatmap(name_dataframe.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12)

plt.tight_layout()

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize',
#        'Ulasan_normalized', 'Ulasan_stop_removed', 'Ulasan_Stemmed',
#        'Ulasan_clean', 'label', 'Polarity', 'Subjectivity', 'Sentiment',
#        'month'],
#       dtype='object')

# %%
train_s3 = data_label[data_label["Sentiment"] == 'Neutral']

# %%
train_s3["Ulasan_clean"] = train_s3["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-77-0d6c2c4956f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s3["Ulasan_clean"] = train_s3["Ulasan_clean"].fillna("tidak ada komentar")

# %%
all_text_s0 = ' '.join(word for word in train_s3["Ulasan_clean"])
wordcloud = WordCloud(colormap='gist_stern', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s0)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
print("Neutral words")
plt.show()
# Out:
# Neutral words

# %%
from wordcloud import WordCloud

# %%
train_s0 = data_label[data_label["Sentiment"] == 'Negative']

# %%
train_s0["Ulasan_clean"] = train_s0["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-81-4a391e85ccb2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s0["Ulasan_clean"] = train_s0["Ulasan_clean"].fillna("tidak ada komentar")

# %%
train_s0
# Out:
#                 Nama pengguna  \
# 2             hidayat mudaris
# 23              Sutris Trisno
# 27              Afifur Rohman
# 65    Kaloka Galih Kayu Wangi
# 67               Bam Hendrian
# 95                     Lemuel
# 134                    eH boy
# 153             inaya putry26
# 271          Achenk Chonsleth
# 285               Endi irawan
# 299                  dwi momo
# 327            Arjuna Pratama
# 343            Silva Widianti
# 401               Vaka Vaka13
# 441                Dhani Deff
# 464            Muhammad Basir
# 494              tri mulyanto
# 495               david james
# 501                 Trade Day
# 502                     WesLi
# 520                  Nyon bae
# 523           Novi Nurhalimah
# 526                Ahmad Amek
# 543            Richo Agustian
# 545              Cucu Latipah
# 552             Annisa Arifah
# 553             ari hariyanto
# 555                   Hambali
# 732            Herianto Halim
# 736                Tegar Ibnu
# 778     Ulfa Mar'atus Solihah
# 840         Oktavdian Sonjaya
# 897           Pengguna Google
# 906               Najwa Jemur
# 924           Pengguna Google
# 929           Pengguna Google
# 936                 Hr Tester
# 982           Pengguna Google
# 1038                Fian Syah
# 1098      Armand Arya Firdaus
# 1138         Rosana Anjaswari
# 1163       Rosyidin Atmadja 2
# 1166          Pengguna Google
# 1167             wisnu arifin
# 1262          Pengguna Google
# 1265          Pengguna Google
#
#                                            Ulasan_clean Sentiment
# 2     tolong rumit verifikasi akun saldo bukalapak p...  Negative
# 23    guna setia bltp perlahan alih toko online lain...  Negative
# 27    aplikasi bagus minus ongkir mahal voucher paka...  Negative
# 65    jual emas bukaemas susah banget banget problem...  Negative
# 67    kesini sistem nya berat ajabanyak sisrem gunab...  Negative
# 95    mohon maaf kasih bintang alas hubung cs via ch...  Negative
# 134   developer bukalapak lihat aplikasi shopee laza...  Negative
# 153   aplikasi nya visa live chat maju bukalapak pes...  Negative
# 271   lumayan bagus minus sedia menu layan varian pr...  Negative
# 285   beli barang nonfisik chip game inti barang fis...  Negative
# 299   beres market rugi barang cek aplikasi nya pesa...  Negative
# 327   tanggal beli unit powerbank merek soulkarena f...  Negative
# 343   tagih paylater bl resah kanbelum jatuh tempo a...  Negative
# 401   bingung komentar apasly ssh cari minus kkurang...  Negative
# 441   kesini bagus aplikasi buka chat loading tampil...  Negative
# 464   sussh seller tmbhin varian prdukgk kayak tkope...  Negative
# 494   kecewa kali belanja lapak merespon pesan batas...  Negative
# 495   order alamat kirim laku lapak bilang kode book...  Negative
# 501   kecewa sihketika voucher voucher alas voucher ...  Negative
# 502   susah hubungin cs sulit hubung cs pakai email ...  Negative
# 520   aplikasi guna ganti nomor hp kirim foto ktp ga...  Negative
# 523   kecewa aplikasi bukalapak telat bayar jatuh te...  Negative
# 526   maaf turun bintangnyakarena pakai bukalapak pa...  Negative
# 543   halo bukalapak email ganti alas gagal kirim em...  Negative
# 545   sengaja bintang biar baca isi saldo atm tangga...  Negative
# 552   kecewa sellernya fiturnya live chat susah tamb...  Negative
# 553   parah bukalapak komplen klaim barang sulit pot...  Negative
# 555   rekan saran belanja bukalapak bayak tipu salah...  Negative
# 732   kasih kritik negatif nyata akun langsung bloki...  Negative
# 736   sih asih voucher gratis ongkir minimal potong ...  Negative
# 778   edit ulas hubung customer care aplikasi kait b...  Negative
# 840      suka bingung bonus credit nya ya plus minus ya  Negative
# 897   heran aplikasi upload jual barang kaya susahhh...  Negative
# 906   kalo bukalapak rame tampil barang jual bayar i...  Negative
# 924   baik servernya fitur macet traffict diserver j...  Negative
# 929   bukastruk gagal struk identifikasi deteksi dup...  Negative
# 936   aplikasi bagus bantu kendala admin komplain me...  Negative
# 982   kurangtapi suka dwngan tampil bukalapak update...  Negative
# 1038  barang pesan langsung aju komplain selesai isi...  Negative
# 1098  aplikasi bukalapak seller oriented bukalapak g...  Negative
# 1138  halo bayar paylater beku pakai doang beli puls...  Negative
# 1163  sayang usaha buka lapak jual produk game bau j...  Negative
# 1166  baharu akun email username error pakai transak...  Negative
# 1167  aplikasi belanja mepersulit melakukakan ubah d...  Negative
# 1262  bagus sih jual gampang fiturnya mudah lapak op...  Negative
# 1265  bukalapak update beres koneksi bagus wifi kenc...  Negative

# %%
all_text_s0 = ' '.join(word for word in train_s0["Ulasan_clean"])
wordcloud = WordCloud(colormap='Reds', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s0)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
print("Negatif words")
plt.show()
# Out:
# Negatif words

# %%
train_s1 = data_label[data_label["Sentiment"] == 'Positive']

# %%
train_s1["Ulasan_clean"] = train_s1["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-85-89653e0cae75>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s1["Ulasan_clean"] = train_s1["Ulasan_clean"].fillna("tidak ada komentar")

# %%
train_s1
# Out:
#                          Nama pengguna  \
# 3     dedy kelana (CV PRIBUMI BANGKIT)
# 6                            Ferry Tfy
# 10                      Achmad Rifandi
# 13                     Muhammad Arsyad
# 14                       Reza Mahendra
# ...                                ...
# 1263                   Pengguna Google
# 1269                        Hilmy leon
# 1287                         Andri Tea
# 1289                       Gospel Indo
# 1294                  Raden Ardiansyah
#
#                                            Ulasan_clean Sentiment
# 3     pasti hp wifi lemmooottttt dasar bukalapak kar...  Positive
# 6     aplikasi berat kalah toko online belah klik la...  Positive
# 10    payleter bayar lancar payleter nya pakai top u...  Positive
# 13    mohon bantuannyasaya alami sulit logindikarena...  Positive
# 14    lapak produk digital tanggal mei potongam supe...  Positive
# ...                                                 ...       ...
# 1263  bukalapak semenjak baru bugbuka notif lamamasu...  Positive
# 1269  burukkk top up saldo juta masuk cs oper tunggu...  Positive
# 1287  kali pesan barang datang banget live chat buka...  Positive
# 1289  mahal biaya super seller langsung ambil pasar ...  Positive
# 1294  bukalapak mantap fitur baru dangampang guna ya...  Positive
#
# [195 rows x 3 columns]

# %%
all_text_s1 = ' '.join(word for word in train_s1["Ulasan_clean"])
wordcloud = WordCloud(colormap='Blues', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s1)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Ulasan Positif")
plt.margins(x=0, y=0)
print("Positif words")
plt.show()
# Out:
# Positif words

# %%
data_label['Ulasan_clean'] = data_label['Ulasan_clean'].fillna("tidak ada komentar")
# Out:
# <ipython-input-88-27b828896519>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['Ulasan_clean'] = data_label['Ulasan_clean'].fillna("tidak ada komentar")

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_clean'], data_label['Sentiment'], 
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(data_label['Ulasan_clean'])

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, data_label['Sentiment'], test_size=0.2, random_state=42)

# Train the Gaussian Naive Bayes classifier on the training set
gnb = GaussianNB()
gnb.fit(X_train.toarray(), y_train)

# Evaluate the classifier on the testing set
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)

# Use the classifier to predict the sentiment class for all reviews in the dataset
data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# Save the resulting dataframe to a new CSV file
data_label.to_csv('predicted_sentiment1.csv', index=False)
# Out:
# Accuracy: 0.5807692307692308
# <ipython-input-92-35ea0f31f4f4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# %%
import numpy as np

# %%
from sklearn.feature_extraction.text import TfidfVectorizer             #menghitung n menjumlah kan dan menjumlah kan tf and n berdasarkan seluruh dokumen 
vectorizer = TfidfVectorizer(decode_error='replace', encoding='utf-8')

# %%
data_label['predicted_sentiment_class'].hist()
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# **sample random**
#
# mengambil secara acak dari daftar sample atau sampling frame yang tersedia setiap individu memiliki peluang yang sama untuk terpilih
# peluang tersebut ada melakukan peluang sama ketika mempunyai data besar akan memliki peluang lebih besar untuk terpilih tetapi sebaliknya ketika mempunyai data dikit dapat peluang lebih sedikit

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_clean'], data_label['Sentiment'], 
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# Vectorize the text data
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# Create the Naive Bayes Classifier object
gnb = GaussianNB()

# Perform cross-validation
scores = cross_val_score(gnb, X_train.toarray(), y_train, cv=5)

# Print the cross-validation scores
print('Cross-validation scores:', scores)

# Fit the classifier to the training data
gnb.fit(X_train.toarray(), y_train)

# Predict the sentiment of the test data
y_pred = gnb.predict(X_test.toarray())

# Print the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:\n', conf_matrix)
# Out:
# Cross-validation scores: [0.6025641  0.55982906 0.54700855 0.58547009 0.53846154]
# Confusion Matrix:
#  [[ 0  4  1]
#  [11 63 32]
#  [ 0 10  9]]

# %%
# Convert sparse matrix to dense numpy array
X_train_dense = X_train.toarray()
X_test_dense = X_test.toarray()

# Print the scores on the training and test sets
print('Training set score: {:.4f}'.format(gnb.score(X_train_dense, y_train)))
print('Test set score: {:.4f}'.format(gnb.score(X_test_dense, y_test)))
# Out:
# Training set score: 0.8752
# Test set score: 0.5538

# %%
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.5538461538461539

# %%
vectorizer
# Out:
# TfidfVectorizer()

# %%
nb = GaussianNB(var_smoothing=1.0) # untuk tidak overviting

# %%
data_label
# Out:
#                          Nama pengguna  \
# 0                         Nizar Rayyan
# 1                           Fandy Komo
# 2                      hidayat mudaris
# 3     dedy kelana (CV PRIBUMI BANGKIT)
# 4                         Aris Gunawan
# ...                                ...
# 1295                    Sitorus Edward
# 1296                      DK Mattawang
# 1297                      M2D Projects
# 1298                          KA risma
# 1299                Bic Stevie Sualang
#
#                                            Ulasan_clean Sentiment  \
# 0     paylater batal otomatis kadang nya ganti jatuh...   Neutral
# 1     kesini buka lapak bagus layan komplan susah su...   Neutral
# 2     tolong rumit verifikasi akun saldo bukalapak p...  Negative
# 3     pasti hp wifi lemmooottttt dasar bukalapak kar...  Positive
# 4     aplikasi bukalapak bantu proses kirim uang mud...   Neutral
# ...                                                 ...       ...
# 1295                                       cepat proses   Neutral
# 1296                                       guna manfaat   Neutral
# 1297                      barang cari klik barang hapus   Neutral
# 1298  permisi sistem aplikasi bukalapak eror hubung ...   Neutral
# 1299              tingkat jaga nyaman nasabah transaksi   Neutral
#
#      predicted_sentiment_class
# 0                      Neutral
# 1                      Neutral
# 2                     Negative
# 3                     Positive
# 4                      Neutral
# ...                        ...
# 1295                  Positive
# 1296                   Neutral
# 1297                  Negative
# 1298                   Neutral
# 1299                   Neutral
#
# [1300 rows x 4 columns]

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
print('--------------------- confusion matrix  ----------------------------')
print(confusion_matrix(y_test, y_pred))
print('--------------------- classification report  ----------------------------')
print(classification_report(y_test, y_pred))
# Out:
# --------------------- confusion matrix  ----------------------------
# [[ 0  4  1]
#  [11 63 32]
#  [ 0 10  9]]
# --------------------- classification report  ----------------------------
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         5
#      Neutral       0.82      0.59      0.69       106
#     Positive       0.21      0.47      0.30        19
#
#     accuracy                           0.55       130
#    macro avg       0.34      0.36      0.33       130
# weighted avg       0.70      0.55      0.60       130

# %%
TP = cm[0,0]
TN = cm[1,1]
FP = cm[0,1]
FN = cm[1,0]

# %%
# print classification error kesalahan klasifikasi 

classification_error = (FP + FN) / float(TP + TN + FP + FN)

print('Classification error : {0:0.4f}'.format(classification_error))
# Out:
# Classification error : 0.1923

# %%
classification_accuracy = (TP + TN) / float(TP + TN + FP + FN)

print('Classification accuracy : {0:0.4f}'.format(classification_accuracy))
# Out:
# Classification accuracy : 0.8077

# %%
# visualize confusion matrix with seaborn heatmap

cm_matrix = pd.DataFrame(data=cm, columns=['Negative:1', 'Neutral:0', 'Positive:2'], 
                                 index=['Negative:1', 'Neutral:0', 'Positive:2'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <Axes: >

# %%
X_test
# Out:
# <130x3369 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1478 stored elements in Compressed Sparse Row format>

# %%
X_train
# Out:
# <1170x3369 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16240 stored elements in Compressed Sparse Row format>

# %%
y_test
# Out:
# 312      Neutral
# 1251     Neutral
# 982     Negative
# 1131     Neutral
# 1136     Neutral
#           ...
# 470      Neutral
# 1181    Positive
# 895      Neutral
# 211     Positive
# 428      Neutral
# Name: Sentiment, Length: 130, dtype: object

# %%
y_train
# Out:
# 810     Neutral
# 533     Neutral
# 347     Neutral
# 858     Neutral
# 35      Neutral
#          ...
# 235     Neutral
# 214     Neutral
# 273     Neutral
# 1064    Neutral
# 499     Neutral
# Name: Sentiment, Length: 1170, dtype: object

# %%
print(y_train)
# Out:
# 810     Neutral
# 533     Neutral
# 347     Neutral
# 858     Neutral
# 35      Neutral
#          ...
# 235     Neutral
# 214     Neutral
# 273     Neutral
# 1064    Neutral
# 499     Neutral
# Name: Sentiment, Length: 1170, dtype: object

# %%
# visualize confusion matrix with seaborn heatmap

cm_matrix = pd.DataFrame(data=cm, columns=['Negative:1', 'Neutral:0', 'Positive:2'], 
                                 index=['Negative:1', 'Neutral:0', 'Positive:2'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <Axes: >

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
print('Confusion matrix\n\n', cm)
# Out:
# Confusion matrix
#
#  [[ 0  4  1]
#  [11 63 32]
#  [ 0 10  9]]

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
# Regresi Logistik
logreg = LogisticRegression()
# SVM
svm = SVC(probability=True)

# %%
logreg.fit(X_train, y_train)
svm.fit(X_train, y_train)
# Out:
# SVC(probability=True)

# %%
y_pred1_logreg = logreg.predict(X_test)
y_pred1_svm = svm.predict(X_test)

# %%
print('---------------  Regresi Logistik  -------------------')
print(classification_report(y_test, y_pred1_logreg))
print('--------------------- SVM ----------------------------')
print(classification_report(y_test, y_pred1_svm))
# Out:
# ---------------  Regresi Logistik  -------------------
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         5
#      Neutral       0.84      1.00      0.91       106
#     Positive       1.00      0.21      0.35        19
#
#     accuracy                           0.85       130
#    macro avg       0.61      0.40      0.42       130
# weighted avg       0.83      0.85      0.80       130
#
# --------------------- SVM ----------------------------
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         5
#      Neutral       0.84      1.00      0.91       106
#     Positive       1.00      0.21      0.35        19
#
#     accuracy                           0.85       130
#    macro avg       0.61      0.40      0.42       130
# weighted avg       0.83      0.85      0.80       130
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
