# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafiryd/Rafiryd/blob/rafiryd/revisi%20cetak%2069%20baru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Proses Pengambilan data**

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

import seaborn as sns

# %%
from google_play_scraper import Sort, reviews

app_id = 'com.bukalapak.android'
lang = 'id'
country = 'id'
sort_order = Sort.MOST_RELEVANT
target_year = 2019  # Change this to the desired target year
end_year = 2023    # Change this to the desired end year
desired_review_count = 1300  # Adjust this as needed

result, continuation_token = reviews(
    app_id,
    lang=lang,
    country=country,
    sort=sort_order,
    count=desired_review_count,
    filter_score_with=None
)

# Extract reviews from the desired years
reviews_from_target_years = []
for review in result:
    review_date = review['at']
    review_year = review_date.year
    if target_year <= review_year <= end_year:
        reviews_from_target_years.append(review)

print(reviews_from_target_years)
# Out:
# [{'reviewId': '746a7625-b356-46ca-a522-3800375c0698', 'userName': 'Wayan Gita', 'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTd_20KxMvJgC_EtLGHP6DMtznutDvZvcYJ8BPcmmAme7o', 'content': 'Fitur bukabantuan nggak guna, aplikasi ribet, ada saldo 700.000+ malah nggak bisa dipakai apa2, mau aku cairin atau transfer malah ribet banget, password dibilang salah, udah riset password masih juga dibilang salah, udah dikit lagi mau selesai malah ada notifikasi kalau sistem lagi eror, apaan sih.', 'score': 1, 'thumbsUpCount': 115, 'reviewCreatedVersion': '5.34.3', 'at': datetime.datetime(2023, 8, 10, 13, 36, 28), 'replyContent': None, 'repliedAt': None, 'appVersion': '5.34.3'}, {'reviewId': '59b85d4e-4a69-4633-afca-6df9549e8eea', 'userName': 'SAM SURI', 'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfMn8ufHejMRVTROlVFMG0Grq0jJV-TwJv2tvL4Bgz2=mo', 'content': 'Laporan barang sudah diterima dan waktunya pun pada jam 23.44, apakah ada yg datang jam segitu, tapi barangnya sudah semalaman tidak datang2. Laporan komplrn pada BL pun langsung close, seperti gak terima komplenan', 'score': 1, 'thumbsUpCount': 2, 'reviewCreatedVersion': '5.35.0', 'at': datetime.datetime(2023, 8, 30, 4, 35, 4), 'replyContent': None, 'repliedAt': None, 'appVersion': '5.35.0'}, {'reviewId': '8a1e53b2-0cca-49aa-9bc0-5084836892d1', 'userName': 'yOga 04', 'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTDa2wAT_UfqLLxKCOujbxZRCL0mTdBF6LwPJvSK3sE6Q', 'content': 'Aplikasi marketplace paling ancur.. Sistem bukabantuan ngga jelas jika ada masalah.. bukannya selesain masalah malah lari dr masalah live chatnya ngga guna.. apalagi sistem paylaternya bobrok.. Silahkan dicoba sendiri yg mau download nanti juga tau..', 'score': 1, 'thumbsUpCount': 208, 'reviewCreatedVersion': '5.34.3', 'at': datetime.datetime(2023, 8, 1, 3, 19, 16), 'replyContent': None, 'repliedAt': None, 'appVersion': '5.34.3'}, {'reviewId': 'a8a18630-fbb3-465a-9b44-03b4f3c53585', 'userName': 'ipin sopandi', 'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSJzy27yVXvaOys8Y4-ZBJAvStwgI_zmpy2Soaf4Hz3Vjw', 'content': 'Nggak bisa komplain sudah seminggu permintaan pencairan dana ke rekening pribadi belum juga berhasil, ....BukaBantuan tidak bisa digunakan Tolong kerjasamanya, aktifkan kembali BukaBantuannya, saya yakin banyak yang punya masalah seperti ini dan nggak bisa komplain. Next jika masalah saya sudah selesai bintangnya diubah jadi 7', 'score': 1, 'thumbsUpCount': 54, 'reviewCreatedVersion': '5.34.3', 'at': datetime.datetime(2023, 8, 7, 13, 7, 29), 'replyContent': None, 'repliedAt': None, 'appVersion': '5.34.3'}, {'reviewId': '92d269ae-6ddc-4c71-bb25-188b042198ff', 'userName': 'Popi Anggraini', 'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcnSObzsH651R9rQPQWWJgcNZ7f5Ro20G1KtTzbOPoL=mo', 'content': 'Saya sudah transfer melalui bca virtual account, tapi tidak terverifikasi, padahal saldo rekening saya sudah terpotong... saya komplain lewat live chat tapi kok arahanya ribet banget, parahnya tiba tiba live chat langsung keluar dengan alasan koneksi terputus.... ganti email juga ribet banget. Harus selfilah, ktplah, mutasi rekeninglah, harus satu framelah... kembalikan dana saya... saya sudah transfer ke bukalapak... katanya ditangani tim dan harus nunggu 3 x 24 jam... tapi gak ada selesai', 'score': 1, 'thumbsUpCount': 53, 'reviewCreatedVersion': '5.33.1', 'at': datetime.datetime(2023, 7, 5, 23, 47, 51), 'replyContent': None, 'repliedAt': None, 'appVersion': '5.33.1'}, {'reviewId': 'ee89c8f1-7d27-45f3-8720-539a0965d0dc', 'userName': 'Imagination Music Store', 'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQzM4ABiFSBR9RUr4JWVNxTzedaK_BT7_kONBcvkrYI9Q', 'content': 'Aplikasi yg sangat ribet. Tiap mau edit produk, giliran berhasil, ujung2nya iklan produk yg dijual selalu hilang alias otomatis dihapus oleh bukalapak. Tolong ditingkatkan ulang sistemnya. jangan buat penjual & pembeli meninggalkan aplikasi ini', 'score': 1, 'thumbsUpCount': 94 ...

# %% [markdown]
# Problems slovlig tools = mencari akar permasalahan pada suatu masalah
#
# 5 why
#
# metode mencari problems sloving dengan cara menanyakan apa penyebab permasalahaan muncul dan mencari jawabannya. hal ini di lakUkan berkali klai sampai permasalahan dapat tergambar dengan jelas
#
# action priority
#
# diagram yang dapat di gunakan untuk mencari prioritas masalah berdasarkan impact atas benefit yang bisa diberikan dengan diagram ini kita memilih masalah yang impactnya mayoritas dari permasalahan yang ada.
#
# fishbone digram
#
# digram yang dapat di gunakan untuk merinci masalah dan membantu mencari akar masalah yang dapat dilihat dari beberapa point of view
#
# flowchart/algo
#
# metode pemecahan masalah dengan cara memetakan flow atau membuat pseudo algoritma yang untuk menentukan masalah dan cara untuk mencari solusinya secara sistematis

# %% [markdown]
# # **Data diproleh**

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId        userName  \
# 0  746a7625-b356-46ca-a522-3800375c0698      Wayan Gita
# 1  59b85d4e-4a69-4633-afca-6df9549e8eea        SAM SURI
# 2  8a1e53b2-0cca-49aa-9bc0-5084836892d1         yOga 04
# 3  a8a18630-fbb3-465a-9b44-03b4f3c53585    ipin sopandi
# 4  92d269ae-6ddc-4c71-bb25-188b042198ff  Popi Anggraini
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# 1  https://play-lh.googleusercontent.com/a/AAcHTt...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a-/AD_cM...
# 4  https://play-lh.googleusercontent.com/a/AAcHTt...
#
#                                              content  score  thumbsUpCount  \
# 0  Fitur bukabantuan nggak guna, aplikasi ribet, ...      1            115
# 1  Laporan barang sudah diterima dan waktunya pun...      1              2
# 2  Aplikasi marketplace paling ancur.. Sistem buk...      1            208
# 3  Nggak bisa komplain sudah seminggu permintaan ...      1             54
# 4  Saya sudah transfer melalui bca virtual accoun...      1             53
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0               5.34.3 2023-08-10 13:36:28         None       NaT     5.34.3
# 1               5.35.0 2023-08-30 04:35:04         None       NaT     5.35.0
# 2               5.34.3 2023-08-01 03:19:16         None       NaT     5.34.3
# 3               5.34.3 2023-08-07 13:07:29         None       NaT     5.34.3
# 4               5.33.1 2023-07-05 23:47:51         None       NaT     5.33.1

# %%
len(df_busu.index) #count the number of data we got
# Out:
# 1300

# %%
df_busu[['userName', 'score','at', 'content']].tail()  #preview userName, rating, date-time, and reviews only
# Out:
#               userName  score                  at  \
# 1295     Totok Sunarno      5 2023-07-07 10:08:08
# 1296  Arif Nur Pramono      1 2023-07-21 01:23:04
# 1297   JebodZz Channel      5 2023-07-27 22:20:57
# 1298        king black      5 2023-07-27 05:51:59
# 1299   Muhammad Fandri      1 2023-07-23 13:47:34
#
#                                                 content
# 1295  Sangat membantu kebutuhan kita...terima kasih ...
# 1296  Kenapa barang yg sdh tdk ada masih ada di ikla...
# 1297  Mantappp ,cepat.. Alhamdulillah dengan adanya ...
# 1298  Pengiriman termaksud cepat dari si Oren , mant...
# 1299  Saya beli barang. Tp tidak dikirim. Tolong kal...

# %% [markdown]
# # **Perubahan Penamaan Pada Setiap Kolom**

# %%
name_dataframe = df_busu.loc[:,["userName", "score", "at", "content"]]
name_dataframe.rename(columns={"userName": "Nama pengguna", "score":"Rating", "at": "Date", "content": "Ulasan"}, inplace=True)

# %%
name_dataframe.tail()
# Out:
#          Nama pengguna  Rating                Date  \
# 1295     Totok Sunarno       5 2023-07-07 10:08:08
# 1296  Arif Nur Pramono       1 2023-07-21 01:23:04
# 1297   JebodZz Channel       5 2023-07-27 22:20:57
# 1298        king black       5 2023-07-27 05:51:59
# 1299   Muhammad Fandri       1 2023-07-23 13:47:34
#
#                                                  Ulasan
# 1295  Sangat membantu kebutuhan kita...terima kasih ...
# 1296  Kenapa barang yg sdh tdk ada masih ada di ikla...
# 1297  Mantappp ,cepat.. Alhamdulillah dengan adanya ...
# 1298  Pengiriman termaksud cepat dari si Oren , mant...
# 1299  Saya beli barang. Tp tidak dikirim. Tolong kal...

# %%
name_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nama pengguna  1300 non-null   object
#  1   Rating         1300 non-null   int64
#  2   Date           1300 non-null   datetime64[ns]
#  3   Ulasan         1300 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 40.8+ KB

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].astype(str)
name_dataframe.head()
# Out:
#     Nama pengguna  Rating                Date  \
# 0      Wayan Gita       1 2023-08-10 13:36:28
# 1        SAM SURI       1 2023-08-30 04:35:04
# 2         yOga 04       1 2023-08-01 03:19:16
# 3    ipin sopandi       1 2023-08-07 13:07:29
# 4  Popi Anggraini       1 2023-07-05 23:47:51
#
#                                               Ulasan
# 0  Fitur bukabantuan nggak guna, aplikasi ribet, ...
# 1  Laporan barang sudah diterima dan waktunya pun...
# 2  Aplikasi marketplace paling ancur.. Sistem buk...
# 3  Nggak bisa komplain sudah seminggu permintaan ...
# 4  Saya sudah transfer melalui bca virtual accoun...

# %% [markdown]
# # **Case folding**

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].str.lower()

# %% [markdown]
# # **cleansing**

# %%
import string
import re
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

def remove_links(text):
    # menghapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus URL
    return text.replace("http://", " ").replace("https://", " ")

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_links)

# %%
#menghapus number
def remove_number(text):
    return  re.sub(r"\d+", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_number)

# %%
#menghapus punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_punctuation)

# %%
# menghapus single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_singl_char)

# %% [markdown]
# # **Tokenizing**

# %%
# Tokenisasi
def word_tokenize_wrapper(text):
    return word_tokenize(text)

name_dataframe['Ulasan_tokenize'] = name_dataframe['Ulasan'].apply(word_tokenize_wrapper)

# %%
name_dataframe
# Out:
#          Nama pengguna  Rating                Date  \
# 0           Wayan Gita       1 2023-08-10 13:36:28
# 1             SAM SURI       1 2023-08-30 04:35:04
# 2              yOga 04       1 2023-08-01 03:19:16
# 3         ipin sopandi       1 2023-08-07 13:07:29
# 4       Popi Anggraini       1 2023-07-05 23:47:51
# ...                ...     ...                 ...
# 1295     Totok Sunarno       5 2023-07-07 10:08:08
# 1296  Arif Nur Pramono       1 2023-07-21 01:23:04
# 1297   JebodZz Channel       5 2023-07-27 22:20:57
# 1298        king black       5 2023-07-27 05:51:59
# 1299   Muhammad Fandri       1 2023-07-23 13:47:34
#
#                                                  Ulasan  \
# 0     fitur bukabantuan nggak guna aplikasi ribet ad...
# 1     laporan barang sudah diterima dan waktunya pun...
# 2     aplikasi marketplace paling ancur sistem bukab...
# 3     nggak bisa komplain sudah seminggu permintaan ...
# 4     saya sudah transfer melalui bca virtual accoun...
# ...                                                 ...
# 1295  sangat membantu kebutuhan kitaterima kasih buk...
# 1296  kenapa barang yg sdh tdk ada masih ada di ikla...
# 1297  mantappp cepat alhamdulillah dengan adanya buk...
# 1298  pengiriman termaksud cepat dari si oren  manta...
# 1299  saya beli barang tp tidak dikirim tolong kalia...
#
#                                         Ulasan_tokenize
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [laporan, barang, sudah, diterima, dan, waktun...
# 2     [aplikasi, marketplace, paling, ancur, sistem,...
# 3     [nggak, bisa, komplain, sudah, seminggu, permi...
# 4     [saya, sudah, transfer, melalui, bca, virtual,...
# ...                                                 ...
# 1295  [sangat, membantu, kebutuhan, kitaterima, kasi...
# 1296  [kenapa, barang, yg, sdh, tdk, ada, masih, ada...
# 1297  [mantappp, cepat, alhamdulillah, dengan, adany...
# 1298  [pengiriman, termaksud, cepat, dari, si, oren,...
# 1299  [saya, beli, barang, tp, tidak, dikirim, tolon...
#
# [1300 rows x 5 columns]

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize'], dtype='object')

# %%
#Run This Code to Sort the Data By Date
# tanggal 26-04-2022 sampai 12-10-2022

new_df = name_dataframe[['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize']]
sorted_df = new_df.sort_values(by='Date', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#              Nama pengguna  Rating                Date  \
# 395              david jig       5 2023-08-30 12:14:39
# 254        Nurrohib Abidin       1 2023-08-30 11:32:35
# 249  Ravin Ariadi Siswanto       1 2023-08-30 10:40:22
# 565             dika Villa       5 2023-08-30 09:38:58
# 177            Rizal Fakih       5 2023-08-30 08:43:52
#
#                                                 Ulasan  \
# 395        error ni aplikasi sdh waktunya di uninstal
# 254  sangat kecewa dgn paylater buka lapak kalah sa...
# 249  masa biaya pembayaran virtualaccount kena admi...
# 565  mantap aplikasi bagus ringan dan nyaman berbel...
# 177  sangat perfect apalagi dalam transaksi dan men...
#
#                                        Ulasan_tokenize
# 395  [error, ni, aplikasi, sdh, waktunya, di, unins...
# 254  [sangat, kecewa, dgn, paylater, buka, lapak, k...
# 249  [masa, biaya, pembayaran, virtualaccount, kena...
# 565  [mantap, aplikasi, bagus, ringan, dan, nyaman,...
# 177  [sangat, perfect, apalagi, dalam, transaksi, d...

# %%
sorted_df.dtypes
# Out:
# Nama pengguna              object
# Rating                      int64
# Date               datetime64[ns]
# Ulasan                     object
# Ulasan_tokenize            object
# dtype: object

# %%
import pandas as pd

# Assuming you have a DataFrame named ulasan with columns 'Ulasan_tokenize' and 'Ulasan_ears'

word_to_erase = 'nya'  # Replace 'word' with the word you want to erase

name_dataframe["ulasan_ears"] = name_dataframe['Ulasan_tokenize'].apply(lambda x: [word for word in x if word != word_to_erase])

print(name_dataframe)
# Out:
#          Nama pengguna  Rating                Date  \
# 0           Wayan Gita       1 2023-08-10 13:36:28
# 1             SAM SURI       1 2023-08-30 04:35:04
# 2              yOga 04       1 2023-08-01 03:19:16
# 3         ipin sopandi       1 2023-08-07 13:07:29
# 4       Popi Anggraini       1 2023-07-05 23:47:51
# ...                ...     ...                 ...
# 1295     Totok Sunarno       5 2023-07-07 10:08:08
# 1296  Arif Nur Pramono       1 2023-07-21 01:23:04
# 1297   JebodZz Channel       5 2023-07-27 22:20:57
# 1298        king black       5 2023-07-27 05:51:59
# 1299   Muhammad Fandri       1 2023-07-23 13:47:34
#
#                                                  Ulasan  \
# 0     fitur bukabantuan nggak guna aplikasi ribet ad...
# 1     laporan barang sudah diterima dan waktunya pun...
# 2     aplikasi marketplace paling ancur sistem bukab...
# 3     nggak bisa komplain sudah seminggu permintaan ...
# 4     saya sudah transfer melalui bca virtual accoun...
# ...                                                 ...
# 1295  sangat membantu kebutuhan kitaterima kasih buk...
# 1296  kenapa barang yg sdh tdk ada masih ada di ikla...
# 1297  mantappp cepat alhamdulillah dengan adanya buk...
# 1298  pengiriman termaksud cepat dari si oren  manta...
# 1299  saya beli barang tp tidak dikirim tolong kalia...
#
#                                         Ulasan_tokenize  \
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [laporan, barang, sudah, diterima, dan, waktun...
# 2     [aplikasi, marketplace, paling, ancur, sistem,...
# 3     [nggak, bisa, komplain, sudah, seminggu, permi...
# 4     [saya, sudah, transfer, melalui, bca, virtual,...
# ...                                                 ...
# 1295  [sangat, membantu, kebutuhan, kitaterima, kasi...
# 1296  [kenapa, barang, yg, sdh, tdk, ada, masih, ada...
# 1297  [mantappp, cepat, alhamdulillah, dengan, adany...
# 1298  [pengiriman, termaksud, cepat, dari, si, oren,...
# 1299  [saya, beli, barang, tp, tidak, dikirim, tolon...
#
#                                             ulasan_ears
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [laporan, barang, sudah, diterima, dan, waktun...
# 2     [aplikasi, marketplace, paling, ancur, sistem,...
# 3     [nggak, bisa, komplain, sudah, seminggu, permi...
# 4     [saya, sudah, transfer, melalui, bca, virtual,...
# ...                                                 ...
# 1295  [sangat, membantu, kebutuhan, kitaterima, kasi...
# 1296  [kenapa, barang, yg, sdh, tdk, ada, masih, ada...
# 1297  [mantappp, cepat, alhamdulillah, dengan, adany...
# 1298  [pengiriman, termaksud, cepat, dari, si, oren,...
# 1299  [saya, beli, barang, tp, tidak, dikirim, tolon...
#
# [1300 rows x 6 columns]

# %%
name_dataframe.head()
# Out:
#     Nama pengguna  Rating                Date  \
# 0      Wayan Gita       1 2023-08-10 13:36:28
# 1        SAM SURI       1 2023-08-30 04:35:04
# 2         yOga 04       1 2023-08-01 03:19:16
# 3    ipin sopandi       1 2023-08-07 13:07:29
# 4  Popi Anggraini       1 2023-07-05 23:47:51
#
#                                               Ulasan  \
# 0  fitur bukabantuan nggak guna aplikasi ribet ad...
# 1  laporan barang sudah diterima dan waktunya pun...
# 2  aplikasi marketplace paling ancur sistem bukab...
# 3  nggak bisa komplain sudah seminggu permintaan ...
# 4  saya sudah transfer melalui bca virtual accoun...
#
#                                      Ulasan_tokenize  \
# 0  [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1  [laporan, barang, sudah, diterima, dan, waktun...
# 2  [aplikasi, marketplace, paling, ancur, sistem,...
# 3  [nggak, bisa, komplain, sudah, seminggu, permi...
# 4  [saya, sudah, transfer, melalui, bca, virtual,...
#
#                                          ulasan_ears
# 0  [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1  [laporan, barang, sudah, diterima, dan, waktun...
# 2  [aplikasi, marketplace, paling, ancur, sistem,...
# 3  [nggak, bisa, komplain, sudah, seminggu, permi...
# 4  [saya, sudah, transfer, melalui, bca, virtual,...

# %%
# Menghitung Distibusi Persebaran Kata
def freqDist_wrapper(text):
    return FreqDist(text)

Ulasan_fqsist = name_dataframe['ulasan_ears'].apply(freqDist_wrapper)

print('Frequency Tokens : \n')
print(Ulasan_fqsist.head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(malah, 3), (nggak, 2), (ribet, 2), (ada, 2),...
# 1    [(laporan, 2), (sudah, 2), (pun, 2), (pada, 2)...
# 2    [(masalah, 3), (sistem, 2), (ngga, 2), (aplika...
# 3    [(bisa, 3), (nggak, 2), (komplain, 2), (sudah,...
# 4    [(saya, 5), (sudah, 3), (tapi, 3), (harus, 3),...
# Name: ulasan_ears, dtype: object

# %%
print(name_dataframe.columns)
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize',
#        'ulasan_ears'],
#       dtype='object')

# %%
name_dataframe['Ulasan_tokenize'].unique
# Out:
# <bound method Series.unique of 0       [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1       [laporan, barang, sudah, diterima, dan, waktun...
# 2       [aplikasi, marketplace, paling, ancur, sistem,...
# 3       [nggak, bisa, komplain, sudah, seminggu, permi...
# 4       [saya, sudah, transfer, melalui, bca, virtual,...
#                               ...
# 1295    [sangat, membantu, kebutuhan, kitaterima, kasi...
# 1296    [kenapa, barang, yg, sdh, tdk, ada, masih, ada...
# 1297    [mantappp, cepat, alhamdulillah, dengan, adany...
# 1298    [pengiriman, termaksud, cepat, dari, si, oren,...
# 1299    [saya, beli, barang, tp, tidak, dikirim, tolon...
# Name: Ulasan_tokenize, Length: 1300, dtype: object>

# %%
slank_word_dict = {
    "berjalansudah" : "berjalan",
    "paraah" : "parah",
    "keduakali" : "",
    "keduakali" : "kedua kali",
    "agak" : "sedikit",
    "pas" : "saat",
    "produkx" : "produknya",
    "sukamkasih" : "suka makasih",
    "gak" : "tidak",
    "cpt" : "cepat",
    "sdh" : "sudah",
    "recommend" : "rekomendasi",
    "bagusseller" : "bagus",
    "bagusssss" : "bagus",
    "bagussssss" : "bagus",
    "baguuussss" : "bagus",
    "cepatmakasih": "cepat",
    "cepatmantappp": "cepat",
    "cepatproduct": "cepat",
    "cepatrecomended": "cepat",
    "cepattoko": "cepat",
    "recomended": "rekomendasi",
    "recommended": "rekomendasi",
    "rekomendasi": "rekomendasi",
    "rekomended": "rekomendasi",
    }

def slank_normalized_term(document):
    return [slank_word_dict[term] if term in slank_word_dict else term for term in document]

# %% [markdown]
# # **Normalization**

# %%
normalizad_word = pd.read_csv("/content/kamusindonesia.csv (5).csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1]

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

# %%
name_dataframe['Ulasan_normalized'] = name_dataframe['Ulasan_tokenize'].apply(normalized_term).apply(slank_normalized_term)

# %%
name_dataframe.head(100)
# Out:
#            Nama pengguna  Rating                Date  \
# 0             Wayan Gita       1 2023-08-10 13:36:28
# 1               SAM SURI       1 2023-08-30 04:35:04
# 2                yOga 04       1 2023-08-01 03:19:16
# 3           ipin sopandi       1 2023-08-07 13:07:29
# 4         Popi Anggraini       1 2023-07-05 23:47:51
# ..                   ...     ...                 ...
# 95           Zeguh Plaza       1 2023-08-19 15:06:05
# 96           Steven Tonz       1 2023-07-04 06:22:32
# 97           Saiful Hadi       1 2023-07-25 14:24:54
# 98  zulky jaya (shirenk)       1 2023-08-14 06:25:42
# 99         Raufan Azizan       1 2023-08-19 03:02:37
#
#                                                Ulasan  \
# 0   fitur bukabantuan nggak guna aplikasi ribet ad...
# 1   laporan barang sudah diterima dan waktunya pun...
# 2   aplikasi marketplace paling ancur sistem bukab...
# 3   nggak bisa komplain sudah seminggu permintaan ...
# 4   saya sudah transfer melalui bca virtual accoun...
# ..                                                ...
# 95  mon maap nih napa akun saya bisa di nonaktifka...
# 96  saya ada masalah dengan data akun saya bagaima...
# 97  bikin emosi daftar sana sini jawabnya sudah da...
# 98  tolong di rubah pengaturan waktu proses   hr a...
# 99  ini aplikasi market apaan guna nya bukabantuan...
#
#                                       Ulasan_tokenize  \
# 0   [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1   [laporan, barang, sudah, diterima, dan, waktun...
# 2   [aplikasi, marketplace, paling, ancur, sistem,...
# 3   [nggak, bisa, komplain, sudah, seminggu, permi...
# 4   [saya, sudah, transfer, melalui, bca, virtual,...
# ..                                                ...
# 95  [mon, maap, nih, napa, akun, saya, bisa, di, n...
# 96  [saya, ada, masalah, dengan, data, akun, saya,...
# 97  [bikin, emosi, daftar, sana, sini, jawabnya, s...
# 98  [tolong, di, rubah, pengaturan, waktu, proses,...
# 99  [ini, aplikasi, market, apaan, guna, nya, buka...
#
#                                           ulasan_ears  \
# 0   [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1   [laporan, barang, sudah, diterima, dan, waktun...
# 2   [aplikasi, marketplace, paling, ancur, sistem,...
# 3   [nggak, bisa, komplain, sudah, seminggu, permi...
# 4   [saya, sudah, transfer, melalui, bca, virtual,...
# ..                                                ...
# 95  [mon, maap, nih, napa, akun, saya, bisa, di, n...
# 96  [saya, ada, masalah, dengan, data, akun, saya,...
# 97  [bikin, emosi, daftar, sana, sini, jawabnya, s...
# 98  [tolong, di, rubah, pengaturan, waktu, proses,...
# 99  [ini, aplikasi, market, apaan, guna, bukabantu...
#
#                                     Ulasan_normalized
# 0   [fitur, bukabantuan, enggak, guna, aplikasi, r...
# 1   [laporan, barang, sudah, diterima, dan, waktun...
# 2   [aplikasi, marketplace, paling, hancur, sistem...
# 3   [enggak, bisa, komplain, sudah, seminggu, perm...
# 4   [saya, sudah, transfer, melalui, baca, virtual...
# ..                                                ...
# 95  [mon, maaf, nih, kenapa, akun, saya, bisa, di,...
# 96  [saya, ada, masalah, dengan, data, akun, saya,...
# 97  [bikin, emosi, daftar, sana, sini, jawabnya, s...
# 98  [tolong, di, rubah, pengaturan, waktu, proses,...
# 99  [ini, aplikasi, market, apaan, guna, nya, buka...
#
# [100 rows x 7 columns]

# %%
name_dataframe['Ulasan_normalized'].unique
# Out:
# <bound method Series.unique of 0       [fitur, bukabantuan, enggak, guna, aplikasi, r...
# 1       [laporan, barang, sudah, diterima, dan, waktun...
# 2       [aplikasi, marketplace, paling, hancur, sistem...
# 3       [enggak, bisa, komplain, sudah, seminggu, perm...
# 4       [saya, sudah, transfer, melalui, baca, virtual...
#                               ...
# 1295    [sangat, membantu, kebutuhan, kitaterima, kasi...
# 1296    [kenapa, barang, yang, sudah, tidak, ada, masi...
# 1297    [mantap, cepat, alhamdulillah, dengan, adanya,...
# 1298    [pengiriman, termaksud, cepat, dari, sih, oren...
# 1299    [saya, beli, barang, tapi, tidak, dikirim, tol...
# Name: Ulasan_normalized, Length: 1300, dtype: object>

# %% [markdown]
# # **Stop Removal**

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

name_dataframe['Ulasan_stop_removed'] = name_dataframe['Ulasan_normalized'].apply(stopwords_removal)

# %%
name_dataframe
# Out:
#          Nama pengguna  Rating                Date  \
# 0           Wayan Gita       1 2023-08-10 13:36:28
# 1             SAM SURI       1 2023-08-30 04:35:04
# 2              yOga 04       1 2023-08-01 03:19:16
# 3         ipin sopandi       1 2023-08-07 13:07:29
# 4       Popi Anggraini       1 2023-07-05 23:47:51
# ...                ...     ...                 ...
# 1295     Totok Sunarno       5 2023-07-07 10:08:08
# 1296  Arif Nur Pramono       1 2023-07-21 01:23:04
# 1297   JebodZz Channel       5 2023-07-27 22:20:57
# 1298        king black       5 2023-07-27 05:51:59
# 1299   Muhammad Fandri       1 2023-07-23 13:47:34
#
#                                                  Ulasan  \
# 0     fitur bukabantuan nggak guna aplikasi ribet ad...
# 1     laporan barang sudah diterima dan waktunya pun...
# 2     aplikasi marketplace paling ancur sistem bukab...
# 3     nggak bisa komplain sudah seminggu permintaan ...
# 4     saya sudah transfer melalui bca virtual accoun...
# ...                                                 ...
# 1295  sangat membantu kebutuhan kitaterima kasih buk...
# 1296  kenapa barang yg sdh tdk ada masih ada di ikla...
# 1297  mantappp cepat alhamdulillah dengan adanya buk...
# 1298  pengiriman termaksud cepat dari si oren  manta...
# 1299  saya beli barang tp tidak dikirim tolong kalia...
#
#                                         Ulasan_tokenize  \
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [laporan, barang, sudah, diterima, dan, waktun...
# 2     [aplikasi, marketplace, paling, ancur, sistem,...
# 3     [nggak, bisa, komplain, sudah, seminggu, permi...
# 4     [saya, sudah, transfer, melalui, bca, virtual,...
# ...                                                 ...
# 1295  [sangat, membantu, kebutuhan, kitaterima, kasi...
# 1296  [kenapa, barang, yg, sdh, tdk, ada, masih, ada...
# 1297  [mantappp, cepat, alhamdulillah, dengan, adany...
# 1298  [pengiriman, termaksud, cepat, dari, si, oren,...
# 1299  [saya, beli, barang, tp, tidak, dikirim, tolon...
#
#                                             ulasan_ears  \
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [laporan, barang, sudah, diterima, dan, waktun...
# 2     [aplikasi, marketplace, paling, ancur, sistem,...
# 3     [nggak, bisa, komplain, sudah, seminggu, permi...
# 4     [saya, sudah, transfer, melalui, bca, virtual,...
# ...                                                 ...
# 1295  [sangat, membantu, kebutuhan, kitaterima, kasi...
# 1296  [kenapa, barang, yg, sdh, tdk, ada, masih, ada...
# 1297  [mantappp, cepat, alhamdulillah, dengan, adany...
# 1298  [pengiriman, termaksud, cepat, dari, si, oren,...
# 1299  [saya, beli, barang, tp, tidak, dikirim, tolon...
#
#                                       Ulasan_normalized  \
# 0     [fitur, bukabantuan, enggak, guna, aplikasi, r...
# 1     [laporan, barang, sudah, diterima, dan, waktun...
# 2     [aplikasi, marketplace, paling, hancur, sistem...
# 3     [enggak, bisa, komplain, sudah, seminggu, perm...
# 4     [saya, sudah, transfer, melalui, baca, virtual...
# ...                                                 ...
# 1295  [sangat, membantu, kebutuhan, kitaterima, kasi...
# 1296  [kenapa, barang, yang, sudah, tidak, ada, masi...
# 1297  [mantap, cepat, alhamdulillah, dengan, adanya,...
# 1298  [pengiriman, termaksud, cepat, dari, sih, oren...
# 1299  [saya, beli, barang, tapi, tidak, dikirim, tol...
#
#                                     Ulasan_stop_removed
# 0     [fitur, bukabantuan, aplikasi, ribet, saldo, d...
# 1     [laporan, barang, diterima, jam, jam, segitu, ...
# 2     [aplikasi, marketplace, hancur, sistem, bukaba...
# 3     [komplain, seminggu, permintaan, pencairan, da...
# 4     [transfer, baca, virtual, account, terverifika...
# ...                                                 ...
# 1295  [membantu, kebutuhan, kitaterima, kasih, bukal...
# 1296               [barang, iklan, ya, dihapus, ajalah]
# 1297    [mantap, cepat, alhamdulillah, bukalapak, beli]
# 1298  [pengiriman, termaksud, cepat, sih, oren, mant...
# 1299  [beli, barang, dikirim, tolong, filter, dikit,...
#
# [1300 rows x 8 columns]

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
pip install swifter
# Out:
# Collecting swifter
#   Downloading swifter-1.4.0.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (1.5.3)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.10/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2023.8.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (4.66.1)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (23.1)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (1.23.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask[dataframe]>=2.10.0->swifter) (3.16.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->swifter) (1.16.0)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.4.0-py3-none-any.whl size=16507 sha256=2be827c2b1a4b2c0af8d7ce44ad87ad4d300171280b15928ff915a8e2b88912f
#   Stored in directory: /root/.cache/pip/wheels/e4/cf/51/0904952972ee2c7aa3709437065278dc534ec1b8d2ad41b443
# Successfully built swifter
# Installing collected packages: swifter
# Successfully installed swifter-1.4.0

# %% [markdown]
# # **Stemming**

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in name_dataframe['Ulasan_stop_removed']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '

print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])

print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

name_dataframe['Ulasan_Stemmed'] = name_dataframe['Ulasan_stop_removed'].swifter.apply(get_stemmed_term)
# Out:
# 4515
# ------------------------
# fitur : fitur
# bukabantuan : bukabantuan
# aplikasi : aplikasi
# ribet : ribet
# saldo : saldo
# dipakai : pakai
# cairin : cairin
# transfer : transfer
# banget : banget
# password : password
# dibilang : bilang
# salah : salah
# riset : riset
# dikit : dikit
# selesai : selesai
# notifikasi : notifikasi
# sistem : sistem
# eror : eror
# sih : sih
# laporan : lapor
# barang : barang
# diterima : terima
# jam : jam
# segitu : segitu
# barangnya : barang
# semalaman : malam
# komplrn : komplrn
# bl : bl
# langsung : langsung
# close : close
# terima : terima
# komplenan : komplenan
# marketplace : marketplace
# hancur : hancur
# selesain : selesain
# lari : lari
# live : live
# chatnya : chatnya
# paylaternya : paylaternya
# bobrok : bobrok
# silakan : sila
# dicoba : coba
# download : download
# tau : tau
# komplain : komplain
# seminggu : minggu
# permintaan : minta
# pencairan : cair
# dana : dana
# rekening : rekening
# pribadi : pribadi
# berhasil : hasil
# tolong : tolong
# kerjasamanya : kerjasamanya
# aktifkan : aktif
# bukabantuannya : bukabantuannya
# next : next
# bintangnya : bintang
# diubah : ubah
# baca : baca
# virtual : virtual
# account : account
# terverifikasi : verifikasi
# terpotong : potong
# chat : chat
# arahanya : arahanya
# parahnya : parah
# alasan : alas
# koneksi : koneksi
# terputus : putus
# ganti : ganti
# email : email
# selfilah : selfilah
# ktplah : ktplah
# mutasi : mutasi
# rekeninglah : rekening
# framelah : framelah
# kembalikan : kembali
# bukalapak : bukalapak
# ditangani : tangan
# tim : tim
# menunggu : tunggu
# edit : edit
# produk : produk
# giliran : gilir
# ujung : ujung
# nya : nya
# iklan : iklan
# dijual : jual
# hilang : hilang
# alias : alias
# otomatis : otomatis
# dihapus : hapus
# ditingkatkan : tingkat
# ulang : ulang
# sistemnya : sistem
# penjual : jual
# pembeli : beli
# meninggalkan : tinggal
# gue : gue
# suka : suka
# apps : apps
# tampilannya : tampil
# oke : oke
# beli : beli
# pulsa : pulsa
# isi : isi
# pln : pln
# murah : murah
# cuman : cuman
# belanja : belanja
# online : online
# ongkirnya : ongkirnya
# mahal : mahal
# ampun : ampun
# potongan : potong
# ongkir : ongkir
# kayak : kayak
# shopee : shopee
# gratis : gratis
# bug : bug
# cari : cari
# favorit : favorit
# via : via
# ketik : ketik
# nama : nama
# habis : habis
# muncul : muncul
# ngeload : ngeload
# percaya : percaya
# penjualnya : jual
# respon : respon
# pembelinya : bel
# mengirim : kirim
# rugi : rugi
# transaksi : transaksi
# dianggap : anggap
# kalo : kalo
# pengiriman : kirim
# kali : kali
# menerima : terima
# mbulet : mbulet
# dibukalapak : dibukalapak
# gangguan : ganggu
# terusan : terus
# diskon : diskon
# pelit : pelit
# harga : harga
# rekomendasi : rekomendasi
# deh : deh
# perbaiki : baik
# apk : apk
# rugikan : rugi
# paket : paket
# internet : internet
# masukmasuk : masukmasuk
# tertulisnya : tulis
# pembayaran : bayar
# bayar : bayar
# lamalama : lamalama
# kecewa : kecewa
# paylater : paylater
# aktif : aktif
# dibatalkan : batal
# cek : cek
# ya : ya
# hun : hun
# cs : cs
# telepon : telepon
# dibuka : buka
# kolom : kolom
# tanggapan : tanggap
# bagus : bagus
# puas : puas
# promo : promo
# discount : discount
# syarat : syarat
# bohong : bohong
# pakai : pakai
# bonus : bonus
# reward : reward
# roda : roda
# putar : putar
# kredit : kredit
# perak : perak
# hadeeh : hadeeh
# mending : mending
# kaya : kaya
# kena : kena
# biaya : biaya
# bulanan : bulan
# rp : rp
# ditambah : tambah
# keterangan : terang
# merchant : merchant
# mudah : mudah
# sukses : sukses
# bukelepek : bukelepek
# sampah : sampah
# tutup : tutup
# akun : akun
# bertele : tele
# beda : beda
# tokopedia : tokopedia
# shope : shope
# hapus : hapus
# tombol : tombol
# klik : klik
# bukulepek : bukulepek
# seakan : akan
# perbolehkan : boleh
# menyenangkan : senang
# sayalive : sayalive
# susahyang : susahyang
# melayani : layan
# robot : robot
# terusni : terusni
# perusahaan : usaha
# warung : warung
# kelontongan : kelontong
# sihminta : sihminta
# bantuan : bantu
# susahmasa : susahmasa
# datacuma : datacuma
# seharga : harga
# anmasa : anmasa
# tahangawat : tahangawat
# iniklo : iniklo
# mendadak : dadak
# kehabisan : habis
# datagimana : datagimana
# tuh : tuh
# parah : parah
# bangettolong : bangettolong
# inikarena : inikarena
# kebutuhan : butuh
# kamiuang : kamiuang
# tahan : tahan
# hatihati : hatihati
# penipu : tipu
# menjebak : jebak
# costumer : costumer
# alat : alat
# pancing : pancing
# sengaja : sengaja
# membiarkan : biar
# tagihan : tagih
# admin : admin
# perbulan : bulan
# berjalan : jalan
# membayar : bayar
# memberitahu : memberitahu
# nonaktifkan : nonaktif
# ecommerce : ecommerce
# terbobrok : bobrok
# merugikan : rugi
# menyesal : sesal
# pesanan : pesan
# proses : proses
# cancel : cancel
# prosesnya : proses
# buang : buang
# menu : menu
# error : error
# diperbaiki : baik
# kendala : kendala
# status : status
# dikirim : kirim
# tujuan : tuju
# mantap : mantap
# sediakan : sedia
# foto : foto
# bukti : bukti
# nyabiar : nyabiar
# oh : oh
# taro : taro
# situ : situ
# kurir : kurir
# mengantarkan : antar
# alamat : alamat
# posisi : posisi
# aman : aman
# konfirmasi : konfirmasi
# mohon : mohon
# tingkat : tingkat
# aplikasinya : aplikasi
# memiliki : milik
# kompeten : kompeten
# payah : payah
# menghubungi : hubung
# susah : susah
# mencoba : coba
# kaitin : kaitin
# gagal : gagal
# aneh : aneh
# diakun : akun
# terikat : ikat
# bukalapaknya : bukalapaknya
# ngaktifin : ngaktifin
# bukapaylater : bukapaylater
# iya : iya
# layanan : layan
# lipat : lipat
# dibanding : banding
# lakukan : laku
# mengadakan : ada
# voucher : voucher
# plus : plus
# jdiny : jdiny
# maaftidak : maaftidak
# paylatter : paylatter
# bintang : bintang
# berbicara : bicara
# pengalaman : alam
# kagak : kagak
# pelatihan : latih
# prakerja : prakerja
# vocer : vocer
# valid : valid
# kontak : kontak
# diperbaharui : baharu
# jadwal : jadwal
# ridem : ridem
# sungguh : sungguh
# menyambung : sambung
# bertransaksi : transaksi
# lihat : lihat
# ulasan : ulas
# biar : biar
# jelek : jelek
# komplen : komplen
# csbarang : csbarang
# kurim : rim
# returdi : returdi
# jasa : jasa
# kirim : kirim
# veritifikasi : veritifikasi
# sandinya : sandi
# daftar : daftar
# sandi : sandi
# tulisannya : tulis
# serbu : serbu
# meleset : meleset
# uang : uang
# mentooog : mentooog
# keren : keren
# sayangtidak : sayangtidak
# saran : saran
# kasih : kasih
# hadiah : hadiah
# penghargaan : harga
# pelanggan : langgan
# pindah : pindah
# shoopee : shoopee
# janjinya : janji
# nyatasudah : nyatasudah
# diakui : aku
# member : member
# platinum : platinum
# estimasi : estimasi
# melenceng : lenceng
# kupon : kupon
# keamanan : aman
# sok : sok
# far : far
# good : good
# tingkatkan : tingkat
# kenyamanan : nyaman
# membantu : bantu
# depantapi : depantapi
# sayang : sayang
# ribu : ribu
# bulannya : bulan
# pakaiklo : pakaiklo
# ilangin : ilangin
# yalimit : yalimit
# bos : bos
# buka : buka
# memperaulitcall : memperaulitcall
# center : center
# terkesan : kes
# malas : malas
# menanggapi : tanggap
# keluhan : keluh
# pelanggansemua : pelanggansemua
# persyaratan : syarat
# dibpenuhichat : dibpenuhichat
# alihkanni : alihkanni
# bantuanmemalukan : bantuanmemalukan
# bermasalahga : bermasalahga
# pertqma : pertqma
# pertamani : taman
# kemari : kemari
# parahcall : parahcall
# centernya : centernya
# nihbuat : nihbuat
# halaman : halaman
# pemakai : pakai
# super : super
# seller : seller
# kuota : kuota
# dagangan : dagang
# jualannya : jual
# antik : antik
# unik : unik
# quota : quota
# diketerangan : terang
# promosi : promosi
# toko : toko
# sebelah : belah
# bodoh : bodoh
# mewajibkan : wajib
# tolol : tolol
# kebobolan : bobol
# pengajuan : aju
# pelapak : lapak
# nakal : nakal
# terkirim : kirim
# cepat : cepat
# bantun : bantun
# limit : limit
# bertambah : tambah
# semoga : moga
# oye : oye
# nyaman : nyaman
# ketemu : ketemu
# abal : abal
# menipu : tipu
# lapak : lapak
# turun : turun
# tangan : tangan
# menyelamatkan : selamat
# juta : juta
# terselamatkan : selamat
# sulit : sulit
# muter : muter
# penarikan : tari
# dompet : dompet
# pengaduan : adu
# slow : slow
# duit : duit
# bermasalah : masalah
# repot : repot
# susahnya : susah
# terkait : kait
# langganan : langgan
# difavoritkan : favorit
# searching : searching
# rubah : rubah
# apl : apl
# pahamipakai : pahamipakai
# pemula : mula
# tlong : tlong
# verifikasi : verifikasi
# data : data
# nomer : nomer
# nik : nik
# tnggal : tnggal
# lahir : lahir
# tolak : tolak
# wa : wa
# berguna : guna
# dihubungi : hubung
# penjualan : jual
# wahana : wahana
# resi : resi
# diupdate : diupdate
# batal : batal
# hubungi : hubung
# update : update
# dicek : cek
# manual : manual
# perjalanan : jalan
# token : token
# listrik : listrik
# melalu : lalu
# dibantu : bantu
# dipersulit : sulit
# permainan : main
# kah : kah
# mengambil : ambil
# hak : hak
# miliknya : milik
# orang : orang
# pikir : pikir
# mengerikan : keri
# diangap : diangap
# penjahat : jahat
# main : main
# bekukan : beku
# kredivo : kredivo
# dibekukan : beku
# akulaku : akulaku
# hati : hati
# toped : toped
# minim : minim
# jahat : jahat
# tambahan : tambah
# dirinci : dirinci
# pelacakan : lacak
# diantar : antar
# dikasih : kasih
# penerima : terima
# cod : cod
# keterima : terima
# diberitahu : diberitahu
# kedepannya : depan
# tanggap : tanggap
# retur : retur
# kode : kode
# otp : otp
# coba : coba
# masuk : masuk
# memasukkan : masuk
# disuruh : suruh
# upgrade : upgrade
# terpaksa : paksa
# belikan : belikan
# pantesan : pantesan
# merosot : merosot
# tukang : tukang
# nipu : nipu
# program : program
# sedih : sedih
# mitra : mitra
# andalkan : andal
# batalkan : batal
# efisien : efisien
# dibandingkan : banding
# kekurangan : kurang
# merk : merk
# alternatif : alternatif
# pt : pt
# mengakuisisi : akuisisi
# mengunakan : mengunakan
# smartphone : smartphone
# membuka : buka
# kepala : kepala
# pusing : pusing
# layoutnya : layoutnya
# berantakan : beranta
# xxx : xxx
# tampilan : tampil
# ponsel : ponsel
# aksesoris : aksesoris
# suku : suku
# cadang : cadang
# dll : dll
# penantan : penantan
# produknya : produk
# tampilkan : tampil
# rapi : rapi
# rekan : rekan
# bosan : bosan
# jenuh : jenuh
# melanjutkan : lanjut
# kesini : kesini
# seler : seler
# setatus : setatus
# kadang : kadang
# pembatalan : batal
# pemberitahuan : pemberitahuan
# tiktok : tiktok
# mah : mah
# halo : halo
# diproses : proses
# melampaui : lampau
# batas : batas
# membatalkan : batal
# dihubungichat : dihubungichat
# tokoselernya : tokoselernya
# pencerahannya : cerah
# sesuai : sesuai
# informasi : informasi
# hubungin : hubungin
# mencuri : curi
# pelayanan : layan
# kebawah : bawah
# nih : nih
# senang : senang
# ijo : ijo
# cashback : cashback
# ayo : ayo
# inovasiinovasi : inovasiinovasi
# kalah : kalah
# bekuin : bekuin
# baiknya : baik
# jalan : jalan
# bersaing : saing
# loh : loh
# tertinggal : tinggal
# pedagang : dagang
# tersambung : sambung
# tibatiba : tibatiba
# game : game
# memperpanjang : panjang
# umur : umur
# gulung : gulung
# tikar : tikar
# platform : platform
# jual : jual
# dikembalikan : kembali
# stok : stok
# habisdan : habisdan
# berdasarkan : dasar
# info : info
# verifikasinya : verifikasi
# nomor : nomor
# maksimal : maksimal
# ktp : ktp
# keteranganya : keteranganya
# hp : hp
# berbeda : beda
# memblokir : blokir
# mengatasnamakan : mengatasnamakan
# takut : takut
# disalahgunakan : disalahgunakan
# akses : akses
# memeberikan : memeberikan
# solusi : solusi
# buruk : buruk
# lunasi : lunas
# pakaitrus : pakaitrus
# jatuh : jatuh
# temponya : tempo
# lansung : lansung
# tanggal : tanggal
# sd : sd
# metode : metode
# bank : bank
# ocbc : ocbc
# nisp : nisp
# lwh : lwh
# pilihan : pilih
# kekelasan : kelas
# payletter : payletter
# rbbaru : rbbaru
# kalieeeengga : kalieeeengga
# lagiwk : lagiwk
# wkkok : wkkok
# yabl : yabl
# lambat : lambat
# pengirimannyahrs : pengirimannyahrs
# perbaikan : baik
# berbelanja : belanja
# kurangnya : kurang
# dipromo : dipromo
# jarang : jarang
# berat : berat
# terimakasih : terimakasih
# utakatik : utakatik
# detail : detail
# lazada : lazada
# shoppe : shoppe
# top : top
# up : up
# bayarkan : bayar
# atm : atm
# bri : bri
# struk : struk
# berhenti : henti
# masak : masak
# dibayar : bayar
# nunggunya : nunggunya
# rbuan : rbuan
# bermutu : mutu
# komplin : komplin
# diblokir : blokir
# ramai : ramai
# un : un
# install : install
# shopeelazada : shopeelazada
# bukalapakakin : bukalapakakin
# erorr : erorr
# sekalinya : sekali
# penjawab : jawab
# tanggung : tanggung
# makan : makan
# gaji : gaji
# buta : buta
# customer : customer
# mundur : mundur
# non : non
# aktifsaya : aktifsaya
# aktiftoko : aktiftoko
# systemnya : systemnya
# maintenance : maintenance
# membantusaat : membantusaat
# pulsatoken : pulsatoken
# mengatasi : atas
# cepatsemua : cepatsemua
# teratasi : atas
# memuaskanmaju : memuaskanmaju
# inovatif : inovatif
# penagihan : tagih
# lunas : lunas
# macet : macet
# aduh : aduh
# gercep : gercep
# nyambing : nyambing
# digital : digital
# dirugikan : rugi
# diuntungkan : untung
# mewq : mewq
# iinv : iinv
# pembelian : beli
# berkurang : kurang
# sialnya : sial
# besoknya : besok
# kadaluarsa : kadaluarsa
# anjir : anjir
# pembelikomplain : pembelikomplain
# bisatpi : bisatpi
# jasalancar : jasalancar
# motong : motong
# masalahpasti : masalahpasti
# komplainblm : komplainblm
# livechat : livechat
# dikhususkan : khusus
# ketinggalan : tinggal
# bandingkan : banding
# olshop : olshop
# kemudahan : mudah
# customernya : customernya
# dimudahkan : mudah
# apapun : apa
# mengganti : ganti
# gmail : gmail
# suruh : suruh
# sajah : sajah
# enak : enak
# bisnis : bisnis
# contoh : contoh
# biyaya : biyaya
# penanganan : tangan
# kes : kes
# modal : modal
# untung : untung
# untungnya : untung
# sebenar : benar
# cth : cth
# kemarin : kemarin
# ambil : ambil
# bareng : bareng
# hrg : hrg
# san : san
# pemesanan : mesan
# jutaan : juta
# asli : asli
# kacau : kacau
# bohongan : bohong
# bebayar : bebayar
# sebutin : sebutin
# complain : complain
# berteletele : berteletele
# layani : layan
# penukaran : tukar
# bikin : bikin
# ceria : ceria
# konfirmasitapi : konfirmasitapi
# sni : sni
# php : php
# tokoh : tokoh
# ntk : ntk
# mmbatalkan : mmbatalkan
# kmna : kmna
# mntak : mntak
# mhon : mhon
# sistim : sistim
# min : min
# pantasan : pantas
# sepi : sepi
# sebulan : bulan
# ditahan : tahan
# diteruskan : terus
# tekan : tekan
# dananya : dana
# oper : oper
# lapakbarang : lapakbarang
# minggu : minggu
# otomatislapor : otomatislapor
# penjualpenjual : penjualpenjual
# nyuruh : nyuruh
# terimabarang : terimabarang
# ditransfer : transfer
# bukannkesalahan : bukannkesalahan
# pembelibeda : pembelibeda
# dngn : dngn
# oren : oren
# estimadi : estimadi
# kembalibenar : kembalibenar
# gunakanhabis : gunakanhabis
# hilangkan : hilang
# pengguna : guna
# tulis : tulis
# belaku : bela
# refund : refund
# berbelitstatus : berbelitstatus
# diiterima : diiterima
# terkirimhati : terkirimhati
# bukalapakbaru : bukalapakbaru
# alami : alami
# juni : juni
# chattidak : chattidak
# pertanyataan : pertanyataan
# disediakan : sedia
# user : user
# mengirimkan : kirim
# poto : poto
# permanen : permanen
# pemakaian : pakai
# beralih : alih
# shoppy : shoppy
# maaf : maaf
# pesan : pesan
# membeli : beli
# enggak jelas : enggak jelas
# enggak tau : enggak tau
# pay : pay
# later : later
# oakai : oakai
# scam : scam
# uninstal : uninstal
# apli : apli
# allshop : allshop
# jelasaplikasi : jelasaplikasi
# busuk : busuk
# belanjanya : belanja
# gampang : gampang
# bayarnya : bayar
# livechatnya : livechatnya
# dimana : mana
# dilunasi : lunas
# telat : telat
# rumah : rumah
# lancar : lancar
# gantian : ganti
# tempo : tempo
# keterlambatan : lambat
# merasakan : rasa
# rasakan : rasa
# seenak : enak
# menyalahkan : salah
# pro : pro
# partai : partai
# rakyatlagi : rakyatlagi
# ruwt : ruwt
# ruwet : ruwet
# iklanhasilnya : iklanhasilnya
# manfaatatnya : manfaatatnya
# satupuntidak : satupuntidak
# laku : laku
# fakta : fakta
# initapi : initapi
# memuaskan : muas
# kualitas : kualitas
# tagihantagihan : tagihantagihan
# tv : tv
# kabel : kabel
# kasihan : kasihan
# konsumen : konsumen
# lumayan : lumayan
# nasabah : nasabah
# urgent : urgent
# memudahkan : mudah
# calon : calon
# mencari : cari
# dibutuhkan : butuh
# produsen : produsen
# mempromosikan : promosi
# terkendala : kendala
# jauhnya : jauh
# lokasi : lokasi
# dibukakapak : dibukakapak
# relatif : relatif
# mall : mall
# kaki : kaki
# jaringanlah : jaring
# jaringan : jaring
# full : full
# sngat : sngat
# terbukti : bukti
# dibeli : beli
# gambar : gambar
# video : video
# deskripsinya : deskripsi
# indonesia : indonesia
# mon : mon
# aktip : aktip
# akunku : akun
# perasaan : asa
# langgar : langgar
# device : device
# gonta : gonta
# aseli : aseli
# terhubung : hubung
# emosi : emosi
# kedaftargimana : kedaftargimana
# maksutnya : maksutnya
# order : order
# pulahadehbikin : pulahadehbikin
# sajaauto : sajaauto
# delete : delete
# pengaturan : atur
# ajakarna : ajakarna
# butuhkan : butuh
# bataldan : bataldan
# pesenan : sen
# rumit : rumit
# market : market
# ajukan : aju
# buyer : buyer
# artikel : artikel
# mulu : mulu
# bangkrut : bangkrut
# service : service
# terpakai : pakai
# mincara : mincara
# lupa : lupa
# pinseingat : pinseingat
# pin : pin
# memuaskantapi : memuaskantapi
# sayangkan : sayang
# ongkos : ongkos
# pengirimannya : kirim
# tinggal : tinggal
# banda : banda
# acehdi : acehdi
# mencapai : capai
# perkilonyapadahal : perkilonyapadahal
# semahal : mahal
# itupaling : itupaling
# an : an
# acehmohon : acehmohon
# pertimbangan : timbang
# acehmaunya : acehmaunya
# aceh : aceh
# inibelakangan : inibelakangan
# daerah : daerah
# sampainyadicoba : sampainyadicoba
# terusongkir : terusongkir
# bukaekpress : bukaekpress
# berattidak : berattidak
# shopbelanja : shopbelanja
# enggak ada : enggak ada
# pengaduanonline : pengaduanonline
# kenakalan : nakal
# penipuan : tipu
# pelapakseller : pelapakseller
# rentan : rentan
# venus : venus
# shop : shop
# on : on
# pengadua : pengadua
# sibuka : sibuka
# lapaknya : lapak
# tersedia : sedia
# tetangga : tetangga
# serviceny : serviceny
# bliblihari : bliblihari
# mesti : mesti
# bijak : bijak
# berisiko : risiko
# alhamdulillah : alhamdulillah
# menambah : tambah
# terima kasih : terima kasih
# sekian : sekian
# kecewasejauh : kecewasejauh
# menggaet : gaet
# minat : minat
# diturunkan : turun
# normal : normal
# kerenfitur : kerenfitur
# lengkap : lengkap
# komplit : komplit
# kirimdan : kirimdan
# jualan : jual
# mudahsemoga : mudahsemoga
# depannya : depan
# simpel : simpel
# pembeligood : pembeligood
# luck : luck
# sekalisemua : sekalisemua
# maju : maju
# sayasy : sayasy
# berkalikali : berkalikali
# nyabintang : nyabintang
# dilapak : lapak
# verivisi : verivisi
# sekaliganti : sekaliganti
# menyertakan : serta
# no : no
# rek : rek
# buku : buku
# tabungandengan : tabungandengan
# kiriman : kirim
# nyangkut : nyangkut
# expedisi : expedisi
# berkali : kali
# ditelusuri : telusur
# sakit : sakit
# sembuhnya : sembuh
# datangnya : datang
# separo : paro
# titip : titip
# jaminan : jamin
# paham : paham
# hack : hack
# curi : curi
# login : login
# jambi : jambi
# jakarta : jakarta
# amanan : aman
# membaca : baca
# janggalan : janggal
# pemilik : milik
# bodohnya : bodoh
# contak : contak
# pastikan : pasti
# viral : viral
# sebentar : sebentar
# bahasanya : bahasa
# adminnya : adminnya
# sopannya : sopan
# preman : preman
# penagihannya : tagih
# komen : komen
# tks : tks
# bingung : bingung
# mengasih : asih
# feedback : feedback
# tertulis : tulis
# tlol : tlol
# responya : responya
# upload : upload
# kurasi : kuras
# kategori : kategori
# kak : kak
# form : form
# file : file
# format : format
# xml : xml
# nanyain : nanyain
# komentar : komentar
# asyikasyiknya : asyikasyiknya
# nemu : nemu
# diincar : incar
# eh : eh
# popupiklan : popupiklan
# emas : emas
# mengganggu : ganggu
# beranda : beranda
# kedepan : depan
# banyakan : banyak
# popup : popup
# jujur : jujur
# pembiayaan : biaya
# penuh : penuh
# jebakan : jebak
# saing : saing
# orange : orange
# koid : koid
# perubahan : ubah
# charge : charge
# keberuntungan : untung
# puter : puter
# item : item
# money : money
# tiket : tiket
# kereta : kereta
# api : api
# enggak bisa : enggak bisa
# tolonglah : tolong
# benerin : benerin
# tunggu : tunggu
# log : log
# tertera : tera
# ah : ah
# setia : setia
# back : back
# out : out
# bisabolak : bisabolak
# ajatolong : ajatolong
# lapakbisa : lapakbisa
# kelar : kelar
# seharian : hari
# bolak : bolak
# blk : blk
# lunaspaylater : lunaspaylater
# apapunselalu : apapunselalu
# berhari : hari
# tersambungjawaban : tersambungjawaban
# agen : agen
# sibuk : sibuk
# parahpayah : parahpayah
# nge : nge
# freeze : freeze
# kompatible : kompatible
# android : android
# bro : bro
# dinperbaiki : dinperbaiki
# ganguan : ganguan
# pelanggam : langgam
# hadehh : hadehh
# adil : adil
# kga : kga
# story : story
# pending : pending
# terpilih : pilih
# seru : seru
# sebu : sebu
# nyata : nyata
# kirimkan : kirim
# serbuan : serbu
# refundnya : refundnya
# konplain : konplain
# komplainnya : komplain
# penyelesaian : selesai
# bukalapaksangat : bukalapaksangat
# digunaakan : digunaakan
# capek : capek
# fungsinya : fungsi
# pajangan : pajang
# doang : doang
# bagikan : bagi
# cetak : cetak
# prin : prin
# bluetooth : bluetooth
# terimkasih : terimkasih
# kesehatan : sehat
# kondisi : kondisi
# membaik : baik
# melaksanakan : laksana
# uangnya : uang
# refound : refound
# sekalichat : sekalichat
# bisaenakan : bisaenakan
# chip : chip
# shoppee : shoppee
# tertahan : tahan
# kapandulu : kapandulu
# pembatalansekarang : pembatalansekarang
# hilangapk : hilangapk
# puyeng : puyeng
# dibukak : dibukak
# tulisan : tulis
# kesalahan : salah
# memantau : pantau
# pergerakan : gera
# errorbarusan : errorbarusan
# notif : notif
# besok : besok
# pagi : pagi
# malam : malam
# terbayar : bayar
# kentut : kentut
# ngikngung : ngikngung
# betah : betah
# pelayanannya : layan
# komplan : komplan
# beberapakali : beberapakali
# kepotong : potong
# pengin : pengin
# kehilangan : hilang
# kpotong : kpotong
# link : link
# bkti : bkti
# trnper : trnper
# dipesen : sen
# kadarluarsa : kadarluarsa
# pelru : pelru
# perbaikian : perbaikian
# sangatembantu : sangatembantu
# melacak : lacak
# experssya : experssya
# mengecek : ecek
# kulir : kulir
# kekurangannya : kurang
# togel : togel
# keluarsudah : keluarsudah
# kembalibuka : kembalibuka
# sangatsangatsangatsangat : sangatsangatsangatsangat
# bergunasupersupersuper : bergunasupersupersuper
# parahselalu : parahselalu
# chatjawaban : chatjawaban
# pengecekan : kece
# bersabaryg : bersabaryg
# disalahkan : salah
# bankpadahal : bankpadahal
# dasar : dasar
# kesel : kesel
# mengajukan : aju
# emailnya : email
# lgsuruh : lgsuruh
# masukan : masuk
# pakaiuang : pakaiuang
# raib : raib
# maksudnya : maksud
# kontek : kontek
# bisaitu : bisaitu
# nipubuka : nipubuka
# burukwoy : burukwoy
# orgbalikin : orgbalikin
# stop : stop
# bermacammacam : bermacammacam
# bebas : bebas
# menarik : tarik
# buatkan : buat
# gkjelasudah : gkjelasudah
# spaylater : spaylater
# tidaksuruh : tidaksuruh
# wajahudah : wajahudah
# diverifikasi : verifikasi
# muka : muka
# jelastetap : jelastetap
# buramgakjeas : buramgakjeas
# arahan : arah
# ditutup : tutup
# diskusi : diskusi
# wkwkwk : wkwkwk
# vritualacount : vritualacount
# tagihansusah : tagihansusah
# jadinyagimana : jadinyagimana
# adapas : adapas
# agustussaya : agustussaya
# adatolong : adatolong
# servive : servive
# ditanggapin : ditanggapin
# uangku : uang
# stiker : stiker
# dikelompokkan : kelompok
# vareasi : vareasi
# motormobil : motormobil
# sekelas : kelas
# keuntungan : untung
# dipertimbangkan : timbang
# kurangi : kurang
# tab : tab
# untukk : untukk
# wawasan : wawas
# komponen : komponen
# mbelgedez : mbelgedez
# express : express
# tuju : tuju
# ta : ta
# trnsaksi : trnsaksi
# berhasilpulsa : berhasilpulsa
# masuktagihan : masuktagihan
# adakomplen : adakomplen
# diurus : urus
# mesin : mesin
# satunya : satu
# rampog : rampog
# paraaaaaaaahhhhh : paraaaaaaaahhhhh
# mengalami : alami
# kemunduranmasa : kemunduranmasa
# hahahhakatanya : hahahhakatanya
# menghindar : hindar
# komplainhahaha : komplainhahaha
# kocak : kocak
# inisaya : inisaya
# ajak : ajak
# ngobrolhahah : ngobrolhahah
# lucu : lucu
# bilang : bilang
# adaklau : adaklau
# sayaklau : sayaklau
# tidur : tidur
# mahalsekarang : mahalsekarang
# turunin : turunin
# harganya : harga
# ditemuakan : tua
# kejelasan : jelas
# kerja : kerja
# hafal : hafal
# hpnya : hpnya
# pasword : pasword
# otpnya : otpnya
# tertaut : taut
# kosong : kosong
# nancep : nancep
# tarik : tarik
# penjelasan : jelas
# srlalu : srlalu
# gagalada : gagalada
# solusinya : solusi
# tlpnya : tlpnya
# aktifsetiap : aktifsetiap
# jawabanya : jawabanya
# system : system
# kapok : kapok
# riwayat : riwayat
# alhasil : alhasil
# klaim : klaim
# gara : gara
# tukar : tukar
# kesan : kesan
# jualbeli : jualbeli
# persaingan : saing
# ketat : ketat
# ytpinmnrt : ytpinmnrt
# akubukalapak : akubukalapak
# mnjadinyg : mnjadinyg
# terbaik : baik
# terdepansemoga : terdepansemoga
# kdp : kdp
# ybukalapak : ybukalapak
# berkembang : kembang
# segi : segi
# pelayananpioritaskn : pelayananpioritaskn
# yagar : yagar
# bertransaksitrimakasih : bertransaksitrimakasih
# menangani : tangan
# batalin : batalin
# penyakitnya : sakit
# merasai : rasai
# indak : indak
# menerus : terus
# gajelasss : gajelasss
# terurus : urus
# terselesaikan : selesai
# denhan : denhan
# pantauan : pantau
# keyword : keyword
# saingan : saing
# promote : promote
# perfect : perfect
# menyediakan : sedia
# keliling : keliling
# manfaatin : manfaatin
# call : call
# diangkat : angkat
# ditelepon : telepon
# mati : mati
# motor : motor
# byson : byson
# onderdil : onderdil
# alhamdulilah : alhamdulilah
# ready : ready
# amplop : amplop
# template : template
# dosa : dosa
# lu : lu
# menahan : tahan
# rejeki : rejeki
# paraaaahhhh : paraaaahhhh
# mahalnya : mahal
# kg : kg
# pulau : pulau
# jawa : jawa
# jembersemarang : jembersemarang
# label : label
# diperbanyak : banyak
# bukalampak : bukalampak
# berjualan : jual
# betrasasi : betrasasi
# blanja : blanja
# pengembalian : kembali
# berfungsisy : berfungsisy
# butuh : butuh
# ajuin : ajuin
# komplainada : komplainada
# diarahin : diarahin
# pusat : pusat
# pembatalanpengembalian : pembatalanpengembalian
# payahmenyulitkan : payahmenyulitkan
# loading : loading
# ngulang : ngulang
# asuransi : asuransi
# kerusakan : rusa
# barangtapi : barangtapi
# rusak : rusak
# klaimnya : klaim
# ditolak : tolak
# bukalapakmending : bukalapakmending
# ajalebih : ajalebih
# terpercaya : percaya
# app : app
# menawarkan : tawar
# unlimited : unlimited
# perampok : rampok
# berkedok : kedok
# ok : ok
# murahselalu : murahselalu
# free : free
# lagidulu : lagidulu
# enakpaling : enakpaling
# versi : versi
# kantong : kantong
# repotstatus : repotstatus
# updatedi : updatedi
# kirimpembeli : kirimpembeli
# ngomelauto : ngomelauto
# off : off
# loyal : loyal
# lamasetiajarang : lamasetiajarang
# kurirnya : kurir
# pilihannya : pilih
# terjangkau : jangkau
# ramah : ramah
# semangat : semangat
# grtis : grtis
# asik : asik
# playlater : playlater
# menghubungkan : hubung
# danamohon : danamohon
# lapaklapak : lapaklapak
# bayak : bayak
# gagaluang : gagaluang
# danacukup : danacukup
# bukalapakmalah : bukalapakmalah
# merepotkan : repot
# bermanfaat : manfaat
# diskonfaucer : diskonfaucer
# potongnya : potong
# jaya : jaya
# tabungannya : tabung
# voucer : voucer
# total : total
# nominal : nominal
# auto : auto
# uninstall : uninstall
# kelalaian : lalai
# duluan : duluan
# kompetitor : kompetitor
# setting : setting
# maps : maps
# refresh : refresh
# mengulangi : ulang
# kebanyakan : banyak
# ekspedisi : ekspedisi
# bukasend : bukasend
# mengurus : urus
# dicairin : dicairin
# nominalnya : nominal
# topup : topup
# ikhlasin : ikhlasin
# pencarian : cari
# anehnya : aneh
# scrol : scrol
# smpek : smpek
# menutupi : tutup
# ongkirku : ongkirku
# dipotong : potong
# kemana : mana
# permasalahan : masalah
# heran : heran
# tidka : tidka
# mengerti : erti
# prihal : prihal
# payleter : payleter
# mentok : mentok
# oernah : oernah
# disediain : ain
# serasa : serasa
# ditipu : tipu
# ekspres : ekspres
# peniriman : peniriman
# bertanggung : tanggung
# kerugian : rugi
# materi : materi
# naikyg : naikyg
# mode : mode
# aga : aga
# benahi : benah
# sinyal : sinyal
# byar : byar
# diarahkan : arah
# menulis : tulis
# persulit : sulit
# ditemukanmakin : ditemukanmakin
# semenjak : semenjak
# canter : canter
# bantuannya : bantu
# mencewakan : mencewakan
# selsai : selsai
# benarbenar : benarbenar
# truss : truss
# hasil : hasil
# balesan : balesan
# bukalapakudah : bukalapakudah
# cekout : cekout
# payment : payment
# selesaitapidi : selesaitapidi
# nyaakhirnya : nyaakhirnya
# kemanaudah : kemanaudah
# sedikitkecewa : sedikitkecewa
# pesananselalu : pesananselalu
# tulusan : tulus
# lacak : lacak
# instal : instal
# paketnya : paket
# nyampek : nyampek
# statusnya : status
# berubah : ubah
# ku : ku
# juli : juli
# rupa : rupa
# hitung : hitung
# gandakan : ganda
# pintar : pintar
# rekom : rekom
# ppob : ppob
# pokok : pokok
# brisaldo : brisaldo
# bayarparah : bayarparah
# ajaudh : ajaudh
# cuihhh : cuihhh
# hape : hape
# bajak : bajak
# pembajak : bajak
# turunkan : turun
# satusaya : satusaya
# kenakan : kena
# anehjelas : anehjelas
# knapa : knapa
# sekalimohon : sekalimohon
# infonya : info
# verifikasigak : verifikasigak
# lemot : lot
# nyamantidak : nyamantidak
# bukalapakselain : bukalapakselain
# mahalada : mahalada
# bebankanmending : bebankanmending
# benermending : benermending
# tujuansudah : tujuansudah
# jamannya : jaman
# muat : muat
# trakhir : trakhir
# apknya : apknya
# blapak : blapak
# namanya : nama
# berfungsi : fungsi
# orderan : order
# whatsapp : whatsapp
# tetapkan : tetap
# expedisinya : expedisinya
# ditunda : tunda
# ngambil : ngambil
# profesional : profesional
# kerjanya : kerja
# post : post
# ditokopedia : ditokopedia
# poduk : poduk
# brng : brng
# seperri : seperri
# seblum : seblum
# kecewapesan : kecewapesan
# bukaexpress : bukaexpress
# waktueh : waktueh
# sicepat : sicepat
# halu : halu
# sepuluh : puluh
# sementarasebelum : sementarasebelum
# diterimasaya : diterimasaya
# lho : lho
# transaksasi : transaksasi
# rewelkomplain : rewelkomplain
# dibodohi : bodoh
# dibohongi : bohong
# menampilkan : tampil
# onderdilpart : onderdilpart
# pretelan : pretel
# cuci : cuci
# evaluasi : evaluasi
# inimungkin : inimungkin
# option : option
# tersendiri : sendiri
# part : part
# wajar : wajar
# kuotanya : kuota
# diskonnya : diskon
# balikin : balikin
# vouchernya : vouchernya
# gua : gua
# sebagus : bagus
# aturan : atur
# iklanin : iklanin
# serius : serius
# unggul : unggul
# sukamudah : sukamudah
# ndk : ndk
# dijemput : jemput
# dichat : dichat
# mengecewakan : kecewa
# dirumahterimakasih : dirumahterimakasih
# barangbarang : barangbarang
# ongkirn : ongkirn
# codnya : codnya
# dibatasin : dibatasin
# belnja : belnja
# ratusan : ratus
# mendapati : dapat
# praktisbukalapak : praktisbukalapak
# berulangkali : berulangkali
# variasi : variasi
# editdihapusdiganti : editdihapusdiganti
# deskripsi : deskripsi
# cantumkan : cantum
# lapor : lapor
# bergantung : gantung
# blokir : blokir
# virtualaccount : virtualaccount
# memakai : pakai
# acount : acount
# seribu : ribu
# menempel : tempel
# haduhhudah : haduhhudah
# unistal : unistal
# indah : indah
# cache : cache
# kebuka : buka
# bentar : bentar
# play : play
# store : store
# sms : sms
# pesaing : saing
# canggihbisa : canggihbisa
# ajakan : aja
# rendah : rendah
# tagihansaya : tagihansaya
# kualitasnya : kualitas
# jangkauan : jangkau
# luas : luas
# pandangan : pandang
# salam : salam
# bahagia : bahagia
# cinta : cinta
# keluarga : keluarga
# malaikat : malaikat
# allah : allah
# ganteng : ganteng
# sedunia : dunia
# dilaporkan : lapor
# kementerian : menteri
# perdagangan : dagang
# masyarakat : masyarakat
# respect : respect
# korban : korban
# berulang : ulang
# bbrapa : bbrapa
# terpantau : pantau
# sanggar : sanggar
# tida : tida
# konek : konek
# diam : diam
# ditempat : tempat
# inisiatif : inisiatif
# menaikkan : naik
# naikin : naikin
# superseller : superseller
# menutup : tutup
# mp : mp
# ngeluh : ngeluh
# manajemen : manajemen
# memahami : paham
# catatan : catat
# sellernya : sellernya
# editan : edit
# puluhan : puluh
# kejadian : jadi
# merekomendasikan : rekomendasi
# kerabat : kerabat
# aktifin : aktifin
# diaktifkan : aktif
# penjelasannya : jelas
# gunakankan : gunakankan
# dm : dm
# balas : balas
# ongkirskalinya : ongkirskalinya
# is : is
# the : the
# best : best
# bernama : nama
# puji : puji
# memutuskan : putus
# sambungan : sambung
# diputuskan : putus
# berdebat : debat
# pertahankan : tahan
# siang : siang
# kecamatan : camat
# mudahan : mudah
# dicari : cari
# lapaklebih : lapaklebih
# pelapaknya : lapak
# lamaaaa : lamaaaa
# pengirim : kirim
# negeri : negeri
# terusuntuk : terusuntuk
# lamaperlu : lamaperlu
# resmi : resmi
# nyapengiriman : nyapengiriman
# melambat : lambat
# intinya : inti
# puasini : puasini
# team : team
# pelapakada : pelapakada
# solusifitur : solusifitur
# mutarmuter : mutarmuter
# pilih : pilih
# agustus : agustus
# anjer : anjer
# dibulan : bulan
# dipenjualan : jual
# connection : connection
# reset : reset
# lainys : lainys
# selesaikan : selesai
# jawabannya : jawab
# terprogram : program
# place : place
# ampasss : ampasss
# bantuanya : bantuanya
# bisanya : bisa
# kepastian : pasti
# ampasssss : ampasssss
# mempermudah : mudah
# aplikasinyakomplit : aplikasinyakomplit
# adadan : adad
# ancurrrrr : ancurrrrr
# anehmeneruskan : anehmeneruskan
# pilapak : pilapak
# klga : klga
# reseller : reseller
# antrean : antre
# samle : samle
# diantrean : antre
# praktis : praktis
# puassssssssssssssbanget : puassssssssssssssbanget
# diharapkan : harap
# ragu : ragu
# terjamin : jamin
# amanah : amanah
# wajib : wajib
# pushiklan : pushiklan
# sehat : sehat
# duitpun : duit
# banyakk : banyakk
# expres : expres
# leletmending : leletmending
# ajaga : ajaga
# mengurusi : urus
# expedisiapa : expedisiapa
# bekasi : bekas
# karawang : karawang
# nyampebangke : nyampebangke
# muraspantasnya : muraspantasnya
# trx : trx
# terakhirgag : terakhirgag
# dahlebih : dahlebih
# bukanya : buka
# ketimbang : ketimbang
# bangetpencarian : bangetpencarian
# promonya : promonya
# merubah : rubah
# hilangakan : hilangakan
# situs : situs
# baguspengiriman : baguspengiriman
# cepatbarang : cepatbarang
# tiada : tiada
# berinovasi : inovasi
# semangatsemangat : semangatsemangat
# laporkan : lapor
# kepelapak : lapak
# buakalapak : buakalapak
# maling : maling
# melulu : melulu
# kebnyakan : kebnyakan
# vocher : vocher
# ongkirapk : ongkirapk
# bukanyaa : bukanyaa
# jauhpadahal : jauhpadahal
# peminatnya : minat
# akunotp : akunotp
# masukvie : masukvie
# masukbolak : masukbolak
# capca : capca
# orisinal : orisinal
# bangkelimit : bangkelimit
# utuh : utuh
# belanjain : belanjain
# iklannya : iklan
# peasana : peasana
# sesuaipembeli : sesuaipembeli
# pengembalianpadahal : pengembalianpadahal
# penjualdimana : penjualdimana
# servis : servis
# handphonerugi : handphonerugi
# waktuuang : waktuuang
# perangkatnya : perangkat
# kelartolong : kelartolong
# perhatikan : perhati
# sesiusterima : sesiusterima
# tunggakan : tunggak
# donwload : donwload
# ukuran : ukur
# ngeprint : ngeprint
# printer : printer
# thermal : thermal
# bntuan : bntuan
# tokped : tokped
# jelekk : jelekk
# ngelag : ngelag
# bangkitlah : bangkit
# orenny : orenny
# membatasi : batas
# jayadan : jayadan
# taaii : taaii
# sussah : sussah
# laman : laman
# trsedia : trsedia
# mkstnya : mkstnya
# paylter : paylter
# hlaman : hlaman
# goblok : goblok
# harapkan : harap
# penambahan : tambah
# berhak : hak
# cocok : cocok
# okee : okee
# startegi : startegi
# memancing : pancing
# bkalapak : bkalapak
# rebu : rebu
# payaater : payaater
# payater : payater
# gambarpacking : gambarpacking
# belaja : baja
# harcur : harcur
# terys : terys
# penguna : penguna
# gifwey : gifwey
# donlowd : donlowd
# ngabisin : ngabisin
# bagusan : bagus
# bukajadinya : bukajadinya
# kitapd : kitapd
# bayarsdh : bayarsdh
# transfergimana : transfergimana
# diupload : diupload
# diberubah : ubah
# tersaingi : saing
# ubah : ubah
# stoknya : stok
# melanggar : langgar
# tersebutdan : tersebutdan
# photo : photo
# ciplakmakin : ciplakmakin
# menurun : turun
# aplakasi : aplakasi
# ngisi : ngisi
# mengecewa : kecewa
# arah : arah
# mengetik : etik
# beralamat : alamat
# jauhsetidaknya : jauhsetidaknya
# membantusukses : membantusukses
# menylelesaikan : menylelesaikan
# packing : packing
# cepatgoodjob : cepatgoodjob
# ambang : ambang
# kehancuran : hancur
# secepatnya : cepat
# semangkin : semangkin
# padehal : padehal
# kemjuan : kemjuan
# banding : banding
# tabah : tabah
# letoy : letoy
# enakan : enak
# lada : lada
# tmbahantrus : tmbahantrus
# tertipu : tipu
# sepeda : sepeda
# isnawati : isnawati
# byrkan : byrkan
# penipudn : penipudn
# selektif : selektif
# memilih : pilih
# krj : krj
# gajls : gajls
# by : by
# koreksi : koreksi
# laahh : laahh
# ajatrs : ajatrs
# trtera : trtera
# ceklis : ceklis
# satutrs : satutrs
# disitu : situ
# pnjualy : pnjualy
# penipubkn : penipubkn
# budegpura : budegpura
# ingatanpokok : ingatanpokok
# pdagang : pdagang
# brkliaran : brkliaran
# mantab : mantab
# sgr : sgr
# atasi : atas
# siiip : siiip
# tooooopp : tooooopp
# biru : biru
# sibiru : sibiru
# subsidi : subsidi
# melimpah : limpah
# sensitif : sensitif
# kesekian : sekian
# kalinya : kali
# professional : professional
# buatlah : buat
# customers : customers
# terbaiksangat : terbaiksangat
# lapakdan : lapakdan
# kota : kota
# trimakasih : trimakasih
# transaksierror : transaksierror
# perbaikitidak : perbaikitidak
# bis : bis
# histori : histori
# barangthanks : barangthanks
# babi : babi
# ngotak : ngotak
# anjink : anjink
# checkout : checkout
# biayanya : biaya
# rban : rban
# dagang : dagang
# pasaran : pasar
# cp : cp
# of : of
# duty : duty
# mobile : mobile
# naikan : naik
# kabur : kabur
# mintabtolong : mintabtolong
# batalinnatau : batalinnatau
# otw : otw
# developer : developer
# compalin : compalin
# dulumasa : dulumasa
# gliran : gliran
# sue : sue
# minga : minga
# lapa : lapa
# prioritas : prioritas
# majuuuuuuu : majuuuuuuu
# binggung : binggung
# kebaikan : baik
# pokoknya : pokok
# datengin : datengin
# omong doang : omong doang
# kerjain : kerjain
# terbaru : baru
# kiamat : kiamat
# duitnya : duit
# jne : jne
# updatesudah : updatesudah
# apapa : apapa
# bantu : bantu
# masukkan : masuk
# tulisanya : tulisanya
# berlaku : laku
# belanjaan : belanja
# memaksakan : paksa
# pentingmending : pentingmending
# dah : dah
# sadar : sadar
# guaudh : guaudh
# kenamasa : kenamasa
# ngutang : ngutang
# dobel : dobel
# dikonter : konter
# guaga : guaga
# untungyamending : untungyamending
# apldibukalapak : apldibukalapak
# payleternya : payleternya
# biayalayanan : biayalayanan
# pembeliancukup : pembeliancukup
# lagibayar : lagibayar
# kebangetan : banget
# contol : contol
# tol : tol
# tolollll : tolollll
# instan : instan
# menyelesaikan : selesai
# belanjaanya : belanjaanya
# kirimnya : kirim
# sampekalah : sampekalah
# akh : akh
# aplikasigak : aplikasigak
# persyaratannya : syarat
# jadual : jadual
# dijanjikan : janji
# kemasan : kemas
# masuknya : masuk
# mengadu : adu
# foucher : foucher
# kirimjt : kirimjt
# digunakanpadahal : digunakanpadahal
# adagimana : adagimana
# gan : gan
# ditaukan : tau
# walleteh : walleteh
# ludeskok : ludeskok
# cepatsat : cepatsat
# set : set
# rekomendet : rekomendet
# teknik : teknik
# okpelapak : okpelapak
# admintmantap : admintmantap
# steam : steam
# wallet : wallet
# redeem : redeem
# codenya : codenya
# terpercayatercepat : terpercayatercepat
# gunakansukses : gunakansukses
# menang : menang
# memikirkan : pikir
# maunya : mau
# bukalpak : bukalpak
# terussayang : terussayang
# mahalan : mahal
# dikittapi : dikittapi
# apalah : apa
# pokoe : pokoe
# jozz : jozz
# trik : trik
# modus : modus
# search : search
# engine : engine
# google : google
# tersediamemang : tersediamemang
# dihati : hati
# kadaluwarsa : kadaluwarsa
# jelass : jelass
# kinerja : kerja
# pembelanjaan : belanja
# playlaternya : playlaternya
# dendanya : denda
# penggunanya : guna
# airlistrik : airlistrik
# bedanya : beda
# layanansama : layanansama
# custamerknpa : custamerknpa
# membedakan : beda
# katanyabayar : katanyabayar
# listri : listri
# conter : conter
# layanin : layanin
# orangnyamemang : orangnyamemang
# manusia : manusia
# harta : harta
# air : air
# bulalapak : bulalapak
# mengikuti : ikut
# misi : misi
# caranyaini : caranyaini
# mengaco : aco
# haridigunain : haridigunain
# bisacoba : bisacoba
# jelaskansampe : jelaskansampe
# ditagih : tagih
# bukalapaksedangkan : bukalapaksedangkan
# gagalaneh : gagalaneh
# menguntungkanyg : menguntungkanyg
# tersendiridan : tersendiridan
# ifennya : ifennya
# loging : loging
# donlow : donlow
# pacebok : pacebok
# geugle : geugle
# eee : eee
# dikonfirmasi : konfirmasi
# donwlod : donwlod
# pemesanansaya : pemesanansaya
# kecewasaya : kecewasaya
# inibukalapak : inibukalapak
# wadah : wadah
# dinyatakan : nyata
# mengutamakan : utama
# penggunaan : guna
# limitnya : limit
# sisa : sisa
# bisaslalu : bisaslalu
# otomatisketerangan : otomatisketerangan
# pembatalannya : batal
# dibatalkanseakan : dibatalkanseakan
# batalkanpadahal : batalkanpadahal
# potong : potong
# kedaluarsa : kedaluarsa
# disaat : saat
# penjualanpembatalan : penjualanpembatalan
# nyanotif : nyanotif
# pencariannya : cari
# ikan : ikan
# hias : hias
# pakan : pakan
# ganggu : ganggu
# minusnya : minus
# memenuhi : penuh
# aplikais : aplikais
# upraged : upraged
# jualanannya : jualanannya
# membela : bela
# kepentingan : penting
# menjanjikan : janji
# mematikan : mati
# obrolannya : obrol
# hangus : hangus
# kyc : kyc
# sory : sory
# ane : ane
# join : join
# kesana : kesana
# koleksinya : koleksi
# berbulan : bulan
# stagnan : stagnan
# greget : greget
# ol : ol
# bukalapakygdulu : bukalapakygdulu
# dipilih : pilih
# zonk : zonk
# mengapai : kapai
# kepercayan : kepercayan
# ecom : ecom
# utama : utama
# aktifasi : aktifasi
# sumpah : sumpah
# enek : enek
# sefty : sefty
# lo : lo
# nyataanya : nyataanya
# nomornya : nomor
# aktivasi : aktivasi
# syaratnya : syarat
# pinjaman : pinjam
# sumpaah : sumpaah
# oohh : oohh
# devlover : devlover
# lebay : lebay
# commerce : commerce
# worth : worth
# sampainya : sampai
# pengembang : kembang
# halamannya : halaman
# stabil : stabil
# dikirimkan : kirim
# ktprekening : ktprekening
# seribet : seribet
# cantumin : cantumin
# tipenyasaya : tipenyasaya
# validpadahal : validpadahal
# kesal : kesal
# memproses : proses
# bst : bst
# pasan : pas
# muterin : muterin
# berakibat : akibat
# tsbt : tsbt
# matikan : mati
# menunya : menu
# simple : simple
# pahami : paham
# lemottnya : lemottnya
# bukaemas : bukaemas
# problemnya : problem
# bad : bad
# gateway : gateway
# kayaknya : kayak
# investasi : investasi
# dibikin : bikin
# credit : credit
# ketentuan : tentu
# ketahui : tahu
# didownload : didownload
# touch : touch
# az : az
# beku : beku
# baned : baned
# feed : feed
# gede : gede
# ajabanyak : ajabanyak
# sisrem : sisrem
# gunabuka : gunabuka
# ajaisi : ajaisi
# harap : harap
# ajadan : ajadan
# bagusmasuk : bagusmasuk
# ribetnya : ribetnya
# bantuannyasaya : bantuannyasaya
# kesulitan : sulit
# logindikarenakan : logindikarenakan
# aktifmau : aktifmau
# sayadan : sayadan
# bukalapakmohon : bukalapakmohon
# mempersulit : sulit
# ribuan : ribu
# cumq : cumq
# tampil : tampil
# temukan : temu
# gaya : gaya
# pengunjung : unjung
# kadaluarsamau : kadaluarsamau
# fiturnya : fiturnya
# nonaktif : nonaktif
# dear : dear
# check : check
# pesana : sana
# perhatiannya : perhati
# menggangu : menggangu
# dengar : dengar
# dibalas : balas
# april : april
# mls : mls
# woi : woi
# cicilan : cicil
# perbanyak : banyak
# beban : beban
# and : and
# dipiara : piara
# perihal : perihal
# event : event
# bukatabungan : bukatabungan
# menggundang : gundang
# dalem : dalem
# detik : detik
# canggih : canggih
# dikomplain : komplain
# sadah : sadah
# kembaliini : kembaliini
# kepastianpayah : kepastianpayah
# kekurir : kurir
# sudahlama : sudahlama
# kayanya : kaya
# berasa : asa
# tabungan : tabung
# fiture : fiture
# moga : moga
# left : left
# seenaknyalangsg : seenaknyalangsg
# percakapan : cakap
# percakapanjadi : percakapanjadi
# kebelakang : belakang
# antrian : antri
# nutup : nutup
# trecking : trecking
# snapdragon : snapdragon
# gen : gen
# ram : ram
# gb : gb
# clear : clear
# chace : chace
# logout : logout
# server : server
# editsaat : editsaat
# bisakalau : bisakalau
# pelosokmungkintapi : pelosokmungkintapi
# lainsaya : lainsaya
# manualtanpa : manualtanpa
# gpssaya : gpssaya
# kecewakarena : kecewakarena
# berbelanjatapi : berbelanjatapi
# dam : dam
# halapalagi : halapalagi
# sistemnyakecewa : sistemnyakecewa
# pemilihan : pilih
# report : report
# bermasalahpaket : bermasalahpaket
# kompensasi : kompensasi
# kembalihanya : kembalihanya
# slogan : slogan
# belakabagaimana : belakabagaimana
# susupin : susupin
# pasang : pasang
# separuhnya : paruh
# realpict : realpict
# ajalihat : ajalihat
# history : history
# mainnumpuk : mainnumpuk
# diserver : diserver
# akunbuatlah : akunbuatlah
# penyimpanan : simpan
# buset : buset
# ditemukan : temu
# hebat : hebat
# lenya : lenya
# manapun : mana
# fee : fee
# lainnyamataap : lainnyamataap
# gunawan : gunawan
# bukalapk : bukalapk
# tautpi : tautpi
# gramdi : gramdi
# kgdan : kgdan
# ahirnya : ahirnya
# sayagak : sayagak
# ijoklo : ijoklo
# ampas : ampas
# sellerseller : sellerseller
# bertanggungjawab : bertanggungjawab
# ujungnya : ujung
# lepas : lepas
# aa : aa
# kakak : kakak
# ktpno : ktpno
# telphone : telphone
# membuktikan : bukti
# tertata : tata
# batasi : batas
# pepalak : palak
# kompalain : kompalain
# tpdiketangan : tpdiketangan
# terdaftar : daftar
# lainemang : lainemang
# daptar : daptar
# alikasi : alikasi
# yahsangat : yahsangat
# membingungkanlangsung : membingungkanlangsung
# kecewadimana : kecewadimana
# codtapi : codtapi
# menyesak : sesak
# sgitu : sgitu
# tuhklo : tuhklo
# kepakasa : kepakasa
# saking : saking
# belu : belu
# cairkan : cair
# hadehhh : hadehhh
# gunanya : guna
# payleater : payleater
# bukalapaksaya : bukalapaksaya
# tagih : tagih
# lagibukti : lagibukti
# struknya : struknya
# kasir : kasir
# indomart : indomart
# yeah : yeah
# tagihantapi : tagihantapi
# star : star
# memberatkan : berat
# itemku : item
# higs : higs
# domino : domino
# menerapkan : terap
# transaksinya : transaksi
# peforma : forma
# huhuhuuuuu : huhuhuuuuu
# sekalai : sekala
# kompin : kompin
# kerjasama : kerjasama
# beres : beres
# mempertanggungjawabkan : mempertanggungjawabkan
# didunia : dunia
# akherat : akherat
# bsi : bsi
# shrusnya : shrusnya
# fitr : fitr
# lngsng : lngsng
# dinonaktifkan : nonaktif
# januari : januari
# jugasudah : jugasudah
# tanggapi : tanggap
# bukalapaksungguh : bukalapaksungguh
# ribeettt : ribeettt
# reg : reg
# day : day
# pick : pick
# lelet : lelet
# criss : criss
# cross : cross
# sop : sop
# ybs : ybs
# kepercayaan : percaya
# permudah : mudah
# andalan : andal
# way : way
# diklik : klik
# kompak : kompak
# fungsi : fungsi
# tindak : tindak
# agt : agt
# pengoperasian : operasi
# urusan : urus
# profil : profil
# des : des
# ajib : ajib
# fiturfiturnya : fiturfiturnya
# desain : desain
# layar : layar
# mjnta : mjnta
# onlinekonformasi : onlinekonformasi
# dlluegk : dlluegk
# pmbeeli : pmbeeli
# jelaspercuma : jelaspercuma
# limite : limite
# transaksinyesel : transaksinyesel
# belanjajelas : belanjajelas
# sekaliperdetik : sekaliperdetik
# uninstalmakasih : uninstalmakasih
# serba : serba
# tokonya : toko
# mengenali : nali
# beliau : beliau
# sayabagi : sayabagi
# digitalpelapak : digitalpelapak
# curang : curang
# terimacobalah : terimacobalah
# komplainsampai : komplainsampai
# teruskan : terus
# pelapakbats : pelapakbats
# berjalanterus : berjalanterus
# nyalewat : nyalewat
# jelasssbuat : jelasssbuat
# bisapulsa : bisapulsa
# bisahanya : bisahanya
# bagusmemuaskan : bagusmemuaskan
# dikala : kala
# membutuhkan : butuh
# hubungkan : hubung
# aplkasi : aplkasi
# iniakun : iniakun
# vcr : vcr
# berhati : hati
# mendewakan : dewa
# ekpedisi : ekpedisi
# quicksend : quicksend
# cash : cash
# lom : lom
# jawabannyacoba : jawabannyacoba
# tanggepin : tanggepin
# tentui : tentu
# jgbuat : jgbuat
# bantumakin : bantumakin
# chatlemot : chatlemot
# tele : tele
# lag : lag
# memperbaiki : baik
# karuan : karuan
# paylatternya : paylatternya
# bertahun : tahun
# dibenahi : benah
# boongan : boongan
# jnt : jnt
# nyantumin : nyantumin
# pembohong : bohong
# ribetkl : ribetkl
# selamat : selamat
# jutabegitu : jutabegitu
# cekoutpembayaran : cekoutpembayaran
# ditolakaneh : ditolakaneh
# bertahan : tahan
# kompetitornya : kompetitor
# yuk : yuk
# buruan : buru
# konsisten : konsisten
# timbul : timbul
# tenggelam : tenggelam
# hehee : hehee
# semacem : semacem
# tlng : tlng
# terkaitdevelop : terkaitdevelop
# dikecewain : dikecewain
# ket : ket
# meningkat : tingkat
# sarannya : saran
# mmbeli : mmbeli
# sayapadahal : sayapadahal
# inipadahal : inipadahal
# pinbiasanya : pinbiasanya
# sajapadahal : sajapadahal
# sabar : sabar
# siniudah : siniudah
# ngetikpas : ngetikpas
# jdinya : jdinya
# terimatpi : terimatpi
# reportnya : reportnya
# bingungmo : bingungmo
# pasrah : pasrah
# tanggapin : tanggapin
# screenshoot : screenshoot
# mautanya : mautanya
# terkecuali : kecuali
# transit : transit
# penutupan : tutup
# tanggapinnya : tanggapinnya
# formulir : formulir
# permohonan : mohon
# terlambat : lambat
# tagihannya : tagih
# terlanjur : lanjur
# kelain : lain
# hatikayaknya : hatikayaknya
# historikalaupun : historikalaupun
# thok : thok
# penambahanknpa : penambahanknpa
# kwalitas : kwalitas
# byr : byr
# vamandiri : vamandiri
# pembyran : pembyran
# ditarik : tarik
# transferpenarikkan : transferpenarikkan
# premium : premium
# selepas : lepas
# mendesakharusnya : mendesakharusnya
# kembalibagaimanapun : kembalibagaimanapun
# bldah : bldah
# ulangi : ulang
# samatapi : samatapi
# ngemis : ngemis
# rating : rating
# kuturunin : kuturunin
# algoritma : algoritma
# dibenerin : dibenerin
# permisi : permisi
# paylternya : paylternya
# ayolah : ayo
# penipunya : tipu
# diakses : akses
# mudahmudahan : mudahmudahan
# saudara : saudara
# card : card
# aplikasih : aplikasih
# opsi : opsi
# dicetak : cetak
# helooo : helooo
# syaa : syaa
# driver : driver
# friendly : friendly
# menyulitkan : sulit
# penilain : penilain
# kenpa : kenpa
# yaakun : yaakun
# why : why
# bukareksauang : bukareksauang
# setatusy : setatusy
# selesaidikomplen : selesaidikomplen
# transfermasuk : transfermasuk
# belbel : belbel
# terusruwed : terusruwed
# dibajak : bajak
# kartu : kartu
# bukalapakeh : bukalapakeh
# suami : suami
# jutamasa : jutamasa
# bajakhrsny : bajakhrsny
# pesanannyakan : pesanannyakan
# flashdeal : flashdeal
# belinya : beli
# shake : shake
# thon : thon
# dapatnya : dapat
# thx : thx
# telusur : telusur
# kunci : kunci
# merek : merek
# official : official
# brand : brand
# mantappertahankan : mantappertahankan
# tipu : tipu
# bukalapakpaylater : bukalapakpaylater
# pkknya : pkknya
# sekalisukses : sekalisukses
# membingungkan : bingung
# melunasi : lunas
# ditinjau : tinjau
# dc : dc
# screen : screen
# shot : shot
# menagih : tagih
# ditindak : tindak
# lanjuti : lanjut
# minimal : minimal
# orentiktok : orentiktok
# layak : layak
# disana : sana
# wkwk : wkwk
# paras : paras
# diamon : diamon
# gamenya : gamenya
# gamenyatolong : gamenyatolong
# munculin : munculin
# diamonnya : diamonnya
# pliss : pliss
# loadingnya : loadingnya
# hang : hang
# selebihnya : lebih
# ceritanya : cerita
# boskuh : boskuh
# bari : bari
# dikirm : dikirm
# nyampai : nyampai
# aktiv : aktiv
# memilah : mem
# dadi : dadi
# action : action
# ribumending : ribumending
# sejarah : sejarah
# pejual : jual
# jugasedangkan : jugasedangkan
# gunakanharus : gunakanharus
# mengadutolong : mengadutolong
# lapakbiar : lapakbiar
# mengadukan : adu
# ringan : ringan
# menarim : menarim
# danakenapa : danakenapa
# penarikannya : tari
# bangetharus : bangetharus
# danapoto : danapoto
# rekam : rekam
# wajah : wajah
# minknp : minknp
# vidio : vidio
# kecuali : kecuali
# masalahsudah : masalahsudah
# hasilnya : hasil
# keluarketika : keluarketika
# putus : putus
# nyakalo : nyakalo
# menggu : menggu
# yohana : yohana
# bersabar : sabar
# nunggusaaya : nunggusaaya
# ...
# bukalapakbukabantuan : bukalapakbukabantuan
# berfungsikembalikan : berfungsikembalikan
# pertanggung : tanggung
# sarangnya : sarang
# konyol : konyol
# bermamfaat : bermamfaat
# tlpon : tlpon
# mendesak : desak
# bravo : bravo
# lebihlebih : lebihlebih
# seharus : harus
# es : es
# batu : batu
# biarkan : biar
# memudahkn : memudahkn
# dengn : dengn
# pekerjaan : kerja
# parahcs : parahcs
# bertangtung : bertangtung
# jawabcancel : jawabcancel
# susahgk : susahgk
# mantaaappppp : mantaaappppp
# buklapak : buklapak
# berpihak : pihak
# curangtipu : curangtipu
# ilegal : ilegal
# nanggung : nanggung
# depok : depok
# kalimantan : kalimantan
# diasuransikan : asuransi
# admincs : admincs
# sulitcuek : sulitcuek
# sia : sia
# kunjungan : kunjung
# pendapatan : dapat
# phk : phk
# karyawan : karyawan
# lestari : lestari
# jakbar : jakbar
# mengemas : emas
# area : area
# cempaka : cempaka
# akibatnya : akibat
# pinasa : pinasa
# kaos : kaos
# logintiba : logintiba
# bertransaksinyacepat : bertransaksinyacepat
# yrus : yrus
# dilengkapi : lengkap
# terimakasihhh : terimakasihhh
# dipesan : pes
# dengarkan : dengar
# saka : saka
# tercepat : cepat
# novita : novita
# sari : sari
# peserta : serta
# mentor : mentor
# memotivasi : motivasi
# mengembangkan : kembang
# potensi : potensi
# miliki : milik
# digunakangak : digunakangak
# parahgak : parahgak
# tahi : tahi
# samapai : samapai
# hoyy : hoyy
# setan : setan
# assalamualaikum : assalamualaikum
# membelih : membelih
# berjudul : judul
# kuasai : kuasa
# nlp : nlp
# pelatihannya : latih
# ditoko : toko
# orangehijau : orangehijau
# optimalkan : optimal
# deal : deal
# jenis : jenis
# optimalisasi : optimalisasi
# membentuk : bentuk
# mobil : mobil
# filternya : filter
# ikonik : ikonik
# vita : vita
# membelinya : bel
# tema : tema
# menarikedukatif : menarikedukatif
# inspiratif : inspiratif
# pencarinya : pencar
# difilter : filter
# lakunya : laku
# webnya : webnya
# memverifikasi : verifikasi
# aslipadahal : aslipadahal
# mendaftar : daftar
# laintapi : laintapi
# menolak : tolak
# verifikasinyalucu : verifikasinyalucu
# cacat : cacat
# kamera : kamera
# memotret : potret
# hptidak : hptidak
# familiar : familiar
# dropshiper : dropshiper
# supplier : supplier
# mengaktifkan : aktif
# menonaktifkan : nonaktif
# lemmooottttt : lemmooottttt
# transsaksi : transsaksi
# terisi : isi
# penawaran : tawar
# terbaca : baca
# kepencet : pencet
# bermain : main
# kecurigaan : curiga
# maafkan : maaf
# respone : respone
# diatasi : atas
# oiya : oiya
# dipercepat : cepat
# sekaliterutama : sekaliterutama
# pajak : pajak
# bugbuka : bugbuka
# lamamasuk : lamamasuk
# lamake : lamake
# iconnya : iconnya
# perbarui : baru
# ahjgn : ahjgn
# inigak : inigak
# kencang : kencang
# tulisanmu : tulis
# down : down
# cobalagi : cobalagi
# terusmenjengkelkan : terusmenjengkelkan
# tokosebelah : tokosebelah
# pelangganny : pelangganny
# kebocoran : bocor
# kecurangan : curang
# staf : staf
# didalamnya : dalam
# undiannya : undi
# fiturfitur : fiturfitur
# bervariatif : variatif
# informasinya : informasi
# frakerja : frakerja
# rinci : rinci
# kemenaker : kemenaker
# terbantudengan : terbantudengan
# ilmu : ilmu
# amin : amin
# beyar : beyar
# layananya : layananya
# hadeh : hadeh
# responsif : responsif
# siplah : sip
# terimakasi : terimakasi
# ijobiruoren : ijobiruoren
# padaha : padaha
# najis : najis
# akulakukredivojuloasal : akulakukredivojuloasal
# pelatihanujungnya : pelatihanujungnya
# pelatihaanya : pelatihaanya
# keterangannya : terang
# adanyaminimal : adanyaminimal
# bukalapakgk : bukalapakgk
# pesananbutuh : pesananbutuh
# bukalapakdengan : bukalapakdengan
# meninggoy : meninggoy
# termurah : murah
# oyen : oyen
# judi : judi
# anggota : anggota
# dpr : dpr
# ri : ri
# zeus : zeus
# rapat : rapat
# galaxy : galaxy
# undian : undi
# pemenangnya : menang
# lini : lini
# kehidupan : hidup
# rampok : rampok
# bertangung : bertangung
# lengkapcepat : lengkapcepat
# nyentuh : nyentuh
# ngadi : ngadi
# tf : tf
# anjay : anjay
# apeee : apeee
# dihhh : dihhh
# noh : noh
# apapunnn : apapunnn
# sedia : sedia
# sejarahbuktiin : sejarahbuktiin
# sendirikalah : sendirikalah
# sebelahjoos : sebelahjoos
# terdepan : depan
# pelayananya : pelayananya
# responterima : responterima
# sosial : sosial
# media : media
# penggunannya : gun
# sempurna : sempurna
# mengembirakan : mengembirakan
# sisi : sisi
# ekspetasi : ekspetasi
# ektp : ektp
# blur : blur
# frame : frame
# teus : teus
# komisi : komisi
# telkom : telkom
# pdam : pdam
# kab : kab
# kediri : diri
# fif : fif
# adira : adira
# kasirnya : kasir
# terintegrasi : integrasi
# keamanannya : aman
# diprioritaskan : prioritas
# lampiran : lampir
# negatif : negatif
# ive : ive
# idea : idea
# hai : hai
# bukal : bukal
# pcs : pcs
# parsel : parsel
# sebagia : sebagia
# sah : sah
# porum : porum
# notip : notip
# datanya : data
# coin : coin
# kecepatan : cepat
# tujuanya : tujuanya
# hangusnya : hangus
# panjangin : panjangin
# variatif : variatif
# salin : salin
# paste : paste
# lainkali : lainkali
# diperuntukkan : untuk
# bergabung : gabung
# pendapat : dapat
# bangsa : bangsa
# masyarakan : masyarakan
# warungwarung : warungwarung
# sesi : sesi
# indonesiabukalapak : indonesiabukalapak
# digunakanitu : digunakanitu
# dulusekarang : dulusekarang
# kecewakomplain : kecewakomplain
# berteletelepembelian : berteletelepembelian
# saldodanabisa : saldodanabisa
# rekeningribetjadi : rekeningribetjadi
# bintangnyamaafmau : bintangnyamaafmau
# balikhadeuhh : balikhadeuhh
# memory : memory
# kepepet : pepet
# ribut : ribut
# bangetlah : banget
# instruksi : instruksi
# dltingkatin : dltingkatin
# imbang : imbang
# adm : adm
# bulanannya : bulan
# meningkatkan : tingkat
# didaftarin : didaftarin
# mala : mala
# pemaksaan : paksa
# lembagalembaga : lembagalembaga
# slowrespon : slowrespon
# jadikan : jadi
# cadangan : cadang
# faktor : faktor
# lzd : lzd
# fastrespon : fastrespon
# dikembangkan : kembang
# pencantuman : cantum
# baju : baju
# lengan : lengan
# pendek : pendek
# inbox : inbox
# lagharus : lagharus
# telkomsel : telkomsel
# beritahuakan : beritahuakan
# yaadi : yaadi
# xsetelah : xsetelah
# tercantumini : tercantumini
# akal : akal
# kabarsangat : kabarsangat
# burukpenipuan : burukpenipuan
# mengedukasi : edukasi
# pola : pola
# gagasan : gagas
# pikiran : pikir
# uturakan : uturakan
# bukapalak : bukapalak
# dikartu : kartu
# komunikasi : komunikasi
# menunjang : tunjang
# karir : karir
# gaib : gaib
# mengajak : ajak
# rajin : rajin
# traksaksi : traksaksi
# kaliklo : kaliklo
# terjangkauongkos : terjangkauongkos
# onlen : onlen
# aktual : aktual
# dominan : dominan
# over : over
# perlukan : perlu
# ongir : ongir
# acuh : acuh
# cuek : cuek
# tanggapannya : tanggap
# lemah : lemah
# taii : taii
# rekomendasikan : rekomendasi
# penerapan : terap
# midtrans : midtrans
# lempar : lempar
# mnit : mnit
# kill : kill
# process : process
# blnya : blnya
# berbenti : berbenti
# dibagian : bagi
# mantapharga : mantapharga
# lainpadahal : lainpadahal
# memajukan : maju
# dipoto : dipoto
# pohon : pohon
# gabung : gabung
# rejekiroda : rejekiroda
# hilangsaya : hilangsaya
# mengubah : ubah
# smswa : smswa
# karenasempet : karenasempet
# telpwa : telpwa
# salenya : sale
# internkaryawan : internkaryawan
# buktinya : bukti
# list : list
# mengaku : aku
# persetujuan : tuju
# kepuasan : puas
# baguskarena : baguskarena
# hpseharusnya : hpseharusnya
# lagiklau : lagiklau
# membayarnyamisalkan : membayarnyamisalkan
# atmno : atmno
# bankklau : bankklau
# pulsanya : pulsa
# agr : agr
# lagimksih : lagimksih
# callcenter : callcenter
# minkemaren : minkemaren
# linkajatetapi : linkajatetapi
# berhasilehh : berhasilehh
# semalam : malam
# pembayarangimana : pembayarangimana
# linkaja : linkaja
# diriwayat : riwayat
# hmmm : hmmm
# mincs : mincs
# mepersulit : mepersulit
# melakukakan : melakukakan
# telpon : telpon
# kontakcall : kontakcall
# berinteraksi : interaksi
# matiin : matiin
# eroor : eroor
# pemainnya : main
# standart : standart
# pemain : main
# aslinya : asli
# uninsntall : uninsntall
# sebelmnya : sebelmnya
# menjengkelkan : jengkel
# rada : rada
# dihadapi : hadap
# bukadanabukadompet : bukadanabukadompet
# bukadana : bukadana
# dinaikin : dinaikin
# olah : olah
# blankgak : blankgak
# bukaoia : bukaoia
# osaplikay : osaplikay
# apalokasi : apalokasi
# jaringanyang : jaringanyang
# uptodatejadi : uptodatejadi
# perbaikilah : baik
# lapaksudah : lapaksudah
# mnurun : mnurun
# jayapura : jayapura
# dijangkau : jangkau
# appnya : appnya
# kualitasmu : kualitas
# drop : drop
# matang : matang
# sekarangmalesbosen : sekarangmalesbosen
# keselkarena : keselkarena
# perbaharui : baharu
# leletlemotkayak : leletlemotkayak
# siput : siput
# mabuktolong : mabuktolong
# perbaikidan : perbaikidan
# alangkah : alangkah
# terbarutapi : terbarutapi
# bisatrims : bisatrims
# panjual : panjual
# weekend : weekend
# mengetiktdk : mengetiktdk
# algoritmanya : algoritmanya
# kembangkan : kembang
# date : date
# pengiklanan : iklan
# regbarang : regbarang
# sminggu : sminggu
# myd : myd
# inv : inv
# dalemnya : dalem
# even : even
# serbunya : serbu
# ngrestart : ngrestart
# kenyamana : kenyamana
# utamakan : utama
# terbaikresponship : terbaikresponship
# bukunya : buku
# sebatas : batas
# padahalkan : padahal
# jarak : jarak
# harapan : harap
# bepergian : pergi
# ngebug : ngebug
# double : double
# ilfil : ilfil
# susa : susa
# masukansaran : masukansaran
# pemberian : beri
# lamaterutama : lamaterutama
# grabgosend : grabgosend
# jugakarena : jugakarena
# ditangan : tang
# ketiga : tiga
# perpesanan : pesan
# bals : bals
# attch : attch
# delay : delay
# boro : boro
# sektor : sektor
# melaporkan : lapor
# feedbacknya : feedbacknya
# disajikan : saji
# aplikator : aplikator
# aaa : aaa
# pemenang : menang
# identitas : identitas
# nabungbuat : nabungbuat
# paspasan : paspasan
# meringankan : ringan
# flashdealnya : flashdealnya
# jin : jin
# hitungan : hitung
# lampu : lampu
# dslr : dslr
# seper : per
# kamuyang : kamuyang
# nyarinya : nyarinya
# ketampil : tampil
# aneka : aneka
# akurasi : akurasi
# antra : antra
# akurat : akurat
# source : source
# pembodohan : bodoh
# pembertahuannya : tahu
# kenyamanannya : nyaman
# dicairkan : cair
# dibelanjakan : belanja
# terlupakan : lupa
# pleleter : pleleter
# lemotjadinya : lemotjadinya
# ide : ide
# burukjadi : burukjadi
# makain : makain
# berfaedah : faedah
# promopromo : promopromo
# promosikan : promosi
# minimum : minimum
# virus : virus
# dibuang : buang
# promosinya : promosi
# menyedikan : dik
# usernya : usernya
# dilayani : layan
# prmbelian : prmbelian
# medsos : medsos
# atay : atay
# skala : skala
# berjual : jual
# bukabantu : bukabantu
# amananpesana : amananpesana
# susahtolong : susahtolong
# stres : stres
# prkmbangn : prkmbangn
# pningktn : pningktn
# seprti : seprti
# duluagak : duluagak
# brang : brang
# duh : duh
# print : print
# sekarangbarang : sekarangbarang
# mubazir : mubazir
# menuhin : menuhin
# bukaklapak : bukaklapak
# adminya : adminya
# bocor : bocor
# korbanya : korbanya
# aplkasinya : aplkasinya
# wkwkkw : wkwkkw
# ongkirturunin : ongkirturunin
# milim : milim
# piye : piye
# jal : jal
# cepatmantap : cepatmantap
# surantap : surantap
# seharihari : seharihari
# sistemnyadari : sistemnyadari
# pengambilan : ambil
# presentase : presentase
# fiturfirurnyanotifikasi : fiturfirurnyanotifikasi
# chatsaya : chatsaya
# selersudah : selersudah
# terdaftardan : terdaftardan
# kagetnya : kaget
# besarsaran : besarsaran
# transaksinyaterimakasih : transaksinyaterimakasih
# tumben : tumben
# pembayarannya : bayar
# ditransferdibayar : ditransferdibayar
# pembelianya : belia
# memeriksa : periksa
# pengembaliannya : kembali
# nuwon : nuwon
# menghubukan : menghubukan
# pesanannya : pesan
# tindakan : tindak
# nol : nol
# rupiah : rupiah
# nice : nice
# tq : tq
# perbelanjaan : belanja
# terbantukanbelanja : terbantukanbelanja
# power : power
# nibelanja : nibelanja
# nyakena : nyakena
# bosampunn : bosampunn
# bukalapakjangan : bukalapakjangan
# terkahir : terkahir
# sykenapa : sykenapa
# didana : dana
# dipakaipadahal : dipakaipadahal
# vs : vs
# bulanpayah : bulanpayah
# donlod : donlod
# kodenya : kode
# lm : lm
# lolos : lolos
# perekonomian : ekonomi
# babiknpa : babiknpa
# reksadana : reksadana
# kampreeeet : kampreeeet
# membagongkan : bagong
# pelayanam : pelayanam
# memprihantinkan : memprihantinkan
# menjelesakan : menjelesakan
# bhahaha : bhahaha
# wrwb : wrwb
# direspon : direspon
# menyelesaikannya : selesai
# sertifikat : sertifikat
# dashboart : dashboart
# buktikan : bukti
# lumyan : lumyan
# lengkapharga : lengkapharga
# jb : jb
# sigap : sigap
# bukalapan : bukalapan
# asu : asu
# mampus : mampus
# sistemloapp : sistemloapp
# torok : torok
# ranting : ranting
# topselernyata : topselernyata
# padalan : padalan
# bukabantuanya : bukabantuanya
# real : real
# bukareksa : bukareksa
# menginginkannya : ingin
# peleter : leter
# kitaterima : kitaterima
# termaksud : maksud
# deploper : deploper
# viralkan : viralkan
# {'fitur': 'fitur', 'bukabantuan': 'bukabantuan', 'aplikasi': 'aplikasi', 'ribet': 'ribet', 'saldo': 'saldo', 'dipakai': 'pakai', 'cairin': 'cairin', 'transfer': 'transfer', 'banget': 'banget', 'password': 'password', 'dibilang': 'bilang', 'salah': 'salah', 'riset': 'riset', 'dikit': 'dikit', 'selesai': 'selesai', 'notifikasi': 'notifikasi', 'sistem': 'sistem', 'eror': 'eror', 'sih': 'sih', 'laporan': 'lapor', 'barang': 'barang', 'diterima': 'terima', 'jam': 'jam', 'segitu': 'segitu', 'barangnya': 'barang', 'semalaman': 'malam', 'komplrn': 'komplrn', 'bl': 'bl', 'langsung': 'langsung', 'close': 'close', 'terima': 'terima', 'komplenan': 'komplenan', 'marketplace': 'marketplace', 'hancur': 'hancur', 'selesain': 'selesain', 'lari': 'lari', 'live': 'live', 'chatnya': 'chatnya', 'paylaternya': 'paylaternya', 'bobrok': 'bobrok', 'silakan': 'sila', 'dicoba': 'coba', 'download': 'download', 'tau': 'tau', 'komplain': 'komplain', 'seminggu': 'minggu', 'permintaan': 'minta', 'pencairan': 'cair', 'dana': 'dana', 'rekening': 'rekening', 'pribadi': 'pribadi', 'berhasil': 'hasil', 'tolong': 'tolong', 'kerjasamanya': 'kerjasamanya', 'aktifkan': 'aktif', 'bukabantuannya': 'bukabantuannya', 'next': 'next', 'bintangnya': 'bintang', 'diubah': 'ubah', 'baca': 'baca', 'virtual': 'virtual', 'account': 'account', 'terverifikasi': 'verifikasi', 'terpotong': 'potong', 'chat': 'chat', 'arahanya': 'arahanya', 'parahnya': 'parah', 'alasan': 'alas', 'koneksi': 'koneksi', 'terputus': 'putus', 'ganti': 'ganti', 'email': 'email', 'selfilah': 'selfilah', 'ktplah': 'ktplah', 'mutasi': 'mutasi', 'rekeninglah': 'rekening', 'framelah': 'framelah', 'kembalikan': 'kembali', 'bukalapak': 'bukalapak', 'ditangani': 'tangan', 'tim': 'tim', 'menunggu': 'tunggu', 'edit': 'edit', 'produk': 'produk', 'giliran': 'gilir', 'ujung': 'ujung', 'nya': 'nya', 'iklan': 'iklan', 'dijual': 'jual', 'hilang': 'hilang', 'alias': 'alias', 'otomatis': 'otomatis', 'dihapus': 'hapus', 'ditingkatkan': 'tingkat', 'ulang': 'ulang', 'sistemnya': 'sistem', 'penjual': 'jual', 'pembeli': 'beli', 'meninggalkan': 'tinggal', 'gue': 'gue', 'suka': 'suka', 'apps': 'apps', 'tampilannya': 'tampil', 'oke': 'oke', 'beli': 'beli', 'pulsa': 'pulsa', 'isi': 'isi', 'pln': 'pln', 'murah': 'murah', 'cuman': 'cuman', 'belanja': 'belanja', 'online': 'online', 'ongkirnya': 'ongkirnya', 'mahal': 'mahal', 'ampun': 'ampun', 'potongan': 'potong', 'ongkir': 'ongkir', 'kayak': 'kayak', 'shopee': 'shopee', 'gratis': 'gratis', 'bug': 'bug', 'cari': 'cari', 'favorit': 'favorit', 'via': 'via', 'ketik': 'ketik', 'nama': 'nama', 'habis': 'habis', 'muncul': 'muncul', 'ngeload': 'ngeload', 'percaya': 'percaya', 'penjualnya': 'jual', 'respon': 'respon', 'pembelinya': 'bel', 'mengirim': 'kirim', 'rugi': 'rugi', 'transaksi': 'transaksi', 'dianggap': 'anggap', 'kalo': 'kalo', 'pengiriman': 'kirim', 'kali': 'kali', 'menerima': 'terima', 'mbulet': 'mbulet', 'dibukalapak': 'dibukalapak', 'gangguan': 'ganggu', 'terusan': 'terus', 'diskon': 'diskon', 'pelit': 'pelit', 'harga': 'harga', 'rekomendasi': 'rekomendasi', 'deh': 'deh', 'perbaiki': 'baik', 'apk': 'apk', 'rugikan': 'rugi', 'paket': 'paket', 'internet': 'internet', 'masukmasuk': 'masukmasuk', 'tertulisnya': 'tulis', 'pembayaran': 'bayar', 'bayar': 'bayar', 'lamalama': 'lamalama', 'kecewa': 'kecewa', 'paylater': 'paylater', 'aktif': 'aktif', 'dibatalkan': 'batal', 'cek': 'cek', 'ya': 'ya', 'hun': 'hun', 'cs': 'cs', 'telepon': 'telepon', 'dibuka': 'buka', 'kolom': 'kolom', 'tanggapan': 'tanggap', 'bagus': 'bagus', 'puas': 'puas', 'promo': 'promo', 'discount': 'discount', 'syarat': 'syarat', 'bohong': 'bohong', 'pakai': 'pakai', 'bonus': 'bonus', 'reward': 'reward', 'roda': 'roda', 'putar': 'putar', 'kredit': 'kredit', 'perak': 'perak', 'hadeeh': 'hadeeh', 'mending': 'mending', 'kaya': 'kaya', 'kena': 'kena', 'biaya': 'biaya', 'bulanan': 'bulan', 'rp': 'rp', 'ditambah': 'tambah', 'keterangan': 'terang', 'merchant': 'merchant', 'mudah': 'mudah', 'sukses': 'sukses', 'bukelepek': 'bukelep ...
# ------------------------
# Pandas Apply:   0%|          | 0/1300 [00:00<?, ?it/s]

# %%
name_dataframe["Ulasan_siap"] = [' '.join(map(str, l)) for l in name_dataframe['Ulasan_Stemmed']]

# %%
name_dataframe.to_excel("bukalapak.xlsx")

# %%
ulasan = ' '.join(str(v) for v in name_dataframe['Ulasan_siap'])

# %%
tokenize_ulasan = word_tokenize(ulasan)

# %%
tokenize_ulasan
# Out:
# ['fitur',
#  'bukabantuan',
#  'aplikasi',
#  'ribet',
#  'saldo',
#  'pakai',
#  'cairin',
#  'transfer',
#  'ribet',
#  'banget',
#  'password',
#  'bilang',
#  'salah',
#  'riset',
#  'password',
#  'bilang',
#  'salah',
#  'dikit',
#  'selesai',
#  'notifikasi',
#  'sistem',
#  'eror',
#  'sih',
#  'lapor',
#  'barang',
#  'terima',
#  'jam',
#  'jam',
#  'segitu',
#  'barang',
#  'malam',
#  'lapor',
#  'komplrn',
#  'bl',
#  'langsung',
#  'close',
#  'terima',
#  'komplenan',
#  'aplikasi',
#  'marketplace',
#  'hancur',
#  'sistem',
#  'bukabantuan',
#  'selesain',
#  'lari',
#  'live',
#  'chatnya',
#  'sistem',
#  'paylaternya',
#  'bobrok',
#  'sila',
#  'coba',
#  'download',
#  'tau',
#  'komplain',
#  'minggu',
#  'minta',
#  'cair',
#  'dana',
#  'rekening',
#  'pribadi',
#  'hasil',
#  'bukabantuan',
#  'tolong',
#  'kerjasamanya',
#  'aktif',
#  'bukabantuannya',
#  'komplain',
#  'next',
#  'selesai',
#  'bintang',
#  'ubah',
#  'transfer',
#  'baca',
#  'virtual',
#  'account',
#  'verifikasi',
#  'saldo',
#  'rekening',
#  'potong',
#  'komplain',
#  'live',
#  'chat',
#  'arahanya',
#  'ribet',
#  'banget',
#  'parah',
#  'live',
#  'chat',
#  'langsung',
#  'alas',
#  'koneksi',
#  'putus',
#  'ganti',
#  'email',
#  'ribet',
#  'banget',
#  'selfilah',
#  'ktplah',
#  'mutasi',
#  'rekening',
#  'framelah',
#  'kembali',
#  'dana',
#  'transfer',
#  'bukalapak',
#  'tangan',
#  'tim',
#  'tunggu',
#  'jam',
#  'selesai',
#  'aplikasi',
#  'ribet',
#  'edit',
#  'produk',
#  'gilir',
#  'hasil',
#  'ujung',
#  'nya',
#  'iklan',
#  'produk',
#  'jual',
#  'hilang',
#  'alias',
#  'otomatis',
#  'hapus',
#  'bukalapak',
#  'tolong',
#  'tingkat',
#  'ulang',
#  'sistem',
#  'jual',
#  'beli',
#  'tinggal',
#  'aplikasi',
#  'gue',
#  'suka',
#  'sih',
#  'apps',
#  'bukalapak',
#  'tampil',
#  'oke',
#  'beli',
#  'pulsa',
#  'isi',
#  'ulang',
#  'pln',
#  'murah',
#  'cuman',
#  'gue',
#  'suka',
#  'belanja',
#  'online',
#  'ongkirnya',
#  'mahal',
#  'nya',
#  'ampun',
#  'potong',
#  'ongkir',
#  'kayak',
#  'shopee',
#  'ongkir',
#  'murah',
#  'gratis',
#  'ongkir',
#  'bug',
#  'cari',
#  'barang',
#  'favorit',
#  'via',
#  'ketik',
#  'nama',
#  'barang',
#  'barang',
#  'habis',
#  'muncul',
#  'iklan',
#  'iklan',
#  'ngeload',
#  'percaya',
#  'jual',
#  'respon',
#  'komplain',
#  'bel',
#  'salah',
#  'kirim',
#  'jual',
#  'rugi',
#  'transaksi',
#  'anggap',
#  'selesai',
#  'beli',
#  'anggap',
#  'terima',
#  'barang',
#  'komplain',
#  'kalo',
#  'jual',
#  'salah',
#  'kirim',
#  'kali',
#  'jual',
#  'kirim',
#  'barang',
#  'notifikasi',
#  'terima',
#  'komplain',
#  'bl',
#  'ribet',
#  'mbulet',
#  'bukalapak',
#  'ribet',
#  'saldo',
#  'dibukalapak',
#  'ganggu',
#  'terus',
#  'ganggu',
#  'nya',
#  'bukalapak',
#  'hancur',
#  'aplikasi',
#  'nya',
#  'diskon',
#  'pelit',
#  'harga',
#  'rekomendasi',
#  'deh',
#  'bukalapak',
#  'tolong',
#  'baik',
#  'apk',
#  'nya',
#  'rugi',
#  'beli',
#  'paket',
#  'internet',
#  'masukmasuk',
#  'tulis',
#  'tunggu',
#  'bayar',
#  'saldo',
#  'potong',
#  'bayar',
#  'lamalama',
#  'apk',
#  'nya',
#  'kecewa',
#  'bukalapak',
#  'paylater',
#  'aktif',
#  'kali',
#  'transaksi',
#  'bayar',
#  'paylater',
#  'langsung',
#  'batal',
#  'otomatis',
#  'cek',
#  'paylater',
#  'aktif',
#  'salah',
#  'ya',
#  'hun',
#  'cs',
#  'telepon',
#  'komplain',
#  'live',
#  'chat',
#  'buka',
#  'kolom',
#  'chat',
#  'nya',
#  'tolong',
#  'tanggap',
#  'nya',
#  'bagus',
#  'puas',
#  'tolong',
#  'pelit',
#  'promo',
#  'discount',
#  'gratis',
#  'ongkir',
#  'gratis',
#  'ongkir',
#  'nya',
#  'syarat',
#  'bohong',
#  'pakai',
#  'belanja',
#  'bonus',
#  'reward',
#  'roda',
#  'putar',
#  'nya',
#  'kredit',
#  'perak',
#  'hadeeh',
#  'mending',
#  'kalo',
#  'kaya',
#  'bukalapak',
#  'paylater',
#  'kena',
#  'biaya',
#  'bulan',
#  'rp',
#  'bayar',
#  'tambah',
#  'rp',
#  'terang',
#  'biaya',
#  'kecewa',
#  'bukalapak',
#  'sistem',
#  'puas',
#  'belanja',
#  'bukalapak',
#  'belanja',
#  'merchant',
#  'bayar',
#  'nya',
#  'mudah',
#  'bayar',
#  'pakai',
#  'paylater',
#  'sukses',
#  'bukalapak',
#  'bukelepek',
#  'kayak',
#  'sampah',
#  'tutup',
#  'akun',
#  'tele',
#  'beda',
#  'tokopedia',
#  'shope',
#  'hapus',
#  'akun',
#  'tombol',
#  'hapus',
#  'akun',
#  'klik',
#  'hapus',
#  'akun',
#  'langsung',
#  'sukses',
#  'bukulepek',
#  'akan',
#  'boleh',
#  'hapus',
#  'akun',
#  'senang',
#  'sayalive',
#  'chatnya',
#  'susahyang',
#  'layan',
#  'robot',
#  'terusni',
#  'usaha',
#  'warung',
#  'kelontong',
#  'sihminta',
#  'bantu',
#  'susahmasa',
#  'saldo',
#  'pakai',
#  'beli',
#  'paket',
#  'datacuma',
#  'harga',
#  'anmasa',
#  'saldo',
#  'tahangawat',
#  'iniklo',
#  'dadak',
#  'habis',
#  'datagimana',
#  'tuh',
#  'tuh',
#  'bintang',
#  'parah',
#  'bangettolong',
#  'baik',
#  'inikarena',
#  'butuh',
#  'kamiuang',
#  'tahan',
#  'hatihati',
#  'bukalapak',
#  'tipu',
#  'jebak',
#  'costumer',
#  'alat',
#  'pancing',
#  'paylater',
#  'sengaja',
#  'biar',
#  'tagih',
#  'biaya',
#  'admin',
#  'paylater',
#  'bulan',
#  'jalan',
#  'costumer',
#  'bayar',
#  'biaya',
#  'admin',
#  'bulan',
#  'memberitahu',
#  'costumer',
#  'akun',
#  'paylater',
#  'bukalapak',
#  'costumer',
#  'nya',
#  'nonaktif',
#  'aktif',
#  'costumer',
#  'saldo',
#  'paylater',
#  'nya',
#  'ecommerce',
#  'cs',
#  'bobrok',
#  'rugi',
#  'costumer',
#  'sesal',
#  'gue',
#  'belanja',
#  'pakai',
#  'apk',
#  'bukalapak',
#  'jual',
#  'chat',
#  'pesan',
#  'proses',
#  'cancel',
#  'proses',
#  'minggu',
#  'buang',
#  'menu',
#  'komplain',
#  'error',
#  'tolong',
#  'baik',
#  'kendala',
#  'transaksi',
#  'status',
#  'kirim',
#  'tuju',
#  'terima',
#  'produk',
#  'mantap',
#  'tolong',
#  'kalo',
#  'paket',
#  'sedia',
#  'foto',
#  'bukti',
#  'kirim',
#  'nyabiar',
#  'tau',
#  'oh',
#  'paket',
#  'nya',
#  'taro',
#  'situ',
#  'kurir',
#  'antar',
#  'barang',
#  'salah',
#  'alamat',
#  'tau',
#  'posisi',
#  'paket',
#  'aman',
#  'konfirmasi',
#  'kurir',
#  'nya',
#  'mohon',
#  'tingkat',
#  'bagus',
#  'banget',
#  'aplikasi',
#  'aplikasi',
#  'milik',
#  'milik',
#  'kompeten',
#  'payah',
#  'hubung',
#  'bantu',
#  'susah',
#  'ampun',
#  'coba',
#  'kaitin',
#  'akun',
#  'dana',
#  'susah',
#  'gagal',
#  'aneh',
#  'akun',
#  'dana',
#  'nya',
#  'ikat',
#  'apk',
#  'bukalapaknya',
#  'ngaktifin',
#  'bukapaylater',
#  'pakai',
#  'belanja',
#  'iya',
#  'biaya',
#  'layan',
#  'mahal',
#  'kali',
#  'lipat',
#  'banding',
#  'transaksi',
#  'laku',
#  'payah',
#  'kalo',
#  'ada',
#  'voucher',
#  'diskon',
#  'bayar',
#  'plus',
#  'jdiny',
#  'mohon',
#  'maaftidak',
#  'rekomendasi',
#  'banget',
#  'aplikasi',
#  'nya',
#  'paylatter',
#  'nya',
#  'kena',
#  'layan',
#  'transaksi',
#  'rugi',
#  'biaya',
#  'layan',
#  'nya',
#  'belanja',
#  'bintang',
#  'bicara',
#  'alam',
#  'aplikasi',
#  'kagak',
#  'beli',
#  'latih',
#  'prakerja',
#  'vocer',
#  'valid',
#  'kontak',
#  'cs',
#  'baharu',
#  'vocer',
#  'valid',
#  'jadwal',
#  'latih',
#  'vocer',
#  'ridem',
#  'jadwal',
#  'latih',
#  'sungguh',
#  'kagak',
#  'sambung',
#  'sesal',
#  'transaksi',
#  'aplikasi',
#  'mending',
#  'lihat',
#  'lihat',
#  'ulas',
#  'aplikasi',
#  'biar',
#  'kagak',
#  'sesal',
#  'jelek',
#  'komplen',
#  'hubung',
#  'csbarang',
#  'gagal',
#  'rim',
#  'barang',
#  'returdi',
#  'cek',
#  'jasa',
#  'kirim',
#  'terus',
#  'kirim',
#  'barang',
#  'veritifikasi',
#  'email',
#  'sandi',
#  'daftar',
#  'bukalapak',
#  'aneh',
#  'banget',
#  'ganti',
#  'sandi',
#  'tulis',
#  'sandi',
#  'baik',
#  'aneh',
#  'banget',
#  'serbu',
#  'meleset',
#  'meleset',
#  'meleset',
#  'meleset',
#  'meleset',
#  'habis',
#  'uang',
#  'dana',
#  'roda',
#  'putar',
#  'mentooog',
#  'potong',
#  'ongkir',
#  'keren',
#  'dikit',
#  'belanja',
#  'bl',
#  'sungguh',
#  'sayangtidak',
#  'bonus',
#  'saran',
#  'bl',
#  'kalo',
#  'kasih',
#  'hadiah',
#  'pakai',
#  'serbu',
#  'kasih',
#  'harga',
#  'langgan',
#  'aplikasi',
#  'pindah',
#  'shoopee',
#  'janji',
#  'nyatasudah',
#  'aku',
#  'member',
#  'platinum',
#  'estimasi',
#  'barang',
#  'lenceng',
#  'kupon',
#  'diskon',
#  'promo',
#  'aman',
#  'kirim',
#  'barang',
#  'sok',
#  'far',
#  'sok',
#  'good',
#  'tingkat',
#  'nyaman',
#  'beli',
#  'aplikasi',
#  'bantu',
#  'belanja',
#  'bayar',
#  'depantapi',
#  'sayang',
#  'biaya',
#  'admin',
#  'ribu',
#  'bulan',
#  'kalo',
#  'paylater',
#  'pakaiklo',
#  'ilangin',
#  'yalimit',
#  'bos',
#  'buka',
#  'bantu',
#  'nya',
#  'bantu',
#  'memperaulitcall',
#  'center',
#  'nya',
#  'kes',
#  'malas',
#  'tanggap',
#  'keluh',
#  'pelanggansemua',
#  'syarat',
#  'dibpenuhichat',
#  'alihkanni',
#  'buka',
#  'bantuanmemalukan',
#  'transaksi',
#  'bermasalahga',
#  'pertqma',
#  'taman',
#  'kemari',
#  'parahcall',
#  'centernya',
#  'latih',
#  'nihbuat',
#  'hilang',
#  'langgan',
#  'bukalapak',
#  'tuh',
#  'iklan',
#  'halaman',
#  'pakai',
#  'klik',
#  'tinggal',
#  'bl',
#  'ribet',
#  'super',
#  'seller',
#  'kuota',
#  'barang',
#  'dagang',
#  'jual',
#  'antik',
#  'unik',
#  'bayar',
#  'pakai',
#  'bayar',
#  'quota',
#  'barang',
#  'terang',
#  'promosi',
#  'toko',
#  'belah',
#  'bodoh',
#  'wajib',
#  'aplikasi',
#  'dana',
#  'tolol',
#  'tolol',
#  'pakai',
#  'dana',
#  'bobol',
#  'saldo',
#  'aju',
#  'komplen',
#  'lapak',
#  'nakal',
#  'ribet',
#  'transaksi',
#  'status',
#  'barang',
#  'kirim',
#  'terima',
#  'tolong',
#  'tambah',
#  'fitur',
#  'respon',
#  'cepat',
#  'fitur',
#  'bantun',
#  'bantu',
#  'langgan',
#  'paylater',
#  'bayar',
#  'limit',
#  'tambah',
#  'moga',
#  'aplikasi',
#  'bukalapak',
#  'bukalapak',
#  'oye',
#  'aman',
#  'nyaman',
#  'alam',
#  'jasa',
#  'ketemu',
#  'lapak',
#  'abal',
#  'abal',
#  'tipu',
#  'cepat',
#  'buka',
#  'lapak',
#  'turun',
#  'tangan',
#  'bantu',
#  'selamat',
#  'uang',
#  'uang',
#  'juta',
#  'selamat',
#  'terima',
#  'kasih',
#  'buka',
#  'lapak',
#  'fitur',
#  'buka',
#  'lapak',
#  'eror',
#  'sulit',
#  'buka',
#  'muter',
#  'vocer',
#  'aplikasi',
#  'aplikasi',
#  'jelek',
#  'tari',
#  'saldo',
#  'dompet',
#  'rekening',
#  'ribet',
#  'proses',
#  'adu',
#  'komplain',
#  'slow',
#  'respon',
#  'duit',
#  'duit',
#  'bukalapak',
#  'aneh',
#  'paylater',
#  'masalah',
#  'bayar',
#  'ya',
#  'deh',
#  'paylater',
#  'repot',
#  'susah',
#  'hubung',
#  'bukalapak',
#  'kait',
#  'fitur',
#  'apk',
#  'bukalapak',
#  'hilang',
#  'nya',
#  'fitur',
#  'lapak',
#  'langgan',
#  'barang',
#  'favorit',
#  'searching',
#  'rubah',
#  'bintang',
#  'apl',
#  'bagus',
#  'mudah',
#  'pahamipakai',
#  'mula',
#  'tlong',
#  'verifikasi',
#  'data',
#  'pribadi',
#  'nomer',
#  'nik',
#  'tnggal',
#  'lahir',
#  'tolak',
#  'bantu',
#  'cs',
#  'wa',
#  'buka',
#  'bantu',
#  'bukalapak',
#  'guna',
#  'hubung',
#  'transaksi',
#  'jual',
#  'barang',
#  'kirim',
#  'kurir',
#  'wahana',
#  'resi',
#  'otomatis',
#  'diupdate',
#  'sistem',
#  'bukalapak',
#  'transaksi',
#  'batal',
#  'otomatis',
#  'hubung',
#  'buka',
#  'bantu',
#  'update',
#  'resi',
#  'cek',
#  'manual',
#  'barang',
#  'kirim',
#  'jalan',
#  'beli',
#  'token',
#  'listrik',
#  'bukalapak',
#  'lalu',
#  'virtual',
#  'account',
#  'saldo',
#  'potong',
#  'bayar',
#  'verifikasi',
#  'komplen',
#  'live',
#  'chat',
#  'cs',
#  'nya',
#  'banget',
#  'bantu',
#  'sulit',
#  'main',
#  'kah',
#  'ambil',
#  'hak',
#  'milik',
#  'orang',
#  'download',
#  'aplikasi',
#  'bukalapak',
#  'pikir',
#  'deh',
#  'keri',
#  'belanja',
#  'bukalapak',
#  'beli',
#  'diangap',
#  'jahat',
#  'main',
#  'beku',
#  'akun',
#  'orang',
#  'akun',
#  'kredivo',
#  'beku',
#  'akun',
#  'akulaku',
#  'beku',
#  'jahat',
#  'beli',
#  'jual',
#  'hati',
#  'hati',
#  'belanja',
#  'bukalapak',
#  'pakai',
#  'kredivo',
#  'akulaku',
#  'sayang',
#  'akun',
#  'mending',
#  'belanja',
#  'toped',
#  'aman',
#  'nyaman',
#  'minim',
#  'jual',
#  'jahat',
#  'voucher',
#  'gratis',
#  'ongkir',
#  'biaya',
#  'tambah',
#  'tolong',
#  'dirinci',
#  'lacak',
#  'paket',
#  'kalo',
#  'paket',
#  'antar',
#  'kasih',
#  'notifikasi',
#  'kalo',
#  'paket',
#  'antar',
#  'alamat',
#  'terima',
#  'sistem',
#  'cod',
#  'paket',
#  'terima',
#  'kalo',
#  'klik',
#  'terima',
#  'pesan',
#  'diberitahu',
#  'kurir',
#  'jalan',
#  'moga',
#  'depan',
#  'tanggap',
#  'transfer',
#  'retur',
#  'rekening',
#  'kode',
#  'otp',
#  'kirim',
#  'email',
#  'coba',
#  'masuk',
#  'masuk',
#  'dana',
#  'transfer',
#  ...]

# %%
fqdist = FreqDist(tokenize_ulasan)

# %%
fqdist
# Out:
# FreqDist({'aplikasi': 483, 'bukalapak': 476, 'nya': 412, 'barang': 408, 'beli': 242, 'kirim': 241, 'buka': 238, 'bayar': 224, 'pakai': 212, 'belanja': 208, ...})

# %% [markdown]
# # **Mencetak 15 Kata Paling Banyak Digunakan**

# %%
fqdist.most_common(15)
# Out:
# [('aplikasi', 483),
#  ('bukalapak', 476),
#  ('nya', 412),
#  ('barang', 408),
#  ('beli', 242),
#  ('kirim', 241),
#  ('buka', 238),
#  ('bayar', 224),
#  ('pakai', 212),
#  ('belanja', 208),
#  ('lapak', 192),
#  ('transaksi', 183),
#  ('bantu', 182),
#  ('mudah', 162),
#  ('jual', 147)]

# %%
import matplotlib.pyplot as plt

# plotting
fqdist.plot(10,cumulative=False)
plt.show()

# %%
label = []
for index, row in name_dataframe.iterrows():
    if row["Rating"] == 5 or row["Rating"] == 4:
        label.append(1)
    else:
        label.append(0)

name_dataframe["label"] = label

name_dataframe
# Out:
#          Nama pengguna  Rating                Date  \
# 0           Wayan Gita       1 2023-08-10 13:36:28
# 1             SAM SURI       1 2023-08-30 04:35:04
# 2              yOga 04       1 2023-08-01 03:19:16
# 3         ipin sopandi       1 2023-08-07 13:07:29
# 4       Popi Anggraini       1 2023-07-05 23:47:51
# ...                ...     ...                 ...
# 1295     Totok Sunarno       5 2023-07-07 10:08:08
# 1296  Arif Nur Pramono       1 2023-07-21 01:23:04
# 1297   JebodZz Channel       5 2023-07-27 22:20:57
# 1298        king black       5 2023-07-27 05:51:59
# 1299   Muhammad Fandri       1 2023-07-23 13:47:34
#
#                                                  Ulasan  \
# 0     fitur bukabantuan nggak guna aplikasi ribet ad...
# 1     laporan barang sudah diterima dan waktunya pun...
# 2     aplikasi marketplace paling ancur sistem bukab...
# 3     nggak bisa komplain sudah seminggu permintaan ...
# 4     saya sudah transfer melalui bca virtual accoun...
# ...                                                 ...
# 1295  sangat membantu kebutuhan kitaterima kasih buk...
# 1296  kenapa barang yg sdh tdk ada masih ada di ikla...
# 1297  mantappp cepat alhamdulillah dengan adanya buk...
# 1298  pengiriman termaksud cepat dari si oren  manta...
# 1299  saya beli barang tp tidak dikirim tolong kalia...
#
#                                         Ulasan_tokenize  \
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [laporan, barang, sudah, diterima, dan, waktun...
# 2     [aplikasi, marketplace, paling, ancur, sistem,...
# 3     [nggak, bisa, komplain, sudah, seminggu, permi...
# 4     [saya, sudah, transfer, melalui, bca, virtual,...
# ...                                                 ...
# 1295  [sangat, membantu, kebutuhan, kitaterima, kasi...
# 1296  [kenapa, barang, yg, sdh, tdk, ada, masih, ada...
# 1297  [mantappp, cepat, alhamdulillah, dengan, adany...
# 1298  [pengiriman, termaksud, cepat, dari, si, oren,...
# 1299  [saya, beli, barang, tp, tidak, dikirim, tolon...
#
#                                             ulasan_ears  \
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [laporan, barang, sudah, diterima, dan, waktun...
# 2     [aplikasi, marketplace, paling, ancur, sistem,...
# 3     [nggak, bisa, komplain, sudah, seminggu, permi...
# 4     [saya, sudah, transfer, melalui, bca, virtual,...
# ...                                                 ...
# 1295  [sangat, membantu, kebutuhan, kitaterima, kasi...
# 1296  [kenapa, barang, yg, sdh, tdk, ada, masih, ada...
# 1297  [mantappp, cepat, alhamdulillah, dengan, adany...
# 1298  [pengiriman, termaksud, cepat, dari, si, oren,...
# 1299  [saya, beli, barang, tp, tidak, dikirim, tolon...
#
#                                       Ulasan_normalized  \
# 0     [fitur, bukabantuan, enggak, guna, aplikasi, r...
# 1     [laporan, barang, sudah, diterima, dan, waktun...
# 2     [aplikasi, marketplace, paling, hancur, sistem...
# 3     [enggak, bisa, komplain, sudah, seminggu, perm...
# 4     [saya, sudah, transfer, melalui, baca, virtual...
# ...                                                 ...
# 1295  [sangat, membantu, kebutuhan, kitaterima, kasi...
# 1296  [kenapa, barang, yang, sudah, tidak, ada, masi...
# 1297  [mantap, cepat, alhamdulillah, dengan, adanya,...
# 1298  [pengiriman, termaksud, cepat, dari, sih, oren...
# 1299  [saya, beli, barang, tapi, tidak, dikirim, tol...
#
#                                     Ulasan_stop_removed  \
# 0     [fitur, bukabantuan, aplikasi, ribet, saldo, d...
# 1     [laporan, barang, diterima, jam, jam, segitu, ...
# 2     [aplikasi, marketplace, hancur, sistem, bukaba...
# 3     [komplain, seminggu, permintaan, pencairan, da...
# 4     [transfer, baca, virtual, account, terverifika...
# ...                                                 ...
# 1295  [membantu, kebutuhan, kitaterima, kasih, bukal...
# 1296               [barang, iklan, ya, dihapus, ajalah]
# 1297    [mantap, cepat, alhamdulillah, bukalapak, beli]
# 1298  [pengiriman, termaksud, cepat, sih, oren, mant...
# 1299  [beli, barang, dikirim, tolong, filter, dikit,...
#
#                                          Ulasan_Stemmed  \
# 0     [fitur, bukabantuan, aplikasi, ribet, saldo, p...
# 1     [lapor, barang, terima, jam, jam, segitu, bara...
# 2     [aplikasi, marketplace, hancur, sistem, bukaba...
# 3     [komplain, minggu, minta, cair, dana, rekening...
# 4     [transfer, baca, virtual, account, verifikasi,...
# ...                                                 ...
# 1295       [bantu, butuh, kitaterima, kasih, bukalapak]
# 1296                    [barang, iklan, ya, hapus, aja]
# 1297    [mantap, cepat, alhamdulillah, bukalapak, beli]
# 1298  [kirim, maksud, cepat, sih, oren, mantap, depl...
# 1299  [beli, barang, kirim, tolong, filter, dikit, a...
#
#                                             Ulasan_siap  label
# 0     fitur bukabantuan aplikasi ribet saldo pakai c...      0
# 1     lapor barang terima jam jam segitu barang mala...      0
# 2     aplikasi marketplace hancur sistem bukabantuan...      0
# 3     komplain minggu minta cair dana rekening priba...      0
# 4     transfer baca virtual account verifikasi saldo...      0
# ...                                                 ...    ...
# 1295             bantu butuh kitaterima kasih bukalapak      1
# 1296                          barang iklan ya hapus aja      0
# 1297          mantap cepat alhamdulillah bukalapak beli      1
# 1298        kirim maksud cepat sih oren mantap deploper      1
# 1299  beli barang kirim tolong filter dikit asih lap...      0
#
# [1300 rows x 11 columns]

# %% [markdown]
# # **Subjekvity dan Polarity**

# %%
from textblob import TextBlob
def getSubjectivity(review):
 return TextBlob(review).sentiment.subjectivity
def getPolarity(review):
 return TextBlob(review).sentiment.polarity
def analyze(score):
 if score < 0:
    return 'Negative'
 elif score == 0:
    return 'Neutral'
 else:
    return 'Positive'

# %%
name_dataframe['Subjectivity'] = name_dataframe['Ulasan_siap'].apply(getSubjectivity)
name_dataframe['Polarity'] = name_dataframe['Ulasan_siap'].apply(getPolarity)
name_dataframe['Sentiment'] = name_dataframe['Polarity'].apply(analyze)
name_dataframe.head()
# Out:
#     Nama pengguna  Rating                Date  \
# 0      Wayan Gita       1 2023-08-10 13:36:28
# 1        SAM SURI       1 2023-08-30 04:35:04
# 2         yOga 04       1 2023-08-01 03:19:16
# 3    ipin sopandi       1 2023-08-07 13:07:29
# 4  Popi Anggraini       1 2023-07-05 23:47:51
#
#                                               Ulasan  \
# 0  fitur bukabantuan nggak guna aplikasi ribet ad...
# 1  laporan barang sudah diterima dan waktunya pun...
# 2  aplikasi marketplace paling ancur sistem bukab...
# 3  nggak bisa komplain sudah seminggu permintaan ...
# 4  saya sudah transfer melalui bca virtual accoun...
#
#                                      Ulasan_tokenize  \
# 0  [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1  [laporan, barang, sudah, diterima, dan, waktun...
# 2  [aplikasi, marketplace, paling, ancur, sistem,...
# 3  [nggak, bisa, komplain, sudah, seminggu, permi...
# 4  [saya, sudah, transfer, melalui, bca, virtual,...
#
#                                          ulasan_ears  \
# 0  [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1  [laporan, barang, sudah, diterima, dan, waktun...
# 2  [aplikasi, marketplace, paling, ancur, sistem,...
# 3  [nggak, bisa, komplain, sudah, seminggu, permi...
# 4  [saya, sudah, transfer, melalui, bca, virtual,...
#
#                                    Ulasan_normalized  \
# 0  [fitur, bukabantuan, enggak, guna, aplikasi, r...
# 1  [laporan, barang, sudah, diterima, dan, waktun...
# 2  [aplikasi, marketplace, paling, hancur, sistem...
# 3  [enggak, bisa, komplain, sudah, seminggu, perm...
# 4  [saya, sudah, transfer, melalui, baca, virtual...
#
#                                  Ulasan_stop_removed  \
# 0  [fitur, bukabantuan, aplikasi, ribet, saldo, d...
# 1  [laporan, barang, diterima, jam, jam, segitu, ...
# 2  [aplikasi, marketplace, hancur, sistem, bukaba...
# 3  [komplain, seminggu, permintaan, pencairan, da...
# 4  [transfer, baca, virtual, account, terverifika...
#
#                                       Ulasan_Stemmed  \
# 0  [fitur, bukabantuan, aplikasi, ribet, saldo, p...
# 1  [lapor, barang, terima, jam, jam, segitu, bara...
# 2  [aplikasi, marketplace, hancur, sistem, bukaba...
# 3  [komplain, minggu, minta, cair, dana, rekening...
# 4  [transfer, baca, virtual, account, verifikasi,...
#
#                                          Ulasan_siap  label  Subjectivity  \
# 0  fitur bukabantuan aplikasi ribet saldo pakai c...      0      0.000000
# 1  lapor barang terima jam jam segitu barang mala...      0      0.000000
# 2  aplikasi marketplace hancur sistem bukabantuan...      0      0.500000
# 3  komplain minggu minta cair dana rekening priba...      0      0.000000
# 4  transfer baca virtual account verifikasi saldo...      0      0.666667
#
#    Polarity Sentiment
# 0  0.000000   Neutral
# 1  0.000000   Neutral
# 2  0.136364  Positive
# 3  0.000000   Neutral
# 4 -0.042424  Negative

# %%
name_dataframe.head()
# Out:
#     Nama pengguna  Rating                Date  \
# 0      Wayan Gita       1 2023-08-10 13:36:28
# 1        SAM SURI       1 2023-08-30 04:35:04
# 2         yOga 04       1 2023-08-01 03:19:16
# 3    ipin sopandi       1 2023-08-07 13:07:29
# 4  Popi Anggraini       1 2023-07-05 23:47:51
#
#                                               Ulasan  \
# 0  fitur bukabantuan nggak guna aplikasi ribet ad...
# 1  laporan barang sudah diterima dan waktunya pun...
# 2  aplikasi marketplace paling ancur sistem bukab...
# 3  nggak bisa komplain sudah seminggu permintaan ...
# 4  saya sudah transfer melalui bca virtual accoun...
#
#                                      Ulasan_tokenize  \
# 0  [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1  [laporan, barang, sudah, diterima, dan, waktun...
# 2  [aplikasi, marketplace, paling, ancur, sistem,...
# 3  [nggak, bisa, komplain, sudah, seminggu, permi...
# 4  [saya, sudah, transfer, melalui, bca, virtual,...
#
#                                          ulasan_ears  \
# 0  [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1  [laporan, barang, sudah, diterima, dan, waktun...
# 2  [aplikasi, marketplace, paling, ancur, sistem,...
# 3  [nggak, bisa, komplain, sudah, seminggu, permi...
# 4  [saya, sudah, transfer, melalui, bca, virtual,...
#
#                                    Ulasan_normalized  \
# 0  [fitur, bukabantuan, enggak, guna, aplikasi, r...
# 1  [laporan, barang, sudah, diterima, dan, waktun...
# 2  [aplikasi, marketplace, paling, hancur, sistem...
# 3  [enggak, bisa, komplain, sudah, seminggu, perm...
# 4  [saya, sudah, transfer, melalui, baca, virtual...
#
#                                  Ulasan_stop_removed  \
# 0  [fitur, bukabantuan, aplikasi, ribet, saldo, d...
# 1  [laporan, barang, diterima, jam, jam, segitu, ...
# 2  [aplikasi, marketplace, hancur, sistem, bukaba...
# 3  [komplain, seminggu, permintaan, pencairan, da...
# 4  [transfer, baca, virtual, account, terverifika...
#
#                                       Ulasan_Stemmed  \
# 0  [fitur, bukabantuan, aplikasi, ribet, saldo, p...
# 1  [lapor, barang, terima, jam, jam, segitu, bara...
# 2  [aplikasi, marketplace, hancur, sistem, bukaba...
# 3  [komplain, minggu, minta, cair, dana, rekening...
# 4  [transfer, baca, virtual, account, verifikasi,...
#
#                                          Ulasan_siap  label  Subjectivity  \
# 0  fitur bukabantuan aplikasi ribet saldo pakai c...      0      0.000000
# 1  lapor barang terima jam jam segitu barang mala...      0      0.000000
# 2  aplikasi marketplace hancur sistem bukabantuan...      0      0.500000
# 3  komplain minggu minta cair dana rekening priba...      0      0.000000
# 4  transfer baca virtual account verifikasi saldo...      0      0.666667
#
#    Polarity Sentiment
# 0  0.000000   Neutral
# 1  0.000000   Neutral
# 2  0.136364  Positive
# 3  0.000000   Neutral
# 4 -0.042424  Negative

# %%
from textblob import TextBlob

# %%
name_dataframe['month'] = name_dataframe['Date'].dt.month

# %%
name_dataframe
# Out:
#          Nama pengguna  Rating                Date  \
# 0           Wayan Gita       1 2023-08-10 13:36:28
# 1             SAM SURI       1 2023-08-30 04:35:04
# 2              yOga 04       1 2023-08-01 03:19:16
# 3         ipin sopandi       1 2023-08-07 13:07:29
# 4       Popi Anggraini       1 2023-07-05 23:47:51
# ...                ...     ...                 ...
# 1295     Totok Sunarno       5 2023-07-07 10:08:08
# 1296  Arif Nur Pramono       1 2023-07-21 01:23:04
# 1297   JebodZz Channel       5 2023-07-27 22:20:57
# 1298        king black       5 2023-07-27 05:51:59
# 1299   Muhammad Fandri       1 2023-07-23 13:47:34
#
#                                                  Ulasan  \
# 0     fitur bukabantuan nggak guna aplikasi ribet ad...
# 1     laporan barang sudah diterima dan waktunya pun...
# 2     aplikasi marketplace paling ancur sistem bukab...
# 3     nggak bisa komplain sudah seminggu permintaan ...
# 4     saya sudah transfer melalui bca virtual accoun...
# ...                                                 ...
# 1295  sangat membantu kebutuhan kitaterima kasih buk...
# 1296  kenapa barang yg sdh tdk ada masih ada di ikla...
# 1297  mantappp cepat alhamdulillah dengan adanya buk...
# 1298  pengiriman termaksud cepat dari si oren  manta...
# 1299  saya beli barang tp tidak dikirim tolong kalia...
#
#                                         Ulasan_tokenize  \
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [laporan, barang, sudah, diterima, dan, waktun...
# 2     [aplikasi, marketplace, paling, ancur, sistem,...
# 3     [nggak, bisa, komplain, sudah, seminggu, permi...
# 4     [saya, sudah, transfer, melalui, bca, virtual,...
# ...                                                 ...
# 1295  [sangat, membantu, kebutuhan, kitaterima, kasi...
# 1296  [kenapa, barang, yg, sdh, tdk, ada, masih, ada...
# 1297  [mantappp, cepat, alhamdulillah, dengan, adany...
# 1298  [pengiriman, termaksud, cepat, dari, si, oren,...
# 1299  [saya, beli, barang, tp, tidak, dikirim, tolon...
#
#                                             ulasan_ears  \
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [laporan, barang, sudah, diterima, dan, waktun...
# 2     [aplikasi, marketplace, paling, ancur, sistem,...
# 3     [nggak, bisa, komplain, sudah, seminggu, permi...
# 4     [saya, sudah, transfer, melalui, bca, virtual,...
# ...                                                 ...
# 1295  [sangat, membantu, kebutuhan, kitaterima, kasi...
# 1296  [kenapa, barang, yg, sdh, tdk, ada, masih, ada...
# 1297  [mantappp, cepat, alhamdulillah, dengan, adany...
# 1298  [pengiriman, termaksud, cepat, dari, si, oren,...
# 1299  [saya, beli, barang, tp, tidak, dikirim, tolon...
#
#                                       Ulasan_normalized  \
# 0     [fitur, bukabantuan, enggak, guna, aplikasi, r...
# 1     [laporan, barang, sudah, diterima, dan, waktun...
# 2     [aplikasi, marketplace, paling, hancur, sistem...
# 3     [enggak, bisa, komplain, sudah, seminggu, perm...
# 4     [saya, sudah, transfer, melalui, baca, virtual...
# ...                                                 ...
# 1295  [sangat, membantu, kebutuhan, kitaterima, kasi...
# 1296  [kenapa, barang, yang, sudah, tidak, ada, masi...
# 1297  [mantap, cepat, alhamdulillah, dengan, adanya,...
# 1298  [pengiriman, termaksud, cepat, dari, sih, oren...
# 1299  [saya, beli, barang, tapi, tidak, dikirim, tol...
#
#                                     Ulasan_stop_removed  \
# 0     [fitur, bukabantuan, aplikasi, ribet, saldo, d...
# 1     [laporan, barang, diterima, jam, jam, segitu, ...
# 2     [aplikasi, marketplace, hancur, sistem, bukaba...
# 3     [komplain, seminggu, permintaan, pencairan, da...
# 4     [transfer, baca, virtual, account, terverifika...
# ...                                                 ...
# 1295  [membantu, kebutuhan, kitaterima, kasih, bukal...
# 1296               [barang, iklan, ya, dihapus, ajalah]
# 1297    [mantap, cepat, alhamdulillah, bukalapak, beli]
# 1298  [pengiriman, termaksud, cepat, sih, oren, mant...
# 1299  [beli, barang, dikirim, tolong, filter, dikit,...
#
#                                          Ulasan_Stemmed  \
# 0     [fitur, bukabantuan, aplikasi, ribet, saldo, p...
# 1     [lapor, barang, terima, jam, jam, segitu, bara...
# 2     [aplikasi, marketplace, hancur, sistem, bukaba...
# 3     [komplain, minggu, minta, cair, dana, rekening...
# 4     [transfer, baca, virtual, account, verifikasi,...
# ...                                                 ...
# 1295       [bantu, butuh, kitaterima, kasih, bukalapak]
# 1296                    [barang, iklan, ya, hapus, aja]
# 1297    [mantap, cepat, alhamdulillah, bukalapak, beli]
# 1298  [kirim, maksud, cepat, sih, oren, mantap, depl...
# 1299  [beli, barang, kirim, tolong, filter, dikit, a...
#
#                                             Ulasan_siap  label  Subjectivity  \
# 0     fitur bukabantuan aplikasi ribet saldo pakai c...      0      0.000000
# 1     lapor barang terima jam jam segitu barang mala...      0      0.000000
# 2     aplikasi marketplace hancur sistem bukabantuan...      0      0.500000
# 3     komplain minggu minta cair dana rekening priba...      0      0.000000
# 4     transfer baca virtual account verifikasi saldo...      0      0.666667
# ...                                                 ...    ...           ...
# 1295             bantu butuh kitaterima kasih bukalapak      1      0.000000
# 1296                          barang iklan ya hapus aja      0      0.000000
# 1297          mantap cepat alhamdulillah bukalapak beli      1      0.000000
# 1298        kirim maksud cepat sih oren mantap deploper      1      0.000000
# 1299  beli barang kirim tolong filter dikit asih lap...      0      0.000000
#
#       Polarity Sentiment  month
# 0     0.000000   Neutral      8
# 1     0.000000   Neutral      8
# 2     0.136364  Positive      8
# 3     0.000000   Neutral      8
# 4    -0.042424  Negative      7
# ...        ...       ...    ...
# 1295  0.000000   Neutral      7
# 1296  0.000000   Neutral      7
# 1297  0.000000   Neutral      7
# 1298  0.000000   Neutral      7
# 1299  0.000000   Neutral      7
#
# [1300 rows x 15 columns]

# %%
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # **Visualisasi Bobot Nilai**

# %%
# Create scatter plot
sns.set_style('darkgrid')
plt.figure(figsize = (15,7))

markers = {'Positive':'o', 'Neutral':'s','Negative':'X'}

sns.scatterplot(data=name_dataframe, x='Polarity', y='Subjectivity', hue = 'Sentiment', style = 'Sentiment', markers = markers, palette = 'gist_earth').set(xlim=(-1,1))
plt.title('Scatter Plot')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')

plt.tight_layout()

# %% [markdown]
# # **Visualiasi Polarity dan subjecvity perbulan**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group by month and sentiment
sentiment_df = name_dataframe.groupby(['month', 'Sentiment']).size().reset_index(name='Count')


# Plot the sentiment counts by month
plt.figure(figsize=(12, 6))
sns.lineplot(x='month', y='Count', hue='Sentiment', data=sentiment_df)
plt.title('Sentiment by Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %%
sentimen_data=pd.value_counts(name_dataframe["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["green", "red", "black"])
plt.title('Bar chart')
plt.show()

# %%
name_dataframe["Sentiment"].value_counts()
# Out:
# Neutral     1095
# Positive     163
# Negative      42
# Name: Sentiment, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
Ulasan = name_dataframe['Ulasan_siap']

# %%
Ulasan.isnull().sum()
# Out:
# 0

# %% [markdown]
# # **Proses (TF-IDF)**

# %%
#untuk menghitung jumlah kata yang telah di steming
cv = CountVectorizer()
term_fit = cv.fit(Ulasan)

print (len(term_fit.vocabulary_))
# Out:
# 3600

# %%
term_fit.vocabulary_ #mengurutkan berdasarkan urutab abjad kata
# Out:
# {'fitur': 1069,
#  'bukabantuan': 543,
#  'aplikasi': 192,
#  'ribet': 2764,
#  'saldo': 2825,
#  'pakai': 2369,
#  'cairin': 638,
#  'transfer': 3388,
#  'banget': 278,
#  'password': 2416,
#  'bilang': 452,
#  'salah': 2823,
#  'riset': 2781,
#  'dikit': 879,
#  'selesai': 2929,
#  'notifikasi': 2233,
#  'sistem': 3051,
#  'eror': 1016,
#  'sih': 3033,
#  'lapor': 1794,
#  'barang': 308,
#  'terima': 3256,
#  'jam': 1378,
#  'segitu': 2904,
#  'malam': 1924,
#  'komplrn': 1663,
#  'bl': 480,
#  'langsung': 1778,
#  'close': 712,
#  'komplenan': 1660,
#  'marketplace': 1957,
#  'hancur': 1211,
#  'selesain': 2931,
#  'lari': 1795,
#  'live': 1863,
#  'chatnya': 698,
#  'paylaternya': 2428,
#  'bobrok': 506,
#  'sila': 3036,
#  'coba': 713,
#  'download': 945,
#  'tau': 3206,
#  'komplain': 1651,
#  'minggu': 2069,
#  'minta': 2076,
#  'cair': 637,
#  'dana': 781,
#  'rekening': 2717,
#  'pribadi': 2611,
#  'hasil': 1229,
#  'tolong': 3359,
#  'kerjasamanya': 1587,
#  'aktif': 84,
#  'bukabantuannya': 544,
#  'next': 2168,
#  'bintang': 458,
#  'ubah': 3443,
#  'baca': 244,
#  'virtual': 3525,
#  'account': 11,
#  'verifikasi': 3513,
#  'potong': 2597,
#  'chat': 693,
#  'arahanya': 210,
#  'parah': 2395,
#  'alas': 110,
#  'koneksi': 1671,
#  'putus': 2664,
#  'ganti': 1127,
#  'email': 999,
#  'selfilah': 2934,
#  'ktplah': 1697,
#  'mutasi': 2137,
#  'framelah': 1089,
#  'kembali': 1556,
#  'bukalapak': 557,
#  'tangan': 3191,
#  'tim': 3319,
#  'tunggu': 3431,
#  'edit': 974,
#  'produk': 2627,
#  'gilir': 1149,
#  'ujung': 3447,
#  'nya': 2243,
#  'iklan': 1289,
#  'jual': 1441,
#  'hilang': 1245,
#  'alias': 118,
#  'otomatis': 2338,
#  'hapus': 1219,
#  'tingkat': 3324,
#  'ulang': 3449,
#  'beli': 368,
#  'tinggal': 3323,
#  'gue': 1175,
#  'suka': 3127,
#  'apps': 207,
#  'tampil': 3188,
#  'oke': 2286,
#  'pulsa': 2654,
#  'isi': 1355,
#  'pln': 2576,
#  'murah': 2131,
#  'cuman': 756,
#  'belanja': 358,
#  'online': 2314,
#  'ongkirnya': 2307,
#  'mahal': 1908,
#  'ampun': 138,
#  'ongkir': 2302,
#  'kayak': 1514,
#  'shopee': 3013,
#  'gratis': 1166,
#  'bug': 538,
#  'cari': 657,
#  'favorit': 1054,
#  'via': 3520,
#  'ketik': 1602,
#  'nama': 2153,
#  'habis': 1189,
#  'muncul': 2128,
#  'ngeload': 2184,
#  'percaya': 2510,
#  'respon': 2744,
#  'bel': 353,
#  'kirim': 1614,
#  'rugi': 2795,
#  'transaksi': 3380,
#  'anggap': 152,
#  'kalo': 1485,
#  'kali': 1481,
#  'mbulet': 1983,
#  'dibukalapak': 852,
#  'ganggu': 1124,
#  'terus': 3282,
#  'diskon': 904,
#  'pelit': 2457,
#  'harga': 1222,
#  'rekomendasi': 2722,
#  'deh': 808,
#  'baik': 261,
#  'apk': 183,
#  'paket': 2376,
#  'internet': 1347,
#  'masukmasuk': 1967,
#  'tulis': 3423,
#  'bayar': 337,
#  'lamalama': 1757,
#  'kecewa': 1523,
#  'paylater': 2427,
#  'batal': 325,
#  'cek': 666,
#  'ya': 3579,
#  'hun': 1270,
#  'cs': 746,
#  'telepon': 3218,
#  'buka': 541,
#  'kolom': 1635,
#  'tanggap': 3194,
#  'bagus': 251,
#  'puas': 2645,
#  'promo': 2636,
#  'discount': 902,
#  'syarat': 3156,
#  'bohong': 509,
#  'bonus': 512,
#  'reward': 2758,
#  'roda': 2786,
#  'putar': 2661,
#  'kredit': 1692,
#  'perak': 2502,
#  'hadeeh': 1193,
#  'mending': 2016,
#  'kaya': 1513,
#  'kena': 1566,
#  'biaya': 445,
#  'bulan': 610,
#  'rp': 2791,
#  'tambah': 3186,
#  'terang': 3241,
#  'merchant': 2047,
#  'mudah': 2118,
#  'sukses': 3129,
#  'bukelepek': 602,
#  'sampah': 2834,
#  'tutup': 3437,
#  'akun': 101,
#  'tele': 3217,
#  'beda': 348,
#  'tokopedia': 3349,
#  'shope': 3012,
#  'tombol': 3360,
#  'klik': 1626,
#  'bukulepek': 606,
#  'akan': 76,
#  'boleh': 511,
#  'senang': 2958,
#  'sayalive': 2865,
#  'susahyang': 3151,
#  'layan': 1801,
#  'robot': 2784,
#  'terusni': 3284,
#  'usaha': 3491,
#  'warung': 3553,
#  'kelontong': 1544,
#  'sihminta': 3034,
#  'bantu': 295,
#  'susahmasa': 3149,
#  'datacuma': 797,
#  'anmasa': 165,
#  'tahangawat': 3177,
#  'iniklo': 1323,
#  'dadak': 770,
#  'datagimana': 798,
#  'tuh': 3415,
#  'bangettolong': 284,
#  'inikarena': 1322,
#  'butuh': 624,
#  'kamiuang': 1487,
#  'tahan': 3176,
#  'hatihati': 1232,
#  'tipu': 3330,
#  'jebak': 1411,
#  'costumer': 739,
#  'alat': 112,
#  'pancing': 2384,
#  'sengaja': 2962,
#  'biar': 444,
#  'tagih': 3170,
#  'admin': 35,
#  'jalan': 1376,
#  'memberitahu': 1998,
#  'nonaktif': 2226,
#  'ecommerce': 971,
#  'sesal': 2990,
#  'pesan': 2529,
#  'proses': 2642,
#  'cancel': 645,
#  'buang': 534,
#  'menu': 2041,
#  'error': 1019,
#  'kendala': 1569,
#  'status': 3106,
#  'tuju': 3417,
#  'mantap': 1944,
#  'sedia': 2898,
#  'foto': 1085,
#  'bukti': 604,
#  'nyabiar': 2245,
#  'oh': 2283,
#  'taro': 3204,
#  'situ': 3057,
#  'kurir': 1713,
#  'antar': 166,
#  'alamat': 107,
#  'posisi': 2593,
#  'aman': 127,
#  'konfirmasi': 1672,
#  'mohon': 2103,
#  'milik': 2062,
#  'kompeten': 1647,
#  'payah': 2424,
#  'hubung': 1266,
#  'susah': 3146,
#  'kaitin': 1474,
#  'gagal': 1103,
#  'aneh': 147,
#  'ikat': 1286,
#  'bukalapaknya': 573,
#  'ngaktifin': 2175,
#  'bukapaylater': 595,
#  'iya': 1365,
#  'lipat': 1859,
#  'banding': 275,
#  'laku': 1751,
#  'ada': 20,
#  'voucher': 3534,
#  'plus': 2577,
#  'jdiny': 1409,
#  'maaftidak': 1902,
#  'paylatter': 2429,
#  'bicara': 447,
#  'alam': 106,
#  'kagak': 1470,
#  'latih': 1797,
#  'prakerja': 2602,
#  'vocer': 3531,
#  'valid': 3501,
#  'kontak': 1679,
#  'baharu': 259,
#  'jadwal': 1369,
#  'ridem': 2772,
#  'sungguh': 3135,
#  'sambung': 2831,
#  'lihat': 1846,
#  'ulas': 3450,
#  'jelek': 1421,
#  'komplen': 1659,
#  'csbarang': 747,
#  'rim': 2774,
#  'returdi': 2756,
#  'jasa': 1390,
#  'veritifikasi': 3516,
#  'sandi': 2844,
#  'daftar': 773,
#  'serbu': 2974,
#  'meleset': 1988,
#  'uang': 3442,
#  'mentooog': 2039,
#  'keren': 1580,
#  'sayangtidak': 2867,
#  'saran': 2848,
#  'kasih': 1507,
#  'hadiah': 1198,
#  'langgan': 1776,
#  'pindah': 2552,
#  'shoopee': 3009,
#  'janji': 1384,
#  'nyatasudah': 2268,
#  'aku': 96,
#  'member': 1997,
#  'platinum': 2568,
#  'estimasi': 1026,
#  'lenceng': 1828,
#  'kupon': 1709,
#  'sok': 3078,
#  'far': 1050,
#  'good': 1158,
#  'nyaman': 2252,
#  'depantapi': 818,
#  'sayang': 2866,
#  'ribu': 2769,
#  'pakaiklo': 2371,
#  'ilangin': 1294,
#  'yalimit': 3585,
#  'bos': 516,
#  'memperaulitcall': 2003,
#  'center': 674,
#  'kes': 1588,
#  'malas': 1925,
#  'keluh': 1550,
#  'pelanggansemua': 2447,
#  'dibpenuhichat': 849,
#  'alihkanni': 120,
#  'bantuanmemalukan': 296,
#  'bermasalahga': 418,
#  'pertqma': 2526,
#  'taman': 3185,
#  'kemari': 1553,
#  'parahcall': 2396,
#  'centernya': 675,
#  'nihbuat': 2211,
#  'halaman': 1205,
#  'super': 3136,
#  'seller': 2937,
#  'kuota': 1708,
#  'dagang': 775,
#  'antik': 170,
#  'unik': 3461,
#  'quota': 2667,
#  'promosi': 2639,
#  'toko': 3346,
#  'belah': 355,
#  'bodoh': 508,
#  'wajib': 3547,
#  'tolol': 3356,
#  'bobol': 505,
#  'aju': 71,
#  'lapak': 1783,
#  'nakal': 2151,
#  'cepat': 677,
#  'bantun': 302,
#  'limit': 1847,
#  'moga': 2102,
#  'oye': 2350,
#  'ketemu': 1597,
#  'abal': 3,
#  'turun': 3434,
#  'selamat': 2924,
#  'juta': 1456,
#  'sulit': 3131,
#  'muter': 2138,
#  'tari': 3201,
#  'dompet': 934,
#  'adu': 41,
#  'slow': 3064,
#  'duit': 957,
#  'masalah': 1960,
#  'repot': 2734,
#  'kait': 1473,
#  'searching': 2883,
#  'rubah': 2793,
#  'apl': 185,
#  'pahamipakai': 2363,
#  'mula': 2125,
#  'tlong': 3337,
#  'data': 796,
#  'nomer': 2222,
#  'nik': 2212,
#  'tnggal': 3342,
#  'lahir': 1735,
#  'tolak': 3355,
#  'wa': 3539,
#  'guna': 1178,
#  'wahana': 3543,
#  'resi': 2740,
#  'diupdate': 920,
#  'update': 3478,
#  'manual': 1948,
#  'token': 3345,
#  'listrik': 1862,
#  'lalu': 1753,
#  'main': 1911,
#  'kah': 1472,
#  'ambil': 132,
#  'hak': 1204,
#  'orang': 2325,
#  'pikir': 2546,
#  'keri': 1583,
#  'diangap': 839,
#  'jahat': 1371,
#  'beku': 351,
#  'kredivo': 1694,
#  'akulaku': 99,
#  'hati': 1231,
#  'toped': 3363,
#  'minim': 2070,
#  'dirinci': 899,
#  'lacak': 1722,
#  'cod': 716,
#  'diberitahu': 848,
#  'depan': 817,
#  'retur': 2755,
#  'kode': 1631,
#  'otp': 2341,
#  'masuk': 1964,
#  'suruh': 3143,
#  'upgrade': 3483,
#  'paksa': 2378,
#  'belikan': 372,
#  'pantesan': 2391,
#  'merosot': 2053,
#  'tukang': 3421,
#  'nipu': 2214,
#  'program': 2634,
#  'sedih': 2899,
#  'mitra': 2082,
#  'andal': 143,
#  'efisien': 982,
#  'kurang': 1710,
#  'merk': 2051,
#  'alternatif': 126,
#  'pt': 2644,
#  'akuisisi': 98,
#  'mengunakan': 2030,
#  'smartphone': 3067,
#  'kepala': 1575,
#  'pusing': 2659,
#  'layoutnya': 1809,
#  'beranta': 392,
#  'xxx': 3578,
#  'ponsel': 2587,
#  'aksesoris': 83,
#  'suku': 3130,
#  'cadang': 636,
#  'dll': 922,
#  'penantan': 2473,
#  'rapi': 2682,
#  'rekan': 2716,
#  'bosan': 518,
#  'jenuh': 1429,
#  'lanjut': 1780,
#  'kesini': 1594,
#  'seler': 2927,
#  'setatus': 2998,
#  'kadang': 1467,
#  'pemberitahuan': 2469,
#  'tiktok': 3318,
#  'mah': 1906,
#  'halo': 1209,
#  'lampau': 1768,
#  'batas': 331,
#  'dihubungichat': 868,
#  'tokoselernya': 3351,
#  'cerah': 686,
#  'sesuai': 2994,
#  'informasi': 1312,
#  'hubungin': 1268,
#  'curi': 760,
#  'bawah': 335,
#  'nih': 2209,
#  'ijo': 1282,
#  'cashback': 661,
#  'ayo': 240,
#  'inovasiinovasi': 1332,
#  'kalah': 1479,
#  'bekuin': 352,
#  'saing': 2815,
#  'loh': 1878,
#  'tibatiba': 3307,
#  'game': 1116,
#  'panjang': 2386,
#  'umur': 3452,
#  'gulung': 1176,
#  'tikar': 3316,
#  'platform': 2567,
#  'stok': 3112,
#  'habisdan': 1190,
#  'dasar': 794,
#  'info': 1311,
#  'nomor': 2224,
#  'maksimal': 1919,
#  'ktp': 1696,
#  'keteranganya': 1600,
#  'hp': 1261,
#  'blokir': 493,
#  'mengatasnamakan': 2019,
#  'takut': 3183,
#  'disalahgunakan': 901,
#  'akses': 81,
#  'memeberikan': 2000,
#  'solusi': 3080,
#  'buruk': 617,
#  'lunas': 1895,
#  'pakaitrus': 2372,
#  'jatuh': 1394,
#  'tempo': 3232,
#  'lansung': 1781,
#  'tanggal': 3193,
#  'sd': 2879,
#  'metode': 2058,
#  'bank': 292,
#  'ocbc': 2277,
#  'nisp': 2216,
#  'lwh': 1898,
#  'pilih': 2548,
#  'kelas': 1540,
#  'payletter': 2434,
#  'rbbaru': 2690,
#  'kalieeeengga': 1482,
#  'lagiwk': 1734,
#  'wkkok': 3569,
#  'yabl': 3582,
#  'lambat': 1766,
#  'pengirimannyahrs': 2483,
#  'dipromo': 892,
#  'jarang': 1387,
#  'berat': 393,
#  'terimakasih': 3261,
#  'utakatik': 3496,
#  'detail': 826,
#  'lazada': 1810,
#  'shoppe': 3017,
#  'top': 3362,
#  'up': 3477,
#  'atm': 230,
#  'bri': 524,
#  'struk': 3120,
#  'henti': 1238,
#  'masak': 1959,
#  'nunggunya': 2239,
#  'rbuan': 2691,
#  'mutu': 2140,
#  'komplin': 1661,
#  'ramai': 2676,
#  'un': 3454,
#  'install': 1337,
#  'shopeelazada': 3014,
#  'bukalapakakin': 558,
#  'erorr': 1017,
#  'sekali': 2910,
#  'jawab': 1399,
#  'tanggung': 3198,
#  'makan': 1917,
#  'gaji': 1110,
#  'buta': 623,
#  'customer': 764,
#  'mundur': 2130,
#  'non': 2225,
#  'aktifsaya': 88,
#  'aktiftoko': 90,
#  'systemnya': 3160,
#  'maintenance': 1913,
#  'membantusaat': 1992,
#  'pulsatoken': 2655,
#  'atas': 228,
#  'cepatsemua': 684,
#  'memuaskanmaju': 2006,
#  'inovatif': 1333,
#  'macet': 1904,
#  'aduh': 42,
#  'gercep': 1144,
#  'nyambing': 2255,
#  'digital': 859,
#  'untung': 3475,
#  'mewq': 2059,
#  'iinv': 1281,
#  'sial': 3023,
#  'besok': 435,
#  'kadaluarsa': 1464,
#  'anjir': 163,
#  'pembelikomplain': 2468,
#  'bisatpi': 474,
#  'jasalancar': 1391,
#  'motong': 2110,
#  'masalahpasti': 1962,
#  'komplainblm': 1653,
#  'livechat': 1864,
#  'khusus': 1609,
#  'olshop': 2293,
#  'customernya': 765,
#  'apa': 175,
#  'gmail': 1153,
#  'sajah': 2817,
#  'enak': 1003,
#  'bisnis': 476,
#  'contoh': 735,
#  'biyaya': 477,
#  'modal': 2096,
#  'benar': 377,
#  'cth': 749,
#  'kemarin': 1554,
#  'bareng': 317,
#  'hrg': 1265,
#  'san': 2842,
#  'mesan': 2055,
#  'asli': 221,
#  'kacau': 1463,
#  'bebayar': 346,
#  'sebutin': 2893,
#  'complain': 728,
#  'berteletele': 426,
#  'tukar': 3422,
#  'bikin': 451,
#  'ceria': 687,
#  'konfirmasitapi': 1673,
#  'sni': 3076,
#  'php': 2539,
#  'tokoh': 3347,
#  'ntk': 2238,
#  'mmbatalkan': 2087,
#  'kmna': 1628,
#  'mntak': 2092,
#  'mhon': 2060,
#  'sistim': 3056,
#  'min': 2064,
#  'pantas': 2389,
#  'sepi': 2970,
#  'tekan': 3212,
#  'oper': 2318,
#  'lapakbarang': 1784,
#  'otomatislapor': 2340,
#  'penjualpenjual': 2495,
#  'nyuruh': 2273,
#  'terimabarang': 3257,
#  'bukannkesalahan': 591,
#  'pembelibeda': 2465,
#  'dngn': 926,
#  'oren': 2332,
#  'estimadi': 1025,
#  'kembalibenar': 1558,
#  'gunakanhabis': 1181,
#  'bela': 354,
#  'refund': 2706,
#  'berbelitstatus': 396,
#  'diiterima': 872,
#  'terkirimhati': 3271,
#  'bukalapakbaru': 559,
#  'alami': 108,
#  'juni': 1455,
#  'chattidak': 701,
#  'pertanyataan': 2525,
#  'user': 3492,
#  'poto': 2596,
#  'permanen': 2520,
#  'alih': 119,
#  'shoppy': 3019,
#  'maaf': 1901,
#  'enggak': 1008,
#  'jelas': 1413,
#  'pay': 2422,
#  'later': 1796,
#  'oakai': 2274,
#  'scam': 2873,
#  'uninstal': 3463,
#  'apli': 189,
#  'allshop': 125,
#  'jelasaplikasi': 1414,
#  'busuk': 622,
#  'gampang': 1119,
#  'livechatnya': 1865,
#  'mana': 1931,
#  'telat': 3215,
#  'rumah': 2796,
#  'lancar': 1771,
#  'rasa': 2683,
#  'pro': 2624,
#  'partai': 2409,
#  'rakyatlagi': 2673,
#  'ruwt': 2807,
#  'ruwet': 2806,
#  'iklanhasilnya': 1290,
#  'manfaatatnya': 1935,
#  'satupuntidak': 2855,
#  'fakta': 1046,
#  'initapi': 1328,
#  'muas': 2115,
#  'kualitas': 1701,
#  'tagihantagihan': 3174,
#  'tv': 3439,
#  'kabel': 1461,
#  'kasihan': 1508,
#  'konsumen': 1678,
#  'lumayan': 1893,
#  'nasabah': 2159,
#  'urgent': 3489,
#  'calon': 643,
#  'produsen': 2630,
#  'jauh': 1395,
#  'lokasi': 1879,
#  'dibukakapak': 851,
#  'relatif': 2726,
#  'mall': 1927,
#  'kaki': 1477,
#  'jaring': 1388,
#  'full': 1094,
#  'sngat': 3075,
#  'gambar': 1114,
#  'video': 3521,
#  'deskripsi': 824,
#  'indonesia': 1309,
#  'mon': 2105,
#  'aktip': 91,
#  'asa': 215,
#  'langgar': 1777,
#  'device': 830,
#  'gonta': 1157,
#  'aseli': 217,
#  'emosi': 1002,
#  'kedaftargimana': 1533,
#  'maksutnya': 1921,
#  'order': 2330,
#  'pulahadehbikin': 2652,
#  'sajaauto': 2816,
#  'delete': 811,
#  'atur': 234,
#  'ajakarna': 63,
#  'bataldan': 326,
#  'sen': 2957,
#  'rumit': 2797,
#  'market': 1955,
#  'buyer': 626,
#  'artikel': 213,
#  'mulu': 2126,
#  'bangkrut': 288,
#  'service': 2985,
#  'mincara': 2066,
#  'lupa': 1897,
#  'pinseingat': 2557,
#  'pin': 2549,
#  'memuaskantapi': 2008,
#  'ongkos': 2311,
#  'banda': 274,
#  'acehdi': 13,
#  'capai': 651,
#  'perkilonyapadahal': 2517,
#  'itupaling': 1363,
#  'an': 139,
#  'acehmohon': 15,
#  'timbang': 3320,
#  'acehmaunya': 14,
#  'aceh': 12,
#  'inibelakangan': 1319,
#  'daerah': 772,
#  'sampainyadicoba': 2836,
#  'terusongkir': 3285,
#  'bukaekpress': 549,
#  'berattidak': 394,
#  'shopbelanja': 3011,
#  'pengaduanonline': 2480,
#  'pelapakseller': 2450,
#  'rentan': 2729,
#  'venus': 3511,
#  'shop': 3010,
#  'on': 2297,
#  'pengadua': 2479,
#  'sibuka': 3028,
#  'tetangga': 3293,
#  'serviceny': 2986,
#  'bliblihari': 487,
#  'mesti': 2057,
#  'bijak': 449,
#  'risiko': 2782,
#  'alhamdulillah': 116,
#  'sekian': 2922,
#  'kecewasejauh': 1530,
#  'gaet': 1102,
#  'minat': 2065,
#  'normal': 2228,
#  'kerenfitur': 1581,
#  'lengkap': 1830,
#  'komplit': 1662,
#  'kirimdan': 1615,
#  'mudahsemoga': 2122,
#  'simpel': 3039,
#  'pembeligood': 2466,
#  'luck': 1890,
#  'sekalisemua': 2916,
#  'maju': 1914,
#  'sayasy': 2871,
#  'berkalikali': 409,
#  'nyabintang': 2246,
#  'verivisi': 3517,
#  'sekaliganti': 2912,
#  'serta': 2980,
#  'no': 2219,
#  'rek': 2714,
#  'buku': 605,
#  'tabungandengan': 3168,
#  'nyangkut': 2260,
#  'expedisi': 1037,
#  'telusur': 3226,
#  'sakit': 2822,
#  'sembuh': 2950,
#  'datang': 799,
#  'paro': 2406,
#  'titip': 3332,
#  'jamin': 1381,
#  'paham': 2362,
#  'hack': 1191,
#  'login': 1873,
#  'jambi': 1380,
#  'jakarta': 1373,
#  'janggal': 1382,
#  'contak': 733,
#  'pasti': 2419,
#  'viral': 3523,
#  'sebentar': 2890,
#  'bahasa': 260,
#  'adminnya': 38,
#  'sopan': 3083,
#  'preman': 2606,
#  'komen': 1637,
#  'tks': 3333,
#  'bingung': 454,
#  'asih': 218,
#  'feedback': 1060,
#  'tlol': 3336,
#  'responya': 2753,
#  'upload': 3485,
#  'kuras': 1712,
#  'kategori': 1511,
#  'kak': 1475,
#  'form': 1079,
#  'file': 1065,
#  'format': 1082,
#  'xml': 3576,
#  'nanyain': 2158,
#  'komentar': 1638,
#  'asyikasyiknya': 227,
#  'nemu': 2165,
#  'incar': 1302,
#  'eh': 984,
#  'popupiklan': 2591,
#  'emas': 1000,
#  'beranda': 390,
#  'banyak': 304,
#  'popup': 2590,
#  'jujur': 1452,
#  'penuh': 2498,
#  'orange': 2326,
#  'koid': 1632,
#  'charge': 692,
#  'puter': 2662,
#  'item': 1358,
#  'money': 2106,
#  'tiket': 3317,
#  'kereta': 1582,
#  'api': 182,
#  'bisa': 463,
#  'benerin': 379,
#  'log': 1872,
#  'tera': 3239,
#  'ah': 51,
#  'setia': 3000,
#  'back': 245,
#  'out': 2344,
#  'bisabolak': 464,
#  'ajatolong': 67,
#  'lapakbisa': 1786,
#  'kelar': 1538,
#  'hari': 1224,
#  'bolak': 510,
#  'blk': 489,
#  'lunaspaylater': 1896,
#  'apapunselalu': 180,
#  'tersambungjawaban': 3276,
#  'agen': 46,
#  'sibuk': 3027,
#  'parahpayah': 2401,
#  'nge': 2177,
#  'freeze': 1092,
#  'kompatible': 1645,
#  'android': 144,
#  'bro': 530,
#  'dinperbaiki': 886,
#  'ganguan': 1125,
#  'langgam': 1775,
#  'hadehh': 1195,
#  'adil': 32,
#  'kga': 1607,
#  'story': 3115,
#  'pending': 2478,
#  'seru': 2982,
#  'sebu': 2892,
#  'nyata': 2266,
#  'refundnya': 2707,
#  'konplain': 1674,
#  'bukalapaksangat': 576,
#  'digunaakan': 861,
#  'capek': 653,
#  'fungsi': 1095,
#  'pajang': 2367,
#  'doang': 927,
#  'bagi': 249,
#  'cetak': 689,
#  'prin': 2616,
#  'bluetooth': 500,
#  'terimkasih': 3264,
#  'sehat': 2906,
#  'kondisi': 1668,
#  'laksana': 1750,
#  'refound': 2703,
#  'sekalichat': 2911,
#  'bisaenakan': 466,
#  'chip': 706,
#  'shoppee': 3018,
#  'kapandulu': 1495,
#  'pembatalansekarang': 2462,
#  'hilangapk': 1247,
#  'puyeng': 2665,
#  'dibukak': 850,
#  'pantau': 2390,
#  'gera': 1141,
#  'errorbarusan': 1020,
#  'notif': 2232,
#  'pagi': 2361,
#  'kentut': 1572,
#  'ngikngung': 2192,
#  'betah': 437,
#  'komplan': 1658,
#  'beberapakali': 347,
#  'pengin': 2482,
#  'kpotong': 1691,
#  'link': 1854,
#  'bkti': 479,
#  'trnper': 3404,
#  'kadarluarsa': 1468,
#  'pelru': 2459,
#  'perbaikian': 2505,
#  'sangatembantu': 2845,
#  'experssya': 1040,
#  'ecek': 969,
#  'kulir': 1704,
#  'togel': 3343,
#  'keluarsudah': 1548,
#  'kembalibuka': 1559,
#  'sangatsangatsangatsangat': 2846,
#  'bergunasupersupersuper': 402,
#  'parahselalu': 2402,
#  'chatjawaban': 695,
#  'kece': 1522,
#  'bersabaryg': 420,
#  'bankpadahal': 294,
#  'kesel': 1592,
#  'lgsuruh': 1842,
#  'pakaiuang': 2373,
#  'raib': 2670,
#  'maksud': 1920,
#  'kontek': 1681,
#  'bisaitu': 468,
#  'nipubuka': 2215,
#  'burukwoy': 620,
#  'orgbalikin': 2335,
#  'stop': 3113,
#  'bermacammacam': 415,
#  'bebas': 345,
#  'tarik': 3203,
#  'buat': 535,
#  'gkjelasudah': 1151,
#  'spaylater': 3091,
#  'tidaksuruh': 3310,
#  'wajahudah': 3545,
#  'muka': 2123,
#  'jelastetap': 1420,
#  'buramgakjeas': 615,
#  'arah': 209,
#  'diskusi': 906,
#  'wkwkwk': 3572,
#  'vritualacount': 3537,
#  ...}

# %%
#kolom pertama ini berarti jumlah dokumen
#kolom kedua berarti letak katanya
#kolom ketiga hasil dari tf

term_frequency_all = term_fit.transform(Ulasan)
print (term_frequency_all)
# Out:
#   (0, 192)	1
#   (0, 278)	1
#   (0, 452)	2
#   (0, 543)	1
#   (0, 638)	1
#   (0, 879)	1
#   (0, 1016)	1
#   (0, 1069)	1
#   (0, 2233)	1
#   (0, 2369)	1
#   (0, 2416)	2
#   (0, 2764)	2
#   (0, 2781)	1
#   (0, 2823)	2
#   (0, 2825)	1
#   (0, 2929)	1
#   (0, 3033)	1
#   (0, 3051)	1
#   (0, 3388)	1
#   (1, 308)	2
#   (1, 480)	1
#   (1, 712)	1
#   (1, 1378)	2
#   (1, 1660)	1
#   (1, 1663)	1
#   :	:
#   (1296, 3579)	1
#   (1297, 116)	1
#   (1297, 368)	1
#   (1297, 557)	1
#   (1297, 677)	1
#   (1297, 1944)	1
#   (1298, 677)	1
#   (1298, 819)	1
#   (1298, 1614)	1
#   (1298, 1920)	1
#   (1298, 1944)	1
#   (1298, 2332)	1
#   (1298, 3033)	1
#   (1299, 218)	1
#   (1299, 308)	1
#   (1299, 368)	1
#   (1299, 444)	1
#   (1299, 458)	1
#   (1299, 879)	1
#   (1299, 1066)	1
#   (1299, 1614)	1
#   (1299, 1783)	1
#   (1299, 2243)	1
#   (1299, 3359)	1
#   (1299, 3524)	1

# %%
ulasan_tf = Ulasan[1] #memanggil kata pada index ke 1
print (ulasan_tf)
# Out:
# lapor barang terima jam jam segitu barang malam lapor komplrn bl langsung close terima komplenan

# %%
term_frequency = term_fit.transform([ulasan_tf]) #hanya menampilkan hasil document 1
print (term_frequency)
# Out:
#   (0, 308)	2
#   (0, 480)	1
#   (0, 712)	1
#   (0, 1378)	2
#   (0, 1660)	1
#   (0, 1663)	1
#   (0, 1778)	1
#   (0, 1794)	2
#   (0, 1924)	1
#   (0, 2904)	1
#   (0, 3256)	2

# %%
dokumen = term_fit.transform(Ulasan) #hasil perhitungan tf idf dalam 1 doc
tfidf_transformer = TfidfTransformer().fit(dokumen)
print (tfidf_transformer.idf_)

tfidf=tfidf_transformer.transform(term_frequency)
print (tfidf) #hasil manual dengan sistem pyhton
# Out:
# [7.4777413  7.4777413  7.07227619 ... 7.4777413  7.07227619 7.4777413 ]
#   (0, 3256)	0.31776964163383026
#   (0, 2904)	0.2619013524780446
#   (0, 1924)	0.26838688052255577
#   (0, 1794)	0.46547762350289074
#   (0, 1778)	0.17293734538051614
#   (0, 1663)	0.3146084139999691
#   (0, 1660)	0.297549421249155
#   (0, 1378)	0.4133883800267081
#   (0, 712)	0.28544587327336984
#   (0, 480)	0.16325994393772564
#   (0, 308)	0.21280191383198516

# %%
data_label = name_dataframe[["Nama pengguna", "Ulasan_siap", "Sentiment"]]

# %%
data_label["Ulasan_siap"] = data_label["Ulasan_siap"].fillna("tidak ada komentar")
# Out:
# <ipython-input-71-63aa05b24bd2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label["Ulasan_siap"] = data_label["Ulasan_siap"].fillna("tidak ada komentar")

# %%
data_label.to_excel("data_label.xlsx")

# %%
sentimen_data=pd.value_counts(data_label["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["#ccd5ae"])
plt.title('Bar chart')
plt.show()

# %%
plt.figure(figsize=(16, 6))

heatmap = sns.heatmap(name_dataframe.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12)

plt.tight_layout()

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize',
#        'ulasan_ears', 'Ulasan_normalized', 'Ulasan_stop_removed',
#        'Ulasan_Stemmed', 'Ulasan_siap', 'label', 'Subjectivity', 'Polarity',
#        'Sentiment', 'month'],
#       dtype='object')

# %%
train_s3 = data_label[data_label["Sentiment"] == 'Neutral']

# %% [markdown]
# # **Proses visualiasi kata terbanyak dari Neutral**

# %%
train_s3["Ulasan_siap"] = train_s3["Ulasan_siap"].fillna("tidak ada komentar")
# Out:
# <ipython-input-124-fe2b4a0b3676>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s3["Ulasan_siap"] = train_s3["Ulasan_siap"].fillna("tidak ada komentar")

# %%
# Sample text data
all_text_s3 = ' '.join(word for word in train_s3["Ulasan_siap"])

# Exclude specific words
words_to_exclude = ["bukalapak", "and", "other", "words", "to", "exclude"]

# Filter out the excluded words
filtered_text_s3 = ' '.join(word for word in all_text_s3.split() if word.lower() not in words_to_exclude)

# Generate the word cloud
wordcloud = WordCloud(colormap='gist_stern', width=1000, height=1000, mode='RGBA', background_color='white').generate(filtered_text_s3)

# Display the word cloud
plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Word Cloud (Excluding Specific Words)")
plt.show()

# %%
from wordcloud import WordCloud

# %%
train_s0 = data_label[data_label["Sentiment"] == 'Negative']

# %%
train_s0["Ulasan_siap"] = train_s0["Ulasan_siap"].fillna("tidak ada komentar")
# Out:
# <ipython-input-81-dc46e426e77c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s0["Ulasan_siap"] = train_s0["Ulasan_siap"].fillna("tidak ada komentar")

# %%
train_s0
# Out:
#                       Nama pengguna  \
# 4                    Popi Anggraini
# 29                    Syamriza Alam
# 34                findi perda wisma
# 50                       Adityo Nur
# 51                   Dadang Setiaji
# 61                    Mirdad Wangsa
# 153                    Abrar Sinaro
# 172            Dery Riyanto (STARK)
# 227                    agus jatnika
# 293                     AKO Pinrang
# 381                    Ahmad Sahrul
# 412                   Afifur Rohman
# 429         Kaloka Galih Kayu Wangi
# 433                    Bam Hendrian
# 462              Ilham Padka Wijaya
# 501                     imam maliki
# 554                          eH boy
# 640                  Silva Widianti
# 655                        Nursamsi
# 688                   Candra Wijaya
# 704                 Pengguna Google
# 713                     Najwa Jemur
# 729                 Pengguna Google
# 768                 Pengguna Google
# 771                       Hr Tester
# 827                 Pengguna Google
# 876              haidar dabi kataro
# 880                       Fian Syah
# 894                   Farhan Fiddin
# 914                   Dinnss Livina
# 949                 Sugiarto Giarto
# 970                     Ray Purnama
# 980                 Pengguna Google
# 1014                 muhammad Iqbal
# 1056                Pengguna Google
# 1060                Pengguna Google
# 1100              Sondang Panjaitan
# 1149                Pengguna Google
# 1154                  wisnul arifin
# 1208  Infinik smart6 Infinik smart6
# 1211                Pengguna Google
# 1222                 Syahril ikhsan
#
#                                             Ulasan_siap Sentiment
# 4     transfer baca virtual account verifikasi saldo...  Negative
# 29    buka bantu nya bantu memperaulitcall center ny...  Negative
# 34    aplikasi jelek tari saldo dompet rekening ribe...  Negative
# 50    beku alas kalo bekuin akun baik kasih alas jal...  Negative
# 51    saldo dana sambung tibatiba potong voucher gam...  Negative
# 61    rugi beli masak barang bayar nunggunya batal u...  Negative
# 153   promo bebas ongkir tingkat biar tarik langgan ...  Negative
# 172   tangan kirim jam suruh tunggu batalin pesan je...  Negative
# 227   kasih bintang segitu blapak buka detail pesan ...  Negative
# 293   transaksi game bukalapak cepat harga muraspant...  Negative
# 381   playlater kalo hp nomor nya hilang alas ktp pa...  Negative
# 412   aplikasi bagus minus ongkir mahal voucher paka...  Negative
# 429   jual emas bukaemas susah banget banget problem...  Negative
# 433   kesini sistem nya berat ajabanyak sisrem gunab...  Negative
# 462   bukalapak marketplace nya sellerseller tipu ka...  Negative
# 501   hati hubung akun aplkasi iniakun kena hack tra...  Negative
# 554   developer bukalapak lihat aplikasi shopee laza...  Negative
# 640   parah paylater buka lapak limit beku tampa asi...  Negative
# 655   mantap paylater limit paylaternya ditambahin c...  Negative
# 688   aplikasi bangkai belanja barang minggu bayar a...  Negative
# 704   heran aplikasi upload jual barang kaya susahhh...  Negative
# 713   kalo bukalapak rame tampil barang jual bayar i...  Negative
# 729   baik servernya fitur macet traffict diserver j...  Negative
# 768   bukastruk gagal struk identifikasi deteksi dup...  Negative
# 771   aplikasi bagus bantu kendala admin komplain me...  Negative
# 827   kurangtapi suka dwngan tampil bukalapak update...  Negative
# 876   proses konfirmasi nya lamaproses kirim nya lam...  Negative
# 880   barang pesan langsung aju komplain selesai isi...  Negative
# 894   beli emas buka emas tarik alas konekai masalah...  Negative
# 914   pakai pinjol nya kredivo sadis biaya layan rib...  Negative
# 949   kasih bintang paylater susah dapetnya alas nik...  Negative
# 970   hancur aplikasi kali belanja kali uang refund ...  Negative
# 980   baharu akun email username error pakai transak...  Negative
# 1014  verifikasi banget foto ktp gagal nomer telp ot...  Negative
# 1056  bagus sih jual gampang fiturnya mudah lapak op...  Negative
# 1060  bukalapak update beres koneksi bagus wifi kenc...  Negative
# 1100  buka lapak bertangung kembali dana jelas alas ...  Negative
# 1149  baguskarena bukalapak beli voucher game via pu...  Negative
# 1154  aplikasi belanja mepersulit melakukakan ubah d...  Negative
# 1208  bintang deh gagal pinjem alas pinjam tunai akt...  Negative
# 1211  bl transaksi bl nominal nilai ratus juta feedb...  Negative
# 1222  duh deh belanja deh bayar bayar eror kah deh p...  Negative

# %% [markdown]
# # **Proses visualiasi kata terbanyak dari Negatif**

# %%
# Sample text data
all_text_s0 = ' '.join(word for word in train_s0["Ulasan_siap"])

# Exclude specific words
words_to_exclude = ["alas", "and", "other", "words", "to", "exclude"]

# Filter out the excluded words
filtered_text_s0 = ' '.join(word for word in all_text_s0.split() if word.lower() not in words_to_exclude)

# Generate the word cloud
wordcloud = WordCloud(colormap='Reds', width=1000, height=1000, mode='RGBA', background_color='white').generate(filtered_text_s0)

# Display the word cloud
plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Word Cloud (Excluding Specific Words)")
plt.show()

# %% [markdown]
# # **Proses visualiasi kata terbanyak dari Positif**

# %%
train_s1 = data_label[data_label["Sentiment"] == 'Positive']

# %%
train_s1["Ulasan_siap"] = train_s1["Ulasan_siap"].fillna("tidak ada komentar")
# Out:
# <ipython-input-85-d1952b0b5859>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s1["Ulasan_siap"] = train_s1["Ulasan_siap"].fillna("tidak ada komentar")

# %%
train_s1
# Out:
#             Nama pengguna                                        Ulasan_siap  \
# 2                 yOga 04  aplikasi marketplace hancur sistem bukabantuan...
# 11      Christien Denysie  bukalapak paylater aktif kali transaksi bayar ...
# 27              ivan reza  estimasi barang lenceng kupon diskon promo ama...
# 30      Fahmi Nugroho art  iklan halaman pakai klik tinggal bl ribet supe...
# 39          Bella Ariesta  beli token listrik bukalapak lalu virtual acco...
# ...                   ...                                                ...
# 1251         The Infinity              nice belanja jual apa proses mudah tq
# 1255  Danang Eko Prayikno                                   power full pakai
# 1262           Mulfi yadi  mohon bl merespon keluh sykenapa saldo dana di...
# 1276            Nur Cahyo  assalamualaikum wrwb bukalapak mohon direspon ...
# 1292         Solution Bes  adu real live tolong kembali uang masuk bukare...
#
#      Sentiment
# 2     Positive
# 11    Positive
# 27    Positive
# 30    Positive
# 39    Positive
# ...        ...
# 1251  Positive
# 1255  Positive
# 1262  Positive
# 1276  Positive
# 1292  Positive
#
# [163 rows x 3 columns]

# %%
all_text_s1 = ' '.join(word for word in train_s1["Ulasan_siap"])
wordcloud = WordCloud(colormap='Blues', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s1)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Ulasan Positif")
plt.margins(x=0, y=0)
print("Positif words")
plt.show()
# Out:
# Positif words

# %%
data_label['Ulasan_clean'] = data_label['Ulasan_siap'].fillna("tidak ada komentar")
# Out:
# <ipython-input-88-2ed151e306fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['Ulasan_clean'] = data_label['Ulasan_siap'].fillna("tidak ada komentar")

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# # **Mensplit Data Ulasan Siap Dan Data Sentiment**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_siap'], data_label['Sentiment'],
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# %% [markdown]
# # **Melakukan Pembelajaran Melihat Akurasi Dan Mendapatkan Kolom Baru Prediksi**

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(data_label['Ulasan_siap'])

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, data_label['Sentiment'], test_size=0.2, random_state=42)

# Train the Gaussian Naive Bayes classifier on the training set
gnb = GaussianNB()
gnb.fit(X_train.toarray(), y_train)

# Evaluate the classifier on the testing set
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)

# Evaluate the classifier on the testing set
y_pred = gnb.predict(X_test.toarray())
cm = confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))

# Use the classifier to predict the sentiment class for all reviews in the dataset
data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# Save the resulting dataframe to a new CSV file
data_label.to_csv('predicted_sentiment1.csv', index=False)
# Out:
# Accuracy: 0.6115384615384616
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         6
#      Neutral       0.86      0.65      0.74       216
#     Positive       0.25      0.50      0.33        38
#
#     accuracy                           0.61       260
#    macro avg       0.37      0.38      0.36       260
# weighted avg       0.75      0.61      0.66       260
# <ipython-input-92-100d2ce1e090>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# %%
import numpy as np

X_train = X_train.toarray()
X_test = X_test.toarray()

# %% [markdown]
# # **Melihat Akurasi Terbaik**

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# Gaussian Naive Bayes with original data
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_gnb = gnb.predict(X_test)
print('Original Results:')
print(classification_report(y_test, y_gnb))
print(confusion_matrix(y_test, y_gnb))
print('Accuracy with original test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with undersampling mengurangi class
rus = RandomUnderSampler(random_state=1)
X_rus, y_rus = rus.fit_resample(X_train, y_train)
gnb = GaussianNB()
gnb.fit(X_rus, y_rus)
y_gnb = gnb.predict(X_test)
print('Undersampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with undersampling test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with oversampling menggandakan class
smote = SMOTE(random_state=1)
X_smote, y_smote = smote.fit_resample(X_train, y_train)
gnb = GaussianNB()
gnb.fit(X_smote, y_smote)
y_gnb = gnb.predict(X_test)
print('Oversampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with oversampling test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with combined oversampling and undersampling menggandakan dan mengurangi class
rus = RandomUnderSampler(random_state=1)
X_rus, y_rus = rus.fit_resample(X_train, y_train)

smote = SMOTE(random_state=1)
X_smt, y_smt = smote.fit_resample(X_rus, y_rus)

gnb = GaussianNB()
gnb.fit(X_smt, y_smt)
y_gnb = gnb.predict(X_test)
print('Combined Oversampling and Undersampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with combined oversampling and undersampling test data:', accuracy_score(y_test, y_gnb))
# Out:
# Original Results:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         6
#      Neutral       0.86      0.65      0.74       216
#     Positive       0.25      0.50      0.33        38
#
#     accuracy                           0.61       260
#    macro avg       0.37      0.38      0.36       260
# weighted avg       0.75      0.61      0.66       260
#
# [[  0   5   1]
#  [ 20 140  56]
#  [  2  17  19]]
# Accuracy with original test data: 0.6115384615384616
# Undersampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.05      0.50      0.09         6
#      Neutral       0.91      0.53      0.67       216
#     Positive       0.24      0.47      0.32        38
#
#     accuracy                           0.52       260
#    macro avg       0.40      0.50      0.36       260
# weighted avg       0.79      0.52      0.61       260
#
# Accuracy with undersampling test data: 0.5230769230769231
# Oversampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         6
#      Neutral       0.86      0.65      0.74       216
#     Positive       0.25      0.50      0.33        38
#
#     accuracy                           0.61       260
#    macro avg       0.37      0.38      0.36       260
# weighted avg       0.75      0.61      0.66       260
#
# Accuracy with oversampling test data: 0.6115384615384616
# Combined Oversampling and Undersampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.05      0.50      0.09         6
#      Neutral       0.91      0.53      0.67       216
#     Positive       0.24      0.47      0.32        38
#
#     accuracy                           0.52       260
#    macro avg       0.40      0.50      0.36       260
# weighted avg       0.79      0.52      0.61       260
#
# Accuracy with combined oversampling and undersampling test data: 0.5230769230769231

# %%
import numpy as np

# %%
from sklearn.feature_extraction.text import TfidfVectorizer             #menghitung n menjumlah kan dan menjumlah kan tf and n berdasarkan seluruh dokumen
vectorizer = TfidfVectorizer(decode_error='replace', encoding='utf-8')

# %%
data_label['predicted_sentiment_class'].value_counts()
# Out:
# Neutral     929
# Positive    266
# Negative    105
# Name: predicted_sentiment_class, dtype: int64

# %% [markdown]
# # **VISUALISASI Hasil Prediksi**

# %%
data_label['predicted_sentiment_class'].hist()
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# # **CrossValidation gaussion naive bayes**

# %% [markdown]
# ![10-K-Fold-Cross-Validation.png](data:image/png;base64,...)

# %% [markdown]
# **sample random**
#
# mengambil secara acak dari daftar sample atau sampling frame yang tersedia setiap individu memiliki peluang yang sama untuk terpilih
# peluang tersebut ada melakukan peluang sama ketika mempunyai data besar akan memliki peluang lebih besar untuk terpilih tetapi sebaliknya ketika mempunyai data dikit dapat peluang lebih sedikit

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_siap'], data_label['Sentiment'],
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# Vectorize the text data
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# Create the Naive Bayes Classifier object
gnb = GaussianNB()

# Perform cross-validation
scores = cross_val_score(gnb, X_train.toarray(), y_train, cv=5)

# Print the cross-validation scores
print('Cross-validation scores:', scores)

# Fit the classifier to the training data
gnb.fit(X_train.toarray(), y_train)

# Predict the sentiment of the test data
y_pred = gnb.predict(X_test.toarray())

# Print the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:\n', conf_matrix)
# Out:
# Cross-validation scores: [0.62393162 0.5982906  0.5982906  0.64102564 0.62820513]
# Confusion Matrix:
#  [[ 0  3  1]
#  [14 63 33]
#  [ 0 10  6]]

# %%
# Convert sparse matrix to dense numpy array
X_train_dense = X_train.toarray()
X_test_dense = X_test.toarray()

# Print the scores on the training and test sets
print('Training set score: {:.4f}'.format(gnb.score(X_train_dense, y_train)))
print('Test set score: {:.4f}'.format(gnb.score(X_test_dense, y_test)))

#ternyata permasalahannya bukan traning tapi test set score nya 0.50%
# Out:
# Training set score: 0.8786
# Test set score: 0.5308

# %%
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.5307692307692308

# %%
vectorizer
# Out:
# TfidfVectorizer()

# %%
nb = GaussianNB(var_smoothing=1.0) # untuk tidak overviting

# %% [markdown]
# # **Data Prediksi**

# %%
data_label.tail(100)
# Out:
#             Nama pengguna                                        Ulasan_siap  \
# 1200         Neymar Akbar  aplikasi oke kurir nya bagus kirim pick up uba...
# 1201  mramdani ncexlionel                       pleleter susah daftar blanja
# 1202      Pengguna Google  buka lapak munculin iklan notifikasi mana apli...
# 1203          Anto Jabrik  guna bukalapak perhati makain kesini menu faed...
# 1204      Pengguna Google  tolong mati iklan muncul buka aplikasi ganggu ...
# ...                   ...                                                ...
# 1295        Totok Sunarno             bantu butuh kitaterima kasih bukalapak
# 1296     Arif Nur Pramono                          barang iklan ya hapus aja
# 1297      JebodZz Channel          mantap cepat alhamdulillah bukalapak beli
# 1298           king black        kirim maksud cepat sih oren mantap deploper
# 1299      Muhammad Fandri  beli barang kirim tolong filter dikit asih lap...
#
#      Sentiment                                       Ulasan_clean  \
# 1200   Neutral  aplikasi oke kurir nya bagus kirim pick up uba...
# 1201   Neutral                       pleleter susah daftar blanja
# 1202   Neutral  buka lapak munculin iklan notifikasi mana apli...
# 1203   Neutral  guna bukalapak perhati makain kesini menu faed...
# 1204   Neutral  tolong mati iklan muncul buka aplikasi ganggu ...
# ...        ...                                                ...
# 1295   Neutral             bantu butuh kitaterima kasih bukalapak
# 1296   Neutral                          barang iklan ya hapus aja
# 1297   Neutral          mantap cepat alhamdulillah bukalapak beli
# 1298   Neutral        kirim maksud cepat sih oren mantap deploper
# 1299   Neutral  beli barang kirim tolong filter dikit asih lap...
#
#      predicted_sentiment_class
# 1200                   Neutral
# 1201                   Neutral
# 1202                   Neutral
# 1203                   Neutral
# 1204                   Neutral
# ...                        ...
# 1295                   Neutral
# 1296                   Neutral
# 1297                  Positive
# 1298                   Neutral
# 1299                   Neutral
#
# [100 rows x 5 columns]

# %%
X_test
# Out:
# <130x3367 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1432 stored elements in Compressed Sparse Row format>

# %%
X_train
# Out:
# <1170x3367 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16244 stored elements in Compressed Sparse Row format>

# %%
y_test
# Out:
# 432      Neutral
# 90       Neutral
# 817      Neutral
# 1161     Neutral
# 531      Neutral
#           ...
# 785      Neutral
# 444     Positive
# 895      Neutral
# 326     Positive
# 757      Neutral
# Name: Sentiment, Length: 130, dtype: object

# %%
y_train
# Out:
# 40      Positive
# 1192     Neutral
# 598      Neutral
# 0        Neutral
# 847      Neutral
#           ...
# 988     Positive
# 215     Positive
# 1159     Neutral
# 716      Neutral
# 136      Neutral
# Name: Sentiment, Length: 1170, dtype: object

# %%
print(y_train)
# Out:
# 40      Positive
# 1192     Neutral
# 598      Neutral
# 0        Neutral
# 847      Neutral
#           ...
# 988     Positive
# 215     Positive
# 1159     Neutral
# 716      Neutral
# 136      Neutral
# Name: Sentiment, Length: 1170, dtype: object

# %% [markdown]
# # **CONFIUSIN MATRIK**
# melihat seberapa baik distribusi dari setiap kelas

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, classification_report
import pandas as pd

# Assuming you have loaded the data into the 'data_label' DataFrame.

# Initialize the CountVectorizer
vectorizer = CountVectorizer()

# Transform the text data into numerical feature vectors
X = vectorizer.fit_transform(data_label['Ulasan_siap'])

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, data_label['Sentiment'], test_size=0.3, random_state=42)

# Train the Gaussian Naive Bayes classifier on the training set
gnb = GaussianNB()
gnb.fit(X_train.toarray(), y_train)

# Evaluate the classifier on the testing set
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)

# Evaluate the classifier on the testing set
y_pred = gnb.predict(X_test.toarray())

# Get the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Print the confusion matrix
print("Confusion Matrix:")
print(cm)

# Print classification report with precision, recall, F1-score for each class
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Use the classifier to predict the sentiment class for all reviews in the dataset
data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# Save the resulting dataframe to a new CSV file
data_label.to_csv('predicted_sentiment1.csv', index=False)
# Out:
# Accuracy: 0.6461538461538462
# Confusion Matrix:
# [[  0   9   2]
#  [ 27 222  76]
#  [  2  22  30]]
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00        11
#      Neutral       0.88      0.68      0.77       325
#     Positive       0.28      0.56      0.37        54
#
#     accuracy                           0.65       390
#    macro avg       0.39      0.41      0.38       390
# weighted avg       0.77      0.65      0.69       390
# <ipython-input-111-27db70896ee7>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())
