# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafiryd/Rafiryd/blob/rafiryd/skripsi19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Referensi: https://www.linkedin.com/pulse/how-scrape-google-play-reviews-4-simple-steps-using-python-kundi/

# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

import seaborn as sns

# %%
#Scrape desired number of reviews
#Run kode ini jika ingin scrape data dengan jumlah tertentu. Ganti (misal, ingin scrape sejumlah 1000, maka ganti kode , count = 1000 )

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.bukalapak.android',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=1300, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %% [markdown]
# Problems slovlig tools = mencari akar permasalahan pada suatu masalah
#
# 5 why
#
# metode mencari problems sloving dengan cara menanyakan apa penyebab permasalahaan muncul dan mencari jawabannya. hal ini di lakUkan berkali klai sampai permasalahan dapat tergambar dengan jelas
#
# action priority
#
# diagram yang dapat di gunakan untuk mencari prioritas masalah berdasarkan impact atas benefit yang bisa diberikan dengan diagram ini kita memilih masalah yang impactnya mayoritas dari permasalahan yang ada.
#
# fishbone digram
#
# digram yang dapat di gunakan untuk merinci masalah dan membantu mencari akar masalah yang dapat dilihat dari beberapa point of view
#
# flowchart/algo
#
# metode pemecahan masalah dengan cara memetakan flow atau membuat pseudo algoritma yang untuk menentukan masalah dan cara untuk mencari solusinya secara sistematis

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId                          userName  \
# 0  f2e26548-83d2-4bcf-bac3-6dc9db1cb12d                      Nizar Rayyan
# 1  9d6aac3b-63cf-4144-9b4e-c94d291d808a  dedy kelana (CV PRIBUMI BANGKIT)
# 2  69ef4cd3-e71e-4383-9f34-d9e3fc959987                      Rika Riyanti
# 3  cc641f6a-2765-4d72-9d47-24594dc4f32a                     Afifur Rohman
# 4  8b78cd2a-ec29-442d-b42c-d9d3a2a841c0                        Yuni Artha
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ACB-R...
# 1  https://play-lh.googleusercontent.com/a/AGNmyx...
# 2  https://play-lh.googleusercontent.com/a/AGNmyx...
# 3  https://play-lh.googleusercontent.com/a-/ACB-R...
# 4  https://play-lh.googleusercontent.com/a/AGNmyx...
#
#                                              content  score  thumbsUpCount  \
# 0  Paylater ngk bener.. selalu di batalkan otomat...      1             85
# 1  pastinya bukan hp dan wifi saya yang lemmooott...      1            154
# 2  Sangat membantu sekali bukalapak, tapi sudah s...      5             60
# 3  Sebenarnya aplikasi ini cukup bagus. Cuma ada ...      1              4
# 4  BUKALAPAK semakin parah.. Pesanan tgl 5 April,...      1             29
#
#   reviewCreatedVersion                  at  \
# 0               5.31.3 2023-04-16 23:03:31
# 1               5.30.2 2023-03-25 10:26:56
# 2               5.31.3 2023-04-11 13:30:31
# 3               5.31.3 2023-04-26 08:16:00
# 4               5.31.3 2023-04-13 19:30:16
#
#                                         replyContent           repliedAt  \
# 0  Hai, mohon maaf atas ketidaknyamanannya. Jika ... 2020-03-06 11:44:30
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4                                               None                 NaT
#
#   appVersion
# 0     5.31.3
# 1     5.30.2
# 2     5.31.3
# 3     5.31.3
# 4     5.31.3

# %%
len(df_busu.index) #count the number of data we got
# Out:
# 1300

# %%
df_busu[['userName', 'score','at', 'content']].tail()  #preview userName, rating, date-time, and reviews only
# Out:
#              userName  score                  at  \
# 1295  Pengguna Google      1 2019-05-12 10:33:31
# 1296    Rinto Martadi      1 2023-02-02 10:16:53
# 1297   nursito gendut      5 2022-12-08 13:00:45
# 1298      agus rianto      5 2023-04-14 02:13:14
# 1299  Pengguna Google      5 2020-04-23 01:55:46
#
#                                                 content
# 1295  Satu dulu ya bintangnya nanti kalo sdh normal ...
# 1296  Berhenti lah belanja di Bukalapak..... Makin b...
# 1297  saya sdh dari dulu pakai aplikasi buka lapak d...
# 1298                          Sangat mudah bertransaksi
# 1299  Bagus aplikasi menguntungkan hampir semua bara...

# %%
name_dataframe = df_busu.loc[:,["userName", "score", "at", "content"]]
name_dataframe.rename(columns={"userName": "Nama pengguna", "score":"Rating", "at": "Date", "content": "Ulasan"}, inplace=True)

# %%
name_dataframe.tail()
# Out:
#         Nama pengguna  Rating                Date  \
# 1295  Pengguna Google       1 2019-05-12 10:33:31
# 1296    Rinto Martadi       1 2023-02-02 10:16:53
# 1297   nursito gendut       5 2022-12-08 13:00:45
# 1298      agus rianto       5 2023-04-14 02:13:14
# 1299  Pengguna Google       5 2020-04-23 01:55:46
#
#                                                  Ulasan
# 1295  Satu dulu ya bintangnya nanti kalo sdh normal ...
# 1296  Berhenti lah belanja di Bukalapak..... Makin b...
# 1297  saya sdh dari dulu pakai aplikasi buka lapak d...
# 1298                          Sangat mudah bertransaksi
# 1299  Bagus aplikasi menguntungkan hampir semua bara...

# %%
name_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nama pengguna  1300 non-null   object
#  1   Rating         1300 non-null   int64
#  2   Date           1300 non-null   datetime64[ns]
#  3   Ulasan         1300 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 40.8+ KB

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].astype(str)
name_dataframe.head()
# Out:
#                       Nama pengguna  Rating                Date  \
# 0                      Nizar Rayyan       1 2023-04-16 23:03:31
# 1  dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 2                      Rika Riyanti       5 2023-04-11 13:30:31
# 3                     Afifur Rohman       1 2023-04-26 08:16:00
# 4                        Yuni Artha       1 2023-04-13 19:30:16
#
#                                               Ulasan
# 0  Paylater ngk bener.. selalu di batalkan otomat...
# 1  pastinya bukan hp dan wifi saya yang lemmooott...
# 2  Sangat membantu sekali bukalapak, tapi sudah s...
# 3  Sebenarnya aplikasi ini cukup bagus. Cuma ada ...
# 4  BUKALAPAK semakin parah.. Pesanan tgl 5 April,...

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].str.lower()

# %%
import string 
import re 
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

def remove_links(text):
    # menghapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus URL
    return text.replace("http://", " ").replace("https://", " ")
                
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_links)

# %%
#menghapus number
def remove_number(text):
    return  re.sub(r"\d+", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_number)

# %%
#menghapus punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_punctuation)

# %%
# menghapus single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_singl_char)

# %%
# Tokenisasi 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

name_dataframe['Ulasan_tokenize'] = name_dataframe['Ulasan'].apply(word_tokenize_wrapper)

# %%
name_dataframe
# Out:
#                          Nama pengguna  Rating                Date  \
# 0                         Nizar Rayyan       1 2023-04-16 23:03:31
# 1     dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 2                         Rika Riyanti       5 2023-04-11 13:30:31
# 3                        Afifur Rohman       1 2023-04-26 08:16:00
# 4                           Yuni Artha       1 2023-04-13 19:30:16
# ...                                ...     ...                 ...
# 1295                   Pengguna Google       1 2019-05-12 10:33:31
# 1296                     Rinto Martadi       1 2023-02-02 10:16:53
# 1297                    nursito gendut       5 2022-12-08 13:00:45
# 1298                       agus rianto       5 2023-04-14 02:13:14
# 1299                   Pengguna Google       5 2020-04-23 01:55:46
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     pastinya bukan hp dan wifi saya yang lemmooott...
# 2     sangat membantu sekali bukalapak tapi sudah sa...
# 3     sebenarnya aplikasi ini cukup bagus cuma ada b...
# 4     bukalapak semakin parah pesanan tgl   april di...
# ...                                                 ...
# 1295  satu dulu ya bintangnya nanti kalo sdh normal ...
# 1296  berhenti lah belanja di bukalapak makin banyak...
# 1297  saya sdh dari dulu pakai aplikasi buka lapak d...
# 1298                          sangat mudah bertransaksi
# 1299  bagus aplikasi menguntungkan hampir semua bara...
#
#                                         Ulasan_tokenize
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2     [sangat, membantu, sekali, bukalapak, tapi, su...
# 3     [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4     [bukalapak, semakin, parah, pesanan, tgl, apri...
# ...                                                 ...
# 1295  [satu, dulu, ya, bintangnya, nanti, kalo, sdh,...
# 1296  [berhenti, lah, belanja, di, bukalapak, makin,...
# 1297  [saya, sdh, dari, dulu, pakai, aplikasi, buka,...
# 1298                      [sangat, mudah, bertransaksi]
# 1299  [bagus, aplikasi, menguntungkan, hampir, semua...
#
# [1300 rows x 5 columns]

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize'], dtype='object')

# %%
#Run This Code to Sort the Data By Date 
# tanggal 26-04-2022 sampai 12-10-2022

new_df = name_dataframe[['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize']]
sorted_df = new_df.sort_values(by='Date', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#        Nama pengguna  Rating                Date  \
# 255   I LOVE MUKBANG       5 2023-04-28 13:08:04
# 10   Kaliri Alwariji       4 2023-04-28 13:05:41
# 39          Sudrajat       2 2023-04-28 11:39:46
# 912       Supri Anto       5 2023-04-28 09:59:47
# 102      Iqbal Khoir       4 2023-04-28 07:13:47
#
#                                                 Ulasan  \
# 255  belanja di buka lapak puas mudah dan cepat no ...
# 10   sekarang banyak iklannya jadi loadingnya lama ...
# 39   tolong dong begitu barang sudah di terima sama...
# 912  tolong dong kasih jatuh temponya   bulan dan b...
# 102  terimakasih bukalapak sudah menindaklanjuti ke...
#
#                                        Ulasan_tokenize
# 255  [belanja, di, buka, lapak, puas, mudah, dan, c...
# 10   [sekarang, banyak, iklannya, jadi, loadingnya,...
# 39   [tolong, dong, begitu, barang, sudah, di, teri...
# 912  [tolong, dong, kasih, jatuh, temponya, bulan, ...
# 102  [terimakasih, bukalapak, sudah, menindaklanjut...

# %%
sorted_df.dtypes
# Out:
# Nama pengguna              object
# Rating                      int64
# Date               datetime64[ns]
# Ulasan                     object
# Ulasan_tokenize            object
# dtype: object

# %%
# Menghitung Distibusi Persebaran Kata
def freqDist_wrapper(text):
    return FreqDist(text)

Ulasan_fqsist = name_dataframe['Ulasan_tokenize'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(Ulasan_fqsist.head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(tidak, 4), (di, 3), (nya, 3), (kadang, 2), (...
# 1    [(dan, 3), (saya, 3), (mau, 3), (yang, 2), (se...
# 2    [(sangat, 2), (sekali, 2), (bukalapak, 2), (ta...
# 3    [(sebenarnya, 1), (aplikasi, 1), (ini, 1), (cu...
# 4    [(april, 3), (di, 3), (dengan, 3), (bukalapak,...
# Name: Ulasan_tokenize, dtype: object

# %%
name_dataframe['Ulasan_tokenize'].unique
# Out:
# <bound method Series.unique of 0       [paylater, ngk, bener, selalu, di, batalkan, o...
# 1       [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2       [sangat, membantu, sekali, bukalapak, tapi, su...
# 3       [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4       [bukalapak, semakin, parah, pesanan, tgl, apri...
#                               ...
# 1295    [satu, dulu, ya, bintangnya, nanti, kalo, sdh,...
# 1296    [berhenti, lah, belanja, di, bukalapak, makin,...
# 1297    [saya, sdh, dari, dulu, pakai, aplikasi, buka,...
# 1298                        [sangat, mudah, bertransaksi]
# 1299    [bagus, aplikasi, menguntungkan, hampir, semua...
# Name: Ulasan_tokenize, Length: 1300, dtype: object>

# %%
slank_word_dict = {
    "berjalansudah" : "berjalan",
    "paraah" : "parah",
    "keduakali" : "",
    "keduakali" : "kedua kali",
    "agak" : "sedikit",
    "pas" : "saat",
    "produkx" : "produknya",
    "sukamkasih" : "suka makasih",
    "gak" : "tidak",
    "cpt" : "cepat",
    "sdh" : "sudah",
    "recommend" : "rekomendasi",
    "bagusseller" : "bagus",
    "bagusssss" : "bagus",
    "bagussssss" : "bagus",
    "baguuussss" : "bagus",
    "cepatmakasih": "cepat",
    "cepatmantappp": "cepat",
    "cepatproduct": "cepat",
    "cepatrecomended": "cepat",
    "cepattoko": "cepat",
    "recomended": "rekomendasi",
    "recommended": "rekomendasi",
    "rekomendasi": "rekomendasi",
    "rekomended": "rekomendasi",
    }

def slank_normalized_term(document):
    return [slank_word_dict[term] if term in slank_word_dict else term for term in document]

# %%
normalizad_word = pd.read_csv("/content/kamusindonesia.csv.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

# %%
name_dataframe['Ulasan_normalized'] = name_dataframe['Ulasan_tokenize'].apply(normalized_term).apply(slank_normalized_term)

# %%
name_dataframe
# Out:
#                          Nama pengguna  Rating                Date  \
# 0                         Nizar Rayyan       1 2023-04-16 23:03:31
# 1     dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 2                         Rika Riyanti       5 2023-04-11 13:30:31
# 3                        Afifur Rohman       1 2023-04-26 08:16:00
# 4                           Yuni Artha       1 2023-04-13 19:30:16
# ...                                ...     ...                 ...
# 1295                   Pengguna Google       1 2019-05-12 10:33:31
# 1296                     Rinto Martadi       1 2023-02-02 10:16:53
# 1297                    nursito gendut       5 2022-12-08 13:00:45
# 1298                       agus rianto       5 2023-04-14 02:13:14
# 1299                   Pengguna Google       5 2020-04-23 01:55:46
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     pastinya bukan hp dan wifi saya yang lemmooott...
# 2     sangat membantu sekali bukalapak tapi sudah sa...
# 3     sebenarnya aplikasi ini cukup bagus cuma ada b...
# 4     bukalapak semakin parah pesanan tgl   april di...
# ...                                                 ...
# 1295  satu dulu ya bintangnya nanti kalo sdh normal ...
# 1296  berhenti lah belanja di bukalapak makin banyak...
# 1297  saya sdh dari dulu pakai aplikasi buka lapak d...
# 1298                          sangat mudah bertransaksi
# 1299  bagus aplikasi menguntungkan hampir semua bara...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2     [sangat, membantu, sekali, bukalapak, tapi, su...
# 3     [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4     [bukalapak, semakin, parah, pesanan, tgl, apri...
# ...                                                 ...
# 1295  [satu, dulu, ya, bintangnya, nanti, kalo, sdh,...
# 1296  [berhenti, lah, belanja, di, bukalapak, makin,...
# 1297  [saya, sdh, dari, dulu, pakai, aplikasi, buka,...
# 1298                      [sangat, mudah, bertransaksi]
# 1299  [bagus, aplikasi, menguntungkan, hampir, semua...
#
#                                       Ulasan_normalized
# 0     [paylater, enggak, benar, selalu, di, batalkan...
# 1     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2     [sangat, membantu, sekali, bukalapak, tapi, su...
# 3     [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4     [bukalapak, semakin, parah, pesanan, tanggal, ...
# ...                                                 ...
# 1295  [satu, dulu, ya, bintangnya, nanti, kalo, suda...
# 1296  [berhenti, lah, belanja, di, bukalapak, makin,...
# 1297  [saya, sudah, dari, dulu, pakai, aplikasi, buk...
# 1298                      [sangat, mudah, bertransaksi]
# 1299  [bagus, aplikasi, menguntungkan, hampir, semua...
#
# [1300 rows x 6 columns]

# %%
name_dataframe['Ulasan_normalized'].unique
# Out:
# <bound method Series.unique of 0       [paylater, enggak, benar, selalu, di, batalkan...
# 1       [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2       [sangat, membantu, sekali, bukalapak, tapi, su...
# 3       [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4       [bukalapak, semakin, parah, pesanan, tanggal, ...
#                               ...
# 1295    [satu, dulu, ya, bintangnya, nanti, kalo, suda...
# 1296    [berhenti, lah, belanja, di, bukalapak, makin,...
# 1297    [saya, sudah, dari, dulu, pakai, aplikasi, buk...
# 1298                        [sangat, mudah, bertransaksi]
# 1299    [bagus, aplikasi, menguntungkan, hampir, semua...
# Name: Ulasan_normalized, Length: 1300, dtype: object>

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

name_dataframe['Ulasan_stop_removed'] = name_dataframe['Ulasan_normalized'].apply(stopwords_removal)

# %%
name_dataframe
# Out:
#                          Nama pengguna  Rating                Date  \
# 0                         Nizar Rayyan       1 2023-04-16 23:03:31
# 1     dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 2                         Rika Riyanti       5 2023-04-11 13:30:31
# 3                        Afifur Rohman       1 2023-04-26 08:16:00
# 4                           Yuni Artha       1 2023-04-13 19:30:16
# ...                                ...     ...                 ...
# 1295                   Pengguna Google       1 2019-05-12 10:33:31
# 1296                     Rinto Martadi       1 2023-02-02 10:16:53
# 1297                    nursito gendut       5 2022-12-08 13:00:45
# 1298                       agus rianto       5 2023-04-14 02:13:14
# 1299                   Pengguna Google       5 2020-04-23 01:55:46
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     pastinya bukan hp dan wifi saya yang lemmooott...
# 2     sangat membantu sekali bukalapak tapi sudah sa...
# 3     sebenarnya aplikasi ini cukup bagus cuma ada b...
# 4     bukalapak semakin parah pesanan tgl   april di...
# ...                                                 ...
# 1295  satu dulu ya bintangnya nanti kalo sdh normal ...
# 1296  berhenti lah belanja di bukalapak makin banyak...
# 1297  saya sdh dari dulu pakai aplikasi buka lapak d...
# 1298                          sangat mudah bertransaksi
# 1299  bagus aplikasi menguntungkan hampir semua bara...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2     [sangat, membantu, sekali, bukalapak, tapi, su...
# 3     [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4     [bukalapak, semakin, parah, pesanan, tgl, apri...
# ...                                                 ...
# 1295  [satu, dulu, ya, bintangnya, nanti, kalo, sdh,...
# 1296  [berhenti, lah, belanja, di, bukalapak, makin,...
# 1297  [saya, sdh, dari, dulu, pakai, aplikasi, buka,...
# 1298                      [sangat, mudah, bertransaksi]
# 1299  [bagus, aplikasi, menguntungkan, hampir, semua...
#
#                                       Ulasan_normalized  \
# 0     [paylater, enggak, benar, selalu, di, batalkan...
# 1     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2     [sangat, membantu, sekali, bukalapak, tapi, su...
# 3     [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4     [bukalapak, semakin, parah, pesanan, tanggal, ...
# ...                                                 ...
# 1295  [satu, dulu, ya, bintangnya, nanti, kalo, suda...
# 1296  [berhenti, lah, belanja, di, bukalapak, makin,...
# 1297  [saya, sudah, dari, dulu, pakai, aplikasi, buk...
# 1298                      [sangat, mudah, bertransaksi]
# 1299  [bagus, aplikasi, menguntungkan, hampir, semua...
#
#                                     Ulasan_stop_removed
# 0     [paylater, batalkan, otomatis, kadang, nya, ga...
# 1     [pastinya, hp, wifi, lemmooottttt, dasarnya, b...
# 2     [membantu, bukalapak, pelanggan, paylater, pem...
# 3     [aplikasi, bagus, minusnya, ongkir, mahal, vou...
# 4     [bukalapak, parah, pesanan, tanggal, april, di...
# ...                                                 ...
# 1295  [ya, bintangnya, kalo, normal, app, blnya, dit...
# 1296  [berhenti, belanja, bukalapak, pelapak, amanah...
# 1297  [pakai, aplikasi, buka, lapak, puas, layananny...
# 1298                              [mudah, bertransaksi]
# 1299  [bagus, aplikasi, menguntungkan, barang, buka,...
#
# [1300 rows x 7 columns]

# %%
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting swifter
#   Downloading swifter-1.3.4.tar.gz (830 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 830.9/830.9 kB 11.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (1.5.3)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.10/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2022.12.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (4.65.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (7.7.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from swifter) (2.2.1)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from swifter) (6.0.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.4.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (8.1.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (23.1)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2023.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.22.4)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (5.7.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (3.0.7)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (7.34.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1.12)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.14.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (3.0.38)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 47.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (67.7.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (6.4.8)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (23.2.1)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.17.1)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.6)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.3.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.3.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (6.5.4)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.16.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.1.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.8.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.1.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.11.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.9.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (23.1.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.21)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.3.4-py3-none-any.whl size=16321 sha256=2ebb61e716d5143be8848fad68e70b077357cb7e6db34032c9e1cebb9680d330
#   Stored in directory: /root/.cache/pip/wheels/6c/bd/3e/2d6afc9bc36c9975f8e4215a270bbac6580c4361ebd6bb2323
# Successfully built swifter
# Installing collected packages: jedi, swifter
# Successfully installed jedi-0.18.2 swifter-1.3.4

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in name_dataframe['Ulasan_stop_removed']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

name_dataframe['Ulasan_Stemmed'] = name_dataframe['Ulasan_stop_removed'].swifter.apply(get_stemmed_term)
# Out:
# 4558
# ------------------------
# paylater : paylater
# batalkan : batal
# otomatis : otomatis
# kadang : kadang
# nya : nya
# gantian : ganti
# jatuh : jatuh
# tempo : tempo
# bayar : bayar
# biaya : biaya
# keterlambatan : lambat
# layanan : layan
# biar : biar
# merasakan : rasa
# rasakan : rasa
# sistem : sistem
# seenak : enak
# chat : chat
# susah : susah
# error : error
# menyalahkan : salah
# bikin : bikin
# pusing : pusing
# pastinya : pasti
# hp : hp
# wifi : wifi
# lemmooottttt : lemmooottttt
# dasarnya : dasar
# bukalapak : bukalapak
# karuan : karuan
# lihat : lihat
# status : status
# transsaksi : transsaksi
# menunggu : tunggu
# halaman : halaman
# terisi : isi
# penuh : penuh
# muncul : muncul
# penawaran : tawar
# tanda : tanda
# kesulitan : sulit
# terbaca : baca
# kepencet : pencet
# bulalapak : bulalapak
# bermain : main
# paket : paket
# data : data
# orang : orang
# konten : konten
# webnya : webnya
# lumayan : lumayan
# hasilnya : hasil
# semoga : moga
# kecurigaan : curiga
# maafkan : maaf
# membantu : bantu
# pelanggan : langgan
# pembayaran : bayar
# limit : limit
# bertambah : tambah
# profesional : profesional
# maju : maju
# aplikasi : aplikasi
# bagus : bagus
# minusnya : minus
# ongkir : ongkir
# mahal : mahal
# voucher : voucher
# dipakai : pakai
# memenuhi : penuh
# persyaratan : syarat
# pilihan : pilih
# jasa : jasa
# ekspedisi : ekspedisi
# parah : parah
# pesanan : pesan
# tanggal : tanggal
# april : april
# dikirim : kirim
# pelapak : lapak
# barang : barang
# simpan : simpan
# gudang : gudang
# bukaexpress : bukaexpress
# buka : buka
# bantuan : bantu
# menu : menu
# livechat : livechat
# berfungsi : fungsi
# beda : beda
# merchant : merchant
# kecewa : kecewa
# jual : jual
# emas : emas
# bukaemas : bukaemas
# banget : banget
# problemnya : problem
# verifikasi : verifikasi
# no : no
# bad : bad
# gateway : gateway
# kode : kode
# enggak bisa : enggak bisa
# ulang : ulang
# kayaknya : kayak
# sengaja : sengaja
# dipersulit : sulit
# tarik : tarik
# investasi : investasi
# app : app
# berat : berat
# fitur : fitur
# kebanyakan : banyak
# rusak : rusak
# tolong : tolong
# dibikin : bikin
# simpel : simpel
# solusi : solusi
# bukabantuan : bukabantuan
# live : live
# jam : jam
# cs : cs
# mematikan : mati
# obrolannya : obrol
# aktifin : aktifin
# akun : akun
# hangus : hangus
# terverifikasi : verifikasi
# kyc : kyc
# sory : sory
# ane : ane
# uninstall : uninstall
# join : join
# seller : seller
# deh : deh
# bl : bl
# kepercayan : kepercayan
# ecom : ecom
# utama : utama
# transaksi : transaksi
# aktifasi : aktifasi
# gampang : gampang
# komplin : komplin
# sumpah : sumpah
# enek : enek
# masak : masak
# kirim : kirim
# otp : otp
# nomer : nomer
# aktif : aktif
# email : email
# sefty : sefty
# main : main
# lo : lo
# nyataanya : nyataanya
# nomor : nomor
# nomornya : nomor
# aktivasi : aktivasi
# ya : ya
# ampun : ampun
# syaratnya : syarat
# kayak : kayak
# mengajukan : aju
# pinjaman : pinjam
# bank : bank
# sumpaah : sumpaah
# oohh : oohh
# devlover : devlover
# lebay : lebay
# syarat : syarat
# pengin : pengin
# masuk : masuk
# dikirimkan : kirim
# ganti : ganti
# foto : foto
# ktprekening : ktprekening
# daftar : daftar
# pakai : pakai
# ktp : ktp
# rekening : rekening
# seribet : seribet
# kah : kah
# cantumin : cantumin
# keterangan : terang
# diubah : ubah
# memasukkan : masuk
# terima : terima
# tipenyasaya : tipenyasaya
# komplain : komplain
# admin : admin
# menyelesaikan : selesai
# rugi : rugi
# menerima : terima
# hilang : hilang
# uang : uang
# iklannya : iklan
# loadingnya : loadingnya
# membuka : buka
# lapak : lapak
# ngechek : ngechek
# pengiriman : kirim
# loading : loading
# iklan : iklan
# mohon : mohon
# nyaman : nyaman
# kuota : kuota
# internetdi : internetdi
# nglungker : nglungker
# jenuhtlg : jenuhtlg
# perhatikan : perhati
# jelek : jelek
# aplikasinya : aplikasi
# lemot : lot
# mengadu : adu
# langsung : langsung
# bertele : tele
# kesana : kesana
# kemari : kemari
# coba : coba
# kasih : kasih
# tinggal : tinggal
# klik : klik
# cari : cari
# sulit : sulit
# cuman : cuman
# dikit : dikit
# barangnya : barang
# kalah : kalah
# bukalapakygdulu : bukalapakygdulu
# ribuan : ribu
# upload : upload
# cumq : cumq
# tampil : tampil
# pencarian : cari
# kalo : kalo
# temukan : temu
# gaya : gaya
# pembeli : beli
# sepi : sepi
# pengunjung : unjung
# kesini : kesini
# ajabanyak : ajabanyak
# sisrem : sisrem
# gunabuka : gunabuka
# apk : apk
# kaya : kaya
# game : game
# ajaisi : ajaisi
# harap : harap
# buang : buang
# ajadan : ajadan
# bagusmasuk : bagusmasuk
# ribetnya : ribetnya
# aneh : aneh
# didownload : didownload
# touch : touch
# dihapus : hapus
# az : az
# merepotkan : repot
# batal : batal
# proses : proses
# statusnya : status
# penjual : jual
# kadaluarsamau : kadaluarsamau
# komplen : komplen
# ambil : ambil
# kapok : kapok
# belanja : belanja
# cod : cod
# uninstal : uninstal
# beban : beban
# and : and
# sampah : sampah
# smartphone : smartphone
# gue : gue
# dipiara : piara
# bermanfaat : manfaat
# kendala : kendala
# dibeli : beli
# dibayar : bayar
# sistemnya : sistem
# canggih : canggih
# dikomplain : komplain
# sadah : sadah
# kembaliini : kembaliini
# kepastianpayah : kepastianpayah
# menyesal : sesal
# beli : beli
# dibukalapak : dibukalapak
# mitra : mitra
# dalem : dalem
# penipu : tipu
# tertipu : tipu
# refund : refund
# detik : detik
# mengerti : erti
# biyaya : biyaya
# penanganan : tangan
# maksudnya : maksud
# menyesak : sesak
# sgitu : sgitu
# ilangin : ilangin
# tuhklo : tuhklo
# kurangi : kurang
# kepakasa : kepakasa
# blanja : blanja
# saking : saking
# mengecewakan : kecewa
# mempermudah : mudah
# berbelanjatapi : berbelanjatapi
# dam : dam
# halapalagi : halapalagi
# tanggapan : tanggap
# buset : buset
# pajangan : pajang
# ditemukan : temu
# diterima : terima
# hebat : hebat
# lenya : lenya
# ribu : ribu
# pelayan : layan
# dikecewakan : kecewa
# dikerjain : dikerjain
# diperbaiki : baik
# sistemnyakecewa : sistemnyakecewa
# pelayanan : layan
# telat : telat
# pemilihan : pilih
# kurir : kurir
# ditambah : tambah
# report : report
# bermasalahpaket : bermasalahpaket
# jadwal : jadwal
# kompensasi : kompensasi
# jaminan : jamin
# kembalihanya : kembalihanya
# slogan : slogan
# belakabagaimana : belakabagaimana
# min : min
# respon : respon
# payah : payah
# ah : ah
# saldo : saldo
# habis : habis
# untung : untung
# ngisi : ngisi
# isi : isi
# cash : cash
# back : back
# lom : lom
# tau : tau
# telepon : telepon
# memuaskan : muas
# jawabannyacoba : jawabannyacoba
# membatalkan : batal
# tanggepin : tanggepin
# tlong : tlong
# jawabannya : jawab
# tentui : tentu
# jgbuat : jgbuat
# bantumakin : bantumakin
# hubungin : hubungin
# chatlemot : chatlemot
# tele : tele
# turun : turun
# lag : lag
# bintang : bintang
# memperbaiki : baik
# saran : saran
# expedisi : expedisi
# reg : reg
# next : next
# day : day
# sicepat : sicepat
# pick : pick
# up : up
# lelet : lelet
# criss : criss
# cross : cross
# sesuai : sesuai
# sop : sop
# resi : resi
# update : update
# ybs : ybs
# kepercayaan : percaya
# konsumen : konsumen
# perbaiki : baik
# kedepan : depan
# kecewadimana : kecewadimana
# menyediakan : sedia
# codtapi : codtapi
# express : express
# payleater : payleater
# bukalapaksaya : bukalapaksaya
# tagihan : tagih
# tagih : tagih
# lagibukti : lagibukti
# struknya : struknya
# kasir : kasir
# indomart : indomart
# berhasil : hasil
# yeah : yeah
# tagihantapi : tagihantapi
# anehnya : aneh
# bingung : bingung
# salah : salah
# pesan : pesan
# januari : januari
# jugasudah : jugasudah
# ajukan : aju
# tanggapi : tanggap
# bukalapaksungguh : bukalapaksungguh
# buruk : buruk
# gratis : gratis
# tertulis : tulis
# andalan : andal
# online : online
# way : way
# ketinggalan : tinggal
# mending : mending
# pusat : pusat
# pembelian : beli
# pulsa : pulsa
# tujuan : tuju
# terpotong : potong
# account : account
# dana : dana
# bermasalah : masalah
# berani : berani
# kontak : kontak
# rumit : rumit
# danabukalapak : danabukalapak
# trimakasih : trimakasih
# inovatif : inovatif
# ecommerce : ecommerce
# cocok : cocok
# pembisnis : bisnis
# simple : simple
# ringan : ringan
# all : all
# one : one
# feature : feature
# rekomendasi : rekomendasi
# toko : toko
# sebelah : belah
# terbuka : buka
# promo : promo
# super : super
# updatenya : updatenya
# punyeng : punyeng
# pokoknya : pokok
# sih : sih
# kak : kak
# estimasi : estimasi
# cek : cek
# transit : transit
# tangan : tangan
# pay : pay
# later : later
# dibajak : bajak
# kartu : kartu
# kredit : kredit
# hubungi : hubung
# pending : pending
# bukalapakeh : bukalapakeh
# suami : suami
# jutamasa : jutamasa
# blokir : blokir
# bajakhrsny : bajakhrsny
# ditahan : tahan
# pesanannyakan : pesanannyakan
# uangnya : uang
# pengalaman : alam
# urusan : urus
# selesai : selesai
# auto : auto
# hapus : hapus
# lambat : lambat
# rekomen : rekomen
# shopee : shopee
# gua : gua
# ramadhan : ramadhan
# jualan : jual
# posting : posting
# produk : produk
# enak : enak
# lemotbukan : lemotbukan
# internet : internet
# lemotaplikasinya : lemotaplikasinya
# perbaikimasi : perbaikimasi
# orangemasa : orangemasa
# utuma : utuma
# penilain : penilain
# kasihan : kasihan
# developer : developer
# lazada : lazada
# tiktok : tiktok
# minimal : minimal
# wajar : wajar
# orentiktok : orentiktok
# layak : layak
# disana : sana
# ketimbang : ketimbang
# wkwk : wkwk
# batalin : batalin
# pejual : jual
# jugasedangkan : jugasedangkan
# kepotong : potong
# gunakanharus : gunakanharus
# mengadutolong : mengadutolong
# lapakbiar : lapakbiar
# mengadukan : adu
# keluhan : keluh
# gagal : gagal
# chatlive : chatlive
# disuruh : suruh
# ngelunasin : ngelunasin
# memakai : pakai
# sehari : hari
# praktis : praktis
# efisien : efisien
# hemat : hemat
# duduk : duduk
# manis : manis
# rumah : rumah
# low : low
# cost : cost
# eh : eh
# ngirit : ngirit
# sayang : sayang
# masalahsudah : masalahsudah
# kali : kali
# jalan : jalan
# keluarketika : keluarketika
# mengetik : etik
# putus : putus
# sambungan : sambung
# nyakalo : nyakalo
# menggu : menggu
# tunggu : tunggu
# giliran : gilir
# yohana : yohana
# nama : nama
# bersabar : sabar
# nunggusaaya : nunggusaaya
# ngetiikkkk : ngetiikkkk
# amanah : amanah
# diproses : proses
# pelapaknya : lapak
# bukamall : bukamall
# pilihannya : pilih
# complainnya : complainnya
# berguna : guna
# complain : complain
# digunain : digunain
# metode : metode
# gonta : gonta
# mencukupi : cukup
# memiliki : milik
# hadehh : hadehh
# tolonglah : tolong
# paylaternya : paylaternya
# bekukan : beku
# basah : basah
# basih : basih
# custumer : custumer
# customer : customer
# servicenya : servicenya
# tengkyuu : tengkyuu
# dijamin : jamin
# tabungan : tabung
# ktpreffvral : ktpreffvral
# btbldkzqvt : btbldkzqvt
# mencoba : coba
# nyaaplikasii : nyaaplikasii
# suka : suka
# lamasangat : lamasangat
# dikala : kala
# belanjatinggal : belanjatinggal
# bayarbarang : bayarbarang
# kedepannya : depan
# membaiktengkyuuu : membaiktengkyuuu
# pengirimannya : kirim
# koreksi : koreksi
# wilyah : wilyah
# timur : timur
# indonesia : indonesia
# harganya : harga
# contoh : contoh
# ongkos : ongkos
# kirimnya : kirim
# mencapai : capai
# fer : fer
# kemahalan : mahal
# jadikan : jadi
# masukan : masuk
# bertransaksi : transaksi
# pantesan : pantesan
# jadul : jadul
# ditinggalkan : tinggal
# costumer : costumer
# fiturnya : fiturnya
# banyaktidak : banyaktidak
# bukabantuannya : bukabantuannya
# susahnya : susah
# penyelesaian : selesai
# merugikan : rugi
# ninja : ninja
# expres : expres
# berpuluh : puluh
# puluh : puluh
# dilacak : lacak
# dikasih : kasih
# sukur : sukur
# tibatiba : tibatiba
# ditangguhkan : tangguh
# konfirmasi : konfirmasi
# login : login
# sunguh : sunguh
# sarankan : saran
# menyimpan : simpan
# menghindari : hindar
# alami : alami
# kemarin : kemarin
# dibuka : buka
# diskusi : diskusi
# mengembalikan : kembali
# kekurangan : kurang
# transfer : transfer
# traktiran : traktir
# pengguna : guna
# debitnya : debit
# tambahan : tambah
# knyatanya : knyatanya
# sebulan : bulan
# akunnya : akun
# hoax : hoax
# selau : selau
# sesi : sesi
# info : info
# payleter : payleter
# ijo : ijo
# oran : oran
# pemberitahuan : pemberitahuan
# paylter : paylter
# jebakan : jebak
# betmen : betmen
# harapan : harap
# ku : ku
# jaringan : jaring
# stabil : stabil
# bangettolong : bangettolong
# mantulll : mantulll
# kondisi : kondisi
# ready : ready
# very : very
# gus : gus
# diriwayat : riwayat
# pagi : pagi
# posisi : posisi
# alamat : alamat
# penerima : terima
# an : an
# terima kasih : terima kasih
# penjualnya : jual
# bukalapaknya : bukalapaknya
# seharus : harus
# mengasih : asih
# php : php
# kesempatan : sempat
# ribet : ribet
# dinonaktifkan : nonaktif
# aman : aman
# drastis : drastis
# hasil : hasil
# berjualan : jual
# cairkan : cair
# butuh : butuh
# keperluan : perlu
# mendesak : desak
# cair : cair
# pinjam : pinjam
# tetangga : tetangga
# pencairan : cair
# inikasih : inikasih
# memproses : proses
# bgtkasihan : bgtkasihan
# dongharusnya : dongharusnya
# max : max
# mengirimkan : kirim
# haribukanya : haribukanya
# pembelimenurut : pembelimenurut
# bukalapakklo : bukalapakklo
# pesananmereka : pesananmereka
# sendiridan : sendiridan
# kirimkanentah : kirimkanentah
# lupaatau : lupaatau
# readymohon : readymohon
# lagibuat : lagibuat
# rumitpadahal : rumitpadahal
# refaund : refaund
# prosespadahal : prosespadahal
# maaf : maaf
# alasan : alas
# via : via
# artikel : artikel
# review : review
# dok : dok
# prosez : prosez
# memutuskan : putus
# melampirkan : lampir
# buku : buku
# rek : rek
# mutasi : mutasi
# nampaklah : nampaklah
# nota : nota
# bene : bene
# informasi : informasi
# krusial : krusial
# pengaturan : atur
# profile : profile
# dmpak : dmpak
# securitynya : securitynya
# setia : setia
# bltp : bltp
# perlahan : perlahan
# beralih : alih
# lainselain : lainselain
# potongan : potong
# rendah : rendah
# kolom : kolom
# mudah : mudah
# beragamdi : beragamdi
# tawarkn : tawarkn
# ketikcari : ketikcari
# hubungkan : hubung
# dibilang : bilang
# tertua : tua
# inovasi : inovasi
# pencariannya : cari
# mencari : cari
# ikan : ikan
# hias : hias
# pakan : pakan
# ganggu : ganggu
# sistemnyasya : sistemnyasya
# sellerkenapa : sellerkenapa
# pencariandi : pencariandi
# tracking : tracking
# validbanyak : validbanyak
# pembelitapi : pembelitapi
# trackingnya : trackingnya
# percepat : cepat
# marketpkace : marketpkace
# mengaco : aco
# pelit : pelit
# aturan : atur
# nonaktif : nonaktif
# dijual : jual
# berulang : ulang
# set : set
# chip : chip
# snapdragon : snapdragon
# gen : gen
# ram : ram
# gb : gb
# clear : clear
# chace : chace
# logout : logout
# terbaru : baru
# permasalahan : masalah
# server : server
# telp : telp
# custemservis : custemservis
# ngurusinya : ngurusinya
# itupun : itu
# codpembayaran : codpembayaran
# tunai : tunai
# diskon : diskon
# tingkatkan : tingkat
# membanyaki : banyak
# vouchernya : vouchernya
# kargo : kargo
# sediakan : sedia
# laman : laman
# tks : tks
# jembutsaya : jembutsaya
# dagang : dagang
# push : push
# dlliklan : dlliklan
# belasan : bas
# rating : rating
# boroboro : boroboro
# munculbangsaaatt : munculbangsaaatt
# satusatunya : satusatunya
# akses : akses
# berfungsihatihati : berfungsihatihati
# xufsinv : xufsinv
# melebihi : lebih
# batas : batas
# maksimal : maksimal
# dbatalkan : dbatalkan
# tertahan : tahan
# jelasjelas : jelasjelas
# tertera : tera
# bukatabungan : bukatabungan
# minada : mada
# gangguan : ganggu
# teman : teman
# undang : undang
# permasalahn : permasalahn
# bual : bual
# adakan : adakan
# request : request
# pickup : pickup
# cepat : cepat
# kembalikan : kembali
# awam : awam
# edit : edit
# tampilan : tampil
# varian : varian
# keterangannya : terang
# tipe : tipe
# nginput : nginput
# apanya : apa
# disamainnnnn : disamainnnnn
# feedback : feedback
# dibalas : balas
# dm : dm
# ig : ig
# digubris : gubris
# sptnya : sptnya
# halooooo : halooooo
# biji : biji
# order : order
# marketplace : marketplace
# free : free
# pajaknya : pajak
# gede : gede
# royal : royal
# emosi : emosi
# install : install
# berulangulang : berulangulang
# wadew : wadew
# blank : blank
# tandatanda : tandatanda
# apapun : apa
# berjamjam : berjamjam
# sore : sore
# biarkan : biar
# normal : normal
# kemana : mana
# kena : kena
# warning : warning
# nih : nih
# emak : emak
# lato : lato
# swafoto : swafoto
# kanan : kanan
# kiri : kiri
# pegang : pegang
# bantuin : bantuin
# repot : repot
# menilai : nilai
# kemunduran : mundur
# ratingnya : ratingnya
# angsuran : angsur
# sajadan : sajadan
# aktifharus : aktifharus
# belanjabrg : belanjabrg
# list : list
# item : item
# beranda : beranda
# ditampilkan : tampil
# capek : capek
# halah : halah
# pikir : pikir
# saller : saller
# menghubungi : hubung
# servis : servis
# presiden : presiden
# standby : standby
# lokasi : lokasi
# dihalaman : halaman
# ngalami : ngalami
# mendingan : mending
# doang : doang
# ngalamin : ngalamin
# bhulshittt : bhulshittt
# program : program
# garansi : garansi
# tipu : tipu
# tipunya : tipu
# mode : mode
# claimnya : claimnya
# default : default
# curang : curang
# berkahh : berkahh
# siasat : siasat
# mnjamingaransi : mnjamingaransi
# bertanggung : tanggung
# down : down
# laporan : lapor
# kesuksesan : sukses
# terkocak : kocak
# terkirim : kirim
# mulu : mulu
# kelar : kelar
# eneg : eneg
# dengernya : dengernya
# badut : badut
# password : password
# sekalibegitu : sekalibegitu
# verif : verif
# suruh : suruh
# passwordklik : passwordklik
# lupa : lupa
# bisagimana : bisagimana
# percaya : percaya
# ulasan : ulas
# promoted : promoted
# orderan : order
# variannya : varian
# dipermudah : mudah
# fleksibel : fleksibel
# monoton : monoton
# disesuaikan : sesuai
# size : size
# real : real
# nurut : nurut
# disediakan : sedia
# kategori : kategori
# bisaselalu : bisaselalu
# lengkapi : lengkap
# chapta : chapta
# dinyatakan : nyata
# lulus : lulus
# promot : promot
# ngitung : ngitung
# utang : utang
# lunas : lunas
# penjumlahan : jumlah
# mines : mes
# hutang : hutang
# lagiterima : lagiterima
# pengembalian : kembali
# dompet : dompet
# asuransi : asuransi
# barangterima : barangterima
# bukalapaktidak : bukalapaktidak
# mengecewakanjaya : mengecewakanjaya
# bukalapakaplikasi : bukalapakaplikasi
# indonesiasekali : indonesiasekali
# aga : aga
# dowload : dowload
# inikarna : inikarna
# lamatp : lamatp
# barangpengiriman : barangpengiriman
# standar : standar
# membaiksesuai : membaiksesuai
# estimasiuntuk : estimasiuntuk
# ditingkat : tingkat
# lgtrima : lgtrima
# kasihapk : kasihapk
# solusinya : solusi
# kabar : kabar
# brengsek : brengsek
# dajjal : dajjal
# google : google
# tutup : tutup
# permanen : permanen
# kagak : kagak
# permintaan : minta
# pembayaranya : pembayaranya
# lainyasangat : lainyasangat
# mudahsangat : mudahsangat
# kalangan : kalang
# menengah : tengah
# kebawahapalagi : kebawahapalagi
# vocer : vocer
# lainya : lai
# dapatkanpayah : dapatkanpayah
# bonus : bonus
# event : event
# secepatnya : cepat
# mini : mini
# periode : periode
# maret : maret
# telkom : telkom
# pelayanannya : layan
# wib : wib
# terimakasih : terimakasih
# menindaklanjuti : menindaklanjuti
# ditingkatkan : tingkat
# platform : platform
# mnrut : mnrut
# terbaiknya : baik
# acc : acc
# good : good
# job : job
# penyedia : sedia
# fasilitas : fasilitas
# history : history
# prifasi : prifasi
# histori : histori
# obatproduk : obatproduk
# dewasa : dewasa
# sebagainyaitu : sebagainyaitu
# prifasitrims : prifasitrims
# keren : keren
# bertahan : tahan
# persaingan : saing
# ketat : ketat
# kompetitornya : kompetitor
# yuk : yuk
# buruan : buru
# download : download
# konsisten : konsisten
# timbul : timbul
# tenggelam : tenggelam
# loh : loh
# hehee : hehee
# sukses : sukses
# ok : ok
# barusan : barusan
# pindah : pindah
# tertinggal : tinggal
# tik : tik
# tok : tok
# murah : murah
# masang : masang
# pasang : pasang
# ayo : ayo
# diminati : mati
# grosiran : grosir
# tranksaksi : tranksaksi
# tranksasi : tranksasi
# layanananya : layanananya
# untungnya : untung
# parahhhhhhhhhhh : parahhhhhhhhhhh
# langanan : langanan
# laganan : lagan
# perbarui : baru
# kualitas : kualitas
# menurun : turun
# mengadakan : ada
# kerjasama : kerjasama
# referral : referral
# alhamdulillah : alhamdulillah
# rezeki : rezeki
# tsbt : tsbt
# mengajak : ajak
# mendaftar : daftar
# perpanjang : panjang
# bukutabungan : bukutabungan
# hpgmail : hpgmail
# code : code
# undangan : undang
# btblvj : btblvj
# sisi : sisi
# ui : ui
# user : user
# friendly : friendly
# popup : popup
# mengganggu : ganggu
# mengecewakanaman : mengecewakanaman
# customertingkatkan : customertingkatkan
# prestasi : prestasi
# blspy : blspy
# service : service
# kendaladan : kendaladan
# solusitidak : solusitidak
# sekian : sekian
# dikirimlha : dikirimlha
# visa : visa
# dibatalkan : batal
# nyampek : nyampek
# terkadang : terkadang
# nnya : nnya
# sd : sd
# amana : amana
# menit : menit
# software : software
# instal : instal
# akunpu : akunpu
# petunjuk : tunjuk
# bantuannya : bantu
# lacak : lacak
# nasabah : nasabah
# token : token
# listrik : listrik
# urgent : urgent
# laaahh : laaahh
# kabupaten : kabupaten
# bandung : bandung
# padalarang : padalarang
# mesan : mesan
# februari : februari
# tulisan : tulis
# nobody : nobody
# at : at
# home : home
# dirumah : rumah
# ente : ente
# jne : jne
# dll : dll
# beginiga : beginiga
# kabbandung : kabbandung
# jakarta : jakarta
# bareng : bareng
# dipahami : paham
# mantablah : mantablah
# virtual : virtual
# kadaluarsa : kadaluarsa
# kmna : kmna
# larinya : lari
# keselahan : lah
# dimana : mana
# captcha : captcha
# mengulang : ulang
# beresin : resin
# terganggu : ganggu
# ongkirnya : ongkirnya
# yrus : yrus
# berkembang : kembang
# pesana : sana
# prosespelapak : prosespelapak
# meresponsolusi : meresponsolusi
# menungguini : menungguini
# pemrosesan : pemrosesan
# hak : hak
# letoy : letoy
# audit : audit
# gimmick : gimmick
# langganan : langgan
# heran : heran
# lagicustomer : lagicustomer
# servisnya : servis
# bantu : bantu
# onlinetapi : onlinetapi
# buatlah : buat
# system : system
# indomaretalfamartbahkan : indomaretalfamartbahkan
# atmjadi : atmjadi
# trnsaksi : trnsaksi
# berhasilpulsa : berhasilpulsa
# masuktagihan : masuktagihan
# adakomplen : adakomplen
# diurus : urus
# mesin : mesin
# nonaktifkan : nonaktif
# reseller : reseller
# kayanya : kaya
# diperbaharui : baharu
# dimudahkan : mudah
# transfertapi : transfertapi
# oke : oke
# pertahankan : tahan
# pencaria : pencaria
# penjualanya : penjualanya
# bug : bug
# visual : visual
# alangkah : alangkah
# baiknya : baik
# lemott : lemott
# sistemya : sistemya
# test : test
# bberapa : bberapa
# mempelajari : ajar
# jarang : jarang
# palsu : palsu
# eror : eror
# apalah : apa
# gabakalan : gabakalan
# mudahproses : mudahproses
# cepatdan : cepatdan
# menariksangat : menariksangat
# rekomendit : rekomendit
# alias : alias
# gajelasgda : gajelasgda
# dgunainmaupun : dgunainmaupun
# gitupadahal : gitupadahal
# plytrkecewa : plytrkecewa
# pahami : paham
# terpercaya : percaya
# perlindungan : lindung
# stak : stak
# perubahan : ubah
# erortolong : erortolong
# dipwrbaiki : dipwrbaiki
# nyaterima : nyaterima
# always : always
# nice : nice
# lengkap : lengkap
# provider : provider
# satisfied : satisfied
# roda : roda
# rejeki : rejeki
# sdikit : sdikit
# lakukan : laku
# payletter : payletter
# menagih : tagih
# teror : teror
# berfungsipadahal : berfungsipadahal
# codketika : codketika
# checkout : checkout
# benerin : benerin
# iya : iya
# notifikasi : notifikasi
# kota : kota
# pengirim : kirim
# nyasar : nyasar
# bukalapakpesanan : bukalapakpesanan
# kurur : kurur
# cepattapi : cepattapi
# complainmenu : complainmenu
# bukanantuan : bukanantuan
# betfungsi : betfungsi
# aplikasinyamau : aplikasinyamau
# bagusmemori : bagusmemori
# banyakkuota : banyakkuota
# hmm : hmm
# detail : detail
# penjemputan : jemput
# indihome : indihome
# kepeeluan : kepeeluan
# dagangan : dagang
# kmp : kmp
# bisatp : bisatp
# kuotapulsatoken : kuotapulsatoken
# lancar : lancar
# ybarang : ybarang
# kirimtapi : kirimtapi
# sistembarang : sistembarang
# komple : komple
# pejualan : jual
# selesaiklu : selesaiklu
# ketingakan : ketingakan
# shopetikopedia : shopetikopedia
# nominal : nominal
# dipaktur : dipaktur
# selisihnya : selisih
# lemoot : lemoot
# aplikasinyatolong : aplikasinyatolong
# lainudh : lainudh
# layar : layar
# putih : putih
# berjam : jam
# berhubung : hubung
# newbie : newbie
# nilai : nilai
# mantap : mantap
# dah : dah
# ragu : ragu
# komplainan : komplain
# livechatnya : livechatnya
# disaat : saat
# wadah : wadah
# prosedur : prosedur
# amnah : amnah
# sopan : sopan
# mas : mas
# shop : shop
# keluarga : keluarga
# diragukan : ragu
# discountnya : discountnya
# tambahkan : tambah
# sertakan : serta
# bukti : bukti
# fotonya : foto
# star : star
# bagusmalah : bagusmalah
# menurunupdate : menurunupdate
# berpengaruhhapus : berpengaruhhapus
# cacheclear : cacheclear
# datasama : datasama
# ajaaplikasi : ajaaplikasi
# menonton : tonton
# streaming : streaming
# hd : hd
# jaya : jaya
# abuabu : abuabu
# lemah : lemah
# keamanan : aman
# taii : taii
# rekomendasikan : rekomendasi
# penipuan : tipu
# masal : masal
# artikelnya : artikel
# kenyataannya : nyata
# imfor : imfor
# kunci : kunci
# ujung : ujung
# ujungnya : ujung
# matikan : mati
# paham : paham
# matiin : matiin
# eroor : eroor
# playlater : playlater
# lapaksudah : lapaksudah
# diaktifkan : aktif
# dicoba : coba
# kebutuhan : butuh
# biaa : biaa
# dilesan : les
# dikirimnya : kirim
# fast : fast
# kepuasan : puas
# diseleksi : seleksi
# menunda : tunda
# pesanannya : pesan
# dikembalikan : kembali
# lagibuang : lagibuang
# euy : euy
# wninv : wninv
# pembatalan : batal
# curiga : curiga
# pencuri : curi
# pengganti : ganti
# bukasen : bukasen
# input : input
# kostumer : kostumer
# media : media
# sosial : sosial
# fb : fb
# aktf : aktf
# cht : cht
# agen : agen
# memahami : paham
# kejadian : jadi
# tiki : tik
# mengaktifkan : aktif
# zaman : zaman
# manual : manual
# setahun : tahun
# laku : laku
# ditampilin : ditampilin
# etalase : etalase
# profil : profil
# ampas : ampas
# aneka : aneka
# sparepart : sparepart
# otomotif : otomotif
# inden : inden
# bintan : bintan
# terbatas : batas
# csa : csa
# pelayananaslowresponudh : pelayananaslowresponudh
# masalaha : masalaha
# selesaisorry : selesaisorry
# aplikasimending : aplikasimending
# tokped : tokped
# akulaku : akulaku
# pin : pin
# dibantu : bantu
# nonaktifin : nonaktifin
# skalian : skalian
# full : full
# ber : ber
# menyenangkan : senang
# tersedia : sedia
# original : original
# reward : reward
# btblbnfvpw : btblbnfvpw
# luncurkan : luncur
# versi : versi
# lite : lite
# mah : mah
# minimum : minimum
# makai : maka
# mudahan : mudah
# harga : harga
# cashback : cashback
# masuktp : masuktp
# terpotongmau : terpotongmau
# digubriskecewa : digubriskecewa
# trim : trim
# gan : gan
# mendarat : darat
# selamat : selamat
# manfaat : manfaat
# diberanda : beranda
# gambarnya : gambar
# kosongsearch : kosongsearch
# kosonggimana : kosonggimana
# jringan : jringan
# ngebut : ngebut
# setenga : setenga
# serbah : serbah
# laloadnya : laloadnya
# yx : yx
# responnya : responnya
# samday : samday
# sekeng : keng
# disarankan : saran
# jangn : jangn
# sinh : sinh
# stuck : stuck
# tuh : tuh
# situh : situh
# melulubebalik : melulubebalik
# bacaan : baca
# begituan : begitu
# pembelanjaan : belanja
# nihpadahal : nihpadahal
# fullberat : fullberat
# trmksh : trmksh
# puassssssssssssbanget : puassssssssssssbanget
# mngajukan : mngajukan
# payltr : payltr
# setujui : tuju
# berhasilaplikasi : berhasilaplikasi
# taiiiii : taiiiii
# ketidak : tidak
# nyamanan : nyaman
# bla : bla
# bersaing : saing
# jaman : jaman
# is : is
# the : the
# best : best
# menjalankan : jalan
# bisnis : bisnis
# kelola : kelola
# terimaka : terimaka
# thanks : thanks
# baguskalo : baguskalo
# top : top
# murahsama : murahsama
# pelayananterutama : pelayananterutama
# transitnya : transit
# melulu : melulu
# kelas : kelas
# prakerja : prakerja
# badal : badal
# tolak : tolak
# terusapk : terusapk
# berbelit : belit
# belit : belit
# bagussesuai : bagussesuai
# dicobasemoga : dicobasemoga
# signal : signal
# kebutuhandan : kebutuhandan
# berkwalitas : berkwalitas
# grab : grab
# instan : instan
# depoktangsel : depoktangsel
# jaraka : jaraka
# depelover : depelover
# diprosses : diprosses
# bisabisa : bisabisa
# upnya : upnya
# minggu : minggu
# pelyanannya : pelyanannya
# woiiiiiii : woiiiiiii
# manaudah : manaudah
# logindaftar : logindaftar
# ongkirtp : ongkirtp
# murahjd : murahjd
# virtualsaldo : virtualsaldo
# mengirim : kirim
# plus : plus
# dendauang : dendauang
# melayangmau : melayangmau
# bisajadi : bisajadi
# terbaik : baik
# aesuai : aesuai
# subhanallah : subhanallah
# janji : janji
# alhamdulilah : alhamdulilah
# kemajuan : maju
# watelpon : watelpon
# membingunkan : membingunkan
# terhubung : hubung
# terputus : putus
# mati : mati
# membela : bela
# muter : muter
# galeri : galeri
# taunya : tau
# oren : oren
# pengajuan : aju
# riwayat : riwayat
# bilang : bilang
# nyeesel : nyeesel
# seminggu : minggu
# rada : rada
# niat : niat
# eksis : eks
# berbelanjatp : berbelanjatp
# pembayarannya : bayar
# permudah : mudah
# bebas : bebas
# persulit : sulit
# contohhanya : contohhanya
# berlaku : laku
# kreditx : kreditx
# dipindahkan : pindah
# minkhusus : minkhusus
# mengapai : kapai
# rokets : rokets
# dapatx : dapatx
# kekumpul : kumpul
# exp : exp
# cc : cc
# pilih : pilih
# cicilan : cicil
# tertagih : tagih
# confirmasi : confirmasi
# urus : urus
# korban : korban
# pertanda : tanda
# bangkrut : bangkrut
# kolaps : kolaps
# dibutuhin : dibutuhin
# peningkatan : tingkat
# hadeuhh : hadeuhh
# on : on
# line : line
# penggunaannya : guna
# segitu : segitu
# limitnya : limit
# tokxxxxxx : tokxxxxxx
# shoxxx : shoxxx
# lazxxx : lazxxx
# bukakapok : bukakapok
# puas : puas
# display : display
# merk : merk
# spesifikasi : spesifikasi
# tertampil : tampil
# variatif : variatif
# selisih : selisih
# signifikan : signifikan
# memilih : pilih
# berbeda : beda
# kwalitas : kwalitas
# pisan : pis
# gambarfoto : gambarfoto
# ditujuan : tuju
# barangpesanan : barangpesanan
# paya : paya
# lainmau : lainmau
# bisayang : bisayang
# mikir : mikir
# belajan : bajan
# akal : akal
# berbelanja : belanja
# aplika : aplika
# maling : maling
# juta : juta
# bunga : bunga
# itikad : itikad
# kinerjanya : kerja
# bukalapakuntuk : bukalapakuntuk
# chatnya : chatnya
# diakses : akses
# terbaikresponship : terbaikresponship
# tf : tf
# komunikasi : komunikasi
# bintangnya : bintang
# play : play
# emailpun : email
# direspon : direspon
# bloon : bloon
# retur : retur
# bukasend : bukasend
# semprul : semprul
# kredivo : kredivo
# amin : amin
# iming : iming
# warung : warung
# hahaha : hahaha
# haaaaa : haaaaa
# ketemu : ketemu
# acha : acha
# berkali : kali
# cancel : cancel
# serius : serius
# kopeten : kopeten
# stock : stock
# notif : notif
# tayangin : tayangin
# kesalahan : salah
# transparant : transparant
# store : store
# updatetan : updatetan
# jepara : jepara
# teramat : amat
# lamalebih : lamalebih
# wajargk : wajargk
# lagibukan : lagibukan
# berpihak : pihak
# kepelapak : lapak
# kompalin : kompalin
# banyakan : banyak
# intinya : inti
# pudar : pudar
# butuuutttt : butuuutttt
# pelayananya : pelayananya
# responterima : responterima
# belanjanya : belanja
# mengikuti : ikut
# arahan : arah
# bebarapa : bebarapa
# chattapi : chattapi
# terkesan : kes
# memutus : putus
# percakapan : cakap
# etika : etika
# tuntutan : tuntut
# ceritanya : cerita
# dibl : dibl
# menarik : tarik
# sekalinya : sekali
# akibatnya : akibat
# pelangganfollow : pelangganfollow
# mles : mles
# blnj : blnj
# ikuti : ikut
# ketoko : toko
# tokonya : toko
# byebye : byebye
# opsi : opsi
# terpaksa : paksa
# berubah : ubah
# pikiran : pikir
# kecepatan : cepat
# hitungannya : hitung
# keyword : keyword
# luas : luas
# turunin : turunin
# buffering : buffering
# sh : sh
# pee : pee
# byar : byar
# superseller : superseller
# keuntungan : untung
# dinaikin : dinaikin
# berikanhanya : berikanhanya
# diwajibakan : diwajibakan
# tampa : tampa
# penerimaan : terima
# variasi : variasi
# laptop : laptop
# pc : pc
# terjangkau : jangkau
# perbaikan : baik
# gara : gara
# bangking : bangking
# cencel : cencel
# uangpun : uang
# tindak : tindak
# lanjuti : lanjut
# ngulur : ngulur
# mepet : mepet
# mengomong : omong
# stok : stok
# kosong : kosong
# banned : banned
# ditindak : tindak
# kebiasaan : biasa
# com : com
# laindan : laindan
# dek : dek
# livecat : livecat
# ecomercial : ecomercial
# tiada : tiada
# berinovasi : inovasi
# semangatsemangat : semangatsemangat
# semangat : semangat
# ditolak : tolak
# reksadana : reksadana
# samapai : samapai
# kadaluwarsa : kadaluwarsa
# dapatnya : dapat
# mesti : mesti
# mengantri : antri
# stay : stay
# page : page
# dibatalin : dibatalin
# antrian : antri
# ndk : ndk
# bisauang : bisauang
# ditranfer : ditranfer
# lagisudah : lagisudah
# responrelakan : responrelakan
# custom : custom
# kalimat : kalimat
# baku : baku
# hijau : hijau
# orange : orange
# harapannya : harap
# ngambil : ngambil
# lapakbelanja : lapakbelanja
# thdihistory : thdihistory
# puluhan : puluh
# jttapi : jttapi
# kanmasa : kanmasa
# sayalebih : sayalebih
# blsaya : blsaya
# akanpindah : akanpindah
# merespon : merespon
# mengepentingkan : penting
# nb : nb
# menawarkan : tawar
# shopy : shopy
# jos : jos
# judul : judul
# gambar : gambar
# memodifikasi : modifikasi
# selainnya : selain
# booking : booking
# muncultdk : muncultdk
# tercantum : cantum
# nyangkut : nyangkut
# resmi : resmi
# halo : halo
# bukadompet : bukadompet
# dibekukan : beku
# senilai : nila
# rp : rp
# struk : struk
# topup : topup
# berjaya : jaya
# seleksi : seleksi
# curangpenjual : curangpenjual
# nakal : nakal
# menipu : tipu
# pertahanan : tahan
# pedagang : dagang
# ketempat : tempat
# sihketika : sihketika
# adil : adil
# malas : malas
# nombokin : nombokin
# lingkungan : lingkung
# pilihah : pilihah
# pemesanan : mesan
# membeli : beli
# berkalikali : berkalikali
# mutermuter : mutermuter
# market : market
# place : place
# backup : backup
# tuntas : tuntas
# berpikir : pikir
# tingkat : tingkat
# pemgiriman : pemgiriman
# setatus : setatus
# brang : brang
# keburu : keburu
# mingkin : mingkin
# finalti : finalti
# perbiaki : biak
# lagicoba : lagicoba
# menurunbukan : menurunbukan
# membaik : baik
# pengelompokan : kelompok
# wishlist : wishlist
# favorit : favorit
# filter : filter
# mengelompokkan : kelompok
# stabilitas : stabilitas
# file : file
# mbak : mbak
# crop : crop
# dicari : cari
# dikecilkan : kecil
# komputer : komputer
# maunya : mau
# dibatasbatasin : dibatasbatasin
# kenapaverifikasi : kenapaverifikasi
# sms : sms
# kodenyasampe : kodenyasampe
# terusuninstal : terusuninstal
# bisakode : bisakode
# berhenti : henti
# kethabis : kethabis
# memuncak : puncak
# ditiadakan : tiada
# bersifat : sifat
# dikonfirmasi : konfirmasi
# improve : improve
# woy : woy
# hati : hati
# perampok : rampok
# olshop : olshop
# ol : ol
# sellertoko : sellertoko
# direct : direct
# call : call
# center : center
# wa : wa
# pengirimanretur : pengirimanretur
# semangaaat : semangaaat
# timmanjemen : timmanjemen
# penggantian : ganti
# sayangnya : sayang
# kasik : kasik
# pasword : pasword
# elh : elh
# screen : screen
# shot : shot
# dihubungi : hubung
# kacau : kacau
# bukalapaknamun : bukalapaknamun
# tgn : tgn
# ongkirjasa : ongkirjasa
# kuriryang : kuriryang
# mahaltujuan : mahaltujuan
# manado : manado
# ribunamun : ribunamun
# permainan : main
# darathanya : darathanya
# ribualhasil : ribualhasil
# samasaya : samasaya
# berbenahjgn : berbenahjgn
# permainkan : main
# pelangganjangan : pelangganjangan
# salahkan : salah
# bnyaktapi : bnyaktapi
# difungsikan : fungsi
# ewallet : ewallet
# gila : gila
# okelah : oke
# fine : fine
# gapapa : gapapa
# fair : fair
# woi : woi
# zolim : zolim
# namanya : nama
# evalusi : evalusi
# sukabikin : sukabikin
# costumers : costumers
# segi : segi
# apapunbaik : apapunbaik
# pengirimanada : pengirimanada
# compl : compl
# tanggapdisc : tanggapdisc
# sebelahsejauh : sebelahsejauh
# terusmakin : terusmakin
# majusukses : majusukses
# kunjung : kunjung
# tentukan : tentu
# tahan : tahan
# nonfisik : nonfisik
# fisikisinya : fisikisinya
# semuasaya : semuasaya
# higgs : higgs
# domino : domino
# selesaisukses : selesaisukses
# dikirimudah : dikirimudah
# tanggapidiliat : tanggapidiliat
# mengambil : ambil
# keputusan : putus
# mitrabukalapak : mitrabukalapak
# penghasilanbikin : penghasilanbikin
# pelangganbikin : pelangganbikin
# senang : senang
# laris : laris
# manisbiaya : manisbiaya
# komplit : komplit
# poin : poin
# lagicari : lagicari
# username : username
# adeirmasari : adeirmasari
# ranting : ranting
# unistal : unistal
# rekomdasi : rekomdasi
# kurisr : kurisr
# irm : irm
# mengantar : antar
# sedia : sedia
# melayani : layan
# jnt : jnt
# aktifkan : aktif
# disalah : salah
# kepembayaran : bayar
# diselesaikan : selesai
# dicek : cek
# berkala : kala
# kabur : kabur
# pembelianpenjualan : pembelianpenjualan
# control : control
# terselesaikan : selesai
# knpsejak : knpsejak
# bajakdi : bajakdi
# situ : situ
# cemasdan : cemasdan
# updatelengkap : updatelengkap
# rinci : rinci
# malesblm : malesblm
# nyablm : nyablm
# nyatrlalu : nyatrlalu
# makan : makan
# waktucoba : waktucoba
# lahapa : lahapa
# titipagar : titipagar
# perbaikiagar : perbaikiagar
# berbobotdan : berbobotdan
# lagiputusin : lagiputusin
# hubungan : hubung
# paylaterpercumaga : paylaterpercumaga
# jugakl : jugakl
# wat : wat
# pribadi : pribadi
# sydah : sydah
# pemilik : milik
# angkutan : angkut
# disaring : saring
# handphone : handphone
# jengkel : jengkel
# sehat : sehat
# berisikan : risi
# pengusaha : usaha
# tiputipu : tiputipu
# tekan : tekan
# smile : smile
# disayangkan : sayang
# permen : permen
# soptex : soptex
# meningkat : tingkat
# jutaan : juta
# selepas : lepas
# mendesakharusnya : mendesakharusnya
# kembalibagaimanapun : kembalibagaimanapun
# bldah : bldah
# ulangi : ulang
# samatapi : samatapi
# diedit : edit
# sekedar : dar
# tiket : tiket
# pelaporan : lapor
# dokumen : dokumen
# bukalapaksukses : bukalapaksukses
# off : off
# mantapsya : mantapsya
# bisakarena : bisakarena
# terivikasi : terivikasi
# voucherpotongan : voucherpotongan
# training : training
# tercover : tercover
# pembayan : pembayan
# va : va
# bukalapakbayar : bukalapakbayar
# telatmalah : telatmalah
# splayter : splayter
# splayternya : splayternya
# aktifinntar : aktifinntar
# menjual : jual
# terjual : jual
# penjualan : jual
# hda : hda
# tua : tua
# berbenah : benah
# fyuuhh : fyuuhh
# beres : beres
# ngeri : ngeri
# slow : slow
# ancurlahhh : ancurlahhh
# move : move
# ptongan : ptongan
# rda : rda
# maksud : maksud
# daya : daya
# klaim : klaim
# menjaga : jaga
# mengembangkan : kembang
# ketentuan : tentu
# kompalain : kompalain
# tpdiketangan : tpdiketangan
# upgrade : upgrade
# cap : cap
# kaki : kaki
# atm : atm
# sellernya : sellernya
# permintaannya : minta
# prosesnya : proses
# elektronik : elektronik
# relatif : relatif
# ols : ols
# seribu : ribu
# dibayarkan : bayar
# mencekik : cekik
# memuat : muat
# pilihannyacuma : pilihannyacuma
# alau : alau
# check : check
# outcaranya : outcaranya
# ukuran : ukur
# warna : warna
# barangtp : barangtp
# bagusisinya : bagusisinya
# adajooossss : adajooossss
# membayar : bayar
# siapsiap : siapsiap
# memudahkan : mudah
# kejutan : kejut
# sungguh : sungguh
# perbaruijadi : perbaruijadi
# rumitkonfirmasi : rumitkonfirmasi
# teruspadahal : teruspadahal
# koneksi : koneksi
# wifimakin : wifimakin
# nyamanlama : nyamanlama
# kebukatolong : kebukatolong
# bagusdri : bagusdri
# betah : betah
# negeri : negeri
# wakanda : wakanda
# kocaksesi : kocaksesi
# room : room
# bisasinyal : bisasinyal
# baguspenjualan : baguspenjualan
# adaapk : adaapk
# tanding : tanding
# hahhaha : hahhaha
# antrean : antre
# terusgak : terusgak
# takut : takut
# belik : belik
# kerjainyaa : kerjainyaa
# mempermainkan : main
# enggak jelas : enggak jelas
# truss : truss
# separah : parah
# enggak apa-apa : enggak apa
# power : power
# perasaan : asa
# walopun : walopun
# kencang : kencang
# perasaaan : perasaaan
# wkwkwwk : wkwkwwk
# delay : delay
# disisni : disisni
# berkomunikasi : komunikasi
# videokan : video
# youtube : youtube
# lamagak : lamagak
# hadehhh : hadehhh
# adabeberapa : adabeberapa
# ongkirlahmasa : ongkirlahmasa
# sukarela : sukarela
# mengantarkan : antar
# belanjatingkat : belanjatingkat
# peminatnya : minat
# tangkurak : tangkurak
# sia : sia
# sinyal : sinyal
# butuuuuuuuut : butuuuuuuuut
# loyo : loyo
# vouher : vouher
# kurirnya : kurir
# pmbelian : pmbelian
# terachir : terachir
# perkiraan : kira
# nyala : nyala
# lemottttmending : lemottttmending
# sat : sat
# pesanancuman : pesanancuman
# apknya : apknya
# loodingnya : loodingnya
# biometrik : biometrik
# bukalapa : bukalapa
# kejelasan : jelas
# kb : kb
# malashubungkan : malashubungkan
# susahsilahkn : susahsilahkn
# diam : diam
# keluhn : keluhn
# kitamalas : kitamalas
# bklapak : bklapak
# benlanja : benlanja
# shoppe : shoppe
# siaga : siaga
# susahbertanya : susahbertanya
# opensusahgek : opensusahgek
# cpat : cpat
# pokokny : pokokny
# rekomend : rekomend
# rajin : rajin
# sussh : sussh
# tmbhin : tmbhin
# prdukgk : prdukgk
# tkopedia : tkopedia
# shope : shope
# gampangcontact : gampangcontact
# hbngitnya : hbngitnya
# smuagmna : smuagmna
# konsulpntesan : konsulpntesan
# klah : klah
# tokopedia : tokopedia
# mahalsukses : mahalsukses
# bukalapaksangat : bukalapaksangat
# bayarnya : bayar
# cashterimkasih : cashterimkasih
# belangganan : banggan
# berharap : harap
# meninjau : tinjau
# big : big
# kecewatiap : kecewatiap
# utuh : utuh
# menyebalkan : sebal
# ampuuuunnnnnbaru : ampuuuunnnnnbaru
# downlod : downlod
# lemooooooooottttttudh : lemooooooooottttttudh
# kebuka : buka
# layarnya : layar
# teruuuuussssaplikasi : teruuuuussssaplikasi
# jlelekgk : jlelekgk
# rubah : rubah
# emailnya : email
# bayarkan : bayar
# alfamaret : alfamaret
# terkena : kena
# denda : denda
# bantuanya : bantuanya
# lumayanterpercayameskipun : lumayanterpercayameskipun
# mengganggap : mengganggap
# raja : raja
# dihargai : harga
# dilayani : layan
# mungkinpihak : mungkinpihak
# menegur : tegur
# promonya : promonya
# unik : unik
# caseback : caseback
# turunkan : turun
# pepek : pepek
# macet : macet
# loadinggg : loadinggg
# alah : alah
# sampaaaahhhhhh : sampaaaahhhhhh
# mu : mu
# minnnnn : minnnnn
# smswhatsapp : smswhatsapp
# ngirimnya : ngirimnya
# kelewatan : lewat
# lol : lol
# sebagus : bagus
# gantung : gantung
# kejarin : kejarin
# selesaikan : selesai
# karana : karana
# macammohon : macammohon
# crpat : crpat
# sangsi : sangsi
# pembelimestinya : pembelimestinya
# dirugikan : rugi
# komentar : komentar
# apasly : apasly
# ssh : ssh
# minus : minus
# kkurangan : kkurangan
# daplikasi : daplikasi
# bukalapaksky : bukalapaksky
# ysuper : ysuper
# lengkapapa : lengkapapa
# bthknada : bthknada
# di dalam : di dalam
# inibuat : inibuat
# raguuntk : raguuntk
# mdownloadpergunakan : mdownloadpergunakan
# jgnikmati : jgnikmati
# kmudahan : kmudahan
# ysukses : ysukses
# truntuk : truntuk
# bukalapaktq : bukalapaktq
# but : but
# fungsional : fungsional
# pakr : pakr
# mantapsemoga : mantapsemoga
# naikan : naik
# membership : membership
# bagusan : bagus
# koleksi : koleksi
# musik : musik
# kaset : kaset
# celana dalam : celana dalam
# memuaskandan : memuaskandan
# datangi : datang
# sesui : sesui
# diharapkankurir : diharapkankurir
# okrespon : okrespon
# siiip : siiip
# baca : baca
# trnyta : trnyta
# bnar : bnar
# dngn : dngn
# hrg : hrg
# trnytaa : trnytaa
# trma : trma
# trtahan : trtahan
# complen : complen
# bsatidak : bsatidak
# tnggung : tnggung
# bossharap : bossharap
# dibaca : baca
# pelan : pelan
# kepepet : pepet
# simpati : simpati
# paylaterbayarnya : paylaterbayarnya
# gaessternyata : gaessternyata
# cas : cas
# ditetangga : tetangga
# bulannya : bulan
# memberatkan : berat
# koperasi : koperasi
# snub : snub
# ring : ring
# lemotsdh : lemotsdh
# bcara : bcara
# verifikasiketika : verifikasiketika
# pesananan : pesananan
# gunanya : guna
# woyy : woyy
# tlng : tlng
# gercep : gercep
# hah : hah
# khusus : khusus
# chapca : chapca
# terferivikasi : terferivikasi
# duit : duit
# iklanhasilnya : iklanhasilnya
# manfaatatnya : manfaatatnya
# satupuntidak : satupuntidak
# berlangganan : langgan
# sayangkan : sayang
# otomatisnya : otomatis
# dulusekali : dulusekali
# parahudh : parahudh
# tahunan : tahun
# lazadauinstal : lazadauinstal
# bukalapakudah : bukalapakudah
# terpakai : pakai
# butuhkan : butuh
# centre : centre
# tott : tott
# kesal : kesal
# malam : malam
# ngebug : ngebug
# terburuk : buruk
# berjalan : jalan
# raib : raib
# pengecekan : kece
# kepala : kepala
# bapako : bapako
# kotak : kotak
# stop : stop
# kebijakan : bijak
# saler : saler
# bahaya : bahaya
# pushnya : pushnya
# penipusaya : penipusaya
# telpon : telpon
# bukalapakmksd : bukalapakmksd
# kerjanya : kerja
# nipu : nipu
# kerana : rana
# pinada : pada
# kumpulkan : kumpul
# oia : oia
# penjyal : penjyal
# berbuat : buat
# oknum : oknum
# berwajib : wajib
# aplikasii : aplikasi
# bisadi : bisadi
# negeriigoodgood : negeriigoodgood
# mainkan : main
# rubahterus : rubahterus
# valid : valid
# coz : coz
# lolos : lolos
# maless : maless
# bnaget : bnaget
# pahit : pahit
# paylaterparah : paylaterparah
# sgini : sgini
# lamabukabantuan : lamabukabantuan
# ribetsusah : ribetsusah
# seringan : sering
# web : web
# penjaualan : penjaualan
# rekeninglama : rekeninglama
# nyairkan : nyairkan
# berhari : hari
# xpenanganan : xpenanganan
# banking : banking
# verifikasibikin : verifikasibikin
# darting : darting
# paylatersetiap : paylatersetiap
# layanannya : layan
# rbkalau : rbkalau
# kapooooookk : kapooooookk
# yamg : yamg
# menguntung : untung
# rekning : rekning
# refral : refral
# eventevent : eventevent
# unruk : unruk
# penggunaan : guna
# inti : inti
# recomendasi : recomendasi
# kembang : kembang
# apliaksi : apliaksi
# muluss : muluss
# difitur : difitur
# berdaya : daya
# banding : banding
# dipriroritaskan : dipriroritaskan
# pembeki : bek
# dapatkan : dapat
# pasaran : pasar
# beljar : beljar
# mudahada : mudahada
# kluhan : kluhan
# tirmkasih : tirmkasih
# aplicationtapi : aplicationtapi
# sueee : sueee
# nglunasin : nglunasin
# nabung : nabung
# tabungannya : tabung
# dasar : dasar
# memorinya : memori
# kemauan : mau
# otomasi : otomasi
# kerlambatan : kerlambatan
# lakh : lakh
# negatif : negatif
# pembelinya : bel
# plin : plin
# plan : plan
# bukalapaktpi : bukalapaktpi
# amati : amat
# ngluarin : ngluarin
# vouchermending : vouchermending
# lazadashopee : lazadashopee
# bahasa : bahasa
# marketing : marketing
# nik : nik
# kakak : kakak
# apikasi : apikasi
# perbankan : perban
# apaapa : apaapa
# parahhhh : parahhhh
# inisaya : inisaya
# kronologinya : kronologi
# mengakibatkan : akibat
# pembelisaya : pembelisaya
# menemukan : temu
# melunasi : lunas
# koplain : koplain
# putuskan : putus
# setan : setan
# setuju : tuju
# pembatasan : batas
# menanggapi : tanggap
# adakah : ada
# unuk : unuk
# menelpon : telpon
# hantu : hantu
# lapor : lapor
# mobile : mobile
# alhamdulillahnya : alhamdulillah
# anjeng : anjeng
# modal : modal
# putar : putar
# bukapak : bukapak
# modalnya : modal
# bos : bos
# bukalapakbangkrut : bukalapakbangkrut
# errorresi : errorresi
# trucking : trucking
# otomatismau : otomatismau
# adaga : adaga
# bisalive : bisalive
# pergunakan : guna
# alhasil : alhasil
# telfon : telfon
# untjk : untjk
# pegawai : pegawai
# batu : batu
# nasi : nasi
# kerja : kerja
# disc : disc
# byr : byr
# sisanya : sisa
# esok : esok
# masukannya : masuk
# sebentar : sebentar
# mata : mata
# berkunang : nang
# kunang : nang
# warni : warni
# lollipop : lollipop
# detil : detil
# buyer : buyer
# nyauntuk : nyauntuk
# hitungan : hitung
# akhirmya : akhirmya
# dilampirkan : lampir
# penilaian : nilai
# bajakan : baja
# sarat : sarat
# voucer : voucer
# diperbarui : baru
# habisrefund : habisrefund
# yth : yth
# pt : pt
# kupon : kupon
# pelatihan : latih
# sebelumsebelumnya : sebelumsebelumnya
# tim : tim
# diganti : ganti
# realtime : realtime
# infonya : info
# buruburu : buruburu
# ditinggal : tinggal
# bentar : bentar
# pergi : pergi
# disitu : situ
# hey : hey
# ss : ss
# dicarikan : cari
# menghilangkan : hilang
# serbu : serbu
# seru : seru
# casback : casback
# badai : badai
# tap : tap
# vocher : vocher
# melimpah : limpah
# bersamaan : sama
# tiru : tiru
# biru : biru
# muluk : muluk
# hadiah : hadiah
# merata : rata
# durasi : durasi
# persetujuan : tuju
# dirubah : rubah
# berbelitbelit : berbelitbelit
# trik : trik
# cekout : cekout
# anu : anu
# jenis : jenis
# ogah : ogah
# lucu : lucu
# langgananku : langgan
# favoritku : favorit
# buatku : buat
# lengkapbagus : lengkapbagus
# discount : discount
# mengatas : atas
# namakan : nama
# tokennya : tokennya
# tatanan : tatanan
# letak : letak
# menurutku : turut
# lainlainnya : lainlainnya
# dibintang : bintang
# usahini : usahini
# aps : aps
# berisik : berisik
# maksa : maksa
# silakan : sila
# bye : bye
# commerce : commerce
# terparah : parah
# diklik : klik
# muat : muat
# bego : bego
# terbayar : bayar
# taih : taih
# csnya : csnya
# ramah : ramah
# terkait : kait
# mengalami : alami
# positif : positif
# diputus : putus
# pertimbangannya : timbang
# buatan : buat
# anak : anak
# bangsa : bangsa
# kompeten : kompeten
# sikap : sikap
# reseler : reseler
# nenguntungkan : nenguntungkan
# hatihati : hatihati
# cermat : cermat
# menguntungkan : untung
# jahat : jahat
# ditangani : tangan
# dampaknya : dampak
# beribas : beribas
# jshat : jshat
# tegaaaa : tegaaaa
# outlet : outlet
# mundur : mundur
# sellerseller : sellerseller
# katalog : katalog
# bernomor : nomor
# stuk : stuk
# link : link
# url : url
# kerjaangak : kerjaangak
# syulit : syulit
# bobrok : bobrok
# detailnya : detail
# dipesan : pes
# bertul : bertul
# emah : emah
# lapangan : lapang
# buktinya : bukti
# dibalikin : dibalikin
# dianggap : anggap
# tanggapanapa : tanggapanapa
# karyawannya : karyawannya
# syaa : syaa
# pakaidan : pakaidan
# belanjatp : belanjatp
# rewardatau : rewardatau
# kelebihan : lebih
# adasama : adasama
# baruakhir : baruakhir
# lainsemakin : lainsemakin
# log : log
# arahkan : arah
# instruksi : instruksi
# team : team
# mengutamakan : utama
# custumernya : custumernya
# arror : arror
# pertahanin : pertahanin
# menggiurkan : giur
# embel : embel
# aslinya : asli
# amanan : aman
# bot : bot
# pokok : pokok
# bukalapakbukalapakpaylater : bukalapakbukalapakpaylater
# fitue : fitue
# bukalapakpaylater : bukalapakpaylater
# gajih : gajih
# ta : ta
# soale : soale
# kesel : kesel
# bukamaal : bukamaal
# woiii : woiii
# november : november
# memegang : pegang
# tlpn : tlpn
# sengsara : sengsara
# lu : lu
# bintangnyakarena : bintangnyakarena
# sayaudh : sayaudh
# terhitung : hitung
# sayasaya : sayasaya
# naikin : naikin
# recom : recom
# sabtu : sabtu
# pengirimana : pengirimana
# reguler : reguler
# senin : senin
# danauang : danauang
# bertemunya : temu
# dangan : dang
# kompetetif : kompetetif
# melindungi : lindung
# tindakan : tindak
# prestasinya : prestasi
# salam : salam
# dasboard : dasboard
# kriteria : kriteria
# mencairkan : cair
# langkah : langkah
# poto : poto
# benarbenar : benarbenar
# minim : minim
# penerapan : terap
# diberlakukan : laku
# dihentikan : henti
# tegaskan : tegas
# mendapati : dapat
# pelanggaran : langgar
# tokomuakunmu : tokomuakunmu
# masalh : masalh
# seperi : per
# mempersulit : sulit
# mbangking : mbangking
# whatapps : whatapps
# mencet : mencet
# tombol : tombol
# close : close
# hubungiaktifpercuma : hubungiaktifpercuma
# terkonfirmasi : konfirmasi
# menghasilkan : hasil
# bermutu : mutu
# covid : covid
# dicentang : centang
# merekatanpa : merekatanpa
# centangkalau : centangkalau
# anti : anti
# rupiah : rupiah
# bukalapakada : bukalapakada
# kebakaran : bakar
# menggunakannya : guna
# cepatlama : cepatlama
# waktunyaudah : waktunyaudah
# blga : blga
# blapa : blapa
# melaporkan : lapor
# jawabga : jawabga
# dlutolong : dlutolong
# koo : koo
# akomodatif : akomodatif
# siihmaaaana : siihmaaaana
# robot : robot
# doangngeklaim : doangngeklaim
# laaagini : laaagini
# gimanabeneran : gimanabeneran
# tata : tata
# digagalkan : gagal
# dananya : dana
# ditunggu : tunggu
# padahalan : padahal
# tulis : tulis
# spam : spam
# apesnya : apes
# terlanjur : lanjur
# sulitnya : sulit
# recomded : recomded
# brengseksangat : brengseksangat
# menjengkelkantiap : menjengkelkantiap
# ubah : ubah
# bisaaplikasi : bisaaplikasi
# duniasudah : duniasudah
# teleponaplikasi : teleponaplikasi
# berengsek : berengsek
# tokenya : toke
# balikin : balikin
# temui : temu
# mengundang : undang
# ...
# mengajarkan : ajar
# disetiap : tiap
# koneksimu : koneksi
# pesawat : pesawat
# antariksa : antariksa
# melintas : lintas
# shoop : shoop
# apilkasi : apilkasi
# grtis : grtis
# penangannan : penangannan
# bukalapk : bukalapk
# malesin : malesin
# membantudulu : membantudulu
# membantutapi : membantutapi
# bekukanpdhal : bekukanpdhal
# sekalibukalapak : sekalibukalapak
# enggak mau : enggak mau
# beku : beku
# belenja : belenja
# blenk : blenk
# dengar : dengar
# lemotjadi : lemotjadi
# diikuti : ikut
# compatible : compatible
# rotasi : rotasi
# tegak : tegak
# landscape : landscape
# mengurangi : kurang
# sentuh : sentuh
# genting : genting
# competitornya : competitornya
# parahhhhh : parahhhhh
# ngurusi : ngurusi
# terjaga : jaga
# membantusemoga : membantusemoga
# sealu : alu
# penguriman : penguriman
# samakin : samakin
# moga : moga
# maksimalkan : maksimal
# payahhh : payahhh
# dipromosiin : dipromosiin
# nol : nol
# peringan : pering
# appnya : appnya
# punyak : punyak
# dinonaktifkandibekukansetelah : dinonaktifkandibekukansetelah
# mengatasnamakan : mengatasnamakan
# membayarnya : bayar
# govloq : govloq
# ramerame : ramerame
# menyertakan : serta
# delivery : delivery
# bukalapaksemoga : bukalapaksemoga
# depannya : depan
# diorder : order
# adaterutama : adaterutama
# stb : stb
# dvbt : dvbt
# aplgi : aplgi
# pngiriman : pngiriman
# terintegritas : integritas
# puaskarna : puaskarna
# pinjamankalau : pinjamankalau
# bunganya : bunga
# sikurangin : sikurangin
# dikitlahhehehemantap : dikitlahhehehemantap
# belnja : belnja
# lemotbahkan : lemotbahkan
# sesimpel : simpel
# emaneman : emaneman
# berdiri : diri
# tetspi : tetspi
# performanya : performa
# bertambahnya : tambah
# kemampuan : mampu
# seringkali : seringkali
# lemotnya : lot
# jaditerus : jaditerus
# hapusmau : hapusmau
# perubahanmau : perubahanmau
# gantiotp : gantiotp
# nmor : nmor
# lgiauto : lgiauto
# byby : byby
# keamanananya : keamanananya
# tidk : tidk
# making : making
# mintak : mintak
# photo : photo
# menunjukan : tunjuk
# ttansaksi : ttansaksi
# bekukanpadahal : bekukanpadahal
# pakaipas : pakaipas
# daftargiliran : daftargiliran
# silahjkan : silahjkan
# loginkok : loginkok
# ditinjau : tinjau
# laintokopedia : laintokopedia
# akalkok : akalkok
# uinstal : uinstal
# diatas : atas
# lapaktp : lapaktp
# diposting : diposting
# bukalapakkrn : bukalapakkrn
# mengisi : isi
# meneruskan : terus
# diajukan : aju
# lambatasuknya : lambatasuknya
# marketplaca : marketplaca
# kacaumasa : kacaumasa
# ngorder : ngorder
# jaktim : jaktim
# jaksel : jaksel
# parahngk : parahngk
# ekspedisiyg : ekspedisiyg
# cepatganti : cepatganti
# sikeong : sikeong
# bidang : bidang
# umkm : umkm
# academy : academy
# dimengerti : erti
# awet : awet
# abang : abang
# semang : semang
# handle : handle
# hape : hape
# besoknya : besok
# gerak : gerak
# sekalik : sekalik
# hank : hank
# terbit : terbit
# enggak pernah : enggak pernah
# ilangresetbaik : ilangresetbaik
# perncarian : perncarian
# sellerbuyer : sellerbuyer
# puasnyaman : puasnyaman
# tenang : tenang
# gangguannya : ganggu
# kepastian : pasti
# sependapat : dapat
# acara : acara
# mjd : mjd
# bunyi : bunyi
# pesannya : pesan
# rese : rese
# seri : seri
# platformnya : platform
# operating : operating
# interfacenya : interfacenya
# menutup : tutup
# reinstal : reinstal
# akitivitas : akitivitas
# desktop : desktop
# androin : androin
# ios : ios
# ngelink : ngelink
# terlewati : lewat
# dibawah : bawah
# bunyinya : bunyi
# baruudah : baruudah
# mohondiperbaiki : mohondiperbaiki
# teraman : ram
# fiktif : fiktif
# dichat : dichat
# transaksinyajd : transaksinyajd
# anter : anter
# pendaftaran : daftar
# bukalapakbukatabungan : bukalapakbukatabungan
# landing : landing
# enggak usah : enggak usah
# nyapada : nyapada
# eksekusi : eksekusi
# transaksidalam : transaksidalam
# satuharus : satuharus
# catatan : catat
# berkualitastidak : berkualitastidak
# bedanya : beda
# lancarbisa : lancarbisa
# errorserver : errorserver
# berkualitasdan : berkualitasdan
# berkualitasbuat : berkualitasbuat
# mengubah : ubah
# tabunganrekeningsedangkan : tabunganrekeningsedangkan
# wajib : wajib
# datanya : data
# minnn : minnn
# adaptasi : adaptasi
# pentingkan : penting
# waktupokoknya : waktupokoknya
# ahlak : ahlak
# mengeluarkan : keluar
# vyata : vyata
# air : air
# boom : boom
# bentuknya : bentuk
# bentuk : bentuk
# haga : haga
# ati : ati
# direkomendasi : rekomendasi
# dijemput : jemput
# tuhhhh : tuhhhh
# datenggg : datenggg
# komplainn : komplainn
# rugiii : rugiii
# nihhhh : nihhhh
# seduniacuma : seduniacuma
# ambilini : ambilini
# kendla : kendla
# bngung : bngung
# siapaini : siapaini
# adminbuat : adminbuat
# tanganin : tanganin
# ajaapliaksi : ajaapliaksi
# nangungtinggal : nangungtinggal
# tutupnya : tutup
# doankgini : doankgini
# saingin : saingin
# shopemimpi : shopemimpi
# lue : lue
# bang : bang
# higss : higss
# perjudian : judi
# berkedok : kedok
# gameyang : gameyang
# marketplce : marketplce
# tolakcuma : tolakcuma
# terimasadar : terimasadar
# nuggu : nuggu
# diperbaikisoalnya : diperbaikisoalnya
# kecamatan : camat
# dimanfaatkan : manfaat
# ordreran : ordreran
# ekspedisikarna : ekspedisikarna
# ongkirdgn : ongkirdgn
# inikalo : inikalo
# nyanda : nyanda
# ongkirpdhal : ongkirpdhal
# sekalibelanja : sekalibelanja
# lgjd : lgjd
# nyaga : nyaga
# sebln : sebln
# terkorup : korup
# masamasa : masamasa
# ampuncs : ampuncs
# melamun : lamun
# bukalapakkualitas : bukalapakkualitas
# bagusongkirnya : bagusongkirnya
# murahterjangkau : murahterjangkau
# estimasinya : estimasi
# barangnyapokoknya : barangnyapokoknya
# maleskalau : maleskalau
# mbelgedez : mbelgedez
# tuju : tuju
# rentang : rentang
# kadauwarsa : kadauwarsa
# keuangannya : uang
# optimal : optimal
# keblokir : blokir
# nomormasuk : nomormasuk
# diupload : diupload
# otpnya : otpnya
# okeehh : okeehh
# yeezssss : yeezssss
# mantabbss : mantabbss
# reaponsif : reaponsif
# pelajari : ajar
# etc : etc
# instant : instant
# itulahpantes : itulahpantes
# balas : balas
# arahin : arahin
# blidappreview : blidappreview
# nonus : nonus
# neruntun : neruntun
# mendeteksi : deteksi
# kejanggalan : janggal
# bantuantapi : bantuantapi
# ngakses : ngakses
# pencerahannya : cerah
# menbuat : menbuat
# ketahui : tahu
# penyebabnya : sebab
# bukapinjaman : bukapinjaman
# singkronisasi : singkronisasi
# bgsond : bgsond
# shak : shak
# tingkatkkan : tingkatkkan
# mbnya : mbnya
# belikan : belikan
# waswas : waswas
# maraknya : marak
# macamtapi : macamtapi
# responnyaterima : responnyaterima
# pelayanannyagoodluck : pelayanannyagoodluck
# angin : angin
# enggak tau : enggak tau
# terduga : duga
# naikthanks : naikthanks
# recovery : recovery
# baiktpi : baiktpi
# apkmempermudah : apkmempermudah
# spaylater : spaylater
# menggangu : menggangu
# sejenisnya : jenis
# setting : setting
# filternya : filter
# ikonik : ikonik
# iconnect : iconnect
# kerjasamanya : kerjasamanya
# iconnet : iconnet
# susunan : susun
# disederhanakan : sederhana
# transisi : transisi
# memakan : makan
# membangun : bangun
# modern : modern
# trimakasihhh : trimakasihhh
# cttn : cttn
# be : be
# connected : connected
# copy : copy
# perangkat : perangkat
# gamti : gamti
# eamasalah : eamasalah
# cicilansaya : cicilansaya
# merchan : merchan
# verifikasitrus : verifikasitrus
# dihistory : dihistory
# kenal : kenal
# siang : siang
# non : non
# masalahny : masalahny
# rutin : rutin
# aktifparah : aktifparah
# bagusbangke : bagusbangke
# playstoregak : playstoregak
# gegara : gegara
# pemantauan : pantau
# serunya : seru
# mantapppp : mantapppp
# kendor : kendor
# oriented : oriented
# wasit : wasit
# intermediasi : intermediasi
# haknya : hak
# kompaint : kompaint
# complaint : complaint
# action : action
# kau : kau
# menceritakan : cerita
# semesta : semesta
# mencatat : catat
# wilayah : wilayah
# papua : papua
# keriditvo : keriditvo
# giamanasih : giamanasih
# mgadain : mgadain
# sesuaikalo : sesuaikalo
# ngafain : ngafain
# gala : gala
# gj : gj
# saldobuktinya : saldobuktinya
# halaaaah : halaaaah
# belielektronik : belielektronik
# nyatrimakasih : nyatrimakasih
# sajayang : sajayang
# byaya : byaya
# lanannya : lanannya
# yanyoba : yanyoba
# wkwkwkprasaan : wkwkwkprasaan
# layannalias : layannalias
# besok : besok
# penjelasan : jelas
# kaos : kaos
# mngecewakan : mngecewakan
# dehkayak : dehkayak
# nyaklo : nyaklo
# termurah : murah
# reksada : reksada
# banyakkarena : banyakkarena
# sah : sah
# diblokir : blokir
# garajual : garajual
# perselisihan : selisih
# apl : apl
# nyagara : nyagara
# lunassss : lunassss
# pergantian : ganti
# lather : lather
# hmnnnmnmmmmmn : hmnnnmnmmmmmn
# berbedaaneh : berbedaaneh
# pto : pto
# pp : pp
# memprioritaskan : prioritas
# gadget : gadget
# berselancar : selancar
# jadulku : jadulku
# sumpai : sumpai
# ribettt : ribettt
# keyboard : keyboard
# drivernya : drivernya
# kabel : kabel
# handrem : handrem
# nampaknya : nampaknya
# penanggulangan : tanggulang
# pulsatoken : pulsatoken
# dilunasi : lunas
# diapakai : diapakai
# batalkanmode : batalkanmode
# pembayran : pembayran
# ceriatapi : ceriatapi
# kembalimau : kembalimau
# sihada : sihada
# diamkan : diam
# bukalapakpaling : bukalapakpaling
# terbantu : bantu
# diadakan : ada
# sebelahkarena : sebelahkarena
# kbnykn : kbnykn
# duluantransfer : duluantransfer
# mantaaps : mantaaps
# masalihat : masalihat
# lapakpernah : lapakpernah
# aplikator : aplikator
# memelihara : pelihara
# nyaternyata : nyaternyata
# pedahal : pedahal
# melewati : lewat
# vitur : vitur
# gampangpengiriman : gampangpengiriman
# cepatkurir : cepatkurir
# minat : minat
# aplikasiditambah : aplikasiditambah
# mahaaallll : mahaaallll
# bukalapakgw : bukalapakgw
# mitrabukannya : mitrabukannya
# belanjaitu : belanjaitu
# kanknpa : kanknpa
# bukalapakaneh : bukalapakaneh
# manapun : mana
# playleter : playleter
# gdk : gdk
# bumi : bumi
# limid : limid
# kepake : kepake
# mencekit : cekit
# licik : licik
# doakan : doa
# pengurus : urus
# mengenaskan : enas
# riba : riba
# onderdil : onderdil
# sepeda : sepeda
# kreatif : kreatif
# optimis : optimis
# geblek : geblek
# emailbuka : emailbuka
# lgtrus : lgtrus
# palah : palah
# ktol : ktol
# pesananaku : pesananaku
# pertamakalinya : pertamakalinya
# goodbay : goodbay
# mengganti : ganti
# kendalanya : kendala
# dyoutube : dyoutube
# tutornya : tutor
# ternyta : ternyta
# trhbung : trhbung
# bhkan : bhkan
# mslah : mslah
# trselesaikan : trselesaikan
# lapaknya : lapak
# recomendkomplen : recomendkomplen
# lagiga : lagiga
# perbaikannya : baik
# rekomented : rekomented
# teruuuss : teruuuss
# adehh : adehh
# gblok : gblok
# istri : istri
# rbpula : rbpula
# bagussssssssss : bagussssssssss
# seting : ting
# planggan : planggan
# juaranya : juara
# sebelahharga : sebelahharga
# mantullllll : mantullllll
# optimalkan : optimal
# kesedot : sedot
# terbodoh : bodoh
# re : re
# kebukapas : kebukapas
# barangselalu : barangselalu
# awaldan : awaldan
# icon : icon
# animasi : animasi
# berlaripayah : berlaripayah
# perbaikisaya : perbaikisaya
# respect : respect
# instagram : instagram
# dibales : dibales
# untukberbelanja : untukberbelanja
# bagusmempermudah : bagusmempermudah
# hatihatai : hatihatai
# diajak : ajak
# dont : dont
# this : this
# dipercayabarang : dipercayabarang
# komplituang : komplituang
# return : return
# gampangsaya : gampangsaya
# tertarik : tarik
# reload : reload
# berabe : berabe
# latter : latter
# kualitasnya : kualitas
# sarana : sarana
# perantara : antara
# berintegritas : integritas
# keinginanpesanan : keinginanpesanan
# dinamika : dinamika
# kasat : kasat
# diandalkanayo : diandalkanayo
# secepatnyananti : secepatnyananti
# ketinggalankita : ketinggalankita
# surat : surat
# sistemkurang : sistemkurang
# formitu : formitu
# masalahnyajawaban : masalahnyajawaban
# lamawaalaaeh : lamawaalaaeh
# lapakdan : lapakdan
# berterimakasih : berterimakasih
# penyampaian : sampai
# materinya : materi
# terperincipelatihannya : terperincipelatihannya
# pahamisangat : pahamisangat
# sayatrimakasih : sayatrimakasih
# perbanyak : banyak
# pembelajaran : ajar
# prakerjasaya : prakerjasaya
# menerangkan : terang
# terjun : terjun
# freelancer : freelancer
# nampilin : nampilin
# terpopuler : populer
# komparasi : komparasi
# puaskanpengunaan : puaskanpengunaan
# carisaya : carisaya
# upgrde : upgrde
# dibukasetiap : dibukasetiap
# aplikase : aplikase
# keluarsuruh : keluarsuruh
# upgradepdahal : upgradepdahal
# calon : calon
# atow : atow
# waktubukalapak : waktubukalapak
# traksaksi : traksaksi
# kaliklo : kaliklo
# terjangkauongkos : terjangkauongkos
# shaller : shaller
# samsung : samsung
# ringansekarang : ringansekarang
# hitam : hitam
# duluterus : duluterus
# merespongak : merespongak
# aplikasibiar : aplikasibiar
# terbawa : bawa
# pebaharui : baharu
# mepersulit : mepersulit
# melakukakan : melakukakan
# kontakcall : kontakcall
# berinteraksi : interaksi
# blnya : blnya
# berbenti : berbenti
# dibagian : bagi
# diklaim : klaim
# ngurut : ngurut
# {'paylater': 'paylater', 'batalkan': 'batal', 'otomatis': 'otomatis', 'kadang': 'kadang', 'nya': 'nya', 'gantian': 'ganti', 'jatuh': 'jatuh', 'tempo': 'tempo', 'bayar': 'bayar', 'biaya': 'biaya', 'keterlambatan': 'lambat', 'layanan': 'layan', 'biar': 'biar', 'merasakan': 'rasa', 'rasakan': 'rasa', 'sistem': 'sistem', 'seenak': 'enak', 'chat': 'chat', 'susah': 'susah', 'error': 'error', 'menyalahkan': 'salah', 'bikin': 'bikin', 'pusing': 'pusing', 'pastinya': 'pasti', 'hp': 'hp', 'wifi': 'wifi', 'lemmooottttt': 'lemmooottttt', 'dasarnya': 'dasar', 'bukalapak': 'bukalapak', 'karuan': 'karuan', 'lihat': 'lihat', 'status': 'status', 'transsaksi': 'transsaksi', 'menunggu': 'tunggu', 'halaman': 'halaman', 'terisi': 'isi', 'penuh': 'penuh', 'muncul': 'muncul', 'penawaran': 'tawar', 'tanda': 'tanda', 'kesulitan': 'sulit', 'terbaca': 'baca', 'kepencet': 'pencet', 'bulalapak': 'bulalapak', 'bermain': 'main', 'paket': 'paket', 'data': 'data', 'orang': 'orang', 'konten': 'konten', 'webnya': 'webnya', 'lumayan': 'lumayan', 'hasilnya': 'hasil', 'semoga': 'moga', 'kecurigaan': 'curiga', 'maafkan': 'maaf', 'membantu': 'bantu', 'pelanggan': 'langgan', 'pembayaran': 'bayar', 'limit': 'limit', 'bertambah': 'tambah', 'profesional': 'profesional', 'maju': 'maju', 'aplikasi': 'aplikasi', 'bagus': 'bagus', 'minusnya': 'minus', 'ongkir': 'ongkir', 'mahal': 'mahal', 'voucher': 'voucher', 'dipakai': 'pakai', 'memenuhi': 'penuh', 'persyaratan': 'syarat', 'pilihan': 'pilih', 'jasa': 'jasa', 'ekspedisi': 'ekspedisi', 'parah': 'parah', 'pesanan': 'pesan', 'tanggal': 'tanggal', 'april': 'april', 'dikirim': 'kirim', 'pelapak': 'lapak', 'barang': 'barang', 'simpan': 'simpan', 'gudang': 'gudang', 'bukaexpress': 'bukaexpress', 'buka': 'buka', 'bantuan': 'bantu', 'menu': 'menu', 'livechat': 'livechat', 'berfungsi': 'fungsi', 'beda': 'beda', 'merchant': 'merchant', 'kecewa': 'kecewa', 'jual': 'jual', 'emas': 'emas', 'bukaemas': 'bukaemas', 'banget': 'banget', 'problemnya': 'problem', 'verifikasi': 'verifikasi', 'no': 'no', 'bad': 'bad', 'gateway': 'gateway', 'kode': 'kode', 'enggak bisa': 'enggak bisa', 'ulang': 'ulang', 'kayaknya': 'kayak', 'sengaja': 'sengaja', 'dipersulit': 'sulit', 'tarik': 'tarik', 'investasi': 'investasi', 'app': 'app', 'berat': 'berat', 'fitur': 'fitur', 'kebanyakan': 'banyak', 'rusak': 'rusak', 'tolong': 'tolong', 'dibikin': 'bikin', 'simpel': 'simpel', 'solusi': 'solusi', 'bukabantuan': 'bukabantuan', 'live': 'live', 'jam': 'jam', 'cs': 'cs', 'mematikan': 'mati', 'obrolannya': 'obrol', 'aktifin': 'aktifin', 'akun': 'akun', 'hangus': 'hangus', 'terverifikasi': 'verifikasi', 'kyc': 'kyc', 'sory': 'sory', 'ane': 'ane', 'uninstall': 'uninstall', 'join': 'join', 'seller': 'seller', 'deh': 'deh', 'bl': 'bl', 'kepercayan': 'kepercayan', 'ecom': 'ecom', 'utama': 'utama', 'transaksi': 'transaksi', 'aktifasi': 'aktifasi', 'gampang': 'gampang', 'komplin': 'komplin', 'sumpah': 'sumpah', 'enek': 'enek', 'masak': 'masak', 'kirim': 'kirim', 'otp': 'otp', 'nomer': 'nomer', 'aktif': 'aktif', 'email': 'email', 'sefty': 'sefty', 'main': 'main', 'lo': 'lo', 'nyataanya': 'nyataanya', 'nomor': 'nomor', 'nomornya': 'nomor', 'aktivasi': 'aktivasi', 'ya': 'ya', 'ampun': 'ampun', 'syaratnya': 'syarat', 'kayak': 'kayak', 'mengajukan': 'aju', 'pinjaman': 'pinjam', 'bank': 'bank', 'sumpaah': 'sumpaah', 'oohh': 'oohh', 'devlover': 'devlover', 'lebay': 'lebay', 'syarat': 'syarat', 'pengin': 'pengin', 'masuk': 'masuk', 'dikirimkan': 'kirim', 'ganti': 'ganti', 'foto': 'foto', 'ktprekening': 'ktprekening', 'daftar': 'daftar', 'pakai': 'pakai', 'ktp': 'ktp', 'rekening': 'rekening', 'seribet': 'seribet', 'kah': 'kah', 'cantumin': 'cantumin', 'keterangan': 'terang', 'diubah': 'ubah', 'memasukkan': 'masuk', 'terima': 'terima', 'tipenyasaya': 'tipenyasaya', 'komplain': 'komplain', 'admin': 'admin', 'menyelesaikan': 'selesai', 'rugi': 'rugi', 'menerima': 'terima', 'hilang': 'hilang', 'uang': 'uang', 'iklannya': 'iklan', 'loadingnya': 'loadingnya', 'membuka': 'buka', 'lapak': ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/1300 [00:00<?, ?it/s]

# %%
name_dataframe["Ulasan_clean"] = [' '.join(map(str, l)) for l in name_dataframe['Ulasan_Stemmed']]

# %%
name_dataframe.to_excel("tokped_text.xlsx")

# %%
ulasan = ' '.join(str(v) for v in name_dataframe['Ulasan_clean'])

# %%
tokenize_ulasan = word_tokenize(ulasan)

# %%
tokenize_ulasan
# Out:
# ['paylater',
#  'batal',
#  'otomatis',
#  'kadang',
#  'nya',
#  'ganti',
#  'jatuh',
#  'tempo',
#  'bayar',
#  'biaya',
#  'lambat',
#  'biaya',
#  'layan',
#  'biar',
#  'rasa',
#  'rasa',
#  'sistem',
#  'enak',
#  'nya',
#  'chat',
#  'susah',
#  'kadang',
#  'error',
#  'salah',
#  'layan',
#  'nya',
#  'bikin',
#  'pusing',
#  'ganti',
#  'pusing',
#  'pasti',
#  'hp',
#  'wifi',
#  'lemmooottttt',
#  'dasar',
#  'bukalapak',
#  'karuan',
#  'lihat',
#  'status',
#  'transsaksi',
#  'tunggu',
#  'halaman',
#  'isi',
#  'penuh',
#  'muncul',
#  'tawar',
#  'kadang',
#  'tanda',
#  'nya',
#  'sulit',
#  'baca',
#  'pencet',
#  'bulalapak',
#  'main',
#  'paket',
#  'data',
#  'orang',
#  'konten',
#  'webnya',
#  'lumayan',
#  'hasil',
#  'moga',
#  'curiga',
#  'maaf',
#  'bantu',
#  'bukalapak',
#  'langgan',
#  'paylater',
#  'bayar',
#  'limit',
#  'tambah',
#  'moga',
#  'bukalapak',
#  'profesional',
#  'maju',
#  'aplikasi',
#  'bagus',
#  'minus',
#  'ongkir',
#  'mahal',
#  'voucher',
#  'pakai',
#  'penuh',
#  'syarat',
#  'pilih',
#  'jasa',
#  'ekspedisi',
#  'bukalapak',
#  'parah',
#  'pesan',
#  'tanggal',
#  'april',
#  'kirim',
#  'lapak',
#  'april',
#  'april',
#  'barang',
#  'simpan',
#  'gudang',
#  'ekspedisi',
#  'bukaexpress',
#  'buka',
#  'bantu',
#  'menu',
#  'livechat',
#  'fungsi',
#  'beda',
#  'aplikasi',
#  'merchant',
#  'bukalapak',
#  'bikin',
#  'kecewa',
#  'jual',
#  'emas',
#  'bukaemas',
#  'susah',
#  'banget',
#  'banget',
#  'problem',
#  'verifikasi',
#  'no',
#  'hp',
#  'muncul',
#  'bad',
#  'gateway',
#  'kode',
#  'verifikasi',
#  'enggak',
#  'bisa',
#  'kirim',
#  'ulang',
#  'kayak',
#  'sengaja',
#  'sulit',
#  'tarik',
#  'investasi',
#  'bukalapak',
#  'app',
#  'nya',
#  'berat',
#  'fitur',
#  'banyak',
#  'fitur',
#  'rusak',
#  'tolong',
#  'bikin',
#  'simpel',
#  'solusi',
#  'bukabantuan',
#  'live',
#  'chat',
#  'bantu',
#  'tunggu',
#  'jam',
#  'cs',
#  'nya',
#  'mati',
#  'obrol',
#  'parah',
#  'bantu',
#  'aktifin',
#  'akun',
#  'no',
#  'nya',
#  'hangus',
#  'verifikasi',
#  'kyc',
#  'aktifin',
#  'sory',
#  'ane',
#  'uninstall',
#  'join',
#  'seller',
#  'deh',
#  'bl',
#  'kepercayan',
#  'ecom',
#  'utama',
#  'transaksi',
#  'aktifasi',
#  'gampang',
#  'komplin',
#  'gampang',
#  'sumpah',
#  'enek',
#  'masak',
#  'kirim',
#  'kode',
#  'otp',
#  'nomer',
#  'aktif',
#  'kirim',
#  'email',
#  'sefty',
#  'email',
#  'main',
#  'lo',
#  'nyataanya',
#  'nomor',
#  'otp',
#  'orang',
#  'nomor',
#  'aktif',
#  'aktivasi',
#  'akun',
#  'ya',
#  'ampun',
#  'syarat',
#  'kayak',
#  'orang',
#  'aju',
#  'pinjam',
#  'bank',
#  'sumpaah',
#  'oohh',
#  'devlover',
#  'bl',
#  'lebay',
#  'bikin',
#  'syarat',
#  'aktivasi',
#  'parah',
#  'kayak',
#  'pengin',
#  'masuk',
#  'akun',
#  'email',
#  'kode',
#  'verifikasi',
#  'nya',
#  'kirim',
#  'nomor',
#  'nomor',
#  'aktif',
#  'pengin',
#  'ganti',
#  'nomor',
#  'syarat',
#  'nya',
#  'foto',
#  'ktprekening',
#  'daftar',
#  'pakai',
#  'ktp',
#  'rekening',
#  'seribet',
#  'kah',
#  'daftar',
#  'bikin',
#  'akun',
#  'pengin',
#  'cantumin',
#  'email',
#  'terang',
#  'nya',
#  'email',
#  'ubah',
#  'masuk',
#  'email',
#  'nya',
#  'terima',
#  'barang',
#  'tipenyasaya',
#  'komplain',
#  'admin',
#  'selesai',
#  'bayar',
#  'rugi',
#  'terima',
#  'paket',
#  'lapak',
#  'hilang',
#  'uang',
#  'transaksi',
#  'barang',
#  'terima',
#  'iklan',
#  'loadingnya',
#  'buka',
#  'aplikasi',
#  'buka',
#  'lapak',
#  'ngechek',
#  'kirim',
#  'tunggu',
#  'loading',
#  'iklan',
#  'mohon',
#  'biar',
#  'langgan',
#  'nyaman',
#  'buka',
#  'aplikasi',
#  'pakai',
#  'kuota',
#  'internetdi',
#  'iklan',
#  'nglungker',
#  'tambah',
#  'jenuhtlg',
#  'perhati',
#  'jelek',
#  'bukalapak',
#  'aplikasi',
#  'lot',
#  'adu',
#  'bukabantuan',
#  'langsung',
#  'tele',
#  'kesana',
#  'kemari',
#  'coba',
#  'kasih',
#  'menu',
#  'langsung',
#  'tinggal',
#  'klik',
#  'cari',
#  'barang',
#  'sulit',
#  'cuman',
#  'dikit',
#  'barang',
#  'kalah',
#  'aplikasi',
#  'bukalapakygdulu',
#  'bukalapak',
#  'ribu',
#  'barang',
#  'upload',
#  'cumq',
#  'tampil',
#  'cari',
#  'kalo',
#  'klik',
#  'barang',
#  'temu',
#  'gaya',
#  'barang',
#  'jual',
#  'temu',
#  'beli',
#  'bukalapak',
#  'sepi',
#  'unjung',
#  'kesini',
#  'sistem',
#  'nya',
#  'berat',
#  'ajabanyak',
#  'sisrem',
#  'gunabuka',
#  'apk',
#  'bl',
#  'kaya',
#  'buka',
#  'game',
#  'berat',
#  'ajaisi',
#  'harap',
#  'buang',
#  'ajadan',
#  'sistem',
#  'bagusmasuk',
#  'buka',
#  'bantu',
#  'ribetnya',
#  'ampun',
#  'aneh',
#  'ya',
#  'didownload',
#  'ulang',
#  'masuk',
#  'apk',
#  'touch',
#  'touch',
#  'pakai',
#  'ya',
#  'apk',
#  'nya',
#  'hapus',
#  'az',
#  'apk',
#  'nya',
#  'repot',
#  'pesan',
#  'batal',
#  'otomatis',
#  'tanggal',
#  'proses',
#  'status',
#  'jual',
#  'kadaluarsamau',
#  'komplen',
#  'hilang',
#  'uang',
#  'ambil',
#  'buka',
#  'lapak',
#  'kapok',
#  'belanja',
#  'buka',
#  'lapak',
#  'apk',
#  'error',
#  'sistem',
#  'cod',
#  'uninstal',
#  'beban',
#  'and',
#  'sampah',
#  'smartphone',
#  'gue',
#  'piara',
#  'nya',
#  'apk',
#  'manfaat',
#  'gue',
#  'pesan',
#  'kendala',
#  'kirim',
#  'barang',
#  'beli',
#  'bayar',
#  'sistem',
#  'canggih',
#  'komplain',
#  'tunggu',
#  'aplikasi',
#  'cuman',
#  'uang',
#  'sadah',
#  'kembaliini',
#  'tunggu',
#  'kepastianpayah',
#  'sesal',
#  'gue',
#  'beli',
#  'barang',
#  'dibukalapak',
#  'uang',
#  'gue',
#  'apk',
#  'sulit',
#  'komplain',
#  'kendala',
#  'live',
#  'chat',
#  'cs',
#  'nya',
#  'mitra',
#  'dalem',
#  'nya',
#  'tipu',
#  'tipu',
#  'uang',
#  'masuk',
#  'refund',
#  'detik',
#  'erti',
#  'biyaya',
#  'tangan',
#  'maksud',
#  'sesak',
#  'biyaya',
#  'sgitu',
#  'kalo',
#  'ilangin',
#  'tuhklo',
#  'kurang',
#  'kepakasa',
#  'blanja',
#  'saking',
#  'barang',
#  'kecewa',
#  'aplikasi',
#  'mudah',
#  'berbelanjatapi',
#  'susah',
#  'dam',
#  'halapalagi',
#  'tanggap',
#  'lapak',
#  'nya',
#  'bantu',
#  'beli',
#  'buset',
#  'fitur',
#  'fitur',
#  'bukalapak',
#  'pajang',
#  'fitur',
#  'komplain',
#  'halaman',
#  'temu',
#  'pesan',
#  'terima',
#  'otomatis',
#  'bukalapak',
#  'hebat',
#  'uang',
#  'lenya',
#  'ribu',
#  'layan',
#  'bukalapak',
#  'bagus',
#  'kesini',
#  'kecewa',
#  'status',
#  'proses',
#  'kirim',
#  'barang',
#  'beli',
#  'kecewa',
#  'lapak',
#  'dikerjain',
#  'buka',
#  'aplikasi',
#  'pesan',
#  'status',
#  'baik',
#  'sistemnyakecewa',
#  'layan',
#  'bukaexpress',
#  'paket',
#  'telat',
#  'pilih',
#  'kurir',
#  'tambah',
#  'report',
#  'kurir',
#  'bermasalahpaket',
#  'jadwal',
#  'kompensasi',
#  'jamin',
#  'uang',
#  'kembalihanya',
#  'slogan',
#  'belakabagaimana',
#  'min',
#  'chat',
#  'buka',
#  'bantu',
#  'respon',
#  'payah',
#  'ah',
#  'kecewa',
#  'saldo',
#  'habis',
#  'untung',
#  'ngisi',
#  'nya',
#  'coba',
#  'isi',
#  'saldo',
#  'cash',
#  'back',
#  'lom',
#  'pakai',
#  'tau',
#  'ambil',
#  'telepon',
#  'cs',
#  'muas',
#  'jawabannyacoba',
#  'batal',
#  'transaksi',
#  'tanggepin',
#  'lapak',
#  'tlong',
#  'cs',
#  'jawab',
#  'tunggu',
#  'tentu',
#  'sistem',
#  'jgbuat',
#  'cs',
#  'kalo',
#  'bantumakin',
#  'kesini',
#  'parah',
#  'buka',
#  'lapak',
#  'hubungin',
#  'live',
#  'chatlemot',
#  'tele',
#  'tele',
#  'sory',
#  'turun',
#  'lag',
#  'bintang',
#  'baik',
#  'karuan',
#  'saran',
#  'expedisi',
#  'kurir',
#  'reg',
#  'next',
#  'day',
#  'bukaexpress',
#  'pakai',
#  'sicepat',
#  'error',
#  'pick',
#  'up',
#  'kurir',
#  'lelet',
#  'kurir',
#  'kurir',
#  'kirim',
#  'criss',
#  'cross',
#  'sesuai',
#  'sop',
#  'status',
#  'resi',
#  'update',
#  'komplen',
#  'cs',
#  'ybs',
#  'solusi',
#  'percaya',
#  'kirim',
#  'konsumen',
#  'moga',
#  'baik',
#  'depan',
#  'nya',
#  'beli',
#  'kecewadimana',
#  'lapak',
#  'sedia',
#  'bayar',
#  'codtapi',
#  'bukalapak',
#  'sedia',
#  'pilih',
#  'bayar',
#  'cod',
#  'buka',
#  'express',
#  'cod',
#  'cod',
#  'kecewa',
#  'payleater',
#  'bukalapaksaya',
#  'bayar',
#  'tagih',
#  'tagih',
#  'lagibukti',
#  'struknya',
#  'buang',
#  'nya',
#  'bayar',
#  'kasir',
#  'indomart',
#  'hasil',
#  'aplikasi',
#  'bukalapak',
#  'yeah',
#  'tagihantapi',
#  'aneh',
#  'saldo',
#  'limit',
#  'komplain',
#  'nya',
#  'bingung',
#  'salah',
#  'orang',
#  'indomart',
#  'kah',
#  'paylater',
#  'bukalapak',
#  'kecewa',
#  'pesan',
#  'barang',
#  'tanggal',
#  'januari',
#  'kirim',
#  'jugasudah',
#  'aju',
#  'komplain',
#  'tanggap',
#  'bukalapaksungguh',
#  'buruk',
#  'layan',
#  'bukalapak',
#  'gratis',
#  'ongkir',
#  'tulis',
#  'banyak',
#  'syarat',
#  'bukalapak',
#  'andal',
#  'belanja',
#  'online',
#  'no',
#  'way',
#  'tinggal',
#  'mending',
#  'pakai',
#  'update',
#  'pusat',
#  'bantu',
#  'pakai',
#  'chat',
#  'cs',
#  'respon',
#  'komplain',
#  'beli',
#  'pulsa',
#  'no',
#  'tuju',
#  'saldo',
#  'potong',
#  'pulsa',
#  'masuk',
#  'account',
#  'dana',
#  'bukalapak',
#  'masalah',
#  'berani',
#  'belanja',
#  'kontak',
#  'cs',
#  'dana',
#  'rumit',
#  'solusi',
#  'pakai',
#  'danabukalapak',
#  'trimakasih',
#  'bukalapak',
#  'maju',
#  'inovatif',
#  'aplikasi',
#  'ecommerce',
#  'bagus',
#  'cocok',
#  'bisnis',
#  'lapak',
#  'online',
#  'simple',
#  'aplikasi',
#  'ringan',
#  'all',
#  'one',
#  'feature',
#  'nya',
#  'rekomendasi',
#  'app',
#  'aplikasi',
#  'berat',
#  'kalah',
#  'toko',
#  'online',
#  'belah',
#  'klik',
#  'langsung',
#  'buka',
#  'promo',
#  'lapak',
#  'bukalapak',
#  'super',
#  'lot',
#  'nyaman',
#  'aplikasi',
#  'kasih',
#  'updatenya',
#  'coba',
#  'update',
#  'punyeng',
#  'deh',
#  'pokok',
#  'parah',
#  'banget',
#  'sih',
#  'kak',
#  'barang',
#  'nya',
#  'tanggal',
#  'estimasi',
#  'terima',
#  'status',
#  'kirim',
#  'cek',
#  'transit',
#  'nya',
#  'tangan',
#  'bayar',
#  'pakai',
#  'pay',
#  'later',
#  'kecewa',
#  'komplen',
#  'bajak',
#  'kartu',
#  'kredit',
#  'hubung',
#  'pusat',
#  'bantu',
#  'status',
#  'pending',
#  'uang',
#  'bukalapakeh',
#  'uang',
#  'suami',
#  'bajak',
#  'jutamasa',
#  'sih',
#  'blokir',
#  'akun',
#  'bajakhrsny',
#  'tahan',
#  'barang',
#  'pesanannyakan',
#  'uang',
#  'bukalapak',
#  'nya',
#  'uang',
#  'alam',
#  'apk',
#  'kalo',
#  'urus',
#  'selesai',
#  'langsung',
#  'auto',
#  'hapus',
#  'kecewa',
#  'kirim',
#  'ekspedisi',
#  'lambat',
#  'transit',
#  'toko',
#  'lambat',
#  'pick',
#  'up',
#  'barang',
#  'rekomen',
#  'belanja',
#  'bukalapak',
#  'mending',
#  'pakai',
#  'shopee',
#  'gua',
#  'kasih',
#  'bintang',
#  'ramadhan',
#  'aplikasi',
#  'susah',
#  'banget',
#  'jual',
#  'belanja',
#  'lot',
#  'banget',
#  'posting',
#  'belanja',
#  'cari',
#  'produk',
#  'update',
#  'lot',
#  'tolong',
#  'baik',
#  'ya',
#  'enak',
#  'auto',
#  'bintang',
#  'aplikasi',
#  'nya',
#  'lemotbukan',
#  'internet',
#  'lemotaplikasinya',
#  'lot',
#  'perbaikimasi',
#  'ringan',
#  'apk',
#  'orangemasa',
#  'buka',
#  'menu',
#  'utuma',
#  'lot',
#  'lot',
#  'nya',
#  'tolong',
#  'barang',
#  'terima',
#  'beli',
#  'tunggu',
#  'jam',
#  'kasih',
#  'terima',
#  'barang',
#  'kasih',
#  'penilain',
#  'jual',
#  'kasihan',
#  'jual',
#  'nya',
#  'tunggu',
#  'uang',
#  'nya',
#  'terima',
#  'kasih',
#  'developer',
#  'bukalapak',
#  'lihat',
#  'aplikasi',
#  'shopee',
#  'lazada',
#  'tiktok',
#  'ya',
#  'belanja',
#  'minimal',
#  'gratis',
#  'ongkir',
#  'bukalapak',
#  'maju',
#  'wajar',
#  'orang',
#  'belanja',
#  'toko',
#  'orentiktok',
#  'promo',
#  'ongkir',
#  'layak',
#  'sana',
#  'sih',
#  'ketimbang',
#  'bl',
#  'wkwk',
#  'pesan',
#  'barang',
#  'batalin',
#  'jual',
#  'batalin',
#  'jugasedangkan',
#  'limit',
#  'potong',
#  'fitur',
#  'live',
#  'chat',
#  'gunakanharus',
#  'mengadutolong',
#  'kasih',
#  'admin',
#  'aplikasi',
#  'buka',
#  'lapakbiar',
#  'adu',
#  'keluh',
#  'transaksi',
#  'gagal',
#  'daftar',
#  'paylater',
#  'enggak',
#  'bisa',
#  'chatlive',
#  'suruh',
#  'ngelunasin',
#  'pakai',
#  'hari',
#  'payah',
#  'belanja',
#  'praktis',
#  'pilih',
#  'efisien',
#  'hemat',
#  'duduk',
#  'manis',
#  'barang',
#  'rumah',
#  'low',
#  'cost',
#  'eh',
#  'ngirit',
#  'bagus',
#  'aplikasi',
#  'sayang',
#  'cs',
#  'nya',
#  'selesai',
#  'masalahsudah',
#  'kali',
#  'komplain',
#  'hasil',
#  'jalan',
#  'keluarketika',
#  'komplain',
#  'etik',
#  'komplain',
#  'putus',
#  'sambung',
#  'cs',
#  'nyakalo',
#  'menggu',
#  'cs',
#  'nya',
#  'cek',
#  'transaksi',
#  'tunggu',
#  ...]

# %%
fqdist = FreqDist(tokenize_ulasan)

# %%
fqdist
# Out:
# FreqDist({'bukalapak': 542, 'aplikasi': 482, 'nya': 434, 'barang': 392, 'pakai': 258, 'bayar': 250, 'buka': 241, 'belanja': 228, 'lapak': 224, 'beli': 220, ...})

# %%
# mencetak 15 kata paling banyak digunakan
fqdist.most_common(15)
# Out:
# [('bukalapak', 542),
#  ('aplikasi', 482),
#  ('nya', 434),
#  ('barang', 392),
#  ('pakai', 258),
#  ('bayar', 250),
#  ('buka', 241),
#  ('belanja', 228),
#  ('lapak', 224),
#  ('beli', 220),
#  ('kirim', 219),
#  ('jual', 182),
#  ('transaksi', 181),
#  ('bantu', 168),
#  ('bagus', 155)]

# %%
import matplotlib.pyplot as plt

# plotting
fqdist.plot(10,cumulative=False)
plt.show()

# %%
label = []
for index, row in name_dataframe.iterrows():
    if row["Rating"] == 5 or row["Rating"] == 4:
        label.append(1)
    else:
        label.append(0)

name_dataframe["label"] = label

name_dataframe
# Out:
#                          Nama pengguna  Rating                Date  \
# 0                         Nizar Rayyan       1 2023-04-16 23:03:31
# 1     dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 2                         Rika Riyanti       5 2023-04-11 13:30:31
# 3                        Afifur Rohman       1 2023-04-26 08:16:00
# 4                           Yuni Artha       1 2023-04-13 19:30:16
# ...                                ...     ...                 ...
# 1295                   Pengguna Google       1 2019-05-12 10:33:31
# 1296                     Rinto Martadi       1 2023-02-02 10:16:53
# 1297                    nursito gendut       5 2022-12-08 13:00:45
# 1298                       agus rianto       5 2023-04-14 02:13:14
# 1299                   Pengguna Google       5 2020-04-23 01:55:46
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     pastinya bukan hp dan wifi saya yang lemmooott...
# 2     sangat membantu sekali bukalapak tapi sudah sa...
# 3     sebenarnya aplikasi ini cukup bagus cuma ada b...
# 4     bukalapak semakin parah pesanan tgl   april di...
# ...                                                 ...
# 1295  satu dulu ya bintangnya nanti kalo sdh normal ...
# 1296  berhenti lah belanja di bukalapak makin banyak...
# 1297  saya sdh dari dulu pakai aplikasi buka lapak d...
# 1298                          sangat mudah bertransaksi
# 1299  bagus aplikasi menguntungkan hampir semua bara...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2     [sangat, membantu, sekali, bukalapak, tapi, su...
# 3     [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4     [bukalapak, semakin, parah, pesanan, tgl, apri...
# ...                                                 ...
# 1295  [satu, dulu, ya, bintangnya, nanti, kalo, sdh,...
# 1296  [berhenti, lah, belanja, di, bukalapak, makin,...
# 1297  [saya, sdh, dari, dulu, pakai, aplikasi, buka,...
# 1298                      [sangat, mudah, bertransaksi]
# 1299  [bagus, aplikasi, menguntungkan, hampir, semua...
#
#                                       Ulasan_normalized  \
# 0     [paylater, enggak, benar, selalu, di, batalkan...
# 1     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2     [sangat, membantu, sekali, bukalapak, tapi, su...
# 3     [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4     [bukalapak, semakin, parah, pesanan, tanggal, ...
# ...                                                 ...
# 1295  [satu, dulu, ya, bintangnya, nanti, kalo, suda...
# 1296  [berhenti, lah, belanja, di, bukalapak, makin,...
# 1297  [saya, sudah, dari, dulu, pakai, aplikasi, buk...
# 1298                      [sangat, mudah, bertransaksi]
# 1299  [bagus, aplikasi, menguntungkan, hampir, semua...
#
#                                     Ulasan_stop_removed  \
# 0     [paylater, batalkan, otomatis, kadang, nya, ga...
# 1     [pastinya, hp, wifi, lemmooottttt, dasarnya, b...
# 2     [membantu, bukalapak, pelanggan, paylater, pem...
# 3     [aplikasi, bagus, minusnya, ongkir, mahal, vou...
# 4     [bukalapak, parah, pesanan, tanggal, april, di...
# ...                                                 ...
# 1295  [ya, bintangnya, kalo, normal, app, blnya, dit...
# 1296  [berhenti, belanja, bukalapak, pelapak, amanah...
# 1297  [pakai, aplikasi, buka, lapak, puas, layananny...
# 1298                              [mudah, bertransaksi]
# 1299  [bagus, aplikasi, menguntungkan, barang, buka,...
#
#                                          Ulasan_Stemmed  \
# 0     [paylater, batal, otomatis, kadang, nya, ganti...
# 1     [pasti, hp, wifi, lemmooottttt, dasar, bukalap...
# 2     [bantu, bukalapak, langgan, paylater, bayar, l...
# 3     [aplikasi, bagus, minus, ongkir, mahal, vouche...
# 4     [bukalapak, parah, pesan, tanggal, april, kiri...
# ...                                                 ...
# 1295  [ya, bintang, kalo, normal, app, blnya, tambah...
# 1296  [henti, belanja, bukalapak, lapak, amanah, ref...
# 1297  [pakai, aplikasi, buka, lapak, puas, layan, ti...
# 1298                                 [mudah, transaksi]
# 1299  [bagus, aplikasi, untung, barang, buka, lapak,...
#
#                                            Ulasan_clean  label
# 0     paylater batal otomatis kadang nya ganti jatuh...      0
# 1     pasti hp wifi lemmooottttt dasar bukalapak kar...      0
# 2     bantu bukalapak langgan paylater bayar limit t...      1
# 3     aplikasi bagus minus ongkir mahal voucher paka...      0
# 4     bukalapak parah pesan tanggal april kirim lapa...      0
# ...                                                 ...    ...
# 1295  ya bintang kalo normal app blnya tambah bintan...      0
# 1296  henti belanja bukalapak lapak amanah refund as...      0
# 1297  pakai aplikasi buka lapak puas layan tingkat b...      1
# 1298                                    mudah transaksi      1
# 1299  bagus aplikasi untung barang buka lapak nya to...      1
#
# [1300 rows x 10 columns]

# %%
#create a user define function to find out polarity & subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

#creating another user define function to label the sentiment 

def getSentiment(value):
    if value<0:
        return 'Negative'
    elif value==0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
name_dataframe.head()
# Out:
#                       Nama pengguna  Rating                Date  \
# 0                      Nizar Rayyan       1 2023-04-16 23:03:31
# 1  dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 2                      Rika Riyanti       5 2023-04-11 13:30:31
# 3                     Afifur Rohman       1 2023-04-26 08:16:00
# 4                        Yuni Artha       1 2023-04-13 19:30:16
#
#                                               Ulasan  \
# 0  paylater ngk bener selalu di batalkan otomatis...
# 1  pastinya bukan hp dan wifi saya yang lemmooott...
# 2  sangat membantu sekali bukalapak tapi sudah sa...
# 3  sebenarnya aplikasi ini cukup bagus cuma ada b...
# 4  bukalapak semakin parah pesanan tgl   april di...
#
#                                      Ulasan_tokenize  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2  [sangat, membantu, sekali, bukalapak, tapi, su...
# 3  [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4  [bukalapak, semakin, parah, pesanan, tgl, apri...
#
#                                    Ulasan_normalized  \
# 0  [paylater, enggak, benar, selalu, di, batalkan...
# 1  [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2  [sangat, membantu, sekali, bukalapak, tapi, su...
# 3  [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4  [bukalapak, semakin, parah, pesanan, tanggal, ...
#
#                                  Ulasan_stop_removed  \
# 0  [paylater, batalkan, otomatis, kadang, nya, ga...
# 1  [pastinya, hp, wifi, lemmooottttt, dasarnya, b...
# 2  [membantu, bukalapak, pelanggan, paylater, pem...
# 3  [aplikasi, bagus, minusnya, ongkir, mahal, vou...
# 4  [bukalapak, parah, pesanan, tanggal, april, di...
#
#                                       Ulasan_Stemmed  \
# 0  [paylater, batal, otomatis, kadang, nya, ganti...
# 1  [pasti, hp, wifi, lemmooottttt, dasar, bukalap...
# 2  [bantu, bukalapak, langgan, paylater, bayar, l...
# 3  [aplikasi, bagus, minus, ongkir, mahal, vouche...
# 4  [bukalapak, parah, pesan, tanggal, april, kiri...
#
#                                         Ulasan_clean  label
# 0  paylater batal otomatis kadang nya ganti jatuh...      0
# 1  pasti hp wifi lemmooottttt dasar bukalapak kar...      0
# 2  bantu bukalapak langgan paylater bayar limit t...      1
# 3  aplikasi bagus minus ongkir mahal voucher paka...      0
# 4  bukalapak parah pesan tanggal april kirim lapa...      0

# %%
from textblob import TextBlob

# %%
def run_vader(name_dataframe):
    # Generate VADER sentiment analyzer object
    sid = SentimentIntensityAnalyzer()

# %%
name_dataframe['Polarity']=name_dataframe['Ulasan_clean'].apply(getPolarity)
name_dataframe['Subjectivity']=name_dataframe['Ulasan_clean'].apply(getSubjectivity)
name_dataframe['Sentiment']=name_dataframe['Polarity'].apply(getSentiment)
name_dataframe.head()
# Out:
#                       Nama pengguna  Rating                Date  \
# 0                      Nizar Rayyan       1 2023-04-16 23:03:31
# 1  dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 2                      Rika Riyanti       5 2023-04-11 13:30:31
# 3                     Afifur Rohman       1 2023-04-26 08:16:00
# 4                        Yuni Artha       1 2023-04-13 19:30:16
#
#                                               Ulasan  \
# 0  paylater ngk bener selalu di batalkan otomatis...
# 1  pastinya bukan hp dan wifi saya yang lemmooott...
# 2  sangat membantu sekali bukalapak tapi sudah sa...
# 3  sebenarnya aplikasi ini cukup bagus cuma ada b...
# 4  bukalapak semakin parah pesanan tgl   april di...
#
#                                      Ulasan_tokenize  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2  [sangat, membantu, sekali, bukalapak, tapi, su...
# 3  [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4  [bukalapak, semakin, parah, pesanan, tgl, apri...
#
#                                    Ulasan_normalized  \
# 0  [paylater, enggak, benar, selalu, di, batalkan...
# 1  [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2  [sangat, membantu, sekali, bukalapak, tapi, su...
# 3  [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4  [bukalapak, semakin, parah, pesanan, tanggal, ...
#
#                                  Ulasan_stop_removed  \
# 0  [paylater, batalkan, otomatis, kadang, nya, ga...
# 1  [pastinya, hp, wifi, lemmooottttt, dasarnya, b...
# 2  [membantu, bukalapak, pelanggan, paylater, pem...
# 3  [aplikasi, bagus, minusnya, ongkir, mahal, vou...
# 4  [bukalapak, parah, pesanan, tanggal, april, di...
#
#                                       Ulasan_Stemmed  \
# 0  [paylater, batal, otomatis, kadang, nya, ganti...
# 1  [pasti, hp, wifi, lemmooottttt, dasar, bukalap...
# 2  [bantu, bukalapak, langgan, paylater, bayar, l...
# 3  [aplikasi, bagus, minus, ongkir, mahal, vouche...
# 4  [bukalapak, parah, pesan, tanggal, april, kiri...
#
#                                         Ulasan_clean  label  Polarity  \
# 0  paylater batal otomatis kadang nya ganti jatuh...      0  0.000000
# 1  pasti hp wifi lemmooottttt dasar bukalapak kar...      0  0.166667
# 2  bantu bukalapak langgan paylater bayar limit t...      1  0.000000
# 3  aplikasi bagus minus ongkir mahal voucher paka...      0 -0.100000
# 4  bukalapak parah pesan tanggal april kirim lapa...      0  0.000000
#
#    Subjectivity Sentiment
# 0      0.000000   Neutral
# 1      0.333333  Positive
# 2      0.000000   Neutral
# 3      0.100000  Negative
# 4      0.000000   Neutral

# %%
name_dataframe['month'] = name_dataframe['Date'].dt.month

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group by month and sentiment
sentiment_df = name_dataframe.groupby(['month', 'Sentiment']).size().reset_index(name='Count')


# Plot the sentiment counts by month
plt.figure(figsize=(12, 6))
sns.lineplot(x='month', y='Count', hue='Sentiment', data=sentiment_df)
plt.title('Sentiment by Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %%
name_dataframe
# Out:
#                          Nama pengguna  Rating                Date  \
# 0                         Nizar Rayyan       1 2023-04-16 23:03:31
# 1     dedy kelana (CV PRIBUMI BANGKIT)       1 2023-03-25 10:26:56
# 2                         Rika Riyanti       5 2023-04-11 13:30:31
# 3                        Afifur Rohman       1 2023-04-26 08:16:00
# 4                           Yuni Artha       1 2023-04-13 19:30:16
# ...                                ...     ...                 ...
# 1295                   Pengguna Google       1 2019-05-12 10:33:31
# 1296                     Rinto Martadi       1 2023-02-02 10:16:53
# 1297                    nursito gendut       5 2022-12-08 13:00:45
# 1298                       agus rianto       5 2023-04-14 02:13:14
# 1299                   Pengguna Google       5 2020-04-23 01:55:46
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     pastinya bukan hp dan wifi saya yang lemmooott...
# 2     sangat membantu sekali bukalapak tapi sudah sa...
# 3     sebenarnya aplikasi ini cukup bagus cuma ada b...
# 4     bukalapak semakin parah pesanan tgl   april di...
# ...                                                 ...
# 1295  satu dulu ya bintangnya nanti kalo sdh normal ...
# 1296  berhenti lah belanja di bukalapak makin banyak...
# 1297  saya sdh dari dulu pakai aplikasi buka lapak d...
# 1298                          sangat mudah bertransaksi
# 1299  bagus aplikasi menguntungkan hampir semua bara...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2     [sangat, membantu, sekali, bukalapak, tapi, su...
# 3     [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4     [bukalapak, semakin, parah, pesanan, tgl, apri...
# ...                                                 ...
# 1295  [satu, dulu, ya, bintangnya, nanti, kalo, sdh,...
# 1296  [berhenti, lah, belanja, di, bukalapak, makin,...
# 1297  [saya, sdh, dari, dulu, pakai, aplikasi, buka,...
# 1298                      [sangat, mudah, bertransaksi]
# 1299  [bagus, aplikasi, menguntungkan, hampir, semua...
#
#                                       Ulasan_normalized  \
# 0     [paylater, enggak, benar, selalu, di, batalkan...
# 1     [pastinya, bukan, hp, dan, wifi, saya, yang, l...
# 2     [sangat, membantu, sekali, bukalapak, tapi, su...
# 3     [sebenarnya, aplikasi, ini, cukup, bagus, cuma...
# 4     [bukalapak, semakin, parah, pesanan, tanggal, ...
# ...                                                 ...
# 1295  [satu, dulu, ya, bintangnya, nanti, kalo, suda...
# 1296  [berhenti, lah, belanja, di, bukalapak, makin,...
# 1297  [saya, sudah, dari, dulu, pakai, aplikasi, buk...
# 1298                      [sangat, mudah, bertransaksi]
# 1299  [bagus, aplikasi, menguntungkan, hampir, semua...
#
#                                     Ulasan_stop_removed  \
# 0     [paylater, batalkan, otomatis, kadang, nya, ga...
# 1     [pastinya, hp, wifi, lemmooottttt, dasarnya, b...
# 2     [membantu, bukalapak, pelanggan, paylater, pem...
# 3     [aplikasi, bagus, minusnya, ongkir, mahal, vou...
# 4     [bukalapak, parah, pesanan, tanggal, april, di...
# ...                                                 ...
# 1295  [ya, bintangnya, kalo, normal, app, blnya, dit...
# 1296  [berhenti, belanja, bukalapak, pelapak, amanah...
# 1297  [pakai, aplikasi, buka, lapak, puas, layananny...
# 1298                              [mudah, bertransaksi]
# 1299  [bagus, aplikasi, menguntungkan, barang, buka,...
#
#                                          Ulasan_Stemmed  \
# 0     [paylater, batal, otomatis, kadang, nya, ganti...
# 1     [pasti, hp, wifi, lemmooottttt, dasar, bukalap...
# 2     [bantu, bukalapak, langgan, paylater, bayar, l...
# 3     [aplikasi, bagus, minus, ongkir, mahal, vouche...
# 4     [bukalapak, parah, pesan, tanggal, april, kiri...
# ...                                                 ...
# 1295  [ya, bintang, kalo, normal, app, blnya, tambah...
# 1296  [henti, belanja, bukalapak, lapak, amanah, ref...
# 1297  [pakai, aplikasi, buka, lapak, puas, layan, ti...
# 1298                                 [mudah, transaksi]
# 1299  [bagus, aplikasi, untung, barang, buka, lapak,...
#
#                                            Ulasan_clean  label  Polarity  \
# 0     paylater batal otomatis kadang nya ganti jatuh...      0  0.000000
# 1     pasti hp wifi lemmooottttt dasar bukalapak kar...      0  0.166667
# 2     bantu bukalapak langgan paylater bayar limit t...      1  0.000000
# 3     aplikasi bagus minus ongkir mahal voucher paka...      0 -0.100000
# 4     bukalapak parah pesan tanggal april kirim lapa...      0  0.000000
# ...                                                 ...    ...       ...
# 1295  ya bintang kalo normal app blnya tambah bintan...      0  0.150000
# 1296  henti belanja bukalapak lapak amanah refund as...      0  0.000000
# 1297  pakai aplikasi buka lapak puas layan tingkat b...      1  0.000000
# 1298                                    mudah transaksi      1  0.000000
# 1299  bagus aplikasi untung barang buka lapak nya to...      1  0.000000
#
#       Subjectivity Sentiment
# 0         0.000000   Neutral
# 1         0.333333  Positive
# 2         0.000000   Neutral
# 3         0.100000  Negative
# 4         0.000000   Neutral
# ...            ...       ...
# 1295      0.650000  Positive
# 1296      0.000000   Neutral
# 1297      0.000000   Neutral
# 1298      0.000000   Neutral
# 1299      0.000000   Neutral
#
# [1300 rows x 13 columns]

# %%
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
name_dataframe.head()

# %%
train_pos = name_dataframe[ name_dataframe['Sentiment'] == 'Positive']
train_pos = train_pos['Ulasan_clean']
train_neg = name_dataframe[ name_dataframe['Sentiment'] == 'Negative']
train_neg = train_neg['Ulasan_clean']
train_net = name_dataframe[ name_dataframe['Sentiment'] == 'Neutral']
train_net = train_net['Ulasan_clean']

def wordcloud_draw(data, color = '#FAFAD2'):
    words = ' '.join(data)
    cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and not word.startswith('nya')
                                and word != 'RT'
                            ])
    wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color=color,
                      width=2500,
                      height=2000
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    
print("Positive words")
wordcloud_draw(train_pos,'white')
print("Negative words")
wordcloud_draw(train_neg)
print("Neutral words")
wordcloud_draw(train_net,'#ccd5ae')
# Out:
# Positive words
# Negative words
# Neutral words

# %%
sentimen_data=pd.value_counts(name_dataframe["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["green", "red", "black"])
plt.title('Bar chart')
plt.show()

# %%
name_dataframe["Sentiment"].value_counts()
# Out:
# Neutral     1049
# Positive     202
# Negative      49
# Name: Sentiment, dtype: int64

# %%
name_dataframe["Sentiment"].value_counts()
# Out:
# Neutral     1049
# Positive     202
# Negative      49
# Name: Sentiment, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
Ulasan = name_dataframe['Ulasan_clean']

# %%
Ulasan.isnull().sum()
# Out:
# 0

# %%
#untuk menghitung jumlah kata yang telah di steming
cv = CountVectorizer()
term_fit = cv.fit(Ulasan)

print (len(term_fit.vocabulary_))
# Out:
# 3671

# %%
term_fit.vocabulary_ #mengurutkan berdasarkan urutab abjad kata
# Out:
# {'paylater': 2463,
#  'batal': 320,
#  'otomatis': 2392,
#  'kadang': 1455,
#  'nya': 2301,
#  'ganti': 1144,
#  'jatuh': 1395,
#  'tempo': 3300,
#  'bayar': 332,
#  'biaya': 451,
#  'lambat': 1780,
#  'layan': 1821,
#  'biar': 449,
#  'rasa': 2726,
#  'sistem': 3106,
#  'enak': 1036,
#  'chat': 717,
#  'susah': 3210,
#  'error': 1052,
#  'salah': 2863,
#  'bikin': 457,
#  'pusing': 2704,
#  'pasti': 2454,
#  'hp': 1281,
#  'wifi': 3629,
#  'lemmooottttt': 1838,
#  'dasar': 823,
#  'bukalapak': 570,
#  'karuan': 1488,
#  'lihat': 1874,
#  'status': 3172,
#  'transsaksi': 3446,
#  'tunggu': 3485,
#  'halaman': 1222,
#  'isi': 1359,
#  'penuh': 2546,
#  'muncul': 2168,
#  'tawar': 3274,
#  'tanda': 3244,
#  'sulit': 3199,
#  'baca': 224,
#  'pencet': 2526,
#  'bulalapak': 625,
#  'main': 1943,
#  'paket': 2427,
#  'data': 825,
#  'orang': 2381,
#  'konten': 1669,
#  'webnya': 3623,
#  'lumayan': 1923,
#  'hasil': 1246,
#  'moga': 2144,
#  'curiga': 787,
#  'maaf': 1932,
#  'bantu': 286,
#  'langgan': 1792,
#  'limit': 1876,
#  'tambah': 3240,
#  'profesional': 2663,
#  'maju': 1944,
#  'aplikasi': 178,
#  'bagus': 234,
#  'minus': 2121,
#  'ongkir': 2358,
#  'mahal': 1940,
#  'voucher': 3586,
#  'pakai': 2420,
#  'syarat': 3218,
#  'pilih': 2592,
#  'jasa': 1394,
#  'ekspedisi': 1019,
#  'parah': 2439,
#  'pesan': 2577,
#  'tanggal': 3251,
#  'april': 194,
#  'kirim': 1609,
#  'lapak': 1800,
#  'barang': 298,
#  'simpan': 3090,
#  'gudang': 1196,
#  'bukaexpress': 565,
#  'buka': 559,
#  'menu': 2080,
#  'livechat': 1890,
#  'fungsi': 1118,
#  'beda': 344,
#  'merchant': 2088,
#  'kecewa': 1514,
#  'jual': 1428,
#  'emas': 1033,
#  'bukaemas': 563,
#  'banget': 274,
#  'problem': 2658,
#  'verifikasi': 3567,
#  'no': 2271,
#  'bad': 228,
#  'gateway': 1153,
#  'kode': 1627,
#  'enggak': 1043,
#  'bisa': 466,
#  'ulang': 3508,
#  'kayak': 1502,
#  'sengaja': 2997,
#  'tarik': 3268,
#  'investasi': 1354,
#  'app': 189,
#  'berat': 394,
#  'fitur': 1102,
#  'banyak': 293,
#  'rusak': 2848,
#  'tolong': 3418,
#  'simpel': 3094,
#  'solusi': 3142,
#  'bukabantuan': 560,
#  'live': 1888,
#  'jam': 1381,
#  'cs': 773,
#  'mati': 2020,
#  'obrol': 2334,
#  'aktifin': 69,
#  'akun': 78,
#  'hangus': 1233,
#  'kyc': 1724,
#  'sory': 3150,
#  'ane': 132,
#  'uninstall': 3518,
#  'join': 1422,
#  'seller': 2972,
#  'deh': 841,
#  'bl': 490,
#  'kepercayan': 1567,
#  'ecom': 1006,
#  'utama': 3554,
#  'transaksi': 3436,
#  'aktifasi': 67,
#  'gampang': 1137,
#  'komplin': 1649,
#  'sumpah': 3201,
#  'enek': 1042,
#  'masak': 1998,
#  'otp': 2395,
#  'nomer': 2275,
#  'aktif': 66,
#  'email': 1028,
#  'sefty': 2941,
#  'lo': 1892,
#  'nyataanya': 2323,
#  'nomor': 2277,
#  'aktivasi': 74,
#  'ya': 3649,
#  'ampun': 119,
#  'aju': 54,
#  'pinjam': 2599,
#  'bank': 283,
#  'sumpaah': 3200,
#  'oohh': 2373,
#  'devlover': 868,
#  'lebay': 1834,
#  'pengin': 2530,
#  'masuk': 2012,
#  'foto': 1112,
#  'ktprekening': 1701,
#  'daftar': 799,
#  'ktp': 1699,
#  'rekening': 2764,
#  'seribet': 3015,
#  'kah': 1459,
#  'cantumin': 663,
#  'terang': 3313,
#  'ubah': 3499,
#  'terima': 3322,
#  'tipenyasaya': 3388,
#  'komplain': 1645,
#  'admin': 31,
#  'selesai': 2964,
#  'rugi': 2840,
#  'hilang': 1268,
#  'uang': 3497,
#  'iklan': 1300,
#  'loadingnya': 1896,
#  'ngechek': 2228,
#  'loading': 1894,
#  'mohon': 2145,
#  'nyaman': 2313,
#  'kuota': 1709,
#  'internetdi': 1351,
#  'nglungker': 2247,
#  'jenuhtlg': 1413,
#  'perhati': 2560,
#  'jelek': 1407,
#  'lot': 1912,
#  'adu': 34,
#  'langsung': 1796,
#  'tele': 3288,
#  'kesana': 1582,
#  'kemari': 1542,
#  'coba': 735,
#  'kasih': 1492,
#  'tinggal': 3383,
#  'klik': 1617,
#  'cari': 670,
#  'cuman': 782,
#  'dikit': 910,
#  'kalah': 1465,
#  'bukalapakygdulu': 607,
#  'ribu': 2813,
#  'upload': 3541,
#  'cumq': 783,
#  'tampil': 3242,
#  'kalo': 1471,
#  'temu': 3301,
#  'gaya': 1155,
#  'beli': 371,
#  'sepi': 3006,
#  'unjung': 3520,
#  'kesini': 1587,
#  'ajabanyak': 48,
#  'sisrem': 3105,
#  'gunabuka': 1200,
#  'apk': 167,
#  'kaya': 1501,
#  'game': 1135,
#  'ajaisi': 50,
#  'harap': 1240,
#  'buang': 552,
#  'ajadan': 49,
#  'bagusmasuk': 244,
#  'ribetnya': 2810,
#  'aneh': 133,
#  'didownload': 890,
#  'touch': 3426,
#  'hapus': 1237,
#  'az': 223,
#  'repot': 2781,
#  'proses': 2677,
#  'kadaluarsamau': 1453,
#  'komplen': 1648,
#  'ambil': 112,
#  'kapok': 1482,
#  'belanja': 362,
#  'cod': 737,
#  'uninstal': 3517,
#  'beban': 340,
#  'and': 128,
#  'sampah': 2881,
#  'smartphone': 3125,
#  'gue': 1197,
#  'piara': 2587,
#  'manfaat': 1966,
#  'kendala': 1556,
#  'canggih': 661,
#  'sadah': 2854,
#  'kembaliini': 1547,
#  'kepastianpayah': 1565,
#  'sesal': 3028,
#  'dibukalapak': 883,
#  'mitra': 2125,
#  'dalem': 806,
#  'tipu': 3391,
#  'refund': 2755,
#  'detik': 864,
#  'erti': 1056,
#  'biyaya': 487,
#  'tangan': 3248,
#  'maksud': 1951,
#  'sesak': 3027,
#  'sgitu': 3042,
#  'ilangin': 1305,
#  'tuhklo': 3477,
#  'kurang': 1713,
#  'kepakasa': 1562,
#  'blanja': 492,
#  'saking': 2862,
#  'mudah': 2154,
#  'berbelanjatapi': 397,
#  'dam': 807,
#  'halapalagi': 1224,
#  'tanggap': 3252,
#  'buset': 635,
#  'pajang': 2418,
#  'hebat': 1253,
#  'lenya': 1856,
#  'dikerjain': 906,
#  'baik': 256,
#  'sistemnyakecewa': 3110,
#  'telat': 3284,
#  'kurir': 1716,
#  'report': 2780,
#  'bermasalahpaket': 427,
#  'jadwal': 1374,
#  'kompensasi': 1639,
#  'jamin': 1383,
#  'kembalihanya': 1546,
#  'slogan': 3122,
#  'belakabagaimana': 360,
#  'min': 2104,
#  'respon': 2792,
#  'payah': 2459,
#  'ah': 40,
#  'saldo': 2865,
#  'habis': 1206,
#  'untung': 3528,
#  'ngisi': 2242,
#  'cash': 675,
#  'back': 225,
#  'lom': 1910,
#  'tau': 3272,
#  'telepon': 3290,
#  'muas': 2152,
#  'jawabannyacoba': 1397,
#  'tanggepin': 3256,
#  'tlong': 3399,
#  'jawab': 1396,
#  'tentu': 3309,
#  'jgbuat': 1415,
#  'bantumakin': 292,
#  'hubungin': 1287,
#  'chatlemot': 719,
#  'turun': 3489,
#  'lag': 1730,
#  'bintang': 462,
#  'saran': 2893,
#  'expedisi': 1072,
#  'reg': 2756,
#  'next': 2210,
#  'day': 831,
#  'sicepat': 3073,
#  'pick': 2588,
#  'up': 3530,
#  'lelet': 1836,
#  'criss': 769,
#  'cross': 771,
#  'sesuai': 3031,
#  'sop': 3144,
#  'resi': 2787,
#  'update': 3531,
#  'ybs': 3656,
#  'percaya': 2557,
#  'konsumen': 1665,
#  'depan': 852,
#  'kecewadimana': 1515,
#  'sedia': 2937,
#  'codtapi': 741,
#  'express': 1074,
#  'payleater': 2472,
#  'bukalapaksaya': 595,
#  'tagih': 3227,
#  'lagibukti': 1736,
#  'struknya': 3185,
#  'kasir': 1496,
#  'indomart': 1320,
#  'yeah': 3657,
#  'tagihantapi': 3229,
#  'bingung': 460,
#  'januari': 1389,
#  'jugasudah': 1437,
#  'bukalapaksungguh': 600,
#  'buruk': 634,
#  'gratis': 1190,
#  'tulis': 3481,
#  'andal': 129,
#  'online': 2368,
#  'way': 3621,
#  'mending': 2061,
#  'pusat': 2701,
#  'pulsa': 2695,
#  'tuju': 3478,
#  'potong': 2637,
#  'account': 10,
#  'dana': 809,
#  'masalah': 2001,
#  'berani': 392,
#  'kontak': 1667,
#  'rumit': 2843,
#  'danabukalapak': 810,
#  'trimakasih': 3453,
#  'inovatif': 1336,
#  'ecommerce': 1008,
#  'cocok': 736,
#  'bisnis': 486,
#  'simple': 3095,
#  'ringan': 2820,
#  'all': 100,
#  'one': 2357,
#  'feature': 1086,
#  'rekomendasi': 2770,
#  'toko': 3408,
#  'belah': 359,
#  'promo': 2670,
#  'super': 3205,
#  'updatenya': 3534,
#  'punyeng': 2700,
#  'pokok': 2624,
#  'sih': 3078,
#  'kak': 1461,
#  'estimasi': 1058,
#  'cek': 683,
#  'transit': 3443,
#  'pay': 2457,
#  'later': 1812,
#  'bajak': 259,
#  'kartu': 1487,
#  'kredit': 1688,
#  'hubung': 1285,
#  'pending': 2527,
#  'bukalapakeh': 580,
#  'suami': 3188,
#  'jutamasa': 1442,
#  'blokir': 504,
#  'bajakhrsny': 261,
#  'tahan': 3230,
#  'pesanannyakan': 2582,
#  'alam': 82,
#  'urus': 3546,
#  'auto': 216,
#  'rekomen': 2768,
#  'shopee': 3053,
#  'gua': 1193,
#  'ramadhan': 2717,
#  'posting': 2634,
#  'produk': 2660,
#  'lemotbukan': 1844,
#  'internet': 1350,
#  'lemotaplikasinya': 1842,
#  'perbaikimasi': 2553,
#  'orangemasa': 2383,
#  'utuma': 3557,
#  'penilain': 2538,
#  'kasihan': 1493,
#  'developer': 866,
#  'lazada': 1827,
#  'tiktok': 3374,
#  'minimal': 2110,
#  'wajar': 3601,
#  'orentiktok': 2388,
#  'layak': 1820,
#  'sana': 2887,
#  'ketimbang': 1595,
#  'wkwk': 3634,
#  'batalin': 321,
#  'jugasedangkan': 1436,
#  'gunakanharus': 1202,
#  'mengadutolong': 2063,
#  'lapakbiar': 1802,
#  'keluh': 1539,
#  'gagal': 1126,
#  'chatlive': 720,
#  'suruh': 3209,
#  'ngelunasin': 2234,
#  'hari': 1242,
#  'praktis': 2643,
#  'efisien': 1013,
#  'hemat': 1258,
#  'duduk': 987,
#  'manis': 1969,
#  'rumah': 2842,
#  'low': 1914,
#  'cost': 761,
#  'eh': 1015,
#  'ngirit': 2241,
#  'sayang': 2907,
#  'masalahsudah': 2007,
#  'kali': 1468,
#  'jalan': 1380,
#  'keluarketika': 1537,
#  'etik': 1062,
#  'putus': 2708,
#  'sambung': 2877,
#  'nyakalo': 2309,
#  'menggu': 2071,
#  'gilir': 1170,
#  'yohana': 3659,
#  'nama': 2189,
#  'sabar': 2852,
#  'nunggusaaya': 2298,
#  'ngetiikkkk': 2238,
#  'amanah': 108,
#  'bukamall': 610,
#  'complainnya': 751,
#  'guna': 1199,
#  'complain': 748,
#  'digunain': 897,
#  'metode': 2099,
#  'gonta': 1180,
#  'cukup': 781,
#  'milik': 2102,
#  'hadehh': 1210,
#  'paylaternya': 2465,
#  'beku': 353,
#  'basah': 317,
#  'basih': 319,
#  'custumer': 794,
#  'customer': 791,
#  'servicenya': 3025,
#  'tengkyuu': 3308,
#  'tabung': 3225,
#  'ktpreffvral': 1700,
#  'btbldkzqvt': 548,
#  'nyaaplikasii': 2304,
#  'suka': 3193,
#  'lamasangat': 1777,
#  'kala': 1464,
#  'belanjatinggal': 367,
#  'bayarbarang': 333,
#  'membaiktengkyuuu': 2042,
#  'koreksi': 1676,
#  'wilyah': 3632,
#  'timur': 3379,
#  'indonesia': 1321,
#  'harga': 1241,
#  'contoh': 757,
#  'ongkos': 2366,
#  'capai': 665,
#  'fer': 1090,
#  'jadi': 1370,
#  'pantesan': 2437,
#  'jadul': 1372,
#  'costumer': 762,
#  'fiturnya': 1103,
#  'banyaktidak': 296,
#  'bukabantuannya': 561,
#  'ninja': 2267,
#  'expres': 1073,
#  'puluh': 2697,
#  'lacak': 1727,
#  'sukur': 3198,
#  'tibatiba': 3366,
#  'tangguh': 3258,
#  'konfirmasi': 1659,
#  'login': 1898,
#  'sunguh': 3204,
#  'hindar': 1270,
#  'alami': 84,
#  'kemarin': 1543,
#  'diskusi': 945,
#  'kembali': 1544,
#  'transfer': 3440,
#  'traktir': 3433,
#  'debit': 839,
#  'knyatanya': 1624,
#  'bulan': 626,
#  'hoax': 1278,
#  'selau': 2960,
#  'sesi': 3030,
#  'info': 1323,
#  'payleter': 2473,
#  'ijo': 1297,
#  'oran': 2380,
#  'pemberitahuan': 2516,
#  'paylter': 2476,
#  'jebak': 1403,
#  'betmen': 441,
#  'ku': 1702,
#  'jaring': 1393,
#  'stabil': 3165,
#  'bangettolong': 277,
#  'mantulll': 1983,
#  'kondisi': 1657,
#  'ready': 2737,
#  'very': 3573,
#  'gus': 1204,
#  'riwayat': 2827,
#  'pagi': 2413,
#  'posisi': 2632,
#  'alamat': 83,
#  'an': 124,
#  'bukalapaknya': 589,
#  'harus': 1245,
#  'asih': 203,
#  'php': 2586,
#  'sempat': 2989,
#  'ribet': 2808,
#  'nonaktif': 2281,
#  'aman': 106,
#  'drastis': 982,
#  'cair': 653,
#  'butuh': 639,
#  'perlu': 2564,
#  'desak': 857,
#  'tetangga': 3352,
#  'inikasih': 1332,
#  'bgtkasihan': 444,
#  'dongharusnya': 970,
#  'max': 2024,
#  'haribukanya': 1243,
#  'pembelimenurut': 2512,
#  'bukalapakklo': 582,
#  'pesananmereka': 2581,
#  'sendiridan': 2996,
#  'kirimkanentah': 1610,
#  'lupaatau': 1929,
#  'readymohon': 2738,
#  'lagibuat': 1734,
#  'rumitpadahal': 2845,
#  'refaund': 2749,
#  'prosespadahal': 2678,
#  'alas': 87,
#  'via': 3574,
#  'artikel': 200,
#  'review': 2802,
#  'dok': 965,
#  'prosez': 2681,
#  'lampir': 1784,
#  'buku': 622,
#  'rek': 2761,
#  'mutasi': 2179,
#  'nampaklah': 2192,
#  'nota': 2287,
#  'bene': 380,
#  'informasi': 1324,
#  'krusial': 1695,
#  'atur': 214,
#  'profile': 2666,
#  'dmpak': 959,
#  'securitynya': 2935,
#  'setia': 3038,
#  'bltp': 510,
#  'perlahan': 2563,
#  'alih': 98,
#  'lainselain': 1757,
#  'rendah': 2778,
#  'kolom': 1632,
#  'beragamdi': 390,
#  'tawarkn': 3275,
#  'ketikcari': 1594,
#  'bilang': 458,
#  'tua': 3474,
#  'inovasi': 1335,
#  'ikan': 1299,
#  'hias': 1263,
#  'pakan': 2423,
#  'ganggu': 1143,
#  'sistemnyasya': 3111,
#  'sellerkenapa': 2974,
#  'pencariandi': 2524,
#  'tracking': 3428,
#  'validbanyak': 3560,
#  'pembelitapi': 2515,
#  'trackingnya': 3429,
#  'cepat': 696,
#  'marketpkace': 1991,
#  'aco': 13,
#  'pelit': 2500,
#  'set': 3034,
#  'chip': 727,
#  'snapdragon': 3134,
#  'gen': 1163,
#  'ram': 2716,
#  'gb': 1156,
#  'clear': 733,
#  'chace': 713,
#  'logout': 1901,
#  'baru': 312,
#  'server': 3022,
#  'telp': 3295,
#  'custemservis': 789,
#  'ngurusinya': 2253,
#  'itu': 1365,
#  'codpembayaran': 740,
#  'tunai': 3482,
#  'diskon': 943,
#  'tingkat': 3384,
#  'vouchernya': 3588,
#  'kargo': 1485,
#  'laman': 1776,
#  'tks': 3397,
#  'jembutsaya': 1408,
#  'dagang': 801,
#  'push': 2702,
#  'dlliklan': 956,
#  'bas': 316,
#  'rating': 2728,
#  'boroboro': 528,
#  'munculbangsaaatt': 2169,
#  'satusatunya': 2904,
#  'akses': 63,
#  'berfungsihatihati': 406,
#  'xufsinv': 3648,
#  'lebih': 1835,
#  'batas': 324,
#  'maksimal': 1950,
#  'dbatalkan': 834,
#  'jelasjelas': 1406,
#  'tera': 3311,
#  'bukatabungan': 620,
#  'mada': 1936,
#  'teman': 3298,
#  'undang': 3513,
#  'permasalahn': 2566,
#  'bual': 551,
#  'adakan': 23,
#  'request': 2782,
#  'pickup': 2589,
#  'awam': 220,
#  'edit': 1009,
#  'varian': 3562,
#  'tipe': 3387,
#  'nginput': 2239,
#  'apa': 159,
#  'disamainnnnn': 934,
#  'feedback': 1089,
#  'balas': 267,
#  'dm': 958,
#  'ig': 1295,
#  'gubris': 1195,
#  'sptnya': 3161,
#  'halooooo': 1226,
#  'biji': 455,
#  'order': 2385,
#  'marketplace': 1993,
#  'free': 1113,
#  'pajak': 2417,
#  'gede': 1160,
#  'royal': 2835,
#  'emosi': 1035,
#  'install': 1340,
#  'berulangulang': 434,
#  'wadew': 3600,
#  'blank': 494,
#  'tandatanda': 3245,
#  'berjamjam': 415,
#  'sore': 3148,
#  'normal': 2286,
#  'mana': 1962,
#  'kena': 1552,
#  'warning': 3613,
#  'nih': 2257,
#  'emak': 1030,
#  'lato': 1815,
#  'swafoto': 3216,
#  'kanan': 1474,
#  'kiri': 1608,
#  'pegang': 2486,
#  'bantuin': 290,
#  'nilai': 2264,
#  'mundur': 2171,
#  'ratingnya': 2729,
#  'angsur': 141,
#  'sajadan': 2859,
#  'aktifharus': 68,
#  'belanjabrg': 363,
#  'list': 1885,
#  'item': 1362,
#  'beranda': 391,
#  'capek': 666,
#  'halah': 1221,
#  'pikir': 2591,
#  'saller': 2868,
#  'servis': 3026,
#  'presiden': 2646,
#  'standby': 3169,
#  'lokasi': 1905,
#  'ngalami': 2217,
#  'doang': 962,
#  'ngalamin': 2218,
#  'bhulshittt': 446,
#  'program': 2668,
#  'garansi': 1152,
#  'mode': 2139,
#  'claimnya': 732,
#  'default': 840,
#  'curang': 784,
#  'berkahh': 417,
#  'siasat': 3071,
#  'mnjamingaransi': 2134,
#  'tanggung': 3260,
#  'down': 974,
#  'lapor': 1808,
#  'sukses': 3196,
#  'kocak': 1625,
#  'mulu': 2164,
#  'kelar': 1531,
#  'eneg': 1041,
#  'dengernya': 851,
#  'badut': 231,
#  'password': 2452,
#  'sekalibegitu': 2948,
#  'verif': 3566,
#  'passwordklik': 2453,
#  'lupa': 1928,
#  'bisagimana': 470,
#  'ulas': 3509,
#  'promoted': 2675,
#  'fleksibel': 1106,
#  'monoton': 2147,
#  'size': 3116,
#  'real': 2739,
#  'nurut': 2300,
#  'kategori': 1498,
#  'bisaselalu': 480,
#  'lengkap': 1852,
#  'chapta': 716,
#  'nyata': 2322,
#  'lulus': 1922,
#  'promot': 2674,
#  'ngitung': 2243,
#  'utang': 3555,
#  'lunas': 1925,
#  'jumlah': 1440,
#  'mes': 2095,
#  'hutang': 1289,
#  'lagiterima': 1746,
#  'dompet': 968,
#  'asuransi': 207,
#  'barangterima': 308,
#  'bukalapaktidak': 602,
#  'mengecewakanjaya': 2067,
#  'bukalapakaplikasi': 573,
#  'indonesiasekali': 1322,
#  'aga': 37,
#  'dowload': 973,
#  'inikarna': 1331,
#  'lamatp': 1778,
#  'barangpengiriman': 304,
#  'standar': 3168,
#  'membaiksesuai': 2041,
#  'estimasiuntuk': 1059,
#  'lgtrima': 1870,
#  'kasihapk': 1494,
#  'kabar': 1443,
#  'brengsek': 537,
#  'dajjal': 804,
#  'google': 1184,
#  'tutup': 3494,
#  'permanen': 2565,
#  'kagak': 1457,
#  'minta': 2116,
#  'pembayaranya': 2507,
#  'lainyasangat': 1764,
#  'mudahsangat': 2160,
#  'kalang': 1466,
#  'tengah': 3305,
#  'kebawahapalagi': 1507,
#  'vocer': 3581,
#  'lai': 1752,
#  'dapatkanpayah': 815,
#  'bonus': 524,
#  'event': 1067,
#  'mini': 2108,
#  'periode': 2562,
#  'maret': 1988,
#  'telkom': 3293,
#  'wib': 3628,
#  'terimakasih': 3325,
#  'menindaklanjuti': 2077,
#  'platform': 2608,
#  'mnrut': 2136,
#  'acc': 9,
#  'good': 1182,
#  'job': 1421,
#  'fasilitas': 1082,
#  'history': 1272,
#  'prifasi': 2649,
#  'histori': 1271,
#  'obatproduk': 2333,
#  'dewasa': 869,
#  'sebagainyaitu': 2921,
#  'prifasitrims': 2650,
#  'keren': 1572,
#  'saing': 2857,
#  'ketat': 1588,
#  'kompetitor': 1643,
#  'yuk': 3665,
#  'buru': 632,
#  'download': 976,
#  'konsisten': 1661,
#  'timbul': 3377,
#  'tenggelam': 3307,
#  'loh': 1902,
#  'hehee': 1255,
#  'ok': 2341,
#  'barusan': 314,
#  'pindah': 2598,
#  'tik': 3372,
#  'tok': 3403,
#  'murah': 2173,
#  'masang': 2011,
#  'pasang': 2450,
#  'ayo': 222,
#  'grosir': 1191,
#  'tranksaksi': 3434,
#  'tranksasi': 3435,
#  'layanananya': 1824,
#  'parahhhhhhhhhhh': 2443,
#  'langanan': 1791,
#  'lagan': 1731,
#  'kualitas': 1703,
#  'ada': 15,
#  'kerjasama': 1577,
#  'referral': 2750,
#  'alhamdulillah': 94,
#  'rezeki': 2806,
#  'tsbt': 3470,
#  'ajak': 51,
#  'panjang': 2434,
#  'bukutabungan': 623,
#  'hpgmail': 1282,
#  'code': 738,
#  'btblvj': 549,
#  'sisi': 3104,
#  'ui': 3502,
#  'user': 3550,
#  'friendly': 1115,
#  'popup': 2630,
#  'mengecewakanaman': 2066,
#  'customertingkatkan': 792,
#  'prestasi': 2647,
#  'blspy': 508,
#  'service': 3024,
#  'kendaladan': 1557,
#  'solusitidak': 3143,
#  'sekian': 2955,
#  'dikirimlha': 907,
#  'visa': 3578,
#  'nyampek': 2315,
#  'terkadang': 3332,
#  'nnya': 2270,
#  'sd': 2915,
#  'amana': 107,
#  'menit': 2078,
#  'software': 3139,
#  'instal': 1339,
#  'akunpu': 79,
#  'tunjuk': 3486,
#  'nasabah': 2197,
#  'token': 3405,
#  'listrik': 1886,
#  'urgent': 3544,
#  'laaahh': 1726,
#  'kabupaten': 1447,
#  'bandung': 271,
#  'padalarang': 2410,
#  'mesan': 2096,
#  'februari': 1088,
#  'nobody': 2272,
#  'at': 208,
#  'home': 1279,
#  'ente': 1047,
#  'jne': 1419,
#  'dll': 955,
#  'beginiga': 346,
#  'kabbandung': 1445,
#  'jakarta': 1377,
#  'bareng': 310,
#  'paham': 2414,
#  'mantablah': 1976,
#  'virtual': 3576,
#  'kadaluarsa': 1451,
#  'kmna': 1619,
#  'lari': 1810,
#  'lah': 1748,
#  'captcha': 668,
#  'resin': 2788,
#  'ongkirnya': 2362,
#  'yrus': 3661,
#  'kembang': 1551,
#  'prosespelapak': 2679,
#  'meresponsolusi': 2093,
#  'menungguini': 2081,
#  'pemrosesan': 2520,
#  'hak': 1219,
#  'letoy': 1863,
#  'audit': 215,
#  'gimmick': 1172,
#  'heran': 1261,
#  'lagicustomer': 1739,
#  'onlinetapi': 2371,
#  'buat': 553,
#  'system': 3220,
#  'indomaretalfamartbahkan': 1319,
#  'atmjadi': 212,
#  'trnsaksi': 3459,
#  'berhasilpulsa': 410,
#  'masuktagihan': 2015,
#  'adakomplen': 24,
#  'mesin': 2097,
#  'reseller': 2785,
#  'baharu': 253,
#  'transfertapi': 3441,
#  'oke': 2342,
#  'pencaria': 2523,
#  'penjualanya': 2543,
#  'bug': 556,
#  'visual': 3579,
#  'alangkah': 86,
#  'lemott': 1848,
#  'sistemya': 3112,
#  'test': 3351,
#  'bberapa': 336,
#  'ajar': 53,
#  'jarang': 1392,
#  'palsu': 2432,
#  'eror': 1050,
#  'gabakalan': 1121,
#  'mudahproses': 2159,
#  'cepatdan': 698,
#  'menariksangat': 2057,
#  'rekomendit': 2771,
#  'alias': 96,
#  'gajelasgda': 1127,
#  ...}

# %%
#kolom pertama ini berarti jumlah dokumen
#kolom kedua berarti letak katanya
#kolom ketiga hasil dari tf

term_frequency_all = term_fit.transform(Ulasan)
print (term_frequency_all)
# Out:
#   (0, 320)	1
#   (0, 332)	1
#   (0, 449)	1
#   (0, 451)	2
#   (0, 457)	1
#   (0, 717)	1
#   (0, 1036)	1
#   (0, 1052)	1
#   (0, 1144)	2
#   (0, 1395)	1
#   (0, 1455)	2
#   (0, 1780)	1
#   (0, 1821)	2
#   (0, 2301)	3
#   (0, 2392)	1
#   (0, 2463)	1
#   (0, 2704)	2
#   (0, 2726)	2
#   (0, 2863)	1
#   (0, 3106)	1
#   (0, 3210)	1
#   (0, 3300)	1
#   (1, 224)	1
#   (1, 570)	1
#   (1, 625)	1
#   :	:
#   (1297, 449)	1
#   (1297, 559)	1
#   (1297, 1199)	1
#   (1297, 1800)	1
#   (1297, 1821)	1
#   (1297, 2420)	1
#   (1297, 2688)	1
#   (1297, 3384)	1
#   (1298, 2154)	1
#   (1298, 3436)	1
#   (1299, 178)	1
#   (1299, 234)	1
#   (1299, 298)	3
#   (1299, 559)	1
#   (1299, 670)	1
#   (1299, 1084)	1
#   (1299, 1800)	1
#   (1299, 1951)	1
#   (1299, 2012)	1
#   (1299, 2212)	1
#   (1299, 2254)	1
#   (1299, 2301)	2
#   (1299, 3307)	1
#   (1299, 3418)	1
#   (1299, 3528)	1

# %%
ulasan_tf = Ulasan[1] #memanggil kata pada index ke 1
print (ulasan_tf)
# Out:
# pasti hp wifi lemmooottttt dasar bukalapak karuan lihat status transsaksi tunggu halaman isi penuh muncul tawar kadang tanda nya sulit baca pencet bulalapak main paket data orang konten webnya lumayan hasil moga curiga maaf

# %%
term_frequency = term_fit.transform([ulasan_tf]) #hanya menampilkan hasil document 1
print (term_frequency)
# Out:
#   (0, 224)	1
#   (0, 570)	1
#   (0, 625)	1
#   (0, 787)	1
#   (0, 823)	1
#   (0, 825)	1
#   (0, 1222)	1
#   (0, 1246)	1
#   (0, 1281)	1
#   (0, 1359)	1
#   (0, 1455)	1
#   (0, 1488)	1
#   (0, 1669)	1
#   (0, 1838)	1
#   (0, 1874)	1
#   (0, 1923)	1
#   (0, 1932)	1
#   (0, 1943)	1
#   (0, 2144)	1
#   (0, 2168)	1
#   (0, 2301)	1
#   (0, 2381)	1
#   (0, 2427)	1
#   (0, 2454)	1
#   (0, 2526)	1
#   (0, 2546)	1
#   (0, 3172)	1
#   (0, 3199)	1
#   (0, 3244)	1
#   (0, 3274)	1
#   (0, 3446)	1
#   (0, 3485)	1
#   (0, 3623)	1
#   (0, 3629)	1

# %%
dokumen = term_fit.transform(Ulasan) #hasil perhitungan tf idf dalam 1 doc
tfidf_transformer = TfidfTransformer().fit(dokumen)
print (tfidf_transformer.idf_)

tfidf=tfidf_transformer.transform(term_frequency)
print (tfidf) #hasil manual dengan sistem pyhton
# Out:
# [6.78459412 6.78459412 7.4777413  ... 7.4777413  7.4777413  7.4777413 ]
#   (0, 3629)	0.1864703905254794
#   (0, 3623)	0.22890740977261875
#   (0, 3485)	0.12095903051599532
#   (0, 3446)	0.2164953773216395
#   (0, 3274)	0.1864703905254794
#   (0, 3244)	0.20085806576958412
#   (0, 3199)	0.13359698162048633
#   (0, 3172)	0.13099014453527852
#   (0, 2546)	0.1828648352470906
#   (0, 2526)	0.20085806576958412
#   (0, 2454)	0.20085806576958412
#   (0, 2427)	0.14812101271859412
#   (0, 2381)	0.14129017833912916
#   (0, 2301)	0.07552265082129159
#   (0, 2168)	0.13498866847850502
#   (0, 2144)	0.1285879841079976
#   (0, 1943)	0.1828648352470906
#   (0, 1932)	0.15692748989118455
#   (0, 1923)	0.15550342668048206
#   (0, 1874)	0.1716081036253722
#   (0, 1838)	0.22890740977261875
#   (0, 1669)	0.2164953773216395
#   (0, 1488)	0.2076889001490491
#   (0, 1455)	0.14500525730719113
#   (0, 1359)	0.16164632562352094
#   (0, 1281)	0.13428491705691237
#   (0, 1246)	0.1379775615508233
#   (0, 1222)	0.16164632562352094
#   (0, 825)	0.15414267649877902
#   (0, 823)	0.1864703905254794
#   (0, 787)	0.20085806576958412
#   (0, 625)	0.22890740977261875
#   (0, 570)	0.06603504159903695
#   (0, 224)	0.15692748989118455

# %%
data_label = name_dataframe[["Nama pengguna", "Ulasan_clean", "Sentiment"]]

# %%
data_label["Ulasan_clean"] = data_label["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-73-5732072d6cca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label["Ulasan_clean"] = data_label["Ulasan_clean"].fillna("tidak ada komentar")

# %%
data_label.to_excel("data_label.xlsx")

# %%
sentimen_data=pd.value_counts(data_label["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["#ccd5ae"])
plt.title('Bar chart')
plt.show()

# %%
plt.figure(figsize=(16, 6))

heatmap = sns.heatmap(name_dataframe.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12)

plt.tight_layout()

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize',
#        'Ulasan_normalized', 'Ulasan_stop_removed', 'Ulasan_Stemmed',
#        'Ulasan_clean', 'label', 'Polarity', 'Subjectivity', 'Sentiment'],
#       dtype='object')

# %%
from wordcloud import WordCloud

# %%
train_s0 = data_label[data_label["Sentiment"] == 'Negative']

# %%
train_s0["Ulasan_clean"] = train_s0["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-83-4a391e85ccb2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s0["Ulasan_clean"] = train_s0["Ulasan_clean"].fillna("tidak ada komentar")

# %%
train_s0
# Out:
#                 Nama pengguna  \
# 3               Afifur Rohman
# 5     Kaloka Galih Kayu Wangi
# 13               Bam Hendrian
# 40                     eH boy
# 62                     Lemuel
# 63              Sutris Trisno
# 86                Kamal Yusup
# 115             inaya putry26
# 289              tri mulyanto
# 290          Achenk Chonsleth
# 291               david james
# 294                 Trade Day
# 306                  Nyon bae
# 314               Endi irawan
# 333                  dwi momo
# 378            Muhammad Basir
# 401               Vaka Vaka13
# 430                Dhani Deff
# 472                     WesLi
# 497           Novi Nurhalimah
# 502                Ahmad Amek
# 503             Helmi Arianto
# 509            official store
# 524            Richo Agustian
# 528              Cucu Latipah
# 539             Annisa Arifah
# 540             ari hariyanto
# 544                   Hambali
# 598               munif abdul
# 644         Oktavdian Sonjaya
# 733            Herianto Halim
# 739                Tegar Ibnu
# 796     Ulfa Mar'atus Solihah
# 844        Rosyidin Atmadja 2
# 941         Budiman Android16
# 974           Pengguna Google
# 983               Najwa Jemur
# 1001          Pengguna Google
# 1006          Pengguna Google
# 1012                Hr Tester
# 1055          Pengguna Google
# 1074                  Y end Y
# 1085          nur ahmad salim
# 1115                Fian Syah
# 1186      Armand Arya Firdaus
# 1214             Sri Sutrisni
# 1256         Rosana Anjaswari
# 1293          Pengguna Google
# 1294             wisnu arifin
#
#                                            Ulasan_clean Sentiment
# 3     aplikasi bagus minus ongkir mahal voucher paka...  Negative
# 5     jual emas bukaemas susah banget banget problem...  Negative
# 13    kesini sistem nya berat ajabanyak sisrem gunab...  Negative
# 40    developer bukalapak lihat aplikasi shopee laza...  Negative
# 62    mohon maaf kasih bintang alas hubung cs via ch...  Negative
# 63    guna setia bltp perlahan alih toko online lain...  Negative
# 86    down lapor pesan cocok pesan terima lapor pesa...  Negative
# 115   aplikasi nya visa live chat maju bukalapak pes...  Negative
# 289   kecewa kali belanja lapak merespon pesan batas...  Negative
# 290   lumayan bagus minus sedia menu layan varian pr...  Negative
# 291   order alamat kirim laku lapak bilang kode book...  Negative
# 294   kecewa sihketika voucher voucher alas voucher ...  Negative
# 306   aplikasi guna ganti nomor hp kirim foto ktp ga...  Negative
# 314   beli barang nonfisik chip game inti barang fis...  Negative
# 333   beres market rugi barang cek aplikasi nya pesa...  Negative
# 378   sussh seller tmbhin varian prdukgk kayak tkope...  Negative
# 401   bingung komentar apasly ssh cari minus kkurang...  Negative
# 430   kesini bagus aplikasi buka chat loading tampil...  Negative
# 472   susah hubungin cs sulit hubung cs pakai email ...  Negative
# 497   kecewa aplikasi bukalapak telat bayar jatuh te...  Negative
# 502   maaf turun bintangnyakarena pakai bukalapak pa...  Negative
# 503   jual barang bukalapak sabtu sore transaksi bar...  Negative
# 509   aplikasi sungguh kecewa konsisten terap atur s...  Negative
# 524   halo bukalapak email ganti alas gagal kirim em...  Negative
# 528   sengaja bintang biar baca isi saldo atm tangga...  Negative
# 539   kecewa sellernya fiturnya live chat susah tamb...  Negative
# 540   parah bukalapak komplen klaim barang sulit pot...  Negative
# 544   rekan saran belanja bukalapak bayak tipu salah...  Negative
# 598   komplain tagih bayar lelet deh bayar status ba...  Negative
# 644      suka bingung bonus credit nya ya plus minus ya  Negative
# 733   kasih kritik negatif nyata akun langsung bloki...  Negative
# 739   sih asih voucher gratis ongkir minimal potong ...  Negative
# 796   edit ulas hubung customer care aplikasi kait b...  Negative
# 844   sayang usaha buka lapak jual produk game bau j...  Negative
# 941   sistem nya parah seller ecek jual masuk ecek a...  Negative
# 974   heran aplikasi upload jual barang kaya susahhh...  Negative
# 983   kalo bukalapak rame tampil barang jual bayar i...  Negative
# 1001  baik servernya fitur macet traffict diserver j...  Negative
# 1006  bukastruk gagal struk identifikasi deteksi dup...  Negative
# 1012  aplikasi bagus bantu kendala admin komplain me...  Negative
# 1055  kurangtapi suka dwngan tampil bukalapak update...  Negative
# 1074  coba deh segi server nya baik iya malam down s...  Negative
# 1085  sistem kalah competitornya lot gagal sistem al...  Negative
# 1115  barang pesan langsung aju komplain selesai isi...  Negative
# 1186  aplikasi bukalapak seller oriented bukalapak g...  Negative
# 1214  lapak kecewa bukalapak komplain susah lapak tu...  Negative
# 1256  halo bayar paylater beku pakai doang beli puls...  Negative
# 1293  baharu akun email username error pakai transak...  Negative
# 1294  aplikasi belanja mepersulit melakukakan ubah d...  Negative

# %%
all_text_s0 = ' '.join(word for word in train_s0["Ulasan_clean"])
wordcloud = WordCloud(colormap='Reds', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s0)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
# Create scatter plot
sns.set_style('darkgrid')
plt.figure(figsize = (15,7))

markers = {'Positive':'o', 'Neutral':'s','Negative':'X'}

sns.scatterplot(data=name_dataframe, x='Polarity', y='Subjectivity', hue = 'Sentiment', style = 'Sentiment', markers = markers, palette = 'gist_earth').set(xlim=(-1,1))
plt.title('Scatter Plot')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')

plt.tight_layout()

# %%
train_s1 = data_label[data_label["Sentiment"] == 'Positive']

# %%
train_s1["Ulasan_clean"] = train_s1["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-88-89653e0cae75>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s1["Ulasan_clean"] = train_s1["Ulasan_clean"].fillna("tidak ada komentar")

# %%
train_s1
# Out:
#                          Nama pengguna  \
# 1     dedy kelana (CV PRIBUMI BANGKIT)
# 6                        Kosim Nurseha
# 7                          Bayazid_Boy
# 18                     Arif Zulkarnaen
# 24                          Ratna Dewi
# ...                                ...
# 1252                     Phai Muhammad
# 1261                      Iwan Setiono
# 1268           Mizannudin Hardiyansyah
# 1292                         Eko Yudhi
# 1295                   Pengguna Google
#
#                                            Ulasan_clean Sentiment
# 1     pasti hp wifi lemmooottttt dasar bukalapak kar...  Positive
# 6     solusi bukabantuan live chat bantu tunggu jam ...  Positive
# 7     bl kepercayan ecom utama transaksi aktifasi ga...  Positive
# 18    apk sulit komplain kendala live chat cs nya mi...  Positive
# 24    payah ah kecewa saldo habis untung ngisi nya c...  Positive
# ...                                                 ...       ...
# 1252  aplikasi jual tipu belanja bukalapak gue pesan...  Positive
# 1261  ok kirim cepat toko sebelahharga murah toko be...  Positive
# 1268  aplikasi belanja buruk cs nya pakai robot chat...  Positive
# 1292  suka banget bukalapak manja belanja online mud...  Positive
# 1295  ya bintang kalo normal app blnya tambah bintan...  Positive
#
# [202 rows x 3 columns]

# %%
all_text_s1 = ' '.join(word for word in train_s1["Ulasan_clean"])
wordcloud = WordCloud(colormap='Blues', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s1)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Ulasan Positif")
plt.margins(x=0, y=0)
plt.show()

# %%
data_label['Ulasan_clean'] = data_label['Ulasan_clean'].fillna("tidak ada komentar")
# Out:
# <ipython-input-91-27b828896519>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['Ulasan_clean'] = data_label['Ulasan_clean'].fillna("tidak ada komentar")

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_clean'], data_label['Sentiment'], 
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# %%
import numpy as np

# %%
from sklearn.feature_extraction.text import TfidfVectorizer             #menghitung n menjumlah kan dan menjumlah kan tf and n berdasarkan seluruh dokumen 
vectorizer = TfidfVectorizer(decode_error='replace', encoding='utf-8')

# %%
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

print(X_train.shape)
print(X_test.shape)
# Out:
# (1170, 3365)
# (130, 3365)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-fa8c0b6824ed> in <cell line: 1>()
# ----> 1 print('Training set score: {:.4f}'.format(gnb.score(X_train, y_train)))
#       2
#       3 print('Test set score: {:.4f}'.format(gnb.score(X_test, y_test)))
#
# NameError: name 'gnb' is not defined

# %% [markdown]
# **sample random**
#
# mengambil secara acak dari daftar sample atau sampling frame yang tersedia setiap individu memiliki peluang yang sama untuk terpilih
# peluang tersebut ada melakukan peluang sama ketika mempunyai data besar akan memliki peluang lebih besar untuk terpilih tetapi sebaliknya ketika mempunyai data dikit dapat peluang lebih sedikit

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_clean'], data_label['Sentiment'], 
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# Vectorize the text data
vectorizer = TfidfVectorizer(decode_error='replace', encoding='utf-8')
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# Create the Naive Bayes Classifier object
gnb = GaussianNB()

# Perform cross-validation
scores = cross_val_score(gnb, X_train.toarray(), y_train, cv=5)

# Print the cross-validation scores
print('Cross-validation scores:', scores)

# Fit the classifier to the training data
gnb.fit(X_train.toarray(), y_train)

# Predict the sentiment of the test data
y_pred = gnb.predict(X_test.toarray())

# Print the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:\n', conf_matrix)
# Out:
# Cross-validation scores: [0.56837607 0.5982906  0.60683761 0.5982906  0.55128205]
# Confusion Matrix:
#  [[ 0  4  1]
#  [10 66 29]
#  [ 1 14  5]]

# %%
classification_accuracy = (TP + TN) / float(TP + TN + FP + FN)

print('Classification accuracy : {0:0.4f}'.format(classification_accuracy))
# Out:
# Classification accuracy : 0.8250

# %%
TP = cm[0,0]
TN = cm[1,1]
FP = cm[0,1]
FN = cm[1,0]

# %%
# print classification error kesalahan klasifikasi 

classification_error = (FP + FN) / float(TP + TN + FP + FN)

print('Classification error : {0:0.4f}'.format(classification_error))
# Out:
# Classification error : 0.1750

# %%
y_pred_prob_df = pd.DataFrame(data=y_pred, columns=['Positif', 'Neutral', 'Negatif'])

y_pred_prob_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-1b5bb8c238ac> in <cell line: 1>()
# ----> 1 y_pred_prob_df = pd.DataFrame(data=y_pred, columns=['Positif', 'Neutral', 'Negatif'])
#       2
#       3 y_pred_prob_df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     720                 )
#     721             else:
# --> 722                 mgr = ndarray_to_mgr(
#     723                     data,
#     724                     index,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     347     )
#     348
# --> 349     _check_values_indices_shape_match(values, index, columns)
#     350
#     351     if typ == "array":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _check_values_indices_shape_match(values, index, columns)
#     418         passed = values.shape
#     419         implied = (len(index), len(columns))
# --> 420         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     421
#     422
#
# ValueError: Shape of passed values is (130, 1), indices imply (130, 3)

# %%
y_pred = gnb.predict(X_test)

y_pred
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-0e627d888d33> in <cell line: 1>()
# ----> 1 y_pred = gnb.predict(X_test)
#       2
#       3 y_pred
#
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py in predict(self, X)
#     103         """
#     104         check_is_fitted(self)
# --> 105         X = self._check_X(X)
#     106         jll = self._joint_log_likelihood(X)
#     107         return self.classes_[np.argmax(jll, axis=1)]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py in _check_X(self, X)
#     271     def _check_X(self, X):
#     272         """Validate X, used only in predict* methods."""
# --> 273         return self._validate_data(X, reset=False)
#     274
#     275     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     563             raise ValueError("Validation should be done on X, y or both.")
#     564         elif not no_val_X and no_val_y:
# --> 565             X = check_array(X, input_name="X", **check_params)
#     566             out = X
#     567         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     843     if sp.issparse(array):
#     844         _ensure_no_complex_data(array)
# --> 845         array = _ensure_sparse_format(
#     846             array,
#     847             accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in _ensure_sparse_format(spmatrix, accept_sparse, dtype, copy, force_all_finite, accept_large_sparse, estimator_name, input_name)
#     520
#     521     if accept_sparse is False:
# --> 522         raise TypeError(
#     523             "A sparse matrix was passed, but dense "
#     524             "data is required. Use X.toarray() to "
#
# TypeError: A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array.

# %%
X_test = pd.DataFrame(X_test, columns=[cols])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-e4a31057a819> in <cell line: 1>()
# ----> 1 X_test = pd.DataFrame(X_test, columns=[cols])
#
# NameError: name 'cols' is not defined

# %%
print('--------------------- confusion matrix  ----------------------------')
print(confusion_matrix(y_test, y_pred))
print('--------------------- classification report  ----------------------------')
print(classification_report(y_test, y_pred))
# Out:
# --------------------- confusion matrix  ----------------------------
# [[ 0  4  1]
#  [10 66 29]
#  [ 1 14  5]]
# --------------------- classification report  ----------------------------
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         5
#      Neutral       0.79      0.63      0.70       105
#     Positive       0.14      0.25      0.18        20
#
#     accuracy                           0.55       130
#    macro avg       0.31      0.29      0.29       130
# weighted avg       0.66      0.55      0.59       130

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
# visualize confusion matrix with seaborn heatmap

cm_matrix = pd.DataFrame(data=cm, columns=['Negative:1', 'Neutral:0', 'Positive:2'], 
                                 index=['Negative:1', 'Neutral:0', 'Positive:2'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')

# %%
X_train = X_train.toarray()

# %%
X_test = X_test.toarray()

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

#deklarasi metode cross validation
cv_method = RepeatedStratifiedKFold(n_splits=5,  n_repeats=3, random_state=999)
#tuning hyperparameter menggunakan gridsearch

params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}
gscv_nb = GridSearchCV(estimator=nb, 
                 param_grid=params_NB, 
                 cv=cv_method,   # use any cross validation technique 
                 verbose=1, 
                 scoring='accuracy') 

#Fitting ke Model
gscv_nb.fit(X_train,y_train)
#mendapatkan hyperparameters terbaik
gscv_nb.best_params_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-068c838240c7> in <cell line: 10>()
#       8
#       9 params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}
# ---> 10 gscv_nb = GridSearchCV(estimator=nb,
#      11                  param_grid=params_NB,
#      12                  cv=cv_method,   # use any cross validation technique
#
# NameError: name 'nb' is not defined

# %%
nb = GaussianNB(var_smoothing=1.0) # untuk tidak overviting

# %%
nb.fit(X_train, y_train)

# %%
y_pred_nb = nb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
print(y_train)

# %%
# visualize confusion matrix with seaborn heatmap

cm_matrix = pd.DataFrame(data=cm, columns=['Negative:1', 'Neutral:0', 'Positive:2'], 
                                 index=['Negative:1', 'Neutral:0', 'Positive:2'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
print('Confusion matrix\n\n', cm)

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
# Regresi Logistik
logreg = LogisticRegression()
# SVM
svm = SVC(probability=True)

# %%
logreg.fit(X_train, y_train)
svm.fit(X_train, y_train)

# %%
y_pred1_logreg = logreg.predict(X_test)
y_pred1_svm = svm.predict(X_test)

# %%
print('---------------  Regresi Logistik  -------------------')
print(classification_report(y_test, y_pred1_logreg))
print('--------------------- SVM ----------------------------')
print(classification_report(y_test, y_pred1_svm))
