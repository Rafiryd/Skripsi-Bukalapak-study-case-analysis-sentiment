# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafiryd/Rafiryd/blob/rafiryd/skripsi%20compre%20jum'at%20akurasi%2069%20baru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Proses Pengambilan data**

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

import seaborn as sns

# %%
from google_play_scraper import Sort, reviews

app_id = 'com.bukalapak.android'
lang = 'id'
country = 'id'
sort_order = Sort.MOST_RELEVANT
target_year = 2019  # Change this to the desired target year
end_year = 2023    # Change this to the desired end year
desired_review_count = 1300  # Adjust this as needed

result, continuation_token = reviews(
    app_id,
    lang=lang,
    country=country,
    sort=sort_order,
    count=desired_review_count,
    filter_score_with=None
)

# Extract reviews from the desired years
reviews_from_target_years = []
for review in result:
    review_date = review['at']
    review_year = review_date.year
    if target_year <= review_year <= end_year:
        reviews_from_target_years.append(review)

print(reviews_from_target_years)
# Out:
# [{'reviewId': '746a7625-b356-46ca-a522-3800375c0698', 'userName': 'Wayan Gita', 'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTd_20KxMvJgC_EtLGHP6DMtznutDvZvcYJ8BPcmmAme7o', 'content': 'Fitur bukabantuan nggak guna, aplikasi ribet, ada saldo 700.000+ malah nggak bisa dipakai apa2, mau aku cairin atau transfer malah ribet banget, password dibilang salah, udah riset password masih juga dibilang salah, udah dikit lagi mau selesai malah ada notifikasi kalau sistem lagi eror, apaan sih.', 'score': 1, 'thumbsUpCount': 48, 'reviewCreatedVersion': '5.34.3', 'at': datetime.datetime(2023, 8, 10, 13, 36, 28), 'replyContent': None, 'repliedAt': None, 'appVersion': '5.34.3'}, {'reviewId': '8a1e53b2-0cca-49aa-9bc0-5084836892d1', 'userName': 'yOga 04', 'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTDa2wAT_UfqLLxKCOujbxZRCL0mTdBF6LwPJvSK3sE6Q', 'content': 'Aplikasi marketplace paling ancur.. Sistem bukabantuan ngga jelas jika ada masalah.. bukannya selesain masalah malah lari dr masalah live chatnya ngga guna.. apalagi sistem paylaternya bobrok.. Silahkan dicoba sendiri yg mau download nanti juga tau..', 'score': 1, 'thumbsUpCount': 138, 'reviewCreatedVersion': '5.34.3', 'at': datetime.datetime(2023, 8, 1, 3, 19, 16), 'replyContent': None, 'repliedAt': None, 'appVersion': '5.34.3'}, {'reviewId': 'a9e36908-f0e9-41a3-9c64-2abb91481416', 'userName': 'Muhamad Basir', 'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMT-c1sZMO97E9bOS61fexlmZvKXUNV_AuZ7lMDzc0xLpQ', 'content': 'Bingung bgt mau hub cs caranya gmn.. Mau ngaktifin fitur live chat harus ngasih feedback, udh ngasih feedback tapi fitur live chat tetep gk aktif. Saya cuma mau tanya kenapa saya gak bisa liat transaksi pembelian saya, karna setiap saya klik, selalu tertulis sedang gangguan. Tapi saya klik transaksi sy yg lain, gak ada gangguan. Saya coba email juga tidak bisa terkirim. Aplikasi t*lol!!!', 'score': 1, 'thumbsUpCount': 204, 'reviewCreatedVersion': '5.32.2', 'at': datetime.datetime(2023, 6, 10, 15, 44, 50), 'replyContent': None, 'repliedAt': None, 'appVersion': '5.32.2'}, {'reviewId': '3c8c9231-adfb-4dfb-bde2-4f64f69b5424', 'userName': 'Erick Matahine', 'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTfexprtC_pmoTL6rLlryZ9wu9tim8HIzevQfz157N3jeQ', 'content': 'Lagi asyik-asyiknya nemu barang yang diincar, eehhh... Muncul popup/iklan Buka Emas yg dimana sangat mengganggu, saat close (X) bukannya kembali ke barang yg diincar eh malah masuk ke menu buka emas, saat keluar dari menu buka emas malah ke beranda. Nggak jadi beli dah, akhirnya ke Tokopedia & Shopee untuk belanja barang tersebut. Kedepan kalau banyakan popup gitu jujur saya uninstal aja', 'score': 1, 'thumbsUpCount': 44, 'reviewCreatedVersion': '5.32.2', 'at': datetime.datetime(2023, 6, 12, 7, 17, 25), 'replyContent': None, 'repliedAt': None, 'appVersion': '5.32.2'}, {'reviewId': 'a8a18630-fbb3-465a-9b44-03b4f3c53585', 'userName': 'ipin sopandi', 'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSJzy27yVXvaOys8Y4-ZBJAvStwgI_zmpy2Soaf4Hz3Vjw', 'content': 'Nggak bisa komplain sudah seminggu permintaan pencairan dana ke rekening pribadi belum juga berhasil, ....BukaBantuan tidak bisa digunakan Tolong kerjasamanya, aktifkan kembali BukaBantuannya, saya yakin banyak yang punya masalah seperti ini dan nggak bisa komplain. Next jika masalah saya sudah selesai bintangnya diubah jadi 7', 'score': 1, 'thumbsUpCount': 26, 'reviewCreatedVersion': '5.34.3', 'at': datetime.datetime(2023, 8, 7, 13, 7, 29), 'replyContent': None, 'repliedAt': None, 'appVersion': '5.34.3'}, {'reviewId': '18f72c9e-254f-4107-9e05-bdc0d0fce382', 'userName': 'Robin Bintaro', 'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTq49Q5e_P9mKA-lEr_bXYYPjuNN-FtUZ5jqfsPF5YDM9Q', 'content': 'Setelah update malah jadi suka error padahal sebelumnya cepat dan tidak suka error..barusan turun lagi bintangnya dari 3 jadi 2.. karna sudah beberapa hari notif tagihan tidak bisa hilang padahal semua pemba ...

# %% [markdown]
# Problems slovlig tools = mencari akar permasalahan pada suatu masalah
#
# 5 why
#
# metode mencari problems sloving dengan cara menanyakan apa penyebab permasalahaan muncul dan mencari jawabannya. hal ini di lakUkan berkali klai sampai permasalahan dapat tergambar dengan jelas
#
# action priority
#
# diagram yang dapat di gunakan untuk mencari prioritas masalah berdasarkan impact atas benefit yang bisa diberikan dengan diagram ini kita memilih masalah yang impactnya mayoritas dari permasalahan yang ada.
#
# fishbone digram
#
# digram yang dapat di gunakan untuk merinci masalah dan membantu mencari akar masalah yang dapat dilihat dari beberapa point of view
#
# flowchart/algo
#
# metode pemecahan masalah dengan cara memetakan flow atau membuat pseudo algoritma yang untuk menentukan masalah dan cara untuk mencari solusinya secara sistematis

# %% [markdown]
# # **Data diproleh**

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId        userName  \
# 0  746a7625-b356-46ca-a522-3800375c0698      Wayan Gita
# 1  8a1e53b2-0cca-49aa-9bc0-5084836892d1         yOga 04
# 2  a9e36908-f0e9-41a3-9c64-2abb91481416   Muhamad Basir
# 3  3c8c9231-adfb-4dfb-bde2-4f64f69b5424  Erick Matahine
# 4  a8a18630-fbb3-465a-9b44-03b4f3c53585    ipin sopandi
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# 1  https://play-lh.googleusercontent.com/a-/AD_cM...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a-/AD_cM...
# 4  https://play-lh.googleusercontent.com/a-/AD_cM...
#
#                                              content  score  thumbsUpCount  \
# 0  Fitur bukabantuan nggak guna, aplikasi ribet, ...      1             48
# 1  Aplikasi marketplace paling ancur.. Sistem buk...      1            138
# 2  Bingung bgt mau hub cs caranya gmn.. Mau ngakt...      1            204
# 3  Lagi asyik-asyiknya nemu barang yang diincar, ...      1             44
# 4  Nggak bisa komplain sudah seminggu permintaan ...      1             26
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0               5.34.3 2023-08-10 13:36:28         None       NaT     5.34.3
# 1               5.34.3 2023-08-01 03:19:16         None       NaT     5.34.3
# 2               5.32.2 2023-06-10 15:44:50         None       NaT     5.32.2
# 3               5.32.2 2023-06-12 07:17:25         None       NaT     5.32.2
# 4               5.34.3 2023-08-07 13:07:29         None       NaT     5.34.3

# %%
len(df_busu.index) #count the number of data we got
# Out:
# 1300

# %%
df_busu[['userName', 'score','at', 'content']].tail()  #preview userName, rating, date-time, and reviews only
# Out:
#                       userName  score                  at  \
# 1295                 Dede Kurt      1 2023-06-15 15:26:18
# 1296  Ahlul Fakri Almuthalliby      1 2023-06-10 15:45:56
# 1297              eka jayaos46      5 2023-07-11 10:23:31
# 1298                 Hero Hero      5 2023-06-18 07:47:11
# 1299                 aris dude      5 2023-07-06 03:03:21
#
#                                                 content
# 1295  Ga jelas sinyal bagus malah internet tidak ter...
# 1296  Saya ingin membeli pelatihan prakerja tapi tid...
# 1297  sangat membantu berjualan dan berbelanja, Teri...
# 1298            Lebih lengkap lagi untuk jualan nya gan
# 1299  Sangat membantu paylaternya, naikin limitnya dong

# %% [markdown]
# # **Perubahan Penamaan Pada Setiap Kolom**

# %%
name_dataframe = df_busu.loc[:,["userName", "score", "at", "content"]]
name_dataframe.rename(columns={"userName": "Nama pengguna", "score":"Rating", "at": "Date", "content": "Ulasan"}, inplace=True)

# %%
name_dataframe.tail()
# Out:
#                  Nama pengguna  Rating                Date  \
# 1295                 Dede Kurt       1 2023-06-15 15:26:18
# 1296  Ahlul Fakri Almuthalliby       1 2023-06-10 15:45:56
# 1297              eka jayaos46       5 2023-07-11 10:23:31
# 1298                 Hero Hero       5 2023-06-18 07:47:11
# 1299                 aris dude       5 2023-07-06 03:03:21
#
#                                                  Ulasan
# 1295  Ga jelas sinyal bagus malah internet tidak ter...
# 1296  Saya ingin membeli pelatihan prakerja tapi tid...
# 1297  sangat membantu berjualan dan berbelanja, Teri...
# 1298            Lebih lengkap lagi untuk jualan nya gan
# 1299  Sangat membantu paylaternya, naikin limitnya dong

# %%
name_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nama pengguna  1300 non-null   object
#  1   Rating         1300 non-null   int64
#  2   Date           1300 non-null   datetime64[ns]
#  3   Ulasan         1300 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 40.8+ KB

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].astype(str)
name_dataframe.head()
# Out:
#     Nama pengguna  Rating                Date  \
# 0      Wayan Gita       1 2023-08-10 13:36:28
# 1         yOga 04       1 2023-08-01 03:19:16
# 2   Muhamad Basir       1 2023-06-10 15:44:50
# 3  Erick Matahine       1 2023-06-12 07:17:25
# 4    ipin sopandi       1 2023-08-07 13:07:29
#
#                                               Ulasan
# 0  Fitur bukabantuan nggak guna, aplikasi ribet, ...
# 1  Aplikasi marketplace paling ancur.. Sistem buk...
# 2  Bingung bgt mau hub cs caranya gmn.. Mau ngakt...
# 3  Lagi asyik-asyiknya nemu barang yang diincar, ...
# 4  Nggak bisa komplain sudah seminggu permintaan ...

# %% [markdown]
# # **Case folding**

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].str.lower()

# %% [markdown]
# # **cleansing**

# %%
import string
import re
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

def remove_links(text):
    # menghapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus URL
    return text.replace("http://", " ").replace("https://", " ")

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_links)

# %%
#menghapus number
def remove_number(text):
    return  re.sub(r"\d+", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_number)

# %%
#menghapus punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_punctuation)

# %%
# menghapus single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_singl_char)

# %% [markdown]
# # **Tokenizing**

# %%
# Tokenisasi
def word_tokenize_wrapper(text):
    return word_tokenize(text)

name_dataframe['Ulasan_tokenize'] = name_dataframe['Ulasan'].apply(word_tokenize_wrapper)

# %%
name_dataframe
# Out:
#                  Nama pengguna  Rating                Date  \
# 0                   Wayan Gita       1 2023-08-10 13:36:28
# 1                      yOga 04       1 2023-08-01 03:19:16
# 2                Muhamad Basir       1 2023-06-10 15:44:50
# 3               Erick Matahine       1 2023-06-12 07:17:25
# 4                 ipin sopandi       1 2023-08-07 13:07:29
# ...                        ...     ...                 ...
# 1295                 Dede Kurt       1 2023-06-15 15:26:18
# 1296  Ahlul Fakri Almuthalliby       1 2023-06-10 15:45:56
# 1297              eka jayaos46       5 2023-07-11 10:23:31
# 1298                 Hero Hero       5 2023-06-18 07:47:11
# 1299                 aris dude       5 2023-07-06 03:03:21
#
#                                                  Ulasan  \
# 0     fitur bukabantuan nggak guna aplikasi ribet ad...
# 1     aplikasi marketplace paling ancur sistem bukab...
# 2     bingung bgt mau hub cs caranya gmn mau ngaktif...
# 3     lagi asyikasyiknya nemu barang yang diincar ee...
# 4     nggak bisa komplain sudah seminggu permintaan ...
# ...                                                 ...
# 1295  ga jelas sinyal bagus malah internet tidak ter...
# 1296  saya ingin membeli pelatihan prakerja tapi tid...
# 1297  sangat membantu berjualan dan berbelanja terim...
# 1298            lebih lengkap lagi untuk jualan nya gan
# 1299   sangat membantu paylaternya naikin limitnya dong
#
#                                         Ulasan_tokenize
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [aplikasi, marketplace, paling, ancur, sistem,...
# 2     [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3     [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4     [nggak, bisa, komplain, sudah, seminggu, permi...
# ...                                                 ...
# 1295  [ga, jelas, sinyal, bagus, malah, internet, ti...
# 1296  [saya, ingin, membeli, pelatihan, prakerja, ta...
# 1297  [sangat, membantu, berjualan, dan, berbelanja,...
# 1298    [lebih, lengkap, lagi, untuk, jualan, nya, gan]
# 1299  [sangat, membantu, paylaternya, naikin, limitn...
#
# [1300 rows x 5 columns]

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize'], dtype='object')

# %%
#Run This Code to Sort the Data By Date
# tanggal 26-04-2022 sampai 12-10-2022

new_df = name_dataframe[['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize']]
sorted_df = new_df.sort_values(by='Date', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#                     Nama pengguna  Rating                Date  \
# 106   Mayang Roro Kinanti (Kinan)       1 2023-08-21 12:51:36
# 1075           Creative music sby       1 2023-08-21 10:48:39
# 728                     Ali Mukti       5 2023-08-21 08:12:14
# 1068                   Sarna Azis       5 2023-08-21 06:10:06
# 552             Meyda Triatmajaya       5 2023-08-21 05:25:29
#
#                                                  Ulasan  \
# 106   merasa di rugikan banyak lebih dari  rb top up...
# 1075                         susah logintiba tiba blank
# 728   sangat sangat membantu kita yang blm gajian ke...
# 1068  semoga semakin sukses dan memberikan pelayanan...
# 552   terus tingkatkan kualitas aplikasinya terimaka...
#
#                                         Ulasan_tokenize
# 106   [merasa, di, rugikan, banyak, lebih, dari, rb,...
# 1075                    [susah, logintiba, tiba, blank]
# 728   [sangat, sangat, membantu, kita, yang, blm, ga...
# 1068  [semoga, semakin, sukses, dan, memberikan, pel...
# 552   [terus, tingkatkan, kualitas, aplikasinya, ter...

# %%
sorted_df.dtypes
# Out:
# Nama pengguna              object
# Rating                      int64
# Date               datetime64[ns]
# Ulasan                     object
# Ulasan_tokenize            object
# dtype: object

# %%
import pandas as pd

# Assuming you have a DataFrame named ulasan with columns 'Ulasan_tokenize' and 'Ulasan_ears'

word_to_erase = 'nya'  # Replace 'word' with the word you want to erase

name_dataframe["ulasan_ears"] = name_dataframe['Ulasan_tokenize'].apply(lambda x: [word for word in x if word != word_to_erase])

print(name_dataframe)
# Out:
#                  Nama pengguna  Rating                Date  \
# 0                   Wayan Gita       1 2023-08-10 13:36:28
# 1                      yOga 04       1 2023-08-01 03:19:16
# 2                Muhamad Basir       1 2023-06-10 15:44:50
# 3               Erick Matahine       1 2023-06-12 07:17:25
# 4                 ipin sopandi       1 2023-08-07 13:07:29
# ...                        ...     ...                 ...
# 1295                 Dede Kurt       1 2023-06-15 15:26:18
# 1296  Ahlul Fakri Almuthalliby       1 2023-06-10 15:45:56
# 1297              eka jayaos46       5 2023-07-11 10:23:31
# 1298                 Hero Hero       5 2023-06-18 07:47:11
# 1299                 aris dude       5 2023-07-06 03:03:21
#
#                                                  Ulasan  \
# 0     fitur bukabantuan nggak guna aplikasi ribet ad...
# 1     aplikasi marketplace paling ancur sistem bukab...
# 2     bingung bgt mau hub cs caranya gmn mau ngaktif...
# 3     lagi asyikasyiknya nemu barang yang diincar ee...
# 4     nggak bisa komplain sudah seminggu permintaan ...
# ...                                                 ...
# 1295  ga jelas sinyal bagus malah internet tidak ter...
# 1296  saya ingin membeli pelatihan prakerja tapi tid...
# 1297  sangat membantu berjualan dan berbelanja terim...
# 1298            lebih lengkap lagi untuk jualan nya gan
# 1299   sangat membantu paylaternya naikin limitnya dong
#
#                                         Ulasan_tokenize  \
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [aplikasi, marketplace, paling, ancur, sistem,...
# 2     [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3     [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4     [nggak, bisa, komplain, sudah, seminggu, permi...
# ...                                                 ...
# 1295  [ga, jelas, sinyal, bagus, malah, internet, ti...
# 1296  [saya, ingin, membeli, pelatihan, prakerja, ta...
# 1297  [sangat, membantu, berjualan, dan, berbelanja,...
# 1298    [lebih, lengkap, lagi, untuk, jualan, nya, gan]
# 1299  [sangat, membantu, paylaternya, naikin, limitn...
#
#                                             ulasan_ears
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [aplikasi, marketplace, paling, ancur, sistem,...
# 2     [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3     [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4     [nggak, bisa, komplain, sudah, seminggu, permi...
# ...                                                 ...
# 1295  [ga, jelas, sinyal, bagus, malah, internet, ti...
# 1296  [saya, ingin, membeli, pelatihan, prakerja, ta...
# 1297  [sangat, membantu, berjualan, dan, berbelanja,...
# 1298         [lebih, lengkap, lagi, untuk, jualan, gan]
# 1299  [sangat, membantu, paylaternya, naikin, limitn...
#
# [1300 rows x 6 columns]

# %%
name_dataframe.head()
# Out:
#     Nama pengguna  Rating                Date  \
# 0      Wayan Gita       1 2023-08-10 13:36:28
# 1         yOga 04       1 2023-08-01 03:19:16
# 2   Muhamad Basir       1 2023-06-10 15:44:50
# 3  Erick Matahine       1 2023-06-12 07:17:25
# 4    ipin sopandi       1 2023-08-07 13:07:29
#
#                                               Ulasan  \
# 0  fitur bukabantuan nggak guna aplikasi ribet ad...
# 1  aplikasi marketplace paling ancur sistem bukab...
# 2  bingung bgt mau hub cs caranya gmn mau ngaktif...
# 3  lagi asyikasyiknya nemu barang yang diincar ee...
# 4  nggak bisa komplain sudah seminggu permintaan ...
#
#                                      Ulasan_tokenize  \
# 0  [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1  [aplikasi, marketplace, paling, ancur, sistem,...
# 2  [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3  [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4  [nggak, bisa, komplain, sudah, seminggu, permi...
#
#                                          ulasan_ears
# 0  [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1  [aplikasi, marketplace, paling, ancur, sistem,...
# 2  [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3  [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4  [nggak, bisa, komplain, sudah, seminggu, permi...

# %%
# Menghitung Distibusi Persebaran Kata
def freqDist_wrapper(text):
    return FreqDist(text)

Ulasan_fqsist = name_dataframe['ulasan_ears'].apply(freqDist_wrapper)

print('Frequency Tokens : \n')
print(Ulasan_fqsist.head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(malah, 3), (nggak, 2), (ribet, 2), (ada, 2),...
# 1    [(masalah, 3), (sistem, 2), (ngga, 2), (aplika...
# 2    [(saya, 6), (mau, 3), (fitur, 2), (live, 2), (...
# 3    [(ke, 4), (barang, 3), (buka, 3), (emas, 3), (...
# 4    [(bisa, 3), (nggak, 2), (komplain, 2), (sudah,...
# Name: ulasan_ears, dtype: object

# %%
print(name_dataframe.columns)
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize',
#        'ulasan_ears'],
#       dtype='object')

# %%
name_dataframe['Ulasan_tokenize'].unique
# Out:
# <bound method Series.unique of 0       [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1       [aplikasi, marketplace, paling, ancur, sistem,...
# 2       [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3       [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4       [nggak, bisa, komplain, sudah, seminggu, permi...
#                               ...
# 1295    [ga, jelas, sinyal, bagus, malah, internet, ti...
# 1296    [saya, ingin, membeli, pelatihan, prakerja, ta...
# 1297    [sangat, membantu, berjualan, dan, berbelanja,...
# 1298      [lebih, lengkap, lagi, untuk, jualan, nya, gan]
# 1299    [sangat, membantu, paylaternya, naikin, limitn...
# Name: Ulasan_tokenize, Length: 1300, dtype: object>

# %%
slank_word_dict = {
    "berjalansudah" : "berjalan",
    "paraah" : "parah",
    "keduakali" : "",
    "keduakali" : "kedua kali",
    "agak" : "sedikit",
    "pas" : "saat",
    "produkx" : "produknya",
    "sukamkasih" : "suka makasih",
    "gak" : "tidak",
    "cpt" : "cepat",
    "sdh" : "sudah",
    "recommend" : "rekomendasi",
    "bagusseller" : "bagus",
    "bagusssss" : "bagus",
    "bagussssss" : "bagus",
    "baguuussss" : "bagus",
    "cepatmakasih": "cepat",
    "cepatmantappp": "cepat",
    "cepatproduct": "cepat",
    "cepatrecomended": "cepat",
    "cepattoko": "cepat",
    "recomended": "rekomendasi",
    "recommended": "rekomendasi",
    "rekomendasi": "rekomendasi",
    "rekomended": "rekomendasi",
    }

def slank_normalized_term(document):
    return [slank_word_dict[term] if term in slank_word_dict else term for term in document]

# %% [markdown]
# # **Normalization**

# %%
normalizad_word = pd.read_csv("/content/kamusindonesia.csv (5).csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1]

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

# %%
name_dataframe['Ulasan_normalized'] = name_dataframe['Ulasan_tokenize'].apply(normalized_term).apply(slank_normalized_term)

# %%
name_dataframe.head(100)
# Out:
#      Nama pengguna  Rating                Date  \
# 0       Wayan Gita       1 2023-08-10 13:36:28
# 1          yOga 04       1 2023-08-01 03:19:16
# 2    Muhamad Basir       1 2023-06-10 15:44:50
# 3   Erick Matahine       1 2023-06-12 07:17:25
# 4     ipin sopandi       1 2023-08-07 13:07:29
# ..             ...     ...                 ...
# 95       atvatar v       1 2023-06-06 07:14:19
# 96   bayu fernando       1 2023-07-02 12:48:57
# 97       hard Cool       5 2023-06-12 14:01:07
# 98         Yogapra       3 2023-07-11 00:58:40
# 99           Rudin       1 2023-07-08 18:38:18
#
#                                                Ulasan  \
# 0   fitur bukabantuan nggak guna aplikasi ribet ad...
# 1   aplikasi marketplace paling ancur sistem bukab...
# 2   bingung bgt mau hub cs caranya gmn mau ngaktif...
# 3   lagi asyikasyiknya nemu barang yang diincar ee...
# 4   nggak bisa komplain sudah seminggu permintaan ...
# ..                                                ...
# 95  ini voucher diskon saya beli pakai dana kok pa...
# 96  bukalapak gk pernah kasih solusi untuk pembeli...
# 97  ok terus pertahankan pelayanan yang baik dari ...
# 98  bintang   karena tidak adanya fitur live chat ...
# 99  tolong ditingkatkan fitur live chat nya dan ka...
#
#                                       Ulasan_tokenize  \
# 0   [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1   [aplikasi, marketplace, paling, ancur, sistem,...
# 2   [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3   [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4   [nggak, bisa, komplain, sudah, seminggu, permi...
# ..                                                ...
# 95  [ini, voucher, diskon, saya, beli, pakai, dana...
# 96  [bukalapak, gk, pernah, kasih, solusi, untuk, ...
# 97  [ok, terus, pertahankan, pelayanan, yang, baik...
# 98  [bintang, karena, tidak, adanya, fitur, live, ...
# 99  [tolong, ditingkatkan, fitur, live, chat, nya,...
#
#                                           ulasan_ears  \
# 0   [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1   [aplikasi, marketplace, paling, ancur, sistem,...
# 2   [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3   [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4   [nggak, bisa, komplain, sudah, seminggu, permi...
# ..                                                ...
# 95  [ini, voucher, diskon, saya, beli, pakai, dana...
# 96  [bukalapak, gk, pernah, kasih, solusi, untuk, ...
# 97  [ok, terus, pertahankan, pelayanan, yang, baik...
# 98  [bintang, karena, tidak, adanya, fitur, live, ...
# 99  [tolong, ditingkatkan, fitur, live, chat, dan,...
#
#                                     Ulasan_normalized
# 0   [fitur, bukabantuan, enggak, guna, aplikasi, r...
# 1   [aplikasi, marketplace, paling, hancur, sistem...
# 2   [bingung, banget, mau, hubungi, cs, caranya, b...
# 3   [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4   [enggak, bisa, komplain, sudah, seminggu, perm...
# ..                                                ...
# 95  [ini, voucher, diskon, saya, beli, pakai, dana...
# 96  [bukalapak, enggak, pernah, kasih, solusi, unt...
# 97  [ok, terus, pertahankan, pelayanan, yang, baik...
# 98  [bintang, karena, tidak, adanya, fitur, live, ...
# 99  [tolong, ditingkatkan, fitur, live, chat, nya,...
#
# [100 rows x 7 columns]

# %%
name_dataframe['Ulasan_normalized'].unique
# Out:
# <bound method Series.unique of 0       [fitur, bukabantuan, enggak, guna, aplikasi, r...
# 1       [aplikasi, marketplace, paling, hancur, sistem...
# 2       [bingung, banget, mau, hubungi, cs, caranya, b...
# 3       [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4       [enggak, bisa, komplain, sudah, seminggu, perm...
#                               ...
# 1295    [enggak, jelas, sinyal, bagus, malah, internet...
# 1296    [saya, ingin, membeli, pelatihan, prakerja, ta...
# 1297    [sangat, membantu, berjualan, dan, berbelanja,...
# 1298      [lebih, lengkap, lagi, untuk, jualan, nya, gan]
# 1299    [sangat, membantu, paylaternya, naikin, limitn...
# Name: Ulasan_normalized, Length: 1300, dtype: object>

# %% [markdown]
# # **Stop Removal**

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

name_dataframe['Ulasan_stop_removed'] = name_dataframe['Ulasan_normalized'].apply(stopwords_removal)

# %%
name_dataframe
# Out:
#                  Nama pengguna  Rating                Date  \
# 0                   Wayan Gita       1 2023-08-10 13:36:28
# 1                      yOga 04       1 2023-08-01 03:19:16
# 2                Muhamad Basir       1 2023-06-10 15:44:50
# 3               Erick Matahine       1 2023-06-12 07:17:25
# 4                 ipin sopandi       1 2023-08-07 13:07:29
# ...                        ...     ...                 ...
# 1295                 Dede Kurt       1 2023-06-15 15:26:18
# 1296  Ahlul Fakri Almuthalliby       1 2023-06-10 15:45:56
# 1297              eka jayaos46       5 2023-07-11 10:23:31
# 1298                 Hero Hero       5 2023-06-18 07:47:11
# 1299                 aris dude       5 2023-07-06 03:03:21
#
#                                                  Ulasan  \
# 0     fitur bukabantuan nggak guna aplikasi ribet ad...
# 1     aplikasi marketplace paling ancur sistem bukab...
# 2     bingung bgt mau hub cs caranya gmn mau ngaktif...
# 3     lagi asyikasyiknya nemu barang yang diincar ee...
# 4     nggak bisa komplain sudah seminggu permintaan ...
# ...                                                 ...
# 1295  ga jelas sinyal bagus malah internet tidak ter...
# 1296  saya ingin membeli pelatihan prakerja tapi tid...
# 1297  sangat membantu berjualan dan berbelanja terim...
# 1298            lebih lengkap lagi untuk jualan nya gan
# 1299   sangat membantu paylaternya naikin limitnya dong
#
#                                         Ulasan_tokenize  \
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [aplikasi, marketplace, paling, ancur, sistem,...
# 2     [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3     [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4     [nggak, bisa, komplain, sudah, seminggu, permi...
# ...                                                 ...
# 1295  [ga, jelas, sinyal, bagus, malah, internet, ti...
# 1296  [saya, ingin, membeli, pelatihan, prakerja, ta...
# 1297  [sangat, membantu, berjualan, dan, berbelanja,...
# 1298    [lebih, lengkap, lagi, untuk, jualan, nya, gan]
# 1299  [sangat, membantu, paylaternya, naikin, limitn...
#
#                                             ulasan_ears  \
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [aplikasi, marketplace, paling, ancur, sistem,...
# 2     [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3     [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4     [nggak, bisa, komplain, sudah, seminggu, permi...
# ...                                                 ...
# 1295  [ga, jelas, sinyal, bagus, malah, internet, ti...
# 1296  [saya, ingin, membeli, pelatihan, prakerja, ta...
# 1297  [sangat, membantu, berjualan, dan, berbelanja,...
# 1298         [lebih, lengkap, lagi, untuk, jualan, gan]
# 1299  [sangat, membantu, paylaternya, naikin, limitn...
#
#                                       Ulasan_normalized  \
# 0     [fitur, bukabantuan, enggak, guna, aplikasi, r...
# 1     [aplikasi, marketplace, paling, hancur, sistem...
# 2     [bingung, banget, mau, hubungi, cs, caranya, b...
# 3     [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4     [enggak, bisa, komplain, sudah, seminggu, perm...
# ...                                                 ...
# 1295  [enggak, jelas, sinyal, bagus, malah, internet...
# 1296  [saya, ingin, membeli, pelatihan, prakerja, ta...
# 1297  [sangat, membantu, berjualan, dan, berbelanja,...
# 1298    [lebih, lengkap, lagi, untuk, jualan, nya, gan]
# 1299  [sangat, membantu, paylaternya, naikin, limitn...
#
#                                     Ulasan_stop_removed
# 0     [fitur, bukabantuan, aplikasi, ribet, saldo, d...
# 1     [aplikasi, marketplace, hancur, sistem, bukaba...
# 2     [bingung, banget, hubungi, cs, ngaktifin, fitu...
# 3     [asyikasyiknya, nemu, barang, diincar, eh, mun...
# 4     [komplain, seminggu, permintaan, pencairan, da...
# ...                                                 ...
# 1295              [sinyal, bagus, internet, tersambung]
# 1296  [membeli, pelatihan, prakerja, memilih, jadwal...
# 1297  [membantu, berjualan, berbelanja, terima, kasi...
# 1298                        [lengkap, jualan, nya, gan]
# 1299          [membantu, paylaternya, naikin, limitnya]
#
# [1300 rows x 8 columns]

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
pip install swifter
# Out:
# Collecting swifter
#   Downloading swifter-1.4.0.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (1.5.3)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.10/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2023.8.0)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (4.66.1)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (23.1)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (1.23.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask[dataframe]>=2.10.0->swifter) (3.16.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->swifter) (1.16.0)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.4.0-py3-none-any.whl size=16505 sha256=e5a66719a979252cc6aef33a8fa05f5b8bfadd6aadbf4dba947a7a97754c02d2
#   Stored in directory: /root/.cache/pip/wheels/e4/cf/51/0904952972ee2c7aa3709437065278dc534ec1b8d2ad41b443
# Successfully built swifter
# Installing collected packages: swifter
# Successfully installed swifter-1.4.0

# %% [markdown]
# # **Stemming**

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in name_dataframe['Ulasan_stop_removed']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '

print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])

print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

name_dataframe['Ulasan_Stemmed'] = name_dataframe['Ulasan_stop_removed'].swifter.apply(get_stemmed_term)
# Out:
# 4460
# ------------------------
# fitur : fitur
# bukabantuan : bukabantuan
# aplikasi : aplikasi
# ribet : ribet
# saldo : saldo
# dipakai : pakai
# cairin : cairin
# transfer : transfer
# banget : banget
# password : password
# dibilang : bilang
# salah : salah
# riset : riset
# dikit : dikit
# selesai : selesai
# notifikasi : notifikasi
# sistem : sistem
# eror : eror
# sih : sih
# marketplace : marketplace
# hancur : hancur
# selesain : selesain
# lari : lari
# live : live
# chatnya : chatnya
# paylaternya : paylaternya
# bobrok : bobrok
# silakan : sila
# dicoba : coba
# download : download
# tau : tau
# bingung : bingung
# hubungi : hubung
# cs : cs
# ngaktifin : ngaktifin
# chat : chat
# mengasih : asih
# feedback : feedback
# aktif : aktif
# lihat : lihat
# transaksi : transaksi
# pembelian : beli
# klik : klik
# tertulis : tulis
# gangguan : ganggu
# coba : coba
# email : email
# terkirim : kirim
# tlol : tlol
# asyikasyiknya : asyikasyiknya
# nemu : nemu
# barang : barang
# diincar : incar
# eh : eh
# muncul : muncul
# popupiklan : popupiklan
# buka : buka
# emas : emas
# dimana : mana
# mengganggu : ganggu
# close : close
# masuk : masuk
# menu : menu
# beranda : beranda
# beli : beli
# deh : deh
# tokopedia : tokopedia
# shopee : shopee
# belanja : belanja
# kedepan : depan
# banyakan : banyak
# popup : popup
# jujur : jujur
# uninstal : uninstal
# komplain : komplain
# seminggu : minggu
# permintaan : minta
# pencairan : cair
# dana : dana
# rekening : rekening
# pribadi : pribadi
# berhasil : hasil
# tolong : tolong
# kerjasamanya : kerjasamanya
# aktifkan : aktif
# bukabantuannya : bukabantuannya
# next : next
# bintangnya : bintang
# diubah : ubah
# update : update
# suka : suka
# error : error
# cepat : cepat
# errorbarusan : errorbarusan
# turun : turun
# notif : notif
# tagihan : tagih
# hilang : hilang
# pembayaran : bayar
# besok : besok
# bintang : bintang
# dibuka : buka
# tanggal : tanggal
# juni : juni
# pagi : pagi
# malam : malam
# cek : cek
# detail : detail
# pesanan : pesan
# terbayar : bayar
# mantap : mantap
# kalo : kalo
# paket : paket
# sediakan : sedia
# foto : foto
# bukti : bukti
# pengiriman : kirim
# nyabiar : nyabiar
# oh : oh
# nya : nya
# taro : taro
# situ : situ
# kurir : kurir
# mengantarkan : antar
# alamat : alamat
# posisi : posisi
# aman : aman
# konfirmasi : konfirmasi
# mohon : mohon
# tingkat : tingkat
# bagus : bagus
# aplikasinya : aplikasi
# edit : edit
# produk : produk
# giliran : gilir
# ujung : ujung
# iklan : iklan
# dijual : jual
# alias : alias
# otomatis : otomatis
# dihapus : hapus
# bukalapak : bukalapak
# ditingkatkan : tingkat
# ulang : ulang
# sistemnya : sistem
# penjual : jual
# pembeli : beli
# meninggalkan : tinggal
# nih : nih
# order : order
# pelapak : lapak
# keterlambatan : lambat
# kesehatan : sehat
# kondisi : kondisi
# membaik : baik
# kirim : kirim
# status : status
# dibatalkan : batal
# parahnya : parah
# melaksanakan : laksana
# uangnya : uang
# refound : refound
# dirugikan : rugi
# kesel : kesel
# pemesanan : mesan
# limit : limit
# tersedia : sedia
# mengajukan : aju
# sulit : sulit
# emailnya : email
# perbaiki : baik
# mengunakan : mengunakan
# paylatter : paylatter
# terima : terima
# kasih : kasih
# diupdate : diupdate
# bug : bug
# contoh : contoh
# out : out
# dibukak : dibukak
# tulisan : tulis
# kesalahan : salah
# memantau : pantau
# pergerakan : gera
# baca : baca
# virtual : virtual
# account : account
# terverifikasi : verifikasi
# terpotong : potong
# arahanya : arahanya
# langsung : langsung
# alasan : alas
# koneksi : koneksi
# terputus : putus
# ganti : ganti
# selfilah : selfilah
# ktplah : ktplah
# mutasi : mutasi
# rekeninglah : rekening
# framelah : framelah
# kembalikan : kembali
# ditangani : tangan
# tim : tim
# menunggu : tunggu
# jam : jam
# percaya : percaya
# penjualnya : jual
# respon : respon
# pembelinya : bel
# mengirim : kirim
# rugi : rugi
# dianggap : anggap
# kali : kali
# menerima : terima
# bl : bl
# mbulet : mbulet
# apk : apk
# rugikan : rugi
# internet : internet
# masukmasuk : masukmasuk
# tertulisnya : tulis
# bayar : bayar
# lamalama : lamalama
# kecewa : kecewa
# diperbaiki : baik
# paylater : paylater
# atm : atm
# laporan : lapor
# kemarin : kemarin
# cari : cari
# nomor : nomor
# dihubungi : hubung
# google : google
# penipuan : tipu
# telfon : telfon
# ya : ya
# hun : hun
# telepon : telepon
# kolom : kolom
# tanggapan : tanggap
# menyenangkan : senang
# sayalive : sayalive
# susahyang : susahyang
# melayani : layan
# robot : robot
# terusni : terusni
# perusahaan : usaha
# warung : warung
# kelontongan : kelontong
# sihminta : sihminta
# bantuan : bantu
# susahmasa : susahmasa
# pakai : pakai
# datacuma : datacuma
# seharga : harga
# anmasa : anmasa
# tahangawat : tahangawat
# iniklo : iniklo
# mendadak : dadak
# kehabisan : habis
# datagimana : datagimana
# tuh : tuh
# parah : parah
# bangettolong : bangettolong
# inikarena : inikarena
# kebutuhan : butuh
# kamiuang : kamiuang
# tahan : tahan
# jelek : jelek
# penarikan : tari
# dompet : dompet
# proses : proses
# pengaduan : adu
# slow : slow
# duit : duit
# susahnya : susah
# menghubungi : hubung
# terkait : kait
# langganan : langgan
# difavoritkan : favorit
# searching : searching
# rubah : rubah
# berguna : guna
# penjualan : jual
# dikirim : kirim
# wahana : wahana
# resi : resi
# batal : batal
# dicek : cek
# manual : manual
# perjalanan : jalan
# voucher : voucher
# gratis : gratis
# ongkir : ongkir
# biaya : biaya
# tambahan : tambah
# dirinci : dirinci
# pelacakan : lacak
# diantar : antar
# dikasih : kasih
# penerima : terima
# cod : cod
# keterima : terima
# diberitahu : diberitahu
# semoga : moga
# kedepannya : depan
# tanggap : tanggap
# memiliki : milik
# kompeten : kompeten
# payah : payah
# susah : susah
# ampun : ampun
# mencoba : coba
# kaitin : kaitin
# akun : akun
# gagal : gagal
# aneh : aneh
# diakun : akun
# terikat : ikat
# bukalapaknya : bukalapaknya
# bukapaylater : bukapaylater
# iya : iya
# layanan : layan
# mahal : mahal
# lipat : lipat
# dibanding : banding
# lakukan : laku
# mengadakan : ada
# diskon : diskon
# plus : plus
# jdiny : jdiny
# mengerikan : keri
# diangap : diangap
# penjahat : jahat
# main : main
# bekukan : beku
# orang : orang
# kredivo : kredivo
# dibekukan : beku
# akulaku : akulaku
# hati : hati
# sayang : sayang
# mending : mending
# toped : toped
# nyaman : nyaman
# minim : minim
# jahat : jahat
# maaftidak : maaftidak
# rekomendasi : rekomendasi
# kena : kena
# berbicara : bicara
# pengalaman : alam
# kagak : kagak
# pelatihan : latih
# prakerja : prakerja
# vocer : vocer
# valid : valid
# kontak : kontak
# diperbaharui : baharu
# jadwal : jadwal
# ridem : ridem
# sungguh : sungguh
# menyambung : sambung
# menyesal : sesal
# bertransaksi : transaksi
# ulasan : ulas
# biar : biar
# komplen : komplen
# csbarang : csbarang
# kurim : rim
# returdi : returdi
# jasa : jasa
# terusan : terus
# veritifikasi : veritifikasi
# sandinya : sandi
# daftar : daftar
# sandi : sandi
# tulisannya : tulis
# serbu : serbu
# meleset : meleset
# habis : habis
# uang : uang
# roda : roda
# putar : putar
# mentooog : mentooog
# potongan : potong
# keren : keren
# sayangtidak : sayangtidak
# bonus : bonus
# saran : saran
# hadiah : hadiah
# penghargaan : harga
# pelanggan : langgan
# pindah : pindah
# shoopee : shoopee
# janjinya : janji
# nyatasudah : nyatasudah
# diakui : aku
# member : member
# platinum : platinum
# estimasi : estimasi
# melenceng : lenceng
# kupon : kupon
# promo : promo
# keamanan : aman
# sok : sok
# far : far
# good : good
# tingkatkan : tingkat
# kenyamanan : nyaman
# membantusaat : membantusaat
# pulsatoken : pulsatoken
# listrik : listrik
# mengatasi : atas
# andalkan : andal
# cepatsemua : cepatsemua
# teratasi : atas
# memuaskanmaju : memuaskanmaju
# inovatif : inovatif
# membantu : bantu
# depantapi : depantapi
# admin : admin
# ribu : ribu
# bulannya : bulan
# pakaiklo : pakaiklo
# ilangin : ilangin
# yalimit : yalimit
# bos : bos
# memperaulitcall : memperaulitcall
# center : center
# terkesan : kes
# malas : malas
# menanggapi : tanggap
# keluhan : keluh
# pelanggansemua : pelanggansemua
# persyaratan : syarat
# dibpenuhichat : dibpenuhichat
# alihkanni : alihkanni
# bantuanmemalukan : bantuanmemalukan
# bermasalahga : bermasalahga
# pertqma : pertqma
# pertamani : taman
# kemari : kemari
# parahcall : parahcall
# centernya : centernya
# nihbuat : nihbuat
# rp : rp
# top : top
# up : up
# bayarkan : bayar
# via : via
# bri : bri
# struk : struk
# berhenti : henti
# merugikan : rugi
# masak : masak
# barangnya : barang
# dibayar : bayar
# nunggunya : nunggunya
# dikembalikan : kembali
# rbuan : rbuan
# bermutu : mutu
# komplin : komplin
# diblokir : blokir
# halaman : halaman
# pemakai : pakai
# super : super
# seller : seller
# kuota : kuota
# dagangan : dagang
# jualannya : jual
# antik : antik
# unik : unik
# quota : quota
# diketerangan : terang
# promosi : promosi
# toko : toko
# sebelah : belah
# bodoh : bodoh
# mewajibkan : wajib
# tolol : tolol
# kebobolan : bobol
# pengajuan : aju
# nakal : nakal
# ditambah : tambah
# bantun : bantun
# bertambah : tambah
# mudah : mudah
# repot : repot
# rumah : rumah
# lancar : lancar
# oye : oye
# ketemu : ketemu
# abal : abal
# menipu : tipu
# lapak : lapak
# tangan : tangan
# menyelamatkan : selamat
# juta : juta
# terselamatkan : selamat
# muter : muter
# bermasalah : masalah
# sebulan : bulan
# ditahan : tahan
# diteruskan : terus
# tekan : tekan
# tombol : tombol
# dananya : dana
# oper : oper
# kekurangan : kurang
# lambat : lambat
# kelalaian : lalai
# bandingkan : banding
# duluan : duluan
# bersaing : saing
# kompetitor : kompetitor
# setting : setting
# maps : maps
# refresh : refresh
# mengulangi : ulang
# kebanyakan : banyak
# informasi : informasi
# ekspedisi : ekspedisi
# bukasend : bukasend
# terpaksa : paksa
# mengurus : urus
# refund : refund
# apapun : apa
# dicairin : dicairin
# nominalnya : nominal
# topup : topup
# ikhlasin : ikhlasin
# token : token
# melalu : lalu
# verifikasi : verifikasi
# dibantu : bantu
# dipersulit : sulit
# permainan : main
# kah : kah
# mengambil : ambil
# hak : hak
# miliknya : milik
# pikir : pikir
# pln : pln
# byar : byar
# kadarluarsa : kadarluarsa
# diarahkan : arah
# artikel : artikel
# menulis : tulis
# persulit : sulit
# ditemukanmakin : ditemukanmakin
# heran : heran
# tidka : tidka
# mengerti : erti
# prihal : prihal
# payleter : payleter
# enggak bisa : enggak bisa
# batalkan : batal
# pesan : pesan
# mentok : mentok
# minggu : minggu
# macet : macet
# enggak ada : enggak ada
# oernah : oernah
# disediain : ain
# komplan : komplan
# benahi : benah
# sinyal : sinyal
# jatuh : jatuh
# tempo : tempo
# naikyg : naikyg
# mode : mode
# aga : aga
# berbelanja : belanja
# permanen : permanen
# pemakaian : pakai
# beralih : alih
# shoppy : shoppy
# mengaco : aco
# favorit : favorit
# search : search
# kemana : mana
# item : item
# maaf : maaf
# pesananselalu : pesananselalu
# tulusan : tulus
# lacak : lacak
# nomer : nomer
# instal : instal
# paketnya : paket
# nyampek : nyampek
# sekian : sekian
# berat : berat
# serasa : serasa
# ditipu : tipu
# ekspres : ekspres
# kerja : kerja
# peniriman : peniriman
# bertanggung : tanggung
# kerugian : rugi
# materi : materi
# semenjak : semenjak
# upgrade : upgrade
# call : call
# canter : canter
# bantuannya : bantu
# mencewakan : mencewakan
# permasalahan : masalah
# selsai : selsai
# kacau : kacau
# benarbenar : benarbenar
# retur : retur
# kode : kode
# otp : otp
# memasukkan : masuk
# disuruh : suruh
# belikan : belikan
# pulsa : pulsa
# pantesan : pantesan
# merosot : merosot
# tukang : tukang
# nipu : nipu
# program : program
# diproses : proses
# terhubung : hubung
# bilang : bilang
# kejebak : jebak
# bukalapakudah : bukalapakudah
# cekout : cekout
# payment : payment
# selesaitapidi : selesaitapidi
# nyaakhirnya : nyaakhirnya
# kemanaudah : kemanaudah
# hubungin : hubungin
# sesuai : sesuai
# sedikitkecewa : sedikitkecewa
# sedih : sedih
# mitra : mitra
# efisien : efisien
# dibandingkan : banding
# merk : merk
# alternatif : alternatif
# pt : pt
# mengakuisisi : akuisisi
# statusnya : status
# berubah : ubah
# brisaldo : brisaldo
# kepotong : potong
# bayarparah : bayarparah
# ajaudh : ajaudh
# kadaluarsa : kadaluarsa
# untung : untung
# doang : doang
# cuihhh : cuihhh
# smartphone : smartphone
# membuka : buka
# kepala : kepala
# pusing : pusing
# layoutnya : layoutnya
# berantakan : beranta
# xxx : xxx
# tampilan : tampil
# ponsel : ponsel
# aksesoris : aksesoris
# suku : suku
# cadang : cadang
# dll : dll
# penantan : penantan
# produknya : produk
# tampilkan : tampil
# rapi : rapi
# rekan : rekan
# bosan : bosan
# jenuh : jenuh
# melanjutkan : lanjut
# kesini : kesini
# seler : seler
# setatus : setatus
# kadang : kadang
# pembatalan : batal
# pemberitahuan : pemberitahuan
# tiktok : tiktok
# mah : mah
# halo : halo
# melampaui : lampau
# batas : batas
# membatalkan : batal
# dihubungichat : dihubungichat
# tokoselernya : tokoselernya
# pencerahannya : cerah
# ku : ku
# juli : juli
# rupa : rupa
# hitung : hitung
# gandakan : ganda
# pintar : pintar
# rekom : rekom
# pengguna : guna
# ppob : ppob
# pokok : pokok
# turunkan : turun
# satusaya : satusaya
# kenakan : kena
# biyaya : biyaya
# bulanan : bulan
# anehjelas : anehjelas
# knapa : knapa
# sekalimohon : sekalimohon
# cashback : cashback
# jualan : jual
# sepi : sepi
# online : online
# lengkap : lengkap
# ktp : ktp
# infonya : info
# verifikasigak : verifikasigak
# upload : upload
# lemot : lot
# mencuri : curi
# pelayanan : layan
# pin : pin
# hape : hape
# bajak : bajak
# pembajak : bajak
# kebawah : bawah
# senang : senang
# ijo : ijo
# ayo : ayo
# inovasiinovasi : inovasiinovasi
# kalah : kalah
# hatihati : hatihati
# bekuin : bekuin
# baiknya : baik
# jalan : jalan
# loh : loh
# tertinggal : tinggal
# pedagang : dagang
# tersambung : sambung
# tibatiba : tibatiba
# game : game
# memperpanjang : panjang
# umur : umur
# gulung : gulung
# tikar : tikar
# kayak : kayak
# platform : platform
# jual : jual
# nyamantidak : nyamantidak
# bukalapakselain : bukalapakselain
# mahalada : mahalada
# bebankanmending : bebankanmending
# benermending : benermending
# tujuansudah : tujuansudah
# jamannya : jaman
# dibukalapak : dibukalapak
# cancel : cancel
# stok : stok
# habisdan : habisdan
# berdasarkan : dasar
# info : info
# tolonglah : tolong
# suruh : suruh
# muat : muat
# trakhir : trakhir
# uninstall : uninstall
# apknya : apknya
# min : min
# data : data
# verifikasinya : verifikasi
# maksimal : maksimal
# keteranganya : keteranganya
# hp : hp
# berbeda : beda
# memblokir : blokir
# mengatasnamakan : mengatasnamakan
# takut : takut
# disalahgunakan : disalahgunakan
# akses : akses
# memeberikan : memeberikan
# solusi : solusi
# buruk : buruk
# lunasi : lunas
# pakaitrus : pakaitrus
# temponya : tempo
# lansung : lansung
# segitu : segitu
# blapak : blapak
# namanya : nama
# berfungsi : fungsi
# login : login
# bikin : bikin
# jarang : jarang
# harga : harga
# sd : sd
# metode : metode
# bank : bank
# ocbc : ocbc
# nisp : nisp
# lwh : lwh
# pilihan : pilih
# kekelasan : kelas
# tutup : tutup
# orderan : order
# ajukan : aju
# whatsapp : whatsapp
# payletter : payletter
# rbbaru : rbbaru
# kalieeeengga : kalieeeengga
# lagiwk : lagiwk
# wkkok : wkkok
# yabl : yabl
# pengirimannyahrs : pengirimannyahrs
# perbaikan : baik
# kurangnya : kurang
# dipromo : dipromo
# terimakasih : terimakasih
# utakatik : utakatik
# penipu : tipu
# beda : beda
# lazada : lazada
# shoppe : shoppe
# pencarian : cari
# menampilkan : tampil
# onderdilpart : onderdilpart
# pretelan : pretel
# ketik : ketik
# mesin : mesin
# cuci : cuci
# onderdil : onderdil
# kurangi : kurang
# evaluasi : evaluasi
# inimungkin : inimungkin
# option : option
# tersendiri : sendiri
# part : part
# ongkos : ongkos
# tetapkan : tetap
# expedisinya : expedisinya
# ditunda : tunda
# pengirimannya : kirim
# ngambil : ngambil
# profesional : profesional
# kerjanya : kerja
# post : post
# poto : poto
# ditokopedia : ditokopedia
# poduk : poduk
# brng : brng
# seperri : seperri
# seblum : seblum
# ramai : ramai
# un : un
# install : install
# shopeelazada : shopeelazada
# bukalapakakin : bukalapakakin
# erorr : erorr
# sekalinya : sekali
# penjawab : jawab
# tanggung : tanggung
# sengaja : sengaja
# makan : makan
# gaji : gaji
# buta : buta
# customer : customer
# mundur : mundur
# non : non
# aktifsaya : aktifsaya
# aktiftoko : aktiftoko
# systemnya : systemnya
# maintenance : maintenance
# mengecek : ecek
# wajar : wajar
# penagihan : tagih
# lunas : lunas
# aduh : aduh
# gercep : gercep
# nyambing : nyambing
# digital : digital
# diuntungkan : untung
# mewq : mewq
# iinv : iinv
# berkurang : kurang
# keterangan : terang
# sialnya : sial
# besoknya : besok
# anjir : anjir
# kuotanya : kuota
# diskonnya : diskon
# balikin : balikin
# vouchernya : vouchernya
# pembelikomplain : pembelikomplain
# bisatpi : bisatpi
# jasalancar : jasalancar
# motong : motong
# masalahpasti : masalahpasti
# komplainblm : komplainblm
# ok : ok
# pertahankan : tahan
# siang : siang
# kecamatan : camat
# mudahan : mudah
# livechat : livechat
# dikhususkan : khusus
# ketinggalan : tinggal
# olshop : olshop
# kemudahan : mudah
# customernya : customernya
# dimudahkan : mudah
# mengganti : ganti
# gmail : gmail
# sajah : sajah
# seharian : hari
# dijemput : jemput
# dichat : dichat
# mengecewakan : kecewa
# barangbarang : barangbarang
# oke : oke
# ongkirn : ongkirn
# codnya : codnya
# dibatasin : dibatasin
# belnja : belnja
# ratusan : ratus
# mendapati : dapat
# grtis : grtis
# ongkirnya : ongkirnya
# oren : oren
# berkedok : kedok
# kapok : kapok
# lapor : lapor
# bergantung : gantung
# lucu : lucu
# sebenar : benar
# cth : cth
# ambil : ambil
# bareng : bareng
# hrg : hrg
# san : san
# jutaan : juta
# asli : asli
# bohongan : bohong
# bebayar : bebayar
# sebutin : sebutin
# complain : complain
# berteletele : berteletele
# layani : layan
# penukaran : tukar
# ceria : ceria
# konfirmasitapi : konfirmasitapi
# selepas : lepas
# mendesakharusnya : mendesakharusnya
# kembalibagaimanapun : kembalibagaimanapun
# konsumen : konsumen
# bldah : bldah
# ulangi : ulang
# samatapi : samatapi
# lapakbarang : lapakbarang
# otomatislapor : otomatislapor
# penjualpenjual : penjualpenjual
# nyuruh : nyuruh
# terimabarang : terimabarang
# ditransfer : transfer
# bukannkesalahan : bukannkesalahan
# pembelibeda : pembelibeda
# dngn : dngn
# diterima : terima
# estimadi : estimadi
# kembalibenar : kembalibenar
# puas : puas
# gunakanhabis : gunakanhabis
# hilangkan : hilang
# tulis : tulis
# belaku : bela
# berbelitstatus : berbelitstatus
# diiterima : diiterima
# terkirimhati : terkirimhati
# bukalapakbaru : bukalapakbaru
# alami : alami
# apl : apl
# sngat : sngat
# terbukti : bukti
# dibeli : beli
# gambar : gambar
# video : video
# deskripsinya : deskripsi
# sukses : sukses
# indonesia : indonesia
# chattidak : chattidak
# kendala : kendala
# pertanyataan : pertanyataan
# disediakan : sedia
# user : user
# mengirimkan : kirim
# diupload : diupload
# diberubah : ubah
# tersaingi : saing
# mesti : mesti
# seenak : enak
# ubah : ubah
# stoknya : stok
# melanggar : langgar
# tersebutdan : tersebutdan
# photo : photo
# hasil : hasil
# ciplakmakin : ciplakmakin
# menurun : turun
# aplakasi : aplakasi
# okee : okee
# enggak jelas : enggak jelas
# emosi : emosi
# kedaftargimana : kedaftargimana
# maksutnya : maksutnya
# pulahadehbikin : pulahadehbikin
# sajaauto : sajaauto
# delete : delete
# belanjanya : belanja
# gampang : gampang
# bayarnya : bayar
# livechatnya : livechatnya
# dilunasi : lunas
# telat : telat
# bukajadinya : bukajadinya
# kitapd : kitapd
# bayarsdh : bayarsdh
# transfergimana : transfergimana
# gantian : ganti
# merasakan : rasa
# rasakan : rasa
# menyalahkan : salah
# pro : pro
# partai : partai
# rakyatlagi : rakyatlagi
# ruwt : ruwt
# ruwet : ruwet
# buang : buang
# iklanhasilnya : iklanhasilnya
# manfaatatnya : manfaatatnya
# satupuntidak : satupuntidak
# laku : laku
# fakta : fakta
# mengecewa : kecewa
# arah : arah
# mengetik : etik
# no : no
# initapi : initapi
# memuaskan : muas
# kualitas : kualitas
# pesenan : sen
# menylelesaikan : menylelesaikan
# jawabannya : jawab
# peasana : peasana
# sesuaipembeli : sesuaipembeli
# membayar : bayar
# pengembalianpadahal : pengembalianpadahal
# penjualdimana : penjualdimana
# servis : servis
# handphonerugi : handphonerugi
# waktuuang : waktuuang
# perangkatnya : perangkat
# kelartolong : kelartolong
# perhatikan : perhati
# sesiusterima : sesiusterima
# transaksierror : transaksierror
# perbaikitidak : perbaikitidak
# bis : bis
# histori : histori
# barangthanks : barangthanks
# harapkan : harap
# penambahan : tambah
# berhak : hak
# cocok : cocok
# lumayan : lumayan
# nasabah : nasabah
# urgent : urgent
# normal : normal
# memudahkan : mudah
# calon : calon
# mencari : cari
# dibutuhkan : butuh
# produsen : produsen
# mempromosikan : promosi
# terkendala : kendala
# jauhnya : jauh
# lokasi : lokasi
# dibukakapak : dibukakapak
# relatif : relatif
# murah : murah
# mall : mall
# kaki : kaki
# caranyaini : caranyaini
# haridigunain : haridigunain
# bisacoba : bisacoba
# jelaskansampe : jelaskansampe
# ditagih : tagih
# bukalapaksedangkan : bukalapaksedangkan
# gagalaneh : gagalaneh
# pemesanansaya : pemesanansaya
# tertipu : tipu
# store : store
# kecewasaya : kecewasaya
# total : total
# kejadian : jadi
# inibukalapak : inibukalapak
# jaringanlah : jaring
# jaringan : jaring
# full : full
# mon : mon
# nonaktifkan : nonaktif
# aktip : aktip
# akunku : akun
# perasaan : asa
# langgar : langgar
# device : device
# gonta : gonta
# aseli : aseli
# kecuali : kecuali
# pajangan : pajang
# sensitif : sensitif
# kerenfitur : kerenfitur
# komplit : komplit
# kirimdan : kirimdan
# mudahsemoga : mudahsemoga
# depannya : depan
# simpel : simpel
# pembeligood : pembeligood
# luck : luck
# diklik : klik
# kompak : kompak
# fungsi : fungsi
# dinonaktifkan : nonaktif
# tindak : tindak
# developer : developer
# pengaturan : atur
# ajakarna : ajakarna
# butuhkan : butuh
# bataldan : bataldan
# rumit : rumit
# market : market
# buyer : buyer
# mulu : mulu
# bangkrut : bangkrut
# service : service
# terpakai : pakai
# mincara : mincara
# lupa : lupa
# pinseingat : pinseingat
# isi : isi
# memuaskantapi : memuaskantapi
# sayangkan : sayang
# tinggal : tinggal
# banda : banda
# acehdi : acehdi
# mencapai : capai
# perkilonyapadahal : perkilonyapadahal
# semahal : mahal
# itupaling : itupaling
# an : an
# acehmohon : acehmohon
# pertimbangan : timbang
# acehmaunya : acehmaunya
# aceh : aceh
# inibelakangan : inibelakangan
# daerah : daerah
# sampainyadicoba : sampainyadicoba
# terusongkir : terusongkir
# bukaekpress : bukaekpress
# berattidak : berattidak
# jelaspercuma : jelaspercuma
# limite : limite
# transaksinyesel : transaksinyesel
# belanjajelas : belanjajelas
# sekaliperdetik : sekaliperdetik
# uninstalmakasih : uninstalmakasih
# sayabagi : sayabagi
# digitalpelapak : digitalpelapak
# curang : curang
# terimacobalah : terimacobalah
# komplainsampai : komplainsampai
# teruskan : terus
# pelapakbats : pelapakbats
# pengembalian : kembali
# berjalanterus : berjalanterus
# nyalewat : nyalewat
# shopbelanja : shopbelanja
# pengaduanonline : pengaduanonline
# kenakalan : nakal
# pelapakseller : pelapakseller
# rentan : rentan
# venus : venus
# shop : shop
# on : on
# pengadua : pengadua
# sibuka : sibuka
# lapaknya : lapak
# tetangga : tetangga
# serviceny : serviceny
# bliblihari : bliblihari
# bijak : bijak
# berisiko : risiko
# alhamdulillah : alhamdulillah
# menambah : tambah
# terima kasih : terima kasih
# kecewasejauh : kecewasejauh
# menggaet : gaet
# minat : minat
# diturunkan : turun
# deskripsi : deskripsi
# screenshoot : screenshoot
# ditutup : tutup
# kurasi : kuras
# kategori : kategori
# serepes : repes
# terlanjur : lanjur
# kelain : lain
# hatikayaknya : hatikayaknya
# rejeki : rejeki
# voucer : voucer
# berkalikali : berkalikali
# historikalaupun : historikalaupun
# thok : thok
# penambahanknpa : penambahanknpa
# kwalitas : kwalitas
# tokoh : tokoh
# sayasy : sayasy
# nyabintang : nyabintang
# dilapak : lapak
# kiriman : kirim
# nyangkut : nyangkut
# expedisi : expedisi
# berkali : kali
# ditelusuri : telusur
# sakit : sakit
# sembuhnya : sembuh
# datangnya : datang
# separo : paro
# charge : charge
# keberuntungan : untung
# puter : puter
# money : money
# tiket : tiket
# kereta : kereta
# api : api
# orange : orange
# koid : koid
# perubahan : ubah
# kawan : kawan
# diskusi : diskusi
# cenderung : cenderung
# korban : korban
# pertimbangkan : timbang
# terdaftar : daftar
# kocak : kocak
# mudahpengiriman : mudahpengiriman
# cepatqualitas : cepatqualitas
# hargasaya : hargasaya
# jaya : jaya
# andalan : andal
# penggunanya : guna
# responya : responya
# kak : kak
# form : form
# file : file
# format : format
# xml : xml
# nanyain : nanyain
# komentar : komentar
# refundnya : refundnya
# konplain : konplain
# komplainnya : komplain
# ecommerce : ecommerce
# pembiayaan : biaya
# penuh : penuh
# jebakan : jebak
# saing : saing
# sekalichat : sekalichat
# bisaenakan : bisaenakan
# chip : chip
# shoppee : shoppee
# benerin : benerin
# tunggu : tunggu
# telusur : telusur
# kunci : kunci
# merek : merek
# official : official
# brand : brand
# gue : gue
# log : log
# tertera : tera
# ah : ah
# setia : setia
# back : back
# bisabolak : bisabolak
# ajatolong : ajatolong
# lapakbisa : lapakbisa
# kelar : kelar
# bolak : bolak
# blk : blk
# dikirm : dikirm
# nyampai : nyampai
# sayagak : sayagak
# aktiv : aktiv
# sangatembantu : sangatembantu
# melacak : lacak
# experssya : experssya
# kulir : kulir
# kekurangannya : kurang
# lunaspaylater : lunaspaylater
# apapunselalu : apapunselalu
# berhari : hari
# tersambungjawaban : tersambungjawaban
# agen : agen
# sibuk : sibuk
# parahpayah : parahpayah
# pbb : pbb
# koreksi : koreksi
# nge : nge
# freeze : freeze
# kompatible : kompatible
# android : android
# hadehh : hadehh
# adil : adil
# kga : kga
# komponen : komponen
# story : story
# pending : pending
# kaitkan : kait
# terpilih : pilih
# seru : seru
# sebu : sebu
# nyata : nyata
# kirimkan : kirim
# serbuan : serbu
# penyelesaian : selesai
# bukalapaksangat : bukalapaksangat
# bertele : tele
# bermacammacam : bermacammacam
# selamat : selamat
# terhormat : hormat
# pusat : pusat
# mengabaikan : abai
# balasan : balas
# tlpn : tlpn
# angkat : angkat
# seluler : seluler
# pengaduannya : adu
# digunaakan : digunaakan
# capek : capek
# fungsinya : fungsi
# kantor : kantor
# diperlakukan : laku
# kosong : kosong
# nancep : nancep
# tarik : tarik
# penjelasan : jelas
# tertahan : tahan
# kapandulu : kapandulu
# pembatalansekarang : pembatalansekarang
# hilangapk : hilangapk
# puyeng : puyeng
# berfungsisy : berfungsisy
# butuh : butuh
# ajuin : ajuin
# komplainada : komplainada
# diarahin : diarahin
# pembatalanpengembalian : pembatalanpengembalian
# payahmenyulitkan : payahmenyulitkan
# kentut : kentut
# ngikngung : ngikngung
# betah : betah
# pelayanannya : layan
# beberapakali : beberapakali
# pengin : pengin
# kehilangan : hilang
# kpotong : kpotong
# link : link
# bkti : bkti
# trnper : trnper
# dipesen : sen
# pelru : pelru
# perbaikian : perbaikian
# anjurin : anjurin
# pinjol : pinjol
# hadeuhhhhh : hadeuhhhhh
# bebas : bebas
# menarik : tarik
# buatkan : buat
# gkjelasudah : gkjelasudah
# spaylater : spaylater
# tidaksuruh : tidaksuruh
# wajahudah : wajahudah
# diverifikasi : verifikasi
# muka : muka
# jelastetap : jelastetap
# buramgakjeas : buramgakjeas
# gua : gua
# cair : cair
# allah : allah
# membalas : balas
# kelecikan : leci
# arahan : arah
# wkwkwk : wkwkwk
# vritualacount : vritualacount
# tagihansusah : tagihansusah
# jadinyagimana : jadinyagimana
# adapas : adapas
# agustussaya : agustussaya
# adatolong : adatolong
# servive : servive
# ditanggapin : ditanggapin
# uangku : uang
# stiker : stiker
# dikelompokkan : kelompok
# vareasi : vareasi
# motormobil : motormobil
# sekelas : kelas
# keuntungan : untung
# dipertimbangkan : timbang
# danakenapa : danakenapa
# penarikannya : tari
# bangetharus : bangetharus
# danapoto : danapoto
# rekam : rekam
# wajah : wajah
# minknp : minknp
# tab : tab
# jualbeli : jualbeli
# persaingan : saing
# ketat : ketat
# ytpinmnrt : ytpinmnrt
# akubukalapak : akubukalapak
# mnjadinyg : mnjadinyg
# terbaik : baik
# terdepansemoga : terdepansemoga
# kdp : kdp
# ybukalapak : ybukalapak
# berkembang : kembang
# maju : maju
# segi : segi
# pelayananpioritaskn : pelayananpioritaskn
# yagar : yagar
# bertransaksitrimakasih : bertransaksitrimakasih
# sellernya : sellernya
# apliksi : apliksi
# mbelgedez : mbelgedez
# express : express
# tuju : tuju
# ta : ta
# melindungi : lindung
# membantuuang : membantuuang
# trnsaksi : trnsaksi
# berhasilpulsa : berhasilpulsa
# masuktagihan : masuktagihan
# adakomplen : adakomplen
# diurus : urus
# satunya : satu
# rampog : rampog
# paraaaaaaaahhhhh : paraaaaaaaahhhhh
# mengalami : alami
# kemunduranmasa : kemunduranmasa
# cuman : cuman
# hahahhakatanya : hahahhakatanya
# menghindar : hindar
# komplainhahaha : komplainhahaha
# inisaya : inisaya
# ajak : ajak
# ngobrolhahah : ngobrolhahah
# adaklau : adaklau
# sayaklau : sayaklau
# adminnya : adminnya
# tidur : tidur
# motor : motor
# byson : byson
# alhamdulilah : alhamdulilah
# asuransi : asuransi
# kerusakan : rusa
# barangtapi : barangtapi
# rusak : rusak
# klaimnya : klaim
# ditolak : tolak
# bukalapakmending : bukalapakmending
# ajalebih : ajalebih
# terpercaya : percaya
# mahalnya : mahal
# kg : kg
# pulau : pulau
# jawa : jawa
# jembersemarang : jembersemarang
# label : label
# kantong : kantong
# bukalampak : bukalampak
# berjualan : jual
# betrasasi : betrasasi
# blanja : blanja
# bgst : bgst
# securty : securty
# checkup : checkup
# jugamasih : jugamasih
# hidup : hidup
# komplenan : komplenan
# bukatempek : bukatempek
# mahalsekarang : mahalsekarang
# turunin : turunin
# harganya : harga
# ditemuakan : tua
# kejelasan : jelas
# membeli : beli
# dirumahterimakasih : dirumahterimakasih
# srlalu : srlalu
# gagalada : gagalada
# solusinya : solusi
# tlpnya : tlpnya
# aktifsetiap : aktifsetiap
# jawabanya : jawabanya
# system : system
# apps : apps
# berkebun : kebun
# pelapaknya : lapak
# fast : fast
# kemahalan : mahal
# kreditx : kreditx
# dipindahkan : pindah
# minkhusus : minkhusus
# mengapai : kapai
# rokets : rokets
# dapatx : dapatx
# kekumpul : kumpul
# exp : exp
# menangani : tangan
# batalin : batalin
# penyakitnya : sakit
# merasai : rasai
# indak : indak
# menerus : terus
# gajelasss : gajelasss
# pelit : pelit
# costumer : costumer
# terurus : urus
# terselesaikan : selesai
# denhan : denhan
# pop : pop
# kanan : kanan
# duribu : duribu
# keliling : keliling
# manfaatin : manfaatin
# pickup : pickup
# diangkat : angkat
# ditelepon : telepon
# mati : mati
# prima : prima
# abalabal : abalabal
# disengaja : sengaja
# diseleksi : seleksi
# ready : ready
# amplop : amplop
# template : template
# dosa : dosa
# lu : lu
# menahan : tahan
# paraaaahhhh : paraaaahhhh
# kecewapesan : kecewapesan
# bukaexpress : bukaexpress
# waktueh : waktueh
# sicepat : sicepat
# halu : halu
# sepuluh : puluh
# sementarasebelum : sementarasebelum
# diterimasaya : diterimasaya
# lho : lho
# transaksasi : transaksasi
# rewelkomplain : rewelkomplain
# dibodohi : bodoh
# dibohongi : bohong
# praktisbukalapak : praktisbukalapak
# diperbanyak : banyak
# app : app
# menawarkan : tawar
# unlimited : unlimited
# sukamudah : sukamudah
# ndk : ndk
# perampok : rampok
# murahselalu : murahselalu
# free : free
# lagidulu : lagidulu
# enakpaling : enakpaling
# versi : versi
# cantumkan : cantum
# repotstatus : repotstatus
# updatedi : updatedi
# kirimpembeli : kirimpembeli
# ngomelauto : ngomelauto
# off : off
# bulanansaldo : bulanansaldo
# discount : discount
# loyal : loyal
# lamasetiajarang : lamasetiajarang
# kurirnya : kurir
# pilihannya : pilih
# terjangkau : jangkau
# ramah : ramah
# semangat : semangat
# asik : asik
# playlater : playlater
# menghubungkan : hubung
# danamohon : danamohon
# gagaluang : gagaluang
# masukan : masuk
# danacukup : danacukup
# bukalapakmalah : bukalapakmalah
# merepotkan : repot
# bermanfaat : manfaat
# diskonfaucer : diskonfaucer
# potongnya : potong
# tabungannya : tabung
# nominal : nominal
# auto : auto
# penggunaan : guna
# limitnya : limit
# sisa : sisa
# bisaslalu : bisaslalu
# otomatisketerangan : otomatisketerangan
# pembatalannya : batal
# dibatalkanseakan : dibatalkanseakan
# batalkanpadahal : batalkanpadahal
# commerce : commerce
# worth : worth
# pengecekan : kece
# sampainya : sampai
# pengembang : kembang
# halamannya : halaman
# stabil : stabil
# aplikais : aplikais
# upraged : upraged
# bisanya : bisa
# jualanannya : jualanannya
# nama : nama
# anehnya : aneh
# scrol : scrol
# smpek : smpek
# menutupi : tutup
# ongkirku : ongkirku
# dipotong : potong
# validpadahal : validpadahal
# kesal : kesal
# bst : bst
# modal : modal
# pasan : pas
# muterin : muterin
# berakibat : akibat
# truss : truss
# balesan : balesan
# sampah : sampah
# tsbt : tsbt
# matikan : mati
# mengadu : adu
# memproses : proses
# cicilan : cicil
# perbanyak : banyak
# perihal : perihal
# event : event
# bukatabungan : bukatabungan
# menggundang : gundang
# reward : reward
# left : left
# seenaknyalangsg : seenaknyalangsg
# percakapan : cakap
# percakapanjadi : percakapanjadi
# ragu : ragu
# editsaat : editsaat
# bisakalau : bisakalau
# pelosokmungkintapi : pelosokmungkintapi
# lainsaya : lainsaya
# manualtanpa : manualtanpa
# gpssaya : gpssaya
# kecewakarena : kecewakarena
# sellerseller : sellerseller
# seakan : akan
# bertanggungjawab : bertanggungjawab
# ujungnya : ujung
# lepas : lepas
# aa : aa
# bantu : bantu
# kakak : kakak
# ktpno : ktpno
# telphone : telphone
# membuktikan : bukti
# pemilik : milik
# lainemang : lainemang
# daptar : daptar
# alikasi : alikasi
# yahsangat : yahsangat
# membingungkanlangsung : membingungkanlangsung
# barusan : barusan
# bsi : bsi
# akunotp : akunotp
# sms : sms
# masukvie : masukvie
# masukbolak : masukbolak
# capca : capca
# dikomplain : komplain
# bersabar : sabar
# lion : lion
# parcel : parcel
# dibiarkan : biar
# bukalapakjasa : bukalapakjasa
# banyaksemoga : banyaksemoga
# berulangkali : berulangkali
# filter : filter
# kota : kota
# sayabarang : sayabarang
# memilikki : memilikki
# variasi : variasi
# editdihapusdiganti : editdihapusdiganti
# flash : flash
# sale : sale
# bukalapakmau : bukalapakmau
# bngetnyesel : bngetnyesel
# rek : rek
# haduhhudah : haduhhudah
# unistal : unistal
# indah : indah
# hapus : hapus
# cache : cache
# kebuka : buka
# bentar : bentar
# play : play
# wa : wa
# canggihbisa : canggihbisa
# ajakan : aja
# pokoknya : pokok
# rendah : rendah
# tagihansaya : tagihansaya
# sebagus : bagus
# dulumasa : dulumasa
# penanganan : tangan
# gliran : gliran
# sue : sue
# mhon : mhon
# minga : minga
# dilaporkan : lapor
# kementerian : menteri
# perdagangan : dagang
# masyarakat : masyarakat
# respect : respect
# jaminan : jamin
# berulang : ulang
# diam : diam
# ditempat : tempat
# inisiatif : inisiatif
# menaikkan : naik
# naikin : naikin
# superseller : superseller
# menutup : tutup
# mp : mp
# ngeluh : ngeluh
# manajemen : manajemen
# memahami : paham
# catatan : catat
# editan : edit
# puluhan : puluh
# merekomendasikan : rekomendasi
# kerabat : kerabat
# aktifin : aktifin
# diaktifkan : aktif
# ditaukan : tau
# walleteh : walleteh
# ludeskok : ludeskok
# mantab : mantab
# cepatsat : cepatsat
# set : set
# rekomendet : rekomendet
# teknik : teknik
# dm : dm
# balas : balas
# loading : loading
# ngulang : ngulang
# bernama : nama
# puji : puji
# memutuskan : putus
# sambungan : sambung
# diputuskan : putus
# berdebat : debat
# agt : agt
# pengoperasian : operasi
# praktis : praktis
# urusan : urus
# profil : profil
# des : des
# ajib : ajib
# fiturfiturnya : fiturfiturnya
# dicari : cari
# desain : desain
# layar : layar
# biru : biru
# pesanchat : pesanchat
# lapaklebih : lapaklebih
# lamaaaa : lamaaaa
# pengirim : kirim
# negeri : negeri
# terusuntuk : terusuntuk
# lamaperlu : lamaperlu
# resmi : resmi
# nyapengiriman : nyapengiriman
# melambat : lambat
# intinya : inti
# puasini : puasini
# team : team
# pelapakada : pelapakada
# solusifitur : solusifitur
# mutarmuter : mutarmuter
# pilih : pilih
# agustus : agustus
# anjer : anjer
# dibulan : bulan
# dipenjualan : jual
# bad : bad
# nyesal : nyesal
# kesekian : sekian
# kalinya : kali
# professional : professional
# buatlah : buat
# customers : customers
# connection : connection
# reset : reset
# lainys : lainys
# selesaikan : selesai
# terprogram : program
# terbaiksangat : terbaiksangat
# lapakdan : lapakdan
# place : place
# ampasss : ampasss
# bantuanya : bantuanya
# kepastian : pasti
# ampasssss : ampasssss
# mempermudah : mudah
# aplikasinyakomplit : aplikasinyakomplit
# adadan : adad
# ancurrrrr : ancurrrrr
# anehmeneruskan : anehmeneruskan
# pilapak : pilapak
# klga : klga
# kasihan : kasihan
# reseller : reseller
# binggung : binggung
# kebaikan : baik
# antrean : antre
# sebentar : sebentar
# samle : samle
# diantrean : antre
# puassssssssssssssbanget : puassssssssssssssbanget
# masukkan : masuk
# tulisanya : tulisanya
# berlaku : laku
# belanjaan : belanja
# diharapkan : harap
# terjamin : jamin
# amanah : amanah
# sadar : sadar
# guaudh : guaudh
# kenamasa : kenamasa
# ngutang : ngutang
# dobel : dobel
# dikonter : konter
# guaga : guaga
# untungyamending : untungyamending
# apldibukalapak : apldibukalapak
# payleternya : payleternya
# biayalayanan : biayalayanan
# pembeliancukup : pembeliancukup
# lagibayar : lagibayar
# kebangetan : banget
# wajib : wajib
# pushiklan : pushiklan
# sehat : sehat
# duitpun : duit
# banyakk : banyakk
# expres : expres
# leletmending : leletmending
# ajaga : ajaga
# mengurusi : urus
# expedisiapa : expedisiapa
# bekasi : bekas
# karawang : karawang
# nyampebangke : nyampebangke
# muraspantasnya : muraspantasnya
# aplikasigak : aplikasigak
# trx : trx
# terakhirgag : terakhirgag
# dahlebih : dahlebih
# bukanya : buka
# ketimbang : ketimbang
# bangetpencarian : bangetpencarian
# promonya : promonya
# merubah : rubah
# hilangakan : hilangakan
# situs : situs
# baguspengiriman : baguspengiriman
# cepatbarang : cepatbarang
# trik : trik
# modus : modus
# tiada : tiada
# berinovasi : inovasi
# semangatsemangat : semangatsemangat
# laporkan : lapor
# kepelapak : lapak
# buakalapak : buakalapak
# dasar : dasar
# maling : maling
# melulu : melulu
# kebnyakan : kebnyakan
# vocher : vocher
# ongkirapk : ongkirapk
# bukanyaa : bukanyaa
# pinjem : pinjem
# pinjaman : pinjam
# tunai : tunai
# peminatnya : minat
# bertahun : tahun
# dibenahi : benah
# kabur : kabur
# orisinal : orisinal
# semacem : semacem
# tlng : tlng
# terkaitdevelop : terkaitdevelop
# memakai : pakai
# dikecewain : dikecewain
# errorklo : errorklo
# sendiripayahudah : sendiripayahudah
# ongkirskrg : ongkirskrg
# tunggakan : tunggak
# diperparah : parah
# erornya : eror
# donwload : donwload
# ukuran : ukur
# enak : enak
# ngeprint : ngeprint
# printer : printer
# thermal : thermal
# bntuan : bntuan
# tokped : tokped
# jelekk : jelekk
# penutupan : tutup
# tanggapinnya : tanggapinnya
# formulir : formulir
# permohonan : mohon
# listriknya : listrik
# paham : paham
# aturan : atur
# iklanin : iklanin
# serius : serius
# unggul : unggul
# ngelag : ngelag
# bangkitlah : bangkit
# orenny : orenny
# membatasi : batas
# jayadan : jayadan
# taaii : taaii
# pay : pay
# later : later
# sussah : sussah
# laman : laman
# trsedia : trsedia
# mkstnya : mkstnya
# paylter : paylter
# hlaman : hlaman
# goblok : goblok
# menguntungkanyg : menguntungkanyg
# bisnis : bisnis
# tersendiridan : tersendiridan
# ifennya : ifennya
# startegi : startegi
# memancing : pancing
# bkalapak : bkalapak
# rebu : rebu
# payaater : payaater
# payater : payater
# belaja : baja
# harcur : harcur
# terys : terys
# penguna : penguna
# gifwey : gifwey
# donlowd : donlowd
# ngabisin : ngabisin
# bagusan : bagus
# terbaru : baru
# ekonomis : ekonomis
# ngisi : ngisi
# beralamat : alamat
# jauhsetidaknya : jauhsetidaknya
# membantusukses : membantusukses
# ngacoooo : ngacoooo
# packing : packing
# cepatgoodjob : cepatgoodjob
# konekai : konekai
# streaming : streaming
# youtube : youtube
# buffering : buffering
# diperbaikiaplikasi : diperbaikiaplikasi
# belanjanotifikasinya : belanjanotifikasinya
# ambang : ambang
# kehancuran : hancur
# secepatnya : cepat
# semangkin : semangkin
# padehal : padehal
# kemjuan : kemjuan
# banding : banding
# tabah : tabah
# letoy : letoy
# enakan : enak
# lada : lada
# tmbahantrus : tmbahantrus
# sepeda : sepeda
# isnawati : isnawati
# byrkan : byrkan
# penipudn : penipudn
# selektif : selektif
# memilih : pilih
# krj : krj
# gajls : gajls
# by : by
# laahh : laahh
# menuaskan : tuas
# sampainyatrims : sampainyatrims
# ajatrs : ajatrs
# trtera : trtera
# ceklis : ceklis
# satutrs : satutrs
# kmna : kmna
# disitu : situ
# pnjualy : pnjualy
# penipubkn : penipubkn
# budegpura : budegpura
# ingatanpokok : ingatanpokok
# pdagang : pdagang
# brkliaran : brkliaran
# sgr : sgr
# atasi : atas
# siiip : siiip
# tooooopp : tooooopp
# konfirm : konfirm
# sibiru : sibiru
# subsidi : subsidi
# melimpah : limpah
# briva : briva
# saldonya : saldo
# babi : babi
# tujuan : tuju
# trimakasih : trimakasih
# ngotak : ngotak
# anjink : anjink
# checkout : checkout
# tolak : tolak
# biayanya : biaya
# rban : rban
# dagang : dagang
# pasaran : pasar
# cp : cp
# of : of
# duty : duty
# mobile : mobile
# naikan : naik
# bego : bego
# gabut : gabut
# open : open
# maksimalkan : maksimal
# om : om
# mintabtolong : mintabtolong
# batalinnatau : batalinnatau
# otw : otw
# beku : beku
# akui : aku
# bukalapakmenyebabkan : bukalapakmenyebabkan
# dibekukantp : dibekukantp
# pembelanjaan : belanja
# pesananan : pesananan
# nyagara : nyagara
# gara : gara
# lunassss : lunassss
# problem : problem
# blkadang : blkadang
# wae : wae
# euy : euy
# kumaha : maha
# atuh : atuh
# outomatistapi : outomatistapi
# outomatis : outomatis
# tercancelsudah : tercancelsudah
# jawabanyasampai : jawabanyasampai
# menunggusampai : menunggusampai
# ayam : ayam
# terbang : terbang
# barukecewa : barukecewa
# sayapelapak : sayapelapak
# merespon : merespon
# compalin : compalin
# transaksinya : transaksi
# responnyaselamat : responnyaselamat
# beraktifitas : beraktifitas
# lapa : lapa
# prioritas : prioritas
# majuuuuuuu : majuuuuuuu
# aplikasikadang : aplikasikadang
# dipencarian : cari
# jalanpadahal : jalanpadahal
# normallama : normallama
# ditinggak : ditinggak
# kaya : kaya
# datengin : datengin
# omong doang : omong doang
# kerjain : kerjain
# pasword : pasword
# kiamat : kiamat
# dikecewakan : kecewa
# duanya : dua
# edannnnn : edannnnn
# lemotnya : lot
# parahhhh : parahhhh
# jaringannya : jaring
# duitnya : duit
# paitmasuk : paitmasuk
# bajaktapi : bajaktapi
# membiarkan : biar
# syyg : syyg
# orgbikin : orgbikin
# raya : raya
# the : the
# best : best
# lapakmenurut : lapakmenurut
# rekrutmen : rekrutmen
# resller : resller
# nyadan : nyadan
# cepatjk : cepatjk
# sadis : sadis
# perak : perak
# bunganya : bunga
# mencekik : cekik
# hitungannya : hitung
# perhari : hari
# nagihnya : nagihnya
# teror : teror
# jatem : jatem
# nagih : nagih
# iming : iming
# kuat : kuat
# mental : mental
# berasa : asa
# dibegoin : dibegoin
# pinjolnya : pinjolnya
# benersudah : benersudah
# goblog : goblog
# jne : jne
# updatesudah : updatesudah
# apapa : apapa
# kelas : kelas
# berlangganan : langgan
# woi : woi
# layanannya : layan
# uanggood : uanggood
# job : job
# success : success
# memaksakan : paksa
# pentingmending : pentingmending
# dah : dah
# disimpan : simpan
# utuh : utuh
# aktive : aktive
# pencerahan : cerah
# tele : tele
# playlaternya : playlaternya
# daftarnyagak : daftarnyagak
# tpln : tpln
# sopir : sopir
# rakus : rakus
# peredaran : edar
# contol : contol
# tol : tol
# tolollll : tolollll
# instan : instan
# menyelesaikan : selesai
# belanjaanya : belanjaanya
# kirimnya : kirim
# sampekalah : sampekalah
# akh : akh
# codapl : codapl
# enjoi : enjoi
# ditempatbukalapak : ditempatbukalapak
# awas : awas
# sepengetahuan : tahu
# ovo : ovo
# persyaratannya : syarat
# jadual : jadual
# dijanjikan : janji
# kemasan : kemas
# perlukandengan : perlukandengan
# simple : simple
# masuknya : masuk
# sampenya : sampenya
# responnya : responnya
# darurat : darurat
# jamin : jamin
# klianynk : klianynk
# kerjaana : kerjaana
# numpuk : numpuk
# brang : brang
# impian : impi
# ples : ples
# torrr : torrr
# belanjaehh : belanjaehh
# bataltdk : bataltdk
# ongkirdan : ongkirdan
# terbatas : batas
# rbaiki : rbaiki
# secepat : cepat
# nabung : nabung
# nabungnya : nabungnya
# sayasdh : sayasdh
# initdk : initdk
# voc : voc
# kirm : kirm
# tabunganny : tabunganny
# blsuka : blsuka
# pakaiini : pakaiini
# bagaimanavoc : bagaimanavoc
# okpelapak : okpelapak
# admintmantap : admintmantap
# menyesalkan : sesal
# pemutusannya : putus
# belanjanyasukses : belanjanyasukses
# bukalapaksekarang : bukalapaksekarang
# tks : tks
# steam : steam
# wallet : wallet
# redeem : redeem
# codenya : codenya
# teman : teman
# penipuansya : penipuansya
# keterangannyayah : keterangannyayah
# maksudnya : maksud
# bantuannyaoiiii : bantuannyaoiiii
# sayaaaaaa : sayaaaaaa
# terpercayatercepat : terpercayatercepat
# gunakansukses : gunakansukses
# berkualitas : kualitas
# menang : menang
# memikirkan : pikir
# gantihilang : gantihilang
# dableg : dableg
# tahi : tahi
# samapai : samapai
# hoyy : hoyy
# lo : lo
# setan : setan
# belanjaada : belanjaada
# nyatp : nyatp
# maunya : mau
# bukalpak : bukalpak
# terussayang : terussayang
# mahalan : mahal
# dikittapi : dikittapi
# apalah : apa
# pokoe : pokoe
# jozz : jozz
# mencukupi : cukup
# transaksiversi : transaksiversi
# bisasisany : bisasisany
# dihati : hati
# kadaluwarsa : kadaluwarsa
# jelass : jelass
# kinerja : kerja
# dendanya : denda
# airlistrik : airlistrik
# bedanya : beda
# layanansama : layanansama
# custamerknpa : custamerknpa
# membedakan : beda
# katanyabayar : katanyabayar
# listri : listri
# conter : conter
# layanin : layanin
# orangnyamemang : orangnyamemang
# manusia : manusia
# harta : harta
# air : air
# bulalapak : bulalapak
# mengikuti : ikut
# misi : misi
# loging : loging
# donlow : donlow
# pacebok : pacebok
# geugle : geugle
# eee : eee
# dikonfirmasi : konfirmasi
# donwlod : donwlod
# digunakangak : digunakangak
# tokonya : toko
# bayak : bayak
# wadah : wadah
# alhasil : alhasil
# dinyatakan : nyata
# mengutamakan : utama
# potong : potong
# kedaluarsa : kedaluarsa
# disaat : saat
# penjualanpembatalan : penjualanpembatalan
# nyanotif : nyanotif
# pencariannya : cari
# ikan : ikan
# hias : hias
# pakan : pakan
# ganggu : ganggu
# minusnya : minus
# memenuhi : penuh
# membela : bela
# kepentingan : penting
# menjanjikan : janji
# mematikan : mati
# obrolannya : obrol
# hangus : hangus
# kyc : kyc
# sory : sory
# ane : ane
# join : join
# kesana : kesana
# koleksinya : koleksi
# berbulan : bulan
# stagnan : stagnan
# greget : greget
# ol : ol
# bukalapakygdulu : bukalapakygdulu
# dipilih : pilih
# zonk : zonk
# kepercayan : kepercayan
# ecom : ecom
# utama : utama
# aktifasi : aktifasi
# sumpah : sumpah
# enek : enek
# sefty : sefty
# nyataanya : nyataanya
# nomornya : nomor
# aktivasi : aktivasi
# syaratnya : syarat
# sumpaah : sumpaah
# oohh : oohh
# devlover : devlover
# lebay : lebay
# syarat : syarat
# dikirimkan : kirim
# ktprekening : ktprekening
# seribet : seribet
# cantumin : cantumin
# tipenyasaya : tipenyasaya
# menunya : menu
# pahami : paham
# lemottnya : lemottnya
# bukaemas : bukaemas
# problemnya : problem
# gateway : gateway
# kayaknya : kayak
# investasi : investasi
# dibikin : bikin
# credit : credit
# ketentuan : tentu
# ketahui : tahu
# didownload : didownload
# touch : touch
# az : az
# baned : baned
# feed : feed
# gede : gede
# ajabanyak : ajabanyak
# sisrem : sisrem
# gunabuka : gunabuka
# ajaisi : ajaisi
# harap : harap
# ajadan : ajadan
# bagusmasuk : bagusmasuk
# ribetnya : ribetnya
# bantuannyasaya : bantuannyasaya
# kesulitan : sulit
# logindikarenakan : logindikarenakan
# aktifmau : aktifmau
# sayadan : sayadan
# bukalapakmohon : bukalapakmohon
# mempersulit : sulit
# ribuan : ribu
# cumq : cumq
# tampil : tampil
# temukan : temu
# gaya : gaya
# pengunjung : unjung
# kadaluarsamau : kadaluarsamau
# fiturnya : fiturnya
# nonaktif : nonaktif
# dear : dear
# check : check
# pesana : sana
# perhatiannya : perhati
# menggangu : menggangu
# dengar : dengar
# dibalas : balas
# april : april
# mls : mls
# beban : beban
# and : and
# dipiara : piara
# dalem : dalem
# detik : detik
# canggih : canggih
# sadah : sadah
# kembaliini : kembaliini
# kepastianpayah : kepastianpayah
# kekurir : kurir
# sudahlama : sudahlama
# kayanya : kaya
# tabungan : tabung
# fiture : fiture
# moga : moga
# kebelakang : belakang
# antrian : antri
# nutup : nutup
# trecking : trecking
# snapdragon : snapdragon
# gen : gen
# ram : ram
# gb : gb
# clear : clear
# chace : chace
# logout : logout
# server : server
# berbelanjatapi : berbelanjatapi
# dam : dam
# halapalagi : halapalagi
# sistemnyakecewa : sistemnyakecewa
# pemilihan : pilih
# report : report
# bermasalahpaket : bermasalahpaket
# kompensasi : kompensasi
# kembalihanya : kembalihanya
# slogan : slogan
# belakabagaimana : belakabagaimana
# susupin : susupin
# pasang : pasang
# separuhnya : paruh
# realpict : realpict
# ajalihat : ajalihat
# history : history
# mainnumpuk : mainnumpuk
# diserver : diserver
# akunbuatlah : akunbuatlah
# penyimpanan : simpan
# buset : buset
# ditemukan : temu
# hebat : hebat
# lenya : lenya
# manapun : mana
# fee : fee
# lainnyamataap : lainnyamataap
# gunawan : gunawan
# bukalapk : bukalapk
# tautpi : tautpi
# gramdi : gramdi
# kgdan : kgdan
# ahirnya : ahirnya
# ijoklo : ijoklo
# ampas : ampas
# tertata : tata
# batasi : batas
# pepalak : palak
# kompalain : kompalain
# tpdiketangan : tpdiketangan
# kecewadimana : kecewadimana
# menyediakan : sedia
# codtapi : codtapi
# menyesak : sesak
# sgitu : sgitu
# tuhklo : tuhklo
# kepakasa : kepakasa
# saking : saking
# belu : belu
# cairkan : cair
# hadehhh : hadehhh
# gunanya : guna
# payleater : payleater
# bukalapaksaya : bukalapaksaya
# tagih : tagih
# lagibukti : lagibukti
# struknya : struknya
# kasir : kasir
# indomart : indomart
# yeah : yeah
# tagihantapi : tagihantapi
# star : star
# memberatkan : berat
# itemku : item
# higs : higs
# domino : domino
# menerapkan : terap
# peforma : forma
# huhuhuuuuu : huhuhuuuuu
# sekaliterutama : sekaliterutama
# pajak : pajak
# sekalai : sekala
# kompin : kompin
# kerjasama : kerjasama
# beres : beres
# mempertanggungjawabkan : mempertanggungjawabkan
# didunia : dunia
# akherat : akherat
# shrusnya : shrusnya
# fitr : fitr
# lngsng : lngsng
# sosial : sosial
# media : media
# penggunannya : gun
# hai : hai
# bukal : bukal
# pcs : pcs
# parsel : parsel
# curi : curi
# vidio : vidio
# sebagia : sebagia
# sah : sah
# porum : porum
# notip : notip
# januari : januari
# jugasudah : jugasudah
# tanggapi : tanggap
# bukalapaksungguh : bukalapaksungguh
# ribeettt : ribeettt
# reg : reg
# day : day
# pick : pick
# lelet : lelet
# criss : criss
# cross : cross
# sop : sop
# ybs : ybs
# kepercayaan : percaya
# ket : ket
# gaib : gaib
# meningkatkan : tingkat
# mengajak : ajak
# keranjang : keranjang
# way : way
# mantapharga : mantapharga
# ringan : ringan
# lainpadahal : lainpadahal
# kualitasnya : kualitas
# tipu : tipu
# melaporkan : lapor
# feedbacknya : feedbacknya
# kepuasan : puas
# mjnta : mjnta
# onlinekonformasi : onlinekonformasi
# dlluegk : dlluegk
# pmbeeli : pmbeeli
# terbaikresponship : terbaikresponship
# serba : serba
# mengenali : nali
# beliau : beliau
# riwayat : riwayat
# standar : standar
# aneka : aneka
# bagusmemuaskan : bagusmemuaskan
# dikala : kala
# membutuhkan : butuh
# hubungkan : hubung
# aplkasi : aplkasi
# iniakun : iniakun
# hack : hack
# vcr : vcr
# berhati : hati
# mendewakan : dewa
# chattingan : chattingan
# ekpedisi : ekpedisi
# quicksend : quicksend
# cash : cash
# lom : lom
# jawabannyacoba : jawabannyacoba
# tanggepin : tanggepin
# tlong : tlong
# tentui : tentu
# jgbuat : jgbuat
# bantumakin : bantumakin
# chatlemot : chatlemot
# lag : lag
# memperbaiki : baik
# karuan : karuan
# paylatternya : paylatternya
# scroll : scroll
# boongan : boongan
# jnt : jnt
# nyantumin : nyantumin
# pembohong : bohong
# ribetkl : ribetkl
# jutabegitu : jutabegitu
# cekoutpembayaran : cekoutpembayaran
# ditolakaneh : ditolakaneh
# bukadempet : bukadempet
# permudah : mudah
# bertahan : tahan
# kompetitornya : kompetitor
# yuk : yuk
# buruan : buru
# konsisten : konsisten
# timbul : timbul
# tenggelam : tenggelam
# hehee : hehee
# mmbeli : mmbeli
# sayapadahal : sayapadahal
# inipadahal : inipadahal
# pinbiasanya : pinbiasanya
# sajapadahal : sajapadahal
# sabar : sabar
# siniudah : siniudah
# ngetikpas : ngetikpas
# jdinya : jdinya
# terimatpi : terimatpi
# ...
# formitu : formitu
# masalahnyajawaban : masalahnyajawaban
# lamawaalaaeh : lamawaalaaeh
# berterimakasih : berterimakasih
# aksesnya : akses
# penyampaian : sampai
# materinya : materi
# terperincipelatihannya : terperincipelatihannya
# pahamisangat : pahamisangat
# sayatrimakasih : sayatrimakasih
# semuaskrg : semuaskrg
# nyamantap : nyamantap
# blsmoga : blsmoga
# umurmakin : umurmakin
# efektifcepat : efektifcepat
# pembelajaran : ajar
# prakerjasaya : prakerjasaya
# menerangkan : terang
# terjun : terjun
# freelancer : freelancer
# nampilin : nampilin
# terpopuler : populer
# komparasi : komparasi
# puaskanpengunaan : puaskanpengunaan
# carisaya : carisaya
# tua : tua
# anak : anak
# bini : bini
# cacing : cacing
# perut : perut
# ikhlas : ikhlas
# jelasss : jelasss
# apaapaan : apaapaan
# kunjung : kunjung
# rentang : rentang
# kadauwarsa : kadauwarsa
# keuangannya : uang
# disayangkan : sayang
# optimal : optimal
# dukungan : dukung
# selleraplikasinya : selleraplikasinya
# komplainnyesel : komplainnyesel
# nginstall : nginstall
# diskripsi : skripsi
# shaller : shaller
# fotonya : foto
# berhubung : hubung
# newbie : newbie
# ringansekarang : ringansekarang
# hitam : hitam
# duluterus : duluterus
# merespongak : merespongak
# aplikasibiar : aplikasibiar
# menengah : tengah
# terbawa : bawa
# pebaharui : baharu
# username : username
# prosedur : prosedur
# minus : minus
# etc : etc
# instant : instant
# itulahpantes : itulahpantes
# arahin : arahin
# blidappreview : blidappreview
# menguntungkan : untung
# ngurut : ngurut
# ngacak : ngacak
# omzet : omzet
# berujung : ujung
# pahit : pahit
# dibobol : bobol
# phising : phising
# tentukan : tentu
# diberanda : beranda
# disesuaikan : sesuai
# judulnya : judul
# shoponline : shoponline
# dikemas : kemas
# iti : iti
# diperhatikan : perhati
# abang : abang
# ekspedisinya : ekspedisi
# diganti : ganti
# regbarang : regbarang
# myd : myd
# inv : inv
# compatible : compatible
# rotasi : rotasi
# perputaran : putar
# tegak : tegak
# landscape : landscape
# mengurangi : kurang
# sentuh : sentuh
# terganggu : ganggu
# genting : genting
# mark : mark
# tarif : tarif
# gerai : gerai
# pembeliannya : beli
# menyempatkan : sempat
# siasia : siasia
# naikkan : naik
# enggan : enggan
# perpaling : paling
# menghalangi : halang
# ditemui : temu
# laih : laih
# survey : survey
# berkaitan : kait
# pecah : pecah
# telur : telur
# rusakkomplainnya : rusakkomplainnya
# sepadan : padan
# hasilnyakarna : hasilnyakarna
# klaimkomplain : klaimkomplain
# rusaknya : rusak
# ekspedisimemang : ekspedisimemang
# kitauntuk : kitauntuk
# fiktur : fiktur
# musnahkan : musnah
# merchan : merchan
# seharihari : seharihari
# perbulannya : bulan
# mpe : mpe
# dipakedenda : dipakedenda
# wadaww : wadaww
# pertanggung : tanggung
# tlpon : tlpon
# kasihbukalapak : kasihbukalapak
# mengembangan : kembang
# lebihlebih : lebihlebih
# memudahkn : memudahkn
# dengn : dengn
# lestari : lestari
# jakbar : jakbar
# mengemas : emas
# area : area
# cempaka : cempaka
# akibatnya : akibat
# pinasa : pinasa
# kaos : kaos
# logintiba : logintiba
# termaksud : maksud
# deploper : deploper
# dilengkapi : lengkap
# dengarkan : dengar
# cinta : cinta
# saka : saka
# tercepat : cepat
# novita : novita
# sari : sari
# peserta : serta
# mentor : mentor
# memotivasi : motivasi
# wawasan : wawas
# mengembangkan : kembang
# potensi : potensi
# miliki : milik
# line : line
# parahgak : parahgak
# assalamualaikum : assalamualaikum
# membelih : membelih
# berjudul : judul
# kuasai : kuasa
# nlp : nlp
# pelatihannya : latih
# ditoko : toko
# orangehijau : orangehijau
# optimalkan : optimal
# deal : deal
# jenis : jenis
# optimalisasi : optimalisasi
# membentuk : bentuk
# luas : luas
# mobil : mobil
# filternya : filter
# ikonik : ikonik
# vita : vita
# membelinya : bel
# tema : tema
# menarikedukatif : menarikedukatif
# inspiratif : inspiratif
# pencarinya : pencar
# difilter : filter
# lakunya : laku
# webnya : webnya
# cacat : cacat
# kamera : kamera
# memotret : potret
# hptidak : hptidak
# familiar : familiar
# dropshiper : dropshiper
# supplier : supplier
# mengaktifkan : aktif
# menonaktifkan : nonaktif
# lemmooottttt : lemmooottttt
# transsaksi : transsaksi
# terisi : isi
# penawaran : tawar
# terbaca : baca
# kepencet : pencet
# kecurigaan : curiga
# maafkan : maaf
# respone : respone
# diatasi : atas
# oiya : oiya
# dipercepat : cepat
# bugbuka : bugbuka
# lamamasuk : lamamasuk
# lamake : lamake
# iconnya : iconnya
# perbarui : baru
# ahjgn : ahjgn
# inigak : inigak
# kencang : kencang
# tulisanmu : tulis
# down : down
# cobalagi : cobalagi
# terusmenjengkelkan : terusmenjengkelkan
# tokosebelah : tokosebelah
# pelangganny : pelangganny
# fiturfitur : fiturfitur
# bervariatif : variatif
# informasinya : informasi
# frakerja : frakerja
# bahasanya : bahasa
# rinci : rinci
# kemenaker : kemenaker
# terbantudengan : terbantudengan
# ilmu : ilmu
# beyar : beyar
# layananya : layananya
# perbulan : bulan
# siplah : sip
# ilegal : ilegal
# stres : stres
# aplkasinya : aplkasinya
# terimakasi : terimakasi
# ijobiruoren : ijobiruoren
# padaha : padaha
# najis : najis
# akulakukredivojuloasal : akulakukredivojuloasal
# pelatihanujungnya : pelatihanujungnya
# pelatihaanya : pelatihaanya
# keterangannya : terang
# nice : nice
# tq : tq
# adanyaminimal : adanyaminimal
# nibelanja : nibelanja
# nyakena : nyakena
# bosampunn : bosampunn
# bukalapakgk : bukalapakgk
# pesananbutuh : pesananbutuh
# bukalapakdengan : bukalapakdengan
# meninggoy : meninggoy
# buktikan : bukti
# termurah : murah
# sigap : sigap
# oyen : oyen
# judi : judi
# anggota : anggota
# dpr : dpr
# ri : ri
# zeus : zeus
# rapat : rapat
# galaxy : galaxy
# undian : undi
# pemenangnya : menang
# lini : lini
# kehidupan : hidup
# rampok : rampok
# bertangung : bertangung
# real : real
# bukareksa : bukareksa
# menginginkannya : ingin
# lengkapcepat : lengkapcepat
# nyentuh : nyentuh
# ngadi : ngadi
# tf : tf
# anjay : anjay
# apeee : apeee
# dihhh : dihhh
# noh : noh
# apapunnn : apapunnn
# sedia : sedia
# viralkan : viralkan
# sejarahbuktiin : sejarahbuktiin
# sendirikalah : sendirikalah
# sebelahjoos : sebelahjoos
# terdepan : depan
# pelayananya : pelayananya
# responterima : responterima
# mengembirakan : mengembirakan
# sisi : sisi
# ekspetasi : ekspetasi
# ektp : ektp
# blur : blur
# frame : frame
# teus : teus
# cepatsangat : cepatsangat
# komisi : komisi
# telkom : telkom
# pdam : pdam
# kab : kab
# kediri : diri
# fif : fif
# adira : adira
# cetak : cetak
# bluetooth : bluetooth
# kasirnya : kasir
# terintegrasi : integrasi
# keamanannya : aman
# diprioritaskan : prioritas
# lampiran : lampir
# negatif : negatif
# ive : ive
# idea : idea
# datanya : data
# coin : coin
# kecepatan : cepat
# tujuanya : tujuanya
# hangusnya : hangus
# panjangin : panjangin
# variatif : variatif
# salin : salin
# paste : paste
# lainkali : lainkali
# diperuntukkan : untuk
# pendapat : dapat
# bangsa : bangsa
# masyarakan : masyarakan
# warungwarung : warungwarung
# sesi : sesi
# indonesiabukalapak : indonesiabukalapak
# digunakanitu : digunakanitu
# dulusekarang : dulusekarang
# kecewakomplain : kecewakomplain
# berteletelepembelian : berteletelepembelian
# saldodanabisa : saldodanabisa
# rekeningribetjadi : rekeningribetjadi
# bintangnyamaafmau : bintangnyamaafmau
# balikhadeuhh : balikhadeuhh
# memory : memory
# hpko : hpko
# kepepet : pepet
# ribut : ribut
# bangetlah : banget
# instruksi : instruksi
# dltingkatin : dltingkatin
# imbang : imbang
# adm : adm
# bulanannya : bulan
# buku : buku
# didaftarin : didaftarin
# mala : mala
# pemaksaan : paksa
# lembagalembaga : lembagalembaga
# slowrespon : slowrespon
# jadikan : jadi
# cadangan : cadang
# faktor : faktor
# lzd : lzd
# fastrespon : fastrespon
# dikembangkan : kembang
# pencantuman : cantum
# baju : baju
# lengan : lengan
# pendek : pendek
# inbox : inbox
# lagharus : lagharus
# telkomsel : telkomsel
# lanjay : lanjay
# beritahuakan : beritahuakan
# yaadi : yaadi
# xsetelah : xsetelah
# tercantumini : tercantumini
# akal : akal
# kabarsangat : kabarsangat
# burukpenipuan : burukpenipuan
# mengedukasi : edukasi
# pola : pola
# gagasan : gagas
# pikiran : pikir
# uturakan : uturakan
# bukapalak : bukapalak
# dikartu : kartu
# komunikasi : komunikasi
# menunjang : tunjang
# karir : karir
# rajin : rajin
# traksaksi : traksaksi
# kaliklo : kaliklo
# terjangkauongkos : terjangkauongkos
# onlen : onlen
# aktual : aktual
# dominan : dominan
# over : over
# perlukan : perlu
# ongir : ongir
# acuh : acuh
# cuek : cuek
# tanggapannya : tanggap
# lemah : lemah
# taii : taii
# rekomendasikan : rekomendasi
# penerapan : terap
# midtrans : midtrans
# lempar : lempar
# mnit : mnit
# kill : kill
# process : process
# blnya : blnya
# berbenti : berbenti
# dibagian : bagi
# memajukan : maju
# dipoto : dipoto
# liqid : liqid
# pohon : pohon
# gabung : gabung
# rejekiroda : rejekiroda
# hilangsaya : hilangsaya
# mengubah : ubah
# smswa : smswa
# karenasempet : karenasempet
# telpwa : telpwa
# salenya : sale
# internkaryawan : internkaryawan
# buktinya : bukti
# list : list
# mengaku : aku
# persetujuan : tuju
# baguskarena : baguskarena
# hpseharusnya : hpseharusnya
# lagiklau : lagiklau
# membayarnyamisalkan : membayarnyamisalkan
# atmno : atmno
# bankklau : bankklau
# agr : agr
# lagimksih : lagimksih
# callcenter : callcenter
# minkemaren : minkemaren
# linkajatetapi : linkajatetapi
# berhasilehh : berhasilehh
# semalam : malam
# pembayarangimana : pembayarangimana
# linkaja : linkaja
# diriwayat : riwayat
# hmmm : hmmm
# mincs : mincs
# mepersulit : mepersulit
# melakukakan : melakukakan
# telpon : telpon
# kontakcall : kontakcall
# berinteraksi : interaksi
# matiin : matiin
# eroor : eroor
# pemainnya : main
# standart : standart
# pemain : main
# aslinya : asli
# uninsntall : uninsntall
# sebelmnya : sebelmnya
# menjengkelkan : jengkel
# rada : rada
# dihadapi : hadap
# bukadanabukadompet : bukadanabukadompet
# bukadana : bukadana
# dinaikin : dinaikin
# olah : olah
# pesaing : saing
# blankgak : blankgak
# bukaoia : bukaoia
# osaplikay : osaplikay
# apalokasi : apalokasi
# jaringanyang : jaringanyang
# uptodatejadi : uptodatejadi
# perbaikilah : baik
# lapaksudah : lapaksudah
# mnurun : mnurun
# jayapura : jayapura
# dijangkau : jangkau
# appnya : appnya
# kualitasmu : kualitas
# drop : drop
# matang : matang
# sekarangmalesbosen : sekarangmalesbosen
# keselkarena : keselkarena
# perbaharui : baharu
# leletlemotkayak : leletlemotkayak
# siput : siput
# mabuktolong : mabuktolong
# perbaikidan : perbaikidan
# alangkah : alangkah
# terbarutapi : terbarutapi
# bisatrims : bisatrims
# orkirnya : orkirnya
# seimbang : imbang
# beliberani : beliberani
# orkir : orkir
# panjual : panjual
# weekend : weekend
# is : is
# mengetiktdk : mengetiktdk
# algoritmanya : algoritmanya
# kembangkan : kembang
# date : date
# pengiklanan : iklan
# dalemnya : dalem
# even : even
# serbunya : serbu
# ngrestart : ngrestart
# kenyamana : kenyamana
# utamakan : utama
# bukunya : buku
# sebatas : batas
# padahalkan : padahal
# jarak : jarak
# harapan : harap
# bepergian : pergi
# ngebug : ngebug
# double : double
# ilfil : ilfil
# susa : susa
# masukansaran : masukansaran
# pemberian : beri
# lamaterutama : lamaterutama
# grabgosend : grabgosend
# jugakarena : jugakarena
# ditangan : tang
# ketiga : tiga
# perpesanan : pesan
# bals : bals
# attch : attch
# delay : delay
# boro : boro
# sektor : sektor
# teranyar : anyar
# namana : namana
# dipantau : pantau
# disajikan : saji
# aplikator : aplikator
# aaa : aaa
# pemenang : menang
# identitas : identitas
# nabungbuat : nabungbuat
# paspasan : paspasan
# meringankan : ringan
# flashdealnya : flashdealnya
# jin : jin
# hitungan : hitung
# lampu : lampu
# dslr : dslr
# seper : per
# kamuyang : kamuyang
# nyarinya : nyarinya
# ketampil : tampil
# akurasi : akurasi
# antra : antra
# keyword : keyword
# akurat : akurat
# source : source
# pembodohan : bodoh
# pembertahuannya : tahu
# kenyamanannya : nyaman
# memuaskanaplikasi : memuaskanaplikasi
# dicairkan : cair
# dibelanjakan : belanja
# terlupakan : lupa
# pleleter : pleleter
# lemotjadinya : lemotjadinya
# ide : ide
# burukjadi : burukjadi
# makain : makain
# berfaedah : faedah
# promopromo : promopromo
# promosikan : promosi
# minimum : minimum
# virus : virus
# dibuang : buang
# promosinya : promosi
# menyedikan : dik
# usernya : usernya
# dilayani : layan
# prmbelian : prmbelian
# medsos : medsos
# konek : konek
# atay : atay
# skala : skala
# kwalitasnya : kwalitasnya
# jelasmaen : jelasmaen
# wkw : wkw
# berjual : jual
# melewati : lewat
# bukabantu : bukabantu
# amananpesana : amananpesana
# raib : raib
# susahtolong : susahtolong
# konfirmasinya : konfirmasi
# hadehhhh : hadehhhh
# performaa : performaa
# prkmbangn : prkmbangn
# pningktn : pningktn
# seprti : seprti
# duluagak : duluagak
# hayu : hayu
# terkenal : kenal
# tutu : tutu
# duh : duh
# print : print
# sekarangbarang : sekarangbarang
# mubazir : mubazir
# menuhin : menuhin
# adminya : adminya
# bocor : bocor
# korbanya : korbanya
# wkwkkw : wkwkkw
# jadwalnya : jadwal
# {'fitur': 'fitur', 'bukabantuan': 'bukabantuan', 'aplikasi': 'aplikasi', 'ribet': 'ribet', 'saldo': 'saldo', 'dipakai': 'pakai', 'cairin': 'cairin', 'transfer': 'transfer', 'banget': 'banget', 'password': 'password', 'dibilang': 'bilang', 'salah': 'salah', 'riset': 'riset', 'dikit': 'dikit', 'selesai': 'selesai', 'notifikasi': 'notifikasi', 'sistem': 'sistem', 'eror': 'eror', 'sih': 'sih', 'marketplace': 'marketplace', 'hancur': 'hancur', 'selesain': 'selesain', 'lari': 'lari', 'live': 'live', 'chatnya': 'chatnya', 'paylaternya': 'paylaternya', 'bobrok': 'bobrok', 'silakan': 'sila', 'dicoba': 'coba', 'download': 'download', 'tau': 'tau', 'bingung': 'bingung', 'hubungi': 'hubung', 'cs': 'cs', 'ngaktifin': 'ngaktifin', 'chat': 'chat', 'mengasih': 'asih', 'feedback': 'feedback', 'aktif': 'aktif', 'lihat': 'lihat', 'transaksi': 'transaksi', 'pembelian': 'beli', 'klik': 'klik', 'tertulis': 'tulis', 'gangguan': 'ganggu', 'coba': 'coba', 'email': 'email', 'terkirim': 'kirim', 'tlol': 'tlol', 'asyikasyiknya': 'asyikasyiknya', 'nemu': 'nemu', 'barang': 'barang', 'diincar': 'incar', 'eh': 'eh', 'muncul': 'muncul', 'popupiklan': 'popupiklan', 'buka': 'buka', 'emas': 'emas', 'dimana': 'mana', 'mengganggu': 'ganggu', 'close': 'close', 'masuk': 'masuk', 'menu': 'menu', 'beranda': 'beranda', 'beli': 'beli', 'deh': 'deh', 'tokopedia': 'tokopedia', 'shopee': 'shopee', 'belanja': 'belanja', 'kedepan': 'depan', 'banyakan': 'banyak', 'popup': 'popup', 'jujur': 'jujur', 'uninstal': 'uninstal', 'komplain': 'komplain', 'seminggu': 'minggu', 'permintaan': 'minta', 'pencairan': 'cair', 'dana': 'dana', 'rekening': 'rekening', 'pribadi': 'pribadi', 'berhasil': 'hasil', 'tolong': 'tolong', 'kerjasamanya': 'kerjasamanya', 'aktifkan': 'aktif', 'bukabantuannya': 'bukabantuannya', 'next': 'next', 'bintangnya': 'bintang', 'diubah': 'ubah', 'update': 'update', 'suka': 'suka', 'error': 'error', 'cepat': 'cepat', 'errorbarusan': 'errorbarusan', 'turun': 'turun', 'notif': 'notif', 'tagihan': 'tagih', 'hilang': 'hilang', 'pembayaran': 'bayar', 'besok': 'besok', 'bintang': 'bintang', 'dibuka': 'buka', 'tanggal': 'tanggal', 'juni': 'juni', 'pagi': 'pagi', 'malam': 'malam', 'cek': 'cek', 'detail': 'detail', 'pesanan': 'pesan', 'terbayar': 'bayar', 'mantap': 'mantap', 'kalo': 'kalo', 'paket': 'paket', 'sediakan': 'sedia', 'foto': 'foto', 'bukti': 'bukti', 'pengiriman': 'kirim', 'nyabiar': 'nyabiar', 'oh': 'oh', 'nya': 'nya', 'taro': 'taro', 'situ': 'situ', 'kurir': 'kurir', 'mengantarkan': 'antar', 'alamat': 'alamat', 'posisi': 'posisi', 'aman': 'aman', 'konfirmasi': 'konfirmasi', 'mohon': 'mohon', 'tingkat': 'tingkat', 'bagus': 'bagus', 'aplikasinya': 'aplikasi', 'edit': 'edit', 'produk': 'produk', 'giliran': 'gilir', 'ujung': 'ujung', 'iklan': 'iklan', 'dijual': 'jual', 'alias': 'alias', 'otomatis': 'otomatis', 'dihapus': 'hapus', 'bukalapak': 'bukalapak', 'ditingkatkan': 'tingkat', 'ulang': 'ulang', 'sistemnya': 'sistem', 'penjual': 'jual', 'pembeli': 'beli', 'meninggalkan': 'tinggal', 'nih': 'nih', 'order': 'order', 'pelapak': 'lapak', 'keterlambatan': 'lambat', 'kesehatan': 'sehat', 'kondisi': 'kondisi', 'membaik': 'baik', 'kirim': 'kirim', 'status': 'status', 'dibatalkan': 'batal', 'parahnya': 'parah', 'melaksanakan': 'laksana', 'uangnya': 'uang', 'refound': 'refound', 'dirugikan': 'rugi', 'kesel': 'kesel', 'pemesanan': 'mesan', 'limit': 'limit', 'tersedia': 'sedia', 'mengajukan': 'aju', 'sulit': 'sulit', 'emailnya': 'email', 'perbaiki': 'baik', 'mengunakan': 'mengunakan', 'paylatter': 'paylatter', 'terima': 'terima', 'kasih': 'kasih', 'diupdate': 'diupdate', 'bug': 'bug', 'contoh': 'contoh', 'out': 'out', 'dibukak': 'dibukak', 'tulisan': 'tulis', 'kesalahan': 'salah', 'memantau': 'pantau', 'pergerakan': 'gera', 'baca': 'baca', 'virtual': 'virtual', 'account': 'account', 'terverifikasi': 'verifikasi', 'terpotong': 'potong', 'arahanya': 'arahanya', 'langsung': 'langsung', 'alasan': 'alas', 'koneksi': 'koneksi', 'terputus': 'putus', 'ganti': 'ganti', 'selfilah': ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/1300 [00:00<?, ?it/s]

# %%
name_dataframe["Ulasan_siap"] = [' '.join(map(str, l)) for l in name_dataframe['Ulasan_Stemmed']]

# %%
name_dataframe.to_excel("bukalapak.xlsx")

# %%
ulasan = ' '.join(str(v) for v in name_dataframe['Ulasan_siap'])

# %%
tokenize_ulasan = word_tokenize(ulasan)

# %%
tokenize_ulasan
# Out:
# ['fitur',
#  'bukabantuan',
#  'aplikasi',
#  'ribet',
#  'saldo',
#  'pakai',
#  'cairin',
#  'transfer',
#  'ribet',
#  'banget',
#  'password',
#  'bilang',
#  'salah',
#  'riset',
#  'password',
#  'bilang',
#  'salah',
#  'dikit',
#  'selesai',
#  'notifikasi',
#  'sistem',
#  'eror',
#  'sih',
#  'aplikasi',
#  'marketplace',
#  'hancur',
#  'sistem',
#  'bukabantuan',
#  'selesain',
#  'lari',
#  'live',
#  'chatnya',
#  'sistem',
#  'paylaternya',
#  'bobrok',
#  'sila',
#  'coba',
#  'download',
#  'tau',
#  'bingung',
#  'banget',
#  'hubung',
#  'cs',
#  'ngaktifin',
#  'fitur',
#  'live',
#  'chat',
#  'asih',
#  'feedback',
#  'asih',
#  'feedback',
#  'fitur',
#  'live',
#  'chat',
#  'aktif',
#  'lihat',
#  'transaksi',
#  'beli',
#  'klik',
#  'tulis',
#  'ganggu',
#  'klik',
#  'transaksi',
#  'ganggu',
#  'coba',
#  'email',
#  'kirim',
#  'aplikasi',
#  'tlol',
#  'asyikasyiknya',
#  'nemu',
#  'barang',
#  'incar',
#  'eh',
#  'muncul',
#  'popupiklan',
#  'buka',
#  'emas',
#  'mana',
#  'ganggu',
#  'close',
#  'barang',
#  'incar',
#  'eh',
#  'masuk',
#  'menu',
#  'buka',
#  'emas',
#  'menu',
#  'buka',
#  'emas',
#  'beranda',
#  'beli',
#  'deh',
#  'tokopedia',
#  'shopee',
#  'belanja',
#  'barang',
#  'depan',
#  'banyak',
#  'popup',
#  'jujur',
#  'uninstal',
#  'komplain',
#  'minggu',
#  'minta',
#  'cair',
#  'dana',
#  'rekening',
#  'pribadi',
#  'hasil',
#  'bukabantuan',
#  'tolong',
#  'kerjasamanya',
#  'aktif',
#  'bukabantuannya',
#  'komplain',
#  'next',
#  'selesai',
#  'bintang',
#  'ubah',
#  'update',
#  'suka',
#  'error',
#  'cepat',
#  'suka',
#  'errorbarusan',
#  'turun',
#  'bintang',
#  'notif',
#  'tagih',
#  'hilang',
#  'bayar',
#  'selesai',
#  'tagih',
#  'besok',
#  'bintang',
#  'buka',
#  'tanggal',
#  'juni',
#  'pagi',
#  'malam',
#  'cek',
#  'detail',
#  'pesan',
#  'bayar',
#  'mantap',
#  'tolong',
#  'kalo',
#  'paket',
#  'sedia',
#  'foto',
#  'bukti',
#  'kirim',
#  'nyabiar',
#  'tau',
#  'oh',
#  'paket',
#  'nya',
#  'taro',
#  'situ',
#  'kurir',
#  'antar',
#  'barang',
#  'salah',
#  'alamat',
#  'tau',
#  'posisi',
#  'paket',
#  'aman',
#  'konfirmasi',
#  'kurir',
#  'nya',
#  'mohon',
#  'tingkat',
#  'bagus',
#  'banget',
#  'aplikasi',
#  'aplikasi',
#  'ribet',
#  'edit',
#  'produk',
#  'gilir',
#  'hasil',
#  'ujung',
#  'nya',
#  'iklan',
#  'produk',
#  'jual',
#  'hilang',
#  'alias',
#  'otomatis',
#  'hapus',
#  'bukalapak',
#  'tolong',
#  'tingkat',
#  'ulang',
#  'sistem',
#  'jual',
#  'beli',
#  'tinggal',
#  'aplikasi',
#  'nih',
#  'order',
#  'barang',
#  'lapak',
#  'chat',
#  'lambat',
#  'kirim',
#  'sehat',
#  'kondisi',
#  'baik',
#  'kirim',
#  'barang',
#  'status',
#  'pesan',
#  'aktif',
#  'batal',
#  'parah',
#  'laksana',
#  'transaksi',
#  'uang',
#  'refound',
#  'saldo',
#  'dana',
#  'kalo',
#  'rugi',
#  'kesel',
#  'banget',
#  'nih',
#  'aplikasi',
#  'mesan',
#  'batal',
#  'otomatis',
#  'limit',
#  'sedia',
#  'tagih',
#  'aju',
#  'komplain',
#  'sulit',
#  'kirim',
#  'email',
#  'alamat',
#  'email',
#  'tolong',
#  'baik',
#  'mengunakan',
#  'paylatter',
#  'belanja',
#  'bukalapak',
#  'terima',
#  'kasih',
#  'diupdate',
#  'bug',
#  'contoh',
#  'cek',
#  'out',
#  'pesan',
#  'bayar',
#  'hasil',
#  'pesan',
#  'dibukak',
#  'tulis',
#  'salah',
#  'dana',
#  'masuk',
#  'sistem',
#  'pantau',
#  'gera',
#  'pesan',
#  'transfer',
#  'baca',
#  'virtual',
#  'account',
#  'verifikasi',
#  'saldo',
#  'rekening',
#  'potong',
#  'komplain',
#  'live',
#  'chat',
#  'arahanya',
#  'ribet',
#  'banget',
#  'parah',
#  'live',
#  'chat',
#  'langsung',
#  'alas',
#  'koneksi',
#  'putus',
#  'ganti',
#  'email',
#  'ribet',
#  'banget',
#  'selfilah',
#  'ktplah',
#  'mutasi',
#  'rekening',
#  'framelah',
#  'kembali',
#  'dana',
#  'transfer',
#  'bukalapak',
#  'tangan',
#  'tim',
#  'tunggu',
#  'jam',
#  'selesai',
#  'percaya',
#  'jual',
#  'respon',
#  'komplain',
#  'bel',
#  'salah',
#  'kirim',
#  'jual',
#  'rugi',
#  'transaksi',
#  'anggap',
#  'selesai',
#  'beli',
#  'anggap',
#  'terima',
#  'barang',
#  'komplain',
#  'kalo',
#  'jual',
#  'salah',
#  'kirim',
#  'kali',
#  'jual',
#  'kirim',
#  'barang',
#  'notifikasi',
#  'terima',
#  'komplain',
#  'bl',
#  'ribet',
#  'mbulet',
#  'tolong',
#  'baik',
#  'apk',
#  'nya',
#  'rugi',
#  'beli',
#  'paket',
#  'internet',
#  'masukmasuk',
#  'tulis',
#  'tunggu',
#  'bayar',
#  'saldo',
#  'potong',
#  'bayar',
#  'lamalama',
#  'apk',
#  'nya',
#  'kecewa',
#  'tolong',
#  'baik',
#  'bayar',
#  'tagih',
#  'paylater',
#  'saldo',
#  'atm',
#  'potong',
#  'hasil',
#  'aplikasi',
#  'tunggu',
#  'bayar',
#  'lapor',
#  'kemarin',
#  'respon',
#  'coba',
#  'cari',
#  'nomor',
#  'hubung',
#  'google',
#  'tipu',
#  'tolong',
#  'baik',
#  'telfon',
#  'bukalapak',
#  'paylater',
#  'aktif',
#  'kali',
#  'transaksi',
#  'bayar',
#  'paylater',
#  'langsung',
#  'batal',
#  'otomatis',
#  'cek',
#  'paylater',
#  'aktif',
#  'salah',
#  'ya',
#  'hun',
#  'cs',
#  'telepon',
#  'komplain',
#  'live',
#  'chat',
#  'buka',
#  'kolom',
#  'chat',
#  'nya',
#  'tolong',
#  'tanggap',
#  'nya',
#  'senang',
#  'sayalive',
#  'chatnya',
#  'susahyang',
#  'layan',
#  'robot',
#  'terusni',
#  'usaha',
#  'warung',
#  'kelontong',
#  'sihminta',
#  'bantu',
#  'susahmasa',
#  'saldo',
#  'pakai',
#  'beli',
#  'paket',
#  'datacuma',
#  'harga',
#  'anmasa',
#  'saldo',
#  'tahangawat',
#  'iniklo',
#  'dadak',
#  'habis',
#  'datagimana',
#  'tuh',
#  'tuh',
#  'bintang',
#  'parah',
#  'bangettolong',
#  'baik',
#  'inikarena',
#  'butuh',
#  'kamiuang',
#  'tahan',
#  'aplikasi',
#  'jelek',
#  'tari',
#  'saldo',
#  'dompet',
#  'rekening',
#  'ribet',
#  'proses',
#  'adu',
#  'komplain',
#  'slow',
#  'respon',
#  'duit',
#  'duit',
#  'bukalapak',
#  'susah',
#  'hubung',
#  'bukalapak',
#  'kait',
#  'fitur',
#  'apk',
#  'bukalapak',
#  'hilang',
#  'nya',
#  'fitur',
#  'lapak',
#  'langgan',
#  'barang',
#  'favorit',
#  'searching',
#  'rubah',
#  'bintang',
#  'buka',
#  'bantu',
#  'bukalapak',
#  'guna',
#  'hubung',
#  'transaksi',
#  'jual',
#  'barang',
#  'kirim',
#  'kurir',
#  'wahana',
#  'resi',
#  'otomatis',
#  'diupdate',
#  'sistem',
#  'bukalapak',
#  'transaksi',
#  'batal',
#  'otomatis',
#  'hubung',
#  'buka',
#  'bantu',
#  'update',
#  'resi',
#  'cek',
#  'manual',
#  'barang',
#  'kirim',
#  'jalan',
#  'voucher',
#  'gratis',
#  'ongkir',
#  'biaya',
#  'tambah',
#  'tolong',
#  'dirinci',
#  'lacak',
#  'paket',
#  'kalo',
#  'paket',
#  'antar',
#  'kasih',
#  'notifikasi',
#  'kalo',
#  'paket',
#  'antar',
#  'alamat',
#  'terima',
#  'sistem',
#  'cod',
#  'paket',
#  'terima',
#  'kalo',
#  'klik',
#  'terima',
#  'pesan',
#  'diberitahu',
#  'kurir',
#  'jalan',
#  'moga',
#  'depan',
#  'tanggap',
#  'aplikasi',
#  'milik',
#  'milik',
#  'kompeten',
#  'payah',
#  'hubung',
#  'bantu',
#  'susah',
#  'ampun',
#  'coba',
#  'kaitin',
#  'akun',
#  'dana',
#  'susah',
#  'gagal',
#  'aneh',
#  'akun',
#  'dana',
#  'nya',
#  'ikat',
#  'apk',
#  'bukalapaknya',
#  'ngaktifin',
#  'bukapaylater',
#  'pakai',
#  'belanja',
#  'iya',
#  'biaya',
#  'layan',
#  'mahal',
#  'kali',
#  'lipat',
#  'banding',
#  'transaksi',
#  'laku',
#  'payah',
#  'kalo',
#  'ada',
#  'voucher',
#  'diskon',
#  'bayar',
#  'plus',
#  'jdiny',
#  'keri',
#  'belanja',
#  'bukalapak',
#  'beli',
#  'diangap',
#  'jahat',
#  'main',
#  'beku',
#  'akun',
#  'orang',
#  'akun',
#  'kredivo',
#  'beku',
#  'akun',
#  'akulaku',
#  'beku',
#  'jahat',
#  'beli',
#  'jual',
#  'hati',
#  'hati',
#  'belanja',
#  'bukalapak',
#  'pakai',
#  'kredivo',
#  'akulaku',
#  'sayang',
#  'akun',
#  'mending',
#  'belanja',
#  'toped',
#  'aman',
#  'nyaman',
#  'minim',
#  'jual',
#  'jahat',
#  'mohon',
#  'maaftidak',
#  'rekomendasi',
#  'banget',
#  'aplikasi',
#  'nya',
#  'paylatter',
#  'nya',
#  'kena',
#  'layan',
#  'transaksi',
#  'rugi',
#  'biaya',
#  'layan',
#  'nya',
#  'belanja',
#  'bintang',
#  'bicara',
#  'alam',
#  'aplikasi',
#  'kagak',
#  'beli',
#  'latih',
#  'prakerja',
#  'vocer',
#  'valid',
#  'kontak',
#  'cs',
#  'baharu',
#  'vocer',
#  'valid',
#  'jadwal',
#  'latih',
#  'vocer',
#  'ridem',
#  'jadwal',
#  'latih',
#  'sungguh',
#  'kagak',
#  'sambung',
#  'sesal',
#  'transaksi',
#  'aplikasi',
#  'mending',
#  'lihat',
#  'lihat',
#  'ulas',
#  'aplikasi',
#  'biar',
#  'kagak',
#  'sesal',
#  'jelek',
#  'komplen',
#  'hubung',
#  'csbarang',
#  'gagal',
#  'rim',
#  'barang',
#  'returdi',
#  'cek',
#  'jasa',
#  'kirim',
#  'terus',
#  'kirim',
#  'barang',
#  'veritifikasi',
#  'email',
#  'sandi',
#  'daftar',
#  'bukalapak',
#  'aneh',
#  'banget',
#  'ganti',
#  'sandi',
#  'tulis',
#  'sandi',
#  'baik',
#  'aneh',
#  'banget',
#  'serbu',
#  'meleset',
#  'meleset',
#  'meleset',
#  'meleset',
#  'meleset',
#  'habis',
#  'uang',
#  'dana',
#  'roda',
#  'putar',
#  'mentooog',
#  'potong',
#  'ongkir',
#  'keren',
#  'dikit',
#  'belanja',
#  'bl',
#  'sungguh',
#  'sayangtidak',
#  'bonus',
#  'saran',
#  'bl',
#  'kalo',
#  'kasih',
#  'hadiah',
#  'pakai',
#  'serbu',
#  'kasih',
#  'harga',
#  'langgan',
#  'aplikasi',
#  'pindah',
#  'shoopee',
#  'janji',
#  'nyatasudah',
#  'aku',
#  'member',
#  'platinum',
#  'estimasi',
#  'barang',
#  'lenceng',
#  'kupon',
#  'diskon',
#  'promo',
#  'aman',
#  'kirim',
#  'barang',
#  'sok',
#  'far',
#  'sok',
#  'good',
#  'tingkat',
#  'nyaman',
#  'beli',
#  'bukalapak',
#  'membantusaat',
#  'beli',
#  'pulsatoken',
#  'listrik',
#  'butuh',
#  'nya',
#  'bukalapak',
#  'atas',
#  'ribet',
#  'andal',
#  'cepatsemua',
#  'atas',
#  'cepat',
#  'aman',
#  'memuaskanmaju',
#  'inovatif',
#  'bukalapak',
#  'aplikasi',
#  'bantu',
#  'belanja',
#  'bayar',
#  'depantapi',
#  'sayang',
#  'biaya',
#  'admin',
#  'ribu',
#  'bulan',
#  'kalo',
#  'paylater',
#  'pakaiklo',
#  'ilangin',
#  'yalimit',
#  'bos',
#  'buka',
#  'bantu',
#  'nya',
#  'bantu',
#  'memperaulitcall',
#  'center',
#  'nya',
#  'kes',
#  'malas',
#  'tanggap',
#  'keluh',
#  'pelanggansemua',
#  'syarat',
#  'dibpenuhichat',
#  'alihkanni',
#  'buka',
#  'bantuanmemalukan',
#  'transaksi',
#  'bermasalahga',
#  'pertqma',
#  'taman',
#  'kemari',
#  'parahcall',
#  'centernya',
#  'latih',
#  'nihbuat',
#  'hilang',
#  'langgan',
#  'bukalapak',
#  'tuh',
#  'rugi',
#  'rp',
#  'top',
#  'up',
#  'dana',
#  'bukalapak',
#  'bayar',
#  'via',
#  'atm',
#  'bri',
#  'struk',
#  'bayar',
#  'saldo',
#  'masuk',
#  'henti',
#  'tunggu',
#  'bayar',
#  'rugi',
#  'beli',
#  'masak',
#  'barang',
#  'bayar',
#  'nunggunya',
#  'batal',
#  'uang',
#  'kembali',
#  'rbuan',
#  'alas',
#  'ongkir',
#  'jasa',
#  'kirim',
#  'mutu',
#  'komplin',
#  'klik',
#  'layan',
#  'bantu',
#  'komplin',
#  'blokir',
#  'iklan',
#  'halaman',
#  'pakai',
#  'klik',
#  'tinggal',
#  'bl',
#  'ribet',
#  'super',
#  'seller',
#  'kuota',
#  'barang',
#  'dagang',
#  'jual',
#  'antik',
#  'unik',
#  'bayar',
#  'pakai',
#  'bayar',
#  'quota',
#  'barang',
#  'terang',
#  'promosi',
#  'toko',
#  'belah',
#  'bodoh',
#  'wajib',
#  'aplikasi',
#  'dana',
#  'tolol',
#  'tolol',
#  'pakai',
#  'dana',
#  'bobol',
#  'saldo',
#  'aju',
#  'komplen',
#  'lapak',
#  'nakal',
#  'ribet',
#  'transaksi',
#  'status',
#  'barang',
#  'kirim',
#  'terima',
#  'tolong',
#  'tambah',
#  'fitur',
#  'respon',
#  'cepat',
#  'fitur',
#  'bantun',
#  'bantu',
#  'langgan',
#  'paylater',
#  'bayar',
#  'limit',
#  'tambah',
#  'moga',
#  'aplikasi',
#  'bukalapak',
#  'aplikasi',
#  'bantu',
#  'belanja',
#  'mudah',
#  'repot',
#  'rumah',
#  'proses',
#  'belanja',
#  'lancar',
#  'bukalapak',
#  'oye',
#  'aman',
#  'nyaman',
#  'alam',
#  'jasa',
#  'ketemu',
#  'lapak',
#  'abal',
#  'abal',
#  'tipu',
#  'cepat',
#  'buka',
#  'lapak',
#  'turun',
#  'tangan',
#  'bantu',
#  'selamat',
#  'uang',
#  'uang',
#  'juta',
#  'selamat',
#  'terima',
#  'kasih',
#  'buka',
#  'lapak',
#  'fitur',
#  'buka',
#  'lapak',
#  'eror',
#  'sulit',
#  'buka',
#  'muter',
#  'vocer',
#  'aplikasi',
#  'aneh',
#  'paylater',
#  'masalah',
#  'bayar',
#  'ya',
#  'deh',
#  'paylater',
#  'repot',
#  'beli',
#  'barang',
#  'harga',
#  'ribu',
#  'bulan',
#  'dana',
#  'tahan',
#  'kasih',
#  'terus',
#  'jual',
#  'tekan',
#  'tombol',
#  'terima',
#  'cs',
#  'nya',
#  'parah',
#  'banget',
#  'kalo',
#  'dana',
#  'oper',
#  'jual',
#  'kurang',
#  'nya',
#  'bukalapak',
#  'ongkir',
#  'nya',
#  'mahal',
#  'kirim',
#  'nya',
#  'lambat',
#  'chat',
#  'lapak',
#  ...]

# %%
fqdist = FreqDist(tokenize_ulasan)

# %%
fqdist
# Out:
# FreqDist({'aplikasi': 484, 'bukalapak': 473, 'barang': 421, 'nya': 408, 'kirim': 246, 'buka': 238, 'beli': 236, 'bayar': 223, 'pakai': 206, 'belanja': 206, ...})

# %% [markdown]
# # **Mencetak 15 Kata Paling Banyak Digunakan**

# %%
fqdist.most_common(15)
# Out:
# [('aplikasi', 484),
#  ('bukalapak', 473),
#  ('barang', 421),
#  ('nya', 408),
#  ('kirim', 246),
#  ('buka', 238),
#  ('beli', 236),
#  ('bayar', 223),
#  ('pakai', 206),
#  ('belanja', 206),
#  ('lapak', 192),
#  ('transaksi', 184),
#  ('bantu', 177),
#  ('mudah', 161),
#  ('jual', 153)]

# %%
import matplotlib.pyplot as plt

# plotting
fqdist.plot(10,cumulative=False)
plt.show()

# %%
label = []
for index, row in name_dataframe.iterrows():
    if row["Rating"] == 5 or row["Rating"] == 4:
        label.append(1)
    else:
        label.append(0)

name_dataframe["label"] = label

name_dataframe
# Out:
#                  Nama pengguna  Rating                Date  \
# 0                   Wayan Gita       1 2023-08-10 13:36:28
# 1                      yOga 04       1 2023-08-01 03:19:16
# 2                Muhamad Basir       1 2023-06-10 15:44:50
# 3               Erick Matahine       1 2023-06-12 07:17:25
# 4                 ipin sopandi       1 2023-08-07 13:07:29
# ...                        ...     ...                 ...
# 1295                 Dede Kurt       1 2023-06-15 15:26:18
# 1296  Ahlul Fakri Almuthalliby       1 2023-06-10 15:45:56
# 1297              eka jayaos46       5 2023-07-11 10:23:31
# 1298                 Hero Hero       5 2023-06-18 07:47:11
# 1299                 aris dude       5 2023-07-06 03:03:21
#
#                                                  Ulasan  \
# 0     fitur bukabantuan nggak guna aplikasi ribet ad...
# 1     aplikasi marketplace paling ancur sistem bukab...
# 2     bingung bgt mau hub cs caranya gmn mau ngaktif...
# 3     lagi asyikasyiknya nemu barang yang diincar ee...
# 4     nggak bisa komplain sudah seminggu permintaan ...
# ...                                                 ...
# 1295  ga jelas sinyal bagus malah internet tidak ter...
# 1296  saya ingin membeli pelatihan prakerja tapi tid...
# 1297  sangat membantu berjualan dan berbelanja terim...
# 1298            lebih lengkap lagi untuk jualan nya gan
# 1299   sangat membantu paylaternya naikin limitnya dong
#
#                                         Ulasan_tokenize  \
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [aplikasi, marketplace, paling, ancur, sistem,...
# 2     [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3     [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4     [nggak, bisa, komplain, sudah, seminggu, permi...
# ...                                                 ...
# 1295  [ga, jelas, sinyal, bagus, malah, internet, ti...
# 1296  [saya, ingin, membeli, pelatihan, prakerja, ta...
# 1297  [sangat, membantu, berjualan, dan, berbelanja,...
# 1298    [lebih, lengkap, lagi, untuk, jualan, nya, gan]
# 1299  [sangat, membantu, paylaternya, naikin, limitn...
#
#                                             ulasan_ears  \
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [aplikasi, marketplace, paling, ancur, sistem,...
# 2     [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3     [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4     [nggak, bisa, komplain, sudah, seminggu, permi...
# ...                                                 ...
# 1295  [ga, jelas, sinyal, bagus, malah, internet, ti...
# 1296  [saya, ingin, membeli, pelatihan, prakerja, ta...
# 1297  [sangat, membantu, berjualan, dan, berbelanja,...
# 1298         [lebih, lengkap, lagi, untuk, jualan, gan]
# 1299  [sangat, membantu, paylaternya, naikin, limitn...
#
#                                       Ulasan_normalized  \
# 0     [fitur, bukabantuan, enggak, guna, aplikasi, r...
# 1     [aplikasi, marketplace, paling, hancur, sistem...
# 2     [bingung, banget, mau, hubungi, cs, caranya, b...
# 3     [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4     [enggak, bisa, komplain, sudah, seminggu, perm...
# ...                                                 ...
# 1295  [enggak, jelas, sinyal, bagus, malah, internet...
# 1296  [saya, ingin, membeli, pelatihan, prakerja, ta...
# 1297  [sangat, membantu, berjualan, dan, berbelanja,...
# 1298    [lebih, lengkap, lagi, untuk, jualan, nya, gan]
# 1299  [sangat, membantu, paylaternya, naikin, limitn...
#
#                                     Ulasan_stop_removed  \
# 0     [fitur, bukabantuan, aplikasi, ribet, saldo, d...
# 1     [aplikasi, marketplace, hancur, sistem, bukaba...
# 2     [bingung, banget, hubungi, cs, ngaktifin, fitu...
# 3     [asyikasyiknya, nemu, barang, diincar, eh, mun...
# 4     [komplain, seminggu, permintaan, pencairan, da...
# ...                                                 ...
# 1295              [sinyal, bagus, internet, tersambung]
# 1296  [membeli, pelatihan, prakerja, memilih, jadwal...
# 1297  [membantu, berjualan, berbelanja, terima, kasi...
# 1298                        [lengkap, jualan, nya, gan]
# 1299          [membantu, paylaternya, naikin, limitnya]
#
#                                          Ulasan_Stemmed  \
# 0     [fitur, bukabantuan, aplikasi, ribet, saldo, p...
# 1     [aplikasi, marketplace, hancur, sistem, bukaba...
# 2     [bingung, banget, hubung, cs, ngaktifin, fitur...
# 3     [asyikasyiknya, nemu, barang, incar, eh, muncu...
# 4     [komplain, minggu, minta, cair, dana, rekening...
# ...                                                 ...
# 1295                 [sinyal, bagus, internet, sambung]
# 1296  [beli, latih, prakerja, pilih, jadwal, tolong,...
# 1297  [bantu, jual, belanja, terima, kasih, sukses, ...
# 1298                          [lengkap, jual, nya, gan]
# 1299                [bantu, paylaternya, naikin, limit]
#
#                                             Ulasan_siap  label
# 0     fitur bukabantuan aplikasi ribet saldo pakai c...      0
# 1     aplikasi marketplace hancur sistem bukabantuan...      0
# 2     bingung banget hubung cs ngaktifin fitur live ...      0
# 3     asyikasyiknya nemu barang incar eh muncul popu...      0
# 4     komplain minggu minta cair dana rekening priba...      0
# ...                                                 ...    ...
# 1295                      sinyal bagus internet sambung      0
# 1296       beli latih prakerja pilih jadwal tolong baik      0
# 1297  bantu jual belanja terima kasih sukses ya buka...      1
# 1298                               lengkap jual nya gan      1
# 1299                     bantu paylaternya naikin limit      1
#
# [1300 rows x 11 columns]

# %% [markdown]
# # **Subjekvity dan Polarity**

# %%
from textblob import TextBlob
def getSubjectivity(review):
 return TextBlob(review).sentiment.subjectivity
def getPolarity(review):
 return TextBlob(review).sentiment.polarity
def analyze(score):
 if score < 0:
    return 'Negative'
 elif score == 0:
    return 'Neutral'
 else:
    return 'Positive'

# %%
name_dataframe['Subjectivity'] = name_dataframe['Ulasan_siap'].apply(getSubjectivity)
name_dataframe['Polarity'] = name_dataframe['Ulasan_siap'].apply(getPolarity)
name_dataframe['Sentiment'] = name_dataframe['Polarity'].apply(analyze)
name_dataframe.head()
# Out:
#     Nama pengguna  Rating                Date  \
# 0      Wayan Gita       1 2023-08-10 13:36:28
# 1         yOga 04       1 2023-08-01 03:19:16
# 2   Muhamad Basir       1 2023-06-10 15:44:50
# 3  Erick Matahine       1 2023-06-12 07:17:25
# 4    ipin sopandi       1 2023-08-07 13:07:29
#
#                                               Ulasan  \
# 0  fitur bukabantuan nggak guna aplikasi ribet ad...
# 1  aplikasi marketplace paling ancur sistem bukab...
# 2  bingung bgt mau hub cs caranya gmn mau ngaktif...
# 3  lagi asyikasyiknya nemu barang yang diincar ee...
# 4  nggak bisa komplain sudah seminggu permintaan ...
#
#                                      Ulasan_tokenize  \
# 0  [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1  [aplikasi, marketplace, paling, ancur, sistem,...
# 2  [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3  [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4  [nggak, bisa, komplain, sudah, seminggu, permi...
#
#                                          ulasan_ears  \
# 0  [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1  [aplikasi, marketplace, paling, ancur, sistem,...
# 2  [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3  [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4  [nggak, bisa, komplain, sudah, seminggu, permi...
#
#                                    Ulasan_normalized  \
# 0  [fitur, bukabantuan, enggak, guna, aplikasi, r...
# 1  [aplikasi, marketplace, paling, hancur, sistem...
# 2  [bingung, banget, mau, hubungi, cs, caranya, b...
# 3  [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4  [enggak, bisa, komplain, sudah, seminggu, perm...
#
#                                  Ulasan_stop_removed  \
# 0  [fitur, bukabantuan, aplikasi, ribet, saldo, d...
# 1  [aplikasi, marketplace, hancur, sistem, bukaba...
# 2  [bingung, banget, hubungi, cs, ngaktifin, fitu...
# 3  [asyikasyiknya, nemu, barang, diincar, eh, mun...
# 4  [komplain, seminggu, permintaan, pencairan, da...
#
#                                       Ulasan_Stemmed  \
# 0  [fitur, bukabantuan, aplikasi, ribet, saldo, p...
# 1  [aplikasi, marketplace, hancur, sistem, bukaba...
# 2  [bingung, banget, hubung, cs, ngaktifin, fitur...
# 3  [asyikasyiknya, nemu, barang, incar, eh, muncu...
# 4  [komplain, minggu, minta, cair, dana, rekening...
#
#                                          Ulasan_siap  label  Subjectivity  \
# 0  fitur bukabantuan aplikasi ribet saldo pakai c...      0           0.0
# 1  aplikasi marketplace hancur sistem bukabantuan...      0           0.5
# 2  bingung banget hubung cs ngaktifin fitur live ...      0           0.5
# 3  asyikasyiknya nemu barang incar eh muncul popu...      0           0.0
# 4  komplain minggu minta cair dana rekening priba...      0           0.0
#
#    Polarity Sentiment
# 0  0.000000   Neutral
# 1  0.136364  Positive
# 2  0.136364  Positive
# 3  0.000000   Neutral
# 4  0.000000   Neutral

# %%
name_dataframe.head()
# Out:
#     Nama pengguna  Rating                Date  \
# 0      Wayan Gita       1 2023-08-10 13:36:28
# 1         yOga 04       1 2023-08-01 03:19:16
# 2   Muhamad Basir       1 2023-06-10 15:44:50
# 3  Erick Matahine       1 2023-06-12 07:17:25
# 4    ipin sopandi       1 2023-08-07 13:07:29
#
#                                               Ulasan  \
# 0  fitur bukabantuan nggak guna aplikasi ribet ad...
# 1  aplikasi marketplace paling ancur sistem bukab...
# 2  bingung bgt mau hub cs caranya gmn mau ngaktif...
# 3  lagi asyikasyiknya nemu barang yang diincar ee...
# 4  nggak bisa komplain sudah seminggu permintaan ...
#
#                                      Ulasan_tokenize  \
# 0  [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1  [aplikasi, marketplace, paling, ancur, sistem,...
# 2  [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3  [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4  [nggak, bisa, komplain, sudah, seminggu, permi...
#
#                                          ulasan_ears  \
# 0  [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1  [aplikasi, marketplace, paling, ancur, sistem,...
# 2  [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3  [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4  [nggak, bisa, komplain, sudah, seminggu, permi...
#
#                                    Ulasan_normalized  \
# 0  [fitur, bukabantuan, enggak, guna, aplikasi, r...
# 1  [aplikasi, marketplace, paling, hancur, sistem...
# 2  [bingung, banget, mau, hubungi, cs, caranya, b...
# 3  [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4  [enggak, bisa, komplain, sudah, seminggu, perm...
#
#                                  Ulasan_stop_removed  \
# 0  [fitur, bukabantuan, aplikasi, ribet, saldo, d...
# 1  [aplikasi, marketplace, hancur, sistem, bukaba...
# 2  [bingung, banget, hubungi, cs, ngaktifin, fitu...
# 3  [asyikasyiknya, nemu, barang, diincar, eh, mun...
# 4  [komplain, seminggu, permintaan, pencairan, da...
#
#                                       Ulasan_Stemmed  \
# 0  [fitur, bukabantuan, aplikasi, ribet, saldo, p...
# 1  [aplikasi, marketplace, hancur, sistem, bukaba...
# 2  [bingung, banget, hubung, cs, ngaktifin, fitur...
# 3  [asyikasyiknya, nemu, barang, incar, eh, muncu...
# 4  [komplain, minggu, minta, cair, dana, rekening...
#
#                                          Ulasan_siap  label  Subjectivity  \
# 0  fitur bukabantuan aplikasi ribet saldo pakai c...      0           0.0
# 1  aplikasi marketplace hancur sistem bukabantuan...      0           0.5
# 2  bingung banget hubung cs ngaktifin fitur live ...      0           0.5
# 3  asyikasyiknya nemu barang incar eh muncul popu...      0           0.0
# 4  komplain minggu minta cair dana rekening priba...      0           0.0
#
#    Polarity Sentiment
# 0  0.000000   Neutral
# 1  0.136364  Positive
# 2  0.136364  Positive
# 3  0.000000   Neutral
# 4  0.000000   Neutral

# %%
from textblob import TextBlob

# %%
name_dataframe['month'] = name_dataframe['Date'].dt.month

# %%
name_dataframe
# Out:
#                  Nama pengguna  Rating                Date  \
# 0                   Wayan Gita       1 2023-08-10 13:36:28
# 1                      yOga 04       1 2023-08-01 03:19:16
# 2                Muhamad Basir       1 2023-06-10 15:44:50
# 3               Erick Matahine       1 2023-06-12 07:17:25
# 4                 ipin sopandi       1 2023-08-07 13:07:29
# ...                        ...     ...                 ...
# 1295                 Dede Kurt       1 2023-06-15 15:26:18
# 1296  Ahlul Fakri Almuthalliby       1 2023-06-10 15:45:56
# 1297              eka jayaos46       5 2023-07-11 10:23:31
# 1298                 Hero Hero       5 2023-06-18 07:47:11
# 1299                 aris dude       5 2023-07-06 03:03:21
#
#                                                  Ulasan  \
# 0     fitur bukabantuan nggak guna aplikasi ribet ad...
# 1     aplikasi marketplace paling ancur sistem bukab...
# 2     bingung bgt mau hub cs caranya gmn mau ngaktif...
# 3     lagi asyikasyiknya nemu barang yang diincar ee...
# 4     nggak bisa komplain sudah seminggu permintaan ...
# ...                                                 ...
# 1295  ga jelas sinyal bagus malah internet tidak ter...
# 1296  saya ingin membeli pelatihan prakerja tapi tid...
# 1297  sangat membantu berjualan dan berbelanja terim...
# 1298            lebih lengkap lagi untuk jualan nya gan
# 1299   sangat membantu paylaternya naikin limitnya dong
#
#                                         Ulasan_tokenize  \
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [aplikasi, marketplace, paling, ancur, sistem,...
# 2     [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3     [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4     [nggak, bisa, komplain, sudah, seminggu, permi...
# ...                                                 ...
# 1295  [ga, jelas, sinyal, bagus, malah, internet, ti...
# 1296  [saya, ingin, membeli, pelatihan, prakerja, ta...
# 1297  [sangat, membantu, berjualan, dan, berbelanja,...
# 1298    [lebih, lengkap, lagi, untuk, jualan, nya, gan]
# 1299  [sangat, membantu, paylaternya, naikin, limitn...
#
#                                             ulasan_ears  \
# 0     [fitur, bukabantuan, nggak, guna, aplikasi, ri...
# 1     [aplikasi, marketplace, paling, ancur, sistem,...
# 2     [bingung, bgt, mau, hub, cs, caranya, gmn, mau...
# 3     [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4     [nggak, bisa, komplain, sudah, seminggu, permi...
# ...                                                 ...
# 1295  [ga, jelas, sinyal, bagus, malah, internet, ti...
# 1296  [saya, ingin, membeli, pelatihan, prakerja, ta...
# 1297  [sangat, membantu, berjualan, dan, berbelanja,...
# 1298         [lebih, lengkap, lagi, untuk, jualan, gan]
# 1299  [sangat, membantu, paylaternya, naikin, limitn...
#
#                                       Ulasan_normalized  \
# 0     [fitur, bukabantuan, enggak, guna, aplikasi, r...
# 1     [aplikasi, marketplace, paling, hancur, sistem...
# 2     [bingung, banget, mau, hubungi, cs, caranya, b...
# 3     [lagi, asyikasyiknya, nemu, barang, yang, diin...
# 4     [enggak, bisa, komplain, sudah, seminggu, perm...
# ...                                                 ...
# 1295  [enggak, jelas, sinyal, bagus, malah, internet...
# 1296  [saya, ingin, membeli, pelatihan, prakerja, ta...
# 1297  [sangat, membantu, berjualan, dan, berbelanja,...
# 1298    [lebih, lengkap, lagi, untuk, jualan, nya, gan]
# 1299  [sangat, membantu, paylaternya, naikin, limitn...
#
#                                     Ulasan_stop_removed  \
# 0     [fitur, bukabantuan, aplikasi, ribet, saldo, d...
# 1     [aplikasi, marketplace, hancur, sistem, bukaba...
# 2     [bingung, banget, hubungi, cs, ngaktifin, fitu...
# 3     [asyikasyiknya, nemu, barang, diincar, eh, mun...
# 4     [komplain, seminggu, permintaan, pencairan, da...
# ...                                                 ...
# 1295              [sinyal, bagus, internet, tersambung]
# 1296  [membeli, pelatihan, prakerja, memilih, jadwal...
# 1297  [membantu, berjualan, berbelanja, terima, kasi...
# 1298                        [lengkap, jualan, nya, gan]
# 1299          [membantu, paylaternya, naikin, limitnya]
#
#                                          Ulasan_Stemmed  \
# 0     [fitur, bukabantuan, aplikasi, ribet, saldo, p...
# 1     [aplikasi, marketplace, hancur, sistem, bukaba...
# 2     [bingung, banget, hubung, cs, ngaktifin, fitur...
# 3     [asyikasyiknya, nemu, barang, incar, eh, muncu...
# 4     [komplain, minggu, minta, cair, dana, rekening...
# ...                                                 ...
# 1295                 [sinyal, bagus, internet, sambung]
# 1296  [beli, latih, prakerja, pilih, jadwal, tolong,...
# 1297  [bantu, jual, belanja, terima, kasih, sukses, ...
# 1298                          [lengkap, jual, nya, gan]
# 1299                [bantu, paylaternya, naikin, limit]
#
#                                             Ulasan_siap  label  Subjectivity  \
# 0     fitur bukabantuan aplikasi ribet saldo pakai c...      0           0.0
# 1     aplikasi marketplace hancur sistem bukabantuan...      0           0.5
# 2     bingung banget hubung cs ngaktifin fitur live ...      0           0.5
# 3     asyikasyiknya nemu barang incar eh muncul popu...      0           0.0
# 4     komplain minggu minta cair dana rekening priba...      0           0.0
# ...                                                 ...    ...           ...
# 1295                      sinyal bagus internet sambung      0           0.0
# 1296       beli latih prakerja pilih jadwal tolong baik      0           0.0
# 1297  bantu jual belanja terima kasih sukses ya buka...      1           0.0
# 1298                               lengkap jual nya gan      1           0.0
# 1299                     bantu paylaternya naikin limit      1           0.0
#
#       Polarity Sentiment  month
# 0     0.000000   Neutral      8
# 1     0.136364  Positive      8
# 2     0.136364  Positive      6
# 3     0.000000   Neutral      6
# 4     0.000000   Neutral      8
# ...        ...       ...    ...
# 1295  0.000000   Neutral      6
# 1296  0.000000   Neutral      6
# 1297  0.000000   Neutral      7
# 1298  0.000000   Neutral      6
# 1299  0.000000   Neutral      7
#
# [1300 rows x 15 columns]

# %%
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # **Visualisasi Bobot Nilai**

# %%
# Create scatter plot
sns.set_style('darkgrid')
plt.figure(figsize = (15,7))

markers = {'Positive':'o', 'Neutral':'s','Negative':'X'}

sns.scatterplot(data=name_dataframe, x='Polarity', y='Subjectivity', hue = 'Sentiment', style = 'Sentiment', markers = markers, palette = 'gist_earth').set(xlim=(-1,1))
plt.title('Scatter Plot')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')

plt.tight_layout()

# %% [markdown]
# # **Visualiasi Polarity dan subjecvity perbulan**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group by month and sentiment
sentiment_df = name_dataframe.groupby(['month', 'Sentiment']).size().reset_index(name='Count')


# Plot the sentiment counts by month
plt.figure(figsize=(12, 6))
sns.lineplot(x='month', y='Count', hue='Sentiment', data=sentiment_df)
plt.title('Sentiment by Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %%
sentimen_data=pd.value_counts(name_dataframe["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["green", "red", "black"])
plt.title('Bar chart')
plt.show()

# %%
name_dataframe["Sentiment"].value_counts()
# Out:
# Neutral     1088
# Positive     167
# Negative      45
# Name: Sentiment, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
Ulasan = name_dataframe['Ulasan_siap']

# %%
Ulasan.isnull().sum()
# Out:
# 0

# %% [markdown]
# # **Proses (TF-IDF)**

# %%
#untuk menghitung jumlah kata yang telah di steming
cv = CountVectorizer()
term_fit = cv.fit(Ulasan)

print (len(term_fit.vocabulary_))
# Out:
# 3558

# %%
term_fit.vocabulary_ #mengurutkan berdasarkan urutab abjad kata
# Out:
# {'fitur': 1047,
#  'bukabantuan': 528,
#  'aplikasi': 189,
#  'ribet': 2733,
#  'saldo': 2795,
#  'pakai': 2345,
#  'cairin': 615,
#  'transfer': 3344,
#  'banget': 275,
#  'password': 2387,
#  'bilang': 441,
#  'salah': 2794,
#  'riset': 2753,
#  'dikit': 860,
#  'selesai': 2896,
#  'notifikasi': 2206,
#  'sistem': 3020,
#  'eror': 994,
#  'sih': 3001,
#  'marketplace': 1935,
#  'hancur': 1188,
#  'selesain': 2898,
#  'lari': 1774,
#  'live': 1843,
#  'chatnya': 676,
#  'paylaternya': 2399,
#  'bobrok': 493,
#  'sila': 3005,
#  'coba': 691,
#  'download': 923,
#  'tau': 3170,
#  'bingung': 443,
#  'hubung': 1245,
#  'cs': 725,
#  'ngaktifin': 2149,
#  'chat': 672,
#  'asih': 215,
#  'feedback': 1038,
#  'aktif': 84,
#  'lihat': 1824,
#  'transaksi': 3337,
#  'beli': 364,
#  'klik': 1605,
#  'tulis': 3381,
#  'ganggu': 1101,
#  'email': 977,
#  'kirim': 1593,
#  'tlol': 3295,
#  'asyikasyiknya': 224,
#  'nemu': 2139,
#  'barang': 303,
#  'incar': 1283,
#  'eh': 964,
#  'muncul': 2102,
#  'popupiklan': 2560,
#  'buka': 526,
#  'emas': 978,
#  'mana': 1908,
#  'close': 690,
#  'masuk': 1944,
#  'menu': 2021,
#  'beranda': 385,
#  'deh': 789,
#  'tokopedia': 3308,
#  'shopee': 2981,
#  'belanja': 354,
#  'depan': 798,
#  'banyak': 299,
#  'popup': 2559,
#  'jujur': 1431,
#  'uninstal': 3423,
#  'komplain': 1630,
#  'minggu': 2046,
#  'minta': 2053,
#  'cair': 614,
#  'dana': 760,
#  'rekening': 2686,
#  'pribadi': 2579,
#  'hasil': 1205,
#  'tolong': 3317,
#  'kerjasamanya': 1565,
#  'bukabantuannya': 529,
#  'next': 2142,
#  'bintang': 447,
#  'ubah': 3402,
#  'update': 3438,
#  'suka': 3094,
#  'error': 997,
#  'cepat': 655,
#  'errorbarusan': 998,
#  'turun': 3391,
#  'notif': 2205,
#  'tagih': 3135,
#  'hilang': 1222,
#  'bayar': 333,
#  'besok': 424,
#  'tanggal': 3157,
#  'juni': 1434,
#  'pagi': 2337,
#  'malam': 1902,
#  'cek': 644,
#  'detail': 805,
#  'pesan': 2502,
#  'mantap': 1922,
#  'kalo': 1463,
#  'paket': 2351,
#  'sedia': 2866,
#  'foto': 1063,
#  'bukti': 585,
#  'nyabiar': 2218,
#  'oh': 2259,
#  'nya': 2216,
#  'taro': 3168,
#  'situ': 3023,
#  'kurir': 1691,
#  'antar': 163,
#  'alamat': 107,
#  'posisi': 2562,
#  'aman': 125,
#  'konfirmasi': 1652,
#  'mohon': 2078,
#  'tingkat': 3283,
#  'bagus': 246,
#  'edit': 954,
#  'produk': 2594,
#  'gilir': 1124,
#  'ujung': 3407,
#  'iklan': 1268,
#  'jual': 1420,
#  'alias': 117,
#  'otomatis': 2316,
#  'hapus': 1196,
#  'bukalapak': 542,
#  'ulang': 3409,
#  'tinggal': 3282,
#  'nih': 2181,
#  'order': 2306,
#  'lapak': 1763,
#  'lambat': 1745,
#  'sehat': 2874,
#  'kondisi': 1647,
#  'baik': 256,
#  'status': 3073,
#  'batal': 321,
#  'parah': 2368,
#  'laksana': 1728,
#  'uang': 3400,
#  'refound': 2671,
#  'rugi': 2767,
#  'kesel': 1569,
#  'mesan': 2033,
#  'limit': 1825,
#  'aju': 70,
#  'sulit': 3098,
#  'mengunakan': 2011,
#  'paylatter': 2400,
#  'terima': 3221,
#  'kasih': 1484,
#  'diupdate': 899,
#  'bug': 523,
#  'contoh': 713,
#  'out': 2321,
#  'dibukak': 830,
#  'pantau': 2363,
#  'gera': 1116,
#  'baca': 240,
#  'virtual': 3483,
#  'account': 11,
#  'verifikasi': 3473,
#  'potong': 2568,
#  'arahanya': 207,
#  'langsung': 1756,
#  'alas': 110,
#  'koneksi': 1650,
#  'putus': 2630,
#  'ganti': 1102,
#  'selfilah': 2902,
#  'ktplah': 1675,
#  'mutasi': 2111,
#  'framelah': 1067,
#  'kembali': 1533,
#  'tangan': 3155,
#  'tim': 3278,
#  'tunggu': 3388,
#  'jam': 1359,
#  'percaya': 2484,
#  'respon': 2713,
#  'bel': 349,
#  'anggap': 149,
#  'kali': 1460,
#  'bl': 466,
#  'mbulet': 1963,
#  'apk': 181,
#  'internet': 1329,
#  'masukmasuk': 1947,
#  'lamalama': 1735,
#  'kecewa': 1501,
#  'paylater': 2398,
#  'atm': 227,
#  'lapor': 1773,
#  'kemarin': 1531,
#  'cari': 635,
#  'nomor': 2196,
#  'google': 1136,
#  'tipu': 3290,
#  'telfon': 3183,
#  'ya': 3537,
#  'hun': 1249,
#  'telepon': 3182,
#  'kolom': 1614,
#  'tanggap': 3158,
#  'senang': 2928,
#  'sayalive': 2833,
#  'susahyang': 3117,
#  'layan': 1780,
#  'robot': 2756,
#  'terusni': 3245,
#  'usaha': 3451,
#  'warung': 3510,
#  'kelontong': 1522,
#  'sihminta': 3002,
#  'bantu': 290,
#  'susahmasa': 3114,
#  'datacuma': 777,
#  'harga': 1199,
#  'anmasa': 162,
#  'tahangawat': 3141,
#  'iniklo': 1305,
#  'dadak': 749,
#  'habis': 1166,
#  'datagimana': 778,
#  'tuh': 3373,
#  'bangettolong': 281,
#  'inikarena': 1304,
#  'butuh': 601,
#  'kamiuang': 1465,
#  'tahan': 3140,
#  'jelek': 1400,
#  'tari': 3165,
#  'dompet': 913,
#  'proses': 2608,
#  'adu': 38,
#  'slow': 3031,
#  'duit': 937,
#  'susah': 3112,
#  'kait': 1451,
#  'langgan': 1754,
#  'favorit': 1032,
#  'searching': 2851,
#  'rubah': 2765,
#  'guna': 1156,
#  'wahana': 3499,
#  'resi': 2708,
#  'manual': 1926,
#  'jalan': 1357,
#  'voucher': 3491,
#  'gratis': 1143,
#  'ongkir': 2279,
#  'biaya': 434,
#  'tambah': 3150,
#  'dirinci': 878,
#  'lacak': 1701,
#  'cod': 694,
#  'diberitahu': 828,
#  'moga': 2077,
#  'milik': 2040,
#  'kompeten': 1626,
#  'payah': 2395,
#  'ampun': 136,
#  'kaitin': 1452,
#  'akun': 101,
#  'gagal': 1081,
#  'aneh': 145,
#  'ikat': 1265,
#  'bukalapaknya': 557,
#  'bukapaylater': 578,
#  'iya': 1347,
#  'mahal': 1886,
#  'lipat': 1838,
#  'banding': 271,
#  'laku': 1729,
#  'ada': 19,
#  'diskon': 883,
#  'plus': 2546,
#  'jdiny': 1387,
#  'keri': 1560,
#  'diangap': 819,
#  'jahat': 1354,
#  'main': 1889,
#  'beku': 346,
#  'orang': 2301,
#  'kredivo': 1672,
#  'akulaku': 99,
#  'hati': 1207,
#  'sayang': 2834,
#  'mending': 1998,
#  'toped': 3321,
#  'nyaman': 2227,
#  'minim': 2047,
#  'maaftidak': 1880,
#  'rekomendasi': 2690,
#  'kena': 1542,
#  'bicara': 436,
#  'alam': 106,
#  'kagak': 1448,
#  'latih': 1776,
#  'prakerja': 2572,
#  'vocer': 3488,
#  'valid': 3461,
#  'kontak': 1659,
#  'baharu': 254,
#  'jadwal': 1352,
#  'ridem': 2744,
#  'sungguh': 3102,
#  'sambung': 2801,
#  'sesal': 2959,
#  'ulas': 3410,
#  'biar': 433,
#  'komplen': 1638,
#  'csbarang': 726,
#  'rim': 2746,
#  'returdi': 2725,
#  'jasa': 1370,
#  'terus': 3243,
#  'veritifikasi': 3476,
#  'sandi': 2815,
#  'daftar': 752,
#  'serbu': 2944,
#  'meleset': 1968,
#  'roda': 2758,
#  'putar': 2627,
#  'mentooog': 2019,
#  'keren': 1557,
#  'sayangtidak': 2835,
#  'bonus': 498,
#  'saran': 2817,
#  'hadiah': 1176,
#  'pindah': 2521,
#  'shoopee': 2978,
#  'janji': 1364,
#  'nyatasudah': 2244,
#  'aku': 96,
#  'member': 1977,
#  'platinum': 2536,
#  'estimasi': 1003,
#  'lenceng': 1809,
#  'kupon': 1687,
#  'promo': 2603,
#  'sok': 3044,
#  'far': 1028,
#  'good': 1135,
#  'membantusaat': 1972,
#  'pulsatoken': 2621,
#  'listrik': 1842,
#  'atas': 225,
#  'andal': 141,
#  'cepatsemua': 663,
#  'memuaskanmaju': 1988,
#  'inovatif': 1315,
#  'depantapi': 799,
#  'admin': 33,
#  'ribu': 2741,
#  'bulan': 590,
#  'pakaiklo': 2347,
#  'ilangin': 1273,
#  'yalimit': 3544,
#  'bos': 502,
#  'memperaulitcall': 1985,
#  'center': 652,
#  'kes': 1566,
#  'malas': 1903,
#  'keluh': 1526,
#  'pelanggansemua': 2418,
#  'syarat': 3122,
#  'dibpenuhichat': 829,
#  'alihkanni': 119,
#  'bantuanmemalukan': 291,
#  'bermasalahga': 411,
#  'pertqma': 2499,
#  'taman': 3149,
#  'kemari': 1530,
#  'parahcall': 2369,
#  'centernya': 653,
#  'nihbuat': 2183,
#  'rp': 2763,
#  'top': 3320,
#  'up': 3437,
#  'via': 3479,
#  'bri': 509,
#  'struk': 3086,
#  'henti': 1215,
#  'masak': 1939,
#  'nunggunya': 2213,
#  'rbuan': 2659,
#  'mutu': 2114,
#  'komplin': 1641,
#  'blokir': 479,
#  'halaman': 1182,
#  'super': 3103,
#  'seller': 2905,
#  'kuota': 1686,
#  'dagang': 754,
#  'antik': 167,
#  'unik': 3421,
#  'quota': 2633,
#  'terang': 3206,
#  'promosi': 2606,
#  'toko': 3304,
#  'belah': 351,
#  'bodoh': 495,
#  'wajib': 3503,
#  'tolol': 3315,
#  'bobol': 492,
#  'nakal': 2125,
#  'bantun': 297,
#  'mudah': 2092,
#  'repot': 2702,
#  'rumah': 2768,
#  'lancar': 1750,
#  'oye': 2327,
#  'ketemu': 1575,
#  'abal': 3,
#  'selamat': 2892,
#  'juta': 1435,
#  'muter': 2112,
#  'masalah': 1940,
#  'tekan': 3176,
#  'tombol': 3318,
#  'oper': 2294,
#  'kurang': 1688,
#  'lalai': 1730,
#  'duluan': 940,
#  'saing': 2786,
#  'kompetitor': 1628,
#  'setting': 2970,
#  'maps': 1930,
#  'refresh': 2673,
#  'informasi': 1294,
#  'ekspedisi': 969,
#  'bukasend': 581,
#  'paksa': 2353,
#  'urus': 3450,
#  'refund': 2674,
#  'apa': 173,
#  'dicairin': 833,
#  'nominal': 2195,
#  'topup': 3323,
#  'ikhlasin': 1267,
#  'token': 3303,
#  'lalu': 1731,
#  'kah': 1450,
#  'ambil': 130,
#  'hak': 1181,
#  'pikir': 2515,
#  'pln': 2545,
#  'byar': 605,
#  'kadarluarsa': 1446,
#  'arah': 206,
#  'artikel': 210,
#  'ditemukanmakin': 891,
#  'heran': 1216,
#  'tidka': 3272,
#  'erti': 1001,
#  'prihal': 2582,
#  'payleter': 2403,
#  'enggak': 987,
#  'bisa': 452,
#  'mentok': 2018,
#  'macet': 1882,
#  'oernah': 2254,
#  'ain': 51,
#  'komplan': 1637,
#  'benah': 371,
#  'sinyal': 3014,
#  'jatuh': 1374,
#  'tempo': 3196,
#  'naikyg': 2123,
#  'mode': 2072,
#  'aga': 41,
#  'permanen': 2493,
#  'alih': 118,
#  'shoppy': 2988,
#  'aco': 16,
#  'search': 2850,
#  'item': 1340,
#  'maaf': 1879,
#  'pesananselalu': 2506,
#  'tulus': 3383,
#  'nomer': 2194,
#  'instal': 1318,
#  'nyampek': 2235,
#  'sekian': 2890,
#  'berat': 388,
#  'serasa': 2942,
#  'ekspres': 974,
#  'kerja': 1561,
#  'peniriman': 2464,
#  'tanggung': 3162,
#  'materi': 1954,
#  'semenjak': 2919,
#  'upgrade': 3443,
#  'call': 618,
#  'canter': 626,
#  'mencewakan': 1996,
#  'selsai': 2911,
#  'kacau': 1441,
#  'benarbenar': 373,
#  'retur': 2724,
#  'kode': 1610,
#  'otp': 2319,
#  'suruh': 3109,
#  'belikan': 367,
#  'pulsa': 2620,
#  'pantesan': 2364,
#  'merosot': 2031,
#  'tukang': 3379,
#  'nipu': 2187,
#  'program': 2601,
#  'jebak': 1389,
#  'bukalapakudah': 567,
#  'cekout': 647,
#  'payment': 2408,
#  'selesaitapidi': 2899,
#  'nyaakhirnya': 2217,
#  'kemanaudah': 1529,
#  'hubungin': 1247,
#  'sesuai': 2963,
#  'sedikitkecewa': 2868,
#  'sedih': 2867,
#  'mitra': 2059,
#  'efisien': 962,
#  'merk': 2030,
#  'alternatif': 124,
#  'pt': 2610,
#  'akuisisi': 98,
#  'brisaldo': 511,
#  'bayarparah': 334,
#  'ajaudh': 66,
#  'kadaluarsa': 1442,
#  'untung': 3435,
#  'doang': 906,
#  'cuihhh': 733,
#  'smartphone': 3034,
#  'kepala': 1552,
#  'pusing': 2625,
#  'layoutnya': 1788,
#  'beranta': 387,
#  'xxx': 3536,
#  'tampil': 3152,
#  'ponsel': 2556,
#  'aksesoris': 83,
#  'suku': 3097,
#  'cadang': 613,
#  'dll': 901,
#  'penantan': 2444,
#  'rapi': 2648,
#  'rekan': 2684,
#  'bosan': 504,
#  'jenuh': 1408,
#  'lanjut': 1759,
#  'kesini': 1572,
#  'seler': 2895,
#  'setatus': 2967,
#  'kadang': 1445,
#  'pemberitahuan': 2440,
#  'tiktok': 3277,
#  'mah': 1884,
#  'halo': 1186,
#  'lampau': 1747,
#  'batas': 327,
#  'dihubungichat': 849,
#  'tokoselernya': 3310,
#  'cerah': 665,
#  'ku': 1678,
#  'juli': 1433,
#  'rupa': 2771,
#  'hitung': 1233,
#  'ganda': 1099,
#  'pintar': 2527,
#  'rekom': 2689,
#  'ppob': 2570,
#  'pokok': 2554,
#  'satusaya': 2824,
#  'biyaya': 463,
#  'anehjelas': 146,
#  'knapa': 1608,
#  'sekalimohon': 2882,
#  'cashback': 639,
#  'sepi': 2940,
#  'online': 2290,
#  'lengkap': 1811,
#  'ktp': 1674,
#  'info': 1293,
#  'verifikasigak': 3474,
#  'upload': 3445,
#  'lot': 1861,
#  'curi': 738,
#  'pin': 2518,
#  'hape': 1195,
#  'bajak': 259,
#  'bawah': 331,
#  'ijo': 1261,
#  'ayo': 237,
#  'inovasiinovasi': 1314,
#  'kalah': 1458,
#  'hatihati': 1208,
#  'bekuin': 347,
#  'loh': 1857,
#  'tibatiba': 3268,
#  'game': 1093,
#  'panjang': 2360,
#  'umur': 3412,
#  'gulung': 1154,
#  'tikar': 3275,
#  'kayak': 1492,
#  'platform': 2535,
#  'nyamantidak': 2229,
#  'bukalapakselain': 564,
#  'mahalada': 1887,
#  'bebankanmending': 339,
#  'benermending': 375,
#  'tujuansudah': 3376,
#  'jaman': 1360,
#  'dibukalapak': 832,
#  'cancel': 623,
#  'stok': 3079,
#  'habisdan': 1167,
#  'dasar': 775,
#  'muat': 2090,
#  'trakhir': 3332,
#  'uninstall': 3425,
#  'apknya': 182,
#  'min': 2041,
#  'data': 776,
#  'maksimal': 1897,
#  'keteranganya': 1578,
#  'hp': 1239,
#  'beda': 343,
#  'mengatasnamakan': 2001,
#  'takut': 3147,
#  'disalahgunakan': 880,
#  'akses': 80,
#  'memeberikan': 1981,
#  'solusi': 3046,
#  'buruk': 596,
#  'lunas': 1872,
#  'pakaitrus': 2348,
#  'lansung': 1761,
#  'segitu': 2872,
#  'blapak': 470,
#  'nama': 2127,
#  'fungsi': 1073,
#  'login': 1852,
#  'bikin': 440,
#  'jarang': 1367,
#  'sd': 2847,
#  'metode': 2036,
#  'bank': 288,
#  'ocbc': 2253,
#  'nisp': 2188,
#  'lwh': 1876,
#  'pilih': 2517,
#  'kelas': 1518,
#  'tutup': 3395,
#  'whatsapp': 3520,
#  'payletter': 2405,
#  'rbbaru': 2658,
#  'kalieeeengga': 1461,
#  'lagiwk': 1713,
#  'wkkok': 3526,
#  'yabl': 3541,
#  'pengirimannyahrs': 2455,
#  'dipromo': 872,
#  'terimakasih': 3225,
#  'utakatik': 3456,
#  'lazada': 1789,
#  'shoppe': 2986,
#  'onderdilpart': 2276,
#  'pretel': 2578,
#  'ketik': 1580,
#  'mesin': 2034,
#  'cuci': 731,
#  'onderdil': 2275,
#  'evaluasi': 1008,
#  'inimungkin': 1306,
#  'option': 2300,
#  'sendiri': 2929,
#  'part': 2379,
#  'ongkos': 2287,
#  'tetap': 3255,
#  'expedisinya': 1016,
#  'tunda': 3386,
#  'ngambil': 2150,
#  'profesional': 2598,
#  'post': 2563,
#  'poto': 2567,
#  'ditokopedia': 897,
#  'poduk': 2550,
#  'brng': 514,
#  'seperri': 2939,
#  'seblum': 2859,
#  'ramai': 2643,
#  'un': 3414,
#  'install': 1319,
#  'shopeelazada': 2983,
#  'bukalapakakin': 543,
#  'erorr': 995,
#  'sekali': 2878,
#  'jawab': 1378,
#  'sengaja': 2932,
#  'makan': 1895,
#  'gaji': 1088,
#  'buta': 600,
#  'customer': 743,
#  'mundur': 2104,
#  'non': 2197,
#  'aktifsaya': 88,
#  'aktiftoko': 90,
#  'systemnya': 3125,
#  'maintenance': 1891,
#  'ecek': 949,
#  'wajar': 3502,
#  'aduh': 39,
#  'gercep': 1119,
#  'nyambing': 2230,
#  'digital': 839,
#  'mewq': 2037,
#  'iinv': 1260,
#  'sial': 2991,
#  'anjir': 160,
#  'balikin': 268,
#  'vouchernya': 3492,
#  'pembelikomplain': 2439,
#  'bisatpi': 460,
#  'jasalancar': 1371,
#  'motong': 2084,
#  'masalahpasti': 1942,
#  'komplainblm': 1632,
#  'ok': 2261,
#  'siang': 2992,
#  'camat': 622,
#  'livechat': 1844,
#  'khusus': 1587,
#  'olshop': 2270,
#  'customernya': 744,
#  'gmail': 1128,
#  'sajah': 2788,
#  'hari': 1201,
#  'jemput': 1405,
#  'dichat': 835,
#  'barangbarang': 304,
#  'oke': 2262,
#  'ongkirn': 2284,
#  'codnya': 698,
#  'dibatasin': 824,
#  'belnja': 369,
#  'ratus': 2654,
#  'dapat': 768,
#  'grtis': 1147,
#  'ongkirnya': 2285,
#  'oren': 2308,
#  'kedok': 1513,
#  'kapok': 1474,
#  'gantung': 1104,
#  'lucu': 1869,
#  'benar': 372,
#  'cth': 728,
#  'bareng': 312,
#  'hrg': 1244,
#  'san': 2813,
#  'asli': 218,
#  'bohong': 496,
#  'bebayar': 341,
#  'sebutin': 2861,
#  'complain': 707,
#  'berteletele': 417,
#  'tukar': 3380,
#  'ceria': 666,
#  'konfirmasitapi': 1653,
#  'lepas': 1815,
#  'mendesakharusnya': 1997,
#  'kembalibagaimanapun': 1534,
#  'konsumen': 1658,
#  'bldah': 471,
#  'samatapi': 2800,
#  'lapakbarang': 1764,
#  'otomatislapor': 2318,
#  'penjualpenjual': 2468,
#  'nyuruh': 2250,
#  'terimabarang': 3222,
#  'bukannkesalahan': 574,
#  'pembelibeda': 2436,
#  'dngn': 905,
#  'estimadi': 1002,
#  'kembalibenar': 1535,
#  'puas': 2611,
#  'gunakanhabis': 1159,
#  'bela': 350,
#  'berbelitstatus': 391,
#  'diiterima': 853,
#  'terkirimhati': 3232,
#  'bukalapakbaru': 544,
#  'alami': 108,
#  'apl': 183,
#  'sngat': 3042,
#  'gambar': 1092,
#  'video': 3480,
#  'deskripsi': 803,
#  'sukses': 3096,
#  'indonesia': 1291,
#  'chattidak': 678,
#  'kendala': 1546,
#  'pertanyataan': 2498,
#  'user': 3452,
#  'diupload': 900,
#  'mesti': 2035,
#  'enak': 982,
#  'langgar': 1755,
#  'tersebutdan': 3239,
#  'photo': 2510,
#  'ciplakmakin': 687,
#  'aplakasi': 184,
#  'okee': 2263,
#  'jelas': 1391,
#  'emosi': 980,
#  'kedaftargimana': 1511,
#  'maksutnya': 1900,
#  'pulahadehbikin': 2618,
#  'sajaauto': 2787,
#  'delete': 792,
#  'gampang': 1096,
#  'livechatnya': 1845,
#  'telat': 3179,
#  'bukajadinya': 537,
#  'kitapd': 1598,
#  'bayarsdh': 335,
#  'transfergimana': 3345,
#  'rasa': 2649,
#  'pro': 2591,
#  'partai': 2380,
#  'rakyatlagi': 2640,
#  'ruwt': 2778,
#  'ruwet': 2777,
#  'buang': 519,
#  'iklanhasilnya': 1269,
#  'manfaatatnya': 1913,
#  'satupuntidak': 2823,
#  'fakta': 1024,
#  'etik': 1006,
#  'no': 2191,
#  'initapi': 1310,
#  'muas': 2089,
#  'kualitas': 1679,
#  'sen': 2927,
#  'menylelesaikan': 2024,
#  'peasana': 2415,
#  'sesuaipembeli': 2964,
#  'pengembalianpadahal': 2452,
#  'penjualdimana': 2467,
#  'servis': 2956,
#  'handphonerugi': 1191,
#  'waktuuang': 3506,
#  'perangkat': 2477,
#  'kelartolong': 1517,
#  'perhati': 2488,
#  'sesiusterima': 2962,
#  'transaksierror': 3339,
#  'perbaikitidak': 2482,
#  'bis': 451,
#  'histori': 1228,
#  'barangthanks': 311,
#  'harap': 1197,
#  'cocok': 693,
#  'lumayan': 1871,
#  'nasabah': 2133,
#  'urgent': 3449,
#  'normal': 2201,
#  'calon': 621,
#  'produsen': 2597,
#  'jauh': 1375,
#  'lokasi': 1858,
#  'dibukakapak': 831,
#  'relatif': 2694,
#  'murah': 2105,
#  'mall': 1905,
#  'kaki': 1455,
#  'caranyaini': 632,
#  'haridigunain': 1202,
#  'bisacoba': 454,
#  'jelaskansampe': 1393,
#  'bukalapaksedangkan': 562,
#  'gagalaneh': 1083,
#  'pemesanansaya': 2442,
#  'store': 3080,
#  'kecewasaya': 1507,
#  'total': 3325,
#  'jadi': 1349,
#  'inibukalapak': 1302,
#  'jaring': 1368,
#  'full': 1072,
#  'mon': 2080,
#  'nonaktif': 2198,
#  'aktip': 91,
#  'asa': 212,
#  'device': 809,
#  'gonta': 1134,
#  'aseli': 214,
#  'kecuali': 1510,
#  'pajang': 2343,
#  'sensitif': 2935,
#  'kerenfitur': 1558,
#  'komplit': 1642,
#  'kirimdan': 1594,
#  'mudahsemoga': 2096,
#  'simpel': 3008,
#  'pembeligood': 2437,
#  'luck': 1868,
#  'kompak': 1620,
#  'tindak': 3281,
#  'developer': 808,
#  'atur': 231,
#  'ajakarna': 60,
#  'bataldan': 322,
#  'rumit': 2769,
#  'market': 1933,
#  'buyer': 603,
#  'mulu': 2099,
#  'bangkrut': 284,
#  'service': 2954,
#  'mincara': 2043,
#  'lupa': 1875,
#  'pinseingat': 2526,
#  'isi': 1337,
#  'memuaskantapi': 1990,
#  'banda': 270,
#  'acehdi': 13,
#  'capai': 629,
#  'perkilonyapadahal': 2490,
#  'itupaling': 1345,
#  'an': 137,
#  'acehmohon': 15,
#  'timbang': 3279,
#  'acehmaunya': 14,
#  'aceh': 12,
#  'inibelakangan': 1301,
#  'daerah': 751,
#  'sampainyadicoba': 2806,
#  'terusongkir': 3246,
#  'bukaekpress': 534,
#  'berattidak': 389,
#  'jelaspercuma': 1396,
#  'limite': 1826,
#  'transaksinyesel': 3341,
#  'belanjajelas': 358,
#  'sekaliperdetik': 2883,
#  'uninstalmakasih': 3426,
#  'sayabagi': 2828,
#  'digitalpelapak': 840,
#  'curang': 737,
#  'terimacobalah': 3223,
#  'komplainsampai': 1635,
#  'pelapakbats': 2420,
#  'berjalanterus': 401,
#  'nyalewat': 2226,
#  'shopbelanja': 2980,
#  'pengaduanonline': 2451,
#  'pelapakseller': 2421,
#  'rentan': 2697,
#  'venus': 3471,
#  'shop': 2979,
#  'on': 2274,
#  'pengadua': 2450,
#  'sibuka': 2996,
#  'tetangga': 3254,
#  'serviceny': 2955,
#  'bliblihari': 473,
#  'bijak': 438,
#  'risiko': 2754,
#  'alhamdulillah': 115,
#  'kecewasejauh': 1508,
#  'gaet': 1080,
#  'minat': 2042,
#  'screenshoot': 2844,
#  'kuras': 1690,
#  'kategori': 1489,
#  'repes': 2699,
#  'lanjur': 1758,
#  'lain': 1717,
#  'hatikayaknya': 1209,
#  'rejeki': 2680,
#  'voucer': 3490,
#  'berkalikali': 403,
#  'historikalaupun': 1229,
#  'thok': 3262,
#  'penambahanknpa': 2443,
#  'kwalitas': 1696,
#  'tokoh': 3306,
#  'sayasy': 2839,
#  'nyabintang': 2219,
#  'nyangkut': 2236,
#  ...}

# %%
#kolom pertama ini berarti jumlah dokumen
#kolom kedua berarti letak katanya
#kolom ketiga hasil dari tf

term_frequency_all = term_fit.transform(Ulasan)
print (term_frequency_all)
# Out:
#   (0, 189)	1
#   (0, 275)	1
#   (0, 441)	2
#   (0, 528)	1
#   (0, 615)	1
#   (0, 860)	1
#   (0, 994)	1
#   (0, 1047)	1
#   (0, 2206)	1
#   (0, 2345)	1
#   (0, 2387)	2
#   (0, 2733)	2
#   (0, 2753)	1
#   (0, 2794)	2
#   (0, 2795)	1
#   (0, 2896)	1
#   (0, 3001)	1
#   (0, 3020)	1
#   (0, 3344)	1
#   (1, 189)	1
#   (1, 493)	1
#   (1, 528)	1
#   (1, 676)	1
#   (1, 691)	1
#   (1, 923)	1
#   :	:
#   (1295, 3014)	1
#   (1296, 256)	1
#   (1296, 364)	1
#   (1296, 1352)	1
#   (1296, 1776)	1
#   (1296, 2517)	1
#   (1296, 2572)	1
#   (1296, 3317)	1
#   (1297, 131)	1
#   (1297, 290)	1
#   (1297, 354)	1
#   (1297, 542)	1
#   (1297, 1420)	1
#   (1297, 1484)	1
#   (1297, 3096)	1
#   (1297, 3221)	1
#   (1297, 3537)	1
#   (1298, 1098)	1
#   (1298, 1420)	1
#   (1298, 1811)	1
#   (1298, 2216)	1
#   (1299, 290)	1
#   (1299, 1825)	1
#   (1299, 2122)	1
#   (1299, 2399)	1

# %%
ulasan_tf = Ulasan[1] #memanggil kata pada index ke 1
print (ulasan_tf)
# Out:
# aplikasi marketplace hancur sistem bukabantuan selesain lari live chatnya sistem paylaternya bobrok sila coba download tau

# %%
term_frequency = term_fit.transform([ulasan_tf]) #hanya menampilkan hasil document 1
print (term_frequency)
# Out:
#   (0, 189)	1
#   (0, 493)	1
#   (0, 528)	1
#   (0, 676)	1
#   (0, 691)	1
#   (0, 923)	1
#   (0, 1188)	1
#   (0, 1774)	1
#   (0, 1843)	1
#   (0, 1935)	1
#   (0, 2399)	1
#   (0, 2898)	1
#   (0, 3005)	1
#   (0, 3020)	2
#   (0, 3170)	1

# %%
dokumen = term_fit.transform(Ulasan) #hasil perhitungan tf idf dalam 1 doc
tfidf_transformer = TfidfTransformer().fit(dokumen)
print (tfidf_transformer.idf_)

tfidf=tfidf_transformer.transform(term_frequency)
print (tfidf) #hasil manual dengan sistem pyhton
# Out:
# [7.4777413  7.4777413  7.07227619 ... 7.4777413  7.07227619 7.4777413 ]
#   (0, 3170)	0.20974039584882045
#   (0, 3020)	0.3610022186385605
#   (0, 3005)	0.3131460678193531
#   (0, 2898)	0.33109924171043303
#   (0, 2399)	0.2449382809179997
#   (0, 1935)	0.2517637608545586
#   (0, 1843)	0.1790492423664232
#   (0, 1774)	0.27562943440039694
#   (0, 1188)	0.27562943440039694
#   (0, 923)	0.23381058696347864
#   (0, 691)	0.18683732488620863
#   (0, 676)	0.2697169347456385
#   (0, 528)	0.23141659989563504
#   (0, 493)	0.29052774365755196
#   (0, 189)	0.10166035958715507

# %%
data_label = name_dataframe[["Nama pengguna", "Ulasan_siap", "Sentiment"]]

# %%
data_label["Ulasan_siap"] = data_label["Ulasan_siap"].fillna("tidak ada komentar")
# Out:
# <ipython-input-75-63aa05b24bd2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label["Ulasan_siap"] = data_label["Ulasan_siap"].fillna("tidak ada komentar")

# %%
data_label.to_excel("data_label.xlsx")

# %%
sentimen_data=pd.value_counts(data_label["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["#ccd5ae"])
plt.title('Bar chart')
plt.show()

# %%
plt.figure(figsize=(16, 6))

heatmap = sns.heatmap(name_dataframe.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12)

plt.tight_layout()

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize',
#        'ulasan_ears', 'Ulasan_normalized', 'Ulasan_stop_removed',
#        'Ulasan_Stemmed', 'Ulasan_siap', 'label', 'Subjectivity', 'Polarity',
#        'Sentiment', 'month'],
#       dtype='object')

# %%
train_s3 = data_label[data_label["Sentiment"] == 'Neutral']

# %% [markdown]
# # **Proses visualiasi kata terbanyak dari Neutral**

# %%
train_s3["Ulasan_siap"] = train_s3["Ulasan_siap"].fillna("tidak ada komentar")
# Out:
# <ipython-input-81-4fc6d4cc0ecf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s3["Ulasan_siap"] = train_s3["Ulasan_siap"].fillna("tidak ada komentar")

# %%
all_text_s0 = ' '.join(word for word in train_s3["Ulasan_siap"])
wordcloud = WordCloud(colormap='gist_stern', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s0)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
print("Neutral words")
plt.show()
# Out:
# Neutral words

# %%
from wordcloud import WordCloud

# %%
train_s0 = data_label[data_label["Sentiment"] == 'Negative']

# %%
train_s0["Ulasan_siap"] = train_s0["Ulasan_siap"].fillna("tidak ada komentar")
# Out:
# <ipython-input-85-dc46e426e77c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s0["Ulasan_siap"] = train_s0["Ulasan_siap"].fillna("tidak ada komentar")

# %%
train_s0
# Out:
#                       Nama pengguna  \
# 11                   Popi Anggraini
# 17                findi perda wisma
# 31                    Syamriza Alam
# 33                    Mirdad Wangsa
# 70                       Adityo Nur
# 71                   Dadang Setiaji
# 78                     agus jatnika
# 196                    Abrar Sinaro
# 223            Dery Riyanto (STARK)
# 269              Ilham Padka Wijaya
# 311                    New Expander
# 334                     AKO Pinrang
# 338                    Ahmad Sahrul
# 352   Infinik smart6 Infinik smart6
# 378                   Farhan Fiddin
# 423                   Dinnss Livina
# 491                   Afifur Rohman
# 501         Kaloka Galih Kayu Wangi
# 505                    Bam Hendrian
# 567                     imam maliki
# 606                 26Naya Queensya
# 630                          eH boy
# 731                  Silva Widianti
# 753                        Nursamsi
# 783                   Candra Wijaya
# 800                 Pengguna Google
# 809                     Najwa Jemur
# 825                 Pengguna Google
# 861                 Pengguna Google
# 864                       Hr Tester
# 923                 Pengguna Google
# 979              haidar dabi kataro
# 982                       Fian Syah
# 1016                Sugiarto Giarto
# 1033                    Ray Purnama
# 1042                Pengguna Google
# 1065                 muhammad Iqbal
# 1094                Pengguna Google
# 1097                Pengguna Google
# 1149              Sondang Panjaitan
# 1203                Pengguna Google
# 1208                  wisnul arifin
# 1263                Pengguna Google
# 1282                      X0s Sprtn
# 1284                 Syahril ikhsan
#
#                                             Ulasan_siap Sentiment
# 11    transfer baca virtual account verifikasi saldo...  Negative
# 17    aplikasi jelek tari saldo dompet rekening ribe...  Negative
# 31    buka bantu nya bantu memperaulitcall center ny...  Negative
# 33    rugi beli masak barang bayar nunggunya batal u...  Negative
# 70    beku alas kalo bekuin akun baik kasih alas jal...  Negative
# 71    saldo dana sambung tibatiba potong voucher gam...  Negative
# 78    kasih bintang segitu blapak buka detail pesan ...  Negative
# 196   promo bebas ongkir tingkat biar tarik langgan ...  Negative
# 223   tangan kirim jam suruh tunggu batalin pesan je...  Negative
# 269   bukalapak marketplace nya sellerseller tipu ka...  Negative
# 311   bad buruk rekomendasi layan buruk paylatter be...  Negative
# 334   transaksi game bukalapak cepat harga muraspant...  Negative
# 338   playlater kalo hp nomor nya hilang alas ktp pa...  Negative
# 352   bintang deh gagal pinjem alas pinjam tunai akt...  Negative
# 378   beli emas buka emas tarik alas konekai masalah...  Negative
# 423   pakai pinjol nya kredivo sadis biaya layan rib...  Negative
# 491   aplikasi bagus minus ongkir mahal voucher paka...  Negative
# 501   jual emas bukaemas susah banget banget problem...  Negative
# 505   kesini sistem nya berat ajabanyak sisrem gunab...  Negative
# 567   hati hubung akun aplkasi iniakun kena hack tra...  Negative
# 606               beli gampang bagus belanja game makan  Negative
# 630   developer bukalapak lihat aplikasi shopee laza...  Negative
# 731   parah paylater buka lapak limit beku tampa asi...  Negative
# 753   mantap paylater limit paylaternya ditambahin c...  Negative
# 783   aplikasi bangkai belanja barang minggu bayar a...  Negative
# 800   heran aplikasi upload jual barang kaya susahhh...  Negative
# 809   kalo bukalapak rame tampil barang jual bayar i...  Negative
# 825   baik servernya fitur macet traffict diserver j...  Negative
# 861   bukastruk gagal struk identifikasi deteksi dup...  Negative
# 864   aplikasi bagus bantu kendala admin komplain me...  Negative
# 923   kurangtapi suka dwngan tampil bukalapak update...  Negative
# 979   proses konfirmasi nya lamaproses kirim nya lam...  Negative
# 982   barang pesan langsung aju komplain selesai isi...  Negative
# 1016  kasih bintang paylater susah dapetnya alas nik...  Negative
# 1033  hancur aplikasi kali belanja kali uang refund ...  Negative
# 1042  baharu akun email username error pakai transak...  Negative
# 1065  verifikasi banget foto ktp gagal nomer telp ot...  Negative
# 1094  bagus sih jual gampang fiturnya mudah lapak op...  Negative
# 1097  bukalapak update beres koneksi bagus wifi kenc...  Negative
# 1149  buka lapak bertangung kembali dana jelas alas ...  Negative
# 1203  baguskarena bukalapak beli voucher game via pu...  Negative
# 1208  aplikasi belanja mepersulit melakukakan ubah d...  Negative
# 1263  bl transaksi bl nominal nilai ratus juta feedb...  Negative
# 1282  pilih bl belanja voucher voucher minimal belan...  Negative
# 1284  duh deh belanja deh bayar bayar eror kah deh p...  Negative

# %% [markdown]
# # **Proses visualiasi kata terbanyak dari Negatif**

# %%
all_text_s0 = ' '.join(word for word in train_s0["Ulasan_siap"])
wordcloud = WordCloud(colormap='Reds', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s0)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
print("Negatif words")
plt.show()
# Out:
# Negatif words

# %% [markdown]
# # **Proses visualiasi kata terbanyak dari Positif**

# %%
train_s1 = data_label[data_label["Sentiment"] == 'Positive']

# %%
train_s1["Ulasan_siap"] = train_s1["Ulasan_siap"].fillna("tidak ada komentar")
# Out:
# <ipython-input-89-d1952b0b5859>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s1["Ulasan_siap"] = train_s1["Ulasan_siap"].fillna("tidak ada komentar")

# %%
train_s1
# Out:
#           Nama pengguna                                        Ulasan_siap  \
# 1               yOga 04  aplikasi marketplace hancur sistem bukabantuan...
# 2         Muhamad Basir  bingung banget hubung cs ngaktifin fitur live ...
# 15    Christien Denysie  bukalapak paylater aktif kali transaksi bayar ...
# 22               Gb Jkt  keri belanja bukalapak beli diangap jahat main...
# 28            ivan reza  estimasi barang lenceng kupon diskon promo ama...
# ...                 ...                                                ...
# 1239    Pengguna Google  bilang flashdealnya jin hitung detik barang le...
# 1261    Pengguna Google  tampil lumayan user friendly history transaksi...
# 1268         JUHER UDIN               ok mantap tingkat kwalitasnya barang
# 1281         harmi juan  ok prkmbangn pningktn seprti duluagak mahal su...
# 1283    Andina Agustina  hormat masyarakat indonesia hayu tutup aplikas...
#
#      Sentiment
# 1     Positive
# 2     Positive
# 15    Positive
# 22    Positive
# 28    Positive
# ...        ...
# 1239  Positive
# 1261  Positive
# 1268  Positive
# 1281  Positive
# 1283  Positive
#
# [167 rows x 3 columns]

# %%
all_text_s1 = ' '.join(word for word in train_s1["Ulasan_siap"])
wordcloud = WordCloud(colormap='Blues', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s1)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Ulasan Positif")
plt.margins(x=0, y=0)
print("Positif words")
plt.show()
# Out:
# Positif words

# %%
data_label['Ulasan_clean'] = data_label['Ulasan_siap'].fillna("tidak ada komentar")
# Out:
# <ipython-input-92-2ed151e306fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['Ulasan_clean'] = data_label['Ulasan_siap'].fillna("tidak ada komentar")

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# # **Mensplit Data Ulasan Siap Dan Data Sentiment**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_siap'], data_label['Sentiment'],
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# %% [markdown]
# # **Melakukan Pembelajaran Melihat Akurasi Dan Mendapatkan Kolom Baru Prediksi**

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(data_label['Ulasan_siap'])

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, data_label['Sentiment'], test_size=0.2, random_state=42)

# Train the Gaussian Naive Bayes classifier on the training set
gnb = GaussianNB()
gnb.fit(X_train.toarray(), y_train)

# Evaluate the classifier on the testing set
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)

# Evaluate the classifier on the testing set
y_pred = gnb.predict(X_test.toarray())
cm = confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))

# Use the classifier to predict the sentiment class for all reviews in the dataset
data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# Save the resulting dataframe to a new CSV file
data_label.to_csv('predicted_sentiment1.csv', index=False)
# Out:
# Accuracy: 0.6230769230769231
#               precision    recall  f1-score   support
#
#     Negative       0.04      0.09      0.06        11
#      Neutral       0.83      0.70      0.76       208
#     Positive       0.25      0.39      0.31        41
#
#     accuracy                           0.62       260
#    macro avg       0.38      0.39      0.38       260
# weighted avg       0.71      0.62      0.66       260
# <ipython-input-96-100d2ce1e090>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# %%
import numpy as np

X_train = X_train.toarray()
X_test = X_test.toarray()

# %% [markdown]
# # **Melihat Akurasi Terbaik**

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# Gaussian Naive Bayes with original data
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_gnb = gnb.predict(X_test)
print('Original Results:')
print(classification_report(y_test, y_gnb))
print(confusion_matrix(y_test, y_gnb))
print('Accuracy with original test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with undersampling mengurangi class
rus = RandomUnderSampler(random_state=1)
X_rus, y_rus = rus.fit_resample(X_train, y_train)
gnb = GaussianNB()
gnb.fit(X_rus, y_rus)
y_gnb = gnb.predict(X_test)
print('Undersampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with undersampling test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with oversampling menggandakan class
smote = SMOTE(random_state=1)
X_smote, y_smote = smote.fit_resample(X_train, y_train)
gnb = GaussianNB()
gnb.fit(X_smote, y_smote)
y_gnb = gnb.predict(X_test)
print('Oversampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with oversampling test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with combined oversampling and undersampling menggandakan dan mengurangi class
rus = RandomUnderSampler(random_state=1)
X_rus, y_rus = rus.fit_resample(X_train, y_train)

smote = SMOTE(random_state=1)
X_smt, y_smt = smote.fit_resample(X_rus, y_rus)

gnb = GaussianNB()
gnb.fit(X_smt, y_smt)
y_gnb = gnb.predict(X_test)
print('Combined Oversampling and Undersampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with combined oversampling and undersampling test data:', accuracy_score(y_test, y_gnb))
# Out:
# Original Results:
#               precision    recall  f1-score   support
#
#     Negative       0.04      0.09      0.06        11
#      Neutral       0.83      0.70      0.76       208
#     Positive       0.25      0.39      0.31        41
#
#     accuracy                           0.62       260
#    macro avg       0.38      0.39      0.38       260
# weighted avg       0.71      0.62      0.66       260
#
# [[  1   7   3]
#  [ 19 145  44]
#  [  3  22  16]]
# Accuracy with original test data: 0.6230769230769231
# Undersampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.06      0.55      0.11        11
#      Neutral       0.89      0.39      0.54       208
#     Positive       0.25      0.41      0.31        41
#
#     accuracy                           0.40       260
#    macro avg       0.40      0.45      0.32       260
# weighted avg       0.75      0.40      0.49       260
#
# Accuracy with undersampling test data: 0.4
# Oversampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.04      0.09      0.06        11
#      Neutral       0.83      0.70      0.76       208
#     Positive       0.25      0.39      0.31        41
#
#     accuracy                           0.62       260
#    macro avg       0.38      0.39      0.38       260
# weighted avg       0.71      0.62      0.66       260
#
# Accuracy with oversampling test data: 0.6230769230769231
# Combined Oversampling and Undersampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.06      0.55      0.11        11
#      Neutral       0.89      0.39      0.54       208
#     Positive       0.25      0.41      0.31        41
#
#     accuracy                           0.40       260
#    macro avg       0.40      0.45      0.32       260
# weighted avg       0.75      0.40      0.49       260
#
# Accuracy with combined oversampling and undersampling test data: 0.4

# %%
import numpy as np

# %%
from sklearn.feature_extraction.text import TfidfVectorizer             #menghitung n menjumlah kan dan menjumlah kan tf and n berdasarkan seluruh dokumen
vectorizer = TfidfVectorizer(decode_error='replace', encoding='utf-8')

# %%
data_label['predicted_sentiment_class'].value_counts()
# Out:
# Neutral     943
# Positive    271
# Negative     86
# Name: predicted_sentiment_class, dtype: int64

# %% [markdown]
# # **VISUALISASI Hasil Prediksi**

# %%
data_label['predicted_sentiment_class'].hist()
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# # **CrossValidation gaussion naive bayes**

# %% [markdown]
# ![10-K-Fold-Cross-Validation.png](data:image/png;base64,...)

# %% [markdown]
# **sample random**
#
# mengambil secara acak dari daftar sample atau sampling frame yang tersedia setiap individu memiliki peluang yang sama untuk terpilih
# peluang tersebut ada melakukan peluang sama ketika mempunyai data besar akan memliki peluang lebih besar untuk terpilih tetapi sebaliknya ketika mempunyai data dikit dapat peluang lebih sedikit

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_siap'], data_label['Sentiment'],
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# Vectorize the text data
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# Create the Naive Bayes Classifier object
gnb = GaussianNB()

# Perform cross-validation
scores = cross_val_score(gnb, X_train.toarray(), y_train, cv=5)

# Print the cross-validation scores
print('Cross-validation scores:', scores)

# Fit the classifier to the training data
gnb.fit(X_train.toarray(), y_train)

# Predict the sentiment of the test data
y_pred = gnb.predict(X_test.toarray())

# Print the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:\n', conf_matrix)
# Out:
# Cross-validation scores: [0.62393162 0.58974359 0.57692308 0.5982906  0.5982906 ]
# Confusion Matrix:
#  [[ 0  4  0]
#  [ 7 76 26]
#  [ 1  9  7]]

# %%
# Convert sparse matrix to dense numpy array
X_train_dense = X_train.toarray()
X_test_dense = X_test.toarray()

# Print the scores on the training and test sets
print('Training set score: {:.4f}'.format(gnb.score(X_train_dense, y_train)))
print('Test set score: {:.4f}'.format(gnb.score(X_test_dense, y_test)))

#ternyata permasalahannya bukan traning tapi test set score nya 0.50%
# Out:
# Training set score: 0.8718
# Test set score: 0.6385

# %%
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.6384615384615384

# %%
vectorizer
# Out:
# TfidfVectorizer()

# %%
nb = GaussianNB(var_smoothing=1.0) # untuk tidak overviting

# %% [markdown]
# # **Data Prediksi**

# %%
data_label.tail(100)
# Out:
#                  Nama pengguna  \
# 1200           Pengguna Google
# 1201           Pengguna Google
# 1202         Fahrul Noviantoro
# 1203           Pengguna Google
# 1204                  Haryanto
# ...                        ...
# 1295                 Dede Kurt
# 1296  Ahlul Fakri Almuthalliby
# 1297              eka jayaos46
# 1298                 Hero Hero
# 1299                 aris dude
#
#                                             Ulasan_siap Sentiment  \
# 1200  tolong kasih opsi pilih kirim kode otp smswa e...   Neutral
# 1201  review ku kemarin hilang kecewa flash sale kur...   Neutral
# 1202  aplikasi bagus percaya harga jangkau lapak jas...   Neutral
# 1203  baguskarena bukalapak beli voucher game via pu...  Negative
# 1204  satu marketplace callcenter livechat bukabantu...   Neutral
# ...                                                 ...       ...
# 1295                      sinyal bagus internet sambung   Neutral
# 1296       beli latih prakerja pilih jadwal tolong baik   Neutral
# 1297  bantu jual belanja terima kasih sukses ya buka...   Neutral
# 1298                               lengkap jual nya gan   Neutral
# 1299                     bantu paylaternya naikin limit   Neutral
#
#                                            Ulasan_clean  \
# 1200  tolong kasih opsi pilih kirim kode otp smswa e...
# 1201  review ku kemarin hilang kecewa flash sale kur...
# 1202  aplikasi bagus percaya harga jangkau lapak jas...
# 1203  baguskarena bukalapak beli voucher game via pu...
# 1204  satu marketplace callcenter livechat bukabantu...
# ...                                                 ...
# 1295                      sinyal bagus internet sambung
# 1296       beli latih prakerja pilih jadwal tolong baik
# 1297  bantu jual belanja terima kasih sukses ya buka...
# 1298                               lengkap jual nya gan
# 1299                     bantu paylaternya naikin limit
#
#      predicted_sentiment_class
# 1200                   Neutral
# 1201                   Neutral
# 1202                   Neutral
# 1203                  Positive
# 1204                   Neutral
# ...                        ...
# 1295                  Positive
# 1296                   Neutral
# 1297                   Neutral
# 1298                   Neutral
# 1299                   Neutral
#
# [100 rows x 5 columns]

# %%
X_test
# Out:
# <130x3299 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1458 stored elements in Compressed Sparse Row format>

# %%
X_train
# Out:
# <1170x3299 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16069 stored elements in Compressed Sparse Row format>

# %%
y_test
# Out:
# 147      Neutral
# 306      Neutral
# 999      Neutral
# 401      Neutral
# 1105     Neutral
#           ...
# 453      Neutral
# 797     Positive
# 101      Neutral
# 712     Positive
# 758      Neutral
# Name: Sentiment, Length: 130, dtype: object

# %%
y_train
# Out:
# 1127    Positive
# 1109     Neutral
# 785      Neutral
# 413      Neutral
# 214      Neutral
#           ...
# 622     Positive
# 1193    Positive
# 20       Neutral
# 1275     Neutral
# 1124     Neutral
# Name: Sentiment, Length: 1170, dtype: object

# %%
print(y_train)
# Out:
# 1127    Positive
# 1109     Neutral
# 785      Neutral
# 413      Neutral
# 214      Neutral
#           ...
# 622     Positive
# 1193    Positive
# 20       Neutral
# 1275     Neutral
# 1124     Neutral
# Name: Sentiment, Length: 1170, dtype: object

# %% [markdown]
# # **CONFIUSIN MATRIK**
# melihat seberapa baik distribusi dari setiap kelas

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, classification_report
import pandas as pd

# Assuming you have loaded the data into the 'data_label' DataFrame.

# Initialize the CountVectorizer
vectorizer = CountVectorizer()

# Transform the text data into numerical feature vectors
X = vectorizer.fit_transform(data_label['Ulasan_siap'])

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, data_label['Sentiment'], test_size=0.3, random_state=42)

# Train the Gaussian Naive Bayes classifier on the training set
gnb = GaussianNB()
gnb.fit(X_train.toarray(), y_train)

# Evaluate the classifier on the testing set
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)

# Evaluate the classifier on the testing set
y_pred = gnb.predict(X_test.toarray())

# Get the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Print the confusion matrix
print("Confusion Matrix:")
print(cm)

# Print classification report with precision, recall, F1-score for each class
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Use the classifier to predict the sentiment class for all reviews in the dataset
data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# Save the resulting dataframe to a new CSV file
data_label.to_csv('predicted_sentiment1.csv', index=False)
# Out:
# Accuracy: 0.6512820512820513
# Confusion Matrix:
# [[  1  10   4]
#  [ 25 231  65]
#  [  3  29  22]]
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.03      0.07      0.05        15
#      Neutral       0.86      0.72      0.78       321
#     Positive       0.24      0.41      0.30        54
#
#     accuracy                           0.65       390
#    macro avg       0.38      0.40      0.38       390
# weighted avg       0.74      0.65      0.69       390
# <ipython-input-115-27db70896ee7>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())
