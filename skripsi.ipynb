# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafiryd/Rafiryd/blob/rafiryd/skripsi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Referensi: https://www.linkedin.com/pulse/how-scrape-google-play-reviews-4-simple-steps-using-python-kundi/

# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.2-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.2

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
# Scrape All available reviews 
#(DONT RUN THIS CELL!!! RUN ONLY IF YOU WANT TO SCRAPE ALL AVAILABLE REVIEWS)
#JANGAN DI RUN KODE INI, KECUALI ANDA INGIN SCRAPE SEMUA REVIEWS SEKALIGUS

from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.bukalapak.android',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT , you can use Sort.NEWEST to get newst reviews
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1ed9407b5f80> in <module>
#      10     lang='id', # defaults to 'en'
#      11     country='id', # defaults to 'us'
# ---> 12     sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT , you can use Sort.NEWEST to get newst reviews
#      13 )
#
# /usr/local/lib/python3.7/dist-packages/google_play_scraper/features/reviews.py in reviews_all(app_id, sleep_milliseconds, **kwargs)
#     131             count=MAX_COUNT_EACH_FETCH,
#     132             continuation_token=continuation_token,
# --> 133             **kwargs
#     134         )
#     135
#
# /usr/local/lib/python3.7/dist-packages/google_play_scraper/features/reviews.py in reviews(app_id, lang, country, sort, count, filter_score_with, continuation_token)
#      92         try:
#      93             review_items, token = _fetch_review_items(
# ---> 94                 url, app_id, sort, _fetch_count, filter_score_with, token
#      95             )
#      96         except (TypeError, IndexError):
#
# /usr/local/lib/python3.7/dist-packages/google_play_scraper/features/reviews.py in _fetch_review_items(url, app_id, sort, count, filter_score_with, pagination_token)
#      43             pagination_token,
#      44         ),
# ---> 45         {"content-type": "application/x-www-form-urlencoded"},
#      46     )
#      47
#
# /usr/local/lib/python3.7/dist-packages/google_play_scraper/utils/request.py in post(url, data, headers)
#      22
#      23 def post(url: str, data: Union[str, bytes], headers: dict) -> str:
# ---> 24     return _urlopen(Request(url, data=data, headers=headers))
#      25
#      26
#
# /usr/local/lib/python3.7/dist-packages/google_play_scraper/utils/request.py in _urlopen(obj)
#       9 def _urlopen(obj):
#      10     try:
# ---> 11         resp = urlopen(obj)
#      12     except HTTPError as e:
#      13         if e.code == 404:
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /usr/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /usr/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /usr/lib/python3.7/urllib/request.py in https_open(self, req)
#    1391         def https_open(self, req):
#    1392             return self.do_open(http.client.HTTPSConnection, req,
# -> 1393                 context=self._context, check_hostname=self._check_hostname)
#    1394
#    1395         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1351             except OSError as err: # timeout error
#    1352                 raise URLError(err)
# -> 1353             r = h.getresponse()
#    1354         except:
#    1355             h.close()
#
# /usr/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /usr/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#Scrape desired number of reviews
#Run kode ini jika ingin scrape data dengan jumlah tertentu. Ganti (misal, ingin scrape sejumlah 1000, maka ganti kode , count = 1000 )

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.bukalapak.android',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=1001, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId           userName  \
# 0  6fa67572-5ca0-4ebc-8edc-24eda3025085   ReGodam ReloadME
# 1  24dce380-728f-421b-be6e-8a4fd359340a  Rahman F Official
# 2  753e28ab-d262-4900-84b5-208671eab4d7          FilNoz CH
# 3  3fc67f75-594e-479d-86c9-a3c5fcdc6212            ahmad y
# 4  0544c875-cbfe-44d4-911a-d528a774863e    Denny Pramudita
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ACNPE...
# 1  https://play-lh.googleusercontent.com/a-/ACNPE...
# 2  https://play-lh.googleusercontent.com/a/ALm5wu...
# 3  https://play-lh.googleusercontent.com/a-/ACNPE...
# 4  https://play-lh.googleusercontent.com/a-/ACNPE...
#
#                                              content  score  thumbsUpCount  \
# 0  Menu dalam apps lebih sedikit, contohnya tidak...      2            444
# 1  Apk.nya bagus sih, cuma kalau ada pesanan masu...      3             11
# 2  Mau belanja ribet di BukaLapak harus melalui D...      1            262
# 3  dari pelayanan sih ga pernah mengecewakan. Tap...      5            115
# 4  Sangat kecewa sekali, pembayaran dengan paylet...      1            154
#
#   reviewCreatedVersion                  at  \
# 0               5.17.1 2022-08-04 05:10:30
# 1               5.22.1 2022-10-15 03:40:36
# 2               5.18.0 2022-08-15 16:53:45
# 3               5.18.0 2022-09-22 10:36:22
# 4               5.18.0 2022-08-29 12:49:06
#
#                                         replyContent           repliedAt
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2  Halo kak, maaf udah bikin kesel ya Kak. Jangan... 2021-12-18 09:19:18
# 3                                               None                 NaT
# 4                                               None                 NaT

# %%
len(df_busu.index) #count the number of data we got
# Out:
# 1001

# %%
df_busu[['userName', 'score','at', 'content']].tail()  #preview userName, rating, date-time, and reviews only
# Out:
#              userName  score                  at  \
# 996    Rahman Saputra      1 2022-08-03 19:22:57
# 997          nabil 85      5 2022-08-14 06:00:43
# 998       Narto Toaja      5 2022-09-24 08:34:13
# 999   Pengguna Google      5 2022-09-11 12:56:54
# 1000            Husni      1 2022-08-06 04:56:57
#
#                                                 content
# 996   tolong kembalikan seperti semula akun saya,kar...
# 997   Selalu belanja di tempat ini sejak dulu. Kalau...
# 998   Belanja makin mudah.dan bisa cari barang yg di...
# 999          Belanja mudah, pelayanan cepat, harga baik
# 1000  Kita mau komplen saja sangat kesulitan mau men...

# %%
name_dataframe = df_busu.loc[:,["userName", "score", "at", "content"]]
name_dataframe.rename(columns={"userName": "Nama pengguna", "score":"Rating", "at": "Date", "content": "Ulasan"}, inplace=True)

# %%
name_dataframe.tail()
# Out:
#         Nama pengguna  Rating                Date  \
# 996    Rahman Saputra       1 2022-08-03 19:22:57
# 997          nabil 85       5 2022-08-14 06:00:43
# 998       Narto Toaja       5 2022-09-24 08:34:13
# 999   Pengguna Google       5 2022-09-11 12:56:54
# 1000            Husni       1 2022-08-06 04:56:57
#
#                                                  Ulasan
# 996   tolong kembalikan seperti semula akun saya,kar...
# 997   Selalu belanja di tempat ini sejak dulu. Kalau...
# 998   Belanja makin mudah.dan bisa cari barang yg di...
# 999          Belanja mudah, pelayanan cepat, harga baik
# 1000  Kita mau komplen saja sangat kesulitan mau men...

# %%
name_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nama pengguna  1001 non-null   object
#  1   Rating         1001 non-null   int64
#  2   Date           1001 non-null   datetime64[ns]
#  3   Ulasan         1001 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 31.4+ KB

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].astype(str)
name_dataframe.head()
# Out:
#        Nama pengguna  Rating                Date  \
# 0   ReGodam ReloadME       2 2022-08-04 05:10:30
# 1  Rahman F Official       3 2022-10-15 03:40:36
# 2          FilNoz CH       1 2022-08-15 16:53:45
# 3            ahmad y       5 2022-09-22 10:36:22
# 4    Denny Pramudita       1 2022-08-29 12:49:06
#
#                                               Ulasan
# 0  Menu dalam apps lebih sedikit, contohnya tidak...
# 1  Apk.nya bagus sih, cuma kalau ada pesanan masu...
# 2  Mau belanja ribet di BukaLapak harus melalui D...
# 3  dari pelayanan sih ga pernah mengecewakan. Tap...
# 4  Sangat kecewa sekali, pembayaran dengan paylet...

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].str.lower()

# %%
import string 
import re 
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

def remove_links(text):
    # menghapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus URL
    return text.replace("http://", " ").replace("https://", " ")
                
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_links)

# %%
#menghapus number
def remove_number(text):
    return  re.sub(r"\d+", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_number)

# %%
#menghapus punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_punctuation)

# %%
# menghapus single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_singl_char)

# %%
# Tokenisasi 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

name_dataframe['Ulasan_tokenize'] = name_dataframe['Ulasan'].apply(word_tokenize_wrapper)

# %%
name_dataframe
# Out:
#            Nama pengguna  Rating                Date  \
# 0       ReGodam ReloadME       2 2022-08-04 05:10:30
# 1                ahmad y       5 2022-09-22 10:36:22
# 2               Budi Lie       1 2022-10-04 03:09:26
# 3              FilNoz CH       1 2022-08-15 16:53:45
# 4        Denny Pramudita       1 2022-08-29 12:49:06
# ...                  ...     ...                 ...
# 996             BIG game       4 2022-07-06 10:27:43
# 997      PRI JAYA TEKNIK       5 2022-06-01 02:09:12
# 998   Iqbal Pratuna sndy       2 2022-07-01 04:37:28
# 999         Asep Rubaman       5 2022-07-05 02:37:16
# 1000           Den Broto       5 2022-06-13 05:59:50
#
#                                                  Ulasan  \
# 0     menu dalam apps lebih sedikit contohnya tidak ...
# 1     dari pelayanan sih ga pernah mengecewakan tapi...
# 2     bl dw dinvini aplikasi kenapa tiba  bisa beli ...
# 3     mau belanja ribet di bukalapak harus melalui d...
# 4     sangat kecewa sekali pembayaran dengan paylete...
# ...                                                 ...
# 996   ok sih apk ini hanya mesti di rapihkan lagi kl...
# 997   untuk aplikasi sangat mantap hanya saja pada s...
# 998   kok gak bisa buat login padahal udh vertifikas...
# 999   aplikasi belanja online pertama yg saya instal...
# 1000  senang belanja di buka lapak itemnya komplit t...
#
#                                         Ulasan_tokenize
# 0     [menu, dalam, apps, lebih, sedikit, contohnya,...
# 1     [dari, pelayanan, sih, ga, pernah, mengecewaka...
# 2     [bl, dw, dinvini, aplikasi, kenapa, tiba, bisa...
# 3     [mau, belanja, ribet, di, bukalapak, harus, me...
# 4     [sangat, kecewa, sekali, pembayaran, dengan, p...
# ...                                                 ...
# 996   [ok, sih, apk, ini, hanya, mesti, di, rapihkan...
# 997   [untuk, aplikasi, sangat, mantap, hanya, saja,...
# 998   [kok, gak, bisa, buat, login, padahal, udh, ve...
# 999   [aplikasi, belanja, online, pertama, yg, saya,...
# 1000  [senang, belanja, di, buka, lapak, itemnya, ko...
#
# [1001 rows x 5 columns]

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize'], dtype='object')

# %%
#Run This Code to Sort the Data By Date 
# tanggal 26-04-2022 sampai 12-10-2022

new_df = name_dataframe[['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize']]
sorted_df = new_df.sort_values(by='Date', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#        Nama pengguna  Rating                Date  \
# 307  Nurjannah Nanna       5 2022-10-12 10:30:19
# 361      Surya Darma       5 2022-10-12 09:11:54
# 243        Azhari Ys       5 2022-10-12 08:51:49
# 804    triyuwono adi       1 2022-10-12 05:43:39
# 554     Afid Prianto       5 2022-10-12 05:15:35
#
#                                                 Ulasan  \
# 307  makasih bukalapak membeli pelatihan prosesnya ...
# 361  mudah mudahan kedepannya para reseller nya leb...
# 243  gampang belanjanya mudah barangnya  gampang ba...
# 804  hati  belanja di buka lapak transksi pakai ban...
# 554  produk yang tersedia berkawalitas harga bersah...
#
#                                        Ulasan_tokenize
# 307  [makasih, bukalapak, membeli, pelatihan, prose...
# 361  [mudah, mudahan, kedepannya, para, reseller, n...
# 243  [gampang, belanjanya, mudah, barangnya, gampan...
# 804  [hati, belanja, di, buka, lapak, transksi, pak...
# 554  [produk, yang, tersedia, berkawalitas, harga, ...

# %%
sorted_df.dtypes
# Out:
# Nama pengguna              object
# Rating                      int64
# Date               datetime64[ns]
# Ulasan                     object
# Ulasan_tokenize            object
# dtype: object

# %%
# Menghitung Distibusi Persebaran Kata
def freqDist_wrapper(text):
    return FreqDist(text)

Ulasan_fqsist = name_dataframe['Ulasan_tokenize'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(Ulasan_fqsist.head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(tidak, 3), (ada, 3), (pengiriman, 3), (di, 3...
# 1    [(pesanan, 3), (masuk, 2), (jadi, 2), (apknya,...
# 2    [(mau, 5), (di, 5), (belanja, 3), (bukalapak, ...
# 3    [(di, 4), (cari, 3), (barang, 3), (ga, 2), (bl...
# 4    [(dengan, 2), (tidak, 2), (tagihan, 2), (sanga...
# Name: Ulasan_tokenize, dtype: object

# %%
name_dataframe['Ulasan_tokenize'].unique
# Out:
# <bound method Series.unique of 0       [menu, dalam, apps, lebih, sedikit, contohnya,...
# 1       [dari, pelayanan, sih, ga, pernah, mengecewaka...
# 2       [bl, dw, dinvini, aplikasi, kenapa, tiba, bisa...
# 3       [mau, belanja, ribet, di, bukalapak, harus, me...
# 4       [sangat, kecewa, sekali, pembayaran, dengan, p...
#                               ...
# 996     [ok, sih, apk, ini, hanya, mesti, di, rapihkan...
# 997     [untuk, aplikasi, sangat, mantap, hanya, saja,...
# 998     [kok, gak, bisa, buat, login, padahal, udh, ve...
# 999     [aplikasi, belanja, online, pertama, yg, saya,...
# 1000    [senang, belanja, di, buka, lapak, itemnya, ko...
# Name: Ulasan_tokenize, Length: 1001, dtype: object>

# %%
slank_word_dict = {
    "keduakali" : "kedua kali",
    "agak" : "sedikit",
    "pas" : "saat",
    "produkx" : "produknya",
    "sukamkasih" : "suka makasih",
    "gak" : "tidak",
    "cpt" : "cepat",
    "sdh" : "sudah",
    "recommend" : "rekomendasi",
    "bagusseller" : "bagus",
    "bagusssss" : "bagus",
    "bagussssss" : "bagus",
    "baguuussss" : "bagus",
    "cepatmakasih": "cepat",
    "cepatmantappp": "cepat",
    "cepatproduct": "cepat",
    "cepatrecomended": "cepat",
    "cepattoko": "cepat",
    "recomended": "rekomendasi",
    "recommended": "rekomendasi",
    "rekomendasi": "rekomendasi",
    "rekomended": "rekomendasi",
    }

def slank_normalized_term(document):
    return [slank_word_dict[term] if term in slank_word_dict else term for term in document]

# %%
normalizad_word = pd.read_csv("/content/kamusalayindonesia.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

# %%
name_dataframe['Ulasan_normalized'] = name_dataframe['Ulasan_tokenize'].apply(normalized_term).apply(slank_normalized_term)

# %%
name_dataframe
# Out:
#           Nama pengguna  Rating                Date  \
# 0      ReGodam ReloadME       2 2022-08-04 05:10:30
# 1     Rahman F Official       3 2022-10-15 03:40:36
# 2             FilNoz CH       1 2022-08-15 16:53:45
# 3               ahmad y       5 2022-09-22 10:36:22
# 4       Denny Pramudita       1 2022-08-29 12:49:06
# ...                 ...     ...                 ...
# 996      Rahman Saputra       1 2022-08-03 19:22:57
# 997            nabil 85       5 2022-08-14 06:00:43
# 998         Narto Toaja       5 2022-09-24 08:34:13
# 999     Pengguna Google       5 2022-09-11 12:56:54
# 1000              Husni       1 2022-08-06 04:56:57
#
#                                                  Ulasan  \
# 0     menu dalam apps lebih sedikit contohnya tidak ...
# 1     apknya bagus sih cuma kalau ada pesanan masuk ...
# 2     mau belanja ribet di bukalapak harus melalui d...
# 3     dari pelayanan sih ga pernah mengecewakan tapi...
# 4     sangat kecewa sekali pembayaran dengan paylete...
# ...                                                 ...
# 996   tolong kembalikan seperti semula akun sayakarn...
# 997   selalu belanja di tempat ini sejak dulu kalau ...
# 998   belanja makin mudahdan bisa cari barang yg di ...
# 999            belanja mudah pelayanan cepat harga baik
# 1000  kita mau komplen saja sangat kesulitan mau men...
#
#                                         Ulasan_tokenize  \
# 0     [menu, dalam, apps, lebih, sedikit, contohnya,...
# 1     [apknya, bagus, sih, cuma, kalau, ada, pesanan...
# 2     [mau, belanja, ribet, di, bukalapak, harus, me...
# 3     [dari, pelayanan, sih, ga, pernah, mengecewaka...
# 4     [sangat, kecewa, sekali, pembayaran, dengan, p...
# ...                                                 ...
# 996   [tolong, kembalikan, seperti, semula, akun, sa...
# 997   [selalu, belanja, di, tempat, ini, sejak, dulu...
# 998   [belanja, makin, mudahdan, bisa, cari, barang,...
# 999     [belanja, mudah, pelayanan, cepat, harga, baik]
# 1000  [kita, mau, komplen, saja, sangat, kesulitan, ...
#
#                                       Ulasan_normalized
# 0     [menu, dalam, apps, lebih, sedikit, contohnya,...
# 1     [apknya, bagus, sih, cuma, kalau, ada, pesanan...
# 2     [mau, belanja, ribet, di, bukalapak, harus, me...
# 3     [dari, pelayanan, sih, enggak, pernah, mengece...
# 4     [sangat, kecewa, sekali, pembayaran, dengan, p...
# ...                                                 ...
# 996   [tolong, kembalikan, seperti, semula, akun, sa...
# 997   [selalu, belanja, di, tempat, ini, sejak, dulu...
# 998   [belanja, makin, mudahdan, bisa, cari, barang,...
# 999     [belanja, mudah, pelayanan, cepat, harga, baik]
# 1000  [kita, mau, komplen, saja, sangat, kesulitan, ...
#
# [1001 rows x 6 columns]

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

name_dataframe['Ulasan_stop_removed'] = name_dataframe['Ulasan_normalized'].apply(stopwords_removal)

# %%
name_dataframe
# Out:
#           Nama pengguna  Rating                Date  \
# 0      ReGodam ReloadME       2 2022-08-04 05:10:30
# 1     Rahman F Official       3 2022-10-15 03:40:36
# 2             FilNoz CH       1 2022-08-15 16:53:45
# 3               ahmad y       5 2022-09-22 10:36:22
# 4       Denny Pramudita       1 2022-08-29 12:49:06
# ...                 ...     ...                 ...
# 996      Rahman Saputra       1 2022-08-03 19:22:57
# 997            nabil 85       5 2022-08-14 06:00:43
# 998         Narto Toaja       5 2022-09-24 08:34:13
# 999     Pengguna Google       5 2022-09-11 12:56:54
# 1000              Husni       1 2022-08-06 04:56:57
#
#                                                  Ulasan  \
# 0     menu dalam apps lebih sedikit contohnya tidak ...
# 1     apknya bagus sih cuma kalau ada pesanan masuk ...
# 2     mau belanja ribet di bukalapak harus melalui d...
# 3     dari pelayanan sih ga pernah mengecewakan tapi...
# 4     sangat kecewa sekali pembayaran dengan paylete...
# ...                                                 ...
# 996   tolong kembalikan seperti semula akun sayakarn...
# 997   selalu belanja di tempat ini sejak dulu kalau ...
# 998   belanja makin mudahdan bisa cari barang yg di ...
# 999            belanja mudah pelayanan cepat harga baik
# 1000  kita mau komplen saja sangat kesulitan mau men...
#
#                                         Ulasan_tokenize  \
# 0     [menu, dalam, apps, lebih, sedikit, contohnya,...
# 1     [apknya, bagus, sih, cuma, kalau, ada, pesanan...
# 2     [mau, belanja, ribet, di, bukalapak, harus, me...
# 3     [dari, pelayanan, sih, ga, pernah, mengecewaka...
# 4     [sangat, kecewa, sekali, pembayaran, dengan, p...
# ...                                                 ...
# 996   [tolong, kembalikan, seperti, semula, akun, sa...
# 997   [selalu, belanja, di, tempat, ini, sejak, dulu...
# 998   [belanja, makin, mudahdan, bisa, cari, barang,...
# 999     [belanja, mudah, pelayanan, cepat, harga, baik]
# 1000  [kita, mau, komplen, saja, sangat, kesulitan, ...
#
#                                       Ulasan_normalized  \
# 0     [menu, dalam, apps, lebih, sedikit, contohnya,...
# 1     [apknya, bagus, sih, cuma, kalau, ada, pesanan...
# 2     [mau, belanja, ribet, di, bukalapak, harus, me...
# 3     [dari, pelayanan, sih, enggak, pernah, mengece...
# 4     [sangat, kecewa, sekali, pembayaran, dengan, p...
# ...                                                 ...
# 996   [tolong, kembalikan, seperti, semula, akun, sa...
# 997   [selalu, belanja, di, tempat, ini, sejak, dulu...
# 998   [belanja, makin, mudahdan, bisa, cari, barang,...
# 999     [belanja, mudah, pelayanan, cepat, harga, baik]
# 1000  [kita, mau, komplen, saja, sangat, kesulitan, ...
#
#                                     Ulasan_stop_removed
# 0     [menu, apps, contohnya, menu, history, pengiri...
# 1     [apknya, bagus, sih, pesanan, masuk, orderan, ...
# 2     [belanja, ribet, bukalapak, dana, hatihati, be...
# 3     [pelayanan, sih, mengecewakan, mengasih, masuk...
# 4     [kecewa, pembayaran, payleter, biaya, layanan,...
# ...                                                 ...
# 996   [tolong, kembalikan, akun, sayakarna, membutuh...
# 997   [belanja, dikasih, bintang, bagus, mengharap, ...
# 998                   [belanja, mudahdan, cari, barang]
# 999           [belanja, mudah, pelayanan, cepat, harga]
# 1000  [komplen, kesulitan, menghubungi, cs, cs, buka...
#
# [1001 rows x 7 columns]

# %%
pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 26.4 MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting swifter
#   Downloading swifter-1.3.4.tar.gz (830 kB)
#      |████████████████████████████████| 830 kB 28.9 MB/s
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.5)
# Collecting psutil>=5.6.6
#   Downloading psutil-5.9.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (291 kB)
#      |████████████████████████████████| 291 kB 48.9 MB/s
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (2022.2.0)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (4.64.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (7.7.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.5.0)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from swifter) (5.0.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (1.15.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.3.0)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2022.8.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (21.3)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.21.6)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (3.0.3)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (7.9.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1.12)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 59.1 MB/s
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.0.10)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (57.4.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->dask[dataframe]>=2.10.0->swifter) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2022.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.5.0)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.11.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.6.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.11.3)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.7.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.13.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (23.2.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.1.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.10.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.3.4-py3-none-any.whl size=16322 sha256=fec89f21ec39211821835988e223acb9c8e6754c55b01cd560e2d0b9ff268840
#   Stored in directory: /root/.cache/pip/wheels/29/a7/0e/3a8f17ac69d759e1e93647114bc9bdc95957e5b0cbfd405205
# Successfully built swifter
# Installing collected packages: jedi, psutil, swifter
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# Successfully installed jedi-0.18.1 psutil-5.9.3 swifter-1.3.4

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in name_dataframe['Ulasan_stop_removed']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

name_dataframe['Ulasan_Stemmed'] = name_dataframe['Ulasan_stop_removed'].swifter.apply(get_stemmed_term)
# Out:
# 3814
# ------------------------
# menu : menu
# apps : apps
# contohnya : contoh
# history : history
# pengiriman : kirim
# nomor : nomor
# resi : resi
# daftar : daftar
# transakski : transakski
# cuman : cuman
# status : status
# pembelian : beli
# diproses : proses
# dikirim : kirim
# selesai : selesai
# akses : akses
# website : website
# tolong : tolong
# lengkapi : lengkap
# menyalahkan : salah
# penjual : jual
# proses : proses
# apknya : apknya
# bagus : bagus
# sih : sih
# pesanan : pesan
# masuk : masuk
# orderan : order
# notifikasinya : notifikasi
# terkadang : terkadang
# muncul : muncul
# telat : telat
# konfirmasi : konfirmasi
# diomelin : diomelin
# pelanggan : langgan
# dibatalkan : batal
# diperbaiki : baik
# biar : biar
# nyaman : nyaman
# pakai : pakai
# apk : apk
# bl : bl
# terima : terima
# kasih : kasih
# belanja : belanja
# ribet : ribet
# bukalapak : bukalapak
# dana : dana
# hatihati : hatihati
# kemarin : kemarin
# isi : isi
# token : token
# listrik : listrik
# saldo : saldo
# ribu : ribu
# bayar : bayar
# verifikasi : verifikasi
# sms : sms
# wa : wa
# celakanya : celaka
# seluler : seluler
# hilang : hilang
# daftarkan : daftar
# ganti : ganti
# akun : akun
# bingung : bingung
# shopee : shopee
# shopeepay : shopeepay
# tinggal : tinggal
# masukkan : masuk
# nopin : nopin
# pelayanan : layan
# mengecewakan : kecewa
# mengasih : asih
# masukan : masuk
# nih : nih
# tim : tim
# cari : cari
# barang : barang
# lengkapkarna : lengkapkarna
# sebelah : belah
# berisial : berisial
# disana : sana
# jual : jual
# semoga : moga
# nya : nya
# lengkap : lengkap
# konsumen : konsumen
# beralih : alih
# temukan : temu
# kecewa : kecewa
# pembayaran : bayar
# payleter : payleter
# biaya : biaya
# layanan : layan
# tampilkan : tampil
# diawal : awal
# nominalnya : nominal
# cek : cek
# tagihan : tagih
# bengkak : bengkak
# sesuai : sesuai
# ditampilkan : tampil
# mohon : mohon
# dipertimbangkan : timbang
# berkembang : kembang
# aplikasi : aplikasi
# maju : maju
# fikturnya : fikturnya
# rumit : rumit
# nomer : nomer
# imail : imail
# persulit : sulit
# beda : beda
# banget : banget
# tetangga : tetangga
# mudah : mudah
# aman : aman
# kayak : kayak
# kabur : kabur
# pilihan : pilih
# keranjang : keranjang
# pengikut : ikut
# user : user
# bangga : bangga
# mngenalkan : mngenalkan
# mepromosikan : mepromosikan
# programnya : program
# didaerah : daerah
# terhitung : hitung
# wajah : wajah
# kesombongan : sombong
# fasilitas : fasilitas
# paylaterbayar : paylaterbayar
# dibekukan : beku
# program : program
# umkm : umkm
# mati : mati
# an : an
# membuatmu : buat
# dikenal : kenal
# orang : orang
# update : update
# appnya : appnya
# loading : loading
# blank : blank
# coba : coba
# data : data
# wifi : wifi
# pikir : pikir
# koneksi : koneksi
# internet : internet
# fix : fix
# system : system
# tanggal : tanggal
# limit : limit
# paylater : paylater
# rp : rp
# bayarkan : bayar
# terverifikasi : verifikasi
# struk : struk
# indomaret : indomaret
# berhasil : hasil
# dibsystem : dibsystem
# terbayar : bayar
# kenakan : kena
# denda : denda
# meng : meng
# hubungi : hubung
# cs : cs
# mengembalikan : kembali
# uang : uang
# memakai : pakai
# kali : kali
# sisa : sisa
# saldonya : saldo
# pulsa : pulsa
# mengadakan : ada
# option : option
# bantuan : bantu
# via : via
# live : live
# chat : chat
# prosedurnya : prosedur
# search : search
# enginenya : enginenya
# ditemukan : temu
# browserpun : browser
# nihil : nihil
# hasil : hasil
# pencariannya : cari
# ketemunya : ketemu
# rekomendasi : rekomendasi
# untukmu : untuk
# terimakasih : terimakasih
# transaksi : transaksi
# sistem : sistem
# sibuk : sibuk
# membantu : bantu
# itemnya : item
# bervariasi : variasi
# cepat : cepat
# lancar : lancar
# sayangnya : sayang
# ongkir : ongkir
# mahallllll : mahallllll
# beli : beli
# online : online
# shop : shop
# rusak : rusak
# komplen : komplen
# komplenan : komplenan
# upload : upload
# videogimana : videogimana
# nyakalau : nyakalau
# kirim : kirim
# foto : foto
# doanggk : doanggk
# videomalah : videomalah
# youtube : youtube
# duluapa : duluapa
# hubungannya : hubung
# pesan : pesan
# apl : apl
# siang : siang
# sore : sore
# langsung : langsung
# kapok : kapok
# dinikmati : nikmat
# prosesnya : proses
# sulit : sulit
# tanggapannya : tanggap
# direkomendasikan : rekomendasi
# toko : toko
# tingkatkan : tingkat
# performan : forman
# pokok : pokok
# jualan : jual
# tingkat : tingkat
# pengunjung : unjung
# varian : varian
# salin : salin
# semuanyaharus : semuanyaharus
# memasukkan : masuk
# gambar : gambar
# buka : buka
# lapak : lapak
# sytemnya : sytemnya
# lelet : lelet
# bukanya : buka
# bantu : bantu
# jam : jam
# app : app
# mundur : mundur
# terburuk : buruk
# jaman : jaman
# aplikasinya : aplikasi
# bermanfaat : manfaat
# ecommerce : ecommerce
# rekomendid : rekomendid
# fitur : fitur
# onlinenya : onlinenya
# belanjanya : belanja
# gampang : gampang
# harga : harga
# tawarkan : tawar
# terjangkau : jangkau
# banding : banding
# lai : lai
# pengirimannya : kirim
# ekspedisi : ekspedisi
# tinggalku : tinggal
# ekspresi : ekspresi
# rumah : rumah
# tangga : tangga
# doyan : doyan
# monggo : monggo
# pencairan : cair
# penalty : penalty
# pelapak : lapak
# lalai : lalai
# terkena : kena
# dampak : dampak
# mengirimkan : kirim
# disahkan : sah
# perjanjian : janji
# salah : salah
# sengaja : sengaja
# rating : rating
# berapatp : berapatp
# bonus : bonus
# potongan : potong
# koin : koin
# didapatkan : dapat
# tukar : tukar
# belanjasudah : belanjasudah
# malas : malas
# dw : dw
# dinvini : dinvini
# malampadahal : malampadahal
# hp : hp
# kondisi : kondisi
# matichat : matichat
# ampun : ampun
# seburuk : buruk
# nyaseperti : nyaseperti
# matikan : mati
# sayaterima : sayaterima
# menakutkan : takut
# dibukalapak : dibukalapak
# livechat : livechat
# ig : ig
# telpon : telpon
# kelivechat : kelivechat
# susahnya : susah
# sekalinya : sekali
# terhubung : hubung
# diputus : putus
# diperlakukan : laku
# pengguna : guna
# mengeluhkan : keluh
# kesimpulannya : simpul
# keluhan : keluh
# ngetes : ngetes
# diskon : diskon
# jatuhnya : jatuh
# dikenakan : kena
# kalo : kalo
# perubahan : ubah
# kebijakannya : bijak
# mahal : mahal
# promo : promo
# gencar : gencar
# free : free
# discount : discount
# pendaftaran : daftar
# nik : nik
# tercatat : catat
# adaada : adaada
# terdaftar : daftar
# tolongdi : tolongdi
# sesuaikan : sesuai
# kependudukan : duduk
# saran : saran
# cssalah : cssalah
# pencet : pencet
# mengambil : ambil
# shoot : shoot
# chatnya : chatnya
# ketemu : ketemu
# lanjutkan : lanjut
# perhatikan : perhati
# thx : thx
# senang : senang
# berpatner : berpatner
# dgnbukalapak : dgnbukalapak
# cocok : cocok
# bidang : bidang
# usaha : usaha
# bengkel : bengkel
# otomotifmotor : otomotifmotor
# kesulitan : sulit
# pengadaan : ada
# spareparts : spareparts
# teratasi : atas
# kesini : kesini
# bertele : tele
# tele : tele
# penganannya : penganan
# dibikin : bikin
# terputus : putus
# bintang : bintang
# pastinya : pasti
# belajar : ajar
# burukkk : burukkk
# riwayat : riwayat
# perjalanan : jalan
# paket : paket
# kembalikan : kembali
# kenyamanan : nyaman
# mode : mode
# upgrade : upgrade
# seller : seller
# teror : teror
# customer : customer
# transfer : transfer
# rekening : rekening
# tuh : tuh
# lamaa : lamaa
# mah : mah
# kerja : kerja
# udha : udha
# dikit : dikit
# besoknya : besok
# oramg : oramg
# butuh : butuh
# uangnya : uang
# stok : stok
# kocak : kocak
# pelatihan : latih
# oktober : oktober
# prakerja : prakerja
# boro : boro
# kode : kode
# voucher : voucher
# berkurang : kurang
# respon : respon
# hack : hack
# juta : juta
# raib : raib
# tau : tau
# bertindak : tindak
# bertanggung : tanggung
# alasan : alas
# kobfirm : kobfirm
# kepolisian : polisi
# begjtu : begjtu
# komen : komen
# pasang : pasang
# iklan : iklan
# dijual : jual
# pilih : pilih
# set : set
# komplain : komplain
# kurir : kurir
# dll : dll
# berfungsi : fungsi
# pengajuan : aju
# return : return
# tolak : tolak
# bukti : bukti
# video : video
# fisik : fisik
# hello : hello
# fisiknya : fisik
# oke : oke
# mesin : mesin
# modem : modem
# wifinya : wifinya
# dihukumi : hukum
# kacau : kacau
# aturan : atur
# diterima : terima
# diteruskan : terus
# asli : asli
# rugi : rugi
# poll : poll
# otomatis : otomatis
# uninsstall : uninsstall
# share : share
# medsos : medsos
# ku : ku
# feedback : feedback
# rubah : rubah
# tanggung : tanggung
# admin : admin
# merespom : merespom
# masalahtampilan : masalahtampilan
# sederhana : sederhana
# memudahkan : mudah
# sayang : sayang
# berat : berat
# sinyal : sinyal
# jalan : jalan
# sekalisudah : sekalisudah
# dibukalapaktp : dibukalapaktp
# permanendan : permanendan
# pemberitahuan : pemberitahuan
# sebelumnyamengecewakan : sebelumnyamengecewakan
# akulakupaylater : akulakupaylater
# dibayar : bayar
# selang : selang
# total : total
# diaplikasi : aplikasi
# diresi : resi
# menahulalu : menahulalu
# balasnya : balas
# balas : balas
# ya : ya
# cetakan : cetak
# kepembeli : bel
# kasihan : kasihan
# kena : kena
# bareng : bareng
# list : list
# mengklik : klik
# dihapus : hapus
# permanen : permanen
# penjualan : jual
# menurun : turun
# platform : platform
# buruk : buruk
# dompet : dompet
# prosedur : prosedur
# melanggar : langgar
# ketentuan : tentu
# kalah : kalah
# hak : hak
# ketiga : tiga
# pembeli : beli
# bertransaksi : transaksi
# mengajukan : aju
# menyesal : sesal
# trakhir : trakhir
# kalinya : kali
# durasi : durasi
# batal : batal
# merugikan : rugi
# alami : alami
# membayar : bayar
# stock : stock
# kosong : kosong
# pembatalan : batal
# merespon : merespon
# persetujuan : tuju
# terpaksa : paksa
# tunggu : tunggu
# tolonglah : tolong
# dirubah : rubah
# menghapus : hapus
# inisebab : inisebab
# memiliki : milik
# barangsebelumnya : barangsebelumnya
# menyulitkan : sulit
# memantau : pantau
# minggu : minggu
# sekian : sekian
# tertinggal : tinggal
# bergaransi : garansi
# parah : parah
# transit : transit
# gerak : gerak
# error : error
# ubah : ubah
# ulasan : ulas
# bahan : bahan
# mentok : mentok
# sanasini : sanasini
# pakibu : pakibu
# barangpaket : barangpaket
# sampaibelum : sampaibelum
# penerima : terima
# nama : nama
# opang : opang
# dikeluarga : keluarga
# ulyg : ulyg
# disuruh : suruh
# menghubungi : hubung
# jne : jne
# pusat : pusat
# telepon : telepon
# menyelesaikan : selesai
# expedisi : expedisi
# gembel : gembel
# eh : eh
# sellernya : sellernya
# bilang : bilang
# detail : detail
# opsi : opsi
# teros : ros
# saia : saia
# menunggu : tunggu
# ditentukan : tentu
# cancel : cancel
# tod : tod
# tagihannya : tagih
# emailnya : email
# payah : payah
# penggunanya : guna
# chatt : chatt
# susah : susah
# call : call
# center : center
# perbaiki : baik
# kendala : kendala
# segampang : gampang
# woi : woi
# gosend : gosend
# instan : instan
# barangnya : barang
# pengemasan : emas
# terkendala : kendala
# memuaskan : muas
# apaapaan : apaapaan
# bukalapakpake : bukalapakpake
# rbsekali : rbsekali
# trnsaksiya : trnsaksiya
# transaksinya : transaksi
# gppnah : gppnah
# hrg : hrg
# seberapakok : seberapakok
# ditambahi : tambah
# rbdan : rbdan
# rbbelum : rbbelum
# dllpayah : dllpayah
# dibawah : bawah
# gue : gue
# cashback : cashback
# keterangan : terang
# promonya : promonya
# lambat : lambat
# suka : suka
# berburu : buru
# mending : mending
# tokopedia : tokopedia
# penanganan : tangan
# menerima : terima
# statusnya : status
# dicek : cek
# web : web
# sesimple : sesimple
# managemen : managemen
# bukalapaktlong : bukalapaktlong
# sistemnya : sistem
# rubahmasak : rubahmasak
# tombol : tombol
# jamkasihan : jamkasihan
# penjualnyangecek : penjualnyangecek
# xmending : xmending
# fikir : fikir
# tanda : tanda
# kiriman : kirim
# kompiramasi : kompiramasi
# sekatang : sekatang
# praktis : praktis
# murah : murah
# roda : roda
# rejeki : rejeki
# jarang : jarang
# dbeli : dbeli
# aneh : aneh
# dsitu : dsitu
# hehe : hehe
# seiring : iring
# barangku : barang
# hapus : hapus
# uninstal : uninstal
# mencoba : coba
# berjualan : jual
# menemani : tani
# min : min
# blanja : blanja
# enggak ada : enggak ada
# tf : tf
# keterangannya : terang
# kadarluasa : kadarluasa
# otak : otak
# atik : atik
# service : service
# mampus : mampus
# kontak : kontak
# bukabantuan : bukabantuan
# berinteraksi : interaksi
# tutup : tutup
# namanya : nama
# ane : ane
# delete : delete
# mpe : mpe
# detik : detik
# maaf : maaf
# ye : ye
# kick : kick
# bejibun : bejibun
# alhamdulillah : alhamdulillah
# ekspetasi : ekspetasi
# komplainreturcancel : komplainreturcancel
# terselesaikan : selesai
# aduhai : aduhai
# apapun : apa
# aseeek : aseeek
# oyelah : oyelah
# tertulis : tulis
# terpakai : pakai
# meteran : meter
# bertambah : tambah
# balasan : balas
# penjelasan : jelas
# aktif : aktif
# bikin : bikin
# marketplace : marketplace
# sampah : sampah
# bot : bot
# sesampahsampahnya : sesampahsampahnya
# bajak : bajak
# bahaya : bahaya
# isipake : isipake
# takut : takut
# menyesak : sesak
# cod : cod
# duluan : duluan
# barusan : barusan
# email : email
# pasword : pasword
# berbeda : beda
# angka : angka
# oranglain : oranglain
# ngehack : ngehack
# memblokir : blokir
# khawatir : khawatir
# salahgunakan : salahgunakan
# fungsinya : fungsi
# menjadikan : jadi
# perhatian : perhati
# terkesan : kes
# laku : laku
# dagangannya : dagang
# solusinya : solusi
# moga : moga
# tks : tks
# kurangi : kurang
# buyer : buyer
# paham : paham
# sangka : sangka
# akibatnya : akibat
# membatalkan : batal
# menunya : menu
# contoh : contoh
# sameday : sameday
# pencarian : cari
# driver : driver
# inginny : inginny
# sehubungan : hubung
# diorder : order
# turunin : turunin
# order : order
# bersifat : sifat
# pribadi : pribadi
# menyediakan : sedia
# kerahasiaan : rahasia
# menjaga : jaga
# privasi : privasi
# sekedar : dar
# gojek : gojek
# grabb : grabb
# herannya : heran
# tracking : tracking
# progress : progress
# sedetail : detail
# dikembalikan : kembali
# kartu : kartu
# kredit : kredit
# valid : valid
# refund : refund
# refundnya : refundnya
# pemakaian : pakai
# ente : ente
# balikin : balikin
# wxpk : wxpk
# inv : inv
# lumayan : lumayan
# samsung : samsung
# ssd : ssd
# tb : tb
# produk : produk
# produksi : produksi
# awet : awet
# tahan : tahan
# dipakai : pakai
# dipotong : potong
# alamat : alamat
# selisih : selisih
# suruh : suruh
# alamatini : alamatini
# dimna : dimna
# paranormal : paranormal
# kompline : kompline
# susahuntuk : susahuntuk
# ambil : ambil
# gara : gara
# pin : pin
# rekenening : rekenening
# buang : buang
# deh : deh
# benertapi : benertapi
# disalahinpasword : disalahinpasword
# salahcek : salahcek
# yagiliran : yagiliran
# direset : direset
# paswordmasih : paswordmasih
# salahmau : salahmau
# bisadisuruh : bisadisuruh
# bisamaksutnya : bisamaksutnya
# giliran : gilir
# urgent : urgent
# bisaampass : bisaampass
# jelassaya : jelassaya
# kadang : kadang
# menyambung : sambung
# dibales : dibales
# onlineshop : onlineshop
# jebak : jebak
# paylatersaya : paylatersaya
# lazada : lazada
# imingimingi : imingimingi
# voucer : voucer
# toker : toker
# tebus : tebus
# segitu : segitu
# jebakan : jebak
# batman : batman
# kayanya : kaya
# selamanyasorry : selamanyasorry
# pelunasan : lunas
# jaringan : jaring
# lola : lola
# gangguan : ganggu
# preman : preman
# satpol : satpol
# pp : pp
# nyamanterimakasih : nyamanterimakasih
# sungoku : sungoku
# krilin : krilin
# jinkurakura : jinkurakura
# jajarannya : jajar
# memperindah : indah
# kecilku : kecil
# hubungin : hubungin
# numpuk : numpuk
# berlaku : laku
# kreditwkwkwkklo : kreditwkwkwkklo
# iklhas : iklhas
# sok : sok
# mantap : mantap
# pelacakan : lacak
# dimana : mana
# internetnya : internetnya
# jelek : jelek
# enggak bisa : enggak bisa
# ditampilin : ditampilin
# kebanyakan : banyak
# bug : bug
# kupon : kupon
# terpotong : potong
# dicobain : dicobain
# pagi : pagi
# malam : malam
# bank : bank
# normal : normal
# kebukanya : buka
# berjalan : jalan
# kebuka : buka
# ayolah : ayo
# perbarui : baru
# tersambung : sambung
# stabil : stabil
# perbaikilah : baik
# sertifikat : sertifikat
# dashboard : dashboard
# bangetsangat : bangetsangat
# semuakta : semuakta
# investasi : investasi
# iniwow : iniwow
# kembangkantrus : kembangkantrus
# rampok : rampok
# mengkafirkan : kafir
# bebas : bebas
# ongkirke : ongkirke
# pelapakini : pelapakini
# perampokan : ampo
# minapa : minapa
# diuntung : untung
# caranyapotong : caranyapotong
# potong : potong
# untung : untung
# mintolong : mintolong
# diperhatikan : perhati
# kerjanya : kerja
# ginikecewa : ginikecewa
# subsidi : subsidi
# ongkirnya : ongkirnya
# shopping : shopping
# support : support
# bukalapaknya : bukalapaknya
# klik : klik
# pesanannyasangat : pesanannyasangat
# mengecewakanfix : mengecewakanfix
# disaat : saat
# sekarangbeli : sekarangbeli
# terpercaya : percaya
# dicari : cari
# membaca : baca
# initolong : initolong
# berhatisaat : berhatisaat
# membeli : beli
# transaksilihat : transaksilihat
# terjualsaya : terjualsaya
# tertipu : tipu
# pelapakpembayaran : pelapakpembayaran
# jatuh : jatuh
# tgldan : tgldan
# teruskan : terus
# otomatisdan : otomatisdan
# kejelasan : jelas
# mempertahankan : tahan
# bukareksa : bukareksa
# hitungan : hitung
# berpaling : paling
# bebet : bebet
# instannya : instan
# pindah : pindah
# warungpedia : warungpedia
# menit : menit
# pindahin : pindahin
# warung : warung
# ayam : ayam
# afiliasi : afiliasi
# top : top
# up : up
# mutasi : mutasi
# no : no
# dasar : dasar
# maling : maling
# kesalahan : salah
# terlanjur : lanjur
# ketik : ketik
# lanyanan : lanyanan
# retur : retur
# dihubungi : hubung
# bodong : bodong
# loh : loh
# dibantu : bantu
# returdana : returdana
# bukadompet : bukadompet
# cairikan : cairikan
# metode : metode
# handphone : handphone
# otp : otp
# terikat : ikat
# pengembalian : kembali
# berdiam : diam
# mencari : cari
# barangsaya : barangsaya
# terbaru : baru
# hasilnya : hasil
# acakdulu : acakdulu
# bekas : bekas
# bekasdulu : bekasdulu
# seminggu : minggu
# bermasalah : masalah
# mengisi : isi
# handphonemalah : handphonemalah
# versi : versi
# browser : browser
# browserjadi : browserjadi
# mubazir : mubazir
# download : download
# google : google
# play : play
# kepake : kepake
# harap : harap
# berkala : kala
# bosss : bosss
# berjuta : juta
# laporkan : lapor
# berwajib : wajib
# pasal : pasal
# penipuan : tipu
# bukalapaknyelesein : bukalapaknyelesein
# komplainan : komplain
# transaksilangsung : transaksilangsung
# kadaluwarsakomplain : kadaluwarsakomplain
# parahlanjut : parahlanjut
# sistemkapok : sistemkapok
# nominal : nominal
# perhatikangimana : perhatikangimana
# dilaporin : dilaporin
# digital : digital
# dikomplain : komplain
# artikel : artikel
# berhubungan : hubung
# kemana : mana
# kualitasnya : kualitas
# mengecewakanterlalu : mengecewakanterlalu
# kekurangan : kurang
# contohpembayaran : contohpembayaran
# mekanismenya : mekanisme
# ditambah : tambah
# sialan : sial
# refound : refound
# hangus : hangus
# mengikuti : ikut
# syaratnya : syarat
# ktp : ktp
# buku : buku
# tabungan : tabung
# selfie : selfie
# mengomong : omong
# matiin : matiin
# duit : duit
# nyangkut : nyangkut
# credits : credits
# mengatur : atur
# gua : gua
# kesel : kesel
# visa : visa
# sebagianmenggabung : sebagianmenggabung
# eror : eror
# mengandalkan : andal
# leve : leve
# aplly : aplly
# solusi : solusi
# taunya : tau
# berbelit : belit
# belit : belit
# ditungguin : ditungguin
# seharian : hari
# costumer : costumer
# ditelpon : telpon
# melayani : layan
# pengaduan : adu
# ok : ok
# friendly : friendly
# mesti : mesti
# diisi : isi
# repot : repot
# haruanya : haruanya
# utarakan : utara
# dls : dls
# tulis : tulis
# masalahny : masalahny
# bagussesuaicuma : bagussesuaicuma
# infodeskripsi : infodeskripsi
# detile : detile
# daerah : daerah
# catatan : catat
# singkronselebih : singkronselebih
# lahbravo : lahbravo
# jaya : jaya
# hati : hati
# ngalamin : ngalamin
# sayauang : sayauang
# barangpun : barang
# bukalapakekspedisisicepat : bukalapakekspedisisicepat
# regpelapaknos : regpelapaknos
# part : part
# klaten : klaten
# sayaestimasi : sayaestimasi
# keberadaan : ada
# nyakomplain : nyakomplain
# akseskalau : akseskalau
# janji : janji
# merubah : rubah
# kotak : kotak
# isinya : isi
# unboxing : unboxing
# mengutamakan : utama
# menipu : tipu
# dirugikan : rugi
# tempatnya : tempat
# mafia : mafia
# pengembaliannya : kembali
# menguntungka : menguntungka
# ditarik : tarik
# muter : muter
# kesambung : sambung
# auto : auto
# end : end
# diruangan : ruang
# penjualnya : jual
# bad : bad
# experience : experience
# marketkplace : marketkplace
# terpayah : payah
# menurutku : turut
# max : max
# manual : manual
# berulangkali : berulangkali
# ingatkan : ingat
# diselesaikan : selesai
# tindakan : tindak
# ijo : ijo
# tampil : tampil
# fb : fb
# diklik : klik
# tersedia : sedia
# menjengkelkan : jengkel
# diiklanin : diiklanin
# sukses : sukses
# kadaluawarsa : kadaluawarsa
# berita : berita
# acara : acara
# dicoba : coba
# dm : dm
# dimasuki : masuk
# tulisan : tulis
# terkonfirmasi : konfirmasi
# daftarmasa : daftarmasa
# dibilang : bilang
# terkait : kait
# merasakan : rasa
# berubah : ubah
# september : september
# jugaharga : jugaharga
# capek : capek
# menuggu : menuggu
# sedikitpunlelah : sedikitpunlelah
# cuk : cuk
# pelit : pelit
# bagusan : bagus
# bagusnya : bagus
# dikasih : kasih
# vocer : vocer
# wkwk : wkwk
# carikan : cari
# membingunkan : membingunkan
# push : push
# sumbangan : sumbang
# kebutuhan : butuh
# mempersulit : sulit
# mempermudah : mudah
# transaksiperjlanan : transaksiperjlanan
# detailcoba : detailcoba
# dengn : dengn
# akuratjgn : akuratjgn
# lihat : lihat
# posisi : posisi
# sudan : sudan
# logingak : logingak
# dibuka : buka
# mengganti : ganti
# air : air
# identitas : identitas
# dilogin : dilogin
# tipu : tipu
# ajukan : aju
# ditanggapi : tanggap
# berharap : harap
# bantuannya : bantu
# menyarankan : saran
# keamanan : aman
# rendah : rendah
# nonaktifkan : nonaktif
# berusaha : usaha
# berguna : guna
# pelapaknya : lapak
# credit : credit
# cairnya : cair
# kedepan : depan
# cair : cair
# kepepet : pepet
# rajin : rajin
# baguskatanya : baguskatanya
# usianya : usia
# tua : tua
# market : market
# place : place
# menentukan : tentu
# pertahankan : tahan
# dipenjualan : jual
# aploud : aploud
# masuknya : masuk
# aplilasi : aplilasi
# aktifkah : aktif
# mnurun : mnurun
# pembelinyajualan : pembelinyajualan
# sepi : sepi
# hancurvoucher : hancurvoucher
# pantesan : pantesan
# sepitrnyata : sepitrnyata
# minat : minat
# surutaplikasi : surutaplikasi
# mutu : mutu
# konsekuen : konsekuen
# iklannya : iklan
# berlebihanmasa : berlebihanmasa
# calon : calon
# pembelitekor : pembelitekor
# antpi : antpi
# kemajuan : maju
# kelebihanya : kelebihanya
# ringan : ringan
# cashbacknya : cashbacknya
# orange : orange
# gratis : gratis
# super : super
# lemot : lot
# kanjasa : kanjasa
# jnt : jnt
# lambatsampe : lambatsampe
# cepattolong : cepattolong
# lagibiasanya : lagibiasanya
# sampeini : sampeini
# komplit : komplit
# saranuntuk : saranuntuk
# pengirimansertakan : pengirimansertakan
# sibiru : sibiru
# zuntuk : zuntuk
# keterlambatan : lambat
# estimasi : estimasi
# pengirimanitu : pengirimanitu
# good : good
# joob : joob
# updateterakhir : updateterakhir
# agustusdi : agustusdi
# oranyega : oranyega
# updatepun : updatepun
# aplikasinyagimana : aplikasinyagimana
# dikembangkan : kembang
# penarikan : tari
# blu : blu
# keuangan : uang
# manajeman : manajeman
# rame : rame
# sebulan : bulan
# ecommers : ecommers
# mendaftar : daftar
# kakak : kakak
# membuka : buka
# tindak : tindak
# bersangkutan : sangkut
# penangkapan : tangkap
# profil : profil
# tertera : tera
# id : id
# reset : reset
# passwrd : passwrd
# seakan : akan
# login : login
# mendaftarkan : daftar
# berbelanjatp : berbelanjatp
# pembayarannya : bayar
# permudah : mudah
# apalah : apa
# gttks : gttks
# berpindah : pindah
# setting : setting
# bukatutup : bukatutup
# diotak : otak
# libur : libur
# ulang : ulang
# selesaiblm : selesaiblm
# terjawab : jawab
# kendalanya : kendala
# agustus : agustus
# senilai : nila
# tokennya : tokennya
# penjelasnnya : penjelasnnya
# bintangnya : bintang
# nyasar : nyasar
# provinsi : provinsi
# kejadian : jadi
# perbaikan : baik
# kejar : kejar
# setan : setan
# slesai : slesai
# tutupsangat : tutupsangat
# tlong : tlong
# smartphone : smartphone
# doang : doang
# kenal : kenal
# menarik : tarik
# mahalnya : mahal
# logis : logis
# evaluasi : evaluasi
# loyalisnya : loyalis
# bebenah : bebenah
# tokoku : toko
# blokir : blokir
# gajadi : gajadi
# mengadu : adu
# permasalahan : masalah
# kolom : kolom
# nomornya : nomor
# penggunaan : guna
# spesial : spesial
# kinerja : kerja
# heiii : heiii
# real : real
# menahan : tahan
# habis : habis
# otw : otw
# tokped : tokped
# turunkan : turun
# pembayarn : pembayarn
# dilahat : dilahat
# pembyaran : pembyaran
# tertulia : tertulia
# huh : huh
# teliti : teliti
# bulanan : bulan
# disayangkan : sayang
# ditempat : tempat
# bunga : bunga
# tenornya : tenor
# kesempatan : sempat
# paylaterbaru : paylaterbaru
# normalbegitu : normalbegitu
# dibatalkandan : dibatalkandan
# membatalkanjadi : membatalkanjadi
# pay : pay
# later : later
# ngetem : ngetem
# alat : alat
# pembayaranlebih : pembayaranlebih
# minim : minim
# ajjadi : ajjadi
# kecewajadi : kecewajadi
# hutang : hutang
# ditakutin : ditakutin
# plunasanyamohon : plunasanyamohon
# direspon : direspon
# ter : ter
# jegal : jegal
# point : point
# seringkali : seringkali
# ngebug : ngebug
# ngehang : ngehang
# khususny : khususny
# perangkat : perangkat
# mendukung : dukung
# pelanggaran : langgar
# menjualnya : jual
# ratting : ratting
# marketpalce : marketpalce
# tibatiba : tibatiba
# tanggapan : tanggap
# berhenti : henti
# halo : halo
# kak : kak
# memesan : mes
# bulalapak : bulalapak
# memilih : pilih
# pos : pos
# kilat : kilat
# penerimaan : terima
# terlacak : lacak
# disaya : saya
# jasa : jasa
# barangketika : barangketika
# ttolong : ttolong
# nyamasih : nyamasih
# mahaljauh : mahaljauh
# agen : agen
# pulsacuma : pulsacuma
# lapakkumplitsmua : lapakkumplitsmua
# serba : serba
# adaya : adaya
# bangettrs : bangettrs
# pengalaman : alam
# utamanya : utama
# alamatnya : alamat
# lamahadeeh : lamahadeeh
# systemnya : systemnya
# ruwet : ruwet
# biru : biru
# pelayanannya : layan
# item : item
# jakarta : jakarta
# bekasi : bekas
# jaraknya : jarak
# mitra : mitra
# expedisimu : expedisimu
# karya : karya
# anak : anak
# bangsa : bangsa
# diarahkan : arah
# kontolllll : kontolllll
# perivikasi : perivikasi
# kyc : kyc
# dibalas : balas
# menemukan : temu
# solusipadahal : solusipadahal
# era : era
# sebanding : banding
# tidakkarna : tidakkarna
# buklapak : buklapak
# ramah : ramah
# memproses : proses
# merchant : merchant
# plikasi : plikasi
# cacatnya : cacat
# kuota : kuota
# dibeli : beli
# alias : alias
# dimakan : makan
# bukalapan : bukalapan
# teman : teman
# komitmen : komitmen
# batalkan : batal
# vf : vf
# vpdinv : vpdinv
# hai : hai
# kehilangan : hilang
# gaji : gaji
# turun : turun
# lunasin : lunasin
# rekan : rekan
# sedangsudah : sedangsudah
# tempo : tempo
# silakan : sila
# difikir : difikir
# ajakanseruan : ajakanseruan
# berbagi : bagi
# note : note
# mengerti : erti
# maksud : maksud
# sampaiditerima : sampaiditerima
# sipembeli : sipembeli
# kompirmasi : kompirmasi
# brang : brang
# sampaimnurut : sampaimnurut
# eeeh : eeeh
# expresnya : expresnya
# histori : histori
# playstore : playstore
# relevan : relevan
# kaya : kaya
# unistall : unistall
# yalive : yalive
# bisaemail : bisaemail
# masukbukabantuan : masukbukabantuan
# lengkapcukup : lengkapcukup
# digunakanterutama : digunakanterutama
# paylaternya : paylaternya
# dibutuhkanagar : dibutuhkanagar
# dipermudah : mudah
# bronet : bronet
# gb : gb
# hrtransaksi : hrtransaksi
# datanya : data
# pscnya : pscnya
# fiturnya : fiturnya
# bilangnya : bilang
# mempelajari : ajar
# nariknya : nariknya
# hhmmmbener : hhmmmbener
# menyusahkan : susah
# link : link
# pishing : pishing
# rentan : rentan
# akunku : akun
# bobol : bobol
# pelaku : laku
# menghilang : hilang
# mudahnya : mudah
# pemindahan : pindah
# pelajaran : ajar
# warna : warna
# pelangi : pelangi
# halaman : halaman
# diubah : ubah
# tampilan : tampil
# perbanyak : banyak
# kerjasama : kerjasama
# variatif : variatif
# mengajak : ajak
# sodara : sodara
# memake : memake
# praktikkarena : praktikkarena
# robot : robot
# mengurus : urus
# mengadunya : adu
# csnya : csnya
# lucu : lucu
# ongkinya : ongkinya
# ditiadakan : tiada
# arahkan : arah
# nabung : nabung
# shoopie : shoopie
# penguna : penguna
# nycepat : nycepat
# benahi : benah
# pelangan : pelang
# menjebak : jebak
# tagih : tagih
# akui : aku
# sitem : sitem
# paksa : paksa
# ah : ah
# pengantaran : antar
# dilht : dilht
# dikirimnya : kirim
# mingak : mingak
# merek : merek
# sesuaijd : sesuaijd
# kecewasama : kecewasama
# otomatischat : otomatischat
# gagal : gagal
# mengalami : alami
# uninstall : uninstall
# dimengerti : erti
# mengirim : kirim
# setatus : setatus
# pesnan : pesnan
# kantor : kantor
# cat : cat
# laev : laev
# setia : setia
# flashdeal : flashdeal
# belinya : beli
# shake : shake
# thon : thon
# dapatnya : dapat
# perak : perak
# bukapalak : bukapalak
# larinya : lari
# gede : gede
# duitnya : duit
# kemanamana : kemanamana
# maksudnya : maksud
# itikad : itikad
# baiknya : baik
# lakukan : laku
# sarankan : saran
# cheating : cheating
# mbanking : mbanking
# notif : notif
# pesanannya : pesan
# direfund : direfund
# keterima : terima
# knapa : knapa
# imbas : imbas
# baguscuma : baguscuma
# promosi : promosi
# gratisnya : gratis
# dibatasi : batas
# dagangan : dagang
# sekaliditingkatkan : sekaliditingkatkan
# konsumennyaterima : konsumennyaterima
# keren : keren
# kedepannya : depan
# srkarang : srkarang
# simpel : simpel
# minimalis : minimal
# lemotlebih : lemotlebih
# lite : lite
# menjangkau : jangkau
# diabaikan : abai
# nakal : nakal
# dropshiper : dropshiper
# interaksi : interaksi
# sopan : sopan
# menciptakan : cipta
# berjualbeli : berjualbeli
# proteksi : proteksi
# selulernya : seluler
# persyaratan : syarat
# berfungsitidak : berfungsitidak
# diklikperbaiki : diklikperbaiki
# binrang : binrang
# puas : puas
# berkali : kali
# pendaftarannya : daftar
# terima kasih : terima kasih
# jujur : jujur
# masterpiece : masterpiece
# expres : expres
# mentang : mentang
# kapokk : kapokk
# dibawa : bawa
# mutermuter : mutermuter
# pokoknya : pokok
# untungnya : untung
# shope : shope
# iseng : iseng
# kepercayaan : percaya
# kemudahan : mudah
# asuransi : asuransi
# covid : covid
# dicentang : centang
# merekatanpa : merekatanpa
# centangkalau : centangkalau
# tambahan : tambah
# olah : olah
# betmen : betmen
# kompetitornya : kompetitor
# tarik : tarik
# pengoperasiannya : operasi
# simple : simple
# unggul : unggul
# kompetitor : kompetitor
# responnya : responnya
# sebnarny : sebnarny
# disesuaikan : sesuai
# adminnya : adminnya
# bekukan : beku
# aktifkan : aktif
# enggak jelas : enggak jelas
# sensistif : sensistif
# rokkvapepod : rokkvapepod
# engine : engine
# alihkan : alih
# verivikasi : verivikasi
# emailtpi : emailtpi
# emailganti : emailganti
# ribetharus : ribetharus
# inti : inti
# meribet : meribet
# giniharus : giniharus
# dipindah : pindah
# sandi : sandi
# emailku : email
# lupajadi : lupajadi
# iniq : iniq
# log : log
# facebook : facebook
# lamake : lamake
# uangku : uang
# recomend : recomend
# bobrok : bobrok
# inbox : inbox
# menyebalkan : sebal
# cash : cash
# back : back
# saingan : saing
# vgduweinv : vgduweinv
# pertambahan : tambah
# dimasukkan : masuk
# trhubung : trhubung
# batalakan : batalakan
# bagu : bagu
# force : force
# closing : closing
# android : android
# lollipop : lollipop
# managementdidengar : managementdidengar
# cust : cust
# adakan : adakan
# menghubungkan : hubung
# sajasangat : sajasangat
# nomel : nomel
# dipakaisangat : dipakaisangat
# ngumpulin : ngumpulin
# mengerikantinggi : mengerikantinggi
# bakat : bakat
# tetaplah : tetap
# pintar : pintar
# dibaca : baca
# deskripsi : deskripsi
# harapan : harap
# yuk : yuk
# manfaatkan : manfaat
# kelemahan : lemah
# fokus : fokus
# sesuka : suka
# harganya : harga
# bersaing : saing
# ongkosnya : ongkos
# diperketat : ketat
# kenakalan : nakal
# mnurut : mnurut
# ketimbang : ketimbang
# paylatter : paylatter
# bukalapakkenapa : bukalapakkenapa
# indomart : indomart
# alfamrt : alfamrt
# berpikir : pikir
# dikondisikan : kondisi
# kemahalan : mahal
# kepaksa : paksa
# ecomerce : ecomerce
# bgtz : bgtz
# gan : gan
# membanyaki : banyak
# hemat : hemat
# rampenyimpanan : rampenyimpanan
# mulu : mulu
# tanggapi : tanggap
# instagram : instagram
# terkirim : kirim
# lapor : lapor
# terbantu : bantu
# keperluan : perlu
# sparepart : sparepart
# kendaraan : kendara
# tanggadllharga : tanggadllharga
# product : product
# original : original
# deskripsiongkirnya : deskripsiongkirnya
# digunakanmantappp : digunakanmantappp
# kelemahannya : lemah
# aplikasihnya : aplikasihnya
# perubahannya : ubah
# aktivasi : aktivasi
# kelar : kelar
# puluh : puluh
# mendownload : mendownload
# siniuntuk : siniuntuk
# kembaligiliran : kembaligiliran
# lapakdi : lapakdi
# makasihhh : makasihhh
# apes : apes
# operasi : operasi
# sampainya : sampai
# sumpah : sumpah
# cooooooooo : cooooooooo
# jarak : jarak
# tampilannya : tampil
# animasi : animasi
# kadaluarsa : kadaluarsa
# slow : slow
# ayo : ayo
# flash : flash
# sale : sale
# shpe : shpe
# tokopaedi : tokopaedi
# berani : berani
# mengikut : ikut
# harinya : hari
# variasi : variasi
# tenggelam : tenggelam
# berinovasi : inovasi
# notifikasi : notifikasi
# jeda : jeda
# masyarakat : masyarakat
# efesien : efesien
# ditingkatkan : tingkat
# feed : feed
# streaming : streaming
# ginigini : ginigini
# yaelah : yaelah
# dpat : dpat
# tranksaksi : tranksaksi
# lantas : lantas
# mengunakan : mengunakan
# indak : indak
# ajaapk : ajaapk
# batas : batas
# mengepentingkan : penting
# apkanya : apkanya
# kencang : kencang
# dilunasi : lunas
# lcd : lcd
# ngeblank : ngeblank
# maksimal : maksimal
# hancur : hancur
# kunjung : kunjung
# berstatus : status
# main : main
# mqu : mqu
# audah : audah
# vertifikasi : vertifikasi
# urus : urus
# puter : puter
# info : info
# halu : halu
# ganda : ganda
# disediakan : sedia
# karenan : karenan
# antrian : antri
# manusia : manusia
# bukaexpres : bukaexpres
# taggal : taggal
# komplin : komplin
# parahhhhhhh : parahhhhhhh
# modal : modal
# efisien : efisien
# diandalkan : andal
# dirumah : rumah
# dijalan : jalan
# raya : raya
# bangkrut : bangkrut
# tokok : tokok
# diputar : putar
# love : love
# kbuka : kbuka
# mewadahi : wadah
# pelapakpenjual : pelapakpenjual
# menjual : jual
# produknya : produk
# pedagang : dagang
# ready : ready
# jumlanya : jumlanya
# cacat : cacat
# materi : materi
# lembaga : lembaga
# dipelajari : ajar
# dipahami : paham
# pembelajaran : ajar
# butuhkan : butuh
# check : check
# out : out
# bukalapakpaylater : bukalapakpaylater
# pembayarantapi : pembayarantapi
# apdate : apdate
# laman : laman
# penjualanchatcm : penjualanchatcm
# mahalbanyakin : mahalbanyakin
# manjakan : manja
# sebelahgratis : sebelahgratis
# ongkirgratis : ongkirgratis
# ongkirdan : ongkirdan
# menolak : tolak
# padahalkami : padahalkami
# terimatapi : terimatapi
# laporan : lapor
# pedback : pedback
# mengabaikan : abai
# negatif : negatif
# ongkirdiskon : ongkirdiskon
# payahhhhh : payahhhhh
# sapa : sapa
# jawabannya : jawab
# iya : iya
# pelayannya : layan
# topup : topup
# bembelian : bembelian
# virtual : virtual
# accord : accord
# pusing : pusing
# teamnya : teamnya
# permhonan : permhonan
# loloskan : lolos
# keb : keb
# menyenangkan : senang
# berbelanja : belanja
# depannya : depan
# bukaexpress : bukaexpress
# reg : reg
# terkirimnya : kirim
# servicenya : servicenya
# sambungin : sambungin
# same : same
# day : day
# nanyain : nanyain
# batalin : batalin
# complain : complain
# invoice : invoice
# dcek : dcek
# ibanking : ibanking
# motong : motong
# melewati : lewat
# pemrosesan : pemrosesan
# tertahan : tahan
# flyer : flyer
# buru : buru
# terhambat : hambat
# layanannya : layan
# kecuali : kecuali
# tolonh : tolonh
# developer : developer
# alhamdullilah : alhamdullilah
# selesaikan : selesai
# baikuntuk : baikuntuk
# tempatkan : tempat
# mudahkan : mudah
# cstks : cstks
# hilangkan : hilang
# pinjol : pinjol
# oren : oren
# busuk : busuk
# payletter : payletter
# its : its
# oketerima : oketerima
# recomment : recomment
# dibatalkanpadahal : dibatalkanpadahal
# pahami : paham
# insyaallah : insyaallah
# amanah : amanah
# putar : putar
# esoknya : esok
# niat : niat
# dibohongi : bohong
# kesulitanmisal : kesulitanmisal
# gagaltrnsaksi : gagaltrnsaksi
# setlh : setlh
# jamproses : jamproses
# lamadan : lamadan
# sdikit : sdikit
# terganggu : ganggu
# spamnya : spamnya
# kubilang : bilang
# is : is
# the : the
# best : best
# dear : dear
# milik : milik
# kota : kota
# ngajukan : ngajukan
# khusus : khusus
# pembajakan : baja
# menonton : tonton
# tutorial : tutorial
# terupdate : terupdate
# terimakenapa : terimakenapa
# terimaada : terimaada
# olshop : olshop
# segi : segi
# bersaingnya : saing
# berloma : berloma
# lomba : lomba
# mahalin : mahalin
# sicepat : sicepat
# pick : pick
# mengecewakann : mengecewakann
# fanspage : fanspage
# naikin : naikin
# pembelanjaan : belanja
# minimal : minimal
# apdet : apdet
# berpikiran : pikir
# jelasorder : jelasorder
# grab : grab
# pickup : pickup
# kenyataan : nyata
# serahkan : serah
# hubungilive : hubungilive
# taaiiiiii : taaiiiiii
# berulang : ulang
# semau : mau
# mu : mu
# sesuaidengan : sesuaidengan
# kenyataannya : nyata
# sihmasa : sihmasa
# menutup : tutup
# sajaeh : sajaeh
# diskusi : diskusi
# ditutup : tutup
# joss : joss
# btw : btw
# jioss : jioss
# telegram : telegram
# whatsapp : whatsapp
# enak : enak
# nunggunya : nunggunya
# barangn : barangn
# paspus : paspus
# bubar : bubar
# nonaktifkandi : nonaktifkandi
# aktifdibekukan : aktifdibekukan
# belooommm : belooommm
# naikan : naik
# bekuan : beku
# koto : koto
# seler : seler
# job : job
# haiisaya : haiisaya
# bukalapakbukalapak : bukalapakbukalapak
# bagusuntuk : bagusuntuk
# ikuti : ikut
# casbak : casbak
# jamin : jamin
# klou : klou
# puluhan : puluh
# vocher : vocher
# casback : casback
# atou : atou
# nipu : nipu
# dgan : dgan
# besaran : besar
# sando : sando
# kuno : kuno
# adh : adh
# kredibel : kredibel
# respect : respect
# berkualitas : kualitas
# care : care
# hape : hape
# dipengaturan : atur
# kebalik : balik
# games : games
# mitragames : mitragames
# zonk : zonk
# sesi : sesi
# bintangpermasalahan : bintangpermasalahan
# timbul : timbul
# match : match
# bijak : bijak
# ditulis : tulis
# tyt : tyt
# adaadmin : adaadmin
# responsifjgn : responsifjgn
# diam : diam
# ajamerugikan : ajamerugikan
# bela : bela
# begadang : begadang
# sembuh : sembuh
# fiturfiturnya : fiturfiturnya
# pertahanin : pertahanin
# pendatang : datang
# tahap : tahap
# bang : bang
# btpn : btpn
# baca : baca
# semenjak : semenjak
# tlpn : tlpn
# penelpon : telpon
# rizqi : rizqi
# ramadan : ramadan
# hadiah : hadiah
# jta : jta
# responsif : responsif
# terlambat : lambat
# reksa : reksa
# cairkan : cair
# loadingnya : loadingnya
# pergantian : ganti
# toke : toke
# account : account
# jahat : jahat
# adminya : adminya
# limitnya : limit
# terkecuali : kecuali
# berasa : asa
# paylattercicilan : paylattercicilan
# penciaran : ciar
# terina : ina
# terpilih : pilih
# dipacking : dipacking
# rapi : rapi
# melacak : lacak
# vocernya : vocernya
# batuan : batu
# rspon : rspon
# wd : wd
# karenakan : karena
# transaks : transaks
# tingkatkandan : tingkatkandan
# bayarnya : bayar
# harganyabanyak : harganyabanyak
# jenis : jenis
# barangnyasucses : barangnyasucses
# sebutin : sebutin
# diperbaharui : baharu
# hadeww : hadeww
# delive : delive
# rincian : rincian
# penasaran : penasaran
# surprise : surprise
# komentar : komentar
# not : not
# found : found
# rekaman : rekam
# layar : layar
# informasi : informasi
# dapatkan : dapat
# maunya : mau
# kualitas : kualitas
# ribetmasa : ribetmasa
# hadeeeuuuhhhh : hadeeeuuuhhhh
# revisi : revisi
# ulasannyapitur : ulasannyapitur
# gakjelas : gakjelas
# tailah : tailah
# tlfn : tlfn
# bct : bct
# srvice : srvice
# ngehubungin : ngehubungin
# ngatasin : ngatasin
# pln : pln
# bunganya : bunga
# benertempo : benertempo
# ribugile : ribugile
# rentenirampuungak : rentenirampuungak
# ongkos : ongkos
# tembus : tembus
# gram : gram
# kabserang : kabserang
# sadis : sadis
# keputusan : putus
# maintenance : maintenance
# haduhhh : haduhhh
# pesenan : sen
# besok : besok
# reguler : reguler
# dibatalin : dibatalin
# ngikut : ngikut
# kurirnya : kurir
# dapatin : dapatin
# berjam : jam
# putih : putih
# oi : oi
# nyarinya : nyarinya
# loding : loding
# sinyalnya : sinyal
# terferifikasibukti : terferifikasibukti
# adajujur : adajujur
# kreatif : kreatif
# produktif : produktif
# bisnis : bisnis
# mantab : mantab
# sinergi : sinergi
# tukang : tukang
# ngemis : ngemis
# kukasih : kasih
# algoritma : algoritma
# dibenerin : dibenerin
# sebel : sebel
# lapakkarna : lapakkarna
# bayarmaupun : bayarmaupun
# sulitnya : sulit
# presidenbarang : presidenbarang
# dilapak : lapak
# semuasecara : semuasecara
# mengusir : usir
# penjualmakanya : penjualmakanya
# roko : roko
# onlaine : onlaine
# jangkauan : jangkau
# luas : luas
# otpnyabeli : otpnyabeli
# emas : emas
# otpnya : otpnya
# munculgiliran : munculgiliran
# pencuri : curi
# desemer : desemer
# ditahan : tahan
# sungguh : sungguh
# miris : miris
# sosmed : sosmed
# rugiiiii : rugiiiii
# bukasend : bukasend
# penyantuman : penyantuman
# kecamatan : camat
# kabupaten : kabupaten
# diedit : edit
# enakan : enak
# pulau : pulau
# pengisian : isi
# fleksibel : fleksibel
# template : template
# perform : perform
# quick : quick
# respons : respons
# initapi : initapi
# dikembalikandibatalkan : dikembalikandibatalkan
# tersediaheran : tersediaheran
# dipajang : pajang
# etalasenyaaplikasi : etalasenyaaplikasi
# kadaluwarsa : kadaluwarsa
# bukalapakpmbayaran : bukalapakpmbayaran
# lkkan : lkkan
# ovo : ovo
# pemesann : pemesann
# berkurangsy : berkurangsy
# responapakah : responapakah
# lgpembayarn : lgpembayarn
# pmbayaran : pmbayaran
# lari : lari
# nyakapok : nyakapok
# brng : brng
# bangkai : bangkai
# pembaruan : baru
# diperbaruitggl : diperbaruitggl
# menginstal : menginstal
# pengunduhan : unduh
# brenti : brenti
# ditengah : tengah
# pengin : pengin
# nguras : nguras
# dalih : dalih
# lembaruan : lembaruan
# linkaja : linkaja
# ki : ki
# keuntunganya : keuntunganya
# lho : lho
# bersahabat : sahabat
# diantar : antar
# bagusdan : bagusdan
# barangbarangnya : barangbarangnya
# kuotadan : kuotadan
# terbaik : baik
# penjuslan : penjuslan
# fituruntuk : fituruntuk
# kuran : kur
# kmna : kmna
# komplaind : komplaind
# pmbeli : pmbeli
# terupdatemasih : terupdatemasih
# mrugikan : mrugikan
# inifitur : inifitur
# bla : bla
# dsruh : dsruh
# jlasss : jlasss
# kmnaa : kmnaa
# panduan : pandu
# singkron : singkron
# puyeng : puyeng
# langkah : langkah
# anjurkan : anjur
# jalankan : jalan
# petunjuk : tunjuk
# servis : servis
# terverikasi : terverikasi
# ituitu : ituitu
# secepatnya : cepat
# berkalikali : berkalikali
# sedih : sedih
# percayaterima : percayaterima
# bukalapakbarang : bukalapakbarang
# yahuuuutt : yahuuuutt
# kasihby : kasihby
# rahesa : rahesa
# dewaga : dewaga
# adanyadi : adanyadi
# manasemua : manasemua
# lapakga : lapakga
# tertarik : tarik
# lapakselalu : lapakselalu
# memenuhi : penuh
# membatu : batu
# butuhlncr : butuhlncr
# terusmudahan : terusmudahan
# instal : instal
# tapcash : tapcash
# syukur : syukur
# bagushanya : bagushanya
# saransayangnya : saransayangnya
# pinjam : pinjam
# tunai : tunai
# alcoba : alcoba
# semprna : semprna
# mantapsangat : mantapsangat
# membantuterima : membantuterima
# usul : usul
# cicilannya : cicil
# pinjaman : pinjam
# paslater : paslater
# kedaluarsa : kedaluarsa
# selamat : selamat
# kredivo : kredivo
# dosa : dosa
# ditolakanu : ditolakanu
# weangsuran : weangsuran
# waktunyagk : waktunyagk
# bejakn : bejakn
# sikredivo : sikredivo
# aing : aing
# naon : naon
# photo : photo
# ukuran : ukur
# file : file
# melebihi : lebih
# mbak : mbak
# kb : kb
# telfon : telfon
# outo : outo
# tinggalkan : tinggal
# berteletele : berteletele
# menjamin : jamin
# prosesnnya : prosesnnya
# transparan : transparan
# permisi : permisi
# send : send
# kecepatan : cepat
# ketepatan : tepat
# leluasa : leluasa
# lawak : lawak
# underratedmasih : underratedmasih
# konyol : konyol
# tingkah : tingkah
# itupun : itu
# sadarbaru : sadarbaru
# engah : engah
# kekecewaan : kecewa
# kalopun : kalo
# wsrted : wsrted
# maa : maa
# syaa : syaa
# allah : allah
# professional : professional
# komunikatif : komunikatif
# menikmati : nikmat
# bk : bk
# bertahun : tahun
# naikada : naikada
# pengirimanbuka : pengirimanbuka
# bangetada : bangetada
# sakitga : sakitga
# alhamdulillahlg : alhamdulillahlg
# pulsapaketan : pulsapaketan
# habislangsung : habislangsung
# ditujuan : tuju
# toped : toped
# benaran : benar
# mudahmudahan : mudahmudahan
# lupa : lupa
# expirednya : expirednya
# gegara : gegara
# expired : expired
# ditinggal : tinggal
# penjualseller : penjualseller
# masak : masak
# setuju : tuju
# seharga : harga
# pejual : jual
# tolol : tolol
# layout : layout
# payment : payment
# dst : dst
# ahlinya : ahli
# kentang : kentang
# oyen : oyen
# rivalnya : rival
# histoririwayat : histoririwayat
# sampaisampai : sampaisampai
# penguriman : penguriman
# cinta : cinta
# lokal : lokal
# pungkiri : pungkiri
# diurusnya : urus
# kemunduran : mundur
# saluran : salur
# perusahaan : usaha
# dpet : dpet
# belnja : belnja
# setidky : setidky
# trnsaksi : trnsaksi
# peliiit : peliiit
# jutaan : juta
# kga : kga
# aktifsaya : aktifsaya
# provider : provider
# ternyataaaaa : ternyataaaaa
# masaalah : masaalah
# keteranngannya : keteranngannya
# dendanya : denda
# modus : modus
# ego : ego
# nyakl : nyakl
# dinaikinsama : dinaikinsama
# cicilan : cicil
# memecahkan : pecah
# putuskan : putus
# percaya : percaya
# budget : budget
# paspasan : paspasan
# materai : materai
# selfi : selfi
# gabung : gabung
# customernya : customernya
# apliksi : apliksi
# slalau : slalau
# titipkan : titip
# saing : saing
# yaudah : yaudah
# haluan : haluan
# ditoko : toko
# hahahaaaa : hahahaaaa
# responsip : responsip
# tap : tap
# bukaexspress : bukaexspress
# tempel : tempel
# infonya : info
# kompensasi : kompensasi
# langganan : langgan
# bukalapakis : bukalapakis
# bagussangat : bagussangat
# prakerjasekoga : prakerjasekoga
# unggah : unggah
# membantusemoga : membantusemoga
# besartambah : besartambah
# syarat : syarat
# mnyesal : mnyesal
# anehnya : aneh
# cerdas : cerdas
# disita : sita
# bea : bea
# cukai : cukai
# marah : marah
# menelontarkan : menelontarkan
# kasar : kasar
# lainya : lai
# ditipu : tipu
# terjamin : jamin
# mancing : mancing
# ahahhahaha : ahahhahaha
# bermutuni : bermutuni
# game : game
# lemoooooottttttttttttt : lemoooooottttttttttttt
# very : very
# fikasi : fikasi
# hebat : hebat
# merchan : merchan
# lainnyapantas : lainnyapantas
# hijau : hijau
# orens : orens
# ungumerah : ungumerah
# omgkir : omgkir
# bukareg : bukareg
# tiputipu : tiputipu
# dibiaya : biaya
# fake : fake
# kekurangannya : kurang
# epesien : epesien
# kouta : kouta
# commerce : commerce
# indonesiasaya : indonesiasaya
# endapkan : endap
# alasanpun : alas
# akal : akal
# diendapi : endap
# woy : woy
# keras : keras
# dicairka : dicairka
# tranfer : tranfer
# banking : banking
# ol : ol
# berapakali : berapakali
# un : un
# brooo : brooo
# sabeli : sabel
# jawa : jawa
# kertas : kertas
# bertuliskan : tulis
# dibebankan : beban
# kesaya : saya
# gimmick : gimmick
# logout : logout
# rada : rada
# memperhatikan : perhati
# pedangang : pedangang
# kee : kee
# berbtas : berbtas
# cuan : cuan
# atuh : atuh
# klikklikkan : klikklikkan
# nyantol : nyantol
# satupun : satu
# padahan : padah
# computers : computers
# dianggap : anggap
# kecewaa : kecewaa
# unistal : unistal
# kategori : kategori
# dibedakan : beda
# terkhusus : khusus
# jangka : jangka
# disamakan : sama
# ngutang : ngutang
# imbasnya : imbas
# abaikan : abai
# tindas : tindas
# diatur : atur
# variannya : varian
# memasukan : pasu
# dikala : kala
# ngisi : ngisi
# pulsapaket : pulsapaket
# kenomor : nomor
# beranda : beranda
# diganti : ganti
# bodoh : bodoh
# kosongin : kosongin
# logikanya : logika
# ntk : ntk
# penautan : taut
# pilhan : pilhan
# telp : telp
# menautkan : taut
# semuatdk : semuatdk
# ditanyakn : ditanyakn
# tiket : tiket
# april : april
# cairpadahal : cairpadahal
# cairini : cairini
# temanteman : temanteman
# garagara : garagara
# cantumkan : cantum
# kembalian : kembali
# lenyap : lenyap
# dialihkan : alih
# ngubungin : ngubungin
# kekirim : kirim
# bos : bos
# kepastian : pasti
# memohon : mohon
# berbulan : bulan
# belanjakan : belanja
# gulung : gulung
# tikar : tikar
# noh : noh
# refresh : refresh
# discon : discon
# batasi : batas
# semangkin : semangkin
# nongkrong : nongkrong
# penjualterbatas : penjualterbatas
# huuuhuyyy : huuuhuyyy
# lihatnya : lihat
# button : button
# diskonnya : diskon
# sasaran : sasar
# wkwkwk : wkwkwk
# disitu : situ
# blanjapengajuan : blanjapengajuan
# ditolaktidak : ditolaktidak
# gonta : gonta
# datekalau : datekalau
# date : date
# bukajadi : bukajadi
# malestidak : malestidak
# duluapk : duluapk
# menarikbersaing : menarikbersaing
# jauhkreatifitas : jauhkreatifitas
# monoton : monoton
# nyekek : nyekek
# gila : gila
# pemakai : pakai
# nyata : nyata
# pakain : pakain
# sepatu : sepatu
# diskripsi : skripsi
# dipesan : pes
# standar : standar
# memaki : maki
# cenderung : cenderung
# rugikan : rugi
# ruang : ruang
# melindungi : lindung
# ditransfer : transfer
# emoney : emoney
# rupiah : rupiah
# penyelesaian : selesai
# danasudah : danasudah
# gagaal : gagaal
# lagipdhal : lagipdhal
# terhubungmasih : terhubungmasih
# terhub : terhub
# ung : ung
# samatolong : samatolong
# bantuanyasudah : bantuanyasudah
# appreview : appreview
# kagak : kagak
# bisaudah : bisaudah
# hsilnya : hsilnya
# ajatp : ajatp
# terhubungcuma : terhubungcuma
# bulalapaknya : bulalapaknya
# responkalaupun : responkalaupun
# ontime : ontime
# ambrolllllllll : ambrolllllllll
# dibandingkan : banding
# kemunculannya : muncul
# bertahan : tahan
# merah : merah
# ramai : ramai
# lihatkecuali : lihatkecuali
# services : services
# social : social
# media : media
# edit : edit
# juli : juli
# nongol : nongol
# pop : pop
# vitur : vitur
# anehkenapakarna : anehkenapakarna
# trx : trx
# inibatal : inibatal
# bisakarna : bisakarna
# sellersdngkan : sellersdngkan
# jugajdi : jugajdi
# gmnabelajarlah : gmnabelajarlah
# shopebuat : shopebuat
# kcuali : kcuali
# psanan : psanan
# atm : atm
# tanggapamnya : tanggapamnya
# tanggap : tanggap
# selebihnya : lebih
# promopromo : promopromo
# minimum : minimum
# menegur : tegur
# mengomongnya : omong
# modern : modern
# membingungkan : bingung
# kian : kian
# kecenderungan : cenderung
# dulukalau : dulukalau
# tambahkan : tambah
# matket : matket
# pleace : pleace
# dicairkan : cair
# ataupum : ataupum
# alhasil : alhasil
# menumpuk : tumpuk
# gunain : gunain
# bamtuan : bamtuan
# delay : delay
# kelanjutannya : lanjut
# dibelanjakan : belanja
# apaapa : apaapa
# diriwayat : riwayat
# follow : follow
# lngsng : lngsng
# dicancel : dicancel
# basa : basa
# basi : basi
# password : password
# diarahin : diarahin
# layani : layan
# missed : missed
# mengetik : etik
# eneg : eneg
# recomand : recomand
# fast : fast
# respone : respone
# tnggung : tnggung
# bye : bye
# oknum : oknum
# parahnya : parah
# bukapadahal : bukapadahal
# bayaryg : bayaryg
# apapunsy : apapunsy
# melapor : lapor
# chatdari : chatdari
# disuru : disuru
# emaildari : emaildari
# proseshadir : proseshadir
# bintng : bintng
# memperbaiki : baik
# dinonaktifkan : nonaktif
# mengatuhi : mengatuhi
# penyebab : sebab
# pencerahannya : cerah
# vidio : vidio
# sudut : sudut
# dzoliman : dzoliman
# berantakan : beranta
# iklas : iklas
# mengakses : akses
# platihan : platihan
# pra : pra
# mantapmoga : mantapmoga
# berkelanjutannext : berkelanjutannext
# lgcuma : lgcuma
# trucingjd : trucingjd
# sejam : jam
# sekrg : sekrg
# pelapaktapi : pelapaktapi
# saldosulit : saldosulit
# akunkok : akunkok
# sihk : sihk
# bukalapakbukannya : bukalapakbukannya
# bagusmalah : bagusmalah
# memburukperbaikin : memburukperbaikin
# laaahklo : laaahklo
# penilaiannyakecewa : penilaiannyakecewa
# cacatvocer : cacatvocer
# dipakeakhirnya : dipakeakhirnya
# sebulanbjngn : sebulanbjngn
# lainnyaakan : lainnyaakan
# utama : utama
# purwodadi : purwodadi
# memakan : makan
# separo : paro
# trtentu : trtentu
# wilayah : wilayah
# dapt : dapt
# jama : jama
# chek : chek
# mahalsaya : mahalsaya
# gitar : gitar
# ...
# stuck : stuck
# marahmallow : marahmallow
# keberatan : berat
# sihcoba : sihcoba
# dikurangi : rang
# terbuka : buka
# sopi : sopi
# ridak : ridak
# terferivikasi : terferivikasi
# menanggapi : tanggap
# diputuskan : putus
# disalahkan : salah
# all : all
# indonesia : indonesia
# menjalankan : jalan
# kelola : kelola
# profesional : profesional
# termaka : maka
# bossku : bossku
# gendut : gendut
# walupun : walupun
# tujuan : tuju
# area : area
# agentnya : agentnya
# sangking : sangking
# lur : lur
# penghargaan : harga
# menampak : tampak
# dinilai : nilai
# mengakak : akak
# semkin : semkin
# membingungkaninfo : membingungkaninfo
# confirm : confirm
# dtrima : dtrima
# lamakasian : lamakasian
# semalem : semalem
# smart : smart
# teraman : ram
# greget : greget
# oooooooo : oooooooo
# tambahgoblok : tambahgoblok
# goblok : goblok
# susuai : susuai
# kemauan : mau
# ditokonya : toko
# unik : unik
# tjdak : tjdak
# prakiraan : prakira
# codbarang : codbarang
# berhari : hari
# berjalanbarang : berjalanbarang
# tujuankemungkinan : tujuankemungkinan
# miskin : miskin
# harta : harta
# akhlat : akhlat
# kesadaran : sadar
# waras : waras
# tutuptetap : tutuptetap
# dimananyari : dimananyari
# adahancur : adahancur
# adakah : ada
# bukalemot : bukalemot
# baikharga : baikharga
# baikproduk : baikproduk
# notifnya : notifnya
# contohbarang : contohbarang
# sampaipengiriman : sampaipengiriman
# dilacakkonfirmasi : dilacakkonfirmasi
# sampaitapi : sampaitapi
# bonuscashback : bonuscashback
# nohp : nohp
# yahkan : yahkan
# rahasia : rahasia
# aktifmaaf : aktifmaaf
# mantul : mantul
# penerbitan : terbit
# terbit : terbit
# saudara : saudara
# gagalmenunggu : gagalmenunggu
# meninggalkan : tinggal
# vouchervoucher : vouchervoucher
# juni : juni
# tokotoko : tokotoko
# hilanghangus : hilanghangus
# tokai : tokai
# makan : makan
# ketidak : tidak
# jelasan : jelas
# bagusbagus : bagusbagus
# singkat : singkat
# bandwidth : bandwidth
# perlebar : lebar
# jalur : jalur
# bersamaan : sama
# terhindar : hindar
# pembatasan : batas
# susaahhhhhh : susaahhhhhh
# pindaahh : pindaahh
# garibet : garibet
# lebar : lebar
# susahh : susahh
# kelarin : kelarin
# money : money
# topupgiliran : topupgiliran
# ditempel : tempel
# pendingsudah : pendingsudah
# gitumasa : gitumasa
# mandiri : mandiri
# alfa : alfa
# klaim : klaim
# sekarangseperti : sekarangseperti
# pelapaknyasebelumnya : pelapaknyasebelumnya
# minus : minus
# bijaksana : bijaksana
# masalahtrims : masalahtrims
# arah : arah
# tangan : tangan
# dipersulit : sulit
# diatasi : atas
# lanjuti : lanjut
# indosat : indosat
# tinjau : tinjau
# pengirima : pengirima
# ditagih : tagih
# tercantum : cantum
# pemula : mula
# sayabukalapak : sayabukalapak
# sekalidan : sekalidan
# susahsudah : susahsudah
# lolos : lolos
# verikasi : verikasi
# kredivopaylater : kredivopaylater
# mei : mei
# terbayarsaya : terbayarsaya
# dipindahkan : pindah
# paswood : paswood
# terjual : jual
# mengatasi : atas
# ridha : ridha
# kesan : kesan
# menulis : tulis
# dihadapi : hadap
# ngeklik : ngeklik
# chatan : chatan
# alternatif : alternatif
# lainkah : lain
# alih : alih
# cakap : cakap
# materinya : materi
# praktekan : praktek
# supercuan : supercuan
# mengarah : arah
# berdasarkan : dasar
# huuuf : huuuf
# diclaim : diclaim
# berbarengan : bareng
# resmi : resmi
# lapaknya : lapak
# keuntungan : untung
# bukapay : bukapay
# bukanantuan : bukanantuan
# diguanakan : diguanakan
# sajah : sajah
# fiitur : fiitur
# hadir : hadir
# pengiraman : iram
# dipelosok : pelosok
# mengembangkan : kembang
# fikri : fikri
# azhari : azhari
# tekor : tekor
# diakses : akses
# ngurangin : ngurangin
# rewards : rewards
# tungguin : tungguin
# tiru : tiru
# paketku : paket
# sorry : sorry
# dipakaimenurut : dipakaimenurut
# masalahtapi : masalahtapi
# lagibuka : lagibuka
# jelasdan : jelasdan
# mengaktifan : aktif
# mengapai : kapai
# gimanaya : gimanaya
# sesalkan : sesal
# besarsedangkan : besarsedangkan
# layananmaaf : layananmaaf
# ugrade : ugrade
# merekam : rekam
# rekam : rekam
# label : label
# ketanggapan : tanggap
# pebaiki : baik
# ketentuanya : ketentuanya
# latter : latter
# relatif : relatif
# response : response
# pembelibisa : pembelibisa
# gampangdan : gampangdan
# dululive : dululive
# benci : benci
# ajalah : aja
# muak : muak
# anjienng : anjienng
# yga : yga
# seijo : seijo
# shopi : shopi
# jadulsuper : jadulsuper
# dngklw : dngklw
# nyamksh : nyamksh
# redup : redup
# dagang : dagang
# sehari : hari
# laternya : laternya
# ferifikasi : ferifikasi
# terang : terang
# dilingkaran : lingkar
# intruksi : intruksi
# spion : spion
# baju : baju
# gamis : gamis
# tampa : tampa
# sh : sh
# jualanbelanja : jualanbelanja
# atasi : atas
# peniputransaksi : peniputransaksi
# bib : bib
# menerbitkan : terbit
# regulasi : regulasi
# maks : maks
# bursa : bursa
# setujui : tuju
# heran : heran
# far : far
# kredivothanks : kredivothanks
# yajangan : yajangan
# lainsaran : lainsaran
# niadain : niadain
# grtis : grtis
# belanjatanggal : belanjatanggal
# nyamaaf : nyamaaf
# ajapaylater : ajapaylater
# kendalasaya : kendalasaya
# masalahpas : masalahpas
# problem : problem
# nyarepot : nyarepot
# nantihehe : nantihehe
# double : double
# truss : truss
# uangnyaa : uangnyaa
# udan : udan
# apklikasi : apklikasi
# bermaaf : maaf
# irang : irang
# admintnya : admintnya
# tollooll : tollooll
# buta : buta
# huruf : huruf
# logika : logika
# intinya : inti
# taii : taii
# kucing : kucing
# komunikasi : komunikasi
# trace : trace
# sicepatnya : sicepatnya
# kacaaaaauuu : kacaaaaauuu
# pengirimnya : kirim
# tapiternyata : tapiternyata
# dimintain : dimintain
# kukir : kir
# aspek : aspek
# install : install
# ribeeeeetnya : ribeeeeetnya
# tagihanjadi : tagihanjadi
# ajaharus : ajaharus
# kemanatidak : kemanatidak
# terbuang : buang
# sia : sia
# menindak : tindak
# prosesmau : prosesmau
# haburkan : haburkan
# pelitl : pelitl
# menyadari : sadar
# terblokir : blokir
# mempekerjakan : kerja
# ekspektasi : ekspektasi
# bentuk : bentuk
# pitur : pitur
# slu : slu
# jong : jong
# ilangin : ilangin
# nyesellllllllllllllllllllllllllll : nyesellllllllllllllllllllllllllll
# kepuasan : puas
# nilai : nilai
# pokoke : pokoke
# diupdate : diupdate
# donlod : donlod
# donload : donload
# diinstal : diinstal
# dihp : dihp
# nomornyapun : nomor
# masmbak : masmbak
# ogah : ogah
# alasannya : alas
# hadapi : hadap
# disarankan : saran
# bgtga : bgtga
# digit : digit
# trnsfer : trnsfer
# ngipercuma : ngipercuma
# penyelesaianlicik : penyelesaianlicik
# bgtklo : bgtklo
# powerfull : powerfull
# pasar : pasar
# masukkin : masukkin
# gagalnya : gagal
# kepastianmales : kepastianmales
# inikomplen : inikomplen
# pelayananya : pelayananya
# memburuktoko : memburuktoko
# peringatan : ingat
# dahulupotongan : dahulupotongan
# besarkalau : besarkalau
# lainharap : lainharap
# ditiru : tiru
# referensi : referensi
# sihtoko : sihtoko
# discountnya : discountnya
# kesannya : kesan
# dasboard : dasboard
# ulas : ulas
# percepat : cepat
# nursari : nursari
# beratcekout : beratcekout
# jelasbeda : jelasbeda
# enteng : enteng
# loadingnnya : loadingnnya
# tidakdi : tidakdi
# team : team
# tidakbida : tidakbida
# tetapga : tetapga
# tandinya : tandinya
# payleternya : payleternya
# berlangganan : langgan
# kredivonya : kredivonya
# pengancaman : ancam
# deteksi : deteksi
# situs : situs
# persis : persis
# kalimat : kalimat
# jemput : jemput
# memperlambat : lambat
# ngambil : ngambil
# tunda : tunda
# shopie : shopie
# byr : byr
# menganti : anti
# verifikasiharus : verifikasiharus
# bukalapaksementara : bukalapaksementara
# nambahin : nambahin
# duluribet : duluribet
# njirtrus : njirtrus
# berswafoto : berswafoto
# tabunganudah : tabunganudah
# minjem : minjem
# ajee : ajee
# peribetsaingan : peribetsaingan
# banyakkalau : banyakkalau
# segalapadahal : segalapadahal
# cukupudh : cukupudh
# reapin : reapin
# sekaliparah : sekaliparah
# belanjain : belanjain
# bisahancur : bisahancur
# inj : inj
# ribettt : ribettt
# januari : januari
# gudang : gudang
# ajuin : ajuin
# menyengsarakan : sengsara
# inihadeuuuhhh : inihadeuuuhhh
# httpsbuklpkappreview : httpsbuklpkappreview
# penyeselesain : penyeselesain
# tranafer : tranafer
# disemua : semua
# minimalnya : minimal
# sistimnya : sistimnya
# sistim : sistim
# cocoknya : cocok
# transaksibegitu : transaksibegitu
# exit : exit
# lapaktrus : lapaktrus
# csgimana : csgimana
# sayatolong : sayatolong
# minkarena : minkarena
# mencetak : cetak
# stnk : stnk
# buruksaya : buruksaya
# servisechat : servisechat
# sajatp : sajatp
# dngn : dngn
# tentukan : tentu
# barng : barng
# handle : handle
# instant : instant
# next : next
# teraneh : aneh
# teribet : teribet
# dftar : dftar
# pesn : pesn
# mlkukan : mlkukan
# kjlsan : kjlsan
# pembelidi : pembelidi
# masalahkasih : masalahkasih
# sanksi : sanksi
# muka : muka
# secepat : cepat
# cepatnyakirim : cepatnyakirim
# selambat : lambat
# lambatnya : lambat
# bsnk : bsnk
# llivechat : llivechat
# from : from
# begtu : begtu
# bekuka : bekuka
# pmbatalan : pmbatalan
# hpnya : hpnya
# sayangkan : sayang
# sanjung : sanjung
# coins : coins
# ketidakjelasnkendala : ketidakjelasnkendala
# nyapun : nyapun
# tolang : tolang
# terblokirsudah : terblokirsudah
# rbsaya : rbsaya
# tlpon : tlpon
# telpnmasih : telpnmasih
# centre : centre
# dihubungiklo : dihubungiklo
# caranyasaya : caranyasaya
# rugimending : rugimending
# pakepelayananya : pakepelayananya
# kurangmenting : kurangmenting
# yasudah : yasudah
# unistalupdtesama : unistalupdtesama
# ajaklu : ajaklu
# teks : teks
# dalil : dalil
# jm : jm
# jawabapan : jawabapan
# kna : kna
# akunharus : akunharus
# moderasiproses : moderasiproses
# jelasdi : jelasdi
# tutupuninstal : tutupuninstal
# pusingkualitas : pusingkualitas
# rilislol : rilislol
# segini : gin
# alamimohon : alamimohon
# mingguan : minggu
# rapihkan : rapihkan
# campur : campur
# popup : popup
# hppadahal : hppadahal
# nisoalnya : nisoalnya
# installbelum : installbelum
# dikecewakan : kecewa
# nyayg : nyayg
# tenang : tenang
# jaminan : jamin
# lapaksukses : lapaksukses
# yt : yt
# dananya : dana
# bergabung : gabung
# antarkan : antar
# lebihuangpun : lebihuangpun
# kembalikansaya : kembalikansaya
# tokony : tokony
# syamksd : syamksd
# akhirakhir : akhirakhir
# hitung : hitung
# offline : offline
# takustom : takustom
# ojk : ojk
# scrol : scrol
# juva : juva
# gampamg : gampamg
# mengingatkanpunya : mengingatkanpunya
# keamanancustomer : keamanancustomer
# beraneka : aneka
# ragam : ragam
# sni : sni
# menariknya : tarik
# bintanglama : bintanglama
# bukalapakgak : bukalapakgak
# shopeetokopediadan : shopeetokopediadan
# saldopas : saldopas
# ngurusnyapas : ngurusnyapas
# ehhhh : ehhhh
# permintaan : minta
# aksesnya : akses
# lelettttttttt : lelettttttttt
# ramahpokoknya : ramahpokoknya
# telponmengganggu : telponmengganggu
# kerjaansaya : kerjaansaya
# bayartolong : bayartolong
# kabari : kabar
# nagihnya : nagihnya
# depkolektorjadi : depkolektorjadi
# ngeri : ngeri
# bangetbahkan : bangetbahkan
# diluar : luar
# adahadeuh : adahadeuh
# contact : contact
# disertakan : serta
# contct : contct
# prmbajakan : prmbajakan
# jobs : jobs
# serius : serius
# putusin : putusin
# koneksinya : koneksi
# akulaku : akulaku
# maksimalkan : maksimal
# memaksimalkan : maksimal
# tahunan : tahun
# rekanan : rekan
# dksih : dksih
# dehmasa : dehmasa
# bintangpdhl : bintangpdhl
# dksh : dksh
# transaksimasa : transaksimasa
# mulumaunya : mulumaunya
# sihjgn : sihjgn
# bosan : bosan
# gr : gr
# mslah : mslah
# iniinget : iniinget
# diulang : ulang
# baruaku : barua
# pngguna : pngguna
# anjirkesel : anjirkesel
# jdinya : jdinya
# kananeh : kananeh
# diamond : diamond
# ml : ml
# ajg : ajg
# digunakanmengecewakansudah : digunakanmengecewakansudah
# pendidikan : didik
# serunya : seru
# menang : menang
# ikutan : ikut
# beruntungtapi : beruntungtapi
# overall : overall
# membobol : bobol
# bukalapaktapi : bukalapaktapi
# codtolong : codtolong
# merata : rata
# lapa : lapa
# mintak : mintak
# ampunsudah : ampunsudah
# chatting : chatting
# berbisnis : bisnis
# diadakan : ada
# dievaluasi : evaluasi
# amannyamanmemuaskanterpercayabarangbarang : amannyamanmemuaskanterpercayabarangbarang
# bismillah : bismillah
# pembohong : bohong
# cicil : cicil
# mrmbantu : mrmbantu
# lamaaaa : lamaaaa
# terlama : lama
# depanya : depa
# administrasi : administrasi
# gerai : gerai
# tiadakan : tiada
# brengsek : brengsek
# nungu : nungu
# kebutuhn : kebutuhn
# mendesak : desak
# layak : layak
# daan : daan
# vrepikasi : vrepikasi
# pengaturan : atur
# you : you
# tube : tube
# bklapak : bklapak
# pengunagua : pengunagua
# pastiagar : pastiagar
# tidal : tidal
# paking : paking
# mulus : mulus
# tren : tren
# ankun : ankun
# sensor : sensor
# nge : nge
# kerjaannya : kerja
# memudah : mudah
# jos : jos
# gandos : gandos
# mafianya : mafia
# sayakarna : sayakarna
# membutuhkan : butuh
# tersebuttolong : tersebuttolong
# mengharap : harap
# penilaian : nilai
# kezl : kezl
# mudahdan : mudahdan
# bukatabungan : bukatabungan
# semestinya : mesti
# {'menu': 'menu', 'apps': 'apps', 'contohnya': 'contoh', 'history': 'history', 'pengiriman': 'kirim', 'nomor': 'nomor', 'resi': 'resi', 'daftar': 'daftar', 'transakski': 'transakski', 'cuman': 'cuman', 'status': 'status', 'pembelian': 'beli', 'diproses': 'proses', 'dikirim': 'kirim', 'selesai': 'selesai', 'akses': 'akses', 'website': 'website', 'tolong': 'tolong', 'lengkapi': 'lengkap', 'menyalahkan': 'salah', 'penjual': 'jual', 'proses': 'proses', 'apknya': 'apknya', 'bagus': 'bagus', 'sih': 'sih', 'pesanan': 'pesan', 'masuk': 'masuk', 'orderan': 'order', 'notifikasinya': 'notifikasi', 'terkadang': 'terkadang', 'muncul': 'muncul', 'telat': 'telat', 'konfirmasi': 'konfirmasi', 'diomelin': 'diomelin', 'pelanggan': 'langgan', 'dibatalkan': 'batal', 'diperbaiki': 'baik', 'biar': 'biar', 'nyaman': 'nyaman', 'pakai': 'pakai', 'apk': 'apk', 'bl': 'bl', 'terima': 'terima', 'kasih': 'kasih', 'belanja': 'belanja', 'ribet': 'ribet', 'bukalapak': 'bukalapak', 'dana': 'dana', 'hatihati': 'hatihati', 'kemarin': 'kemarin', 'isi': 'isi', 'token': 'token', 'listrik': 'listrik', 'saldo': 'saldo', 'ribu': 'ribu', 'bayar': 'bayar', 'verifikasi': 'verifikasi', 'sms': 'sms', 'wa': 'wa', 'celakanya': 'celaka', 'seluler': 'seluler', 'hilang': 'hilang', 'daftarkan': 'daftar', 'ganti': 'ganti', 'akun': 'akun', 'bingung': 'bingung', 'shopee': 'shopee', 'shopeepay': 'shopeepay', 'tinggal': 'tinggal', 'masukkan': 'masuk', 'nopin': 'nopin', 'pelayanan': 'layan', 'mengecewakan': 'kecewa', 'mengasih': 'asih', 'masukan': 'masuk', 'nih': 'nih', 'tim': 'tim', 'cari': 'cari', 'barang': 'barang', 'lengkapkarna': 'lengkapkarna', 'sebelah': 'belah', 'berisial': 'berisial', 'disana': 'sana', 'jual': 'jual', 'semoga': 'moga', 'nya': 'nya', 'lengkap': 'lengkap', 'konsumen': 'konsumen', 'beralih': 'alih', 'temukan': 'temu', 'kecewa': 'kecewa', 'pembayaran': 'bayar', 'payleter': 'payleter', 'biaya': 'biaya', 'layanan': 'layan', 'tampilkan': 'tampil', 'diawal': 'awal', 'nominalnya': 'nominal', 'cek': 'cek', 'tagihan': 'tagih', 'bengkak': 'bengkak', 'sesuai': 'sesuai', 'ditampilkan': 'tampil', 'mohon': 'mohon', 'dipertimbangkan': 'timbang', 'berkembang': 'kembang', 'aplikasi': 'aplikasi', 'maju': 'maju', 'fikturnya': 'fikturnya', 'rumit': 'rumit', 'nomer': 'nomer', 'imail': 'imail', 'persulit': 'sulit', 'beda': 'beda', 'banget': 'banget', 'tetangga': 'tetangga', 'mudah': 'mudah', 'aman': 'aman', 'kayak': 'kayak', 'kabur': 'kabur', 'pilihan': 'pilih', 'keranjang': 'keranjang', 'pengikut': 'ikut', 'user': 'user', 'bangga': 'bangga', 'mngenalkan': 'mngenalkan', 'mepromosikan': 'mepromosikan', 'programnya': 'program', 'didaerah': 'daerah', 'terhitung': 'hitung', 'wajah': 'wajah', 'kesombongan': 'sombong', 'fasilitas': 'fasilitas', 'paylaterbayar': 'paylaterbayar', 'dibekukan': 'beku', 'program': 'program', 'umkm': 'umkm', 'mati': 'mati', 'an': 'an', 'membuatmu': 'buat', 'dikenal': 'kenal', 'orang': 'orang', 'update': 'update', 'appnya': 'appnya', 'loading': 'loading', 'blank': 'blank', 'coba': 'coba', 'data': 'data', 'wifi': 'wifi', 'pikir': 'pikir', 'koneksi': 'koneksi', 'internet': 'internet', 'fix': 'fix', 'system': 'system', 'tanggal': 'tanggal', 'limit': 'limit', 'paylater': 'paylater', 'rp': 'rp', 'bayarkan': 'bayar', 'terverifikasi': 'verifikasi', 'struk': 'struk', 'indomaret': 'indomaret', 'berhasil': 'hasil', 'dibsystem': 'dibsystem', 'terbayar': 'bayar', 'kenakan': 'kena', 'denda': 'denda', 'meng': 'meng', 'hubungi': 'hubung', 'cs': 'cs', 'mengembalikan': 'kembali', 'uang': 'uang', 'memakai': 'pakai', 'kali': 'kali', 'sisa': 'sisa', 'saldonya': 'saldo', 'pulsa': 'pulsa', 'mengadakan': 'ada', 'option': 'option', 'bantuan': 'bantu', 'via': 'via', 'live': 'live', 'chat': 'chat', 'prosedurnya': 'prosedur', 'search': 'search', 'enginenya': 'enginenya', 'ditemukan': 'temu', 'browserpun': 'browser', 'nihil': 'nihil', 'hasil': 'hasil', 'pencariannya': 'cari', 'ketemunya': 'ketemu', 'rekomendasi': 'rekomendasi', 'untukmu': 'untuk', 'terimakasih': 'terimakasih', 'transaksi':  ...
# ------------------------
# Pandas Apply:   0%|          | 0/1001 [00:00<?, ?it/s]

# %%
name_dataframe
# Out:
#           Nama pengguna  Rating                Date  \
# 0      ReGodam ReloadME       2 2022-08-04 05:10:30
# 1     Rahman F Official       3 2022-10-15 03:40:36
# 2             FilNoz CH       1 2022-08-15 16:53:45
# 3               ahmad y       5 2022-09-22 10:36:22
# 4       Denny Pramudita       1 2022-08-29 12:49:06
# ...                 ...     ...                 ...
# 996      Rahman Saputra       1 2022-08-03 19:22:57
# 997            nabil 85       5 2022-08-14 06:00:43
# 998         Narto Toaja       5 2022-09-24 08:34:13
# 999     Pengguna Google       5 2022-09-11 12:56:54
# 1000              Husni       1 2022-08-06 04:56:57
#
#                                                  Ulasan  \
# 0     menu dalam apps lebih sedikit contohnya tidak ...
# 1     apknya bagus sih cuma kalau ada pesanan masuk ...
# 2     mau belanja ribet di bukalapak harus melalui d...
# 3     dari pelayanan sih ga pernah mengecewakan tapi...
# 4     sangat kecewa sekali pembayaran dengan paylete...
# ...                                                 ...
# 996   tolong kembalikan seperti semula akun sayakarn...
# 997   selalu belanja di tempat ini sejak dulu kalau ...
# 998   belanja makin mudahdan bisa cari barang yg di ...
# 999            belanja mudah pelayanan cepat harga baik
# 1000  kita mau komplen saja sangat kesulitan mau men...
#
#                                         Ulasan_tokenize  \
# 0     [menu, dalam, apps, lebih, sedikit, contohnya,...
# 1     [apknya, bagus, sih, cuma, kalau, ada, pesanan...
# 2     [mau, belanja, ribet, di, bukalapak, harus, me...
# 3     [dari, pelayanan, sih, ga, pernah, mengecewaka...
# 4     [sangat, kecewa, sekali, pembayaran, dengan, p...
# ...                                                 ...
# 996   [tolong, kembalikan, seperti, semula, akun, sa...
# 997   [selalu, belanja, di, tempat, ini, sejak, dulu...
# 998   [belanja, makin, mudahdan, bisa, cari, barang,...
# 999     [belanja, mudah, pelayanan, cepat, harga, baik]
# 1000  [kita, mau, komplen, saja, sangat, kesulitan, ...
#
#                                       Ulasan_normalized  \
# 0     [menu, dalam, apps, lebih, sedikit, contohnya,...
# 1     [apknya, bagus, sih, cuma, kalau, ada, pesanan...
# 2     [mau, belanja, ribet, di, bukalapak, harus, me...
# 3     [dari, pelayanan, sih, enggak, pernah, mengece...
# 4     [sangat, kecewa, sekali, pembayaran, dengan, p...
# ...                                                 ...
# 996   [tolong, kembalikan, seperti, semula, akun, sa...
# 997   [selalu, belanja, di, tempat, ini, sejak, dulu...
# 998   [belanja, makin, mudahdan, bisa, cari, barang,...
# 999     [belanja, mudah, pelayanan, cepat, harga, baik]
# 1000  [kita, mau, komplen, saja, sangat, kesulitan, ...
#
#                                     Ulasan_stop_removed  \
# 0     [menu, apps, contohnya, menu, history, pengiri...
# 1     [apknya, bagus, sih, pesanan, masuk, orderan, ...
# 2     [belanja, ribet, bukalapak, dana, hatihati, be...
# 3     [pelayanan, sih, mengecewakan, mengasih, masuk...
# 4     [kecewa, pembayaran, payleter, biaya, layanan,...
# ...                                                 ...
# 996   [tolong, kembalikan, akun, sayakarna, membutuh...
# 997   [belanja, dikasih, bintang, bagus, mengharap, ...
# 998                   [belanja, mudahdan, cari, barang]
# 999           [belanja, mudah, pelayanan, cepat, harga]
# 1000  [komplen, kesulitan, menghubungi, cs, cs, buka...
#
#                                          Ulasan_Stemmed
# 0     [menu, apps, contoh, menu, history, kirim, nom...
# 1     [apknya, bagus, sih, pesan, masuk, order, noti...
# 2     [belanja, ribet, bukalapak, dana, hatihati, be...
# 3     [layan, sih, kecewa, asih, masuk, nih, tim, bl...
# 4     [kecewa, bayar, payleter, biaya, layan, tampil...
# ...                                                 ...
# 996   [tolong, kembali, akun, sayakarna, butuh, sald...
# 997   [belanja, kasih, bintang, bagus, harap, bintan...
# 998                   [belanja, mudahdan, cari, barang]
# 999               [belanja, mudah, layan, cepat, harga]
# 1000  [komplen, sulit, hubung, cs, cs, bukatabungan,...
#
# [1001 rows x 8 columns]

# %%
name_dataframe["Ulasan_clean"] = [' '.join(map(str, l)) for l in name_dataframe['Ulasan_Stemmed']]

# %%
name_dataframe.to_excel("tokped_text.xlsx")
