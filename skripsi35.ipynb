# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafiryd/Rafiryd/blob/rafiryd/skripsi35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Proses Pengambilan data**

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

import seaborn as sns

# %%
#Scrape desired number of reviews
#Run kode ini jika ingin scrape data dengan jumlah tertentu. Ganti (misal, ingin scrape sejumlah 1000, maka ganti kode , count = 1000 )

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.bukalapak.android',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=1300, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %% [markdown]
# Problems slovlig tools = mencari akar permasalahan pada suatu masalah
#
# 5 why
#
# metode mencari problems sloving dengan cara menanyakan apa penyebab permasalahaan muncul dan mencari jawabannya. hal ini di lakUkan berkali klai sampai permasalahan dapat tergambar dengan jelas
#
# action priority
#
# diagram yang dapat di gunakan untuk mencari prioritas masalah berdasarkan impact atas benefit yang bisa diberikan dengan diagram ini kita memilih masalah yang impactnya mayoritas dari permasalahan yang ada.
#
# fishbone digram
#
# digram yang dapat di gunakan untuk merinci masalah dan membantu mencari akar masalah yang dapat dilihat dari beberapa point of view
#
# flowchart/algo
#
# metode pemecahan masalah dengan cara memetakan flow atau membuat pseudo algoritma yang untuk menentukan masalah dan cara untuk mencari solusinya secara sistematis

# %% [markdown]
# # **Data diproleh**

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId                 userName  \
# 0  8a1e53b2-0cca-49aa-9bc0-5084836892d1                  yOga 04
# 1  ee89c8f1-7d27-45f3-8720-539a0965d0dc  Imagination Music Store
# 2  09caeb61-3922-48d4-8df0-b93ebf9d7e6a        Mas bagoess Kocak
# 3  18b4a740-9d95-4b62-a36f-9c718fd7dcbf                 Sis Maya
# 4  bb9513b0-9127-46da-9d3f-d9ddafeb807c                   Gb Jkt
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# 1  https://play-lh.googleusercontent.com/a-/AD_cM...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a/AAcHTt...
# 4  https://play-lh.googleusercontent.com/a/AAcHTt...
#
#                                              content  score  thumbsUpCount  \
# 0  Aplikasi marketplace paling ancur.. Sistem buk...      1             12
# 1  Aplikasi yg sangat ribet. Tiap mau edit produk...      1             22
# 2  Buka bantuan Bukalapak tidak berguna karena ti...      1             26
# 3  Saya sangat sedih sekali belanja lewat mitra B...      1             52
# 4  Makin lama makin mengerikan belanja di bukalap...      1              1
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0               5.34.3 2023-08-01 03:19:16         None       NaT     5.34.3
# 1               5.34.3 2023-07-28 08:32:00         None       NaT     5.34.3
# 2               5.34.3 2023-07-27 22:26:26         None       NaT     5.34.3
# 3               5.34.2 2023-07-22 10:54:24         None       NaT     5.34.2
# 4               5.34.3 2023-08-01 03:57:42         None       NaT     5.34.3

# %%
len(df_busu.index) #count the number of data we got
# Out:
# 1300

# %%
df_busu[['userName', 'score','at', 'content']].tail()  #preview userName, rating, date-time, and reviews only
# Out:
#             userName  score                  at  \
# 1295  aditya anugrah      1 2020-12-28 13:01:51
# 1296    ary surjamin      5 2023-04-26 05:28:37
# 1297          yunita      2 2020-10-02 17:55:26
# 1298     Xiaomi Mi03      5 2020-08-22 06:35:44
# 1299         Go Cell      3 2021-11-30 04:36:34
#
#                                                 content
# 1295  Aplikasi buruk....!!! Selalu ngRestart sendiri...
# 1296  Barang sesuai yg dilesan, cepat respon dan dik...
# 1297  Saya melakukan pembayaran untuk pemesanan sebu...
# 1298  Aplikasinya membantu bangat bisa belanja jarak...
# 1299  Setelah diupdate bukannya jadi bagus. Malah ja...

# %% [markdown]
# # **Perubahan Penamaan Pada Setiap Kolom**

# %%
name_dataframe = df_busu.loc[:,["userName", "score", "at", "content"]]
name_dataframe.rename(columns={"userName": "Nama pengguna", "score":"Rating", "at": "Date", "content": "Ulasan"}, inplace=True)

# %%
name_dataframe.tail()
# Out:
#        Nama pengguna  Rating                Date  \
# 1295  aditya anugrah       1 2020-12-28 13:01:51
# 1296    ary surjamin       5 2023-04-26 05:28:37
# 1297          yunita       2 2020-10-02 17:55:26
# 1298     Xiaomi Mi03       5 2020-08-22 06:35:44
# 1299         Go Cell       3 2021-11-30 04:36:34
#
#                                                  Ulasan
# 1295  Aplikasi buruk....!!! Selalu ngRestart sendiri...
# 1296  Barang sesuai yg dilesan, cepat respon dan dik...
# 1297  Saya melakukan pembayaran untuk pemesanan sebu...
# 1298  Aplikasinya membantu bangat bisa belanja jarak...
# 1299  Setelah diupdate bukannya jadi bagus. Malah ja...

# %%
name_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nama pengguna  1300 non-null   object
#  1   Rating         1300 non-null   int64
#  2   Date           1300 non-null   datetime64[ns]
#  3   Ulasan         1300 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 40.8+ KB

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].astype(str)
name_dataframe.head()
# Out:
#              Nama pengguna  Rating                Date  \
# 0                  yOga 04       1 2023-08-01 03:19:16
# 1  Imagination Music Store       1 2023-07-28 08:32:00
# 2        Mas bagoess Kocak       1 2023-07-27 22:26:26
# 3                 Sis Maya       1 2023-07-22 10:54:24
# 4                   Gb Jkt       1 2023-08-01 03:57:42
#
#                                               Ulasan
# 0  Aplikasi marketplace paling ancur.. Sistem buk...
# 1  Aplikasi yg sangat ribet. Tiap mau edit produk...
# 2  Buka bantuan Bukalapak tidak berguna karena ti...
# 3  Saya sangat sedih sekali belanja lewat mitra B...
# 4  Makin lama makin mengerikan belanja di bukalap...

# %% [markdown]
# # **Case folding**

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].str.lower()

# %% [markdown]
# # **cleansing**

# %%
import string
import re
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

def remove_links(text):
    # menghapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus URL
    return text.replace("http://", " ").replace("https://", " ")

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_links)

# %%
#menghapus number
def remove_number(text):
    return  re.sub(r"\d+", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_number)

# %%
#menghapus punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_punctuation)

# %%
# menghapus single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_singl_char)

# %% [markdown]
# # **Tokenizing**

# %%
# Tokenisasi
def word_tokenize_wrapper(text):
    return word_tokenize(text)

name_dataframe['Ulasan_tokenize'] = name_dataframe['Ulasan'].apply(word_tokenize_wrapper)

# %%
name_dataframe
# Out:
#                 Nama pengguna  Rating                Date  \
# 0                     yOga 04       1 2023-08-01 03:19:16
# 1     Imagination Music Store       1 2023-07-28 08:32:00
# 2           Mas bagoess Kocak       1 2023-07-27 22:26:26
# 3                    Sis Maya       1 2023-07-22 10:54:24
# 4                      Gb Jkt       1 2023-08-01 03:57:42
# ...                       ...     ...                 ...
# 1295           aditya anugrah       1 2020-12-28 13:01:51
# 1296             ary surjamin       5 2023-04-26 05:28:37
# 1297                   yunita       2 2020-10-02 17:55:26
# 1298              Xiaomi Mi03       5 2020-08-22 06:35:44
# 1299                  Go Cell       3 2021-11-30 04:36:34
#
#                                                  Ulasan  \
# 0     aplikasi marketplace paling ancur sistem bukab...
# 1     aplikasi yg sangat ribet tiap mau edit produk ...
# 2     buka bantuan bukalapak tidak berguna karena ti...
# 3     saya sangat sedih sekali belanja lewat mitra b...
# 4     makin lama makin mengerikan belanja di bukalap...
# ...                                                 ...
# 1295  aplikasi buruk selalu ngrestart sendiri klo lg...
# 1296  barang sesuai yg dilesan cepat respon dan diki...
# 1297  saya melakukan pembayaran untuk pemesanan sebu...
# 1298  aplikasinya membantu bangat bisa belanja jarak...
# 1299  setelah diupdate bukannya jadi bagus malah jad...
#
#                                         Ulasan_tokenize
# 0     [aplikasi, marketplace, paling, ancur, sistem,...
# 1     [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2     [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3     [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4     [makin, lama, makin, mengerikan, belanja, di, ...
# ...                                                 ...
# 1295  [aplikasi, buruk, selalu, ngrestart, sendiri, ...
# 1296  [barang, sesuai, yg, dilesan, cepat, respon, d...
# 1297  [saya, melakukan, pembayaran, untuk, pemesanan...
# 1298  [aplikasinya, membantu, bangat, bisa, belanja,...
# 1299  [setelah, diupdate, bukannya, jadi, bagus, mal...
#
# [1300 rows x 5 columns]

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize'], dtype='object')

# %%
#Run This Code to Sort the Data By Date
# tanggal 26-04-2022 sampai 12-10-2022

new_df = name_dataframe[['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize']]
sorted_df = new_df.sort_values(by='Date', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#        Nama pengguna  Rating                Date  \
# 616    Zainal Fanani       1 2023-08-05 07:36:37
# 782     alvin chanel       1 2023-08-03 11:55:23
# 776        Fitri Ani       5 2023-08-03 11:31:13
# 191   M Hananto Ardi       5 2023-08-03 09:23:37
# 1168        Heal_ Me       1 2023-08-03 08:35:57
#
#                                                  Ulasan  \
# 616   halaman komplain eror pelayananx makin jelek s...
# 782   bukalapakgk bisa batalin pesananbutuh bantuan ...
# 776         sangat bisa memuaskan dan bermanfaat sekali
# 191   bagus lancar pada saat belanja seperti yang di...
# 1168  lestari motor jakbar salah cara mengemas baran...
#
#                                         Ulasan_tokenize
# 616   [halaman, komplain, eror, pelayananx, makin, j...
# 782   [bukalapakgk, bisa, batalin, pesananbutuh, ban...
# 776   [sangat, bisa, memuaskan, dan, bermanfaat, sek...
# 191   [bagus, lancar, pada, saat, belanja, seperti, ...
# 1168  [lestari, motor, jakbar, salah, cara, mengemas...

# %%
sorted_df.dtypes
# Out:
# Nama pengguna              object
# Rating                      int64
# Date               datetime64[ns]
# Ulasan                     object
# Ulasan_tokenize            object
# dtype: object

# %%
import pandas as pd

# Assuming you have a DataFrame named ulasan with columns 'Ulasan_tokenize' and 'Ulasan_ears'

word_to_erase = 'nya'  # Replace 'word' with the word you want to erase

name_dataframe["ulasan_ears"] = name_dataframe['Ulasan_tokenize'].apply(lambda x: [word for word in x if word != word_to_erase])

print(name_dataframe)
# Out:
#                 Nama pengguna  Rating                Date  \
# 0                     yOga 04       1 2023-08-01 03:19:16
# 1     Imagination Music Store       1 2023-07-28 08:32:00
# 2           Mas bagoess Kocak       1 2023-07-27 22:26:26
# 3                    Sis Maya       1 2023-07-22 10:54:24
# 4                      Gb Jkt       1 2023-08-01 03:57:42
# ...                       ...     ...                 ...
# 1295           aditya anugrah       1 2020-12-28 13:01:51
# 1296             ary surjamin       5 2023-04-26 05:28:37
# 1297                   yunita       2 2020-10-02 17:55:26
# 1298              Xiaomi Mi03       5 2020-08-22 06:35:44
# 1299                  Go Cell       3 2021-11-30 04:36:34
#
#                                                  Ulasan  \
# 0     aplikasi marketplace paling ancur sistem bukab...
# 1     aplikasi yg sangat ribet tiap mau edit produk ...
# 2     buka bantuan bukalapak tidak berguna karena ti...
# 3     saya sangat sedih sekali belanja lewat mitra b...
# 4     makin lama makin mengerikan belanja di bukalap...
# ...                                                 ...
# 1295  aplikasi buruk selalu ngrestart sendiri klo lg...
# 1296  barang sesuai yg dilesan cepat respon dan diki...
# 1297  saya melakukan pembayaran untuk pemesanan sebu...
# 1298  aplikasinya membantu bangat bisa belanja jarak...
# 1299  setelah diupdate bukannya jadi bagus malah jad...
#
#                                         Ulasan_tokenize  \
# 0     [aplikasi, marketplace, paling, ancur, sistem,...
# 1     [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2     [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3     [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4     [makin, lama, makin, mengerikan, belanja, di, ...
# ...                                                 ...
# 1295  [aplikasi, buruk, selalu, ngrestart, sendiri, ...
# 1296  [barang, sesuai, yg, dilesan, cepat, respon, d...
# 1297  [saya, melakukan, pembayaran, untuk, pemesanan...
# 1298  [aplikasinya, membantu, bangat, bisa, belanja,...
# 1299  [setelah, diupdate, bukannya, jadi, bagus, mal...
#
#                                             ulasan_ears
# 0     [aplikasi, marketplace, paling, ancur, sistem,...
# 1     [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2     [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3     [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4     [makin, lama, makin, mengerikan, belanja, di, ...
# ...                                                 ...
# 1295  [aplikasi, buruk, selalu, ngrestart, sendiri, ...
# 1296  [barang, sesuai, yg, dilesan, cepat, respon, d...
# 1297  [saya, melakukan, pembayaran, untuk, pemesanan...
# 1298  [aplikasinya, membantu, bangat, bisa, belanja,...
# 1299  [setelah, diupdate, bukannya, jadi, bagus, mal...
#
# [1300 rows x 6 columns]

# %%
name_dataframe.head()
# Out:
#              Nama pengguna  Rating                Date  \
# 0                  yOga 04       1 2023-08-01 03:19:16
# 1  Imagination Music Store       1 2023-07-28 08:32:00
# 2        Mas bagoess Kocak       1 2023-07-27 22:26:26
# 3                 Sis Maya       1 2023-07-22 10:54:24
# 4                   Gb Jkt       1 2023-08-01 03:57:42
#
#                                               Ulasan  \
# 0  aplikasi marketplace paling ancur sistem bukab...
# 1  aplikasi yg sangat ribet tiap mau edit produk ...
# 2  buka bantuan bukalapak tidak berguna karena ti...
# 3  saya sangat sedih sekali belanja lewat mitra b...
# 4  makin lama makin mengerikan belanja di bukalap...
#
#                                      Ulasan_tokenize  \
# 0  [aplikasi, marketplace, paling, ancur, sistem,...
# 1  [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2  [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3  [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4  [makin, lama, makin, mengerikan, belanja, di, ...
#
#                                          ulasan_ears
# 0  [aplikasi, marketplace, paling, ancur, sistem,...
# 1  [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2  [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3  [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4  [makin, lama, makin, mengerikan, belanja, di, ...

# %%
# Menghitung Distibusi Persebaran Kata
def freqDist_wrapper(text):
    return FreqDist(text)

Ulasan_fqsist = name_dataframe['ulasan_ears'].apply(freqDist_wrapper)

print('Frequency Tokens : \n')
print(Ulasan_fqsist.head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(masalah, 3), (sistem, 2), (ngga, 2), (aplika...
# 1    [(aplikasi, 2), (yg, 2), (produk, 2), (sangat,...
# 2    [(tidak, 3), (buka, 2), (bantuan, 2), (bukalap...
# 3    [(saya, 3), (tidak, 3), (bisa, 2), (di, 2), (t...
# 4    [(akun, 4), (belanja, 3), (di, 3), (makin, 2),...
# Name: ulasan_ears, dtype: object

# %%
print(name_dataframe.columns)
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize',
#        'ulasan_ears'],
#       dtype='object')

# %%
name_dataframe['Ulasan_tokenize'].unique
# Out:
# <bound method Series.unique of 0       [aplikasi, marketplace, paling, ancur, sistem,...
# 1       [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2       [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3       [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4       [makin, lama, makin, mengerikan, belanja, di, ...
#                               ...
# 1295    [aplikasi, buruk, selalu, ngrestart, sendiri, ...
# 1296    [barang, sesuai, yg, dilesan, cepat, respon, d...
# 1297    [saya, melakukan, pembayaran, untuk, pemesanan...
# 1298    [aplikasinya, membantu, bangat, bisa, belanja,...
# 1299    [setelah, diupdate, bukannya, jadi, bagus, mal...
# Name: Ulasan_tokenize, Length: 1300, dtype: object>

# %%
slank_word_dict = {
    "berjalansudah" : "berjalan",
    "paraah" : "parah",
    "keduakali" : "",
    "keduakali" : "kedua kali",
    "agak" : "sedikit",
    "pas" : "saat",
    "produkx" : "produknya",
    "sukamkasih" : "suka makasih",
    "gak" : "tidak",
    "cpt" : "cepat",
    "sdh" : "sudah",
    "recommend" : "rekomendasi",
    "bagusseller" : "bagus",
    "bagusssss" : "bagus",
    "bagussssss" : "bagus",
    "baguuussss" : "bagus",
    "cepatmakasih": "cepat",
    "cepatmantappp": "cepat",
    "cepatproduct": "cepat",
    "cepatrecomended": "cepat",
    "cepattoko": "cepat",
    "recomended": "rekomendasi",
    "recommended": "rekomendasi",
    "rekomendasi": "rekomendasi",
    "rekomended": "rekomendasi",
    }

def slank_normalized_term(document):
    return [slank_word_dict[term] if term in slank_word_dict else term for term in document]

# %% [markdown]
# # **Normalization**

# %%
normalizad_word = pd.read_csv("/content/kamusindonesia.csv.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1]

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

# %%
name_dataframe['Ulasan_normalized'] = name_dataframe['Ulasan_tokenize'].apply(normalized_term).apply(slank_normalized_term)

# %%
name_dataframe.head(100)
# Out:
#               Nama pengguna  Rating                Date  \
# 0                   yOga 04       1 2023-08-01 03:19:16
# 1   Imagination Music Store       1 2023-07-28 08:32:00
# 2         Mas bagoess Kocak       1 2023-07-27 22:26:26
# 3                  Sis Maya       1 2023-07-22 10:54:24
# 4                    Gb Jkt       1 2023-08-01 03:57:42
# ..                      ...     ...                 ...
# 95   Nurjanah Mega Putri AR       1 2023-06-21 08:18:23
# 96                  Sdi Sjy       2 2023-07-03 01:40:45
# 97               c_nursheto       1 2023-07-01 09:07:53
# 98            Candra Maliki       1 2023-06-18 22:43:11
# 99     I Gede Mas Mahardika       2 2023-07-07 06:10:59
#
#                                                Ulasan  \
# 0   aplikasi marketplace paling ancur sistem bukab...
# 1   aplikasi yg sangat ribet tiap mau edit produk ...
# 2   buka bantuan bukalapak tidak berguna karena ti...
# 3   saya sangat sedih sekali belanja lewat mitra b...
# 4   makin lama makin mengerikan belanja di bukalap...
# ..                                                ...
# 95  saya udah nungguin seharian paket dijemput buk...
# 96  barangbarang yg dijual sih oke cuma sayang vou...
# 97  mau komplain dipersulit beli produk digital st...
# 98  tolong di perbaiki lagi banyak penipu berkedok...
# 99  belanjanya gampang bayarnya ribet dan jika ada...
#
#                                       Ulasan_tokenize  \
# 0   [aplikasi, marketplace, paling, ancur, sistem,...
# 1   [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2   [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3   [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4   [makin, lama, makin, mengerikan, belanja, di, ...
# ..                                                ...
# 95  [saya, udah, nungguin, seharian, paket, dijemp...
# 96  [barangbarang, yg, dijual, sih, oke, cuma, say...
# 97  [mau, komplain, dipersulit, beli, produk, digi...
# 98  [tolong, di, perbaiki, lagi, banyak, penipu, b...
# 99  [belanjanya, gampang, bayarnya, ribet, dan, ji...
#
#                                           ulasan_ears  \
# 0   [aplikasi, marketplace, paling, ancur, sistem,...
# 1   [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2   [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3   [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4   [makin, lama, makin, mengerikan, belanja, di, ...
# ..                                                ...
# 95  [saya, udah, nungguin, seharian, paket, dijemp...
# 96  [barangbarang, yg, dijual, sih, oke, cuma, say...
# 97  [mau, komplain, dipersulit, beli, produk, digi...
# 98  [tolong, di, perbaiki, lagi, banyak, penipu, b...
# 99  [belanjanya, gampang, bayarnya, ribet, dan, ji...
#
#                                     Ulasan_normalized
# 0   [aplikasi, marketplace, paling, hancur, sistem...
# 1   [aplikasi, yang, sangat, ribet, tiap, mau, edi...
# 2   [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3   [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4   [makin, lama, makin, mengerikan, belanja, di, ...
# ..                                                ...
# 95  [saya, sudah, menunggu, seharian, paket, dijem...
# 96  [barangbarang, yang, dijual, sih, oke, cuma, s...
# 97  [mau, komplain, dipersulit, beli, produk, digi...
# 98  [tolong, di, perbaiki, lagi, banyak, penipu, b...
# 99  [belanjanya, gampang, bayarnya, ribet, dan, ji...
#
# [100 rows x 7 columns]

# %%
name_dataframe['Ulasan_normalized'].unique
# Out:
# <bound method Series.unique of 0       [aplikasi, marketplace, paling, hancur, sistem...
# 1       [aplikasi, yang, sangat, ribet, tiap, mau, edi...
# 2       [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3       [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4       [makin, lama, makin, mengerikan, belanja, di, ...
#                               ...
# 1295    [aplikasi, buruk, selalu, ngrestart, sendiri, ...
# 1296    [barang, sesuai, yang, dilesan, cepat, respon,...
# 1297    [saya, melakukan, pembayaran, untuk, pemesanan...
# 1298    [aplikasinya, membantu, banget, bisa, belanja,...
# 1299    [setelah, diupdate, bukannya, jadi, bagus, mal...
# Name: Ulasan_normalized, Length: 1300, dtype: object>

# %% [markdown]
# # **Stop Removal**

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

name_dataframe['Ulasan_stop_removed'] = name_dataframe['Ulasan_normalized'].apply(stopwords_removal)

# %%
name_dataframe
# Out:
#                 Nama pengguna  Rating                Date  \
# 0                     yOga 04       1 2023-08-01 03:19:16
# 1     Imagination Music Store       1 2023-07-28 08:32:00
# 2           Mas bagoess Kocak       1 2023-07-27 22:26:26
# 3                    Sis Maya       1 2023-07-22 10:54:24
# 4                      Gb Jkt       1 2023-08-01 03:57:42
# ...                       ...     ...                 ...
# 1295           aditya anugrah       1 2020-12-28 13:01:51
# 1296             ary surjamin       5 2023-04-26 05:28:37
# 1297                   yunita       2 2020-10-02 17:55:26
# 1298              Xiaomi Mi03       5 2020-08-22 06:35:44
# 1299                  Go Cell       3 2021-11-30 04:36:34
#
#                                                  Ulasan  \
# 0     aplikasi marketplace paling ancur sistem bukab...
# 1     aplikasi yg sangat ribet tiap mau edit produk ...
# 2     buka bantuan bukalapak tidak berguna karena ti...
# 3     saya sangat sedih sekali belanja lewat mitra b...
# 4     makin lama makin mengerikan belanja di bukalap...
# ...                                                 ...
# 1295  aplikasi buruk selalu ngrestart sendiri klo lg...
# 1296  barang sesuai yg dilesan cepat respon dan diki...
# 1297  saya melakukan pembayaran untuk pemesanan sebu...
# 1298  aplikasinya membantu bangat bisa belanja jarak...
# 1299  setelah diupdate bukannya jadi bagus malah jad...
#
#                                         Ulasan_tokenize  \
# 0     [aplikasi, marketplace, paling, ancur, sistem,...
# 1     [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2     [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3     [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4     [makin, lama, makin, mengerikan, belanja, di, ...
# ...                                                 ...
# 1295  [aplikasi, buruk, selalu, ngrestart, sendiri, ...
# 1296  [barang, sesuai, yg, dilesan, cepat, respon, d...
# 1297  [saya, melakukan, pembayaran, untuk, pemesanan...
# 1298  [aplikasinya, membantu, bangat, bisa, belanja,...
# 1299  [setelah, diupdate, bukannya, jadi, bagus, mal...
#
#                                             ulasan_ears  \
# 0     [aplikasi, marketplace, paling, ancur, sistem,...
# 1     [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2     [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3     [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4     [makin, lama, makin, mengerikan, belanja, di, ...
# ...                                                 ...
# 1295  [aplikasi, buruk, selalu, ngrestart, sendiri, ...
# 1296  [barang, sesuai, yg, dilesan, cepat, respon, d...
# 1297  [saya, melakukan, pembayaran, untuk, pemesanan...
# 1298  [aplikasinya, membantu, bangat, bisa, belanja,...
# 1299  [setelah, diupdate, bukannya, jadi, bagus, mal...
#
#                                       Ulasan_normalized  \
# 0     [aplikasi, marketplace, paling, hancur, sistem...
# 1     [aplikasi, yang, sangat, ribet, tiap, mau, edi...
# 2     [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3     [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4     [makin, lama, makin, mengerikan, belanja, di, ...
# ...                                                 ...
# 1295  [aplikasi, buruk, selalu, ngrestart, sendiri, ...
# 1296  [barang, sesuai, yang, dilesan, cepat, respon,...
# 1297  [saya, melakukan, pembayaran, untuk, pemesanan...
# 1298  [aplikasinya, membantu, banget, bisa, belanja,...
# 1299  [setelah, diupdate, bukannya, jadi, bagus, mal...
#
#                                     Ulasan_stop_removed
# 0     [aplikasi, marketplace, hancur, sistem, bukaba...
# 1     [aplikasi, ribet, edit, produk, giliran, berha...
# 2     [buka, bantuan, bukalapak, berguna, dihubungi,...
# 3     [sedih, belanja, mitra, bukalapak, live, bukab...
# 4     [mengerikan, belanja, bukalapak, pembeli, dian...
# ...                                                 ...
# 1295  [aplikasi, buruk, ngrestart, kalo, lanjutkan, ...
# 1296  [barang, sesuai, dilesan, cepat, respon, dikir...
# 1297  [pembayaran, pemesanan, buku, bukunya, kirim, ...
# 1298  [aplikasinya, membantu, banget, belanja, jarak...
# 1299  [diupdate, bagus, ngebug, berat, buffering, lo...
#
# [1300 rows x 8 columns]

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
pip install swifter
# Out:
# Collecting swifter
#   Downloading swifter-1.4.0.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (1.5.3)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.10/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2022.12.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (4.65.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (8.1.6)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2.2.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (23.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0.1)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2022.7.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->swifter) (1.16.0)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.4.0-py3-none-any.whl size=16510 sha256=30fdde1540eba2dbdb0dd8c30c66831bd8b604081a9490a9393c871cd54d2e5f
#   Stored in directory: /root/.cache/pip/wheels/e4/cf/51/0904952972ee2c7aa3709437065278dc534ec1b8d2ad41b443
# Successfully built swifter
# Installing collected packages: swifter
# Successfully installed swifter-1.4.0

# %% [markdown]
# # **Stemming**

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in name_dataframe['Ulasan_stop_removed']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '

print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])

print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

name_dataframe['Ulasan_Stemmed'] = name_dataframe['Ulasan_stop_removed'].swifter.apply(get_stemmed_term)
# Out:
# 4585
# ------------------------
# aplikasi : aplikasi
# marketplace : marketplace
# hancur : hancur
# sistem : sistem
# bukabantuan : bukabantuan
# selesain : selesain
# lari : lari
# live : live
# chatnya : chatnya
# paylaternya : paylaternya
# bobrok : bobrok
# silakan : sila
# dicoba : coba
# download : download
# tau : tau
# ribet : ribet
# edit : edit
# produk : produk
# giliran : gilir
# berhasil : hasil
# ujung : ujung
# nya : nya
# iklan : iklan
# dijual : jual
# hilang : hilang
# alias : alias
# otomatis : otomatis
# dihapus : hapus
# bukalapak : bukalapak
# tolong : tolong
# ditingkatkan : tingkat
# ulang : ulang
# sistemnya : sistem
# penjual : jual
# pembeli : beli
# meninggalkan : tinggal
# buka : buka
# bantuan : bantu
# berguna : guna
# dihubungi : hubung
# transaksi : transaksi
# penjualan : jual
# barang : barang
# dikirim : kirim
# kurir : kurir
# wahana : wahana
# resi : resi
# diupdate : diupdate
# batal : batal
# hubungi : hubung
# update : update
# dicek : cek
# manual : manual
# perjalanan : jalan
# sedih : sedih
# belanja : belanja
# mitra : mitra
# andalkan : andal
# batalkan : batal
# terima : terima
# pikir : pikir
# kalo : kalo
# pakai : pakai
# cod : cod
# mengerikan : keri
# diangap : diangap
# penjahat : jahat
# main : main
# bekukan : beku
# akun : akun
# orang : orang
# kredivo : kredivo
# dibekukan : beku
# akulaku : akulaku
# hati : hati
# sayang : sayang
# mending : mending
# toped : toped
# aman : aman
# nyaman : nyaman
# minim : minim
# jahat : jahat
# jual : jual
# beli : beli
# online : online
# kerenfitur : kerenfitur
# lengkap : lengkap
# metode : metode
# pembayaran : bayar
# komplit : komplit
# pesanan : pesan
# cepat : cepat
# kirimdan : kirimdan
# lapak : lapak
# jualan : jual
# mudahsemoga : mudahsemoga
# depannya : depan
# simpel : simpel
# memudahkan : mudah
# seller : seller
# pembeligood : pembeligood
# luck : luck
# kena : kena
# charge : charge
# rp : rp
# roda : roda
# keberuntungan : untung
# puter : puter
# item : item
# top : top
# up : up
# money : money
# pesan : pesan
# tiket : tiket
# kereta : kereta
# api : api
# membantusaat : membantusaat
# pulsatoken : pulsatoken
# listrik : listrik
# kebutuhan : butuh
# mengatasi : atas
# cepatsemua : cepatsemua
# teratasi : atas
# memuaskanmaju : memuaskanmaju
# inovatif : inovatif
# membantu : bantu
# bayar : bayar
# depantapi : depantapi
# biaya : biaya
# admin : admin
# ribu : ribu
# bulannya : bulan
# paylater : paylater
# pakaiklo : pakaiklo
# ilangin : ilangin
# yalimit : yalimit
# bos : bos
# rugikan : rugi
# dana : dana
# bayarkan : bayar
# via : via
# atm : atm
# bri : bri
# struk : struk
# saldo : saldo
# masuk : masuk
# berhenti : henti
# menunggu : tunggu
# memperaulitcall : memperaulitcall
# center : center
# terkesan : kes
# malas : malas
# menanggapi : tanggap
# keluhan : keluh
# pelanggansemua : pelanggansemua
# persyaratan : syarat
# dibpenuhichat : dibpenuhichat
# alihkanni : alihkanni
# bantuanmemalukan : bantuanmemalukan
# bermasalahga : bermasalahga
# pertqma : pertqma
# pertamani : taman
# kemari : kemari
# parahcall : parahcall
# centernya : centernya
# pelatihan : latih
# nihbuat : nihbuat
# pelanggan : langgan
# tuh : tuh
# apl : apl
# sngat : sngat
# customer : customer
# pengalaman : alam
# terbukti : bukti
# dibeli : beli
# sesuai : sesuai
# gambar : gambar
# video : video
# deskripsinya : deskripsi
# sukses : sukses
# indonesia : indonesia
# merugikan : rugi
# masak : masak
# barangnya : barang
# dibayar : bayar
# nunggunya : nunggunya
# dibatalkan : batal
# uang : uang
# dikembalikan : kembali
# rbuan : rbuan
# alasan : alas
# ongkir : ongkir
# jasa : jasa
# pengiriman : kirim
# bermutu : mutu
# komplin : komplin
# klik : klik
# layanan : layan
# diblokir : blokir
# seharga : harga
# sebulan : bulan
# ditahan : tahan
# dikasih : kasih
# diteruskan : terus
# tekan : tekan
# tombol : tombol
# cs : cs
# parah : parah
# banget : banget
# dananya : dana
# oper : oper
# bingung : bingung
# ngaktifin : ngaktifin
# fitur : fitur
# chat : chat
# mengasih : asih
# feedback : feedback
# aktif : aktif
# lihat : lihat
# pembelian : beli
# tertulis : tulis
# gangguan : ganggu
# coba : coba
# email : email
# terkirim : kirim
# tlol : tlol
# asyikasyiknya : asyikasyiknya
# nemu : nemu
# diincar : incar
# eh : eh
# muncul : muncul
# popupiklan : popupiklan
# emas : emas
# dimana : mana
# mengganggu : ganggu
# close : close
# menu : menu
# beranda : beranda
# deh : deh
# tokopedia : tokopedia
# shopee : shopee
# kedepan : depan
# banyakan : banyak
# popup : popup
# jujur : jujur
# uninstal : uninstal
# suka : suka
# error : error
# errorbarusan : errorbarusan
# turun : turun
# bintangnya : bintang
# notif : notif
# tagihan : tagih
# selesai : selesai
# besok : besok
# bintang : bintang
# dibuka : buka
# tanggal : tanggal
# juni : juni
# pagi : pagi
# malam : malam
# cek : cek
# detail : detail
# terbayar : bayar
# nih : nih
# order : order
# pelapak : lapak
# keterlambatan : lambat
# kesehatan : sehat
# kondisi : kondisi
# membaik : baik
# kirim : kirim
# status : status
# parahnya : parah
# melaksanakan : laksana
# uangnya : uang
# refound : refound
# dirugikan : rugi
# kesel : kesel
# pemesanan : mesan
# limit : limit
# tersedia : sedia
# mengajukan : aju
# komplain : komplain
# sulit : sulit
# alamat : alamat
# emailnya : email
# perbaiki : baik
# mengunakan : mengunakan
# paylatter : paylatter
# kasih : kasih
# bug : bug
# contoh : contoh
# out : out
# dibukak : dibukak
# tulisan : tulis
# kesalahan : salah
# memantau : pantau
# pergerakan : gera
# pengembalian : kembali
# berfungsisy : berfungsisy
# butuh : butuh
# ajuin : ajuin
# komplainada : komplainada
# diarahin : diarahin
# pusat : pusat
# pengajuan : aju
# pembatalanpengembalian : pembatalanpengembalian
# aplikasinya : aplikasi
# payahmenyulitkan : payahmenyulitkan
# konsumen : konsumen
# senang : senang
# bertransaksi : transaksi
# mudah : mudah
# bermacammacam : bermacammacam
# relatif : relatif
# murah : murah
# ayo : ayo
# transfer : transfer
# baca : baca
# virtual : virtual
# account : account
# terverifikasi : verifikasi
# rekening : rekening
# terpotong : potong
# arahanya : arahanya
# langsung : langsung
# koneksi : koneksi
# terputus : putus
# ganti : ganti
# selfilah : selfilah
# ktplah : ktplah
# mutasi : mutasi
# rekeninglah : rekening
# framelah : framelah
# kembalikan : kembali
# ditangani : tangan
# tim : tim
# jam : jam
# maaf : maaf
# ya : ya
# apk : apk
# sih : sih
# star : star
# memuaskan : muas
# dipakai : pakai
# rekomendasi : rekomendasi
# dengam : dengam
# pulsa : pulsa
# diskon : diskon
# respon : respon
# semoga : moga
# maksimal : maksimal
# promo : promo
# efisien : efisien
# dibandingkan : banding
# kekurangan : kurang
# merk : merk
# voucher : voucher
# alternatif : alternatif
# pt : pt
# mengakuisisi : akuisisi
# gratis : gratis
# ku : ku
# juli : juli
# rupa : rupa
# kali : kali
# hitung : hitung
# lipat : lipat
# gandakan : ganda
# pintar : pintar
# rekom : rekom
# pengguna : guna
# bagus : bagus
# cari : cari
# ppob : ppob
# pokok : pokok
# dibukalapak : dibukalapak
# cancel : cancel
# stok : stok
# habisdan : habisdan
# berdasarkan : dasar
# info : info
# asuransi : asuransi
# menyedihkan : sedih
# asuransinya : asuransi
# proses : proses
# ditunggu : tunggu
# mengecewakan : kecewa
# kecewa : kecewa
# bulanan : bulan
# aktifkan : aktif
# lunasi : lunas
# pakaitrus : pakaitrus
# jatuh : jatuh
# temponya : tempo
# lansung : lansung
# complain : complain
# berteletele : berteletele
# layani : layan
# penukaran : tukar
# prakerja : prakerja
# bikin : bikin
# bl : bl
# mewq : mewq
# iinv : iinv
# berkurang : kurang
# token : token
# keterangan : terang
# sialnya : sial
# besoknya : besok
# kadaluarsa : kadaluarsa
# anjir : anjir
# mahal : mahal
# lambat : lambat
# kelalaian : lalai
# bandingkan : banding
# duluan : duluan
# rubah : rubah
# bersaing : saing
# kompetitor : kompetitor
# melalu : lalu
# verifikasi : verifikasi
# komplen : komplen
# dibantu : bantu
# dipersulit : sulit
# permainan : main
# kah : kah
# mengambil : ambil
# hak : hak
# miliknya : milik
# tambahan : tambah
# dirinci : dirinci
# pelacakan : lacak
# paket : paket
# diantar : antar
# notifikasi : notifikasi
# penerima : terima
# keterima : terima
# diberitahu : diberitahu
# kedepannya : depan
# tanggap : tanggap
# retur : retur
# kode : kode
# otp : otp
# memasukkan : masuk
# disuruh : suruh
# upgrade : upgrade
# terpaksa : paksa
# belikan : belikan
# pantesan : pantesan
# merosot : merosot
# tukang : tukang
# nipu : nipu
# program : program
# serbu : serbu
# halo : halo
# diproses : proses
# melampaui : lampau
# batas : batas
# membatalkan : batal
# dihubungichat : dihubungichat
# tokoselernya : tokoselernya
# mohon : mohon
# pencerahannya : cerah
# puas : puas
# vocer : vocer
# cashback : cashback
# kadang : kadang
# gunakanhabis : gunakanhabis
# habis : habis
# hilangkan : hilang
# tulis : tulis
# belaku : bela
# halaman : halaman
# kebawah : bawah
# ijo : ijo
# bonus : bonus
# dll : dll
# tingkatkan : tingkat
# inovasiinovasi : inovasiinovasi
# kalah : kalah
# hatihati : hatihati
# payletter : payletter
# rbbaru : rbbaru
# kalieeeengga : kalieeeengga
# lagiwk : lagiwk
# wkkok : wkkok
# yabl : yabl
# pengirimannyahrs : pengirimannyahrs
# perbaikan : baik
# sd : sd
# bank : bank
# ocbc : ocbc
# nisp : nisp
# lwh : lwh
# pilihan : pilih
# kekelasan : kelas
# tutup : tutup
# pelayanan : layan
# buruk : buruk
# susah : susah
# akses : akses
# memeberikan : memeberikan
# solusi : solusi
# bekuin : bekuin
# baiknya : baik
# jalan : jalan
# loh : loh
# tertinggal : tinggal
# ditambah : tambah
# kenyamanan : nyaman
# pedagang : dagang
# berbelanja : belanja
# permanen : permanen
# pemakaian : pakai
# beralih : alih
# sebelah : belah
# shoppy : shoppy
# menghubungi : hubung
# livechat : livechat
# dikhususkan : khusus
# ketinggalan : tinggal
# olshop : olshop
# kemudahan : mudah
# customernya : customernya
# dimudahkan : mudah
# apapun : apa
# mengganti : ganti
# gmail : gmail
# suruh : suruh
# nomor : nomor
# sajah : sajah
# terkait : kait
# upload : upload
# dagangan : dagang
# kurasi : kuras
# kategori : kategori
# normal : normal
# gagal : gagal
# sangatembantu : sangatembantu
# mesti : mesti
# informasi : informasi
# melacak : lacak
# experssya : experssya
# mengecek : ecek
# no : no
# kulir : kulir
# segitu : segitu
# kekurangannya : kurang
# komponen : komponen
# unik : unik
# setting : setting
# maps : maps
# refresh : refresh
# mengulangi : ulang
# kebanyakan : banyak
# ekspedisi : ekspedisi
# bukasend : bukasend
# mengurus : urus
# refund : refund
# dicairin : dicairin
# nominalnya : nominal
# topup : topup
# ikhlasin : ikhlasin
# pln : pln
# byar : byar
# kadarluarsa : kadarluarsa
# diarahkan : arah
# artikel : artikel
# menulis : tulis
# persulit : sulit
# ditemukanmakin : ditemukanmakin
# heran : heran
# tidka : tidka
# mengerti : erti
# prihal : prihal
# payleter : payleter
# enggak bisa : enggak bisa
# mentok : mentok
# minggu : minggu
# macet : macet
# enggak ada : enggak ada
# tanggapan : tanggap
# oernah : oernah
# disediain : ain
# komplan : komplan
# benahi : benah
# sinyal : sinyal
# tempo : tempo
# naikyg : naikyg
# percaya : percaya
# mode : mode
# aga : aga
# mengaco : aco
# favorit : favorit
# search : search
# kemana : mana
# toko : toko
# systemnya : systemnya
# menutupi : tutup
# kurirnya : kurir
# mengirim : kirim
# ongkirku : ongkirku
# dipotong : potong
# ongkirnya : ongkirnya
# permasalahan : masalah
# pesananselalu : pesananselalu
# tulusan : tulus
# lacak : lacak
# nomer : nomer
# instal : instal
# paketnya : paket
# nyampek : nyampek
# sekian : sekian
# berat : berat
# serasa : serasa
# ditipu : tipu
# ekspres : ekspres
# estimasi : estimasi
# kerja : kerja
# peniriman : peniriman
# bertanggung : tanggung
# kerugian : rugi
# materi : materi
# semenjak : semenjak
# call : call
# canter : canter
# bantuannya : bantu
# mencewakan : mencewakan
# selsai : selsai
# kacau : kacau
# benarbenar : benarbenar
# bermasalah : masalah
# terhubung : hubung
# salah : salah
# bilang : bilang
# kejebak : jebak
# menerima : terima
# bukalapakudah : bukalapakudah
# cekout : cekout
# payment : payment
# selesaitapidi : selesaitapidi
# nyaakhirnya : nyaakhirnya
# kemanaudah : kemanaudah
# hubungin : hubungin
# sedikitkecewa : sedikitkecewa
# statusnya : status
# berubah : ubah
# konfirmasi : konfirmasi
# brisaldo : brisaldo
# kepotong : potong
# bayarparah : bayarparah
# ajaudh : ajaudh
# untung : untung
# doang : doang
# cuihhh : cuihhh
# smartphone : smartphone
# membuka : buka
# lamalama : lamalama
# kepala : kepala
# pusing : pusing
# layoutnya : layoutnya
# berantakan : beranta
# xxx : xxx
# tampilan : tampil
# ponsel : ponsel
# aksesoris : aksesoris
# suku : suku
# cadang : cadang
# penantan : penantan
# kolom : kolom
# produknya : produk
# tampilkan : tampil
# rapi : rapi
# rekan : rekan
# bosan : bosan
# jenuh : jenuh
# melanjutkan : lanjut
# pencairan : cair
# kesini : kesini
# seler : seler
# setatus : setatus
# pembatalan : batal
# pemberitahuan : pemberitahuan
# tiktok : tiktok
# mah : mah
# turunkan : turun
# satusaya : satusaya
# kenakan : kena
# biyaya : biyaya
# anehjelas : anehjelas
# knapa : knapa
# sekalimohon : sekalimohon
# dikit : dikit
# sepi : sepi
# ktp : ktp
# infonya : info
# verifikasigak : verifikasigak
# lemot : lot
# duit : duit
# mencuri : curi
# pin : pin
# hape : hape
# bajak : bajak
# pembajak : bajak
# tersambung : sambung
# tibatiba : tibatiba
# game : game
# memperpanjang : panjang
# umur : umur
# gulung : gulung
# tikar : tikar
# kayak : kayak
# platform : platform
# nyamantidak : nyamantidak
# bukalapakselain : bukalapakselain
# mahalada : mahalada
# bebankanmending : bebankanmending
# benermending : benermending
# tujuansudah : tujuansudah
# jamannya : jaman
# tolonglah : tolong
# muat : muat
# trakhir : trakhir
# uninstall : uninstall
# apknya : apknya
# min : min
# data : data
# verifikasinya : verifikasi
# keteranganya : keteranganya
# hp : hp
# berbeda : beda
# memblokir : blokir
# mengatasnamakan : mengatasnamakan
# takut : takut
# disalahgunakan : disalahgunakan
# blapak : blapak
# namanya : nama
# berfungsi : fungsi
# login : login
# jarang : jarang
# potongan : potong
# harga : harga
# orderan : order
# ajukan : aju
# whatsapp : whatsapp
# kurangnya : kurang
# dipromo : dipromo
# terimakasih : terimakasih
# utakatik : utakatik
# penipu : tipu
# beda : beda
# lazada : lazada
# shoppe : shoppe
# pencarian : cari
# menampilkan : tampil
# onderdilpart : onderdilpart
# pretelan : pretel
# ketik : ketik
# mesin : mesin
# cuci : cuci
# onderdil : onderdil
# kurangi : kurang
# evaluasi : evaluasi
# inimungkin : inimungkin
# option : option
# tersendiri : sendiri
# part : part
# ongkos : ongkos
# tetapkan : tetap
# bukti : bukti
# tangan : tangan
# expedisinya : expedisinya
# ditunda : tunda
# pengirimannya : kirim
# ngambil : ngambil
# profesional : profesional
# kerjanya : kerja
# foto : foto
# post : post
# poto : poto
# ditokopedia : ditokopedia
# poduk : poduk
# brng : brng
# seperri : seperri
# seblum : seblum
# ramai : ramai
# un : un
# install : install
# pindah : pindah
# shopeelazada : shopeelazada
# bukalapakakin : bukalapakakin
# erorr : erorr
# sekalinya : sekali
# robot : robot
# penjawab : jawab
# tanggung : tanggung
# sengaja : sengaja
# makan : makan
# gaji : gaji
# buta : buta
# mundur : mundur
# non : non
# aktifsaya : aktifsaya
# aktiftoko : aktiftoko
# maintenance : maintenance
# pemakai : pakai
# wajar : wajar
# penagihan : tagih
# lunas : lunas
# aduh : aduh
# susahnya : susah
# ampun : ampun
# gercep : gercep
# nyambing : nyambing
# penjualnya : jual
# pembelinya : bel
# rugi : rugi
# dianggap : anggap
# bertambah : tambah
# dompet : dompet
# berkali : kali
# tunggu : tunggu
# aa : aa
# bantu : bantu
# kendala : kendala
# kakak : kakak
# alami : alami
# solusinya : solusi
# ktpno : ktpno
# telphone : telphone
# membuktikan : bukti
# pemilik : milik
# digital : digital
# diuntungkan : untung
# kuotanya : kuota
# diskonnya : diskon
# balikin : balikin
# vouchernya : vouchernya
# pembelikomplain : pembelikomplain
# bisatpi : bisatpi
# jasalancar : jasalancar
# motong : motong
# menyesal : sesal
# masalahpasti : masalahpasti
# komplainblm : komplainblm
# orange : orange
# tinggal : tinggal
# koid : koid
# perubahan : ubah
# seharian : hari
# dijemput : jemput
# dichat : dichat
# barangbarang : barangbarang
# oke : oke
# ongkirn : ongkirn
# codnya : codnya
# dibatasin : dibatasin
# belnja : belnja
# ratusan : ratus
# mendapati : dapat
# grtis : grtis
# oren : oren
# berkedok : kedok
# kapok : kapok
# seminggu : minggu
# lapor : lapor
# bergantung : gantung
# lucu : lucu
# belanjanya : belanja
# gampang : gampang
# bayarnya : bayar
# livechatnya : livechatnya
# dilunasi : lunas
# telat : telat
# sebenar : benar
# cth : cth
# kemarin : kemarin
# ambil : ambil
# bareng : bareng
# hrg : hrg
# san : san
# jutaan : juta
# asli : asli
# bohongan : bohong
# bebayar : bebayar
# sebutin : sebutin
# mengecewa : kecewa
# arah : arah
# mengetik : etik
# initapi : initapi
# kualitas : kualitas
# lumayan : lumayan
# nasabah : nasabah
# urgent : urgent
# chattidak : chattidak
# pertanyataan : pertanyataan
# disediakan : sedia
# user : user
# mengirimkan : kirim
# refundnya : refundnya
# konplain : konplain
# komplainnya : komplain
# ecommerce : ecommerce
# selepas : lepas
# mendesakharusnya : mendesakharusnya
# kembalibagaimanapun : kembalibagaimanapun
# bldah : bldah
# ulangi : ulang
# samatapi : samatapi
# ok : ok
# pertahankan : tahan
# siang : siang
# kecamatan : camat
# mudahan : mudah
# berbelitstatus : berbelitstatus
# diiterima : diiterima
# terkirimhati : terkirimhati
# bukalapakbaru : bukalapakbaru
# diupload : diupload
# diberubah : ubah
# aneh : aneh
# tersaingi : saing
# seenak : enak
# ubah : ubah
# stoknya : stok
# melanggar : langgar
# tersebutdan : tersebutdan
# photo : photo
# hasil : hasil
# ciplakmakin : ciplakmakin
# menurun : turun
# aplakasi : aplakasi
# jaringanlah : jaring
# jaringan : jaring
# full : full
# mautanya : mautanya
# calon : calon
# terkecuali : kecuali
# link : link
# okee : okee
# enggak jelas : enggak jelas
# emosi : emosi
# daftar : daftar
# kedaftargimana : kedaftargimana
# maksutnya : maksutnya
# pulahadehbikin : pulahadehbikin
# sajaauto : sajaauto
# delete : delete
# nge : nge
# freeze : freeze
# kompatible : kompatible
# android : android
# bukajadinya : bukajadinya
# kitapd : kitapd
# bayarsdh : bayarsdh
# transfergimana : transfergimana
# gantian : ganti
# biar : biar
# merasakan : rasa
# rasakan : rasa
# menyalahkan : salah
# pesenan : sen
# menylelesaikan : menylelesaikan
# jawabannya : jawab
# payah : payah
# peasana : peasana
# sesuaipembeli : sesuaipembeli
# membayar : bayar
# pengembalianpadahal : pengembalianpadahal
# penjualdimana : penjualdimana
# servis : servis
# handphonerugi : handphonerugi
# waktuuang : waktuuang
# perangkatnya : perangkat
# kelartolong : kelartolong
# perhatikan : perhati
# sesiusterima : sesiusterima
# transaksierror : transaksierror
# perbaikitidak : perbaikitidak
# bis : bis
# histori : histori
# barangthanks : barangthanks
# harapkan : harap
# penambahan : tambah
# berhak : hak
# cocok : cocok
# mincara : mincara
# lupa : lupa
# pinseingat : pinseingat
# isi : isi
# caranyaini : caranyaini
# haridigunain : haridigunain
# bisacoba : bisacoba
# jelaskansampe : jelaskansampe
# ditagih : tagih
# bukalapaksedangkan : bukalapaksedangkan
# gagalaneh : gagalaneh
# pemesanansaya : pemesanansaya
# tertipu : tipu
# store : store
# kecewasaya : kecewasaya
# total : total
# kejadian : jadi
# inibukalapak : inibukalapak
# kecewasejauh : kecewasejauh
# menggaet : gaet
# minat : minat
# diturunkan : turun
# kecuali : kecuali
# pajangan : pajang
# sensitif : sensitif
# saran : saran
# diklik : klik
# kompak : kompak
# fungsi : fungsi
# dinonaktifkan : nonaktif
# tokoh : tokoh
# sayasy : sayasy
# berkalikali : berkalikali
# nyabintang : nyabintang
# dilapak : lapak
# tindak : tindak
# developer : developer
# kiriman : kirim
# nyangkut : nyangkut
# expedisi : expedisi
# juta : juta
# ditelusuri : telusur
# sakit : sakit
# sembuhnya : sembuh
# memuaskantapi : memuaskantapi
# sayangkan : sayang
# banda : banda
# acehdi : acehdi
# mencapai : capai
# perkilonyapadahal : perkilonyapadahal
# semahal : mahal
# itupaling : itupaling
# an : an
# acehmohon : acehmohon
# pertimbangan : timbang
# acehmaunya : acehmaunya
# aceh : aceh
# inibelakangan : inibelakangan
# daerah : daerah
# sampainyadicoba : sampainyadicoba
# terusongkir : terusongkir
# bukaekpress : bukaekpress
# berattidak : berattidak
# tab : tab
# jelaspercuma : jelaspercuma
# limite : limite
# transaksinyesel : transaksinyesel
# belanjajelas : belanjajelas
# sekaliperdetik : sekaliperdetik
# uninstalmakasih : uninstalmakasih
# sayabagi : sayabagi
# digitalpelapak : digitalpelapak
# curang : curang
# terimacobalah : terimacobalah
# komplainsampai : komplainsampai
# laporan : lapor
# tahan : tahan
# teruskan : terus
# pelapakbats : pelapakbats
# berjalanterus : berjalanterus
# nyalewat : nyalewat
# alhamdulillah : alhamdulillah
# menambah : tambah
# terima kasih : terima kasih
# datangnya : datang
# separo : paro
# mahalnya : mahal
# kg : kg
# pulau : pulau
# jawa : jawa
# jembersemarang : jembersemarang
# label : label
# penipuan : tipu
# diterima : terima
# deskripsi : deskripsi
# screenshoot : screenshoot
# ditutup : tutup
# menyenangkan : senang
# membeli : beli
# dibutuhkan : butuh
# dirumahterimakasih : dirumahterimakasih
# motor : motor
# byson : byson
# alhamdulilah : alhamdulilah
# kak : kak
# form : form
# file : file
# format : format
# xml : xml
# nanyain : nanyain
# komentar : komentar
# serepes : repes
# penuh : penuh
# jebakan : jebak
# saing : saing
# terlanjur : lanjur
# kelain : lain
# hatikayaknya : hatikayaknya
# rejeki : rejeki
# voucer : voucer
# historikalaupun : historikalaupun
# thok : thok
# penambahanknpa : penambahanknpa
# kwalitas : kwalitas
# kerusakan : rusa
# barangtapi : barangtapi
# rusak : rusak
# klaimnya : klaim
# ditolak : tolak
# bukalapakmending : bukalapakmending
# ajalebih : ajalebih
# terpercaya : percaya
# kantong : kantong
# mantap : mantap
# gue : gue
# nonaktifkan : nonaktif
# log : log
# tertera : tera
# ah : ah
# setia : setia
# pembiayaan : biaya
# recomend : recomend
# super : super
# terselesaikan : selesai
# kawan : kawan
# diskusi : diskusi
# cenderung : cenderung
# korban : korban
# pertimbangkan : timbang
# terdaftar : daftar
# kocak : kocak
# hadehh : hadehh
# adil : adil
# kga : kga
# mudahpengiriman : mudahpengiriman
# cepatqualitas : cepatqualitas
# hargasaya : hargasaya
# jaya : jaya
# andalan : andal
# penggunanya : guna
# pelit : pelit
# costumer : costumer
# service : service
# trnsaksi : trnsaksi
# berhasilpulsa : berhasilpulsa
# masuktagihan : masuktagihan
# adakomplen : adakomplen
# diurus : urus
# satunya : satu
# rampog : rampog
# paraaaaaaaahhhhh : paraaaaaaaahhhhh
# buang : buang
# iklanhasilnya : iklanhasilnya
# manfaatatnya : manfaatatnya
# satupuntidak : satupuntidak
# laku : laku
# fakta : fakta
# sekalichat : sekalichat
# bisaenakan : bisaenakan
# chip : chip
# shoppee : shoppee
# mencari : cari
# telusur : telusur
# kunci : kunci
# merek : merek
# official : official
# brand : brand
# back : back
# bisabolak : bisabolak
# ajatolong : ajatolong
# lapakbisa : lapakbisa
# kelar : kelar
# bolak : bolak
# blk : blk
# dikirm : dikirm
# nyampai : nyampai
# sayagak : sayagak
# aktiv : aktiv
# menipu : tipu
# cantumkan : cantum
# repotstatus : repotstatus
# updatedi : updatedi
# kirimpembeli : kirimpembeli
# ngomelauto : ngomelauto
# off : off
# lunaspaylater : lunaspaylater
# apapunselalu : apapunselalu
# berhari : hari
# tersambungjawaban : tersambungjawaban
# agen : agen
# sibuk : sibuk
# parahpayah : parahpayah
# tertahan : tahan
# kapandulu : kapandulu
# pembatalansekarang : pembatalansekarang
# hilangapk : hilangapk
# puyeng : puyeng
# responya : responya
# kosong : kosong
# nancep : nancep
# tarik : tarik
# penjelasan : jelas
# pbb : pbb
# koreksi : koreksi
# lancar : lancar
# eror : eror
# keamanan : aman
# kaitkan : kait
# terpilih : pilih
# seru : seru
# sebu : sebu
# nyata : nyata
# kirimkan : kirim
# serbuan : serbu
# akunotp : akunotp
# sms : sms
# masukvie : masukvie
# masukbolak : masukbolak
# capca : capca
# penyelesaian : selesai
# bukalapaksangat : bukalapaksangat
# bertele : tele
# anjurin : anjurin
# pinjol : pinjol
# hadeuhhhhh : hadeuhhhhh
# selamat : selamat
# terhormat : hormat
# mengabaikan : abai
# balasan : balas
# tlpn : tlpn
# angkat : angkat
# seluler : seluler
# pengaduannya : adu
# kantor : kantor
# diperlakukan : laku
# sungguh : sungguh
# ready : ready
# ditransfer : transfer
# amplop : amplop
# template : template
# kagak : kagak
# dosa : dosa
# lu : lu
# menahan : tahan
# paraaaahhhh : paraaaahhhh
# terusuntuk : terusuntuk
# lamaperlu : lamaperlu
# wa : wa
# resmi : resmi
# nyapengiriman : nyapengiriman
# melambat : lambat
# intinya : inti
# puasini : puasini
# masukan : masuk
# team : team
# pelapakada : pelapakada
# solusifitur : solusifitur
# mutarmuter : mutarmuter
# ulasan : ulas
# pilih : pilih
# agustus : agustus
# anjer : anjer
# dibulan : bulan
# dipenjualan : jual
# kesekian : sekian
# kalinya : kali
# mengalami : alami
# professional : professional
# good : good
# buatlah : buat
# customers : customers
# terbaiksangat : terbaiksangat
# lapakdan : lapakdan
# aplikasinyakomplit : aplikasinyakomplit
# adadan : adad
# binggung : binggung
# kebaikan : baik
# belanjaan : belanja
# free : free
# masukkan : masuk
# tulisanya : tulisanya
# berlaku : laku
# diharapkan : harap
# sadar : sadar
# guaudh : guaudh
# kenamasa : kenamasa
# ngutang : ngutang
# dobel : dobel
# dikonter : konter
# guaga : guaga
# untungyamending : untungyamending
# hapus : hapus
# apldibukalapak : apldibukalapak
# payleternya : payleternya
# biayalayanan : biayalayanan
# pembeliancukup : pembeliancukup
# lagibayar : lagibayar
# kebangetan : banget
# ragu : ragu
# terjamin : jamin
# amanah : amanah
# aplikasigak : aplikasigak
# playlater : playlater
# bangetpencarian : bangetpencarian
# promonya : promonya
# bukanya : buka
# ketimbang : ketimbang
# market : market
# place : place
# diperbanyak : banyak
# hilangakan : hilangakan
# trik : trik
# modus : modus
# melulu : melulu
# hadiah : hadiah
# kebnyakan : kebnyakan
# vocher : vocher
# ongkirapk : ongkirapk
# bukanyaa : bukanyaa
# pelayanannya : layan
# beberapakali : beberapakali
# lapaknya : lapak
# pengin : pengin
# kehilangan : hilang
# ditemuakan : tua
# kejelasan : jelas
# mantab : mantab
# sgr : sgr
# atasi : atas
# siiip : siiip
# tooooopp : tooooopp
# menangani : tangan
# batalin : batalin
# jelek : jelek
# penyakitnya : sakit
# slow : slow
# bukalampak : bukalampak
# berjualan : jual
# betrasasi : betrasasi
# blanja : blanja
# gkjelasudah : gkjelasudah
# spaylater : spaylater
# tidaksuruh : tidaksuruh
# wajahudah : wajahudah
# diverifikasi : verifikasi
# muka : muka
# jelastetap : jelastetap
# buramgakjeas : buramgakjeas
# kasihan : kasihan
# gua : gua
# cair : cair
# allah : allah
# membalas : balas
# kelecikan : leci
# pastinya : pasti
# wifi : wifi
# lemmooottttt : lemmooottttt
# dasarnya : dasar
# karuan : karuan
# transsaksi : transsaksi
# terisi : isi
# penawaran : tawar
# tanda : tanda
# kesulitan : sulit
# terbaca : baca
# kepencet : pencet
# bulalapak : bulalapak
# bermain : main
# konten : konten
# webnya : webnya
# hasilnya : hasil
# kecurigaan : curiga
# maafkan : maaf
# servive : servive
# ditanggapin : ditanggapin
# uangku : uang
# danakenapa : danakenapa
# penarikannya : tari
# bangetharus : bangetharus
# danapoto : danapoto
# rekam : rekam
# wajah : wajah
# minknp : minknp
# terbaru : baru
# jualbeli : jualbeli
# persaingan : saing
# ketat : ketat
# ytpinmnrt : ytpinmnrt
# akubukalapak : akubukalapak
# mnjadinyg : mnjadinyg
# terbaik : baik
# terdepansemoga : terdepansemoga
# kdp : kdp
# ybukalapak : ybukalapak
# berkembang : kembang
# maju : maju
# segi : segi
# pelayananpioritaskn : pelayananpioritaskn
# yagar : yagar
# bertransaksitrimakasih : bertransaksitrimakasih
# sellernya : sellernya
# apliksi : apliksi
# bukalapaknya : bukalapaknya
# melindungi : lindung
# membantuuang : membantuuang
# kemunduranmasa : kemunduranmasa
# cuman : cuman
# hahahhakatanya : hahahhakatanya
# perusahaan : usaha
# menghindar : hindar
# komplainhahaha : komplainhahaha
# inisaya : inisaya
# ajak : ajak
# ngobrolhahah : ngobrolhahah
# adaklau : adaklau
# sayaklau : sayaklau
# adminnya : adminnya
# tidur : tidur
# pembelanjaan : belanja
# playlaternya : playlaternya
# dendanya : denda
# bgst : bgst
# securty : securty
# checkup : checkup
# jugamasih : jugamasih
# hidup : hidup
# komplenan : komplenan
# bukatempek : bukatempek
# mahalsekarang : mahalsekarang
# turunin : turunin
# harganya : harga
# app : app
# menawarkan : tawar
# unlimited : unlimited
# apps : apps
# berkebun : kebun
# pelapaknya : lapak
# fast : fast
# kemahalan : mahal
# kreditx : kreditx
# dipindahkan : pindah
# minkhusus : minkhusus
# mengapai : kapai
# rokets : rokets
# dapatx : dapatx
# kekumpul : kumpul
# exp : exp
# discount : discount
# loyal : loyal
# lamasetiajarang : lamasetiajarang
# ket : ket
# kecewapesan : kecewapesan
# bukaexpress : bukaexpress
# waktueh : waktueh
# sicepat : sicepat
# halu : halu
# sepuluh : puluh
# sementarasebelum : sementarasebelum
# diterimasaya : diterimasaya
# lho : lho
# transaksasi : transaksasi
# rewelkomplain : rewelkomplain
# dibodohi : bodoh
# dibohongi : bohong
# praktisbukalapak : praktisbukalapak
# pop : pop
# kanan : kanan
# duribu : duribu
# pickup : pickup
# gagaluang : gagaluang
# danacukup : danacukup
# bukalapakmalah : bukalapakmalah
# merepotkan : repot
# keuntungan : untung
# semangat : semangat
# prima : prima
# ketemu : ketemu
# abalabal : abalabal
# disengaja : sengaja
# diseleksi : seleksi
# memperumit : rumit
# checkout : checkout
# muter : muter
# disitu : situ
# diperbaiki : baik
# urusan : urus
# minimal : minimal
# mempersulit : sulit
# perampok : rampok
# bulanansaldo : bulanansaldo
# rek : rek
# loading : loading
# ngulang : ngulang
# laporkan : lapor
# kepelapak : lapak
# buakalapak : buakalapak
# dasar : dasar
# maling : maling
# riwayat : riwayat
# auto : auto
# transit : transit
# pick : pick
# rekomen : rekomen
# lapaklebih : lapaklebih
# lamaaaa : lamaaaa
# pengirim : kirim
# negeri : negeri
# tabungannya : tabung
# nominal : nominal
# tiada : tiada
# berinovasi : inovasi
# semangatsemangat : semangatsemangat
# penggunaan : guna
# limitnya : limit
# terpakai : pakai
# sisa : sisa
# bisaslalu : bisaslalu
# otomatisketerangan : otomatisketerangan
# pembatalannya : batal
# dibatalkanseakan : dibatalkanseakan
# batalkanpadahal : batalkanpadahal
# wadah : wadah
# system : system
# alhasil : alhasil
# dinyatakan : nyata
# valid : valid
# mengutamakan : utama
# potong : potong
# kedaluarsa : kedaluarsa
# commerce : commerce
# worth : worth
# pengecekan : kece
# sampainya : sampai
# pengembang : kembang
# halamannya : halaman
# internet : internet
# stabil : stabil
# aplikais : aplikais
# upraged : upraged
# bisanya : bisa
# jualanannya : jualanannya
# membela : bela
# kepentingan : penting
# menjanjikan : janji
# nama : nama
# anehnya : aneh
# scrol : scrol
# smpek : smpek
# mengadu : adu
# kesana : kesana
# koleksinya : koleksi
# berbulan : bulan
# stagnan : stagnan
# greget : greget
# ol : ol
# shop : shop
# bukalapakygdulu : bukalapakygdulu
# validpadahal : validpadahal
# kesal : kesal
# bst : bst
# modal : modal
# pasan : pas
# muterin : muterin
# berakibat : akibat
# truss : truss
# nyuruh : nyuruh
# balesan : balesan
# credit : credit
# syarat : syarat
# ketentuan : tentu
# ketahui : tahu
# sampah : sampah
# tsbt : tsbt
# matikan : mati
# memproses : proses
# udda : udda
# langganan : langgan
# ketiga : tiga
# mulu : mulu
# beku : beku
# baned : baned
# feed : feed
# gede : gede
# bantuannyasaya : bantuannyasaya
# logindikarenakan : logindikarenakan
# aktifmau : aktifmau
# sayadan : sayadan
# bukalapakmohon : bukalapakmohon
# pengaturan : atur
# betah : betah
# perdagangan : dagang
# mei : mei
# potongam : potongam
# saller : saller
# promote : promote
# push : push
# efek : efek
# tercontreng : tercontreng
# covid : covid
# kebaca : baca
# kebeli : kebel
# gara : gara
# buru : buru
# cicilan : cicil
# mengadakan : ada
# perbanyak : banyak
# perihal : perihal
# event : event
# bukatabungan : bukatabungan
# menggundang : gundang
# reward : reward
# tabungan : tabung
# fiture : fiture
# moga : moga
# kekurir : kurir
# left : left
# seenaknyalangsg : seenaknyalangsg
# percakapan : cakap
# percakapanjadi : percakapanjadi
# kebelakang : belakang
# antrian : antri
# nutup : nutup
# trecking : trecking
# editsaat : editsaat
# bisakalau : bisakalau
# dibilang : bilang
# pelosokmungkintapi : pelosokmungkintapi
# lainsaya : lainsaya
# manualtanpa : manualtanpa
# gpssaya : gpssaya
# kecewakarena : kecewakarena
# susupin : susupin
# pasang : pasang
# separuhnya : paruh
# realpict : realpict
# bukalapk : bukalapk
# tautpi : tautpi
# gramdi : gramdi
# kgdan : kgdan
# ahirnya : ahirnya
# ijoklo : ijoklo
# ampas : ampas
# bangkrut : bangkrut
# play : play
# sellerseller : sellerseller
# seakan : akan
# bertanggungjawab : bertanggungjawab
# ujungnya : ujung
# lepas : lepas
# tertata : tata
# batasi : batas
# pepalak : palak
# kompalain : kompalain
# tpdiketangan : tpdiketangan
# lainemang : lainemang
# daptar : daptar
# alikasi : alikasi
# yahsangat : yahsangat
# membingungkanlangsung : membingungkanlangsung
# enak : enak
# memakai : pakai
# belu : belu
# cairkan : cair
# hadehhh : hadehhh
# sandi : sandi
# gunanya : guna
# barusan : barusan
# bsi : bsi
# berulangkali : berulangkali
# dikomplain : komplain
# bersabar : sabar
# lion : lion
# parcel : parcel
# dibiarkan : biar
# utama : utama
# bukalapakjasa : bukalapakjasa
# banyaksemoga : banyaksemoga
# filter : filter
# kota : kota
# sayabarang : sayabarang
# memilikki : memilikki
# variasi : variasi
# editdihapusdiganti : editdihapusdiganti
# jualannya : jual
# bangkitlah : bangkit
# orenny : orenny
# membatasi : batas
# aturan : atur
# jayadan : jayadan
# ngisi : ngisi
# flash : flash
# sale : sale
# bukalapakmau : bukalapakmau
# bngetnyesel : bngetnyesel
# sepeda : sepeda
# isnawati : isnawati
# byrkan : byrkan
# penipudn : penipudn
# selektif : selektif
# memilih : pilih
# krj : krj
# enakan : enak
# lada : lada
# tmbahantrus : tmbahantrus
# ajatrs : ajatrs
# trtera : trtera
# ceklis : ceklis
# satutrs : satutrs
# kmna : kmna
# pnjualy : pnjualy
# penipubkn : penipubkn
# budegpura : budegpura
# ingatanpokok : ingatanpokok
# pdagang : pdagang
# brkliaran : brkliaran
# biru : biru
# sibiru : sibiru
# subsidi : subsidi
# melimpah : limpah
# pokoknya : pokok
# compalin : compalin
# sebagus : bagus
# dulumasa : dulumasa
# penanganan : tangan
# gliran : gliran
# sue : sue
# mhon : mhon
# minga : minga
# lapa : lapa
# prioritas : prioritas
# majuuuuuuu : majuuuuuuu
# unistal : unistal
# datengin : datengin
# omong doang : omong doang
# kerjain : kerjain
# reset : reset
# pasword : pasword
# kiamat : kiamat
# butuhkan : butuh
# jne : jne
# updatesudah : updatesudah
# apapa : apapa
# jadual : jadual
# dijanjikan : janji
# kemasan : kemas
# ditaukan : tau
# walleteh : walleteh
# ludeskok : ludeskok
# cepatsat : cepatsat
# set : set
# rekomendet : rekomendet
# teknik : teknik
# okpelapak : okpelapak
# menang : menang
# memikirkan : pikir
# bernama : nama
# puji : puji
# memutuskan : putus
# sambungan : sambung
# diputuskan : putus
# berdebat : debat
# agt : agt
# pengoperasian : operasi
# praktis : praktis
# profil : profil
# des : des
# ajib : ajib
# fiturfiturnya : fiturfiturnya
# dicari : cari
# desain : desain
# layar : layar
# mengikuti : ikut
# misi : misi
# pesanchat : pesanchat
# mengenali : nali
# pribadi : pribadi
# beliau : beliau
# ambang : ambang
# kehancuran : hancur
# secepatnya : cepat
# gajls : gajls
# by : by
# laahh : laahh
# tujuan : tuju
# trimakasih : trimakasih
# babi : babi
# ngotak : ngotak
# anjink : anjink
# tolak : tolak
# biayanya : biaya
# rban : rban
# dagang : dagang
# pasaran : pasar
# cp : cp
# of : of
# duty : duty
# mobile : mobile
# naikan : naik
# kabur : kabur
# memaksakan : paksa
# pentingmending : pentingmending
# dah : dah
# masuknya : masuk
# versi : versi
# menyambung : sambung
# admintmantap : admintmantap
# tks : tks
# airlistrik : airlistrik
# bedanya : beda
# layanansama : layanansama
# custamerknpa : custamerknpa
# membedakan : beda
# katanyabayar : katanyabayar
# listri : listri
# conter : conter
# layanin : layanin
# orangnyamemang : orangnyamemang
# manusia : manusia
# harta : harta
# air : air
# pengadun : adun
# hubungkan : hubung
# aplkasi : aplkasi
# iniakun : iniakun
# hack : hack
# steam : steam
# vcr : vcr
# berhati : hati
# mendewakan : dewa
# pinjem : pinjem
# pinjaman : pinjam
# tunai : tunai
# wajib : wajib
# permudah : mudah
# peminatnya : minat
# dihati : hati
# bertahun : tahun
# dibenahi : benah
# boongan : boongan
# jnt : jnt
# nyantumin : nyantumin
# pembohong : bohong
# bayak : bayak
# menguntungkanyg : menguntungkanyg
# bisnis : bisnis
# tersendiridan : tersendiridan
# ifennya : ifennya
# semacem : semacem
# tlng : tlng
# terkaitdevelop : terkaitdevelop
# dikecewain : dikecewain
# errorklo : errorklo
# sendiripayahudah : sendiripayahudah
# ongkirskrg : ongkirskrg
# diperparah : parah
# erornya : eror
# donwload : donwload
# ukuran : ukur
# ngeprint : ngeprint
# printer : printer
# thermal : thermal
# siniudah : siniudah
# capek : capek
# ngetikpas : ngetikpas
# tuju : tuju
# jdinya : jdinya
# terimatpi : terimatpi
# reportnya : reportnya
# bingungmo : bingungmo
# pasrah : pasrah
# tanggapin : tanggapin
# bukaemas : bukaemas
# sabar : sabar
# kepastian : pasti
# penutupan : tutup
# tanggapinnya : tanggapinnya
# formulir : formulir
# permohonan : mohon
# listriknya : listrik
# paham : paham
# iklanin : iklanin
# serius : serius
# unggul : unggul
# aktifin : aktifin
# ribumending : ribumending
# sejarah : sejarah
# setahun : tahun
# iser : iser
# name : name
# daniwardiyanto : daniwardiyanto
# bukalapakkk : bukalapakkk
# paylaterr : paylaterr
# kosonnggh : kosonnggh
# ekonomis : ekonomis
# adminatau : adminatau
# paylatternya : paylatternya
# beralamat : alamat
# jauhsetidaknya : jauhsetidaknya
# membantusukses : membantusukses
# penipunya : tipu
# pengaduan : adu
# klaim : klaim
# refundlangsung : refundlangsung
# customermau : customermau
# ngacoooo : ngacoooo
# packing : packing
# cepatgoodjob : cepatgoodjob
# konekai : konekai
# streaming : streaming
# youtube : youtube
# buffering : buffering
# diperbaikiaplikasi : diperbaikiaplikasi
# belanjanotifikasinya : belanjanotifikasinya
# semangkin : semangkin
# padehal : padehal
# kemjuan : kemjuan
# banding : banding
# tabah : tabah
# letoy : letoy
# menuaskan : tuas
# sampainyatrims : sampainyatrims
# konfirm : konfirm
# briva : briva
# saldonya : saldo
# bego : bego
# tolol : tolol
# gabut : gabut
# open : open
# maksimalkan : maksimal
# om : om
# mintabtolong : mintabtolong
# batalinnatau : batalinnatau
# otw : otw
# padaha : padaha
# akui : aku
# bukalapakmenyebabkan : bukalapakmenyebabkan
# dibekukantp : dibekukantp
# iya : iya
# pesananan : pesananan
# nyagara : nyagara
# lunassss : lunassss
# diberikankalau : diberikankalau
# ditambh : ditambh
# problem : problem
# blkadang : blkadang
# wae : wae
# euy : euy
# kumaha : maha
# atuh : atuh
# outomatistapi : outomatistapi
# outomatis : outomatis
# tercancelsudah : tercancelsudah
# dilaporkan : lapor
# berulang : ulang
# jawabanya : jawabanya
# jawabanyasampai : jawabanyasampai
# menunggusampai : menunggusampai
# ayam : ayam
# terbang : terbang
# barukecewa : barukecewa
# sayapelapak : sayapelapak
# merespon : merespon
# transaksinya : transaksi
# responnyaselamat : responnyaselamat
# beraktifitas : beraktifitas
# aplikasikadang : aplikasikadang
# dipencarian : cari
# diam : diam
# jalanpadahal : jalanpadahal
# normallama : normallama
# ditinggak : ditinggak
# kaya : kaya
# dikecewakan : kecewa
# duanya : dua
# edannnnn : edannnnn
# lemotnya : lot
# parahhhh : parahhhh
# jaringannya : jaring
# mencoba : coba
# duitnya : duit
# paitmasuk : paitmasuk
# bajaktapi : bajaktapi
# membiarkan : biar
# syyg : syyg
# orgbikin : orgbikin
# raya : raya
# the : the
# best : best
# lapakmenurut : lapakmenurut
# rekrutmen : rekrutmen
# resller : resller
# nyadan : nyadan
# cepatjk : cepatjk
# sadis : sadis
# perak : perak
# bunganya : bunga
# mencekik : cekik
# hitungannya : hitung
# perhari : hari
# nagihnya : nagihnya
# teror : teror
# jatem : jatem
# telepon : telepon
# nagih : nagih
# iming : iming
# kuat : kuat
# mental : mental
# berasa : asa
# dibegoin : dibegoin
# pinjolnya : pinjolnya
# benersudah : benersudah
# goblog : goblog
# kelas : kelas
# berlangganan : langgan
# woi : woi
# layanannya : layan
# uanggood : uanggood
# job : job
# success : success
# disimpan : simpan
# utuh : utuh
# aktive : aktive
# pencerahan : cerah
# tele : tele
# daftarnyagak : daftarnyagak
# tpln : tpln
# password : password
# sopir : sopir
# rakus : rakus
# peredaran : edar
# contol : contol
# tol : tol
# tolollll : tolollll
# instan : instan
# menyelesaikan : selesai
# belanjaanya : belanjaanya
# kirimnya : kirim
# sampekalah : sampekalah
# akh : akh
# codapl : codapl
# enjoi : enjoi
# ditempatbukalapak : ditempatbukalapak
# lakukan : laku
# awas : awas
# sepengetahuan : tahu
# ovo : ovo
# persyaratannya : syarat
# mempermudah : mudah
# perlukandengan : perlukandengan
# simple : simple
# sampenya : sampenya
# responnya : responnya
# darurat : darurat
# jamin : jamin
# klianynk : klianynk
# kerjaana : kerjaana
# numpuk : numpuk
# brang : brang
# impian : impi
# ples : ples
# torrr : torrr
# belanjaehh : belanjaehh
# bataltdk : bataltdk
# ongkirdan : ongkirdan
# terbatas : batas
# rbaiki : rbaiki
# secepat : cepat
# claim : claim
# rumit : rumit
# ikhlas : ikhlas
# nabung : nabung
# nabungnya : nabungnya
# sayasdh : sayasdh
# initdk : initdk
# voc : voc
# kirm : kirm
# tabunganny : tabunganny
# blsuka : blsuka
# pakaiini : pakaiini
# bagaimanavoc : bagaimanavoc
# menyesalkan : sesal
# pemutusannya : putus
# ditawarkan : tawar
# belanjanyasukses : belanjanyasukses
# bukalapaksekarang : bukalapaksekarang
# wallet : wallet
# redeem : redeem
# codenya : codenya
# teman : teman
# penipuansya : penipuansya
# keterangannyayah : keterangannyayah
# maksudnya : maksud
# bantuannyaoiiii : bantuannyaoiiii
# sayaaaaaa : sayaaaaaa
# terpercayatercepat : terpercayatercepat
# gunakansukses : gunakansukses
# berkualitas : kualitas
# terjangkau : jangkau
# gantihilang : gantihilang
# dableg : dableg
# tahi : tahi
# samapai : samapai
# hoyy : hoyy
# lo : lo
# mengurusi : urus
# setan : setan
# belanjaada : belanjaada
# nyatp : nyatp
# mencukupi : cukup
# transaksiversi : transaksiversi
# bisasisany : bisasisany
# opsi : opsi
# dicetak : cetak
# helooo : helooo
# syaa : syaa
# buyer : buyer
# driver : driver
# friendly : friendly
# menyulitkan : sulit
# bukareksauang : bukareksauang
# setatusy : setatusy
# selesaidikomplen : selesaidikomplen
# transfermasuk : transfermasuk
# jawabpaylater : jawabpaylater
# rusuhmasih : rusuhmasih
# belbel : belbel
# terusruwed : terusruwed
# memutar : putar
# vidio : vidio
# flashdeal : flashdeal
# belinya : beli
# shake : shake
# thon : thon
# dapatnya : dapat
# thx : thx
# ekpedisi : ekpedisi
# quicksend : quicksend
# express : express
# serba : serba
# tokonya : toko
# josss : josss
# dipahami : paham
# menguntungkan : untung
# nyakita : nyakita
# sarankan : saran
# bangettdk : bangettdk
# nyambunganeh : nyambunganeh
# notifnyaslesai : notifnyaslesai
# digunakangak : digunakangak
# tren : tren
# nik : nik
# angkun : angkun
# tertua : tua
# inovasi : inovasi
# satusatunya : satusatunya
# berfungsihatihati : berfungsihatihati
# xufsinv : xufsinv
# melebihi : lebih
# dbatalkan : dbatalkan
# jelasjelas : jelasjelas
# terbuka : buka
# updatenya : updatenya
# punyeng : punyeng
# disaat : saat
# permintaan : minta
# penjualanpembatalan : penjualanpembatalan
# nyanotif : nyanotif
# pencariannya : cari
# ikan : ikan
# hias : hias
# pakan : pakan
# ganggu : ganggu
# tampil : tampil
# varian : varian
# keterangannya : terang
# memiliki : milik
# tipe : tipe
# nginput : nginput
# apanya : apa
# disamainnnnn : disamainnnnn
# dibalas : balas
# dm : dm
# ig : ig
# digubris : gubris
# sptnya : sptnya
# minada : mada
# undang : undang
# permasalahn : permasalahn
# bual : bual
# adakan : adakan
# request : request
# awam : awam
# minusnya : minus
# memenuhi : penuh
# ramadhan : ramadhan
# posting : posting
# april : april
# simpan : simpan
# gudang : gudang
# merchant : merchant
# wilyah : wilyah
# timur : timur
# ribuan : ribu
# fer : fer
# jadikan : jadi
# halooooo : halooooo
# biji : biji
# pajaknya : pajak
# royal : royal
# jadul : jadul
# ditinggalkan : tinggal
# fiturnya : fiturnya
# banyaktidak : banyaktidak
# bukabantuannya : bukabantuannya
# ninja : ninja
# expres : expres
# berpuluh : puluh
# puluh : puluh
# dilacak : lacak
# sukur : sukur
# mematikan : mati
# obrolannya : obrol
# hangus : hangus
# kyc : kyc
# sory : sory
# ane : ane
# join : join
# dipilih : pilih
# zonk : zonk
# kepercayan : kepercayan
# ecom : ecom
# aktifasi : aktifasi
# sumpah : sumpah
# enek : enek
# sefty : sefty
# nyataanya : nyataanya
# nomornya : nomor
# aktivasi : aktivasi
# syaratnya : syarat
# sumpaah : sumpaah
# oohh : oohh
# devlover : devlover
# lebay : lebay
# dikirimkan : kirim
# ktprekening : ktprekening
# seribet : seribet
# cantumin : cantumin
# diubah : ubah
# berulangulang : berulangulang
# wadew : wadew
# blank : blank
# tandatanda : tandatanda
# berjamjam : berjamjam
# sore : sore
# biarkan : biar
# tipenyasaya : tipenyasaya
# gonta : gonta
# basah : basah
# basih : basih
# custumer : custumer
# servicenya : servicenya
# ditangguhkan : tangguh
# sunguh : sunguh
# menyimpan : simpan
# menghindari : hindar
# menunya : menu
# pahami : paham
# lemottnya : lemottnya
# problemnya : problem
# bad : bad
# gateway : gateway
# kayaknya : kayak
# investasi : investasi
# dibikin : bikin
# emak : emak
# lato : lato
# swafoto : swafoto
# kiri : kiri
# pegang : pegang
# buku : buku
# bantuin : bantuin
# repot : repot
# kartu : kartu
# kredit : kredit
# warning : warning
# sistemnyasya : sistemnyasya
# sellerkenapa : sellerkenapa
# pencariandi : pencariandi
# tracking : tracking
# validbanyak : validbanyak
# pembelitapi : pembelitapi
# trackingnya : trackingnya
# percepat : cepat
# marketpkace : marketpkace
# didownload : didownload
# touch : touch
# az : az
# list : list
# profile : profile
# ditampilkan : tampil
# halah : halah
# mengembalikan : kembali
# ajabanyak : ajabanyak
# sisrem : sisrem
# gunabuka : gunabuka
# ajaisi : ajaisi
# harap : harap
# ajadan : ajadan
# bagusmasuk : bagusmasuk
# ribetnya : ribetnya
# menilai : nilai
# kemunduran : mundur
# ratingnya : ratingnya
# cumq : cumq
# temukan : temu
# gaya : gaya
# pengunjung : unjung
# kadaluarsamau : kadaluarsamau
# nonaktif : nonaktif
# dear : dear
# check : check
# posisi : posisi
# pesana : sana
# perhatiannya : perhati
# menggangu : menggangu
# dengar : dengar
# mls : mls
# bhulshittt : bhulshittt
# garansi : garansi
# tipu : tipu
# tipunya : tipu
# claimnya : claimnya
# default : default
# berkahh : berkahh
# siasat : siasat
# mnjamingaransi : mnjamingaransi
# terkocak : kocak
# eneg : eneg
# dengernya : dengernya
# blokir : blokir
# badut : badut
# beban : beban
# and : and
# dipiara : piara
# bermanfaat : manfaat
# sekalibegitu : sekalibegitu
# verif : verif
# passwordklik : passwordklik
# bisagimana : bisagimana
# traktiran : traktir
# debitnya : debit
# knyatanya : knyatanya
# akunnya : akun
# hoax : hoax
# tengkyuu : tengkyuu
# dijamin : jamin
# ktpreffvral : ktpreffvral
# btbldkzqvt : btbldkzqvt
# nyaaplikasii : nyaaplikasii
# lamasangat : lamasangat
# dikala : kala
# belanjatinggal : belanjatinggal
# bayarbarang : bayarbarang
# membaiktengkyuuu : membaiktengkyuuu
# angsuran : angsur
# sajadan : sajadan
# aktifharus : aktifharus
# belanjabrg : belanjabrg
# dalem : dalem
# detik : detik
# canggih : canggih
# sadah : sadah
# kembaliini : kembaliini
# kepastianpayah : kepastianpayah
# sudahlama : sudahlama
# kayanya : kaya
# presiden : presiden
# standby : standby
# lokasi : lokasi
# dihalaman : halaman
# ngalami : ngalami
# mendingan : mending
# ngalamin : ngalamin
# variannya : varian
# dipermudah : mudah
# fleksibel : fleksibel
# monoton : monoton
# disesuaikan : sesuai
# size : size
# real : real
# nurut : nurut
# promoted : promoted
# snapdragon : snapdragon
# gen : gen
# ram : ram
# gb : gb
# clear : clear
# chace : chace
# logout : logout
# server : server
# drastis : drastis
# keperluan : perlu
# mendesak : desak
# pinjam : pinjam
# tetangga : tetangga
# berbelanjatapi : berbelanjatapi
# dam : dam
# halapalagi : halapalagi
# bisaselalu : bisaselalu
# lengkapi : lengkap
# chapta : chapta
# lulus : lulus
# promot : promot
# ngitung : ngitung
# utang : utang
# penjumlahan : jumlah
# mines : mes
# hutang : hutang
# sistemnyakecewa : sistemnyakecewa
# pemilihan : pilih
# report : report
# bermasalahpaket : bermasalahpaket
# jadwal : jadwal
# kompensasi : kompensasi
# jaminan : jamin
# kembalihanya : kembalihanya
# slogan : slogan
# belakabagaimana : belakabagaimana
# ajalihat : ajalihat
# history : history
# mainnumpuk : mainnumpuk
# diserver : diserver
# akunbuatlah : akunbuatlah
# penyimpanan : simpan
# inikasih : inikasih
# bgtkasihan : bgtkasihan
# dongharusnya : dongharusnya
# max : max
# haribukanya : haribukanya
# pembelimenurut : pembelimenurut
# bukalapakklo : bukalapakklo
# pesananmereka : pesananmereka
# sendiridan : sendiridan
# kirimkanentah : kirimkanentah
# lupaatau : lupaatau
# readymohon : readymohon
# lagibuat : lagibuat
# buset : buset
# ditemukan : temu
# hebat : hebat
# lenya : lenya
# manapun : mana
# fee : fee
# lainnyamataap : lainnyamataap
# gunawan : gunawan
# rumitpadahal : rumitpadahal
# mengadukan : adu
# refaund : refaund
# prosespadahal : prosespadahal
# kabar : kabar
# review : review
# dok : dok
# prosez : prosez
# melampirkan : lampir
# nampaklah : nampaklah
# nota : nota
# bene : bene
# krusial : krusial
# dmpak : dmpak
# securitynya : securitynya
# oran : oran
# paylter : paylter
# betmen : betmen
# harapan : harap
# kecewadimana : kecewadimana
# menyediakan : sedia
# codtapi : codtapi
# menyesak : sesak
# sgitu : sgitu
# tuhklo : tuhklo
# kepakasa : kepakasa
# saking : saking
# seharus : harus
# php : php
# kesempatan : sempat
# brengsek : brengsek
# dajjal : dajjal
# google : google
# mini : mini
# periode : periode
# maret : maret
# payleater : payleater
# bukalapaksaya : bukalapaksaya
# tagih : tagih
# lagibukti : lagibukti
# struknya : struknya
# kasir : kasir
# indomart : indomart
# yeah : yeah
# tagihantapi : tagihantapi
# memberatkan : berat
# itemku : item
# higs : higs
# domino : domino
# menerapkan : terap
# peforma : forma
# huhuhuuuuu : huhuhuuuuu
# sekaliterutama : sekaliterutama
# pajak : pajak
# melunasi : lunas
# ditinjau : tinjau
# dc : dc
# screen : screen
# shot : shot
# menagih : tagih
# ditindak : tindak
# lanjuti : lanjut
# telkom : telkom
# wib : wib
# shrusnya : shrusnya
# fitr : fitr
# lngsng : lngsng
# sosial : sosial
# media : media
# penggunannya : gun
# hai : hai
# bukal : bukal
# pcs : pcs
# parsel : parsel
# rumah : rumah
# curi : curi
# sebagia : sebagia
# sah : sah
# porum : porum
# notip : notip
# transparan : transparan
# pilihannya : pilih
# januari : januari
# jugasudah : jugasudah
# tanggapi : tanggap
# bukalapaksungguh : bukalapaksungguh
# ribeettt : ribeettt
# reg : reg
# next : next
# day : day
# lelet : lelet
# criss : criss
# cross : cross
# sop : sop
# ybs : ybs
# kepercayaan : percaya
# bari : bari
# gaib : gaib
# meningkatkan : tingkat
# mengajak : ajak
# keranjang : keranjang
# way : way
# mantapharga : mantapharga
# ringan : ringan
# dibanding : banding
# lainpadahal : lainpadahal
# kualitasnya : kualitas
# melaporkan : lapor
# feedbacknya : feedbacknya
# asik : asik
# kepuasan : puas
# bltp : bltp
# perlahan : perlahan
# lainselain : lainselain
# rendah : rendah
# beragamdi : beragamdi
# tawarkn : tawarkn
# ketikcari : ketikcari
# terburuk : buruk
# uaah : uaah
# terbaikresponship : terbaikresponship
# foucher : foucher
# kirimjt : kirimjt
# digunakanpadahal : digunakanpadahal
# adagimana : adagimana
# gan : gan
# banya : banya
# kompalin : kompalin
# mantulll : mantulll
# very : very
# gus : gus
# diriwayat : riwayat
# standar : standar
# aneka : aneka
# mudahmudahan : mudahmudahan
# bagusmemuaskan : bagusmemuaskan
# membutuhkan : butuh
# sebentar : sebentar
# chattingan : chattingan
# cash : cash
# lom : lom
# jawabannyacoba : jawabannyacoba
# tanggepin : tanggepin
# tlong : tlong
# tentui : tentu
# jgbuat : jgbuat
# bantumakin : bantumakin
# chatlemot : chatlemot
# lag : lag
# memperbaiki : baik
# memesan : mes
# rokok : rokok
# pindahkan : pindah
# scroll : scroll
# kenpa : kenpa
# yaakun : yaakun
# why : why
# gunakanauto : gunakanauto
# uninstaljika : uninstaljika
# ...
# kebagusannya : bagus
# selfie : selfie
# oknum : oknum
# memgecewakan : memgecewakan
# biargak : biargak
# biargesit : biargesit
# dicairkan : cair
# contact : contact
# maa : maa
# komunikatif : komunikatif
# please : please
# mantapsudah : mantapsudah
# bagussesuai : bagussesuai
# crash : crash
# tawarkan : tawar
# pengusaha : usaha
# bijak : bijak
# bagussemua : bagussemua
# rillrespon : rillrespon
# cepatpuas : cepatpuas
# najis : najis
# terpercayasemua : terpercayasemua
# adajelascepat : adajelascepat
# bgtmantep : bgtmantep
# arahan : arah
# bebarapa : bebarapa
# chattapi : chattapi
# memutus : putus
# etika : etika
# tuntutan : tuntut
# re : re
# kebukapas : kebukapas
# tap : tap
# barangselalu : barangselalu
# awaldan : awaldan
# animasi : animasi
# berlaripayah : berlaripayah
# perbaikisaya : perbaikisaya
# mantul : mantul
# tokotoko : tokotoko
# mengecewakanmasa : mengecewakanmasa
# lazadadi : lazadadi
# reload : reload
# berabe : berabe
# diperbaikisoalnya : diperbaikisoalnya
# dimanfaatkan : manfaat
# ordreran : ordreran
# ekspedisikarna : ekspedisikarna
# lemoot : lemoot
# aplikasinyatolong : aplikasinyatolong
# lainudh : lainudh
# perantara : antara
# berintegritas : integritas
# tidk : tidk
# keinginanpesanan : keinginanpesanan
# dinamika : dinamika
# kasat : kasat
# diandalkanayo : diandalkanayo
# secepatnyananti : secepatnyananti
# ketinggalankita : ketinggalankita
# surat : surat
# sistemkurang : sistemkurang
# dijadikan : jadi
# formitu : formitu
# masalahnyajawaban : masalahnyajawaban
# lamawaalaaeh : lamawaalaaeh
# berterimakasih : berterimakasih
# aksesnya : akses
# penyampaian : sampai
# materinya : materi
# terperincipelatihannya : terperincipelatihannya
# pahamisangat : pahamisangat
# sayatrimakasih : sayatrimakasih
# pembelajaran : ajar
# prakerjasaya : prakerjasaya
# menerangkan : terang
# terjun : terjun
# freelancer : freelancer
# nampilin : nampilin
# terpopuler : populer
# komparasi : komparasi
# puaskanpengunaan : puaskanpengunaan
# carisaya : carisaya
# pohon : pohon
# gabung : gabung
# rejekiroda : rejekiroda
# kunjung : kunjung
# rentang : rentang
# kadauwarsa : kadauwarsa
# keuangannya : uang
# disayangkan : sayang
# optimal : optimal
# rajin : rajin
# traksaksi : traksaksi
# kaliklo : kaliklo
# terjangkauongkos : terjangkauongkos
# diskripsi : skripsi
# shaller : shaller
# berhubung : hubung
# newbie : newbie
# ringansekarang : ringansekarang
# hitam : hitam
# duluterus : duluterus
# merespongak : merespongak
# aplikasibiar : aplikasibiar
# menengah : tengah
# terbawa : bawa
# pebaharui : baharu
# username : username
# minus : minus
# etc : etc
# instant : instant
# itulahpantes : itulahpantes
# balas : balas
# arahin : arahin
# blidappreview : blidappreview
# blnya : blnya
# berbenti : berbenti
# dibagian : bagi
# gunakanpadahal : gunakanpadahal
# lunastransakasi : lunastransakasi
# teruscoba : teruscoba
# sparepart : sparepart
# otomotif : otomotif
# inden : inden
# ngurut : ngurut
# ngacak : ngacak
# dibobol : bobol
# phising : phising
# tentukan : tentu
# faylaternya : faylaternya
# bisah : bisah
# diberanda : beranda
# judulnya : judul
# shoponline : shoponline
# dikemas : kemas
# iti : iti
# diperhatikan : perhati
# abang : abang
# ekspedisinya : ekspedisi
# diganti : ganti
# diupgrade : diupgrade
# penyedot : sedot
# lemotblengga : lemotblengga
# inikayak : inikayak
# xxxxx : xxxxx
# mark : mark
# tarif : tarif
# gerai : gerai
# pembeliannya : beli
# menyempatkan : sempat
# siasia : siasia
# naikkan : naik
# dalamapa : dalamapa
# bongkaran : bongkar
# higgs : higgs
# dominosaya : dominosaya
# susahcukup : susahcukup
# pembelijangan : pembelijangan
# dulususah : dulususah
# komfirmasi : komfirmasi
# enggan : enggan
# perpaling : paling
# menghalangi : halang
# ditemui : temu
# laih : laih
# dipertimbangkan : timbang
# survey : survey
# berkaitan : kait
# pecah : pecah
# telur : telur
# rusakkomplainnya : rusakkomplainnya
# sepadan : padan
# hasilnyakarna : hasilnyakarna
# klaimkomplain : klaimkomplain
# rusaknya : rusak
# ekspedisimemang : ekspedisimemang
# kitauntuk : kitauntuk
# adminya : adminya
# bocor : bocor
# korbanya : korbanya
# ongkirturunin : ongkirturunin
# milim : milim
# cepatmantap : cepatmantap
# seharihari : seharihari
# pesanannya : pesan
# tindakan : tindak
# perbelanjaan : belanja
# terbantukanbelanja : terbantukanbelanja
# sykenapa : sykenapa
# didana : dana
# dipakaipadahal : dipakaipadahal
# donlod : donlod
# lm : lm
# lolos : lolos
# membagongkan : bagong
# bhahaha : bhahaha
# assalamualaikum : assalamualaikum
# wrwb : wrwb
# menyelesaikannya : selesai
# sertifikat : sertifikat
# dashboart : dashboart
# kasihbukalapak : kasihbukalapak
# mengembangan : kembang
# bukalapan : bukalapan
# ranting : ranting
# topselernyata : topselernyata
# ndk : ndk
# bisauang : bisauang
# ditranfer : ditranfer
# lagisudah : lagisudah
# responrelakan : responrelakan
# lestari : lestari
# jakbar : jakbar
# mengemas : emas
# cempaka : cempaka
# akibatnya : akibat
# pinasa : pinasa
# bekasi : bekas
# kaos : kaos
# termaksud : maksud
# deploper : deploper
# menghubungkan : hubung
# dihubungiseolaholah : dihubungiseolaholah
# paketan : paket
# benci : benci
# dengarkan : dengar
# cinta : cinta
# saka : saka
# tercepat : cepat
# sekarangmalesbosen : sekarangmalesbosen
# keselkarena : keselkarena
# perbaharui : baharu
# leletlemotkayak : leletlemotkayak
# siput : siput
# mabuktolong : mabuktolong
# perbaikidan : perbaikidan
# terbarutapi : terbarutapi
# bisatrims : bisatrims
# novita : novita
# sari : sari
# peserta : serta
# mentor : mentor
# memotivasi : motivasi
# wawasan : wawas
# mengembangkan : kembang
# potensi : potensi
# miliki : milik
# membelih : membelih
# berjudul : judul
# kuasai : kuasa
# berbicara : bicara
# nlp : nlp
# pelatihannya : latih
# ditoko : toko
# orangehijau : orangehijau
# optimalkan : optimal
# deal : deal
# jenis : jenis
# optimalisasi : optimalisasi
# membentuk : bentuk
# luas : luas
# mobil : mobil
# filternya : filter
# ikonik : ikonik
# vita : vita
# membelinya : bel
# tema : tema
# menarikedukatif : menarikedukatif
# inspiratif : inspiratif
# pengirimankedepanya : pengirimankedepanya
# pdam : pdam
# dipercepat : cepat
# tanggalnya : tanggal
# pencarinya : pencar
# difilter : filter
# lakunya : laku
# bgtpadahal : bgtpadahal
# bekasipake : bekasipake
# cacat : cacat
# kamera : kamera
# memotret : potret
# hptidak : hptidak
# familiar : familiar
# dropshiper : dropshiper
# supplier : supplier
# mengaktifkan : aktif
# menonaktifkan : nonaktif
# respone : respone
# diatasi : atas
# oiya : oiya
# bugbuka : bugbuka
# lamamasuk : lamamasuk
# lamake : lamake
# iconnya : iconnya
# perbarui : baru
# ahjgn : ahjgn
# inigak : inigak
# kencang : kencang
# tulisanmu : tulis
# down : down
# cobalagi : cobalagi
# terusmenjengkelkan : terusmenjengkelkan
# tokosebelah : tokosebelah
# pelangganny : pelangganny
# kejutan : kejut
# fiturfitur : fiturfitur
# bervariatif : variatif
# frakerja : frakerja
# bahasanya : bahasa
# rinci : rinci
# kemenaker : kemenaker
# terbantudengan : terbantudengan
# ilmu : ilmu
# amananpesana : amananpesana
# raib : raib
# susahtolong : susahtolong
# prkmbangn : prkmbangn
# pningktn : pningktn
# seprti : seprti
# duluagak : duluagak
# print : print
# piye : piye
# jal : jal
# surantap : surantap
# nol : nol
# rupiah : rupiah
# terimakasi : terimakasi
# bukalapakdengan : bukalapakdengan
# bukalapakjangan : bukalapakjangan
# terkahir : terkahir
# perekonomian : ekonomi
# bukalpak : bukalpak
# babiknpa : babiknpa
# reksadana : reksadana
# kampreeeet : kampreeeet
# lumyan : lumyan
# lengkapharga : lengkapharga
# telpon : telpon
# padalan : padalan
# bukabantuanya : bukabantuanya
# kitaterima : kitaterima
# sejarahbuktiin : sejarahbuktiin
# sendirikalah : sendirikalah
# sebelahjoos : sebelahjoos
# kebukatolong : kebukatolong
# bukalapa : bukalapa
# terdepan : depan
# pelayananya : pelayananya
# responterima : responterima
# pilihannyacuma : pilihannyacuma
# alau : alau
# outcaranya : outcaranya
# barangtp : barangtp
# bagusisinya : bagusisinya
# adajooossss : adajooossss
# mengembirakan : mengembirakan
# ekspetasi : ekspetasi
# ektp : ektp
# blur : blur
# frame : frame
# teus : teus
# cepatsangat : cepatsangat
# komisi : komisi
# kab : kab
# kediri : diri
# fif : fif
# adira : adira
# cetak : cetak
# bluetooth : bluetooth
# kasirnya : kasir
# terintegrasi : integrasi
# keamanannya : aman
# diprioritaskan : prioritas
# lampiran : lampir
# negatif : negatif
# ive : ive
# idea : idea
# datanya : data
# coin : coin
# kecepatan : cepat
# tujuanya : tujuanya
# hangusnya : hangus
# panjangin : panjangin
# variatif : variatif
# salin : salin
# paste : paste
# lainkali : lainkali
# diperuntukkan : untuk
# pendapat : dapat
# bangsa : bangsa
# masyarakan : masyarakan
# warungwarung : warungwarung
# sesi : sesi
# indonesiabukalapak : indonesiabukalapak
# digunakanitu : digunakanitu
# dulusekarang : dulusekarang
# kecewakomplain : kecewakomplain
# berteletelepembelian : berteletelepembelian
# saldodanabisa : saldodanabisa
# rekeningribetjadi : rekeningribetjadi
# bintangnyamaafmau : bintangnyamaafmau
# balikhadeuhh : balikhadeuhh
# memory : memory
# hpko : hpko
# belik : belik
# kepepet : pepet
# ribut : ribut
# bangetlah : banget
# instruksi : instruksi
# dltingkatin : dltingkatin
# imbang : imbang
# adm : adm
# bulanannya : bulan
# utamakan : utama
# merah : merah
# bendera : bendera
# jingga : jingga
# cintai : cinta
# karya : karya
# didaftarin : didaftarin
# punyasekalipun : punyasekalipun
# indomartalfamart : indomartalfamart
# mala : mala
# pemaksaan : paksa
# bagusbanyakin : bagusbanyakin
# mencret : mencret
# we : we
# penasaran : penasaran
# rentenir : rentenir
# kelewatan : lewat
# lembagalembaga : lembagalembaga
# slowrespon : slowrespon
# cadangan : cadang
# faktor : faktor
# lzd : lzd
# fastrespon : fastrespon
# dikembangkan : kembang
# pencantuman : cantum
# baju : baju
# lengan : lengan
# pendek : pendek
# inbox : inbox
# lagharus : lagharus
# telkomsel : telkomsel
# lanjay : lanjay
# beritahuakan : beritahuakan
# yaadi : yaadi
# xsetelah : xsetelah
# tercantumini : tercantumini
# melayang : layang
# kabarsangat : kabarsangat
# burukpenipuan : burukpenipuan
# mengedukasi : edukasi
# pola : pola
# gagasan : gagas
# pikiran : pikir
# uturakan : uturakan
# bukapalak : bukapalak
# dikartu : kartu
# komunikasi : komunikasi
# menunjang : tunjang
# karir : karir
# sh : sh
# pee : pee
# onlen : onlen
# aktual : aktual
# dominan : dominan
# over : over
# perlukan : perlu
# ongir : ongir
# acuh : acuh
# puluhan : puluh
# cuek : cuek
# tanggapannya : tanggap
# lemah : lemah
# taii : taii
# rekomendasikan : rekomendasi
# penerapan : terap
# midtrans : midtrans
# lempar : lempar
# mnit : mnit
# kill : kill
# process : process
# digagalkan : gagal
# pengambilan : ambil
# keping : keping
# gram : gram
# memajukan : maju
# dipoto : dipoto
# disisni : disisni
# hilangsaya : hilangsaya
# mengubah : ubah
# smswa : smswa
# karenasempet : karenasempet
# telpwa : telpwa
# salenya : sale
# internkaryawan : internkaryawan
# buktinya : bukti
# mengaku : aku
# persetujuan : tuju
# baguskarena : baguskarena
# hpseharusnya : hpseharusnya
# lagiklau : lagiklau
# membayarnyamisalkan : membayarnyamisalkan
# atmno : atmno
# bankklau : bankklau
# agr : agr
# lagimksih : lagimksih
# minkemaren : minkemaren
# linkajatetapi : linkajatetapi
# berhasilehh : berhasilehh
# semalam : malam
# pembayarangimana : pembayarangimana
# linkaja : linkaja
# hmmm : hmmm
# mincs : mincs
# mepersulit : mepersulit
# melakukakan : melakukakan
# kontakcall : kontakcall
# berinteraksi : interaksi
# matiin : matiin
# eroor : eroor
# pemainnya : main
# standart : standart
# pemain : main
# aslinya : asli
# uninsntall : uninsntall
# sebelmnya : sebelmnya
# menjengkelkan : jengkel
# rada : rada
# dihadapi : hadap
# bukadanabukadompet : bukadanabukadompet
# bukadana : bukadana
# dinaikin : dinaikin
# olah : olah
# pesaing : saing
# memahami : paham
# blankgak : blankgak
# bukaoia : bukaoia
# osaplikay : osaplikay
# apalokasi : apalokasi
# jaringanyang : jaringanyang
# uptodatejadi : uptodatejadi
# perbaikilah : baik
# lapaksudah : lapaksudah
# paylaternyakatanya : paylaternyakatanya
# mnurun : mnurun
# jayapura : jayapura
# dijangkau : jangkau
# kualitasmu : kualitas
# drop : drop
# matang : matang
# orkirnya : orkirnya
# seimbang : imbang
# beliberani : beliberani
# orkir : orkir
# panjual : panjual
# weekend : weekend
# is : is
# tagihannya : tagih
# ngegantung : ngegantung
# kebijakannya : bijak
# mengetiktdk : mengetiktdk
# algoritmanya : algoritmanya
# kembangkan : kembang
# date : date
# pengiklanan : iklan
# bisatidak : bisatidak
# fungsinya : fungsi
# initerahir : initerahir
# updatesetelah : updatesetelah
# belangganan : banggan
# dalemnya : dalem
# even : even
# serbunya : serbu
# ngrestart : ngrestart
# kenyamana : kenyamana
# dilesan : les
# dikirimnya : kirim
# bukunya : buku
# sebatas : batas
# padahalkan : padahal
# jarak : jarak
# bepergian : pergi
# ngebug : ngebug
# double : double
# ilfil : ilfil
# {'aplikasi': 'aplikasi', 'marketplace': 'marketplace', 'hancur': 'hancur', 'sistem': 'sistem', 'bukabantuan': 'bukabantuan', 'selesain': 'selesain', 'lari': 'lari', 'live': 'live', 'chatnya': 'chatnya', 'paylaternya': 'paylaternya', 'bobrok': 'bobrok', 'silakan': 'sila', 'dicoba': 'coba', 'download': 'download', 'tau': 'tau', 'ribet': 'ribet', 'edit': 'edit', 'produk': 'produk', 'giliran': 'gilir', 'berhasil': 'hasil', 'ujung': 'ujung', 'nya': 'nya', 'iklan': 'iklan', 'dijual': 'jual', 'hilang': 'hilang', 'alias': 'alias', 'otomatis': 'otomatis', 'dihapus': 'hapus', 'bukalapak': 'bukalapak', 'tolong': 'tolong', 'ditingkatkan': 'tingkat', 'ulang': 'ulang', 'sistemnya': 'sistem', 'penjual': 'jual', 'pembeli': 'beli', 'meninggalkan': 'tinggal', 'buka': 'buka', 'bantuan': 'bantu', 'berguna': 'guna', 'dihubungi': 'hubung', 'transaksi': 'transaksi', 'penjualan': 'jual', 'barang': 'barang', 'dikirim': 'kirim', 'kurir': 'kurir', 'wahana': 'wahana', 'resi': 'resi', 'diupdate': 'diupdate', 'batal': 'batal', 'hubungi': 'hubung', 'update': 'update', 'dicek': 'cek', 'manual': 'manual', 'perjalanan': 'jalan', 'sedih': 'sedih', 'belanja': 'belanja', 'mitra': 'mitra', 'andalkan': 'andal', 'batalkan': 'batal', 'terima': 'terima', 'pikir': 'pikir', 'kalo': 'kalo', 'pakai': 'pakai', 'cod': 'cod', 'mengerikan': 'keri', 'diangap': 'diangap', 'penjahat': 'jahat', 'main': 'main', 'bekukan': 'beku', 'akun': 'akun', 'orang': 'orang', 'kredivo': 'kredivo', 'dibekukan': 'beku', 'akulaku': 'akulaku', 'hati': 'hati', 'sayang': 'sayang', 'mending': 'mending', 'toped': 'toped', 'aman': 'aman', 'nyaman': 'nyaman', 'minim': 'minim', 'jahat': 'jahat', 'jual': 'jual', 'beli': 'beli', 'online': 'online', 'kerenfitur': 'kerenfitur', 'lengkap': 'lengkap', 'metode': 'metode', 'pembayaran': 'bayar', 'komplit': 'komplit', 'pesanan': 'pesan', 'cepat': 'cepat', 'kirimdan': 'kirimdan', 'lapak': 'lapak', 'jualan': 'jual', 'mudahsemoga': 'mudahsemoga', 'depannya': 'depan', 'simpel': 'simpel', 'memudahkan': 'mudah', 'seller': 'seller', 'pembeligood': 'pembeligood', 'luck': 'luck', 'kena': 'kena', 'charge': 'charge', 'rp': 'rp', 'roda': 'roda', 'keberuntungan': 'untung', 'puter': 'puter', 'item': 'item', 'top': 'top', 'up': 'up', 'money': 'money', 'pesan': 'pesan', 'tiket': 'tiket', 'kereta': 'kereta', 'api': 'api', 'membantusaat': 'membantusaat', 'pulsatoken': 'pulsatoken', 'listrik': 'listrik', 'kebutuhan': 'butuh', 'mengatasi': 'atas', 'cepatsemua': 'cepatsemua', 'teratasi': 'atas', 'memuaskanmaju': 'memuaskanmaju', 'inovatif': 'inovatif', 'membantu': 'bantu', 'bayar': 'bayar', 'depantapi': 'depantapi', 'biaya': 'biaya', 'admin': 'admin', 'ribu': 'ribu', 'bulannya': 'bulan', 'paylater': 'paylater', 'pakaiklo': 'pakaiklo', 'ilangin': 'ilangin', 'yalimit': 'yalimit', 'bos': 'bos', 'rugikan': 'rugi', 'dana': 'dana', 'bayarkan': 'bayar', 'via': 'via', 'atm': 'atm', 'bri': 'bri', 'struk': 'struk', 'saldo': 'saldo', 'masuk': 'masuk', 'berhenti': 'henti', 'menunggu': 'tunggu', 'memperaulitcall': 'memperaulitcall', 'center': 'center', 'terkesan': 'kes', 'malas': 'malas', 'menanggapi': 'tanggap', 'keluhan': 'keluh', 'pelanggansemua': 'pelanggansemua', 'persyaratan': 'syarat', 'dibpenuhichat': 'dibpenuhichat', 'alihkanni': 'alihkanni', 'bantuanmemalukan': 'bantuanmemalukan', 'bermasalahga': 'bermasalahga', 'pertqma': 'pertqma', 'pertamani': 'taman', 'kemari': 'kemari', 'parahcall': 'parahcall', 'centernya': 'centernya', 'pelatihan': 'latih', 'nihbuat': 'nihbuat', 'pelanggan': 'langgan', 'tuh': 'tuh', 'apl': 'apl', 'sngat': 'sngat', 'customer': 'customer', 'pengalaman': 'alam', 'terbukti': 'bukti', 'dibeli': 'beli', 'sesuai': 'sesuai', 'gambar': 'gambar', 'video': 'video', 'deskripsinya': 'deskripsi', 'sukses': 'sukses', 'indonesia': 'indonesia', 'merugikan': 'rugi', 'masak': 'masak', 'barangnya': 'barang', 'dibayar': 'bayar', 'nunggunya': 'nunggunya', 'dibatalkan': 'batal', 'uang': 'uang', 'dikembalikan': 'kembali', 'rbuan': 'rbuan', 'alasan': 'alas', 'ongkir': 'ongkir', 'jasa': ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/1300 [00:00<?, ?it/s]

# %%
name_dataframe["Ulasan_siap"] = [' '.join(map(str, l)) for l in name_dataframe['Ulasan_Stemmed']]

# %%
name_dataframe.to_excel("bukalapak.xlsx")

# %%
ulasan = ' '.join(str(v) for v in name_dataframe['Ulasan_siap'])

# %%
tokenize_ulasan = word_tokenize(ulasan)

# %%
tokenize_ulasan
# Out:
# ['aplikasi',
#  'marketplace',
#  'hancur',
#  'sistem',
#  'bukabantuan',
#  'selesain',
#  'lari',
#  'live',
#  'chatnya',
#  'sistem',
#  'paylaternya',
#  'bobrok',
#  'sila',
#  'coba',
#  'download',
#  'tau',
#  'aplikasi',
#  'ribet',
#  'edit',
#  'produk',
#  'gilir',
#  'hasil',
#  'ujung',
#  'nya',
#  'iklan',
#  'produk',
#  'jual',
#  'hilang',
#  'alias',
#  'otomatis',
#  'hapus',
#  'bukalapak',
#  'tolong',
#  'tingkat',
#  'ulang',
#  'sistem',
#  'jual',
#  'beli',
#  'tinggal',
#  'aplikasi',
#  'buka',
#  'bantu',
#  'bukalapak',
#  'guna',
#  'hubung',
#  'transaksi',
#  'jual',
#  'barang',
#  'kirim',
#  'kurir',
#  'wahana',
#  'resi',
#  'otomatis',
#  'diupdate',
#  'sistem',
#  'bukalapak',
#  'transaksi',
#  'batal',
#  'otomatis',
#  'hubung',
#  'buka',
#  'bantu',
#  'update',
#  'resi',
#  'cek',
#  'manual',
#  'barang',
#  'kirim',
#  'jalan',
#  'sedih',
#  'belanja',
#  'mitra',
#  'bukalapak',
#  'live',
#  'bukabantuan',
#  'andal',
#  'transaksi',
#  'batal',
#  'terima',
#  'barang',
#  'pikir',
#  'kalo',
#  'transaksi',
#  'pakai',
#  'cod',
#  'keri',
#  'belanja',
#  'bukalapak',
#  'beli',
#  'diangap',
#  'jahat',
#  'main',
#  'beku',
#  'akun',
#  'orang',
#  'akun',
#  'kredivo',
#  'beku',
#  'akun',
#  'akulaku',
#  'beku',
#  'jahat',
#  'beli',
#  'jual',
#  'hati',
#  'hati',
#  'belanja',
#  'bukalapak',
#  'pakai',
#  'kredivo',
#  'akulaku',
#  'sayang',
#  'akun',
#  'mending',
#  'belanja',
#  'toped',
#  'aman',
#  'nyaman',
#  'minim',
#  'jual',
#  'jahat',
#  'bukalapak',
#  'aplikasi',
#  'jual',
#  'beli',
#  'online',
#  'kerenfitur',
#  'nya',
#  'lengkap',
#  'metode',
#  'bayar',
#  'komplit',
#  'pesan',
#  'cepat',
#  'kirimdan',
#  'buka',
#  'lapak',
#  'jual',
#  'mudahsemoga',
#  'depan',
#  'simpel',
#  'mudah',
#  'seller',
#  'pembeligood',
#  'luck',
#  'bukalapak',
#  'kena',
#  'charge',
#  'rp',
#  'kalo',
#  'beli',
#  'barang',
#  'roda',
#  'untung',
#  'nya',
#  'puter',
#  'beli',
#  'item',
#  'tau',
#  'top',
#  'up',
#  'money',
#  'pesan',
#  'tiket',
#  'kereta',
#  'api',
#  'bukalapak',
#  'membantusaat',
#  'beli',
#  'pulsatoken',
#  'listrik',
#  'butuh',
#  'nya',
#  'bukalapak',
#  'atas',
#  'ribet',
#  'andal',
#  'cepatsemua',
#  'atas',
#  'cepat',
#  'aman',
#  'memuaskanmaju',
#  'inovatif',
#  'bukalapak',
#  'aplikasi',
#  'bantu',
#  'belanja',
#  'bayar',
#  'depantapi',
#  'sayang',
#  'biaya',
#  'admin',
#  'ribu',
#  'bulan',
#  'kalo',
#  'paylater',
#  'pakaiklo',
#  'ilangin',
#  'yalimit',
#  'bos',
#  'rugi',
#  'rp',
#  'top',
#  'up',
#  'dana',
#  'bukalapak',
#  'bayar',
#  'via',
#  'atm',
#  'bri',
#  'struk',
#  'bayar',
#  'saldo',
#  'masuk',
#  'henti',
#  'tunggu',
#  'bayar',
#  'buka',
#  'bantu',
#  'nya',
#  'bantu',
#  'memperaulitcall',
#  'center',
#  'nya',
#  'kes',
#  'malas',
#  'tanggap',
#  'keluh',
#  'pelanggansemua',
#  'syarat',
#  'dibpenuhichat',
#  'alihkanni',
#  'buka',
#  'bantuanmemalukan',
#  'transaksi',
#  'bermasalahga',
#  'pertqma',
#  'taman',
#  'kemari',
#  'parahcall',
#  'centernya',
#  'latih',
#  'nihbuat',
#  'hilang',
#  'langgan',
#  'bukalapak',
#  'tuh',
#  'apl',
#  'belanja',
#  'online',
#  'sngat',
#  'bantu',
#  'butuh',
#  'customer',
#  'alam',
#  'belanja',
#  'bukti',
#  'barang',
#  'beli',
#  'sesuai',
#  'gambar',
#  'video',
#  'deskripsi',
#  'sukses',
#  'bukalapak',
#  'indonesia',
#  'rugi',
#  'beli',
#  'masak',
#  'barang',
#  'bayar',
#  'nunggunya',
#  'batal',
#  'uang',
#  'kembali',
#  'rbuan',
#  'alas',
#  'ongkir',
#  'jasa',
#  'kirim',
#  'mutu',
#  'komplin',
#  'klik',
#  'layan',
#  'bantu',
#  'komplin',
#  'blokir',
#  'beli',
#  'barang',
#  'harga',
#  'ribu',
#  'bulan',
#  'dana',
#  'tahan',
#  'kasih',
#  'terus',
#  'jual',
#  'tekan',
#  'tombol',
#  'terima',
#  'cs',
#  'nya',
#  'parah',
#  'banget',
#  'kalo',
#  'dana',
#  'oper',
#  'jual',
#  'bingung',
#  'banget',
#  'hubung',
#  'cs',
#  'ngaktifin',
#  'fitur',
#  'live',
#  'chat',
#  'asih',
#  'feedback',
#  'asih',
#  'feedback',
#  'fitur',
#  'live',
#  'chat',
#  'aktif',
#  'lihat',
#  'transaksi',
#  'beli',
#  'klik',
#  'tulis',
#  'ganggu',
#  'klik',
#  'transaksi',
#  'ganggu',
#  'coba',
#  'email',
#  'kirim',
#  'aplikasi',
#  'tlol',
#  'asyikasyiknya',
#  'nemu',
#  'barang',
#  'incar',
#  'eh',
#  'muncul',
#  'popupiklan',
#  'buka',
#  'emas',
#  'mana',
#  'ganggu',
#  'close',
#  'barang',
#  'incar',
#  'eh',
#  'masuk',
#  'menu',
#  'buka',
#  'emas',
#  'menu',
#  'buka',
#  'emas',
#  'beranda',
#  'beli',
#  'deh',
#  'tokopedia',
#  'shopee',
#  'belanja',
#  'barang',
#  'depan',
#  'banyak',
#  'popup',
#  'jujur',
#  'uninstal',
#  'update',
#  'suka',
#  'error',
#  'cepat',
#  'suka',
#  'errorbarusan',
#  'turun',
#  'bintang',
#  'notif',
#  'tagih',
#  'hilang',
#  'bayar',
#  'selesai',
#  'tagih',
#  'besok',
#  'bintang',
#  'buka',
#  'tanggal',
#  'juni',
#  'pagi',
#  'malam',
#  'cek',
#  'detail',
#  'pesan',
#  'bayar',
#  'nih',
#  'order',
#  'barang',
#  'lapak',
#  'chat',
#  'lambat',
#  'kirim',
#  'sehat',
#  'kondisi',
#  'baik',
#  'kirim',
#  'barang',
#  'status',
#  'pesan',
#  'aktif',
#  'batal',
#  'parah',
#  'laksana',
#  'transaksi',
#  'uang',
#  'refound',
#  'saldo',
#  'dana',
#  'kalo',
#  'rugi',
#  'kesel',
#  'banget',
#  'nih',
#  'aplikasi',
#  'mesan',
#  'batal',
#  'otomatis',
#  'limit',
#  'sedia',
#  'tagih',
#  'aju',
#  'komplain',
#  'sulit',
#  'kirim',
#  'email',
#  'alamat',
#  'email',
#  'tolong',
#  'baik',
#  'mengunakan',
#  'paylatter',
#  'belanja',
#  'bukalapak',
#  'terima',
#  'kasih',
#  'diupdate',
#  'bug',
#  'contoh',
#  'cek',
#  'out',
#  'pesan',
#  'bayar',
#  'hasil',
#  'pesan',
#  'dibukak',
#  'tulis',
#  'salah',
#  'dana',
#  'masuk',
#  'sistem',
#  'pantau',
#  'gera',
#  'pesan',
#  'kembali',
#  'dana',
#  'otomatis',
#  'berfungsisy',
#  'butuh',
#  'banget',
#  'dana',
#  'ajuin',
#  'komplainada',
#  'tombol',
#  'komplain',
#  'diarahin',
#  'pusat',
#  'bantu',
#  'tombol',
#  'aju',
#  'pembatalanpengembalian',
#  'dana',
#  'aplikasi',
#  'payahmenyulitkan',
#  'konsumen',
#  'senang',
#  'transaksi',
#  'bukalapak',
#  'mudah',
#  'mudah',
#  'barang',
#  'bermacammacam',
#  'relatif',
#  'murah',
#  'ayo',
#  'download',
#  'aplikasi',
#  'transfer',
#  'baca',
#  'virtual',
#  'account',
#  'verifikasi',
#  'saldo',
#  'rekening',
#  'potong',
#  'komplain',
#  'live',
#  'chat',
#  'arahanya',
#  'ribet',
#  'banget',
#  'parah',
#  'live',
#  'chat',
#  'langsung',
#  'alas',
#  'koneksi',
#  'putus',
#  'ganti',
#  'email',
#  'ribet',
#  'banget',
#  'selfilah',
#  'ktplah',
#  'mutasi',
#  'rekening',
#  'framelah',
#  'kembali',
#  'dana',
#  'transfer',
#  'bukalapak',
#  'tangan',
#  'tim',
#  'tunggu',
#  'jam',
#  'selesai',
#  'maaf',
#  'maaf',
#  'banget',
#  'nih',
#  'ya',
#  'apk',
#  'sih',
#  'paylater',
#  'kasih',
#  'star',
#  'muas',
#  'pakai',
#  'bukalapak',
#  'rekomendasi',
#  'dengam',
#  'star',
#  'transaksi',
#  'pulsa',
#  'tagih',
#  'diskon',
#  'respon',
#  'cepat',
#  'moga',
#  'maksimal',
#  'promo',
#  'bayar',
#  'pulsa',
#  'tagih',
#  'aplikasi',
#  'efisien',
#  'banding',
#  'aplikasi',
#  'kurang',
#  'banding',
#  'merk',
#  'voucher',
#  'ongkir',
#  'alternatif',
#  'pt',
#  'bukalapak',
#  'akuisisi',
#  'jasa',
#  'kirim',
#  'promo',
#  'gratis',
#  'ongkir',
#  'aplikasi',
#  'ku',
#  'kasih',
#  'bintang',
#  'sesuai',
#  'beli',
#  'juni',
#  'juli',
#  'rupa',
#  'nya',
#  'kali',
#  'hitung',
#  'lipat',
#  'ganda',
#  'pintar',
#  'ya',
#  'rekom',
#  'guna',
#  'bagus',
#  'cari',
#  'ppob',
#  'bagus',
#  'pokok',
#  'nya',
#  'bukalapak',
#  'ya',
#  'buka',
#  'lapak',
#  'uang',
#  'kembali',
#  'belanja',
#  'dibukalapak',
#  'uang',
#  'transfer',
#  'barang',
#  'cancel',
#  'stok',
#  'barang',
#  'habisdan',
#  'dasar',
#  'info',
#  'bukalapak',
#  'uang',
#  'kembali',
#  'akun',
#  'dana',
#  'uang',
#  'masuk',
#  'akun',
#  'dana',
#  'komplain',
#  'respon',
#  'aplikasi',
#  'bagus',
#  'asuransi',
#  'kirim',
#  'nya',
#  'sedih',
#  'barang',
#  'hilang',
#  'asuransi',
#  'proses',
#  'uang',
#  'kembali',
#  'kalo',
#  'nya',
#  'tunggu',
#  'kecewa',
#  'kecewa',
#  'limit',
#  'paylater',
#  'pakai',
#  'biaya',
#  'bulan',
#  'akun',
#  'paylater',
#  'beku',
#  'aktif',
#  'lunas',
#  'limit',
#  'pakaitrus',
#  'biaya',
#  'bulan',
#  'tagih',
#  'jatuh',
#  'tempo',
#  'bayar',
#  'pakai',
#  'fitur',
#  'live',
#  'chat',
#  'bukalapak',
#  'selesai',
#  'chat',
#  'lansung',
#  'aplikasi',
#  'complain',
#  'live',
#  'chat',
#  'berteletele',
#  'cepat',
#  'layan',
#  'parah',
#  'tukar',
#  'voucher',
#  'prakerja',
#  'beli',
#  'hasil',
#  'aplikasi',
#  'ya',
#  'bikin',
#  'aplikasi',
#  'bl',
#  'mewq',
#  'iinv',
#  'beli',
#  'pulsa',
#  'saldo',
#  'kurang',
#  'token',
#  'pulsa',
#  'listrik',
#  'masuk',
#  'terang',
#  'tunggu',
#  'bayar',
#  'sial',
#  'besok',
#  'cek',
#  'kadaluarsa',
#  'anjir',
#  'uang',
#  'hilang',
#  'kurang',
#  'nya',
#  'bukalapak',
#  'ongkir',
#  'nya',
#  'mahal',
#  'kirim',
#  'nya',
#  'lambat',
#  'chat',
#  'lapak',
#  'nya',
#  'kirim',
#  'update',
#  'resi',
#  'nya',
#  'tau',
#  'lalai',
#  'lapak',
#  'coba',
#  'banding',
#  'aplikasi',
#  'transfer',
#  'proses',
#  'nya',
#  'aplikasi',
#  'duluan',
#  'sistem',
#  'bukalapak',
#  'rubah',
#  'saing',
#  'kompetitor',
#  'beli',
#  'token',
#  'listrik',
#  'bukalapak',
#  'lalu',
#  'virtual',
#  'account',
#  'saldo',
#  'potong',
#  'bayar',
#  'verifikasi',
#  'komplen',
#  'live',
#  'chat',
#  'cs',
#  'nya',
#  'banget',
#  'bantu',
#  'sulit',
#  'main',
#  'kah',
#  'ambil',
#  'hak',
#  'milik',
#  'orang',
#  'download',
#  'aplikasi',
#  'bukalapak',
#  'pikir',
#  'deh',
#  'voucher',
#  'gratis',
#  'ongkir',
#  'biaya',
#  'tambah',
#  'tolong',
#  'dirinci',
#  'lacak',
#  'paket',
#  'kalo',
#  'paket',
#  'antar',
#  'kasih',
#  'notifikasi',
#  'kalo',
#  'paket',
#  'antar',
#  'alamat',
#  'terima',
#  'sistem',
#  'cod',
#  'paket',
#  'terima',
#  'kalo',
#  'klik',
#  'terima',
#  'pesan',
#  'diberitahu',
#  'kurir',
#  'jalan',
#  'moga',
#  'depan',
#  'tanggap',
#  'transfer',
#  'retur',
#  'rekening',
#  'kode',
#  'otp',
#  'kirim',
#  'email',
#  'coba',
#  'masuk',
#  'masuk',
#  'dana',
#  'transfer',
#  'rekening',
#  'suruh',
#  'upgrade',
#  'paksa',
#  'belikan',
#  'pulsa',
#  'pantesan',
#  'merosot',
#  'tukang',
#  'nipu',
#  'program',
#  'serbu',
#  'halo',
#  'bukalapak',
#  'pesan',
#  'proses',
#  'kirim',
#  'seller',
#  'lampau',
#  'batas',
#  'sistem',
#  'batal',
#  'otomatis',
#  'dihubungichat',
#  'tokoselernya',
#  'aktif',
#  'mohon',
#  'cerah',
#  'terima',
#  'kasih',
#  'buka',
#  'lapak',
#  'bagus',
#  'puas',
#  'vocer',
#  'cashback',
#  'kadang',
#  'gunakanhabis',
#  'limit',
#  'habis',
#  'limit',
#  'hilang',
#  'guna',
#  'mitra',
#  'langsung',
#  'tulis',
#  'bela',
#  'guna',
#  'mitra',
#  'halaman',
#  'sayang',
#  'bukalapak',
#  'bawah',
#  'nih',
#  'senang',
#  'belanja',
#  'sih',
#  'ijo',
#  'sih',
#  'ijo',
#  'cashback',
#  'bonus',
#  'dll',
#  'ayo',
#  'bl',
#  'tingkat',
#  'inovasiinovasi',
#  'nya',
#  'kalah',
#  'sih',
#  'ijo',
#  'hatihati',
#  'aplikasi',
#  'dana',
#  'aman',
#  'payletter',
#  'rbbaru',
#  'pakai',
#  'kalieeeengga',
#  'lagiwk',
#  'wkkok',
#  'yabl',
#  'lambat',
#  'banget',
#  'update',
#  'pengirimannyahrs',
#  'baik',
#  'aplikasi',
#  'tanggal',
#  'sd',
#  'tanggal',
#  'bayar',
#  'transaksi',
#  'bukalapak',
#  'metode',
#  'virtual',
#  'account',
#  'bank',
#  'ocbc',
#  'nisp',
#  'lwh',
#  'buka',
#  'bantu',
#  'bukalapak',
#  'menu',
#  'pilih',
#  'cs',
#  'kelas',
#  'selesai',
#  'cs',
#  'main',
#  'tutup',
#  'chat',
#  'layan',
#  'cs',
#  'buruk',
#  'kasih',
#  'limit',
#  'paylater',
#  'pakai',
#  'belanja',
#  'fitur',
#  'bantu',
#  'live',
#  'chat',
#  'susah',
#  'akses',
#  'cs',
#  'memeberikan',
#  'solusi',
#  'aplikasi',
#  'buruk',
#  'beku',
#  'alas',
#  'kalo',
#  'bekuin',
#  'akun',
#  'baik',
#  'kasih',
#  'alas',
#  'jalan',
#  'bukalapak',
#  'saing',
#  'loh',
#  'tokopedia',
#  'tinggal',
#  'tambah',
#  'nyaman',
#  'dagang',
#  'nyaman',
#  'belanja',
#  'buka',
#  'lapak',
#  'paylater',
#  'beku',
#  'permanen',
#  'pakai',
#  'paylaternya',
#  'tagih',
#  'bayar',
#  'mending',
#  'alih',
#  'belah',
#  'shoppy',
#  'buka',
#  'lapak',
#  'bintang',
#  'fitur',
#  'live',
#  'chat',
#  'hubung',
#  'cs',
#  'fitur',
#  'livechat',
#  'khusus',
#  'tinggal',
#  'banding',
#  ...]

# %%
fqdist = FreqDist(tokenize_ulasan)

# %%
fqdist
# Out:
# FreqDist({'bukalapak': 504, 'aplikasi': 497, 'barang': 430, 'nya': 412, 'kirim': 256, 'beli': 242, 'buka': 226, 'bayar': 222, 'belanja': 216, 'pakai': 211, ...})

# %% [markdown]
# # **Mencetak 15 Kata Paling Banyak Digunakan**

# %%
fqdist.most_common(15)
# Out:
# [('bukalapak', 504),
#  ('aplikasi', 497),
#  ('barang', 430),
#  ('nya', 412),
#  ('kirim', 256),
#  ('beli', 242),
#  ('buka', 226),
#  ('bayar', 222),
#  ('belanja', 216),
#  ('pakai', 211),
#  ('lapak', 201),
#  ('transaksi', 184),
#  ('bantu', 163),
#  ('mudah', 163),
#  ('jual', 157)]

# %%
import matplotlib.pyplot as plt

# plotting
fqdist.plot(10,cumulative=False)
plt.show()

# %%
label = []
for index, row in name_dataframe.iterrows():
    if row["Rating"] == 5 or row["Rating"] == 4:
        label.append(1)
    else:
        label.append(0)

name_dataframe["label"] = label

name_dataframe
# Out:
#                 Nama pengguna  Rating                Date  \
# 0                     yOga 04       1 2023-08-01 03:19:16
# 1     Imagination Music Store       1 2023-07-28 08:32:00
# 2           Mas bagoess Kocak       1 2023-07-27 22:26:26
# 3                    Sis Maya       1 2023-07-22 10:54:24
# 4                      Gb Jkt       1 2023-08-01 03:57:42
# ...                       ...     ...                 ...
# 1295           aditya anugrah       1 2020-12-28 13:01:51
# 1296             ary surjamin       5 2023-04-26 05:28:37
# 1297                   yunita       2 2020-10-02 17:55:26
# 1298              Xiaomi Mi03       5 2020-08-22 06:35:44
# 1299                  Go Cell       3 2021-11-30 04:36:34
#
#                                                  Ulasan  \
# 0     aplikasi marketplace paling ancur sistem bukab...
# 1     aplikasi yg sangat ribet tiap mau edit produk ...
# 2     buka bantuan bukalapak tidak berguna karena ti...
# 3     saya sangat sedih sekali belanja lewat mitra b...
# 4     makin lama makin mengerikan belanja di bukalap...
# ...                                                 ...
# 1295  aplikasi buruk selalu ngrestart sendiri klo lg...
# 1296  barang sesuai yg dilesan cepat respon dan diki...
# 1297  saya melakukan pembayaran untuk pemesanan sebu...
# 1298  aplikasinya membantu bangat bisa belanja jarak...
# 1299  setelah diupdate bukannya jadi bagus malah jad...
#
#                                         Ulasan_tokenize  \
# 0     [aplikasi, marketplace, paling, ancur, sistem,...
# 1     [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2     [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3     [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4     [makin, lama, makin, mengerikan, belanja, di, ...
# ...                                                 ...
# 1295  [aplikasi, buruk, selalu, ngrestart, sendiri, ...
# 1296  [barang, sesuai, yg, dilesan, cepat, respon, d...
# 1297  [saya, melakukan, pembayaran, untuk, pemesanan...
# 1298  [aplikasinya, membantu, bangat, bisa, belanja,...
# 1299  [setelah, diupdate, bukannya, jadi, bagus, mal...
#
#                                             ulasan_ears  \
# 0     [aplikasi, marketplace, paling, ancur, sistem,...
# 1     [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2     [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3     [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4     [makin, lama, makin, mengerikan, belanja, di, ...
# ...                                                 ...
# 1295  [aplikasi, buruk, selalu, ngrestart, sendiri, ...
# 1296  [barang, sesuai, yg, dilesan, cepat, respon, d...
# 1297  [saya, melakukan, pembayaran, untuk, pemesanan...
# 1298  [aplikasinya, membantu, bangat, bisa, belanja,...
# 1299  [setelah, diupdate, bukannya, jadi, bagus, mal...
#
#                                       Ulasan_normalized  \
# 0     [aplikasi, marketplace, paling, hancur, sistem...
# 1     [aplikasi, yang, sangat, ribet, tiap, mau, edi...
# 2     [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3     [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4     [makin, lama, makin, mengerikan, belanja, di, ...
# ...                                                 ...
# 1295  [aplikasi, buruk, selalu, ngrestart, sendiri, ...
# 1296  [barang, sesuai, yang, dilesan, cepat, respon,...
# 1297  [saya, melakukan, pembayaran, untuk, pemesanan...
# 1298  [aplikasinya, membantu, banget, bisa, belanja,...
# 1299  [setelah, diupdate, bukannya, jadi, bagus, mal...
#
#                                     Ulasan_stop_removed  \
# 0     [aplikasi, marketplace, hancur, sistem, bukaba...
# 1     [aplikasi, ribet, edit, produk, giliran, berha...
# 2     [buka, bantuan, bukalapak, berguna, dihubungi,...
# 3     [sedih, belanja, mitra, bukalapak, live, bukab...
# 4     [mengerikan, belanja, bukalapak, pembeli, dian...
# ...                                                 ...
# 1295  [aplikasi, buruk, ngrestart, kalo, lanjutkan, ...
# 1296  [barang, sesuai, dilesan, cepat, respon, dikir...
# 1297  [pembayaran, pemesanan, buku, bukunya, kirim, ...
# 1298  [aplikasinya, membantu, banget, belanja, jarak...
# 1299  [diupdate, bagus, ngebug, berat, buffering, lo...
#
#                                          Ulasan_Stemmed  \
# 0     [aplikasi, marketplace, hancur, sistem, bukaba...
# 1     [aplikasi, ribet, edit, produk, gilir, hasil, ...
# 2     [buka, bantu, bukalapak, guna, hubung, transak...
# 3     [sedih, belanja, mitra, bukalapak, live, bukab...
# 4     [keri, belanja, bukalapak, beli, diangap, jaha...
# ...                                                 ...
# 1295  [aplikasi, buruk, ngrestart, kalo, lanjut, tra...
# 1296  [barang, sesuai, les, cepat, respon, kirim, ce...
# 1297  [bayar, mesan, buku, buku, kirim, batas, mesan...
# 1298  [aplikasi, bantu, banget, belanja, jarak, muda...
# 1299  [diupdate, bagus, ngebug, berat, buffering, lo...
#
#                                             Ulasan_siap  label
# 0     aplikasi marketplace hancur sistem bukabantuan...      0
# 1     aplikasi ribet edit produk gilir hasil ujung n...      0
# 2     buka bantu bukalapak guna hubung transaksi jua...      0
# 3     sedih belanja mitra bukalapak live bukabantuan...      0
# 4     keri belanja bukalapak beli diangap jahat main...      0
# ...                                                 ...    ...
# 1295  aplikasi buruk ngrestart kalo lanjut transaksi...      0
# 1296  barang sesuai les cepat respon kirim cepat ter...      1
# 1297  bayar mesan buku buku kirim batas mesan batal ...      0
# 1298  aplikasi bantu banget belanja jarak mudah tran...      1
# 1299  diupdate bagus ngebug berat buffering loading ...      0
#
# [1300 rows x 11 columns]

# %% [markdown]
# # **Subjekvity dan Polarity**

# %%
#create a user define function to find out polarity & subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

#creating another user define function to label the sentiment

def getSentiment(value):
    if value < 0:
        return 'Negative'
    elif value > 0:
        return 'Positive'
    else:
        return 'Neutral'

# %%
name_dataframe.head()
# Out:
#              Nama pengguna  Rating                Date  \
# 0                  yOga 04       1 2023-08-01 03:19:16
# 1  Imagination Music Store       1 2023-07-28 08:32:00
# 2        Mas bagoess Kocak       1 2023-07-27 22:26:26
# 3                 Sis Maya       1 2023-07-22 10:54:24
# 4                   Gb Jkt       1 2023-08-01 03:57:42
#
#                                               Ulasan  \
# 0  aplikasi marketplace paling ancur sistem bukab...
# 1  aplikasi yg sangat ribet tiap mau edit produk ...
# 2  buka bantuan bukalapak tidak berguna karena ti...
# 3  saya sangat sedih sekali belanja lewat mitra b...
# 4  makin lama makin mengerikan belanja di bukalap...
#
#                                      Ulasan_tokenize  \
# 0  [aplikasi, marketplace, paling, ancur, sistem,...
# 1  [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2  [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3  [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4  [makin, lama, makin, mengerikan, belanja, di, ...
#
#                                          ulasan_ears  \
# 0  [aplikasi, marketplace, paling, ancur, sistem,...
# 1  [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2  [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3  [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4  [makin, lama, makin, mengerikan, belanja, di, ...
#
#                                    Ulasan_normalized  \
# 0  [aplikasi, marketplace, paling, hancur, sistem...
# 1  [aplikasi, yang, sangat, ribet, tiap, mau, edi...
# 2  [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3  [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4  [makin, lama, makin, mengerikan, belanja, di, ...
#
#                                  Ulasan_stop_removed  \
# 0  [aplikasi, marketplace, hancur, sistem, bukaba...
# 1  [aplikasi, ribet, edit, produk, giliran, berha...
# 2  [buka, bantuan, bukalapak, berguna, dihubungi,...
# 3  [sedih, belanja, mitra, bukalapak, live, bukab...
# 4  [mengerikan, belanja, bukalapak, pembeli, dian...
#
#                                       Ulasan_Stemmed  \
# 0  [aplikasi, marketplace, hancur, sistem, bukaba...
# 1  [aplikasi, ribet, edit, produk, gilir, hasil, ...
# 2  [buka, bantu, bukalapak, guna, hubung, transak...
# 3  [sedih, belanja, mitra, bukalapak, live, bukab...
# 4  [keri, belanja, bukalapak, beli, diangap, jaha...
#
#                                          Ulasan_siap  label
# 0  aplikasi marketplace hancur sistem bukabantuan...      0
# 1  aplikasi ribet edit produk gilir hasil ujung n...      0
# 2  buka bantu bukalapak guna hubung transaksi jua...      0
# 3  sedih belanja mitra bukalapak live bukabantuan...      0
# 4  keri belanja bukalapak beli diangap jahat main...      0

# %%
from textblob import TextBlob

# %%
def run_vader(name_dataframe):
    # Generate VADER sentiment analyzer object
    sid = SentimentIntensityAnalyzer()

# %%
name_dataframe['Polarity']=name_dataframe['Ulasan_siap'].apply(getPolarity)
name_dataframe['Subjectivity']=name_dataframe['Ulasan_siap'].apply(getSubjectivity)
name_dataframe['Sentiment']=name_dataframe['Polarity'].apply(getSentiment)
name_dataframe.head()
# Out:
#              Nama pengguna  Rating                Date  \
# 0                  yOga 04       1 2023-08-01 03:19:16
# 1  Imagination Music Store       1 2023-07-28 08:32:00
# 2        Mas bagoess Kocak       1 2023-07-27 22:26:26
# 3                 Sis Maya       1 2023-07-22 10:54:24
# 4                   Gb Jkt       1 2023-08-01 03:57:42
#
#                                               Ulasan  \
# 0  aplikasi marketplace paling ancur sistem bukab...
# 1  aplikasi yg sangat ribet tiap mau edit produk ...
# 2  buka bantuan bukalapak tidak berguna karena ti...
# 3  saya sangat sedih sekali belanja lewat mitra b...
# 4  makin lama makin mengerikan belanja di bukalap...
#
#                                      Ulasan_tokenize  \
# 0  [aplikasi, marketplace, paling, ancur, sistem,...
# 1  [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2  [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3  [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4  [makin, lama, makin, mengerikan, belanja, di, ...
#
#                                          ulasan_ears  \
# 0  [aplikasi, marketplace, paling, ancur, sistem,...
# 1  [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2  [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3  [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4  [makin, lama, makin, mengerikan, belanja, di, ...
#
#                                    Ulasan_normalized  \
# 0  [aplikasi, marketplace, paling, hancur, sistem...
# 1  [aplikasi, yang, sangat, ribet, tiap, mau, edi...
# 2  [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3  [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4  [makin, lama, makin, mengerikan, belanja, di, ...
#
#                                  Ulasan_stop_removed  \
# 0  [aplikasi, marketplace, hancur, sistem, bukaba...
# 1  [aplikasi, ribet, edit, produk, giliran, berha...
# 2  [buka, bantuan, bukalapak, berguna, dihubungi,...
# 3  [sedih, belanja, mitra, bukalapak, live, bukab...
# 4  [mengerikan, belanja, bukalapak, pembeli, dian...
#
#                                       Ulasan_Stemmed  \
# 0  [aplikasi, marketplace, hancur, sistem, bukaba...
# 1  [aplikasi, ribet, edit, produk, gilir, hasil, ...
# 2  [buka, bantu, bukalapak, guna, hubung, transak...
# 3  [sedih, belanja, mitra, bukalapak, live, bukab...
# 4  [keri, belanja, bukalapak, beli, diangap, jaha...
#
#                                          Ulasan_siap  label  Polarity  \
# 0  aplikasi marketplace hancur sistem bukabantuan...      0  0.136364
# 1  aplikasi ribet edit produk gilir hasil ujung n...      0  0.000000
# 2  buka bantu bukalapak guna hubung transaksi jua...      0  0.000000
# 3  sedih belanja mitra bukalapak live bukabantuan...      0  0.136364
# 4  keri belanja bukalapak beli diangap jahat main...      0  0.166667
#
#    Subjectivity Sentiment
# 0      0.500000  Positive
# 1      0.000000   Neutral
# 2      0.000000   Neutral
# 3      0.500000  Positive
# 4      0.333333  Positive

# %%
name_dataframe['month'] = name_dataframe['Date'].dt.month

# %%
name_dataframe
# Out:
#                 Nama pengguna  Rating                Date  \
# 0                     yOga 04       1 2023-08-01 03:19:16
# 1     Imagination Music Store       1 2023-07-28 08:32:00
# 2           Mas bagoess Kocak       1 2023-07-27 22:26:26
# 3                    Sis Maya       1 2023-07-22 10:54:24
# 4                      Gb Jkt       1 2023-08-01 03:57:42
# ...                       ...     ...                 ...
# 1295           aditya anugrah       1 2020-12-28 13:01:51
# 1296             ary surjamin       5 2023-04-26 05:28:37
# 1297                   yunita       2 2020-10-02 17:55:26
# 1298              Xiaomi Mi03       5 2020-08-22 06:35:44
# 1299                  Go Cell       3 2021-11-30 04:36:34
#
#                                                  Ulasan  \
# 0     aplikasi marketplace paling ancur sistem bukab...
# 1     aplikasi yg sangat ribet tiap mau edit produk ...
# 2     buka bantuan bukalapak tidak berguna karena ti...
# 3     saya sangat sedih sekali belanja lewat mitra b...
# 4     makin lama makin mengerikan belanja di bukalap...
# ...                                                 ...
# 1295  aplikasi buruk selalu ngrestart sendiri klo lg...
# 1296  barang sesuai yg dilesan cepat respon dan diki...
# 1297  saya melakukan pembayaran untuk pemesanan sebu...
# 1298  aplikasinya membantu bangat bisa belanja jarak...
# 1299  setelah diupdate bukannya jadi bagus malah jad...
#
#                                         Ulasan_tokenize  \
# 0     [aplikasi, marketplace, paling, ancur, sistem,...
# 1     [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2     [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3     [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4     [makin, lama, makin, mengerikan, belanja, di, ...
# ...                                                 ...
# 1295  [aplikasi, buruk, selalu, ngrestart, sendiri, ...
# 1296  [barang, sesuai, yg, dilesan, cepat, respon, d...
# 1297  [saya, melakukan, pembayaran, untuk, pemesanan...
# 1298  [aplikasinya, membantu, bangat, bisa, belanja,...
# 1299  [setelah, diupdate, bukannya, jadi, bagus, mal...
#
#                                             ulasan_ears  \
# 0     [aplikasi, marketplace, paling, ancur, sistem,...
# 1     [aplikasi, yg, sangat, ribet, tiap, mau, edit,...
# 2     [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3     [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4     [makin, lama, makin, mengerikan, belanja, di, ...
# ...                                                 ...
# 1295  [aplikasi, buruk, selalu, ngrestart, sendiri, ...
# 1296  [barang, sesuai, yg, dilesan, cepat, respon, d...
# 1297  [saya, melakukan, pembayaran, untuk, pemesanan...
# 1298  [aplikasinya, membantu, bangat, bisa, belanja,...
# 1299  [setelah, diupdate, bukannya, jadi, bagus, mal...
#
#                                       Ulasan_normalized  \
# 0     [aplikasi, marketplace, paling, hancur, sistem...
# 1     [aplikasi, yang, sangat, ribet, tiap, mau, edi...
# 2     [buka, bantuan, bukalapak, tidak, berguna, kar...
# 3     [saya, sangat, sedih, sekali, belanja, lewat, ...
# 4     [makin, lama, makin, mengerikan, belanja, di, ...
# ...                                                 ...
# 1295  [aplikasi, buruk, selalu, ngrestart, sendiri, ...
# 1296  [barang, sesuai, yang, dilesan, cepat, respon,...
# 1297  [saya, melakukan, pembayaran, untuk, pemesanan...
# 1298  [aplikasinya, membantu, banget, bisa, belanja,...
# 1299  [setelah, diupdate, bukannya, jadi, bagus, mal...
#
#                                     Ulasan_stop_removed  \
# 0     [aplikasi, marketplace, hancur, sistem, bukaba...
# 1     [aplikasi, ribet, edit, produk, giliran, berha...
# 2     [buka, bantuan, bukalapak, berguna, dihubungi,...
# 3     [sedih, belanja, mitra, bukalapak, live, bukab...
# 4     [mengerikan, belanja, bukalapak, pembeli, dian...
# ...                                                 ...
# 1295  [aplikasi, buruk, ngrestart, kalo, lanjutkan, ...
# 1296  [barang, sesuai, dilesan, cepat, respon, dikir...
# 1297  [pembayaran, pemesanan, buku, bukunya, kirim, ...
# 1298  [aplikasinya, membantu, banget, belanja, jarak...
# 1299  [diupdate, bagus, ngebug, berat, buffering, lo...
#
#                                          Ulasan_Stemmed  \
# 0     [aplikasi, marketplace, hancur, sistem, bukaba...
# 1     [aplikasi, ribet, edit, produk, gilir, hasil, ...
# 2     [buka, bantu, bukalapak, guna, hubung, transak...
# 3     [sedih, belanja, mitra, bukalapak, live, bukab...
# 4     [keri, belanja, bukalapak, beli, diangap, jaha...
# ...                                                 ...
# 1295  [aplikasi, buruk, ngrestart, kalo, lanjut, tra...
# 1296  [barang, sesuai, les, cepat, respon, kirim, ce...
# 1297  [bayar, mesan, buku, buku, kirim, batas, mesan...
# 1298  [aplikasi, bantu, banget, belanja, jarak, muda...
# 1299  [diupdate, bagus, ngebug, berat, buffering, lo...
#
#                                             Ulasan_siap  label  Polarity  \
# 0     aplikasi marketplace hancur sistem bukabantuan...      0  0.136364
# 1     aplikasi ribet edit produk gilir hasil ujung n...      0  0.000000
# 2     buka bantu bukalapak guna hubung transaksi jua...      0  0.000000
# 3     sedih belanja mitra bukalapak live bukabantuan...      0  0.136364
# 4     keri belanja bukalapak beli diangap jahat main...      0  0.166667
# ...                                                 ...    ...       ...
# 1295  aplikasi buruk ngrestart kalo lanjut transaksi...      0  0.000000
# 1296  barang sesuai les cepat respon kirim cepat ter...      1  0.000000
# 1297  bayar mesan buku buku kirim batas mesan batal ...      0  0.000000
# 1298  aplikasi bantu banget belanja jarak mudah tran...      1  0.000000
# 1299  diupdate bagus ngebug berat buffering loading ...      0  0.000000
#
#       Subjectivity Sentiment  month
# 0         0.500000  Positive      8
# 1         0.000000   Neutral      7
# 2         0.000000   Neutral      7
# 3         0.500000  Positive      7
# 4         0.333333  Positive      8
# ...            ...       ...    ...
# 1295      0.000000   Neutral     12
# 1296      0.000000   Neutral      4
# 1297      0.000000   Neutral     10
# 1298      0.000000   Neutral      8
# 1299      0.000000   Neutral     11
#
# [1300 rows x 15 columns]

# %%
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # **Visualisasi Bobot Nilai**

# %%
# Create scatter plot
sns.set_style('darkgrid')
plt.figure(figsize = (15,7))

markers = {'Positive':'o', 'Neutral':'s','Negative':'X'}

sns.scatterplot(data=name_dataframe, x='Polarity', y='Subjectivity', hue = 'Sentiment', style = 'Sentiment', markers = markers, palette = 'gist_earth').set(xlim=(-1,1))
plt.title('Scatter Plot')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')

plt.tight_layout()

# %% [markdown]
# # **Visualiasi Polarity dan subjecvity perbulan**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group by month and sentiment
sentiment_df = name_dataframe.groupby(['month', 'Sentiment']).size().reset_index(name='Count')


# Plot the sentiment counts by month
plt.figure(figsize=(12, 6))
sns.lineplot(x='month', y='Count', hue='Sentiment', data=sentiment_df)
plt.title('Sentiment by Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %%
sentimen_data=pd.value_counts(name_dataframe["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["green", "red", "black"])
plt.title('Bar chart')
plt.show()

# %%
name_dataframe["Sentiment"].value_counts()
# Out:
# Neutral     1087
# Positive     171
# Negative      42
# Name: Sentiment, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
Ulasan = name_dataframe['Ulasan_siap']

# %%
Ulasan.isnull().sum()
# Out:
# 0

# %% [markdown]
# # **Proses (TF-IDF)**

# %%
#untuk menghitung jumlah kata yang telah di steming
cv = CountVectorizer()
term_fit = cv.fit(Ulasan)

print (len(term_fit.vocabulary_))
# Out:
# 3663

# %%
term_fit.vocabulary_ #mengurutkan berdasarkan urutab abjad kata
# Out:
# {'aplikasi': 172,
#  'marketplace': 1998,
#  'hancur': 1235,
#  'sistem': 3100,
#  'bukabantuan': 559,
#  'selesain': 2977,
#  'lari': 1832,
#  'live': 1901,
#  'chatnya': 708,
#  'paylaternya': 2466,
#  'bobrok': 518,
#  'sila': 3085,
#  'coba': 725,
#  'download': 967,
#  'tau': 3259,
#  'ribet': 2814,
#  'edit': 997,
#  'produk': 2667,
#  'gilir': 1167,
#  'hasil': 1253,
#  'ujung': 3499,
#  'nya': 2286,
#  'iklan': 1314,
#  'jual': 1465,
#  'hilang': 1270,
#  'alias': 111,
#  'otomatis': 2386,
#  'hapus': 1243,
#  'bukalapak': 574,
#  'tolong': 3410,
#  'tingkat': 3377,
#  'ulang': 3501,
#  'beli': 368,
#  'tinggal': 3376,
#  'buka': 558,
#  'bantu': 283,
#  'guna': 1199,
#  'hubung': 1294,
#  'transaksi': 3432,
#  'barang': 296,
#  'kirim': 1642,
#  'kurir': 1748,
#  'wahana': 3592,
#  'resi': 2792,
#  'diupdate': 941,
#  'batal': 318,
#  'update': 3529,
#  'cek': 675,
#  'manual': 1988,
#  'jalan': 1409,
#  'sedih': 2946,
#  'belanja': 356,
#  'mitra': 2125,
#  'andal': 134,
#  'terima': 3312,
#  'pikir': 2590,
#  'kalo': 1508,
#  'pakai': 2415,
#  'cod': 728,
#  'keri': 1607,
#  'diangap': 860,
#  'jahat': 1404,
#  'main': 1952,
#  'beku': 347,
#  'akun': 95,
#  'orang': 2370,
#  'kredivo': 1726,
#  'akulaku': 94,
#  'hati': 1255,
#  'sayang': 2915,
#  'mending': 2063,
#  'toped': 3414,
#  'aman': 120,
#  'nyaman': 2298,
#  'minim': 2114,
#  'online': 2358,
#  'kerenfitur': 1605,
#  'lengkap': 1870,
#  'metode': 2101,
#  'bayar': 329,
#  'komplit': 1697,
#  'pesan': 2575,
#  'cepat': 685,
#  'kirimdan': 1643,
#  'lapak': 1822,
#  'mudahsemoga': 2158,
#  'depan': 838,
#  'simpel': 3088,
#  'mudah': 2153,
#  'seller': 2985,
#  'pembeligood': 2504,
#  'luck': 1927,
#  'kena': 1587,
#  'charge': 703,
#  'rp': 2842,
#  'roda': 2836,
#  'untung': 3526,
#  'puter': 2707,
#  'item': 1390,
#  'top': 3413,
#  'up': 3528,
#  'money': 2144,
#  'tiket': 3369,
#  'kereta': 1606,
#  'api': 163,
#  'membantusaat': 2037,
#  'pulsatoken': 2698,
#  'listrik': 1900,
#  'butuh': 635,
#  'atas': 207,
#  'cepatsemua': 695,
#  'memuaskanmaju': 2052,
#  'inovatif': 1364,
#  'depantapi': 839,
#  'biaya': 455,
#  'admin': 32,
#  'ribu': 2821,
#  'bulan': 625,
#  'paylater': 2465,
#  'pakaiklo': 2418,
#  'ilangin': 1319,
#  'yalimit': 3646,
#  'bos': 529,
#  'rugi': 2846,
#  'dana': 798,
#  'via': 3571,
#  'atm': 208,
#  'bri': 538,
#  'struk': 3175,
#  'saldo': 2874,
#  'masuk': 2010,
#  'henti': 1262,
#  'tunggu': 3479,
#  'memperaulitcall': 2051,
#  'center': 682,
#  'kes': 1612,
#  'malas': 1965,
#  'tanggap': 3247,
#  'keluh': 1572,
#  'pelanggansemua': 2489,
#  'syarat': 3213,
#  'dibpenuhichat': 871,
#  'alihkanni': 113,
#  'bantuanmemalukan': 284,
#  'bermasalahga': 424,
#  'pertqma': 2573,
#  'taman': 3239,
#  'kemari': 1576,
#  'parahcall': 2439,
#  'centernya': 683,
#  'latih': 1834,
#  'nihbuat': 2248,
#  'langgan': 1813,
#  'tuh': 3465,
#  'apl': 166,
#  'sngat': 3126,
#  'customer': 779,
#  'alam': 99,
#  'bukti': 619,
#  'sesuai': 3044,
#  'gambar': 1134,
#  'video': 3572,
#  'deskripsi': 844,
#  'sukses': 3186,
#  'indonesia': 1340,
#  'masak': 2003,
#  'nunggunya': 2282,
#  'uang': 3491,
#  'kembali': 1579,
#  'rbuan': 2736,
#  'alas': 103,
#  'ongkir': 2346,
#  'jasa': 1423,
#  'mutu': 2176,
#  'komplin': 1696,
#  'klik': 1656,
#  'layan': 1838,
#  'blokir': 505,
#  'harga': 1245,
#  'tahan': 3230,
#  'kasih': 1530,
#  'terus': 3336,
#  'tekan': 3267,
#  'tombol': 3411,
#  'cs': 762,
#  'parah': 2438,
#  'banget': 267,
#  'oper': 2362,
#  'bingung': 465,
#  'ngaktifin': 2210,
#  'fitur': 1088,
#  'chat': 704,
#  'asih': 195,
#  'feedback': 1079,
#  'aktif': 80,
#  'lihat': 1884,
#  'tulis': 3473,
#  'ganggu': 1143,
#  'email': 1017,
#  'tlol': 3389,
#  'asyikasyiknya': 205,
#  'nemu': 2201,
#  'incar': 1330,
#  'eh': 1005,
#  'muncul': 2165,
#  'popupiklan': 2632,
#  'emas': 1019,
#  'mana': 1970,
#  'close': 724,
#  'menu': 2084,
#  'beranda': 394,
#  'deh': 829,
#  'tokopedia': 3401,
#  'shopee': 3061,
#  'banyak': 291,
#  'popup': 2631,
#  'jujur': 1474,
#  'uninstal': 3514,
#  'suka': 3185,
#  'error': 1038,
#  'errorbarusan': 1039,
#  'turun': 3483,
#  'bintang': 468,
#  'notif': 2273,
#  'tagih': 3228,
#  'selesai': 2974,
#  'besok': 437,
#  'tanggal': 3246,
#  'juni': 1477,
#  'pagi': 2407,
#  'malam': 1964,
#  'detail': 846,
#  'nih': 2246,
#  'order': 2375,
#  'lambat': 1805,
#  'sehat': 2955,
#  'kondisi': 1702,
#  'baik': 247,
#  'status': 3162,
#  'laksana': 1788,
#  'refound': 2750,
#  'kesel': 1615,
#  'mesan': 2098,
#  'limit': 1885,
#  'sedia': 2945,
#  'aju': 67,
#  'komplain': 1684,
#  'sulit': 3189,
#  'alamat': 100,
#  'mengunakan': 2077,
#  'paylatter': 2469,
#  'bug': 555,
#  'contoh': 749,
#  'out': 2391,
#  'dibukak': 872,
#  'salah': 2873,
#  'pantau': 2433,
#  'gera': 1160,
#  'berfungsisy': 406,
#  'ajuin': 68,
#  'komplainada': 1685,
#  'diarahin': 861,
#  'pusat': 2702,
#  'pembatalanpengembalian': 2500,
#  'payahmenyulitkan': 2463,
#  'konsumen': 1711,
#  'senang': 3008,
#  'bermacammacam': 422,
#  'relatif': 2777,
#  'murah': 2169,
#  'ayo': 220,
#  'transfer': 3439,
#  'baca': 224,
#  'virtual': 3575,
#  'account': 9,
#  'verifikasi': 3565,
#  'rekening': 2766,
#  'potong': 2640,
#  'arahanya': 189,
#  'langsung': 1815,
#  'koneksi': 1704,
#  'putus': 2709,
#  'ganti': 1144,
#  'selfilah': 2982,
#  'ktplah': 1730,
#  'mutasi': 2173,
#  'framelah': 1109,
#  'tangan': 3244,
#  'tim': 3371,
#  'jam': 1411,
#  'maaf': 1942,
#  'ya': 3638,
#  'apk': 164,
#  'sih': 3082,
#  'star': 3159,
#  'muas': 2151,
#  'rekomendasi': 2771,
#  'dengam': 835,
#  'pulsa': 2697,
#  'diskon': 926,
#  'respon': 2797,
#  'moga': 2141,
#  'maksimal': 1959,
#  'promo': 2676,
#  'efisien': 1003,
#  'banding': 262,
#  'kurang': 1745,
#  'merk': 2095,
#  'voucher': 3585,
#  'alternatif': 118,
#  'pt': 2689,
#  'akuisisi': 93,
#  'gratis': 1186,
#  'ku': 1734,
#  'juli': 1475,
#  'rupa': 2851,
#  'kali': 1504,
#  'hitung': 1281,
#  'lipat': 1897,
#  'ganda': 1141,
#  'pintar': 2601,
#  'rekom': 2769,
#  'bagus': 232,
#  'cari': 666,
#  'ppob': 2643,
#  'pokok': 2626,
#  'dibukalapak': 873,
#  'cancel': 655,
#  'stok': 3168,
#  'habisdan': 1213,
#  'dasar': 814,
#  'info': 1342,
#  'asuransi': 203,
#  'proses': 2683,
#  'kecewa': 1548,
#  'lunas': 1933,
#  'pakaitrus': 2419,
#  'jatuh': 1426,
#  'tempo': 3285,
#  'lansung': 1820,
#  'complain': 743,
#  'berteletele': 430,
#  'tukar': 3472,
#  'prakerja': 2645,
#  'bikin': 462,
#  'bl': 491,
#  'mewq': 2102,
#  'iinv': 1307,
#  'token': 3395,
#  'terang': 3295,
#  'sial': 3072,
#  'kadaluarsa': 1487,
#  'anjir': 150,
#  'mahal': 1949,
#  'lalai': 1790,
#  'duluan': 983,
#  'rubah': 2844,
#  'saing': 2866,
#  'kompetitor': 1683,
#  'lalu': 1791,
#  'komplen': 1693,
#  'kah': 1496,
#  'ambil': 125,
#  'hak': 1226,
#  'milik': 2105,
#  'tambah': 3240,
#  'dirinci': 918,
#  'lacak': 1759,
#  'paket': 2422,
#  'antar': 152,
#  'notifikasi': 2274,
#  'diberitahu': 870,
#  'retur': 2807,
#  'kode': 1663,
#  'otp': 2389,
#  'suruh': 3201,
#  'upgrade': 3536,
#  'paksa': 2424,
#  'belikan': 372,
#  'pantesan': 2434,
#  'merosot': 2096,
#  'tukang': 3471,
#  'nipu': 2253,
#  'program': 2674,
#  'serbu': 3025,
#  'halo': 1232,
#  'lampau': 1807,
#  'batas': 323,
#  'dihubungichat': 889,
#  'tokoselernya': 3403,
#  'mohon': 2142,
#  'cerah': 697,
#  'puas': 2690,
#  'vocer': 3582,
#  'cashback': 670,
#  'kadang': 1491,
#  'gunakanhabis': 1202,
#  'habis': 1212,
#  'bela': 352,
#  'halaman': 1228,
#  'bawah': 327,
#  'ijo': 1308,
#  'bonus': 525,
#  'dll': 944,
#  'inovasiinovasi': 1363,
#  'kalah': 1502,
#  'hatihati': 1256,
#  'payletter': 2474,
#  'rbbaru': 2735,
#  'kalieeeengga': 1505,
#  'lagiwk': 1772,
#  'wkkok': 3624,
#  'yabl': 3642,
#  'pengirimannyahrs': 2529,
#  'sd': 2927,
#  'bank': 280,
#  'ocbc': 2319,
#  'nisp': 2254,
#  'lwh': 1939,
#  'pilih': 2591,
#  'kelas': 1566,
#  'tutup': 3486,
#  'buruk': 631,
#  'susah': 3203,
#  'akses': 76,
#  'memeberikan': 2046,
#  'solusi': 3131,
#  'bekuin': 348,
#  'loh': 1914,
#  'dagang': 791,
#  'permanen': 2566,
#  'alih': 112,
#  'belah': 353,
#  'shoppy': 3069,
#  'livechat': 1902,
#  'khusus': 1635,
#  'olshop': 2337,
#  'customernya': 781,
#  'apa': 158,
#  'gmail': 1172,
#  'nomor': 2263,
#  'sajah': 2869,
#  'kait': 1497,
#  'upload': 3538,
#  'kuras': 1747,
#  'kategori': 1535,
#  'normal': 2268,
#  'gagal': 1124,
#  'sangatembantu': 2895,
#  'mesti': 2100,
#  'informasi': 1343,
#  'experssya': 1057,
#  'ecek': 992,
#  'no': 2257,
#  'kulir': 1738,
#  'segitu': 2953,
#  'komponen': 1698,
#  'unik': 3512,
#  'setting': 3051,
#  'maps': 1992,
#  'refresh': 2752,
#  'ekspedisi': 1010,
#  'bukasend': 615,
#  'urus': 3543,
#  'refund': 2753,
#  'dicairin': 875,
#  'nominal': 2262,
#  'topup': 3416,
#  'ikhlasin': 1313,
#  'pln': 2617,
#  'byar': 638,
#  'kadarluarsa': 1492,
#  'arah': 188,
#  'artikel': 192,
#  'ditemukanmakin': 935,
#  'heran': 1263,
#  'tidka': 3364,
#  'erti': 1042,
#  'prihal': 2656,
#  'payleter': 2472,
#  'enggak': 1028,
#  'bisa': 472,
#  'mentok': 2082,
#  'minggu': 2112,
#  'macet': 1944,
#  'ada': 18,
#  'oernah': 2320,
#  'ain': 50,
#  'komplan': 1691,
#  'benah': 376,
#  'sinyal': 3094,
#  'naikyg': 2184,
#  'percaya': 2555,
#  'mode': 2137,
#  'aga': 41,
#  'aco': 15,
#  'favorit': 1071,
#  'search': 2929,
#  'toko': 3397,
#  'systemnya': 3217,
#  'ongkirku': 2350,
#  'ongkirnya': 2352,
#  'masalah': 2005,
#  'pesananselalu': 2580,
#  'tulus': 3475,
#  'nomer': 2261,
#  'instal': 1367,
#  'nyampek': 2304,
#  'sekian': 2969,
#  'berat': 397,
#  'serasa': 3023,
#  'tipu': 3384,
#  'ekspres': 1014,
#  'estimasi': 1043,
#  'kerja': 1608,
#  'peniriman': 2537,
#  'tanggung': 3252,
#  'materi': 2018,
#  'semenjak': 3000,
#  'call': 650,
#  'canter': 657,
#  'mencewakan': 2060,
#  'selsai': 2992,
#  'kacau': 1486,
#  'benarbenar': 378,
#  'bilang': 463,
#  'jebak': 1439,
#  'bukalapakudah': 601,
#  'cekout': 678,
#  'payment': 2477,
#  'selesaitapidi': 2978,
#  'nyaakhirnya': 2287,
#  'kemanaudah': 1575,
#  'hubungin': 1296,
#  'sedikitkecewa': 2947,
#  'ubah': 3493,
#  'konfirmasi': 1706,
#  'brisaldo': 540,
#  'bayarparah': 331,
#  'ajaudh': 63,
#  'doang': 950,
#  'cuihhh': 769,
#  'smartphone': 3118,
#  'lamalama': 1795,
#  'kepala': 1597,
#  'pusing': 2704,
#  'layoutnya': 1845,
#  'beranta': 396,
#  'xxx': 3636,
#  'tampil': 3241,
#  'ponsel': 2628,
#  'aksesoris': 79,
#  'suku': 3187,
#  'cadang': 645,
#  'penantan': 2515,
#  'kolom': 1667,
#  'rapi': 2726,
#  'rekan': 2764,
#  'bosan': 531,
#  'jenuh': 1455,
#  'lanjut': 1818,
#  'cair': 646,
#  'kesini': 1618,
#  'seler': 2973,
#  'setatus': 3048,
#  'pemberitahuan': 2510,
#  'tiktok': 3370,
#  'mah': 1947,
#  'satusaya': 2905,
#  'biyaya': 490,
#  'anehjelas': 139,
#  'knapa': 1659,
#  'sekalimohon': 2963,
#  'dikit': 901,
#  'sepi': 3021,
#  'ktp': 1729,
#  'verifikasigak': 3566,
#  'lot': 1919,
#  'duit': 980,
#  'curi': 774,
#  'pin': 2593,
#  'hape': 1242,
#  'bajak': 249,
#  'sambung': 2881,
#  'tibatiba': 3360,
#  'game': 1135,
#  'panjang': 2430,
#  'umur': 3504,
#  'gulung': 1197,
#  'tikar': 3368,
#  'kayak': 1538,
#  'platform': 2608,
#  'nyamantidak': 2299,
#  'bukalapakselain': 598,
#  'mahalada': 1950,
#  'bebankanmending': 337,
#  'benermending': 383,
#  'tujuansudah': 3468,
#  'jaman': 1412,
#  'muat': 2152,
#  'trakhir': 3426,
#  'uninstall': 3516,
#  'apknya': 165,
#  'min': 2107,
#  'data': 816,
#  'keteranganya': 1624,
#  'hp': 1287,
#  'beda': 342,
#  'mengatasnamakan': 2066,
#  'takut': 3237,
#  'disalahgunakan': 920,
#  'blapak': 496,
#  'nama': 2188,
#  'fungsi': 1115,
#  'login': 1911,
#  'jarang': 1420,
#  'whatsapp': 3616,
#  'dipromo': 912,
#  'terimakasih': 3315,
#  'utakatik': 3548,
#  'lazada': 1846,
#  'shoppe': 3067,
#  'onderdilpart': 2343,
#  'pretel': 2652,
#  'ketik': 1626,
#  'mesin': 2099,
#  'cuci': 767,
#  'onderdil': 2342,
#  'evaluasi': 1049,
#  'inimungkin': 1355,
#  'option': 2368,
#  'sendiri': 3009,
#  'part': 2448,
#  'ongkos': 2355,
#  'tetap': 3347,
#  'expedisinya': 1056,
#  'tunda': 3478,
#  'ngambil': 2213,
#  'profesional': 2670,
#  'foto': 1105,
#  'post': 2635,
#  'poto': 2639,
#  'ditokopedia': 939,
#  'poduk': 2623,
#  'brng': 543,
#  'seperri': 3020,
#  'seblum': 2937,
#  'ramai': 2721,
#  'un': 3505,
#  'install': 1368,
#  'pindah': 2595,
#  'shopeelazada': 3063,
#  'bukalapakakin': 575,
#  'erorr': 1036,
#  'sekali': 2958,
#  'robot': 2834,
#  'jawab': 1429,
#  'sengaja': 3013,
#  'makan': 1957,
#  'gaji': 1131,
#  'buta': 634,
#  'mundur': 2168,
#  'non': 2264,
#  'aktifsaya': 85,
#  'aktiftoko': 86,
#  'maintenance': 1954,
#  'wajar': 3595,
#  'aduh': 38,
#  'ampun': 130,
#  'gercep': 1163,
#  'nyambing': 2300,
#  'bel': 351,
#  'anggap': 141,
#  'dompet': 958,
#  'aa': 0,
#  'kendala': 1591,
#  'kakak': 1499,
#  'alami': 101,
#  'ktpno': 1731,
#  'telphone': 3277,
#  'digital': 881,
#  'kuota': 1742,
#  'balikin': 259,
#  'vouchernya': 3586,
#  'pembelikomplain': 2507,
#  'bisatpi': 486,
#  'jasalancar': 1424,
#  'motong': 2148,
#  'sesal': 3040,
#  'masalahpasti': 2007,
#  'komplainblm': 1686,
#  'orange': 2371,
#  'koid': 1664,
#  'hari': 1247,
#  'jemput': 1452,
#  'dichat': 877,
#  'barangbarang': 297,
#  'oke': 2328,
#  'ongkirn': 2351,
#  'codnya': 733,
#  'dibatasin': 865,
#  'belnja': 374,
#  'ratus': 2731,
#  'dapat': 808,
#  'grtis': 1190,
#  'oren': 2377,
#  'kedok': 1560,
#  'kapok': 1518,
#  'lapor': 1831,
#  'gantung': 1146,
#  'lucu': 1928,
#  'gampang': 1138,
#  'livechatnya': 1903,
#  'telat': 3270,
#  'benar': 377,
#  'cth': 764,
#  'kemarin': 1577,
#  'bareng': 306,
#  'hrg': 1293,
#  'san': 2892,
#  'juta': 1478,
#  'asli': 198,
#  'bohong': 522,
#  'bebayar': 340,
#  'sebutin': 2939,
#  'etik': 1046,
#  'initapi': 1358,
#  'kualitas': 1735,
#  'lumayan': 1931,
#  'nasabah': 2195,
#  'urgent': 3542,
#  'chattidak': 711,
#  'pertanyataan': 2572,
#  'user': 3545,
#  'refundnya': 2755,
#  'konplain': 1707,
#  'ecommerce': 994,
#  'lepas': 1874,
#  'mendesakharusnya': 2062,
#  'kembalibagaimanapun': 1580,
#  'bldah': 497,
#  'samatapi': 2880,
#  'ok': 2327,
#  'siang': 3073,
#  'camat': 654,
#  'berbelitstatus': 400,
#  'diiterima': 894,
#  'terkirimhati': 3323,
#  'bukalapakbaru': 576,
#  'diupload': 943,
#  'aneh': 138,
#  'enak': 1023,
#  'langgar': 1814,
#  'tersebutdan': 3332,
#  'photo': 2584,
#  'ciplakmakin': 720,
#  'aplakasi': 167,
#  'jaring': 1421,
#  'full': 1114,
#  'mautanya': 2022,
#  'calon': 653,
#  'kecuali': 1557,
#  'link': 1892,
#  'okee': 2329,
#  'jelas': 1441,
#  'emosi': 1021,
#  'daftar': 789,
#  'kedaftargimana': 1558,
#  'maksutnya': 1962,
#  'pulahadehbikin': 2695,
#  'sajaauto': 2867,
#  'delete': 831,
#  'nge': 2214,
#  'freeze': 1112,
#  'kompatible': 1680,
#  'android': 135,
#  'bukajadinya': 569,
#  'kitapd': 1649,
#  'bayarsdh': 332,
#  'transfergimana': 3440,
#  'biar': 452,
#  'rasa': 2727,
#  'sen': 3007,
#  'menylelesaikan': 2087,
#  'payah': 2462,
#  'peasana': 2484,
#  'sesuaipembeli': 3045,
#  'pengembalianpadahal': 2525,
#  'penjualdimana': 2541,
#  'servis': 3037,
#  'handphonerugi': 1238,
#  'waktuuang': 3599,
#  'perangkat': 2549,
#  'kelartolong': 1565,
#  'perhati': 2558,
#  'sesiusterima': 3043,
#  'transaksierror': 3434,
#  'perbaikitidak': 2553,
#  'bis': 471,
#  'histori': 1276,
#  'barangthanks': 304,
#  'harap': 1244,
#  'cocok': 727,
#  'mincara': 2109,
#  'lupa': 1937,
#  'pinseingat': 2600,
#  'isi': 1387,
#  'caranyaini': 664,
#  'haridigunain': 1249,
#  'bisacoba': 474,
#  'jelaskansampe': 1444,
#  'bukalapaksedangkan': 596,
#  'gagalaneh': 1125,
#  'pemesanansaya': 2512,
#  'store': 3169,
#  'kecewasaya': 1554,
#  'total': 3418,
#  'jadi': 1399,
#  'inibukalapak': 1351,
#  'kecewasejauh': 1555,
#  'gaet': 1123,
#  'minat': 2108,
#  'pajang': 2413,
#  'sensitif': 3016,
#  'saran': 2896,
#  'kompak': 1676,
#  'nonaktif': 2265,
#  'tokoh': 3399,
#  'sayasy': 2919,
#  'berkalikali': 416,
#  'nyabintang': 2289,
#  'tindak': 3375,
#  'developer': 849,
#  'nyangkut': 2305,
#  'expedisi': 1055,
#  'telusur': 3281,
#  'sakit': 2872,
#  'sembuh': 2999,
#  'memuaskantapi': 2054,
#  'banda': 261,
#  'acehdi': 11,
#  'capai': 660,
#  'perkilonyapadahal': 2562,
#  'itupaling': 1395,
#  'an': 131,
#  'acehmohon': 13,
#  'timbang': 3372,
#  'acehmaunya': 12,
#  'aceh': 10,
#  'inibelakangan': 1350,
#  'daerah': 788,
#  'sampainyadicoba': 2885,
#  'terusongkir': 3339,
#  'bukaekpress': 566,
#  'berattidak': 398,
#  'tab': 3222,
#  'jelaspercuma': 1446,
#  'limite': 1886,
#  'transaksinyesel': 3436,
#  'belanjajelas': 361,
#  'sekaliperdetik': 2964,
#  'uninstalmakasih': 3517,
#  'sayabagi': 2909,
#  'digitalpelapak': 882,
#  'curang': 773,
#  'terimacobalah': 3313,
#  'komplainsampai': 1689,
#  'pelapakbats': 2491,
#  'berjalanterus': 413,
#  'nyalewat': 2297,
#  'alhamdulillah': 109,
#  'datang': 817,
#  'paro': 2446,
#  'kg': 1631,
#  'pulau': 2696,
#  'jawa': 1428,
#  'jembersemarang': 1449,
#  'label': 1758,
#  'screenshoot': 2924,
#  'dirumahterimakasih': 919,
#  'motor': 2149,
#  'byson': 642,
#  'alhamdulilah': 108,
#  'kak': 1498,
#  'form': 1099,
#  'file': 1084,
#  'format': 1102,
#  'xml': 3633,
#  'nanyain': 2194,
#  'komentar': 1670,
#  'repes': 2782,
#  'penuh': 2545,
#  'lanjur': 1817,
#  'lain': 1777,
#  'hatikayaknya': 1257,
#  'rejeki': 2760,
#  'voucer': 3584,
#  'historikalaupun': 1277,
#  'thok': 3354,
#  'penambahanknpa': 2514,
#  'kwalitas': 1753,
#  'rusa': 2853,
#  'barangtapi': 303,
#  'rusak': 2854,
#  'klaim': 1652,
#  'tolak': 3407,
#  'bukalapakmending': 589,
#  'ajalebih': 58,
#  'kantong': 1512,
#  'mantap': 1982,
#  'gue': 1196,
#  'log': 1910,
#  'tera': 3294,
#  'ah': 47,
#  'setia': 3050,
#  'recomend': 2744,
#  'super': 3195,
#  'kawan': 1536,
#  'diskusi': 927,
#  'cenderung': 680,
#  'korban': 1716,
#  'kocak': 1661,
#  'hadehh': 1217,
#  'adil': 29,
#  'kga': 1632,
#  'mudahpengiriman': 2156,
#  'cepatqualitas': 692,
#  'hargasaya': 1246,
#  'jaya': 1434,
#  'pelit': 2496,
#  'costumer': 753,
#  'service': 3035,
#  'trnsaksi': 3456,
#  'berhasilpulsa': 409,
#  'masuktagihan': 2012,
#  'adakomplen': 26,
#  'satu': 2901,
#  'rampog': 2723,
#  'paraaaaaaaahhhhh': 2436,
#  'buang': 551,
#  'iklanhasilnya': 1315,
#  'manfaatatnya': 1974,
#  'satupuntidak': 2903,
#  'laku': 1789,
#  'fakta': 1063,
#  'sekalichat': 2960,
#  'bisaenakan': 475,
#  'chip': 717,
#  'shoppee': 3068,
#  'kunci': 1740,
#  'merek': 2091,
#  'official': 2323,
#  'brand': 534,
#  'back': 225,
#  'bisabolak': 473,
#  'ajatolong': 61,
#  'lapakbisa': 1824,
#  'kelar': 1564,
#  'bolak': 523,
#  'blk': 500,
#  'dikirm': 900,
#  'nyampai': 2303,
#  'sayagak': 2912,
#  'aktiv': 87,
#  'cantum': 658,
#  'repotstatus': 2786,
#  'updatedi': 3530,
#  'kirimpembeli': 1646,
#  'ngomelauto': 2236,
#  'off': 2322,
#  'lunaspaylater': 1934,
#  'apapunselalu': 161,
#  'tersambungjawaban': 3331,
#  'agen': 43,
#  'sibuk': 3077,
#  'parahpayah': 2444,
#  'kapandulu': 1516,
#  'pembatalansekarang': 2501,
#  'hilangapk': 1272,
#  'puyeng': 2710,
#  'responya': 2805,
#  'kosong': 1719,
#  'nancep': 2192,
#  'tarik': 3257,
#  'pbb': 2478,
#  'koreksi': 1718,
#  'lancar': 1809,
#  'eror': 1035,
#  'seru': 3032,
#  'sebu': 2938,
#  'nyata': 2310,
#  'akunotp': 97,
#  'sms': 3122,
#  'masukvie': 2013,
#  'masukbolak': 2011,
#  'capca': 661,
#  'bukalapaksangat': 594,
#  'tele': 3272,
#  'anjurin': 151,
#  'pinjol': 2598,
#  ...}

# %%
#kolom pertama ini berarti jumlah dokumen
#kolom kedua berarti letak katanya
#kolom ketiga hasil dari tf

term_frequency_all = term_fit.transform(Ulasan)
print (term_frequency_all)
# Out:
#   (0, 172)	1
#   (0, 518)	1
#   (0, 559)	1
#   (0, 708)	1
#   (0, 725)	1
#   (0, 967)	1
#   (0, 1235)	1
#   (0, 1832)	1
#   (0, 1901)	1
#   (0, 1998)	1
#   (0, 2466)	1
#   (0, 2977)	1
#   (0, 3085)	1
#   (0, 3100)	2
#   (0, 3259)	1
#   (1, 111)	1
#   (1, 172)	2
#   (1, 368)	1
#   (1, 574)	1
#   (1, 997)	1
#   (1, 1167)	1
#   (1, 1243)	1
#   (1, 1253)	1
#   (1, 1270)	1
#   (1, 1314)	1
#   :	:
#   (1298, 2557)	1
#   (1298, 2626)	1
#   (1298, 3044)	1
#   (1298, 3312)	1
#   (1298, 3432)	1
#   (1299, 232)	1
#   (1299, 247)	1
#   (1299, 397)	1
#   (1299, 462)	2
#   (1299, 554)	1
#   (1299, 558)	1
#   (1299, 675)	1
#   (1299, 941)	1
#   (1299, 965)	1
#   (1299, 1322)	1
#   (1299, 1393)	1
#   (1299, 1491)	1
#   (1299, 1642)	1
#   (1299, 1656)	1
#   (1299, 1908)	2
#   (1299, 2084)	1
#   (1299, 2142)	1
#   (1299, 2216)	1
#   (1299, 2683)	1
#   (1299, 3432)	2

# %%
ulasan_tf = Ulasan[1] #memanggil kata pada index ke 1
print (ulasan_tf)
# Out:
# aplikasi ribet edit produk gilir hasil ujung nya iklan produk jual hilang alias otomatis hapus bukalapak tolong tingkat ulang sistem jual beli tinggal aplikasi

# %%
term_frequency = term_fit.transform([ulasan_tf]) #hanya menampilkan hasil document 1
print (term_frequency)
# Out:
#   (0, 111)	1
#   (0, 172)	2
#   (0, 368)	1
#   (0, 574)	1
#   (0, 997)	1
#   (0, 1167)	1
#   (0, 1243)	1
#   (0, 1253)	1
#   (0, 1270)	1
#   (0, 1314)	1
#   (0, 1465)	2
#   (0, 2286)	1
#   (0, 2386)	1
#   (0, 2667)	2
#   (0, 2814)	1
#   (0, 3100)	1
#   (0, 3376)	1
#   (0, 3377)	1
#   (0, 3410)	1
#   (0, 3499)	1
#   (0, 3501)	1

# %%
dokumen = term_fit.transform(Ulasan) #hasil perhitungan tf idf dalam 1 doc
tfidf_transformer = TfidfTransformer().fit(dokumen)
print (tfidf_transformer.idf_)

tfidf=tfidf_transformer.transform(term_frequency)
print (tfidf) #hasil manual dengan sistem pyhton
# Out:
# [7.4777413  7.07227619 7.4777413  ... 6.56145057 7.4777413  7.4777413 ]
#   (0, 3501)	0.2070232070922842
#   (0, 3499)	0.2806769227366515
#   (0, 3410)	0.15350271926930056
#   (0, 3377)	0.19202269132112737
#   (0, 3376)	0.21615918441146495
#   (0, 3100)	0.180104395192847
#   (0, 2814)	0.17134288187696178
#   (0, 2667)	0.3713224499882442
#   (0, 2386)	0.195058326253661
#   (0, 2286)	0.11080769243331486
#   (0, 1465)	0.297003587908905
#   (0, 1314)	0.21968100390196582
#   (0, 1270)	0.18400067868664344
#   (0, 1253)	0.2018408412943046
#   (0, 1243)	0.21449863810398628
#   (0, 1167)	0.2540073990667255
#   (0, 997)	0.25017896331930867
#   (0, 574)	0.09633523618203169
#   (0, 368)	0.12595318116860524
#   (0, 172)	0.20008525702226324
#   (0, 111)	0.26801912592696986

# %%
data_label = name_dataframe[["Nama pengguna", "Ulasan_siap", "Sentiment"]]

# %%
data_label["Ulasan_siap"] = data_label["Ulasan_siap"].fillna("tidak ada komentar")
# Out:
# <ipython-input-74-63aa05b24bd2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label["Ulasan_siap"] = data_label["Ulasan_siap"].fillna("tidak ada komentar")

# %%
data_label.to_excel("data_label.xlsx")

# %%
sentimen_data=pd.value_counts(data_label["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["#ccd5ae"])
plt.title('Bar chart')
plt.show()

# %%
plt.figure(figsize=(16, 6))

heatmap = sns.heatmap(name_dataframe.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12)

plt.tight_layout()

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize',
#        'ulasan_ears', 'Ulasan_normalized', 'Ulasan_stop_removed',
#        'Ulasan_Stemmed', 'Ulasan_siap', 'label', 'Polarity', 'Subjectivity',
#        'Sentiment', 'month'],
#       dtype='object')

# %%
train_s3 = data_label[data_label["Sentiment"] == 'Neutral']

# %% [markdown]
# # **Proses visualiasi kata terbanyak dari Neutral**

# %%
train_s3["Ulasan_siap"] = train_s3["Ulasan_siap"].fillna("tidak ada komentar")
# Out:
# <ipython-input-80-4fc6d4cc0ecf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s3["Ulasan_siap"] = train_s3["Ulasan_siap"].fillna("tidak ada komentar")

# %%
all_text_s0 = ' '.join(word for word in train_s3["Ulasan_siap"])
wordcloud = WordCloud(colormap='gist_stern', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s0)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
print("Neutral words")
plt.show()
# Out:
# Neutral words

# %%
from wordcloud import WordCloud

# %%
train_s0 = data_label[data_label["Sentiment"] == 'Negative']

# %%
train_s0["Ulasan_siap"] = train_s0["Ulasan_siap"].fillna("tidak ada komentar")
# Out:
# <ipython-input-84-dc46e426e77c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s0["Ulasan_siap"] = train_s0["Ulasan_siap"].fillna("tidak ada komentar")

# %%
train_s0
# Out:
#                       Nama pengguna  \
# 10                    Syamriza Alam
# 12                    Mirdad Wangsa
# 22                   Popi Anggraini
# 42                       Adityo Nur
# 71                   Dadang Setiaji
# 75                     agus jatnika
# 196                    Ahmad Sahrul
# 209            Dery Riyanto (STARK)
# 239                 hidayat mudaris
# 283              Ilham Padka Wijaya
# 339                     imam maliki
# 340   Infinik smart6 Infinik smart6
# 370                   Farhan Fiddin
# 400                   Dinnss Livina
# 463                   Afifur Rohman
# 479         Kaloka Galih Kayu Wangi
# 486                    Bam Hendrian
# 521                          Lemuel
# 550                   Sutris Trisno
# 599                 26Naya Queensya
# 626                          eH boy
# 651                   inaya putry26
# 751                   Candra Wijaya
# 757                        Nursamsi
# 792               Sondang Panjaitan
# 810              haidar dabi kataro
# 830                 Pengguna Google
# 839                     Najwa Jemur
# 856                 Pengguna Google
# 895                 Pengguna Google
# 898                       Hr Tester
# 955                 Pengguna Google
# 1016                      Fian Syah
# 1046                       Ucu Imen
# 1082           Dony Settia Official
# 1086                   Bayu Arsandi
# 1091                    Fudin Fudin
# 1122                Pengguna Google
# 1192                Pengguna Google
# 1194                Pengguna Google
# 1271                Pengguna Google
# 1273                  wisnul arifin
#
#                                             Ulasan_siap Sentiment
# 10    buka bantu nya bantu memperaulitcall center ny...  Negative
# 12    rugi beli masak barang bayar nunggunya batal u...  Negative
# 22    transfer baca virtual account verifikasi saldo...  Negative
# 42    beku alas kalo bekuin akun baik kasih alas jal...  Negative
# 71    saldo dana sambung tibatiba potong voucher gam...  Negative
# 75    kasih bintang segitu blapak buka detail pesan ...  Negative
# 196   playlater kalo hp nomor nya hilang alas ktp pa...  Negative
# 209   tangan kirim jam suruh tunggu batalin pesan je...  Negative
# 239   tolong rumit verifikasi akun saldo bukalapak p...  Negative
# 283   bukalapak marketplace nya sellerseller tipu ka...  Negative
# 339   hati hubung akun aplkasi iniakun kena hack tra...  Negative
# 340   bintang deh gagal pinjem alas pinjam tunai akt...  Negative
# 370   beli emas buka emas tarik alas konekai masalah...  Negative
# 400   pakai pinjol nya kredivo sadis biaya layan rib...  Negative
# 463   aplikasi bagus minus ongkir mahal voucher paka...  Negative
# 479   jual emas bukaemas susah banget banget problem...  Negative
# 486   kesini sistem nya berat ajabanyak sisrem gunab...  Negative
# 521   mohon maaf kasih bintang alas hubung cs via ch...  Negative
# 550   guna setia bltp perlahan alih toko online lain...  Negative
# 599               beli gampang bagus belanja game makan  Negative
# 626   developer bukalapak lihat aplikasi shopee laza...  Negative
# 651   aplikasi nya visa live chat maju bukalapak pes...  Negative
# 751   aplikasi bangkai belanja barang minggu bayar a...  Negative
# 757   mantap paylater limit paylaternya ditambahin c...  Negative
# 792   buka lapak bertangung kembali dana jelas alas ...  Negative
# 810   proses konfirmasi nya lamaproses kirim nya lam...  Negative
# 830   heran aplikasi upload jual barang kaya susahhh...  Negative
# 839   kalo bukalapak rame tampil barang jual bayar i...  Negative
# 856   baik servernya fitur macet traffict diserver j...  Negative
# 895   bukastruk gagal struk identifikasi deteksi dup...  Negative
# 898   aplikasi bagus bantu kendala admin komplain me...  Negative
# 955   kurangtapi suka dwngan tampil bukalapak update...  Negative
# 1016  barang pesan langsung aju komplain selesai isi...  Negative
# 1046  hati hati download aplikasi korban bayar lunas...  Negative
# 1082  kali kecewa kembali refund dana masuk dompet s...  Negative
# 1086            seller slow respon pesan batal otomatis  Negative
# 1091               barang lengkap minimal gratis ongkir  Negative
# 1122  baharu akun email username error pakai transak...  Negative
# 1192  bagus sih jual gampang fiturnya mudah lapak op...  Negative
# 1194  bukalapak update beres koneksi bagus wifi kenc...  Negative
# 1271  baguskarena bukalapak beli voucher game via pu...  Negative
# 1273  aplikasi belanja mepersulit melakukakan ubah d...  Negative

# %% [markdown]
# # **Proses visualiasi kata terbanyak dari Negatif**

# %%
all_text_s0 = ' '.join(word for word in train_s0["Ulasan_siap"])
wordcloud = WordCloud(colormap='Reds', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s0)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
print("Negatif words")
plt.show()
# Out:
# Negatif words

# %% [markdown]
# # **Proses visualiasi kata terbanyak dari Positif**

# %%
train_s1 = data_label[data_label["Sentiment"] == 'Positive']

# %%
train_s1["Ulasan_siap"] = train_s1["Ulasan_siap"].fillna("tidak ada komentar")
# Out:
# <ipython-input-88-d1952b0b5859>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s1["Ulasan_siap"] = train_s1["Ulasan_siap"].fillna("tidak ada komentar")

# %%
train_s1
# Out:
#         Nama pengguna                                        Ulasan_siap  \
# 0             yOga 04  aplikasi marketplace hancur sistem bukabantuan...
# 3            Sis Maya  sedih belanja mitra bukalapak live bukabantuan...
# 4              Gb Jkt  keri belanja bukalapak beli diangap jahat main...
# 6      Rino Syaprudin  bukalapak kena charge rp kalo beli barang roda...
# 9     Muhammad Hafidz  rugi rp top up dana bukalapak bayar via atm br...
# ...               ...                                                ...
# 1261  Pengguna Google  terap kode promo seringkali hilang promonya tr...
# 1272      King Arthur  minkemaren top up dana aplikasi bukalapak baya...
# 1275         Jay Nata  aplikasi bagus sayang main tau standart harga ...
# 1286  Pengguna Google  alhamdulillah ubah aplikasi lelet banget user ...
# 1287  Pengguna Google  rada kecewa top up bayar tagih saldo rekning o...
#
#      Sentiment
# 0     Positive
# 3     Positive
# 4     Positive
# 6     Positive
# 9     Positive
# ...        ...
# 1261  Positive
# 1272  Positive
# 1275  Positive
# 1286  Positive
# 1287  Positive
#
# [171 rows x 3 columns]

# %%
all_text_s1 = ' '.join(word for word in train_s1["Ulasan_siap"])
wordcloud = WordCloud(colormap='Blues', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s1)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Ulasan Positif")
plt.margins(x=0, y=0)
print("Positif words")
plt.show()
# Out:
# Positif words

# %%
data_label['Ulasan_clean'] = data_label['Ulasan_siap'].fillna("tidak ada komentar")
# Out:
# <ipython-input-91-2ed151e306fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['Ulasan_clean'] = data_label['Ulasan_siap'].fillna("tidak ada komentar")

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# # **Mensplit Data Ulasan Siap Dan Data Sentiment**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_siap'], data_label['Sentiment'],
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# %% [markdown]
# # **Melakukan Pembelajaran Melihat Akurasi Dan Mendapatkan Kolom Baru Prediksi**

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(data_label['Ulasan_siap'])

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, data_label['Sentiment'], test_size=0.2, random_state=42)

# Train the Gaussian Naive Bayes classifier on the training set
gnb = GaussianNB()
gnb.fit(X_train.toarray(), y_train)

# Evaluate the classifier on the testing set
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)

# Evaluate the classifier on the testing set
y_pred = gnb.predict(X_test.toarray())
cm = confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))

# Use the classifier to predict the sentiment class for all reviews in the dataset
data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# Save the resulting dataframe to a new CSV file
data_label.to_csv('predicted_sentiment1.csv', index=False)
# Out:
# Accuracy: 0.6807692307692308
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         6
#      Neutral       0.87      0.73      0.79       217
#     Positive       0.30      0.51      0.38        37
#
#     accuracy                           0.68       260
#    macro avg       0.39      0.41      0.39       260
# weighted avg       0.77      0.68      0.72       260
# <ipython-input-95-100d2ce1e090>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# %%
import numpy as np

X_train = X_train.toarray()
X_test = X_test.toarray()

# %% [markdown]
# # **Melihat Akurasi Terbaik**

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# Gaussian Naive Bayes with original data
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_gnb = gnb.predict(X_test)
print('Original Results:')
print(classification_report(y_test, y_gnb))
print(confusion_matrix(y_test, y_gnb))
print('Accuracy with original test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with undersampling mengurangi class
rus = RandomUnderSampler(random_state=1)
X_rus, y_rus = rus.fit_resample(X_train, y_train)
gnb = GaussianNB()
gnb.fit(X_rus, y_rus)
y_gnb = gnb.predict(X_test)
print('Undersampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with undersampling test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with oversampling menggandakan class
smote = SMOTE(random_state=1)
X_smote, y_smote = smote.fit_resample(X_train, y_train)
gnb = GaussianNB()
gnb.fit(X_smote, y_smote)
y_gnb = gnb.predict(X_test)
print('Oversampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with oversampling test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with combined oversampling and undersampling menggandakan dan mengurangi class
rus = RandomUnderSampler(random_state=1)
X_rus, y_rus = rus.fit_resample(X_train, y_train)

smote = SMOTE(random_state=1)
X_smt, y_smt = smote.fit_resample(X_rus, y_rus)

gnb = GaussianNB()
gnb.fit(X_smt, y_smt)
y_gnb = gnb.predict(X_test)
print('Combined Oversampling and Undersampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with combined oversampling and undersampling test data:', accuracy_score(y_test, y_gnb))
# Out:
# Original Results:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         6
#      Neutral       0.87      0.73      0.79       217
#     Positive       0.30      0.51      0.38        37
#
#     accuracy                           0.68       260
#    macro avg       0.39      0.41      0.39       260
# weighted avg       0.77      0.68      0.72       260
#
# [[  0   6   0]
#  [ 15 158  44]
#  [  1  17  19]]
# Accuracy with original test data: 0.6807692307692308
# Undersampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.06      0.83      0.11         6
#      Neutral       0.88      0.31      0.46       217
#     Positive       0.19      0.49      0.27        37
#
#     accuracy                           0.35       260
#    macro avg       0.38      0.54      0.28       260
# weighted avg       0.77      0.35      0.43       260
#
# Accuracy with undersampling test data: 0.35
# Oversampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         6
#      Neutral       0.87      0.73      0.79       217
#     Positive       0.30      0.51      0.38        37
#
#     accuracy                           0.68       260
#    macro avg       0.39      0.41      0.39       260
# weighted avg       0.77      0.68      0.72       260
#
# Accuracy with oversampling test data: 0.6807692307692308
# Combined Oversampling and Undersampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.06      0.83      0.11         6
#      Neutral       0.88      0.31      0.46       217
#     Positive       0.19      0.49      0.27        37
#
#     accuracy                           0.35       260
#    macro avg       0.38      0.54      0.28       260
# weighted avg       0.77      0.35      0.43       260
#
# Accuracy with combined oversampling and undersampling test data: 0.35

# %%
import numpy as np

# %%
from sklearn.feature_extraction.text import TfidfVectorizer             #menghitung n menjumlah kan dan menjumlah kan tf and n berdasarkan seluruh dokumen
vectorizer = TfidfVectorizer(decode_error='replace', encoding='utf-8')

# %%
data_label['predicted_sentiment_class'].value_counts()
# Out:
# Neutral     950
# Positive    264
# Negative     86
# Name: predicted_sentiment_class, dtype: int64

# %% [markdown]
# # **VISUALISASI Hasil Prediksi**

# %%
data_label['predicted_sentiment_class'].hist()
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# # **CrossValidation gaussion naive bayes**

# %% [markdown]
# ![10-K-Fold-Cross-Validation.png](data:image/png;base64,...)

# %% [markdown]
# **sample random**
#
# mengambil secara acak dari daftar sample atau sampling frame yang tersedia setiap individu memiliki peluang yang sama untuk terpilih
# peluang tersebut ada melakukan peluang sama ketika mempunyai data besar akan memliki peluang lebih besar untuk terpilih tetapi sebaliknya ketika mempunyai data dikit dapat peluang lebih sedikit

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_siap'], data_label['Sentiment'],
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# Vectorize the text data
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# Create the Naive Bayes Classifier object
gnb = GaussianNB()

# Perform cross-validation
scores = cross_val_score(gnb, X_train.toarray(), y_train, cv=5)

# Print the cross-validation scores
print('Cross-validation scores:', scores)

# Fit the classifier to the training data
gnb.fit(X_train.toarray(), y_train)

# Predict the sentiment of the test data
y_pred = gnb.predict(X_test.toarray())

# Print the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:\n', conf_matrix)
# Out:
# Cross-validation scores: [0.61538462 0.59401709 0.62393162 0.6025641  0.6025641 ]
# Confusion Matrix:
#  [[ 0  4  0]
#  [ 7 71 31]
#  [ 0 10  7]]

# %%
# Convert sparse matrix to dense numpy array
X_train_dense = X_train.toarray()
X_test_dense = X_test.toarray()

# Print the scores on the training and test sets
print('Training set score: {:.4f}'.format(gnb.score(X_train_dense, y_train)))
print('Test set score: {:.4f}'.format(gnb.score(X_test_dense, y_test)))

#ternyata permasalahannya bukan traning tapi test set score nya 0.50%
# Out:
# Training set score: 0.8897
# Test set score: 0.6000

# %%
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.6

# %%
vectorizer
# Out:
# TfidfVectorizer()

# %%
nb = GaussianNB(var_smoothing=1.0) # untuk tidak overviting

# %% [markdown]
# # **Data Prediksi**

# %%
data_label.tail(100)
# Out:
#                         Nama pengguna  \
# 1200                  rapfandra nicko
# 1201                       Roberto 21
# 1202  agus Bengkel Kabelbody Sidoarjo
# 1203                    Munadi Budjid
# 1204                     eka jayaos46
# ...                               ...
# 1295                   aditya anugrah
# 1296                     ary surjamin
# 1297                           yunita
# 1298                      Xiaomi Mi03
# 1299                          Go Cell
#
#                                             Ulasan_siap Sentiment  \
# 1200  bukalapak maling kembali dana isi saldo masuk ...   Neutral
# 1201                                         mudah guna   Neutral
# 1202                                      barang kecewa   Neutral
# 1203                               manfaat guna belanja   Neutral
# 1204  bantu jual belanja terima kasih sukses ya buka...   Neutral
# ...                                                 ...       ...
# 1295  aplikasi buruk ngrestart kalo lanjut transaksi...   Neutral
# 1296  barang sesuai les cepat respon kirim cepat ter...   Neutral
# 1297  bayar mesan buku buku kirim batas mesan batal ...   Neutral
# 1298  aplikasi bantu banget belanja jarak mudah tran...   Neutral
# 1299  diupdate bagus ngebug berat buffering loading ...   Neutral
#
#                                            Ulasan_clean  \
# 1200  bukalapak maling kembali dana isi saldo masuk ...
# 1201                                         mudah guna
# 1202                                      barang kecewa
# 1203                               manfaat guna belanja
# 1204  bantu jual belanja terima kasih sukses ya buka...
# ...                                                 ...
# 1295  aplikasi buruk ngrestart kalo lanjut transaksi...
# 1296  barang sesuai les cepat respon kirim cepat ter...
# 1297  bayar mesan buku buku kirim batas mesan batal ...
# 1298  aplikasi bantu banget belanja jarak mudah tran...
# 1299  diupdate bagus ngebug berat buffering loading ...
#
#      predicted_sentiment_class
# 1200                   Neutral
# 1201                  Negative
# 1202                  Negative
# 1203                   Neutral
# 1204                   Neutral
# ...                        ...
# 1295                   Neutral
# 1296                   Neutral
# 1297                   Neutral
# 1298                   Neutral
# 1299                   Neutral
#
# [100 rows x 5 columns]

# %% [markdown]
# # **CONFIUSIN MATRIK**
# melihat seberapa baik distribusi dari setiap kelas

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
print('--------------------- confusion matrix  ----------------------------')
print(confusion_matrix(y_test, y_pred))
print('--------------------- classification report  ----------------------------')
print(classification_report(y_test, y_pred))
# Out:
# --------------------- confusion matrix  ----------------------------
# [[ 0  4  0]
#  [ 7 71 31]
#  [ 0 10  7]]
# --------------------- classification report  ----------------------------
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         4
#      Neutral       0.84      0.65      0.73       109
#     Positive       0.18      0.41      0.25        17
#
#     accuracy                           0.60       130
#    macro avg       0.34      0.35      0.33       130
# weighted avg       0.72      0.60      0.65       130

# %% [markdown]
# # **Melihat Kesalahan Classifikasi**

# %%
# visualize confusion matrix with seaborn heatmap

cm_matrix = pd.DataFrame(data=cm, columns=['Negative:1', 'Neutral:0', 'Positive:2'],
                                 index=['Negative:1', 'Neutral:0', 'Positive:2'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <Axes: >

# %%
X_test
# Out:
# <130x3412 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1554 stored elements in Compressed Sparse Row format>

# %%
X_train
# Out:
# <1170x3412 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16349 stored elements in Compressed Sparse Row format>

# %%
y_test
# Out:
# 70       Neutral
# 309      Neutral
# 1035     Neutral
# 399      Neutral
# 224      Neutral
#           ...
# 716     Positive
# 1055     Neutral
# 181      Neutral
# 1206     Neutral
# 90       Neutral
# Name: Sentiment, Length: 130, dtype: object

# %%
y_train
# Out:
# 1127     Neutral
# 973      Neutral
# 1179     Neutral
# 616      Neutral
# 500     Positive
#           ...
# 77       Neutral
# 834      Neutral
# 776      Neutral
# 963      Neutral
# 423      Neutral
# Name: Sentiment, Length: 1170, dtype: object

# %%
print(y_train)
# Out:
# 1127     Neutral
# 973      Neutral
# 1179     Neutral
# 616      Neutral
# 500     Positive
#           ...
# 77       Neutral
# 834      Neutral
# 776      Neutral
# 963      Neutral
# 423      Neutral
# Name: Sentiment, Length: 1170, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, classification_report
import pandas as pd

# Assuming you have loaded the data into the 'data_label' DataFrame.

# Initialize the CountVectorizer
vectorizer = CountVectorizer()

# Transform the text data into numerical feature vectors
X = vectorizer.fit_transform(data_label['Ulasan_siap'])

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, data_label['Sentiment'], test_size=0.3, random_state=42)

# Train the Gaussian Naive Bayes classifier on the training set
gnb = GaussianNB()
gnb.fit(X_train.toarray(), y_train)

# Evaluate the classifier on the testing set
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)

# Evaluate the classifier on the testing set
y_pred = gnb.predict(X_test.toarray())

# Get the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Print the confusion matrix
print("Confusion Matrix:")
print(cm)

# Print classification report with precision, recall, F1-score for each class
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Use the classifier to predict the sentiment class for all reviews in the dataset
data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# Save the resulting dataframe to a new CSV file
data_label.to_csv('predicted_sentiment1.csv', index=False)
# Out:
# Accuracy: 0.617948717948718
# Confusion Matrix:
# [[  0   9   2]
#  [ 32 214  83]
#  [  1  22  27]]
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00        11
#      Neutral       0.87      0.65      0.75       329
#     Positive       0.24      0.54      0.33        50
#
#     accuracy                           0.62       390
#    macro avg       0.37      0.40      0.36       390
# weighted avg       0.77      0.62      0.67       390
# <ipython-input-117-27db70896ee7>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())
