# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafiryd/Rafiryd/blob/rafiryd/skripsi24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Referensi: https://www.linkedin.com/pulse/how-scrape-google-play-reviews-4-simple-steps-using-python-kundi/

# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

import seaborn as sns

# %%
#Scrape desired number of reviews
#Run kode ini jika ingin scrape data dengan jumlah tertentu. Ganti (misal, ingin scrape sejumlah 1000, maka ganti kode , count = 1000 )

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.bukalapak.android',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=1300, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %% [markdown]
# Problems slovlig tools = mencari akar permasalahan pada suatu masalah
#
# 5 why
#
# metode mencari problems sloving dengan cara menanyakan apa penyebab permasalahaan muncul dan mencari jawabannya. hal ini di lakUkan berkali klai sampai permasalahan dapat tergambar dengan jelas
#
# action priority
#
# diagram yang dapat di gunakan untuk mencari prioritas masalah berdasarkan impact atas benefit yang bisa diberikan dengan diagram ini kita memilih masalah yang impactnya mayoritas dari permasalahan yang ada.
#
# fishbone digram
#
# digram yang dapat di gunakan untuk merinci masalah dan membantu mencari akar masalah yang dapat dilihat dari beberapa point of view
#
# flowchart/algo
#
# metode pemecahan masalah dengan cara memetakan flow atau membuat pseudo algoritma yang untuk menentukan masalah dan cara untuk mencari solusinya secara sistematis

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId       userName  \
# 0  f2e26548-83d2-4bcf-bac3-6dc9db1cb12d   Nizar Rayyan
# 1  5ef5f760-f72a-473b-9fb3-48e5556cefc6     Fandy Komo
# 2  2aff4969-ae41-4e08-a1f0-a6c1acd0c3f4  Triadhi Purna
# 3  fd7ccf35-79f2-42a1-a996-95741c2dc22b  Hendi Suhendi
# 4  83453da6-3fbf-4f64-9640-5691d151aee9      halim nur
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# 1  https://play-lh.googleusercontent.com/a/AAcHTt...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a-/AD_cM...
# 4  https://play-lh.googleusercontent.com/a-/AD_cM...
#
#                                              content  score  thumbsUpCount  \
# 0  Paylater ngk bener.. selalu di batalkan otomat...      1            277
# 1  Tambah kesini buka lapak tambah kurang bagus p...      1            144
# 2  Batal pesanan susah amat yak?? Penjual awal bi...      1             24
# 3  Min mautanya, saya jual barang di bukalapak, t...      3              1
# 4  Saya beli barang udah 2x tapi sistemnya kayak ...      1              3
#
#   reviewCreatedVersion                  at  \
# 0               5.31.3 2023-04-16 23:03:31
# 1               5.31.3 2023-05-05 02:37:25
# 2               5.31.3 2023-05-19 12:12:22
# 3               5.32.1 2023-05-23 11:51:06
# 4               5.31.3 2023-05-23 07:36:27
#
#                                         replyContent           repliedAt  \
# 0  Hai, mohon maaf atas ketidaknyamanannya. Jika ... 2020-03-06 11:44:30
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4                                               None                 NaT
#
#   appVersion
# 0     5.31.3
# 1     5.31.3
# 2     5.31.3
# 3     5.32.1
# 4     5.31.3

# %%
len(df_busu.index) #count the number of data we got
# Out:
# 1300

# %%
df_busu[['userName', 'score','at', 'content']].tail()  #preview userName, rating, date-time, and reviews only
# Out:
#                  userName  score                  at  \
# 1295      Pengguna Google      2 2018-11-24 10:55:14
# 1296        hendrik teguh      1 2023-05-04 01:34:09
# 1297           Sam Wijaya      1 2020-12-06 03:27:32
# 1298  SOFYAN BAZERGAN,SAP      3 2023-03-10 05:17:43
# 1299            Erfan Dwi      1 2023-04-06 13:59:36
#
#                                                 content
# 1295  tidak ada tombol 'pembatalan pesanan' di detai...
# 1296  Komplain belum ada kesepakatan udah keburu dit...
# 1297  aplikasi online shop paling lambat dan berat l...
# 1298  Layanan tidak baik dan sangat lama respon.kare...
# 1299  Masa tambah saldo dana tidak bisa masuk dari t...

# %%
name_dataframe = df_busu.loc[:,["userName", "score", "at", "content"]]
name_dataframe.rename(columns={"userName": "Nama pengguna", "score":"Rating", "at": "Date", "content": "Ulasan"}, inplace=True)

# %%
name_dataframe.tail()
# Out:
#             Nama pengguna  Rating                Date  \
# 1295      Pengguna Google       2 2018-11-24 10:55:14
# 1296        hendrik teguh       1 2023-05-04 01:34:09
# 1297           Sam Wijaya       1 2020-12-06 03:27:32
# 1298  SOFYAN BAZERGAN,SAP       3 2023-03-10 05:17:43
# 1299            Erfan Dwi       1 2023-04-06 13:59:36
#
#                                                  Ulasan
# 1295  tidak ada tombol 'pembatalan pesanan' di detai...
# 1296  Komplain belum ada kesepakatan udah keburu dit...
# 1297  aplikasi online shop paling lambat dan berat l...
# 1298  Layanan tidak baik dan sangat lama respon.kare...
# 1299  Masa tambah saldo dana tidak bisa masuk dari t...

# %%
name_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nama pengguna  1300 non-null   object
#  1   Rating         1300 non-null   int64
#  2   Date           1300 non-null   datetime64[ns]
#  3   Ulasan         1300 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 40.8+ KB

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].astype(str)
name_dataframe.head()
# Out:
#    Nama pengguna  Rating                Date  \
# 0   Nizar Rayyan       1 2023-04-16 23:03:31
# 1     Fandy Komo       1 2023-05-05 02:37:25
# 2  Triadhi Purna       1 2023-05-19 12:12:22
# 3  Hendi Suhendi       3 2023-05-23 11:51:06
# 4      halim nur       1 2023-05-23 07:36:27
#
#                                               Ulasan
# 0  Paylater ngk bener.. selalu di batalkan otomat...
# 1  Tambah kesini buka lapak tambah kurang bagus p...
# 2  Batal pesanan susah amat yak?? Penjual awal bi...
# 3  Min mautanya, saya jual barang di bukalapak, t...
# 4  Saya beli barang udah 2x tapi sistemnya kayak ...

# %%
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].str.lower()

# %%
import string 
import re 
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

def remove_links(text):
    # menghapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus URL
    return text.replace("http://", " ").replace("https://", " ")
                
name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_links)

# %%
#menghapus number
def remove_number(text):
    return  re.sub(r"\d+", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_number)

# %%
#menghapus punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_punctuation)

# %%
# menghapus single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", " ", text)

name_dataframe['Ulasan'] = name_dataframe['Ulasan'].apply(remove_singl_char)

# %%
# Tokenisasi 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

name_dataframe['Ulasan_tokenize'] = name_dataframe['Ulasan'].apply(word_tokenize_wrapper)

# %%
name_dataframe
# Out:
#             Nama pengguna  Rating                Date  \
# 0            Nizar Rayyan       1 2023-04-16 23:03:31
# 1              Fandy Komo       1 2023-05-05 02:37:25
# 2           Triadhi Purna       1 2023-05-19 12:12:22
# 3           Hendi Suhendi       3 2023-05-23 11:51:06
# 4               halim nur       1 2023-05-23 07:36:27
# ...                   ...     ...                 ...
# 1295      Pengguna Google       2 2018-11-24 10:55:14
# 1296        hendrik teguh       1 2023-05-04 01:34:09
# 1297           Sam Wijaya       1 2020-12-06 03:27:32
# 1298  SOFYAN BAZERGAN,SAP       3 2023-03-10 05:17:43
# 1299            Erfan Dwi       1 2023-04-06 13:59:36
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     tambah kesini buka lapak tambah kurang bagus p...
# 2     batal pesanan susah amat yak penjual awal bila...
# 3     min mautanya saya jual barang di bukalapak tap...
# 4     saya beli barang udah    tapi sistemnya kayak ...
# ...                                                 ...
# 1295  tidak ada tombol pembatalan pesanan di detail ...
# 1296  komplain belum ada kesepakatan udah keburu dit...
# 1297  aplikasi online shop paling lambat dan berat l...
# 1298  layanan tidak baik dan sangat lama responkaren...
# 1299  masa tambah saldo dana tidak bisa masuk dari t...
#
#                                         Ulasan_tokenize
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [batal, pesanan, susah, amat, yak, penjual, aw...
# 3     [min, mautanya, saya, jual, barang, di, bukala...
# 4     [saya, beli, barang, udah, tapi, sistemnya, ka...
# ...                                                 ...
# 1295  [tidak, ada, tombol, pembatalan, pesanan, di, ...
# 1296  [komplain, belum, ada, kesepakatan, udah, kebu...
# 1297  [aplikasi, online, shop, paling, lambat, dan, ...
# 1298  [layanan, tidak, baik, dan, sangat, lama, resp...
# 1299  [masa, tambah, saldo, dana, tidak, bisa, masuk...
#
# [1300 rows x 5 columns]

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize'], dtype='object')

# %%
#Run This Code to Sort the Data By Date 
# tanggal 26-04-2022 sampai 12-10-2022

new_df = name_dataframe[['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize']]
sorted_df = new_df.sort_values(by='Date', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#          Nama pengguna  Rating                Date  \
# 968   Tatang Supriatna       5 2023-05-27 12:47:14
# 574             BEN 10       5 2023-05-27 12:27:27
# 909      Yanto Sutandi       5 2023-05-27 12:09:56
# 46     miko wimdartoni       1 2023-05-27 11:57:03
# 1249        Heru Cahyo       5 2023-05-27 10:43:50
#
#                                                  Ulasan  \
# 968   lumayan buat lagi kepepet kebutuhan cuman saya...
# 574   coba di perbaiki buat aplikasi nya kalau buka ...
# 909   sangat suka brg sesuai sdh di coba mantap suks...
# 46    kenapa sih sma bukalapak ko mkin kesini transa...
# 1249                           barang amanlumayan cepat
#
#                                         Ulasan_tokenize
# 968   [lumayan, buat, lagi, kepepet, kebutuhan, cuma...
# 574   [coba, di, perbaiki, buat, aplikasi, nya, kala...
# 909   [sangat, suka, brg, sesuai, sdh, di, coba, man...
# 46    [kenapa, sih, sma, bukalapak, ko, mkin, kesini...
# 1249                       [barang, amanlumayan, cepat]

# %%
sorted_df.dtypes
# Out:
# Nama pengguna              object
# Rating                      int64
# Date               datetime64[ns]
# Ulasan                     object
# Ulasan_tokenize            object
# dtype: object

# %%
# Menghitung Distibusi Persebaran Kata
def freqDist_wrapper(text):
    return FreqDist(text)

Ulasan_fqsist = name_dataframe['Ulasan_tokenize'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(Ulasan_fqsist.head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(tidak, 4), (di, 3), (nya, 3), (kadang, 2), (...
# 1    [(tambah, 3), (buka, 2), (susah, 2), (di, 2), ...
# 2    [(batal, 3), (penjual, 2), (tp, 2), (amplop, 2...
# 3    [(di, 4), (barang, 3), (saya, 2), (jual, 2), (...
# 4    [(saya, 4), (beli, 3), (udah, 3), (malah, 3), ...
# Name: Ulasan_tokenize, dtype: object

# %%
name_dataframe['Ulasan_tokenize'].unique
# Out:
# <bound method Series.unique of 0       [paylater, ngk, bener, selalu, di, batalkan, o...
# 1       [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2       [batal, pesanan, susah, amat, yak, penjual, aw...
# 3       [min, mautanya, saya, jual, barang, di, bukala...
# 4       [saya, beli, barang, udah, tapi, sistemnya, ka...
#                               ...
# 1295    [tidak, ada, tombol, pembatalan, pesanan, di, ...
# 1296    [komplain, belum, ada, kesepakatan, udah, kebu...
# 1297    [aplikasi, online, shop, paling, lambat, dan, ...
# 1298    [layanan, tidak, baik, dan, sangat, lama, resp...
# 1299    [masa, tambah, saldo, dana, tidak, bisa, masuk...
# Name: Ulasan_tokenize, Length: 1300, dtype: object>

# %%
slank_word_dict = {
    "berjalansudah" : "berjalan",
    "paraah" : "parah",
    "keduakali" : "",
    "keduakali" : "kedua kali",
    "agak" : "sedikit",
    "pas" : "saat",
    "produkx" : "produknya",
    "sukamkasih" : "suka makasih",
    "gak" : "tidak",
    "cpt" : "cepat",
    "sdh" : "sudah",
    "recommend" : "rekomendasi",
    "bagusseller" : "bagus",
    "bagusssss" : "bagus",
    "bagussssss" : "bagus",
    "baguuussss" : "bagus",
    "cepatmakasih": "cepat",
    "cepatmantappp": "cepat",
    "cepatproduct": "cepat",
    "cepatrecomended": "cepat",
    "cepattoko": "cepat",
    "recomended": "rekomendasi",
    "recommended": "rekomendasi",
    "rekomendasi": "rekomendasi",
    "rekomended": "rekomendasi",
    }

def slank_normalized_term(document):
    return [slank_word_dict[term] if term in slank_word_dict else term for term in document]

# %%
normalizad_word = pd.read_csv("/content/kamusindonesia.csv (2).csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

# %%
name_dataframe['Ulasan_normalized'] = name_dataframe['Ulasan_tokenize'].apply(normalized_term).apply(slank_normalized_term)

# %%
name_dataframe
# Out:
#             Nama pengguna  Rating                Date  \
# 0            Nizar Rayyan       1 2023-04-16 23:03:31
# 1              Fandy Komo       1 2023-05-05 02:37:25
# 2           Triadhi Purna       1 2023-05-19 12:12:22
# 3           Hendi Suhendi       3 2023-05-23 11:51:06
# 4               halim nur       1 2023-05-23 07:36:27
# ...                   ...     ...                 ...
# 1295      Pengguna Google       2 2018-11-24 10:55:14
# 1296        hendrik teguh       1 2023-05-04 01:34:09
# 1297           Sam Wijaya       1 2020-12-06 03:27:32
# 1298  SOFYAN BAZERGAN,SAP       3 2023-03-10 05:17:43
# 1299            Erfan Dwi       1 2023-04-06 13:59:36
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     tambah kesini buka lapak tambah kurang bagus p...
# 2     batal pesanan susah amat yak penjual awal bila...
# 3     min mautanya saya jual barang di bukalapak tap...
# 4     saya beli barang udah    tapi sistemnya kayak ...
# ...                                                 ...
# 1295  tidak ada tombol pembatalan pesanan di detail ...
# 1296  komplain belum ada kesepakatan udah keburu dit...
# 1297  aplikasi online shop paling lambat dan berat l...
# 1298  layanan tidak baik dan sangat lama responkaren...
# 1299  masa tambah saldo dana tidak bisa masuk dari t...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [batal, pesanan, susah, amat, yak, penjual, aw...
# 3     [min, mautanya, saya, jual, barang, di, bukala...
# 4     [saya, beli, barang, udah, tapi, sistemnya, ka...
# ...                                                 ...
# 1295  [tidak, ada, tombol, pembatalan, pesanan, di, ...
# 1296  [komplain, belum, ada, kesepakatan, udah, kebu...
# 1297  [aplikasi, online, shop, paling, lambat, dan, ...
# 1298  [layanan, tidak, baik, dan, sangat, lama, resp...
# 1299  [masa, tambah, saldo, dana, tidak, bisa, masuk...
#
#                                       Ulasan_normalized
# 0     [paylater, enggak, benar, selalu, di, batalkan...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [batal, pesanan, susah, amat, ya, penjual, awa...
# 3     [min, mautanya, saya, jual, barang, di, bukala...
# 4     [saya, beli, barang, sudah, tapi, sistemnya, k...
# ...                                                 ...
# 1295  [tidak, ada, tombol, pembatalan, pesanan, di, ...
# 1296  [komplain, belum, ada, kesepakatan, sudah, keb...
# 1297  [aplikasi, online, shop, paling, lambat, dan, ...
# 1298  [layanan, tidak, baik, dan, sangat, lama, resp...
# 1299  [masa, tambah, saldo, dana, tidak, bisa, masuk...
#
# [1300 rows x 6 columns]

# %%
name_dataframe['Ulasan_normalized'].unique
# Out:
# <bound method Series.unique of 0       [paylater, enggak, benar, selalu, di, batalkan...
# 1       [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2       [batal, pesanan, susah, amat, ya, penjual, awa...
# 3       [min, mautanya, saya, jual, barang, di, bukala...
# 4       [saya, beli, barang, sudah, tapi, sistemnya, k...
#                               ...
# 1295    [tidak, ada, tombol, pembatalan, pesanan, di, ...
# 1296    [komplain, belum, ada, kesepakatan, sudah, keb...
# 1297    [aplikasi, online, shop, paling, lambat, dan, ...
# 1298    [layanan, tidak, baik, dan, sangat, lama, resp...
# 1299    [masa, tambah, saldo, dana, tidak, bisa, masuk...
# Name: Ulasan_normalized, Length: 1300, dtype: object>

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

name_dataframe['Ulasan_stop_removed'] = name_dataframe['Ulasan_normalized'].apply(stopwords_removal)

# %%
name_dataframe
# Out:
#             Nama pengguna  Rating                Date  \
# 0            Nizar Rayyan       1 2023-04-16 23:03:31
# 1              Fandy Komo       1 2023-05-05 02:37:25
# 2           Triadhi Purna       1 2023-05-19 12:12:22
# 3           Hendi Suhendi       3 2023-05-23 11:51:06
# 4               halim nur       1 2023-05-23 07:36:27
# ...                   ...     ...                 ...
# 1295      Pengguna Google       2 2018-11-24 10:55:14
# 1296        hendrik teguh       1 2023-05-04 01:34:09
# 1297           Sam Wijaya       1 2020-12-06 03:27:32
# 1298  SOFYAN BAZERGAN,SAP       3 2023-03-10 05:17:43
# 1299            Erfan Dwi       1 2023-04-06 13:59:36
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     tambah kesini buka lapak tambah kurang bagus p...
# 2     batal pesanan susah amat yak penjual awal bila...
# 3     min mautanya saya jual barang di bukalapak tap...
# 4     saya beli barang udah    tapi sistemnya kayak ...
# ...                                                 ...
# 1295  tidak ada tombol pembatalan pesanan di detail ...
# 1296  komplain belum ada kesepakatan udah keburu dit...
# 1297  aplikasi online shop paling lambat dan berat l...
# 1298  layanan tidak baik dan sangat lama responkaren...
# 1299  masa tambah saldo dana tidak bisa masuk dari t...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [batal, pesanan, susah, amat, yak, penjual, aw...
# 3     [min, mautanya, saya, jual, barang, di, bukala...
# 4     [saya, beli, barang, udah, tapi, sistemnya, ka...
# ...                                                 ...
# 1295  [tidak, ada, tombol, pembatalan, pesanan, di, ...
# 1296  [komplain, belum, ada, kesepakatan, udah, kebu...
# 1297  [aplikasi, online, shop, paling, lambat, dan, ...
# 1298  [layanan, tidak, baik, dan, sangat, lama, resp...
# 1299  [masa, tambah, saldo, dana, tidak, bisa, masuk...
#
#                                       Ulasan_normalized  \
# 0     [paylater, enggak, benar, selalu, di, batalkan...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [batal, pesanan, susah, amat, ya, penjual, awa...
# 3     [min, mautanya, saya, jual, barang, di, bukala...
# 4     [saya, beli, barang, sudah, tapi, sistemnya, k...
# ...                                                 ...
# 1295  [tidak, ada, tombol, pembatalan, pesanan, di, ...
# 1296  [komplain, belum, ada, kesepakatan, sudah, keb...
# 1297  [aplikasi, online, shop, paling, lambat, dan, ...
# 1298  [layanan, tidak, baik, dan, sangat, lama, resp...
# 1299  [masa, tambah, saldo, dana, tidak, bisa, masuk...
#
#                                     Ulasan_stop_removed
# 0     [paylater, batalkan, otomatis, kadang, nya, ga...
# 1     [kesini, buka, lapak, bagus, pelayanannya, kom...
# 2     [batal, pesanan, susah, ya, penjual, bilang, r...
# 3     [min, mautanya, jual, barang, bukalapak, baran...
# 4     [beli, barang, sistemnya, kayak, error, bayar,...
# ...                                                 ...
# 1295  [tombol, pembatalan, pesanan, detail, transaks...
# 1296  [komplain, kesepakatan, keburu, ditutup, penga...
# 1297  [aplikasi, online, shop, lambat, berat, load, ...
# 1298  [layanan, responkarena, call, cs, langsungsemu...
# 1299               [saldo, dana, masuk, tanggal, april]
#
# [1300 rows x 7 columns]

# %%
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting swifter
#   Downloading swifter-1.3.4.tar.gz (830 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 830.9/830.9 kB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (1.5.3)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.10/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2022.12.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (4.65.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (7.7.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from swifter) (2.2.1)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from swifter) (6.0.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (8.1.3)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2023.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (23.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.22.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2022.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.3.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.1 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (6.4.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.1.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.11.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.21)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.3.4-py3-none-any.whl size=16299 sha256=dda109946b2f6a009dc24e987ae96540470642d813e53e501d681c4dee9b3de7
#   Stored in directory: /root/.cache/pip/wheels/6c/bd/3e/2d6afc9bc36c9975f8e4215a270bbac6580c4361ebd6bb2323
# Successfully built swifter
# Installing collected packages: jedi, swifter
# Successfully installed jedi-0.18.2 swifter-1.3.4

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in name_dataframe['Ulasan_stop_removed']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

name_dataframe['Ulasan_Stemmed'] = name_dataframe['Ulasan_stop_removed'].swifter.apply(get_stemmed_term)
# Out:
# 4604
# ------------------------
# paylater : paylater
# batalkan : batal
# otomatis : otomatis
# kadang : kadang
# nya : nya
# gantian : ganti
# jatuh : jatuh
# tempo : tempo
# bayar : bayar
# biaya : biaya
# keterlambatan : lambat
# layanan : layan
# biar : biar
# merasakan : rasa
# rasakan : rasa
# sistem : sistem
# seenak : enak
# chat : chat
# susah : susah
# error : error
# menyalahkan : salah
# bikin : bikin
# pusing : pusing
# kesini : kesini
# buka : buka
# lapak : lapak
# bagus : bagus
# pelayanannya : layan
# komplan : komplan
# banget : banget
# beberapakali : beberapakali
# transaksi : transaksi
# rekening : rekening
# deh : deh
# kepotong : potong
# lapaknya : lapak
# terverifikasi : verifikasi
# kalo : kalo
# pengin : pengin
# komplain : komplain
# menu : menu
# upload : upload
# bukti : bukti
# bayarnya : bayar
# muncul : muncul
# kali : kali
# kehilangan : hilang
# uang : uang
# pembayaran : bayar
# gagal : gagal
# batal : batal
# pesanan : pesan
# ya : ya
# penjual : jual
# bilang : bilang
# ready : ready
# stok : stok
# habis : habis
# nomor : nomor
# duit : duit
# ditransfer : transfer
# dikirim : kirim
# amplop : amplop
# kosong : kosong
# pembeli : beli
# cs : cs
# bukabantuan : bukabantuan
# dikasih : kasih
# template : template
# kagak : kagak
# solusi : solusi
# suruh : suruh
# menunggu : tunggu
# jam : jam
# batas : batas
# proses : proses
# tuh : tuh
# parah : parah
# asli : asli
# dosa : dosa
# lu : lu
# menahan : tahan
# rejeki : rejeki
# orang : orang
# paraaaahhhh : paraaaahhhh
# min : min
# mautanya : mautanya
# jual : jual
# barang : barang
# bukalapak : bukalapak
# lihat : lihat
# calon : calon
# terkecuali : kecuali
# kasih : kasih
# link : link
# akses : akses
# beli : beli
# sistemnya : sistem
# kayak : kayak
# item : item
# saldo : saldo
# potong : potong
# kedaluarsa : kedaluarsa
# satunya : satu
# kirim : kirim
# keterangan : terang
# pakai : pakai
# kecewa : kecewa
# pelapak : lapak
# disaat : saat
# terkait : kait
# permintaan : minta
# pengembalian : kembali
# dana : dana
# penjualanpembatalan : penjualanpembatalan
# notif : notif
# apl : apl
# bulalapak : bulalapak
# nyanotif : nyanotif
# penjualan : jual
# email : email
# menanggapi : tanggap
# dibatalkan : batal
# kembalikan : kembali
# merugikan : rugi
# cek : cek
# mohon : mohon
# perbaiki : baik
# fitur : fitur
# tolong : tolong
# tabungan : tabung
# diskon : diskon
# diperbanyak : banyak
# produknya : produk
# produk : produk
# membeli : beli
# langsung : langsung
# fiture : fiture
# cicilan : cicil
# lunas : lunas
# moga : moga
# maju : maju
# aplikasi : aplikasi
# trnsaksi : trnsaksi
# pulsa : pulsa
# berhasilpulsa : berhasilpulsa
# masuktagihan : masuktagihan
# adakomplen : adakomplen
# diurus : urus
# bantuan : bantu
# live : live
# mesin : mesin
# olshop : olshop
# rampog : rampog
# paraaaaaaaahhhhh : paraaaaaaaahhhhh
# dear : dear
# check : check
# posisi : posisi
# pesana : sana
# loading : loading
# bug : bug
# perhatiannya : perhati
# kerusakan : rusa
# system : system
# perbaikan : baik
# menggangu : menggangu
# penggunaan : guna
# nyaman : nyaman
# semoga : moga
# dengar : dengar
# terima : terima
# mengecewakan : kecewa
# membela : bela
# kepentingan : penting
# pelanggan : langgan
# status : status
# selesai : selesai
# menjanjikan : janji
# pengiriman : kirim
# seminggu : minggu
# iklan : iklan
# halaman : halaman
# pemakai : pakai
# klik : klik
# meninggalkan : tinggal
# bl : bl
# ribet : ribet
# super : super
# seller : seller
# kuota : kuota
# dagangan : dagang
# jualannya : jual
# antik : antik
# unik : unik
# quota : quota
# diketerangan : terang
# promosi : promosi
# toko : toko
# sebelah : belah
# payleter : payleter
# lancar : lancar
# top : top
# up : up
# game : game
# cancel : cancel
# sungguh : sungguh
# verifikasi : verifikasi
# validpadahal : validpadahal
# data : data
# kesal : kesal
# login : login
# download : download
# daftar : daftar
# jelek : jelek
# aplikasinya : aplikasi
# lemot : lot
# mengadu : adu
# bertele : tele
# kesana : kesana
# kemari : kemari
# coba : coba
# tinggal : tinggal
# cari : cari
# koleksinya : koleksi
# dikit : dikit
# cuman : cuman
# barangnya : barang
# kalah : kalah
# sepi : sepi
# berbulan : bulan
# laku : laku
# tokopedia : tokopedia
# stagnan : stagnan
# greget : greget
# ol : ol
# shop : shop
# bukalapakygdulu : bukalapakygdulu
# kendala : kendala
# belanja : belanja
# online : online
# bonus : bonus
# credit : credit
# ulasan : ulas
# menyenangkan : senang
# syarat : syarat
# ketentuan : tentu
# ketahui : tahu
# bst : bst
# pedagang : dagang
# modal : modal
# pasan : pas
# muterin : muterin
# ambil : ambil
# feedback : feedback
# berakibat : akibat
# masuk : masuk
# akun : akun
# notifikasi : notifikasi
# sampah : sampah
# berguna : guna
# tsbt : tsbt
# matikan : mati
# makan : makan
# pembelian : beli
# hilang : hilang
# aktifkan : aktif
# pilihan : pilih
# pencarian : cari
# dipilih : pilih
# zonk : zonk
# dihapus : hapus
# alhasil : alhasil
# pilih : pilih
# melanggar : langgar
# saran : saran
# mengapai : kapai
# tampilkan : tampil
# diperbaiki : baik
# benarbenar : benarbenar
# tertata : tata
# penipuan : tipu
# batasi : batas
# pepalak : palak
# mengirimkan : kirim
# transfer : transfer
# puas : puas
# bantuannyasaya : bantuannyasaya
# mengalami : alami
# kesulitan : sulit
# logindikarenakan : logindikarenakan
# menerima : terima
# kode : kode
# otp : otp
# masukkan : masuk
# aktifmau : aktifmau
# sayadan : sayadan
# bukalapakmohon : bukalapakmohon
# bantu : bantu
# mempersulit : sulit
# isi : isi
# pengaturan : atur
# konsumen : konsumen
# betah : betah
# perdagangan : dagang
# rekomendasi : rekomendasi
# tibatiba : tibatiba
# beku : beku
# baned : baned
# feed : feed
# back : back
# gede : gede
# korban : korban
# star : star
# mahal : mahal
# memberatkan : berat
# itemku : item
# higs : higs
# domino : domino
# menerapkan : terap
# digital : digital
# sih : sih
# pesan : pesan
# kekurir : kurir
# kejelasan : jelas
# asuransi : asuransi
# bintang : bintang
# dompet : dompet
# bekukan : beku
# berkali : kali
# tunggu : tunggu
# aa : aa
# maaf : maaf
# kakak : kakak
# alami : alami
# solusinya : solusi
# memudahkan : mudah
# ktpno : ktpno
# telphone : telphone
# membuktikan : bukti
# pemilik : milik
# terimakasih : terimakasih
# kebelakang : belakang
# customer : customer
# no : no
# antrian : antri
# nutup : nutup
# diterima : terima
# trecking : trecking
# pengirimannya : kirim
# susupin : susupin
# shopee : shopee
# pasang : pasang
# harga : harga
# separuhnya : paruh
# sekalinya : sekali
# murah : murah
# rusak : rusak
# realpict : realpict
# malas : malas
# kapok : kapok
# salah : salah
# wajib : wajib
# perbanyak : banyak
# membantu : bantu
# permudah : mudah
# muter : muter
# ajalihat : ajalihat
# history : history
# susahnya : susah
# mainnumpuk : mainnumpuk
# diserver : diserver
# akunbuatlah : akunbuatlah
# penyimpanan : simpan
# update : update
# terbaru : baru
# nge : nge
# loadingnya : loadingnya
# suka : suka
# hang : hang
# selebihnya : lebih
# mantap : mantap
# ampas : ampas
# penipu : tipu
# bangkrut : bangkrut
# hapus : hapus
# play : play
# store : store
# bukalapk : bukalapk
# sicepat : sicepat
# kurir : kurir
# tautpi : tautpi
# berat : berat
# kg : kg
# gramdi : gramdi
# hitung : hitung
# kgdan : kgdan
# ahirnya : ahirnya
# ongkir : ongkir
# terpotong : potong
# sayagak : sayagak
# ijoklo : ijoklo
# komplin : komplin
# teratasi : atas
# nomer : nomer
# hp : hp
# terdaftar : daftar
# lainemang : lainemang
# ganti : ganti
# daptar : daptar
# alikasi : alikasi
# yahsangat : yahsangat
# membingungkanlangsung : membingungkanlangsung
# uninstal : uninstal
# mudah : mudah
# kompalain : kompalain
# ampun : ampun
# tpdiketangan : tpdiketangan
# komplen : komplen
# enak : enak
# memakai : pakai
# eh : eh
# berhasil : hasil
# tarik : tarik
# dananya : dana
# belu : belu
# cairkan : cair
# hadehh : hadehh
# hadehhh : hadehhh
# mengasih : asih
# ktp : ktp
# sandi : sandi
# gunanya : guna
# tingkatkan : tingkat
# potongan : potong
# transaksinya : transaksi
# apk : apk
# peforma : forma
# huhuhuuuuu : huhuhuuuuu
# wadah : wadah
# gampang : gampang
# tim : tim
# bobrok : bobrok
# jawabannya : jawab
# disuruh : suruh
# dinyatakan : nyata
# valid : valid
# mengutamakan : utama
# untung : untung
# rugi : rugi
# cepat : cepat
# tujuan : tuju
# manapun : mana
# promonya : promonya
# fee : fee
# admin : admin
# promo : promo
# lainnyamataap : lainnyamataap
# dah : dah
# gunawan : gunawan
# mantab : mantab
# menunya : menu
# simple : simple
# praktis : praktis
# pahami : paham
# lemottnya : lemottnya
# bingung : bingung
# sayang : sayang
# mengajukan : aju
# dibalas : balas
# tanggal : tanggal
# april : april
# kurirnya : kurir
# mls : mls
# uangnya : uang
# woi : woi
# koneksi : koneksi
# server : server
# bermasalah : masalah
# minim : minim
# ui : ui
# buruk : buruk
# marketplace : marketplace
# agt : agt
# pengoperasian : operasi
# urusan : urus
# mencari : cari
# profil : profil
# favorit : favorit
# des : des
# ajib : ajib
# nih : nih
# fiturfiturnya : fiturfiturnya
# dicari : cari
# desain : desain
# layar : layar
# rapi : rapi
# biru : biru
# belanjaan : belanja
# hasil : hasil
# dipindahin : dipindahin
# kerna : kerna
# limit : limit
# sia : sia
# dipakai : pakai
# recomend : recomend
# respon : respon
# terselesaikan : selesai
# internet : internet
# menampilkan : tampil
# utama : utama
# sudahlama : sudahlama
# retur : retur
# kayanya : kaya
# uninstall : uninstall
# berasa : asa
# aman : aman
# sesuai : sesuai
# hati : hati
# hubungkan : hubung
# aplkasi : aplkasi
# iniakun : iniakun
# kena : kena
# hack : hack
# tagihan : tagih
# steam : steam
# vcr : vcr
# pembajak : bajak
# manusia : manusia
# berhati : hati
# mendewakan : dewa
# enggak jelas : enggak jelas
# semacem : semacem
# enggak bisa : enggak bisa
# tlng : tlng
# terkaitdevelop : terkaitdevelop
# penanganan : tangan
# dikecewain : dikecewain
# penutupan : tutup
# tanggapinnya : tanggapinnya
# formulir : formulir
# permohonan : mohon
# gratis : gratis
# boongan : boongan
# ribu : ribu
# jnt : jnt
# sellernya : sellernya
# nyantumin : nyantumin
# cod : cod
# pembohong : bohong
# siniudah : siniudah
# capek : capek
# ngetikpas : ngetikpas
# tertulis : tulis
# tuju : tuju
# kemana : mana
# jdinya : jdinya
# terimatpi : terimatpi
# reportnya : reportnya
# bingungmo : bingungmo
# pasrah : pasrah
# an : an
# tanggapin : tanggapin
# tutup : tutup
# bertahun : tahun
# dibenahi : benah
# kabur : kabur
# pembelinya : bel
# ok : ok
# alhamdulillah : alhamdulillah
# sengketa : sengketa
# diskusi : diskusi
# butuh : butuh
# aplaus : aplaus
# normal : normal
# pencariannya : cari
# aneh : aneh
# ikan : ikan
# hias : hias
# pakan : pakan
# ganggu : ganggu
# minusnya : minus
# voucher : voucher
# memenuhi : penuh
# persyaratan : syarat
# jasa : jasa
# ekspedisi : ekspedisi
# simpan : simpan
# gudang : gudang
# bukaexpress : bukaexpress
# livechat : livechat
# berfungsi : fungsi
# beda : beda
# merchant : merchant
# mematikan : mati
# obrolannya : obrol
# aktifin : aktifin
# hangus : hangus
# kyc : kyc
# sory : sory
# ane : ane
# join : join
# kepercayan : kepercayan
# ecom : ecom
# aktifasi : aktifasi
# sumpah : sumpah
# enek : enek
# masak : masak
# aktif : aktif
# sefty : sefty
# main : main
# lo : lo
# nyataanya : nyataanya
# nomornya : nomor
# aktivasi : aktivasi
# syaratnya : syarat
# pinjaman : pinjam
# bank : bank
# sumpaah : sumpaah
# oohh : oohh
# devlover : devlover
# lebay : lebay
# dikirimkan : kirim
# foto : foto
# ktprekening : ktprekening
# seribet : seribet
# kah : kah
# cantumin : cantumin
# diubah : ubah
# memasukkan : masuk
# tipenyasaya : tipenyasaya
# menyelesaikan : selesai
# paket : paket
# iklannya : iklan
# membuka : buka
# ngechek : ngechek
# internetdi : internetdi
# nglungker : nglungker
# bertambah : tambah
# jenuhtlg : jenuhtlg
# perhatikan : perhati
# emas : emas
# bukaemas : bukaemas
# problemnya : problem
# bad : bad
# gateway : gateway
# ulang : ulang
# kayaknya : kayak
# sengaja : sengaja
# dipersulit : sulit
# investasi : investasi
# app : app
# kebanyakan : banyak
# dibikin : bikin
# simpel : simpel
# ajabanyak : ajabanyak
# sisrem : sisrem
# gunabuka : gunabuka
# kaya : kaya
# ajaisi : ajaisi
# harap : harap
# buang : buang
# ajadan : ajadan
# bagusmasuk : bagusmasuk
# ribetnya : ribetnya
# didownload : didownload
# touch : touch
# az : az
# merepotkan : repot
# ribuan : ribu
# cumq : cumq
# tampil : tampil
# temukan : temu
# gaya : gaya
# pengunjung : unjung
# statusnya : status
# kadaluarsamau : kadaluarsamau
# dibeli : beli
# dibayar : bayar
# canggih : canggih
# dikomplain : komplain
# sadah : sadah
# kembaliini : kembaliini
# kepastianpayah : kepastianpayah
# menyesal : sesal
# gue : gue
# dibukalapak : dibukalapak
# fiturnya : fiturnya
# mengaco : aco
# pelit : pelit
# aturan : atur
# nonaktif : nonaktif
# dijual : jual
# berulang : ulang
# set : set
# profesional : profesional
# beban : beban
# and : and
# smartphone : smartphone
# dipiara : piara
# bermanfaat : manfaat
# sulit : sulit
# mitra : mitra
# dalem : dalem
# tertipu : tipu
# refund : refund
# detik : detik
# mengerti : erti
# biyaya : biyaya
# maksudnya : maksud
# menyesak : sesak
# sgitu : sgitu
# ilangin : ilangin
# tuhklo : tuhklo
# kurangi : kurang
# kepakasa : kepakasa
# blanja : blanja
# saking : saking
# chip : chip
# snapdragon : snapdragon
# gen : gen
# ram : ram
# gb : gb
# clear : clear
# chace : chace
# logout : logout
# permasalahan : masalah
# expedisi : expedisi
# reg : reg
# next : next
# day : day
# pick : pick
# lelet : lelet
# criss : criss
# cross : cross
# sop : sop
# resi : resi
# ybs : ybs
# kepercayaan : percaya
# kedepan : depan
# buset : buset
# pajangan : pajang
# ditemukan : temu
# hebat : hebat
# lenya : lenya
# mempermudah : mudah
# berbelanjatapi : berbelanjatapi
# dam : dam
# halapalagi : halapalagi
# tanggapan : tanggap
# sistemnyakecewa : sistemnyakecewa
# pelayanan : layan
# telat : telat
# pemilihan : pilih
# ditambah : tambah
# report : report
# bermasalahpaket : bermasalahpaket
# jadwal : jadwal
# kompensasi : kompensasi
# jaminan : jamin
# kembalihanya : kembalihanya
# slogan : slogan
# belakabagaimana : belakabagaimana
# payleater : payleater
# bukalapaksaya : bukalapaksaya
# tagih : tagih
# lagibukti : lagibukti
# struknya : struknya
# kasir : kasir
# indomart : indomart
# yeah : yeah
# tagihantapi : tagihantapi
# anehnya : aneh
# kecewadimana : kecewadimana
# menyediakan : sedia
# codtapi : codtapi
# express : express
# mengenali : nali
# pengguna : guna
# pribadi : pribadi
# beliau : beliau
# berkurang : kurang
# riwayat : riwayat
# paylatternya : paylatternya
# pemberitahuan : pemberitahuan
# januari : januari
# jugasudah : jugasudah
# ajukan : aju
# tanggapi : tanggap
# bukalapaksungguh : bukalapaksungguh
# sukses : sukses
# ditutup : tutup
# konfirmasi : konfirmasi
# turunin : turunin
# bintangnya : bintang
# eror : eror
# langganan : langgan
# sayapadahal : sayapadahal
# label : label
# tersedia : sedia
# cekout : cekout
# catatan : catat
# metode : metode
# inipadahal : inipadahal
# penipunya : tipu
# berubah : ubah
# giliran : gilir
# pengaduan : adu
# mending : mending
# keren : keren
# bertahan : tahan
# persaingan : saing
# ketat : ketat
# kompetitornya : kompetitor
# yuk : yuk
# buruan : buru
# konsisten : konsisten
# timbul : timbul
# tenggelam : tenggelam
# loh : loh
# hehee : hehee
# andalan : andal
# way : way
# ketinggalan : tinggal
# pusat : pusat
# opsi : opsi
# dicetak : cetak
# helooo : helooo
# syaa : syaa
# buyer : buyer
# driver : driver
# tampilan : tampil
# user : user
# friendly : friendly
# menyulitkan : sulit
# payah : payah
# bukareksauang : bukareksauang
# setatusy : setatusy
# selesaidikomplen : selesaidikomplen
# transfermasuk : transfermasuk
# bertanggung : tanggung
# jawabpaylater : jawabpaylater
# rusuhmasih : rusuhmasih
# belbel : belbel
# terusruwed : terusruwed
# sabar : sabar
# pengecekan : kece
# kepastian : pasti
# pemesanan : mesan
# memesan : mes
# rokok : rokok
# pindahkan : pindah
# kartu : kartu
# sd : sd
# setia : setia
# flashdeal : flashdeal
# belinya : beli
# shake : shake
# thon : thon
# dapatnya : dapat
# perak : perak
# thx : thx
# penagihan : tagih
# melunasi : lunas
# ditinjau : tinjau
# dc : dc
# screen : screen
# shot : shot
# menagih : tagih
# wa : wa
# mengganggu : ganggu
# berbeda : beda
# ditindak : tindak
# lanjuti : lanjut
# call : call
# center : center
# via : via
# dadi : dadi
# komplainnya : komplain
# action : action
# kak : kak
# estimasi : estimasi
# transit : transit
# tangan : tangan
# pay : pay
# later : later
# ah : ah
# ngisi : ngisi
# cash : cash
# lom : lom
# tau : tau
# telepon : telepon
# memuaskan : muas
# jawabannyacoba : jawabannyacoba
# membatalkan : batal
# tanggepin : tanggepin
# tlong : tlong
# tentui : tentu
# jgbuat : jgbuat
# bantumakin : bantumakin
# hubungin : hubungin
# chatlemot : chatlemot
# tele : tele
# turun : turun
# lag : lag
# memperbaiki : baik
# karuan : karuan
# dibajak : bajak
# kredit : kredit
# hubungi : hubung
# pending : pending
# bukalapakeh : bukalapakeh
# suami : suami
# jutamasa : jutamasa
# blokir : blokir
# bajakhrsny : bajakhrsny
# ditahan : tahan
# pesanannyakan : pesanannyakan
# rp : rp
# byr : byr
# vamandiri : vamandiri
# pembyran : pembyran
# auto : auto
# ditarik : tarik
# duitnya : duit
# transferpenarikkan : transferpenarikkan
# upgrade : upgrade
# premium : premium
# bari : bari
# dibekukan : beku
# nominal : nominal
# elektronik : elektronik
# digabung : gabung
# darp : darp
# nyaedaaaan : nyaedaaaan
# pemerasan : peras
# its : its
# sense : sense
# fungsi : fungsi
# larinya : lari
# dodol : dodol
# penilain : penilain
# kasihan : kasihan
# danatransfer : danatransfer
# lemotbukan : lemotbukan
# lemotaplikasinya : lemotaplikasinya
# perbaikimasi : perbaikimasi
# ringan : ringan
# orangemasa : orangemasa
# utuma : utuma
# bos : bos
# dikatan : dikatan
# itupun : itu
# bayarkan : bayar
# antusias : antusias
# sydah : sydah
# hynaevinv : hynaevinv
# dicancelsejak : dicancelsejak
# sampaiudah : sampaiudah
# loohhhkembalikan : loohhhkembalikan
# seharga : harga
# ongkirnya : ongkirnya
# sadar : sadar
# gunakanauto : gunakanauto
# uninstaljika : uninstaljika
# paylaternya : paylaternya
# trmksih : trmksih
# chating : chating
# infonya : info
# nagih : nagih
# hutang : hutang
# ditingkatkan : tingkat
# terbaik : baik
# vocer : vocer
# hijau : hijau
# orange : orange
# full : full
# dibatasi : batas
# kuotanya : kuota
# kedepannya : depan
# cantumkan : cantum
# pembatalan : batal
# kolom : kolom
# detail : detail
# masukan : masuk
# batalin : batalin
# pejual : jual
# jugasedangkan : jugasedangkan
# gunakanharus : gunakanharus
# mengadutolong : mengadutolong
# lapakbiar : lapakbiar
# mengadukan : adu
# keluhan : keluh
# developer : developer
# lazada : lazada
# tiktok : tiktok
# minimal : minimal
# wajar : wajar
# orentiktok : orentiktok
# layak : layak
# disana : sana
# ketimbang : ketimbang
# wkwk : wkwk
# bisnis : bisnis
# hasilnya : hasil
# berlimpah : limpah
# mantaab : mantaab
# markotopmaknyosss : markotopmaknyosss
# baikbaiiiil : baikbaiiiil
# masalahsudah : masalahsudah
# jalan : jalan
# keluarketika : keluarketika
# mengetik : etik
# putus : putus
# sambungan : sambung
# nyakalo : nyakalo
# menggu : menggu
# yohana : yohana
# nama : nama
# bersabar : sabar
# nunggusaaya : nunggusaaya
# ngetiikkkk : ngetiikkkk
# enakan : enak
# shopie : shopie
# servernya : servernya
# jaya : jaya
# amanah : amanah
# diproses : proses
# pelapaknya : lapak
# bukamall : bukamall
# pilihannya : pilih
# complainnya : complainnya
# complain : complain
# digunain : digunain
# tandailike : tandailike
# checkout : checkout
# dibatalin : dibatalin
# maksa : maksa
# bentar : bentar
# pokoknya : pokok
# telp : telp
# custemservis : custemservis
# ngurusinya : ngurusinya
# chatlive : chatlive
# ngelunasin : ngelunasin
# sehari : hari
# kinerjanya : kerja
# informasj : informasj
# dipahami : paham
# pengerjaannya : kerja
# kemudahan : mudah
# berbelanja : belanja
# rating : rating
# terpisah : pisah
# berjualan : jual
# jualan : jual
# barangsaya : barangsaya
# codpembayaran : codpembayaran
# tunai : tunai
# berjalan : jalan
# keuangan : uang
# benahi : benah
# pastinya : pasti
# wifi : wifi
# lemmooottttt : lemmooottttt
# dasarnya : dasar
# transsaksi : transsaksi
# terisi : isi
# penuh : penuh
# penawaran : tawar
# tanda : tanda
# terbaca : baca
# kepencet : pencet
# bermain : main
# konten : konten
# webnya : webnya
# lumayan : lumayan
# kecurigaan : curiga
# maafkan : maaf
# harganya : harga
# free : free
# sejenisnya : jenis
# ttup : ttup
# efisien : efisien
# hemat : hemat
# duduk : duduk
# manis : manis
# rumah : rumah
# low : low
# cost : cost
# ngirit : ngirit
# mengundang : undang
# teman : teman
# refferal : refferal
# setujui : tuju
# pembukaan : buka
# undang : undang
# cair : cair
# bantuannya : bantu
# account : account
# berani : berani
# kontak : kontak
# rumit : rumit
# danabukalapak : danabukalapak
# trimakasih : trimakasih
# inovatif : inovatif
# lamaproses : lamaproses
# lamarespon : lamarespon
# penjualnya : jual
# lamabru : lamabru
# bukalapakternyata : bukalapakternyata
# lamaaaa : lamaaaa
# slow : slow
# responfix : responfix
# ecommerce : ecommerce
# cocok : cocok
# pembisnis : bisnis
# all : all
# one : one
# feature : feature
# klaim : klaim
# hak : hak
# refundlangsung : refundlangsung
# customermau : customermau
# barangpake : barangpake
# dikomplen : dikomplen
# kejelasannyakatanya : kejelasannyakatanya
# prosesnya : proses
# diprosesmana : diprosesmana
# ribed : ribed
# menindaklanjuti : menindaklanjuti
# instal : instal
# nipu : nipu
# donload : donload
# bangst : bangst
# platform : platform
# mnrut : mnrut
# terbaiknya : baik
# acc : acc
# good : good
# job : job
# paforitmisal : paforitmisal
# ketik : ketik
# minyak : minyak
# paforit : paforit
# memperumit : rumit
# disitu : situ
# doang : doang
# pencairan : cair
# bukatabungan : bukatabungan
# total : total
# sisanya : sisa
# tranksaksi : tranksaksi
# tranksasi : tranksasi
# layanananya : layanananya
# untungnya : untung
# parahhhhhhhhhhh : parahhhhhhhhhhh
# menutup : tutup
# meresa : resa
# rugikan : rugi
# senang : senang
# belanjatop : belanjatop
# palyeter : palyeter
# akulaku : akulaku
# penilaian : nilai
# ruang : ruang
# tutupdi : tutupdi
# tlfn : tlfn
# marah : marah
# ku : ku
# tipu : tipu
# abuabu : abuabu
# takut : takut
# tipa : tipa
# terpercaya : percaya
# bangkai : bangkai
# minggu : minggu
# alasnya : alas
# alamat : alamat
# komen : komen
# kasar : kasar
# chatnya : chatnya
# block : block
# anjiiinbg : anjiiinbg
# mengecewakanaman : mengecewakanaman
# customertingkatkan : customertingkatkan
# prestasi : prestasi
# blspy : blspy
# padaha : padaha
# diberikankalau : diberikankalau
# ditambh : ditambh
# claim : claim
# ikhlas : ikhlas
# terima kasih : terima kasih
# dgunakan : dgunakan
# watelpon : watelpon
# membingunkan : membingunkan
# ceo : ceo
# asugak : asugak
# mahalan : mahal
# belilama : belilama
# kemarin : kemarin
# kompain : kompain
# terkirim : kirim
# ceat : ceat
# langanan : langanan
# pengalaman : alam
# lambat : lambat
# rekomen : rekomen
# penyedia : sedia
# fasilitas : fasilitas
# sediakan : sedia
# prifasi : prifasi
# histori : histori
# obatproduk : obatproduk
# dewasa : dewasa
# sebagainyaitu : sebagainyaitu
# prifasitrims : prifasitrims
# token : token
# listrik : listrik
# virtual : virtual
# kadaluarsa : kadaluarsa
# kmna : kmna
# khusus : khusus
# diaktifkan : aktif
# haduhh : haduhh
# ribettt : ribettt
# ribett : ribett
# berbelanjatp : berbelanjatp
# pembayarannya : bayar
# bebas : bebas
# persulit : sulit
# contohhanya : contohhanya
# berlaku : laku
# apalah : apa
# membanyaki : banyak
# cc : cc
# tertagih : tagih
# confirmasi : confirmasi
# urus : urus
# kabar : kabar
# pemeliharaan : pelihara
# dimatiin : dimatiin
# apapun : apa
# butuhkan : butuh
# cicil : cicil
# nyampek : nyampek
# terkadang : terkadang
# nnya : nnya
# amana : amana
# suport : suport
# video : video
# kelanjutan : lanjut
# komplainya : komplainya
# jozzzzz : jozzzzz
# gandossssst : gandossssst
# maintenance : maintenance
# disebelah : belah
# keberanda : beranda
# barusan : barusan
# pindah : pindah
# non : non
# etalase : etalase
# nonaktifkan : nonaktif
# lainya : lai
# transfertapi : transfertapi
# oke : oke
# pertahankan : tahan
# menggunakannya : guna
# support : support
# test : test
# bberapa : bberapa
# mempelajari : ajar
# jarang : jarang
# palsu : palsu
# miring : miring
# orisinal : orisinal
# platfom : platfom
# tertatrik : tertatrik
# indonesia : indonesia
# gabakalan : gabakalan
# disaldo : saldo
# dibelikan : beli
# dikembalin : dikembalin
# merubah : rubah
# pertanda : tanda
# kolaps : kolaps
# tf : tf
# service : service
# komunikasi : komunikasi
# bloon : bloon
# bukasend : bukasend
# semprul : semprul
# beritahuakan : beritahuakan
# yaadi : yaadi
# tanggung : tanggung
# xsetelah : xsetelah
# tercantumini : tercantumini
# akal : akal
# melayang : layang
# kabarsangat : kabarsangat
# burukpenipuan : burukpenipuan
# jaringan : jaring
# gua : gua
# anjenggg : anjenggg
# toped : toped
# shopeee : shopeee
# dll : dll
# bapuk : bapuk
# taiii : taiii
# start : start
# mei : mei
# subuh : subuh
# yakali : yakali
# kebagian : bagi
# kouta : kouta
# disengaja : sengaja
# beritahu : beritahu
# disediakan : sedia
# care : care
# faq : faq
# mekanisme : mekanisme
# pengirimanya : pengirimanya
# melebihi : lebih
# tentukan : tentu
# stak : stak
# perubahan : ubah
# erortolong : erortolong
# dipwrbaiki : dipwrbaiki
# nyaterima : nyaterima
# kejadian : jadi
# tiki : tik
# mengaktifkan : aktif
# zaman : zaman
# manual : manual
# perlindungan : lindung
# sejarahbuktiin : sejarahbuktiin
# sendirikalah : sendirikalah
# sebelahjoos : sebelahjoos
# ceritanya : cerita
# harapan : harap
# dibl : dibl
# menarik : tarik
# lengkap : lengkap
# akibatnya : akibat
# instan : instan
# bukalapakpesanan : bukalapakpesanan
# kurur : kurur
# cepattapi : cepattapi
# complainmenu : complainmenu
# bukanantuan : bukanantuan
# betfungsi : betfungsi
# potongam : potongam
# saller : saller
# promote : promote
# push : push
# efek : efek
# roda : roda
# sdikit : sdikit
# menit : menit
# indihome : indihome
# sekian : sekian
# rekomendet : rekomendet
# ongir : ongir
# dibandingkan : banding
# dibantu : bantu
# performa : performa
# kembangkan : kembang
# cinta : cinta
# negeri : negeri
# susa : susa
# lemoot : lemoot
# aplikasinyatolong : aplikasinyatolong
# lainudh : lainudh
# callcenter : callcenter
# isinya : isi
# artikel : artikel
# wkwkwk : wkwkwk
# berhubung : hubung
# newbie : newbie
# nilai : nilai
# bangetmau : bangetmau
# gmail : gmail
# berkalikali : berkalikali
# loginkatanya : loginkatanya
# apanyajelas : apanyajelas
# bilangnya : bilang
# salahsalah : salahsalah
# ahterus : ahterus
# loginnya : loginnya
# pelayananya : pelayananya
# responterima : responterima
# belanjanya : belanja
# custom : custom
# kalimat : kalimat
# terkesan : kes
# baku : baku
# harapannya : harap
# dimudahkan : mudah
# display : display
# merk : merk
# spesifikasi : spesifikasi
# tertampil : tampil
# variatif : variatif
# selisih : selisih
# signifikan : signifikan
# memilih : pilih
# kwalitas : kwalitas
# secepatnya : cepat
# tindak : tindak
# lanjutinsaya : lanjutinsaya
# bekukanke : bekukanke
# gajelasudah : gajelasudah
# lemottoko : lemottoko
# pengawasan : awas
# bukamau : bukamau
# mbatalin : mbatalin
# gabisaharus : gabisaharus
# on : on
# dibilang : bilang
# tertua : tua
# inovasi : inovasi
# satusatunya : satusatunya
# berfungsihatihati : berfungsihatihati
# xufsinv : xufsinv
# maksimal : maksimal
# dbatalkan : dbatalkan
# tertahan : tahan
# jelasjelas : jelasjelas
# tertera : tera
# terbuka : buka
# updatenya : updatenya
# punyeng : punyeng
# minada : mada
# gangguan : ganggu
# permasalahn : permasalahn
# halo : halo
# setahun : tahun
# bukadompet : bukadompet
# senilai : nila
# struk : struk
# topup : topup
# edit : edit
# varian : varian
# keterangannya : terang
# memiliki : milik
# tipe : tipe
# nginput : nginput
# apanya : apa
# disamainnnnn : disamainnnnn
# dm : dm
# ig : ig
# digubris : gubris
# sptnya : sptnya
# bual : bual
# adakan : adakan
# request : request
# pickup : pickup
# awam : awam
# ramadhan : ramadhan
# posting : posting
# iming : iming
# utang : utang
# warung : warung
# hahaha : hahaha
# haaaaa : haaaaa
# berjaya : jaya
# seleksi : seleksi
# curangpenjual : curangpenjual
# nakal : nakal
# menipu : tipu
# dikecewakan : kecewa
# pertahanan : tahan
# ketempat : tempat
# halooooo : halooooo
# biji : biji
# order : order
# pajaknya : pajak
# royal : royal
# emosi : emosi
# pantesan : pantesan
# jadul : jadul
# ditinggalkan : tinggal
# costumer : costumer
# banyaktidak : banyaktidak
# bukabantuannya : bukabantuannya
# penyelesaian : selesai
# ninja : ninja
# expres : expres
# berpuluh : puluh
# puluh : puluh
# dilacak : lacak
# sukur : sukur
# serius : serius
# kopeten : kopeten
# stock : stock
# beranda : beranda
# tayangin : tayangin
# kesalahan : salah
# transparant : transparant
# updatetan : updatetan
# install : install
# berulangulang : berulangulang
# mencoba : coba
# wadew : wadew
# blank : blank
# tandatanda : tandatanda
# berjamjam : berjamjam
# sore : sore
# pagi : pagi
# biarkan : biar
# ketemu : ketemu
# acha : acha
# niat : niat
# koreksi : koreksi
# wilyah : wilyah
# timur : timur
# contoh : contoh
# ongkos : ongkos
# kirimnya : kirim
# mencapai : capai
# fer : fer
# kemahalan : mahal
# jadikan : jadi
# bertransaksi : transaksi
# gonta : gonta
# mencukupi : cukup
# tolonglah : tolong
# basah : basah
# basih : basih
# custumer : custumer
# servicenya : servicenya
# ditangguhkan : tangguh
# sunguh : sunguh
# sarankan : saran
# menyimpan : simpan
# menghindari : hindar
# jepara : jepara
# bandung : bandung
# teramat : amat
# lamalebih : lamalebih
# wajargk : wajargk
# kerjasama : kerjasama
# orderan : order
# lagibukan : lagibukan
# emak : emak
# lato : lato
# swafoto : swafoto
# kanan : kanan
# kiri : kiri
# pegang : pegang
# buku : buku
# bantuin : bantuin
# repot : repot
# warning : warning
# sistemnyasya : sistemnyasya
# sellerkenapa : sellerkenapa
# pencariandi : pencariandi
# tracking : tracking
# validbanyak : validbanyak
# pembelitapi : pembelitapi
# trackingnya : trackingnya
# percepat : cepat
# marketpkace : marketpkace
# dibuka : buka
# mengembalikan : kembali
# kekurangan : kurang
# list : list
# profile : profile
# ditampilkan : tampil
# halah : halah
# pikir : pikir
# menilai : nilai
# kemunduran : mundur
# ratingnya : ratingnya
# angsuran : angsur
# sajadan : sajadan
# aktifharus : aktifharus
# belanjabrg : belanjabrg
# kebutuhan : butuh
# ewallet : ewallet
# bhulshittt : bhulshittt
# program : program
# garansi : garansi
# tipunya : tipu
# mode : mode
# claimnya : claimnya
# default : default
# curang : curang
# berkahh : berkahh
# siasat : siasat
# mnjamingaransi : mnjamingaransi
# kunjung : kunjung
# tahan : tahan
# juta : juta
# nonfisik : nonfisik
# intinya : inti
# fisikisinya : fisikisinya
# semuasaya : semuasaya
# higgs : higgs
# selesaisukses : selesaisukses
# dikirimudah : dikirimudah
# tanggapidiliat : tanggapidiliat
# mengambil : ambil
# keputusan : putus
# selau : selau
# sesi : sesi
# info : info
# terkocak : kocak
# mulu : mulu
# kelar : kelar
# eneg : eneg
# dengernya : dengernya
# badut : badut
# tengkyuu : tengkyuu
# dijamin : jamin
# ktpreffvral : ktpreffvral
# btbldkzqvt : btbldkzqvt
# nyaaplikasii : nyaaplikasii
# lamasangat : lamasangat
# dikala : kala
# belanjatinggal : belanjatinggal
# bayarbarang : bayarbarang
# membaiktengkyuuu : membaiktengkyuuu
# password : password
# sekalibegitu : sekalibegitu
# verif : verif
# passwordklik : passwordklik
# lupa : lupa
# bisagimana : bisagimana
# percaya : percaya
# traktiran : traktir
# debitnya : debit
# tambahan : tambah
# knyatanya : knyatanya
# sebulan : bulan
# akunnya : akun
# hoax : hoax
# menghubungi : hubung
# servis : servis
# presiden : presiden
# standby : standby
# lokasi : lokasi
# dihalaman : halaman
# ngalami : ngalami
# mendingan : mending
# ngalamin : ngalamin
# variannya : varian
# dipermudah : mudah
# fleksibel : fleksibel
# monoton : monoton
# disesuaikan : sesuai
# size : size
# real : real
# nurut : nurut
# kategori : kategori
# promoted : promoted
# dinonaktifkan : nonaktif
# pembayaranya : pembayaranya
# lainyasangat : lainyasangat
# mudahsangat : mudahsangat
# kalangan : kalang
# menengah : tengah
# kebawahapalagi : kebawahapalagi
# dapatkanpayah : dapatkanpayah
# drastis : drastis
# keperluan : perlu
# mendesak : desak
# pinjam : pinjam
# tetangga : tetangga
# bisaselalu : bisaselalu
# lengkapi : lengkap
# chapta : chapta
# lulus : lulus
# promot : promot
# ngitung : ngitung
# penjumlahan : jumlah
# mines : mes
# ijo : ijo
# oran : oran
# paylter : paylter
# jebakan : jebak
# betmen : betmen
# kepelapak : lapak
# tekan : tekan
# dikembalikan : kembali
# smile : smile
# berikanhanya : berikanhanya
# diwajibakan : diwajibakan
# tolak : tolak
# tampa : tampa
# penerimaan : terima
# selepas : lepas
# mendesakharusnya : mendesakharusnya
# kembalibagaimanapun : kembalibagaimanapun
# bldah : bldah
# ulangi : ulang
# samatapi : samatapi
# inikasih : inikasih
# memproses : proses
# bgtkasihan : bgtkasihan
# dongharusnya : dongharusnya
# max : max
# haribukanya : haribukanya
# pembelimenurut : pembelimenurut
# bukalapakklo : bukalapakklo
# pesananmereka : pesananmereka
# sendiridan : sendiridan
# kirimkanentah : kirimkanentah
# lupaatau : lupaatau
# readymohon : readymohon
# lagibuat : lagibuat
# bukalapakbayar : bukalapakbayar
# telatmalah : telatmalah
# splayter : splayter
# rekomendasikan : rekomendasi
# splayternya : splayternya
# aktifinntar : aktifinntar
# rumitpadahal : rumitpadahal
# refaund : refaund
# prosespadahal : prosespadahal
# menjual : jual
# terjual : jual
# maret : maret
# hda : hda
# tua : tua
# berbenah : benah
# iya : iya
# fyuuhh : fyuuhh
# laporan : lapor
# alasan : alas
# review : review
# dok : dok
# prosez : prosez
# memutuskan : putus
# melampirkan : lampir
# rek : rek
# mutasi : mutasi
# nampaklah : nampaklah
# nota : nota
# bene : bene
# informasi : informasi
# krusial : krusial
# dmpak : dmpak
# securitynya : securitynya
# brengsek : brengsek
# dajjal : dajjal
# google : google
# permanen : permanen
# event : event
# mini : mini
# periode : periode
# bukalapaknya : bukalapaknya
# seharus : harus
# php : php
# kesempatan : sempat
# heran : heran
# cap : cap
# kaki : kaki
# atm : atm
# kecepatan : cepat
# permintaannya : minta
# relatif : relatif
# ols : ols
# seribu : ribu
# semangat : semangat
# limitnya : limit
# dibayarkan : bayar
# variasi : variasi
# laptop : laptop
# pc : pc
# telkom : telkom
# wib : wib
# bangking : bangking
# cencel : cencel
# uangpun : uang
# aga : aga
# dowload : dowload
# inikarna : inikarna
# lamatp : lamatp
# barangpengiriman : barangpengiriman
# standar : standar
# membaiksesuai : membaiksesuai
# estimasiuntuk : estimasiuntuk
# ditingkat : tingkat
# lgtrima : lgtrima
# kasihapk : kasihapk
# mati : mati
# galeri : galeri
# taunya : tau
# melulu : melulu
# oren : oren
# pengajuan : aju
# nyeesel : nyeesel
# bltp : bltp
# perlahan : perlahan
# beralih : alih
# lainselain : lainselain
# rendah : rendah
# beragamdi : beragamdi
# tawarkn : tawarkn
# ketikcari : ketikcari
# bersaing : saing
# terbatas : batas
# com : com
# laindan : laindan
# dek : dek
# keaman : aman
# menjamin : jamin
# lemah : lemah
# keamanan : aman
# taii : taii
# ayolah : ayo
# power : power
# perasaan : asa
# lagiterima : lagiterima
# barangterima : barangterima
# bukalapaktidak : bukalapaktidak
# mengecewakanjaya : mengecewakanjaya
# bukalapakaplikasi : bukalapakaplikasi
# indonesiasekali : indonesiasekali
# sok : sok
# far : far
# icon : icon
# mutarmutar : mutarmutar
# dimana : mana
# menemukan : temu
# ujung : ujung
# ujungnya : ujung
# paham : paham
# matiin : matiin
# eroor : eroor
# paylatter : paylatter
# pmesanan : pmesanan
# penjelasannya : jelas
# taeeek : taeeek
# zusah : zusah
# sms : sms
# kepeeet : kepeeet
# hitungan : hitung
# konsumennya : konsumen
# julan : julan
# bayak : bayak
# tampilll : tampilll
# penjuln : penjuln
# peroduk : peroduk
# sayh : sayh
# bertulis : tulis
# juragan : juragan
# tampill : tampill
# peminat : minat
# buatt : buatt
# munculnya : muncul
# chapcat : chapcat
# bolak : bolak
# ters : ters
# otpnya : otpnya
# kesel : kesel
# debit : debit
# indomaret : indomaret
# notifnya : notifnya
# enggak ada : enggak ada
# ovo : ovo
# aduh : aduh
# ngercash : ngercash
# appnya : appnya
# gegara : gegara
# fiturenyanotif : fiturenyanotif
# lokasinya : lokasi
# percayaterima : percayaterima
# bukalapakbarang : bukalapakbarang
# yahuuuutt : yahuuuutt
# kasihby : kasihby
# rahesa : rahesa
# dewaga : dewaga
# adanyadi : adanyadi
# manasemua : manasemua
# lapakga : lapakga
# tertarik : tarik
# love : love
# lapakselalu : lapakselalu
# is : is
# the : the
# bestbuka : bestbuka
# lapakpastiadaa : lapakpastiadaa
# pencariantrus : pencariantrus
# banned : banned
# member : member
# area : area
# wlaaupun : wlaaupun
# tayangkankacau : tayangkankacau
# skrgadukan : skrgadukan
# rindu : rindu
# bpk : bpk
# achmad : achmad
# zakypro : zakypro
# umkm : umkm
# knapa : knapa
# gwa : gwa
# sayamaling : sayamaling
# kocakngak : kocakngak
# nyabukti : nyabukti
# transferan : transfer
# sayaatas : sayaatas
# kwkwkwwktaiktaik : kwkwkwwktaiktaik
# taikjangan : taikjangan
# banyakdan : banyakdan
# payleternya : payleternya
# mmbuat : mmbuat
# brkali : brkali
# bltransaksi : bltransaksi
# sufah : sufah
# diteruskan : terus
# pelapakharus : pelapakharus
# jamaneh : jamaneh
# dtoko : dtoko
# pakaibuat : pakaibuat
# unit : unit
# powerbank : powerbank
# merek : merek
# soulkarena : soulkarena
# masingrp : masingrp
# berhasiltgl : berhasiltgl
# prosestp : prosestp
# dngn : dngn
# systemkarena : systemkarena
# lepas : lepas
# nyuruh : nyuruh
# bukalapakfitur : bukalapakfitur
# pakaibukalapak : pakaibukalapak
# customermana : customermana
# tanggungjawab : tanggungjawab
# andasy : andasy
# paylatenya : paylatenya
# bodong : bodong
# terrlambat : terrlambat
# seumur : umur
# hidup : hidup
# tanggap : tanggap
# kategorinya : kategori
# apknya : apknya
# mskin : mskin
# mendukung : dukung
# dancok : dancok
# asu : asu
# soldoku : soldoku
# wes : wes
# cok : cok
# vlinv : vlinv
# sampainya : sampai
# ditransit : transit
# paketnya : paket
# periksa : periksa
# tambahkan : tambah
# enaknya : enak
# dipercaya : percaya
# pin : pin
# otak : otak
# mutu : mutu
# anti : anti
# tolol : tolol
# get : get
# muncull : muncull
# option : option
# ngalang : ngalang
# ngalangin : ngalangin
# ajjaa : ajjaa
# seduniaongkir : seduniaongkir
# tingkat : tingkat
# danalagian : danalagian
# ngebatalinpuaaaayah : ngebatalinpuaaaayah
# kupon : kupon
# prakerja : prakerja
# centernya : centernya
# apasih : apasih
# lemottt : lemottt
# kapokk : kapokk
# dipertahankan : tahan
# nolong : nolong
# aji : aji
# mumpung : mumpung
# jugajd : jugajd
# terburuk : buruk
# tenggang : tenggang
# nihil : nihil
# carisukses : carisukses
# komlplen : komlplen
# terkonfirmasi : konfirmasi
# jne : jne
# senyum : senyum
# dukung : dukung
# buatan : buat
# anak : anak
# baliksaya : baliksaya
# khawatir : khawatir
# diatas : atas
# efektif : efektif
# balikin : balikin
# comerce : comerce
# ditipu : tipu
# kalikalo : kalikalo
# bagusdan : bagusdan
# bagusawas : bagusawas
# komentartetap : komentartetap
# jaga : jaga
# kebagusannya : bagus
# dibukalapakkarena : dibukalapakkarena
# menguntungkan : untung
# gestun : gestun
# selfie : selfie
# oknum : oknum
# memgecewakan : memgecewakan
# biargak : biargak
# biargesit : biargesit
# bukanya : buka
# meresah : resah
# kanbelum : kanbelum
# puluhan : puluh
# nelpon : nelpon
# maling : maling
# bahasa : bahasa
# duh : duh
# sopan : sopan
# santun : santun
# entar : entar
# siang : siang
# dicairkan : cair
# contact : contact
# maa : maa
# allah : allah
# professional : professional
# komunikatif : komunikatif
# bagussayang : bagussayang
# pos : pos
# please : please
# dimengerti : erti
# pengusaha : usaha
# bijak : bijak
# sehat : sehat
# mantapsudah : mantapsudah
# bagussesuai : bagussesuai
# dihati : hati
# kebijaksanaan : bijaksana
# boskuh : boskuh
# log : log
# tawarkan : tawar
# kudu : kudu
# bagussemua : bagussemua
# rillrespon : rillrespon
# cepatpuas : cepatpuas
# enggak pernah : enggak pernah
# vocher : vocher
# najis : najis
# terpercayasemua : terpercayasemua
# adajelascepat : adajelascepat
# komplit : komplit
# playlater : playlater
# lapaksudah : lapaksudah
# dicoba : coba
# mantapsemakin : mantapsemakin
# bukalapakmemberikan : bukalapakmemberikan
# bertransaksitx : bertransaksitx
# mengecewakanmasa : mengecewakanmasa
# lazadadi : lazadadi
# dilesan : les
# dikirimnya : kirim
# dibuatkan : buat
# diupgrade : diupgrade
# gunakanpadahal : gunakanpadahal
# lunastransakasi : lunastransakasi
# teruscoba : teruscoba
# faylaternya : faylaternya
# bisah : bisah
# nagihnya : nagihnya
# pengganti : ganti
# bukasen : bukasen
# input : input
# kostumer : kostumer
# media : media
# sosial : sosial
# fb : fb
# aktf : aktf
# cht : cht
# agen : agen
# memahami : paham
# penyedot : sedot
# lemotblengga : lemotblengga
# inikayak : inikayak
# xxxxx : xxxxx
# mantulll : mantulll
# kondisi : kondisi
# very : very
# gus : gus
# diriwayat : riwayat
# penerima : terima
# laganan : lagan
# perbarui : baru
# kualitas : kualitas
# menurun : turun
# pembelijangan : pembelijangan
# dulususah : dulususah
# komfirmasi : komfirmasi
# fast : fast
# kepuasan : puas
# diseleksi : seleksi
# menunda : tunda
# pesanannya : pesan
# lagibuang : lagibuang
# euy : euy
# vouchernya : vouchernya
# kargo : kargo
# laman : laman
# tks : tks
# filter : filter
# bgtpadahal : bgtpadahal
# bekasipake : bekasipake
# brng : brng
# pengirimankedepanya : pengirimankedepanya
# pdam : pdam
# dipercepat : cepat
# tanggalnya : tanggal
# diawal : awal
# jembutsaya : jembutsaya
# dagang : dagang
# dlliklan : dlliklan
# belasan : bas
# boroboro : boroboro
# munculbangsaaatt : munculbangsaaatt
# dalamapa : dalamapa
# bongkaran : bongkar
# dominosaya : dominosaya
# susahcukup : susahcukup
# pelatihan : latih
# bgtmantep : bgtmantep
# sisi : sisi
# popup : popup
# dikirimlha : dikirimlha
# kendaladan : kendaladan
# solusitidak : solusitidak
# utamakan : utama
# merah : merah
# bendera : bendera
# putih : putih
# jingga : jingga
# cintai : cinta
# karya : karya
# bangsa : bangsa
# bagusbanyakin : bagusbanyakin
# codnya : codnya
# byar : byar
# dobel : dobel
# bunga : bunga
# anjir : anjir
# mencret : mencret
# we : we
# penasaran : penasaran
# rentenir : rentenir
# parahnya : parah
# kelewatan : lewat
# unistal : unistal
# pengambilan : ambil
# keping : keping
# gram : gram
# bintan : bintan
# kunci : kunci
# csa : csa
# pelayananaslowresponudh : pelayananaslowresponudh
# masalaha : masalaha
# selesaisorry : selesaisorry
# aplikasimending : aplikasimending
# tokped : tokped
# nonaktifin : nonaktifin
# skalian : skalian
# ber : ber
# original : original
# reward : reward
# btblbnfvpw : btblbnfvpw
# luncurkan : luncur
# versi : versi
# lite : lite
# mah : mah
# minimum : minimum
# makai : maka
# mudahan : mudah
# cashback : cashback
# ampuuuunnnnnbaru : ampuuuunnnnnbaru
# downlod : downlod
# lemooooooooottttttudh : lemooooooooottttttudh
# kebuka : buka
# layarnya : layar
# teruuuuussssaplikasi : teruuuuussssaplikasi
# jlelekgk : jlelekgk
# masuktp : masuktp
# terpotongmau : terpotongmau
# digubriskecewa : digubriskecewa
# trim : trim
# gan : gan
# mendarat : darat
# selamat : selamat
# manfaat : manfaat
# diberanda : beranda
# gambarnya : gambar
# kosongsearch : kosongsearch
# kosonggimana : kosonggimana
# jringan : jringan
# ngebut : ngebut
# setenga : setenga
# serbah : serbah
# laloadnya : laloadnya
# malam : malam
# ngebug : ngebug
# yx : yx
# responnya : responnya
# samday : samday
# sekeng : keng
# urgent : urgent
# disarankan : saran
# jangn : jangn
# sinh : sinh
# rubah : rubah
# emailnya : email
# stuck : stuck
# captcha : captcha
# situh : situh
# melulubebalik : melulubebalik
# bacaan : baca
# begituan : begitu
# pembelanjaan : belanja
# mngajukan : mngajukan
# payltr : payltr
# nihpadahal : nihpadahal
# fullberat : fullberat
# trmksh : trmksh
# puassssssssssssbanget : puassssssssssssbanget
# berhasilaplikasi : berhasilaplikasi
# taiiiii : taiiiii
# ketidak : tidak
# nyamanan : nyaman
# bla : bla
# jaman : jaman
# best : best
# tertinggal : tinggal
# menjalankan : jalan
# kelola : kelola
# terimaka : terimaka
# thanks : thanks
# baguskalo : baguskalo
# murahsama : murahsama
# kelas : kelas
# pelayananterutama : pelayananterutama
# transitnya : transit
# badal : badal
# terusapk : terusapk
# berbelit : belit
# belit : belit
# dicobasemoga : dicobasemoga
# signal : signal
# kebutuhandan : kebutuhandan
# berkwalitas : berkwalitas
# grab : grab
# depoktangsel : depoktangsel
# jaraka : jaraka
# bisabisa : bisabisa
# upnya : upnya
# depelover : depelover
# diprosses : diprosses
# pelyanannya : pelyanannya
# woiiiiiii : woiiiiiii
# manaudah : manaudah
# logindaftar : logindaftar
# ongkirtp : ongkirtp
# murahjd : murahjd
# mengadakan : ada
# referral : referral
# rezeki : rezeki
# mengajak : ajak
# mendaftar : daftar
# perpanjang : panjang
# bukutabungan : bukutabungan
# hpgmail : hpgmail
# code : code
# undangan : undang
# btblvj : btblvj
# laaahh : laaahh
# kabupaten : kabupaten
# padalarang : padalarang
# mesan : mesan
# februari : februari
# tulisan : tulis
# nobody : nobody
# at : at
# home : home
# dirumah : rumah
# ente : ente
# beginiga : beginiga
# kabbandung : kabbandung
# jakarta : jakarta
# nasabah : nasabah
# paylaternyakatanya : paylaternyakatanya
# bareng : bareng
# mantablah : mantablah
# rekomend : rekomend
# muluss : muluss
# turunkan : turun
# difitur : difitur
# berdaya : daya
# banding : banding
# dipriroritaskan : dipriroritaskan
# pembeki : bek
# keselahan : lah
# mengulang : ulang
# beresin : resin
# terganggu : ganggu
# aplika : aplika
# itikad : itikad
# yrus : yrus
# berkembang : kembang
# kerendan : kerendan
# paylatersama : paylatersama
# lzdgak : lzdgak
# bukalapakpadahal : bukalapakpadahal
# daftarapa : daftarapa
# ditambahin : ditambahin
# distatus : status
# kompaliannya : kompaliannya
# rada : rada
# eksis : eks
# prosespelapak : prosespelapak
# meresponsolusi : meresponsolusi
# menungguini : menungguini
# pemrosesan : pemrosesan
# sekaliterutama : sekaliterutama
# membayar : bayar
# pepek : pepek
# macet : macet
# jos : jos
# loadinggg : loadinggg
# alah : alah
# sampaaaahhhhhh : sampaaaahhhhhh
# janji : janji
# alhamdulilah : alhamdulilah
# kemajuan : maju
# beljar : beljar
# mudahada : mudahada
# kluhan : kluhan
# dilayani : layan
# streaming : streaming
# tirmkasih : tirmkasih
# letoy : letoy
# audit : audit
# gimmick : gimmick
# inisemoga : inisemoga
# terussukses : terussukses
# tik : tik
# tok : tok
# masang : masang
# ayo : ayo
# diminati : mati
# grosiran : grosir
# pelayan : layan
# buruuktiap : buruuktiap
# solusiyg : solusiyg
# dirugikan : rugi
# sellertrrimakasih : sellertrrimakasih
# mu : mu
# sebelahbrafobukalapak : sebelahbrafobukalapak
# onlinetapi : onlinetapi
# buatlah : buat
# indomaretalfamartbahkan : indomaretalfamartbahkan
# atmjadi : atmjadi
# cas : cas
# memorinya : memori
# terpaksa : paksa
# kemauan : mau
# otomasi : otomasi
# kerlambatan : kerlambatan
# lakh : lakh
# negatif : negatif
# plin : plin
# plan : plan
# merespon : merespon
# mengepentingkan : penting
# nb : nb
# menawarkan : tawar
# shopy : shopy
# lakukan : laku
# booking : booking
# muncultdk : muncultdk
# tercantum : cantum
# nyangkut : nyangkut
# resmi : resmi
# judul : judul
# gambar : gambar
# memodifikasi : modifikasi
# selainnya : selain
# hantu : hantu
# lapor : lapor
# mobile : mobile
# alhamdulillahnya : alhamdulillah
# disc : disc
# esok : esok
# masukannya : masuk
# segi : segi
# sebentar : sebentar
# mata : mata
# berkunang : nang
# kunang : nang
# warna : warna
# warni : warni
# lollipop : lollipop
# sihketika : sihketika
# adil : adil
# nombokin : nombokin
# lingkungan : lingkung
# menghilangkan : hilang
# serbu : serbu
# seru : seru
# casback : casback
# badai : badai
# tap : tap
# melimpah : limpah
# bersamaan : sama
# tiru : tiru
# muluk : muluk
# hadiah : hadiah
# merata : rata
# berbelitbelit : berbelitbelit
# trik : trik
# anu : anu
# jenis : jenis
# ogah : ogah
# lucu : lucu
# pilihah : pilihah
# komentar : komentar
# dibintang : bintang
# usahini : usahini
# aps : aps
# berisik : berisik
# silakan : sila
# bye : bye
# csnya : csnya
# ramah : ramah
# melayani : layan
# positif : positif
# diputus : putus
# pertimbangannya : timbang
# training : training
# kompeten : kompeten
# sikap : sikap
# nenguntungkan : nenguntungkan
# persetujuan : tuju
# hatihati : hatihati
# cermat : cermat
# mutermuter : mutermuter
# market : market
# place : place
# backup : backup
# tuntas : tuntas
# berpikir : pikir
# benerin : benerin
# pemgiriman : pemgiriman
# setatus : setatus
# brang : brang
# keburu : keburu
# mingkin : mingkin
# finalti : finalti
# perbiaki : biak
# lagicoba : lagicoba
# menurunbukan : menurunbukan
# membaik : baik
# pengelompokan : kelompok
# wishlist : wishlist
# mengelompokkan : kelompok
# stabilitas : stabilitas
# detailnya : detail
# dipesan : pes
# bertul : bertul
# emah : emah
# lapangan : lapang
# file : file
# mbak : mbak
# crop : crop
# dikecilkan : kecil
# komputer : komputer
# maunya : mau
# dibatasbatasin : dibatasbatasin
# tanggapanapa : tanggapanapa
# karyawannya : karyawannya
# provider : provider
# woy : woy
# berhenti : henti
# kethabis : kethabis
# memuncak : puncak
# ditiadakan : tiada
# bersifat : sifat
# dikonfirmasi : konfirmasi
# improve : improve
# perampok : rampok
# pakaidan : pakaidan
# belanjatp : belanjatp
# rewardatau : rewardatau
# kelebihan : lebih
# adasama : adasama
# baruakhir : baruakhir
# lainsemakin : lainsemakin
# sellertoko : sellertoko
# direct : direct
# pengirimanretur : pengirimanretur
# semangaaat : semangaaat
# timmanjemen : timmanjemen
# penggantian : ganti
# sayangnya : sayang
# kasik : kasik
# arahkan : arah
# mengikuti : ikut
# instruksi : instruksi
# team : team
# custumernya : custumernya
# pasword : pasword
# elh : elh
# dihubungi : hubung
# kacau : kacau
# bukalapaknamun : bukalapaknamun
# tgn : tgn
# ongkirjasa : ongkirjasa
# kuriryang : kuriryang
# mahaltujuan : mahaltujuan
# manado : manado
# ribunamun : ribunamun
# permainan : main
# alias : alias
# darathanya : darathanya
# ribualhasil : ribualhasil
# samasaya : samasaya
# berbenahjgn : berbenahjgn
# permainkan : main
# pelangganjangan : pelangganjangan
# salahkan : salah
# arror : arror
# amanan : aman
# bot : bot
# pokok : pokok
# bukamaal : bukamaal
# kenapaverifikasi : kenapaverifikasi
# kodenyasampe : kodenyasampe
# terusuninstal : terusuninstal
# bisakode : bisakode
# bnyaktapi : bnyaktapi
# difungsikan : fungsi
# bintangnyakarena : bintangnyakarena
# sayaudh : sayaudh
# terhitung : hitung
# sayasaya : sayasaya
# naikin : naikin
# recom : recom
# gila : gila
# okelah : oke
# fine : fine
# gapapa : gapapa
# fair : fair
# zolim : zolim
# namanya : nama
# dasboard : dasboard
# kriteria : kriteria
# mencairkan : cair
# langkah : langkah
# poto : poto
# telpon : telpon
# tiket : tiket
# mas : mas
# mbangking : mbangking
# baca : baca
# sinyal : sinyal
# whatapps : whatapps
# terbayar : bayar
# hubungiaktifpercuma : hubungiaktifpercuma
# evalusi : evalusi
# sukabikin : sukabikin
# costumers : costumers
# apapunbaik : apapunbaik
# pengirimanada : pengirimanada
# compl : compl
# tanggapdisc : tanggapdisc
# sebelahsejauh : sebelahsejauh
# terusmakin : terusmakin
# majusukses : majusukses
# menghasilkan : hasil
# bermutu : mutu
# covid : covid
# dicentang : centang
# merekatanpa : merekatanpa
# centangkalau : centangkalau
# rupiah : rupiah
# bukalapakada : bukalapakada
# kebakaran : bakar
# waktunyaudah : waktunyaudah
# blga : blga
# blapa : blapa
# melaporkan : lapor
# jawabga : jawabga
# dlutolong : dlutolong
# bantuanya : bantuanya
# mengirim : kirim
# kota : kota
# setuju : tuju
# ditunggu : tunggu
# terhubung : hubung
# brengseksangat : brengseksangat
# menjengkelkantiap : menjengkelkantiap
# ubah : ubah
# bisaaplikasi : bisaaplikasi
# duniasudah : duniasudah
# teleponaplikasi : teleponaplikasi
# berengsek : berengsek
# dibaca : baca
# mitrabukalapak : mitrabukalapak
# penghasilanbikin : penghasilanbikin
# pelangganbikin : pelangganbikin
# laris : laris
# manisbiaya : manisbiaya
# poin : poin
# lagicari : lagicari
# username : username
# adeirmasari : adeirmasari
# ranting : ranting
# rekomdasi : rekomdasi
# kurisr : kurisr
# irm : irm
# mengantar : antar
# sedia : sedia
# disalah : salah
# kepembayaran : bayar
# diselesaikan : selesai
# dicek : cek
# berkala : kala
# pembelianpenjualan : pembelianpenjualan
# gara : gara
# control : control
# knpsejak : knpsejak
# bajakdi : bajakdi
# situ : situ
# cemasdan : cemasdan
# updatelengkap : updatelengkap
# rinci : rinci
# malesblm : malesblm
# nyablm : nyablm
# nyatrlalu : nyatrlalu
# waktucoba : waktucoba
# ...
# sameday : sameday
# mengantarkan : antar
# terkendali : kendali
# namezulmarrusdiputra : namezulmarrusdiputra
# adasemua : adasemua
# setting : setting
# filternya : filter
# ikonik : ikonik
# susunan : susun
# disederhanakan : sederhana
# transisi : transisi
# memakan : makan
# perusahaan : usaha
# membangun : bangun
# modern : modern
# cttn : cttn
# be : be
# connected : connected
# copy : copy
# perangkat : perangkat
# gamti : gamti
# eamasalah : eamasalah
# cicilansaya : cicilansaya
# merchan : merchan
# verifikasitrus : verifikasitrus
# memuaskandan : memuaskandan
# datangi : datang
# sesui : sesui
# diharapkankurir : diharapkankurir
# okrespon : okrespon
# siiip : siiip
# dihistory : dihistory
# menyertakan : serta
# kenal : kenal
# trnyta : trnyta
# bnar : bnar
# hrg : hrg
# trnytaa : trnytaa
# trma : trma
# trtahan : trtahan
# complen : complen
# bsatidak : bsatidak
# tnggung : tnggung
# blsaya : blsaya
# bossharap : bossharap
# pelan : pelan
# simpati : simpati
# paylaterbayarnya : paylaterbayarnya
# gaessternyata : gaessternyata
# ditetangga : tetangga
# lamagak : lamagak
# pemantauan : pantau
# bulannya : bulan
# koperasi : koperasi
# adabeberapa : adabeberapa
# ongkirlahmasa : ongkirlahmasa
# sukarela : sukarela
# belanjatingkat : belanjatingkat
# peminatnya : minat
# terjaga : jaga
# oriented : oriented
# wasit : wasit
# intermediasi : intermediasi
# haknya : hak
# kompaint : kompaint
# complaint : complaint
# kau : kau
# menceritakan : cerita
# semesta : semesta
# mencatat : catat
# wilayah : wilayah
# papua : papua
# giamanasih : giamanasih
# mgadain : mgadain
# sesuaikalo : sesuaikalo
# sanggup : sanggup
# ngafain : ngafain
# gala : gala
# gj : gj
# saldobuktinya : saldobuktinya
# halaaaah : halaaaah
# loyo : loyo
# vouher : vouher
# pmbelian : pmbelian
# terachir : terachir
# belielektronik : belielektronik
# nyatrimakasih : nyatrimakasih
# sajayang : sajayang
# byaya : byaya
# lanannya : lanannya
# yanyoba : yanyoba
# wkwkwkprasaan : wkwkwkprasaan
# layannalias : layannalias
# besok : besok
# snub : snub
# ring : ring
# lemotsdh : lemotsdh
# bcara : bcara
# verifikasiketika : verifikasiketika
# pesananan : pesananan
# woyy : woyy
# gercep : gercep
# membantusemoga : membantusemoga
# sealu : alu
# penguriman : penguriman
# samakin : samakin
# maksimalkan : maksimal
# bekukanpadahal : bekukanpadahal
# pakaipas : pakaipas
# tangkurak : tangkurak
# butuuuuuuuut : butuuuuuuuut
# reksada : reksada
# pesanancuman : pesanancuman
# loodingnya : loodingnya
# perkiraan : kira
# nyala : nyala
# chapca : chapca
# terferivikasi : terferivikasi
# lemottttmending : lemottttmending
# sat : sat
# iklanhasilnya : iklanhasilnya
# manfaatatnya : manfaatatnya
# satupuntidak : satupuntidak
# lather : lather
# hmnnnmnmmmmmn : hmnnnmnmmmmmn
# berlangganan : langgan
# biometrik : biometrik
# bukalapa : bukalapa
# sayangkan : sayang
# otomatisnya : otomatis
# dulusekali : dulusekali
# parahudh : parahudh
# tahunan : tahun
# lazadauinstal : lazadauinstal
# bukalapakudah : bukalapakudah
# terpakai : pakai
# pto : pto
# pp : pp
# date : date
# centre : centre
# tott : tott
# gadget : gadget
# berselancar : selancar
# jadulku : jadulku
# kepala : kepala
# bapako : bapako
# stop : stop
# saler : saler
# bahaya : bahaya
# pushnya : pushnya
# penipusaya : penipusaya
# bukalapakmksd : bukalapakmksd
# kerjanya : kerja
# kerana : rana
# pinada : pada
# kumpulkan : kumpul
# oia : oia
# penjyal : penjyal
# berbuat : buat
# berwajib : wajib
# masalihat : masalihat
# pegawai : pegawai
# lapakpernah : lapakpernah
# aplikator : aplikator
# memelihara : pelihara
# nyaternyata : nyaternyata
# aplikasii : aplikasi
# bisadi : bisadi
# negeriigoodgood : negeriigoodgood
# kb : kb
# mainkan : main
# coz : coz
# rubahterus : rubahterus
# lolos : lolos
# maless : maless
# bnaget : bnaget
# malashubungkan : malashubungkan
# susahsilahkn : susahsilahkn
# diam : diam
# keluhn : keluhn
# kitamalas : kitamalas
# bklapak : bklapak
# benlanja : benlanja
# shoppe : shoppe
# siaga : siaga
# susahbertanya : susahbertanya
# opensusahgek : opensusahgek
# gdk : gdk
# bumi : bumi
# miskin : miskin
# limid : limid
# kepake : kepake
# mencekit : cekit
# licik : licik
# doakan : doa
# pengurus : urus
# mengenaskan : enas
# riba : riba
# pahit : pahit
# paylaterparah : paylaterparah
# sgini : sgini
# lamabukabantuan : lamabukabantuan
# ribetsusah : ribetsusah
# cpat : cpat
# pokokny : pokokny
# recomendkomplen : recomendkomplen
# bisalive : bisalive
# lagiga : lagiga
# perbaikannya : baik
# seringan : sering
# penjaualan : penjaualan
# rekeninglama : rekeninglama
# rajin : rajin
# nyairkan : nyairkan
# xpenanganan : xpenanganan
# sussh : sussh
# tmbhin : tmbhin
# prdukgk : prdukgk
# tkopedia : tkopedia
# shope : shope
# gampangcontact : gampangcontact
# hbngitnya : hbngitnya
# smuagmna : smuagmna
# konsulpntesan : konsulpntesan
# klah : klah
# mahalsukses : mahalsukses
# istri : istri
# nol : nol
# seting : ting
# banking : banking
# verifikasibikin : verifikasibikin
# darting : darting
# bukalapaksangat : bukalapaksangat
# cashterimkasih : cashterimkasih
# paylatersetiap : paylatersetiap
# rbkalau : rbkalau
# kapooooookk : kapooooookk
# aplicationtapi : aplicationtapi
# sueee : sueee
# nglunasin : nglunasin
# re : re
# kebukapas : kebukapas
# barangselalu : barangselalu
# awaldan : awaldan
# animasi : animasi
# berlaripayah : berlaripayah
# perbaikisaya : perbaikisaya
# respect : respect
# instagram : instagram
# dibales : dibales
# reload : reload
# berabe : berabe
# sarana : sarana
# perantara : antara
# berintegritas : integritas
# tidk : tidk
# keinginanpesanan : keinginanpesanan
# dinamika : dinamika
# kasat : kasat
# diandalkanayo : diandalkanayo
# secepatnyananti : secepatnyananti
# ketinggalankita : ketinggalankita
# surat : surat
# sistemkurang : sistemkurang
# dijadikan : jadi
# formitu : formitu
# masalahnyajawaban : masalahnyajawaban
# lamawaalaaeh : lamawaalaaeh
# berterimakasih : berterimakasih
# aksesnya : akses
# penyampaian : sampai
# materinya : materi
# terperincipelatihannya : terperincipelatihannya
# pahamisangat : pahamisangat
# sayatrimakasih : sayatrimakasih
# terbantu : bantu
# pembelajaran : ajar
# prakerjasaya : prakerjasaya
# menerangkan : terang
# terjun : terjun
# freelancer : freelancer
# nampilin : nampilin
# terpopuler : populer
# komparasi : komparasi
# puaskanpengunaan : puaskanpengunaan
# carisaya : carisaya
# pembuat : buat
# traksaksi : traksaksi
# kaliklo : kaliklo
# terjangkauongkos : terjangkauongkos
# shaller : shaller
# samsung : samsung
# ringansekarang : ringansekarang
# hitam : hitam
# duluterus : duluterus
# merespongak : merespongak
# aplikasibiar : aplikasibiar
# terbawa : bawa
# pebaharui : baharu
# mepersulit : mepersulit
# melakukakan : melakukakan
# kontakcall : kontakcall
# berinteraksi : interaksi
# blnya : blnya
# berbenti : berbenti
# dibagian : bagi
# security : security
# cekup : cekup
# ngurut : ngurut
# ngacak : ngacak
# semuajadi : semuajadi
# lapaklangsung : lapaklangsung
# satusebenarnya : satusebenarnya
# menyukai : suka
# lapakmeski : lapakmeski
# lapaksemoga : lapaksemoga
# memajukan : maju
# dipoto : dipoto
# tanggapannya : tanggap
# dibobol : bobol
# phising : phising
# judulnya : judul
# shoponline : shoponline
# iti : iti
# diperhatikan : perhati
# lapakdan : lapakdan
# kecewasaya : kecewasaya
# abang : abang
# ekspedisinya : ekspedisi
# terjamin : jamin
# sim : sim
# dibanned : dibanned
# hahaa : hahaa
# tulisannya : tulis
# sampenyagak : sampenyagak
# lapaknyapdhallimit : lapaknyapdhallimit
# ributp : ributp
# dinofikasinya : dinofikasinya
# berulng : berulng
# lggimana : lggimana
# mark : mark
# tarif : tarif
# dianggap : anggap
# gerai : gerai
# pembeliannya : beli
# menyempatkan : sempat
# customers : customers
# siasia : siasia
# naikkan : naik
# bukadanabukadompet : bukadanabukadompet
# bukadana : bukadana
# uninsntall : uninsntall
# systemnya : systemnya
# sebelmnya : sebelmnya
# perpaling : paling
# menghalangi : halang
# ditemui : temu
# laih : laih
# dipertimbangkan : timbang
# survey : survey
# berkaitan : kait
# telur : telur
# rusakkomplainnya : rusakkomplainnya
# sepadan : padan
# hasilnyakarna : hasilnyakarna
# klaimkomplain : klaimkomplain
# rusaknya : rusak
# ekspedisimemang : ekspedisimemang
# kitauntuk : kitauntuk
# bis : bis
# terkrimalamat : terkrimalamat
# kadaluwarsa : kadaluwarsa
# jeleknya : jelek
# terbaiiiiiiiiiiik : terbaiiiiiiiiiiik
# mempesona : pesona
# ribetsulit : ribetsulit
# memudahkanmantap : memudahkanmantap
# dbayar : dbayar
# lunastp : lunastp
# dpesan : dpesan
# pelapakkesan : pelapakkesan
# mantabbbbb : mantabbbbb
# pelayanannyacepat : pelayanannyacepat
# terbusuk : busuk
# waitnya : waitnya
# komplenretur : komplenretur
# barangikutin : barangikutin
# tutorial : tutorial
# dibantuan : bantu
# menjerumuskan : jerumus
# selesaimerasa : selesaimerasa
# miin : miin
# dibutuhkan : butuh
# tingkatkn : tingkatkn
# plater : plater
# mantafcuman : mantafcuman
# pelayanannyadan : pelayanannyadan
# referal : referal
# benerrrrrr : benerrrrrr
# niatny : niatny
# bpm : bpm
# kedebet : debet
# mantapmudah : mantapmudah
# upgr : upgr
# bagustidak : bagustidak
# sinirekomen : sinirekomen
# pesansn : pesansn
# nyobak : nyobak
# smpk : smpk
# hapusstrrnyta : hapusstrrnyta
# ttpapa : ttpapa
# begn : begn
# veripikasi : veripikasi
# lapaktoko : lapaktoko
# masyarakatmohon : masyarakatmohon
# keamananperlindungan : keamananperlindungan
# mengurus : urus
# dsuruh : dsuruh
# packing : packing
# mantapluar : mantapluar
# berfaedah : faedah
# ngerelog : ngerelog
# terusrefresh : terusrefresh
# readydan : readydan
# ulah : ulah
# passwordya : passwordya
# ngaktifin : ngaktifin
# helloooo : helloooo
# mudahmudahan : mudahmudahan
# lainbagus : lainbagus
# blokiranda : blokiranda
# ngulang : ngulang
# rungkad : rungkad
# afk : afk
# bravo : bravo
# minjam : minjam
# amanlumayan : amanlumayan
# memantau : pantau
# jalannya : jalan
# gulung : gulung
# tikar : tikar
# dengarkan : dengar
# saka : saka
# tercepat : cepat
# ammmpuuun : ammmpuuun
# rewel : rewel
# huuuhpayah : huuuhpayah
# sekarangmalesbosen : sekarangmalesbosen
# keselkarena : keselkarena
# perbaharui : baharu
# leletlemotkayak : leletlemotkayak
# siput : siput
# mabuktolong : mabuktolong
# perbaikidan : perbaikidan
# persyaratannya : syarat
# terbarutapi : terbarutapi
# bisatrims : bisatrims
# panjual : panjual
# weekend : weekend
# novita : novita
# sari : sari
# peserta : serta
# mentor : mentor
# memotivasi : motivasi
# wawasan : wawas
# potensi : potensi
# miliki : milik
# adadan : adad
# pengiklanan : iklan
# assalamualaikum : assalamualaikum
# membelih : membelih
# berjudul : judul
# kuasai : kuasa
# berbicara : bicara
# teknik : teknik
# nlp : nlp
# pelatihannya : latih
# ditoko : toko
# orangehijau : orangehijau
# ngrestart : ngrestart
# reset : reset
# kenyamana : kenyamana
# optimalkan : optimal
# optimalisasi : optimalisasi
# membentuk : bentuk
# luas : luas
# motor : motor
# mobil : mobil
# caseback : caseback
# vita : vita
# membelinya : bel
# tema : tema
# menarikedukatif : menarikedukatif
# inspiratif : inspiratif
# pencarinya : pencar
# difilter : filter
# lakunya : laku
# cacat : cacat
# kamera : kamera
# memotret : potret
# hptidak : hptidak
# familiar : familiar
# dropshiper : dropshiper
# supplier : supplier
# menonaktifkan : nonaktif
# paylaterpadahal : paylaterpadahal
# balesan : balesan
# respone : respone
# oiya : oiya
# bugbuka : bugbuka
# lamamasuk : lamamasuk
# lamake : lamake
# iconnya : iconnya
# ahjgn : ahjgn
# inigak : inigak
# tulisanmu : tulis
# down : down
# cobalagi : cobalagi
# terusmenjengkelkan : terusmenjengkelkan
# tokosebelah : tokosebelah
# saing : saing
# pelangganny : pelangganny
# fiturfitur : fiturfitur
# bervariatif : variatif
# frakerja : frakerja
# bahasanya : bahasa
# kemenaker : kemenaker
# terbantudengan : terbantudengan
# ilmu : ilmu
# burukkk : burukkk
# oper : oper
# konfirmasitindak : konfirmasitindak
# penarikan : tari
# nyesal : nyesal
# rademnya : rademnya
# pelayananan : pelayananan
# bukacare : bukacare
# ditanggapin : ditanggapin
# aktifan : aktif
# oklebih : oklebih
# terimakasi : terimakasi
# terdepan : depan
# masala : masala
# alamin : alamin
# sempurna : sempurna
# makain : makain
# promosikan : promosi
# mengembirakan : mengembirakan
# ekspetasi : ekspetasi
# ektp : ektp
# blur : blur
# delete : delete
# frame : frame
# teus : teus
# komisi : komisi
# kab : kab
# kediri : diri
# fif : fif
# adira : adira
# printer : printer
# bluetooth : bluetooth
# kasirnya : kasir
# terintegrasi : integrasi
# keamanannya : aman
# diprioritaskan : prioritas
# lampiran : lampir
# beol : beol
# ive : ive
# idea : idea
# kesepakatan : sepakat
# coin : coin
# tujuanya : tujuanya
# hangusnya : hangus
# panjangin : panjangin
# responkarena : responkarena
# langsungsemuanya : langsungsemuanya
# chatpelayanan : chatpelayanan
# hayalandi : hayalandi
# cat : cat
# tinggalkan : tinggal
# antri : antri
# penyelesaianmari : penyelesaianmari
# ramai : ramai
# {'paylater': 'paylater', 'batalkan': 'batal', 'otomatis': 'otomatis', 'kadang': 'kadang', 'nya': 'nya', 'gantian': 'ganti', 'jatuh': 'jatuh', 'tempo': 'tempo', 'bayar': 'bayar', 'biaya': 'biaya', 'keterlambatan': 'lambat', 'layanan': 'layan', 'biar': 'biar', 'merasakan': 'rasa', 'rasakan': 'rasa', 'sistem': 'sistem', 'seenak': 'enak', 'chat': 'chat', 'susah': 'susah', 'error': 'error', 'menyalahkan': 'salah', 'bikin': 'bikin', 'pusing': 'pusing', 'kesini': 'kesini', 'buka': 'buka', 'lapak': 'lapak', 'bagus': 'bagus', 'pelayanannya': 'layan', 'komplan': 'komplan', 'banget': 'banget', 'beberapakali': 'beberapakali', 'transaksi': 'transaksi', 'rekening': 'rekening', 'deh': 'deh', 'kepotong': 'potong', 'lapaknya': 'lapak', 'terverifikasi': 'verifikasi', 'kalo': 'kalo', 'pengin': 'pengin', 'komplain': 'komplain', 'menu': 'menu', 'upload': 'upload', 'bukti': 'bukti', 'bayarnya': 'bayar', 'muncul': 'muncul', 'kali': 'kali', 'kehilangan': 'hilang', 'uang': 'uang', 'pembayaran': 'bayar', 'gagal': 'gagal', 'batal': 'batal', 'pesanan': 'pesan', 'ya': 'ya', 'penjual': 'jual', 'bilang': 'bilang', 'ready': 'ready', 'stok': 'stok', 'habis': 'habis', 'nomor': 'nomor', 'duit': 'duit', 'ditransfer': 'transfer', 'dikirim': 'kirim', 'amplop': 'amplop', 'kosong': 'kosong', 'pembeli': 'beli', 'cs': 'cs', 'bukabantuan': 'bukabantuan', 'dikasih': 'kasih', 'template': 'template', 'kagak': 'kagak', 'solusi': 'solusi', 'suruh': 'suruh', 'menunggu': 'tunggu', 'jam': 'jam', 'batas': 'batas', 'proses': 'proses', 'tuh': 'tuh', 'parah': 'parah', 'asli': 'asli', 'dosa': 'dosa', 'lu': 'lu', 'menahan': 'tahan', 'rejeki': 'rejeki', 'orang': 'orang', 'paraaaahhhh': 'paraaaahhhh', 'min': 'min', 'mautanya': 'mautanya', 'jual': 'jual', 'barang': 'barang', 'bukalapak': 'bukalapak', 'lihat': 'lihat', 'calon': 'calon', 'terkecuali': 'kecuali', 'kasih': 'kasih', 'link': 'link', 'akses': 'akses', 'beli': 'beli', 'sistemnya': 'sistem', 'kayak': 'kayak', 'item': 'item', 'saldo': 'saldo', 'potong': 'potong', 'kedaluarsa': 'kedaluarsa', 'satunya': 'satu', 'kirim': 'kirim', 'keterangan': 'terang', 'pakai': 'pakai', 'kecewa': 'kecewa', 'pelapak': 'lapak', 'disaat': 'saat', 'terkait': 'kait', 'permintaan': 'minta', 'pengembalian': 'kembali', 'dana': 'dana', 'penjualanpembatalan': 'penjualanpembatalan', 'notif': 'notif', 'apl': 'apl', 'bulalapak': 'bulalapak', 'nyanotif': 'nyanotif', 'penjualan': 'jual', 'email': 'email', 'menanggapi': 'tanggap', 'dibatalkan': 'batal', 'kembalikan': 'kembali', 'merugikan': 'rugi', 'cek': 'cek', 'mohon': 'mohon', 'perbaiki': 'baik', 'fitur': 'fitur', 'tolong': 'tolong', 'tabungan': 'tabung', 'diskon': 'diskon', 'diperbanyak': 'banyak', 'produknya': 'produk', 'produk': 'produk', 'membeli': 'beli', 'langsung': 'langsung', 'fiture': 'fiture', 'cicilan': 'cicil', 'lunas': 'lunas', 'moga': 'moga', 'maju': 'maju', 'aplikasi': 'aplikasi', 'trnsaksi': 'trnsaksi', 'pulsa': 'pulsa', 'berhasilpulsa': 'berhasilpulsa', 'masuktagihan': 'masuktagihan', 'adakomplen': 'adakomplen', 'diurus': 'urus', 'bantuan': 'bantu', 'live': 'live', 'mesin': 'mesin', 'olshop': 'olshop', 'rampog': 'rampog', 'paraaaaaaaahhhhh': 'paraaaaaaaahhhhh', 'dear': 'dear', 'check': 'check', 'posisi': 'posisi', 'pesana': 'sana', 'loading': 'loading', 'bug': 'bug', 'perhatiannya': 'perhati', 'kerusakan': 'rusa', 'system': 'system', 'perbaikan': 'baik', 'menggangu': 'menggangu', 'penggunaan': 'guna', 'nyaman': 'nyaman', 'semoga': 'moga', 'dengar': 'dengar', 'terima': 'terima', 'mengecewakan': 'kecewa', 'membela': 'bela', 'kepentingan': 'penting', 'pelanggan': 'langgan', 'status': 'status', 'selesai': 'selesai', 'menjanjikan': 'janji', 'pengiriman': 'kirim', 'seminggu': 'minggu', 'iklan': 'iklan', 'halaman': 'halaman', 'pemakai': 'pakai', 'klik': 'klik', 'meninggalkan': 'tinggal', 'bl': 'bl', 'ribet': 'ribet', 'super': 'super', 'seller': 'seller', 'kuota': 'kuota', 'dagangan': 'dagang', 'jualannya': 'jual', 'antik': 'antik', 'unik': 'unik', 'quota': 'quota', 'diketerangan': 'terang', 'promosi' ...
# ------------------------
# Pandas Apply:   0%|          | 0/1300 [00:00<?, ?it/s]

# %%
name_dataframe["Ulasan_clean"] = [' '.join(map(str, l)) for l in name_dataframe['Ulasan_Stemmed']]

# %%
name_dataframe.to_excel("tokped_text.xlsx")

# %%
ulasan = ' '.join(str(v) for v in name_dataframe['Ulasan_clean'])

# %%
tokenize_ulasan = word_tokenize(ulasan)

# %%
tokenize_ulasan
# Out:
# ['paylater',
#  'batal',
#  'otomatis',
#  'kadang',
#  'nya',
#  'ganti',
#  'jatuh',
#  'tempo',
#  'bayar',
#  'biaya',
#  'lambat',
#  'biaya',
#  'layan',
#  'biar',
#  'rasa',
#  'rasa',
#  'sistem',
#  'enak',
#  'nya',
#  'chat',
#  'susah',
#  'kadang',
#  'error',
#  'salah',
#  'layan',
#  'nya',
#  'bikin',
#  'pusing',
#  'ganti',
#  'pusing',
#  'kesini',
#  'buka',
#  'lapak',
#  'bagus',
#  'layan',
#  'komplan',
#  'susah',
#  'susah',
#  'banget',
#  'beberapakali',
#  'transaksi',
#  'rekening',
#  'deh',
#  'potong',
#  'buka',
#  'lapak',
#  'verifikasi',
#  'kalo',
#  'pengin',
#  'komplain',
#  'menu',
#  'upload',
#  'bukti',
#  'bayar',
#  'muncul',
#  'kali',
#  'kali',
#  'hilang',
#  'uang',
#  'bayar',
#  'gagal',
#  'verifikasi',
#  'batal',
#  'pesan',
#  'susah',
#  'ya',
#  'jual',
#  'bilang',
#  'ready',
#  'stok',
#  'habis',
#  'nomor',
#  'rekening',
#  'biar',
#  'duit',
#  'transfer',
#  'kirim',
#  'amplop',
#  'kosong',
#  'jual',
#  'transaksi',
#  'beli',
#  'amplop',
#  'kosong',
#  'komplain',
#  'cs',
#  'bukabantuan',
#  'kasih',
#  'template',
#  'kagak',
#  'solusi',
#  'suruh',
#  'tunggu',
#  'jam',
#  'batas',
#  'proses',
#  'tuh',
#  'batal',
#  'otomatis',
#  'parah',
#  'asli',
#  'parah',
#  'dosa',
#  'lu',
#  'tahan',
#  'rejeki',
#  'orang',
#  'batal',
#  'transaksi',
#  'banget',
#  'paraaaahhhh',
#  'min',
#  'mautanya',
#  'jual',
#  'barang',
#  'bukalapak',
#  'barang',
#  'jual',
#  'lihat',
#  'calon',
#  'beli',
#  'kecuali',
#  'kasih',
#  'link',
#  'barang',
#  'nya',
#  'akses',
#  'beli',
#  'beli',
#  'barang',
#  'sistem',
#  'kayak',
#  'error',
#  'bayar',
#  'item',
#  'saldo',
#  'potong',
#  'sistem',
#  'pesan',
#  'kedaluarsa',
#  'satu',
#  'beli',
#  'item',
#  'satu',
#  'kirim',
#  'beli',
#  'saldo',
#  'potong',
#  'terang',
#  'pakai',
#  'terang',
#  'kecewa',
#  'bukalapak',
#  'lapak',
#  'saat',
#  'komplain',
#  'beli',
#  'kait',
#  'minta',
#  'kembali',
#  'dana',
#  'penjualanpembatalan',
#  'transaksi',
#  'notif',
#  'apl',
#  'bulalapak',
#  'nyanotif',
#  'transaksi',
#  'jual',
#  'notif',
#  'email',
#  'tanggap',
#  'email',
#  'transaksi',
#  'jam',
#  'otomatis',
#  'batal',
#  'dana',
#  'jual',
#  'otomatis',
#  'kembali',
#  'beli',
#  'barang',
#  'kirim',
#  'rugi',
#  'lapak',
#  'saat',
#  'lapak',
#  'cek',
#  'email',
#  'mohon',
#  'baik',
#  'fitur',
#  'komplain',
#  'tolong',
#  'tabung',
#  'diskon',
#  'banyak',
#  'produk',
#  'produk',
#  'orang',
#  'beli',
#  'barang',
#  'langsung',
#  'fiture',
#  'bayar',
#  'cicil',
#  'kalo',
#  'lunas',
#  'barang',
#  'kirim',
#  'orang',
#  'fiture',
#  'moga',
#  'bukalapak',
#  'maju',
#  'aplikasi',
#  'parah',
#  'trnsaksi',
#  'pulsa',
#  'berhasilpulsa',
#  'masuktagihan',
#  'nya',
#  'adakomplen',
#  'urus',
#  'menu',
#  'bantu',
#  'live',
#  'chat',
#  'mesin',
#  'satu',
#  'olshop',
#  'rampog',
#  'transaksi',
#  'muncul',
#  'biaya',
#  'layan',
#  'paraaaaaaaahhhhh',
#  'dear',
#  'bukalapak',
#  'buka',
#  'transaksi',
#  'check',
#  'posisi',
#  'sana',
#  'loading',
#  'nya',
#  'bug',
#  'mohon',
#  'perhati',
#  'rusa',
#  'system',
#  'mohon',
#  'baik',
#  'menggangu',
#  'transaksi',
#  'guna',
#  'nyaman',
#  'moga',
#  'dengar',
#  'bukalapak',
#  'terima',
#  'kasih',
#  'kecewa',
#  'bela',
#  'penting',
#  'langgan',
#  'barang',
#  'kembali',
#  'status',
#  'transaksi',
#  'terima',
#  'selesai',
#  'komplain',
#  'langsung',
#  'uang',
#  'lapak',
#  'janji',
#  'kirim',
#  'deh',
#  'minggu',
#  'barang',
#  'kirim',
#  'iklan',
#  'halaman',
#  'pakai',
#  'klik',
#  'tinggal',
#  'bl',
#  'ribet',
#  'super',
#  'seller',
#  'kuota',
#  'barang',
#  'dagang',
#  'jual',
#  'antik',
#  'unik',
#  'bayar',
#  'pakai',
#  'bayar',
#  'quota',
#  'barang',
#  'terang',
#  'promosi',
#  'toko',
#  'belah',
#  'payleter',
#  'bayar',
#  'lancar',
#  'payleter',
#  'nya',
#  'pakai',
#  'top',
#  'up',
#  'game',
#  'cancel',
#  'otomatis',
#  'bukalapak',
#  'sungguh',
#  'kecewa',
#  'loading',
#  'verifikasi',
#  'email',
#  'validpadahal',
#  'data',
#  'email',
#  'kesal',
#  'nya',
#  'login',
#  'login',
#  'download',
#  'bukalapak',
#  'kesal',
#  'daftar',
#  'nya',
#  'jelek',
#  'bukalapak',
#  'aplikasi',
#  'lot',
#  'adu',
#  'bukabantuan',
#  'langsung',
#  'tele',
#  'kesana',
#  'kemari',
#  'coba',
#  'kasih',
#  'menu',
#  'langsung',
#  'tinggal',
#  'klik',
#  'cari',
#  'barang',
#  'koleksi',
#  'dikit',
#  'cuman',
#  'dikit',
#  'barang',
#  'kalah',
#  'aplikasi',
#  'bl',
#  'sepi',
#  'jual',
#  'barang',
#  'bulan',
#  'laku',
#  'tokopedia',
#  'laku',
#  'stagnan',
#  'kayak',
#  'greget',
#  'ol',
#  'shop',
#  'bukalapakygdulu',
#  'pakai',
#  'bukalapak',
#  'kendala',
#  'belanja',
#  'online',
#  'pakai',
#  'aplikasi',
#  'bonus',
#  'credit',
#  'kasih',
#  'ulas',
#  'barang',
#  'senang',
#  'sistem',
#  'error',
#  'syarat',
#  'tentu',
#  'tahu',
#  'bukalapak',
#  'kesini',
#  'bst',
#  'dagang',
#  'modal',
#  'pas',
#  'muterin',
#  'duit',
#  'beli',
#  'kirim',
#  'ambil',
#  'transaksi',
#  'selesai',
#  'beli',
#  'kasih',
#  'feedback',
#  'akibat',
#  'dana',
#  'masuk',
#  'akun',
#  'notifikasi',
#  'sampah',
#  'notifikasi',
#  'guna',
#  'lapak',
#  'beli',
#  'nyaman',
#  'tsbt',
#  'kalo',
#  'notif',
#  'nya',
#  'mati',
#  'makan',
#  'notifikasi',
#  'beli',
#  'hilang',
#  'kalo',
#  'notifikasi',
#  'beli',
#  'aktif',
#  'notifikasi',
#  'sampah',
#  'masuk',
#  'pilih',
#  'barang',
#  'muncul',
#  'menu',
#  'cari',
#  'pilih',
#  'zonk',
#  'barang',
#  'hapus',
#  'alhasil',
#  'menu',
#  'cari',
#  'pilih',
#  'barang',
#  'zonk',
#  'lapak',
#  'langgar',
#  'alhasil',
#  'menu',
#  'cari',
#  'pilih',
#  'saran',
#  'barang',
#  'hapus',
#  'lapak',
#  'langgar',
#  'muncul',
#  'menu',
#  'cari',
#  'menu',
#  'cari',
#  'kapai',
#  'tampil',
#  'barang',
#  'baik',
#  'aplikasi',
#  'bukalapak',
#  'bagus',
#  'kecewa',
#  'sistem',
#  'benarbenar',
#  'tata',
#  'tipu',
#  'kirim',
#  'batas',
#  'palak',
#  'kirim',
#  'pesan',
#  'sistem',
#  'langsung',
#  'kembali',
#  'dana',
#  'transfer',
#  'puas',
#  'mohon',
#  'bantuannyasaya',
#  'alami',
#  'sulit',
#  'logindikarenakan',
#  'akun',
#  'terima',
#  'kode',
#  'otp',
#  'nomor',
#  'masuk',
#  'nomor',
#  'aktifmau',
#  'bantu',
#  'live',
#  'chat',
#  'akun',
#  'sayadan',
#  'terima',
#  'bantu',
#  'bukalapakmohon',
#  'bantu',
#  'sulit',
#  'isi',
#  'atur',
#  'bukalapak',
#  'konsumen',
#  'betah',
#  'dagang',
#  'beli',
#  'rekomendasi',
#  'toko',
#  'online',
#  'akun',
#  'tibatiba',
#  'beku',
#  'baned',
#  'terima',
#  'pesan',
#  'feed',
#  'back',
#  'bagus',
#  'beli',
#  'tibatiba',
#  'akun',
#  'beku',
#  'rugi',
#  'bayar',
#  'iklan',
#  'gede',
#  'korban',
#  'biaya',
#  'star',
#  'seller',
#  'mahal',
#  'berat',
#  'jual',
#  'beli',
#  'item',
#  'higs',
#  'domino',
#  'bl',
#  'terap',
#  'produk',
#  'digital',
#  'kecewa',
#  'sih',
#  'kecewa',
#  'pesan',
#  'barang',
#  'komplain',
#  'bukalapak',
#  'error',
#  'komplain',
#  'kurir',
#  'jelas',
#  'komplain',
#  'asuransi',
#  'barang',
#  'hilang',
#  'kasih',
#  'bintang',
#  'buka',
#  'dompet',
#  'beku',
#  'chat',
#  'cs',
#  'kali',
#  'kali',
#  'nya',
#  'mohon',
#  'tunggu',
#  'cs',
#  'aa',
#  'bantu',
#  'cek',
#  'mohon',
#  'maaf',
#  'kendala',
#  'kakak',
#  'alami',
#  'tunggu',
#  'email',
#  'solusi',
#  'mohon',
#  'bukalapak',
#  'mudah',
#  'alami',
#  'jual',
#  'beli',
#  'bukti',
#  'ktpno',
#  'telphone',
#  'email',
#  'bukti',
#  'milik',
#  'akun',
#  'terimakasih',
#  'belakang',
#  'bukalapak',
#  'ribet',
#  'aplikasi',
#  'chat',
#  'customer',
#  'bukalapak',
#  'susah',
#  'tunggu',
#  'no',
#  'antri',
#  'nutup',
#  'sistem',
#  'aplikasi',
#  'terima',
#  'barang',
#  'terima',
#  'klik',
#  'cek',
#  'trecking',
#  'kirim',
#  'pakai',
#  'bukalapak',
#  'saran',
#  'kayak',
#  'nya',
#  'bukalapak',
#  'susupin',
#  'orang',
#  'shopee',
#  'lapak',
#  'pasang',
#  'harga',
#  'banget',
#  'shopee',
#  'harga',
#  'paruh',
#  'sekali',
#  'murah',
#  'tipu',
#  'barang',
#  'rusak',
#  'realpict',
#  'bikin',
#  'malas',
#  'beli',
#  'bukalapak',
#  'kapok',
#  'salah',
#  'kalo',
#  'orang',
#  'beli',
#  'online',
#  'belah',
#  'coba',
#  'pakai',
#  'bukalapak',
#  'daftar',
#  'paylater',
#  'wajib',
#  'banyak',
#  'transaksi',
#  'nya',
#  'paylater',
#  'bantu',
#  'transaksi',
#  'belanja',
#  'moga',
#  'mudah',
#  'ya',
#  'terimakasih',
#  'bukalapak',
#  'tolong',
#  'baik',
#  'muter',
#  'ajalihat',
#  'history',
#  'transaksi',
#  'susah',
#  'mainnumpuk',
#  'diserver',
#  'history',
#  'akunbuatlah',
#  'simpan',
#  'biar',
#  'muter',
#  'update',
#  'baru',
#  'nge',
#  'bug',
#  'menu',
#  'transaksi',
#  'loadingnya',
#  'suka',
#  'nge',
#  'hang',
#  'lebih',
#  'mantap',
#  'aplikasi',
#  'ampas',
#  'live',
#  'chat',
#  'jual',
#  'tipu',
#  'komplain',
#  'live',
#  'chat',
#  'bangkrut',
#  'hapus',
#  'aplikasi',
#  'play',
#  'store',
#  'bukalapk',
#  'sicepat',
#  'kurir',
#  'tautpi',
#  'berat',
#  'barang',
#  'kg',
#  'gramdi',
#  'hitung',
#  'kgdan',
#  'ahirnya',
#  'ongkir',
#  'potong',
#  'sayagak',
#  'aplikasi',
#  'ijoklo',
#  'komplin',
#  'langsung',
#  'atas',
#  'nomer',
#  'hp',
#  'daftar',
#  'aplikasi',
#  'lainemang',
#  'ganti',
#  'nomer',
#  'hp',
#  'daptar',
#  'alikasi',
#  'yahsangat',
#  'membingungkanlangsung',
#  'uninstal',
#  'aplikasi',
#  'mudah',
#  'ribet',
#  'kompalain',
#  'susah',
#  'ampun',
#  'kali',
#  'beli',
#  'barang',
#  'bayar',
#  'tpdiketangan',
#  'transaksi',
#  'bayar',
#  'komplen',
#  'susah',
#  'menu',
#  'komplain',
#  'parah',
#  'enak',
#  'pakai',
#  'aplikasi',
#  'eh',
#  'top',
#  'up',
#  'dana',
#  'top',
#  'up',
#  'nya',
#  'hasil',
#  'tarik',
#  'aplikasi',
#  'dompet',
#  'beku',
#  'tunggu',
#  'jam',
#  'dana',
#  'belu',
#  'cair',
#  'hadehh',
#  'hadehhh',
#  'asih',
#  'ktp',
#  'live',
#  'chat',
#  'ganti',
#  'sandi',
#  'guna',
#  'tingkat',
#  'biaya',
#  'potong',
#  'lapak',
#  'produk',
#  'digital',
#  'mahal',
#  'proses',
#  'transaksi',
#  'error',
#  'berat',
#  'apk',
#  'potong',
#  'mahal',
#  'forma',
#  'huhuhuuuuu',
#  'aplikasi',
#  'wadah',
#  'tipu',
#  'gampang',
#  'banget',
#  'tipu',
#  'tim',
#  'system',
#  'bobrok',
#  'beli',
#  'barang',
#  'terima',
#  'komplain',
#  'jawab',
#  'suruh',
#  'tunggu',
#  'alhasil',
#  'bukti',
#  'lapak',
#  'nyata',
#  'valid',
#  'tim',
#  'bukalapak',
#  'bukti',
#  'lapak',
#  'kirim',
#  'utama',
#  'untung',
#  'ya',
#  'bukalapak',
#  'lapak',
#  'untung',
#  'beli',
#  'rugi',
#  'belanja',
#  'aplikasi',
#  'bukalapak',
#  'bantu',
#  'proses',
#  'kirim',
#  'uang',
#  'mudah',
#  'langsung',
#  'cepat',
#  'tuju',
#  'rekening',
#  'mana',
#  'fitur',
#  'promonya',
#  'kirim',
#  'uang',
#  'fee',
#  'admin',
#  'promo',
#  'lainnyamataap',
#  'banget',
#  'dah',
#  'gunawan',
#  'mantab',
#  'menu',
#  'menu',
#  'simple',
#  'praktis',
#  'nyaman',
#  'mudah',
#  'paham',
#  'kayak',
#  'belah',
#  'lemottnya',
#  'ampun',
#  'menu',
#  'menu',
#  'bikin',
#  'bingung',
#  'praktis',
#  'malas',
#  'banget',
#  'pesan',
#  'kirim',
#  'bayar',
#  'cancel',
#  'sayang',
#  'banget',
#  'mahal',
#  'aju',
#  'komplen',
#  'balas',
#  'bayar',
#  'kirim',
#  'tanggal',
#  'april',
#  'tanggal',
#  'kurir',
#  'ambil',
#  'ambil',
#  'mls',
#  'banget',
#  'uang',
#  'pakai',
#  'woi',
#  'rugi',
#  'koneksi',
#  'server',
#  'masalah',
#  'minim',
#  'promo',
#  'ui',
#  'buruk',
#  'kalah',
#  'marketplace',
#  'belah',
#  'agt',
#  'operasi',
#  'aplikasi',
#  'praktis',
#  'cari',
#  'barang',
#  'urus',
#  'cari',
#  'profil',
#  'produk',
#  'favorit',
#  'mudah',
#  'update',
#  'des',
#  'ajib',
#  'nih',
#  'bukalapak',
#  'fiturfiturnya',
#  'mudah',
#  'cari',
#  'desain',
#  'layar',
#  'rapi',
#  'kayak',
#  'aplikasi',
#  'biru',
#  'bayar',
#  'belanja',
#  'pakai',
#  'dompet',
#  'hasil',
#  'jual',
#  'bl',
#  'solusi',
#  'nih',
#  'belanja',
#  'dipindahin',
#  'saldo',
#  'dana',
#  'kerna',
#  'limit',
#  'sia',
#  'sia',
#  'jual',
#  'barang',
#  'pakai',
#  'belanja',
#  'dipindahin',
#  'limit',
#  'tunggu',
#  'aplikasi',
#  'recomend',
#  'respon',
#  'live',
#  'chat',
#  'susah',
#  'super',
#  'live',
#  'chat',
#  'tunggu',
#  'kendala',
#  'selesai',
#  'susah',
#  'buka',
#  'aplikasi',
#  'loading',
#  'internet',
#  'lancar',
#  'belanja',
#  'buka',
#  'susah',
#  'tampil',
#  'menu',
#  'utama',
#  ...]

# %%
fqdist = FreqDist(tokenize_ulasan)

# %%
fqdist
# Out:
# FreqDist({'bukalapak': 500, 'aplikasi': 485, 'nya': 417, 'barang': 416, 'pakai': 249, 'buka': 242, 'kirim': 233, 'lapak': 224, 'belanja': 224, 'beli': 221, ...})

# %%
# mencetak 15 kata paling banyak digunakan
fqdist.most_common(15)
# Out:
# [('bukalapak', 500),
#  ('aplikasi', 485),
#  ('nya', 417),
#  ('barang', 416),
#  ('pakai', 249),
#  ('buka', 242),
#  ('kirim', 233),
#  ('lapak', 224),
#  ('belanja', 224),
#  ('beli', 221),
#  ('bayar', 210),
#  ('transaksi', 195),
#  ('bantu', 162),
#  ('jual', 157),
#  ('mudah', 144)]

# %%
import matplotlib.pyplot as plt

# plotting
fqdist.plot(10,cumulative=False)
plt.show()

# %%
label = []
for index, row in name_dataframe.iterrows():
    if row["Rating"] == 5 or row["Rating"] == 4:
        label.append(1)
    else:
        label.append(0)

name_dataframe["label"] = label

name_dataframe
# Out:
#             Nama pengguna  Rating                Date  \
# 0            Nizar Rayyan       1 2023-04-16 23:03:31
# 1              Fandy Komo       1 2023-05-05 02:37:25
# 2           Triadhi Purna       1 2023-05-19 12:12:22
# 3           Hendi Suhendi       3 2023-05-23 11:51:06
# 4               halim nur       1 2023-05-23 07:36:27
# ...                   ...     ...                 ...
# 1295      Pengguna Google       2 2018-11-24 10:55:14
# 1296        hendrik teguh       1 2023-05-04 01:34:09
# 1297           Sam Wijaya       1 2020-12-06 03:27:32
# 1298  SOFYAN BAZERGAN,SAP       3 2023-03-10 05:17:43
# 1299            Erfan Dwi       1 2023-04-06 13:59:36
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     tambah kesini buka lapak tambah kurang bagus p...
# 2     batal pesanan susah amat yak penjual awal bila...
# 3     min mautanya saya jual barang di bukalapak tap...
# 4     saya beli barang udah    tapi sistemnya kayak ...
# ...                                                 ...
# 1295  tidak ada tombol pembatalan pesanan di detail ...
# 1296  komplain belum ada kesepakatan udah keburu dit...
# 1297  aplikasi online shop paling lambat dan berat l...
# 1298  layanan tidak baik dan sangat lama responkaren...
# 1299  masa tambah saldo dana tidak bisa masuk dari t...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [batal, pesanan, susah, amat, yak, penjual, aw...
# 3     [min, mautanya, saya, jual, barang, di, bukala...
# 4     [saya, beli, barang, udah, tapi, sistemnya, ka...
# ...                                                 ...
# 1295  [tidak, ada, tombol, pembatalan, pesanan, di, ...
# 1296  [komplain, belum, ada, kesepakatan, udah, kebu...
# 1297  [aplikasi, online, shop, paling, lambat, dan, ...
# 1298  [layanan, tidak, baik, dan, sangat, lama, resp...
# 1299  [masa, tambah, saldo, dana, tidak, bisa, masuk...
#
#                                       Ulasan_normalized  \
# 0     [paylater, enggak, benar, selalu, di, batalkan...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [batal, pesanan, susah, amat, ya, penjual, awa...
# 3     [min, mautanya, saya, jual, barang, di, bukala...
# 4     [saya, beli, barang, sudah, tapi, sistemnya, k...
# ...                                                 ...
# 1295  [tidak, ada, tombol, pembatalan, pesanan, di, ...
# 1296  [komplain, belum, ada, kesepakatan, sudah, keb...
# 1297  [aplikasi, online, shop, paling, lambat, dan, ...
# 1298  [layanan, tidak, baik, dan, sangat, lama, resp...
# 1299  [masa, tambah, saldo, dana, tidak, bisa, masuk...
#
#                                     Ulasan_stop_removed  \
# 0     [paylater, batalkan, otomatis, kadang, nya, ga...
# 1     [kesini, buka, lapak, bagus, pelayanannya, kom...
# 2     [batal, pesanan, susah, ya, penjual, bilang, r...
# 3     [min, mautanya, jual, barang, bukalapak, baran...
# 4     [beli, barang, sistemnya, kayak, error, bayar,...
# ...                                                 ...
# 1295  [tombol, pembatalan, pesanan, detail, transaks...
# 1296  [komplain, kesepakatan, keburu, ditutup, penga...
# 1297  [aplikasi, online, shop, lambat, berat, load, ...
# 1298  [layanan, responkarena, call, cs, langsungsemu...
# 1299               [saldo, dana, masuk, tanggal, april]
#
#                                          Ulasan_Stemmed  \
# 0     [paylater, batal, otomatis, kadang, nya, ganti...
# 1     [kesini, buka, lapak, bagus, layan, komplan, s...
# 2     [batal, pesan, susah, ya, jual, bilang, ready,...
# 3     [min, mautanya, jual, barang, bukalapak, baran...
# 4     [beli, barang, sistem, kayak, error, bayar, it...
# ...                                                 ...
# 1295  [tombol, batal, pesan, detail, transaksi, hubu...
# 1296  [komplain, sepakat, keburu, tutup, ambil, dana...
# 1297  [aplikasi, online, shop, lambat, berat, load, ...
# 1298  [layan, responkarena, call, cs, langsungsemuan...
# 1299               [saldo, dana, masuk, tanggal, april]
#
#                                            Ulasan_clean  label
# 0     paylater batal otomatis kadang nya ganti jatuh...      0
# 1     kesini buka lapak bagus layan komplan susah su...      0
# 2     batal pesan susah ya jual bilang ready stok ha...      0
# 3     min mautanya jual barang bukalapak barang jual...      0
# 4     beli barang sistem kayak error bayar item sald...      0
# ...                                                 ...    ...
# 1295  tombol batal pesan detail transaksi hubung ban...      0
# 1296  komplain sepakat keburu tutup ambil dana ribet...      0
# 1297  aplikasi online shop lambat berat load data ce...      0
# 1298  layan responkarena call cs langsungsemuanya sa...      0
# 1299                     saldo dana masuk tanggal april      0
#
# [1300 rows x 10 columns]

# %%
#create a user define function to find out polarity & subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

#creating another user define function to label the sentiment 

def getSentiment(value):
    if value<0:
        return 'Negative'
    elif value==0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
name_dataframe.head()
# Out:
#    Nama pengguna  Rating                Date  \
# 0   Nizar Rayyan       1 2023-04-16 23:03:31
# 1     Fandy Komo       1 2023-05-05 02:37:25
# 2  Triadhi Purna       1 2023-05-19 12:12:22
# 3  Hendi Suhendi       3 2023-05-23 11:51:06
# 4      halim nur       1 2023-05-23 07:36:27
#
#                                               Ulasan  \
# 0  paylater ngk bener selalu di batalkan otomatis...
# 1  tambah kesini buka lapak tambah kurang bagus p...
# 2  batal pesanan susah amat yak penjual awal bila...
# 3  min mautanya saya jual barang di bukalapak tap...
# 4  saya beli barang udah    tapi sistemnya kayak ...
#
#                                      Ulasan_tokenize  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2  [batal, pesanan, susah, amat, yak, penjual, aw...
# 3  [min, mautanya, saya, jual, barang, di, bukala...
# 4  [saya, beli, barang, udah, tapi, sistemnya, ka...
#
#                                    Ulasan_normalized  \
# 0  [paylater, enggak, benar, selalu, di, batalkan...
# 1  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2  [batal, pesanan, susah, amat, ya, penjual, awa...
# 3  [min, mautanya, saya, jual, barang, di, bukala...
# 4  [saya, beli, barang, sudah, tapi, sistemnya, k...
#
#                                  Ulasan_stop_removed  \
# 0  [paylater, batalkan, otomatis, kadang, nya, ga...
# 1  [kesini, buka, lapak, bagus, pelayanannya, kom...
# 2  [batal, pesanan, susah, ya, penjual, bilang, r...
# 3  [min, mautanya, jual, barang, bukalapak, baran...
# 4  [beli, barang, sistemnya, kayak, error, bayar,...
#
#                                       Ulasan_Stemmed  \
# 0  [paylater, batal, otomatis, kadang, nya, ganti...
# 1  [kesini, buka, lapak, bagus, layan, komplan, s...
# 2  [batal, pesan, susah, ya, jual, bilang, ready,...
# 3  [min, mautanya, jual, barang, bukalapak, baran...
# 4  [beli, barang, sistem, kayak, error, bayar, it...
#
#                                         Ulasan_clean  label
# 0  paylater batal otomatis kadang nya ganti jatuh...      0
# 1  kesini buka lapak bagus layan komplan susah su...      0
# 2  batal pesan susah ya jual bilang ready stok ha...      0
# 3  min mautanya jual barang bukalapak barang jual...      0
# 4  beli barang sistem kayak error bayar item sald...      0

# %%
from textblob import TextBlob

# %%
def run_vader(name_dataframe):
    # Generate VADER sentiment analyzer object
    sid = SentimentIntensityAnalyzer()

# %%
name_dataframe['Polarity']=name_dataframe['Ulasan_clean'].apply(getPolarity)
name_dataframe['Subjectivity']=name_dataframe['Ulasan_clean'].apply(getSubjectivity)
name_dataframe['Sentiment']=name_dataframe['Polarity'].apply(getSentiment)
name_dataframe.head()
# Out:
#    Nama pengguna  Rating                Date  \
# 0   Nizar Rayyan       1 2023-04-16 23:03:31
# 1     Fandy Komo       1 2023-05-05 02:37:25
# 2  Triadhi Purna       1 2023-05-19 12:12:22
# 3  Hendi Suhendi       3 2023-05-23 11:51:06
# 4      halim nur       1 2023-05-23 07:36:27
#
#                                               Ulasan  \
# 0  paylater ngk bener selalu di batalkan otomatis...
# 1  tambah kesini buka lapak tambah kurang bagus p...
# 2  batal pesanan susah amat yak penjual awal bila...
# 3  min mautanya saya jual barang di bukalapak tap...
# 4  saya beli barang udah    tapi sistemnya kayak ...
#
#                                      Ulasan_tokenize  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2  [batal, pesanan, susah, amat, yak, penjual, aw...
# 3  [min, mautanya, saya, jual, barang, di, bukala...
# 4  [saya, beli, barang, udah, tapi, sistemnya, ka...
#
#                                    Ulasan_normalized  \
# 0  [paylater, enggak, benar, selalu, di, batalkan...
# 1  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2  [batal, pesanan, susah, amat, ya, penjual, awa...
# 3  [min, mautanya, saya, jual, barang, di, bukala...
# 4  [saya, beli, barang, sudah, tapi, sistemnya, k...
#
#                                  Ulasan_stop_removed  \
# 0  [paylater, batalkan, otomatis, kadang, nya, ga...
# 1  [kesini, buka, lapak, bagus, pelayanannya, kom...
# 2  [batal, pesanan, susah, ya, penjual, bilang, r...
# 3  [min, mautanya, jual, barang, bukalapak, baran...
# 4  [beli, barang, sistemnya, kayak, error, bayar,...
#
#                                       Ulasan_Stemmed  \
# 0  [paylater, batal, otomatis, kadang, nya, ganti...
# 1  [kesini, buka, lapak, bagus, layan, komplan, s...
# 2  [batal, pesan, susah, ya, jual, bilang, ready,...
# 3  [min, mautanya, jual, barang, bukalapak, baran...
# 4  [beli, barang, sistem, kayak, error, bayar, it...
#
#                                         Ulasan_clean  label  Polarity  \
# 0  paylater batal otomatis kadang nya ganti jatuh...      0       0.0
# 1  kesini buka lapak bagus layan komplan susah su...      0       0.0
# 2  batal pesan susah ya jual bilang ready stok ha...      0       0.2
# 3  min mautanya jual barang bukalapak barang jual...      0       0.0
# 4  beli barang sistem kayak error bayar item sald...      0       0.0
#
#    Subjectivity Sentiment
# 0           0.0   Neutral
# 1           0.0   Neutral
# 2           0.5  Positive
# 3           0.0   Neutral
# 4           0.0   Neutral

# %%
name_dataframe['month'] = name_dataframe['Date'].dt.month

# %%
name_dataframe
# Out:
#             Nama pengguna  Rating                Date  \
# 0            Nizar Rayyan       1 2023-04-16 23:03:31
# 1              Fandy Komo       1 2023-05-05 02:37:25
# 2           Triadhi Purna       1 2023-05-19 12:12:22
# 3           Hendi Suhendi       3 2023-05-23 11:51:06
# 4               halim nur       1 2023-05-23 07:36:27
# ...                   ...     ...                 ...
# 1295      Pengguna Google       2 2018-11-24 10:55:14
# 1296        hendrik teguh       1 2023-05-04 01:34:09
# 1297           Sam Wijaya       1 2020-12-06 03:27:32
# 1298  SOFYAN BAZERGAN,SAP       3 2023-03-10 05:17:43
# 1299            Erfan Dwi       1 2023-04-06 13:59:36
#
#                                                  Ulasan  \
# 0     paylater ngk bener selalu di batalkan otomatis...
# 1     tambah kesini buka lapak tambah kurang bagus p...
# 2     batal pesanan susah amat yak penjual awal bila...
# 3     min mautanya saya jual barang di bukalapak tap...
# 4     saya beli barang udah    tapi sistemnya kayak ...
# ...                                                 ...
# 1295  tidak ada tombol pembatalan pesanan di detail ...
# 1296  komplain belum ada kesepakatan udah keburu dit...
# 1297  aplikasi online shop paling lambat dan berat l...
# 1298  layanan tidak baik dan sangat lama responkaren...
# 1299  masa tambah saldo dana tidak bisa masuk dari t...
#
#                                         Ulasan_tokenize  \
# 0     [paylater, ngk, bener, selalu, di, batalkan, o...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [batal, pesanan, susah, amat, yak, penjual, aw...
# 3     [min, mautanya, saya, jual, barang, di, bukala...
# 4     [saya, beli, barang, udah, tapi, sistemnya, ka...
# ...                                                 ...
# 1295  [tidak, ada, tombol, pembatalan, pesanan, di, ...
# 1296  [komplain, belum, ada, kesepakatan, udah, kebu...
# 1297  [aplikasi, online, shop, paling, lambat, dan, ...
# 1298  [layanan, tidak, baik, dan, sangat, lama, resp...
# 1299  [masa, tambah, saldo, dana, tidak, bisa, masuk...
#
#                                       Ulasan_normalized  \
# 0     [paylater, enggak, benar, selalu, di, batalkan...
# 1     [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2     [batal, pesanan, susah, amat, ya, penjual, awa...
# 3     [min, mautanya, saya, jual, barang, di, bukala...
# 4     [saya, beli, barang, sudah, tapi, sistemnya, k...
# ...                                                 ...
# 1295  [tidak, ada, tombol, pembatalan, pesanan, di, ...
# 1296  [komplain, belum, ada, kesepakatan, sudah, keb...
# 1297  [aplikasi, online, shop, paling, lambat, dan, ...
# 1298  [layanan, tidak, baik, dan, sangat, lama, resp...
# 1299  [masa, tambah, saldo, dana, tidak, bisa, masuk...
#
#                                     Ulasan_stop_removed  \
# 0     [paylater, batalkan, otomatis, kadang, nya, ga...
# 1     [kesini, buka, lapak, bagus, pelayanannya, kom...
# 2     [batal, pesanan, susah, ya, penjual, bilang, r...
# 3     [min, mautanya, jual, barang, bukalapak, baran...
# 4     [beli, barang, sistemnya, kayak, error, bayar,...
# ...                                                 ...
# 1295  [tombol, pembatalan, pesanan, detail, transaks...
# 1296  [komplain, kesepakatan, keburu, ditutup, penga...
# 1297  [aplikasi, online, shop, lambat, berat, load, ...
# 1298  [layanan, responkarena, call, cs, langsungsemu...
# 1299               [saldo, dana, masuk, tanggal, april]
#
#                                          Ulasan_Stemmed  \
# 0     [paylater, batal, otomatis, kadang, nya, ganti...
# 1     [kesini, buka, lapak, bagus, layan, komplan, s...
# 2     [batal, pesan, susah, ya, jual, bilang, ready,...
# 3     [min, mautanya, jual, barang, bukalapak, baran...
# 4     [beli, barang, sistem, kayak, error, bayar, it...
# ...                                                 ...
# 1295  [tombol, batal, pesan, detail, transaksi, hubu...
# 1296  [komplain, sepakat, keburu, tutup, ambil, dana...
# 1297  [aplikasi, online, shop, lambat, berat, load, ...
# 1298  [layan, responkarena, call, cs, langsungsemuan...
# 1299               [saldo, dana, masuk, tanggal, april]
#
#                                            Ulasan_clean  label  Polarity  \
# 0     paylater batal otomatis kadang nya ganti jatuh...      0  0.000000
# 1     kesini buka lapak bagus layan komplan susah su...      0  0.000000
# 2     batal pesan susah ya jual bilang ready stok ha...      0  0.200000
# 3     min mautanya jual barang bukalapak barang jual...      0  0.000000
# 4     beli barang sistem kayak error bayar item sald...      0  0.000000
# ...                                                 ...    ...       ...
# 1295  tombol batal pesan detail transaksi hubung ban...      0  0.000000
# 1296  komplain sepakat keburu tutup ambil dana ribet...      0  0.000000
# 1297  aplikasi online shop lambat berat load data ce...      0  0.000000
# 1298  layan responkarena call cs langsungsemuanya sa...      0  0.136364
# 1299                     saldo dana masuk tanggal april      0  0.000000
#
#       Subjectivity Sentiment  month
# 0              0.0   Neutral      4
# 1              0.0   Neutral      5
# 2              0.5  Positive      5
# 3              0.0   Neutral      5
# 4              0.0   Neutral      5
# ...            ...       ...    ...
# 1295           0.0   Neutral     11
# 1296           0.0   Neutral      5
# 1297           0.0   Neutral     12
# 1298           0.5  Positive      3
# 1299           0.0   Neutral      4
#
# [1300 rows x 14 columns]

# %%
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
name_dataframe.head()
# Out:
#    Nama pengguna  Rating                Date  \
# 0   Nizar Rayyan       1 2023-04-16 23:03:31
# 1     Fandy Komo       1 2023-05-05 02:37:25
# 2  Triadhi Purna       1 2023-05-19 12:12:22
# 3  Hendi Suhendi       3 2023-05-23 11:51:06
# 4      halim nur       1 2023-05-23 07:36:27
#
#                                               Ulasan  \
# 0  paylater ngk bener selalu di batalkan otomatis...
# 1  tambah kesini buka lapak tambah kurang bagus p...
# 2  batal pesanan susah amat yak penjual awal bila...
# 3  min mautanya saya jual barang di bukalapak tap...
# 4  saya beli barang udah    tapi sistemnya kayak ...
#
#                                      Ulasan_tokenize  \
# 0  [paylater, ngk, bener, selalu, di, batalkan, o...
# 1  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2  [batal, pesanan, susah, amat, yak, penjual, aw...
# 3  [min, mautanya, saya, jual, barang, di, bukala...
# 4  [saya, beli, barang, udah, tapi, sistemnya, ka...
#
#                                    Ulasan_normalized  \
# 0  [paylater, enggak, benar, selalu, di, batalkan...
# 1  [tambah, kesini, buka, lapak, tambah, kurang, ...
# 2  [batal, pesanan, susah, amat, ya, penjual, awa...
# 3  [min, mautanya, saya, jual, barang, di, bukala...
# 4  [saya, beli, barang, sudah, tapi, sistemnya, k...
#
#                                  Ulasan_stop_removed  \
# 0  [paylater, batalkan, otomatis, kadang, nya, ga...
# 1  [kesini, buka, lapak, bagus, pelayanannya, kom...
# 2  [batal, pesanan, susah, ya, penjual, bilang, r...
# 3  [min, mautanya, jual, barang, bukalapak, baran...
# 4  [beli, barang, sistemnya, kayak, error, bayar,...
#
#                                       Ulasan_Stemmed  \
# 0  [paylater, batal, otomatis, kadang, nya, ganti...
# 1  [kesini, buka, lapak, bagus, layan, komplan, s...
# 2  [batal, pesan, susah, ya, jual, bilang, ready,...
# 3  [min, mautanya, jual, barang, bukalapak, baran...
# 4  [beli, barang, sistem, kayak, error, bayar, it...
#
#                                         Ulasan_clean  label  Polarity  \
# 0  paylater batal otomatis kadang nya ganti jatuh...      0       0.0
# 1  kesini buka lapak bagus layan komplan susah su...      0       0.0
# 2  batal pesan susah ya jual bilang ready stok ha...      0       0.2
# 3  min mautanya jual barang bukalapak barang jual...      0       0.0
# 4  beli barang sistem kayak error bayar item sald...      0       0.0
#
#    Subjectivity Sentiment  month
# 0           0.0   Neutral      4
# 1           0.0   Neutral      5
# 2           0.5  Positive      5
# 3           0.0   Neutral      5
# 4           0.0   Neutral      5

# %%
# Create scatter plot
sns.set_style('darkgrid')
plt.figure(figsize = (15,7))

markers = {'Positive':'o', 'Neutral':'s','Negative':'X'}

sns.scatterplot(data=name_dataframe, x='Polarity', y='Subjectivity', hue = 'Sentiment', style = 'Sentiment', markers = markers, palette = 'gist_earth').set(xlim=(-1,1))
plt.title('Scatter Plot')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')

plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group by month and sentiment
sentiment_df = name_dataframe.groupby(['month', 'Sentiment']).size().reset_index(name='Count')


# Plot the sentiment counts by month
plt.figure(figsize=(12, 6))
sns.lineplot(x='month', y='Count', hue='Sentiment', data=sentiment_df)
plt.title('Sentiment by Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %%
sentimen_data=pd.value_counts(name_dataframe["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["green", "red", "black"])
plt.title('Bar chart')
plt.show()

# %%
name_dataframe["Sentiment"].value_counts()
# Out:
# Neutral     1062
# Positive     189
# Negative      49
# Name: Sentiment, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
Ulasan = name_dataframe['Ulasan_clean']

# %%
Ulasan.isnull().sum()
# Out:
# 0

# %%
#untuk menghitung jumlah kata yang telah di steming
cv = CountVectorizer()
term_fit = cv.fit(Ulasan)

print (len(term_fit.vocabulary_))
# Out:
# 3715

# %%
term_fit.vocabulary_ #mengurutkan berdasarkan urutab abjad kata
# Out:
# {'paylater': 2486,
#  'batal': 301,
#  'otomatis': 2417,
#  'kadang': 1472,
#  'nya': 2327,
#  'ganti': 1150,
#  'jatuh': 1410,
#  'tempo': 3340,
#  'bayar': 308,
#  'biaya': 436,
#  'lambat': 1799,
#  'layan': 1841,
#  'biar': 432,
#  'rasa': 2755,
#  'sistem': 3139,
#  'enak': 1033,
#  'chat': 703,
#  'susah': 3243,
#  'error': 1048,
#  'salah': 2900,
#  'bikin': 444,
#  'pusing': 2732,
#  'kesini': 1597,
#  'buka': 550,
#  'lapak': 1815,
#  'bagus': 217,
#  'komplan': 1665,
#  'banget': 256,
#  'beberapakali': 317,
#  'transaksi': 3484,
#  'rekening': 2791,
#  'deh': 830,
#  'potong': 2665,
#  'verifikasi': 3609,
#  'kalo': 1489,
#  'pengin': 2561,
#  'komplain': 1663,
#  'menu': 2104,
#  'upload': 3583,
#  'bukti': 607,
#  'muncul': 2193,
#  'kali': 1485,
#  'hilang': 1276,
#  'uang': 3541,
#  'gagal': 1135,
#  'pesan': 2609,
#  'ya': 3691,
#  'jual': 1447,
#  'bilang': 445,
#  'ready': 2765,
#  'stok': 3208,
#  'habis': 1214,
#  'nomor': 2304,
#  'duit': 992,
#  'transfer': 3488,
#  'kirim': 1618,
#  'amplop': 116,
#  'kosong': 1697,
#  'beli': 345,
#  'cs': 761,
#  'bukabantuan': 551,
#  'kasih': 1509,
#  'template': 3339,
#  'kagak': 1474,
#  'solusi': 3171,
#  'suruh': 3240,
#  'tunggu': 3529,
#  'jam': 1395,
#  'batas': 303,
#  'proses': 2709,
#  'tuh': 3520,
#  'parah': 2467,
#  'asli': 189,
#  'dosa': 974,
#  'lu': 1940,
#  'tahan': 3266,
#  'rejeki': 2787,
#  'orang': 2402,
#  'paraaaahhhh': 2466,
#  'min': 2130,
#  'mautanya': 2043,
#  'barang': 279,
#  'bukalapak': 562,
#  'lihat': 1895,
#  'calon': 643,
#  'kecuali': 1535,
#  'link': 1902,
#  'akses': 68,
#  'kayak': 1519,
#  'item': 1378,
#  'saldo': 2903,
#  'kedaluarsa': 1536,
#  'satu': 2940,
#  'terang': 3352,
#  'pakai': 2444,
#  'kecewa': 1530,
#  'saat': 2890,
#  'kait': 1477,
#  'minta': 2143,
#  'kembali': 1556,
#  'dana': 796,
#  'penjualanpembatalan': 2574,
#  'notif': 2317,
#  'apl': 159,
#  'bulalapak': 611,
#  'nyanotif': 2340,
#  'email': 1026,
#  'tanggap': 3291,
#  'rugi': 2876,
#  'cek': 669,
#  'mohon': 2169,
#  'baik': 238,
#  'fitur': 1100,
#  'tolong': 3465,
#  'tabung': 3261,
#  'diskon': 937,
#  'banyak': 274,
#  'produk': 2691,
#  'langsung': 1811,
#  'fiture': 1101,
#  'cicil': 716,
#  'lunas': 1946,
#  'moga': 2168,
#  'maju': 1968,
#  'aplikasi': 165,
#  'trnsaksi': 3508,
#  'pulsa': 2724,
#  'berhasilpulsa': 389,
#  'masuktagihan': 2033,
#  'adakomplen': 24,
#  'urus': 3587,
#  'bantu': 268,
#  'live': 1908,
#  'mesin': 2122,
#  'olshop': 2376,
#  'rampog': 2750,
#  'paraaaaaaaahhhhh': 2465,
#  'dear': 825,
#  'check': 712,
#  'posisi': 2659,
#  'sana': 2925,
#  'loading': 1914,
#  'bug': 547,
#  'perhati': 2595,
#  'rusa': 2884,
#  'system': 3255,
#  'menggangu': 2094,
#  'guna': 1204,
#  'nyaman': 2336,
#  'dengar': 840,
#  'terima': 3364,
#  'bela': 333,
#  'penting': 2578,
#  'langgan': 1808,
#  'status': 3203,
#  'selesai': 3003,
#  'janji': 1403,
#  'minggu': 2132,
#  'iklan': 1310,
#  'halaman': 1229,
#  'klik': 1628,
#  'tinggal': 3434,
#  'bl': 476,
#  'ribet': 2839,
#  'super': 3234,
#  'seller': 3013,
#  'kuota': 1726,
#  'dagang': 788,
#  'antik': 145,
#  'unik': 3559,
#  'quota': 2736,
#  'promosi': 2704,
#  'toko': 3456,
#  'belah': 334,
#  'payleter': 2499,
#  'lancar': 1804,
#  'top': 3469,
#  'up': 3573,
#  'game': 1143,
#  'cancel': 645,
#  'sungguh': 3232,
#  'validpadahal': 3600,
#  'data': 813,
#  'kesal': 1592,
#  'login': 1919,
#  'download': 977,
#  'daftar': 786,
#  'jelek': 1424,
#  'lot': 1935,
#  'adu': 36,
#  'tele': 3325,
#  'kesana': 1593,
#  'kemari': 1553,
#  'coba': 722,
#  'cari': 654,
#  'koleksi': 1644,
#  'dikit': 906,
#  'cuman': 767,
#  'kalah': 1482,
#  'sepi': 3044,
#  'bulan': 612,
#  'laku': 1781,
#  'tokopedia': 3458,
#  'stagnan': 3196,
#  'greget': 1195,
#  'ol': 2373,
#  'shop': 3086,
#  'bukalapakygdulu': 595,
#  'kendala': 1566,
#  'belanja': 337,
#  'online': 2389,
#  'bonus': 510,
#  'credit': 756,
#  'ulas': 3552,
#  'senang': 3032,
#  'syarat': 3253,
#  'tentu': 3348,
#  'tahu': 3268,
#  'bst': 537,
#  'modal': 2163,
#  'pas': 2473,
#  'muterin': 2207,
#  'ambil': 111,
#  'feedback': 1087,
#  'akibat': 66,
#  'masuk': 2032,
#  'akun': 79,
#  'notifikasi': 2318,
#  'sampah': 2917,
#  'tsbt': 3515,
#  'mati': 2039,
#  'makan': 1972,
#  'aktif': 71,
#  'pilih': 2626,
#  'zonk': 3712,
#  'hapus': 1244,
#  'alhasil': 94,
#  'langgar': 1809,
#  'saran': 2932,
#  'kapai': 1494,
#  'tampil': 3280,
#  'benarbenar': 356,
#  'tata': 3309,
#  'tipu': 3442,
#  'palak': 2454,
#  'puas': 2718,
#  'bantuannyasaya': 269,
#  'alami': 85,
#  'sulit': 3229,
#  'logindikarenakan': 1921,
#  'kode': 1641,
#  'otp': 2419,
#  'aktifmau': 76,
#  'sayadan': 2946,
#  'bukalapakmohon': 578,
#  'isi': 1375,
#  'atur': 198,
#  'konsumen': 1686,
#  'betah': 420,
#  'rekomendasi': 2797,
#  'tibatiba': 3417,
#  'beku': 328,
#  'baned': 255,
#  'feed': 1086,
#  'back': 209,
#  'gede': 1161,
#  'korban': 1695,
#  'star': 3200,
#  'mahal': 1962,
#  'berat': 374,
#  'higs': 1274,
#  'domino': 966,
#  'terap': 3353,
#  'digital': 888,
#  'sih': 3113,
#  'kurir': 1733,
#  'jelas': 1422,
#  'asuransi': 193,
#  'bintang': 449,
#  'dompet': 968,
#  'aa': 0,
#  'maaf': 1955,
#  'kakak': 1479,
#  'mudah': 2179,
#  'ktpno': 1714,
#  'telphone': 3332,
#  'milik': 2128,
#  'terimakasih': 3368,
#  'belakang': 336,
#  'customer': 775,
#  'no': 2295,
#  'antri': 147,
#  'nutup': 2326,
#  'trecking': 3498,
#  'susupin': 3250,
#  'shopee': 3088,
#  'pasang': 2474,
#  'harga': 1247,
#  'paruh': 2472,
#  'sekali': 2987,
#  'murah': 2199,
#  'rusak': 2885,
#  'realpict': 2769,
#  'malas': 1977,
#  'kapok': 1496,
#  'wajib': 3643,
#  'muter': 2206,
#  'ajalihat': 54,
#  'history': 1280,
#  'mainnumpuk': 1966,
#  'diserver': 935,
#  'akunbuatlah': 80,
#  'simpan': 3121,
#  'update': 3574,
#  'baru': 292,
#  'nge': 2249,
#  'loadingnya': 1916,
#  'suka': 3224,
#  'hang': 1239,
#  'lebih': 1855,
#  'mantap': 2001,
#  'ampas': 115,
#  'bangkrut': 261,
#  'play': 2640,
#  'store': 3210,
#  'bukalapk': 596,
#  'sicepat': 3108,
#  'tautpi': 3311,
#  'kg': 1608,
#  'gramdi': 1193,
#  'hitung': 1282,
#  'kgdan': 1609,
#  'ahirnya': 45,
#  'ongkir': 2382,
#  'sayagak': 2947,
#  'ijoklo': 1307,
#  'komplin': 1670,
#  'atas': 195,
#  'nomer': 2302,
#  'hp': 1288,
#  'lainemang': 1770,
#  'daptar': 805,
#  'alikasi': 97,
#  'yahsangat': 3694,
#  'membingungkanlangsung': 2070,
#  'uninstal': 3561,
#  'kompalain': 1655,
#  'ampun': 117,
#  'tpdiketangan': 3475,
#  'komplen': 1667,
#  'eh': 1012,
#  'hasil': 1252,
#  'tarik': 3308,
#  'belu': 353,
#  'cair': 638,
#  'hadehh': 1217,
#  'hadehhh': 1218,
#  'asih': 186,
#  'ktp': 1713,
#  'sandi': 2926,
#  'tingkat': 3435,
#  'apk': 157,
#  'forma': 1113,
#  'huhuhuuuuu': 1296,
#  'wadah': 3638,
#  'gampang': 1144,
#  'tim': 3426,
#  'bobrok': 503,
#  'jawab': 1411,
#  'nyata': 2344,
#  'valid': 3598,
#  'utama': 3593,
#  'untung': 3572,
#  'cepat': 683,
#  'tuju': 3522,
#  'mana': 1985,
#  'promonya': 2701,
#  'fee': 1085,
#  'admin': 33,
#  'promo': 2700,
#  'lainnyamataap': 1772,
#  'dah': 789,
#  'gunawan': 1210,
#  'mantab': 1997,
#  'simple': 3126,
#  'praktis': 2674,
#  'paham': 2438,
#  'lemottnya': 1872,
#  'bingung': 446,
#  'sayang': 2949,
#  'aju': 61,
#  'balas': 247,
#  'tanggal': 3290,
#  'april': 177,
#  'mls': 2155,
#  'woi': 3683,
#  'koneksi': 1677,
#  'server': 3059,
#  'masalah': 2024,
#  'minim': 2135,
#  'ui': 3545,
#  'buruk': 617,
#  'marketplace': 2018,
#  'agt': 43,
#  'operasi': 2395,
#  'profil': 2696,
#  'favorit': 1079,
#  'des': 845,
#  'ajib': 59,
#  'nih': 2285,
#  'fiturfiturnya': 1104,
#  'desain': 847,
#  'layar': 1846,
#  'rapi': 2754,
#  'biru': 452,
#  'dipindahin': 919,
#  'kerna': 1590,
#  'limit': 1897,
#  'sia': 3100,
#  'recomend': 2772,
#  'respon': 2821,
#  'internet': 1365,
#  'sudahlama': 3221,
#  'retur': 2831,
#  'kaya': 1518,
#  'uninstall': 3563,
#  'asa': 184,
#  'aman': 104,
#  'sesuai': 3068,
#  'hati': 1254,
#  'hubung': 1293,
#  'aplkasi': 171,
#  'iniakun': 1338,
#  'kena': 1562,
#  'hack': 1215,
#  'tagih': 3264,
#  'steam': 3204,
#  'vcr': 3606,
#  'bajak': 240,
#  'manusia': 2010,
#  'dewa': 856,
#  'enggak': 1039,
#  'semacem': 3019,
#  'bisa': 454,
#  'tlng': 3450,
#  'terkaitdevelop': 3376,
#  'tangan': 3289,
#  'dikecewain': 900,
#  'tutup': 3537,
#  'tanggapinnya': 3296,
#  'formulir': 1116,
#  'gratis': 1194,
#  'boongan': 512,
#  'ribu': 2846,
#  'jnt': 1440,
#  'sellernya': 3016,
#  'nyantumin': 2341,
#  'cod': 725,
#  'bohong': 505,
#  'siniudah': 3132,
#  'capek': 651,
#  'ngetikpas': 2265,
#  'tulis': 3525,
#  'jdinya': 1419,
#  'terimatpi': 3370,
#  'reportnya': 2808,
#  'bingungmo': 447,
#  'pasrah': 2475,
#  'an': 120,
#  'tanggapin': 3295,
#  'tahun': 3269,
#  'benah': 354,
#  'kabur': 1467,
#  'bel': 332,
#  'ok': 2365,
#  'alhamdulillah': 93,
#  'sengketa': 3037,
#  'diskusi': 940,
#  'butuh': 625,
#  'aplaus': 160,
#  'normal': 2313,
#  'aneh': 129,
#  'ikan': 1308,
#  'hias': 1270,
#  'pakan': 2449,
#  'ganggu': 1149,
#  'minus': 2146,
#  'voucher': 3630,
#  'penuh': 2579,
#  'jasa': 1409,
#  'ekspedisi': 1016,
#  'gudang': 1201,
#  'bukaexpress': 558,
#  'livechat': 1910,
#  'fungsi': 1125,
#  'beda': 318,
#  'merchant': 2113,
#  'obrol': 2357,
#  'aktifin': 74,
#  'hangus': 1240,
#  'kyc': 1742,
#  'sory': 3179,
#  'ane': 128,
#  'join': 1442,
#  'kepercayan': 1579,
#  'ecom': 1004,
#  'aktifasi': 72,
#  'sumpah': 3231,
#  'enek': 1038,
#  'masak': 2021,
#  'sefty': 2981,
#  'main': 1965,
#  'lo': 1912,
#  'nyataanya': 2345,
#  'aktivasi': 77,
#  'pinjam': 2632,
#  'bank': 265,
#  'sumpaah': 3230,
#  'oohh': 2392,
#  'devlover': 855,
#  'lebay': 1854,
#  'foto': 1117,
#  'ktprekening': 1716,
#  'seribet': 3052,
#  'kah': 1476,
#  'cantumin': 648,
#  'ubah': 3542,
#  'tipenyasaya': 3441,
#  'paket': 2451,
#  'ngechek': 2255,
#  'internetdi': 1366,
#  'nglungker': 2273,
#  'tambah': 3278,
#  'jenuhtlg': 1430,
#  'emas': 1030,
#  'bukaemas': 557,
#  'problem': 2689,
#  'bad': 212,
#  'gateway': 1157,
#  'ulang': 3551,
#  'sengaja': 3036,
#  'investasi': 1369,
#  'app': 173,
#  'simpel': 3125,
#  'ajabanyak': 50,
#  'sisrem': 3138,
#  'gunabuka': 1205,
#  'ajaisi': 52,
#  'harap': 1246,
#  'buang': 543,
#  'ajadan': 51,
#  'bagusmasuk': 227,
#  'ribetnya': 2841,
#  'didownload': 884,
#  'touch': 3474,
#  'az': 207,
#  'repot': 2809,
#  'cumq': 768,
#  'temu': 3341,
#  'gaya': 1158,
#  'unjung': 3566,
#  'kadaluarsamau': 1470,
#  'canggih': 646,
#  'sadah': 2893,
#  'kembaliini': 1559,
#  'kepastianpayah': 1576,
#  'sesal': 3065,
#  'gue': 1202,
#  'dibukalapak': 876,
#  'fiturnya': 1105,
#  'aco': 13,
#  'pelit': 2530,
#  'nonaktif': 2308,
#  'set': 3071,
#  'profesional': 2694,
#  'beban': 314,
#  'and': 123,
#  'smartphone': 3157,
#  'piara': 2621,
#  'manfaat': 1990,
#  'mitra': 2151,
#  'dalem': 794,
#  'refund': 2783,
#  'detik': 853,
#  'erti': 1050,
#  'biyaya': 474,
#  'maksud': 1975,
#  'sesak': 3064,
#  'sgitu': 3078,
#  'ilangin': 1315,
#  'tuhklo': 3521,
#  'kurang': 1730,
#  'kepakasa': 1573,
#  'blanja': 478,
#  'saking': 2899,
#  'chip': 714,
#  'snapdragon': 3165,
#  'gen': 1164,
#  'ram': 2745,
#  'gb': 1159,
#  'clear': 721,
#  'chace': 698,
#  'logout': 1924,
#  'expedisi': 1065,
#  'reg': 2785,
#  'next': 2236,
#  'day': 817,
#  'pick': 2622,
#  'lelet': 1856,
#  'criss': 757,
#  'cross': 759,
#  'sop': 3174,
#  'resi': 2816,
#  'ybs': 3700,
#  'percaya': 2592,
#  'depan': 842,
#  'buset': 621,
#  'pajang': 2442,
#  'hebat': 1260,
#  'lenya': 1881,
#  'berbelanjatapi': 375,
#  'dam': 795,
#  'halapalagi': 1232,
#  'sistemnyakecewa': 3142,
#  'telat': 3322,
#  'report': 2807,
#  'bermasalahpaket': 406,
#  'jadwal': 1390,
#  'kompensasi': 1659,
#  'jamin': 1398,
#  'kembalihanya': 1558,
#  'slogan': 3154,
#  'belakabagaimana': 335,
#  'payleater': 2497,
#  'bukalapaksaya': 585,
#  'lagibukti': 1754,
#  'struknya': 3215,
#  'kasir': 1514,
#  'indomart': 1330,
#  'yeah': 3701,
#  'tagihantapi': 3265,
#  'kecewadimana': 1531,
#  'sedia': 2977,
#  'codtapi': 730,
#  'express': 1067,
#  'nali': 2218,
#  'pribadi': 2680,
#  'beliau': 346,
#  'riwayat': 2861,
#  'paylatternya': 2496,
#  'pemberitahuan': 2542,
#  'januari': 1405,
#  'jugasudah': 1455,
#  'bukalapaksungguh': 588,
#  'sukses': 3227,
#  'konfirmasi': 1679,
#  'turunin': 3534,
#  'eror': 1046,
#  'sayapadahal': 2950,
#  'label': 1744,
#  'cekout': 671,
#  'catat': 665,
#  'metode': 2124,
#  'inipadahal': 1345,
#  'gilir': 1176,
#  'mending': 2084,
#  'keren': 1584,
#  'saing': 2895,
#  'ketat': 1598,
#  'kompetitor': 1662,
#  'yuk': 3707,
#  'buru': 616,
#  'konsisten': 1682,
#  'timbul': 3428,
#  'tenggelam': 3346,
#  'loh': 1925,
#  'hehee': 1262,
#  'andal': 124,
#  'way': 3661,
#  'pusat': 2729,
#  'opsi': 2397,
#  'cetak': 696,
#  'helooo': 1265,
#  'syaa': 3252,
#  'buyer': 627,
#  'driver': 985,
#  'user': 3590,
#  'friendly': 1122,
#  'payah': 2484,
#  'bukareksauang': 602,
#  'setatusy': 3073,
#  'selesaidikomplen': 3004,
#  'transfermasuk': 3489,
#  'tanggung': 3300,
#  'jawabpaylater': 1417,
#  'rusuhmasih': 2887,
#  'belbel': 343,
#  'terusruwed': 3398,
#  'sabar': 2891,
#  'kece': 1529,
#  'pasti': 2479,
#  'mesan': 2121,
#  'mes': 2120,
#  'rokok': 2867,
#  'pindah': 2631,
#  'kartu': 1501,
#  'sd': 2959,
#  'setia': 3075,
#  'flashdeal': 1109,
#  'shake': 3081,
#  'thon': 3412,
#  'dapat': 801,
#  'perak': 2583,
#  'thx': 3414,
#  'tinjau': 3438,
#  'dc': 822,
#  'screen': 2957,
#  'shot': 3098,
#  'wa': 3636,
#  'tindak': 3431,
#  'lanjut': 1813,
#  'call': 641,
#  'center': 679,
#  'via': 3617,
#  'dadi': 784,
#  'action': 14,
#  'kak': 1478,
#  'estimasi': 1052,
#  'transit': 3493,
#  'pay': 2482,
#  'later': 1835,
#  'ah': 44,
#  'ngisi': 2269,
#  'cash': 660,
#  'lom': 1932,
#  'tau': 3310,
#  'telepon': 3326,
#  'muas': 2177,
#  'jawabannyacoba': 1412,
#  'tanggepin': 3297,
#  'tlong': 3451,
#  'jgbuat': 1434,
#  'bantumakin': 273,
#  'hubungin': 1295,
#  'chatlemot': 705,
#  'turun': 3533,
#  'lag': 1748,
#  'karuan': 1502,
#  'kredit': 1705,
#  'pending': 2557,
#  'bukalapakeh': 568,
#  'suami': 3217,
#  'jutamasa': 1461,
#  'blokir': 489,
#  'bajakhrsny': 242,
#  'pesanannyakan': 2613,
#  'rp': 2871,
#  'byr': 633,
#  'vamandiri': 3601,
#  'pembyran': 2545,
#  'auto': 201,
#  'transferpenarikkan': 3490,
#  'upgrade': 3581,
#  'premium': 2677,
#  'bari': 291,
#  'nominal': 2303,
#  'elektronik': 1022,
#  'gabung': 1131,
#  'darp': 809,
#  'nyaedaaaan': 2332,
#  'peras': 2585,
#  'its': 1381,
#  'sense': 3039,
#  'lari': 1833,
#  'dodol': 963,
#  'penilain': 2569,
#  'kasihan': 1510,
#  'danatransfer': 799,
#  'lemotbukan': 1868,
#  'lemotaplikasinya': 1865,
#  'perbaikimasi': 2589,
#  'ringan': 2856,
#  'orangemasa': 2405,
#  'utuma': 3596,
#  'bos': 516,
#  'dikatan': 899,
#  'itu': 1382,
#  'antusias': 148,
#  'sydah': 3254,
#  'hynaevinv': 1300,
#  'dicancelsejak': 880,
#  'sampaiudah': 2921,
#  'loohhhkembalikan': 1934,
#  'ongkirnya': 2385,
#  'sadar': 2894,
#  'gunakanauto': 1207,
#  'uninstaljika': 3562,
#  'paylaternya': 2488,
#  'trmksih': 3507,
#  'chating': 704,
#  'info': 1333,
#  'nagih': 2211,
#  'hutang': 1298,
#  'vocer': 3626,
#  'hijau': 1275,
#  'orange': 2403,
#  'full': 1123,
#  'cantum': 647,
#  'kolom': 1645,
#  'detail': 851,
#  'batalin': 302,
#  'jugasedangkan': 1454,
#  'gunakanharus': 1208,
#  'mengadutolong': 2086,
#  'lapakbiar': 1816,
#  'keluh': 1550,
#  'developer': 854,
#  'lazada': 1847,
#  'tiktok': 3425,
#  'minimal': 2136,
#  'wajar': 3641,
#  'orentiktok': 2410,
#  'layak': 1840,
#  'ketimbang': 1605,
#  'wkwk': 3676,
#  'bisnis': 473,
#  'limpah': 1898,
#  'mantaab': 1996,
#  'markotopmaknyosss': 2019,
#  'baikbaiiiil': 239,
#  'masalahsudah': 2028,
#  'jalan': 1394,
#  'keluarketika': 1549,
#  'etik': 1056,
#  'putus': 2735,
#  'sambung': 2913,
#  'nyakalo': 2334,
#  'menggu': 2095,
#  'yohana': 3702,
#  'nama': 2219,
#  'nunggusaaya': 2324,
#  'ngetiikkkk': 2264,
#  'shopie': 3092,
#  'servernya': 3060,
#  'jaya': 1418,
#  'amanah': 106,
#  'bukamall': 598,
#  'complainnya': 740,
#  'complain': 738,
#  'digunain': 891,
#  'tandailike': 3285,
#  'checkout': 713,
#  'dibatalin': 871,
#  'maksa': 1973,
#  'bentar': 363,
#  'pokok': 2652,
#  'telp': 3330,
#  'custemservis': 773,
#  'ngurusinya': 2279,
#  'chatlive': 706,
#  'ngelunasin': 2260,
#  'hari': 1248,
#  'kerja': 1586,
#  'informasj': 1335,
#  'rating': 2758,
#  'pisah': 2634,
#  'barangsaya': 286,
#  'codpembayaran': 729,
#  'tunai': 3526,
#  'wifi': 3671,
#  'lemmooottttt': 1860,
#  'dasar': 811,
#  'transsaksi': 3496,
#  'tawar': 3312,
#  'tanda': 3284,
#  'baca': 208,
#  'pencet': 2556,
#  'konten': 1689,
#  'webnya': 3664,
#  'lumayan': 1944,
#  'curiga': 772,
#  'free': 1120,
#  'jenis': 1429,
#  'ttup': 3518,
#  'efisien': 1010,
#  'hemat': 1266,
#  'duduk': 990,
#  'manis': 1993,
#  'rumah': 2877,
#  'low': 1937,
#  'cost': 750,
#  'ngirit': 2268,
#  'undang': 3556,
#  'teman': 3336,
#  'refferal': 2779,
#  'account': 10,
#  'berani': 372,
#  'kontak': 1687,
#  'rumit': 2878,
#  'danabukalapak': 797,
#  'trimakasih': 3502,
#  'inovatif': 1349,
#  'lamaproses': 1794,
#  'lamarespon': 1795,
#  'lamabru': 1786,
#  'bukalapakternyata': 590,
#  'lamaaaa': 1784,
#  'slow': 3155,
#  'responfix': 2823,
#  'ecommerce': 1006,
#  'cocok': 724,
#  'all': 99,
#  'one': 2380,
#  'feature': 1082,
#  'klaim': 1626,
#  'hak': 1226,
#  'refundlangsung': 2784,
#  'customermau': 777,
#  'barangpake': 283,
#  'dikomplen': 907,
#  'kejelasannyakatanya': 1541,
#  'diprosesmana': 924,
#  'ribed': 2838,
#  'menindaklanjuti': 2100,
#  'instal': 1353,
#  'nipu': 2292,
#  'donload': 972,
#  'bangst': 263,
#  'platform': 2639,
#  'mnrut': 2160,
#  'acc': 9,
#  'good': 1186,
#  'job': 1441,
#  'paforitmisal': 2436,
#  'ketik': 1603,
#  'minyak': 2147,
#  'paforit': 2435,
#  'situ': 3145,
#  'doang': 961,
#  'bukatabungan': 606,
#  'total': 3472,
#  'sisa': 3136,
#  'tranksaksi': 3482,
#  'tranksasi': 3483,
#  'layanananya': 1843,
#  'parahhhhhhhhhhh': 2469,
#  'resa': 2811,
#  'belanjatop': 341,
#  'palyeter': 2457,
#  'akulaku': 78,
#  'nilai': 2290,
#  'ruang': 2872,
#  'tutupdi': 3538,
#  'tlfn': 3449,
#  'marah': 2012,
#  'ku': 1717,
#  'abuabu': 5,
#  'takut': 3275,
#  'tipa': 3439,
#  'bangkai': 259,
#  'alas': 88,
#  'alamat': 84,
#  'komen': 1646,
#  'kasar': 1506,
#  'chatnya': 707,
#  'block': 488,
#  'anjiiinbg': 138,
#  'mengecewakanaman': 2088,
#  'customertingkatkan': 779,
#  'prestasi': 2679,
#  'blspy': 493,
#  'padaha': 2428,
#  'diberikankalau': 874,
#  'ditambh': 944,
#  'claim': 719,
#  'ikhlas': 1309,
#  'dgunakan': 860,
#  'watelpon': 3658,
#  'membingunkan': 2071,
#  'ceo': 682,
#  'asugak': 192,
#  'belilama': 349,
#  'kemarin': 1554,
#  'kompain': 1653,
#  'ceat': 668,
#  'langanan': 1807,
#  'alam': 83,
#  'rekomen': 2795,
#  'fasilitas': 1077,
#  'prifasi': 2681,
#  'histori': 1279,
#  'obatproduk': 2356,
#  'dewasa': 858,
#  'sebagainyaitu': 2964,
#  'prifasitrims': 2682,
#  'token': 3455,
#  'listrik': 1906,
#  'virtual': 3620,
#  'kadaluarsa': 1469,
#  'kmna': 1631,
#  ...}

# %%
#kolom pertama ini berarti jumlah dokumen
#kolom kedua berarti letak katanya
#kolom ketiga hasil dari tf

term_frequency_all = term_fit.transform(Ulasan)
print (term_frequency_all)
# Out:
#   (0, 301)	1
#   (0, 308)	1
#   (0, 432)	1
#   (0, 436)	2
#   (0, 444)	1
#   (0, 703)	1
#   (0, 1033)	1
#   (0, 1048)	1
#   (0, 1150)	2
#   (0, 1410)	1
#   (0, 1472)	2
#   (0, 1799)	1
#   (0, 1841)	2
#   (0, 2327)	3
#   (0, 2417)	1
#   (0, 2486)	1
#   (0, 2732)	2
#   (0, 2755)	2
#   (0, 2900)	1
#   (0, 3139)	1
#   (0, 3243)	1
#   (0, 3340)	1
#   (1, 217)	1
#   (1, 256)	1
#   (1, 308)	2
#   :	:
#   (1298, 1288)	1
#   (1298, 1395)	1
#   (1298, 1812)	1
#   (1298, 1841)	1
#   (1298, 1846)	1
#   (1298, 1908)	2
#   (1298, 2039)	1
#   (1298, 2327)	1
#   (1298, 2417)	1
#   (1298, 2580)	1
#   (1298, 2748)	1
#   (1298, 2824)	1
#   (1298, 2876)	1
#   (1298, 2932)	1
#   (1298, 3109)	1
#   (1298, 3139)	1
#   (1298, 3330)	1
#   (1298, 3434)	1
#   (1298, 3537)	2
#   (1298, 3617)	1
#   (1299, 177)	1
#   (1299, 796)	1
#   (1299, 2032)	1
#   (1299, 2903)	1
#   (1299, 3290)	1

# %%
ulasan_tf = Ulasan[1] #memanggil kata pada index ke 1
print (ulasan_tf)
# Out:
# kesini buka lapak bagus layan komplan susah susah banget beberapakali transaksi rekening deh potong buka lapak verifikasi kalo pengin komplain menu upload bukti bayar muncul kali kali hilang uang bayar gagal verifikasi

# %%
term_frequency = term_fit.transform([ulasan_tf]) #hanya menampilkan hasil document 1
print (term_frequency)
# Out:
#   (0, 217)	1
#   (0, 256)	1
#   (0, 308)	2
#   (0, 317)	1
#   (0, 550)	2
#   (0, 607)	1
#   (0, 830)	1
#   (0, 1135)	1
#   (0, 1276)	1
#   (0, 1485)	2
#   (0, 1489)	1
#   (0, 1597)	1
#   (0, 1663)	1
#   (0, 1665)	1
#   (0, 1815)	2
#   (0, 1841)	1
#   (0, 2104)	1
#   (0, 2193)	1
#   (0, 2561)	1
#   (0, 2665)	1
#   (0, 2791)	1
#   (0, 3243)	2
#   (0, 3484)	1
#   (0, 3541)	1
#   (0, 3583)	1
#   (0, 3609)	2

# %%
dokumen = term_fit.transform(Ulasan) #hasil perhitungan tf idf dalam 1 doc
tfidf_transformer = TfidfTransformer().fit(dokumen)
print (tfidf_transformer.idf_)

tfidf=tfidf_transformer.transform(term_frequency)
print (tfidf) #hasil manual dengan sistem pyhton
# Out:
# [7.4777413  6.78459412 7.07227619 ... 6.78459412 7.4777413  7.4777413 ]
#   (0, 3609)	0.3425337686596205
#   (0, 3583)	0.17904442784182825
#   (0, 3541)	0.14079907767032493
#   (0, 3484)	0.11331024273860953
#   (0, 3243)	0.2607953522522633
#   (0, 2791)	0.18711238167515384
#   (0, 2665)	0.17126688432981024
#   (0, 2561)	0.22506963557639953
#   (0, 2193)	0.1562202345283951
#   (0, 2104)	0.1539830741996479
#   (0, 1841)	0.12965216743341795
#   (0, 1815)	0.2169645926257395
#   (0, 1665)	0.27036439643502047
#   (0, 1663)	0.12647546186391787
#   (0, 1597)	0.17245242957716675
#   (0, 1489)	0.12715766871854586
#   (0, 1485)	0.2776884582641652
#   (0, 1276)	0.1512004792145182
#   (0, 1135)	0.16792704467117442
#   (0, 830)	0.15187630993111406
#   (0, 607)	0.1951803355084794
#   (0, 550)	0.2102969985063292
#   (0, 317)	0.27036439643502047
#   (0, 308)	0.22615244642424798
#   (0, 256)	0.1275036607427557
#   (0, 217)	0.11780433738681376

# %%
data_label = name_dataframe[["Nama pengguna", "Ulasan_clean", "Sentiment"]]

# %%
data_label["Ulasan_clean"] = data_label["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-70-5732072d6cca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label["Ulasan_clean"] = data_label["Ulasan_clean"].fillna("tidak ada komentar")

# %%
data_label.to_excel("data_label.xlsx")

# %%
sentimen_data=pd.value_counts(data_label["Sentiment"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["#ccd5ae"])
plt.title('Bar chart')
plt.show()

# %%
plt.figure(figsize=(16, 6))

heatmap = sns.heatmap(name_dataframe.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12)

plt.tight_layout()

# %%
name_dataframe.columns
# Out:
# Index(['Nama pengguna', 'Rating', 'Date', 'Ulasan', 'Ulasan_tokenize',
#        'Ulasan_normalized', 'Ulasan_stop_removed', 'Ulasan_Stemmed',
#        'Ulasan_clean', 'label', 'Polarity', 'Subjectivity', 'Sentiment',
#        'month'],
#       dtype='object')

# %%
train_s3 = data_label[data_label["Sentiment"] == 'Neutral']

# %%
train_s3["Ulasan_clean"] = train_s3["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-76-0d6c2c4956f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s3["Ulasan_clean"] = train_s3["Ulasan_clean"].fillna("tidak ada komentar")

# %%
all_text_s0 = ' '.join(word for word in train_s3["Ulasan_clean"])
wordcloud = WordCloud(colormap='gist_stern', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s0)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
print("Neutral words")
plt.show()
# Out:
# Neutral words

# %%
from wordcloud import WordCloud

# %%
train_s0 = data_label[data_label["Sentiment"] == 'Negative']

# %%
train_s0["Ulasan_clean"] = train_s0["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-80-4a391e85ccb2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s0["Ulasan_clean"] = train_s0["Ulasan_clean"].fillna("tidak ada komentar")

# %%
train_s0
# Out:
#                 Nama pengguna  \
# 45                imam maliki
# 53              Afifur Rohman
# 60    Kaloka Galih Kayu Wangi
# 61               Bam Hendrian
# 112                    eH boy
# 131        haidar dabi kataro
# 139           hidayat mudaris
# 147             Candra Wijaya
# 240               Endi irawan
# 266                    Lemuel
# 279             Sutris Trisno
# 303            Arjuna Pratama
# 310                  Ucu Imen
# 346            Silva Widianti
# 347      Dony Settia Official
# 353              Bayu Arsandi
# 358               Fudin Fudin
# 473              tri mulyanto
# 474               david james
# 475          Achenk Chonsleth
# 479                 Trade Day
# 498                  Nyon bae
# 503           Novi Nurhalimah
# 507                Ahmad Amek
# 522              Cucu Latipah
# 534             Annisa Arifah
# 536             ari hariyanto
# 537                   Hambali
# 592             inaya putry26
# 699                Tegar Ibnu
# 742     Ulfa Mar'atus Solihah
# 818         Oktavdian Sonjaya
# 837           Pengguna Google
# 846               Najwa Jemur
# 864           Pengguna Google
# 869           Pengguna Google
# 875                 Hr Tester
# 932           Pengguna Google
# 998                 Fian Syah
# 1036              Vaka Vaka13
# 1064      Armand Arya Firdaus
# 1100               Dhani Deff
# 1124           Muhammad Basir
# 1147          Brandal Cimanuk
# 1154          Pengguna Google
# 1155             wisnu arifin
# 1193              dita 210496
# 1274          Pengguna Google
# 1276          Pengguna Google
#
#                                            Ulasan_clean Sentiment
# 45    hati hubung akun aplkasi iniakun kena hack tra...  Negative
# 53    aplikasi bagus minus ongkir mahal voucher paka...  Negative
# 60    jual emas bukaemas susah banget banget problem...  Negative
# 61    kesini sistem nya berat ajabanyak sisrem gunab...  Negative
# 112   developer bukalapak lihat aplikasi shopee laza...  Negative
# 131   proses konfirmasi nya lamaproses kirim nya lam...  Negative
# 139   tolong rumit verifikasi akun saldo bukalapak p...  Negative
# 147   aplikasi bangkai belanja barang minggu bayar a...  Negative
# 240   beli barang nonfisik chip game inti barang fis...  Negative
# 266   mohon maaf kasih bintang alas hubung cs via ch...  Negative
# 279   guna setia bltp perlahan alih toko online lain...  Negative
# 303   tanggal beli unit powerbank merek soulkarena f...  Negative
# 310   hati hati download aplikasi korban bayar lunas...  Negative
# 346   tagih paylater bl resah kanbelum jatuh tempo a...  Negative
# 347   kali kecewa kembali refund dana masuk dompet s...  Negative
# 353             seller slow respon pesan batal otomatis  Negative
# 358                barang lengkap minimal gratis ongkir  Negative
# 473   kecewa kali belanja lapak merespon pesan batas...  Negative
# 474   order alamat kirim laku lapak bilang kode book...  Negative
# 475   lumayan bagus minus sedia menu layan varian pr...  Negative
# 479   kecewa sihketika voucher voucher alas voucher ...  Negative
# 498   aplikasi guna ganti nomor hp kirim foto ktp ga...  Negative
# 503   kecewa aplikasi bukalapak telat bayar jatuh te...  Negative
# 507   maaf turun bintangnyakarena pakai bukalapak pa...  Negative
# 522   sengaja bintang biar baca isi saldo atm tangga...  Negative
# 534   kecewa sellernya fiturnya live chat susah tamb...  Negative
# 536   parah bukalapak komplen klaim barang sulit pot...  Negative
# 537   rekan saran belanja bukalapak bayak tipu salah...  Negative
# 592   aplikasi nya visa live chat maju bukalapak pes...  Negative
# 699   sih asih voucher gratis ongkir minimal potong ...  Negative
# 742   edit ulas hubung customer care aplikasi kait b...  Negative
# 818      suka bingung bonus credit nya ya plus minus ya  Negative
# 837   heran aplikasi upload jual barang kaya susahhh...  Negative
# 846   kalo bukalapak rame tampil barang jual bayar i...  Negative
# 864   baik servernya fitur macet traffict diserver j...  Negative
# 869   bukastruk gagal struk identifikasi deteksi dup...  Negative
# 875   aplikasi bagus bantu kendala admin komplain me...  Negative
# 932   kurangtapi suka dwngan tampil bukalapak update...  Negative
# 998   barang pesan langsung aju komplain selesai isi...  Negative
# 1036  bingung komentar apasly ssh cari minus kkurang...  Negative
# 1064  aplikasi bukalapak seller oriented bukalapak g...  Negative
# 1100  kesini bagus aplikasi buka chat loading tampil...  Negative
# 1124  sussh seller tmbhin varian prdukgk kayak tkope...  Negative
# 1147  jual gambar kosong alas barang hapus tampil ya...  Negative
# 1154  baharu akun email username error pakai transak...  Negative
# 1155  aplikasi belanja mepersulit melakukakan ubah d...  Negative
# 1193  respon customer center susah komplain barang s...  Negative
# 1274  bagus sih jual gampang fiturnya mudah lapak op...  Negative
# 1276  bukalapak update beres koneksi bagus wifi kenc...  Negative

# %%
all_text_s0 = ' '.join(word for word in train_s0["Ulasan_clean"])
wordcloud = WordCloud(colormap='Reds', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s0)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
print("Negatif words")
plt.show()
# Out:
# Negatif words

# %%
train_s1 = data_label[data_label["Sentiment"] == 'Positive']

# %%
train_s1["Ulasan_clean"] = train_s1["Ulasan_clean"].fillna("tidak ada komentar")
# Out:
# <ipython-input-84-89653e0cae75>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s1["Ulasan_clean"] = train_s1["Ulasan_clean"].fillna("tidak ada komentar")

# %%
train_s1
# Out:
#                   Nama pengguna  \
# 2                 Triadhi Purna
# 7     Servis Tv CIPANAS CIANJUR
# 10            Fahmi Nugroho art
# 11               Achmad Rifandi
# 19              Muhammad Arsyad
# ...                         ...
# 1275            Pengguna Google
# 1279                 Hilmy leon
# 1287               Nur Auliyanu
# 1292            Pengguna Google
# 1298        SOFYAN BAZERGAN,SAP
#
#                                            Ulasan_clean Sentiment
# 2     batal pesan susah ya jual bilang ready stok ha...  Positive
# 7     aplikasi parah trnsaksi pulsa berhasilpulsa ma...  Positive
# 10    iklan halaman pakai klik tinggal bl ribet supe...  Positive
# 11    payleter bayar lancar payleter nya pakai top u...  Positive
# 19    mohon bantuannyasaya alami sulit logindikarena...  Positive
# ...                                                 ...       ...
# 1275  bukalapak semenjak baru bugbuka notif lamamasu...  Positive
# 1279  burukkk top up saldo juta masuk cs oper tunggu...  Positive
# 1287  parah bukalapak chat live tari dana nya lambat...  Positive
# 1292  kasih bintang bug nya baik komisi aplikasi bel...  Positive
# 1298  layan responkarena call cs langsungsemuanya sa...  Positive
#
# [189 rows x 3 columns]

# %%
all_text_s1 = ' '.join(word for word in train_s1["Ulasan_clean"])
wordcloud = WordCloud(colormap='Blues', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s1)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Ulasan Positif")
plt.margins(x=0, y=0)
print("Positif words")
plt.show()
# Out:
# Positif words

# %%
data_label['Ulasan_clean'] = data_label['Ulasan_clean'].fillna("tidak ada komentar")
# Out:
# <ipython-input-87-27b828896519>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['Ulasan_clean'] = data_label['Ulasan_clean'].fillna("tidak ada komentar")

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_clean'], data_label['Sentiment'], 
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(data_label['Ulasan_clean'])

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, data_label['Sentiment'], test_size=0.2, random_state=42)

# Train the Gaussian Naive Bayes classifier on the training set
gnb = GaussianNB()
gnb.fit(X_train.toarray(), y_train)

# Evaluate the classifier on the testing set
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)

# Use the classifier to predict the sentiment class for all reviews in the dataset
data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# Save the resulting dataframe to a new CSV file
data_label.to_csv('predicted_sentiment1.csv', index=False)
# Out:
# Accuracy: 0.5692307692307692
# <ipython-input-165-35ea0f31f4f4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['predicted_sentiment_class'] = gnb.predict(X.toarray())

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# Gaussian Naive Bayes with original data
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_gnb = gnb.predict(X_test)
print('Original Results:')
print(classification_report(y_test, y_gnb))
print(confusion_matrix(y_test, y_gnb))
print('Accuracy with original test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with undersampling
rus = RandomUnderSampler(random_state=1)
X_rus, y_rus = rus.fit_resample(X_train, y_train)
gnb = GaussianNB()
gnb.fit(X_rus, y_rus)
y_gnb = gnb.predict(X_test)
print('Undersampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with undersampling test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with oversampling
smote = SMOTE(random_state=1)
X_smote, y_smote = smote.fit_resample(X_train, y_train)
gnb = GaussianNB()
gnb.fit(X_smote, y_smote)
y_gnb = gnb.predict(X_test)
print('Oversampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with oversampling test data:', accuracy_score(y_test, y_gnb))

# Gaussian Naive Bayes with combined oversampling and undersampling
rus = RandomUnderSampler(random_state=1)
X_rus, y_rus = rus.fit_resample(X_train, y_train)

smote = SMOTE(random_state=1)
X_smt, y_smt = smote.fit_resample(X_rus, y_rus)

gnb = GaussianNB()
gnb.fit(X_smt, y_smt)
y_gnb = gnb.predict(X_test)
print('Combined Oversampling and Undersampling Results:')
print(classification_report(y_test, y_gnb))
print('Accuracy with combined oversampling and undersampling test data:', accuracy_score(y_test, y_gnb))
# Out:
# Original Results:
#               precision    recall  f1-score   support
#
#     Negative       0.05      0.09      0.06        11
#      Neutral       0.85      0.59      0.69       209
#     Positive       0.26      0.60      0.36        40
#
#     accuracy                           0.57       260
#    macro avg       0.38      0.43      0.37       260
# weighted avg       0.72      0.57      0.62       260
#
# [[  1   8   2]
#  [ 19 123  67]
#  [  2  14  24]]
# Accuracy with original test data: 0.5692307692307692
# Undersampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.09      0.64      0.16        11
#      Neutral       0.94      0.41      0.57       209
#     Positive       0.23      0.53      0.32        40
#
#     accuracy                           0.43       260
#    macro avg       0.42      0.52      0.35       260
# weighted avg       0.80      0.43      0.51       260
#
# Accuracy with undersampling test data: 0.4346153846153846
# Oversampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.05      0.09      0.06        11
#      Neutral       0.85      0.59      0.69       209
#     Positive       0.26      0.60      0.36        40
#
#     accuracy                           0.57       260
#    macro avg       0.38      0.43      0.37       260
# weighted avg       0.72      0.57      0.62       260
#
# Accuracy with oversampling test data: 0.5692307692307692
# Combined Oversampling and Undersampling Results:
#               precision    recall  f1-score   support
#
#     Negative       0.09      0.64      0.16        11
#      Neutral       0.94      0.41      0.57       209
#     Positive       0.23      0.53      0.32        40
#
#     accuracy                           0.43       260
#    macro avg       0.42      0.52      0.35       260
# weighted avg       0.80      0.43      0.51       260
#
# Accuracy with combined oversampling and undersampling test data: 0.4346153846153846

# %%
import numpy as np

# %%
from sklearn.feature_extraction.text import TfidfVectorizer             #menghitung n menjumlah kan dan menjumlah kan tf and n berdasarkan seluruh dokumen 
vectorizer = TfidfVectorizer(decode_error='replace', encoding='utf-8')

# %%
data_label['predicted_sentiment_class'].value_counts()
# Out:
# Neutral     897
# Positive    320
# Negative     83
# Name: predicted_sentiment_class, dtype: int64

# %%
data_label['predicted_sentiment_class'].hist()
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# **sample random**
#
# mengambil secara acak dari daftar sample atau sampling frame yang tersedia setiap individu memiliki peluang yang sama untuk terpilih
# peluang tersebut ada melakukan peluang sama ketika mempunyai data besar akan memliki peluang lebih besar untuk terpilih tetapi sebaliknya ketika mempunyai data dikit dapat peluang lebih sedikit

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_clean'], data_label['Sentiment'], 
                                                    test_size=0.1, stratify=data_label['Sentiment'], random_state=30)

# Vectorize the text data
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# Create the Naive Bayes Classifier object
gnb = GaussianNB()

# Perform cross-validation
scores = cross_val_score(gnb, X_train.toarray(), y_train, cv=5)

# Print the cross-validation scores
print('Cross-validation scores:', scores)

# Fit the classifier to the training data
gnb.fit(X_train.toarray(), y_train)

# Predict the sentiment of the test data
y_pred = gnb.predict(X_test.toarray())

# Print the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:\n', conf_matrix)
# Out:
# Cross-validation scores: [0.59401709 0.56410256 0.61111111 0.60683761 0.57692308]
# Confusion Matrix:
#  [[ 1  3  1]
#  [ 8 62 36]
#  [ 0 14  5]]

# %%
# Convert sparse matrix to dense numpy array
X_train_dense = X_train.toarray()
X_test_dense = X_test.toarray()

# Print the scores on the training and test sets
print('Training set score: {:.4f}'.format(gnb.score(X_train_dense, y_train)))
print('Test set score: {:.4f}'.format(gnb.score(X_test_dense, y_test)))
# Out:
# Training set score: 0.8846
# Test set score: 0.5231

# %%
accuracy = gnb.score(X_test.toarray(), y_test)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.5230769230769231

# %%
vectorizer
# Out:
# TfidfVectorizer()

# %%
nb = GaussianNB(var_smoothing=1.0) # untuk tidak overviting

# %%
data_label
# Out:
#             Nama pengguna                                       Ulasan_clean  \
# 0            Nizar Rayyan  paylater batal otomatis kadang nya ganti jatuh...
# 1              Fandy Komo  kesini buka lapak bagus layan komplan susah su...
# 2           Triadhi Purna  batal pesan susah ya jual bilang ready stok ha...
# 3           Hendi Suhendi  min mautanya jual barang bukalapak barang jual...
# 4               halim nur  beli barang sistem kayak error bayar item sald...
# ...                   ...                                                ...
# 1295      Pengguna Google  tombol batal pesan detail transaksi hubung ban...
# 1296        hendrik teguh  komplain sepakat keburu tutup ambil dana ribet...
# 1297           Sam Wijaya  aplikasi online shop lambat berat load data ce...
# 1298  SOFYAN BAZERGAN,SAP  layan responkarena call cs langsungsemuanya sa...
# 1299            Erfan Dwi                     saldo dana masuk tanggal april
#
#      Sentiment predicted_sentiment_class
# 0      Neutral                   Neutral
# 1      Neutral                   Neutral
# 2     Positive                  Positive
# 3      Neutral                   Neutral
# 4      Neutral                   Neutral
# ...        ...                       ...
# 1295   Neutral                   Neutral
# 1296   Neutral                   Neutral
# 1297   Neutral                   Neutral
# 1298  Positive                  Positive
# 1299   Neutral                  Positive
#
# [1300 rows x 4 columns]

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
print('--------------------- confusion matrix  ----------------------------')
print(confusion_matrix(y_test, y_pred))
print('--------------------- classification report  ----------------------------')
print(classification_report(y_test, y_pred))
# Out:
# --------------------- confusion matrix  ----------------------------
# [[ 1  3  1]
#  [ 8 62 36]
#  [ 0 14  5]]
# --------------------- classification report  ----------------------------
#               precision    recall  f1-score   support
#
#     Negative       0.11      0.20      0.14         5
#      Neutral       0.78      0.58      0.67       106
#     Positive       0.12      0.26      0.16        19
#
#     accuracy                           0.52       130
#    macro avg       0.34      0.35      0.33       130
# weighted avg       0.66      0.52      0.58       130

# %%
TP = cm[0,0]
TN = cm[1,1]
FP = cm[0,1]
FN = cm[1,0]

# %%
# print classification error kesalahan klasifikasi 

classification_error = (FP + FN) / float(TP + TN + FP + FN)

print('Classification error : {0:0.4f}'.format(classification_error))
# Out:
# Classification error : 0.1486

# %%
classification_accuracy = (TP + TN) / float(TP + TN + FP + FN)

print('Classification accuracy : {0:0.4f}'.format(classification_accuracy))
# Out:
# Classification accuracy : 0.8514

# %%
# visualize confusion matrix with seaborn heatmap

cm_matrix = pd.DataFrame(data=cm, columns=['Negative:1', 'Neutral:0', 'Positive:2'], 
                                 index=['Negative:1', 'Neutral:0', 'Positive:2'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <Axes: >

# %%
X_test
# Out:
# <130x3480 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1531 stored elements in Compressed Sparse Row format>

# %%
X_train
# Out:
# <1170x3480 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16590 stored elements in Compressed Sparse Row format>

# %%
y_test
# Out:
# 375      Neutral
# 1250     Neutral
# 932     Negative
# 1127     Neutral
# 229      Neutral
#           ...
# 1174    Positive
# 957      Neutral
# 425      Neutral
# 108      Neutral
# 899      Neutral
# Name: Sentiment, Length: 130, dtype: object

# %%
y_train
# Out:
# 1182     Neutral
# 460      Neutral
# 81       Neutral
# 512      Neutral
# 616      Neutral
#           ...
# 421      Neutral
# 102     Positive
# 766      Neutral
# 279     Negative
# 1073     Neutral
# Name: Sentiment, Length: 1170, dtype: object

# %%
print(y_train)
# Out:
# 1182     Neutral
# 460      Neutral
# 81       Neutral
# 512      Neutral
# 616      Neutral
#           ...
# 421      Neutral
# 102     Positive
# 766      Neutral
# 279     Negative
# 1073     Neutral
# Name: Sentiment, Length: 1170, dtype: object

# %%
# visualize confusion matrix with seaborn heatmap

cm_matrix = pd.DataFrame(data=cm, columns=['Negative:1', 'Neutral:0', 'Positive:2'], 
                                 index=['Negative:1', 'Neutral:0', 'Positive:2'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <Axes: >

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
print('Confusion matrix\n\n', cm)
# Out:
# Confusion matrix
#
#  [[ 1  3  1]
#  [ 8 62 36]
#  [ 0 14  5]]

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
# Regresi Logistik
logreg = LogisticRegression()
# SVM
svm = SVC(probability=True)

# %%
logreg.fit(X_train, y_train)
svm.fit(X_train, y_train)
# Out:
# SVC(probability=True)

# %%
y_pred1_logreg = logreg.predict(X_test)
y_pred1_svm = svm.predict(X_test)

# %%
print('---------------  Regresi Logistik  -------------------')
print(classification_report(y_test, y_pred1_logreg))
print('--------------------- SVM ----------------------------')
print(classification_report(y_test, y_pred1_svm))
# Out:
# ---------------  Regresi Logistik  -------------------
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         5
#      Neutral       0.83      1.00      0.91       106
#     Positive       1.00      0.11      0.19        19
#
#     accuracy                           0.83       130
#    macro avg       0.61      0.37      0.37       130
# weighted avg       0.82      0.83      0.77       130
#
# --------------------- SVM ----------------------------
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         5
#      Neutral       0.83      1.00      0.91       106
#     Positive       1.00      0.16      0.27        19
#
#     accuracy                           0.84       130
#    macro avg       0.61      0.39      0.39       130
# weighted avg       0.83      0.84      0.78       130
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
